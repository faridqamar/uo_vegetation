# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %%
num_of_bins = 22
filtersize = 2
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 22
# [[0, 38], [38, 76], [76, 114], [114, 152], [152, 190], [190, 228], [228, 266], [266, 304], [304, 342], [342, 380], [380, 418], [418, 456], [456, 494], [494, 532], [532, 570], [570, 608], [608, 646], [646, 684], [684, 722], [722, 760], [760, 798], [798, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 22)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 22)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 22) (60, 22)
# clouds  (400, 22) (100, 22)
# vegetation  (480, 22) (120, 22)
# water  (40, 22) (10, 22)
# built  (816, 22) (204, 22)
# windows  (400, 22) (100, 22)
# roads  (24, 22) (6, 22)
# cars  (80, 22) (20, 22)
# metal  (80, 22) (20, 22)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 22) (2560,) (2560, 2)
# (640, 22) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 153ms/step - loss: 2.0527 - accuracy: 0.2602 - val_loss: 1.8299 - val_accuracy: 0.3187
# Epoch 2/200
# 5/5 [==============================] - 0s 54ms/step - loss: 1.7734 - accuracy: 0.3328 - val_loss: 1.6784 - val_accuracy: 0.3516
# Epoch 3/200
# 5/5 [==============================] - 0s 40ms/step - loss: 1.6598 - accuracy: 0.4465 - val_loss: 1.5623 - val_accuracy: 0.5891
# Epoch 4/200
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5516 - accuracy: 0.5742 - val_loss: 1.4394 - val_accuracy: 0.6281
# Epoch 5/200
# 5/5 [==============================] - 0s 30ms/step - loss: 1.4451 - accuracy: 0.5789 - val_loss: 1.2985 - val_accuracy: 0.6406
# Epoch 6/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.3127 - accuracy: 0.6086 - val_loss: 1.1720 - val_accuracy: 0.6406
# Epoch 7/200
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2014 - accuracy: 0.6215 - val_loss: 1.0759 - val_accuracy: 0.6531
# Epoch 8/200
# 5/5 [==============================] - 0s 33ms/step - loss: 1.1215 - accuracy: 0.6332 - val_loss: 0.9961 - val_accuracy: 0.6578
# Epoch 9/200
# 5/5 [==============================] - 0s 32ms/step - loss: 1.0516 - accuracy: 0.6359 - val_loss: 0.9398 - val_accuracy: 0.6641
# Epoch 10/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.9994 - accuracy: 0.6562 - val_loss: 0.8897 - val_accuracy: 0.7359
# Epoch 11/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9560 - accuracy: 0.6594 - val_loss: 0.8590 - val_accuracy: 0.6922
# Epoch 12/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.9235 - accuracy: 0.6785 - val_loss: 0.8204 - val_accuracy: 0.7141
# Epoch 13/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8911 - accuracy: 0.6895 - val_loss: 0.7915 - val_accuracy: 0.7219
# Epoch 14/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8702 - accuracy: 0.7004 - val_loss: 0.7662 - val_accuracy: 0.7437
# Epoch 15/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8372 - accuracy: 0.7082 - val_loss: 0.7473 - val_accuracy: 0.7500
# Epoch 16/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8125 - accuracy: 0.7316 - val_loss: 0.7237 - val_accuracy: 0.7609
# Epoch 17/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7896 - accuracy: 0.7340 - val_loss: 0.7046 - val_accuracy: 0.7484
# Epoch 18/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7712 - accuracy: 0.7508 - val_loss: 0.6854 - val_accuracy: 0.8094
# Epoch 19/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7503 - accuracy: 0.7590 - val_loss: 0.6654 - val_accuracy: 0.8094
# Epoch 20/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7158 - accuracy: 0.7684 - val_loss: 0.6471 - val_accuracy: 0.8484
# Epoch 21/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6954 - accuracy: 0.7855 - val_loss: 0.6276 - val_accuracy: 0.8109
# Epoch 22/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6767 - accuracy: 0.7855 - val_loss: 0.6081 - val_accuracy: 0.8188
# Epoch 23/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6714 - accuracy: 0.7953 - val_loss: 0.5988 - val_accuracy: 0.8328
# Epoch 24/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.6393 - accuracy: 0.8043 - val_loss: 0.5716 - val_accuracy: 0.8281
# Epoch 25/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6336 - accuracy: 0.7988 - val_loss: 0.5576 - val_accuracy: 0.8219
# Epoch 26/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6141 - accuracy: 0.8125 - val_loss: 0.5466 - val_accuracy: 0.8484
# Epoch 27/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5948 - accuracy: 0.8148 - val_loss: 0.5273 - val_accuracy: 0.8219
# Epoch 28/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5865 - accuracy: 0.8160 - val_loss: 0.5217 - val_accuracy: 0.8578
# Epoch 29/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5709 - accuracy: 0.8160 - val_loss: 0.5022 - val_accuracy: 0.8391
# Epoch 30/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5707 - accuracy: 0.8230 - val_loss: 0.4989 - val_accuracy: 0.8281
# Epoch 31/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5315 - accuracy: 0.8445 - val_loss: 0.4799 - val_accuracy: 0.8703
# Epoch 32/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5374 - accuracy: 0.8367 - val_loss: 0.4738 - val_accuracy: 0.8484
# Epoch 33/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5167 - accuracy: 0.8344 - val_loss: 0.4608 - val_accuracy: 0.8422
# Epoch 34/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5249 - accuracy: 0.8391 - val_loss: 0.4548 - val_accuracy: 0.8766
# Epoch 35/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5146 - accuracy: 0.8355 - val_loss: 0.4437 - val_accuracy: 0.8703
# Epoch 36/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4922 - accuracy: 0.8480 - val_loss: 0.4327 - val_accuracy: 0.8594
# Epoch 37/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4780 - accuracy: 0.8520 - val_loss: 0.4323 - val_accuracy: 0.8797
# Epoch 38/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4825 - accuracy: 0.8504 - val_loss: 0.4212 - val_accuracy: 0.8719
# Epoch 39/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4855 - accuracy: 0.8531 - val_loss: 0.4164 - val_accuracy: 0.8844
# Epoch 40/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4750 - accuracy: 0.8508 - val_loss: 0.4113 - val_accuracy: 0.8828
# Epoch 41/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4615 - accuracy: 0.8582 - val_loss: 0.4051 - val_accuracy: 0.8828
# Epoch 42/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4507 - accuracy: 0.8609 - val_loss: 0.3948 - val_accuracy: 0.8891
# Epoch 43/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4473 - accuracy: 0.8586 - val_loss: 0.3991 - val_accuracy: 0.8719
# Epoch 44/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4448 - accuracy: 0.8602 - val_loss: 0.3829 - val_accuracy: 0.8922
# Epoch 45/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4404 - accuracy: 0.8664 - val_loss: 0.3799 - val_accuracy: 0.8906
# Epoch 46/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4326 - accuracy: 0.8633 - val_loss: 0.3735 - val_accuracy: 0.8922
# Epoch 47/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4248 - accuracy: 0.8699 - val_loss: 0.3712 - val_accuracy: 0.8922
# Epoch 48/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4142 - accuracy: 0.8687 - val_loss: 0.3657 - val_accuracy: 0.8922
# Epoch 49/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4234 - accuracy: 0.8691 - val_loss: 0.3623 - val_accuracy: 0.8922
# Epoch 50/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4096 - accuracy: 0.8734 - val_loss: 0.3583 - val_accuracy: 0.8922
# Epoch 51/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4187 - accuracy: 0.8684 - val_loss: 0.3537 - val_accuracy: 0.8828
# Epoch 52/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4043 - accuracy: 0.8777 - val_loss: 0.3494 - val_accuracy: 0.8922
# Epoch 53/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4020 - accuracy: 0.8719 - val_loss: 0.3457 - val_accuracy: 0.8922
# Epoch 54/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3995 - accuracy: 0.8672 - val_loss: 0.3462 - val_accuracy: 0.8859
# Epoch 55/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4060 - accuracy: 0.8691 - val_loss: 0.3397 - val_accuracy: 0.8922
# Epoch 56/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4019 - accuracy: 0.8727 - val_loss: 0.3456 - val_accuracy: 0.8969
# Epoch 57/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3868 - accuracy: 0.8785 - val_loss: 0.3400 - val_accuracy: 0.8875
# Epoch 58/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3951 - accuracy: 0.8719 - val_loss: 0.3368 - val_accuracy: 0.8969
# Epoch 59/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3871 - accuracy: 0.8840 - val_loss: 0.3279 - val_accuracy: 0.8922
# Epoch 60/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3853 - accuracy: 0.8680 - val_loss: 0.3257 - val_accuracy: 0.8938
# Epoch 61/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3799 - accuracy: 0.8848 - val_loss: 0.3262 - val_accuracy: 0.8922
# Epoch 62/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3707 - accuracy: 0.8762 - val_loss: 0.3176 - val_accuracy: 0.8938
# Epoch 63/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3696 - accuracy: 0.8852 - val_loss: 0.3177 - val_accuracy: 0.9016
# Epoch 64/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3748 - accuracy: 0.8781 - val_loss: 0.3116 - val_accuracy: 0.8922
# Epoch 65/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3646 - accuracy: 0.8832 - val_loss: 0.3111 - val_accuracy: 0.8984
# Epoch 66/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3670 - accuracy: 0.8859 - val_loss: 0.3100 - val_accuracy: 0.8953
# Epoch 67/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3593 - accuracy: 0.8855 - val_loss: 0.3115 - val_accuracy: 0.8984
# Epoch 68/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3701 - accuracy: 0.8809 - val_loss: 0.3060 - val_accuracy: 0.8953
# Epoch 69/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3560 - accuracy: 0.8898 - val_loss: 0.3094 - val_accuracy: 0.8969
# Epoch 70/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3590 - accuracy: 0.8863 - val_loss: 0.3014 - val_accuracy: 0.8922
# Epoch 71/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3487 - accuracy: 0.8887 - val_loss: 0.2991 - val_accuracy: 0.9047
# Epoch 72/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3451 - accuracy: 0.8941 - val_loss: 0.2934 - val_accuracy: 0.9000
# Epoch 73/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3511 - accuracy: 0.8859 - val_loss: 0.2968 - val_accuracy: 0.9016
# Epoch 74/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3390 - accuracy: 0.8934 - val_loss: 0.2950 - val_accuracy: 0.9000
# Epoch 75/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3384 - accuracy: 0.8906 - val_loss: 0.2888 - val_accuracy: 0.9016
# Epoch 76/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3434 - accuracy: 0.8926 - val_loss: 0.2898 - val_accuracy: 0.9062
# Epoch 77/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3428 - accuracy: 0.8941 - val_loss: 0.2883 - val_accuracy: 0.9047
# Epoch 78/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3339 - accuracy: 0.8930 - val_loss: 0.2833 - val_accuracy: 0.9094
# Epoch 79/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3287 - accuracy: 0.8945 - val_loss: 0.2822 - val_accuracy: 0.9000
# Epoch 80/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3261 - accuracy: 0.8984 - val_loss: 0.2809 - val_accuracy: 0.9062
# Epoch 81/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3273 - accuracy: 0.8977 - val_loss: 0.2823 - val_accuracy: 0.9000
# Epoch 82/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3314 - accuracy: 0.8898 - val_loss: 0.2776 - val_accuracy: 0.9062
# Epoch 83/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3213 - accuracy: 0.8953 - val_loss: 0.2904 - val_accuracy: 0.9062
# Epoch 84/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3282 - accuracy: 0.8945 - val_loss: 0.2766 - val_accuracy: 0.9031
# Epoch 85/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3281 - accuracy: 0.8895 - val_loss: 0.2784 - val_accuracy: 0.9156
# Epoch 86/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3190 - accuracy: 0.8980 - val_loss: 0.2745 - val_accuracy: 0.9078
# Epoch 87/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3216 - accuracy: 0.8984 - val_loss: 0.2703 - val_accuracy: 0.9094
# Epoch 88/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3151 - accuracy: 0.8996 - val_loss: 0.2696 - val_accuracy: 0.9109
# Epoch 89/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3135 - accuracy: 0.9004 - val_loss: 0.2663 - val_accuracy: 0.9094
# Epoch 90/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3143 - accuracy: 0.8973 - val_loss: 0.2727 - val_accuracy: 0.9062
# Epoch 91/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3240 - accuracy: 0.8965 - val_loss: 0.2695 - val_accuracy: 0.9078
# Epoch 92/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3227 - accuracy: 0.8922 - val_loss: 0.2639 - val_accuracy: 0.9109
# Epoch 93/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3062 - accuracy: 0.9047 - val_loss: 0.2597 - val_accuracy: 0.9141
# Epoch 94/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3162 - accuracy: 0.9012 - val_loss: 0.2627 - val_accuracy: 0.9062
# Epoch 95/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3177 - accuracy: 0.9016 - val_loss: 0.2587 - val_accuracy: 0.9156
# Epoch 96/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3141 - accuracy: 0.8977 - val_loss: 0.2571 - val_accuracy: 0.9078
# Epoch 97/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3140 - accuracy: 0.8977 - val_loss: 0.2596 - val_accuracy: 0.9156
# Epoch 98/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3046 - accuracy: 0.9023 - val_loss: 0.2518 - val_accuracy: 0.9125
# Epoch 99/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3063 - accuracy: 0.8980 - val_loss: 0.2535 - val_accuracy: 0.9187
# Epoch 100/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2951 - accuracy: 0.9035 - val_loss: 0.2495 - val_accuracy: 0.9125
# Epoch 101/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3075 - accuracy: 0.8980 - val_loss: 0.2501 - val_accuracy: 0.9172
# Epoch 102/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2936 - accuracy: 0.9078 - val_loss: 0.2475 - val_accuracy: 0.9141
# Epoch 103/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2877 - accuracy: 0.9023 - val_loss: 0.2457 - val_accuracy: 0.9156
# Epoch 104/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2955 - accuracy: 0.8984 - val_loss: 0.2573 - val_accuracy: 0.9187
# Epoch 105/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3005 - accuracy: 0.9020 - val_loss: 0.2474 - val_accuracy: 0.9156
# Epoch 106/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3018 - accuracy: 0.9055 - val_loss: 0.2516 - val_accuracy: 0.9125
# Epoch 107/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3015 - accuracy: 0.9008 - val_loss: 0.2426 - val_accuracy: 0.9187
# Epoch 108/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2894 - accuracy: 0.9090 - val_loss: 0.2422 - val_accuracy: 0.9109
# Epoch 109/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2958 - accuracy: 0.9016 - val_loss: 0.2440 - val_accuracy: 0.9234
# Epoch 110/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2947 - accuracy: 0.9098 - val_loss: 0.2415 - val_accuracy: 0.9141
# Epoch 111/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2915 - accuracy: 0.9043 - val_loss: 0.2410 - val_accuracy: 0.9125
# Epoch 112/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2900 - accuracy: 0.9145 - val_loss: 0.2428 - val_accuracy: 0.9234
# Epoch 113/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2979 - accuracy: 0.9008 - val_loss: 0.2343 - val_accuracy: 0.9172
# Epoch 114/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2972 - accuracy: 0.9047 - val_loss: 0.2384 - val_accuracy: 0.9172
# Epoch 115/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2755 - accuracy: 0.9109 - val_loss: 0.2343 - val_accuracy: 0.9172
# Epoch 116/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2906 - accuracy: 0.9066 - val_loss: 0.2352 - val_accuracy: 0.9203
# Epoch 117/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2807 - accuracy: 0.9113 - val_loss: 0.2328 - val_accuracy: 0.9125
# Epoch 118/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2835 - accuracy: 0.9043 - val_loss: 0.2415 - val_accuracy: 0.9203
# Epoch 119/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2815 - accuracy: 0.9102 - val_loss: 0.2325 - val_accuracy: 0.9109
# Epoch 120/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2854 - accuracy: 0.9070 - val_loss: 0.2425 - val_accuracy: 0.9187
# Epoch 121/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2766 - accuracy: 0.9098 - val_loss: 0.2318 - val_accuracy: 0.9125
# Epoch 122/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2796 - accuracy: 0.9059 - val_loss: 0.2364 - val_accuracy: 0.9250
# Epoch 123/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2822 - accuracy: 0.9113 - val_loss: 0.2286 - val_accuracy: 0.9141
# Epoch 124/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2779 - accuracy: 0.9070 - val_loss: 0.2294 - val_accuracy: 0.9219
# Epoch 125/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2751 - accuracy: 0.9129 - val_loss: 0.2272 - val_accuracy: 0.9156
# Epoch 126/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2809 - accuracy: 0.9055 - val_loss: 0.2314 - val_accuracy: 0.9187
# Epoch 127/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2778 - accuracy: 0.9055 - val_loss: 0.2258 - val_accuracy: 0.9250
# Epoch 128/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2747 - accuracy: 0.9070 - val_loss: 0.2246 - val_accuracy: 0.9172
# Epoch 129/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2767 - accuracy: 0.9098 - val_loss: 0.2257 - val_accuracy: 0.9203
# Epoch 130/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2679 - accuracy: 0.9168 - val_loss: 0.2218 - val_accuracy: 0.9203
# Epoch 131/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2764 - accuracy: 0.9055 - val_loss: 0.2276 - val_accuracy: 0.9219
# Epoch 132/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2711 - accuracy: 0.9148 - val_loss: 0.2226 - val_accuracy: 0.9219
# Epoch 133/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2776 - accuracy: 0.9086 - val_loss: 0.2240 - val_accuracy: 0.9156
# Epoch 134/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2708 - accuracy: 0.9109 - val_loss: 0.2235 - val_accuracy: 0.9219
# Epoch 135/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2645 - accuracy: 0.9086 - val_loss: 0.2188 - val_accuracy: 0.9187
# Epoch 136/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2662 - accuracy: 0.9137 - val_loss: 0.2202 - val_accuracy: 0.9219
# Epoch 137/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2673 - accuracy: 0.9086 - val_loss: 0.2165 - val_accuracy: 0.9156
# Epoch 138/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2627 - accuracy: 0.9133 - val_loss: 0.2210 - val_accuracy: 0.9266
# Epoch 139/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2678 - accuracy: 0.9082 - val_loss: 0.2165 - val_accuracy: 0.9125
# Epoch 140/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2658 - accuracy: 0.9125 - val_loss: 0.2175 - val_accuracy: 0.9203
# Epoch 141/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2741 - accuracy: 0.9094 - val_loss: 0.2155 - val_accuracy: 0.9156
# Epoch 142/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2629 - accuracy: 0.9098 - val_loss: 0.2177 - val_accuracy: 0.9266
# Epoch 143/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2603 - accuracy: 0.9164 - val_loss: 0.2120 - val_accuracy: 0.9187
# Epoch 144/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2608 - accuracy: 0.9094 - val_loss: 0.2176 - val_accuracy: 0.9219
# Epoch 145/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2591 - accuracy: 0.9094 - val_loss: 0.2125 - val_accuracy: 0.9203
# Epoch 146/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2691 - accuracy: 0.9102 - val_loss: 0.2114 - val_accuracy: 0.9203
# Epoch 147/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2614 - accuracy: 0.9137 - val_loss: 0.2153 - val_accuracy: 0.9250
# Epoch 148/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2578 - accuracy: 0.9137 - val_loss: 0.2106 - val_accuracy: 0.9250
# Epoch 149/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2615 - accuracy: 0.9133 - val_loss: 0.2087 - val_accuracy: 0.9250
# Epoch 150/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2652 - accuracy: 0.9109 - val_loss: 0.2087 - val_accuracy: 0.9187
# Epoch 151/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2658 - accuracy: 0.9121 - val_loss: 0.2132 - val_accuracy: 0.9266
# Epoch 152/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2522 - accuracy: 0.9121 - val_loss: 0.2153 - val_accuracy: 0.9219
# Epoch 153/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2602 - accuracy: 0.9090 - val_loss: 0.2121 - val_accuracy: 0.9234
# Epoch 154/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2623 - accuracy: 0.9160 - val_loss: 0.2061 - val_accuracy: 0.9156
# Epoch 155/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2501 - accuracy: 0.9148 - val_loss: 0.2124 - val_accuracy: 0.9234
# Epoch 156/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2537 - accuracy: 0.9137 - val_loss: 0.2043 - val_accuracy: 0.9234
# Epoch 157/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2486 - accuracy: 0.9172 - val_loss: 0.2069 - val_accuracy: 0.9219
# Epoch 158/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2508 - accuracy: 0.9168 - val_loss: 0.2061 - val_accuracy: 0.9234
# Epoch 159/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2535 - accuracy: 0.9137 - val_loss: 0.2035 - val_accuracy: 0.9250
# Epoch 160/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2496 - accuracy: 0.9125 - val_loss: 0.2083 - val_accuracy: 0.9250
# Epoch 161/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2472 - accuracy: 0.9168 - val_loss: 0.2044 - val_accuracy: 0.9203
# Epoch 162/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2557 - accuracy: 0.9141 - val_loss: 0.2056 - val_accuracy: 0.9219
# Epoch 163/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2434 - accuracy: 0.9184 - val_loss: 0.2044 - val_accuracy: 0.9266
# Epoch 164/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2395 - accuracy: 0.9223 - val_loss: 0.2017 - val_accuracy: 0.9234
# Epoch 165/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2377 - accuracy: 0.9227 - val_loss: 0.1994 - val_accuracy: 0.9250
# Epoch 166/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2457 - accuracy: 0.9207 - val_loss: 0.1975 - val_accuracy: 0.9266
# Epoch 167/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2505 - accuracy: 0.9137 - val_loss: 0.1965 - val_accuracy: 0.9266
# Epoch 168/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2505 - accuracy: 0.9191 - val_loss: 0.2119 - val_accuracy: 0.9234
# Epoch 169/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2496 - accuracy: 0.9172 - val_loss: 0.1951 - val_accuracy: 0.9234
# Epoch 170/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2486 - accuracy: 0.9164 - val_loss: 0.2002 - val_accuracy: 0.9266
# Epoch 171/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2368 - accuracy: 0.9223 - val_loss: 0.1965 - val_accuracy: 0.9219
# Epoch 172/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2460 - accuracy: 0.9219 - val_loss: 0.2002 - val_accuracy: 0.9266
# Epoch 173/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2414 - accuracy: 0.9184 - val_loss: 0.1949 - val_accuracy: 0.9203
# Epoch 174/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2499 - accuracy: 0.9152 - val_loss: 0.2127 - val_accuracy: 0.9234
# Epoch 175/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2441 - accuracy: 0.9160 - val_loss: 0.1958 - val_accuracy: 0.9281
# Epoch 176/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2390 - accuracy: 0.9195 - val_loss: 0.1944 - val_accuracy: 0.9266
# Epoch 177/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2419 - accuracy: 0.9187 - val_loss: 0.1956 - val_accuracy: 0.9219
# Epoch 178/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2412 - accuracy: 0.9164 - val_loss: 0.1948 - val_accuracy: 0.9312
# Epoch 179/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2388 - accuracy: 0.9191 - val_loss: 0.1894 - val_accuracy: 0.9281
# Epoch 180/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2458 - accuracy: 0.9160 - val_loss: 0.1965 - val_accuracy: 0.9281
# Epoch 181/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2401 - accuracy: 0.9223 - val_loss: 0.1916 - val_accuracy: 0.9250
# Epoch 182/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2429 - accuracy: 0.9164 - val_loss: 0.1932 - val_accuracy: 0.9250
# Epoch 183/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2341 - accuracy: 0.9215 - val_loss: 0.1894 - val_accuracy: 0.9312
# Epoch 184/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2355 - accuracy: 0.9215 - val_loss: 0.1873 - val_accuracy: 0.9219
# Epoch 185/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2339 - accuracy: 0.9191 - val_loss: 0.1976 - val_accuracy: 0.9281
# Epoch 186/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2359 - accuracy: 0.9238 - val_loss: 0.1900 - val_accuracy: 0.9250
# Epoch 187/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2343 - accuracy: 0.9227 - val_loss: 0.1897 - val_accuracy: 0.9266
# Epoch 188/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2286 - accuracy: 0.9227 - val_loss: 0.1883 - val_accuracy: 0.9219
# Epoch 189/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2438 - accuracy: 0.9164 - val_loss: 0.1977 - val_accuracy: 0.9234
# Epoch 190/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2166 - accuracy: 0.9238 - val_loss: 0.1906 - val_accuracy: 0.9328
# Epoch 191/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2340 - accuracy: 0.9203 - val_loss: 0.1983 - val_accuracy: 0.9250
# Epoch 192/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2264 - accuracy: 0.9219 - val_loss: 0.1864 - val_accuracy: 0.9328
# Epoch 193/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2362 - accuracy: 0.9164 - val_loss: 0.1871 - val_accuracy: 0.9281
# Epoch 194/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2383 - accuracy: 0.9164 - val_loss: 0.1941 - val_accuracy: 0.9234
# Epoch 195/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2275 - accuracy: 0.9254 - val_loss: 0.1852 - val_accuracy: 0.9391
# Epoch 196/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2356 - accuracy: 0.9234 - val_loss: 0.1923 - val_accuracy: 0.9344
# Epoch 197/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2299 - accuracy: 0.9219 - val_loss: 0.1903 - val_accuracy: 0.9219
# Epoch 198/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2277 - accuracy: 0.9184 - val_loss: 0.1867 - val_accuracy: 0.9297
# Epoch 199/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2226 - accuracy: 0.9254 - val_loss: 0.1862 - val_accuracy: 0.9297
# Epoch 200/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2222 - accuracy: 0.9184 - val_loss: 0.1812 - val_accuracy: 0.9266

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 2.0372 - accuracy: 0.2520 - val_loss: 1.8268 - val_accuracy: 0.3187
# Epoch 2/50
# 5/5 [==============================] - 0s 30ms/step - loss: 1.7590 - accuracy: 0.3215 - val_loss: 1.6589 - val_accuracy: 0.3516
# Epoch 3/50
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6326 - accuracy: 0.4363 - val_loss: 1.5270 - val_accuracy: 0.5922
# Epoch 4/50
# 5/5 [==============================] - 0s 24ms/step - loss: 1.5233 - accuracy: 0.5754 - val_loss: 1.3763 - val_accuracy: 0.6500
# Epoch 5/50
# 5/5 [==============================] - 0s 23ms/step - loss: 1.3777 - accuracy: 0.5988 - val_loss: 1.2294 - val_accuracy: 0.6375
# Epoch 6/50
# 5/5 [==============================] - 0s 26ms/step - loss: 1.2518 - accuracy: 0.6070 - val_loss: 1.0953 - val_accuracy: 0.6578
# Epoch 7/50
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1410 - accuracy: 0.6297 - val_loss: 0.9947 - val_accuracy: 0.7047
# Epoch 8/50
# 5/5 [==============================] - 0s 29ms/step - loss: 1.0369 - accuracy: 0.6629 - val_loss: 0.9180 - val_accuracy: 0.7250
# Epoch 9/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9889 - accuracy: 0.6605 - val_loss: 0.8602 - val_accuracy: 0.7203
# Epoch 10/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9319 - accuracy: 0.6801 - val_loss: 0.8140 - val_accuracy: 0.7391
# Epoch 11/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8854 - accuracy: 0.7004 - val_loss: 0.7791 - val_accuracy: 0.7234
# Epoch 12/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8511 - accuracy: 0.7082 - val_loss: 0.7497 - val_accuracy: 0.7266
# Epoch 13/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8184 - accuracy: 0.7383 - val_loss: 0.7226 - val_accuracy: 0.7641
# Epoch 14/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7924 - accuracy: 0.7355 - val_loss: 0.6946 - val_accuracy: 0.7844
# Epoch 15/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7601 - accuracy: 0.7602 - val_loss: 0.6725 - val_accuracy: 0.7891
# Epoch 16/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7238 - accuracy: 0.7738 - val_loss: 0.6484 - val_accuracy: 0.8078
# Epoch 17/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7042 - accuracy: 0.7859 - val_loss: 0.6268 - val_accuracy: 0.8156
# Epoch 18/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6857 - accuracy: 0.7891 - val_loss: 0.6018 - val_accuracy: 0.8172
# Epoch 19/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6586 - accuracy: 0.7980 - val_loss: 0.5855 - val_accuracy: 0.8297
# Epoch 20/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6559 - accuracy: 0.8039 - val_loss: 0.5682 - val_accuracy: 0.8250
# Epoch 21/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6136 - accuracy: 0.8160 - val_loss: 0.5595 - val_accuracy: 0.8266
# Epoch 22/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6215 - accuracy: 0.8168 - val_loss: 0.5666 - val_accuracy: 0.8328
# Epoch 23/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6028 - accuracy: 0.8117 - val_loss: 0.5405 - val_accuracy: 0.8281
# Epoch 24/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5783 - accuracy: 0.8227 - val_loss: 0.5265 - val_accuracy: 0.8500
# Epoch 25/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5658 - accuracy: 0.8281 - val_loss: 0.5099 - val_accuracy: 0.8281
# Epoch 26/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5522 - accuracy: 0.8324 - val_loss: 0.4946 - val_accuracy: 0.8625
# Epoch 27/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5364 - accuracy: 0.8309 - val_loss: 0.4797 - val_accuracy: 0.8281
# Epoch 28/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5332 - accuracy: 0.8406 - val_loss: 0.4701 - val_accuracy: 0.8469
# Epoch 29/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5222 - accuracy: 0.8371 - val_loss: 0.4647 - val_accuracy: 0.8656
# Epoch 30/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5133 - accuracy: 0.8477 - val_loss: 0.4601 - val_accuracy: 0.8313
# Epoch 31/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5041 - accuracy: 0.8445 - val_loss: 0.4522 - val_accuracy: 0.8703
# Epoch 32/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4917 - accuracy: 0.8512 - val_loss: 0.4382 - val_accuracy: 0.8531
# Epoch 33/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4872 - accuracy: 0.8457 - val_loss: 0.4358 - val_accuracy: 0.8719
# Epoch 34/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4806 - accuracy: 0.8484 - val_loss: 0.4233 - val_accuracy: 0.8875
# Epoch 35/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4731 - accuracy: 0.8582 - val_loss: 0.4229 - val_accuracy: 0.8562
# Epoch 36/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4624 - accuracy: 0.8504 - val_loss: 0.4150 - val_accuracy: 0.8828
# Epoch 37/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4515 - accuracy: 0.8570 - val_loss: 0.4095 - val_accuracy: 0.8656
# Epoch 38/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4496 - accuracy: 0.8582 - val_loss: 0.3999 - val_accuracy: 0.8906
# Epoch 39/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4357 - accuracy: 0.8660 - val_loss: 0.3936 - val_accuracy: 0.8922
# Epoch 40/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4444 - accuracy: 0.8617 - val_loss: 0.3912 - val_accuracy: 0.8922
# Epoch 41/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4320 - accuracy: 0.8672 - val_loss: 0.3872 - val_accuracy: 0.8813
# Epoch 42/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4193 - accuracy: 0.8695 - val_loss: 0.3837 - val_accuracy: 0.8922
# Epoch 43/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4228 - accuracy: 0.8703 - val_loss: 0.3768 - val_accuracy: 0.8922
# Epoch 44/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4266 - accuracy: 0.8668 - val_loss: 0.3728 - val_accuracy: 0.8906
# Epoch 45/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4139 - accuracy: 0.8633 - val_loss: 0.3822 - val_accuracy: 0.8859
# Epoch 46/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4152 - accuracy: 0.8699 - val_loss: 0.3783 - val_accuracy: 0.8516
# Epoch 47/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4160 - accuracy: 0.8641 - val_loss: 0.3623 - val_accuracy: 0.8938
# Epoch 48/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3998 - accuracy: 0.8703 - val_loss: 0.3565 - val_accuracy: 0.8922
# Epoch 49/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3957 - accuracy: 0.8781 - val_loss: 0.3549 - val_accuracy: 0.8922
# Epoch 50/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4007 - accuracy: 0.8676 - val_loss: 0.3519 - val_accuracy: 0.8938

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3379 - accuracy: 0.8973
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3519 - accuracy: 0.8938
# 0.897265613079071 0.893750011920929

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 22, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:20

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 117   0   3   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 198   6   0   0   0]
#  [  0   0   0   0  12  88   0   0   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0  12   8   0   0   0]
#  [  0   0   0   0  17   3   0   0   0]]
#
# Accuracy Score
# 0.89375
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.97      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.80      0.97      0.88       204
#     windows       0.84      0.88      0.86       100
#       roads       0.00      0.00      0.00         6
#        cars       0.00      0.00      0.00        20
#       metal       0.00      0.00      0.00        20
#
# avg / total       0.84      0.89      0.86       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 22)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 22)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 22) (80, 22)
# clouds  (400, 22) (100, 22)
# vegetation  (488, 22) (122, 22)
# built  (960, 22) (240, 22)
# windows  (400, 22) (100, 22)
# roads  (48, 22) (12, 22)
# cars  (44, 22) (11, 22)
# metal  (184, 22) (46, 22)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 22) (2844,) (2844, 2)
# (711, 22) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 76ms/step - loss: 2.0427 - accuracy: 0.2736 - val_loss: 1.8174 - val_accuracy: 0.3376
# Epoch 2/200
# 6/6 [==============================] - 0s 33ms/step - loss: 1.7482 - accuracy: 0.3383 - val_loss: 1.6398 - val_accuracy: 0.3376
# Epoch 3/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.6075 - accuracy: 0.3956 - val_loss: 1.5084 - val_accuracy: 0.4895
# Epoch 4/200
# 6/6 [==============================] - 0s 28ms/step - loss: 1.4753 - accuracy: 0.5345 - val_loss: 1.3571 - val_accuracy: 0.6132
# Epoch 5/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3296 - accuracy: 0.5777 - val_loss: 1.2084 - val_accuracy: 0.6470
# Epoch 6/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.1973 - accuracy: 0.6399 - val_loss: 1.0763 - val_accuracy: 0.6723
# Epoch 7/200
# 6/6 [==============================] - 0s 28ms/step - loss: 1.0792 - accuracy: 0.6547 - val_loss: 0.9762 - val_accuracy: 0.6976
# Epoch 8/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.9974 - accuracy: 0.6741 - val_loss: 0.9021 - val_accuracy: 0.7075
# Epoch 9/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9202 - accuracy: 0.6899 - val_loss: 0.8615 - val_accuracy: 0.7215
# Epoch 10/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.8640 - accuracy: 0.6948 - val_loss: 0.8060 - val_accuracy: 0.7018
# Epoch 11/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.8387 - accuracy: 0.7068 - val_loss: 0.7776 - val_accuracy: 0.7300
# Epoch 12/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.7877 - accuracy: 0.7110 - val_loss: 0.7479 - val_accuracy: 0.7117
# Epoch 13/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7615 - accuracy: 0.7219 - val_loss: 0.7260 - val_accuracy: 0.7271
# Epoch 14/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7402 - accuracy: 0.7208 - val_loss: 0.7079 - val_accuracy: 0.7089
# Epoch 15/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.7126 - accuracy: 0.7310 - val_loss: 0.6858 - val_accuracy: 0.7201
# Epoch 16/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6901 - accuracy: 0.7342 - val_loss: 0.6752 - val_accuracy: 0.7426
# Epoch 17/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6724 - accuracy: 0.7402 - val_loss: 0.6587 - val_accuracy: 0.7314
# Epoch 18/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6640 - accuracy: 0.7342 - val_loss: 0.6563 - val_accuracy: 0.7511
# Epoch 19/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6559 - accuracy: 0.7416 - val_loss: 0.6330 - val_accuracy: 0.7243
# Epoch 20/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6417 - accuracy: 0.7395 - val_loss: 0.6211 - val_accuracy: 0.7314
# Epoch 21/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6310 - accuracy: 0.7430 - val_loss: 0.6201 - val_accuracy: 0.7496
# Epoch 22/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6195 - accuracy: 0.7479 - val_loss: 0.6155 - val_accuracy: 0.7440
# Epoch 23/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6078 - accuracy: 0.7609 - val_loss: 0.6064 - val_accuracy: 0.7609
# Epoch 24/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5948 - accuracy: 0.7546 - val_loss: 0.5860 - val_accuracy: 0.7440
# Epoch 25/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6062 - accuracy: 0.7560 - val_loss: 0.5782 - val_accuracy: 0.7384
# Epoch 26/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5906 - accuracy: 0.7563 - val_loss: 0.5803 - val_accuracy: 0.7595
# Epoch 27/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5784 - accuracy: 0.7725 - val_loss: 0.5710 - val_accuracy: 0.7609
# Epoch 28/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5731 - accuracy: 0.7651 - val_loss: 0.5643 - val_accuracy: 0.7651
# Epoch 29/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5610 - accuracy: 0.7648 - val_loss: 0.5537 - val_accuracy: 0.7693
# Epoch 30/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5536 - accuracy: 0.7760 - val_loss: 0.5467 - val_accuracy: 0.7665
# Epoch 31/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5478 - accuracy: 0.7799 - val_loss: 0.5394 - val_accuracy: 0.7679
# Epoch 32/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5368 - accuracy: 0.7714 - val_loss: 0.5351 - val_accuracy: 0.7792
# Epoch 33/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5466 - accuracy: 0.7644 - val_loss: 0.5349 - val_accuracy: 0.7778
# Epoch 34/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5313 - accuracy: 0.7764 - val_loss: 0.5296 - val_accuracy: 0.7820
# Epoch 35/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5259 - accuracy: 0.7827 - val_loss: 0.5252 - val_accuracy: 0.7834
# Epoch 36/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5251 - accuracy: 0.7820 - val_loss: 0.5200 - val_accuracy: 0.7904
# Epoch 37/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5137 - accuracy: 0.7950 - val_loss: 0.5125 - val_accuracy: 0.8045
# Epoch 38/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5023 - accuracy: 0.7996 - val_loss: 0.5070 - val_accuracy: 0.7961
# Epoch 39/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5022 - accuracy: 0.7880 - val_loss: 0.5043 - val_accuracy: 0.8059
# Epoch 40/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5050 - accuracy: 0.7922 - val_loss: 0.4962 - val_accuracy: 0.8172
# Epoch 41/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4985 - accuracy: 0.8038 - val_loss: 0.4949 - val_accuracy: 0.8186
# Epoch 42/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4949 - accuracy: 0.7989 - val_loss: 0.4908 - val_accuracy: 0.8186
# Epoch 43/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4916 - accuracy: 0.7971 - val_loss: 0.4895 - val_accuracy: 0.8200
# Epoch 44/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4885 - accuracy: 0.8010 - val_loss: 0.4922 - val_accuracy: 0.8045
# Epoch 45/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4831 - accuracy: 0.8052 - val_loss: 0.4888 - val_accuracy: 0.8087
# Epoch 46/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4883 - accuracy: 0.7968 - val_loss: 0.4785 - val_accuracy: 0.8270
# Epoch 47/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4737 - accuracy: 0.8087 - val_loss: 0.4834 - val_accuracy: 0.8312
# Epoch 48/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4672 - accuracy: 0.8249 - val_loss: 0.4713 - val_accuracy: 0.8242
# Epoch 49/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4712 - accuracy: 0.8122 - val_loss: 0.4741 - val_accuracy: 0.8312
# Epoch 50/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4651 - accuracy: 0.8154 - val_loss: 0.4670 - val_accuracy: 0.8312
# Epoch 51/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4720 - accuracy: 0.8098 - val_loss: 0.4652 - val_accuracy: 0.8411
# Epoch 52/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4633 - accuracy: 0.8158 - val_loss: 0.4667 - val_accuracy: 0.8425
# Epoch 53/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4731 - accuracy: 0.8112 - val_loss: 0.4569 - val_accuracy: 0.8354
# Epoch 54/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4501 - accuracy: 0.8238 - val_loss: 0.4596 - val_accuracy: 0.8368
# Epoch 55/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4542 - accuracy: 0.8073 - val_loss: 0.4623 - val_accuracy: 0.8453
# Epoch 56/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4490 - accuracy: 0.8291 - val_loss: 0.4513 - val_accuracy: 0.8298
# Epoch 57/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4528 - accuracy: 0.8158 - val_loss: 0.4728 - val_accuracy: 0.8228
# Epoch 58/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4476 - accuracy: 0.8224 - val_loss: 0.4474 - val_accuracy: 0.8383
# Epoch 59/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4462 - accuracy: 0.8249 - val_loss: 0.4513 - val_accuracy: 0.8340
# Epoch 60/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4454 - accuracy: 0.8326 - val_loss: 0.4414 - val_accuracy: 0.8397
# Epoch 61/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4398 - accuracy: 0.8270 - val_loss: 0.4546 - val_accuracy: 0.8298
# Epoch 62/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4439 - accuracy: 0.8221 - val_loss: 0.4395 - val_accuracy: 0.8397
# Epoch 63/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4359 - accuracy: 0.8231 - val_loss: 0.4473 - val_accuracy: 0.8495
# Epoch 64/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4379 - accuracy: 0.8288 - val_loss: 0.4393 - val_accuracy: 0.8411
# Epoch 65/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4427 - accuracy: 0.8242 - val_loss: 0.4461 - val_accuracy: 0.8439
# Epoch 66/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4359 - accuracy: 0.8277 - val_loss: 0.4357 - val_accuracy: 0.8551
# Epoch 67/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4243 - accuracy: 0.8383 - val_loss: 0.4327 - val_accuracy: 0.8453
# Epoch 68/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4276 - accuracy: 0.8319 - val_loss: 0.4338 - val_accuracy: 0.8565
# Epoch 69/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4245 - accuracy: 0.8340 - val_loss: 0.4245 - val_accuracy: 0.8397
# Epoch 70/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4122 - accuracy: 0.8425 - val_loss: 0.4312 - val_accuracy: 0.8411
# Epoch 71/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4143 - accuracy: 0.8418 - val_loss: 0.4470 - val_accuracy: 0.8383
# Epoch 72/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4311 - accuracy: 0.8326 - val_loss: 0.4418 - val_accuracy: 0.8284
# Epoch 73/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4254 - accuracy: 0.8326 - val_loss: 0.4275 - val_accuracy: 0.8537
# Epoch 74/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4286 - accuracy: 0.8347 - val_loss: 0.4363 - val_accuracy: 0.8425
# Epoch 75/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4204 - accuracy: 0.8456 - val_loss: 0.4174 - val_accuracy: 0.8495
# Epoch 76/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4122 - accuracy: 0.8400 - val_loss: 0.4224 - val_accuracy: 0.8594
# Epoch 77/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4071 - accuracy: 0.8492 - val_loss: 0.4195 - val_accuracy: 0.8495
# Epoch 78/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4164 - accuracy: 0.8372 - val_loss: 0.4259 - val_accuracy: 0.8383
# Epoch 79/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4149 - accuracy: 0.8442 - val_loss: 0.4128 - val_accuracy: 0.8565
# Epoch 80/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4054 - accuracy: 0.8499 - val_loss: 0.4197 - val_accuracy: 0.8439
# Epoch 81/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3989 - accuracy: 0.8502 - val_loss: 0.4099 - val_accuracy: 0.8594
# Epoch 82/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4023 - accuracy: 0.8463 - val_loss: 0.4112 - val_accuracy: 0.8481
# Epoch 83/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3955 - accuracy: 0.8565 - val_loss: 0.4155 - val_accuracy: 0.8565
# Epoch 84/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3920 - accuracy: 0.8495 - val_loss: 0.4082 - val_accuracy: 0.8551
# Epoch 85/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3978 - accuracy: 0.8485 - val_loss: 0.4060 - val_accuracy: 0.8537
# Epoch 86/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3925 - accuracy: 0.8506 - val_loss: 0.4048 - val_accuracy: 0.8579
# Epoch 87/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3813 - accuracy: 0.8576 - val_loss: 0.4002 - val_accuracy: 0.8565
# Epoch 88/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3949 - accuracy: 0.8453 - val_loss: 0.4109 - val_accuracy: 0.8509
# Epoch 89/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4001 - accuracy: 0.8453 - val_loss: 0.4088 - val_accuracy: 0.8467
# Epoch 90/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4003 - accuracy: 0.8520 - val_loss: 0.4020 - val_accuracy: 0.8495
# Epoch 91/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3898 - accuracy: 0.8499 - val_loss: 0.4026 - val_accuracy: 0.8579
# Epoch 92/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3797 - accuracy: 0.8576 - val_loss: 0.3986 - val_accuracy: 0.8636
# Epoch 93/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3892 - accuracy: 0.8506 - val_loss: 0.3948 - val_accuracy: 0.8664
# Epoch 94/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3900 - accuracy: 0.8530 - val_loss: 0.3975 - val_accuracy: 0.8579
# Epoch 95/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3908 - accuracy: 0.8453 - val_loss: 0.4025 - val_accuracy: 0.8636
# Epoch 96/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3945 - accuracy: 0.8527 - val_loss: 0.3965 - val_accuracy: 0.8608
# Epoch 97/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3770 - accuracy: 0.8643 - val_loss: 0.3915 - val_accuracy: 0.8622
# Epoch 98/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3820 - accuracy: 0.8565 - val_loss: 0.3935 - val_accuracy: 0.8551
# Epoch 99/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3876 - accuracy: 0.8558 - val_loss: 0.3924 - val_accuracy: 0.8495
# Epoch 100/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3879 - accuracy: 0.8488 - val_loss: 0.4000 - val_accuracy: 0.8692
# Epoch 101/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3712 - accuracy: 0.8695 - val_loss: 0.3826 - val_accuracy: 0.8622
# Epoch 102/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3702 - accuracy: 0.8576 - val_loss: 0.3999 - val_accuracy: 0.8453
# Epoch 103/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3794 - accuracy: 0.8565 - val_loss: 0.3971 - val_accuracy: 0.8467
# Epoch 104/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3704 - accuracy: 0.8579 - val_loss: 0.3943 - val_accuracy: 0.8453
# Epoch 105/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3818 - accuracy: 0.8579 - val_loss: 0.3791 - val_accuracy: 0.8636
# Epoch 106/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3703 - accuracy: 0.8601 - val_loss: 0.3863 - val_accuracy: 0.8720
# Epoch 107/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3579 - accuracy: 0.8667 - val_loss: 0.3811 - val_accuracy: 0.8622
# Epoch 108/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3657 - accuracy: 0.8671 - val_loss: 0.3810 - val_accuracy: 0.8636
# Epoch 109/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3638 - accuracy: 0.8594 - val_loss: 0.3784 - val_accuracy: 0.8678
# Epoch 110/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3637 - accuracy: 0.8615 - val_loss: 0.3860 - val_accuracy: 0.8734
# Epoch 111/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3544 - accuracy: 0.8699 - val_loss: 0.3758 - val_accuracy: 0.8622
# Epoch 112/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3609 - accuracy: 0.8674 - val_loss: 0.3726 - val_accuracy: 0.8678
# Epoch 113/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3603 - accuracy: 0.8695 - val_loss: 0.3746 - val_accuracy: 0.8734
# Epoch 114/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3568 - accuracy: 0.8688 - val_loss: 0.3747 - val_accuracy: 0.8734
# Epoch 115/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3562 - accuracy: 0.8741 - val_loss: 0.3793 - val_accuracy: 0.8748
# Epoch 116/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3573 - accuracy: 0.8710 - val_loss: 0.3723 - val_accuracy: 0.8636
# Epoch 117/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3572 - accuracy: 0.8671 - val_loss: 0.3731 - val_accuracy: 0.8664
# Epoch 118/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3561 - accuracy: 0.8576 - val_loss: 0.4019 - val_accuracy: 0.8551
# Epoch 119/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3533 - accuracy: 0.8717 - val_loss: 0.3677 - val_accuracy: 0.8692
# Epoch 120/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3563 - accuracy: 0.8692 - val_loss: 0.3765 - val_accuracy: 0.8594
# Epoch 121/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3543 - accuracy: 0.8646 - val_loss: 0.3742 - val_accuracy: 0.8776
# Epoch 122/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3569 - accuracy: 0.8688 - val_loss: 0.3702 - val_accuracy: 0.8692
# Epoch 123/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3429 - accuracy: 0.8762 - val_loss: 0.3641 - val_accuracy: 0.8636
# Epoch 124/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3430 - accuracy: 0.8745 - val_loss: 0.3775 - val_accuracy: 0.8664
# Epoch 125/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3423 - accuracy: 0.8776 - val_loss: 0.3577 - val_accuracy: 0.8720
# Epoch 126/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3479 - accuracy: 0.8674 - val_loss: 0.3719 - val_accuracy: 0.8608
# Epoch 127/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3480 - accuracy: 0.8674 - val_loss: 0.3618 - val_accuracy: 0.8762
# Epoch 128/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3391 - accuracy: 0.8826 - val_loss: 0.3599 - val_accuracy: 0.8678
# Epoch 129/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3368 - accuracy: 0.8762 - val_loss: 0.3712 - val_accuracy: 0.8706
# Epoch 130/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3419 - accuracy: 0.8790 - val_loss: 0.3579 - val_accuracy: 0.8678
# Epoch 131/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3357 - accuracy: 0.8766 - val_loss: 0.3541 - val_accuracy: 0.8678
# Epoch 132/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3309 - accuracy: 0.8794 - val_loss: 0.3523 - val_accuracy: 0.8889
# Epoch 133/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3303 - accuracy: 0.8755 - val_loss: 0.3524 - val_accuracy: 0.8762
# Epoch 134/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3328 - accuracy: 0.8762 - val_loss: 0.3526 - val_accuracy: 0.8762
# Epoch 135/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3345 - accuracy: 0.8731 - val_loss: 0.3547 - val_accuracy: 0.8819
# Epoch 136/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3293 - accuracy: 0.8773 - val_loss: 0.3549 - val_accuracy: 0.8650
# Epoch 137/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3252 - accuracy: 0.8794 - val_loss: 0.3464 - val_accuracy: 0.8847
# Epoch 138/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3344 - accuracy: 0.8762 - val_loss: 0.3599 - val_accuracy: 0.8706
# Epoch 139/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3225 - accuracy: 0.8787 - val_loss: 0.3427 - val_accuracy: 0.8762
# Epoch 140/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3336 - accuracy: 0.8769 - val_loss: 0.3556 - val_accuracy: 0.8608
# Epoch 141/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3226 - accuracy: 0.8840 - val_loss: 0.3499 - val_accuracy: 0.8790
# Epoch 142/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3200 - accuracy: 0.8829 - val_loss: 0.3515 - val_accuracy: 0.8692
# Epoch 143/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3349 - accuracy: 0.8738 - val_loss: 0.3522 - val_accuracy: 0.8776
# Epoch 144/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3123 - accuracy: 0.8871 - val_loss: 0.3463 - val_accuracy: 0.8790
# Epoch 145/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3254 - accuracy: 0.8783 - val_loss: 0.3399 - val_accuracy: 0.8790
# Epoch 146/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3134 - accuracy: 0.8868 - val_loss: 0.3445 - val_accuracy: 0.8762
# Epoch 147/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3211 - accuracy: 0.8766 - val_loss: 0.3415 - val_accuracy: 0.8819
# Epoch 148/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3225 - accuracy: 0.8797 - val_loss: 0.3526 - val_accuracy: 0.8734
# Epoch 149/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3234 - accuracy: 0.8780 - val_loss: 0.3455 - val_accuracy: 0.8706
# Epoch 150/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3157 - accuracy: 0.8847 - val_loss: 0.3386 - val_accuracy: 0.8790
# Epoch 151/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3224 - accuracy: 0.8819 - val_loss: 0.3427 - val_accuracy: 0.8762
# Epoch 152/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3115 - accuracy: 0.8861 - val_loss: 0.3328 - val_accuracy: 0.8861
# Epoch 153/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3207 - accuracy: 0.8805 - val_loss: 0.3436 - val_accuracy: 0.8706
# Epoch 154/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3097 - accuracy: 0.8815 - val_loss: 0.3374 - val_accuracy: 0.8790
# Epoch 155/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3200 - accuracy: 0.8815 - val_loss: 0.3429 - val_accuracy: 0.8678
# Epoch 156/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3195 - accuracy: 0.8812 - val_loss: 0.3325 - val_accuracy: 0.8847
# Epoch 157/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3067 - accuracy: 0.8889 - val_loss: 0.3453 - val_accuracy: 0.8748
# Epoch 158/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3043 - accuracy: 0.8928 - val_loss: 0.3325 - val_accuracy: 0.8847
# Epoch 159/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3013 - accuracy: 0.8931 - val_loss: 0.3415 - val_accuracy: 0.8748
# Epoch 160/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3116 - accuracy: 0.8829 - val_loss: 0.3364 - val_accuracy: 0.8734
# Epoch 161/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3123 - accuracy: 0.8815 - val_loss: 0.3384 - val_accuracy: 0.8734
# Epoch 162/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3075 - accuracy: 0.8826 - val_loss: 0.3289 - val_accuracy: 0.8819
# Epoch 163/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3128 - accuracy: 0.8783 - val_loss: 0.3536 - val_accuracy: 0.8650
# Epoch 164/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3027 - accuracy: 0.8868 - val_loss: 0.3249 - val_accuracy: 0.8805
# Epoch 165/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3153 - accuracy: 0.8790 - val_loss: 0.3489 - val_accuracy: 0.8678
# Epoch 166/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2965 - accuracy: 0.8875 - val_loss: 0.3272 - val_accuracy: 0.8805
# Epoch 167/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3041 - accuracy: 0.8854 - val_loss: 0.3428 - val_accuracy: 0.8650
# Epoch 168/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3053 - accuracy: 0.8857 - val_loss: 0.3240 - val_accuracy: 0.8790
# Epoch 169/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3056 - accuracy: 0.8882 - val_loss: 0.3343 - val_accuracy: 0.8734
# Epoch 170/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2997 - accuracy: 0.8949 - val_loss: 0.3201 - val_accuracy: 0.8833
# Epoch 171/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3001 - accuracy: 0.8899 - val_loss: 0.3317 - val_accuracy: 0.8692
# Epoch 172/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2942 - accuracy: 0.8921 - val_loss: 0.3328 - val_accuracy: 0.8819
# Epoch 173/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2941 - accuracy: 0.8921 - val_loss: 0.3363 - val_accuracy: 0.8748
# Epoch 174/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2990 - accuracy: 0.8917 - val_loss: 0.3219 - val_accuracy: 0.8861
# Epoch 175/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2906 - accuracy: 0.8861 - val_loss: 0.3259 - val_accuracy: 0.8734
# Epoch 176/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2905 - accuracy: 0.8973 - val_loss: 0.3206 - val_accuracy: 0.8762
# Epoch 177/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2878 - accuracy: 0.8914 - val_loss: 0.3330 - val_accuracy: 0.8805
# Epoch 178/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2898 - accuracy: 0.8924 - val_loss: 0.3178 - val_accuracy: 0.8847
# Epoch 179/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2873 - accuracy: 0.8994 - val_loss: 0.3269 - val_accuracy: 0.8692
# Epoch 180/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2939 - accuracy: 0.8931 - val_loss: 0.3207 - val_accuracy: 0.8790
# Epoch 181/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2903 - accuracy: 0.8892 - val_loss: 0.3200 - val_accuracy: 0.8790
# Epoch 182/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2922 - accuracy: 0.8910 - val_loss: 0.3144 - val_accuracy: 0.8790
# Epoch 183/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2834 - accuracy: 0.8942 - val_loss: 0.3204 - val_accuracy: 0.8748
# Epoch 184/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2960 - accuracy: 0.8892 - val_loss: 0.3207 - val_accuracy: 0.8790
# Epoch 185/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2904 - accuracy: 0.8952 - val_loss: 0.3152 - val_accuracy: 0.8805
# Epoch 186/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2809 - accuracy: 0.8921 - val_loss: 0.3142 - val_accuracy: 0.8847
# Epoch 187/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2888 - accuracy: 0.8963 - val_loss: 0.3173 - val_accuracy: 0.8734
# Epoch 188/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2891 - accuracy: 0.8945 - val_loss: 0.3155 - val_accuracy: 0.8875
# Epoch 189/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2816 - accuracy: 0.8942 - val_loss: 0.3150 - val_accuracy: 0.8790
# Epoch 190/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2803 - accuracy: 0.8921 - val_loss: 0.3235 - val_accuracy: 0.8776
# Epoch 191/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2858 - accuracy: 0.8952 - val_loss: 0.3136 - val_accuracy: 0.8805
# Epoch 192/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2800 - accuracy: 0.8966 - val_loss: 0.3093 - val_accuracy: 0.8776
# Epoch 193/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2772 - accuracy: 0.8903 - val_loss: 0.3143 - val_accuracy: 0.8805
# Epoch 194/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2817 - accuracy: 0.8966 - val_loss: 0.3123 - val_accuracy: 0.8776
# Epoch 195/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2789 - accuracy: 0.8987 - val_loss: 0.3096 - val_accuracy: 0.8847
# Epoch 196/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2734 - accuracy: 0.9001 - val_loss: 0.3130 - val_accuracy: 0.8748
# Epoch 197/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2812 - accuracy: 0.8910 - val_loss: 0.3127 - val_accuracy: 0.8748
# Epoch 198/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2764 - accuracy: 0.8931 - val_loss: 0.3100 - val_accuracy: 0.8861
# Epoch 199/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2740 - accuracy: 0.8935 - val_loss: 0.3183 - val_accuracy: 0.8776
# Epoch 200/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2798 - accuracy: 0.8942 - val_loss: 0.3052 - val_accuracy: 0.8776

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 0s 66ms/step - loss: 1.9814 - accuracy: 0.3070 - val_loss: 1.7813 - val_accuracy: 0.3376
# Epoch 2/40
# 6/6 [==============================] - 0s 32ms/step - loss: 1.7357 - accuracy: 0.3386 - val_loss: 1.6257 - val_accuracy: 0.3404
# Epoch 3/40
# 6/6 [==============================] - 0s 26ms/step - loss: 1.5909 - accuracy: 0.4290 - val_loss: 1.4903 - val_accuracy: 0.6104
# Epoch 4/40
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4504 - accuracy: 0.5763 - val_loss: 1.3312 - val_accuracy: 0.5879
# Epoch 5/40
# 6/6 [==============================] - 0s 26ms/step - loss: 1.3011 - accuracy: 0.5967 - val_loss: 1.1690 - val_accuracy: 0.6610
# Epoch 6/40
# 6/6 [==============================] - 0s 25ms/step - loss: 1.1476 - accuracy: 0.6582 - val_loss: 1.0466 - val_accuracy: 0.6681
# Epoch 7/40
# 6/6 [==============================] - 0s 24ms/step - loss: 1.0432 - accuracy: 0.6772 - val_loss: 0.9516 - val_accuracy: 0.7032
# Epoch 8/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.9567 - accuracy: 0.6832 - val_loss: 0.8869 - val_accuracy: 0.7075
# Epoch 9/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8908 - accuracy: 0.6962 - val_loss: 0.8300 - val_accuracy: 0.7243
# Epoch 10/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8362 - accuracy: 0.7096 - val_loss: 0.7858 - val_accuracy: 0.7229
# Epoch 11/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.7926 - accuracy: 0.7233 - val_loss: 0.7545 - val_accuracy: 0.7243
# Epoch 12/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7590 - accuracy: 0.7219 - val_loss: 0.7226 - val_accuracy: 0.7328
# Epoch 13/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.7342 - accuracy: 0.7293 - val_loss: 0.6955 - val_accuracy: 0.7412
# Epoch 14/40
# 6/6 [==============================] - 0s 31ms/step - loss: 0.7064 - accuracy: 0.7282 - val_loss: 0.6821 - val_accuracy: 0.7300
# Epoch 15/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6788 - accuracy: 0.7370 - val_loss: 0.6640 - val_accuracy: 0.7356
# Epoch 16/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6620 - accuracy: 0.7482 - val_loss: 0.6436 - val_accuracy: 0.7384
# Epoch 17/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6362 - accuracy: 0.7447 - val_loss: 0.6313 - val_accuracy: 0.7398
# Epoch 18/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6193 - accuracy: 0.7595 - val_loss: 0.6178 - val_accuracy: 0.7511
# Epoch 19/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6079 - accuracy: 0.7591 - val_loss: 0.6114 - val_accuracy: 0.7525
# Epoch 20/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5973 - accuracy: 0.7620 - val_loss: 0.5908 - val_accuracy: 0.7693
# Epoch 21/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5866 - accuracy: 0.7697 - val_loss: 0.5916 - val_accuracy: 0.7679
# Epoch 22/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5869 - accuracy: 0.7591 - val_loss: 0.5768 - val_accuracy: 0.7693
# Epoch 23/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5705 - accuracy: 0.7700 - val_loss: 0.5633 - val_accuracy: 0.7848
# Epoch 24/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5656 - accuracy: 0.7753 - val_loss: 0.5675 - val_accuracy: 0.7792
# Epoch 25/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5595 - accuracy: 0.7816 - val_loss: 0.5510 - val_accuracy: 0.7778
# Epoch 26/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5512 - accuracy: 0.7750 - val_loss: 0.5440 - val_accuracy: 0.7890
# Epoch 27/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5373 - accuracy: 0.7880 - val_loss: 0.5387 - val_accuracy: 0.7989
# Epoch 28/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5314 - accuracy: 0.7982 - val_loss: 0.5392 - val_accuracy: 0.7961
# Epoch 29/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5204 - accuracy: 0.7901 - val_loss: 0.5269 - val_accuracy: 0.7947
# Epoch 30/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5219 - accuracy: 0.7880 - val_loss: 0.5154 - val_accuracy: 0.8101
# Epoch 31/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5116 - accuracy: 0.7954 - val_loss: 0.5196 - val_accuracy: 0.7918
# Epoch 32/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5057 - accuracy: 0.8020 - val_loss: 0.5128 - val_accuracy: 0.8143
# Epoch 33/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4986 - accuracy: 0.8052 - val_loss: 0.5120 - val_accuracy: 0.7876
# Epoch 34/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5016 - accuracy: 0.8013 - val_loss: 0.5150 - val_accuracy: 0.7961
# Epoch 35/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4947 - accuracy: 0.7975 - val_loss: 0.4965 - val_accuracy: 0.8186
# Epoch 36/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4911 - accuracy: 0.8094 - val_loss: 0.4908 - val_accuracy: 0.8242
# Epoch 37/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4858 - accuracy: 0.8133 - val_loss: 0.4897 - val_accuracy: 0.8115
# Epoch 38/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4786 - accuracy: 0.8179 - val_loss: 0.4809 - val_accuracy: 0.8298
# Epoch 39/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4662 - accuracy: 0.8228 - val_loss: 0.4803 - val_accuracy: 0.8256
# Epoch 40/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4662 - accuracy: 0.8200 - val_loss: 0.4811 - val_accuracy: 0.8411

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 3ms/step - loss: 0.4161 - accuracy: 0.8769
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.8411
# 0.8769338726997375 0.8410689234733582

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 22, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:22

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  99   0   1   0   0   0   0]
#  [  0   1 116   2   3   0   0   0]
#  [  0   1   1 218  15   0   0   5]
#  [  1   1   0  40  50   0   0   8]
#  [  0   0   0   0   2  10   0   0]
#  [  0   0   0   0   2   2   7   0]
#  [  0   0   0  24   4   0   0  18]]
#
# Accuracy Score
# 0.8410689170182841
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.99      1.00      0.99        80
#      clouds       0.97      0.99      0.98       100
#  vegetation       0.99      0.95      0.97       122
#       built       0.76      0.91      0.83       240
#     windows       0.66      0.50      0.57       100
#       roads       0.83      0.83      0.83        12
#        cars       1.00      0.64      0.78        11
#       metal       0.58      0.39      0.47        46
#
# avg / total       0.84      0.84      0.83       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 22
# [[0, 39], [39, 78], [78, 117], [117, 156], [156, 195], [195, 234], [234, 273], [273, 312], [312, 351], [351, 390], [390, 429], [429, 468], [468, 507], [507, 546], [546, 585], [585, 624], [624, 663], [663, 702], [702, 741], [741, 780], [780, 819], [819, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 22)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 22)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 22) (60, 22)
# clouds  (160, 22) (40, 22)
# vegetation  (560, 22) (140, 22)
# water  (496, 22) (124, 22)
# built  (1280, 22) (320, 22)
# windows  (480, 22) (120, 22)
# roads  (200, 22) (50, 22)
# cars  (200, 22) (50, 22)
# metal  (148, 22) (37, 22)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 22) (3764,) (3764, 2)
# (941, 22) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 55ms/step - loss: 1.9821 - accuracy: 0.3050 - val_loss: 1.8108 - val_accuracy: 0.3475
# Epoch 2/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.7818 - accuracy: 0.3948 - val_loss: 1.6399 - val_accuracy: 0.4708
# Epoch 3/200
# 8/8 [==============================] - 0s 23ms/step - loss: 1.6294 - accuracy: 0.4663 - val_loss: 1.4874 - val_accuracy: 0.4761
# Epoch 4/200
# 8/8 [==============================] - 0s 24ms/step - loss: 1.4809 - accuracy: 0.4934 - val_loss: 1.3659 - val_accuracy: 0.5515
# Epoch 5/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.3889 - accuracy: 0.5207 - val_loss: 1.2919 - val_accuracy: 0.5452
# Epoch 6/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3188 - accuracy: 0.5446 - val_loss: 1.2350 - val_accuracy: 0.5654
# Epoch 7/200
# 8/8 [==============================] - 0s 23ms/step - loss: 1.2653 - accuracy: 0.5648 - val_loss: 1.1893 - val_accuracy: 0.6164
# Epoch 8/200
# 8/8 [==============================] - 0s 21ms/step - loss: 1.2114 - accuracy: 0.5911 - val_loss: 1.1530 - val_accuracy: 0.6142
# Epoch 9/200
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1713 - accuracy: 0.6055 - val_loss: 1.1103 - val_accuracy: 0.6376
# Epoch 10/200
# 8/8 [==============================] - 0s 32ms/step - loss: 1.1329 - accuracy: 0.6246 - val_loss: 1.0798 - val_accuracy: 0.6323
# Epoch 11/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1112 - accuracy: 0.6259 - val_loss: 1.0398 - val_accuracy: 0.6589
# Epoch 12/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0684 - accuracy: 0.6368 - val_loss: 1.0169 - val_accuracy: 0.6727
# Epoch 13/200
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0386 - accuracy: 0.6408 - val_loss: 0.9807 - val_accuracy: 0.6652
# Epoch 14/200
# 8/8 [==============================] - 0s 22ms/step - loss: 1.0275 - accuracy: 0.6597 - val_loss: 0.9562 - val_accuracy: 0.6716
# Epoch 15/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.9999 - accuracy: 0.6586 - val_loss: 0.9351 - val_accuracy: 0.6695
# Epoch 16/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.9794 - accuracy: 0.6700 - val_loss: 0.9435 - val_accuracy: 0.7046
# Epoch 17/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.9666 - accuracy: 0.6727 - val_loss: 0.8952 - val_accuracy: 0.6801
# Epoch 18/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9377 - accuracy: 0.6793 - val_loss: 0.8744 - val_accuracy: 0.7046
# Epoch 19/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.9160 - accuracy: 0.6939 - val_loss: 0.8567 - val_accuracy: 0.6908
# Epoch 20/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.9003 - accuracy: 0.7006 - val_loss: 0.8422 - val_accuracy: 0.7056
# Epoch 21/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8922 - accuracy: 0.6958 - val_loss: 0.8260 - val_accuracy: 0.7078
# Epoch 22/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.8680 - accuracy: 0.6987 - val_loss: 0.8133 - val_accuracy: 0.7173
# Epoch 23/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8538 - accuracy: 0.7109 - val_loss: 0.7975 - val_accuracy: 0.7407
# Epoch 24/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8423 - accuracy: 0.7205 - val_loss: 0.7855 - val_accuracy: 0.7311
# Epoch 25/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.8307 - accuracy: 0.7221 - val_loss: 0.7692 - val_accuracy: 0.7407
# Epoch 26/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.8196 - accuracy: 0.7269 - val_loss: 0.7633 - val_accuracy: 0.7524
# Epoch 27/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8176 - accuracy: 0.7261 - val_loss: 0.7522 - val_accuracy: 0.7715
# Epoch 28/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8010 - accuracy: 0.7365 - val_loss: 0.7423 - val_accuracy: 0.7811
# Epoch 29/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7935 - accuracy: 0.7378 - val_loss: 0.7447 - val_accuracy: 0.7747
# Epoch 30/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7880 - accuracy: 0.7423 - val_loss: 0.7221 - val_accuracy: 0.7843
# Epoch 31/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7700 - accuracy: 0.7564 - val_loss: 0.7064 - val_accuracy: 0.7736
# Epoch 32/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7581 - accuracy: 0.7540 - val_loss: 0.6989 - val_accuracy: 0.7747
# Epoch 33/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7515 - accuracy: 0.7585 - val_loss: 0.6963 - val_accuracy: 0.7694
# Epoch 34/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7360 - accuracy: 0.7673 - val_loss: 0.6893 - val_accuracy: 0.7662
# Epoch 35/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7358 - accuracy: 0.7641 - val_loss: 0.6806 - val_accuracy: 0.7832
# Epoch 36/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7294 - accuracy: 0.7678 - val_loss: 0.6719 - val_accuracy: 0.7906
# Epoch 37/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7221 - accuracy: 0.7742 - val_loss: 0.6657 - val_accuracy: 0.8023
# Epoch 38/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7140 - accuracy: 0.7707 - val_loss: 0.6754 - val_accuracy: 0.8034
# Epoch 39/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7165 - accuracy: 0.7665 - val_loss: 0.6681 - val_accuracy: 0.8034
# Epoch 40/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6990 - accuracy: 0.7779 - val_loss: 0.6657 - val_accuracy: 0.8045
# Epoch 41/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6944 - accuracy: 0.7784 - val_loss: 0.6591 - val_accuracy: 0.8098
# Epoch 42/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6923 - accuracy: 0.7806 - val_loss: 0.6377 - val_accuracy: 0.7949
# Epoch 43/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6956 - accuracy: 0.7811 - val_loss: 0.6409 - val_accuracy: 0.8215
# Epoch 44/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6887 - accuracy: 0.7867 - val_loss: 0.6279 - val_accuracy: 0.8023
# Epoch 45/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6797 - accuracy: 0.7875 - val_loss: 0.6311 - val_accuracy: 0.8055
# Epoch 46/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6671 - accuracy: 0.7909 - val_loss: 0.6237 - val_accuracy: 0.8289
# Epoch 47/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6715 - accuracy: 0.7872 - val_loss: 0.6255 - val_accuracy: 0.8108
# Epoch 48/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6646 - accuracy: 0.7883 - val_loss: 0.6233 - val_accuracy: 0.8310
# Epoch 49/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6626 - accuracy: 0.7904 - val_loss: 0.6157 - val_accuracy: 0.8162
# Epoch 50/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6516 - accuracy: 0.7952 - val_loss: 0.6015 - val_accuracy: 0.8268
# Epoch 51/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6548 - accuracy: 0.7891 - val_loss: 0.6068 - val_accuracy: 0.8204
# Epoch 52/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6596 - accuracy: 0.7936 - val_loss: 0.6033 - val_accuracy: 0.8098
# Epoch 53/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6343 - accuracy: 0.8002 - val_loss: 0.5931 - val_accuracy: 0.8289
# Epoch 54/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6382 - accuracy: 0.7989 - val_loss: 0.5962 - val_accuracy: 0.8204
# Epoch 55/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6224 - accuracy: 0.8007 - val_loss: 0.5769 - val_accuracy: 0.8300
# Epoch 56/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6284 - accuracy: 0.8039 - val_loss: 0.5789 - val_accuracy: 0.8321
# Epoch 57/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6315 - accuracy: 0.8039 - val_loss: 0.5786 - val_accuracy: 0.8459
# Epoch 58/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6162 - accuracy: 0.8114 - val_loss: 0.5770 - val_accuracy: 0.8332
# Epoch 59/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6179 - accuracy: 0.8058 - val_loss: 0.5686 - val_accuracy: 0.8385
# Epoch 60/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6211 - accuracy: 0.8007 - val_loss: 0.5764 - val_accuracy: 0.8257
# Epoch 61/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6083 - accuracy: 0.8124 - val_loss: 0.5601 - val_accuracy: 0.8470
# Epoch 62/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6038 - accuracy: 0.8114 - val_loss: 0.5658 - val_accuracy: 0.8395
# Epoch 63/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6005 - accuracy: 0.8140 - val_loss: 0.5599 - val_accuracy: 0.8395
# Epoch 64/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6052 - accuracy: 0.8079 - val_loss: 0.5570 - val_accuracy: 0.8491
# Epoch 65/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6011 - accuracy: 0.8138 - val_loss: 0.5641 - val_accuracy: 0.8310
# Epoch 66/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6018 - accuracy: 0.8177 - val_loss: 0.5592 - val_accuracy: 0.8459
# Epoch 67/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5887 - accuracy: 0.8223 - val_loss: 0.5479 - val_accuracy: 0.8459
# Epoch 68/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5839 - accuracy: 0.8201 - val_loss: 0.5463 - val_accuracy: 0.8406
# Epoch 69/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5799 - accuracy: 0.8201 - val_loss: 0.5512 - val_accuracy: 0.8470
# Epoch 70/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5837 - accuracy: 0.8204 - val_loss: 0.5534 - val_accuracy: 0.8289
# Epoch 71/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5833 - accuracy: 0.8209 - val_loss: 0.5393 - val_accuracy: 0.8523
# Epoch 72/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5757 - accuracy: 0.8209 - val_loss: 0.5447 - val_accuracy: 0.8427
# Epoch 73/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5745 - accuracy: 0.8156 - val_loss: 0.5562 - val_accuracy: 0.8533
# Epoch 74/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5845 - accuracy: 0.8175 - val_loss: 0.5493 - val_accuracy: 0.8353
# Epoch 75/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5780 - accuracy: 0.8090 - val_loss: 0.5448 - val_accuracy: 0.8480
# Epoch 76/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5595 - accuracy: 0.8217 - val_loss: 0.5390 - val_accuracy: 0.8438
# Epoch 77/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5627 - accuracy: 0.8223 - val_loss: 0.5427 - val_accuracy: 0.8512
# Epoch 78/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5798 - accuracy: 0.8183 - val_loss: 0.5351 - val_accuracy: 0.8470
# Epoch 79/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5635 - accuracy: 0.8318 - val_loss: 0.5279 - val_accuracy: 0.8533
# Epoch 80/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5588 - accuracy: 0.8233 - val_loss: 0.5276 - val_accuracy: 0.8565
# Epoch 81/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5587 - accuracy: 0.8281 - val_loss: 0.5283 - val_accuracy: 0.8470
# Epoch 82/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5552 - accuracy: 0.8276 - val_loss: 0.5226 - val_accuracy: 0.8565
# Epoch 83/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5621 - accuracy: 0.8239 - val_loss: 0.5305 - val_accuracy: 0.8480
# Epoch 84/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5586 - accuracy: 0.8284 - val_loss: 0.5244 - val_accuracy: 0.8491
# Epoch 85/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5512 - accuracy: 0.8273 - val_loss: 0.5330 - val_accuracy: 0.8576
# Epoch 86/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5413 - accuracy: 0.8286 - val_loss: 0.5404 - val_accuracy: 0.8395
# Epoch 87/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5607 - accuracy: 0.8223 - val_loss: 0.5368 - val_accuracy: 0.8491
# Epoch 88/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5517 - accuracy: 0.8262 - val_loss: 0.5301 - val_accuracy: 0.8448
# Epoch 89/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5483 - accuracy: 0.8268 - val_loss: 0.5150 - val_accuracy: 0.8597
# Epoch 90/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5457 - accuracy: 0.8300 - val_loss: 0.5126 - val_accuracy: 0.8470
# Epoch 91/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5386 - accuracy: 0.8321 - val_loss: 0.5114 - val_accuracy: 0.8544
# Epoch 92/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5363 - accuracy: 0.8332 - val_loss: 0.5116 - val_accuracy: 0.8565
# Epoch 93/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5247 - accuracy: 0.8369 - val_loss: 0.5098 - val_accuracy: 0.8544
# Epoch 94/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5298 - accuracy: 0.8326 - val_loss: 0.5138 - val_accuracy: 0.8587
# Epoch 95/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5291 - accuracy: 0.8350 - val_loss: 0.5002 - val_accuracy: 0.8555
# Epoch 96/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5340 - accuracy: 0.8305 - val_loss: 0.5066 - val_accuracy: 0.8555
# Epoch 97/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5338 - accuracy: 0.8300 - val_loss: 0.5022 - val_accuracy: 0.8565
# Epoch 98/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5282 - accuracy: 0.8374 - val_loss: 0.5039 - val_accuracy: 0.8491
# Epoch 99/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5190 - accuracy: 0.8353 - val_loss: 0.5041 - val_accuracy: 0.8640
# Epoch 100/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5133 - accuracy: 0.8440 - val_loss: 0.5008 - val_accuracy: 0.8533
# Epoch 101/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5229 - accuracy: 0.8390 - val_loss: 0.4950 - val_accuracy: 0.8597
# Epoch 102/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5249 - accuracy: 0.8340 - val_loss: 0.4906 - val_accuracy: 0.8576
# Epoch 103/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5152 - accuracy: 0.8387 - val_loss: 0.4970 - val_accuracy: 0.8640
# Epoch 104/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5100 - accuracy: 0.8385 - val_loss: 0.5006 - val_accuracy: 0.8597
# Epoch 105/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5210 - accuracy: 0.8324 - val_loss: 0.4941 - val_accuracy: 0.8587
# Epoch 106/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5149 - accuracy: 0.8358 - val_loss: 0.4916 - val_accuracy: 0.8597
# Epoch 107/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5130 - accuracy: 0.8422 - val_loss: 0.4883 - val_accuracy: 0.8597
# Epoch 108/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5033 - accuracy: 0.8403 - val_loss: 0.4866 - val_accuracy: 0.8565
# Epoch 109/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5065 - accuracy: 0.8417 - val_loss: 0.4825 - val_accuracy: 0.8618
# Epoch 110/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4944 - accuracy: 0.8430 - val_loss: 0.4835 - val_accuracy: 0.8587
# Epoch 111/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5121 - accuracy: 0.8398 - val_loss: 0.4831 - val_accuracy: 0.8576
# Epoch 112/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4958 - accuracy: 0.8456 - val_loss: 0.4782 - val_accuracy: 0.8608
# Epoch 113/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5042 - accuracy: 0.8435 - val_loss: 0.4809 - val_accuracy: 0.8608
# Epoch 114/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5012 - accuracy: 0.8494 - val_loss: 0.4824 - val_accuracy: 0.8565
# Epoch 115/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5021 - accuracy: 0.8401 - val_loss: 0.4779 - val_accuracy: 0.8629
# Epoch 116/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4952 - accuracy: 0.8395 - val_loss: 0.4788 - val_accuracy: 0.8597
# Epoch 117/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5010 - accuracy: 0.8467 - val_loss: 0.4752 - val_accuracy: 0.8565
# Epoch 118/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4865 - accuracy: 0.8443 - val_loss: 0.4761 - val_accuracy: 0.8682
# Epoch 119/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4898 - accuracy: 0.8459 - val_loss: 0.4680 - val_accuracy: 0.8650
# Epoch 120/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4844 - accuracy: 0.8459 - val_loss: 0.4724 - val_accuracy: 0.8629
# Epoch 121/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4862 - accuracy: 0.8440 - val_loss: 0.4714 - val_accuracy: 0.8693
# Epoch 122/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4905 - accuracy: 0.8433 - val_loss: 0.4749 - val_accuracy: 0.8693
# Epoch 123/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4914 - accuracy: 0.8443 - val_loss: 0.4777 - val_accuracy: 0.8704
# Epoch 124/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4980 - accuracy: 0.8483 - val_loss: 0.4716 - val_accuracy: 0.8714
# Epoch 125/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4735 - accuracy: 0.8536 - val_loss: 0.4593 - val_accuracy: 0.8735
# Epoch 126/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4700 - accuracy: 0.8518 - val_loss: 0.4606 - val_accuracy: 0.8693
# Epoch 127/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4719 - accuracy: 0.8539 - val_loss: 0.4606 - val_accuracy: 0.8714
# Epoch 128/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4824 - accuracy: 0.8491 - val_loss: 0.4616 - val_accuracy: 0.8661
# Epoch 129/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4777 - accuracy: 0.8510 - val_loss: 0.4576 - val_accuracy: 0.8725
# Epoch 130/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4798 - accuracy: 0.8483 - val_loss: 0.4565 - val_accuracy: 0.8672
# Epoch 131/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4773 - accuracy: 0.8531 - val_loss: 0.4613 - val_accuracy: 0.8661
# Epoch 132/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4686 - accuracy: 0.8510 - val_loss: 0.4548 - val_accuracy: 0.8778
# Epoch 133/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4744 - accuracy: 0.8488 - val_loss: 0.4535 - val_accuracy: 0.8618
# Epoch 134/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4694 - accuracy: 0.8571 - val_loss: 0.4493 - val_accuracy: 0.8725
# Epoch 135/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4705 - accuracy: 0.8528 - val_loss: 0.4501 - val_accuracy: 0.8672
# Epoch 136/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4630 - accuracy: 0.8549 - val_loss: 0.4500 - val_accuracy: 0.8714
# Epoch 137/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4695 - accuracy: 0.8555 - val_loss: 0.4524 - val_accuracy: 0.8704
# Epoch 138/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4715 - accuracy: 0.8547 - val_loss: 0.4488 - val_accuracy: 0.8778
# Epoch 139/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4680 - accuracy: 0.8451 - val_loss: 0.4515 - val_accuracy: 0.8704
# Epoch 140/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4638 - accuracy: 0.8523 - val_loss: 0.4478 - val_accuracy: 0.8789
# Epoch 141/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4635 - accuracy: 0.8536 - val_loss: 0.4454 - val_accuracy: 0.8661
# Epoch 142/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4566 - accuracy: 0.8555 - val_loss: 0.4432 - val_accuracy: 0.8831
# Epoch 143/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4524 - accuracy: 0.8584 - val_loss: 0.4463 - val_accuracy: 0.8661
# Epoch 144/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4528 - accuracy: 0.8541 - val_loss: 0.4403 - val_accuracy: 0.8778
# Epoch 145/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4632 - accuracy: 0.8547 - val_loss: 0.4410 - val_accuracy: 0.8757
# Epoch 146/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4546 - accuracy: 0.8584 - val_loss: 0.4377 - val_accuracy: 0.8810
# Epoch 147/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4463 - accuracy: 0.8616 - val_loss: 0.4376 - val_accuracy: 0.8789
# Epoch 148/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4494 - accuracy: 0.8549 - val_loss: 0.4348 - val_accuracy: 0.8842
# Epoch 149/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4441 - accuracy: 0.8573 - val_loss: 0.4391 - val_accuracy: 0.8746
# Epoch 150/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4499 - accuracy: 0.8600 - val_loss: 0.4343 - val_accuracy: 0.8778
# Epoch 151/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4374 - accuracy: 0.8624 - val_loss: 0.4335 - val_accuracy: 0.8820
# Epoch 152/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4459 - accuracy: 0.8563 - val_loss: 0.4354 - val_accuracy: 0.8757
# Epoch 153/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4526 - accuracy: 0.8531 - val_loss: 0.4372 - val_accuracy: 0.8799
# Epoch 154/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4411 - accuracy: 0.8595 - val_loss: 0.4366 - val_accuracy: 0.8746
# Epoch 155/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4440 - accuracy: 0.8595 - val_loss: 0.4313 - val_accuracy: 0.8842
# Epoch 156/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4422 - accuracy: 0.8624 - val_loss: 0.4296 - val_accuracy: 0.8778
# Epoch 157/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4433 - accuracy: 0.8597 - val_loss: 0.4285 - val_accuracy: 0.8810
# Epoch 158/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4413 - accuracy: 0.8600 - val_loss: 0.4293 - val_accuracy: 0.8810
# Epoch 159/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4351 - accuracy: 0.8587 - val_loss: 0.4230 - val_accuracy: 0.8820
# Epoch 160/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4300 - accuracy: 0.8672 - val_loss: 0.4337 - val_accuracy: 0.8799
# Epoch 161/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4437 - accuracy: 0.8571 - val_loss: 0.4280 - val_accuracy: 0.8810
# Epoch 162/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4377 - accuracy: 0.8616 - val_loss: 0.4234 - val_accuracy: 0.8799
# Epoch 163/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4434 - accuracy: 0.8629 - val_loss: 0.4219 - val_accuracy: 0.8757
# Epoch 164/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4406 - accuracy: 0.8608 - val_loss: 0.4180 - val_accuracy: 0.8863
# Epoch 165/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4398 - accuracy: 0.8595 - val_loss: 0.4269 - val_accuracy: 0.8799
# Epoch 166/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4333 - accuracy: 0.8618 - val_loss: 0.4187 - val_accuracy: 0.8874
# Epoch 167/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4362 - accuracy: 0.8595 - val_loss: 0.4210 - val_accuracy: 0.8757
# Epoch 168/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4344 - accuracy: 0.8560 - val_loss: 0.4153 - val_accuracy: 0.8820
# Epoch 169/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4154 - accuracy: 0.8677 - val_loss: 0.4113 - val_accuracy: 0.8863
# Epoch 170/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4184 - accuracy: 0.8650 - val_loss: 0.4151 - val_accuracy: 0.8799
# Epoch 171/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4211 - accuracy: 0.8637 - val_loss: 0.4134 - val_accuracy: 0.8810
# Epoch 172/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4167 - accuracy: 0.8698 - val_loss: 0.4058 - val_accuracy: 0.8852
# Epoch 173/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4165 - accuracy: 0.8669 - val_loss: 0.4127 - val_accuracy: 0.8735
# Epoch 174/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4134 - accuracy: 0.8632 - val_loss: 0.4099 - val_accuracy: 0.8842
# Epoch 175/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4104 - accuracy: 0.8640 - val_loss: 0.4202 - val_accuracy: 0.8799
# Epoch 176/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4274 - accuracy: 0.8669 - val_loss: 0.4136 - val_accuracy: 0.8842
# Epoch 177/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4078 - accuracy: 0.8738 - val_loss: 0.4188 - val_accuracy: 0.8852
# Epoch 178/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4095 - accuracy: 0.8698 - val_loss: 0.4102 - val_accuracy: 0.8789
# Epoch 179/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4193 - accuracy: 0.8680 - val_loss: 0.4038 - val_accuracy: 0.8863
# Epoch 180/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4109 - accuracy: 0.8642 - val_loss: 0.4023 - val_accuracy: 0.8831
# Epoch 181/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4140 - accuracy: 0.8743 - val_loss: 0.4021 - val_accuracy: 0.8852
# Epoch 182/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4097 - accuracy: 0.8685 - val_loss: 0.3999 - val_accuracy: 0.8863
# Epoch 183/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4104 - accuracy: 0.8661 - val_loss: 0.4013 - val_accuracy: 0.8852
# Epoch 184/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4052 - accuracy: 0.8696 - val_loss: 0.3960 - val_accuracy: 0.8916
# Epoch 185/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4058 - accuracy: 0.8714 - val_loss: 0.4019 - val_accuracy: 0.8863
# Epoch 186/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4046 - accuracy: 0.8727 - val_loss: 0.4050 - val_accuracy: 0.8852
# Epoch 187/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4018 - accuracy: 0.8725 - val_loss: 0.4003 - val_accuracy: 0.8905
# Epoch 188/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4041 - accuracy: 0.8711 - val_loss: 0.3990 - val_accuracy: 0.8874
# Epoch 189/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4023 - accuracy: 0.8704 - val_loss: 0.3922 - val_accuracy: 0.8884
# Epoch 190/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4030 - accuracy: 0.8722 - val_loss: 0.3972 - val_accuracy: 0.8842
# Epoch 191/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4043 - accuracy: 0.8711 - val_loss: 0.3892 - val_accuracy: 0.8895
# Epoch 192/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4012 - accuracy: 0.8685 - val_loss: 0.3938 - val_accuracy: 0.8842
# Epoch 193/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3974 - accuracy: 0.8674 - val_loss: 0.3897 - val_accuracy: 0.8937
# Epoch 194/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3910 - accuracy: 0.8722 - val_loss: 0.3898 - val_accuracy: 0.8905
# Epoch 195/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3961 - accuracy: 0.8693 - val_loss: 0.3894 - val_accuracy: 0.8863
# Epoch 196/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3864 - accuracy: 0.8791 - val_loss: 0.3882 - val_accuracy: 0.8884
# Epoch 197/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3961 - accuracy: 0.8746 - val_loss: 0.3865 - val_accuracy: 0.8863
# Epoch 198/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3962 - accuracy: 0.8717 - val_loss: 0.3884 - val_accuracy: 0.8842
# Epoch 199/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3962 - accuracy: 0.8717 - val_loss: 0.3842 - val_accuracy: 0.8927
# Epoch 200/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3950 - accuracy: 0.8738 - val_loss: 0.3902 - val_accuracy: 0.8884

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 43ms/step - loss: 2.0088 - accuracy: 0.2869 - val_loss: 1.7997 - val_accuracy: 0.3475
# Epoch 2/50
# 8/8 [==============================] - 0s 22ms/step - loss: 1.7689 - accuracy: 0.3908 - val_loss: 1.6382 - val_accuracy: 0.4570
# Epoch 3/50
# 8/8 [==============================] - 0s 24ms/step - loss: 1.6180 - accuracy: 0.5045 - val_loss: 1.4849 - val_accuracy: 0.5441
# Epoch 4/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.4877 - accuracy: 0.4997 - val_loss: 1.3756 - val_accuracy: 0.5558
# Epoch 5/50
# 8/8 [==============================] - 0s 23ms/step - loss: 1.3947 - accuracy: 0.5247 - val_loss: 1.2994 - val_accuracy: 0.5558
# Epoch 6/50
# 8/8 [==============================] - 0s 22ms/step - loss: 1.3305 - accuracy: 0.5383 - val_loss: 1.2496 - val_accuracy: 0.5462
# Epoch 7/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.2806 - accuracy: 0.5481 - val_loss: 1.2007 - val_accuracy: 0.5919
# Epoch 8/50
# 8/8 [==============================] - 0s 23ms/step - loss: 1.2346 - accuracy: 0.5715 - val_loss: 1.1678 - val_accuracy: 0.6344
# Epoch 9/50
# 8/8 [==============================] - 0s 22ms/step - loss: 1.1978 - accuracy: 0.6004 - val_loss: 1.1233 - val_accuracy: 0.6334
# Epoch 10/50
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1578 - accuracy: 0.6065 - val_loss: 1.0892 - val_accuracy: 0.6472
# Epoch 11/50
# 8/8 [==============================] - 0s 22ms/step - loss: 1.1211 - accuracy: 0.6254 - val_loss: 1.0550 - val_accuracy: 0.6440
# Epoch 12/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0845 - accuracy: 0.6312 - val_loss: 1.0262 - val_accuracy: 0.6557
# Epoch 13/50
# 8/8 [==============================] - 0s 23ms/step - loss: 1.0673 - accuracy: 0.6387 - val_loss: 0.9948 - val_accuracy: 0.6791
# Epoch 14/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0356 - accuracy: 0.6392 - val_loss: 0.9683 - val_accuracy: 0.6663
# Epoch 15/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0001 - accuracy: 0.6719 - val_loss: 0.9444 - val_accuracy: 0.6801
# Epoch 16/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.9932 - accuracy: 0.6607 - val_loss: 0.9250 - val_accuracy: 0.6791
# Epoch 17/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9652 - accuracy: 0.6682 - val_loss: 0.9049 - val_accuracy: 0.6961
# Epoch 18/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.9457 - accuracy: 0.6767 - val_loss: 0.8858 - val_accuracy: 0.7163
# Epoch 19/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.9292 - accuracy: 0.6852 - val_loss: 0.8696 - val_accuracy: 0.7226
# Epoch 20/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9095 - accuracy: 0.6913 - val_loss: 0.8555 - val_accuracy: 0.7418
# Epoch 21/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9036 - accuracy: 0.6921 - val_loss: 0.8360 - val_accuracy: 0.7439
# Epoch 22/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.8852 - accuracy: 0.6979 - val_loss: 0.8258 - val_accuracy: 0.7152
# Epoch 23/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8682 - accuracy: 0.7165 - val_loss: 0.8077 - val_accuracy: 0.7428
# Epoch 24/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8461 - accuracy: 0.7218 - val_loss: 0.7963 - val_accuracy: 0.7439
# Epoch 25/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8416 - accuracy: 0.7216 - val_loss: 0.7814 - val_accuracy: 0.7641
# Epoch 26/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.8347 - accuracy: 0.7256 - val_loss: 0.7795 - val_accuracy: 0.7407
# Epoch 27/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.8254 - accuracy: 0.7295 - val_loss: 0.7666 - val_accuracy: 0.7428
# Epoch 28/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8103 - accuracy: 0.7309 - val_loss: 0.7570 - val_accuracy: 0.7662
# Epoch 29/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8082 - accuracy: 0.7386 - val_loss: 0.7462 - val_accuracy: 0.7598
# Epoch 30/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7944 - accuracy: 0.7404 - val_loss: 0.7463 - val_accuracy: 0.7620
# Epoch 31/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7940 - accuracy: 0.7362 - val_loss: 0.7368 - val_accuracy: 0.7715
# Epoch 32/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7763 - accuracy: 0.7500 - val_loss: 0.7223 - val_accuracy: 0.7726
# Epoch 33/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7693 - accuracy: 0.7553 - val_loss: 0.7158 - val_accuracy: 0.7790
# Epoch 34/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7629 - accuracy: 0.7495 - val_loss: 0.7149 - val_accuracy: 0.7694
# Epoch 35/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7649 - accuracy: 0.7465 - val_loss: 0.7113 - val_accuracy: 0.7917
# Epoch 36/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7510 - accuracy: 0.7606 - val_loss: 0.6933 - val_accuracy: 0.7896
# Epoch 37/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7458 - accuracy: 0.7590 - val_loss: 0.6865 - val_accuracy: 0.7885
# Epoch 38/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7353 - accuracy: 0.7617 - val_loss: 0.6839 - val_accuracy: 0.7875
# Epoch 39/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7307 - accuracy: 0.7622 - val_loss: 0.6817 - val_accuracy: 0.7768
# Epoch 40/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7274 - accuracy: 0.7659 - val_loss: 0.6730 - val_accuracy: 0.7896
# Epoch 41/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7216 - accuracy: 0.7691 - val_loss: 0.6693 - val_accuracy: 0.8066
# Epoch 42/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7177 - accuracy: 0.7718 - val_loss: 0.6641 - val_accuracy: 0.7981
# Epoch 43/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7067 - accuracy: 0.7723 - val_loss: 0.6633 - val_accuracy: 0.8130
# Epoch 44/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7123 - accuracy: 0.7782 - val_loss: 0.6491 - val_accuracy: 0.8108
# Epoch 45/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6893 - accuracy: 0.7800 - val_loss: 0.6423 - val_accuracy: 0.8119
# Epoch 46/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6931 - accuracy: 0.7808 - val_loss: 0.6389 - val_accuracy: 0.8140
# Epoch 47/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6921 - accuracy: 0.7771 - val_loss: 0.6364 - val_accuracy: 0.8172
# Epoch 48/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6792 - accuracy: 0.7790 - val_loss: 0.6290 - val_accuracy: 0.8193
# Epoch 49/50
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6743 - accuracy: 0.7893 - val_loss: 0.6270 - val_accuracy: 0.8225
# Epoch 50/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6769 - accuracy: 0.7851 - val_loss: 0.6291 - val_accuracy: 0.8183

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 0s 2ms/step - loss: 0.6107 - accuracy: 0.8297
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.8183
# 0.8297024369239807 0.818278431892395

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 22, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:01:52

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
