# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 53
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 53
# [[0, 16], [16, 32], [32, 48], [48, 64], [64, 80], [80, 96], [96, 112], [112, 128], [128, 144], [144, 160], [160, 176], [176, 192], [192, 208], [208, 224], [224, 240], [240, 256], [256, 272], [272, 288], [288, 304], [304, 320], [320, 336], [336, 352], [352, 368], [368, 384], [384, 400], [400, 416], [416, 432], [432, 448], [448, 464], [464, 480], [480, 496], [496, 512], [512, 528], [528, 544], [544, 560], [560, 576], [576, 592], [592, 608], [608, 624], [624, 640], [640, 656], [656, 672], [672, 688], [688, 704], [704, 720], [720, 736], [736, 752], [752, 768], [768, 784], [784, 800], [800, 816], [816, 832], [832, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 53)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 53)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 53) (60, 53)
# clouds  (400, 53) (100, 53)
# vegetation  (480, 53) (120, 53)
# water  (40, 53) (10, 53)
# built  (816, 53) (204, 53)
# windows  (400, 53) (100, 53)
# roads  (24, 53) (6, 53)
# cars  (80, 53) (20, 53)
# metal  (80, 53) (20, 53)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 53) (2560,) (2560, 2)
# (640, 53) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 67ms/step - loss: 1.8920 - accuracy: 0.3059 - val_loss: 1.5603 - val_accuracy: 0.4906
# Epoch 2/200
# 5/5 [==============================] - 0s 37ms/step - loss: 1.4593 - accuracy: 0.5605 - val_loss: 1.1937 - val_accuracy: 0.6516
# Epoch 3/200
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1351 - accuracy: 0.6406 - val_loss: 0.9528 - val_accuracy: 0.7078
# Epoch 4/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.9439 - accuracy: 0.6898 - val_loss: 0.8289 - val_accuracy: 0.7328
# Epoch 5/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.8356 - accuracy: 0.7207 - val_loss: 0.7570 - val_accuracy: 0.7266
# Epoch 6/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7853 - accuracy: 0.7293 - val_loss: 0.7290 - val_accuracy: 0.7656
# Epoch 7/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7362 - accuracy: 0.7660 - val_loss: 0.6534 - val_accuracy: 0.7969
# Epoch 8/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6884 - accuracy: 0.7793 - val_loss: 0.6327 - val_accuracy: 0.8109
# Epoch 9/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6443 - accuracy: 0.7949 - val_loss: 0.5821 - val_accuracy: 0.8047
# Epoch 10/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6087 - accuracy: 0.8039 - val_loss: 0.5438 - val_accuracy: 0.8000
# Epoch 11/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5699 - accuracy: 0.8035 - val_loss: 0.5191 - val_accuracy: 0.8062
# Epoch 12/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5422 - accuracy: 0.8191 - val_loss: 0.4866 - val_accuracy: 0.8172
# Epoch 13/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5193 - accuracy: 0.8234 - val_loss: 0.4702 - val_accuracy: 0.8516
# Epoch 14/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.4952 - accuracy: 0.8426 - val_loss: 0.4416 - val_accuracy: 0.8469
# Epoch 15/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.4699 - accuracy: 0.8469 - val_loss: 0.4210 - val_accuracy: 0.8656
# Epoch 16/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4530 - accuracy: 0.8531 - val_loss: 0.4152 - val_accuracy: 0.8516
# Epoch 17/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4391 - accuracy: 0.8570 - val_loss: 0.3925 - val_accuracy: 0.8828
# Epoch 18/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.4165 - accuracy: 0.8660 - val_loss: 0.3790 - val_accuracy: 0.8969
# Epoch 19/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4105 - accuracy: 0.8758 - val_loss: 0.3729 - val_accuracy: 0.8953
# Epoch 20/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4095 - accuracy: 0.8766 - val_loss: 0.3624 - val_accuracy: 0.8922
# Epoch 21/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3920 - accuracy: 0.8738 - val_loss: 0.3448 - val_accuracy: 0.9016
# Epoch 22/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3808 - accuracy: 0.8801 - val_loss: 0.3408 - val_accuracy: 0.9062
# Epoch 23/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3722 - accuracy: 0.8828 - val_loss: 0.3295 - val_accuracy: 0.9109
# Epoch 24/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3601 - accuracy: 0.8906 - val_loss: 0.3218 - val_accuracy: 0.9078
# Epoch 25/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3662 - accuracy: 0.8875 - val_loss: 0.3211 - val_accuracy: 0.8969
# Epoch 26/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3504 - accuracy: 0.8922 - val_loss: 0.3455 - val_accuracy: 0.8891
# Epoch 27/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3504 - accuracy: 0.8977 - val_loss: 0.3111 - val_accuracy: 0.9062
# Epoch 28/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3358 - accuracy: 0.9023 - val_loss: 0.3079 - val_accuracy: 0.9125
# Epoch 29/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3351 - accuracy: 0.8996 - val_loss: 0.2942 - val_accuracy: 0.9125
# Epoch 30/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3173 - accuracy: 0.9066 - val_loss: 0.2913 - val_accuracy: 0.9094
# Epoch 31/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3108 - accuracy: 0.9074 - val_loss: 0.2842 - val_accuracy: 0.9109
# Epoch 32/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3109 - accuracy: 0.9043 - val_loss: 0.2805 - val_accuracy: 0.9172
# Epoch 33/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3082 - accuracy: 0.9113 - val_loss: 0.2722 - val_accuracy: 0.9156
# Epoch 34/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2973 - accuracy: 0.9137 - val_loss: 0.2686 - val_accuracy: 0.9187
# Epoch 35/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2888 - accuracy: 0.9113 - val_loss: 0.2633 - val_accuracy: 0.9219
# Epoch 36/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2936 - accuracy: 0.9129 - val_loss: 0.2624 - val_accuracy: 0.9187
# Epoch 37/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2802 - accuracy: 0.9156 - val_loss: 0.2575 - val_accuracy: 0.9172
# Epoch 38/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2815 - accuracy: 0.9141 - val_loss: 0.2550 - val_accuracy: 0.9187
# Epoch 39/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2771 - accuracy: 0.9172 - val_loss: 0.2529 - val_accuracy: 0.9156
# Epoch 40/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2720 - accuracy: 0.9168 - val_loss: 0.2472 - val_accuracy: 0.9187
# Epoch 41/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2750 - accuracy: 0.9156 - val_loss: 0.2482 - val_accuracy: 0.9250
# Epoch 42/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2647 - accuracy: 0.9172 - val_loss: 0.2503 - val_accuracy: 0.9234
# Epoch 43/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2758 - accuracy: 0.9191 - val_loss: 0.2390 - val_accuracy: 0.9266
# Epoch 44/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2659 - accuracy: 0.9141 - val_loss: 0.2497 - val_accuracy: 0.9172
# Epoch 45/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2598 - accuracy: 0.9262 - val_loss: 0.2336 - val_accuracy: 0.9266
# Epoch 46/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2586 - accuracy: 0.9207 - val_loss: 0.2346 - val_accuracy: 0.9219
# Epoch 47/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2623 - accuracy: 0.9195 - val_loss: 0.2396 - val_accuracy: 0.9266
# Epoch 48/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2562 - accuracy: 0.9191 - val_loss: 0.2546 - val_accuracy: 0.9250
# Epoch 49/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2713 - accuracy: 0.9105 - val_loss: 0.2534 - val_accuracy: 0.9234
# Epoch 50/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2541 - accuracy: 0.9242 - val_loss: 0.2337 - val_accuracy: 0.9219
# Epoch 51/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2531 - accuracy: 0.9207 - val_loss: 0.2299 - val_accuracy: 0.9234
# Epoch 52/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2407 - accuracy: 0.9246 - val_loss: 0.2283 - val_accuracy: 0.9219
# Epoch 53/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2390 - accuracy: 0.9219 - val_loss: 0.2232 - val_accuracy: 0.9172
# Epoch 54/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2323 - accuracy: 0.9273 - val_loss: 0.2148 - val_accuracy: 0.9297
# Epoch 55/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2267 - accuracy: 0.9266 - val_loss: 0.2215 - val_accuracy: 0.9312
# Epoch 56/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2268 - accuracy: 0.9270 - val_loss: 0.2110 - val_accuracy: 0.9281
# Epoch 57/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2166 - accuracy: 0.9320 - val_loss: 0.2085 - val_accuracy: 0.9234
# Epoch 58/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2198 - accuracy: 0.9312 - val_loss: 0.2094 - val_accuracy: 0.9266
# Epoch 59/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2250 - accuracy: 0.9285 - val_loss: 0.2168 - val_accuracy: 0.9344
# Epoch 60/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2276 - accuracy: 0.9266 - val_loss: 0.2037 - val_accuracy: 0.9312
# Epoch 61/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2238 - accuracy: 0.9250 - val_loss: 0.2094 - val_accuracy: 0.9312
# Epoch 62/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2222 - accuracy: 0.9297 - val_loss: 0.2172 - val_accuracy: 0.9187
# Epoch 63/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2186 - accuracy: 0.9301 - val_loss: 0.1991 - val_accuracy: 0.9266
# Epoch 64/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2119 - accuracy: 0.9301 - val_loss: 0.1992 - val_accuracy: 0.9297
# Epoch 65/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2018 - accuracy: 0.9371 - val_loss: 0.1936 - val_accuracy: 0.9328
# Epoch 66/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2066 - accuracy: 0.9340 - val_loss: 0.1951 - val_accuracy: 0.9328
# Epoch 67/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2039 - accuracy: 0.9332 - val_loss: 0.1939 - val_accuracy: 0.9375
# Epoch 68/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1978 - accuracy: 0.9371 - val_loss: 0.1893 - val_accuracy: 0.9344
# Epoch 69/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1966 - accuracy: 0.9367 - val_loss: 0.1946 - val_accuracy: 0.9391
# Epoch 70/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1872 - accuracy: 0.9391 - val_loss: 0.1827 - val_accuracy: 0.9328
# Epoch 71/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1920 - accuracy: 0.9367 - val_loss: 0.1821 - val_accuracy: 0.9391
# Epoch 72/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1917 - accuracy: 0.9336 - val_loss: 0.1812 - val_accuracy: 0.9328
# Epoch 73/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1855 - accuracy: 0.9395 - val_loss: 0.1789 - val_accuracy: 0.9438
# Epoch 74/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1841 - accuracy: 0.9410 - val_loss: 0.1814 - val_accuracy: 0.9359
# Epoch 75/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1840 - accuracy: 0.9414 - val_loss: 0.1894 - val_accuracy: 0.9297
# Epoch 76/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1873 - accuracy: 0.9379 - val_loss: 0.1825 - val_accuracy: 0.9344
# Epoch 77/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1869 - accuracy: 0.9375 - val_loss: 0.1818 - val_accuracy: 0.9438
# Epoch 78/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1874 - accuracy: 0.9379 - val_loss: 0.1765 - val_accuracy: 0.9359
# Epoch 79/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1790 - accuracy: 0.9363 - val_loss: 0.1947 - val_accuracy: 0.9484
# Epoch 80/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1914 - accuracy: 0.9355 - val_loss: 0.1738 - val_accuracy: 0.9391
# Epoch 81/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1801 - accuracy: 0.9418 - val_loss: 0.1689 - val_accuracy: 0.9469
# Epoch 82/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1806 - accuracy: 0.9422 - val_loss: 0.1692 - val_accuracy: 0.9406
# Epoch 83/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1763 - accuracy: 0.9445 - val_loss: 0.1713 - val_accuracy: 0.9422
# Epoch 84/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1784 - accuracy: 0.9352 - val_loss: 0.1676 - val_accuracy: 0.9453
# Epoch 85/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1735 - accuracy: 0.9434 - val_loss: 0.1683 - val_accuracy: 0.9500
# Epoch 86/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1650 - accuracy: 0.9453 - val_loss: 0.1677 - val_accuracy: 0.9391
# Epoch 87/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1610 - accuracy: 0.9488 - val_loss: 0.1632 - val_accuracy: 0.9422
# Epoch 88/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1639 - accuracy: 0.9457 - val_loss: 0.1596 - val_accuracy: 0.9484
# Epoch 89/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1598 - accuracy: 0.9473 - val_loss: 0.1576 - val_accuracy: 0.9469
# Epoch 90/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1594 - accuracy: 0.9418 - val_loss: 0.1577 - val_accuracy: 0.9516
# Epoch 91/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1670 - accuracy: 0.9461 - val_loss: 0.1600 - val_accuracy: 0.9438
# Epoch 92/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1606 - accuracy: 0.9453 - val_loss: 0.1533 - val_accuracy: 0.9500
# Epoch 93/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1548 - accuracy: 0.9469 - val_loss: 0.1526 - val_accuracy: 0.9500
# Epoch 94/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1515 - accuracy: 0.9457 - val_loss: 0.1549 - val_accuracy: 0.9516
# Epoch 95/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1575 - accuracy: 0.9469 - val_loss: 0.1536 - val_accuracy: 0.9484
# Epoch 96/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1564 - accuracy: 0.9473 - val_loss: 0.1719 - val_accuracy: 0.9469
# Epoch 97/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1606 - accuracy: 0.9480 - val_loss: 0.1687 - val_accuracy: 0.9359
# Epoch 98/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1640 - accuracy: 0.9480 - val_loss: 0.1525 - val_accuracy: 0.9516
# Epoch 99/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1638 - accuracy: 0.9438 - val_loss: 0.1717 - val_accuracy: 0.9484
# Epoch 100/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1632 - accuracy: 0.9480 - val_loss: 0.1632 - val_accuracy: 0.9453
# Epoch 101/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1561 - accuracy: 0.9488 - val_loss: 0.1562 - val_accuracy: 0.9516
# Epoch 102/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1621 - accuracy: 0.9449 - val_loss: 0.1604 - val_accuracy: 0.9516
# Epoch 103/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1581 - accuracy: 0.9477 - val_loss: 0.1591 - val_accuracy: 0.9438
# Epoch 104/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1604 - accuracy: 0.9410 - val_loss: 0.1681 - val_accuracy: 0.9516
# Epoch 105/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1450 - accuracy: 0.9504 - val_loss: 0.1484 - val_accuracy: 0.9500
# Epoch 106/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1422 - accuracy: 0.9547 - val_loss: 0.1447 - val_accuracy: 0.9578
# Epoch 107/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1448 - accuracy: 0.9508 - val_loss: 0.1498 - val_accuracy: 0.9469
# Epoch 108/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1419 - accuracy: 0.9520 - val_loss: 0.1407 - val_accuracy: 0.9563
# Epoch 109/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1343 - accuracy: 0.9523 - val_loss: 0.1414 - val_accuracy: 0.9594
# Epoch 110/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1382 - accuracy: 0.9523 - val_loss: 0.1391 - val_accuracy: 0.9563
# Epoch 111/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1401 - accuracy: 0.9563 - val_loss: 0.1648 - val_accuracy: 0.9391
# Epoch 112/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1600 - accuracy: 0.9410 - val_loss: 0.1695 - val_accuracy: 0.9469
# Epoch 113/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1518 - accuracy: 0.9508 - val_loss: 0.1503 - val_accuracy: 0.9484
# Epoch 114/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1442 - accuracy: 0.9527 - val_loss: 0.1523 - val_accuracy: 0.9578
# Epoch 115/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1347 - accuracy: 0.9559 - val_loss: 0.1394 - val_accuracy: 0.9516
# Epoch 116/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1341 - accuracy: 0.9574 - val_loss: 0.1409 - val_accuracy: 0.9609
# Epoch 117/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1373 - accuracy: 0.9539 - val_loss: 0.1314 - val_accuracy: 0.9578
# Epoch 118/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1248 - accuracy: 0.9590 - val_loss: 0.1355 - val_accuracy: 0.9594
# Epoch 119/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1281 - accuracy: 0.9539 - val_loss: 0.1349 - val_accuracy: 0.9594
# Epoch 120/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1275 - accuracy: 0.9586 - val_loss: 0.1335 - val_accuracy: 0.9609
# Epoch 121/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1237 - accuracy: 0.9609 - val_loss: 0.1367 - val_accuracy: 0.9516
# Epoch 122/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1244 - accuracy: 0.9555 - val_loss: 0.1313 - val_accuracy: 0.9609
# Epoch 123/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1226 - accuracy: 0.9586 - val_loss: 0.1346 - val_accuracy: 0.9625
# Epoch 124/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1224 - accuracy: 0.9555 - val_loss: 0.1342 - val_accuracy: 0.9531
# Epoch 125/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1187 - accuracy: 0.9602 - val_loss: 0.1360 - val_accuracy: 0.9609
# Epoch 126/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1225 - accuracy: 0.9531 - val_loss: 0.1334 - val_accuracy: 0.9625
# Epoch 127/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1211 - accuracy: 0.9590 - val_loss: 0.1301 - val_accuracy: 0.9609
# Epoch 128/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1212 - accuracy: 0.9633 - val_loss: 0.1329 - val_accuracy: 0.9578
# Epoch 129/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1117 - accuracy: 0.9641 - val_loss: 0.1305 - val_accuracy: 0.9609
# Epoch 130/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1159 - accuracy: 0.9586 - val_loss: 0.1315 - val_accuracy: 0.9609
# Epoch 131/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1250 - accuracy: 0.9574 - val_loss: 0.1329 - val_accuracy: 0.9625
# Epoch 132/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1097 - accuracy: 0.9648 - val_loss: 0.1293 - val_accuracy: 0.9563
# Epoch 133/200
# 5/5 [==============================] - 1s 157ms/step - loss: 0.1173 - accuracy: 0.9598 - val_loss: 0.1359 - val_accuracy: 0.9594
# Epoch 134/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1169 - accuracy: 0.9586 - val_loss: 0.1240 - val_accuracy: 0.9578
# Epoch 135/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1183 - accuracy: 0.9598 - val_loss: 0.1268 - val_accuracy: 0.9594
# Epoch 136/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1123 - accuracy: 0.9617 - val_loss: 0.1306 - val_accuracy: 0.9578
# Epoch 137/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1125 - accuracy: 0.9605 - val_loss: 0.1286 - val_accuracy: 0.9625
# Epoch 138/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1206 - accuracy: 0.9590 - val_loss: 0.1268 - val_accuracy: 0.9563
# Epoch 139/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1142 - accuracy: 0.9617 - val_loss: 0.1263 - val_accuracy: 0.9641
# Epoch 140/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1125 - accuracy: 0.9617 - val_loss: 0.1243 - val_accuracy: 0.9625
# Epoch 141/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1069 - accuracy: 0.9652 - val_loss: 0.1296 - val_accuracy: 0.9563
# Epoch 142/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1109 - accuracy: 0.9613 - val_loss: 0.1265 - val_accuracy: 0.9625
# Epoch 143/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1136 - accuracy: 0.9641 - val_loss: 0.1295 - val_accuracy: 0.9547
# Epoch 144/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1107 - accuracy: 0.9641 - val_loss: 0.1274 - val_accuracy: 0.9500
# Epoch 145/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1111 - accuracy: 0.9625 - val_loss: 0.1254 - val_accuracy: 0.9609
# Epoch 146/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1047 - accuracy: 0.9664 - val_loss: 0.1246 - val_accuracy: 0.9609
# Epoch 147/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1103 - accuracy: 0.9617 - val_loss: 0.1329 - val_accuracy: 0.9531
# Epoch 148/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1113 - accuracy: 0.9605 - val_loss: 0.1202 - val_accuracy: 0.9594
# Epoch 149/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1137 - accuracy: 0.9590 - val_loss: 0.1256 - val_accuracy: 0.9656
# Epoch 150/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1024 - accuracy: 0.9664 - val_loss: 0.1215 - val_accuracy: 0.9594
# Epoch 151/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1055 - accuracy: 0.9656 - val_loss: 0.1358 - val_accuracy: 0.9484
# Epoch 152/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1124 - accuracy: 0.9648 - val_loss: 0.1217 - val_accuracy: 0.9578
# Epoch 153/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1126 - accuracy: 0.9605 - val_loss: 0.1268 - val_accuracy: 0.9656
# Epoch 154/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1059 - accuracy: 0.9656 - val_loss: 0.1290 - val_accuracy: 0.9516
# Epoch 155/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1114 - accuracy: 0.9613 - val_loss: 0.1262 - val_accuracy: 0.9563
# Epoch 156/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1057 - accuracy: 0.9629 - val_loss: 0.1245 - val_accuracy: 0.9547
# Epoch 157/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1027 - accuracy: 0.9660 - val_loss: 0.1164 - val_accuracy: 0.9609
# Epoch 158/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1022 - accuracy: 0.9648 - val_loss: 0.1302 - val_accuracy: 0.9547
# Epoch 159/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1061 - accuracy: 0.9613 - val_loss: 0.1200 - val_accuracy: 0.9578
# Epoch 160/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1043 - accuracy: 0.9609 - val_loss: 0.1244 - val_accuracy: 0.9625
# Epoch 161/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1007 - accuracy: 0.9652 - val_loss: 0.1185 - val_accuracy: 0.9578
# Epoch 162/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0970 - accuracy: 0.9688 - val_loss: 0.1196 - val_accuracy: 0.9609
# Epoch 163/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0957 - accuracy: 0.9695 - val_loss: 0.1278 - val_accuracy: 0.9609
# Epoch 164/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0960 - accuracy: 0.9652 - val_loss: 0.1167 - val_accuracy: 0.9609
# Epoch 165/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0920 - accuracy: 0.9707 - val_loss: 0.1195 - val_accuracy: 0.9563
# Epoch 166/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0915 - accuracy: 0.9684 - val_loss: 0.1158 - val_accuracy: 0.9656
# Epoch 167/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0942 - accuracy: 0.9645 - val_loss: 0.1130 - val_accuracy: 0.9578
# Epoch 168/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0967 - accuracy: 0.9703 - val_loss: 0.1191 - val_accuracy: 0.9656
# Epoch 169/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0914 - accuracy: 0.9672 - val_loss: 0.1126 - val_accuracy: 0.9578
# Epoch 170/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0903 - accuracy: 0.9703 - val_loss: 0.1150 - val_accuracy: 0.9547
# Epoch 171/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0913 - accuracy: 0.9672 - val_loss: 0.1131 - val_accuracy: 0.9641
# Epoch 172/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0920 - accuracy: 0.9688 - val_loss: 0.1125 - val_accuracy: 0.9578
# Epoch 173/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0889 - accuracy: 0.9711 - val_loss: 0.1108 - val_accuracy: 0.9625
# Epoch 174/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0847 - accuracy: 0.9711 - val_loss: 0.1193 - val_accuracy: 0.9609
# Epoch 175/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0941 - accuracy: 0.9664 - val_loss: 0.1180 - val_accuracy: 0.9531
# Epoch 176/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 0.1234 - val_accuracy: 0.9578
# Epoch 177/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0915 - accuracy: 0.9691 - val_loss: 0.1091 - val_accuracy: 0.9625
# Epoch 178/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0810 - accuracy: 0.9734 - val_loss: 0.1105 - val_accuracy: 0.9625
# Epoch 179/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0886 - accuracy: 0.9707 - val_loss: 0.1121 - val_accuracy: 0.9594
# Epoch 180/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0845 - accuracy: 0.9723 - val_loss: 0.1062 - val_accuracy: 0.9625
# Epoch 181/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0764 - accuracy: 0.9762 - val_loss: 0.1107 - val_accuracy: 0.9609
# Epoch 182/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0889 - accuracy: 0.9688 - val_loss: 0.1122 - val_accuracy: 0.9641
# Epoch 183/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0891 - accuracy: 0.9668 - val_loss: 0.1087 - val_accuracy: 0.9641
# Epoch 184/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0844 - accuracy: 0.9723 - val_loss: 0.1151 - val_accuracy: 0.9547
# Epoch 185/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0880 - accuracy: 0.9684 - val_loss: 0.1126 - val_accuracy: 0.9609
# Epoch 186/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0814 - accuracy: 0.9723 - val_loss: 0.1153 - val_accuracy: 0.9609
# Epoch 187/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0877 - accuracy: 0.9715 - val_loss: 0.1063 - val_accuracy: 0.9672
# Epoch 188/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0884 - accuracy: 0.9695 - val_loss: 0.1101 - val_accuracy: 0.9672
# Epoch 189/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0778 - accuracy: 0.9758 - val_loss: 0.1207 - val_accuracy: 0.9500
# Epoch 190/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0975 - accuracy: 0.9625 - val_loss: 0.1165 - val_accuracy: 0.9547
# Epoch 191/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0826 - accuracy: 0.9723 - val_loss: 0.1074 - val_accuracy: 0.9578
# Epoch 192/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0837 - accuracy: 0.9734 - val_loss: 0.1198 - val_accuracy: 0.9625
# Epoch 193/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0820 - accuracy: 0.9762 - val_loss: 0.1105 - val_accuracy: 0.9609
# Epoch 194/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0815 - accuracy: 0.9734 - val_loss: 0.1054 - val_accuracy: 0.9672
# Epoch 195/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0790 - accuracy: 0.9742 - val_loss: 0.1154 - val_accuracy: 0.9594
# Epoch 196/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0895 - accuracy: 0.9723 - val_loss: 0.1070 - val_accuracy: 0.9578
# Epoch 197/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0866 - accuracy: 0.9699 - val_loss: 0.1084 - val_accuracy: 0.9656
# Epoch 198/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0796 - accuracy: 0.9781 - val_loss: 0.1205 - val_accuracy: 0.9641
# Epoch 199/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0846 - accuracy: 0.9715 - val_loss: 0.1068 - val_accuracy: 0.9641
# Epoch 200/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0807 - accuracy: 0.9742 - val_loss: 0.1052 - val_accuracy: 0.9656

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 5/5 [==============================] - 0s 70ms/step - loss: 1.9164 - accuracy: 0.3148 - val_loss: 1.5986 - val_accuracy: 0.4047
# Epoch 2/60
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4502 - accuracy: 0.5645 - val_loss: 1.1898 - val_accuracy: 0.7125
# Epoch 3/60
# 5/5 [==============================] - 0s 35ms/step - loss: 1.1215 - accuracy: 0.6535 - val_loss: 0.9304 - val_accuracy: 0.6859
# Epoch 4/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.9340 - accuracy: 0.7008 - val_loss: 0.8286 - val_accuracy: 0.7188
# Epoch 5/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.8457 - accuracy: 0.7172 - val_loss: 0.7792 - val_accuracy: 0.7391
# Epoch 6/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7960 - accuracy: 0.7262 - val_loss: 0.7375 - val_accuracy: 0.7312
# Epoch 7/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7590 - accuracy: 0.7457 - val_loss: 0.6874 - val_accuracy: 0.7953
# Epoch 8/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7152 - accuracy: 0.7715 - val_loss: 0.6405 - val_accuracy: 0.8141
# Epoch 9/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6740 - accuracy: 0.7961 - val_loss: 0.6155 - val_accuracy: 0.8172
# Epoch 10/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6506 - accuracy: 0.7844 - val_loss: 0.5762 - val_accuracy: 0.8297
# Epoch 11/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6071 - accuracy: 0.8035 - val_loss: 0.5478 - val_accuracy: 0.8094
# Epoch 12/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5845 - accuracy: 0.8086 - val_loss: 0.5211 - val_accuracy: 0.8391
# Epoch 13/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5589 - accuracy: 0.8121 - val_loss: 0.5188 - val_accuracy: 0.8297
# Epoch 14/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5451 - accuracy: 0.8184 - val_loss: 0.4980 - val_accuracy: 0.8297
# Epoch 15/60
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5108 - accuracy: 0.8309 - val_loss: 0.4606 - val_accuracy: 0.8609
# Epoch 16/60
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4874 - accuracy: 0.8340 - val_loss: 0.4415 - val_accuracy: 0.8672
# Epoch 17/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4706 - accuracy: 0.8508 - val_loss: 0.4251 - val_accuracy: 0.8484
# Epoch 18/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4612 - accuracy: 0.8504 - val_loss: 0.4086 - val_accuracy: 0.8859
# Epoch 19/60
# 5/5 [==============================] - 0s 45ms/step - loss: 0.4479 - accuracy: 0.8590 - val_loss: 0.4108 - val_accuracy: 0.8719
# Epoch 20/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4401 - accuracy: 0.8594 - val_loss: 0.3836 - val_accuracy: 0.8938
# Epoch 21/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.4178 - accuracy: 0.8699 - val_loss: 0.3755 - val_accuracy: 0.8875
# Epoch 22/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4093 - accuracy: 0.8742 - val_loss: 0.3646 - val_accuracy: 0.8969
# Epoch 23/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3948 - accuracy: 0.8727 - val_loss: 0.3581 - val_accuracy: 0.8891
# Epoch 24/60
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3882 - accuracy: 0.8797 - val_loss: 0.3388 - val_accuracy: 0.9062
# Epoch 25/60
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3826 - accuracy: 0.8816 - val_loss: 0.3368 - val_accuracy: 0.9031
# Epoch 26/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3682 - accuracy: 0.8887 - val_loss: 0.3259 - val_accuracy: 0.8984
# Epoch 27/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3579 - accuracy: 0.8930 - val_loss: 0.3170 - val_accuracy: 0.8984
# Epoch 28/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3516 - accuracy: 0.8949 - val_loss: 0.3125 - val_accuracy: 0.9016
# Epoch 29/60
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3529 - accuracy: 0.8914 - val_loss: 0.3166 - val_accuracy: 0.8953
# Epoch 30/60
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3411 - accuracy: 0.8957 - val_loss: 0.3008 - val_accuracy: 0.9047
# Epoch 31/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3319 - accuracy: 0.9004 - val_loss: 0.2960 - val_accuracy: 0.9062
# Epoch 32/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3355 - accuracy: 0.9000 - val_loss: 0.2995 - val_accuracy: 0.9016
# Epoch 33/60
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3251 - accuracy: 0.9031 - val_loss: 0.2895 - val_accuracy: 0.9031
# Epoch 34/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3195 - accuracy: 0.9066 - val_loss: 0.2954 - val_accuracy: 0.8984
# Epoch 35/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3169 - accuracy: 0.9004 - val_loss: 0.2749 - val_accuracy: 0.9141
# Epoch 36/60
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3118 - accuracy: 0.9051 - val_loss: 0.2765 - val_accuracy: 0.9109
# Epoch 37/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3060 - accuracy: 0.9059 - val_loss: 0.2689 - val_accuracy: 0.9125
# Epoch 38/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3015 - accuracy: 0.9094 - val_loss: 0.2644 - val_accuracy: 0.9141
# Epoch 39/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2960 - accuracy: 0.9094 - val_loss: 0.2614 - val_accuracy: 0.9141
# Epoch 40/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2964 - accuracy: 0.9102 - val_loss: 0.2596 - val_accuracy: 0.9078
# Epoch 41/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2849 - accuracy: 0.9164 - val_loss: 0.2499 - val_accuracy: 0.9156
# Epoch 42/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2913 - accuracy: 0.9094 - val_loss: 0.2512 - val_accuracy: 0.9187
# Epoch 43/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2930 - accuracy: 0.9109 - val_loss: 0.2578 - val_accuracy: 0.9125
# Epoch 44/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2764 - accuracy: 0.9148 - val_loss: 0.2456 - val_accuracy: 0.9187
# Epoch 45/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2713 - accuracy: 0.9195 - val_loss: 0.2408 - val_accuracy: 0.9234
# Epoch 46/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2712 - accuracy: 0.9168 - val_loss: 0.2339 - val_accuracy: 0.9219
# Epoch 47/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2680 - accuracy: 0.9207 - val_loss: 0.2294 - val_accuracy: 0.9203
# Epoch 48/60
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2662 - accuracy: 0.9164 - val_loss: 0.2393 - val_accuracy: 0.9297
# Epoch 49/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2655 - accuracy: 0.9156 - val_loss: 0.2326 - val_accuracy: 0.9219
# Epoch 50/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2603 - accuracy: 0.9187 - val_loss: 0.2236 - val_accuracy: 0.9234
# Epoch 51/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2491 - accuracy: 0.9215 - val_loss: 0.2184 - val_accuracy: 0.9203
# Epoch 52/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2520 - accuracy: 0.9254 - val_loss: 0.2205 - val_accuracy: 0.9266
# Epoch 53/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2460 - accuracy: 0.9207 - val_loss: 0.2230 - val_accuracy: 0.9281
# Epoch 54/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2479 - accuracy: 0.9238 - val_loss: 0.2206 - val_accuracy: 0.9328
# Epoch 55/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2427 - accuracy: 0.9246 - val_loss: 0.2094 - val_accuracy: 0.9250
# Epoch 56/60
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2438 - accuracy: 0.9258 - val_loss: 0.2200 - val_accuracy: 0.9281
# Epoch 57/60
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2374 - accuracy: 0.9305 - val_loss: 0.2168 - val_accuracy: 0.9172
# Epoch 58/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2325 - accuracy: 0.9242 - val_loss: 0.2087 - val_accuracy: 0.9266
# Epoch 59/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2273 - accuracy: 0.9281 - val_loss: 0.1993 - val_accuracy: 0.9266
# Epoch 60/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2347 - accuracy: 0.9242 - val_loss: 0.2044 - val_accuracy: 0.9281

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2003 - accuracy: 0.9332
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2044 - accuracy: 0.9281
# 0.9332031011581421 0.9281250238418579

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 53, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:05:14

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 199   2   0   2   1]
#  [  0   0   0   0   8  90   0   2   0]
#  [  0   0   0   0   5   0   0   1   0]
#  [  0   0   0   0   7   3   0   9   1]
#  [  0   0   0   0   9   2   0   0   9]]
#
# Accuracy Score
# 0.928125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.87      0.98      0.92       204
#     windows       0.93      0.90      0.91       100
#       roads       0.00      0.00      0.00         6
#        cars       0.64      0.45      0.53        20
#       metal       0.82      0.45      0.58        20
#
# avg / total       0.92      0.93      0.92       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 53)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 53)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 53) (80, 53)
# clouds  (400, 53) (100, 53)
# vegetation  (488, 53) (122, 53)
# built  (960, 53) (240, 53)
# windows  (400, 53) (100, 53)
# roads  (48, 53) (12, 53)
# cars  (44, 53) (11, 53)
# metal  (184, 53) (46, 53)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 53) (2844,) (2844, 2)
# (711, 53) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 55ms/step - loss: 1.9132 - accuracy: 0.2999 - val_loss: 1.5470 - val_accuracy: 0.3812
# Epoch 2/200
# 6/6 [==============================] - 0s 39ms/step - loss: 1.4435 - accuracy: 0.5341 - val_loss: 1.2027 - val_accuracy: 0.6006
# Epoch 3/200
# 6/6 [==============================] - 0s 41ms/step - loss: 1.1225 - accuracy: 0.6241 - val_loss: 0.9891 - val_accuracy: 0.6554
# Epoch 4/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.9398 - accuracy: 0.6600 - val_loss: 0.8369 - val_accuracy: 0.7032
# Epoch 5/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.8017 - accuracy: 0.7068 - val_loss: 0.7433 - val_accuracy: 0.7257
# Epoch 6/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.7268 - accuracy: 0.7131 - val_loss: 0.6980 - val_accuracy: 0.7300
# Epoch 7/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.6637 - accuracy: 0.7335 - val_loss: 0.6475 - val_accuracy: 0.7314
# Epoch 8/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.6166 - accuracy: 0.7511 - val_loss: 0.6152 - val_accuracy: 0.7468
# Epoch 9/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.6035 - accuracy: 0.7542 - val_loss: 0.5894 - val_accuracy: 0.7778
# Epoch 10/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.5667 - accuracy: 0.7683 - val_loss: 0.5922 - val_accuracy: 0.7764
# Epoch 11/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5414 - accuracy: 0.7778 - val_loss: 0.5820 - val_accuracy: 0.7862
# Epoch 12/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.5379 - accuracy: 0.7936 - val_loss: 0.5553 - val_accuracy: 0.7834
# Epoch 13/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.5234 - accuracy: 0.7866 - val_loss: 0.5421 - val_accuracy: 0.7947
# Epoch 14/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.5062 - accuracy: 0.8010 - val_loss: 0.5423 - val_accuracy: 0.7989
# Epoch 15/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4931 - accuracy: 0.8186 - val_loss: 0.5201 - val_accuracy: 0.8115
# Epoch 16/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4799 - accuracy: 0.8207 - val_loss: 0.5348 - val_accuracy: 0.8003
# Epoch 17/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4762 - accuracy: 0.8228 - val_loss: 0.5108 - val_accuracy: 0.8186
# Epoch 18/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4554 - accuracy: 0.8397 - val_loss: 0.5100 - val_accuracy: 0.8172
# Epoch 19/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4528 - accuracy: 0.8333 - val_loss: 0.4896 - val_accuracy: 0.8115
# Epoch 20/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4425 - accuracy: 0.8397 - val_loss: 0.5102 - val_accuracy: 0.8087
# Epoch 21/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4497 - accuracy: 0.8358 - val_loss: 0.4853 - val_accuracy: 0.8115
# Epoch 22/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4304 - accuracy: 0.8400 - val_loss: 0.4768 - val_accuracy: 0.8284
# Epoch 23/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4177 - accuracy: 0.8393 - val_loss: 0.4647 - val_accuracy: 0.8298
# Epoch 24/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4112 - accuracy: 0.8527 - val_loss: 0.4668 - val_accuracy: 0.8284
# Epoch 25/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4053 - accuracy: 0.8477 - val_loss: 0.4582 - val_accuracy: 0.8354
# Epoch 26/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4016 - accuracy: 0.8516 - val_loss: 0.4486 - val_accuracy: 0.8383
# Epoch 27/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3976 - accuracy: 0.8520 - val_loss: 0.4486 - val_accuracy: 0.8354
# Epoch 28/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4002 - accuracy: 0.8572 - val_loss: 0.4816 - val_accuracy: 0.8312
# Epoch 29/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4021 - accuracy: 0.8590 - val_loss: 0.4888 - val_accuracy: 0.8101
# Epoch 30/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4030 - accuracy: 0.8551 - val_loss: 0.4645 - val_accuracy: 0.8326
# Epoch 31/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3917 - accuracy: 0.8520 - val_loss: 0.4589 - val_accuracy: 0.8312
# Epoch 32/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3976 - accuracy: 0.8481 - val_loss: 0.4399 - val_accuracy: 0.8411
# Epoch 33/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3917 - accuracy: 0.8643 - val_loss: 0.4488 - val_accuracy: 0.8425
# Epoch 34/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3855 - accuracy: 0.8590 - val_loss: 0.4313 - val_accuracy: 0.8509
# Epoch 35/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3735 - accuracy: 0.8629 - val_loss: 0.4240 - val_accuracy: 0.8481
# Epoch 36/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3707 - accuracy: 0.8590 - val_loss: 0.4349 - val_accuracy: 0.8453
# Epoch 37/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3638 - accuracy: 0.8639 - val_loss: 0.4329 - val_accuracy: 0.8453
# Epoch 38/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3547 - accuracy: 0.8699 - val_loss: 0.4400 - val_accuracy: 0.8425
# Epoch 39/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3539 - accuracy: 0.8734 - val_loss: 0.4247 - val_accuracy: 0.8523
# Epoch 40/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3505 - accuracy: 0.8738 - val_loss: 0.3938 - val_accuracy: 0.8537
# Epoch 41/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3434 - accuracy: 0.8808 - val_loss: 0.3909 - val_accuracy: 0.8664
# Epoch 42/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3394 - accuracy: 0.8776 - val_loss: 0.3864 - val_accuracy: 0.8622
# Epoch 43/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3355 - accuracy: 0.8797 - val_loss: 0.3860 - val_accuracy: 0.8622
# Epoch 44/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3254 - accuracy: 0.8819 - val_loss: 0.3851 - val_accuracy: 0.8579
# Epoch 45/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3245 - accuracy: 0.8836 - val_loss: 0.3795 - val_accuracy: 0.8706
# Epoch 46/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3269 - accuracy: 0.8861 - val_loss: 0.3751 - val_accuracy: 0.8622
# Epoch 47/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3261 - accuracy: 0.8847 - val_loss: 0.3796 - val_accuracy: 0.8636
# Epoch 48/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3264 - accuracy: 0.8885 - val_loss: 0.3753 - val_accuracy: 0.8664
# Epoch 49/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3169 - accuracy: 0.8861 - val_loss: 0.3707 - val_accuracy: 0.8622
# Epoch 50/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3173 - accuracy: 0.8829 - val_loss: 0.3731 - val_accuracy: 0.8720
# Epoch 51/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3089 - accuracy: 0.8864 - val_loss: 0.3632 - val_accuracy: 0.8692
# Epoch 52/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3070 - accuracy: 0.8889 - val_loss: 0.3728 - val_accuracy: 0.8692
# Epoch 53/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3091 - accuracy: 0.8878 - val_loss: 0.3536 - val_accuracy: 0.8748
# Epoch 54/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3016 - accuracy: 0.8938 - val_loss: 0.3586 - val_accuracy: 0.8692
# Epoch 55/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3022 - accuracy: 0.8871 - val_loss: 0.3543 - val_accuracy: 0.8762
# Epoch 56/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3018 - accuracy: 0.8892 - val_loss: 0.3669 - val_accuracy: 0.8650
# Epoch 57/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3003 - accuracy: 0.8892 - val_loss: 0.3494 - val_accuracy: 0.8805
# Epoch 58/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2951 - accuracy: 0.8956 - val_loss: 0.3443 - val_accuracy: 0.8734
# Epoch 59/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2867 - accuracy: 0.8991 - val_loss: 0.3454 - val_accuracy: 0.8819
# Epoch 60/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2923 - accuracy: 0.8921 - val_loss: 0.3514 - val_accuracy: 0.8776
# Epoch 61/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2941 - accuracy: 0.8892 - val_loss: 0.3509 - val_accuracy: 0.8720
# Epoch 62/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2903 - accuracy: 0.8889 - val_loss: 0.3486 - val_accuracy: 0.8847
# Epoch 63/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2870 - accuracy: 0.8966 - val_loss: 0.3437 - val_accuracy: 0.8720
# Epoch 64/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2773 - accuracy: 0.8973 - val_loss: 0.3325 - val_accuracy: 0.8833
# Epoch 65/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2717 - accuracy: 0.9005 - val_loss: 0.3345 - val_accuracy: 0.8762
# Epoch 66/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2734 - accuracy: 0.9044 - val_loss: 0.3352 - val_accuracy: 0.8819
# Epoch 67/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2706 - accuracy: 0.9072 - val_loss: 0.3300 - val_accuracy: 0.8875
# Epoch 68/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2621 - accuracy: 0.9075 - val_loss: 0.3212 - val_accuracy: 0.8875
# Epoch 69/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2546 - accuracy: 0.9100 - val_loss: 0.3192 - val_accuracy: 0.8790
# Epoch 70/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2543 - accuracy: 0.9061 - val_loss: 0.3406 - val_accuracy: 0.8762
# Epoch 71/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2840 - accuracy: 0.8963 - val_loss: 0.3361 - val_accuracy: 0.8776
# Epoch 72/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2803 - accuracy: 0.8987 - val_loss: 0.3526 - val_accuracy: 0.8762
# Epoch 73/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2767 - accuracy: 0.8959 - val_loss: 0.3385 - val_accuracy: 0.8748
# Epoch 74/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2614 - accuracy: 0.9030 - val_loss: 0.3201 - val_accuracy: 0.8917
# Epoch 75/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2489 - accuracy: 0.9135 - val_loss: 0.3138 - val_accuracy: 0.8875
# Epoch 76/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2491 - accuracy: 0.9093 - val_loss: 0.3140 - val_accuracy: 0.8903
# Epoch 77/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2507 - accuracy: 0.9082 - val_loss: 0.3329 - val_accuracy: 0.8776
# Epoch 78/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2543 - accuracy: 0.9054 - val_loss: 0.3070 - val_accuracy: 0.8917
# Epoch 79/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2555 - accuracy: 0.9054 - val_loss: 0.2948 - val_accuracy: 0.8875
# Epoch 80/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2405 - accuracy: 0.9110 - val_loss: 0.3115 - val_accuracy: 0.8847
# Epoch 81/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2454 - accuracy: 0.9132 - val_loss: 0.3036 - val_accuracy: 0.8945
# Epoch 82/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2503 - accuracy: 0.9023 - val_loss: 0.3173 - val_accuracy: 0.8875
# Epoch 83/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2435 - accuracy: 0.9121 - val_loss: 0.2873 - val_accuracy: 0.9058
# Epoch 84/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2302 - accuracy: 0.9216 - val_loss: 0.2919 - val_accuracy: 0.8931
# Epoch 85/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2364 - accuracy: 0.9156 - val_loss: 0.2904 - val_accuracy: 0.8917
# Epoch 86/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2269 - accuracy: 0.9177 - val_loss: 0.2864 - val_accuracy: 0.9001
# Epoch 87/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2342 - accuracy: 0.9153 - val_loss: 0.2866 - val_accuracy: 0.8959
# Epoch 88/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2227 - accuracy: 0.9216 - val_loss: 0.2814 - val_accuracy: 0.9044
# Epoch 89/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2347 - accuracy: 0.9107 - val_loss: 0.2846 - val_accuracy: 0.9001
# Epoch 90/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2351 - accuracy: 0.9160 - val_loss: 0.2969 - val_accuracy: 0.8987
# Epoch 91/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2325 - accuracy: 0.9205 - val_loss: 0.3106 - val_accuracy: 0.8917
# Epoch 92/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2446 - accuracy: 0.9139 - val_loss: 0.3013 - val_accuracy: 0.8959
# Epoch 93/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2374 - accuracy: 0.9170 - val_loss: 0.2869 - val_accuracy: 0.8973
# Epoch 94/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2356 - accuracy: 0.9135 - val_loss: 0.2973 - val_accuracy: 0.8861
# Epoch 95/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2285 - accuracy: 0.9181 - val_loss: 0.2924 - val_accuracy: 0.9001
# Epoch 96/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2141 - accuracy: 0.9233 - val_loss: 0.2802 - val_accuracy: 0.8945
# Epoch 97/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2193 - accuracy: 0.9191 - val_loss: 0.2732 - val_accuracy: 0.9001
# Epoch 98/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2295 - accuracy: 0.9170 - val_loss: 0.2717 - val_accuracy: 0.9001
# Epoch 99/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2164 - accuracy: 0.9223 - val_loss: 0.2837 - val_accuracy: 0.9100
# Epoch 100/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2106 - accuracy: 0.9195 - val_loss: 0.2753 - val_accuracy: 0.9086
# Epoch 101/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2063 - accuracy: 0.9290 - val_loss: 0.2670 - val_accuracy: 0.9015
# Epoch 102/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2086 - accuracy: 0.9209 - val_loss: 0.2943 - val_accuracy: 0.8903
# Epoch 103/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2190 - accuracy: 0.9216 - val_loss: 0.2604 - val_accuracy: 0.9044
# Epoch 104/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2065 - accuracy: 0.9258 - val_loss: 0.2569 - val_accuracy: 0.9170
# Epoch 105/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2005 - accuracy: 0.9269 - val_loss: 0.2630 - val_accuracy: 0.9100
# Epoch 106/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2030 - accuracy: 0.9262 - val_loss: 0.2737 - val_accuracy: 0.9044
# Epoch 107/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2045 - accuracy: 0.9272 - val_loss: 0.2609 - val_accuracy: 0.9086
# Epoch 108/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1998 - accuracy: 0.9300 - val_loss: 0.2564 - val_accuracy: 0.9198
# Epoch 109/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1928 - accuracy: 0.9283 - val_loss: 0.2596 - val_accuracy: 0.9086
# Epoch 110/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1905 - accuracy: 0.9328 - val_loss: 0.2527 - val_accuracy: 0.9142
# Epoch 111/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1924 - accuracy: 0.9311 - val_loss: 0.2435 - val_accuracy: 0.9142
# Epoch 112/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1877 - accuracy: 0.9335 - val_loss: 0.2488 - val_accuracy: 0.9142
# Epoch 113/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1819 - accuracy: 0.9371 - val_loss: 0.2655 - val_accuracy: 0.9114
# Epoch 114/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1956 - accuracy: 0.9276 - val_loss: 0.2456 - val_accuracy: 0.9128
# Epoch 115/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1894 - accuracy: 0.9311 - val_loss: 0.2654 - val_accuracy: 0.9058
# Epoch 116/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1876 - accuracy: 0.9328 - val_loss: 0.2529 - val_accuracy: 0.9058
# Epoch 117/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1822 - accuracy: 0.9346 - val_loss: 0.2692 - val_accuracy: 0.9086
# Epoch 118/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2051 - accuracy: 0.9216 - val_loss: 0.2490 - val_accuracy: 0.9156
# Epoch 119/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1935 - accuracy: 0.9286 - val_loss: 0.2457 - val_accuracy: 0.9072
# Epoch 120/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1866 - accuracy: 0.9353 - val_loss: 0.2596 - val_accuracy: 0.9114
# Epoch 121/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1921 - accuracy: 0.9304 - val_loss: 0.2393 - val_accuracy: 0.9198
# Epoch 122/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1832 - accuracy: 0.9311 - val_loss: 0.2433 - val_accuracy: 0.9184
# Epoch 123/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1810 - accuracy: 0.9364 - val_loss: 0.2427 - val_accuracy: 0.9184
# Epoch 124/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1788 - accuracy: 0.9374 - val_loss: 0.2398 - val_accuracy: 0.9226
# Epoch 125/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1708 - accuracy: 0.9416 - val_loss: 0.2349 - val_accuracy: 0.9269
# Epoch 126/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1732 - accuracy: 0.9430 - val_loss: 0.2417 - val_accuracy: 0.9226
# Epoch 127/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1706 - accuracy: 0.9409 - val_loss: 0.2332 - val_accuracy: 0.9241
# Epoch 128/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1744 - accuracy: 0.9413 - val_loss: 0.2478 - val_accuracy: 0.9142
# Epoch 129/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1664 - accuracy: 0.9406 - val_loss: 0.2343 - val_accuracy: 0.9198
# Epoch 130/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1689 - accuracy: 0.9395 - val_loss: 0.2287 - val_accuracy: 0.9255
# Epoch 131/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1586 - accuracy: 0.9451 - val_loss: 0.2247 - val_accuracy: 0.9325
# Epoch 132/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1660 - accuracy: 0.9444 - val_loss: 0.2375 - val_accuracy: 0.9170
# Epoch 133/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1664 - accuracy: 0.9413 - val_loss: 0.2252 - val_accuracy: 0.9283
# Epoch 134/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1681 - accuracy: 0.9437 - val_loss: 0.2301 - val_accuracy: 0.9226
# Epoch 135/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1670 - accuracy: 0.9388 - val_loss: 0.2345 - val_accuracy: 0.9170
# Epoch 136/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1590 - accuracy: 0.9437 - val_loss: 0.2264 - val_accuracy: 0.9198
# Epoch 137/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1564 - accuracy: 0.9448 - val_loss: 0.2213 - val_accuracy: 0.9311
# Epoch 138/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1534 - accuracy: 0.9483 - val_loss: 0.2395 - val_accuracy: 0.9283
# Epoch 139/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1628 - accuracy: 0.9395 - val_loss: 0.2236 - val_accuracy: 0.9241
# Epoch 140/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1595 - accuracy: 0.9420 - val_loss: 0.2354 - val_accuracy: 0.9058
# Epoch 141/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1716 - accuracy: 0.9367 - val_loss: 0.2393 - val_accuracy: 0.9142
# Epoch 142/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1701 - accuracy: 0.9335 - val_loss: 0.2252 - val_accuracy: 0.9283
# Epoch 143/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1614 - accuracy: 0.9409 - val_loss: 0.2229 - val_accuracy: 0.9297
# Epoch 144/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1597 - accuracy: 0.9420 - val_loss: 0.2279 - val_accuracy: 0.9212
# Epoch 145/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1522 - accuracy: 0.9455 - val_loss: 0.2137 - val_accuracy: 0.9255
# Epoch 146/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1528 - accuracy: 0.9476 - val_loss: 0.2188 - val_accuracy: 0.9226
# Epoch 147/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1480 - accuracy: 0.9448 - val_loss: 0.2277 - val_accuracy: 0.9226
# Epoch 148/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1489 - accuracy: 0.9490 - val_loss: 0.2202 - val_accuracy: 0.9212
# Epoch 149/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1592 - accuracy: 0.9413 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 150/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1615 - accuracy: 0.9420 - val_loss: 0.2220 - val_accuracy: 0.9283
# Epoch 151/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1621 - accuracy: 0.9371 - val_loss: 0.2228 - val_accuracy: 0.9339
# Epoch 152/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1544 - accuracy: 0.9455 - val_loss: 0.2193 - val_accuracy: 0.9255
# Epoch 153/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1565 - accuracy: 0.9423 - val_loss: 0.2252 - val_accuracy: 0.9198
# Epoch 154/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1502 - accuracy: 0.9434 - val_loss: 0.2202 - val_accuracy: 0.9325
# Epoch 155/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1471 - accuracy: 0.9487 - val_loss: 0.2149 - val_accuracy: 0.9325
# Epoch 156/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1455 - accuracy: 0.9511 - val_loss: 0.2105 - val_accuracy: 0.9241
# Epoch 157/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1448 - accuracy: 0.9480 - val_loss: 0.2234 - val_accuracy: 0.9255
# Epoch 158/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1510 - accuracy: 0.9451 - val_loss: 0.2239 - val_accuracy: 0.9212
# Epoch 159/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1497 - accuracy: 0.9444 - val_loss: 0.2083 - val_accuracy: 0.9339
# Epoch 160/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1429 - accuracy: 0.9490 - val_loss: 0.2138 - val_accuracy: 0.9269
# Epoch 161/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1425 - accuracy: 0.9490 - val_loss: 0.2135 - val_accuracy: 0.9353
# Epoch 162/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1423 - accuracy: 0.9490 - val_loss: 0.2072 - val_accuracy: 0.9283
# Epoch 163/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1339 - accuracy: 0.9546 - val_loss: 0.2083 - val_accuracy: 0.9269
# Epoch 164/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1408 - accuracy: 0.9473 - val_loss: 0.1995 - val_accuracy: 0.9311
# Epoch 165/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1343 - accuracy: 0.9515 - val_loss: 0.2231 - val_accuracy: 0.9212
# Epoch 166/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1444 - accuracy: 0.9399 - val_loss: 0.2124 - val_accuracy: 0.9381
# Epoch 167/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1458 - accuracy: 0.9483 - val_loss: 0.2250 - val_accuracy: 0.9297
# Epoch 168/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1417 - accuracy: 0.9476 - val_loss: 0.2162 - val_accuracy: 0.9283
# Epoch 169/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1460 - accuracy: 0.9480 - val_loss: 0.2110 - val_accuracy: 0.9395
# Epoch 170/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1304 - accuracy: 0.9543 - val_loss: 0.2156 - val_accuracy: 0.9297
# Epoch 171/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1301 - accuracy: 0.9539 - val_loss: 0.2048 - val_accuracy: 0.9339
# Epoch 172/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1262 - accuracy: 0.9522 - val_loss: 0.2052 - val_accuracy: 0.9353
# Epoch 173/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1334 - accuracy: 0.9546 - val_loss: 0.2136 - val_accuracy: 0.9381
# Epoch 174/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1285 - accuracy: 0.9557 - val_loss: 0.2072 - val_accuracy: 0.9353
# Epoch 175/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1233 - accuracy: 0.9575 - val_loss: 0.2043 - val_accuracy: 0.9311
# Epoch 176/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1238 - accuracy: 0.9578 - val_loss: 0.2004 - val_accuracy: 0.9395
# Epoch 177/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1264 - accuracy: 0.9564 - val_loss: 0.2001 - val_accuracy: 0.9353
# Epoch 178/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1300 - accuracy: 0.9557 - val_loss: 0.2053 - val_accuracy: 0.9423
# Epoch 179/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1282 - accuracy: 0.9589 - val_loss: 0.2140 - val_accuracy: 0.9325
# Epoch 180/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1424 - accuracy: 0.9494 - val_loss: 0.2125 - val_accuracy: 0.9339
# Epoch 181/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1336 - accuracy: 0.9553 - val_loss: 0.2009 - val_accuracy: 0.9339
# Epoch 182/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1268 - accuracy: 0.9560 - val_loss: 0.2024 - val_accuracy: 0.9353
# Epoch 183/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1229 - accuracy: 0.9589 - val_loss: 0.2117 - val_accuracy: 0.9409
# Epoch 184/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1273 - accuracy: 0.9568 - val_loss: 0.2052 - val_accuracy: 0.9423
# Epoch 185/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1251 - accuracy: 0.9560 - val_loss: 0.2029 - val_accuracy: 0.9325
# Epoch 186/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1249 - accuracy: 0.9539 - val_loss: 0.2122 - val_accuracy: 0.9395
# Epoch 187/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1285 - accuracy: 0.9557 - val_loss: 0.2018 - val_accuracy: 0.9409
# Epoch 188/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1273 - accuracy: 0.9553 - val_loss: 0.2062 - val_accuracy: 0.9325
# Epoch 189/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1211 - accuracy: 0.9592 - val_loss: 0.2055 - val_accuracy: 0.9325
# Epoch 190/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1276 - accuracy: 0.9522 - val_loss: 0.2064 - val_accuracy: 0.9395
# Epoch 191/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1281 - accuracy: 0.9560 - val_loss: 0.2211 - val_accuracy: 0.9226
# Epoch 192/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1310 - accuracy: 0.9550 - val_loss: 0.1953 - val_accuracy: 0.9367
# Epoch 193/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1307 - accuracy: 0.9504 - val_loss: 0.2080 - val_accuracy: 0.9311
# Epoch 194/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1286 - accuracy: 0.9543 - val_loss: 0.1996 - val_accuracy: 0.9480
# Epoch 195/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1330 - accuracy: 0.9536 - val_loss: 0.2255 - val_accuracy: 0.9283
# Epoch 196/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1272 - accuracy: 0.9497 - val_loss: 0.2159 - val_accuracy: 0.9353
# Epoch 197/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1323 - accuracy: 0.9473 - val_loss: 0.2120 - val_accuracy: 0.9339
# Epoch 198/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1332 - accuracy: 0.9529 - val_loss: 0.2005 - val_accuracy: 0.9437
# Epoch 199/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1192 - accuracy: 0.9560 - val_loss: 0.2036 - val_accuracy: 0.9395
# Epoch 200/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1262 - accuracy: 0.9529 - val_loss: 0.2067 - val_accuracy: 0.9269

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 6/6 [==============================] - 0s 73ms/step - loss: 1.8674 - accuracy: 0.3091 - val_loss: 1.4964 - val_accuracy: 0.4557
# Epoch 2/45
# 6/6 [==============================] - 0s 37ms/step - loss: 1.3869 - accuracy: 0.5812 - val_loss: 1.1601 - val_accuracy: 0.6076
# Epoch 3/45
# 6/6 [==============================] - 0s 35ms/step - loss: 1.0983 - accuracy: 0.6160 - val_loss: 0.9486 - val_accuracy: 0.6751
# Epoch 4/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.9208 - accuracy: 0.6783 - val_loss: 0.8326 - val_accuracy: 0.6906
# Epoch 5/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.7999 - accuracy: 0.6892 - val_loss: 0.7426 - val_accuracy: 0.7229
# Epoch 6/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.7217 - accuracy: 0.7180 - val_loss: 0.6778 - val_accuracy: 0.7581
# Epoch 7/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.6695 - accuracy: 0.7328 - val_loss: 0.6553 - val_accuracy: 0.7567
# Epoch 8/45
# 6/6 [==============================] - 0s 46ms/step - loss: 0.6321 - accuracy: 0.7359 - val_loss: 0.6243 - val_accuracy: 0.7567
# Epoch 9/45
# 6/6 [==============================] - 0s 35ms/step - loss: 0.5950 - accuracy: 0.7511 - val_loss: 0.5988 - val_accuracy: 0.7693
# Epoch 10/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5787 - accuracy: 0.7655 - val_loss: 0.5885 - val_accuracy: 0.7918
# Epoch 11/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.5492 - accuracy: 0.7845 - val_loss: 0.5741 - val_accuracy: 0.7764
# Epoch 12/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.5309 - accuracy: 0.7866 - val_loss: 0.5470 - val_accuracy: 0.7989
# Epoch 13/45
# 6/6 [==============================] - 0s 41ms/step - loss: 0.5176 - accuracy: 0.7950 - val_loss: 0.5436 - val_accuracy: 0.7961
# Epoch 14/45
# 6/6 [==============================] - 0s 42ms/step - loss: 0.5096 - accuracy: 0.8066 - val_loss: 0.5356 - val_accuracy: 0.7890
# Epoch 15/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4988 - accuracy: 0.8119 - val_loss: 0.5425 - val_accuracy: 0.7918
# Epoch 16/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4893 - accuracy: 0.8210 - val_loss: 0.5162 - val_accuracy: 0.8101
# Epoch 17/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4667 - accuracy: 0.8200 - val_loss: 0.5022 - val_accuracy: 0.8200
# Epoch 18/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4606 - accuracy: 0.8277 - val_loss: 0.4974 - val_accuracy: 0.8172
# Epoch 19/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4412 - accuracy: 0.8330 - val_loss: 0.4816 - val_accuracy: 0.8129
# Epoch 20/45
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4439 - accuracy: 0.8337 - val_loss: 0.4754 - val_accuracy: 0.8115
# Epoch 21/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4360 - accuracy: 0.8397 - val_loss: 0.4796 - val_accuracy: 0.8172
# Epoch 22/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4293 - accuracy: 0.8456 - val_loss: 0.4781 - val_accuracy: 0.8129
# Epoch 23/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4191 - accuracy: 0.8400 - val_loss: 0.4786 - val_accuracy: 0.8242
# Epoch 24/45
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4213 - accuracy: 0.8407 - val_loss: 0.4687 - val_accuracy: 0.8214
# Epoch 25/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4077 - accuracy: 0.8449 - val_loss: 0.4617 - val_accuracy: 0.8326
# Epoch 26/45
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4015 - accuracy: 0.8513 - val_loss: 0.4461 - val_accuracy: 0.8284
# Epoch 27/45
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3980 - accuracy: 0.8492 - val_loss: 0.4607 - val_accuracy: 0.8256
# Epoch 28/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4076 - accuracy: 0.8527 - val_loss: 0.4775 - val_accuracy: 0.8059
# Epoch 29/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3920 - accuracy: 0.8544 - val_loss: 0.4294 - val_accuracy: 0.8509
# Epoch 30/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3806 - accuracy: 0.8611 - val_loss: 0.4427 - val_accuracy: 0.8439
# Epoch 31/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3735 - accuracy: 0.8615 - val_loss: 0.4319 - val_accuracy: 0.8411
# Epoch 32/45
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3879 - accuracy: 0.8576 - val_loss: 0.4108 - val_accuracy: 0.8495
# Epoch 33/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3723 - accuracy: 0.8632 - val_loss: 0.4281 - val_accuracy: 0.8453
# Epoch 34/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3681 - accuracy: 0.8639 - val_loss: 0.4087 - val_accuracy: 0.8481
# Epoch 35/45
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3646 - accuracy: 0.8646 - val_loss: 0.4090 - val_accuracy: 0.8467
# Epoch 36/45
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3715 - accuracy: 0.8594 - val_loss: 0.4196 - val_accuracy: 0.8425
# Epoch 37/45
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3549 - accuracy: 0.8741 - val_loss: 0.4010 - val_accuracy: 0.8523
# Epoch 38/45
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3551 - accuracy: 0.8703 - val_loss: 0.4004 - val_accuracy: 0.8594
# Epoch 39/45
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3431 - accuracy: 0.8762 - val_loss: 0.3959 - val_accuracy: 0.8495
# Epoch 40/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3477 - accuracy: 0.8717 - val_loss: 0.3928 - val_accuracy: 0.8678
# Epoch 41/45
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3404 - accuracy: 0.8695 - val_loss: 0.3930 - val_accuracy: 0.8636
# Epoch 42/45
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3452 - accuracy: 0.8783 - val_loss: 0.3948 - val_accuracy: 0.8678
# Epoch 43/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3469 - accuracy: 0.8773 - val_loss: 0.4205 - val_accuracy: 0.8565
# Epoch 44/45
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3369 - accuracy: 0.8752 - val_loss: 0.3942 - val_accuracy: 0.8594
# Epoch 45/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3273 - accuracy: 0.8822 - val_loss: 0.3872 - val_accuracy: 0.8551

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 5ms/step - loss: 0.2931 - accuracy: 0.8931
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3872 - accuracy: 0.8551
# 0.8931083083152771 0.855133593082428

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 53, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:05:15

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  95   0   5   0   0   0   0]
#  [  0   0 116   2   4   0   0   0]
#  [  0   0   0 227   7   0   0   6]
#  [  0   2   0  36  57   1   0   4]
#  [  0   0   0   0   3   9   0   0]
#  [  2   0   0   0   3   2   4   0]
#  [  0   0   0  22   4   0   0  20]]
#
# Accuracy Score
# 0.8551336146272855
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.98      1.00      0.99        80
#      clouds       0.98      0.95      0.96       100
#  vegetation       1.00      0.95      0.97       122
#       built       0.78      0.95      0.85       240
#     windows       0.73      0.57      0.64       100
#       roads       0.75      0.75      0.75        12
#        cars       1.00      0.36      0.53        11
#       metal       0.67      0.43      0.53        46
#
# avg / total       0.86      0.86      0.85       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 53
# [[0, 16], [16, 32], [32, 48], [48, 64], [64, 80], [80, 96], [96, 112], [112, 128], [128, 144], [144, 160], [160, 176], [176, 192], [192, 208], [208, 224], [224, 240], [240, 256], [256, 272], [272, 288], [288, 304], [304, 320], [320, 336], [336, 352], [352, 368], [368, 384], [384, 400], [400, 416], [416, 432], [432, 448], [448, 464], [464, 480], [480, 496], [496, 512], [512, 528], [528, 544], [544, 560], [560, 576], [576, 592], [592, 608], [608, 624], [624, 640], [640, 656], [656, 672], [672, 688], [688, 704], [704, 720], [720, 736], [736, 752], [752, 768], [768, 784], [784, 800], [800, 816], [816, 832], [832, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 53)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 53)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 53) (60, 53)
# clouds  (160, 53) (40, 53)
# vegetation  (560, 53) (140, 53)
# water  (496, 53) (124, 53)
# built  (1280, 53) (320, 53)
# windows  (480, 53) (120, 53)
# roads  (200, 53) (50, 53)
# cars  (200, 53) (50, 53)
# metal  (148, 53) (37, 53)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 53) (3764,) (3764, 2)
# (941, 53) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 56ms/step - loss: 1.8944 - accuracy: 0.3305 - val_loss: 1.6004 - val_accuracy: 0.5239
# Epoch 2/200
# 8/8 [==============================] - 0s 36ms/step - loss: 1.5110 - accuracy: 0.4955 - val_loss: 1.3755 - val_accuracy: 0.5494
# Epoch 3/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.3455 - accuracy: 0.5300 - val_loss: 1.2800 - val_accuracy: 0.5313
# Epoch 4/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.2606 - accuracy: 0.5457 - val_loss: 1.2104 - val_accuracy: 0.5643
# Epoch 5/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.2049 - accuracy: 0.5635 - val_loss: 1.1351 - val_accuracy: 0.6174
# Epoch 6/200
# 8/8 [==============================] - 0s 40ms/step - loss: 1.1395 - accuracy: 0.5996 - val_loss: 1.0779 - val_accuracy: 0.6281
# Epoch 7/200
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0851 - accuracy: 0.6323 - val_loss: 1.0160 - val_accuracy: 0.6801
# Epoch 8/200
# 8/8 [==============================] - 0s 33ms/step - loss: 1.0139 - accuracy: 0.6626 - val_loss: 0.9562 - val_accuracy: 0.6950
# Epoch 9/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.9577 - accuracy: 0.6862 - val_loss: 0.9150 - val_accuracy: 0.6844
# Epoch 10/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.9102 - accuracy: 0.7059 - val_loss: 0.8579 - val_accuracy: 0.7333
# Epoch 11/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.8606 - accuracy: 0.7248 - val_loss: 0.8342 - val_accuracy: 0.7354
# Epoch 12/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8372 - accuracy: 0.7282 - val_loss: 0.7787 - val_accuracy: 0.7556
# Epoch 13/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7944 - accuracy: 0.7407 - val_loss: 0.7514 - val_accuracy: 0.7641
# Epoch 14/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7726 - accuracy: 0.7476 - val_loss: 0.7266 - val_accuracy: 0.7800
# Epoch 15/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7457 - accuracy: 0.7604 - val_loss: 0.7060 - val_accuracy: 0.7864
# Epoch 16/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7247 - accuracy: 0.7723 - val_loss: 0.7026 - val_accuracy: 0.7779
# Epoch 17/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.7028 - accuracy: 0.7736 - val_loss: 0.6873 - val_accuracy: 0.7779
# Epoch 18/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7049 - accuracy: 0.7697 - val_loss: 0.6770 - val_accuracy: 0.7705
# Epoch 19/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6923 - accuracy: 0.7670 - val_loss: 0.6380 - val_accuracy: 0.8162
# Epoch 20/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6601 - accuracy: 0.7845 - val_loss: 0.6332 - val_accuracy: 0.8119
# Epoch 21/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6496 - accuracy: 0.7843 - val_loss: 0.6332 - val_accuracy: 0.8034
# Epoch 22/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6316 - accuracy: 0.7920 - val_loss: 0.6018 - val_accuracy: 0.8098
# Epoch 23/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.6093 - accuracy: 0.8023 - val_loss: 0.5906 - val_accuracy: 0.8225
# Epoch 24/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.6016 - accuracy: 0.8114 - val_loss: 0.5879 - val_accuracy: 0.8310
# Epoch 25/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5947 - accuracy: 0.8066 - val_loss: 0.5738 - val_accuracy: 0.8257
# Epoch 26/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5926 - accuracy: 0.8092 - val_loss: 0.5788 - val_accuracy: 0.8395
# Epoch 27/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5851 - accuracy: 0.8122 - val_loss: 0.5501 - val_accuracy: 0.8374
# Epoch 28/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5668 - accuracy: 0.8146 - val_loss: 0.5578 - val_accuracy: 0.8247
# Epoch 29/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5541 - accuracy: 0.8212 - val_loss: 0.5363 - val_accuracy: 0.8417
# Epoch 30/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5585 - accuracy: 0.8228 - val_loss: 0.5411 - val_accuracy: 0.8480
# Epoch 31/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5439 - accuracy: 0.8207 - val_loss: 0.5508 - val_accuracy: 0.8332
# Epoch 32/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5488 - accuracy: 0.8209 - val_loss: 0.5530 - val_accuracy: 0.8278
# Epoch 33/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5481 - accuracy: 0.8244 - val_loss: 0.5436 - val_accuracy: 0.8310
# Epoch 34/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5545 - accuracy: 0.8122 - val_loss: 0.5467 - val_accuracy: 0.8225
# Epoch 35/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5324 - accuracy: 0.8300 - val_loss: 0.5188 - val_accuracy: 0.8480
# Epoch 36/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5288 - accuracy: 0.8326 - val_loss: 0.5212 - val_accuracy: 0.8491
# Epoch 37/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5231 - accuracy: 0.8300 - val_loss: 0.5030 - val_accuracy: 0.8427
# Epoch 38/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5076 - accuracy: 0.8358 - val_loss: 0.4891 - val_accuracy: 0.8576
# Epoch 39/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5027 - accuracy: 0.8387 - val_loss: 0.4889 - val_accuracy: 0.8555
# Epoch 40/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4947 - accuracy: 0.8411 - val_loss: 0.4851 - val_accuracy: 0.8597
# Epoch 41/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4852 - accuracy: 0.8417 - val_loss: 0.4877 - val_accuracy: 0.8597
# Epoch 42/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4918 - accuracy: 0.8438 - val_loss: 0.4651 - val_accuracy: 0.8640
# Epoch 43/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4795 - accuracy: 0.8443 - val_loss: 0.4777 - val_accuracy: 0.8565
# Epoch 44/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4832 - accuracy: 0.8401 - val_loss: 0.4694 - val_accuracy: 0.8618
# Epoch 45/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4766 - accuracy: 0.8462 - val_loss: 0.4660 - val_accuracy: 0.8629
# Epoch 46/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4698 - accuracy: 0.8480 - val_loss: 0.4726 - val_accuracy: 0.8523
# Epoch 47/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4783 - accuracy: 0.8451 - val_loss: 0.4782 - val_accuracy: 0.8427
# Epoch 48/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4729 - accuracy: 0.8496 - val_loss: 0.4536 - val_accuracy: 0.8693
# Epoch 49/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4594 - accuracy: 0.8547 - val_loss: 0.4582 - val_accuracy: 0.8618
# Epoch 50/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4725 - accuracy: 0.8480 - val_loss: 0.4491 - val_accuracy: 0.8682
# Epoch 51/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4549 - accuracy: 0.8547 - val_loss: 0.4394 - val_accuracy: 0.8746
# Epoch 52/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4450 - accuracy: 0.8536 - val_loss: 0.4409 - val_accuracy: 0.8704
# Epoch 53/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4461 - accuracy: 0.8541 - val_loss: 0.4371 - val_accuracy: 0.8682
# Epoch 54/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4344 - accuracy: 0.8510 - val_loss: 0.4362 - val_accuracy: 0.8618
# Epoch 55/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4461 - accuracy: 0.8560 - val_loss: 0.4338 - val_accuracy: 0.8618
# Epoch 56/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4388 - accuracy: 0.8587 - val_loss: 0.4233 - val_accuracy: 0.8714
# Epoch 57/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4248 - accuracy: 0.8688 - val_loss: 0.4225 - val_accuracy: 0.8767
# Epoch 58/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4314 - accuracy: 0.8640 - val_loss: 0.4253 - val_accuracy: 0.8789
# Epoch 59/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4270 - accuracy: 0.8637 - val_loss: 0.4331 - val_accuracy: 0.8735
# Epoch 60/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4172 - accuracy: 0.8626 - val_loss: 0.4174 - val_accuracy: 0.8746
# Epoch 61/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4225 - accuracy: 0.8618 - val_loss: 0.4154 - val_accuracy: 0.8778
# Epoch 62/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4201 - accuracy: 0.8618 - val_loss: 0.4118 - val_accuracy: 0.8746
# Epoch 63/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4100 - accuracy: 0.8690 - val_loss: 0.4224 - val_accuracy: 0.8725
# Epoch 64/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4132 - accuracy: 0.8634 - val_loss: 0.4329 - val_accuracy: 0.8767
# Epoch 65/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4179 - accuracy: 0.8640 - val_loss: 0.4107 - val_accuracy: 0.8735
# Epoch 66/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4025 - accuracy: 0.8714 - val_loss: 0.3966 - val_accuracy: 0.8874
# Epoch 67/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4029 - accuracy: 0.8642 - val_loss: 0.4037 - val_accuracy: 0.8799
# Epoch 68/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3989 - accuracy: 0.8746 - val_loss: 0.3951 - val_accuracy: 0.8905
# Epoch 69/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3877 - accuracy: 0.8751 - val_loss: 0.3893 - val_accuracy: 0.8852
# Epoch 70/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3817 - accuracy: 0.8794 - val_loss: 0.3827 - val_accuracy: 0.8874
# Epoch 71/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3834 - accuracy: 0.8746 - val_loss: 0.3813 - val_accuracy: 0.8927
# Epoch 72/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3791 - accuracy: 0.8781 - val_loss: 0.3995 - val_accuracy: 0.8767
# Epoch 73/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3894 - accuracy: 0.8719 - val_loss: 0.3833 - val_accuracy: 0.8852
# Epoch 74/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3898 - accuracy: 0.8746 - val_loss: 0.3863 - val_accuracy: 0.8842
# Epoch 75/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3787 - accuracy: 0.8781 - val_loss: 0.3759 - val_accuracy: 0.8863
# Epoch 76/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3800 - accuracy: 0.8727 - val_loss: 0.3794 - val_accuracy: 0.8852
# Epoch 77/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3806 - accuracy: 0.8781 - val_loss: 0.3796 - val_accuracy: 0.8905
# Epoch 78/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3807 - accuracy: 0.8735 - val_loss: 0.3939 - val_accuracy: 0.8842
# Epoch 79/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3791 - accuracy: 0.8786 - val_loss: 0.3721 - val_accuracy: 0.8927
# Epoch 80/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3660 - accuracy: 0.8836 - val_loss: 0.3734 - val_accuracy: 0.9001
# Epoch 81/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3691 - accuracy: 0.8828 - val_loss: 0.3936 - val_accuracy: 0.8895
# Epoch 82/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3767 - accuracy: 0.8831 - val_loss: 0.3904 - val_accuracy: 0.8725
# Epoch 83/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3681 - accuracy: 0.8804 - val_loss: 0.3619 - val_accuracy: 0.9012
# Epoch 84/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3517 - accuracy: 0.8929 - val_loss: 0.3593 - val_accuracy: 0.9012
# Epoch 85/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3526 - accuracy: 0.8866 - val_loss: 0.3559 - val_accuracy: 0.9033
# Epoch 86/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3465 - accuracy: 0.8913 - val_loss: 0.3647 - val_accuracy: 0.8916
# Epoch 87/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3450 - accuracy: 0.8892 - val_loss: 0.3571 - val_accuracy: 0.9033
# Epoch 88/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3452 - accuracy: 0.8903 - val_loss: 0.3742 - val_accuracy: 0.8895
# Epoch 89/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3511 - accuracy: 0.8868 - val_loss: 0.3662 - val_accuracy: 0.9012
# Epoch 90/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3608 - accuracy: 0.8812 - val_loss: 0.3590 - val_accuracy: 0.8980
# Epoch 91/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3433 - accuracy: 0.8887 - val_loss: 0.3535 - val_accuracy: 0.9022
# Epoch 92/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3410 - accuracy: 0.8900 - val_loss: 0.3580 - val_accuracy: 0.8980
# Epoch 93/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3340 - accuracy: 0.8911 - val_loss: 0.3459 - val_accuracy: 0.9086
# Epoch 94/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3297 - accuracy: 0.8919 - val_loss: 0.3460 - val_accuracy: 0.9086
# Epoch 95/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3257 - accuracy: 0.8959 - val_loss: 0.3724 - val_accuracy: 0.8969
# Epoch 96/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3348 - accuracy: 0.8929 - val_loss: 0.3463 - val_accuracy: 0.8969
# Epoch 97/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3392 - accuracy: 0.8903 - val_loss: 0.3426 - val_accuracy: 0.9171
# Epoch 98/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3280 - accuracy: 0.8974 - val_loss: 0.3490 - val_accuracy: 0.9033
# Epoch 99/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3319 - accuracy: 0.8967 - val_loss: 0.3457 - val_accuracy: 0.9097
# Epoch 100/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3212 - accuracy: 0.8996 - val_loss: 0.3298 - val_accuracy: 0.9107
# Epoch 101/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3194 - accuracy: 0.8998 - val_loss: 0.3389 - val_accuracy: 0.9086
# Epoch 102/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3173 - accuracy: 0.9009 - val_loss: 0.3463 - val_accuracy: 0.9129
# Epoch 103/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3222 - accuracy: 0.8959 - val_loss: 0.3499 - val_accuracy: 0.9065
# Epoch 104/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3319 - accuracy: 0.8855 - val_loss: 0.3398 - val_accuracy: 0.9139
# Epoch 105/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3146 - accuracy: 0.9049 - val_loss: 0.3301 - val_accuracy: 0.9086
# Epoch 106/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3014 - accuracy: 0.9070 - val_loss: 0.3482 - val_accuracy: 0.9054
# Epoch 107/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3171 - accuracy: 0.8998 - val_loss: 0.3505 - val_accuracy: 0.9001
# Epoch 108/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3169 - accuracy: 0.8996 - val_loss: 0.3452 - val_accuracy: 0.9022
# Epoch 109/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2997 - accuracy: 0.9060 - val_loss: 0.3378 - val_accuracy: 0.9033
# Epoch 110/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3107 - accuracy: 0.9004 - val_loss: 0.3376 - val_accuracy: 0.9129
# Epoch 111/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2973 - accuracy: 0.9057 - val_loss: 0.3328 - val_accuracy: 0.9086
# Epoch 112/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3003 - accuracy: 0.9083 - val_loss: 0.3283 - val_accuracy: 0.9054
# Epoch 113/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2987 - accuracy: 0.9038 - val_loss: 0.3151 - val_accuracy: 0.9118
# Epoch 114/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2851 - accuracy: 0.9113 - val_loss: 0.3206 - val_accuracy: 0.9150
# Epoch 115/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2977 - accuracy: 0.9012 - val_loss: 0.3325 - val_accuracy: 0.9118
# Epoch 116/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2978 - accuracy: 0.9107 - val_loss: 0.3136 - val_accuracy: 0.9139
# Epoch 117/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2949 - accuracy: 0.9004 - val_loss: 0.3254 - val_accuracy: 0.9012
# Epoch 118/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2871 - accuracy: 0.9062 - val_loss: 0.3105 - val_accuracy: 0.9129
# Epoch 119/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2719 - accuracy: 0.9137 - val_loss: 0.3127 - val_accuracy: 0.9192
# Epoch 120/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2791 - accuracy: 0.9131 - val_loss: 0.3287 - val_accuracy: 0.9022
# Epoch 121/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2877 - accuracy: 0.9065 - val_loss: 0.3082 - val_accuracy: 0.9214
# Epoch 122/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2827 - accuracy: 0.9118 - val_loss: 0.3275 - val_accuracy: 0.9171
# Epoch 123/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2884 - accuracy: 0.9083 - val_loss: 0.3144 - val_accuracy: 0.9171
# Epoch 124/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2754 - accuracy: 0.9190 - val_loss: 0.3301 - val_accuracy: 0.9075
# Epoch 125/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2739 - accuracy: 0.9107 - val_loss: 0.2989 - val_accuracy: 0.9214
# Epoch 126/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2675 - accuracy: 0.9211 - val_loss: 0.3123 - val_accuracy: 0.9139
# Epoch 127/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2722 - accuracy: 0.9145 - val_loss: 0.3064 - val_accuracy: 0.9150
# Epoch 128/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2769 - accuracy: 0.9121 - val_loss: 0.3136 - val_accuracy: 0.9097
# Epoch 129/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2714 - accuracy: 0.9160 - val_loss: 0.3091 - val_accuracy: 0.9065
# Epoch 130/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2697 - accuracy: 0.9166 - val_loss: 0.2979 - val_accuracy: 0.9192
# Epoch 131/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2669 - accuracy: 0.9176 - val_loss: 0.3040 - val_accuracy: 0.9171
# Epoch 132/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2719 - accuracy: 0.9126 - val_loss: 0.3232 - val_accuracy: 0.9065
# Epoch 133/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2810 - accuracy: 0.9062 - val_loss: 0.3040 - val_accuracy: 0.9129
# Epoch 134/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2783 - accuracy: 0.9089 - val_loss: 0.3021 - val_accuracy: 0.9097
# Epoch 135/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2715 - accuracy: 0.9152 - val_loss: 0.3014 - val_accuracy: 0.9203
# Epoch 136/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2657 - accuracy: 0.9152 - val_loss: 0.3121 - val_accuracy: 0.9192
# Epoch 137/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2603 - accuracy: 0.9155 - val_loss: 0.3059 - val_accuracy: 0.9139
# Epoch 138/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2564 - accuracy: 0.9232 - val_loss: 0.2875 - val_accuracy: 0.9129
# Epoch 139/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2433 - accuracy: 0.9259 - val_loss: 0.2999 - val_accuracy: 0.9214
# Epoch 140/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2570 - accuracy: 0.9219 - val_loss: 0.2826 - val_accuracy: 0.9277
# Epoch 141/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2586 - accuracy: 0.9203 - val_loss: 0.3104 - val_accuracy: 0.9182
# Epoch 142/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2596 - accuracy: 0.9171 - val_loss: 0.3043 - val_accuracy: 0.9182
# Epoch 143/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2687 - accuracy: 0.9139 - val_loss: 0.3156 - val_accuracy: 0.9160
# Epoch 144/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2526 - accuracy: 0.9222 - val_loss: 0.3134 - val_accuracy: 0.9150
# Epoch 145/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2594 - accuracy: 0.9163 - val_loss: 0.2858 - val_accuracy: 0.9150
# Epoch 146/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2456 - accuracy: 0.9240 - val_loss: 0.2714 - val_accuracy: 0.9182
# Epoch 147/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2503 - accuracy: 0.9232 - val_loss: 0.2909 - val_accuracy: 0.9160
# Epoch 148/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2466 - accuracy: 0.9211 - val_loss: 0.2793 - val_accuracy: 0.9214
# Epoch 149/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2437 - accuracy: 0.9277 - val_loss: 0.2761 - val_accuracy: 0.9182
# Epoch 150/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2314 - accuracy: 0.9275 - val_loss: 0.2832 - val_accuracy: 0.9182
# Epoch 151/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2463 - accuracy: 0.9251 - val_loss: 0.2744 - val_accuracy: 0.9256
# Epoch 152/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2446 - accuracy: 0.9224 - val_loss: 0.2933 - val_accuracy: 0.9139
# Epoch 153/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2551 - accuracy: 0.9158 - val_loss: 0.2784 - val_accuracy: 0.9224
# Epoch 154/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2427 - accuracy: 0.9240 - val_loss: 0.3039 - val_accuracy: 0.9160
# Epoch 155/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2476 - accuracy: 0.9251 - val_loss: 0.2965 - val_accuracy: 0.9118
# Epoch 156/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2440 - accuracy: 0.9198 - val_loss: 0.2888 - val_accuracy: 0.9203
# Epoch 157/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2543 - accuracy: 0.9208 - val_loss: 0.3107 - val_accuracy: 0.9107
# Epoch 158/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2414 - accuracy: 0.9272 - val_loss: 0.2746 - val_accuracy: 0.9288
# Epoch 159/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2217 - accuracy: 0.9296 - val_loss: 0.2808 - val_accuracy: 0.9267
# Epoch 160/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2267 - accuracy: 0.9301 - val_loss: 0.2815 - val_accuracy: 0.9214
# Epoch 161/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2330 - accuracy: 0.9293 - val_loss: 0.2807 - val_accuracy: 0.9203
# Epoch 162/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2313 - accuracy: 0.9259 - val_loss: 0.2811 - val_accuracy: 0.9245
# Epoch 163/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2277 - accuracy: 0.9261 - val_loss: 0.2723 - val_accuracy: 0.9235
# Epoch 164/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2222 - accuracy: 0.9338 - val_loss: 0.2703 - val_accuracy: 0.9224
# Epoch 165/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2201 - accuracy: 0.9333 - val_loss: 0.2705 - val_accuracy: 0.9224
# Epoch 166/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2264 - accuracy: 0.9317 - val_loss: 0.2965 - val_accuracy: 0.9256
# Epoch 167/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2186 - accuracy: 0.9299 - val_loss: 0.3024 - val_accuracy: 0.9150
# Epoch 168/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2237 - accuracy: 0.9323 - val_loss: 0.2782 - val_accuracy: 0.9065
# Epoch 169/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2389 - accuracy: 0.9232 - val_loss: 0.2735 - val_accuracy: 0.9235
# Epoch 170/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2249 - accuracy: 0.9325 - val_loss: 0.2821 - val_accuracy: 0.9192
# Epoch 171/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2335 - accuracy: 0.9224 - val_loss: 0.2980 - val_accuracy: 0.9150
# Epoch 172/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2362 - accuracy: 0.9238 - val_loss: 0.2738 - val_accuracy: 0.9214
# Epoch 173/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2152 - accuracy: 0.9301 - val_loss: 0.2732 - val_accuracy: 0.9224
# Epoch 174/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2118 - accuracy: 0.9346 - val_loss: 0.2721 - val_accuracy: 0.9214
# Epoch 175/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2052 - accuracy: 0.9349 - val_loss: 0.2793 - val_accuracy: 0.9245
# Epoch 176/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2126 - accuracy: 0.9402 - val_loss: 0.2783 - val_accuracy: 0.9235
# Epoch 177/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2150 - accuracy: 0.9323 - val_loss: 0.2592 - val_accuracy: 0.9267
# Epoch 178/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2016 - accuracy: 0.9384 - val_loss: 0.2581 - val_accuracy: 0.9330
# Epoch 179/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2029 - accuracy: 0.9386 - val_loss: 0.2662 - val_accuracy: 0.9320
# Epoch 180/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1995 - accuracy: 0.9392 - val_loss: 0.2542 - val_accuracy: 0.9299
# Epoch 181/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1988 - accuracy: 0.9386 - val_loss: 0.2540 - val_accuracy: 0.9256
# Epoch 182/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2084 - accuracy: 0.9325 - val_loss: 0.2507 - val_accuracy: 0.9330
# Epoch 183/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1992 - accuracy: 0.9386 - val_loss: 0.2666 - val_accuracy: 0.9267
# Epoch 184/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2013 - accuracy: 0.9400 - val_loss: 0.2553 - val_accuracy: 0.9330
# Epoch 185/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1922 - accuracy: 0.9410 - val_loss: 0.2574 - val_accuracy: 0.9288
# Epoch 186/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1928 - accuracy: 0.9426 - val_loss: 0.2529 - val_accuracy: 0.9299
# Epoch 187/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1998 - accuracy: 0.9405 - val_loss: 0.2499 - val_accuracy: 0.9256
# Epoch 188/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1979 - accuracy: 0.9429 - val_loss: 0.2472 - val_accuracy: 0.9320
# Epoch 189/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1916 - accuracy: 0.9389 - val_loss: 0.2817 - val_accuracy: 0.9256
# Epoch 190/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1999 - accuracy: 0.9362 - val_loss: 0.2614 - val_accuracy: 0.9299
# Epoch 191/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1985 - accuracy: 0.9378 - val_loss: 0.2684 - val_accuracy: 0.9256
# Epoch 192/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2004 - accuracy: 0.9400 - val_loss: 0.2728 - val_accuracy: 0.9245
# Epoch 193/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1975 - accuracy: 0.9386 - val_loss: 0.2716 - val_accuracy: 0.9182
# Epoch 194/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1930 - accuracy: 0.9421 - val_loss: 0.2578 - val_accuracy: 0.9245
# Epoch 195/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1856 - accuracy: 0.9450 - val_loss: 0.2638 - val_accuracy: 0.9214
# Epoch 196/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1865 - accuracy: 0.9423 - val_loss: 0.2707 - val_accuracy: 0.9277
# Epoch 197/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1823 - accuracy: 0.9445 - val_loss: 0.2487 - val_accuracy: 0.9224
# Epoch 198/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1909 - accuracy: 0.9416 - val_loss: 0.2591 - val_accuracy: 0.9288
# Epoch 199/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1940 - accuracy: 0.9410 - val_loss: 0.2572 - val_accuracy: 0.9309
# Epoch 200/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1879 - accuracy: 0.9386 - val_loss: 0.2568 - val_accuracy: 0.9235

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 8/8 [==============================] - 0s 60ms/step - loss: 1.8696 - accuracy: 0.3478 - val_loss: 1.5731 - val_accuracy: 0.4942
# Epoch 2/45
# 8/8 [==============================] - 0s 42ms/step - loss: 1.4879 - accuracy: 0.4957 - val_loss: 1.3515 - val_accuracy: 0.5218
# Epoch 3/45
# 8/8 [==============================] - 0s 43ms/step - loss: 1.3356 - accuracy: 0.5252 - val_loss: 1.2665 - val_accuracy: 0.5558
# Epoch 4/45
# 8/8 [==============================] - 0s 32ms/step - loss: 1.2620 - accuracy: 0.5587 - val_loss: 1.2084 - val_accuracy: 0.5739
# Epoch 5/45
# 8/8 [==============================] - 0s 33ms/step - loss: 1.2001 - accuracy: 0.5733 - val_loss: 1.1766 - val_accuracy: 0.5675
# Epoch 6/45
# 8/8 [==============================] - 0s 36ms/step - loss: 1.1457 - accuracy: 0.5906 - val_loss: 1.0880 - val_accuracy: 0.6461
# Epoch 7/45
# 8/8 [==============================] - 0s 38ms/step - loss: 1.0873 - accuracy: 0.6259 - val_loss: 1.0175 - val_accuracy: 0.7014
# Epoch 8/45
# 8/8 [==============================] - 0s 34ms/step - loss: 1.0213 - accuracy: 0.6756 - val_loss: 0.9556 - val_accuracy: 0.7258
# Epoch 9/45
# 8/8 [==============================] - 0s 41ms/step - loss: 0.9723 - accuracy: 0.6836 - val_loss: 0.8978 - val_accuracy: 0.7205
# Epoch 10/45
# 8/8 [==============================] - 0s 37ms/step - loss: 0.9096 - accuracy: 0.7078 - val_loss: 0.8625 - val_accuracy: 0.7194
# Epoch 11/45
# 8/8 [==============================] - 0s 44ms/step - loss: 0.8737 - accuracy: 0.7115 - val_loss: 0.8193 - val_accuracy: 0.7535
# Epoch 12/45
# 8/8 [==============================] - 0s 36ms/step - loss: 0.8368 - accuracy: 0.7293 - val_loss: 0.8104 - val_accuracy: 0.7226
# Epoch 13/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.8138 - accuracy: 0.7311 - val_loss: 0.7721 - val_accuracy: 0.7322
# Epoch 14/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7875 - accuracy: 0.7388 - val_loss: 0.7398 - val_accuracy: 0.7758
# Epoch 15/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7504 - accuracy: 0.7638 - val_loss: 0.7050 - val_accuracy: 0.7832
# Epoch 16/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7247 - accuracy: 0.7633 - val_loss: 0.6899 - val_accuracy: 0.7938
# Epoch 17/45
# 8/8 [==============================] - 0s 31ms/step - loss: 0.7082 - accuracy: 0.7747 - val_loss: 0.6804 - val_accuracy: 0.7790
# Epoch 18/45
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6987 - accuracy: 0.7758 - val_loss: 0.6535 - val_accuracy: 0.8023
# Epoch 19/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6808 - accuracy: 0.7736 - val_loss: 0.6536 - val_accuracy: 0.7960
# Epoch 20/45
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6666 - accuracy: 0.7893 - val_loss: 0.6490 - val_accuracy: 0.7981
# Epoch 21/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6476 - accuracy: 0.7941 - val_loss: 0.6281 - val_accuracy: 0.8193
# Epoch 22/45
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6566 - accuracy: 0.7795 - val_loss: 0.6465 - val_accuracy: 0.7981
# Epoch 23/45
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6569 - accuracy: 0.7803 - val_loss: 0.6057 - val_accuracy: 0.8098
# Epoch 24/45
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6351 - accuracy: 0.7938 - val_loss: 0.6045 - val_accuracy: 0.8130
# Epoch 25/45
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6240 - accuracy: 0.7981 - val_loss: 0.6002 - val_accuracy: 0.8002
# Epoch 26/45
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6006 - accuracy: 0.8084 - val_loss: 0.5785 - val_accuracy: 0.8215
# Epoch 27/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5948 - accuracy: 0.8084 - val_loss: 0.5907 - val_accuracy: 0.8119
# Epoch 28/45
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5874 - accuracy: 0.8039 - val_loss: 0.5737 - val_accuracy: 0.8225
# Epoch 29/45
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5805 - accuracy: 0.8108 - val_loss: 0.5448 - val_accuracy: 0.8533
# Epoch 30/45
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5625 - accuracy: 0.8146 - val_loss: 0.5492 - val_accuracy: 0.8438
# Epoch 31/45
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5514 - accuracy: 0.8180 - val_loss: 0.5337 - val_accuracy: 0.8332
# Epoch 32/45
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5556 - accuracy: 0.8239 - val_loss: 0.5552 - val_accuracy: 0.8385
# Epoch 33/45
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5671 - accuracy: 0.8225 - val_loss: 0.5528 - val_accuracy: 0.8395
# Epoch 34/45
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5459 - accuracy: 0.8233 - val_loss: 0.5374 - val_accuracy: 0.8374
# Epoch 35/45
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5334 - accuracy: 0.8308 - val_loss: 0.5010 - val_accuracy: 0.8587
# Epoch 36/45
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5243 - accuracy: 0.8321 - val_loss: 0.4978 - val_accuracy: 0.8587
# Epoch 37/45
# 8/8 [==============================] - 0s 44ms/step - loss: 0.5075 - accuracy: 0.8377 - val_loss: 0.4951 - val_accuracy: 0.8587
# Epoch 38/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5091 - accuracy: 0.8371 - val_loss: 0.4968 - val_accuracy: 0.8523
# Epoch 39/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4997 - accuracy: 0.8369 - val_loss: 0.4850 - val_accuracy: 0.8618
# Epoch 40/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4927 - accuracy: 0.8403 - val_loss: 0.4799 - val_accuracy: 0.8640
# Epoch 41/45
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4979 - accuracy: 0.8456 - val_loss: 0.4817 - val_accuracy: 0.8523
# Epoch 42/45
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4885 - accuracy: 0.8406 - val_loss: 0.4766 - val_accuracy: 0.8608
# Epoch 43/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4811 - accuracy: 0.8491 - val_loss: 0.4796 - val_accuracy: 0.8565
# Epoch 44/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4788 - accuracy: 0.8448 - val_loss: 0.4875 - val_accuracy: 0.8565
# Epoch 45/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5069 - accuracy: 0.8350 - val_loss: 0.4672 - val_accuracy: 0.8640

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 4ms/step - loss: 0.4364 - accuracy: 0.8656
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.8640
# 0.8655685186386108 0.8639745116233826

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 53, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:08

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   1   0   0   0   0   0]
#  [  1   0   0 117   4   0   0   0   2]
#  [  0   0   0   0 314   5   0   0   1]
#  [  0   0   0   1  36  79   2   0   2]
#  [  0   0   1   0  17   4  24   0   4]
#  [  0   0   0   0  14   9   3  24   0]
#  [  0   0   0   2  11   8   0   0  16]]
#
# Accuracy Score
# 0.8639744952178533
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.98      1.00      0.99        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.97      0.94      0.96       124
#       built       0.79      0.98      0.88       320
#     windows       0.75      0.66      0.70       120
#       roads       0.83      0.48      0.61        50
#        cars       1.00      0.48      0.65        50
#       metal       0.64      0.43      0.52        37
#
# avg / total       0.87      0.86      0.85       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
