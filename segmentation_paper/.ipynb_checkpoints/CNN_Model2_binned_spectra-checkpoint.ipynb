# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %%
num_of_bins = 53
filtersize = 3
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 53
# [[0, 16], [16, 32], [32, 48], [48, 64], [64, 80], [80, 96], [96, 112], [112, 128], [128, 144], [144, 160], [160, 176], [176, 192], [192, 208], [208, 224], [224, 240], [240, 256], [256, 272], [272, 288], [288, 304], [304, 320], [320, 336], [336, 352], [352, 368], [368, 384], [384, 400], [400, 416], [416, 432], [432, 448], [448, 464], [464, 480], [480, 496], [496, 512], [512, 528], [528, 544], [544, 560], [560, 576], [576, 592], [592, 608], [608, 624], [624, 640], [640, 656], [656, 672], [672, 688], [688, 704], [704, 720], [720, 736], [736, 752], [752, 768], [768, 784], [784, 800], [800, 816], [816, 832], [832, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 53)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 53)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 53) (60, 53)
# clouds  (400, 53) (100, 53)
# vegetation  (480, 53) (120, 53)
# water  (40, 53) (10, 53)
# built  (816, 53) (204, 53)
# windows  (400, 53) (100, 53)
# roads  (24, 53) (6, 53)
# cars  (80, 53) (20, 53)
# metal  (80, 53) (20, 53)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 53) (2560,) (2560, 2)
# (640, 53) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 165ms/step - loss: 1.9662 - accuracy: 0.3313 - val_loss: 1.7035 - val_accuracy: 0.3734
# Epoch 2/200
# 5/5 [==============================] - 0s 64ms/step - loss: 1.6230 - accuracy: 0.4355 - val_loss: 1.4543 - val_accuracy: 0.4969
# Epoch 3/200
# 5/5 [==============================] - 0s 39ms/step - loss: 1.4107 - accuracy: 0.6012 - val_loss: 1.2318 - val_accuracy: 0.6562
# Epoch 4/200
# 5/5 [==============================] - 0s 51ms/step - loss: 1.2125 - accuracy: 0.6473 - val_loss: 1.0419 - val_accuracy: 0.6609
# Epoch 5/200
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0365 - accuracy: 0.6805 - val_loss: 0.8942 - val_accuracy: 0.7406
# Epoch 6/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.9181 - accuracy: 0.7113 - val_loss: 0.7926 - val_accuracy: 0.7437
# Epoch 7/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.8421 - accuracy: 0.7320 - val_loss: 0.7302 - val_accuracy: 0.8109
# Epoch 8/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7792 - accuracy: 0.7598 - val_loss: 0.6853 - val_accuracy: 0.7750
# Epoch 9/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7333 - accuracy: 0.7715 - val_loss: 0.6493 - val_accuracy: 0.8188
# Epoch 10/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.7163 - accuracy: 0.7785 - val_loss: 0.6193 - val_accuracy: 0.8188
# Epoch 11/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6817 - accuracy: 0.7879 - val_loss: 0.5922 - val_accuracy: 0.8562
# Epoch 12/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6492 - accuracy: 0.8047 - val_loss: 0.5667 - val_accuracy: 0.8359
# Epoch 13/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6272 - accuracy: 0.8078 - val_loss: 0.5514 - val_accuracy: 0.8203
# Epoch 14/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5942 - accuracy: 0.8246 - val_loss: 0.5382 - val_accuracy: 0.8531
# Epoch 15/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5855 - accuracy: 0.8184 - val_loss: 0.5219 - val_accuracy: 0.8219
# Epoch 16/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5717 - accuracy: 0.8242 - val_loss: 0.4952 - val_accuracy: 0.8656
# Epoch 17/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5484 - accuracy: 0.8309 - val_loss: 0.4852 - val_accuracy: 0.8297
# Epoch 18/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.5285 - accuracy: 0.8336 - val_loss: 0.4640 - val_accuracy: 0.8719
# Epoch 19/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5114 - accuracy: 0.8395 - val_loss: 0.4508 - val_accuracy: 0.8672
# Epoch 20/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.5128 - accuracy: 0.8402 - val_loss: 0.4543 - val_accuracy: 0.8313
# Epoch 21/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4974 - accuracy: 0.8461 - val_loss: 0.4466 - val_accuracy: 0.8687
# Epoch 22/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4887 - accuracy: 0.8465 - val_loss: 0.4292 - val_accuracy: 0.8484
# Epoch 23/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4726 - accuracy: 0.8492 - val_loss: 0.4176 - val_accuracy: 0.8781
# Epoch 24/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4656 - accuracy: 0.8520 - val_loss: 0.4060 - val_accuracy: 0.8875
# Epoch 25/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4517 - accuracy: 0.8609 - val_loss: 0.4008 - val_accuracy: 0.8703
# Epoch 26/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4445 - accuracy: 0.8559 - val_loss: 0.3944 - val_accuracy: 0.8875
# Epoch 27/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4295 - accuracy: 0.8691 - val_loss: 0.3822 - val_accuracy: 0.8922
# Epoch 28/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4136 - accuracy: 0.8797 - val_loss: 0.3748 - val_accuracy: 0.8891
# Epoch 29/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4168 - accuracy: 0.8703 - val_loss: 0.3727 - val_accuracy: 0.8922
# Epoch 30/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4194 - accuracy: 0.8664 - val_loss: 0.3644 - val_accuracy: 0.8922
# Epoch 31/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4013 - accuracy: 0.8746 - val_loss: 0.3579 - val_accuracy: 0.8969
# Epoch 32/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3966 - accuracy: 0.8777 - val_loss: 0.3566 - val_accuracy: 0.8969
# Epoch 33/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3967 - accuracy: 0.8785 - val_loss: 0.3502 - val_accuracy: 0.8906
# Epoch 34/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3828 - accuracy: 0.8824 - val_loss: 0.3424 - val_accuracy: 0.8953
# Epoch 35/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3833 - accuracy: 0.8836 - val_loss: 0.3348 - val_accuracy: 0.8984
# Epoch 36/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3799 - accuracy: 0.8852 - val_loss: 0.3316 - val_accuracy: 0.8938
# Epoch 37/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3752 - accuracy: 0.8789 - val_loss: 0.3378 - val_accuracy: 0.9016
# Epoch 38/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3708 - accuracy: 0.8836 - val_loss: 0.3389 - val_accuracy: 0.8969
# Epoch 39/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3606 - accuracy: 0.8824 - val_loss: 0.3254 - val_accuracy: 0.9062
# Epoch 40/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3537 - accuracy: 0.8895 - val_loss: 0.3210 - val_accuracy: 0.8969
# Epoch 41/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3498 - accuracy: 0.8898 - val_loss: 0.3134 - val_accuracy: 0.9062
# Epoch 42/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3496 - accuracy: 0.8855 - val_loss: 0.3090 - val_accuracy: 0.9094
# Epoch 43/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3512 - accuracy: 0.8941 - val_loss: 0.3096 - val_accuracy: 0.9047
# Epoch 44/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3445 - accuracy: 0.8934 - val_loss: 0.3162 - val_accuracy: 0.8953
# Epoch 45/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3517 - accuracy: 0.8852 - val_loss: 0.3036 - val_accuracy: 0.9125
# Epoch 46/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3428 - accuracy: 0.8977 - val_loss: 0.2992 - val_accuracy: 0.9047
# Epoch 47/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3359 - accuracy: 0.8961 - val_loss: 0.2937 - val_accuracy: 0.9078
# Epoch 48/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3322 - accuracy: 0.8938 - val_loss: 0.2900 - val_accuracy: 0.9094
# Epoch 49/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3211 - accuracy: 0.8980 - val_loss: 0.2863 - val_accuracy: 0.9125
# Epoch 50/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3200 - accuracy: 0.9035 - val_loss: 0.2856 - val_accuracy: 0.9047
# Epoch 51/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3269 - accuracy: 0.8953 - val_loss: 0.2854 - val_accuracy: 0.9109
# Epoch 52/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3197 - accuracy: 0.9000 - val_loss: 0.2831 - val_accuracy: 0.9141
# Epoch 53/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3101 - accuracy: 0.9039 - val_loss: 0.2815 - val_accuracy: 0.9109
# Epoch 54/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3143 - accuracy: 0.9004 - val_loss: 0.2752 - val_accuracy: 0.9141
# Epoch 55/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3155 - accuracy: 0.8988 - val_loss: 0.2699 - val_accuracy: 0.9156
# Epoch 56/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3066 - accuracy: 0.9027 - val_loss: 0.2707 - val_accuracy: 0.9109
# Epoch 57/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3061 - accuracy: 0.8969 - val_loss: 0.2718 - val_accuracy: 0.9156
# Epoch 58/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3184 - accuracy: 0.9031 - val_loss: 0.2627 - val_accuracy: 0.9141
# Epoch 59/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3005 - accuracy: 0.9070 - val_loss: 0.2615 - val_accuracy: 0.9141
# Epoch 60/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2918 - accuracy: 0.9074 - val_loss: 0.2596 - val_accuracy: 0.9172
# Epoch 61/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2915 - accuracy: 0.9086 - val_loss: 0.2603 - val_accuracy: 0.9141
# Epoch 62/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2879 - accuracy: 0.9094 - val_loss: 0.2547 - val_accuracy: 0.9203
# Epoch 63/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2838 - accuracy: 0.9121 - val_loss: 0.2503 - val_accuracy: 0.9172
# Epoch 64/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2842 - accuracy: 0.9090 - val_loss: 0.2489 - val_accuracy: 0.9156
# Epoch 65/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2839 - accuracy: 0.9098 - val_loss: 0.2479 - val_accuracy: 0.9172
# Epoch 66/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2752 - accuracy: 0.9133 - val_loss: 0.2457 - val_accuracy: 0.9172
# Epoch 67/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2743 - accuracy: 0.9137 - val_loss: 0.2461 - val_accuracy: 0.9156
# Epoch 68/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2769 - accuracy: 0.9148 - val_loss: 0.2419 - val_accuracy: 0.9156
# Epoch 69/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2793 - accuracy: 0.9180 - val_loss: 0.2423 - val_accuracy: 0.9187
# Epoch 70/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2716 - accuracy: 0.9109 - val_loss: 0.2390 - val_accuracy: 0.9156
# Epoch 71/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2681 - accuracy: 0.9156 - val_loss: 0.2339 - val_accuracy: 0.9187
# Epoch 72/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2748 - accuracy: 0.9113 - val_loss: 0.2355 - val_accuracy: 0.9219
# Epoch 73/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2671 - accuracy: 0.9129 - val_loss: 0.2341 - val_accuracy: 0.9172
# Epoch 74/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2650 - accuracy: 0.9152 - val_loss: 0.2315 - val_accuracy: 0.9187
# Epoch 75/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2685 - accuracy: 0.9156 - val_loss: 0.2308 - val_accuracy: 0.9187
# Epoch 76/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2631 - accuracy: 0.9133 - val_loss: 0.2370 - val_accuracy: 0.9234
# Epoch 77/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2600 - accuracy: 0.9180 - val_loss: 0.2270 - val_accuracy: 0.9172
# Epoch 78/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2539 - accuracy: 0.9234 - val_loss: 0.2289 - val_accuracy: 0.9266
# Epoch 79/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2572 - accuracy: 0.9207 - val_loss: 0.2273 - val_accuracy: 0.9187
# Epoch 80/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2594 - accuracy: 0.9168 - val_loss: 0.2241 - val_accuracy: 0.9203
# Epoch 81/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2584 - accuracy: 0.9152 - val_loss: 0.2224 - val_accuracy: 0.9234
# Epoch 82/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2434 - accuracy: 0.9184 - val_loss: 0.2213 - val_accuracy: 0.9266
# Epoch 83/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2544 - accuracy: 0.9168 - val_loss: 0.2196 - val_accuracy: 0.9187
# Epoch 84/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2557 - accuracy: 0.9203 - val_loss: 0.2184 - val_accuracy: 0.9219
# Epoch 85/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2507 - accuracy: 0.9223 - val_loss: 0.2198 - val_accuracy: 0.9312
# Epoch 86/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2524 - accuracy: 0.9180 - val_loss: 0.2181 - val_accuracy: 0.9187
# Epoch 87/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2459 - accuracy: 0.9211 - val_loss: 0.2157 - val_accuracy: 0.9328
# Epoch 88/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2418 - accuracy: 0.9234 - val_loss: 0.2114 - val_accuracy: 0.9187
# Epoch 89/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2410 - accuracy: 0.9266 - val_loss: 0.2144 - val_accuracy: 0.9234
# Epoch 90/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2506 - accuracy: 0.9203 - val_loss: 0.2129 - val_accuracy: 0.9187
# Epoch 91/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2365 - accuracy: 0.9246 - val_loss: 0.2170 - val_accuracy: 0.9344
# Epoch 92/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2401 - accuracy: 0.9262 - val_loss: 0.2110 - val_accuracy: 0.9187
# Epoch 93/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2397 - accuracy: 0.9234 - val_loss: 0.2061 - val_accuracy: 0.9281
# Epoch 94/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2464 - accuracy: 0.9156 - val_loss: 0.2120 - val_accuracy: 0.9297
# Epoch 95/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2514 - accuracy: 0.9199 - val_loss: 0.2089 - val_accuracy: 0.9187
# Epoch 96/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2439 - accuracy: 0.9238 - val_loss: 0.2083 - val_accuracy: 0.9281
# Epoch 97/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2404 - accuracy: 0.9195 - val_loss: 0.2128 - val_accuracy: 0.9250
# Epoch 98/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2311 - accuracy: 0.9254 - val_loss: 0.2097 - val_accuracy: 0.9234
# Epoch 99/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2457 - accuracy: 0.9215 - val_loss: 0.2054 - val_accuracy: 0.9391
# Epoch 100/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2288 - accuracy: 0.9234 - val_loss: 0.1989 - val_accuracy: 0.9281
# Epoch 101/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2330 - accuracy: 0.9211 - val_loss: 0.2007 - val_accuracy: 0.9234
# Epoch 102/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2311 - accuracy: 0.9242 - val_loss: 0.1974 - val_accuracy: 0.9312
# Epoch 103/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2224 - accuracy: 0.9238 - val_loss: 0.1939 - val_accuracy: 0.9234
# Epoch 104/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2261 - accuracy: 0.9258 - val_loss: 0.1932 - val_accuracy: 0.9281
# Epoch 105/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2323 - accuracy: 0.9211 - val_loss: 0.1946 - val_accuracy: 0.9328
# Epoch 106/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2255 - accuracy: 0.9281 - val_loss: 0.1924 - val_accuracy: 0.9281
# Epoch 107/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2233 - accuracy: 0.9242 - val_loss: 0.1908 - val_accuracy: 0.9281
# Epoch 108/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2183 - accuracy: 0.9258 - val_loss: 0.1951 - val_accuracy: 0.9406
# Epoch 109/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2341 - accuracy: 0.9219 - val_loss: 0.1943 - val_accuracy: 0.9266
# Epoch 110/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2189 - accuracy: 0.9289 - val_loss: 0.1863 - val_accuracy: 0.9344
# Epoch 111/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2175 - accuracy: 0.9301 - val_loss: 0.1863 - val_accuracy: 0.9375
# Epoch 112/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2128 - accuracy: 0.9312 - val_loss: 0.1873 - val_accuracy: 0.9328
# Epoch 113/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2129 - accuracy: 0.9289 - val_loss: 0.1877 - val_accuracy: 0.9219
# Epoch 114/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2066 - accuracy: 0.9328 - val_loss: 0.1867 - val_accuracy: 0.9438
# Epoch 115/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2171 - accuracy: 0.9301 - val_loss: 0.1832 - val_accuracy: 0.9297
# Epoch 116/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2183 - accuracy: 0.9336 - val_loss: 0.1827 - val_accuracy: 0.9328
# Epoch 117/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2062 - accuracy: 0.9305 - val_loss: 0.1818 - val_accuracy: 0.9406
# Epoch 118/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2075 - accuracy: 0.9273 - val_loss: 0.1835 - val_accuracy: 0.9391
# Epoch 119/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2121 - accuracy: 0.9293 - val_loss: 0.1818 - val_accuracy: 0.9266
# Epoch 120/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2042 - accuracy: 0.9324 - val_loss: 0.1828 - val_accuracy: 0.9250
# Epoch 121/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2132 - accuracy: 0.9297 - val_loss: 0.1831 - val_accuracy: 0.9359
# Epoch 122/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2027 - accuracy: 0.9301 - val_loss: 0.1811 - val_accuracy: 0.9484
# Epoch 123/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2097 - accuracy: 0.9344 - val_loss: 0.1765 - val_accuracy: 0.9328
# Epoch 124/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2117 - accuracy: 0.9270 - val_loss: 0.1763 - val_accuracy: 0.9375
# Epoch 125/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2010 - accuracy: 0.9340 - val_loss: 0.1779 - val_accuracy: 0.9438
# Epoch 126/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2035 - accuracy: 0.9332 - val_loss: 0.1755 - val_accuracy: 0.9375
# Epoch 127/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2114 - accuracy: 0.9277 - val_loss: 0.1757 - val_accuracy: 0.9328
# Epoch 128/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2082 - accuracy: 0.9277 - val_loss: 0.1794 - val_accuracy: 0.9469
# Epoch 129/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2035 - accuracy: 0.9348 - val_loss: 0.1775 - val_accuracy: 0.9266
# Epoch 130/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2050 - accuracy: 0.9289 - val_loss: 0.1756 - val_accuracy: 0.9484
# Epoch 131/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2043 - accuracy: 0.9297 - val_loss: 0.1743 - val_accuracy: 0.9406
# Epoch 132/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2072 - accuracy: 0.9320 - val_loss: 0.1750 - val_accuracy: 0.9312
# Epoch 133/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1966 - accuracy: 0.9328 - val_loss: 0.1728 - val_accuracy: 0.9422
# Epoch 134/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2060 - accuracy: 0.9324 - val_loss: 0.1715 - val_accuracy: 0.9516
# Epoch 135/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1940 - accuracy: 0.9336 - val_loss: 0.1718 - val_accuracy: 0.9438
# Epoch 136/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1924 - accuracy: 0.9402 - val_loss: 0.1667 - val_accuracy: 0.9422
# Epoch 137/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1997 - accuracy: 0.9359 - val_loss: 0.1696 - val_accuracy: 0.9453
# Epoch 138/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1947 - accuracy: 0.9352 - val_loss: 0.1715 - val_accuracy: 0.9422
# Epoch 139/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1923 - accuracy: 0.9398 - val_loss: 0.1682 - val_accuracy: 0.9438
# Epoch 140/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1880 - accuracy: 0.9336 - val_loss: 0.1711 - val_accuracy: 0.9453
# Epoch 141/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1972 - accuracy: 0.9383 - val_loss: 0.1690 - val_accuracy: 0.9328
# Epoch 142/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1949 - accuracy: 0.9371 - val_loss: 0.1742 - val_accuracy: 0.9500
# Epoch 143/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1962 - accuracy: 0.9320 - val_loss: 0.1662 - val_accuracy: 0.9422
# Epoch 144/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1972 - accuracy: 0.9371 - val_loss: 0.1665 - val_accuracy: 0.9375
# Epoch 145/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1969 - accuracy: 0.9367 - val_loss: 0.1673 - val_accuracy: 0.9516
# Epoch 146/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1918 - accuracy: 0.9336 - val_loss: 0.1656 - val_accuracy: 0.9422
# Epoch 147/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1858 - accuracy: 0.9375 - val_loss: 0.1624 - val_accuracy: 0.9406
# Epoch 148/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1979 - accuracy: 0.9301 - val_loss: 0.1647 - val_accuracy: 0.9453
# Epoch 149/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1891 - accuracy: 0.9340 - val_loss: 0.1626 - val_accuracy: 0.9406
# Epoch 150/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1856 - accuracy: 0.9371 - val_loss: 0.1607 - val_accuracy: 0.9484
# Epoch 151/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1825 - accuracy: 0.9352 - val_loss: 0.1584 - val_accuracy: 0.9438
# Epoch 152/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1843 - accuracy: 0.9402 - val_loss: 0.1572 - val_accuracy: 0.9453
# Epoch 153/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1858 - accuracy: 0.9371 - val_loss: 0.1636 - val_accuracy: 0.9422
# Epoch 154/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1601 - val_accuracy: 0.9453
# Epoch 155/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1838 - accuracy: 0.9410 - val_loss: 0.1588 - val_accuracy: 0.9391
# Epoch 156/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1782 - accuracy: 0.9418 - val_loss: 0.1590 - val_accuracy: 0.9484
# Epoch 157/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1850 - accuracy: 0.9406 - val_loss: 0.1566 - val_accuracy: 0.9438
# Epoch 158/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1765 - accuracy: 0.9414 - val_loss: 0.1615 - val_accuracy: 0.9469
# Epoch 159/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1841 - accuracy: 0.9383 - val_loss: 0.1554 - val_accuracy: 0.9359
# Epoch 160/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1799 - accuracy: 0.9406 - val_loss: 0.1546 - val_accuracy: 0.9422
# Epoch 161/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1834 - accuracy: 0.9379 - val_loss: 0.1579 - val_accuracy: 0.9438
# Epoch 162/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1826 - accuracy: 0.9406 - val_loss: 0.1549 - val_accuracy: 0.9406
# Epoch 163/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1821 - accuracy: 0.9375 - val_loss: 0.1533 - val_accuracy: 0.9516
# Epoch 164/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1785 - accuracy: 0.9387 - val_loss: 0.1536 - val_accuracy: 0.9422
# Epoch 165/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1834 - accuracy: 0.9355 - val_loss: 0.1589 - val_accuracy: 0.9469
# Epoch 166/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1787 - accuracy: 0.9414 - val_loss: 0.1508 - val_accuracy: 0.9438
# Epoch 167/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1773 - accuracy: 0.9391 - val_loss: 0.1541 - val_accuracy: 0.9391
# Epoch 168/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1813 - accuracy: 0.9375 - val_loss: 0.1540 - val_accuracy: 0.9406
# Epoch 169/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1734 - accuracy: 0.9418 - val_loss: 0.1508 - val_accuracy: 0.9422
# Epoch 170/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1747 - accuracy: 0.9418 - val_loss: 0.1507 - val_accuracy: 0.9438
# Epoch 171/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1700 - accuracy: 0.9398 - val_loss: 0.1490 - val_accuracy: 0.9406
# Epoch 172/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1703 - accuracy: 0.9422 - val_loss: 0.1457 - val_accuracy: 0.9438
# Epoch 173/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1810 - accuracy: 0.9367 - val_loss: 0.1595 - val_accuracy: 0.9438
# Epoch 174/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1779 - accuracy: 0.9406 - val_loss: 0.1541 - val_accuracy: 0.9422
# Epoch 175/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1733 - accuracy: 0.9391 - val_loss: 0.1498 - val_accuracy: 0.9500
# Epoch 176/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1743 - accuracy: 0.9445 - val_loss: 0.1526 - val_accuracy: 0.9391
# Epoch 177/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1730 - accuracy: 0.9395 - val_loss: 0.1529 - val_accuracy: 0.9469
# Epoch 178/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1755 - accuracy: 0.9398 - val_loss: 0.1509 - val_accuracy: 0.9391
# Epoch 179/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1755 - accuracy: 0.9391 - val_loss: 0.1475 - val_accuracy: 0.9453
# Epoch 180/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1835 - accuracy: 0.9371 - val_loss: 0.1602 - val_accuracy: 0.9484
# Epoch 181/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1722 - accuracy: 0.9371 - val_loss: 0.1518 - val_accuracy: 0.9391
# Epoch 182/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1686 - accuracy: 0.9457 - val_loss: 0.1500 - val_accuracy: 0.9391
# Epoch 183/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1680 - accuracy: 0.9434 - val_loss: 0.1464 - val_accuracy: 0.9453
# Epoch 184/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1649 - accuracy: 0.9469 - val_loss: 0.1437 - val_accuracy: 0.9453
# Epoch 185/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1630 - accuracy: 0.9441 - val_loss: 0.1425 - val_accuracy: 0.9500
# Epoch 186/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1683 - accuracy: 0.9465 - val_loss: 0.1388 - val_accuracy: 0.9484
# Epoch 187/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1693 - accuracy: 0.9418 - val_loss: 0.1406 - val_accuracy: 0.9484
# Epoch 188/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1691 - accuracy: 0.9426 - val_loss: 0.1418 - val_accuracy: 0.9438
# Epoch 189/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1665 - accuracy: 0.9438 - val_loss: 0.1408 - val_accuracy: 0.9438
# Epoch 190/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1675 - accuracy: 0.9438 - val_loss: 0.1450 - val_accuracy: 0.9484
# Epoch 191/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1623 - accuracy: 0.9484 - val_loss: 0.1426 - val_accuracy: 0.9438
# Epoch 192/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1651 - accuracy: 0.9457 - val_loss: 0.1402 - val_accuracy: 0.9484
# Epoch 193/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1578 - accuracy: 0.9477 - val_loss: 0.1423 - val_accuracy: 0.9453
# Epoch 194/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1631 - accuracy: 0.9469 - val_loss: 0.1440 - val_accuracy: 0.9422
# Epoch 195/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1665 - accuracy: 0.9457 - val_loss: 0.1394 - val_accuracy: 0.9453
# Epoch 196/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1663 - accuracy: 0.9430 - val_loss: 0.1454 - val_accuracy: 0.9500
# Epoch 197/200
# 5/5 [==============================] - 3s 580ms/step - loss: 0.1606 - accuracy: 0.9426 - val_loss: 0.1423 - val_accuracy: 0.9422
# Epoch 198/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1604 - accuracy: 0.9473 - val_loss: 0.1381 - val_accuracy: 0.9500
# Epoch 199/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1554 - accuracy: 0.9508 - val_loss: 0.1375 - val_accuracy: 0.9531
# Epoch 200/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1669 - accuracy: 0.9445 - val_loss: 0.1390 - val_accuracy: 0.9406

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 141ms/step - loss: 2.0368 - accuracy: 0.3184 - val_loss: 1.7604 - val_accuracy: 0.3828
# Epoch 2/50
# 5/5 [==============================] - 0s 43ms/step - loss: 1.6610 - accuracy: 0.4254 - val_loss: 1.5070 - val_accuracy: 0.4938
# Epoch 3/50
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4442 - accuracy: 0.5473 - val_loss: 1.2791 - val_accuracy: 0.6625
# Epoch 4/50
# 5/5 [==============================] - 0s 36ms/step - loss: 1.2458 - accuracy: 0.6625 - val_loss: 1.0915 - val_accuracy: 0.6609
# Epoch 5/50
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0761 - accuracy: 0.6746 - val_loss: 0.9387 - val_accuracy: 0.7281
# Epoch 6/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9488 - accuracy: 0.7121 - val_loss: 0.8388 - val_accuracy: 0.7563
# Epoch 7/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.8577 - accuracy: 0.7152 - val_loss: 0.7668 - val_accuracy: 0.7609
# Epoch 8/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.8015 - accuracy: 0.7480 - val_loss: 0.7146 - val_accuracy: 0.7969
# Epoch 9/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7623 - accuracy: 0.7594 - val_loss: 0.6717 - val_accuracy: 0.8047
# Epoch 10/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7174 - accuracy: 0.7852 - val_loss: 0.6430 - val_accuracy: 0.8125
# Epoch 11/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6881 - accuracy: 0.7965 - val_loss: 0.6105 - val_accuracy: 0.8172
# Epoch 12/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6617 - accuracy: 0.7965 - val_loss: 0.5965 - val_accuracy: 0.8281
# Epoch 13/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6401 - accuracy: 0.8035 - val_loss: 0.5610 - val_accuracy: 0.8297
# Epoch 14/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6153 - accuracy: 0.8168 - val_loss: 0.5415 - val_accuracy: 0.8344
# Epoch 15/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.5917 - accuracy: 0.8156 - val_loss: 0.5249 - val_accuracy: 0.8375
# Epoch 16/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5715 - accuracy: 0.8297 - val_loss: 0.5042 - val_accuracy: 0.8594
# Epoch 17/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5484 - accuracy: 0.8340 - val_loss: 0.4890 - val_accuracy: 0.8719
# Epoch 18/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5287 - accuracy: 0.8434 - val_loss: 0.4768 - val_accuracy: 0.8359
# Epoch 19/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5241 - accuracy: 0.8406 - val_loss: 0.4568 - val_accuracy: 0.8734
# Epoch 20/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4960 - accuracy: 0.8488 - val_loss: 0.4553 - val_accuracy: 0.8359
# Epoch 21/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4911 - accuracy: 0.8430 - val_loss: 0.4326 - val_accuracy: 0.8781
# Epoch 22/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4815 - accuracy: 0.8484 - val_loss: 0.4193 - val_accuracy: 0.8891
# Epoch 23/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4685 - accuracy: 0.8656 - val_loss: 0.4164 - val_accuracy: 0.8484
# Epoch 24/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4551 - accuracy: 0.8543 - val_loss: 0.4037 - val_accuracy: 0.8797
# Epoch 25/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4422 - accuracy: 0.8602 - val_loss: 0.3902 - val_accuracy: 0.8938
# Epoch 26/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4304 - accuracy: 0.8746 - val_loss: 0.3843 - val_accuracy: 0.8906
# Epoch 27/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4293 - accuracy: 0.8680 - val_loss: 0.3770 - val_accuracy: 0.8922
# Epoch 28/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4193 - accuracy: 0.8750 - val_loss: 0.3717 - val_accuracy: 0.8938
# Epoch 29/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4155 - accuracy: 0.8723 - val_loss: 0.3616 - val_accuracy: 0.8969
# Epoch 30/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4017 - accuracy: 0.8762 - val_loss: 0.3528 - val_accuracy: 0.9031
# Epoch 31/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4010 - accuracy: 0.8742 - val_loss: 0.3482 - val_accuracy: 0.8953
# Epoch 32/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3964 - accuracy: 0.8750 - val_loss: 0.3411 - val_accuracy: 0.9016
# Epoch 33/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3935 - accuracy: 0.8793 - val_loss: 0.3376 - val_accuracy: 0.9016
# Epoch 34/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3877 - accuracy: 0.8781 - val_loss: 0.3412 - val_accuracy: 0.8953
# Epoch 35/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3792 - accuracy: 0.8934 - val_loss: 0.3285 - val_accuracy: 0.9031
# Epoch 36/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3704 - accuracy: 0.8832 - val_loss: 0.3276 - val_accuracy: 0.8953
# Epoch 37/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3794 - accuracy: 0.8836 - val_loss: 0.3220 - val_accuracy: 0.9062
# Epoch 38/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3668 - accuracy: 0.8816 - val_loss: 0.3142 - val_accuracy: 0.9047
# Epoch 39/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3537 - accuracy: 0.8965 - val_loss: 0.3098 - val_accuracy: 0.9094
# Epoch 40/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3577 - accuracy: 0.8867 - val_loss: 0.3128 - val_accuracy: 0.9047
# Epoch 41/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3461 - accuracy: 0.8949 - val_loss: 0.3045 - val_accuracy: 0.9047
# Epoch 42/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3368 - accuracy: 0.8926 - val_loss: 0.2963 - val_accuracy: 0.9141
# Epoch 43/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3365 - accuracy: 0.8973 - val_loss: 0.2913 - val_accuracy: 0.9094
# Epoch 44/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3380 - accuracy: 0.9016 - val_loss: 0.2916 - val_accuracy: 0.9094
# Epoch 45/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3379 - accuracy: 0.8926 - val_loss: 0.2953 - val_accuracy: 0.9078
# Epoch 46/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3382 - accuracy: 0.8953 - val_loss: 0.2818 - val_accuracy: 0.9172
# Epoch 47/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3187 - accuracy: 0.8984 - val_loss: 0.2791 - val_accuracy: 0.9141
# Epoch 48/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3181 - accuracy: 0.9004 - val_loss: 0.2870 - val_accuracy: 0.9125
# Epoch 49/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3294 - accuracy: 0.9020 - val_loss: 0.2706 - val_accuracy: 0.9172
# Epoch 50/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3085 - accuracy: 0.9055 - val_loss: 0.2667 - val_accuracy: 0.9156

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2691 - accuracy: 0.9137
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.9156
# 0.9136718511581421 0.9156249761581421

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 53, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:03:15

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 199   5   0   0   0]
#  [  0   0   0   0   7  89   0   4   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   4   6   0  10   0]
#  [  0   0   0   0  16   3   0   0   1]]
#
# Accuracy Score
# 0.915625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.85      0.98      0.91       204
#     windows       0.86      0.89      0.88       100
#       roads       0.00      0.00      0.00         6
#        cars       0.71      0.50      0.59        20
#       metal       1.00      0.05      0.10        20
#
# avg / total       0.91      0.92      0.90       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 53)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 53)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 53) (80, 53)
# clouds  (400, 53) (100, 53)
# vegetation  (488, 53) (122, 53)
# built  (960, 53) (240, 53)
# windows  (400, 53) (100, 53)
# roads  (48, 53) (12, 53)
# cars  (44, 53) (11, 53)
# metal  (184, 53) (46, 53)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 53) (2844,) (2844, 2)
# (711, 53) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 85ms/step - loss: 1.8548 - accuracy: 0.3207 - val_loss: 1.5387 - val_accuracy: 0.3685
# Epoch 2/200
# 6/6 [==============================] - 0s 33ms/step - loss: 1.4483 - accuracy: 0.5327 - val_loss: 1.2669 - val_accuracy: 0.6357
# Epoch 3/200
# 6/6 [==============================] - 0s 55ms/step - loss: 1.2312 - accuracy: 0.6185 - val_loss: 1.0955 - val_accuracy: 0.6709
# Epoch 4/200
# 6/6 [==============================] - 0s 35ms/step - loss: 1.0770 - accuracy: 0.6326 - val_loss: 0.9499 - val_accuracy: 0.6920
# Epoch 5/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9484 - accuracy: 0.6748 - val_loss: 0.8841 - val_accuracy: 0.6864
# Epoch 6/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.8834 - accuracy: 0.6751 - val_loss: 0.8054 - val_accuracy: 0.7314
# Epoch 7/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8186 - accuracy: 0.6962 - val_loss: 0.7389 - val_accuracy: 0.7257
# Epoch 8/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.7679 - accuracy: 0.7043 - val_loss: 0.7127 - val_accuracy: 0.7060
# Epoch 9/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.7326 - accuracy: 0.7110 - val_loss: 0.6883 - val_accuracy: 0.7215
# Epoch 10/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.6998 - accuracy: 0.7300 - val_loss: 0.6598 - val_accuracy: 0.7496
# Epoch 11/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6978 - accuracy: 0.7173 - val_loss: 0.6369 - val_accuracy: 0.7609
# Epoch 12/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.6625 - accuracy: 0.7328 - val_loss: 0.6597 - val_accuracy: 0.6821
# Epoch 13/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.6515 - accuracy: 0.7335 - val_loss: 0.6107 - val_accuracy: 0.7665
# Epoch 14/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.6243 - accuracy: 0.7486 - val_loss: 0.6061 - val_accuracy: 0.7679
# Epoch 15/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.6143 - accuracy: 0.7598 - val_loss: 0.5910 - val_accuracy: 0.7482
# Epoch 16/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5897 - accuracy: 0.7634 - val_loss: 0.5772 - val_accuracy: 0.7975
# Epoch 17/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5835 - accuracy: 0.7665 - val_loss: 0.5688 - val_accuracy: 0.7806
# Epoch 18/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5711 - accuracy: 0.7676 - val_loss: 0.5570 - val_accuracy: 0.7961
# Epoch 19/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5529 - accuracy: 0.7732 - val_loss: 0.5539 - val_accuracy: 0.7750
# Epoch 20/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5570 - accuracy: 0.7700 - val_loss: 0.5476 - val_accuracy: 0.7989
# Epoch 21/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5314 - accuracy: 0.7887 - val_loss: 0.5381 - val_accuracy: 0.7806
# Epoch 22/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5329 - accuracy: 0.7922 - val_loss: 0.5283 - val_accuracy: 0.7947
# Epoch 23/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.5285 - accuracy: 0.7887 - val_loss: 0.5292 - val_accuracy: 0.8158
# Epoch 24/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.5117 - accuracy: 0.8024 - val_loss: 0.5355 - val_accuracy: 0.7848
# Epoch 25/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5317 - accuracy: 0.7855 - val_loss: 0.5146 - val_accuracy: 0.8270
# Epoch 26/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5129 - accuracy: 0.7936 - val_loss: 0.5154 - val_accuracy: 0.7848
# Epoch 27/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4918 - accuracy: 0.8115 - val_loss: 0.5034 - val_accuracy: 0.8059
# Epoch 28/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4864 - accuracy: 0.8034 - val_loss: 0.4963 - val_accuracy: 0.8242
# Epoch 29/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4948 - accuracy: 0.7999 - val_loss: 0.5007 - val_accuracy: 0.7961
# Epoch 30/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4828 - accuracy: 0.8063 - val_loss: 0.5045 - val_accuracy: 0.8073
# Epoch 31/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4718 - accuracy: 0.8108 - val_loss: 0.4811 - val_accuracy: 0.8270
# Epoch 32/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4605 - accuracy: 0.8249 - val_loss: 0.4822 - val_accuracy: 0.8143
# Epoch 33/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4502 - accuracy: 0.8200 - val_loss: 0.4757 - val_accuracy: 0.8340
# Epoch 34/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4591 - accuracy: 0.8291 - val_loss: 0.4717 - val_accuracy: 0.8172
# Epoch 35/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4580 - accuracy: 0.8295 - val_loss: 0.4751 - val_accuracy: 0.8172
# Epoch 36/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4611 - accuracy: 0.8203 - val_loss: 0.4809 - val_accuracy: 0.8129
# Epoch 37/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4591 - accuracy: 0.8168 - val_loss: 0.4628 - val_accuracy: 0.8228
# Epoch 38/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4460 - accuracy: 0.8319 - val_loss: 0.4589 - val_accuracy: 0.8383
# Epoch 39/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4374 - accuracy: 0.8186 - val_loss: 0.4623 - val_accuracy: 0.8270
# Epoch 40/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4396 - accuracy: 0.8270 - val_loss: 0.4494 - val_accuracy: 0.8397
# Epoch 41/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4346 - accuracy: 0.8323 - val_loss: 0.4656 - val_accuracy: 0.8045
# Epoch 42/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4392 - accuracy: 0.8259 - val_loss: 0.4469 - val_accuracy: 0.8594
# Epoch 43/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4297 - accuracy: 0.8351 - val_loss: 0.4497 - val_accuracy: 0.8228
# Epoch 44/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4239 - accuracy: 0.8340 - val_loss: 0.4510 - val_accuracy: 0.8340
# Epoch 45/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4328 - accuracy: 0.8274 - val_loss: 0.4366 - val_accuracy: 0.8368
# Epoch 46/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4229 - accuracy: 0.8463 - val_loss: 0.4401 - val_accuracy: 0.8368
# Epoch 47/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4139 - accuracy: 0.8379 - val_loss: 0.4368 - val_accuracy: 0.8594
# Epoch 48/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4204 - accuracy: 0.8414 - val_loss: 0.4343 - val_accuracy: 0.8509
# Epoch 49/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4148 - accuracy: 0.8428 - val_loss: 0.4252 - val_accuracy: 0.8579
# Epoch 50/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4110 - accuracy: 0.8435 - val_loss: 0.4297 - val_accuracy: 0.8453
# Epoch 51/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4117 - accuracy: 0.8407 - val_loss: 0.4255 - val_accuracy: 0.8453
# Epoch 52/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4018 - accuracy: 0.8449 - val_loss: 0.4288 - val_accuracy: 0.8467
# Epoch 53/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3980 - accuracy: 0.8513 - val_loss: 0.4161 - val_accuracy: 0.8537
# Epoch 54/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3932 - accuracy: 0.8495 - val_loss: 0.4179 - val_accuracy: 0.8495
# Epoch 55/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3836 - accuracy: 0.8572 - val_loss: 0.4161 - val_accuracy: 0.8453
# Epoch 56/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3956 - accuracy: 0.8460 - val_loss: 0.4203 - val_accuracy: 0.8622
# Epoch 57/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3868 - accuracy: 0.8562 - val_loss: 0.4056 - val_accuracy: 0.8509
# Epoch 58/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3875 - accuracy: 0.8643 - val_loss: 0.4166 - val_accuracy: 0.8495
# Epoch 59/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3946 - accuracy: 0.8555 - val_loss: 0.4024 - val_accuracy: 0.8622
# Epoch 60/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3817 - accuracy: 0.8639 - val_loss: 0.4052 - val_accuracy: 0.8523
# Epoch 61/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3801 - accuracy: 0.8565 - val_loss: 0.4108 - val_accuracy: 0.8453
# Epoch 62/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3738 - accuracy: 0.8611 - val_loss: 0.4037 - val_accuracy: 0.8608
# Epoch 63/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3819 - accuracy: 0.8541 - val_loss: 0.4029 - val_accuracy: 0.8664
# Epoch 64/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3832 - accuracy: 0.8506 - val_loss: 0.4148 - val_accuracy: 0.8453
# Epoch 65/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3753 - accuracy: 0.8544 - val_loss: 0.3896 - val_accuracy: 0.8650
# Epoch 66/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3599 - accuracy: 0.8643 - val_loss: 0.3950 - val_accuracy: 0.8664
# Epoch 67/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3661 - accuracy: 0.8622 - val_loss: 0.3921 - val_accuracy: 0.8734
# Epoch 68/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3724 - accuracy: 0.8558 - val_loss: 0.3927 - val_accuracy: 0.8706
# Epoch 69/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3635 - accuracy: 0.8601 - val_loss: 0.3904 - val_accuracy: 0.8650
# Epoch 70/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3702 - accuracy: 0.8604 - val_loss: 0.3834 - val_accuracy: 0.8706
# Epoch 71/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3674 - accuracy: 0.8643 - val_loss: 0.3889 - val_accuracy: 0.8608
# Epoch 72/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3562 - accuracy: 0.8646 - val_loss: 0.4024 - val_accuracy: 0.8537
# Epoch 73/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3650 - accuracy: 0.8604 - val_loss: 0.3824 - val_accuracy: 0.8678
# Epoch 74/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3566 - accuracy: 0.8650 - val_loss: 0.3821 - val_accuracy: 0.8692
# Epoch 75/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3527 - accuracy: 0.8734 - val_loss: 0.3744 - val_accuracy: 0.8734
# Epoch 76/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3549 - accuracy: 0.8639 - val_loss: 0.3759 - val_accuracy: 0.8706
# Epoch 77/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3418 - accuracy: 0.8748 - val_loss: 0.3774 - val_accuracy: 0.8636
# Epoch 78/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3514 - accuracy: 0.8650 - val_loss: 0.3708 - val_accuracy: 0.8650
# Epoch 79/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3480 - accuracy: 0.8724 - val_loss: 0.3712 - val_accuracy: 0.8720
# Epoch 80/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3490 - accuracy: 0.8681 - val_loss: 0.3888 - val_accuracy: 0.8692
# Epoch 81/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3607 - accuracy: 0.8632 - val_loss: 0.3726 - val_accuracy: 0.8776
# Epoch 82/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3421 - accuracy: 0.8755 - val_loss: 0.3782 - val_accuracy: 0.8650
# Epoch 83/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3443 - accuracy: 0.8731 - val_loss: 0.3710 - val_accuracy: 0.8636
# Epoch 84/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3440 - accuracy: 0.8713 - val_loss: 0.3778 - val_accuracy: 0.8650
# Epoch 85/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3497 - accuracy: 0.8660 - val_loss: 0.3842 - val_accuracy: 0.8706
# Epoch 86/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3443 - accuracy: 0.8692 - val_loss: 0.3697 - val_accuracy: 0.8706
# Epoch 87/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3403 - accuracy: 0.8745 - val_loss: 0.3725 - val_accuracy: 0.8664
# Epoch 88/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3379 - accuracy: 0.8734 - val_loss: 0.3653 - val_accuracy: 0.8776
# Epoch 89/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3340 - accuracy: 0.8801 - val_loss: 0.3647 - val_accuracy: 0.8776
# Epoch 90/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3363 - accuracy: 0.8783 - val_loss: 0.3596 - val_accuracy: 0.8833
# Epoch 91/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3320 - accuracy: 0.8734 - val_loss: 0.3552 - val_accuracy: 0.8776
# Epoch 92/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3293 - accuracy: 0.8819 - val_loss: 0.3553 - val_accuracy: 0.8790
# Epoch 93/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3246 - accuracy: 0.8815 - val_loss: 0.3567 - val_accuracy: 0.8776
# Epoch 94/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3284 - accuracy: 0.8801 - val_loss: 0.3483 - val_accuracy: 0.8805
# Epoch 95/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3225 - accuracy: 0.8861 - val_loss: 0.3519 - val_accuracy: 0.8805
# Epoch 96/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3183 - accuracy: 0.8843 - val_loss: 0.3532 - val_accuracy: 0.8776
# Epoch 97/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3222 - accuracy: 0.8815 - val_loss: 0.3536 - val_accuracy: 0.8833
# Epoch 98/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3160 - accuracy: 0.8833 - val_loss: 0.3512 - val_accuracy: 0.8805
# Epoch 99/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3220 - accuracy: 0.8843 - val_loss: 0.3557 - val_accuracy: 0.8734
# Epoch 100/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3330 - accuracy: 0.8724 - val_loss: 0.3650 - val_accuracy: 0.8650
# Epoch 101/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3285 - accuracy: 0.8734 - val_loss: 0.3494 - val_accuracy: 0.8790
# Epoch 102/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3134 - accuracy: 0.8794 - val_loss: 0.3638 - val_accuracy: 0.8664
# Epoch 103/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3147 - accuracy: 0.8794 - val_loss: 0.3427 - val_accuracy: 0.8847
# Epoch 104/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3131 - accuracy: 0.8826 - val_loss: 0.3588 - val_accuracy: 0.8720
# Epoch 105/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3177 - accuracy: 0.8812 - val_loss: 0.3401 - val_accuracy: 0.8847
# Epoch 106/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3020 - accuracy: 0.8836 - val_loss: 0.3421 - val_accuracy: 0.8889
# Epoch 107/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3104 - accuracy: 0.8892 - val_loss: 0.3434 - val_accuracy: 0.8734
# Epoch 108/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3087 - accuracy: 0.8914 - val_loss: 0.3443 - val_accuracy: 0.8847
# Epoch 109/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3130 - accuracy: 0.8854 - val_loss: 0.3329 - val_accuracy: 0.8917
# Epoch 110/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3037 - accuracy: 0.8878 - val_loss: 0.3329 - val_accuracy: 0.8875
# Epoch 111/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3007 - accuracy: 0.8875 - val_loss: 0.3344 - val_accuracy: 0.8847
# Epoch 112/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3009 - accuracy: 0.8903 - val_loss: 0.3378 - val_accuracy: 0.8734
# Epoch 113/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3054 - accuracy: 0.8836 - val_loss: 0.3378 - val_accuracy: 0.8861
# Epoch 114/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3091 - accuracy: 0.8826 - val_loss: 0.3289 - val_accuracy: 0.8875
# Epoch 115/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2925 - accuracy: 0.8952 - val_loss: 0.3372 - val_accuracy: 0.8790
# Epoch 116/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3020 - accuracy: 0.8871 - val_loss: 0.3316 - val_accuracy: 0.8917
# Epoch 117/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2964 - accuracy: 0.8935 - val_loss: 0.3358 - val_accuracy: 0.8833
# Epoch 118/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3014 - accuracy: 0.8864 - val_loss: 0.3316 - val_accuracy: 0.8833
# Epoch 119/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3015 - accuracy: 0.8801 - val_loss: 0.3360 - val_accuracy: 0.8889
# Epoch 120/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2903 - accuracy: 0.8970 - val_loss: 0.3345 - val_accuracy: 0.8805
# Epoch 121/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2893 - accuracy: 0.8977 - val_loss: 0.3257 - val_accuracy: 0.8889
# Epoch 122/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2979 - accuracy: 0.8910 - val_loss: 0.3294 - val_accuracy: 0.8959
# Epoch 123/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2971 - accuracy: 0.8917 - val_loss: 0.3513 - val_accuracy: 0.8748
# Epoch 124/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2947 - accuracy: 0.8875 - val_loss: 0.3240 - val_accuracy: 0.8889
# Epoch 125/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2866 - accuracy: 0.9037 - val_loss: 0.3229 - val_accuracy: 0.8903
# Epoch 126/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2887 - accuracy: 0.8970 - val_loss: 0.3234 - val_accuracy: 0.8945
# Epoch 127/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2864 - accuracy: 0.8931 - val_loss: 0.3205 - val_accuracy: 0.8903
# Epoch 128/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2998 - accuracy: 0.8910 - val_loss: 0.3357 - val_accuracy: 0.8805
# Epoch 129/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2855 - accuracy: 0.8984 - val_loss: 0.3287 - val_accuracy: 0.8833
# Epoch 130/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2835 - accuracy: 0.8998 - val_loss: 0.3302 - val_accuracy: 0.8748
# Epoch 131/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2960 - accuracy: 0.8892 - val_loss: 0.3162 - val_accuracy: 0.8945
# Epoch 132/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2841 - accuracy: 0.8963 - val_loss: 0.3163 - val_accuracy: 0.8945
# Epoch 133/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2780 - accuracy: 0.8987 - val_loss: 0.3219 - val_accuracy: 0.8875
# Epoch 134/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2847 - accuracy: 0.8942 - val_loss: 0.3123 - val_accuracy: 0.8903
# Epoch 135/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2867 - accuracy: 0.8973 - val_loss: 0.3242 - val_accuracy: 0.8805
# Epoch 136/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2854 - accuracy: 0.8935 - val_loss: 0.3251 - val_accuracy: 0.8889
# Epoch 137/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2889 - accuracy: 0.8924 - val_loss: 0.3206 - val_accuracy: 0.8861
# Epoch 138/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2836 - accuracy: 0.8959 - val_loss: 0.3153 - val_accuracy: 0.8931
# Epoch 139/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2760 - accuracy: 0.9037 - val_loss: 0.3183 - val_accuracy: 0.8790
# Epoch 140/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2825 - accuracy: 0.8952 - val_loss: 0.3148 - val_accuracy: 0.8917
# Epoch 141/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2781 - accuracy: 0.8956 - val_loss: 0.3190 - val_accuracy: 0.8861
# Epoch 142/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2780 - accuracy: 0.8994 - val_loss: 0.3204 - val_accuracy: 0.8875
# Epoch 143/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2732 - accuracy: 0.9033 - val_loss: 0.3085 - val_accuracy: 0.8945
# Epoch 144/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2720 - accuracy: 0.8963 - val_loss: 0.3047 - val_accuracy: 0.8959
# Epoch 145/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2795 - accuracy: 0.9019 - val_loss: 0.3095 - val_accuracy: 0.8931
# Epoch 146/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2815 - accuracy: 0.8914 - val_loss: 0.3020 - val_accuracy: 0.8945
# Epoch 147/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2668 - accuracy: 0.9001 - val_loss: 0.3231 - val_accuracy: 0.8833
# Epoch 148/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2752 - accuracy: 0.8963 - val_loss: 0.3009 - val_accuracy: 0.8987
# Epoch 149/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2718 - accuracy: 0.8987 - val_loss: 0.3014 - val_accuracy: 0.8973
# Epoch 150/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2654 - accuracy: 0.8952 - val_loss: 0.3048 - val_accuracy: 0.9001
# Epoch 151/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2648 - accuracy: 0.9061 - val_loss: 0.3068 - val_accuracy: 0.9001
# Epoch 152/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2585 - accuracy: 0.9012 - val_loss: 0.3072 - val_accuracy: 0.8819
# Epoch 153/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2753 - accuracy: 0.8963 - val_loss: 0.3060 - val_accuracy: 0.8973
# Epoch 154/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2688 - accuracy: 0.9008 - val_loss: 0.3044 - val_accuracy: 0.8931
# Epoch 155/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2661 - accuracy: 0.9047 - val_loss: 0.3028 - val_accuracy: 0.8973
# Epoch 156/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2676 - accuracy: 0.8994 - val_loss: 0.3031 - val_accuracy: 0.8959
# Epoch 157/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2543 - accuracy: 0.9124 - val_loss: 0.3044 - val_accuracy: 0.8973
# Epoch 158/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2582 - accuracy: 0.9072 - val_loss: 0.2943 - val_accuracy: 0.8917
# Epoch 159/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2606 - accuracy: 0.9012 - val_loss: 0.2977 - val_accuracy: 0.9030
# Epoch 160/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2644 - accuracy: 0.9040 - val_loss: 0.3133 - val_accuracy: 0.8805
# Epoch 161/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2732 - accuracy: 0.8991 - val_loss: 0.3150 - val_accuracy: 0.8833
# Epoch 162/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2789 - accuracy: 0.8966 - val_loss: 0.3197 - val_accuracy: 0.8903
# Epoch 163/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2671 - accuracy: 0.9012 - val_loss: 0.2958 - val_accuracy: 0.8931
# Epoch 164/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2578 - accuracy: 0.9075 - val_loss: 0.2980 - val_accuracy: 0.9001
# Epoch 165/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2479 - accuracy: 0.9110 - val_loss: 0.2907 - val_accuracy: 0.9001
# Epoch 166/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2572 - accuracy: 0.9079 - val_loss: 0.3000 - val_accuracy: 0.8973
# Epoch 167/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2614 - accuracy: 0.9051 - val_loss: 0.2926 - val_accuracy: 0.9015
# Epoch 168/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2547 - accuracy: 0.9061 - val_loss: 0.3006 - val_accuracy: 0.8917
# Epoch 169/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2603 - accuracy: 0.9061 - val_loss: 0.2941 - val_accuracy: 0.9058
# Epoch 170/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2607 - accuracy: 0.9089 - val_loss: 0.2856 - val_accuracy: 0.9058
# Epoch 171/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2463 - accuracy: 0.9124 - val_loss: 0.2934 - val_accuracy: 0.9001
# Epoch 172/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2524 - accuracy: 0.9072 - val_loss: 0.2818 - val_accuracy: 0.9072
# Epoch 173/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2523 - accuracy: 0.9089 - val_loss: 0.3005 - val_accuracy: 0.8931
# Epoch 174/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2544 - accuracy: 0.9142 - val_loss: 0.2872 - val_accuracy: 0.9058
# Epoch 175/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2500 - accuracy: 0.9079 - val_loss: 0.2924 - val_accuracy: 0.8917
# Epoch 176/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2483 - accuracy: 0.9082 - val_loss: 0.2887 - val_accuracy: 0.9058
# Epoch 177/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2485 - accuracy: 0.9132 - val_loss: 0.2863 - val_accuracy: 0.9044
# Epoch 178/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2495 - accuracy: 0.9117 - val_loss: 0.2797 - val_accuracy: 0.9015
# Epoch 179/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2460 - accuracy: 0.9121 - val_loss: 0.2931 - val_accuracy: 0.8903
# Epoch 180/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2331 - accuracy: 0.9139 - val_loss: 0.2801 - val_accuracy: 0.9086
# Epoch 181/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2426 - accuracy: 0.9093 - val_loss: 0.2942 - val_accuracy: 0.9015
# Epoch 182/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2458 - accuracy: 0.9117 - val_loss: 0.2880 - val_accuracy: 0.9072
# Epoch 183/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2396 - accuracy: 0.9114 - val_loss: 0.2830 - val_accuracy: 0.9030
# Epoch 184/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2401 - accuracy: 0.9142 - val_loss: 0.2803 - val_accuracy: 0.9058
# Epoch 185/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2294 - accuracy: 0.9202 - val_loss: 0.2807 - val_accuracy: 0.9001
# Epoch 186/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2394 - accuracy: 0.9103 - val_loss: 0.2757 - val_accuracy: 0.9100
# Epoch 187/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2309 - accuracy: 0.9216 - val_loss: 0.2740 - val_accuracy: 0.9086
# Epoch 188/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2386 - accuracy: 0.9128 - val_loss: 0.2818 - val_accuracy: 0.9058
# Epoch 189/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2389 - accuracy: 0.9153 - val_loss: 0.2751 - val_accuracy: 0.9086
# Epoch 190/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2373 - accuracy: 0.9188 - val_loss: 0.2815 - val_accuracy: 0.9015
# Epoch 191/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2416 - accuracy: 0.9146 - val_loss: 0.2812 - val_accuracy: 0.9100
# Epoch 192/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2379 - accuracy: 0.9124 - val_loss: 0.2741 - val_accuracy: 0.9100
# Epoch 193/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2385 - accuracy: 0.9075 - val_loss: 0.2875 - val_accuracy: 0.8875
# Epoch 194/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2480 - accuracy: 0.9044 - val_loss: 0.2742 - val_accuracy: 0.9114
# Epoch 195/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2325 - accuracy: 0.9184 - val_loss: 0.2721 - val_accuracy: 0.9100
# Epoch 196/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2370 - accuracy: 0.9191 - val_loss: 0.2735 - val_accuracy: 0.9072
# Epoch 197/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2338 - accuracy: 0.9117 - val_loss: 0.2755 - val_accuracy: 0.9058
# Epoch 198/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2321 - accuracy: 0.9153 - val_loss: 0.2725 - val_accuracy: 0.9100
# Epoch 199/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2256 - accuracy: 0.9205 - val_loss: 0.2737 - val_accuracy: 0.9100
# Epoch 200/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2248 - accuracy: 0.9233 - val_loss: 0.2705 - val_accuracy: 0.9086

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 1s 85ms/step - loss: 1.9374 - accuracy: 0.2838 - val_loss: 1.5947 - val_accuracy: 0.3629
# Epoch 2/40
# 6/6 [==============================] - 0s 36ms/step - loss: 1.5300 - accuracy: 0.4736 - val_loss: 1.3599 - val_accuracy: 0.6428
# Epoch 3/40
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3100 - accuracy: 0.6132 - val_loss: 1.1695 - val_accuracy: 0.6442
# Epoch 4/40
# 6/6 [==============================] - 0s 35ms/step - loss: 1.1341 - accuracy: 0.6385 - val_loss: 1.0133 - val_accuracy: 0.6723
# Epoch 5/40
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9996 - accuracy: 0.6572 - val_loss: 0.9140 - val_accuracy: 0.6892
# Epoch 6/40
# 6/6 [==============================] - 0s 32ms/step - loss: 0.8941 - accuracy: 0.6842 - val_loss: 0.8318 - val_accuracy: 0.6906
# Epoch 7/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.8242 - accuracy: 0.6902 - val_loss: 0.7621 - val_accuracy: 0.7370
# Epoch 8/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.7794 - accuracy: 0.7018 - val_loss: 0.7124 - val_accuracy: 0.7412
# Epoch 9/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.7271 - accuracy: 0.7205 - val_loss: 0.6869 - val_accuracy: 0.7496
# Epoch 10/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.6950 - accuracy: 0.7331 - val_loss: 0.6633 - val_accuracy: 0.7412
# Epoch 11/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6723 - accuracy: 0.7321 - val_loss: 0.6353 - val_accuracy: 0.7511
# Epoch 12/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6553 - accuracy: 0.7437 - val_loss: 0.6164 - val_accuracy: 0.7623
# Epoch 13/40
# 6/6 [==============================] - 0s 32ms/step - loss: 0.6373 - accuracy: 0.7468 - val_loss: 0.6116 - val_accuracy: 0.7750
# Epoch 14/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.6347 - accuracy: 0.7461 - val_loss: 0.6052 - val_accuracy: 0.7637
# Epoch 15/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6083 - accuracy: 0.7454 - val_loss: 0.5904 - val_accuracy: 0.7806
# Epoch 16/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5936 - accuracy: 0.7676 - val_loss: 0.6014 - val_accuracy: 0.7595
# Epoch 17/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5951 - accuracy: 0.7676 - val_loss: 0.5806 - val_accuracy: 0.7679
# Epoch 18/40
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5871 - accuracy: 0.7598 - val_loss: 0.5681 - val_accuracy: 0.7778
# Epoch 19/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5725 - accuracy: 0.7729 - val_loss: 0.5565 - val_accuracy: 0.7862
# Epoch 20/40
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5570 - accuracy: 0.7802 - val_loss: 0.5542 - val_accuracy: 0.7707
# Epoch 21/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5461 - accuracy: 0.7806 - val_loss: 0.5532 - val_accuracy: 0.7961
# Epoch 22/40
# 6/6 [==============================] - 1s 109ms/step - loss: 0.5446 - accuracy: 0.7809 - val_loss: 0.5426 - val_accuracy: 0.7834
# Epoch 23/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5416 - accuracy: 0.7809 - val_loss: 0.5295 - val_accuracy: 0.7904
# Epoch 24/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5216 - accuracy: 0.7936 - val_loss: 0.5256 - val_accuracy: 0.7918
# Epoch 25/40
# 6/6 [==============================] - 0s 41ms/step - loss: 0.5100 - accuracy: 0.8013 - val_loss: 0.5284 - val_accuracy: 0.7961
# Epoch 26/40
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5127 - accuracy: 0.7999 - val_loss: 0.5138 - val_accuracy: 0.7975
# Epoch 27/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5093 - accuracy: 0.8020 - val_loss: 0.5260 - val_accuracy: 0.7961
# Epoch 28/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5023 - accuracy: 0.7996 - val_loss: 0.5098 - val_accuracy: 0.8017
# Epoch 29/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4939 - accuracy: 0.8094 - val_loss: 0.5094 - val_accuracy: 0.7975
# Epoch 30/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4939 - accuracy: 0.8049 - val_loss: 0.5460 - val_accuracy: 0.7975
# Epoch 31/40
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5097 - accuracy: 0.7901 - val_loss: 0.5069 - val_accuracy: 0.7961
# Epoch 32/40
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4862 - accuracy: 0.8091 - val_loss: 0.4867 - val_accuracy: 0.8186
# Epoch 33/40
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4821 - accuracy: 0.8063 - val_loss: 0.5027 - val_accuracy: 0.8129
# Epoch 34/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4840 - accuracy: 0.8066 - val_loss: 0.4945 - val_accuracy: 0.8129
# Epoch 35/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4657 - accuracy: 0.8298 - val_loss: 0.4825 - val_accuracy: 0.8172
# Epoch 36/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4575 - accuracy: 0.8274 - val_loss: 0.4830 - val_accuracy: 0.8129
# Epoch 37/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4662 - accuracy: 0.8186 - val_loss: 0.4738 - val_accuracy: 0.8214
# Epoch 38/40
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4562 - accuracy: 0.8291 - val_loss: 0.4729 - val_accuracy: 0.8284
# Epoch 39/40
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4552 - accuracy: 0.8284 - val_loss: 0.4773 - val_accuracy: 0.8158
# Epoch 40/40
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4553 - accuracy: 0.8228 - val_loss: 0.4665 - val_accuracy: 0.8256

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 3ms/step - loss: 0.3920 - accuracy: 0.8664
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4665 - accuracy: 0.8256
# 0.8663854002952576 0.8255977630615234

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 53, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:03:17

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  94   0   6   0   0   0   0]
#  [  0   0 116   2   4   0   0   0]
#  [  0   0   0 231   8   0   0   1]
#  [  0   0   1  51  46   0   1   1]
#  [  0   0   0   0   1  10   1   0]
#  [  3   0   0   0   2   2   4   0]
#  [  0   0   0  36   4   0   0   6]]
#
# Accuracy Score
# 0.8255977496483825
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.96      1.00      0.98        80
#      clouds       1.00      0.94      0.97       100
#  vegetation       0.99      0.95      0.97       122
#       built       0.71      0.96      0.82       240
#     windows       0.71      0.46      0.56       100
#       roads       0.83      0.83      0.83        12
#        cars       0.67      0.36      0.47        11
#       metal       0.75      0.13      0.22        46
#
# avg / total       0.83      0.83      0.80       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 53
# [[0, 16], [16, 32], [32, 48], [48, 64], [64, 80], [80, 96], [96, 112], [112, 128], [128, 144], [144, 160], [160, 176], [176, 192], [192, 208], [208, 224], [224, 240], [240, 256], [256, 272], [272, 288], [288, 304], [304, 320], [320, 336], [336, 352], [352, 368], [368, 384], [384, 400], [400, 416], [416, 432], [432, 448], [448, 464], [464, 480], [480, 496], [496, 512], [512, 528], [528, 544], [544, 560], [560, 576], [576, 592], [592, 608], [608, 624], [624, 640], [640, 656], [656, 672], [672, 688], [688, 704], [704, 720], [720, 736], [736, 752], [752, 768], [768, 784], [784, 800], [800, 816], [816, 832], [832, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 53)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 53)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 53)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 53) (60, 53)
# clouds  (160, 53) (40, 53)
# vegetation  (560, 53) (140, 53)
# water  (496, 53) (124, 53)
# built  (1280, 53) (320, 53)
# windows  (480, 53) (120, 53)
# roads  (200, 53) (50, 53)
# cars  (200, 53) (50, 53)
# metal  (148, 53) (37, 53)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 53) (3764,) (3764, 2)
# (941, 53) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 70ms/step - loss: 1.8763 - accuracy: 0.3366 - val_loss: 1.6121 - val_accuracy: 0.4814
# Epoch 2/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.5762 - accuracy: 0.4880 - val_loss: 1.4103 - val_accuracy: 0.5452
# Epoch 3/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.4153 - accuracy: 0.5096 - val_loss: 1.3262 - val_accuracy: 0.5186
# Epoch 4/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3372 - accuracy: 0.5252 - val_loss: 1.2560 - val_accuracy: 0.6004
# Epoch 5/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2771 - accuracy: 0.5518 - val_loss: 1.1987 - val_accuracy: 0.6419
# Epoch 6/200
# 8/8 [==============================] - 0s 26ms/step - loss: 1.2203 - accuracy: 0.5784 - val_loss: 1.1416 - val_accuracy: 0.6344
# Epoch 7/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1813 - accuracy: 0.5933 - val_loss: 1.0887 - val_accuracy: 0.6419
# Epoch 8/200
# 8/8 [==============================] - 0s 30ms/step - loss: 1.1384 - accuracy: 0.6116 - val_loss: 1.0595 - val_accuracy: 0.7226
# Epoch 9/200
# 8/8 [==============================] - 0s 30ms/step - loss: 1.0930 - accuracy: 0.6384 - val_loss: 1.0118 - val_accuracy: 0.7301
# Epoch 10/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0524 - accuracy: 0.6602 - val_loss: 0.9770 - val_accuracy: 0.7237
# Epoch 11/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.0040 - accuracy: 0.6844 - val_loss: 0.9263 - val_accuracy: 0.7471
# Epoch 12/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.9777 - accuracy: 0.6862 - val_loss: 0.9024 - val_accuracy: 0.7258
# Epoch 13/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9420 - accuracy: 0.7016 - val_loss: 0.8658 - val_accuracy: 0.7365
# Epoch 14/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.9066 - accuracy: 0.7107 - val_loss: 0.8452 - val_accuracy: 0.7545
# Epoch 15/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8838 - accuracy: 0.7242 - val_loss: 0.8157 - val_accuracy: 0.7609
# Epoch 16/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8764 - accuracy: 0.7264 - val_loss: 0.7933 - val_accuracy: 0.7726
# Epoch 17/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8387 - accuracy: 0.7378 - val_loss: 0.7703 - val_accuracy: 0.7705
# Epoch 18/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8230 - accuracy: 0.7402 - val_loss: 0.7466 - val_accuracy: 0.7864
# Epoch 19/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8053 - accuracy: 0.7420 - val_loss: 0.7279 - val_accuracy: 0.8055
# Epoch 20/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.7859 - accuracy: 0.7500 - val_loss: 0.7261 - val_accuracy: 0.7694
# Epoch 21/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7642 - accuracy: 0.7604 - val_loss: 0.7011 - val_accuracy: 0.7811
# Epoch 22/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7475 - accuracy: 0.7713 - val_loss: 0.6874 - val_accuracy: 0.7906
# Epoch 23/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7457 - accuracy: 0.7736 - val_loss: 0.6856 - val_accuracy: 0.7991
# Epoch 24/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7321 - accuracy: 0.7718 - val_loss: 0.6759 - val_accuracy: 0.8289
# Epoch 25/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7083 - accuracy: 0.7835 - val_loss: 0.6547 - val_accuracy: 0.8172
# Epoch 26/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6900 - accuracy: 0.7949 - val_loss: 0.6358 - val_accuracy: 0.8353
# Epoch 27/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6793 - accuracy: 0.7949 - val_loss: 0.6364 - val_accuracy: 0.8321
# Epoch 28/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6719 - accuracy: 0.7920 - val_loss: 0.6169 - val_accuracy: 0.8332
# Epoch 29/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6581 - accuracy: 0.7965 - val_loss: 0.6153 - val_accuracy: 0.8363
# Epoch 30/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6534 - accuracy: 0.7989 - val_loss: 0.6188 - val_accuracy: 0.8087
# Epoch 31/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6511 - accuracy: 0.7917 - val_loss: 0.5961 - val_accuracy: 0.8363
# Epoch 32/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6374 - accuracy: 0.8047 - val_loss: 0.5843 - val_accuracy: 0.8459
# Epoch 33/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6189 - accuracy: 0.8119 - val_loss: 0.5830 - val_accuracy: 0.8427
# Epoch 34/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6159 - accuracy: 0.8100 - val_loss: 0.5746 - val_accuracy: 0.8544
# Epoch 35/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6077 - accuracy: 0.8124 - val_loss: 0.5700 - val_accuracy: 0.8448
# Epoch 36/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6062 - accuracy: 0.8170 - val_loss: 0.5664 - val_accuracy: 0.8512
# Epoch 37/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5953 - accuracy: 0.8228 - val_loss: 0.5520 - val_accuracy: 0.8502
# Epoch 38/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5899 - accuracy: 0.8156 - val_loss: 0.5575 - val_accuracy: 0.8470
# Epoch 39/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5887 - accuracy: 0.8177 - val_loss: 0.5463 - val_accuracy: 0.8459
# Epoch 40/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5718 - accuracy: 0.8257 - val_loss: 0.5428 - val_accuracy: 0.8544
# Epoch 41/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5803 - accuracy: 0.8159 - val_loss: 0.5377 - val_accuracy: 0.8438
# Epoch 42/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5858 - accuracy: 0.8209 - val_loss: 0.5475 - val_accuracy: 0.8268
# Epoch 43/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5693 - accuracy: 0.8207 - val_loss: 0.5395 - val_accuracy: 0.8470
# Epoch 44/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5577 - accuracy: 0.8294 - val_loss: 0.5315 - val_accuracy: 0.8533
# Epoch 45/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5579 - accuracy: 0.8276 - val_loss: 0.5203 - val_accuracy: 0.8576
# Epoch 46/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5534 - accuracy: 0.8289 - val_loss: 0.5265 - val_accuracy: 0.8512
# Epoch 47/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5466 - accuracy: 0.8324 - val_loss: 0.5135 - val_accuracy: 0.8544
# Epoch 48/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5442 - accuracy: 0.8355 - val_loss: 0.5118 - val_accuracy: 0.8629
# Epoch 49/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5363 - accuracy: 0.8409 - val_loss: 0.5066 - val_accuracy: 0.8629
# Epoch 50/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5294 - accuracy: 0.8358 - val_loss: 0.5088 - val_accuracy: 0.8597
# Epoch 51/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5259 - accuracy: 0.8440 - val_loss: 0.4995 - val_accuracy: 0.8640
# Epoch 52/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5277 - accuracy: 0.8379 - val_loss: 0.4952 - val_accuracy: 0.8629
# Epoch 53/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5230 - accuracy: 0.8318 - val_loss: 0.4945 - val_accuracy: 0.8618
# Epoch 54/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5135 - accuracy: 0.8417 - val_loss: 0.5000 - val_accuracy: 0.8650
# Epoch 55/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5156 - accuracy: 0.8427 - val_loss: 0.4848 - val_accuracy: 0.8650
# Epoch 56/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5067 - accuracy: 0.8398 - val_loss: 0.4894 - val_accuracy: 0.8672
# Epoch 57/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5162 - accuracy: 0.8379 - val_loss: 0.5056 - val_accuracy: 0.8555
# Epoch 58/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5196 - accuracy: 0.8353 - val_loss: 0.4946 - val_accuracy: 0.8608
# Epoch 59/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5087 - accuracy: 0.8409 - val_loss: 0.4784 - val_accuracy: 0.8704
# Epoch 60/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5066 - accuracy: 0.8409 - val_loss: 0.4750 - val_accuracy: 0.8650
# Epoch 61/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4926 - accuracy: 0.8440 - val_loss: 0.4730 - val_accuracy: 0.8735
# Epoch 62/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4890 - accuracy: 0.8464 - val_loss: 0.4699 - val_accuracy: 0.8757
# Epoch 63/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4971 - accuracy: 0.8438 - val_loss: 0.4691 - val_accuracy: 0.8714
# Epoch 64/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4905 - accuracy: 0.8446 - val_loss: 0.4720 - val_accuracy: 0.8629
# Epoch 65/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4935 - accuracy: 0.8454 - val_loss: 0.4648 - val_accuracy: 0.8725
# Epoch 66/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4862 - accuracy: 0.8502 - val_loss: 0.4657 - val_accuracy: 0.8767
# Epoch 67/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4862 - accuracy: 0.8472 - val_loss: 0.4593 - val_accuracy: 0.8725
# Epoch 68/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4718 - accuracy: 0.8523 - val_loss: 0.4500 - val_accuracy: 0.8757
# Epoch 69/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4771 - accuracy: 0.8549 - val_loss: 0.4519 - val_accuracy: 0.8682
# Epoch 70/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4768 - accuracy: 0.8518 - val_loss: 0.4550 - val_accuracy: 0.8757
# Epoch 71/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4705 - accuracy: 0.8510 - val_loss: 0.4461 - val_accuracy: 0.8778
# Epoch 72/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4794 - accuracy: 0.8488 - val_loss: 0.4724 - val_accuracy: 0.8618
# Epoch 73/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4759 - accuracy: 0.8464 - val_loss: 0.4604 - val_accuracy: 0.8757
# Epoch 74/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4672 - accuracy: 0.8541 - val_loss: 0.4409 - val_accuracy: 0.8767
# Epoch 75/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4652 - accuracy: 0.8520 - val_loss: 0.4400 - val_accuracy: 0.8661
# Epoch 76/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4573 - accuracy: 0.8576 - val_loss: 0.4353 - val_accuracy: 0.8778
# Epoch 77/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4566 - accuracy: 0.8568 - val_loss: 0.4383 - val_accuracy: 0.8767
# Epoch 78/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4594 - accuracy: 0.8528 - val_loss: 0.4338 - val_accuracy: 0.8746
# Epoch 79/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4551 - accuracy: 0.8544 - val_loss: 0.4342 - val_accuracy: 0.8831
# Epoch 80/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4575 - accuracy: 0.8547 - val_loss: 0.4289 - val_accuracy: 0.8799
# Epoch 81/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4522 - accuracy: 0.8576 - val_loss: 0.4243 - val_accuracy: 0.8789
# Epoch 82/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4501 - accuracy: 0.8624 - val_loss: 0.4259 - val_accuracy: 0.8789
# Epoch 83/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4455 - accuracy: 0.8611 - val_loss: 0.4233 - val_accuracy: 0.8831
# Epoch 84/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4348 - accuracy: 0.8642 - val_loss: 0.4125 - val_accuracy: 0.8778
# Epoch 85/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4432 - accuracy: 0.8557 - val_loss: 0.4140 - val_accuracy: 0.8799
# Epoch 86/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4353 - accuracy: 0.8618 - val_loss: 0.4112 - val_accuracy: 0.8789
# Epoch 87/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4350 - accuracy: 0.8618 - val_loss: 0.4120 - val_accuracy: 0.8874
# Epoch 88/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4299 - accuracy: 0.8680 - val_loss: 0.4129 - val_accuracy: 0.8852
# Epoch 89/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4364 - accuracy: 0.8616 - val_loss: 0.4095 - val_accuracy: 0.8831
# Epoch 90/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4207 - accuracy: 0.8640 - val_loss: 0.4072 - val_accuracy: 0.8852
# Epoch 91/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4247 - accuracy: 0.8629 - val_loss: 0.4060 - val_accuracy: 0.8842
# Epoch 92/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4266 - accuracy: 0.8634 - val_loss: 0.4028 - val_accuracy: 0.8831
# Epoch 93/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4231 - accuracy: 0.8693 - val_loss: 0.4028 - val_accuracy: 0.8895
# Epoch 94/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4273 - accuracy: 0.8661 - val_loss: 0.4038 - val_accuracy: 0.8874
# Epoch 95/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4268 - accuracy: 0.8650 - val_loss: 0.4018 - val_accuracy: 0.8874
# Epoch 96/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4237 - accuracy: 0.8677 - val_loss: 0.4043 - val_accuracy: 0.8842
# Epoch 97/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4166 - accuracy: 0.8680 - val_loss: 0.4083 - val_accuracy: 0.8895
# Epoch 98/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4200 - accuracy: 0.8685 - val_loss: 0.4069 - val_accuracy: 0.8735
# Epoch 99/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4313 - accuracy: 0.8632 - val_loss: 0.4031 - val_accuracy: 0.8852
# Epoch 100/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4129 - accuracy: 0.8730 - val_loss: 0.3926 - val_accuracy: 0.8852
# Epoch 101/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4066 - accuracy: 0.8682 - val_loss: 0.3874 - val_accuracy: 0.8895
# Epoch 102/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4155 - accuracy: 0.8666 - val_loss: 0.3896 - val_accuracy: 0.8852
# Epoch 103/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4176 - accuracy: 0.8672 - val_loss: 0.3913 - val_accuracy: 0.8937
# Epoch 104/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4084 - accuracy: 0.8698 - val_loss: 0.3828 - val_accuracy: 0.8874
# Epoch 105/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4060 - accuracy: 0.8704 - val_loss: 0.3840 - val_accuracy: 0.8895
# Epoch 106/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4041 - accuracy: 0.8727 - val_loss: 0.3895 - val_accuracy: 0.8905
# Epoch 107/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4027 - accuracy: 0.8719 - val_loss: 0.3844 - val_accuracy: 0.8895
# Epoch 108/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3970 - accuracy: 0.8722 - val_loss: 0.3816 - val_accuracy: 0.8927
# Epoch 109/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3968 - accuracy: 0.8741 - val_loss: 0.3818 - val_accuracy: 0.8884
# Epoch 110/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3997 - accuracy: 0.8666 - val_loss: 0.3787 - val_accuracy: 0.8927
# Epoch 111/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3916 - accuracy: 0.8781 - val_loss: 0.3738 - val_accuracy: 0.8916
# Epoch 112/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3843 - accuracy: 0.8746 - val_loss: 0.3719 - val_accuracy: 0.8916
# Epoch 113/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3836 - accuracy: 0.8789 - val_loss: 0.3698 - val_accuracy: 0.8959
# Epoch 114/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3866 - accuracy: 0.8773 - val_loss: 0.3758 - val_accuracy: 0.8959
# Epoch 115/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3903 - accuracy: 0.8770 - val_loss: 0.3721 - val_accuracy: 0.8905
# Epoch 116/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3898 - accuracy: 0.8738 - val_loss: 0.3719 - val_accuracy: 0.9001
# Epoch 117/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3906 - accuracy: 0.8735 - val_loss: 0.3828 - val_accuracy: 0.8874
# Epoch 118/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4003 - accuracy: 0.8664 - val_loss: 0.3727 - val_accuracy: 0.9001
# Epoch 119/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3962 - accuracy: 0.8778 - val_loss: 0.3789 - val_accuracy: 0.8927
# Epoch 120/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3879 - accuracy: 0.8735 - val_loss: 0.3686 - val_accuracy: 0.8916
# Epoch 121/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3795 - accuracy: 0.8775 - val_loss: 0.3700 - val_accuracy: 0.8980
# Epoch 122/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3817 - accuracy: 0.8781 - val_loss: 0.3604 - val_accuracy: 0.8969
# Epoch 123/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3761 - accuracy: 0.8810 - val_loss: 0.3540 - val_accuracy: 0.9044
# Epoch 124/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3790 - accuracy: 0.8794 - val_loss: 0.3585 - val_accuracy: 0.8927
# Epoch 125/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3792 - accuracy: 0.8765 - val_loss: 0.3511 - val_accuracy: 0.8990
# Epoch 126/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3638 - accuracy: 0.8847 - val_loss: 0.3555 - val_accuracy: 0.8959
# Epoch 127/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3610 - accuracy: 0.8847 - val_loss: 0.3457 - val_accuracy: 0.9044
# Epoch 128/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3771 - accuracy: 0.8812 - val_loss: 0.3551 - val_accuracy: 0.8990
# Epoch 129/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3641 - accuracy: 0.8836 - val_loss: 0.3571 - val_accuracy: 0.8969
# Epoch 130/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3715 - accuracy: 0.8842 - val_loss: 0.3567 - val_accuracy: 0.8969
# Epoch 131/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3652 - accuracy: 0.8887 - val_loss: 0.3493 - val_accuracy: 0.8937
# Epoch 132/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3578 - accuracy: 0.8882 - val_loss: 0.3537 - val_accuracy: 0.8990
# Epoch 133/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3638 - accuracy: 0.8807 - val_loss: 0.3459 - val_accuracy: 0.9033
# Epoch 134/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3604 - accuracy: 0.8868 - val_loss: 0.3498 - val_accuracy: 0.9001
# Epoch 135/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3661 - accuracy: 0.8820 - val_loss: 0.3465 - val_accuracy: 0.8990
# Epoch 136/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3650 - accuracy: 0.8815 - val_loss: 0.3452 - val_accuracy: 0.8980
# Epoch 137/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3577 - accuracy: 0.8799 - val_loss: 0.3567 - val_accuracy: 0.8969
# Epoch 138/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3593 - accuracy: 0.8847 - val_loss: 0.3463 - val_accuracy: 0.8980
# Epoch 139/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3490 - accuracy: 0.8900 - val_loss: 0.3400 - val_accuracy: 0.9044
# Epoch 140/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3440 - accuracy: 0.8924 - val_loss: 0.3428 - val_accuracy: 0.8990
# Epoch 141/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3598 - accuracy: 0.8900 - val_loss: 0.3402 - val_accuracy: 0.9033
# Epoch 142/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3475 - accuracy: 0.8908 - val_loss: 0.3380 - val_accuracy: 0.9012
# Epoch 143/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3538 - accuracy: 0.8868 - val_loss: 0.3481 - val_accuracy: 0.8969
# Epoch 144/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3578 - accuracy: 0.8783 - val_loss: 0.3408 - val_accuracy: 0.8980
# Epoch 145/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3444 - accuracy: 0.8924 - val_loss: 0.3373 - val_accuracy: 0.9022
# Epoch 146/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3403 - accuracy: 0.8919 - val_loss: 0.3281 - val_accuracy: 0.9075
# Epoch 147/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3418 - accuracy: 0.8921 - val_loss: 0.3306 - val_accuracy: 0.9065
# Epoch 148/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3455 - accuracy: 0.8858 - val_loss: 0.3430 - val_accuracy: 0.8969
# Epoch 149/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3497 - accuracy: 0.8863 - val_loss: 0.3419 - val_accuracy: 0.9044
# Epoch 150/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3492 - accuracy: 0.8863 - val_loss: 0.3378 - val_accuracy: 0.9012
# Epoch 151/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3487 - accuracy: 0.8855 - val_loss: 0.3403 - val_accuracy: 0.9044
# Epoch 152/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3496 - accuracy: 0.8884 - val_loss: 0.3295 - val_accuracy: 0.9054
# Epoch 153/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3318 - accuracy: 0.8953 - val_loss: 0.3296 - val_accuracy: 0.9044
# Epoch 154/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3431 - accuracy: 0.8876 - val_loss: 0.3307 - val_accuracy: 0.9022
# Epoch 155/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3437 - accuracy: 0.8847 - val_loss: 0.3264 - val_accuracy: 0.9086
# Epoch 156/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3311 - accuracy: 0.8929 - val_loss: 0.3214 - val_accuracy: 0.9054
# Epoch 157/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3307 - accuracy: 0.8919 - val_loss: 0.3212 - val_accuracy: 0.9086
# Epoch 158/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3301 - accuracy: 0.8905 - val_loss: 0.3202 - val_accuracy: 0.9075
# Epoch 159/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3236 - accuracy: 0.8974 - val_loss: 0.3159 - val_accuracy: 0.9150
# Epoch 160/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3263 - accuracy: 0.8967 - val_loss: 0.3151 - val_accuracy: 0.9118
# Epoch 161/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3300 - accuracy: 0.8911 - val_loss: 0.3169 - val_accuracy: 0.9086
# Epoch 162/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3235 - accuracy: 0.8959 - val_loss: 0.3165 - val_accuracy: 0.9097
# Epoch 163/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3237 - accuracy: 0.8943 - val_loss: 0.3161 - val_accuracy: 0.9097
# Epoch 164/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3250 - accuracy: 0.8948 - val_loss: 0.3236 - val_accuracy: 0.9075
# Epoch 165/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3254 - accuracy: 0.8972 - val_loss: 0.3202 - val_accuracy: 0.9044
# Epoch 166/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3206 - accuracy: 0.8964 - val_loss: 0.3169 - val_accuracy: 0.9097
# Epoch 167/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3230 - accuracy: 0.8959 - val_loss: 0.3170 - val_accuracy: 0.9097
# Epoch 168/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3167 - accuracy: 0.8969 - val_loss: 0.3147 - val_accuracy: 0.9097
# Epoch 169/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3138 - accuracy: 0.8972 - val_loss: 0.3158 - val_accuracy: 0.9086
# Epoch 170/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3197 - accuracy: 0.8980 - val_loss: 0.3155 - val_accuracy: 0.9097
# Epoch 171/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3164 - accuracy: 0.8996 - val_loss: 0.3094 - val_accuracy: 0.9107
# Epoch 172/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3175 - accuracy: 0.8974 - val_loss: 0.3122 - val_accuracy: 0.9097
# Epoch 173/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3196 - accuracy: 0.9001 - val_loss: 0.3119 - val_accuracy: 0.9065
# Epoch 174/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3101 - accuracy: 0.9004 - val_loss: 0.3027 - val_accuracy: 0.9129
# Epoch 175/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3092 - accuracy: 0.8977 - val_loss: 0.3043 - val_accuracy: 0.9150
# Epoch 176/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3122 - accuracy: 0.8993 - val_loss: 0.3030 - val_accuracy: 0.9129
# Epoch 177/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3146 - accuracy: 0.9006 - val_loss: 0.3031 - val_accuracy: 0.9118
# Epoch 178/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3104 - accuracy: 0.9001 - val_loss: 0.3155 - val_accuracy: 0.9033
# Epoch 179/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3028 - accuracy: 0.9046 - val_loss: 0.3029 - val_accuracy: 0.9150
# Epoch 180/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3058 - accuracy: 0.9041 - val_loss: 0.2988 - val_accuracy: 0.9118
# Epoch 181/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3149 - accuracy: 0.8964 - val_loss: 0.3106 - val_accuracy: 0.9097
# Epoch 182/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3042 - accuracy: 0.9044 - val_loss: 0.3016 - val_accuracy: 0.9160
# Epoch 183/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3123 - accuracy: 0.8953 - val_loss: 0.3042 - val_accuracy: 0.9129
# Epoch 184/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3060 - accuracy: 0.9014 - val_loss: 0.3109 - val_accuracy: 0.9075
# Epoch 185/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3007 - accuracy: 0.9004 - val_loss: 0.2988 - val_accuracy: 0.9107
# Epoch 186/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2994 - accuracy: 0.9065 - val_loss: 0.3001 - val_accuracy: 0.9118
# Epoch 187/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3002 - accuracy: 0.9004 - val_loss: 0.3064 - val_accuracy: 0.9097
# Epoch 188/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2961 - accuracy: 0.9054 - val_loss: 0.2984 - val_accuracy: 0.9139
# Epoch 189/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2970 - accuracy: 0.9052 - val_loss: 0.2948 - val_accuracy: 0.9139
# Epoch 190/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2891 - accuracy: 0.9078 - val_loss: 0.3048 - val_accuracy: 0.9129
# Epoch 191/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2946 - accuracy: 0.9022 - val_loss: 0.2925 - val_accuracy: 0.9160
# Epoch 192/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2954 - accuracy: 0.9009 - val_loss: 0.2939 - val_accuracy: 0.9150
# Epoch 193/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2991 - accuracy: 0.8990 - val_loss: 0.2935 - val_accuracy: 0.9139
# Epoch 194/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2922 - accuracy: 0.9036 - val_loss: 0.2907 - val_accuracy: 0.9160
# Epoch 195/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2848 - accuracy: 0.9097 - val_loss: 0.2862 - val_accuracy: 0.9182
# Epoch 196/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2955 - accuracy: 0.9046 - val_loss: 0.2870 - val_accuracy: 0.9192
# Epoch 197/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2960 - accuracy: 0.9070 - val_loss: 0.2884 - val_accuracy: 0.9160
# Epoch 198/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2889 - accuracy: 0.9067 - val_loss: 0.2835 - val_accuracy: 0.9214
# Epoch 199/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2939 - accuracy: 0.8996 - val_loss: 0.2942 - val_accuracy: 0.9139
# Epoch 200/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2885 - accuracy: 0.9065 - val_loss: 0.2851 - val_accuracy: 0.9214

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 58ms/step - loss: 1.9404 - accuracy: 0.3262 - val_loss: 1.7070 - val_accuracy: 0.4368
# Epoch 2/50
# 8/8 [==============================] - 0s 32ms/step - loss: 1.6437 - accuracy: 0.4716 - val_loss: 1.4843 - val_accuracy: 0.5165
# Epoch 3/50
# 8/8 [==============================] - 0s 27ms/step - loss: 1.4624 - accuracy: 0.5053 - val_loss: 1.3555 - val_accuracy: 0.5324
# Epoch 4/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.3543 - accuracy: 0.5183 - val_loss: 1.2877 - val_accuracy: 0.5313
# Epoch 5/50
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2963 - accuracy: 0.5476 - val_loss: 1.2290 - val_accuracy: 0.5367
# Epoch 6/50
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2371 - accuracy: 0.5598 - val_loss: 1.1829 - val_accuracy: 0.6185
# Epoch 7/50
# 8/8 [==============================] - 0s 32ms/step - loss: 1.1932 - accuracy: 0.5901 - val_loss: 1.1093 - val_accuracy: 0.6514
# Epoch 8/50
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1338 - accuracy: 0.6092 - val_loss: 1.0635 - val_accuracy: 0.6674
# Epoch 9/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0958 - accuracy: 0.6241 - val_loss: 1.0338 - val_accuracy: 0.6950
# Epoch 10/50
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0683 - accuracy: 0.6520 - val_loss: 0.9964 - val_accuracy: 0.7343
# Epoch 11/50
# 8/8 [==============================] - 0s 28ms/step - loss: 1.0274 - accuracy: 0.6634 - val_loss: 0.9489 - val_accuracy: 0.7386
# Epoch 12/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.9815 - accuracy: 0.6860 - val_loss: 0.9102 - val_accuracy: 0.7513
# Epoch 13/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9499 - accuracy: 0.6945 - val_loss: 0.8789 - val_accuracy: 0.7566
# Epoch 14/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9257 - accuracy: 0.7001 - val_loss: 0.8514 - val_accuracy: 0.7588
# Epoch 15/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9034 - accuracy: 0.7112 - val_loss: 0.8349 - val_accuracy: 0.7630
# Epoch 16/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.8867 - accuracy: 0.7237 - val_loss: 0.8300 - val_accuracy: 0.7396
# Epoch 17/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.8697 - accuracy: 0.7272 - val_loss: 0.7828 - val_accuracy: 0.7705
# Epoch 18/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8393 - accuracy: 0.7306 - val_loss: 0.7675 - val_accuracy: 0.7598
# Epoch 19/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.8172 - accuracy: 0.7484 - val_loss: 0.7460 - val_accuracy: 0.7853
# Epoch 20/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7960 - accuracy: 0.7492 - val_loss: 0.7309 - val_accuracy: 0.8045
# Epoch 21/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7889 - accuracy: 0.7540 - val_loss: 0.7222 - val_accuracy: 0.7768
# Epoch 22/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7719 - accuracy: 0.7572 - val_loss: 0.7084 - val_accuracy: 0.7938
# Epoch 23/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7569 - accuracy: 0.7667 - val_loss: 0.6997 - val_accuracy: 0.7843
# Epoch 24/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7466 - accuracy: 0.7689 - val_loss: 0.6820 - val_accuracy: 0.8193
# Epoch 25/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7329 - accuracy: 0.7752 - val_loss: 0.6743 - val_accuracy: 0.7991
# Epoch 26/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7201 - accuracy: 0.7707 - val_loss: 0.6723 - val_accuracy: 0.8055
# Epoch 27/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7130 - accuracy: 0.7742 - val_loss: 0.6503 - val_accuracy: 0.8172
# Epoch 28/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6851 - accuracy: 0.7904 - val_loss: 0.6395 - val_accuracy: 0.8289
# Epoch 29/50
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6894 - accuracy: 0.7885 - val_loss: 0.6418 - val_accuracy: 0.8162
# Epoch 30/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6812 - accuracy: 0.7893 - val_loss: 0.6254 - val_accuracy: 0.8300
# Epoch 31/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6736 - accuracy: 0.7904 - val_loss: 0.6207 - val_accuracy: 0.8257
# Epoch 32/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6593 - accuracy: 0.7978 - val_loss: 0.6079 - val_accuracy: 0.8374
# Epoch 33/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6477 - accuracy: 0.8069 - val_loss: 0.6028 - val_accuracy: 0.8332
# Epoch 34/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6499 - accuracy: 0.7965 - val_loss: 0.5985 - val_accuracy: 0.8438
# Epoch 35/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6372 - accuracy: 0.8111 - val_loss: 0.5881 - val_accuracy: 0.8459
# Epoch 36/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6303 - accuracy: 0.8135 - val_loss: 0.5907 - val_accuracy: 0.8332
# Epoch 37/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6275 - accuracy: 0.8034 - val_loss: 0.5879 - val_accuracy: 0.8321
# Epoch 38/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6101 - accuracy: 0.8100 - val_loss: 0.5742 - val_accuracy: 0.8438
# Epoch 39/50
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6145 - accuracy: 0.8124 - val_loss: 0.5719 - val_accuracy: 0.8438
# Epoch 40/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6143 - accuracy: 0.8087 - val_loss: 0.5691 - val_accuracy: 0.8417
# Epoch 41/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6000 - accuracy: 0.8106 - val_loss: 0.5709 - val_accuracy: 0.8459
# Epoch 42/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5955 - accuracy: 0.8180 - val_loss: 0.5611 - val_accuracy: 0.8406
# Epoch 43/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6001 - accuracy: 0.8092 - val_loss: 0.5553 - val_accuracy: 0.8289
# Epoch 44/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5912 - accuracy: 0.8167 - val_loss: 0.5525 - val_accuracy: 0.8438
# Epoch 45/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5774 - accuracy: 0.8241 - val_loss: 0.5392 - val_accuracy: 0.8523
# Epoch 46/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5762 - accuracy: 0.8225 - val_loss: 0.5430 - val_accuracy: 0.8565
# Epoch 47/50
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5824 - accuracy: 0.8127 - val_loss: 0.5581 - val_accuracy: 0.8332
# Epoch 48/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5708 - accuracy: 0.8244 - val_loss: 0.5493 - val_accuracy: 0.8470
# Epoch 49/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5723 - accuracy: 0.8217 - val_loss: 0.5351 - val_accuracy: 0.8491
# Epoch 50/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5543 - accuracy: 0.8334 - val_loss: 0.5222 - val_accuracy: 0.8576

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 0s 3ms/step - loss: 0.4995 - accuracy: 0.8589
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5222 - accuracy: 0.8576
# 0.8589266538619995 0.8575983047485352

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 53, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:33

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 138   0   0   2   0   0   0]
#  [  2   0   0 115   0   6   0   0   1]
#  [  0   0   0   0 303  13   0   0   4]
#  [  0   0   0   0  20  97   3   0   0]
#  [  0   0   1   0   9  11  25   0   4]
#  [  0   0   0   0  17  11   2  20   0]
#  [  0   0   0   2  12  14   0   0   9]]
#
# Accuracy Score
# 0.8575982996811902
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.97      1.00      0.98        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.98      0.93      0.95       124
#       built       0.84      0.95      0.89       320
#     windows       0.63      0.81      0.71       120
#       roads       0.83      0.50      0.62        50
#        cars       1.00      0.40      0.57        50
#       metal       0.50      0.24      0.33        37
#
# avg / total       0.86      0.86      0.85       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
# Out:
# 53 3
