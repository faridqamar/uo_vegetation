# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %%
num_of_bins = 15
filtersize = 1
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 15
# [[0, 56], [56, 112], [112, 168], [168, 224], [224, 280], [280, 336], [336, 392], [392, 448], [448, 504], [504, 560], [560, 616], [616, 672], [672, 728], [728, 784], [784, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 15)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 15)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 15) (60, 15)
# clouds  (400, 15) (100, 15)
# vegetation  (480, 15) (120, 15)
# water  (40, 15) (10, 15)
# built  (816, 15) (204, 15)
# windows  (400, 15) (100, 15)
# roads  (24, 15) (6, 15)
# cars  (80, 15) (20, 15)
# metal  (80, 15) (20, 15)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 15) (2560,) (2560, 2)
# (640, 15) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 152ms/step - loss: 2.0865 - accuracy: 0.2414 - val_loss: 1.9017 - val_accuracy: 0.3266
# Epoch 2/200
# 5/5 [==============================] - 0s 46ms/step - loss: 1.8103 - accuracy: 0.3430 - val_loss: 1.7131 - val_accuracy: 0.3531
# Epoch 3/200
# 5/5 [==============================] - 0s 47ms/step - loss: 1.6871 - accuracy: 0.3902 - val_loss: 1.6040 - val_accuracy: 0.4594
# Epoch 4/200
# 5/5 [==============================] - 0s 37ms/step - loss: 1.6049 - accuracy: 0.4711 - val_loss: 1.5088 - val_accuracy: 0.4953
# Epoch 5/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.5208 - accuracy: 0.5398 - val_loss: 1.4132 - val_accuracy: 0.5188
# Epoch 6/200
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4368 - accuracy: 0.5387 - val_loss: 1.3171 - val_accuracy: 0.5031
# Epoch 7/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.3539 - accuracy: 0.5535 - val_loss: 1.2328 - val_accuracy: 0.6219
# Epoch 8/200
# 5/5 [==============================] - 0s 30ms/step - loss: 1.2922 - accuracy: 0.5922 - val_loss: 1.1616 - val_accuracy: 0.6609
# Epoch 9/200
# 5/5 [==============================] - 0s 33ms/step - loss: 1.2123 - accuracy: 0.6102 - val_loss: 1.0936 - val_accuracy: 0.6781
# Epoch 10/200
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1652 - accuracy: 0.6180 - val_loss: 1.0272 - val_accuracy: 0.7281
# Epoch 11/200
# 5/5 [==============================] - 0s 37ms/step - loss: 1.1033 - accuracy: 0.6473 - val_loss: 0.9654 - val_accuracy: 0.7406
# Epoch 12/200
# 5/5 [==============================] - 0s 28ms/step - loss: 1.0682 - accuracy: 0.6480 - val_loss: 0.9163 - val_accuracy: 0.7250
# Epoch 13/200
# 5/5 [==============================] - 0s 30ms/step - loss: 1.0176 - accuracy: 0.6703 - val_loss: 0.8721 - val_accuracy: 0.7234
# Epoch 14/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9688 - accuracy: 0.6832 - val_loss: 0.8396 - val_accuracy: 0.7312
# Epoch 15/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9348 - accuracy: 0.6844 - val_loss: 0.8001 - val_accuracy: 0.7359
# Epoch 16/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8940 - accuracy: 0.7102 - val_loss: 0.7758 - val_accuracy: 0.7547
# Epoch 17/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8532 - accuracy: 0.7199 - val_loss: 0.7497 - val_accuracy: 0.7406
# Epoch 18/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.8309 - accuracy: 0.7289 - val_loss: 0.7337 - val_accuracy: 0.7844
# Epoch 19/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.8081 - accuracy: 0.7305 - val_loss: 0.7078 - val_accuracy: 0.7844
# Epoch 20/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7854 - accuracy: 0.7453 - val_loss: 0.6919 - val_accuracy: 0.7891
# Epoch 21/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7649 - accuracy: 0.7723 - val_loss: 0.6721 - val_accuracy: 0.8031
# Epoch 22/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7391 - accuracy: 0.7754 - val_loss: 0.6543 - val_accuracy: 0.7969
# Epoch 23/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.7262 - accuracy: 0.7691 - val_loss: 0.6374 - val_accuracy: 0.8031
# Epoch 24/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6998 - accuracy: 0.7836 - val_loss: 0.6177 - val_accuracy: 0.8109
# Epoch 25/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6889 - accuracy: 0.7980 - val_loss: 0.6014 - val_accuracy: 0.8156
# Epoch 26/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6689 - accuracy: 0.7980 - val_loss: 0.5885 - val_accuracy: 0.8141
# Epoch 27/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6544 - accuracy: 0.8016 - val_loss: 0.5816 - val_accuracy: 0.8203
# Epoch 28/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6320 - accuracy: 0.8117 - val_loss: 0.5623 - val_accuracy: 0.8188
# Epoch 29/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6294 - accuracy: 0.8176 - val_loss: 0.5549 - val_accuracy: 0.8172
# Epoch 30/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6144 - accuracy: 0.8160 - val_loss: 0.5425 - val_accuracy: 0.8250
# Epoch 31/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6109 - accuracy: 0.8145 - val_loss: 0.5353 - val_accuracy: 0.8172
# Epoch 32/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6010 - accuracy: 0.8145 - val_loss: 0.5331 - val_accuracy: 0.8172
# Epoch 33/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5838 - accuracy: 0.8262 - val_loss: 0.5213 - val_accuracy: 0.8359
# Epoch 34/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5777 - accuracy: 0.8230 - val_loss: 0.5166 - val_accuracy: 0.8188
# Epoch 35/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5661 - accuracy: 0.8285 - val_loss: 0.5120 - val_accuracy: 0.8391
# Epoch 36/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5595 - accuracy: 0.8367 - val_loss: 0.5205 - val_accuracy: 0.8234
# Epoch 37/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5615 - accuracy: 0.8293 - val_loss: 0.4958 - val_accuracy: 0.8516
# Epoch 38/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5453 - accuracy: 0.8391 - val_loss: 0.4917 - val_accuracy: 0.8375
# Epoch 39/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5414 - accuracy: 0.8398 - val_loss: 0.4931 - val_accuracy: 0.8219
# Epoch 40/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5385 - accuracy: 0.8348 - val_loss: 0.4775 - val_accuracy: 0.8672
# Epoch 41/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5222 - accuracy: 0.8363 - val_loss: 0.4721 - val_accuracy: 0.8391
# Epoch 42/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5241 - accuracy: 0.8434 - val_loss: 0.4706 - val_accuracy: 0.8375
# Epoch 43/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5187 - accuracy: 0.8398 - val_loss: 0.4677 - val_accuracy: 0.8453
# Epoch 44/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5090 - accuracy: 0.8484 - val_loss: 0.4679 - val_accuracy: 0.8453
# Epoch 45/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.5159 - accuracy: 0.8430 - val_loss: 0.4490 - val_accuracy: 0.8656
# Epoch 46/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5053 - accuracy: 0.8434 - val_loss: 0.4625 - val_accuracy: 0.8469
# Epoch 47/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4975 - accuracy: 0.8410 - val_loss: 0.4484 - val_accuracy: 0.8734
# Epoch 48/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4930 - accuracy: 0.8418 - val_loss: 0.4379 - val_accuracy: 0.8734
# Epoch 49/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4844 - accuracy: 0.8492 - val_loss: 0.4505 - val_accuracy: 0.8531
# Epoch 50/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4947 - accuracy: 0.8473 - val_loss: 0.4423 - val_accuracy: 0.8719
# Epoch 51/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4670 - accuracy: 0.8621 - val_loss: 0.4282 - val_accuracy: 0.8828
# Epoch 52/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4809 - accuracy: 0.8438 - val_loss: 0.4499 - val_accuracy: 0.8469
# Epoch 53/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4703 - accuracy: 0.8586 - val_loss: 0.4355 - val_accuracy: 0.8609
# Epoch 54/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4658 - accuracy: 0.8535 - val_loss: 0.4176 - val_accuracy: 0.8781
# Epoch 55/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4710 - accuracy: 0.8516 - val_loss: 0.4223 - val_accuracy: 0.8859
# Epoch 56/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4743 - accuracy: 0.8512 - val_loss: 0.4337 - val_accuracy: 0.8578
# Epoch 57/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4715 - accuracy: 0.8555 - val_loss: 0.4282 - val_accuracy: 0.8672
# Epoch 58/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4523 - accuracy: 0.8613 - val_loss: 0.4142 - val_accuracy: 0.8859
# Epoch 59/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4586 - accuracy: 0.8535 - val_loss: 0.4087 - val_accuracy: 0.8781
# Epoch 60/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4590 - accuracy: 0.8602 - val_loss: 0.4539 - val_accuracy: 0.8484
# Epoch 61/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4671 - accuracy: 0.8566 - val_loss: 0.3905 - val_accuracy: 0.8781
# Epoch 62/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4578 - accuracy: 0.8570 - val_loss: 0.4142 - val_accuracy: 0.8953
# Epoch 63/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4478 - accuracy: 0.8625 - val_loss: 0.4130 - val_accuracy: 0.8797
# Epoch 64/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4470 - accuracy: 0.8645 - val_loss: 0.3916 - val_accuracy: 0.8953
# Epoch 65/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4398 - accuracy: 0.8656 - val_loss: 0.3949 - val_accuracy: 0.8828
# Epoch 66/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4241 - accuracy: 0.8723 - val_loss: 0.3954 - val_accuracy: 0.8922
# Epoch 67/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4288 - accuracy: 0.8664 - val_loss: 0.3926 - val_accuracy: 0.8828
# Epoch 68/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4246 - accuracy: 0.8715 - val_loss: 0.4009 - val_accuracy: 0.8875
# Epoch 69/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4211 - accuracy: 0.8672 - val_loss: 0.3865 - val_accuracy: 0.8906
# Epoch 70/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4280 - accuracy: 0.8727 - val_loss: 0.3855 - val_accuracy: 0.8891
# Epoch 71/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4249 - accuracy: 0.8641 - val_loss: 0.3890 - val_accuracy: 0.8906
# Epoch 72/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4199 - accuracy: 0.8746 - val_loss: 0.3744 - val_accuracy: 0.8984
# Epoch 73/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4093 - accuracy: 0.8719 - val_loss: 0.3747 - val_accuracy: 0.8891
# Epoch 74/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4162 - accuracy: 0.8711 - val_loss: 0.3925 - val_accuracy: 0.8750
# Epoch 75/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4046 - accuracy: 0.8742 - val_loss: 0.3686 - val_accuracy: 0.8891
# Epoch 76/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4163 - accuracy: 0.8695 - val_loss: 0.3934 - val_accuracy: 0.8750
# Epoch 77/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3973 - accuracy: 0.8754 - val_loss: 0.3650 - val_accuracy: 0.8938
# Epoch 78/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4063 - accuracy: 0.8719 - val_loss: 0.3710 - val_accuracy: 0.8906
# Epoch 79/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3965 - accuracy: 0.8789 - val_loss: 0.3600 - val_accuracy: 0.8953
# Epoch 80/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4036 - accuracy: 0.8715 - val_loss: 0.3685 - val_accuracy: 0.8891
# Epoch 81/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4037 - accuracy: 0.8766 - val_loss: 0.3793 - val_accuracy: 0.8844
# Epoch 82/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3971 - accuracy: 0.8750 - val_loss: 0.3497 - val_accuracy: 0.8953
# Epoch 83/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3874 - accuracy: 0.8871 - val_loss: 0.3621 - val_accuracy: 0.8984
# Epoch 84/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3919 - accuracy: 0.8742 - val_loss: 0.3536 - val_accuracy: 0.8953
# Epoch 85/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3925 - accuracy: 0.8746 - val_loss: 0.4019 - val_accuracy: 0.8500
# Epoch 86/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3966 - accuracy: 0.8773 - val_loss: 0.3507 - val_accuracy: 0.8938
# Epoch 87/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3862 - accuracy: 0.8879 - val_loss: 0.3693 - val_accuracy: 0.8875
# Epoch 88/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3824 - accuracy: 0.8816 - val_loss: 0.3602 - val_accuracy: 0.8844
# Epoch 89/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3742 - accuracy: 0.8793 - val_loss: 0.3472 - val_accuracy: 0.8984
# Epoch 90/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3846 - accuracy: 0.8781 - val_loss: 0.3545 - val_accuracy: 0.8859
# Epoch 91/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3817 - accuracy: 0.8789 - val_loss: 0.3723 - val_accuracy: 0.8813
# Epoch 92/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3781 - accuracy: 0.8844 - val_loss: 0.3320 - val_accuracy: 0.8969
# Epoch 93/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3731 - accuracy: 0.8809 - val_loss: 0.3495 - val_accuracy: 0.8938
# Epoch 94/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3722 - accuracy: 0.8824 - val_loss: 0.3579 - val_accuracy: 0.8859
# Epoch 95/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3648 - accuracy: 0.8816 - val_loss: 0.3621 - val_accuracy: 0.8734
# Epoch 96/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3723 - accuracy: 0.8828 - val_loss: 0.3599 - val_accuracy: 0.8813
# Epoch 97/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3665 - accuracy: 0.8855 - val_loss: 0.3328 - val_accuracy: 0.9000
# Epoch 98/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3579 - accuracy: 0.8855 - val_loss: 0.3562 - val_accuracy: 0.8844
# Epoch 99/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3603 - accuracy: 0.8867 - val_loss: 0.3535 - val_accuracy: 0.8781
# Epoch 100/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3593 - accuracy: 0.8840 - val_loss: 0.3472 - val_accuracy: 0.8891
# Epoch 101/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3638 - accuracy: 0.8871 - val_loss: 0.3427 - val_accuracy: 0.8875
# Epoch 102/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3557 - accuracy: 0.8832 - val_loss: 0.3391 - val_accuracy: 0.8922
# Epoch 103/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3584 - accuracy: 0.8914 - val_loss: 0.3421 - val_accuracy: 0.8859
# Epoch 104/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3438 - accuracy: 0.8840 - val_loss: 0.3293 - val_accuracy: 0.8984
# Epoch 105/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3582 - accuracy: 0.8895 - val_loss: 0.3547 - val_accuracy: 0.8703
# Epoch 106/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3567 - accuracy: 0.8848 - val_loss: 0.3406 - val_accuracy: 0.8906
# Epoch 107/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3522 - accuracy: 0.8852 - val_loss: 0.3311 - val_accuracy: 0.8922
# Epoch 108/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3528 - accuracy: 0.8859 - val_loss: 0.3576 - val_accuracy: 0.8672
# Epoch 109/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3418 - accuracy: 0.8906 - val_loss: 0.3239 - val_accuracy: 0.8938
# Epoch 110/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3527 - accuracy: 0.8867 - val_loss: 0.3480 - val_accuracy: 0.8766
# Epoch 111/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3487 - accuracy: 0.8875 - val_loss: 0.3338 - val_accuracy: 0.8859
# Epoch 112/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3372 - accuracy: 0.8895 - val_loss: 0.3367 - val_accuracy: 0.8875
# Epoch 113/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3454 - accuracy: 0.8926 - val_loss: 0.3282 - val_accuracy: 0.8875
# Epoch 114/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3507 - accuracy: 0.8820 - val_loss: 0.3306 - val_accuracy: 0.8906
# Epoch 115/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3477 - accuracy: 0.8910 - val_loss: 0.3469 - val_accuracy: 0.8656
# Epoch 116/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3439 - accuracy: 0.8910 - val_loss: 0.3168 - val_accuracy: 0.8938
# Epoch 117/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3399 - accuracy: 0.8914 - val_loss: 0.3384 - val_accuracy: 0.8781
# Epoch 118/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3423 - accuracy: 0.8887 - val_loss: 0.3524 - val_accuracy: 0.8687
# Epoch 119/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3493 - accuracy: 0.8914 - val_loss: 0.3262 - val_accuracy: 0.8891
# Epoch 120/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3358 - accuracy: 0.8953 - val_loss: 0.3200 - val_accuracy: 0.8953
# Epoch 121/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3347 - accuracy: 0.8895 - val_loss: 0.3291 - val_accuracy: 0.8938
# Epoch 122/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3333 - accuracy: 0.8910 - val_loss: 0.3310 - val_accuracy: 0.8828
# Epoch 123/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3345 - accuracy: 0.8887 - val_loss: 0.3780 - val_accuracy: 0.8578
# Epoch 124/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3398 - accuracy: 0.8965 - val_loss: 0.3090 - val_accuracy: 0.8953
# Epoch 125/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3307 - accuracy: 0.8910 - val_loss: 0.3112 - val_accuracy: 0.9000
# Epoch 126/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3417 - accuracy: 0.8891 - val_loss: 0.4024 - val_accuracy: 0.8438
# Epoch 127/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3321 - accuracy: 0.8949 - val_loss: 0.3094 - val_accuracy: 0.8953
# Epoch 128/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3269 - accuracy: 0.8934 - val_loss: 0.3142 - val_accuracy: 0.8922
# Epoch 129/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3109 - accuracy: 0.8996 - val_loss: 0.3491 - val_accuracy: 0.8703
# Epoch 130/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3243 - accuracy: 0.8969 - val_loss: 0.3172 - val_accuracy: 0.8859
# Epoch 131/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3155 - accuracy: 0.9012 - val_loss: 0.3443 - val_accuracy: 0.8656
# Epoch 132/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3150 - accuracy: 0.8930 - val_loss: 0.2993 - val_accuracy: 0.8922
# Epoch 133/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3215 - accuracy: 0.8973 - val_loss: 0.3200 - val_accuracy: 0.8844
# Epoch 134/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3189 - accuracy: 0.8938 - val_loss: 0.3594 - val_accuracy: 0.8594
# Epoch 135/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3181 - accuracy: 0.8945 - val_loss: 0.3161 - val_accuracy: 0.8844
# Epoch 136/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3140 - accuracy: 0.9020 - val_loss: 0.2965 - val_accuracy: 0.9000
# Epoch 137/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3237 - accuracy: 0.8996 - val_loss: 0.3629 - val_accuracy: 0.8641
# Epoch 138/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3299 - accuracy: 0.8918 - val_loss: 0.3132 - val_accuracy: 0.8922
# Epoch 139/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3147 - accuracy: 0.8957 - val_loss: 0.3236 - val_accuracy: 0.8797
# Epoch 140/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3133 - accuracy: 0.8984 - val_loss: 0.3474 - val_accuracy: 0.8703
# Epoch 141/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3162 - accuracy: 0.8953 - val_loss: 0.3137 - val_accuracy: 0.8859
# Epoch 142/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3050 - accuracy: 0.9027 - val_loss: 0.3212 - val_accuracy: 0.8797
# Epoch 143/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3094 - accuracy: 0.9004 - val_loss: 0.3315 - val_accuracy: 0.8750
# Epoch 144/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3140 - accuracy: 0.8957 - val_loss: 0.3138 - val_accuracy: 0.8891
# Epoch 145/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3092 - accuracy: 0.8988 - val_loss: 0.3560 - val_accuracy: 0.8594
# Epoch 146/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3142 - accuracy: 0.8953 - val_loss: 0.3180 - val_accuracy: 0.8922
# Epoch 147/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3077 - accuracy: 0.9004 - val_loss: 0.3018 - val_accuracy: 0.8938
# Epoch 148/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2954 - accuracy: 0.9023 - val_loss: 0.3513 - val_accuracy: 0.8672
# Epoch 149/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2938 - accuracy: 0.9012 - val_loss: 0.2841 - val_accuracy: 0.9016
# Epoch 150/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2981 - accuracy: 0.8992 - val_loss: 0.3384 - val_accuracy: 0.8734
# Epoch 151/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3001 - accuracy: 0.8973 - val_loss: 0.3297 - val_accuracy: 0.8750
# Epoch 152/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3002 - accuracy: 0.9004 - val_loss: 0.3148 - val_accuracy: 0.8797
# Epoch 153/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3119 - accuracy: 0.8977 - val_loss: 0.3276 - val_accuracy: 0.8875
# Epoch 154/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3012 - accuracy: 0.9047 - val_loss: 0.3036 - val_accuracy: 0.8875
# Epoch 155/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3076 - accuracy: 0.8992 - val_loss: 0.3296 - val_accuracy: 0.8813
# Epoch 156/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3046 - accuracy: 0.9008 - val_loss: 0.3133 - val_accuracy: 0.8844
# Epoch 157/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2931 - accuracy: 0.8992 - val_loss: 0.3095 - val_accuracy: 0.8875
# Epoch 158/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2957 - accuracy: 0.9031 - val_loss: 0.3493 - val_accuracy: 0.8766
# Epoch 159/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2960 - accuracy: 0.9000 - val_loss: 0.2982 - val_accuracy: 0.8938
# Epoch 160/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3009 - accuracy: 0.9035 - val_loss: 0.2961 - val_accuracy: 0.8984
# Epoch 161/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3006 - accuracy: 0.9027 - val_loss: 0.3255 - val_accuracy: 0.8828
# Epoch 162/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3025 - accuracy: 0.9023 - val_loss: 0.3272 - val_accuracy: 0.8797
# Epoch 163/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2951 - accuracy: 0.9008 - val_loss: 0.2981 - val_accuracy: 0.8906
# Epoch 164/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2977 - accuracy: 0.8977 - val_loss: 0.2996 - val_accuracy: 0.8922
# Epoch 165/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2894 - accuracy: 0.9062 - val_loss: 0.3114 - val_accuracy: 0.8813
# Epoch 166/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2891 - accuracy: 0.9062 - val_loss: 0.3482 - val_accuracy: 0.8719
# Epoch 167/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2923 - accuracy: 0.9016 - val_loss: 0.3044 - val_accuracy: 0.8891
# Epoch 168/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2927 - accuracy: 0.9055 - val_loss: 0.2945 - val_accuracy: 0.8953
# Epoch 169/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2878 - accuracy: 0.8992 - val_loss: 0.3664 - val_accuracy: 0.8625
# Epoch 170/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2840 - accuracy: 0.9055 - val_loss: 0.2836 - val_accuracy: 0.9031
# Epoch 171/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2919 - accuracy: 0.9000 - val_loss: 0.2934 - val_accuracy: 0.8969
# Epoch 172/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2970 - accuracy: 0.9031 - val_loss: 0.3083 - val_accuracy: 0.8875
# Epoch 173/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2885 - accuracy: 0.9020 - val_loss: 0.3449 - val_accuracy: 0.8687
# Epoch 174/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2848 - accuracy: 0.9055 - val_loss: 0.3043 - val_accuracy: 0.8922
# Epoch 175/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2883 - accuracy: 0.9039 - val_loss: 0.3183 - val_accuracy: 0.8813
# Epoch 176/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2804 - accuracy: 0.9090 - val_loss: 0.3270 - val_accuracy: 0.8828
# Epoch 177/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2846 - accuracy: 0.9121 - val_loss: 0.3039 - val_accuracy: 0.8875
# Epoch 178/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2861 - accuracy: 0.9070 - val_loss: 0.3203 - val_accuracy: 0.8781
# Epoch 179/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2913 - accuracy: 0.9027 - val_loss: 0.3613 - val_accuracy: 0.8687
# Epoch 180/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2919 - accuracy: 0.8977 - val_loss: 0.2842 - val_accuracy: 0.9078
# Epoch 181/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2826 - accuracy: 0.9043 - val_loss: 0.3001 - val_accuracy: 0.8844
# Epoch 182/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2798 - accuracy: 0.9047 - val_loss: 0.3571 - val_accuracy: 0.8625
# Epoch 183/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2908 - accuracy: 0.9000 - val_loss: 0.2878 - val_accuracy: 0.9078
# Epoch 184/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2874 - accuracy: 0.9051 - val_loss: 0.3107 - val_accuracy: 0.8875
# Epoch 185/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2862 - accuracy: 0.9035 - val_loss: 0.3498 - val_accuracy: 0.8672
# Epoch 186/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2872 - accuracy: 0.9020 - val_loss: 0.3238 - val_accuracy: 0.8875
# Epoch 187/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2813 - accuracy: 0.9027 - val_loss: 0.2935 - val_accuracy: 0.8922
# Epoch 188/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2814 - accuracy: 0.9043 - val_loss: 0.3431 - val_accuracy: 0.8750
# Epoch 189/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2794 - accuracy: 0.9086 - val_loss: 0.2986 - val_accuracy: 0.8891
# Epoch 190/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.2780 - accuracy: 0.9066 - val_loss: 0.2991 - val_accuracy: 0.8859
# Epoch 191/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2826 - accuracy: 0.9070 - val_loss: 0.3296 - val_accuracy: 0.8719
# Epoch 192/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2762 - accuracy: 0.9062 - val_loss: 0.3401 - val_accuracy: 0.8672
# Epoch 193/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2713 - accuracy: 0.9098 - val_loss: 0.3260 - val_accuracy: 0.8859
# Epoch 194/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2822 - accuracy: 0.9059 - val_loss: 0.2908 - val_accuracy: 0.8859
# Epoch 195/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2772 - accuracy: 0.9066 - val_loss: 0.3329 - val_accuracy: 0.8781
# Epoch 196/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2857 - accuracy: 0.9016 - val_loss: 0.2919 - val_accuracy: 0.8938
# Epoch 197/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2747 - accuracy: 0.9059 - val_loss: 0.3408 - val_accuracy: 0.8719
# Epoch 198/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2773 - accuracy: 0.9043 - val_loss: 0.3551 - val_accuracy: 0.8625
# Epoch 199/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2696 - accuracy: 0.9082 - val_loss: 0.2791 - val_accuracy: 0.8969
# Epoch 200/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2711 - accuracy: 0.9051 - val_loss: 0.3892 - val_accuracy: 0.8531

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 56ms/step - loss: 1.9999 - accuracy: 0.2824 - val_loss: 1.8355 - val_accuracy: 0.3187
# Epoch 2/50
# 5/5 [==============================] - 0s 24ms/step - loss: 1.7823 - accuracy: 0.3406 - val_loss: 1.7002 - val_accuracy: 0.3766
# Epoch 3/50
# 5/5 [==============================] - 0s 20ms/step - loss: 1.6871 - accuracy: 0.4219 - val_loss: 1.5971 - val_accuracy: 0.4922
# Epoch 4/50
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6025 - accuracy: 0.4871 - val_loss: 1.4910 - val_accuracy: 0.4922
# Epoch 5/50
# 5/5 [==============================] - 0s 20ms/step - loss: 1.5139 - accuracy: 0.5043 - val_loss: 1.3880 - val_accuracy: 0.5109
# Epoch 6/50
# 5/5 [==============================] - 0s 23ms/step - loss: 1.4291 - accuracy: 0.5223 - val_loss: 1.2912 - val_accuracy: 0.5609
# Epoch 7/50
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3391 - accuracy: 0.5750 - val_loss: 1.2062 - val_accuracy: 0.6313
# Epoch 8/50
# 5/5 [==============================] - 0s 29ms/step - loss: 1.2800 - accuracy: 0.5762 - val_loss: 1.1309 - val_accuracy: 0.6391
# Epoch 9/50
# 5/5 [==============================] - 0s 32ms/step - loss: 1.2091 - accuracy: 0.5988 - val_loss: 1.0688 - val_accuracy: 0.7188
# Epoch 10/50
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1472 - accuracy: 0.6262 - val_loss: 0.9947 - val_accuracy: 0.7359
# Epoch 11/50
# 5/5 [==============================] - 0s 25ms/step - loss: 1.1086 - accuracy: 0.6305 - val_loss: 0.9399 - val_accuracy: 0.7500
# Epoch 12/50
# 5/5 [==============================] - 0s 19ms/step - loss: 1.0426 - accuracy: 0.6527 - val_loss: 0.8992 - val_accuracy: 0.7250
# Epoch 13/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9963 - accuracy: 0.6742 - val_loss: 0.8503 - val_accuracy: 0.7250
# Epoch 14/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9687 - accuracy: 0.6715 - val_loss: 0.8220 - val_accuracy: 0.7297
# Epoch 15/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9246 - accuracy: 0.6969 - val_loss: 0.7877 - val_accuracy: 0.7359
# Epoch 16/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9022 - accuracy: 0.6977 - val_loss: 0.7632 - val_accuracy: 0.7344
# Epoch 17/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.8705 - accuracy: 0.7109 - val_loss: 0.7456 - val_accuracy: 0.7859
# Epoch 18/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8458 - accuracy: 0.7145 - val_loss: 0.7256 - val_accuracy: 0.7531
# Epoch 19/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.8098 - accuracy: 0.7238 - val_loss: 0.7014 - val_accuracy: 0.7844
# Epoch 20/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7853 - accuracy: 0.7437 - val_loss: 0.6871 - val_accuracy: 0.7969
# Epoch 21/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7599 - accuracy: 0.7551 - val_loss: 0.6655 - val_accuracy: 0.7922
# Epoch 22/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.7464 - accuracy: 0.7523 - val_loss: 0.6487 - val_accuracy: 0.8078
# Epoch 23/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7322 - accuracy: 0.7738 - val_loss: 0.6342 - val_accuracy: 0.8031
# Epoch 24/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7250 - accuracy: 0.7660 - val_loss: 0.6214 - val_accuracy: 0.8219
# Epoch 25/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6983 - accuracy: 0.7883 - val_loss: 0.6125 - val_accuracy: 0.8016
# Epoch 26/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6716 - accuracy: 0.7883 - val_loss: 0.5937 - val_accuracy: 0.8234
# Epoch 27/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6666 - accuracy: 0.8043 - val_loss: 0.5833 - val_accuracy: 0.8172
# Epoch 28/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6546 - accuracy: 0.7977 - val_loss: 0.5747 - val_accuracy: 0.8188
# Epoch 29/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6422 - accuracy: 0.8004 - val_loss: 0.5616 - val_accuracy: 0.8313
# Epoch 30/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6293 - accuracy: 0.8070 - val_loss: 0.5701 - val_accuracy: 0.8250
# Epoch 31/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6137 - accuracy: 0.8090 - val_loss: 0.5443 - val_accuracy: 0.8438
# Epoch 32/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6153 - accuracy: 0.8117 - val_loss: 0.5399 - val_accuracy: 0.8328
# Epoch 33/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5920 - accuracy: 0.8281 - val_loss: 0.5272 - val_accuracy: 0.8313
# Epoch 34/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5957 - accuracy: 0.8141 - val_loss: 0.5227 - val_accuracy: 0.8328
# Epoch 35/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5984 - accuracy: 0.8145 - val_loss: 0.5242 - val_accuracy: 0.8359
# Epoch 36/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5822 - accuracy: 0.8215 - val_loss: 0.5062 - val_accuracy: 0.8453
# Epoch 37/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5672 - accuracy: 0.8297 - val_loss: 0.5018 - val_accuracy: 0.8406
# Epoch 38/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5576 - accuracy: 0.8277 - val_loss: 0.4913 - val_accuracy: 0.8578
# Epoch 39/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5572 - accuracy: 0.8352 - val_loss: 0.4927 - val_accuracy: 0.8438
# Epoch 40/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5574 - accuracy: 0.8305 - val_loss: 0.4804 - val_accuracy: 0.8531
# Epoch 41/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5414 - accuracy: 0.8270 - val_loss: 0.4776 - val_accuracy: 0.8578
# Epoch 42/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5361 - accuracy: 0.8434 - val_loss: 0.4788 - val_accuracy: 0.8438
# Epoch 43/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5316 - accuracy: 0.8352 - val_loss: 0.4654 - val_accuracy: 0.8797
# Epoch 44/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5315 - accuracy: 0.8387 - val_loss: 0.4640 - val_accuracy: 0.8516
# Epoch 45/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5188 - accuracy: 0.8430 - val_loss: 0.4606 - val_accuracy: 0.8469
# Epoch 46/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5086 - accuracy: 0.8473 - val_loss: 0.4540 - val_accuracy: 0.8500
# Epoch 47/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5047 - accuracy: 0.8492 - val_loss: 0.4439 - val_accuracy: 0.8641
# Epoch 48/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.5050 - accuracy: 0.8469 - val_loss: 0.4478 - val_accuracy: 0.8547
# Epoch 49/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5019 - accuracy: 0.8508 - val_loss: 0.4297 - val_accuracy: 0.8734
# Epoch 50/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5021 - accuracy: 0.8395 - val_loss: 0.4350 - val_accuracy: 0.8813

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 2ms/step - loss: 0.4281 - accuracy: 0.8922
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.8813
# 0.8921874761581421 0.8812500238418579

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 15, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:01:52

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 58   0   0   0   2   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 117   0   3   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  2   0   0   1 188  13   0   0   0]
#  [  0   0   0   1  10  88   0   1   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   7  10   0   3   0]
#  [  0   0   0   0  12   8   0   0   0]]
#
# Accuracy Score
# 0.88125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.97      0.97      0.97        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.97      0.99       120
#       water       0.83      1.00      0.91        10
#       built       0.82      0.92      0.87       204
#     windows       0.74      0.88      0.80       100
#       roads       0.00      0.00      0.00         6
#        cars       0.75      0.15      0.25        20
#       metal       0.00      0.00      0.00        20
#
# avg / total       0.85      0.88      0.86       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 15)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 15)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 15) (80, 15)
# clouds  (400, 15) (100, 15)
# vegetation  (488, 15) (122, 15)
# built  (960, 15) (240, 15)
# windows  (400, 15) (100, 15)
# roads  (48, 15) (12, 15)
# cars  (44, 15) (11, 15)
# metal  (184, 15) (46, 15)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 15) (2844,) (2844, 2)
# (711, 15) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 85ms/step - loss: 2.0382 - accuracy: 0.2936 - val_loss: 1.8787 - val_accuracy: 0.3376
# Epoch 2/200
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8014 - accuracy: 0.3393 - val_loss: 1.7072 - val_accuracy: 0.3376
# Epoch 3/200
# 6/6 [==============================] - 0s 36ms/step - loss: 1.6692 - accuracy: 0.3499 - val_loss: 1.5847 - val_accuracy: 0.3769
# Epoch 4/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.5582 - accuracy: 0.4409 - val_loss: 1.4761 - val_accuracy: 0.6385
# Epoch 5/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.4480 - accuracy: 0.5735 - val_loss: 1.3516 - val_accuracy: 0.6301
# Epoch 6/200
# 6/6 [==============================] - 0s 24ms/step - loss: 1.3303 - accuracy: 0.5897 - val_loss: 1.2353 - val_accuracy: 0.6709
# Epoch 7/200
# 6/6 [==============================] - 0s 23ms/step - loss: 1.2144 - accuracy: 0.6431 - val_loss: 1.1266 - val_accuracy: 0.6596
# Epoch 8/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1263 - accuracy: 0.6593 - val_loss: 1.0323 - val_accuracy: 0.6653
# Epoch 9/200
# 6/6 [==============================] - 0s 22ms/step - loss: 1.0421 - accuracy: 0.6677 - val_loss: 0.9642 - val_accuracy: 0.7004
# Epoch 10/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.9761 - accuracy: 0.6835 - val_loss: 0.9109 - val_accuracy: 0.6990
# Epoch 11/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.9232 - accuracy: 0.6941 - val_loss: 0.8707 - val_accuracy: 0.7032
# Epoch 12/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8895 - accuracy: 0.6853 - val_loss: 0.8500 - val_accuracy: 0.7159
# Epoch 13/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.8573 - accuracy: 0.6997 - val_loss: 0.8138 - val_accuracy: 0.6892
# Epoch 14/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.8274 - accuracy: 0.6881 - val_loss: 0.7954 - val_accuracy: 0.7286
# Epoch 15/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7923 - accuracy: 0.7046 - val_loss: 0.7699 - val_accuracy: 0.7004
# Epoch 16/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7857 - accuracy: 0.7043 - val_loss: 0.7604 - val_accuracy: 0.7286
# Epoch 17/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.7638 - accuracy: 0.6983 - val_loss: 0.7395 - val_accuracy: 0.7243
# Epoch 18/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7431 - accuracy: 0.7229 - val_loss: 0.7242 - val_accuracy: 0.7004
# Epoch 19/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7448 - accuracy: 0.7001 - val_loss: 0.7218 - val_accuracy: 0.7384
# Epoch 20/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.7155 - accuracy: 0.7352 - val_loss: 0.7019 - val_accuracy: 0.6976
# Epoch 21/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.7081 - accuracy: 0.7089 - val_loss: 0.7001 - val_accuracy: 0.7384
# Epoch 22/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6966 - accuracy: 0.7352 - val_loss: 0.6841 - val_accuracy: 0.7173
# Epoch 23/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6852 - accuracy: 0.7173 - val_loss: 0.6859 - val_accuracy: 0.7286
# Epoch 24/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6813 - accuracy: 0.7307 - val_loss: 0.6665 - val_accuracy: 0.7173
# Epoch 25/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6739 - accuracy: 0.7286 - val_loss: 0.6666 - val_accuracy: 0.7412
# Epoch 26/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6704 - accuracy: 0.7317 - val_loss: 0.6486 - val_accuracy: 0.7243
# Epoch 27/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6640 - accuracy: 0.7300 - val_loss: 0.6442 - val_accuracy: 0.7370
# Epoch 28/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6532 - accuracy: 0.7278 - val_loss: 0.6362 - val_accuracy: 0.7243
# Epoch 29/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6332 - accuracy: 0.7486 - val_loss: 0.6294 - val_accuracy: 0.7159
# Epoch 30/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6407 - accuracy: 0.7286 - val_loss: 0.6278 - val_accuracy: 0.7567
# Epoch 31/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6293 - accuracy: 0.7363 - val_loss: 0.6147 - val_accuracy: 0.7201
# Epoch 32/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6155 - accuracy: 0.7496 - val_loss: 0.6060 - val_accuracy: 0.7257
# Epoch 33/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6192 - accuracy: 0.7293 - val_loss: 0.6117 - val_accuracy: 0.7426
# Epoch 34/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6043 - accuracy: 0.7472 - val_loss: 0.5974 - val_accuracy: 0.7468
# Epoch 35/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6082 - accuracy: 0.7461 - val_loss: 0.5946 - val_accuracy: 0.7567
# Epoch 36/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6059 - accuracy: 0.7518 - val_loss: 0.5867 - val_accuracy: 0.7370
# Epoch 37/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5954 - accuracy: 0.7500 - val_loss: 0.5861 - val_accuracy: 0.7454
# Epoch 38/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5876 - accuracy: 0.7504 - val_loss: 0.5786 - val_accuracy: 0.7553
# Epoch 39/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5773 - accuracy: 0.7634 - val_loss: 0.5740 - val_accuracy: 0.7595
# Epoch 40/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5912 - accuracy: 0.7672 - val_loss: 0.5695 - val_accuracy: 0.7468
# Epoch 41/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5806 - accuracy: 0.7616 - val_loss: 0.5661 - val_accuracy: 0.7679
# Epoch 42/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5727 - accuracy: 0.7651 - val_loss: 0.5660 - val_accuracy: 0.7609
# Epoch 43/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5708 - accuracy: 0.7707 - val_loss: 0.5603 - val_accuracy: 0.7637
# Epoch 44/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5587 - accuracy: 0.7729 - val_loss: 0.5632 - val_accuracy: 0.7707
# Epoch 45/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5590 - accuracy: 0.7725 - val_loss: 0.5495 - val_accuracy: 0.7623
# Epoch 46/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5609 - accuracy: 0.7760 - val_loss: 0.5665 - val_accuracy: 0.7736
# Epoch 47/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5595 - accuracy: 0.7665 - val_loss: 0.5482 - val_accuracy: 0.7623
# Epoch 48/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5533 - accuracy: 0.7771 - val_loss: 0.5517 - val_accuracy: 0.7792
# Epoch 49/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5501 - accuracy: 0.7813 - val_loss: 0.5427 - val_accuracy: 0.7764
# Epoch 50/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5343 - accuracy: 0.7915 - val_loss: 0.5461 - val_accuracy: 0.7665
# Epoch 51/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5315 - accuracy: 0.7866 - val_loss: 0.5341 - val_accuracy: 0.7778
# Epoch 52/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5424 - accuracy: 0.7883 - val_loss: 0.5310 - val_accuracy: 0.7890
# Epoch 53/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5216 - accuracy: 0.7911 - val_loss: 0.5277 - val_accuracy: 0.7862
# Epoch 54/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5332 - accuracy: 0.7855 - val_loss: 0.5381 - val_accuracy: 0.7862
# Epoch 55/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5285 - accuracy: 0.7940 - val_loss: 0.5331 - val_accuracy: 0.7792
# Epoch 56/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5178 - accuracy: 0.8034 - val_loss: 0.5204 - val_accuracy: 0.7947
# Epoch 57/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5247 - accuracy: 0.7901 - val_loss: 0.5261 - val_accuracy: 0.7947
# Epoch 58/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5170 - accuracy: 0.7961 - val_loss: 0.5212 - val_accuracy: 0.7961
# Epoch 59/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5213 - accuracy: 0.7954 - val_loss: 0.5129 - val_accuracy: 0.7764
# Epoch 60/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5136 - accuracy: 0.7897 - val_loss: 0.5233 - val_accuracy: 0.8003
# Epoch 61/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5163 - accuracy: 0.7918 - val_loss: 0.5080 - val_accuracy: 0.8059
# Epoch 62/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5033 - accuracy: 0.8031 - val_loss: 0.5137 - val_accuracy: 0.8172
# Epoch 63/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5120 - accuracy: 0.8034 - val_loss: 0.5096 - val_accuracy: 0.8031
# Epoch 64/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5146 - accuracy: 0.8052 - val_loss: 0.5090 - val_accuracy: 0.8172
# Epoch 65/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5092 - accuracy: 0.7947 - val_loss: 0.5064 - val_accuracy: 0.8129
# Epoch 66/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5103 - accuracy: 0.7999 - val_loss: 0.5220 - val_accuracy: 0.7764
# Epoch 67/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5006 - accuracy: 0.8024 - val_loss: 0.4969 - val_accuracy: 0.8045
# Epoch 68/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5044 - accuracy: 0.8003 - val_loss: 0.5135 - val_accuracy: 0.7876
# Epoch 69/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5062 - accuracy: 0.7915 - val_loss: 0.4981 - val_accuracy: 0.8270
# Epoch 70/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5023 - accuracy: 0.8094 - val_loss: 0.4971 - val_accuracy: 0.8129
# Epoch 71/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4900 - accuracy: 0.8038 - val_loss: 0.5149 - val_accuracy: 0.7904
# Epoch 72/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4892 - accuracy: 0.8066 - val_loss: 0.4921 - val_accuracy: 0.8340
# Epoch 73/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4990 - accuracy: 0.8059 - val_loss: 0.4885 - val_accuracy: 0.8087
# Epoch 74/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4969 - accuracy: 0.8101 - val_loss: 0.5042 - val_accuracy: 0.7722
# Epoch 75/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4989 - accuracy: 0.8087 - val_loss: 0.4904 - val_accuracy: 0.8256
# Epoch 76/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4810 - accuracy: 0.8101 - val_loss: 0.4904 - val_accuracy: 0.8312
# Epoch 77/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4740 - accuracy: 0.8193 - val_loss: 0.4987 - val_accuracy: 0.8087
# Epoch 78/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4872 - accuracy: 0.8179 - val_loss: 0.4822 - val_accuracy: 0.8453
# Epoch 79/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4778 - accuracy: 0.8133 - val_loss: 0.4910 - val_accuracy: 0.8172
# Epoch 80/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4762 - accuracy: 0.8133 - val_loss: 0.4899 - val_accuracy: 0.8186
# Epoch 81/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4807 - accuracy: 0.8154 - val_loss: 0.4860 - val_accuracy: 0.8270
# Epoch 82/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4727 - accuracy: 0.8235 - val_loss: 0.4721 - val_accuracy: 0.8298
# Epoch 83/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4722 - accuracy: 0.8186 - val_loss: 0.4919 - val_accuracy: 0.8087
# Epoch 84/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4600 - accuracy: 0.8249 - val_loss: 0.4783 - val_accuracy: 0.8186
# Epoch 85/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4748 - accuracy: 0.8172 - val_loss: 0.4778 - val_accuracy: 0.8284
# Epoch 86/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4576 - accuracy: 0.8182 - val_loss: 0.4781 - val_accuracy: 0.8298
# Epoch 87/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4631 - accuracy: 0.8256 - val_loss: 0.4726 - val_accuracy: 0.8383
# Epoch 88/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4576 - accuracy: 0.8263 - val_loss: 0.4700 - val_accuracy: 0.8200
# Epoch 89/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4608 - accuracy: 0.8259 - val_loss: 0.4690 - val_accuracy: 0.8312
# Epoch 90/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4520 - accuracy: 0.8281 - val_loss: 0.4690 - val_accuracy: 0.8368
# Epoch 91/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4463 - accuracy: 0.8309 - val_loss: 0.4578 - val_accuracy: 0.8354
# Epoch 92/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4512 - accuracy: 0.8182 - val_loss: 0.4628 - val_accuracy: 0.8397
# Epoch 93/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4603 - accuracy: 0.8252 - val_loss: 0.4765 - val_accuracy: 0.8270
# Epoch 94/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4423 - accuracy: 0.8365 - val_loss: 0.4541 - val_accuracy: 0.8397
# Epoch 95/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4443 - accuracy: 0.8256 - val_loss: 0.4875 - val_accuracy: 0.8059
# Epoch 96/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4580 - accuracy: 0.8161 - val_loss: 0.4549 - val_accuracy: 0.8481
# Epoch 97/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4663 - accuracy: 0.8158 - val_loss: 0.4601 - val_accuracy: 0.8270
# Epoch 98/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4464 - accuracy: 0.8256 - val_loss: 0.4700 - val_accuracy: 0.8354
# Epoch 99/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4403 - accuracy: 0.8326 - val_loss: 0.4498 - val_accuracy: 0.8397
# Epoch 100/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4453 - accuracy: 0.8337 - val_loss: 0.4618 - val_accuracy: 0.8411
# Epoch 101/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4477 - accuracy: 0.8330 - val_loss: 0.4556 - val_accuracy: 0.8383
# Epoch 102/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4243 - accuracy: 0.8414 - val_loss: 0.4547 - val_accuracy: 0.8326
# Epoch 103/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4389 - accuracy: 0.8347 - val_loss: 0.4660 - val_accuracy: 0.8368
# Epoch 104/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4339 - accuracy: 0.8407 - val_loss: 0.4397 - val_accuracy: 0.8467
# Epoch 105/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4317 - accuracy: 0.8323 - val_loss: 0.4467 - val_accuracy: 0.8298
# Epoch 106/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4306 - accuracy: 0.8365 - val_loss: 0.4437 - val_accuracy: 0.8439
# Epoch 107/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4256 - accuracy: 0.8407 - val_loss: 0.4474 - val_accuracy: 0.8425
# Epoch 108/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4217 - accuracy: 0.8425 - val_loss: 0.4446 - val_accuracy: 0.8509
# Epoch 109/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4260 - accuracy: 0.8376 - val_loss: 0.4492 - val_accuracy: 0.8298
# Epoch 110/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4185 - accuracy: 0.8446 - val_loss: 0.4278 - val_accuracy: 0.8565
# Epoch 111/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4260 - accuracy: 0.8368 - val_loss: 0.4845 - val_accuracy: 0.8270
# Epoch 112/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4312 - accuracy: 0.8295 - val_loss: 0.4328 - val_accuracy: 0.8467
# Epoch 113/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4258 - accuracy: 0.8513 - val_loss: 0.4380 - val_accuracy: 0.8495
# Epoch 114/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4114 - accuracy: 0.8383 - val_loss: 0.4552 - val_accuracy: 0.8453
# Epoch 115/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4139 - accuracy: 0.8467 - val_loss: 0.4321 - val_accuracy: 0.8495
# Epoch 116/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4136 - accuracy: 0.8404 - val_loss: 0.4545 - val_accuracy: 0.8298
# Epoch 117/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4164 - accuracy: 0.8456 - val_loss: 0.4209 - val_accuracy: 0.8579
# Epoch 118/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4138 - accuracy: 0.8439 - val_loss: 0.4496 - val_accuracy: 0.8284
# Epoch 119/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4231 - accuracy: 0.8502 - val_loss: 0.4253 - val_accuracy: 0.8523
# Epoch 120/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4093 - accuracy: 0.8470 - val_loss: 0.4374 - val_accuracy: 0.8284
# Epoch 121/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4137 - accuracy: 0.8506 - val_loss: 0.4239 - val_accuracy: 0.8551
# Epoch 122/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4081 - accuracy: 0.8463 - val_loss: 0.4430 - val_accuracy: 0.8354
# Epoch 123/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4070 - accuracy: 0.8534 - val_loss: 0.4196 - val_accuracy: 0.8509
# Epoch 124/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4032 - accuracy: 0.8537 - val_loss: 0.4286 - val_accuracy: 0.8537
# Epoch 125/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4049 - accuracy: 0.8509 - val_loss: 0.4125 - val_accuracy: 0.8523
# Epoch 126/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4031 - accuracy: 0.8463 - val_loss: 0.4346 - val_accuracy: 0.8425
# Epoch 127/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3965 - accuracy: 0.8534 - val_loss: 0.4182 - val_accuracy: 0.8509
# Epoch 128/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3888 - accuracy: 0.8579 - val_loss: 0.4272 - val_accuracy: 0.8453
# Epoch 129/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3992 - accuracy: 0.8576 - val_loss: 0.4235 - val_accuracy: 0.8594
# Epoch 130/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4005 - accuracy: 0.8474 - val_loss: 0.4175 - val_accuracy: 0.8467
# Epoch 131/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3910 - accuracy: 0.8509 - val_loss: 0.4257 - val_accuracy: 0.8551
# Epoch 132/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3957 - accuracy: 0.8499 - val_loss: 0.4156 - val_accuracy: 0.8481
# Epoch 133/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3957 - accuracy: 0.8629 - val_loss: 0.4225 - val_accuracy: 0.8608
# Epoch 134/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3923 - accuracy: 0.8523 - val_loss: 0.4296 - val_accuracy: 0.8439
# Epoch 135/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3936 - accuracy: 0.8576 - val_loss: 0.4048 - val_accuracy: 0.8523
# Epoch 136/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3891 - accuracy: 0.8516 - val_loss: 0.4302 - val_accuracy: 0.8608
# Epoch 137/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3751 - accuracy: 0.8608 - val_loss: 0.4108 - val_accuracy: 0.8453
# Epoch 138/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3816 - accuracy: 0.8537 - val_loss: 0.4078 - val_accuracy: 0.8509
# Epoch 139/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3840 - accuracy: 0.8569 - val_loss: 0.4243 - val_accuracy: 0.8411
# Epoch 140/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3826 - accuracy: 0.8604 - val_loss: 0.4006 - val_accuracy: 0.8594
# Epoch 141/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3825 - accuracy: 0.8569 - val_loss: 0.4208 - val_accuracy: 0.8368
# Epoch 142/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3823 - accuracy: 0.8576 - val_loss: 0.4035 - val_accuracy: 0.8636
# Epoch 143/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3834 - accuracy: 0.8562 - val_loss: 0.4170 - val_accuracy: 0.8397
# Epoch 144/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3780 - accuracy: 0.8590 - val_loss: 0.4025 - val_accuracy: 0.8579
# Epoch 145/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3793 - accuracy: 0.8604 - val_loss: 0.3964 - val_accuracy: 0.8565
# Epoch 146/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3732 - accuracy: 0.8586 - val_loss: 0.4208 - val_accuracy: 0.8608
# Epoch 147/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3805 - accuracy: 0.8562 - val_loss: 0.4099 - val_accuracy: 0.8467
# Epoch 148/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3741 - accuracy: 0.8681 - val_loss: 0.3936 - val_accuracy: 0.8579
# Epoch 149/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3700 - accuracy: 0.8569 - val_loss: 0.3994 - val_accuracy: 0.8608
# Epoch 150/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3656 - accuracy: 0.8590 - val_loss: 0.4167 - val_accuracy: 0.8397
# Epoch 151/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3677 - accuracy: 0.8636 - val_loss: 0.3979 - val_accuracy: 0.8481
# Epoch 152/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3643 - accuracy: 0.8713 - val_loss: 0.4020 - val_accuracy: 0.8495
# Epoch 153/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3643 - accuracy: 0.8618 - val_loss: 0.4038 - val_accuracy: 0.8453
# Epoch 154/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3713 - accuracy: 0.8601 - val_loss: 0.4032 - val_accuracy: 0.8495
# Epoch 155/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3715 - accuracy: 0.8601 - val_loss: 0.4074 - val_accuracy: 0.8467
# Epoch 156/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3745 - accuracy: 0.8583 - val_loss: 0.3987 - val_accuracy: 0.8439
# Epoch 157/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3664 - accuracy: 0.8688 - val_loss: 0.3890 - val_accuracy: 0.8579
# Epoch 158/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3778 - accuracy: 0.8513 - val_loss: 0.4014 - val_accuracy: 0.8551
# Epoch 159/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3588 - accuracy: 0.8646 - val_loss: 0.4012 - val_accuracy: 0.8326
# Epoch 160/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3691 - accuracy: 0.8583 - val_loss: 0.3841 - val_accuracy: 0.8608
# Epoch 161/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3672 - accuracy: 0.8667 - val_loss: 0.4013 - val_accuracy: 0.8579
# Epoch 162/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3652 - accuracy: 0.8604 - val_loss: 0.3934 - val_accuracy: 0.8537
# Epoch 163/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3643 - accuracy: 0.8586 - val_loss: 0.3838 - val_accuracy: 0.8551
# Epoch 164/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3544 - accuracy: 0.8703 - val_loss: 0.4020 - val_accuracy: 0.8523
# Epoch 165/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3588 - accuracy: 0.8660 - val_loss: 0.3863 - val_accuracy: 0.8594
# Epoch 166/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3553 - accuracy: 0.8629 - val_loss: 0.3935 - val_accuracy: 0.8608
# Epoch 167/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3578 - accuracy: 0.8576 - val_loss: 0.3938 - val_accuracy: 0.8439
# Epoch 168/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3548 - accuracy: 0.8657 - val_loss: 0.3821 - val_accuracy: 0.8622
# Epoch 169/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3562 - accuracy: 0.8688 - val_loss: 0.3951 - val_accuracy: 0.8481
# Epoch 170/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3568 - accuracy: 0.8597 - val_loss: 0.3966 - val_accuracy: 0.8495
# Epoch 171/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3572 - accuracy: 0.8692 - val_loss: 0.3807 - val_accuracy: 0.8608
# Epoch 172/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3542 - accuracy: 0.8646 - val_loss: 0.3823 - val_accuracy: 0.8467
# Epoch 173/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3497 - accuracy: 0.8650 - val_loss: 0.3880 - val_accuracy: 0.8706
# Epoch 174/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3510 - accuracy: 0.8752 - val_loss: 0.3911 - val_accuracy: 0.8467
# Epoch 175/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3464 - accuracy: 0.8710 - val_loss: 0.3819 - val_accuracy: 0.8622
# Epoch 176/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3399 - accuracy: 0.8720 - val_loss: 0.3798 - val_accuracy: 0.8537
# Epoch 177/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3437 - accuracy: 0.8695 - val_loss: 0.3911 - val_accuracy: 0.8495
# Epoch 178/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3436 - accuracy: 0.8674 - val_loss: 0.3748 - val_accuracy: 0.8692
# Epoch 179/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3520 - accuracy: 0.8639 - val_loss: 0.3916 - val_accuracy: 0.8383
# Epoch 180/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3440 - accuracy: 0.8724 - val_loss: 0.3635 - val_accuracy: 0.8692
# Epoch 181/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3505 - accuracy: 0.8650 - val_loss: 0.4142 - val_accuracy: 0.8397
# Epoch 182/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3478 - accuracy: 0.8703 - val_loss: 0.3662 - val_accuracy: 0.8692
# Epoch 183/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3399 - accuracy: 0.8650 - val_loss: 0.4113 - val_accuracy: 0.8354
# Epoch 184/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3380 - accuracy: 0.8713 - val_loss: 0.3711 - val_accuracy: 0.8608
# Epoch 185/200
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3483 - accuracy: 0.8678 - val_loss: 0.3813 - val_accuracy: 0.8411
# Epoch 186/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3330 - accuracy: 0.8731 - val_loss: 0.3900 - val_accuracy: 0.8551
# Epoch 187/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3521 - accuracy: 0.8699 - val_loss: 0.3702 - val_accuracy: 0.8608
# Epoch 188/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3387 - accuracy: 0.8646 - val_loss: 0.3907 - val_accuracy: 0.8495
# Epoch 189/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3515 - accuracy: 0.8671 - val_loss: 0.3807 - val_accuracy: 0.8608
# Epoch 190/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3354 - accuracy: 0.8745 - val_loss: 0.3950 - val_accuracy: 0.8340
# Epoch 191/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3336 - accuracy: 0.8703 - val_loss: 0.3660 - val_accuracy: 0.8734
# Epoch 192/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3368 - accuracy: 0.8664 - val_loss: 0.3855 - val_accuracy: 0.8453
# Epoch 193/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3447 - accuracy: 0.8695 - val_loss: 0.3612 - val_accuracy: 0.8692
# Epoch 194/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3342 - accuracy: 0.8636 - val_loss: 0.3927 - val_accuracy: 0.8326
# Epoch 195/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3345 - accuracy: 0.8674 - val_loss: 0.3592 - val_accuracy: 0.8622
# Epoch 196/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3374 - accuracy: 0.8664 - val_loss: 0.3860 - val_accuracy: 0.8397
# Epoch 197/200
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3365 - accuracy: 0.8674 - val_loss: 0.3649 - val_accuracy: 0.8551
# Epoch 198/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3501 - accuracy: 0.8615 - val_loss: 0.3782 - val_accuracy: 0.8467
# Epoch 199/200
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3251 - accuracy: 0.8794 - val_loss: 0.3723 - val_accuracy: 0.8537
# Epoch 200/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3318 - accuracy: 0.8703 - val_loss: 0.3794 - val_accuracy: 0.8439

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 0s 50ms/step - loss: 2.0690 - accuracy: 0.3084 - val_loss: 1.9302 - val_accuracy: 0.3376
# Epoch 2/40
# 6/6 [==============================] - 0s 28ms/step - loss: 1.8432 - accuracy: 0.3397 - val_loss: 1.7340 - val_accuracy: 0.3376
# Epoch 3/40
# 6/6 [==============================] - 0s 22ms/step - loss: 1.6905 - accuracy: 0.3393 - val_loss: 1.6171 - val_accuracy: 0.3376
# Epoch 4/40
# 6/6 [==============================] - 0s 24ms/step - loss: 1.5878 - accuracy: 0.3586 - val_loss: 1.5018 - val_accuracy: 0.5288
# Epoch 5/40
# 6/6 [==============================] - 0s 21ms/step - loss: 1.4614 - accuracy: 0.5784 - val_loss: 1.3845 - val_accuracy: 0.6399
# Epoch 6/40
# 6/6 [==============================] - 0s 21ms/step - loss: 1.3487 - accuracy: 0.6188 - val_loss: 1.2569 - val_accuracy: 0.6624
# Epoch 7/40
# 6/6 [==============================] - 0s 21ms/step - loss: 1.2258 - accuracy: 0.6470 - val_loss: 1.1341 - val_accuracy: 0.6835
# Epoch 8/40
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1095 - accuracy: 0.6741 - val_loss: 1.0326 - val_accuracy: 0.6850
# Epoch 9/40
# 6/6 [==============================] - 0s 28ms/step - loss: 1.0224 - accuracy: 0.6719 - val_loss: 0.9566 - val_accuracy: 0.7075
# Epoch 10/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.9464 - accuracy: 0.6867 - val_loss: 0.8995 - val_accuracy: 0.7018
# Epoch 11/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.9061 - accuracy: 0.6860 - val_loss: 0.8549 - val_accuracy: 0.7060
# Epoch 12/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.8515 - accuracy: 0.6990 - val_loss: 0.8182 - val_accuracy: 0.7201
# Epoch 13/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.8238 - accuracy: 0.7050 - val_loss: 0.7878 - val_accuracy: 0.7103
# Epoch 14/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.8002 - accuracy: 0.7039 - val_loss: 0.7676 - val_accuracy: 0.7257
# Epoch 15/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.7655 - accuracy: 0.7215 - val_loss: 0.7442 - val_accuracy: 0.7032
# Epoch 16/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7486 - accuracy: 0.7078 - val_loss: 0.7312 - val_accuracy: 0.7229
# Epoch 17/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7263 - accuracy: 0.7289 - val_loss: 0.7062 - val_accuracy: 0.7075
# Epoch 18/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.7215 - accuracy: 0.7187 - val_loss: 0.6928 - val_accuracy: 0.7398
# Epoch 19/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6959 - accuracy: 0.7243 - val_loss: 0.6749 - val_accuracy: 0.7440
# Epoch 20/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6872 - accuracy: 0.7468 - val_loss: 0.6675 - val_accuracy: 0.7539
# Epoch 21/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6697 - accuracy: 0.7472 - val_loss: 0.6511 - val_accuracy: 0.7511
# Epoch 22/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6510 - accuracy: 0.7430 - val_loss: 0.6401 - val_accuracy: 0.7412
# Epoch 23/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6485 - accuracy: 0.7409 - val_loss: 0.6356 - val_accuracy: 0.7482
# Epoch 24/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6379 - accuracy: 0.7482 - val_loss: 0.6239 - val_accuracy: 0.7553
# Epoch 25/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6399 - accuracy: 0.7458 - val_loss: 0.6204 - val_accuracy: 0.7454
# Epoch 26/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6154 - accuracy: 0.7560 - val_loss: 0.6095 - val_accuracy: 0.7623
# Epoch 27/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6093 - accuracy: 0.7651 - val_loss: 0.6021 - val_accuracy: 0.7426
# Epoch 28/40
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6044 - accuracy: 0.7574 - val_loss: 0.5995 - val_accuracy: 0.7707
# Epoch 29/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5925 - accuracy: 0.7693 - val_loss: 0.5898 - val_accuracy: 0.7623
# Epoch 30/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5935 - accuracy: 0.7658 - val_loss: 0.5784 - val_accuracy: 0.7595
# Epoch 31/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5871 - accuracy: 0.7623 - val_loss: 0.5801 - val_accuracy: 0.7750
# Epoch 32/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5735 - accuracy: 0.7739 - val_loss: 0.5702 - val_accuracy: 0.7736
# Epoch 33/40
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5757 - accuracy: 0.7757 - val_loss: 0.5748 - val_accuracy: 0.7707
# Epoch 34/40
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5676 - accuracy: 0.7739 - val_loss: 0.5595 - val_accuracy: 0.7722
# Epoch 35/40
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5664 - accuracy: 0.7816 - val_loss: 0.5596 - val_accuracy: 0.7736
# Epoch 36/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5526 - accuracy: 0.7908 - val_loss: 0.5478 - val_accuracy: 0.7806
# Epoch 37/40
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5491 - accuracy: 0.7841 - val_loss: 0.5508 - val_accuracy: 0.7834
# Epoch 38/40
# 6/6 [==============================] - 0s 22ms/step - loss: 0.5458 - accuracy: 0.7890 - val_loss: 0.5500 - val_accuracy: 0.7609
# Epoch 39/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5382 - accuracy: 0.7940 - val_loss: 0.5446 - val_accuracy: 0.7693
# Epoch 40/40
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5322 - accuracy: 0.7964 - val_loss: 0.5338 - val_accuracy: 0.7862

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 2ms/step - loss: 0.4675 - accuracy: 0.8277
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5338 - accuracy: 0.7862
# 0.8277074694633484 0.7862166166305542

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 15, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:01:53

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  4  96   0   0   0   0   0   0]
#  [  0   2 116   1   3   0   0   0]
#  [  0  11   4 202  23   0   0   0]
#  [  1   0   1  39  58   1   0   0]
#  [  0   0   0   0  10   2   0   0]
#  [  0   0   0   0   1   5   5   0]
#  [  0   0   0  33  13   0   0   0]]
#
# Accuracy Score
# 0.7862165963431786
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.94      1.00      0.97        80
#      clouds       0.88      0.96      0.92       100
#  vegetation       0.96      0.95      0.95       122
#       built       0.73      0.84      0.78       240
#     windows       0.54      0.58      0.56       100
#       roads       0.25      0.17      0.20        12
#        cars       1.00      0.45      0.62        11
#       metal       0.00      0.00      0.00        46
#
# avg / total       0.74      0.79      0.76       711
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 15
# [[0, 58], [58, 116], [116, 174], [174, 232], [232, 290], [290, 348], [348, 406], [406, 464], [464, 522], [522, 580], [580, 638], [638, 696], [696, 754], [754, 812], [812, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 15)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 15)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 15) (60, 15)
# clouds  (160, 15) (40, 15)
# vegetation  (560, 15) (140, 15)
# water  (496, 15) (124, 15)
# built  (1280, 15) (320, 15)
# windows  (480, 15) (120, 15)
# roads  (200, 15) (50, 15)
# cars  (200, 15) (50, 15)
# metal  (148, 15) (37, 15)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 15) (3764,) (3764, 2)
# (941, 15) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 41ms/step - loss: 2.0631 - accuracy: 0.2917 - val_loss: 1.8716 - val_accuracy: 0.3401
# Epoch 2/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.8247 - accuracy: 0.3467 - val_loss: 1.7351 - val_accuracy: 0.3773
# Epoch 3/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.7237 - accuracy: 0.4200 - val_loss: 1.6127 - val_accuracy: 0.4708
# Epoch 4/200
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6179 - accuracy: 0.4524 - val_loss: 1.4907 - val_accuracy: 0.5324
# Epoch 5/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.5099 - accuracy: 0.4862 - val_loss: 1.3856 - val_accuracy: 0.5675
# Epoch 6/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.4248 - accuracy: 0.5279 - val_loss: 1.3067 - val_accuracy: 0.5813
# Epoch 7/200
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3552 - accuracy: 0.5550 - val_loss: 1.2492 - val_accuracy: 0.6079
# Epoch 8/200
# 8/8 [==============================] - 0s 21ms/step - loss: 1.3006 - accuracy: 0.5712 - val_loss: 1.2002 - val_accuracy: 0.6164
# Epoch 9/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.2615 - accuracy: 0.5840 - val_loss: 1.1702 - val_accuracy: 0.6344
# Epoch 10/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2136 - accuracy: 0.6015 - val_loss: 1.1279 - val_accuracy: 0.6366
# Epoch 11/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.1825 - accuracy: 0.6180 - val_loss: 1.0944 - val_accuracy: 0.6366
# Epoch 12/200
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1397 - accuracy: 0.6201 - val_loss: 1.0655 - val_accuracy: 0.6525
# Epoch 13/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1106 - accuracy: 0.6283 - val_loss: 1.0420 - val_accuracy: 0.6674
# Epoch 14/200
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0849 - accuracy: 0.6374 - val_loss: 1.0076 - val_accuracy: 0.6631
# Epoch 15/200
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0606 - accuracy: 0.6413 - val_loss: 0.9904 - val_accuracy: 0.6706
# Epoch 16/200
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0343 - accuracy: 0.6538 - val_loss: 0.9655 - val_accuracy: 0.6812
# Epoch 17/200
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0132 - accuracy: 0.6602 - val_loss: 0.9445 - val_accuracy: 0.6961
# Epoch 18/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9993 - accuracy: 0.6658 - val_loss: 0.9255 - val_accuracy: 0.7024
# Epoch 19/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.9888 - accuracy: 0.6639 - val_loss: 0.9202 - val_accuracy: 0.7354
# Epoch 20/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.9628 - accuracy: 0.6836 - val_loss: 0.9105 - val_accuracy: 0.7386
# Epoch 21/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9392 - accuracy: 0.6868 - val_loss: 0.8780 - val_accuracy: 0.7248
# Epoch 22/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9361 - accuracy: 0.6825 - val_loss: 0.8624 - val_accuracy: 0.7343
# Epoch 23/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9232 - accuracy: 0.6998 - val_loss: 0.8550 - val_accuracy: 0.7524
# Epoch 24/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9198 - accuracy: 0.6892 - val_loss: 0.8486 - val_accuracy: 0.7588
# Epoch 25/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8980 - accuracy: 0.6971 - val_loss: 0.8418 - val_accuracy: 0.7503
# Epoch 26/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8951 - accuracy: 0.7048 - val_loss: 0.8175 - val_accuracy: 0.7545
# Epoch 27/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8747 - accuracy: 0.7107 - val_loss: 0.8136 - val_accuracy: 0.7577
# Epoch 28/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8602 - accuracy: 0.7216 - val_loss: 0.7994 - val_accuracy: 0.7566
# Epoch 29/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8594 - accuracy: 0.7171 - val_loss: 0.7914 - val_accuracy: 0.7598
# Epoch 30/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.8492 - accuracy: 0.7187 - val_loss: 0.7916 - val_accuracy: 0.7524
# Epoch 31/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8481 - accuracy: 0.7240 - val_loss: 0.7845 - val_accuracy: 0.7556
# Epoch 32/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8288 - accuracy: 0.7343 - val_loss: 0.7719 - val_accuracy: 0.7588
# Epoch 33/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8253 - accuracy: 0.7330 - val_loss: 0.7633 - val_accuracy: 0.7673
# Epoch 34/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8152 - accuracy: 0.7301 - val_loss: 0.7796 - val_accuracy: 0.7492
# Epoch 35/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8201 - accuracy: 0.7322 - val_loss: 0.7549 - val_accuracy: 0.7726
# Epoch 36/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8116 - accuracy: 0.7372 - val_loss: 0.7454 - val_accuracy: 0.7662
# Epoch 37/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8040 - accuracy: 0.7370 - val_loss: 0.7519 - val_accuracy: 0.7598
# Epoch 38/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7900 - accuracy: 0.7410 - val_loss: 0.7432 - val_accuracy: 0.7609
# Epoch 39/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7856 - accuracy: 0.7410 - val_loss: 0.7332 - val_accuracy: 0.7641
# Epoch 40/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7768 - accuracy: 0.7457 - val_loss: 0.7285 - val_accuracy: 0.7662
# Epoch 41/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7738 - accuracy: 0.7450 - val_loss: 0.7248 - val_accuracy: 0.7736
# Epoch 42/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7784 - accuracy: 0.7442 - val_loss: 0.7300 - val_accuracy: 0.7662
# Epoch 43/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7695 - accuracy: 0.7450 - val_loss: 0.7203 - val_accuracy: 0.7747
# Epoch 44/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7656 - accuracy: 0.7481 - val_loss: 0.7110 - val_accuracy: 0.7736
# Epoch 45/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7517 - accuracy: 0.7511 - val_loss: 0.7100 - val_accuracy: 0.7779
# Epoch 46/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7475 - accuracy: 0.7513 - val_loss: 0.7056 - val_accuracy: 0.7736
# Epoch 47/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7426 - accuracy: 0.7556 - val_loss: 0.6984 - val_accuracy: 0.7843
# Epoch 48/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7454 - accuracy: 0.7558 - val_loss: 0.7011 - val_accuracy: 0.7747
# Epoch 49/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7496 - accuracy: 0.7609 - val_loss: 0.6916 - val_accuracy: 0.7811
# Epoch 50/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7430 - accuracy: 0.7593 - val_loss: 0.6902 - val_accuracy: 0.7853
# Epoch 51/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7351 - accuracy: 0.7566 - val_loss: 0.6909 - val_accuracy: 0.7800
# Epoch 52/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7345 - accuracy: 0.7566 - val_loss: 0.6947 - val_accuracy: 0.7747
# Epoch 53/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7408 - accuracy: 0.7620 - val_loss: 0.6796 - val_accuracy: 0.7885
# Epoch 54/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.7407 - accuracy: 0.7593 - val_loss: 0.6853 - val_accuracy: 0.7779
# Epoch 55/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7311 - accuracy: 0.7593 - val_loss: 0.6746 - val_accuracy: 0.7832
# Epoch 56/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7312 - accuracy: 0.7604 - val_loss: 0.6812 - val_accuracy: 0.7949
# Epoch 57/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7180 - accuracy: 0.7667 - val_loss: 0.6807 - val_accuracy: 0.7790
# Epoch 58/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7161 - accuracy: 0.7654 - val_loss: 0.6691 - val_accuracy: 0.7928
# Epoch 59/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7217 - accuracy: 0.7710 - val_loss: 0.6674 - val_accuracy: 0.7896
# Epoch 60/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7106 - accuracy: 0.7728 - val_loss: 0.6652 - val_accuracy: 0.7875
# Epoch 61/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7184 - accuracy: 0.7654 - val_loss: 0.6671 - val_accuracy: 0.7970
# Epoch 62/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7147 - accuracy: 0.7657 - val_loss: 0.6609 - val_accuracy: 0.7864
# Epoch 63/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7109 - accuracy: 0.7678 - val_loss: 0.6606 - val_accuracy: 0.7928
# Epoch 64/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7010 - accuracy: 0.7697 - val_loss: 0.6661 - val_accuracy: 0.7885
# Epoch 65/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6899 - accuracy: 0.7771 - val_loss: 0.6593 - val_accuracy: 0.7970
# Epoch 66/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7002 - accuracy: 0.7752 - val_loss: 0.6493 - val_accuracy: 0.8045
# Epoch 67/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6993 - accuracy: 0.7803 - val_loss: 0.6472 - val_accuracy: 0.8013
# Epoch 68/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6967 - accuracy: 0.7763 - val_loss: 0.6435 - val_accuracy: 0.7991
# Epoch 69/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6872 - accuracy: 0.7755 - val_loss: 0.6488 - val_accuracy: 0.7885
# Epoch 70/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6933 - accuracy: 0.7768 - val_loss: 0.6491 - val_accuracy: 0.8013
# Epoch 71/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6822 - accuracy: 0.7787 - val_loss: 0.6402 - val_accuracy: 0.7949
# Epoch 72/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6872 - accuracy: 0.7705 - val_loss: 0.6438 - val_accuracy: 0.7896
# Epoch 73/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6774 - accuracy: 0.7784 - val_loss: 0.6368 - val_accuracy: 0.7960
# Epoch 74/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6889 - accuracy: 0.7726 - val_loss: 0.6389 - val_accuracy: 0.8077
# Epoch 75/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6728 - accuracy: 0.7829 - val_loss: 0.6325 - val_accuracy: 0.7981
# Epoch 76/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6771 - accuracy: 0.7798 - val_loss: 0.6409 - val_accuracy: 0.7917
# Epoch 77/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6791 - accuracy: 0.7763 - val_loss: 0.6289 - val_accuracy: 0.8023
# Epoch 78/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6702 - accuracy: 0.7824 - val_loss: 0.6295 - val_accuracy: 0.8023
# Epoch 79/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6766 - accuracy: 0.7758 - val_loss: 0.6235 - val_accuracy: 0.8002
# Epoch 80/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6626 - accuracy: 0.7859 - val_loss: 0.6250 - val_accuracy: 0.8108
# Epoch 81/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6580 - accuracy: 0.7891 - val_loss: 0.6195 - val_accuracy: 0.8055
# Epoch 82/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6654 - accuracy: 0.7845 - val_loss: 0.6167 - val_accuracy: 0.7970
# Epoch 83/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6631 - accuracy: 0.7843 - val_loss: 0.6232 - val_accuracy: 0.8066
# Epoch 84/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6597 - accuracy: 0.7808 - val_loss: 0.6156 - val_accuracy: 0.8013
# Epoch 85/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6682 - accuracy: 0.7877 - val_loss: 0.6117 - val_accuracy: 0.8087
# Epoch 86/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6615 - accuracy: 0.7899 - val_loss: 0.6131 - val_accuracy: 0.8151
# Epoch 87/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6519 - accuracy: 0.7859 - val_loss: 0.6114 - val_accuracy: 0.8119
# Epoch 88/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6542 - accuracy: 0.7904 - val_loss: 0.6122 - val_accuracy: 0.8023
# Epoch 89/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6554 - accuracy: 0.7936 - val_loss: 0.6050 - val_accuracy: 0.8108
# Epoch 90/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6467 - accuracy: 0.7938 - val_loss: 0.6026 - val_accuracy: 0.8119
# Epoch 91/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6511 - accuracy: 0.7885 - val_loss: 0.6044 - val_accuracy: 0.8023
# Epoch 92/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6502 - accuracy: 0.7885 - val_loss: 0.6042 - val_accuracy: 0.8130
# Epoch 93/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6394 - accuracy: 0.7941 - val_loss: 0.6125 - val_accuracy: 0.8108
# Epoch 94/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6431 - accuracy: 0.7914 - val_loss: 0.6018 - val_accuracy: 0.8108
# Epoch 95/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6454 - accuracy: 0.7922 - val_loss: 0.5975 - val_accuracy: 0.8119
# Epoch 96/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6538 - accuracy: 0.7813 - val_loss: 0.5982 - val_accuracy: 0.8130
# Epoch 97/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6350 - accuracy: 0.7973 - val_loss: 0.5968 - val_accuracy: 0.8162
# Epoch 98/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6404 - accuracy: 0.7893 - val_loss: 0.5984 - val_accuracy: 0.8162
# Epoch 99/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6306 - accuracy: 0.7978 - val_loss: 0.5945 - val_accuracy: 0.8140
# Epoch 100/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6227 - accuracy: 0.7970 - val_loss: 0.5920 - val_accuracy: 0.8140
# Epoch 101/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6352 - accuracy: 0.7896 - val_loss: 0.5996 - val_accuracy: 0.8098
# Epoch 102/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6292 - accuracy: 0.7997 - val_loss: 0.5869 - val_accuracy: 0.8183
# Epoch 103/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6357 - accuracy: 0.7965 - val_loss: 0.5909 - val_accuracy: 0.8172
# Epoch 104/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6227 - accuracy: 0.7965 - val_loss: 0.5874 - val_accuracy: 0.8151
# Epoch 105/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6267 - accuracy: 0.8007 - val_loss: 0.5833 - val_accuracy: 0.8162
# Epoch 106/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6298 - accuracy: 0.7999 - val_loss: 0.5871 - val_accuracy: 0.8183
# Epoch 107/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6223 - accuracy: 0.8002 - val_loss: 0.5864 - val_accuracy: 0.8183
# Epoch 108/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6231 - accuracy: 0.7952 - val_loss: 0.5795 - val_accuracy: 0.8236
# Epoch 109/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6316 - accuracy: 0.7899 - val_loss: 0.5820 - val_accuracy: 0.8183
# Epoch 110/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6145 - accuracy: 0.7960 - val_loss: 0.5784 - val_accuracy: 0.8236
# Epoch 111/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6189 - accuracy: 0.8037 - val_loss: 0.5813 - val_accuracy: 0.8151
# Epoch 112/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6223 - accuracy: 0.7960 - val_loss: 0.5747 - val_accuracy: 0.8193
# Epoch 113/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6253 - accuracy: 0.8018 - val_loss: 0.5757 - val_accuracy: 0.8247
# Epoch 114/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6141 - accuracy: 0.8066 - val_loss: 0.5862 - val_accuracy: 0.8066
# Epoch 115/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6124 - accuracy: 0.7981 - val_loss: 0.5717 - val_accuracy: 0.8204
# Epoch 116/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6128 - accuracy: 0.7976 - val_loss: 0.5767 - val_accuracy: 0.8193
# Epoch 117/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6064 - accuracy: 0.8050 - val_loss: 0.5657 - val_accuracy: 0.8215
# Epoch 118/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6072 - accuracy: 0.8079 - val_loss: 0.5672 - val_accuracy: 0.8247
# Epoch 119/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6068 - accuracy: 0.8066 - val_loss: 0.5645 - val_accuracy: 0.8215
# Epoch 120/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6089 - accuracy: 0.8061 - val_loss: 0.5612 - val_accuracy: 0.8257
# Epoch 121/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6072 - accuracy: 0.8055 - val_loss: 0.5637 - val_accuracy: 0.8278
# Epoch 122/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6013 - accuracy: 0.8034 - val_loss: 0.5592 - val_accuracy: 0.8247
# Epoch 123/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6007 - accuracy: 0.8071 - val_loss: 0.5606 - val_accuracy: 0.8204
# Epoch 124/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6030 - accuracy: 0.8061 - val_loss: 0.5574 - val_accuracy: 0.8215
# Epoch 125/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5928 - accuracy: 0.8084 - val_loss: 0.5591 - val_accuracy: 0.8289
# Epoch 126/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5980 - accuracy: 0.8079 - val_loss: 0.5546 - val_accuracy: 0.8236
# Epoch 127/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5857 - accuracy: 0.8114 - val_loss: 0.5517 - val_accuracy: 0.8268
# Epoch 128/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5994 - accuracy: 0.7986 - val_loss: 0.5537 - val_accuracy: 0.8321
# Epoch 129/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5920 - accuracy: 0.8063 - val_loss: 0.5493 - val_accuracy: 0.8268
# Epoch 130/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5955 - accuracy: 0.8090 - val_loss: 0.5528 - val_accuracy: 0.8342
# Epoch 131/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5880 - accuracy: 0.8087 - val_loss: 0.5469 - val_accuracy: 0.8278
# Epoch 132/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.5853 - accuracy: 0.8124 - val_loss: 0.5468 - val_accuracy: 0.8300
# Epoch 133/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5846 - accuracy: 0.8167 - val_loss: 0.5496 - val_accuracy: 0.8278
# Epoch 134/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5947 - accuracy: 0.8037 - val_loss: 0.5433 - val_accuracy: 0.8342
# Epoch 135/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5875 - accuracy: 0.8143 - val_loss: 0.5449 - val_accuracy: 0.8300
# Epoch 136/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5856 - accuracy: 0.8116 - val_loss: 0.5449 - val_accuracy: 0.8321
# Epoch 137/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5841 - accuracy: 0.8159 - val_loss: 0.5467 - val_accuracy: 0.8268
# Epoch 138/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5767 - accuracy: 0.8154 - val_loss: 0.5467 - val_accuracy: 0.8289
# Epoch 139/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5748 - accuracy: 0.8114 - val_loss: 0.5398 - val_accuracy: 0.8332
# Epoch 140/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5762 - accuracy: 0.8127 - val_loss: 0.5378 - val_accuracy: 0.8353
# Epoch 141/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5736 - accuracy: 0.8177 - val_loss: 0.5373 - val_accuracy: 0.8321
# Epoch 142/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5820 - accuracy: 0.8098 - val_loss: 0.5406 - val_accuracy: 0.8236
# Epoch 143/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5834 - accuracy: 0.8100 - val_loss: 0.5455 - val_accuracy: 0.8332
# Epoch 144/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5689 - accuracy: 0.8209 - val_loss: 0.5341 - val_accuracy: 0.8363
# Epoch 145/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5864 - accuracy: 0.8082 - val_loss: 0.5297 - val_accuracy: 0.8406
# Epoch 146/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5704 - accuracy: 0.8193 - val_loss: 0.5260 - val_accuracy: 0.8448
# Epoch 147/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5622 - accuracy: 0.8156 - val_loss: 0.5289 - val_accuracy: 0.8342
# Epoch 148/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5618 - accuracy: 0.8207 - val_loss: 0.5347 - val_accuracy: 0.8310
# Epoch 149/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5614 - accuracy: 0.8244 - val_loss: 0.5186 - val_accuracy: 0.8406
# Epoch 150/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5627 - accuracy: 0.8268 - val_loss: 0.5200 - val_accuracy: 0.8353
# Epoch 151/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5672 - accuracy: 0.8148 - val_loss: 0.5300 - val_accuracy: 0.8268
# Epoch 152/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5622 - accuracy: 0.8228 - val_loss: 0.5239 - val_accuracy: 0.8406
# Epoch 153/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5659 - accuracy: 0.8228 - val_loss: 0.5168 - val_accuracy: 0.8332
# Epoch 154/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5577 - accuracy: 0.8260 - val_loss: 0.5180 - val_accuracy: 0.8448
# Epoch 155/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5548 - accuracy: 0.8191 - val_loss: 0.5178 - val_accuracy: 0.8427
# Epoch 156/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5507 - accuracy: 0.8236 - val_loss: 0.5152 - val_accuracy: 0.8406
# Epoch 157/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5509 - accuracy: 0.8220 - val_loss: 0.5136 - val_accuracy: 0.8438
# Epoch 158/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5450 - accuracy: 0.8297 - val_loss: 0.5104 - val_accuracy: 0.8459
# Epoch 159/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5441 - accuracy: 0.8286 - val_loss: 0.5138 - val_accuracy: 0.8427
# Epoch 160/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5456 - accuracy: 0.8207 - val_loss: 0.5080 - val_accuracy: 0.8491
# Epoch 161/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5474 - accuracy: 0.8265 - val_loss: 0.5070 - val_accuracy: 0.8502
# Epoch 162/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5375 - accuracy: 0.8334 - val_loss: 0.5086 - val_accuracy: 0.8448
# Epoch 163/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5524 - accuracy: 0.8278 - val_loss: 0.5117 - val_accuracy: 0.8374
# Epoch 164/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5400 - accuracy: 0.8300 - val_loss: 0.5015 - val_accuracy: 0.8459
# Epoch 165/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5436 - accuracy: 0.8223 - val_loss: 0.5024 - val_accuracy: 0.8502
# Epoch 166/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5482 - accuracy: 0.8350 - val_loss: 0.5068 - val_accuracy: 0.8374
# Epoch 167/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5410 - accuracy: 0.8292 - val_loss: 0.5017 - val_accuracy: 0.8438
# Epoch 168/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5431 - accuracy: 0.8332 - val_loss: 0.4975 - val_accuracy: 0.8459
# Epoch 169/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5349 - accuracy: 0.8300 - val_loss: 0.4981 - val_accuracy: 0.8480
# Epoch 170/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5386 - accuracy: 0.8262 - val_loss: 0.5009 - val_accuracy: 0.8491
# Epoch 171/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5408 - accuracy: 0.8276 - val_loss: 0.4969 - val_accuracy: 0.8502
# Epoch 172/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5329 - accuracy: 0.8289 - val_loss: 0.4975 - val_accuracy: 0.8438
# Epoch 173/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5371 - accuracy: 0.8241 - val_loss: 0.5032 - val_accuracy: 0.8385
# Epoch 174/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5287 - accuracy: 0.8366 - val_loss: 0.4923 - val_accuracy: 0.8459
# Epoch 175/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5336 - accuracy: 0.8334 - val_loss: 0.4940 - val_accuracy: 0.8480
# Epoch 176/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5244 - accuracy: 0.8334 - val_loss: 0.4940 - val_accuracy: 0.8491
# Epoch 177/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5281 - accuracy: 0.8313 - val_loss: 0.4855 - val_accuracy: 0.8502
# Epoch 178/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5209 - accuracy: 0.8379 - val_loss: 0.4934 - val_accuracy: 0.8427
# Epoch 179/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5155 - accuracy: 0.8326 - val_loss: 0.4849 - val_accuracy: 0.8448
# Epoch 180/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5282 - accuracy: 0.8342 - val_loss: 0.4857 - val_accuracy: 0.8544
# Epoch 181/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5188 - accuracy: 0.8350 - val_loss: 0.4857 - val_accuracy: 0.8512
# Epoch 182/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5250 - accuracy: 0.8324 - val_loss: 0.4898 - val_accuracy: 0.8385
# Epoch 183/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5207 - accuracy: 0.8340 - val_loss: 0.4795 - val_accuracy: 0.8512
# Epoch 184/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5133 - accuracy: 0.8324 - val_loss: 0.4796 - val_accuracy: 0.8502
# Epoch 185/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5165 - accuracy: 0.8363 - val_loss: 0.4870 - val_accuracy: 0.8448
# Epoch 186/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5115 - accuracy: 0.8382 - val_loss: 0.4807 - val_accuracy: 0.8502
# Epoch 187/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5158 - accuracy: 0.8337 - val_loss: 0.4824 - val_accuracy: 0.8480
# Epoch 188/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5083 - accuracy: 0.8390 - val_loss: 0.4922 - val_accuracy: 0.8438
# Epoch 189/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5233 - accuracy: 0.8379 - val_loss: 0.4773 - val_accuracy: 0.8459
# Epoch 190/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5105 - accuracy: 0.8390 - val_loss: 0.4779 - val_accuracy: 0.8523
# Epoch 191/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5087 - accuracy: 0.8414 - val_loss: 0.4762 - val_accuracy: 0.8640
# Epoch 192/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5197 - accuracy: 0.8348 - val_loss: 0.4759 - val_accuracy: 0.8480
# Epoch 193/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5082 - accuracy: 0.8358 - val_loss: 0.4783 - val_accuracy: 0.8470
# Epoch 194/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5123 - accuracy: 0.8443 - val_loss: 0.4782 - val_accuracy: 0.8480
# Epoch 195/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5017 - accuracy: 0.8406 - val_loss: 0.4736 - val_accuracy: 0.8544
# Epoch 196/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4974 - accuracy: 0.8369 - val_loss: 0.4726 - val_accuracy: 0.8512
# Epoch 197/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4966 - accuracy: 0.8422 - val_loss: 0.4702 - val_accuracy: 0.8576
# Epoch 198/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4987 - accuracy: 0.8438 - val_loss: 0.4778 - val_accuracy: 0.8470
# Epoch 199/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5009 - accuracy: 0.8398 - val_loss: 0.4670 - val_accuracy: 0.8523
# Epoch 200/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5041 - accuracy: 0.8451 - val_loss: 0.4639 - val_accuracy: 0.8512

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 40ms/step - loss: 2.0912 - accuracy: 0.2582 - val_loss: 1.8939 - val_accuracy: 0.3401
# Epoch 2/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1.8461 - accuracy: 0.3454 - val_loss: 1.7537 - val_accuracy: 0.3688
# Epoch 3/50
# 8/8 [==============================] - 0s 24ms/step - loss: 1.7386 - accuracy: 0.4338 - val_loss: 1.6232 - val_accuracy: 0.4644
# Epoch 4/50
# 8/8 [==============================] - 0s 22ms/step - loss: 1.6239 - accuracy: 0.4655 - val_loss: 1.4936 - val_accuracy: 0.4782
# Epoch 5/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.5207 - accuracy: 0.4843 - val_loss: 1.3969 - val_accuracy: 0.5558
# Epoch 6/50
# 8/8 [==============================] - 0s 20ms/step - loss: 1.4355 - accuracy: 0.5135 - val_loss: 1.3267 - val_accuracy: 0.5622
# Epoch 7/50
# 8/8 [==============================] - 0s 20ms/step - loss: 1.3778 - accuracy: 0.5252 - val_loss: 1.2754 - val_accuracy: 0.5824
# Epoch 8/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3290 - accuracy: 0.5537 - val_loss: 1.2359 - val_accuracy: 0.6196
# Epoch 9/50
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2775 - accuracy: 0.5786 - val_loss: 1.1985 - val_accuracy: 0.6121
# Epoch 10/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2397 - accuracy: 0.5951 - val_loss: 1.1639 - val_accuracy: 0.6397
# Epoch 11/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2113 - accuracy: 0.6002 - val_loss: 1.1311 - val_accuracy: 0.6482
# Epoch 12/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1741 - accuracy: 0.6174 - val_loss: 1.0996 - val_accuracy: 0.6536
# Epoch 13/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1440 - accuracy: 0.6219 - val_loss: 1.0726 - val_accuracy: 0.6599
# Epoch 14/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1089 - accuracy: 0.6334 - val_loss: 1.0432 - val_accuracy: 0.6578
# Epoch 15/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0804 - accuracy: 0.6427 - val_loss: 1.0173 - val_accuracy: 0.6578
# Epoch 16/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0627 - accuracy: 0.6421 - val_loss: 0.9969 - val_accuracy: 0.6706
# Epoch 17/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0390 - accuracy: 0.6488 - val_loss: 0.9731 - val_accuracy: 0.6738
# Epoch 18/50
# 8/8 [==============================] - 0s 19ms/step - loss: 1.0179 - accuracy: 0.6554 - val_loss: 0.9527 - val_accuracy: 0.6663
# Epoch 19/50
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0069 - accuracy: 0.6567 - val_loss: 0.9474 - val_accuracy: 0.7152
# Epoch 20/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9782 - accuracy: 0.6684 - val_loss: 0.9219 - val_accuracy: 0.6939
# Epoch 21/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9725 - accuracy: 0.6615 - val_loss: 0.9051 - val_accuracy: 0.7194
# Epoch 22/50
# 8/8 [==============================] - 0s 21ms/step - loss: 0.9636 - accuracy: 0.6860 - val_loss: 0.8912 - val_accuracy: 0.6844
# Epoch 23/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9370 - accuracy: 0.6846 - val_loss: 0.8747 - val_accuracy: 0.7407
# Epoch 24/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9391 - accuracy: 0.6852 - val_loss: 0.8664 - val_accuracy: 0.7396
# Epoch 25/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.9243 - accuracy: 0.6905 - val_loss: 0.8601 - val_accuracy: 0.7524
# Epoch 26/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9217 - accuracy: 0.6865 - val_loss: 0.8503 - val_accuracy: 0.7556
# Epoch 27/50
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8973 - accuracy: 0.7011 - val_loss: 0.8334 - val_accuracy: 0.7322
# Epoch 28/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8940 - accuracy: 0.6937 - val_loss: 0.8268 - val_accuracy: 0.7396
# Epoch 29/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8839 - accuracy: 0.7019 - val_loss: 0.8230 - val_accuracy: 0.7566
# Epoch 30/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8783 - accuracy: 0.7109 - val_loss: 0.8135 - val_accuracy: 0.7662
# Epoch 31/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8751 - accuracy: 0.7109 - val_loss: 0.8019 - val_accuracy: 0.7577
# Epoch 32/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8697 - accuracy: 0.7067 - val_loss: 0.7957 - val_accuracy: 0.7566
# Epoch 33/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8624 - accuracy: 0.7163 - val_loss: 0.7941 - val_accuracy: 0.7683
# Epoch 34/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8536 - accuracy: 0.7171 - val_loss: 0.7844 - val_accuracy: 0.7566
# Epoch 35/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8509 - accuracy: 0.7171 - val_loss: 0.7816 - val_accuracy: 0.7641
# Epoch 36/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8468 - accuracy: 0.7149 - val_loss: 0.7987 - val_accuracy: 0.7503
# Epoch 37/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8372 - accuracy: 0.7234 - val_loss: 0.7676 - val_accuracy: 0.7705
# Epoch 38/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8432 - accuracy: 0.7242 - val_loss: 0.7725 - val_accuracy: 0.7386
# Epoch 39/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8298 - accuracy: 0.7237 - val_loss: 0.7654 - val_accuracy: 0.7651
# Epoch 40/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8212 - accuracy: 0.7317 - val_loss: 0.7546 - val_accuracy: 0.7736
# Epoch 41/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8162 - accuracy: 0.7341 - val_loss: 0.7499 - val_accuracy: 0.7705
# Epoch 42/50
# 8/8 [==============================] - 0s 20ms/step - loss: 0.8028 - accuracy: 0.7412 - val_loss: 0.7480 - val_accuracy: 0.7683
# Epoch 43/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7983 - accuracy: 0.7473 - val_loss: 0.7364 - val_accuracy: 0.7747
# Epoch 44/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.8037 - accuracy: 0.7357 - val_loss: 0.7363 - val_accuracy: 0.7736
# Epoch 45/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7973 - accuracy: 0.7351 - val_loss: 0.7368 - val_accuracy: 0.7694
# Epoch 46/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7874 - accuracy: 0.7418 - val_loss: 0.7294 - val_accuracy: 0.7758
# Epoch 47/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7931 - accuracy: 0.7415 - val_loss: 0.7294 - val_accuracy: 0.7705
# Epoch 48/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7832 - accuracy: 0.7351 - val_loss: 0.7224 - val_accuracy: 0.7758
# Epoch 49/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7771 - accuracy: 0.7505 - val_loss: 0.7180 - val_accuracy: 0.7768
# Epoch 50/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7779 - accuracy: 0.7476 - val_loss: 0.7191 - val_accuracy: 0.7790

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7034 - accuracy: 0.7899
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7191 - accuracy: 0.7790
# 0.7898512482643127 0.7789585590362549

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 15, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:01:23

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   0   0   1   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 135   0   2   3   0   0   0]
#  [  3   4   0 110   0   6   0   0   1]
#  [  0   0   0   0 302  17   1   0   0]
#  [  0   0   1   3  43  73   0   0   0]
#  [  0   0   1   0  27  12  10   0   0]
#  [  0   0   1   0  31  12   3   3   0]
#  [  0   1   0   3  12  20   0   0   1]]
#
# Accuracy Score
# 0.7789585547290117
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.95      0.98      0.97        60
#      clouds       0.89      1.00      0.94        40
#  vegetation       0.98      0.96      0.97       140
#       water       0.94      0.89      0.91       124
#       built       0.72      0.94      0.82       320
#     windows       0.51      0.61      0.56       120
#       roads       0.71      0.20      0.31        50
#        cars       1.00      0.06      0.11        50
#       metal       0.50      0.03      0.05        37
#
# avg / total       0.79      0.78      0.74       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
# Out:
# 15 1
