# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 848)
# (1600, 1600, 2)

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
train_acc = {}
test_acc = {}

# %%
#lbl = '50_50'
#trrat = 0.5

#lbl = '20_80'
#trrat = 0.2

#lbl = '10_90'
#trrat = 0.1

#lbl = '5_95'
#trrat = 0.05

#lbl = '3_97'
#trrat = 0.03

#lbl = '1_99'
#trrat = 0.01

#lbl = '05_995'
#rrat = 0.005

lbl = '01_999'
trrat = 0.001

# %%
#sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, 0.005, "sky")
#clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, 0.003, "clouds")
#veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, 0.002, "veg")
#wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, 0.03, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
#windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, 0.002, "windows")
#rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, 0.05, "rds")
#cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, 0.01, "cars")
#mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, 0.01, "mtl")
# Out:
# sky: 1 299
# clouds: 1 499
# veg: 1 599
# wtr: 1 49
# blt: 1 1019
# windows: 1 499
# rds: 1 29
# cars: 1 99
# mtl: 1 99

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (1, 848) (299, 848)
# clouds  (1, 848) (499, 848)
# vegetation  (1, 848) (599, 848)
# water  (1, 848) (49, 848)
# built  (1, 848) (1019, 848)
# windows  (1, 848) (499, 848)
# roads  (1, 848) (29, 848)
# cars  (1, 848) (99, 848)
# metal  (1, 848) (99, 848)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (9, 848) (9,) (9, 2)
# (3191, 848) (3191,) (3191, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 486ms/step - loss: 2.1997 - accuracy: 0.0000e+00 - val_loss: 2.0506 - val_accuracy: 0.3403
# Epoch 2/200
# 1/1 [==============================] - 0s 316ms/step - loss: 2.0595 - accuracy: 0.2222 - val_loss: 1.9153 - val_accuracy: 0.5233
# Epoch 3/200
# 1/1 [==============================] - 0s 337ms/step - loss: 1.8956 - accuracy: 0.3333 - val_loss: 1.6844 - val_accuracy: 0.4654
# Epoch 4/200
# 1/1 [==============================] - 0s 290ms/step - loss: 1.7885 - accuracy: 0.2222 - val_loss: 1.5041 - val_accuracy: 0.4437
# Epoch 5/200
# 1/1 [==============================] - 0s 272ms/step - loss: 1.3186 - accuracy: 0.5556 - val_loss: 1.3845 - val_accuracy: 0.4557
# Epoch 6/200
# 1/1 [==============================] - 0s 292ms/step - loss: 1.2564 - accuracy: 0.6667 - val_loss: 1.3706 - val_accuracy: 0.3983
# Epoch 7/200
# 1/1 [==============================] - 0s 289ms/step - loss: 1.1315 - accuracy: 0.3333 - val_loss: 1.4649 - val_accuracy: 0.5917
# Epoch 8/200
# 1/1 [==============================] - 0s 260ms/step - loss: 1.1885 - accuracy: 0.4444 - val_loss: 1.5035 - val_accuracy: 0.5337
# Epoch 9/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.9517 - accuracy: 0.5556 - val_loss: 2.3691 - val_accuracy: 0.3438
# Epoch 10/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.7285 - accuracy: 0.6667 - val_loss: 1.9060 - val_accuracy: 0.3547
# Epoch 11/200
# 1/1 [==============================] - 0s 245ms/step - loss: 1.1541 - accuracy: 0.6667 - val_loss: 1.1999 - val_accuracy: 0.7208
# Epoch 12/200
# 1/1 [==============================] - 0s 281ms/step - loss: 1.2030 - accuracy: 0.5556 - val_loss: 1.3902 - val_accuracy: 0.6615
# Epoch 13/200
# 1/1 [==============================] - 0s 276ms/step - loss: 1.4332 - accuracy: 0.4444 - val_loss: 2.1628 - val_accuracy: 0.4437
# Epoch 14/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.4172 - accuracy: 0.8889 - val_loss: 2.9128 - val_accuracy: 0.4340
# Epoch 15/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.9442 - accuracy: 0.5556 - val_loss: 3.0060 - val_accuracy: 0.3645
# Epoch 16/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.7547 - accuracy: 0.7778 - val_loss: 2.5553 - val_accuracy: 0.3441
# Epoch 17/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.7274 - accuracy: 0.7778 - val_loss: 2.0684 - val_accuracy: 0.3710
# Epoch 18/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.8690 - accuracy: 0.6667 - val_loss: 1.5570 - val_accuracy: 0.6152
# Epoch 19/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.6736 - accuracy: 0.7778 - val_loss: 1.4260 - val_accuracy: 0.6315
# Epoch 20/200
# 1/1 [==============================] - 0s 296ms/step - loss: 1.0119 - accuracy: 0.6667 - val_loss: 1.5326 - val_accuracy: 0.5766
# Epoch 21/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.6735 - accuracy: 0.7778 - val_loss: 1.5867 - val_accuracy: 0.5469
# Epoch 22/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.7912 - accuracy: 0.6667 - val_loss: 1.6039 - val_accuracy: 0.4629
# Epoch 23/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.7601 - accuracy: 0.6667 - val_loss: 1.6899 - val_accuracy: 0.4118
# Epoch 24/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5479 - accuracy: 0.7778 - val_loss: 1.7759 - val_accuracy: 0.3757
# Epoch 25/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.7150 - accuracy: 0.7778 - val_loss: 1.7365 - val_accuracy: 0.3714
# Epoch 26/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.5420 - accuracy: 0.7778 - val_loss: 1.6413 - val_accuracy: 0.3748
# Epoch 27/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.4160 - accuracy: 0.8889 - val_loss: 1.5961 - val_accuracy: 0.4381
# Epoch 28/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.6572 - accuracy: 0.6667 - val_loss: 1.5267 - val_accuracy: 0.5306
# Epoch 29/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.7163 - accuracy: 0.6667 - val_loss: 1.5306 - val_accuracy: 0.5892
# Epoch 30/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.5515 - accuracy: 0.8889 - val_loss: 1.5243 - val_accuracy: 0.6023
# Epoch 31/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.5562 - accuracy: 0.7778 - val_loss: 1.5449 - val_accuracy: 0.5964
# Epoch 32/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.6867 - accuracy: 0.6667 - val_loss: 1.6097 - val_accuracy: 0.5522
# Epoch 33/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3682 - accuracy: 0.8889 - val_loss: 1.6458 - val_accuracy: 0.4998
# Epoch 34/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.4348 - accuracy: 0.8889 - val_loss: 1.6839 - val_accuracy: 0.4475
# Epoch 35/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.3526 - accuracy: 1.0000 - val_loss: 1.6353 - val_accuracy: 0.4569
# Epoch 36/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.2406 - accuracy: 1.0000 - val_loss: 1.6448 - val_accuracy: 0.4610
# Epoch 37/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.5322 - accuracy: 0.6667 - val_loss: 1.6043 - val_accuracy: 0.4845
# Epoch 38/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.4867 - accuracy: 0.7778 - val_loss: 1.6852 - val_accuracy: 0.4854
# Epoch 39/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.2306 - accuracy: 1.0000 - val_loss: 1.8546 - val_accuracy: 0.4798
# Epoch 40/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.1969 - accuracy: 1.0000 - val_loss: 2.0183 - val_accuracy: 0.4716
# Epoch 41/200
# 1/1 [==============================] - 0s 251ms/step - loss: 0.3602 - accuracy: 0.8889 - val_loss: 2.0598 - val_accuracy: 0.4920
# Epoch 42/200
# 1/1 [==============================] - 0s 236ms/step - loss: 0.4402 - accuracy: 0.8889 - val_loss: 2.1396 - val_accuracy: 0.4788
# Epoch 43/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.2999 - accuracy: 0.8889 - val_loss: 2.3343 - val_accuracy: 0.4525
# Epoch 44/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1459 - accuracy: 1.0000 - val_loss: 2.6029 - val_accuracy: 0.4544
# Epoch 45/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.3368 - accuracy: 0.7778 - val_loss: 2.6670 - val_accuracy: 0.4531
# Epoch 46/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.4364 - accuracy: 0.7778 - val_loss: 2.2919 - val_accuracy: 0.4610
# Epoch 47/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.3509 - accuracy: 0.8889 - val_loss: 1.7330 - val_accuracy: 0.5459
# Epoch 48/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 1.4860 - val_accuracy: 0.6243
# Epoch 49/200
# 1/1 [==============================] - 0s 333ms/step - loss: 0.3524 - accuracy: 0.8889 - val_loss: 1.6998 - val_accuracy: 0.5876
# Epoch 50/200
# 1/1 [==============================] - 0s 382ms/step - loss: 0.3166 - accuracy: 0.8889 - val_loss: 2.1198 - val_accuracy: 0.5390
# Epoch 51/200
# 1/1 [==============================] - 0s 347ms/step - loss: 0.1644 - accuracy: 0.8889 - val_loss: 2.6805 - val_accuracy: 0.4469
# Epoch 52/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.2820 - accuracy: 0.8889 - val_loss: 2.8198 - val_accuracy: 0.4472
# Epoch 53/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.3871 - accuracy: 0.8889 - val_loss: 2.7575 - val_accuracy: 0.4406
# Epoch 54/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1855 - accuracy: 1.0000 - val_loss: 2.4653 - val_accuracy: 0.4663
# Epoch 55/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.2016 - accuracy: 1.0000 - val_loss: 2.0051 - val_accuracy: 0.5092
# Epoch 56/200
# 1/1 [==============================] - 0s 320ms/step - loss: 0.2196 - accuracy: 1.0000 - val_loss: 1.7023 - val_accuracy: 0.5575
# Epoch 57/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.2996 - accuracy: 0.8889 - val_loss: 1.7111 - val_accuracy: 0.5478
# Epoch 58/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.1230 - accuracy: 1.0000 - val_loss: 1.8422 - val_accuracy: 0.5199
# Epoch 59/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1724 - accuracy: 0.8889 - val_loss: 2.0704 - val_accuracy: 0.4788
# Epoch 60/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.2544 - accuracy: 0.8889 - val_loss: 2.1922 - val_accuracy: 0.4663
# Epoch 61/200
# 1/1 [==============================] - 0s 242ms/step - loss: 0.1327 - accuracy: 1.0000 - val_loss: 2.5060 - val_accuracy: 0.4491
# Epoch 62/200
# 1/1 [==============================] - 0s 255ms/step - loss: 0.1807 - accuracy: 1.0000 - val_loss: 2.6486 - val_accuracy: 0.4437
# Epoch 63/200
# 1/1 [==============================] - 0s 265ms/step - loss: 0.1544 - accuracy: 0.8889 - val_loss: 2.5496 - val_accuracy: 0.4384
# Epoch 64/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.2396 - accuracy: 0.8889 - val_loss: 2.3078 - val_accuracy: 0.4770
# Epoch 65/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1490 - accuracy: 0.8889 - val_loss: 2.2598 - val_accuracy: 0.4779
# Epoch 66/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 2.2413 - val_accuracy: 0.4861
# Epoch 67/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.2389 - accuracy: 0.8889 - val_loss: 2.2806 - val_accuracy: 0.4738
# Epoch 68/200
# 1/1 [==============================] - 0s 348ms/step - loss: 0.3080 - accuracy: 0.8889 - val_loss: 2.2058 - val_accuracy: 0.4478
# Epoch 69/200
# 1/1 [==============================] - 0s 398ms/step - loss: 0.1218 - accuracy: 1.0000 - val_loss: 2.3118 - val_accuracy: 0.4481
# Epoch 70/200
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0886 - accuracy: 1.0000 - val_loss: 2.4226 - val_accuracy: 0.4531
# Epoch 71/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 2.4902 - val_accuracy: 0.4557
# Epoch 72/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2252 - accuracy: 0.8889 - val_loss: 2.2530 - val_accuracy: 0.4704
# Epoch 73/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.1746 - accuracy: 0.8889 - val_loss: 2.0243 - val_accuracy: 0.4923
# Epoch 74/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1477 - accuracy: 0.8889 - val_loss: 2.0499 - val_accuracy: 0.4839
# Epoch 75/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 2.0805 - val_accuracy: 0.4767
# Epoch 76/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 2.1349 - val_accuracy: 0.4713
# Epoch 77/200
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 2.2436 - val_accuracy: 0.4842
# Epoch 78/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 2.2987 - val_accuracy: 0.4998
# Epoch 79/200
# 1/1 [==============================] - 0s 229ms/step - loss: 0.2824 - accuracy: 0.8889 - val_loss: 2.0491 - val_accuracy: 0.5227
# Epoch 80/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 1.8820 - val_accuracy: 0.5810
# Epoch 81/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 1.8420 - val_accuracy: 0.5920
# Epoch 82/200
# 1/1 [==============================] - 0s 246ms/step - loss: 0.2628 - accuracy: 0.8889 - val_loss: 1.9692 - val_accuracy: 0.5704
# Epoch 83/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.1874 - accuracy: 0.8889 - val_loss: 2.2650 - val_accuracy: 0.4867
# Epoch 84/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 2.5775 - val_accuracy: 0.4519
# Epoch 85/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.1814 - accuracy: 0.8889 - val_loss: 2.6697 - val_accuracy: 0.4475
# Epoch 86/200
# 1/1 [==============================] - 0s 354ms/step - loss: 0.1045 - accuracy: 1.0000 - val_loss: 2.7072 - val_accuracy: 0.4472
# Epoch 87/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 2.7017 - val_accuracy: 0.4510
# Epoch 88/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 2.6574 - val_accuracy: 0.4528
# Epoch 89/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 2.5876 - val_accuracy: 0.4522
# Epoch 90/200
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 2.4927 - val_accuracy: 0.4541
# Epoch 91/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 2.4118 - val_accuracy: 0.4629
# Epoch 92/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 2.3932 - val_accuracy: 0.4660
# Epoch 93/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 2.3597 - val_accuracy: 0.4679
# Epoch 94/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 2.3407 - val_accuracy: 0.4773
# Epoch 95/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0568 - accuracy: 1.0000 - val_loss: 2.4464 - val_accuracy: 0.4713
# Epoch 96/200
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 2.5602 - val_accuracy: 0.4676
# Epoch 97/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 2.6650 - val_accuracy: 0.4654
# Epoch 98/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 2.8242 - val_accuracy: 0.4582
# Epoch 99/200
# 1/1 [==============================] - 0s 256ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 2.9002 - val_accuracy: 0.4519
# Epoch 100/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 2.9621 - val_accuracy: 0.4463
# Epoch 101/200
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 2.9348 - val_accuracy: 0.4466
# Epoch 102/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 2.6836 - val_accuracy: 0.4563
# Epoch 103/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0638 - accuracy: 1.0000 - val_loss: 2.2942 - val_accuracy: 0.5168
# Epoch 104/200
# 1/1 [==============================] - 0s 323ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 2.0945 - val_accuracy: 0.5537
# Epoch 105/200
# 1/1 [==============================] - 0s 419ms/step - loss: 0.2042 - accuracy: 0.8889 - val_loss: 2.2813 - val_accuracy: 0.5284
# Epoch 106/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.4826 - val_accuracy: 0.4810
# Epoch 107/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 2.6808 - val_accuracy: 0.4582
# Epoch 108/200
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.8810 - val_accuracy: 0.4497
# Epoch 109/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 3.1837 - val_accuracy: 0.4387
# Epoch 110/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 3.4174 - val_accuracy: 0.4331
# Epoch 111/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 3.5876 - val_accuracy: 0.4315
# Epoch 112/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 3.6869 - val_accuracy: 0.4290
# Epoch 113/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 3.6817 - val_accuracy: 0.4278
# Epoch 114/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 3.6145 - val_accuracy: 0.4268
# Epoch 115/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 3.5246 - val_accuracy: 0.4309
# Epoch 116/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.4389 - val_accuracy: 0.4343
# Epoch 117/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 3.2918 - val_accuracy: 0.4384
# Epoch 118/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 3.1546 - val_accuracy: 0.4463
# Epoch 119/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 3.0508 - val_accuracy: 0.4604
# Epoch 120/200
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 3.0177 - val_accuracy: 0.4666
# Epoch 121/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 3.0153 - val_accuracy: 0.4666
# Epoch 122/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 3.1795 - val_accuracy: 0.4557
# Epoch 123/200
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 3.3169 - val_accuracy: 0.4535
# Epoch 124/200
# 1/1 [==============================] - 0s 331ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 3.4222 - val_accuracy: 0.4553
# Epoch 125/200
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 3.5003 - val_accuracy: 0.4560
# Epoch 126/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 3.3768 - val_accuracy: 0.4629
# Epoch 127/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 3.2025 - val_accuracy: 0.4688
# Epoch 128/200
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0880 - accuracy: 0.8889 - val_loss: 2.7690 - val_accuracy: 0.5118
# Epoch 129/200
# 1/1 [==============================] - 0s 356ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4728 - val_accuracy: 0.5672
# Epoch 130/200
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 2.2897 - val_accuracy: 0.6095
# Epoch 131/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.1506 - accuracy: 0.8889 - val_loss: 2.2614 - val_accuracy: 0.5757
# Epoch 132/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 2.2918 - val_accuracy: 0.5443
# Epoch 133/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 2.5854 - val_accuracy: 0.4839
# Epoch 134/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 3.0130 - val_accuracy: 0.4572
# Epoch 135/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 3.2595 - val_accuracy: 0.4384
# Epoch 136/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.4846 - val_accuracy: 0.4315
# Epoch 137/200
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 3.5276 - val_accuracy: 0.4271
# Epoch 138/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 3.4153 - val_accuracy: 0.4290
# Epoch 139/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 3.3245 - val_accuracy: 0.4325
# Epoch 140/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.2346 - val_accuracy: 0.4384
# Epoch 141/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 3.1671 - val_accuracy: 0.4488
# Epoch 142/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 3.1624 - val_accuracy: 0.4535
# Epoch 143/200
# 1/1 [==============================] - 0s 344ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 3.1546 - val_accuracy: 0.4635
# Epoch 144/200
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.1508 - val_accuracy: 0.4720
# Epoch 145/200
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.1588 - val_accuracy: 0.4795
# Epoch 146/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 3.1716 - val_accuracy: 0.4817
# Epoch 147/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 3.2741 - val_accuracy: 0.4644
# Epoch 148/200
# 1/1 [==============================] - 0s 343ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.3779 - val_accuracy: 0.4591
# Epoch 149/200
# 1/1 [==============================] - 0s 402ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 3.4835 - val_accuracy: 0.4560
# Epoch 150/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 3.6134 - val_accuracy: 0.4541
# Epoch 151/200
# 1/1 [==============================] - 0s 247ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 3.7100 - val_accuracy: 0.4531
# Epoch 152/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 3.6096 - val_accuracy: 0.4557
# Epoch 153/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 3.4092 - val_accuracy: 0.4638
# Epoch 154/200
# 1/1 [==============================] - 0s 263ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 3.2182 - val_accuracy: 0.4751
# Epoch 155/200
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 3.0542 - val_accuracy: 0.4967
# Epoch 156/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 2.8802 - val_accuracy: 0.5146
# Epoch 157/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.7520 - val_accuracy: 0.5215
# Epoch 158/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 2.6595 - val_accuracy: 0.5252
# Epoch 159/200
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 2.6989 - val_accuracy: 0.5114
# Epoch 160/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 2.8007 - val_accuracy: 0.4870
# Epoch 161/200
# 1/1 [==============================] - 0s 274ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.9114 - val_accuracy: 0.4732
# Epoch 162/200
# 1/1 [==============================] - 0s 274ms/step - loss: 4.0281e-04 - accuracy: 1.0000 - val_loss: 3.0230 - val_accuracy: 0.4666
# Epoch 163/200
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.1390 - val_accuracy: 0.4600
# Epoch 164/200
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 3.2686 - val_accuracy: 0.4566
# Epoch 165/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 3.4166 - val_accuracy: 0.4525
# Epoch 166/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 3.4461 - val_accuracy: 0.4522
# Epoch 167/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 3.4723 - val_accuracy: 0.4525
# Epoch 168/200
# 1/1 [==============================] - 0s 414ms/step - loss: 0.0988 - accuracy: 0.8889 - val_loss: 3.0533 - val_accuracy: 0.4663
# Epoch 169/200
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.7101 - val_accuracy: 0.5055
# Epoch 170/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 2.4920 - val_accuracy: 0.5434
# Epoch 171/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0949 - accuracy: 0.8889 - val_loss: 2.5270 - val_accuracy: 0.5309
# Epoch 172/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 2.6456 - val_accuracy: 0.5049
# Epoch 173/200
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.7915 - val_accuracy: 0.4807
# Epoch 174/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.9777 - val_accuracy: 0.4701
# Epoch 175/200
# 1/1 [==============================] - 0s 250ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 3.1878 - val_accuracy: 0.4654
# Epoch 176/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 3.1167 - val_accuracy: 0.4679
# Epoch 177/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 3.0633 - val_accuracy: 0.4701
# Epoch 178/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 2.9241 - val_accuracy: 0.4720
# Epoch 179/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.8098 - val_accuracy: 0.4776
# Epoch 180/200
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.7013 - val_accuracy: 0.4873
# Epoch 181/200
# 1/1 [==============================] - 0s 246ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 2.6507 - val_accuracy: 0.4929
# Epoch 182/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.6111 - val_accuracy: 0.4967
# Epoch 183/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.6328 - val_accuracy: 0.4961
# Epoch 184/200
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 2.6646 - val_accuracy: 0.4955
# Epoch 185/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 2.7196 - val_accuracy: 0.4951
# Epoch 186/200
# 1/1 [==============================] - 0s 319ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.7956 - val_accuracy: 0.4898
# Epoch 187/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.8757 - val_accuracy: 0.4826
# Epoch 188/200
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 2.9328 - val_accuracy: 0.4788
# Epoch 189/200
# 1/1 [==============================] - 0s 381ms/step - loss: 6.5580e-04 - accuracy: 1.0000 - val_loss: 2.9877 - val_accuracy: 0.4754
# Epoch 190/200
# 1/1 [==============================] - 0s 384ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 3.0702 - val_accuracy: 0.4735
# Epoch 191/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.1445 - val_accuracy: 0.4713
# Epoch 192/200
# 1/1 [==============================] - 0s 260ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.2102 - val_accuracy: 0.4663
# Epoch 193/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.2582 - val_accuracy: 0.4647
# Epoch 194/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 3.3035 - val_accuracy: 0.4594
# Epoch 195/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.3495 - val_accuracy: 0.4566
# Epoch 196/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 3.4233 - val_accuracy: 0.4572
# Epoch 197/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.4966 - val_accuracy: 0.4547
# Epoch 198/200
# 1/1 [==============================] - 0s 263ms/step - loss: 6.7917e-04 - accuracy: 1.0000 - val_loss: 3.5690 - val_accuracy: 0.4522
# Epoch 199/200
# 1/1 [==============================] - 0s 268ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.6368 - val_accuracy: 0.4491
# Epoch 200/200
# 1/1 [==============================] - 0s 258ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.7002 - val_accuracy: 0.4469

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=15, batch_size=512)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 1s 549ms/step - loss: 2.1077 - accuracy: 0.1111 - val_loss: 2.0482 - val_accuracy: 0.3911
# Epoch 2/15
# 1/1 [==============================] - 0s 306ms/step - loss: 2.0637 - accuracy: 0.4444 - val_loss: 1.9274 - val_accuracy: 0.4613
# Epoch 3/15
# 1/1 [==============================] - 0s 354ms/step - loss: 1.7695 - accuracy: 0.3333 - val_loss: 1.6163 - val_accuracy: 0.3688
# Epoch 4/15
# 1/1 [==============================] - 0s 362ms/step - loss: 1.5016 - accuracy: 0.6667 - val_loss: 1.3443 - val_accuracy: 0.5202
# Epoch 5/15
# 1/1 [==============================] - 0s 280ms/step - loss: 1.5321 - accuracy: 0.3333 - val_loss: 1.4493 - val_accuracy: 0.5067
# Epoch 6/15
# 1/1 [==============================] - 0s 266ms/step - loss: 1.0175 - accuracy: 0.4444 - val_loss: 1.5821 - val_accuracy: 0.4400
# Epoch 7/15
# 1/1 [==============================] - 0s 267ms/step - loss: 0.8382 - accuracy: 0.6667 - val_loss: 2.3042 - val_accuracy: 0.3432
# Epoch 8/15
# 1/1 [==============================] - 0s 251ms/step - loss: 1.1541 - accuracy: 0.4444 - val_loss: 1.7147 - val_accuracy: 0.4936
# Epoch 9/15
# 1/1 [==============================] - 0s 338ms/step - loss: 1.1520 - accuracy: 0.4444 - val_loss: 1.3837 - val_accuracy: 0.6628
# Epoch 10/15
# 1/1 [==============================] - 0s 258ms/step - loss: 0.8511 - accuracy: 0.4444 - val_loss: 1.8452 - val_accuracy: 0.4644
# Epoch 11/15
# 1/1 [==============================] - 0s 251ms/step - loss: 0.7484 - accuracy: 0.7778 - val_loss: 2.6633 - val_accuracy: 0.3566
# Epoch 12/15
# 1/1 [==============================] - 0s 245ms/step - loss: 1.1016 - accuracy: 0.6667 - val_loss: 2.8738 - val_accuracy: 0.3322
# Epoch 13/15
# 1/1 [==============================] - 0s 257ms/step - loss: 0.6024 - accuracy: 0.6667 - val_loss: 2.1706 - val_accuracy: 0.4882
# Epoch 14/15
# 1/1 [==============================] - 0s 252ms/step - loss: 0.5338 - accuracy: 0.6667 - val_loss: 1.8028 - val_accuracy: 0.5735
# Epoch 15/15
# 1/1 [==============================] - 0s 261ms/step - loss: 0.7730 - accuracy: 0.6667 - val_loss: 1.7190 - val_accuracy: 0.6371

# %%
# model accuracy on training and testing sets

train_loss, train_acc[trrat] = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc[trrat] = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7863 - accuracy: 0.6667
# 100/100 [==============================] - 1s 8ms/step - loss: 1.7190 - accuracy: 0.6371
# {0.5: 0.9418749809265137, 0.2: 0.9234374761581421, 0.1: 0.934374988079071, 0.05: 0.8993710875511169, 0.03: 0.9263157844543457, 0.01: 0.8787878751754761, 0.005: 0.8235294222831726, 0.001: 0.6666666865348816} {0.5: 0.9212499856948853, 0.2: 0.9144531488418579, 0.1: 0.90625, 0.05: 0.8477474451065063, 0.03: 0.8872785568237305, 0.01: 0.8598042130470276, 0.005: 0.7546340227127075, 0.001: 0.637104332447052}

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 848, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
#fig.savefig("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.png", bbox_inches='tight')

# %%
#import pickle
#pickle.dump(predictCube_reshape, open("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.pickle", "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(lbl), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %%
print("done {0} split".format(lbl))

# %% [markdown]
# ___
# ## Plot Results

# %%
import numpy as np

#train_acc = [train_acc_200, train_acc_100, train_acc_50, train_acc_20, train_acc_10, train_acc_5]
#test_acc =[test_acc_100, test_acc_100, test_acc_50, test_acc_20, test_acc_10, test_acc_5]

plt_train_acc = [0.9574, train_acc[0.5], train_acc[0.2], train_acc[0.1], train_acc[0.05], train_acc[0.03], 
                 train_acc[0.01], train_acc[0.005], train_acc[0.001]]
plt_test_acc =[0.9422, test_acc[0.5], test_acc[0.2], test_acc[0.1], test_acc[0.05], test_acc[0.03],
               test_acc[0.01], test_acc[0.005], test_acc[0.001]]

print(plt_train_acc)
print(plt_test_acc)
# Out:
# [0.9574, 0.9418749809265137, 0.9234374761581421, 0.934374988079071, 0.8993710875511169, 0.9263157844543457, 0.8787878751754761, 0.8235294222831726, 0.8888888955116272]
# [0.9422, 0.9212499856948853, 0.9144531488418579, 0.90625, 0.8477474451065063, 0.8872785568237305, 0.8598042130470276, 0.7546340227127075, 0.4377937912940979]

# %%
n_groups = 9

avg_prec = np.zeros(n_groups)
avg_recall = np.zeros(n_groups)
avg_f1 = np.zeros(n_groups)
train_size = np.zeros(n_groups)
sky_prec = np.zeros(n_groups)
sky_recall = np.zeros(n_groups)
sky_f1 = np.zeros(n_groups)
sky_train_size = np.zeros(n_groups)
clouds_prec = np.zeros(n_groups)
clouds_recall = np.zeros(n_groups)
clouds_f1 = np.zeros(n_groups)
clouds_train_size = np.zeros(n_groups)
veg_prec = np.zeros(n_groups)
veg_recall = np.zeros(n_groups)
veg_f1 = np.zeros(n_groups)
veg_train_size = np.zeros(n_groups)
wtr_prec = np.zeros(n_groups)
wtr_recall = np.zeros(n_groups)
wtr_f1 = np.zeros(n_groups)
wtr_train_size = np.zeros(n_groups)
blt_prec = np.zeros(n_groups)
blt_recall = np.zeros(n_groups)
blt_f1 = np.zeros(n_groups)
blt_train_size = np.zeros(n_groups)
windows_prec = np.zeros(n_groups)
windows_recall = np.zeros(n_groups)
windows_f1 = np.zeros(n_groups)
windows_train_size = np.zeros(n_groups)
rds_prec = np.zeros(n_groups)
rds_recall = np.zeros(n_groups)
rds_f1 = np.zeros(n_groups)
rds_train_size = np.zeros(n_groups)
cars_prec = np.zeros(n_groups)
cars_recall = np.zeros(n_groups)
cars_f1 = np.zeros(n_groups)
cars_train_size = np.zeros(n_groups)
mtl_prec = np.zeros(n_groups)
mtl_recall = np.zeros(n_groups)
mtl_f1 = np.zeros(n_groups)
mtl_train_size = np.zeros(n_groups)

# %%
def read_prec_recall(file, line):
    Nums = []
    for num in file[line].split():
        try:
            Nums.append(float(num))
        except ValueError:
            pass
    prec = Nums[0]
    recall = Nums[1]
    f1 = Nums[2]
    #size = int(Nums[3]*(tt_ratio/100)/((100-tt_ratio)/100))
    size = Nums[3]
    
    return prec, recall, f1, size

# %%
filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics.txt"
f = open(filename, "r")
f1 = f.readlines()
i=0
avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
f.close()

# %%
train_split = ['80_20', '50_50', '20_80', '10_90', '5_95', '3_97', '1_99', '05_995', '01_999']
#tr_splits = [80, 50, 20, 10, 5, 3, 1, 0.5, 0.1]

#i=0
#for split in train_split:
for i in range(1,n_groups):
    filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(train_split[i])
    f = open(filename, "r")
    f1 = f.readlines()

    avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
    sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
    clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
    veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
    wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
    blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
    windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
    rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
    cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
    mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
    f.close()
    #i += 1

# %%
train_size = 3200 - train_size
sky_train_size = sky_coords.shape[0] - sky_train_size
clouds_train_size = clouds_coords.shape[0] - clouds_train_size
veg_train_size = veg_coords.shape[0] - veg_train_size
wtr_train_size = wtr_coords.shape[0] - wtr_train_size
blt_train_size = blt_coords.shape[0] - blt_train_size
windows_train_size = windows_coords.shape[0] - windows_train_size
rds_train_size = rds_coords.shape[0] - rds_train_size
cars_train_size = cars_coords.shape[0] - cars_train_size
mtl_train_size = mtl_coords.shape[0] - mtl_train_size

# %%
print(train_size)
# Out:
# [2560. 1600.  640.  320.  159.   95.   33.   17.    9.]

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 22
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

#train_size = [2560, 1600, 640, 320, 159]

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(20,5))

ax1.plot(train_size, plt_train_acc, '-o', color='b', lw=3, label='train')
ax1.plot(train_size, plt_test_acc, '-o', color='g', lw=3, label='test')
ax1.set_title("Accuracy", fontsize=20)
ax1.set_xlabel("training instances")
ax1.set_ylabel("accuracy")
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white')
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(train_size)
ax1.set_xlim(2800,8)
ax1.set_ylim(0.40,1.0)

ax2.plot(train_size, avg_prec, '-o', color='b', lw=3, label='mP')
ax2.plot(train_size, avg_recall, '-o', color='y', lw=3, label='mR')
ax2.plot(train_size, avg_f1, '-o', color='r', lw=3, label='mF1')
ax2.set_title("Mean Precision, Recall, and F1-Score", fontsize=20)
ax2.set_xlabel("training instances")
ax2.set_ylabel("metric")
handles, labels = ax2.get_legend_handles_labels()
ax2.legend(handles, labels, facecolor='white', loc='lower left')
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(train_size)
ax2.set_xlim(2800,8)
ax2.set_ylim(0.40,1.0)

plt.show
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_overall_metrics_extend.png", bbox_inches='tight', dpi=300
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

fig, ((ax1, ax2, ax3),(ax4, ax5, ax6),(ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(25,18))
ax1.plot(sky_train_size[:-1], sky_prec[:-1], '-o', color='b', lw=3, label='Precision')
ax1.plot(sky_train_size[:-1], sky_recall[:-1], '-o', color='y', lw=3, label='Recall')
ax1.plot(sky_train_size[:-1], sky_f1[:-1], '-o', color='r', lw=3, label='F1 Score')
ax1.set(title="Sky")
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(sky_train_size[:-1])
ax1.set_xticks([1,2,8,32,128,512])
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(0.8,1000)
ax1.set_ylabel("metric")
ax1.invert_xaxis()
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white', loc='lower left')

ax2.plot(clouds_train_size, clouds_prec, '-o', color='b', lw=3)
ax2.plot(clouds_train_size, clouds_recall, '-o', color='y', lw=3)
ax2.plot(clouds_train_size, clouds_f1, '-o', color='r', lw=3)
ax2.set(title="Clouds")
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(clouds_train_size)
ax2.set_xticks([1,2,8,32,128,512])
ax2.set_ylim(-0.1,1.1)
ax2.set_xlim(0.8,1000)
ax2.invert_xaxis()
ax2.legend(handles, labels, facecolor='white', loc='lower left')

ax3.plot(veg_train_size, veg_prec, '-o', color='b', lw=3)
ax3.plot(veg_train_size, veg_recall, '-o', color='y', lw=3)
ax3.plot(veg_train_size, veg_f1, '-o', color='r', lw=3)
ax3.set(title="Vegetation")
ax3.set_xscale('log', basex=2)
ax3.xaxis.set_major_formatter(ScalarFormatter())
#ax3.set_xticks(veg_train_size)
ax3.set_xticks([1,2,8,32,128,512])
ax3.set_ylim(-0.1,1.1)
ax3.set_xlim(0.8,1000)
ax3.invert_xaxis()
ax3.legend(handles, labels, facecolor='white', loc='lower left')

ax4.plot(wtr_train_size[:-3], wtr_prec[:-3], '-o', color='b', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_recall[:-3], '-o', color='y', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_f1[:-3], '-o', color='r', lw=3)
ax4.set(title="Water")
ax4.set_xscale('log', basex=2)
ax4.xaxis.set_major_formatter(ScalarFormatter())
#ax4.set_xticks(wtr_train_size[:-3])
ax4.set_xticks([1,2,8,32,128,512])
ax4.set_ylim(-0.1,1.1)
ax4.set_xlim(0.8,1000)
ax4.set_ylabel("metric")
ax4.invert_xaxis()
ax4.legend(handles, labels, facecolor='white', loc='lower left')

ax5.plot(blt_train_size, blt_prec, '-o', color='b', lw=3)
ax5.plot(blt_train_size, blt_recall, '-o', color='y', lw=3)
ax5.plot(blt_train_size, blt_f1, '-o', color='r', lw=3)
ax5.set(title="Built")
ax5.set_xscale('log', basex=2)
ax5.xaxis.set_major_formatter(ScalarFormatter())
#ax5.set_xticks(blt_train_size)
ax5.set_xticks([1,2,8,32,128,512])
ax5.set_xlim(0.8,1000)
ax5.set_ylim(-0.1,1.1)
ax5.invert_xaxis()
ax5.legend(handles, labels, facecolor='white', loc='lower left')

ax6.plot(windows_train_size, windows_prec, '-o', color='b', lw=3, label='Precision')
ax6.plot(windows_train_size, windows_recall, '-o', color='y', lw=3, label='Recall')
ax6.plot(windows_train_size, windows_f1, '-o', color='r', lw=3, label='F1 Score')
ax6.set(title="Windows")
ax6.set_xscale('log', basex=2)
ax6.xaxis.set_major_formatter(ScalarFormatter())
#ax6.set_xticks(windows_train_size)
ax6.set_xticks([1,2,8,32,128,512])
ax6.set_ylim(-0.1,1.1)
ax6.set_xlim(0.8,1000)
ax6.invert_xaxis()
ax6.legend(handles, labels, facecolor='white', loc='lower left')

ax7.plot(rds_train_size[:-4], rds_prec[:-4], '-o', color='b', lw=3)
ax7.plot(rds_train_size[:-4], rds_recall[:-4], '-o', color='y', lw=3)
ax7.plot(rds_train_size[:-4], rds_f1[:-4], '-o', color='r', lw=3)
ax7.set(title="Roads")
ax7.set_xscale('log', basex=2)
ax7.xaxis.set_major_formatter(ScalarFormatter())
#ax7.set_xticks(rds_train_size[:-4])
ax7.set_xticks([1,2,8,32,128,512])
ax7.set_ylim(-0.1,1.1)
ax7.set_xlim(0.8,1000)
ax7.set_xlabel("training instances")
ax7.set_ylabel("metric")
ax7.invert_xaxis()
ax7.legend(handles, labels, facecolor='white', loc='lower left')

ax8.plot(cars_train_size[:-2], cars_prec[:-2], '-o', color='b', lw=3)
ax8.plot(cars_train_size[:-2], cars_recall[:-2], '-o', color='y', lw=3)
ax8.plot(cars_train_size[:-2], cars_f1[:-2], '-o', color='r', lw=3)
ax8.set(title="Cars")
ax8.set_xscale('log', basex=2)
ax8.xaxis.set_major_formatter(ScalarFormatter())
#ax8.set_xticks(cars_train_size[:-2])
ax8.set_xticks([1,2,8,32,128,512])
ax8.set_ylim(-0.1,1.1)
ax8.set_xlim(0.8,1000)
ax8.set_xlabel("training instances")
ax8.invert_xaxis()
ax8.legend(handles, labels, facecolor='white', loc='lower left')

ax9.plot(mtl_train_size[:-2], mtl_prec[:-2], '-o', color='b', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_recall[:-2], '-o', color='y', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_f1[:-2], '-o', color='r', lw=3)
ax9.set(title="Metal")
ax9.set_xscale('log', basex=2)
ax9.xaxis.set_major_formatter(ScalarFormatter())
#ax9.set_xticks(mtl_train_size[:-2])
ax9.set_xticks([1,2,8,32,128,512])
ax9.set_ylim(-0.1,1.1)
ax9.set_xlim(0.8,1000)
ax9.set_xlabel("training instances")
ax9.invert_xaxis()
ax9.legend(handles, labels, facecolor='white', loc='lower left')

#handles, labels = ax6.get_legend_handles_labels()
#ax6.legend(handles, labels, loc='center right', borderaxespad=-10.0)

plt.show()
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_3_By_Class_Prec_Recall_extend.png",
#           bbox_inches='tight', dpi=300)
