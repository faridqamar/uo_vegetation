# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 122
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 122
# [[0, 6], [6, 12], [12, 18], [18, 24], [24, 30], [30, 36], [36, 42], [42, 48], [48, 54], [54, 60], [60, 66], [66, 72], [72, 78], [78, 84], [84, 90], [90, 96], [96, 102], [102, 108], [108, 114], [114, 120], [120, 126], [126, 132], [132, 138], [138, 144], [144, 150], [150, 156], [156, 162], [162, 168], [168, 174], [174, 180], [180, 186], [186, 192], [192, 198], [198, 204], [204, 210], [210, 216], [216, 222], [222, 228], [228, 234], [234, 240], [240, 246], [246, 252], [252, 258], [258, 264], [264, 270], [270, 276], [276, 282], [282, 288], [288, 294], [294, 300], [300, 306], [306, 312], [312, 318], [318, 324], [324, 330], [330, 336], [336, 342], [342, 348], [348, 354], [354, 360], [360, 366], [366, 372], [372, 378], [378, 384], [384, 390], [390, 396], [396, 402], [402, 408], [408, 414], [414, 420], [420, 426], [426, 432], [432, 438], [438, 444], [444, 450], [450, 456], [456, 462], [462, 468], [468, 474], [474, 480], [480, 486], [486, 492], [492, 498], [498, 504], [504, 510], [510, 516], [516, 522], [522, 528], [528, 534], [534, 540], [540, 546], [546, 552], [552, 558], [558, 564], [564, 570], [570, 576], [576, 582], [582, 588], [588, 594], [594, 600], [600, 606], [606, 612], [612, 618], [618, 624], [624, 630], [630, 636], [636, 642], [642, 648], [648, 654], [654, 660], [660, 666], [666, 672], [672, 678], [678, 684], [684, 690], [690, 696], [696, 702], [702, 708], [708, 714], [714, 720], [720, 726], [726, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 122)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 122)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 122) (60, 122)
# clouds  (400, 122) (100, 122)
# vegetation  (480, 122) (120, 122)
# water  (40, 122) (10, 122)
# built  (816, 122) (204, 122)
# windows  (400, 122) (100, 122)
# roads  (24, 122) (6, 122)
# cars  (80, 122) (20, 122)
# metal  (80, 122) (20, 122)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 122) (2560,) (2560, 2)
# (640, 122) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 105ms/step - loss: 1.7081 - accuracy: 0.4133 - val_loss: 1.2102 - val_accuracy: 0.6547
# Epoch 2/200
# 5/5 [==============================] - 0s 56ms/step - loss: 1.1107 - accuracy: 0.6594 - val_loss: 0.9123 - val_accuracy: 0.6797
# Epoch 3/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.8746 - accuracy: 0.7078 - val_loss: 0.7535 - val_accuracy: 0.7422
# Epoch 4/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.7740 - accuracy: 0.7449 - val_loss: 0.6861 - val_accuracy: 0.7937
# Epoch 5/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.7092 - accuracy: 0.7805 - val_loss: 0.6370 - val_accuracy: 0.7906
# Epoch 6/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.6712 - accuracy: 0.7871 - val_loss: 0.5662 - val_accuracy: 0.8438
# Epoch 7/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.6220 - accuracy: 0.7977 - val_loss: 0.5444 - val_accuracy: 0.8203
# Epoch 8/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.5514 - accuracy: 0.8250 - val_loss: 0.4985 - val_accuracy: 0.8172
# Epoch 9/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.5385 - accuracy: 0.8277 - val_loss: 0.4703 - val_accuracy: 0.8344
# Epoch 10/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4968 - accuracy: 0.8414 - val_loss: 0.4378 - val_accuracy: 0.8750
# Epoch 11/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.4649 - accuracy: 0.8574 - val_loss: 0.4103 - val_accuracy: 0.8734
# Epoch 12/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4509 - accuracy: 0.8590 - val_loss: 0.3782 - val_accuracy: 0.8922
# Epoch 13/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4199 - accuracy: 0.8707 - val_loss: 0.3739 - val_accuracy: 0.8844
# Epoch 14/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4151 - accuracy: 0.8785 - val_loss: 0.3492 - val_accuracy: 0.9078
# Epoch 15/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3981 - accuracy: 0.8789 - val_loss: 0.3374 - val_accuracy: 0.9016
# Epoch 16/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3725 - accuracy: 0.8926 - val_loss: 0.3305 - val_accuracy: 0.9047
# Epoch 17/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.3779 - accuracy: 0.8887 - val_loss: 0.3088 - val_accuracy: 0.9156
# Epoch 18/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.3606 - accuracy: 0.8930 - val_loss: 0.3091 - val_accuracy: 0.9156
# Epoch 19/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3415 - accuracy: 0.9000 - val_loss: 0.3045 - val_accuracy: 0.9125
# Epoch 20/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3450 - accuracy: 0.8988 - val_loss: 0.3013 - val_accuracy: 0.9031
# Epoch 21/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3376 - accuracy: 0.8984 - val_loss: 0.2992 - val_accuracy: 0.9016
# Epoch 22/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.3294 - accuracy: 0.8992 - val_loss: 0.2799 - val_accuracy: 0.9078
# Epoch 23/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3211 - accuracy: 0.9070 - val_loss: 0.2889 - val_accuracy: 0.9047
# Epoch 24/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.3229 - accuracy: 0.8984 - val_loss: 0.2863 - val_accuracy: 0.8984
# Epoch 25/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3332 - accuracy: 0.8969 - val_loss: 0.2828 - val_accuracy: 0.9000
# Epoch 26/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3094 - accuracy: 0.9062 - val_loss: 0.2808 - val_accuracy: 0.8969
# Epoch 27/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2996 - accuracy: 0.9062 - val_loss: 0.2591 - val_accuracy: 0.9109
# Epoch 28/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2942 - accuracy: 0.9121 - val_loss: 0.2556 - val_accuracy: 0.9203
# Epoch 29/200
# 5/5 [==============================] - 0s 72ms/step - loss: 0.2837 - accuracy: 0.9141 - val_loss: 0.2513 - val_accuracy: 0.9109
# Epoch 30/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.2876 - accuracy: 0.9168 - val_loss: 0.2462 - val_accuracy: 0.9187
# Epoch 31/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2753 - accuracy: 0.9148 - val_loss: 0.2394 - val_accuracy: 0.9203
# Epoch 32/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2721 - accuracy: 0.9168 - val_loss: 0.2352 - val_accuracy: 0.9187
# Epoch 33/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2665 - accuracy: 0.9145 - val_loss: 0.2476 - val_accuracy: 0.9094
# Epoch 34/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2681 - accuracy: 0.9148 - val_loss: 0.2325 - val_accuracy: 0.9156
# Epoch 35/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2552 - accuracy: 0.9250 - val_loss: 0.2319 - val_accuracy: 0.9109
# Epoch 36/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2597 - accuracy: 0.9207 - val_loss: 0.2244 - val_accuracy: 0.9172
# Epoch 37/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2499 - accuracy: 0.9199 - val_loss: 0.2206 - val_accuracy: 0.9187
# Epoch 38/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2504 - accuracy: 0.9223 - val_loss: 0.2182 - val_accuracy: 0.9187
# Epoch 39/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2426 - accuracy: 0.9184 - val_loss: 0.2135 - val_accuracy: 0.9266
# Epoch 40/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.2473 - accuracy: 0.9230 - val_loss: 0.2152 - val_accuracy: 0.9219
# Epoch 41/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2406 - accuracy: 0.9211 - val_loss: 0.2069 - val_accuracy: 0.9297
# Epoch 42/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2348 - accuracy: 0.9258 - val_loss: 0.2043 - val_accuracy: 0.9234
# Epoch 43/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.2263 - accuracy: 0.9277 - val_loss: 0.2120 - val_accuracy: 0.9187
# Epoch 44/200
# 5/5 [==============================] - 0s 71ms/step - loss: 0.2253 - accuracy: 0.9258 - val_loss: 0.1997 - val_accuracy: 0.9219
# Epoch 45/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2257 - accuracy: 0.9254 - val_loss: 0.1986 - val_accuracy: 0.9234
# Epoch 46/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2193 - accuracy: 0.9281 - val_loss: 0.1962 - val_accuracy: 0.9266
# Epoch 47/200
# 5/5 [==============================] - 0s 70ms/step - loss: 0.2081 - accuracy: 0.9328 - val_loss: 0.1903 - val_accuracy: 0.9359
# Epoch 48/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.2090 - accuracy: 0.9312 - val_loss: 0.1864 - val_accuracy: 0.9250
# Epoch 49/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2070 - accuracy: 0.9348 - val_loss: 0.1898 - val_accuracy: 0.9391
# Epoch 50/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.2031 - accuracy: 0.9363 - val_loss: 0.1966 - val_accuracy: 0.9172
# Epoch 51/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2032 - accuracy: 0.9285 - val_loss: 0.1863 - val_accuracy: 0.9312
# Epoch 52/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2062 - accuracy: 0.9336 - val_loss: 0.1787 - val_accuracy: 0.9422
# Epoch 53/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1868 - accuracy: 0.9371 - val_loss: 0.1773 - val_accuracy: 0.9406
# Epoch 54/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1962 - accuracy: 0.9324 - val_loss: 0.1798 - val_accuracy: 0.9406
# Epoch 55/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1913 - accuracy: 0.9348 - val_loss: 0.1788 - val_accuracy: 0.9328
# Epoch 56/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1901 - accuracy: 0.9344 - val_loss: 0.1675 - val_accuracy: 0.9297
# Epoch 57/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1892 - accuracy: 0.9348 - val_loss: 0.1694 - val_accuracy: 0.9344
# Epoch 58/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1843 - accuracy: 0.9371 - val_loss: 0.1953 - val_accuracy: 0.9172
# Epoch 59/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1914 - accuracy: 0.9355 - val_loss: 0.1640 - val_accuracy: 0.9453
# Epoch 60/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1790 - accuracy: 0.9391 - val_loss: 0.1648 - val_accuracy: 0.9500
# Epoch 61/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1789 - accuracy: 0.9383 - val_loss: 0.1629 - val_accuracy: 0.9438
# Epoch 62/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1770 - accuracy: 0.9402 - val_loss: 0.1703 - val_accuracy: 0.9375
# Epoch 63/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1788 - accuracy: 0.9371 - val_loss: 0.1613 - val_accuracy: 0.9453
# Epoch 64/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1729 - accuracy: 0.9406 - val_loss: 0.1533 - val_accuracy: 0.9469
# Epoch 65/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1705 - accuracy: 0.9445 - val_loss: 0.1528 - val_accuracy: 0.9406
# Epoch 66/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1695 - accuracy: 0.9430 - val_loss: 0.1504 - val_accuracy: 0.9531
# Epoch 67/200
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1651 - accuracy: 0.9426 - val_loss: 0.1452 - val_accuracy: 0.9500
# Epoch 68/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1598 - accuracy: 0.9473 - val_loss: 0.1491 - val_accuracy: 0.9406
# Epoch 69/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1565 - accuracy: 0.9457 - val_loss: 0.1558 - val_accuracy: 0.9422
# Epoch 70/200
# 5/5 [==============================] - 0s 70ms/step - loss: 0.1617 - accuracy: 0.9473 - val_loss: 0.1530 - val_accuracy: 0.9469
# Epoch 71/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1623 - accuracy: 0.9449 - val_loss: 0.1681 - val_accuracy: 0.9312
# Epoch 72/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1613 - accuracy: 0.9473 - val_loss: 0.1572 - val_accuracy: 0.9422
# Epoch 73/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.1567 - accuracy: 0.9465 - val_loss: 0.1425 - val_accuracy: 0.9500
# Epoch 74/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1514 - accuracy: 0.9477 - val_loss: 0.1376 - val_accuracy: 0.9453
# Epoch 75/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1462 - accuracy: 0.9484 - val_loss: 0.1392 - val_accuracy: 0.9547
# Epoch 76/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.1383 - accuracy: 0.9508 - val_loss: 0.1347 - val_accuracy: 0.9516
# Epoch 77/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1347 - accuracy: 0.9566 - val_loss: 0.1365 - val_accuracy: 0.9484
# Epoch 78/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1394 - accuracy: 0.9539 - val_loss: 0.1457 - val_accuracy: 0.9500
# Epoch 79/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1398 - accuracy: 0.9543 - val_loss: 0.1478 - val_accuracy: 0.9453
# Epoch 80/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1430 - accuracy: 0.9480 - val_loss: 0.1296 - val_accuracy: 0.9547
# Epoch 81/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1346 - accuracy: 0.9531 - val_loss: 0.1268 - val_accuracy: 0.9531
# Epoch 82/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1291 - accuracy: 0.9551 - val_loss: 0.1297 - val_accuracy: 0.9594
# Epoch 83/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1371 - accuracy: 0.9539 - val_loss: 0.1302 - val_accuracy: 0.9563
# Epoch 84/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1269 - accuracy: 0.9559 - val_loss: 0.1286 - val_accuracy: 0.9547
# Epoch 85/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1208 - accuracy: 0.9559 - val_loss: 0.1260 - val_accuracy: 0.9578
# Epoch 86/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1251 - accuracy: 0.9523 - val_loss: 0.1301 - val_accuracy: 0.9594
# Epoch 87/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1286 - accuracy: 0.9563 - val_loss: 0.1303 - val_accuracy: 0.9531
# Epoch 88/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1289 - accuracy: 0.9539 - val_loss: 0.1311 - val_accuracy: 0.9500
# Epoch 89/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1226 - accuracy: 0.9590 - val_loss: 0.1340 - val_accuracy: 0.9469
# Epoch 90/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1269 - accuracy: 0.9547 - val_loss: 0.1296 - val_accuracy: 0.9500
# Epoch 91/200
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1210 - accuracy: 0.9570 - val_loss: 0.1282 - val_accuracy: 0.9500
# Epoch 92/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1239 - accuracy: 0.9586 - val_loss: 0.1368 - val_accuracy: 0.9438
# Epoch 93/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1237 - accuracy: 0.9531 - val_loss: 0.1500 - val_accuracy: 0.9438
# Epoch 94/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1235 - accuracy: 0.9605 - val_loss: 0.1391 - val_accuracy: 0.9453
# Epoch 95/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1247 - accuracy: 0.9602 - val_loss: 0.1362 - val_accuracy: 0.9438
# Epoch 96/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1275 - accuracy: 0.9535 - val_loss: 0.1534 - val_accuracy: 0.9438
# Epoch 97/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1286 - accuracy: 0.9566 - val_loss: 0.1370 - val_accuracy: 0.9516
# Epoch 98/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1158 - accuracy: 0.9563 - val_loss: 0.1297 - val_accuracy: 0.9531
# Epoch 99/200
# 5/5 [==============================] - 0s 72ms/step - loss: 0.1145 - accuracy: 0.9590 - val_loss: 0.1214 - val_accuracy: 0.9531
# Epoch 100/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1230 - accuracy: 0.9559 - val_loss: 0.1286 - val_accuracy: 0.9547
# Epoch 101/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1058 - accuracy: 0.9625 - val_loss: 0.1248 - val_accuracy: 0.9531
# Epoch 102/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1067 - accuracy: 0.9633 - val_loss: 0.1195 - val_accuracy: 0.9609
# Epoch 103/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1048 - accuracy: 0.9605 - val_loss: 0.1217 - val_accuracy: 0.9625
# Epoch 104/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1015 - accuracy: 0.9621 - val_loss: 0.1161 - val_accuracy: 0.9609
# Epoch 105/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1076 - accuracy: 0.9648 - val_loss: 0.1176 - val_accuracy: 0.9563
# Epoch 106/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1043 - accuracy: 0.9645 - val_loss: 0.1142 - val_accuracy: 0.9625
# Epoch 107/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1026 - accuracy: 0.9656 - val_loss: 0.1228 - val_accuracy: 0.9547
# Epoch 108/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1056 - accuracy: 0.9645 - val_loss: 0.1094 - val_accuracy: 0.9641
# Epoch 109/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0987 - accuracy: 0.9668 - val_loss: 0.1131 - val_accuracy: 0.9641
# Epoch 110/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0961 - accuracy: 0.9633 - val_loss: 0.1224 - val_accuracy: 0.9578
# Epoch 111/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0966 - accuracy: 0.9648 - val_loss: 0.1298 - val_accuracy: 0.9516
# Epoch 112/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1125 - accuracy: 0.9613 - val_loss: 0.1237 - val_accuracy: 0.9625
# Epoch 113/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1039 - accuracy: 0.9625 - val_loss: 0.1476 - val_accuracy: 0.9438
# Epoch 114/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1149 - accuracy: 0.9578 - val_loss: 0.1286 - val_accuracy: 0.9547
# Epoch 115/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1095 - accuracy: 0.9602 - val_loss: 0.1238 - val_accuracy: 0.9453
# Epoch 116/200
# 5/5 [==============================] - 0s 74ms/step - loss: 0.1119 - accuracy: 0.9613 - val_loss: 0.1051 - val_accuracy: 0.9672
# Epoch 117/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1010 - accuracy: 0.9688 - val_loss: 0.1092 - val_accuracy: 0.9625
# Epoch 118/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0982 - accuracy: 0.9648 - val_loss: 0.1065 - val_accuracy: 0.9656
# Epoch 119/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1003 - accuracy: 0.9668 - val_loss: 0.1071 - val_accuracy: 0.9672
# Epoch 120/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0913 - accuracy: 0.9699 - val_loss: 0.1132 - val_accuracy: 0.9609
# Epoch 121/200
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0884 - accuracy: 0.9691 - val_loss: 0.1058 - val_accuracy: 0.9641
# Epoch 122/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0860 - accuracy: 0.9723 - val_loss: 0.1035 - val_accuracy: 0.9688
# Epoch 123/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0817 - accuracy: 0.9723 - val_loss: 0.1009 - val_accuracy: 0.9672
# Epoch 124/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0915 - accuracy: 0.9672 - val_loss: 0.1044 - val_accuracy: 0.9688
# Epoch 125/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0941 - accuracy: 0.9664 - val_loss: 0.1100 - val_accuracy: 0.9656
# Epoch 126/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0853 - accuracy: 0.9699 - val_loss: 0.1022 - val_accuracy: 0.9672
# Epoch 127/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0868 - accuracy: 0.9688 - val_loss: 0.1082 - val_accuracy: 0.9641
# Epoch 128/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0784 - accuracy: 0.9734 - val_loss: 0.1083 - val_accuracy: 0.9656
# Epoch 129/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0834 - accuracy: 0.9727 - val_loss: 0.1009 - val_accuracy: 0.9641
# Epoch 130/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0817 - accuracy: 0.9723 - val_loss: 0.0985 - val_accuracy: 0.9672
# Epoch 131/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0775 - accuracy: 0.9754 - val_loss: 0.1108 - val_accuracy: 0.9734
# Epoch 132/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0867 - accuracy: 0.9695 - val_loss: 0.1012 - val_accuracy: 0.9688
# Epoch 133/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0839 - accuracy: 0.9758 - val_loss: 0.1140 - val_accuracy: 0.9547
# Epoch 134/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0835 - accuracy: 0.9707 - val_loss: 0.1114 - val_accuracy: 0.9609
# Epoch 135/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0871 - accuracy: 0.9695 - val_loss: 0.1036 - val_accuracy: 0.9656
# Epoch 136/200
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0845 - accuracy: 0.9730 - val_loss: 0.1046 - val_accuracy: 0.9672
# Epoch 137/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0846 - accuracy: 0.9703 - val_loss: 0.1063 - val_accuracy: 0.9656
# Epoch 138/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0869 - accuracy: 0.9707 - val_loss: 0.1011 - val_accuracy: 0.9672
# Epoch 139/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0741 - accuracy: 0.9758 - val_loss: 0.1061 - val_accuracy: 0.9625
# Epoch 140/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0803 - accuracy: 0.9715 - val_loss: 0.1091 - val_accuracy: 0.9672
# Epoch 141/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0825 - accuracy: 0.9711 - val_loss: 0.0991 - val_accuracy: 0.9672
# Epoch 142/200
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0757 - accuracy: 0.9742 - val_loss: 0.1153 - val_accuracy: 0.9578
# Epoch 143/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0832 - accuracy: 0.9699 - val_loss: 0.1081 - val_accuracy: 0.9641
# Epoch 144/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0887 - accuracy: 0.9691 - val_loss: 0.1030 - val_accuracy: 0.9578
# Epoch 145/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0828 - accuracy: 0.9719 - val_loss: 0.1154 - val_accuracy: 0.9641
# Epoch 146/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0810 - accuracy: 0.9719 - val_loss: 0.1047 - val_accuracy: 0.9703
# Epoch 147/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0775 - accuracy: 0.9715 - val_loss: 0.0983 - val_accuracy: 0.9703
# Epoch 148/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0716 - accuracy: 0.9773 - val_loss: 0.0989 - val_accuracy: 0.9734
# Epoch 149/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0676 - accuracy: 0.9777 - val_loss: 0.0982 - val_accuracy: 0.9672
# Epoch 150/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0688 - accuracy: 0.9789 - val_loss: 0.1020 - val_accuracy: 0.9625
# Epoch 151/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0647 - accuracy: 0.9801 - val_loss: 0.0988 - val_accuracy: 0.9703
# Epoch 152/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0687 - accuracy: 0.9762 - val_loss: 0.1071 - val_accuracy: 0.9656
# Epoch 153/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0703 - accuracy: 0.9730 - val_loss: 0.1022 - val_accuracy: 0.9688
# Epoch 154/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0682 - accuracy: 0.9754 - val_loss: 0.1061 - val_accuracy: 0.9656
# Epoch 155/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0790 - accuracy: 0.9715 - val_loss: 0.1185 - val_accuracy: 0.9656
# Epoch 156/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0822 - accuracy: 0.9727 - val_loss: 0.1008 - val_accuracy: 0.9672
# Epoch 157/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0786 - accuracy: 0.9734 - val_loss: 0.1029 - val_accuracy: 0.9672
# Epoch 158/200
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0715 - accuracy: 0.9754 - val_loss: 0.0999 - val_accuracy: 0.9703
# Epoch 159/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0712 - accuracy: 0.9758 - val_loss: 0.1043 - val_accuracy: 0.9688
# Epoch 160/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0696 - accuracy: 0.9766 - val_loss: 0.1080 - val_accuracy: 0.9594
# Epoch 161/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0718 - accuracy: 0.9727 - val_loss: 0.1108 - val_accuracy: 0.9625
# Epoch 162/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0720 - accuracy: 0.9754 - val_loss: 0.0995 - val_accuracy: 0.9641
# Epoch 163/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0687 - accuracy: 0.9781 - val_loss: 0.1105 - val_accuracy: 0.9734
# Epoch 164/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0752 - accuracy: 0.9742 - val_loss: 0.1102 - val_accuracy: 0.9641
# Epoch 165/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0675 - accuracy: 0.9793 - val_loss: 0.1065 - val_accuracy: 0.9625
# Epoch 166/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0717 - accuracy: 0.9754 - val_loss: 0.0964 - val_accuracy: 0.9703
# Epoch 167/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0668 - accuracy: 0.9770 - val_loss: 0.1048 - val_accuracy: 0.9672
# Epoch 168/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0594 - accuracy: 0.9805 - val_loss: 0.1041 - val_accuracy: 0.9656
# Epoch 169/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0675 - accuracy: 0.9773 - val_loss: 0.1032 - val_accuracy: 0.9656
# Epoch 170/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0638 - accuracy: 0.9805 - val_loss: 0.1057 - val_accuracy: 0.9594
# Epoch 171/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0733 - accuracy: 0.9723 - val_loss: 0.0970 - val_accuracy: 0.9656
# Epoch 172/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0683 - accuracy: 0.9785 - val_loss: 0.1068 - val_accuracy: 0.9609
# Epoch 173/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0703 - accuracy: 0.9746 - val_loss: 0.1089 - val_accuracy: 0.9656
# Epoch 174/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0674 - accuracy: 0.9746 - val_loss: 0.0940 - val_accuracy: 0.9641
# Epoch 175/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0663 - accuracy: 0.9781 - val_loss: 0.0981 - val_accuracy: 0.9719
# Epoch 176/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0585 - accuracy: 0.9805 - val_loss: 0.0949 - val_accuracy: 0.9672
# Epoch 177/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0676 - accuracy: 0.9777 - val_loss: 0.0963 - val_accuracy: 0.9672
# Epoch 178/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0589 - accuracy: 0.9816 - val_loss: 0.1096 - val_accuracy: 0.9656
# Epoch 179/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0591 - accuracy: 0.9785 - val_loss: 0.1067 - val_accuracy: 0.9641
# Epoch 180/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0619 - accuracy: 0.9812 - val_loss: 0.1082 - val_accuracy: 0.9609
# Epoch 181/200
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0571 - accuracy: 0.9816 - val_loss: 0.1023 - val_accuracy: 0.9672
# Epoch 182/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0550 - accuracy: 0.9820 - val_loss: 0.1041 - val_accuracy: 0.9734
# Epoch 183/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0590 - accuracy: 0.9789 - val_loss: 0.1019 - val_accuracy: 0.9625
# Epoch 184/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0617 - accuracy: 0.9816 - val_loss: 0.0948 - val_accuracy: 0.9672
# Epoch 185/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0598 - accuracy: 0.9773 - val_loss: 0.0946 - val_accuracy: 0.9656
# Epoch 186/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0607 - accuracy: 0.9773 - val_loss: 0.0988 - val_accuracy: 0.9656
# Epoch 187/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0554 - accuracy: 0.9797 - val_loss: 0.0939 - val_accuracy: 0.9688
# Epoch 188/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0529 - accuracy: 0.9824 - val_loss: 0.1058 - val_accuracy: 0.9719
# Epoch 189/200
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0535 - accuracy: 0.9832 - val_loss: 0.0979 - val_accuracy: 0.9719
# Epoch 190/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0495 - accuracy: 0.9855 - val_loss: 0.0982 - val_accuracy: 0.9672
# Epoch 191/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0492 - accuracy: 0.9859 - val_loss: 0.0913 - val_accuracy: 0.9688
# Epoch 192/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0486 - accuracy: 0.9867 - val_loss: 0.0992 - val_accuracy: 0.9609
# Epoch 193/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0517 - accuracy: 0.9844 - val_loss: 0.0991 - val_accuracy: 0.9656
# Epoch 194/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0470 - accuracy: 0.9855 - val_loss: 0.0936 - val_accuracy: 0.9641
# Epoch 195/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 0.0926 - val_accuracy: 0.9688
# Epoch 196/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0474 - accuracy: 0.9867 - val_loss: 0.0865 - val_accuracy: 0.9719
# Epoch 197/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0474 - accuracy: 0.9840 - val_loss: 0.0963 - val_accuracy: 0.9672
# Epoch 198/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0508 - accuracy: 0.9844 - val_loss: 0.0948 - val_accuracy: 0.9688
# Epoch 199/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0571 - accuracy: 0.9816 - val_loss: 0.0956 - val_accuracy: 0.9703
# Epoch 200/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0435 - accuracy: 0.9863 - val_loss: 0.0937 - val_accuracy: 0.9656

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 5/5 [==============================] - 0s 82ms/step - loss: 1.8003 - accuracy: 0.3984 - val_loss: 1.2790 - val_accuracy: 0.6875
# Epoch 2/60
# 5/5 [==============================] - 0s 56ms/step - loss: 1.1584 - accuracy: 0.6559 - val_loss: 0.9112 - val_accuracy: 0.7094
# Epoch 3/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.8822 - accuracy: 0.7059 - val_loss: 0.7906 - val_accuracy: 0.7312
# Epoch 4/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.7820 - accuracy: 0.7352 - val_loss: 0.7155 - val_accuracy: 0.7234
# Epoch 5/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.7177 - accuracy: 0.7656 - val_loss: 0.6366 - val_accuracy: 0.8000
# Epoch 6/60
# 5/5 [==============================] - 0s 59ms/step - loss: 0.6705 - accuracy: 0.7812 - val_loss: 0.5792 - val_accuracy: 0.8031
# Epoch 7/60
# 5/5 [==============================] - 0s 71ms/step - loss: 0.6278 - accuracy: 0.7984 - val_loss: 0.5407 - val_accuracy: 0.8375
# Epoch 8/60
# 5/5 [==============================] - 0s 60ms/step - loss: 0.6068 - accuracy: 0.8012 - val_loss: 0.5245 - val_accuracy: 0.8172
# Epoch 9/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.5577 - accuracy: 0.8195 - val_loss: 0.5085 - val_accuracy: 0.8234
# Epoch 10/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.5217 - accuracy: 0.8344 - val_loss: 0.4721 - val_accuracy: 0.8500
# Epoch 11/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.5028 - accuracy: 0.8340 - val_loss: 0.4333 - val_accuracy: 0.8719
# Epoch 12/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4711 - accuracy: 0.8496 - val_loss: 0.4091 - val_accuracy: 0.8797
# Epoch 13/60
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4450 - accuracy: 0.8590 - val_loss: 0.3971 - val_accuracy: 0.8781
# Epoch 14/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4329 - accuracy: 0.8617 - val_loss: 0.3701 - val_accuracy: 0.9062
# Epoch 15/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4167 - accuracy: 0.8742 - val_loss: 0.3606 - val_accuracy: 0.8891
# Epoch 16/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4095 - accuracy: 0.8754 - val_loss: 0.3470 - val_accuracy: 0.9141
# Epoch 17/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3982 - accuracy: 0.8832 - val_loss: 0.3373 - val_accuracy: 0.9062
# Epoch 18/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3867 - accuracy: 0.8863 - val_loss: 0.3373 - val_accuracy: 0.9016
# Epoch 19/60
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3771 - accuracy: 0.8859 - val_loss: 0.3342 - val_accuracy: 0.8922
# Epoch 20/60
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3610 - accuracy: 0.8930 - val_loss: 0.3231 - val_accuracy: 0.9016
# Epoch 21/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.3642 - accuracy: 0.8906 - val_loss: 0.3100 - val_accuracy: 0.9078
# Epoch 22/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3435 - accuracy: 0.8977 - val_loss: 0.3023 - val_accuracy: 0.9109
# Epoch 23/60
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3344 - accuracy: 0.8992 - val_loss: 0.2953 - val_accuracy: 0.9078
# Epoch 24/60
# 5/5 [==============================] - 0s 60ms/step - loss: 0.3288 - accuracy: 0.9023 - val_loss: 0.2921 - val_accuracy: 0.9078
# Epoch 25/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3217 - accuracy: 0.9047 - val_loss: 0.2825 - val_accuracy: 0.9141
# Epoch 26/60
# 5/5 [==============================] - 0s 57ms/step - loss: 0.3173 - accuracy: 0.8984 - val_loss: 0.2782 - val_accuracy: 0.9125
# Epoch 27/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3057 - accuracy: 0.9109 - val_loss: 0.2786 - val_accuracy: 0.9078
# Epoch 28/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3063 - accuracy: 0.9082 - val_loss: 0.2771 - val_accuracy: 0.9156
# Epoch 29/60
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3014 - accuracy: 0.9086 - val_loss: 0.2697 - val_accuracy: 0.9109
# Epoch 30/60
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3024 - accuracy: 0.9125 - val_loss: 0.2744 - val_accuracy: 0.9109
# Epoch 31/60
# 5/5 [==============================] - 0s 76ms/step - loss: 0.2883 - accuracy: 0.9148 - val_loss: 0.2612 - val_accuracy: 0.9125
# Epoch 32/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2795 - accuracy: 0.9137 - val_loss: 0.2542 - val_accuracy: 0.9141
# Epoch 33/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2803 - accuracy: 0.9117 - val_loss: 0.2525 - val_accuracy: 0.9125
# Epoch 34/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2750 - accuracy: 0.9152 - val_loss: 0.2569 - val_accuracy: 0.9141
# Epoch 35/60
# 5/5 [==============================] - 0s 59ms/step - loss: 0.2808 - accuracy: 0.9145 - val_loss: 0.2509 - val_accuracy: 0.9094
# Epoch 36/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2684 - accuracy: 0.9207 - val_loss: 0.2379 - val_accuracy: 0.9203
# Epoch 37/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2652 - accuracy: 0.9191 - val_loss: 0.2480 - val_accuracy: 0.9187
# Epoch 38/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2594 - accuracy: 0.9176 - val_loss: 0.2417 - val_accuracy: 0.9187
# Epoch 39/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2523 - accuracy: 0.9234 - val_loss: 0.2518 - val_accuracy: 0.9031
# Epoch 40/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2534 - accuracy: 0.9227 - val_loss: 0.2544 - val_accuracy: 0.9031
# Epoch 41/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2513 - accuracy: 0.9219 - val_loss: 0.2446 - val_accuracy: 0.9094
# Epoch 42/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2552 - accuracy: 0.9184 - val_loss: 0.2456 - val_accuracy: 0.9078
# Epoch 43/60
# 5/5 [==============================] - 0s 60ms/step - loss: 0.2431 - accuracy: 0.9219 - val_loss: 0.2226 - val_accuracy: 0.9234
# Epoch 44/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2304 - accuracy: 0.9219 - val_loss: 0.2134 - val_accuracy: 0.9266
# Epoch 45/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2249 - accuracy: 0.9293 - val_loss: 0.2121 - val_accuracy: 0.9266
# Epoch 46/60
# 5/5 [==============================] - 0s 68ms/step - loss: 0.2264 - accuracy: 0.9266 - val_loss: 0.2136 - val_accuracy: 0.9266
# Epoch 47/60
# 5/5 [==============================] - 0s 70ms/step - loss: 0.2307 - accuracy: 0.9227 - val_loss: 0.2151 - val_accuracy: 0.9219
# Epoch 48/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2213 - accuracy: 0.9293 - val_loss: 0.2098 - val_accuracy: 0.9187
# Epoch 49/60
# 5/5 [==============================] - 0s 68ms/step - loss: 0.2176 - accuracy: 0.9266 - val_loss: 0.2011 - val_accuracy: 0.9281
# Epoch 50/60
# 5/5 [==============================] - 0s 65ms/step - loss: 0.2205 - accuracy: 0.9301 - val_loss: 0.2005 - val_accuracy: 0.9281
# Epoch 51/60
# 5/5 [==============================] - 0s 60ms/step - loss: 0.2215 - accuracy: 0.9277 - val_loss: 0.2142 - val_accuracy: 0.9328
# Epoch 52/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2173 - accuracy: 0.9324 - val_loss: 0.1978 - val_accuracy: 0.9281
# Epoch 53/60
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2090 - accuracy: 0.9340 - val_loss: 0.1978 - val_accuracy: 0.9297
# Epoch 54/60
# 5/5 [==============================] - 0s 65ms/step - loss: 0.2050 - accuracy: 0.9316 - val_loss: 0.1916 - val_accuracy: 0.9328
# Epoch 55/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2036 - accuracy: 0.9285 - val_loss: 0.1995 - val_accuracy: 0.9359
# Epoch 56/60
# 5/5 [==============================] - 0s 57ms/step - loss: 0.2025 - accuracy: 0.9320 - val_loss: 0.1981 - val_accuracy: 0.9297
# Epoch 57/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1968 - accuracy: 0.9340 - val_loss: 0.1901 - val_accuracy: 0.9250
# Epoch 58/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2028 - accuracy: 0.9297 - val_loss: 0.1848 - val_accuracy: 0.9344
# Epoch 59/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1931 - accuracy: 0.9344 - val_loss: 0.1999 - val_accuracy: 0.9250
# Epoch 60/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1931 - accuracy: 0.9348 - val_loss: 0.1927 - val_accuracy: 0.9203

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1768 - accuracy: 0.9312
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.9203
# 0.9312499761581421 0.9203125238418579

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 122, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:19

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 198   3   0   2   1]
#  [  0   0   0   0   9  89   0   2   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   9   1   0   9   1]
#  [  0   0   0   0  14   1   0   0   5]]
#
# Accuracy Score
# 0.9203125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.83      0.97      0.90       204
#     windows       0.95      0.89      0.92       100
#       roads       0.00      0.00      0.00         6
#        cars       0.69      0.45      0.55        20
#       metal       0.71      0.25      0.37        20
#
# avg / total       0.91      0.92      0.91       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 122)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 122)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 122) (80, 122)
# clouds  (400, 122) (100, 122)
# vegetation  (488, 122) (122, 122)
# built  (960, 122) (240, 122)
# windows  (400, 122) (100, 122)
# roads  (48, 122) (12, 122)
# cars  (44, 122) (11, 122)
# metal  (184, 122) (46, 122)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 122) (2844,) (2844, 2)
# (711, 122) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 89ms/step - loss: 1.7108 - accuracy: 0.3801 - val_loss: 1.2507 - val_accuracy: 0.5977
# Epoch 2/200
# 6/6 [==============================] - 0s 52ms/step - loss: 1.1379 - accuracy: 0.6203 - val_loss: 0.9668 - val_accuracy: 0.6301
# Epoch 3/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.9004 - accuracy: 0.6741 - val_loss: 0.8002 - val_accuracy: 0.6850
# Epoch 4/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.7483 - accuracy: 0.7113 - val_loss: 0.7097 - val_accuracy: 0.6878
# Epoch 5/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.6636 - accuracy: 0.7222 - val_loss: 0.6315 - val_accuracy: 0.7370
# Epoch 6/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.6075 - accuracy: 0.7472 - val_loss: 0.6064 - val_accuracy: 0.7581
# Epoch 7/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.5669 - accuracy: 0.7700 - val_loss: 0.5959 - val_accuracy: 0.7750
# Epoch 8/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.5544 - accuracy: 0.7799 - val_loss: 0.6043 - val_accuracy: 0.7778
# Epoch 9/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.5243 - accuracy: 0.7943 - val_loss: 0.5429 - val_accuracy: 0.7961
# Epoch 10/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.5119 - accuracy: 0.7978 - val_loss: 0.5328 - val_accuracy: 0.7975
# Epoch 11/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4867 - accuracy: 0.8168 - val_loss: 0.5513 - val_accuracy: 0.7412
# Epoch 12/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4848 - accuracy: 0.8003 - val_loss: 0.5109 - val_accuracy: 0.8087
# Epoch 13/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4655 - accuracy: 0.8242 - val_loss: 0.4987 - val_accuracy: 0.8158
# Epoch 14/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4457 - accuracy: 0.8298 - val_loss: 0.5212 - val_accuracy: 0.7989
# Epoch 15/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4517 - accuracy: 0.8284 - val_loss: 0.4806 - val_accuracy: 0.8298
# Epoch 16/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4218 - accuracy: 0.8411 - val_loss: 0.4633 - val_accuracy: 0.8214
# Epoch 17/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4160 - accuracy: 0.8442 - val_loss: 0.4555 - val_accuracy: 0.8383
# Epoch 18/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.4116 - accuracy: 0.8442 - val_loss: 0.4552 - val_accuracy: 0.8158
# Epoch 19/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3971 - accuracy: 0.8565 - val_loss: 0.4457 - val_accuracy: 0.8326
# Epoch 20/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3893 - accuracy: 0.8541 - val_loss: 0.4399 - val_accuracy: 0.8340
# Epoch 21/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3819 - accuracy: 0.8660 - val_loss: 0.4308 - val_accuracy: 0.8411
# Epoch 22/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.3799 - accuracy: 0.8643 - val_loss: 0.4225 - val_accuracy: 0.8453
# Epoch 23/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3693 - accuracy: 0.8653 - val_loss: 0.4138 - val_accuracy: 0.8495
# Epoch 24/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3582 - accuracy: 0.8710 - val_loss: 0.4124 - val_accuracy: 0.8481
# Epoch 25/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3513 - accuracy: 0.8745 - val_loss: 0.4409 - val_accuracy: 0.8312
# Epoch 26/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3523 - accuracy: 0.8762 - val_loss: 0.4193 - val_accuracy: 0.8439
# Epoch 27/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3447 - accuracy: 0.8745 - val_loss: 0.4118 - val_accuracy: 0.8453
# Epoch 28/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3442 - accuracy: 0.8797 - val_loss: 0.4060 - val_accuracy: 0.8509
# Epoch 29/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3406 - accuracy: 0.8787 - val_loss: 0.3935 - val_accuracy: 0.8509
# Epoch 30/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3351 - accuracy: 0.8790 - val_loss: 0.3881 - val_accuracy: 0.8537
# Epoch 31/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3287 - accuracy: 0.8724 - val_loss: 0.3789 - val_accuracy: 0.8720
# Epoch 32/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3268 - accuracy: 0.8759 - val_loss: 0.3885 - val_accuracy: 0.8636
# Epoch 33/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3298 - accuracy: 0.8854 - val_loss: 0.3695 - val_accuracy: 0.8636
# Epoch 34/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3204 - accuracy: 0.8847 - val_loss: 0.3640 - val_accuracy: 0.8748
# Epoch 35/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3159 - accuracy: 0.8899 - val_loss: 0.3721 - val_accuracy: 0.8734
# Epoch 36/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3155 - accuracy: 0.8882 - val_loss: 0.3560 - val_accuracy: 0.8805
# Epoch 37/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3135 - accuracy: 0.8871 - val_loss: 0.3493 - val_accuracy: 0.8805
# Epoch 38/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2993 - accuracy: 0.8921 - val_loss: 0.3464 - val_accuracy: 0.8790
# Epoch 39/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2931 - accuracy: 0.8892 - val_loss: 0.3404 - val_accuracy: 0.8847
# Epoch 40/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2857 - accuracy: 0.8994 - val_loss: 0.3428 - val_accuracy: 0.8875
# Epoch 41/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2829 - accuracy: 0.8980 - val_loss: 0.3348 - val_accuracy: 0.8833
# Epoch 42/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2828 - accuracy: 0.8956 - val_loss: 0.3352 - val_accuracy: 0.8847
# Epoch 43/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3020 - accuracy: 0.8826 - val_loss: 0.3622 - val_accuracy: 0.8636
# Epoch 44/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2981 - accuracy: 0.8945 - val_loss: 0.3323 - val_accuracy: 0.8762
# Epoch 45/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2819 - accuracy: 0.8966 - val_loss: 0.3214 - val_accuracy: 0.8903
# Epoch 46/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2632 - accuracy: 0.9058 - val_loss: 0.3356 - val_accuracy: 0.8833
# Epoch 47/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2610 - accuracy: 0.9047 - val_loss: 0.3172 - val_accuracy: 0.8917
# Epoch 48/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2681 - accuracy: 0.9058 - val_loss: 0.3280 - val_accuracy: 0.8762
# Epoch 49/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2649 - accuracy: 0.9030 - val_loss: 0.3059 - val_accuracy: 0.8931
# Epoch 50/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2562 - accuracy: 0.9061 - val_loss: 0.3109 - val_accuracy: 0.8959
# Epoch 51/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.2607 - accuracy: 0.9075 - val_loss: 0.3229 - val_accuracy: 0.8959
# Epoch 52/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2589 - accuracy: 0.9026 - val_loss: 0.3062 - val_accuracy: 0.8931
# Epoch 53/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2410 - accuracy: 0.9146 - val_loss: 0.2966 - val_accuracy: 0.8987
# Epoch 54/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2511 - accuracy: 0.9079 - val_loss: 0.3163 - val_accuracy: 0.8917
# Epoch 55/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2453 - accuracy: 0.9103 - val_loss: 0.2972 - val_accuracy: 0.8973
# Epoch 56/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2552 - accuracy: 0.9072 - val_loss: 0.3422 - val_accuracy: 0.8776
# Epoch 57/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2601 - accuracy: 0.9008 - val_loss: 0.3471 - val_accuracy: 0.8734
# Epoch 58/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2533 - accuracy: 0.9093 - val_loss: 0.3063 - val_accuracy: 0.8945
# Epoch 59/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2413 - accuracy: 0.9139 - val_loss: 0.3109 - val_accuracy: 0.8917
# Epoch 60/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2296 - accuracy: 0.9226 - val_loss: 0.2930 - val_accuracy: 0.9001
# Epoch 61/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2316 - accuracy: 0.9212 - val_loss: 0.2886 - val_accuracy: 0.9044
# Epoch 62/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2374 - accuracy: 0.9149 - val_loss: 0.3166 - val_accuracy: 0.8875
# Epoch 63/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2330 - accuracy: 0.9174 - val_loss: 0.2832 - val_accuracy: 0.9015
# Epoch 64/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2266 - accuracy: 0.9170 - val_loss: 0.2884 - val_accuracy: 0.8959
# Epoch 65/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2237 - accuracy: 0.9198 - val_loss: 0.2822 - val_accuracy: 0.9015
# Epoch 66/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2230 - accuracy: 0.9170 - val_loss: 0.2825 - val_accuracy: 0.9044
# Epoch 67/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2269 - accuracy: 0.9170 - val_loss: 0.2765 - val_accuracy: 0.9058
# Epoch 68/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2183 - accuracy: 0.9248 - val_loss: 0.2711 - val_accuracy: 0.9015
# Epoch 69/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2066 - accuracy: 0.9216 - val_loss: 0.2721 - val_accuracy: 0.9086
# Epoch 70/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2136 - accuracy: 0.9202 - val_loss: 0.2887 - val_accuracy: 0.9001
# Epoch 71/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2099 - accuracy: 0.9219 - val_loss: 0.2669 - val_accuracy: 0.9142
# Epoch 72/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.2131 - accuracy: 0.9209 - val_loss: 0.2781 - val_accuracy: 0.9015
# Epoch 73/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2344 - accuracy: 0.9114 - val_loss: 0.3085 - val_accuracy: 0.8875
# Epoch 74/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2214 - accuracy: 0.9174 - val_loss: 0.2856 - val_accuracy: 0.9015
# Epoch 75/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2228 - accuracy: 0.9181 - val_loss: 0.2706 - val_accuracy: 0.9030
# Epoch 76/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2106 - accuracy: 0.9248 - val_loss: 0.2796 - val_accuracy: 0.9072
# Epoch 77/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2124 - accuracy: 0.9167 - val_loss: 0.2651 - val_accuracy: 0.9142
# Epoch 78/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2020 - accuracy: 0.9304 - val_loss: 0.2692 - val_accuracy: 0.9072
# Epoch 79/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1967 - accuracy: 0.9328 - val_loss: 0.2575 - val_accuracy: 0.9184
# Epoch 80/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1976 - accuracy: 0.9265 - val_loss: 0.2479 - val_accuracy: 0.9212
# Epoch 81/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1916 - accuracy: 0.9286 - val_loss: 0.2522 - val_accuracy: 0.9170
# Epoch 82/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1865 - accuracy: 0.9248 - val_loss: 0.2588 - val_accuracy: 0.9156
# Epoch 83/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1787 - accuracy: 0.9350 - val_loss: 0.2771 - val_accuracy: 0.9058
# Epoch 84/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1906 - accuracy: 0.9297 - val_loss: 0.2938 - val_accuracy: 0.9015
# Epoch 85/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2032 - accuracy: 0.9272 - val_loss: 0.2673 - val_accuracy: 0.9086
# Epoch 86/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1883 - accuracy: 0.9311 - val_loss: 0.2530 - val_accuracy: 0.9170
# Epoch 87/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1898 - accuracy: 0.9300 - val_loss: 0.2509 - val_accuracy: 0.9156
# Epoch 88/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1827 - accuracy: 0.9342 - val_loss: 0.2525 - val_accuracy: 0.9128
# Epoch 89/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1878 - accuracy: 0.9304 - val_loss: 0.2471 - val_accuracy: 0.9184
# Epoch 90/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1929 - accuracy: 0.9272 - val_loss: 0.2659 - val_accuracy: 0.9086
# Epoch 91/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1903 - accuracy: 0.9262 - val_loss: 0.2563 - val_accuracy: 0.9114
# Epoch 92/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1948 - accuracy: 0.9272 - val_loss: 0.2659 - val_accuracy: 0.9128
# Epoch 93/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1843 - accuracy: 0.9353 - val_loss: 0.2445 - val_accuracy: 0.9142
# Epoch 94/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1830 - accuracy: 0.9325 - val_loss: 0.2478 - val_accuracy: 0.9241
# Epoch 95/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1825 - accuracy: 0.9335 - val_loss: 0.2440 - val_accuracy: 0.9297
# Epoch 96/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1736 - accuracy: 0.9335 - val_loss: 0.2362 - val_accuracy: 0.9212
# Epoch 97/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1783 - accuracy: 0.9318 - val_loss: 0.2583 - val_accuracy: 0.9156
# Epoch 98/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1829 - accuracy: 0.9307 - val_loss: 0.2291 - val_accuracy: 0.9325
# Epoch 99/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1775 - accuracy: 0.9374 - val_loss: 0.2660 - val_accuracy: 0.9072
# Epoch 100/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1703 - accuracy: 0.9381 - val_loss: 0.2363 - val_accuracy: 0.9255
# Epoch 101/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1650 - accuracy: 0.9413 - val_loss: 0.2315 - val_accuracy: 0.9241
# Epoch 102/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1644 - accuracy: 0.9448 - val_loss: 0.2281 - val_accuracy: 0.9311
# Epoch 103/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1537 - accuracy: 0.9441 - val_loss: 0.2344 - val_accuracy: 0.9311
# Epoch 104/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1665 - accuracy: 0.9360 - val_loss: 0.2371 - val_accuracy: 0.9283
# Epoch 105/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1615 - accuracy: 0.9459 - val_loss: 0.2288 - val_accuracy: 0.9297
# Epoch 106/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1518 - accuracy: 0.9462 - val_loss: 0.2316 - val_accuracy: 0.9325
# Epoch 107/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1517 - accuracy: 0.9473 - val_loss: 0.2383 - val_accuracy: 0.9226
# Epoch 108/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1517 - accuracy: 0.9444 - val_loss: 0.2351 - val_accuracy: 0.9297
# Epoch 109/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1501 - accuracy: 0.9437 - val_loss: 0.2456 - val_accuracy: 0.9241
# Epoch 110/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1554 - accuracy: 0.9451 - val_loss: 0.2401 - val_accuracy: 0.9255
# Epoch 111/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1612 - accuracy: 0.9413 - val_loss: 0.2514 - val_accuracy: 0.9156
# Epoch 112/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1601 - accuracy: 0.9427 - val_loss: 0.2294 - val_accuracy: 0.9325
# Epoch 113/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1529 - accuracy: 0.9462 - val_loss: 0.2354 - val_accuracy: 0.9226
# Epoch 114/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1531 - accuracy: 0.9420 - val_loss: 0.2361 - val_accuracy: 0.9325
# Epoch 115/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1487 - accuracy: 0.9459 - val_loss: 0.2377 - val_accuracy: 0.9212
# Epoch 116/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1465 - accuracy: 0.9480 - val_loss: 0.2409 - val_accuracy: 0.9226
# Epoch 117/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1494 - accuracy: 0.9451 - val_loss: 0.2322 - val_accuracy: 0.9353
# Epoch 118/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1464 - accuracy: 0.9490 - val_loss: 0.2240 - val_accuracy: 0.9381
# Epoch 119/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1431 - accuracy: 0.9518 - val_loss: 0.2451 - val_accuracy: 0.9255
# Epoch 120/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1574 - accuracy: 0.9434 - val_loss: 0.2307 - val_accuracy: 0.9269
# Epoch 121/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1434 - accuracy: 0.9497 - val_loss: 0.2276 - val_accuracy: 0.9241
# Epoch 122/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1492 - accuracy: 0.9459 - val_loss: 0.2357 - val_accuracy: 0.9297
# Epoch 123/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1603 - accuracy: 0.9385 - val_loss: 0.2403 - val_accuracy: 0.9198
# Epoch 124/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1505 - accuracy: 0.9434 - val_loss: 0.2345 - val_accuracy: 0.9367
# Epoch 125/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1523 - accuracy: 0.9466 - val_loss: 0.2402 - val_accuracy: 0.9311
# Epoch 126/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1569 - accuracy: 0.9427 - val_loss: 0.2419 - val_accuracy: 0.9311
# Epoch 127/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1515 - accuracy: 0.9473 - val_loss: 0.2401 - val_accuracy: 0.9226
# Epoch 128/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1449 - accuracy: 0.9430 - val_loss: 0.2354 - val_accuracy: 0.9311
# Epoch 129/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1529 - accuracy: 0.9441 - val_loss: 0.2214 - val_accuracy: 0.9325
# Epoch 130/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1427 - accuracy: 0.9487 - val_loss: 0.2252 - val_accuracy: 0.9367
# Epoch 131/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1382 - accuracy: 0.9539 - val_loss: 0.2257 - val_accuracy: 0.9325
# Epoch 132/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1422 - accuracy: 0.9473 - val_loss: 0.2424 - val_accuracy: 0.9283
# Epoch 133/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1381 - accuracy: 0.9522 - val_loss: 0.2440 - val_accuracy: 0.9269
# Epoch 134/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1466 - accuracy: 0.9459 - val_loss: 0.2205 - val_accuracy: 0.9339
# Epoch 135/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1385 - accuracy: 0.9508 - val_loss: 0.2542 - val_accuracy: 0.9226
# Epoch 136/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1583 - accuracy: 0.9385 - val_loss: 0.2229 - val_accuracy: 0.9325
# Epoch 137/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1468 - accuracy: 0.9437 - val_loss: 0.2913 - val_accuracy: 0.9058
# Epoch 138/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1402 - accuracy: 0.9501 - val_loss: 0.2274 - val_accuracy: 0.9297
# Epoch 139/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1451 - accuracy: 0.9487 - val_loss: 0.2245 - val_accuracy: 0.9311
# Epoch 140/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1257 - accuracy: 0.9553 - val_loss: 0.2286 - val_accuracy: 0.9367
# Epoch 141/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1327 - accuracy: 0.9459 - val_loss: 0.2305 - val_accuracy: 0.9339
# Epoch 142/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1323 - accuracy: 0.9487 - val_loss: 0.2158 - val_accuracy: 0.9381
# Epoch 143/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1346 - accuracy: 0.9480 - val_loss: 0.2275 - val_accuracy: 0.9269
# Epoch 144/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1446 - accuracy: 0.9448 - val_loss: 0.2137 - val_accuracy: 0.9367
# Epoch 145/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1319 - accuracy: 0.9501 - val_loss: 0.2409 - val_accuracy: 0.9226
# Epoch 146/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1342 - accuracy: 0.9522 - val_loss: 0.2293 - val_accuracy: 0.9381
# Epoch 147/200
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1429 - accuracy: 0.9441 - val_loss: 0.2351 - val_accuracy: 0.9283
# Epoch 148/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1322 - accuracy: 0.9543 - val_loss: 0.2318 - val_accuracy: 0.9311
# Epoch 149/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1312 - accuracy: 0.9494 - val_loss: 0.2371 - val_accuracy: 0.9311
# Epoch 150/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1159 - accuracy: 0.9582 - val_loss: 0.2187 - val_accuracy: 0.9367
# Epoch 151/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1161 - accuracy: 0.9592 - val_loss: 0.2199 - val_accuracy: 0.9353
# Epoch 152/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1222 - accuracy: 0.9575 - val_loss: 0.2227 - val_accuracy: 0.9466
# Epoch 153/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1168 - accuracy: 0.9599 - val_loss: 0.2168 - val_accuracy: 0.9409
# Epoch 154/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1131 - accuracy: 0.9557 - val_loss: 0.2260 - val_accuracy: 0.9297
# Epoch 155/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1219 - accuracy: 0.9539 - val_loss: 0.2176 - val_accuracy: 0.9367
# Epoch 156/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1224 - accuracy: 0.9571 - val_loss: 0.2335 - val_accuracy: 0.9241
# Epoch 157/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1258 - accuracy: 0.9504 - val_loss: 0.2216 - val_accuracy: 0.9269
# Epoch 158/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1180 - accuracy: 0.9557 - val_loss: 0.2263 - val_accuracy: 0.9409
# Epoch 159/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1201 - accuracy: 0.9543 - val_loss: 0.2243 - val_accuracy: 0.9339
# Epoch 160/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1190 - accuracy: 0.9592 - val_loss: 0.2145 - val_accuracy: 0.9283
# Epoch 161/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1175 - accuracy: 0.9599 - val_loss: 0.2216 - val_accuracy: 0.9381
# Epoch 162/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1154 - accuracy: 0.9543 - val_loss: 0.2205 - val_accuracy: 0.9395
# Epoch 163/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1248 - accuracy: 0.9568 - val_loss: 0.2379 - val_accuracy: 0.9255
# Epoch 164/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1278 - accuracy: 0.9473 - val_loss: 0.2296 - val_accuracy: 0.9381
# Epoch 165/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1197 - accuracy: 0.9550 - val_loss: 0.2062 - val_accuracy: 0.9451
# Epoch 166/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1146 - accuracy: 0.9582 - val_loss: 0.2303 - val_accuracy: 0.9381
# Epoch 167/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1277 - accuracy: 0.9532 - val_loss: 0.2130 - val_accuracy: 0.9451
# Epoch 168/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1179 - accuracy: 0.9603 - val_loss: 0.2215 - val_accuracy: 0.9367
# Epoch 169/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1135 - accuracy: 0.9613 - val_loss: 0.2187 - val_accuracy: 0.9395
# Epoch 170/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1173 - accuracy: 0.9589 - val_loss: 0.2221 - val_accuracy: 0.9437
# Epoch 171/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1142 - accuracy: 0.9589 - val_loss: 0.2140 - val_accuracy: 0.9353
# Epoch 172/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1117 - accuracy: 0.9575 - val_loss: 0.2145 - val_accuracy: 0.9339
# Epoch 173/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1169 - accuracy: 0.9539 - val_loss: 0.2108 - val_accuracy: 0.9451
# Epoch 174/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1067 - accuracy: 0.9634 - val_loss: 0.2192 - val_accuracy: 0.9409
# Epoch 175/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1113 - accuracy: 0.9568 - val_loss: 0.2298 - val_accuracy: 0.9409
# Epoch 176/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1067 - accuracy: 0.9617 - val_loss: 0.2212 - val_accuracy: 0.9367
# Epoch 177/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1094 - accuracy: 0.9557 - val_loss: 0.2132 - val_accuracy: 0.9381
# Epoch 178/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1069 - accuracy: 0.9624 - val_loss: 0.2195 - val_accuracy: 0.9381
# Epoch 179/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1043 - accuracy: 0.9617 - val_loss: 0.2217 - val_accuracy: 0.9367
# Epoch 180/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1114 - accuracy: 0.9617 - val_loss: 0.2152 - val_accuracy: 0.9423
# Epoch 181/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0994 - accuracy: 0.9652 - val_loss: 0.2136 - val_accuracy: 0.9395
# Epoch 182/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1044 - accuracy: 0.9627 - val_loss: 0.2142 - val_accuracy: 0.9423
# Epoch 183/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0977 - accuracy: 0.9627 - val_loss: 0.2266 - val_accuracy: 0.9353
# Epoch 184/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0965 - accuracy: 0.9655 - val_loss: 0.2120 - val_accuracy: 0.9423
# Epoch 185/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0958 - accuracy: 0.9652 - val_loss: 0.2225 - val_accuracy: 0.9409
# Epoch 186/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0897 - accuracy: 0.9680 - val_loss: 0.2252 - val_accuracy: 0.9423
# Epoch 187/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1039 - accuracy: 0.9613 - val_loss: 0.2255 - val_accuracy: 0.9381
# Epoch 188/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0992 - accuracy: 0.9652 - val_loss: 0.2297 - val_accuracy: 0.9353
# Epoch 189/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1044 - accuracy: 0.9575 - val_loss: 0.2244 - val_accuracy: 0.9423
# Epoch 190/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1003 - accuracy: 0.9613 - val_loss: 0.2279 - val_accuracy: 0.9480
# Epoch 191/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.0944 - accuracy: 0.9648 - val_loss: 0.2150 - val_accuracy: 0.9423
# Epoch 192/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.0915 - accuracy: 0.9680 - val_loss: 0.2328 - val_accuracy: 0.9437
# Epoch 193/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.0987 - accuracy: 0.9620 - val_loss: 0.2142 - val_accuracy: 0.9437
# Epoch 194/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.0997 - accuracy: 0.9606 - val_loss: 0.2408 - val_accuracy: 0.9283
# Epoch 195/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1017 - accuracy: 0.9634 - val_loss: 0.2113 - val_accuracy: 0.9466
# Epoch 196/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1016 - accuracy: 0.9620 - val_loss: 0.2218 - val_accuracy: 0.9381
# Epoch 197/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0992 - accuracy: 0.9666 - val_loss: 0.2131 - val_accuracy: 0.9508
# Epoch 198/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0885 - accuracy: 0.9680 - val_loss: 0.2219 - val_accuracy: 0.9423
# Epoch 199/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0921 - accuracy: 0.9677 - val_loss: 0.2233 - val_accuracy: 0.9437
# Epoch 200/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0889 - accuracy: 0.9659 - val_loss: 0.2138 - val_accuracy: 0.9437

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 6/6 [==============================] - 1s 97ms/step - loss: 1.7249 - accuracy: 0.3949 - val_loss: 1.2233 - val_accuracy: 0.5823
# Epoch 2/45
# 6/6 [==============================] - 0s 66ms/step - loss: 1.0992 - accuracy: 0.6276 - val_loss: 0.9254 - val_accuracy: 0.6399
# Epoch 3/45
# 6/6 [==============================] - 0s 60ms/step - loss: 0.8544 - accuracy: 0.6899 - val_loss: 0.7785 - val_accuracy: 0.6864
# Epoch 4/45
# 6/6 [==============================] - 0s 59ms/step - loss: 0.7103 - accuracy: 0.7173 - val_loss: 0.6918 - val_accuracy: 0.7257
# Epoch 5/45
# 6/6 [==============================] - 0s 59ms/step - loss: 0.6380 - accuracy: 0.7419 - val_loss: 0.6315 - val_accuracy: 0.7679
# Epoch 6/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.6014 - accuracy: 0.7584 - val_loss: 0.6347 - val_accuracy: 0.7665
# Epoch 7/45
# 6/6 [==============================] - 0s 58ms/step - loss: 0.5856 - accuracy: 0.7707 - val_loss: 0.5779 - val_accuracy: 0.7806
# Epoch 8/45
# 6/6 [==============================] - 0s 59ms/step - loss: 0.5539 - accuracy: 0.7887 - val_loss: 0.5869 - val_accuracy: 0.7679
# Epoch 9/45
# 6/6 [==============================] - 0s 67ms/step - loss: 0.5399 - accuracy: 0.7925 - val_loss: 0.5722 - val_accuracy: 0.7848
# Epoch 10/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.5169 - accuracy: 0.8024 - val_loss: 0.5755 - val_accuracy: 0.7553
# Epoch 11/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.5056 - accuracy: 0.8024 - val_loss: 0.5962 - val_accuracy: 0.7454
# Epoch 12/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5020 - accuracy: 0.8094 - val_loss: 0.5419 - val_accuracy: 0.7904
# Epoch 13/45
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4819 - accuracy: 0.8179 - val_loss: 0.5167 - val_accuracy: 0.8200
# Epoch 14/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4554 - accuracy: 0.8347 - val_loss: 0.5152 - val_accuracy: 0.8129
# Epoch 15/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4527 - accuracy: 0.8354 - val_loss: 0.5142 - val_accuracy: 0.8143
# Epoch 16/45
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4591 - accuracy: 0.8245 - val_loss: 0.4959 - val_accuracy: 0.8214
# Epoch 17/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4363 - accuracy: 0.8467 - val_loss: 0.4966 - val_accuracy: 0.8129
# Epoch 18/45
# 6/6 [==============================] - 0s 56ms/step - loss: 0.4279 - accuracy: 0.8446 - val_loss: 0.4747 - val_accuracy: 0.8284
# Epoch 19/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4213 - accuracy: 0.8477 - val_loss: 0.4785 - val_accuracy: 0.8172
# Epoch 20/45
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4244 - accuracy: 0.8432 - val_loss: 0.4883 - val_accuracy: 0.8073
# Epoch 21/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4259 - accuracy: 0.8407 - val_loss: 0.4615 - val_accuracy: 0.8242
# Epoch 22/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3958 - accuracy: 0.8544 - val_loss: 0.4485 - val_accuracy: 0.8383
# Epoch 23/45
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3913 - accuracy: 0.8576 - val_loss: 0.4487 - val_accuracy: 0.8340
# Epoch 24/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3726 - accuracy: 0.8685 - val_loss: 0.4465 - val_accuracy: 0.8298
# Epoch 25/45
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3709 - accuracy: 0.8643 - val_loss: 0.4388 - val_accuracy: 0.8368
# Epoch 26/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3730 - accuracy: 0.8615 - val_loss: 0.4359 - val_accuracy: 0.8425
# Epoch 27/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3768 - accuracy: 0.8622 - val_loss: 0.4156 - val_accuracy: 0.8411
# Epoch 28/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3709 - accuracy: 0.8615 - val_loss: 0.4349 - val_accuracy: 0.8368
# Epoch 29/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3657 - accuracy: 0.8674 - val_loss: 0.4002 - val_accuracy: 0.8523
# Epoch 30/45
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3376 - accuracy: 0.8790 - val_loss: 0.4032 - val_accuracy: 0.8565
# Epoch 31/45
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3319 - accuracy: 0.8805 - val_loss: 0.3989 - val_accuracy: 0.8608
# Epoch 32/45
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3343 - accuracy: 0.8727 - val_loss: 0.3837 - val_accuracy: 0.8622
# Epoch 33/45
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3328 - accuracy: 0.8794 - val_loss: 0.4029 - val_accuracy: 0.8481
# Epoch 34/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3267 - accuracy: 0.8829 - val_loss: 0.3743 - val_accuracy: 0.8636
# Epoch 35/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3277 - accuracy: 0.8783 - val_loss: 0.3972 - val_accuracy: 0.8608
# Epoch 36/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3222 - accuracy: 0.8815 - val_loss: 0.3704 - val_accuracy: 0.8636
# Epoch 37/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3222 - accuracy: 0.8783 - val_loss: 0.3658 - val_accuracy: 0.8636
# Epoch 38/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3148 - accuracy: 0.8878 - val_loss: 0.3644 - val_accuracy: 0.8664
# Epoch 39/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3135 - accuracy: 0.8878 - val_loss: 0.3700 - val_accuracy: 0.8678
# Epoch 40/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3077 - accuracy: 0.8910 - val_loss: 0.3679 - val_accuracy: 0.8664
# Epoch 41/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2988 - accuracy: 0.8875 - val_loss: 0.3588 - val_accuracy: 0.8720
# Epoch 42/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3014 - accuracy: 0.8903 - val_loss: 0.3452 - val_accuracy: 0.8734
# Epoch 43/45
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2826 - accuracy: 0.9008 - val_loss: 0.3440 - val_accuracy: 0.8762
# Epoch 44/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2993 - accuracy: 0.8878 - val_loss: 0.3392 - val_accuracy: 0.8748
# Epoch 45/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2820 - accuracy: 0.9005 - val_loss: 0.3347 - val_accuracy: 0.8819

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 6ms/step - loss: 0.2584 - accuracy: 0.9079
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3347 - accuracy: 0.8819
# 0.9078762531280518 0.8818565607070923

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 122, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:19

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   2   1   0   0   0]
#  [  0   0   0 218  10   0   0  12]
#  [  0   0   0  28  61   2   0   9]
#  [  0   0   0   0   0  12   0   0]
#  [  1   0   0   0   0   0  10   0]
#  [  0   0   0  16   2   1   0  27]]
#
# Accuracy Score
# 0.8818565400843882
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.99      1.00      0.99        80
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.83      0.91      0.87       240
#     windows       0.82      0.61      0.70       100
#       roads       0.80      1.00      0.89        12
#        cars       1.00      0.91      0.95        11
#       metal       0.56      0.59      0.57        46
#
# avg / total       0.88      0.88      0.88       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 122
# [[0, 7], [7, 14], [14, 21], [21, 28], [28, 35], [35, 42], [42, 49], [49, 56], [56, 63], [63, 70], [70, 77], [77, 84], [84, 91], [91, 98], [98, 105], [105, 112], [112, 119], [119, 126], [126, 133], [133, 140], [140, 147], [147, 154], [154, 161], [161, 168], [168, 175], [175, 182], [182, 189], [189, 196], [196, 203], [203, 210], [210, 217], [217, 224], [224, 231], [231, 238], [238, 245], [245, 252], [252, 259], [259, 266], [266, 273], [273, 280], [280, 287], [287, 294], [294, 301], [301, 308], [308, 315], [315, 322], [322, 329], [329, 336], [336, 343], [343, 350], [350, 357], [357, 364], [364, 371], [371, 378], [378, 385], [385, 392], [392, 399], [399, 406], [406, 413], [413, 420], [420, 427], [427, 434], [434, 441], [441, 448], [448, 455], [455, 462], [462, 469], [469, 476], [476, 483], [483, 490], [490, 497], [497, 504], [504, 511], [511, 518], [518, 525], [525, 532], [532, 539], [539, 546], [546, 553], [553, 560], [560, 567], [567, 574], [574, 581], [581, 588], [588, 595], [595, 602], [602, 609], [609, 616], [616, 623], [623, 630], [630, 637], [637, 644], [644, 651], [651, 658], [658, 665], [665, 672], [672, 679], [679, 686], [686, 693], [693, 700], [700, 707], [707, 714], [714, 721], [721, 728], [728, 735], [735, 742], [742, 749], [749, 756], [756, 763], [763, 770], [770, 777], [777, 784], [784, 791], [791, 798], [798, 805], [805, 812], [812, 819], [819, 826], [826, 833], [833, 840], [840, 847], [847, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 122)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 122)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 122) (60, 122)
# clouds  (160, 122) (40, 122)
# vegetation  (560, 122) (140, 122)
# water  (496, 122) (124, 122)
# built  (1280, 122) (320, 122)
# windows  (480, 122) (120, 122)
# roads  (200, 122) (50, 122)
# cars  (200, 122) (50, 122)
# metal  (148, 122) (37, 122)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 122) (3764,) (3764, 2)
# (941, 122) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 77ms/step - loss: 1.7273 - accuracy: 0.3988 - val_loss: 1.4016 - val_accuracy: 0.5271
# Epoch 2/200
# 8/8 [==============================] - 0s 57ms/step - loss: 1.3682 - accuracy: 0.5027 - val_loss: 1.2960 - val_accuracy: 0.5367
# Epoch 3/200
# 8/8 [==============================] - 0s 49ms/step - loss: 1.2897 - accuracy: 0.5391 - val_loss: 1.2244 - val_accuracy: 0.5760
# Epoch 4/200
# 8/8 [==============================] - 0s 59ms/step - loss: 1.2135 - accuracy: 0.5603 - val_loss: 1.1893 - val_accuracy: 0.5356
# Epoch 5/200
# 8/8 [==============================] - 0s 54ms/step - loss: 1.1538 - accuracy: 0.5863 - val_loss: 1.0861 - val_accuracy: 0.6451
# Epoch 6/200
# 8/8 [==============================] - 0s 55ms/step - loss: 1.0827 - accuracy: 0.6124 - val_loss: 1.0222 - val_accuracy: 0.6525
# Epoch 7/200
# 8/8 [==============================] - 0s 55ms/step - loss: 1.0328 - accuracy: 0.6443 - val_loss: 0.9406 - val_accuracy: 0.7141
# Epoch 8/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.9672 - accuracy: 0.6889 - val_loss: 0.9060 - val_accuracy: 0.7205
# Epoch 9/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.9035 - accuracy: 0.7048 - val_loss: 0.8362 - val_accuracy: 0.7375
# Epoch 10/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.8468 - accuracy: 0.7224 - val_loss: 0.8022 - val_accuracy: 0.7386
# Epoch 11/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.8002 - accuracy: 0.7293 - val_loss: 0.7575 - val_accuracy: 0.7609
# Epoch 12/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.7728 - accuracy: 0.7402 - val_loss: 0.7262 - val_accuracy: 0.7673
# Epoch 13/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.7362 - accuracy: 0.7630 - val_loss: 0.6776 - val_accuracy: 0.7853
# Epoch 14/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6917 - accuracy: 0.7750 - val_loss: 0.6703 - val_accuracy: 0.7821
# Epoch 15/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6737 - accuracy: 0.7707 - val_loss: 0.6415 - val_accuracy: 0.8002
# Epoch 16/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6456 - accuracy: 0.7821 - val_loss: 0.6077 - val_accuracy: 0.7906
# Epoch 17/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.6192 - accuracy: 0.7938 - val_loss: 0.5902 - val_accuracy: 0.8045
# Epoch 18/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6147 - accuracy: 0.8002 - val_loss: 0.5800 - val_accuracy: 0.8183
# Epoch 19/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5830 - accuracy: 0.8071 - val_loss: 0.5764 - val_accuracy: 0.8045
# Epoch 20/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.5749 - accuracy: 0.7997 - val_loss: 0.5642 - val_accuracy: 0.8183
# Epoch 21/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5838 - accuracy: 0.8063 - val_loss: 0.5501 - val_accuracy: 0.8247
# Epoch 22/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5616 - accuracy: 0.8116 - val_loss: 0.5737 - val_accuracy: 0.8225
# Epoch 23/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5567 - accuracy: 0.8140 - val_loss: 0.5628 - val_accuracy: 0.8172
# Epoch 24/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5431 - accuracy: 0.8164 - val_loss: 0.5393 - val_accuracy: 0.8427
# Epoch 25/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5201 - accuracy: 0.8223 - val_loss: 0.5385 - val_accuracy: 0.8193
# Epoch 26/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.5142 - accuracy: 0.8262 - val_loss: 0.5263 - val_accuracy: 0.8406
# Epoch 27/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.5111 - accuracy: 0.8239 - val_loss: 0.5063 - val_accuracy: 0.8353
# Epoch 28/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.5001 - accuracy: 0.8278 - val_loss: 0.4978 - val_accuracy: 0.8608
# Epoch 29/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4834 - accuracy: 0.8387 - val_loss: 0.4674 - val_accuracy: 0.8693
# Epoch 30/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4694 - accuracy: 0.8478 - val_loss: 0.4713 - val_accuracy: 0.8693
# Epoch 31/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4662 - accuracy: 0.8409 - val_loss: 0.4848 - val_accuracy: 0.8533
# Epoch 32/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4916 - accuracy: 0.8286 - val_loss: 0.5113 - val_accuracy: 0.8597
# Epoch 33/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4870 - accuracy: 0.8467 - val_loss: 0.4763 - val_accuracy: 0.8576
# Epoch 34/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4554 - accuracy: 0.8502 - val_loss: 0.4306 - val_accuracy: 0.8842
# Epoch 35/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4378 - accuracy: 0.8526 - val_loss: 0.4375 - val_accuracy: 0.8650
# Epoch 36/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.4411 - accuracy: 0.8523 - val_loss: 0.4550 - val_accuracy: 0.8427
# Epoch 37/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4408 - accuracy: 0.8483 - val_loss: 0.4389 - val_accuracy: 0.8725
# Epoch 38/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.4285 - accuracy: 0.8568 - val_loss: 0.4204 - val_accuracy: 0.8852
# Epoch 39/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.4151 - accuracy: 0.8640 - val_loss: 0.4354 - val_accuracy: 0.8735
# Epoch 40/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4247 - accuracy: 0.8616 - val_loss: 0.4268 - val_accuracy: 0.8852
# Epoch 41/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.4092 - accuracy: 0.8674 - val_loss: 0.4482 - val_accuracy: 0.8714
# Epoch 42/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.4070 - accuracy: 0.8674 - val_loss: 0.3979 - val_accuracy: 0.8874
# Epoch 43/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3957 - accuracy: 0.8741 - val_loss: 0.4082 - val_accuracy: 0.8831
# Epoch 44/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3944 - accuracy: 0.8765 - val_loss: 0.4100 - val_accuracy: 0.8725
# Epoch 45/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3780 - accuracy: 0.8775 - val_loss: 0.3898 - val_accuracy: 0.8884
# Epoch 46/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3829 - accuracy: 0.8794 - val_loss: 0.4028 - val_accuracy: 0.8757
# Epoch 47/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3780 - accuracy: 0.8770 - val_loss: 0.4139 - val_accuracy: 0.8735
# Epoch 48/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3761 - accuracy: 0.8791 - val_loss: 0.3816 - val_accuracy: 0.8799
# Epoch 49/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3604 - accuracy: 0.8781 - val_loss: 0.3799 - val_accuracy: 0.8874
# Epoch 50/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3566 - accuracy: 0.8796 - val_loss: 0.3839 - val_accuracy: 0.8959
# Epoch 51/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3475 - accuracy: 0.8895 - val_loss: 0.3761 - val_accuracy: 0.8990
# Epoch 52/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3467 - accuracy: 0.8858 - val_loss: 0.3671 - val_accuracy: 0.8927
# Epoch 53/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3516 - accuracy: 0.8826 - val_loss: 0.3746 - val_accuracy: 0.8959
# Epoch 54/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3544 - accuracy: 0.8858 - val_loss: 0.3758 - val_accuracy: 0.8969
# Epoch 55/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3391 - accuracy: 0.8884 - val_loss: 0.3692 - val_accuracy: 0.8959
# Epoch 56/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3408 - accuracy: 0.8842 - val_loss: 0.3569 - val_accuracy: 0.8959
# Epoch 57/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3457 - accuracy: 0.8882 - val_loss: 0.3646 - val_accuracy: 0.9022
# Epoch 58/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3250 - accuracy: 0.8964 - val_loss: 0.3549 - val_accuracy: 0.8980
# Epoch 59/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3308 - accuracy: 0.8889 - val_loss: 0.3819 - val_accuracy: 0.8905
# Epoch 60/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.3348 - accuracy: 0.8927 - val_loss: 0.3468 - val_accuracy: 0.9065
# Epoch 61/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3204 - accuracy: 0.8959 - val_loss: 0.3560 - val_accuracy: 0.9001
# Epoch 62/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3198 - accuracy: 0.8953 - val_loss: 0.3439 - val_accuracy: 0.8969
# Epoch 63/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3218 - accuracy: 0.8945 - val_loss: 0.3666 - val_accuracy: 0.8905
# Epoch 64/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3225 - accuracy: 0.8903 - val_loss: 0.3637 - val_accuracy: 0.8990
# Epoch 65/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3188 - accuracy: 0.8953 - val_loss: 0.3701 - val_accuracy: 0.8948
# Epoch 66/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3264 - accuracy: 0.8892 - val_loss: 0.3672 - val_accuracy: 0.8884
# Epoch 67/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3093 - accuracy: 0.8964 - val_loss: 0.3596 - val_accuracy: 0.9001
# Epoch 68/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3200 - accuracy: 0.8905 - val_loss: 0.3359 - val_accuracy: 0.8969
# Epoch 69/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3059 - accuracy: 0.9028 - val_loss: 0.3417 - val_accuracy: 0.9001
# Epoch 70/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2943 - accuracy: 0.9033 - val_loss: 0.3289 - val_accuracy: 0.9075
# Epoch 71/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2961 - accuracy: 0.9012 - val_loss: 0.3587 - val_accuracy: 0.8863
# Epoch 72/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3130 - accuracy: 0.8964 - val_loss: 0.3394 - val_accuracy: 0.9033
# Epoch 73/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3066 - accuracy: 0.8935 - val_loss: 0.3371 - val_accuracy: 0.8969
# Epoch 74/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.2928 - accuracy: 0.9022 - val_loss: 0.3249 - val_accuracy: 0.9107
# Epoch 75/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2746 - accuracy: 0.9102 - val_loss: 0.3560 - val_accuracy: 0.8927
# Epoch 76/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2893 - accuracy: 0.9078 - val_loss: 0.3572 - val_accuracy: 0.9033
# Epoch 77/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2946 - accuracy: 0.9009 - val_loss: 0.3282 - val_accuracy: 0.8927
# Epoch 78/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2782 - accuracy: 0.9073 - val_loss: 0.3264 - val_accuracy: 0.9118
# Epoch 79/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2685 - accuracy: 0.9129 - val_loss: 0.3285 - val_accuracy: 0.8990
# Epoch 80/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2734 - accuracy: 0.9070 - val_loss: 0.3376 - val_accuracy: 0.9033
# Epoch 81/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2679 - accuracy: 0.9123 - val_loss: 0.3167 - val_accuracy: 0.9065
# Epoch 82/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2579 - accuracy: 0.9137 - val_loss: 0.3446 - val_accuracy: 0.9075
# Epoch 83/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2845 - accuracy: 0.9073 - val_loss: 0.3224 - val_accuracy: 0.8959
# Epoch 84/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2695 - accuracy: 0.9107 - val_loss: 0.3753 - val_accuracy: 0.8959
# Epoch 85/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2796 - accuracy: 0.9014 - val_loss: 0.3226 - val_accuracy: 0.9001
# Epoch 86/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2701 - accuracy: 0.9139 - val_loss: 0.3224 - val_accuracy: 0.9107
# Epoch 87/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2659 - accuracy: 0.9147 - val_loss: 0.3266 - val_accuracy: 0.9118
# Epoch 88/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2606 - accuracy: 0.9137 - val_loss: 0.3152 - val_accuracy: 0.9118
# Epoch 89/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2536 - accuracy: 0.9174 - val_loss: 0.3087 - val_accuracy: 0.9022
# Epoch 90/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2503 - accuracy: 0.9166 - val_loss: 0.3060 - val_accuracy: 0.9097
# Epoch 91/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2544 - accuracy: 0.9110 - val_loss: 0.3564 - val_accuracy: 0.8852
# Epoch 92/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2888 - accuracy: 0.9060 - val_loss: 0.3769 - val_accuracy: 0.8735
# Epoch 93/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2869 - accuracy: 0.8988 - val_loss: 0.3233 - val_accuracy: 0.9097
# Epoch 94/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2781 - accuracy: 0.9060 - val_loss: 0.3072 - val_accuracy: 0.9044
# Epoch 95/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2623 - accuracy: 0.9155 - val_loss: 0.3401 - val_accuracy: 0.9022
# Epoch 96/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2643 - accuracy: 0.9115 - val_loss: 0.3484 - val_accuracy: 0.9022
# Epoch 97/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2712 - accuracy: 0.9078 - val_loss: 0.3197 - val_accuracy: 0.8905
# Epoch 98/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2523 - accuracy: 0.9168 - val_loss: 0.3226 - val_accuracy: 0.9054
# Epoch 99/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2504 - accuracy: 0.9145 - val_loss: 0.2983 - val_accuracy: 0.9139
# Epoch 100/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2441 - accuracy: 0.9163 - val_loss: 0.3045 - val_accuracy: 0.9139
# Epoch 101/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2407 - accuracy: 0.9232 - val_loss: 0.3304 - val_accuracy: 0.9075
# Epoch 102/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2437 - accuracy: 0.9198 - val_loss: 0.3153 - val_accuracy: 0.9139
# Epoch 103/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2465 - accuracy: 0.9176 - val_loss: 0.3517 - val_accuracy: 0.9054
# Epoch 104/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2538 - accuracy: 0.9152 - val_loss: 0.2893 - val_accuracy: 0.9086
# Epoch 105/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2462 - accuracy: 0.9139 - val_loss: 0.3114 - val_accuracy: 0.9065
# Epoch 106/200
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2608 - accuracy: 0.9131 - val_loss: 0.3097 - val_accuracy: 0.9118
# Epoch 107/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2489 - accuracy: 0.9195 - val_loss: 0.3266 - val_accuracy: 0.9118
# Epoch 108/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2275 - accuracy: 0.9259 - val_loss: 0.2865 - val_accuracy: 0.9171
# Epoch 109/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2137 - accuracy: 0.9323 - val_loss: 0.2921 - val_accuracy: 0.9118
# Epoch 110/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2131 - accuracy: 0.9288 - val_loss: 0.2880 - val_accuracy: 0.9182
# Epoch 111/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2145 - accuracy: 0.9283 - val_loss: 0.2910 - val_accuracy: 0.9192
# Epoch 112/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2138 - accuracy: 0.9336 - val_loss: 0.2932 - val_accuracy: 0.9129
# Epoch 113/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2178 - accuracy: 0.9301 - val_loss: 0.3446 - val_accuracy: 0.8990
# Epoch 114/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2383 - accuracy: 0.9176 - val_loss: 0.3077 - val_accuracy: 0.9139
# Epoch 115/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2169 - accuracy: 0.9309 - val_loss: 0.2949 - val_accuracy: 0.9203
# Epoch 116/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.2136 - accuracy: 0.9267 - val_loss: 0.2955 - val_accuracy: 0.9171
# Epoch 117/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2045 - accuracy: 0.9307 - val_loss: 0.2914 - val_accuracy: 0.9182
# Epoch 118/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2059 - accuracy: 0.9304 - val_loss: 0.2893 - val_accuracy: 0.9192
# Epoch 119/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2104 - accuracy: 0.9259 - val_loss: 0.3042 - val_accuracy: 0.9065
# Epoch 120/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2093 - accuracy: 0.9272 - val_loss: 0.2815 - val_accuracy: 0.9171
# Epoch 121/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2025 - accuracy: 0.9338 - val_loss: 0.2850 - val_accuracy: 0.9118
# Epoch 122/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1910 - accuracy: 0.9376 - val_loss: 0.2799 - val_accuracy: 0.9171
# Epoch 123/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1985 - accuracy: 0.9360 - val_loss: 0.2975 - val_accuracy: 0.9118
# Epoch 124/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1962 - accuracy: 0.9346 - val_loss: 0.2913 - val_accuracy: 0.9160
# Epoch 125/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2136 - accuracy: 0.9283 - val_loss: 0.2757 - val_accuracy: 0.9203
# Epoch 126/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2055 - accuracy: 0.9338 - val_loss: 0.2938 - val_accuracy: 0.9182
# Epoch 127/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1907 - accuracy: 0.9357 - val_loss: 0.2953 - val_accuracy: 0.9171
# Epoch 128/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1937 - accuracy: 0.9373 - val_loss: 0.2709 - val_accuracy: 0.9171
# Epoch 129/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2016 - accuracy: 0.9315 - val_loss: 0.2768 - val_accuracy: 0.9192
# Epoch 130/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1990 - accuracy: 0.9307 - val_loss: 0.2829 - val_accuracy: 0.9171
# Epoch 131/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1886 - accuracy: 0.9394 - val_loss: 0.3110 - val_accuracy: 0.9118
# Epoch 132/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1987 - accuracy: 0.9362 - val_loss: 0.2953 - val_accuracy: 0.9118
# Epoch 133/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1958 - accuracy: 0.9317 - val_loss: 0.2781 - val_accuracy: 0.9139
# Epoch 134/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1876 - accuracy: 0.9437 - val_loss: 0.2827 - val_accuracy: 0.9182
# Epoch 135/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1859 - accuracy: 0.9394 - val_loss: 0.2704 - val_accuracy: 0.9118
# Epoch 136/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1852 - accuracy: 0.9402 - val_loss: 0.2668 - val_accuracy: 0.9245
# Epoch 137/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1849 - accuracy: 0.9421 - val_loss: 0.2619 - val_accuracy: 0.9192
# Epoch 138/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1867 - accuracy: 0.9384 - val_loss: 0.2957 - val_accuracy: 0.9203
# Epoch 139/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1947 - accuracy: 0.9344 - val_loss: 0.3010 - val_accuracy: 0.9171
# Epoch 140/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1885 - accuracy: 0.9389 - val_loss: 0.2786 - val_accuracy: 0.9150
# Epoch 141/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1870 - accuracy: 0.9365 - val_loss: 0.2859 - val_accuracy: 0.9235
# Epoch 142/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1754 - accuracy: 0.9429 - val_loss: 0.2890 - val_accuracy: 0.9160
# Epoch 143/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1761 - accuracy: 0.9408 - val_loss: 0.2926 - val_accuracy: 0.9203
# Epoch 144/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1697 - accuracy: 0.9471 - val_loss: 0.2702 - val_accuracy: 0.9224
# Epoch 145/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1660 - accuracy: 0.9463 - val_loss: 0.2662 - val_accuracy: 0.9203
# Epoch 146/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1682 - accuracy: 0.9413 - val_loss: 0.2597 - val_accuracy: 0.9235
# Epoch 147/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1686 - accuracy: 0.9482 - val_loss: 0.2830 - val_accuracy: 0.9214
# Epoch 148/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1851 - accuracy: 0.9405 - val_loss: 0.2757 - val_accuracy: 0.9203
# Epoch 149/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1786 - accuracy: 0.9418 - val_loss: 0.2750 - val_accuracy: 0.9150
# Epoch 150/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1717 - accuracy: 0.9434 - val_loss: 0.2695 - val_accuracy: 0.9192
# Epoch 151/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1674 - accuracy: 0.9485 - val_loss: 0.2627 - val_accuracy: 0.9203
# Epoch 152/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1570 - accuracy: 0.9490 - val_loss: 0.2594 - val_accuracy: 0.9235
# Epoch 153/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1632 - accuracy: 0.9487 - val_loss: 0.2731 - val_accuracy: 0.9203
# Epoch 154/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1570 - accuracy: 0.9474 - val_loss: 0.2779 - val_accuracy: 0.9224
# Epoch 155/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1562 - accuracy: 0.9487 - val_loss: 0.2683 - val_accuracy: 0.9203
# Epoch 156/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1461 - accuracy: 0.9530 - val_loss: 0.2673 - val_accuracy: 0.9150
# Epoch 157/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1558 - accuracy: 0.9498 - val_loss: 0.2807 - val_accuracy: 0.9182
# Epoch 158/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1668 - accuracy: 0.9471 - val_loss: 0.2605 - val_accuracy: 0.9214
# Epoch 159/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1674 - accuracy: 0.9458 - val_loss: 0.2611 - val_accuracy: 0.9160
# Epoch 160/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1761 - accuracy: 0.9431 - val_loss: 0.2733 - val_accuracy: 0.9160
# Epoch 161/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1628 - accuracy: 0.9490 - val_loss: 0.2754 - val_accuracy: 0.9160
# Epoch 162/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1645 - accuracy: 0.9466 - val_loss: 0.2633 - val_accuracy: 0.9182
# Epoch 163/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1610 - accuracy: 0.9482 - val_loss: 0.2684 - val_accuracy: 0.9224
# Epoch 164/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1636 - accuracy: 0.9458 - val_loss: 0.2899 - val_accuracy: 0.9203
# Epoch 165/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1604 - accuracy: 0.9455 - val_loss: 0.2912 - val_accuracy: 0.9267
# Epoch 166/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1528 - accuracy: 0.9485 - val_loss: 0.2666 - val_accuracy: 0.9267
# Epoch 167/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1518 - accuracy: 0.9527 - val_loss: 0.2643 - val_accuracy: 0.9235
# Epoch 168/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1595 - accuracy: 0.9503 - val_loss: 0.2705 - val_accuracy: 0.9203
# Epoch 169/200
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1414 - accuracy: 0.9519 - val_loss: 0.2710 - val_accuracy: 0.9245
# Epoch 170/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1443 - accuracy: 0.9554 - val_loss: 0.2820 - val_accuracy: 0.9192
# Epoch 171/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1535 - accuracy: 0.9493 - val_loss: 0.2756 - val_accuracy: 0.9182
# Epoch 172/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1421 - accuracy: 0.9548 - val_loss: 0.2651 - val_accuracy: 0.9182
# Epoch 173/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1436 - accuracy: 0.9530 - val_loss: 0.2860 - val_accuracy: 0.9203
# Epoch 174/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1470 - accuracy: 0.9524 - val_loss: 0.2747 - val_accuracy: 0.9224
# Epoch 175/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1370 - accuracy: 0.9588 - val_loss: 0.2703 - val_accuracy: 0.9171
# Epoch 176/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1453 - accuracy: 0.9527 - val_loss: 0.2826 - val_accuracy: 0.9182
# Epoch 177/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1502 - accuracy: 0.9511 - val_loss: 0.2731 - val_accuracy: 0.9182
# Epoch 178/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1418 - accuracy: 0.9562 - val_loss: 0.2543 - val_accuracy: 0.9235
# Epoch 179/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1407 - accuracy: 0.9559 - val_loss: 0.2734 - val_accuracy: 0.9235
# Epoch 180/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1423 - accuracy: 0.9516 - val_loss: 0.2574 - val_accuracy: 0.9256
# Epoch 181/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1381 - accuracy: 0.9564 - val_loss: 0.2837 - val_accuracy: 0.9267
# Epoch 182/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1444 - accuracy: 0.9551 - val_loss: 0.2751 - val_accuracy: 0.9203
# Epoch 183/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1306 - accuracy: 0.9580 - val_loss: 0.2679 - val_accuracy: 0.9245
# Epoch 184/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1273 - accuracy: 0.9591 - val_loss: 0.2594 - val_accuracy: 0.9245
# Epoch 185/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1347 - accuracy: 0.9551 - val_loss: 0.3056 - val_accuracy: 0.9150
# Epoch 186/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1329 - accuracy: 0.9578 - val_loss: 0.2691 - val_accuracy: 0.9235
# Epoch 187/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1457 - accuracy: 0.9509 - val_loss: 0.2856 - val_accuracy: 0.9139
# Epoch 188/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1409 - accuracy: 0.9527 - val_loss: 0.2700 - val_accuracy: 0.9214
# Epoch 189/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1378 - accuracy: 0.9591 - val_loss: 0.2747 - val_accuracy: 0.9224
# Epoch 190/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1273 - accuracy: 0.9625 - val_loss: 0.2746 - val_accuracy: 0.9182
# Epoch 191/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1339 - accuracy: 0.9596 - val_loss: 0.2815 - val_accuracy: 0.9214
# Epoch 192/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1291 - accuracy: 0.9570 - val_loss: 0.2729 - val_accuracy: 0.9267
# Epoch 193/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1229 - accuracy: 0.9588 - val_loss: 0.2564 - val_accuracy: 0.9267
# Epoch 194/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1153 - accuracy: 0.9628 - val_loss: 0.2543 - val_accuracy: 0.9267
# Epoch 195/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1269 - accuracy: 0.9607 - val_loss: 0.2828 - val_accuracy: 0.9203
# Epoch 196/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1340 - accuracy: 0.9564 - val_loss: 0.2700 - val_accuracy: 0.9214
# Epoch 197/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1260 - accuracy: 0.9591 - val_loss: 0.2507 - val_accuracy: 0.9245
# Epoch 198/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1250 - accuracy: 0.9601 - val_loss: 0.3246 - val_accuracy: 0.9107
# Epoch 199/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1283 - accuracy: 0.9591 - val_loss: 0.2726 - val_accuracy: 0.9277
# Epoch 200/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1374 - accuracy: 0.9538 - val_loss: 0.2612 - val_accuracy: 0.9256

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 70ms/step - loss: 1.7673 - accuracy: 0.3921 - val_loss: 1.4400 - val_accuracy: 0.5005
# Epoch 2/50
# 8/8 [==============================] - 0s 47ms/step - loss: 1.3828 - accuracy: 0.5064 - val_loss: 1.2835 - val_accuracy: 0.5250
# Epoch 3/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.2705 - accuracy: 0.5510 - val_loss: 1.2025 - val_accuracy: 0.5813
# Epoch 4/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.1872 - accuracy: 0.5802 - val_loss: 1.1114 - val_accuracy: 0.6461
# Epoch 5/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0936 - accuracy: 0.6265 - val_loss: 1.0110 - val_accuracy: 0.7067
# Epoch 6/50
# 8/8 [==============================] - 0s 49ms/step - loss: 1.0123 - accuracy: 0.6514 - val_loss: 0.9404 - val_accuracy: 0.7184
# Epoch 7/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.9432 - accuracy: 0.7011 - val_loss: 0.8678 - val_accuracy: 0.7365
# Epoch 8/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8726 - accuracy: 0.7160 - val_loss: 0.8542 - val_accuracy: 0.7024
# Epoch 9/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.8302 - accuracy: 0.7253 - val_loss: 0.7850 - val_accuracy: 0.7460
# Epoch 10/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7941 - accuracy: 0.7396 - val_loss: 0.7465 - val_accuracy: 0.7566
# Epoch 11/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.7523 - accuracy: 0.7476 - val_loss: 0.7420 - val_accuracy: 0.7333
# Epoch 12/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.7356 - accuracy: 0.7527 - val_loss: 0.6753 - val_accuracy: 0.7726
# Epoch 13/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.6903 - accuracy: 0.7742 - val_loss: 0.6571 - val_accuracy: 0.7811
# Epoch 14/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6842 - accuracy: 0.7713 - val_loss: 0.6252 - val_accuracy: 0.7906
# Epoch 15/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6632 - accuracy: 0.7728 - val_loss: 0.6473 - val_accuracy: 0.8130
# Epoch 16/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6527 - accuracy: 0.7803 - val_loss: 0.6335 - val_accuracy: 0.7906
# Epoch 17/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.6250 - accuracy: 0.7914 - val_loss: 0.5829 - val_accuracy: 0.7981
# Epoch 18/50
# 8/8 [==============================] - 1s 63ms/step - loss: 0.5918 - accuracy: 0.8042 - val_loss: 0.6122 - val_accuracy: 0.7800
# Epoch 19/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5973 - accuracy: 0.7946 - val_loss: 0.5662 - val_accuracy: 0.8087
# Epoch 20/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5773 - accuracy: 0.8111 - val_loss: 0.5442 - val_accuracy: 0.8310
# Epoch 21/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5633 - accuracy: 0.8100 - val_loss: 0.5481 - val_accuracy: 0.8108
# Epoch 22/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5458 - accuracy: 0.8193 - val_loss: 0.5456 - val_accuracy: 0.8406
# Epoch 23/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5414 - accuracy: 0.8265 - val_loss: 0.5223 - val_accuracy: 0.8448
# Epoch 24/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5189 - accuracy: 0.8270 - val_loss: 0.5071 - val_accuracy: 0.8427
# Epoch 25/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.5095 - accuracy: 0.8337 - val_loss: 0.5024 - val_accuracy: 0.8491
# Epoch 26/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5084 - accuracy: 0.8249 - val_loss: 0.4818 - val_accuracy: 0.8576
# Epoch 27/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4998 - accuracy: 0.8419 - val_loss: 0.4814 - val_accuracy: 0.8565
# Epoch 28/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4878 - accuracy: 0.8371 - val_loss: 0.4749 - val_accuracy: 0.8512
# Epoch 29/50
# 8/8 [==============================] - 0s 56ms/step - loss: 0.4777 - accuracy: 0.8451 - val_loss: 0.4740 - val_accuracy: 0.8544
# Epoch 30/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4796 - accuracy: 0.8371 - val_loss: 0.4802 - val_accuracy: 0.8576
# Epoch 31/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4737 - accuracy: 0.8454 - val_loss: 0.4506 - val_accuracy: 0.8789
# Epoch 32/50
# 8/8 [==============================] - 0s 56ms/step - loss: 0.4578 - accuracy: 0.8520 - val_loss: 0.4522 - val_accuracy: 0.8672
# Epoch 33/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.4711 - accuracy: 0.8409 - val_loss: 0.4575 - val_accuracy: 0.8640
# Epoch 34/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.4476 - accuracy: 0.8507 - val_loss: 0.4439 - val_accuracy: 0.8629
# Epoch 35/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.4515 - accuracy: 0.8555 - val_loss: 0.4417 - val_accuracy: 0.8650
# Epoch 36/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4344 - accuracy: 0.8595 - val_loss: 0.4552 - val_accuracy: 0.8544
# Epoch 37/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4329 - accuracy: 0.8541 - val_loss: 0.4272 - val_accuracy: 0.8682
# Epoch 38/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4248 - accuracy: 0.8629 - val_loss: 0.4168 - val_accuracy: 0.8757
# Epoch 39/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4127 - accuracy: 0.8611 - val_loss: 0.4134 - val_accuracy: 0.8820
# Epoch 40/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4108 - accuracy: 0.8656 - val_loss: 0.4595 - val_accuracy: 0.8735
# Epoch 41/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4305 - accuracy: 0.8523 - val_loss: 0.4171 - val_accuracy: 0.8725
# Epoch 42/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4150 - accuracy: 0.8677 - val_loss: 0.4075 - val_accuracy: 0.8746
# Epoch 43/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4001 - accuracy: 0.8666 - val_loss: 0.4088 - val_accuracy: 0.8831
# Epoch 44/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3960 - accuracy: 0.8674 - val_loss: 0.4085 - val_accuracy: 0.8693
# Epoch 45/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3928 - accuracy: 0.8735 - val_loss: 0.4109 - val_accuracy: 0.8608
# Epoch 46/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3959 - accuracy: 0.8672 - val_loss: 0.4007 - val_accuracy: 0.8842
# Epoch 47/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3879 - accuracy: 0.8741 - val_loss: 0.4115 - val_accuracy: 0.8565
# Epoch 48/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3916 - accuracy: 0.8661 - val_loss: 0.3740 - val_accuracy: 0.8916
# Epoch 49/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3640 - accuracy: 0.8783 - val_loss: 0.3745 - val_accuracy: 0.8937
# Epoch 50/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3653 - accuracy: 0.8762 - val_loss: 0.3678 - val_accuracy: 0.8884

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 6ms/step - loss: 0.3226 - accuracy: 0.8943
# 30/30 [==============================] - 0s 6ms/step - loss: 0.3678 - accuracy: 0.8884
# 0.8942614197731018 0.888416588306427

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 122, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:56

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   1   0   0   0   0   0]
#  [  0   0   0 121   0   1   0   0   2]
#  [  0   0   0   0 311   4   3   0   2]
#  [  0   0   0   0  17  89  10   0   4]
#  [  0   0   1   0  11   5  30   0   3]
#  [  0   0   0   0  13   9   1  27   0]
#  [  0   0   0   2   9   7   0   0  19]]
#
# Accuracy Score
# 0.8884165781083954
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.98      0.98      0.98       124
#       built       0.86      0.97      0.91       320
#     windows       0.77      0.74      0.76       120
#       roads       0.68      0.60      0.64        50
#        cars       1.00      0.54      0.70        50
#       metal       0.63      0.51      0.57        37
#
# avg / total       0.89      0.89      0.88       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
