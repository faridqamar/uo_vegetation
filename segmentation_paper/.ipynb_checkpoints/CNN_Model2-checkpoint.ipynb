# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_norm0 = (cube_reshaped0 - cube_reshaped0.min()) / (cube_reshaped0.max() - cube_reshaped0.min())

import matplotlib.pyplot as plt
# %matplotlib inline

red_ind0 = (np.abs(cube0.waves - 650.0)).argmin()
green_ind0 = (np.abs(cube0.waves - 550.0)).argmin()
blue_ind0 = (np.abs(cube0.waves - 450.0)).argmin()

cube_reshaped02 = cube_norm0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], cube_sub0.shape[0])
cube_scene0 = cube_reshaped02[:, :, [red_ind0, green_ind0, blue_ind0]]
fig, ax = plt.subplots(figsize=(10,10))
plt.title('veg_00000 RGB Image')
ax.imshow(cube_scene0, aspect=0.5)
plt.show()

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %%
# NOT NEEDED

xy_sky0 = xy0[sky_coords0[:, 0], sky_coords0[:, 1], :]
xy_clouds0 = xy0[clouds_coords0[:, 0], clouds_coords0[:, 1], :]
xy_veg0 = xy0[veg_coords0[:, 0], veg_coords0[:, 1], :]
#xy_wtr0 = xy0[wtr_coords0[:, 0], wtr_coords0[:, 1], :]
xy_blt0 = xy0[blt_coords0[:, 0], blt_coords0[:, 1], :]
xy_windows0 = xy0[windows_coords0[:, 0], windows_coords0[:, 1], :]
xy_rds0 = xy0[rds_coords0[:, 0], rds_coords0[:, 1], :]
xy_cars0 = xy0[cars_coords0[:, 0], cars_coords0[:, 1], :]
xy_mtl0 = xy0[mtl_coords0[:, 0], mtl_coords0[:, 1], :]

cube_xy0 = np.concatenate((xy_sky0, xy_clouds0, xy_veg0, xy_blt0,
                             xy_windows0, xy_rds0, xy_cars0, xy_mtl0), axis=0)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], cube_sub0.shape[0])
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 848)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)

cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 848) (80, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (488, 848) (122, 848)
# built  (960, 848) (240, 848)
# windows  (400, 848) (100, 848)
# roads  (48, 848) (12, 848)
# cars  (44, 848) (11, 848)
# metal  (184, 848) (46, 848)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 848) (2844,) (2844, 2)
# (711, 848) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 192ms/step - loss: 1.8494 - accuracy: 0.4065 - val_loss: 1.2181 - val_accuracy: 0.5893
# Epoch 2/200
# 6/6 [==============================] - 1s 159ms/step - loss: 1.0449 - accuracy: 0.6621 - val_loss: 0.8433 - val_accuracy: 0.6695
# Epoch 3/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.7486 - accuracy: 0.7247 - val_loss: 0.6753 - val_accuracy: 0.7454
# Epoch 4/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.6366 - accuracy: 0.7352 - val_loss: 0.7311 - val_accuracy: 0.7314
# Epoch 5/200
# 6/6 [==============================] - 1s 155ms/step - loss: 0.6473 - accuracy: 0.7384 - val_loss: 0.6709 - val_accuracy: 0.7398
# Epoch 6/200
# 6/6 [==============================] - 1s 150ms/step - loss: 0.5732 - accuracy: 0.7581 - val_loss: 0.6177 - val_accuracy: 0.7567
# Epoch 7/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.5409 - accuracy: 0.7662 - val_loss: 0.5632 - val_accuracy: 0.8003
# Epoch 8/200
# 6/6 [==============================] - 1s 151ms/step - loss: 0.5018 - accuracy: 0.7999 - val_loss: 0.5302 - val_accuracy: 0.7722
# Epoch 9/200
# 6/6 [==============================] - 1s 154ms/step - loss: 0.4575 - accuracy: 0.8326 - val_loss: 0.5242 - val_accuracy: 0.7848
# Epoch 10/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.4440 - accuracy: 0.8358 - val_loss: 0.4888 - val_accuracy: 0.7975
# Epoch 11/200
# 6/6 [==============================] - 2s 295ms/step - loss: 0.4222 - accuracy: 0.8414 - val_loss: 0.5119 - val_accuracy: 0.8017
# Epoch 12/200
# 6/6 [==============================] - 1s 230ms/step - loss: 0.4156 - accuracy: 0.8432 - val_loss: 0.4662 - val_accuracy: 0.8298
# Epoch 13/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.3849 - accuracy: 0.8590 - val_loss: 0.4484 - val_accuracy: 0.8312
# Epoch 14/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.3714 - accuracy: 0.8590 - val_loss: 0.4191 - val_accuracy: 0.8383
# Epoch 15/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.3547 - accuracy: 0.8766 - val_loss: 0.4171 - val_accuracy: 0.8495
# Epoch 16/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.3496 - accuracy: 0.8681 - val_loss: 0.4213 - val_accuracy: 0.8368
# Epoch 17/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.3491 - accuracy: 0.8724 - val_loss: 0.4094 - val_accuracy: 0.8425
# Epoch 18/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.3442 - accuracy: 0.8745 - val_loss: 0.3993 - val_accuracy: 0.8594
# Epoch 19/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.3262 - accuracy: 0.8769 - val_loss: 0.3782 - val_accuracy: 0.8636
# Epoch 20/200
# 6/6 [==============================] - 1s 191ms/step - loss: 0.3220 - accuracy: 0.8713 - val_loss: 0.4950 - val_accuracy: 0.8312
# Epoch 21/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.3460 - accuracy: 0.8650 - val_loss: 0.3842 - val_accuracy: 0.8551
# Epoch 22/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.3230 - accuracy: 0.8748 - val_loss: 0.3749 - val_accuracy: 0.8622
# Epoch 23/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.3159 - accuracy: 0.8826 - val_loss: 0.4082 - val_accuracy: 0.8509
# Epoch 24/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.3153 - accuracy: 0.8801 - val_loss: 0.3740 - val_accuracy: 0.8551
# Epoch 25/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.3007 - accuracy: 0.8840 - val_loss: 0.3742 - val_accuracy: 0.8579
# Epoch 26/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.2980 - accuracy: 0.8892 - val_loss: 0.3718 - val_accuracy: 0.8664
# Epoch 27/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.3017 - accuracy: 0.8822 - val_loss: 0.3542 - val_accuracy: 0.8636
# Epoch 28/200
# 6/6 [==============================] - 1s 185ms/step - loss: 0.2884 - accuracy: 0.8921 - val_loss: 0.3383 - val_accuracy: 0.8720
# Epoch 29/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.2751 - accuracy: 0.8945 - val_loss: 0.3579 - val_accuracy: 0.8706
# Epoch 30/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.2683 - accuracy: 0.9065 - val_loss: 0.3462 - val_accuracy: 0.8636
# Epoch 31/200
# 6/6 [==============================] - 1s 235ms/step - loss: 0.2710 - accuracy: 0.8963 - val_loss: 0.3280 - val_accuracy: 0.8819
# Epoch 32/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.2592 - accuracy: 0.9012 - val_loss: 0.3301 - val_accuracy: 0.8875
# Epoch 33/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.2612 - accuracy: 0.8987 - val_loss: 0.3197 - val_accuracy: 0.8875
# Epoch 34/200
# 6/6 [==============================] - 1s 190ms/step - loss: 0.2572 - accuracy: 0.9058 - val_loss: 0.3206 - val_accuracy: 0.8790
# Epoch 35/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.2510 - accuracy: 0.9089 - val_loss: 0.3273 - val_accuracy: 0.8819
# Epoch 36/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.2613 - accuracy: 0.9026 - val_loss: 0.3375 - val_accuracy: 0.8889
# Epoch 37/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.2511 - accuracy: 0.9072 - val_loss: 0.3297 - val_accuracy: 0.8819
# Epoch 38/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.2414 - accuracy: 0.9079 - val_loss: 0.3066 - val_accuracy: 0.8889
# Epoch 39/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.2427 - accuracy: 0.9054 - val_loss: 0.3132 - val_accuracy: 0.8847
# Epoch 40/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.2403 - accuracy: 0.9086 - val_loss: 0.3036 - val_accuracy: 0.8973
# Epoch 41/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.2337 - accuracy: 0.9110 - val_loss: 0.3134 - val_accuracy: 0.8861
# Epoch 42/200
# 6/6 [==============================] - 1s 175ms/step - loss: 0.2388 - accuracy: 0.9089 - val_loss: 0.3046 - val_accuracy: 0.8847
# Epoch 43/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.2368 - accuracy: 0.9132 - val_loss: 0.3012 - val_accuracy: 0.8875
# Epoch 44/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.2274 - accuracy: 0.9167 - val_loss: 0.3440 - val_accuracy: 0.8734
# Epoch 45/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.2688 - accuracy: 0.8931 - val_loss: 0.3315 - val_accuracy: 0.8805
# Epoch 46/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2694 - accuracy: 0.8889 - val_loss: 0.3986 - val_accuracy: 0.8326
# Epoch 47/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.2885 - accuracy: 0.8896 - val_loss: 0.3517 - val_accuracy: 0.8776
# Epoch 48/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.2722 - accuracy: 0.8952 - val_loss: 0.3369 - val_accuracy: 0.8678
# Epoch 49/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.2434 - accuracy: 0.9093 - val_loss: 0.3139 - val_accuracy: 0.8931
# Epoch 50/200
# 6/6 [==============================] - 1s 193ms/step - loss: 0.2360 - accuracy: 0.9124 - val_loss: 0.3106 - val_accuracy: 0.8889
# Epoch 51/200
# 6/6 [==============================] - 1s 216ms/step - loss: 0.2257 - accuracy: 0.9198 - val_loss: 0.3069 - val_accuracy: 0.8945
# Epoch 52/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.2276 - accuracy: 0.9174 - val_loss: 0.3515 - val_accuracy: 0.8720
# Epoch 53/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.2436 - accuracy: 0.9030 - val_loss: 0.3135 - val_accuracy: 0.8875
# Epoch 54/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.2348 - accuracy: 0.9121 - val_loss: 0.3104 - val_accuracy: 0.8903
# Epoch 55/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.2366 - accuracy: 0.9068 - val_loss: 0.3057 - val_accuracy: 0.8945
# Epoch 56/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.2306 - accuracy: 0.9146 - val_loss: 0.3276 - val_accuracy: 0.8833
# Epoch 57/200
# 6/6 [==============================] - 1s 216ms/step - loss: 0.2266 - accuracy: 0.9128 - val_loss: 0.3019 - val_accuracy: 0.9001
# Epoch 58/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.2159 - accuracy: 0.9212 - val_loss: 0.2940 - val_accuracy: 0.9044
# Epoch 59/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.2100 - accuracy: 0.9251 - val_loss: 0.2962 - val_accuracy: 0.8931
# Epoch 60/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.2082 - accuracy: 0.9244 - val_loss: 0.3028 - val_accuracy: 0.8875
# Epoch 61/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.2269 - accuracy: 0.9103 - val_loss: 0.3126 - val_accuracy: 0.8805
# Epoch 62/200
# 6/6 [==============================] - 1s 188ms/step - loss: 0.2186 - accuracy: 0.9160 - val_loss: 0.3106 - val_accuracy: 0.8903
# Epoch 63/200
# 6/6 [==============================] - 1s 185ms/step - loss: 0.1997 - accuracy: 0.9304 - val_loss: 0.2740 - val_accuracy: 0.9142
# Epoch 64/200
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1967 - accuracy: 0.9297 - val_loss: 0.2704 - val_accuracy: 0.9058
# Epoch 65/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.1825 - accuracy: 0.9314 - val_loss: 0.2990 - val_accuracy: 0.8987
# Epoch 66/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.1960 - accuracy: 0.9265 - val_loss: 0.2919 - val_accuracy: 0.9030
# Epoch 67/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.1953 - accuracy: 0.9314 - val_loss: 0.2669 - val_accuracy: 0.9114
# Epoch 68/200
# 6/6 [==============================] - 1s 191ms/step - loss: 0.1925 - accuracy: 0.9332 - val_loss: 0.3454 - val_accuracy: 0.8706
# Epoch 69/200
# 6/6 [==============================] - 1s 193ms/step - loss: 0.2171 - accuracy: 0.9174 - val_loss: 0.2973 - val_accuracy: 0.9058
# Epoch 70/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.2036 - accuracy: 0.9233 - val_loss: 0.2867 - val_accuracy: 0.8987
# Epoch 71/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.2075 - accuracy: 0.9230 - val_loss: 0.3161 - val_accuracy: 0.8945
# Epoch 72/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.2018 - accuracy: 0.9241 - val_loss: 0.3191 - val_accuracy: 0.8875
# Epoch 73/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.2021 - accuracy: 0.9279 - val_loss: 0.3010 - val_accuracy: 0.8987
# Epoch 74/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.1889 - accuracy: 0.9314 - val_loss: 0.2687 - val_accuracy: 0.9128
# Epoch 75/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.1807 - accuracy: 0.9328 - val_loss: 0.2715 - val_accuracy: 0.9072
# Epoch 76/200
# 6/6 [==============================] - 1s 185ms/step - loss: 0.1675 - accuracy: 0.9378 - val_loss: 0.2668 - val_accuracy: 0.9198
# Epoch 77/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.1648 - accuracy: 0.9423 - val_loss: 0.2913 - val_accuracy: 0.8959
# Epoch 78/200
# 6/6 [==============================] - 1s 196ms/step - loss: 0.1691 - accuracy: 0.9388 - val_loss: 0.3271 - val_accuracy: 0.8875
# Epoch 79/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.1844 - accuracy: 0.9332 - val_loss: 0.2759 - val_accuracy: 0.9086
# Epoch 80/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1732 - accuracy: 0.9381 - val_loss: 0.2852 - val_accuracy: 0.9086
# Epoch 81/200
# 6/6 [==============================] - 1s 215ms/step - loss: 0.1710 - accuracy: 0.9402 - val_loss: 0.2696 - val_accuracy: 0.9128
# Epoch 82/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.1799 - accuracy: 0.9276 - val_loss: 0.3173 - val_accuracy: 0.8889
# Epoch 83/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.1820 - accuracy: 0.9321 - val_loss: 0.2705 - val_accuracy: 0.9072
# Epoch 84/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.1818 - accuracy: 0.9328 - val_loss: 0.2943 - val_accuracy: 0.8973
# Epoch 85/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.1675 - accuracy: 0.9381 - val_loss: 0.2821 - val_accuracy: 0.8931
# Epoch 86/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.1694 - accuracy: 0.9360 - val_loss: 0.2908 - val_accuracy: 0.9100
# Epoch 87/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.1728 - accuracy: 0.9395 - val_loss: 0.2509 - val_accuracy: 0.9114
# Epoch 88/200
# 6/6 [==============================] - 1s 188ms/step - loss: 0.1512 - accuracy: 0.9448 - val_loss: 0.2724 - val_accuracy: 0.9072
# Epoch 89/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1570 - accuracy: 0.9437 - val_loss: 0.2509 - val_accuracy: 0.9198
# Epoch 90/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.1651 - accuracy: 0.9420 - val_loss: 0.2647 - val_accuracy: 0.9015
# Epoch 91/200
# 6/6 [==============================] - 1s 187ms/step - loss: 0.1674 - accuracy: 0.9367 - val_loss: 0.3025 - val_accuracy: 0.9015
# Epoch 92/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.1726 - accuracy: 0.9350 - val_loss: 0.2551 - val_accuracy: 0.9170
# Epoch 93/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.1647 - accuracy: 0.9392 - val_loss: 0.2474 - val_accuracy: 0.9198
# Epoch 94/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.1585 - accuracy: 0.9444 - val_loss: 0.2488 - val_accuracy: 0.9170
# Epoch 95/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.1635 - accuracy: 0.9402 - val_loss: 0.2585 - val_accuracy: 0.9142
# Epoch 96/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.1553 - accuracy: 0.9451 - val_loss: 0.2583 - val_accuracy: 0.9184
# Epoch 97/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.1438 - accuracy: 0.9487 - val_loss: 0.2498 - val_accuracy: 0.9170
# Epoch 98/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.1531 - accuracy: 0.9395 - val_loss: 0.2601 - val_accuracy: 0.9128
# Epoch 99/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.1567 - accuracy: 0.9434 - val_loss: 0.3339 - val_accuracy: 0.8945
# Epoch 100/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.1733 - accuracy: 0.9385 - val_loss: 0.2567 - val_accuracy: 0.9142
# Epoch 101/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.1678 - accuracy: 0.9350 - val_loss: 0.2646 - val_accuracy: 0.9100
# Epoch 102/200
# 6/6 [==============================] - 1s 226ms/step - loss: 0.1845 - accuracy: 0.9314 - val_loss: 0.2957 - val_accuracy: 0.8945
# Epoch 103/200
# 6/6 [==============================] - 1s 185ms/step - loss: 0.1656 - accuracy: 0.9378 - val_loss: 0.2684 - val_accuracy: 0.9015
# Epoch 104/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.1529 - accuracy: 0.9409 - val_loss: 0.2742 - val_accuracy: 0.9058
# Epoch 105/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1451 - accuracy: 0.9444 - val_loss: 0.2445 - val_accuracy: 0.9170
# Epoch 106/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.1402 - accuracy: 0.9497 - val_loss: 0.2486 - val_accuracy: 0.9198
# Epoch 107/200
# 6/6 [==============================] - 1s 211ms/step - loss: 0.1386 - accuracy: 0.9522 - val_loss: 0.2465 - val_accuracy: 0.9241
# Epoch 108/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1430 - accuracy: 0.9476 - val_loss: 0.2298 - val_accuracy: 0.9297
# Epoch 109/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.1309 - accuracy: 0.9529 - val_loss: 0.2395 - val_accuracy: 0.9241
# Epoch 110/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1277 - accuracy: 0.9550 - val_loss: 0.2469 - val_accuracy: 0.9184
# Epoch 111/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1312 - accuracy: 0.9522 - val_loss: 0.2578 - val_accuracy: 0.9142
# Epoch 112/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.1539 - accuracy: 0.9462 - val_loss: 0.2524 - val_accuracy: 0.9226
# Epoch 113/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.1313 - accuracy: 0.9522 - val_loss: 0.2535 - val_accuracy: 0.9142
# Epoch 114/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.1203 - accuracy: 0.9599 - val_loss: 0.2435 - val_accuracy: 0.9283
# Epoch 115/200
# 6/6 [==============================] - 1s 193ms/step - loss: 0.1244 - accuracy: 0.9539 - val_loss: 0.2361 - val_accuracy: 0.9269
# Epoch 116/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.1167 - accuracy: 0.9560 - val_loss: 0.2420 - val_accuracy: 0.9297
# Epoch 117/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.1155 - accuracy: 0.9631 - val_loss: 0.2510 - val_accuracy: 0.9198
# Epoch 118/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.1327 - accuracy: 0.9483 - val_loss: 0.2374 - val_accuracy: 0.9269
# Epoch 119/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.1198 - accuracy: 0.9610 - val_loss: 0.2347 - val_accuracy: 0.9325
# Epoch 120/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.1252 - accuracy: 0.9564 - val_loss: 0.2364 - val_accuracy: 0.9212
# Epoch 121/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.1219 - accuracy: 0.9578 - val_loss: 0.2358 - val_accuracy: 0.9311
# Epoch 122/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.1115 - accuracy: 0.9592 - val_loss: 0.2601 - val_accuracy: 0.9184
# Epoch 123/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.1293 - accuracy: 0.9532 - val_loss: 0.2456 - val_accuracy: 0.9283
# Epoch 124/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.1119 - accuracy: 0.9578 - val_loss: 0.2274 - val_accuracy: 0.9325
# Epoch 125/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.1073 - accuracy: 0.9603 - val_loss: 0.2286 - val_accuracy: 0.9325
# Epoch 126/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1272 - accuracy: 0.9508 - val_loss: 0.3093 - val_accuracy: 0.9114
# Epoch 127/200
# 6/6 [==============================] - 1s 215ms/step - loss: 0.1497 - accuracy: 0.9444 - val_loss: 0.2986 - val_accuracy: 0.9114
# Epoch 128/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.1510 - accuracy: 0.9451 - val_loss: 0.2772 - val_accuracy: 0.9114
# Epoch 129/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.1347 - accuracy: 0.9525 - val_loss: 0.2452 - val_accuracy: 0.9170
# Epoch 130/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.1271 - accuracy: 0.9560 - val_loss: 0.2739 - val_accuracy: 0.9170
# Epoch 131/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.1308 - accuracy: 0.9501 - val_loss: 0.2581 - val_accuracy: 0.9241
# Epoch 132/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.1163 - accuracy: 0.9599 - val_loss: 0.2641 - val_accuracy: 0.9212
# Epoch 133/200
# 6/6 [==============================] - 1s 181ms/step - loss: 0.1094 - accuracy: 0.9620 - val_loss: 0.2316 - val_accuracy: 0.9353
# Epoch 134/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1019 - accuracy: 0.9645 - val_loss: 0.2528 - val_accuracy: 0.9226
# Epoch 135/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1077 - accuracy: 0.9617 - val_loss: 0.2424 - val_accuracy: 0.9255
# Epoch 136/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1115 - accuracy: 0.9571 - val_loss: 0.2324 - val_accuracy: 0.9311
# Epoch 137/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.1008 - accuracy: 0.9680 - val_loss: 0.2312 - val_accuracy: 0.9339
# Epoch 138/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0972 - accuracy: 0.9648 - val_loss: 0.2380 - val_accuracy: 0.9367
# Epoch 139/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0989 - accuracy: 0.9677 - val_loss: 0.2322 - val_accuracy: 0.9395
# Epoch 140/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0982 - accuracy: 0.9687 - val_loss: 0.2263 - val_accuracy: 0.9409
# Epoch 141/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0973 - accuracy: 0.9655 - val_loss: 0.2318 - val_accuracy: 0.9367
# Epoch 142/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0986 - accuracy: 0.9662 - val_loss: 0.2305 - val_accuracy: 0.9381
# Epoch 143/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1004 - accuracy: 0.9641 - val_loss: 0.2469 - val_accuracy: 0.9283
# Epoch 144/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.1009 - accuracy: 0.9645 - val_loss: 0.2219 - val_accuracy: 0.9353
# Epoch 145/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0940 - accuracy: 0.9662 - val_loss: 0.2230 - val_accuracy: 0.9283
# Epoch 146/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0984 - accuracy: 0.9641 - val_loss: 0.2274 - val_accuracy: 0.9423
# Epoch 147/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0891 - accuracy: 0.9708 - val_loss: 0.2261 - val_accuracy: 0.9451
# Epoch 148/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0948 - accuracy: 0.9659 - val_loss: 0.2182 - val_accuracy: 0.9423
# Epoch 149/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0971 - accuracy: 0.9659 - val_loss: 0.2205 - val_accuracy: 0.9367
# Epoch 150/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0872 - accuracy: 0.9712 - val_loss: 0.2302 - val_accuracy: 0.9311
# Epoch 151/200
# 6/6 [==============================] - 1s 191ms/step - loss: 0.0877 - accuracy: 0.9698 - val_loss: 0.2361 - val_accuracy: 0.9367
# Epoch 152/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.0866 - accuracy: 0.9705 - val_loss: 0.2418 - val_accuracy: 0.9381
# Epoch 153/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0951 - accuracy: 0.9673 - val_loss: 0.2200 - val_accuracy: 0.9367
# Epoch 154/200
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0821 - accuracy: 0.9729 - val_loss: 0.2299 - val_accuracy: 0.9311
# Epoch 155/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.0876 - accuracy: 0.9669 - val_loss: 0.2222 - val_accuracy: 0.9409
# Epoch 156/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0821 - accuracy: 0.9691 - val_loss: 0.2148 - val_accuracy: 0.9367
# Epoch 157/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.0831 - accuracy: 0.9733 - val_loss: 0.2289 - val_accuracy: 0.9381
# Epoch 158/200
# 6/6 [==============================] - 1s 216ms/step - loss: 0.0913 - accuracy: 0.9638 - val_loss: 0.2553 - val_accuracy: 0.9184
# Epoch 159/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1088 - accuracy: 0.9610 - val_loss: 0.2571 - val_accuracy: 0.9269
# Epoch 160/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0972 - accuracy: 0.9655 - val_loss: 0.2378 - val_accuracy: 0.9395
# Epoch 161/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0929 - accuracy: 0.9684 - val_loss: 0.2327 - val_accuracy: 0.9339
# Epoch 162/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.0954 - accuracy: 0.9655 - val_loss: 0.2857 - val_accuracy: 0.9100
# Epoch 163/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.1161 - accuracy: 0.9557 - val_loss: 0.2657 - val_accuracy: 0.9184
# Epoch 164/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.1215 - accuracy: 0.9522 - val_loss: 0.2473 - val_accuracy: 0.9184
# Epoch 165/200
# 6/6 [==============================] - 1s 231ms/step - loss: 0.0979 - accuracy: 0.9645 - val_loss: 0.2196 - val_accuracy: 0.9409
# Epoch 166/200
# 6/6 [==============================] - 1s 198ms/step - loss: 0.1002 - accuracy: 0.9673 - val_loss: 0.2751 - val_accuracy: 0.9297
# Epoch 167/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.1397 - accuracy: 0.9487 - val_loss: 0.2511 - val_accuracy: 0.9297
# Epoch 168/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.1294 - accuracy: 0.9508 - val_loss: 0.2538 - val_accuracy: 0.9142
# Epoch 169/200
# 6/6 [==============================] - 1s 228ms/step - loss: 0.1319 - accuracy: 0.9525 - val_loss: 0.2260 - val_accuracy: 0.9297
# Epoch 170/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.1076 - accuracy: 0.9613 - val_loss: 0.2569 - val_accuracy: 0.9241
# Epoch 171/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.1028 - accuracy: 0.9648 - val_loss: 0.2253 - val_accuracy: 0.9283
# Epoch 172/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.0921 - accuracy: 0.9687 - val_loss: 0.2159 - val_accuracy: 0.9367
# Epoch 173/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.0909 - accuracy: 0.9687 - val_loss: 0.2434 - val_accuracy: 0.9226
# Epoch 174/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0907 - accuracy: 0.9687 - val_loss: 0.2106 - val_accuracy: 0.9437
# Epoch 175/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.0862 - accuracy: 0.9648 - val_loss: 0.2160 - val_accuracy: 0.9381
# Epoch 176/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.0847 - accuracy: 0.9694 - val_loss: 0.2238 - val_accuracy: 0.9381
# Epoch 177/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0822 - accuracy: 0.9694 - val_loss: 0.2291 - val_accuracy: 0.9409
# Epoch 178/200
# 6/6 [==============================] - 1s 223ms/step - loss: 0.0700 - accuracy: 0.9754 - val_loss: 0.2169 - val_accuracy: 0.9381
# Epoch 179/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0766 - accuracy: 0.9740 - val_loss: 0.2185 - val_accuracy: 0.9367
# Epoch 180/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.0726 - accuracy: 0.9743 - val_loss: 0.2241 - val_accuracy: 0.9423
# Epoch 181/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.0623 - accuracy: 0.9761 - val_loss: 0.2277 - val_accuracy: 0.9353
# Epoch 182/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0665 - accuracy: 0.9796 - val_loss: 0.2108 - val_accuracy: 0.9423
# Epoch 183/200
# 6/6 [==============================] - 1s 211ms/step - loss: 0.0632 - accuracy: 0.9771 - val_loss: 0.2631 - val_accuracy: 0.9311
# Epoch 184/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0746 - accuracy: 0.9743 - val_loss: 0.2223 - val_accuracy: 0.9409
# Epoch 185/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.0628 - accuracy: 0.9768 - val_loss: 0.2156 - val_accuracy: 0.9423
# Epoch 186/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0626 - accuracy: 0.9814 - val_loss: 0.2306 - val_accuracy: 0.9395
# Epoch 187/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.2163 - val_accuracy: 0.9423
# Epoch 188/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.0633 - accuracy: 0.9764 - val_loss: 0.2170 - val_accuracy: 0.9494
# Epoch 189/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.0634 - accuracy: 0.9807 - val_loss: 0.2167 - val_accuracy: 0.9451
# Epoch 190/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0663 - accuracy: 0.9764 - val_loss: 0.2300 - val_accuracy: 0.9381
# Epoch 191/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0588 - accuracy: 0.9817 - val_loss: 0.2215 - val_accuracy: 0.9451
# Epoch 192/200
# 6/6 [==============================] - 1s 224ms/step - loss: 0.0595 - accuracy: 0.9817 - val_loss: 0.2224 - val_accuracy: 0.9423
# Epoch 193/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.0619 - accuracy: 0.9807 - val_loss: 0.2247 - val_accuracy: 0.9381
# Epoch 194/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.0693 - accuracy: 0.9761 - val_loss: 0.2516 - val_accuracy: 0.9423
# Epoch 195/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0808 - accuracy: 0.9701 - val_loss: 0.2332 - val_accuracy: 0.9395
# Epoch 196/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.0607 - accuracy: 0.9782 - val_loss: 0.2208 - val_accuracy: 0.9466
# Epoch 197/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.0645 - accuracy: 0.9793 - val_loss: 0.2261 - val_accuracy: 0.9409
# Epoch 198/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.0647 - accuracy: 0.9800 - val_loss: 0.2277 - val_accuracy: 0.9395
# Epoch 199/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.0621 - accuracy: 0.9786 - val_loss: 0.2310 - val_accuracy: 0.9395
# Epoch 200/200
# 6/6 [==============================] - 1s 227ms/step - loss: 0.0680 - accuracy: 0.9786 - val_loss: 0.2223 - val_accuracy: 0.9381

# %%
plot_loss_history(CNNmodel0)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0755 - accuracy: 0.9729 - val_loss: 0.2476 - val_accuracy: 0.9381
# Epoch 2/60
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0734 - accuracy: 0.9733 - val_loss: 0.2227 - val_accuracy: 0.9395
# Epoch 3/60
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0673 - accuracy: 0.9778 - val_loss: 0.2186 - val_accuracy: 0.9423
# Epoch 4/60
# 6/6 [==============================] - 1s 196ms/step - loss: 0.0586 - accuracy: 0.9831 - val_loss: 0.2164 - val_accuracy: 0.9395
# Epoch 5/60
# 6/6 [==============================] - 1s 231ms/step - loss: 0.0655 - accuracy: 0.9750 - val_loss: 0.2250 - val_accuracy: 0.9437
# Epoch 6/60
# 6/6 [==============================] - 1s 219ms/step - loss: 0.0735 - accuracy: 0.9719 - val_loss: 0.2222 - val_accuracy: 0.9367
# Epoch 7/60
# 6/6 [==============================] - 1s 232ms/step - loss: 0.0609 - accuracy: 0.9793 - val_loss: 0.2449 - val_accuracy: 0.9311
# Epoch 8/60
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0671 - accuracy: 0.9775 - val_loss: 0.2167 - val_accuracy: 0.9437
# Epoch 9/60
# 6/6 [==============================] - 1s 196ms/step - loss: 0.0544 - accuracy: 0.9838 - val_loss: 0.2208 - val_accuracy: 0.9423
# Epoch 10/60
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0608 - accuracy: 0.9793 - val_loss: 0.2232 - val_accuracy: 0.9381
# Epoch 11/60
# 6/6 [==============================] - 1s 233ms/step - loss: 0.0535 - accuracy: 0.9824 - val_loss: 0.2393 - val_accuracy: 0.9381
# Epoch 12/60
# 6/6 [==============================] - 1s 181ms/step - loss: 0.0534 - accuracy: 0.9845 - val_loss: 0.2302 - val_accuracy: 0.9367
# Epoch 13/60
# 6/6 [==============================] - 1s 164ms/step - loss: 0.0603 - accuracy: 0.9789 - val_loss: 0.2199 - val_accuracy: 0.9381
# Epoch 14/60
# 6/6 [==============================] - 1s 184ms/step - loss: 0.0464 - accuracy: 0.9891 - val_loss: 0.2294 - val_accuracy: 0.9395
# Epoch 15/60
# 6/6 [==============================] - 1s 226ms/step - loss: 0.0490 - accuracy: 0.9866 - val_loss: 0.2241 - val_accuracy: 0.9381
# Epoch 16/60
# 6/6 [==============================] - 1s 183ms/step - loss: 0.0522 - accuracy: 0.9814 - val_loss: 0.2154 - val_accuracy: 0.9480
# Epoch 17/60
# 6/6 [==============================] - 1s 185ms/step - loss: 0.0537 - accuracy: 0.9845 - val_loss: 0.2722 - val_accuracy: 0.9339
# Epoch 18/60
# 6/6 [==============================] - 1s 185ms/step - loss: 0.0596 - accuracy: 0.9793 - val_loss: 0.2504 - val_accuracy: 0.9381
# Epoch 19/60
# 6/6 [==============================] - 1s 219ms/step - loss: 0.0651 - accuracy: 0.9771 - val_loss: 0.2591 - val_accuracy: 0.9297
# Epoch 20/60
# 6/6 [==============================] - 1s 217ms/step - loss: 0.0635 - accuracy: 0.9793 - val_loss: 0.2505 - val_accuracy: 0.9339
# Epoch 21/60
# 6/6 [==============================] - 1s 191ms/step - loss: 0.0656 - accuracy: 0.9736 - val_loss: 0.2417 - val_accuracy: 0.9409
# Epoch 22/60
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0710 - accuracy: 0.9733 - val_loss: 0.2184 - val_accuracy: 0.9395
# Epoch 23/60
# 6/6 [==============================] - 1s 214ms/step - loss: 0.0472 - accuracy: 0.9863 - val_loss: 0.2314 - val_accuracy: 0.9367
# Epoch 24/60
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0436 - accuracy: 0.9859 - val_loss: 0.2299 - val_accuracy: 0.9353
# Epoch 25/60
# 6/6 [==============================] - 1s 209ms/step - loss: 0.0427 - accuracy: 0.9880 - val_loss: 0.2463 - val_accuracy: 0.9437
# Epoch 26/60
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0442 - accuracy: 0.9873 - val_loss: 0.2118 - val_accuracy: 0.9451
# Epoch 27/60
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0429 - accuracy: 0.9877 - val_loss: 0.2206 - val_accuracy: 0.9409
# Epoch 28/60
# 6/6 [==============================] - 1s 185ms/step - loss: 0.0371 - accuracy: 0.9870 - val_loss: 0.2236 - val_accuracy: 0.9437
# Epoch 29/60
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0351 - accuracy: 0.9880 - val_loss: 0.2349 - val_accuracy: 0.9381
# Epoch 30/60
# 6/6 [==============================] - 1s 198ms/step - loss: 0.0360 - accuracy: 0.9887 - val_loss: 0.2277 - val_accuracy: 0.9437
# Epoch 31/60
# 6/6 [==============================] - 1s 192ms/step - loss: 0.0354 - accuracy: 0.9902 - val_loss: 0.2178 - val_accuracy: 0.9466
# Epoch 32/60
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0350 - accuracy: 0.9898 - val_loss: 0.2450 - val_accuracy: 0.9423
# Epoch 33/60
# 6/6 [==============================] - 1s 212ms/step - loss: 0.0369 - accuracy: 0.9877 - val_loss: 0.2323 - val_accuracy: 0.9451
# Epoch 34/60
# 6/6 [==============================] - 1s 208ms/step - loss: 0.0372 - accuracy: 0.9877 - val_loss: 0.2635 - val_accuracy: 0.9325
# Epoch 35/60
# 6/6 [==============================] - 1s 182ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.2323 - val_accuracy: 0.9423
# Epoch 36/60
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0529 - accuracy: 0.9800 - val_loss: 0.2482 - val_accuracy: 0.9353
# Epoch 37/60
# 6/6 [==============================] - 1s 195ms/step - loss: 0.0615 - accuracy: 0.9768 - val_loss: 0.2437 - val_accuracy: 0.9353
# Epoch 38/60
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0766 - accuracy: 0.9701 - val_loss: 0.2784 - val_accuracy: 0.9353
# Epoch 39/60
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0709 - accuracy: 0.9757 - val_loss: 0.2201 - val_accuracy: 0.9466
# Epoch 40/60
# 6/6 [==============================] - 1s 208ms/step - loss: 0.0692 - accuracy: 0.9736 - val_loss: 0.2235 - val_accuracy: 0.9423
# Epoch 41/60
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0510 - accuracy: 0.9831 - val_loss: 0.2357 - val_accuracy: 0.9423
# Epoch 42/60
# 6/6 [==============================] - 1s 212ms/step - loss: 0.0430 - accuracy: 0.9845 - val_loss: 0.2256 - val_accuracy: 0.9381
# Epoch 43/60
# 6/6 [==============================] - 1s 160ms/step - loss: 0.0578 - accuracy: 0.9800 - val_loss: 0.2313 - val_accuracy: 0.9395
# Epoch 44/60
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0487 - accuracy: 0.9828 - val_loss: 0.2404 - val_accuracy: 0.9395
# Epoch 45/60
# 6/6 [==============================] - 1s 216ms/step - loss: 0.0467 - accuracy: 0.9838 - val_loss: 0.2365 - val_accuracy: 0.9395
# Epoch 46/60
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0419 - accuracy: 0.9859 - val_loss: 0.2229 - val_accuracy: 0.9437
# Epoch 47/60
# 6/6 [==============================] - 1s 186ms/step - loss: 0.0443 - accuracy: 0.9838 - val_loss: 0.2435 - val_accuracy: 0.9423
# Epoch 48/60
# 6/6 [==============================] - 1s 183ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.2393 - val_accuracy: 0.9381
# Epoch 49/60
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0383 - accuracy: 0.9887 - val_loss: 0.2281 - val_accuracy: 0.9423
# Epoch 50/60
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0390 - accuracy: 0.9891 - val_loss: 0.2202 - val_accuracy: 0.9423
# Epoch 51/60
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0452 - accuracy: 0.9838 - val_loss: 0.2943 - val_accuracy: 0.9241
# Epoch 52/60
# 6/6 [==============================] - 1s 218ms/step - loss: 0.0469 - accuracy: 0.9824 - val_loss: 0.2481 - val_accuracy: 0.9451
# Epoch 53/60
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.2363 - val_accuracy: 0.9367
# Epoch 54/60
# 6/6 [==============================] - 1s 219ms/step - loss: 0.0447 - accuracy: 0.9849 - val_loss: 0.2269 - val_accuracy: 0.9423
# Epoch 55/60
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0408 - accuracy: 0.9852 - val_loss: 0.2253 - val_accuracy: 0.9480
# Epoch 56/60
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0422 - accuracy: 0.9856 - val_loss: 0.2576 - val_accuracy: 0.9437
# Epoch 57/60
# 6/6 [==============================] - 1s 168ms/step - loss: 0.0349 - accuracy: 0.9877 - val_loss: 0.2381 - val_accuracy: 0.9437
# Epoch 58/60
# 6/6 [==============================] - 1s 240ms/step - loss: 0.0443 - accuracy: 0.9849 - val_loss: 0.2515 - val_accuracy: 0.9381
# Epoch 59/60
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.2271 - val_accuracy: 0.9437
# Epoch 60/60
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0482 - accuracy: 0.9824 - val_loss: 0.2276 - val_accuracy: 0.9395

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0285 - accuracy: 0.9909
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2276 - accuracy: 0.9395
# 0.9908579587936401 0.9395217895507812

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 848, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:10:44

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_test_000_predict_map.png", bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, open("./plots/CNN_Model2_spatial_train_000_test_000_predict_map.pickle", "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 234   5   0   0   1]
#  [  0   0   0  11  87   0   0   2]
#  [  0   0   0   0   0  12   0   0]
#  [  0   0   0   0   0   4   7   0]
#  [  0   0   0  16   1   0   0  29]]
#
# Accuracy Score
# 0.939521800281294
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        80
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.89      0.97      0.93       240
#     windows       0.94      0.87      0.90       100
#       roads       0.75      1.00      0.86        12
#        cars       1.00      0.64      0.78        11
#       metal       0.91      0.63      0.74        46
#
# avg / total       0.94      0.94      0.94       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_test_000_metrics.txt", "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_norm_north = (cube_reshaped_north - cube_reshaped_north.min()) / (cube_reshaped_north.max() - cube_reshaped_north.min())

import matplotlib.pyplot as plt
# %matplotlib inline

red_ind_n = (np.abs(cube_north.waves - 650.0)).argmin()
green_ind_n = (np.abs(cube_north.waves - 550.0)).argmin()
blue_ind_n = (np.abs(cube_north.waves - 450.0)).argmin()

cube_reshaped_north2 = cube_norm_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], cube_sub_north.shape[0])
cube_scene_north = cube_reshaped_north2[:, :, [red_ind_n, green_ind_n, blue_ind_n]]
fig, ax = plt.subplots(figsize=(10,10))
plt.title('North Facing RGB Image')
ax.imshow(cube_scene_north, aspect=0.4)
plt.show()

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], cube_sub_north.shape[0])
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 872)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 872) (60, 872)
# clouds  (160, 872) (40, 872)
# vegetation  (560, 872) (140, 872)
# water  (496, 872) (124, 872)
# built  (1280, 872) (320, 872)
# windows  (480, 872) (120, 872)
# roads  (200, 872) (50, 872)
# cars  (200, 872) (50, 872)
# metal  (148, 872) (37, 872)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 872) (3764,) (3764, 2)
# (941, 872) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 210ms/step - loss: 2.3388 - accuracy: 0.3087 - val_loss: 1.8177 - val_accuracy: 0.4431
# Epoch 2/200
# 8/8 [==============================] - 1s 162ms/step - loss: 1.5060 - accuracy: 0.4875 - val_loss: 1.2580 - val_accuracy: 0.5909
# Epoch 3/200
# 8/8 [==============================] - 1s 159ms/step - loss: 1.1556 - accuracy: 0.6068 - val_loss: 1.0237 - val_accuracy: 0.6302
# Epoch 4/200
# 8/8 [==============================] - 1s 166ms/step - loss: 0.9569 - accuracy: 0.6533 - val_loss: 0.8755 - val_accuracy: 0.7407
# Epoch 5/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.8247 - accuracy: 0.7250 - val_loss: 0.8383 - val_accuracy: 0.7311
# Epoch 6/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.7794 - accuracy: 0.7349 - val_loss: 0.8988 - val_accuracy: 0.6854
# Epoch 7/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.7673 - accuracy: 0.7317 - val_loss: 0.6864 - val_accuracy: 0.7747
# Epoch 8/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.6827 - accuracy: 0.7593 - val_loss: 0.6369 - val_accuracy: 0.7928
# Epoch 9/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.6638 - accuracy: 0.7606 - val_loss: 0.6069 - val_accuracy: 0.8034
# Epoch 10/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.6059 - accuracy: 0.7806 - val_loss: 0.5812 - val_accuracy: 0.8066
# Epoch 11/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.6254 - accuracy: 0.7726 - val_loss: 0.5727 - val_accuracy: 0.8087
# Epoch 12/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.5822 - accuracy: 0.7891 - val_loss: 0.5720 - val_accuracy: 0.8108
# Epoch 13/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.5635 - accuracy: 0.8034 - val_loss: 0.5342 - val_accuracy: 0.8268
# Epoch 14/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.5473 - accuracy: 0.7999 - val_loss: 0.5469 - val_accuracy: 0.8225
# Epoch 15/200
# 8/8 [==============================] - 2s 224ms/step - loss: 0.5169 - accuracy: 0.8196 - val_loss: 0.5147 - val_accuracy: 0.8321
# Epoch 16/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.5124 - accuracy: 0.8204 - val_loss: 0.4920 - val_accuracy: 0.8459
# Epoch 17/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.4925 - accuracy: 0.8302 - val_loss: 0.5032 - val_accuracy: 0.8374
# Epoch 18/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.5334 - accuracy: 0.8087 - val_loss: 0.6442 - val_accuracy: 0.7875
# Epoch 19/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.5579 - accuracy: 0.7981 - val_loss: 0.5105 - val_accuracy: 0.8332
# Epoch 20/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.5054 - accuracy: 0.8249 - val_loss: 0.5143 - val_accuracy: 0.8363
# Epoch 21/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.4855 - accuracy: 0.8305 - val_loss: 0.4790 - val_accuracy: 0.8395
# Epoch 22/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.4685 - accuracy: 0.8278 - val_loss: 0.4673 - val_accuracy: 0.8576
# Epoch 23/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.4520 - accuracy: 0.8385 - val_loss: 0.4627 - val_accuracy: 0.8470
# Epoch 24/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.4417 - accuracy: 0.8475 - val_loss: 0.4531 - val_accuracy: 0.8608
# Epoch 25/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.4865 - accuracy: 0.8185 - val_loss: 0.4602 - val_accuracy: 0.8661
# Epoch 26/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.4619 - accuracy: 0.8390 - val_loss: 0.4741 - val_accuracy: 0.8587
# Epoch 27/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.4459 - accuracy: 0.8523 - val_loss: 0.4741 - val_accuracy: 0.8555
# Epoch 28/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.4124 - accuracy: 0.8573 - val_loss: 0.4507 - val_accuracy: 0.8523
# Epoch 29/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.4259 - accuracy: 0.8515 - val_loss: 0.4240 - val_accuracy: 0.8587
# Epoch 30/200
# 8/8 [==============================] - 2s 203ms/step - loss: 0.4127 - accuracy: 0.8507 - val_loss: 0.4068 - val_accuracy: 0.8810
# Epoch 31/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.4050 - accuracy: 0.8595 - val_loss: 0.4203 - val_accuracy: 0.8820
# Epoch 32/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.4009 - accuracy: 0.8531 - val_loss: 0.4441 - val_accuracy: 0.8555
# Epoch 33/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.4316 - accuracy: 0.8451 - val_loss: 0.4542 - val_accuracy: 0.8587
# Epoch 34/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.4040 - accuracy: 0.8589 - val_loss: 0.4119 - val_accuracy: 0.8735
# Epoch 35/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.3751 - accuracy: 0.8722 - val_loss: 0.3990 - val_accuracy: 0.8831
# Epoch 36/200
# 8/8 [==============================] - 2s 237ms/step - loss: 0.3739 - accuracy: 0.8629 - val_loss: 0.3883 - val_accuracy: 0.8693
# Epoch 37/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.3971 - accuracy: 0.8581 - val_loss: 0.4263 - val_accuracy: 0.8597
# Epoch 38/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.3750 - accuracy: 0.8701 - val_loss: 0.4078 - val_accuracy: 0.8778
# Epoch 39/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.3491 - accuracy: 0.8834 - val_loss: 0.3830 - val_accuracy: 0.8927
# Epoch 40/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.3503 - accuracy: 0.8802 - val_loss: 0.3907 - val_accuracy: 0.8863
# Epoch 41/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.3514 - accuracy: 0.8802 - val_loss: 0.3944 - val_accuracy: 0.8725
# Epoch 42/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.3406 - accuracy: 0.8831 - val_loss: 0.4163 - val_accuracy: 0.8672
# Epoch 43/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.3745 - accuracy: 0.8674 - val_loss: 0.3735 - val_accuracy: 0.8810
# Epoch 44/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.3320 - accuracy: 0.8855 - val_loss: 0.3893 - val_accuracy: 0.8682
# Epoch 45/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.3317 - accuracy: 0.8839 - val_loss: 0.3937 - val_accuracy: 0.8831
# Epoch 46/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.3524 - accuracy: 0.8807 - val_loss: 0.4296 - val_accuracy: 0.8406
# Epoch 47/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.3585 - accuracy: 0.8711 - val_loss: 0.4332 - val_accuracy: 0.8491
# Epoch 48/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.3586 - accuracy: 0.8765 - val_loss: 0.3800 - val_accuracy: 0.8831
# Epoch 49/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.3339 - accuracy: 0.8802 - val_loss: 0.3767 - val_accuracy: 0.8895
# Epoch 50/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.3165 - accuracy: 0.8882 - val_loss: 0.3545 - val_accuracy: 0.8863
# Epoch 51/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.3019 - accuracy: 0.8977 - val_loss: 0.3608 - val_accuracy: 0.8927
# Epoch 52/200
# 8/8 [==============================] - 2s 234ms/step - loss: 0.3046 - accuracy: 0.8985 - val_loss: 0.3435 - val_accuracy: 0.8959
# Epoch 53/200
# 8/8 [==============================] - 2s 217ms/step - loss: 0.2877 - accuracy: 0.9033 - val_loss: 0.3684 - val_accuracy: 0.8874
# Epoch 54/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.3064 - accuracy: 0.8956 - val_loss: 0.3589 - val_accuracy: 0.9022
# Epoch 55/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.2847 - accuracy: 0.9022 - val_loss: 0.3299 - val_accuracy: 0.8990
# Epoch 56/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.2767 - accuracy: 0.9070 - val_loss: 0.3499 - val_accuracy: 0.8905
# Epoch 57/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.2757 - accuracy: 0.9081 - val_loss: 0.3413 - val_accuracy: 0.9012
# Epoch 58/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.2571 - accuracy: 0.9142 - val_loss: 0.3280 - val_accuracy: 0.9022
# Epoch 59/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.2653 - accuracy: 0.9131 - val_loss: 0.3337 - val_accuracy: 0.9022
# Epoch 60/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.2744 - accuracy: 0.9067 - val_loss: 0.3619 - val_accuracy: 0.9033
# Epoch 61/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.2642 - accuracy: 0.9075 - val_loss: 0.3633 - val_accuracy: 0.8927
# Epoch 62/200
# 8/8 [==============================] - 2s 224ms/step - loss: 0.2784 - accuracy: 0.9046 - val_loss: 0.3584 - val_accuracy: 0.8969
# Epoch 63/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.2675 - accuracy: 0.9089 - val_loss: 0.3193 - val_accuracy: 0.8990
# Epoch 64/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.2669 - accuracy: 0.9097 - val_loss: 0.3389 - val_accuracy: 0.9054
# Epoch 65/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.2645 - accuracy: 0.9102 - val_loss: 0.3324 - val_accuracy: 0.9044
# Epoch 66/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.2563 - accuracy: 0.9134 - val_loss: 0.3501 - val_accuracy: 0.8842
# Epoch 67/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.2491 - accuracy: 0.9142 - val_loss: 0.3568 - val_accuracy: 0.8969
# Epoch 68/200
# 8/8 [==============================] - 2s 223ms/step - loss: 0.2754 - accuracy: 0.9025 - val_loss: 0.3553 - val_accuracy: 0.8948
# Epoch 69/200
# 8/8 [==============================] - 2s 203ms/step - loss: 0.2822 - accuracy: 0.9046 - val_loss: 0.3612 - val_accuracy: 0.8895
# Epoch 70/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.2579 - accuracy: 0.9115 - val_loss: 0.3386 - val_accuracy: 0.8927
# Epoch 71/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.2530 - accuracy: 0.9163 - val_loss: 0.3314 - val_accuracy: 0.9001
# Epoch 72/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.2434 - accuracy: 0.9203 - val_loss: 0.3459 - val_accuracy: 0.9022
# Epoch 73/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.2468 - accuracy: 0.9152 - val_loss: 0.3282 - val_accuracy: 0.9065
# Epoch 74/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.2373 - accuracy: 0.9214 - val_loss: 0.3440 - val_accuracy: 0.9001
# Epoch 75/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.2361 - accuracy: 0.9222 - val_loss: 0.3257 - val_accuracy: 0.9022
# Epoch 76/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.2246 - accuracy: 0.9198 - val_loss: 0.3327 - val_accuracy: 0.9022
# Epoch 77/200
# 8/8 [==============================] - 2s 200ms/step - loss: 0.2328 - accuracy: 0.9219 - val_loss: 0.3084 - val_accuracy: 0.9065
# Epoch 78/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.2174 - accuracy: 0.9288 - val_loss: 0.3322 - val_accuracy: 0.9065
# Epoch 79/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.2113 - accuracy: 0.9349 - val_loss: 0.3103 - val_accuracy: 0.8980
# Epoch 80/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.2191 - accuracy: 0.9235 - val_loss: 0.3519 - val_accuracy: 0.8895
# Epoch 81/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.2158 - accuracy: 0.9248 - val_loss: 0.3188 - val_accuracy: 0.9118
# Epoch 82/200
# 8/8 [==============================] - 1s 171ms/step - loss: 0.2025 - accuracy: 0.9304 - val_loss: 0.3222 - val_accuracy: 0.9107
# Epoch 83/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.2092 - accuracy: 0.9285 - val_loss: 0.3228 - val_accuracy: 0.9075
# Epoch 84/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.2066 - accuracy: 0.9238 - val_loss: 0.3387 - val_accuracy: 0.9054
# Epoch 85/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.1994 - accuracy: 0.9336 - val_loss: 0.2952 - val_accuracy: 0.9022
# Epoch 86/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.2020 - accuracy: 0.9320 - val_loss: 0.3591 - val_accuracy: 0.8959
# Epoch 87/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.2250 - accuracy: 0.9219 - val_loss: 0.3017 - val_accuracy: 0.8990
# Epoch 88/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.1980 - accuracy: 0.9365 - val_loss: 0.3261 - val_accuracy: 0.9129
# Epoch 89/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1909 - accuracy: 0.9384 - val_loss: 0.3233 - val_accuracy: 0.9033
# Epoch 90/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1980 - accuracy: 0.9338 - val_loss: 0.3217 - val_accuracy: 0.9075
# Epoch 91/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1969 - accuracy: 0.9354 - val_loss: 0.3300 - val_accuracy: 0.9033
# Epoch 92/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.1929 - accuracy: 0.9360 - val_loss: 0.3276 - val_accuracy: 0.9001
# Epoch 93/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1911 - accuracy: 0.9376 - val_loss: 0.3213 - val_accuracy: 0.9033
# Epoch 94/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1850 - accuracy: 0.9368 - val_loss: 0.2958 - val_accuracy: 0.9107
# Epoch 95/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1808 - accuracy: 0.9400 - val_loss: 0.3055 - val_accuracy: 0.9160
# Epoch 96/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.1801 - accuracy: 0.9392 - val_loss: 0.3073 - val_accuracy: 0.9097
# Epoch 97/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.1718 - accuracy: 0.9434 - val_loss: 0.2913 - val_accuracy: 0.9214
# Epoch 98/200
# 8/8 [==============================] - 2s 200ms/step - loss: 0.1858 - accuracy: 0.9317 - val_loss: 0.3348 - val_accuracy: 0.9075
# Epoch 99/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.1682 - accuracy: 0.9416 - val_loss: 0.3230 - val_accuracy: 0.9075
# Epoch 100/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.1754 - accuracy: 0.9405 - val_loss: 0.3035 - val_accuracy: 0.9118
# Epoch 101/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1719 - accuracy: 0.9400 - val_loss: 0.3084 - val_accuracy: 0.9054
# Epoch 102/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.1712 - accuracy: 0.9453 - val_loss: 0.3225 - val_accuracy: 0.9001
# Epoch 103/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.1747 - accuracy: 0.9370 - val_loss: 0.3014 - val_accuracy: 0.9160
# Epoch 104/200
# 8/8 [==============================] - 2s 205ms/step - loss: 0.1575 - accuracy: 0.9442 - val_loss: 0.3226 - val_accuracy: 0.9065
# Epoch 105/200
# 8/8 [==============================] - 2s 203ms/step - loss: 0.1554 - accuracy: 0.9471 - val_loss: 0.3243 - val_accuracy: 0.9075
# Epoch 106/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1628 - accuracy: 0.9482 - val_loss: 0.3092 - val_accuracy: 0.9107
# Epoch 107/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.1549 - accuracy: 0.9479 - val_loss: 0.3666 - val_accuracy: 0.8990
# Epoch 108/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.1743 - accuracy: 0.9384 - val_loss: 0.3058 - val_accuracy: 0.9129
# Epoch 109/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.1605 - accuracy: 0.9469 - val_loss: 0.3034 - val_accuracy: 0.9160
# Epoch 110/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.1497 - accuracy: 0.9516 - val_loss: 0.2947 - val_accuracy: 0.9107
# Epoch 111/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.1494 - accuracy: 0.9514 - val_loss: 0.3179 - val_accuracy: 0.9075
# Epoch 112/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1439 - accuracy: 0.9516 - val_loss: 0.3320 - val_accuracy: 0.9107
# Epoch 113/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1451 - accuracy: 0.9498 - val_loss: 0.3052 - val_accuracy: 0.9054
# Epoch 114/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1461 - accuracy: 0.9498 - val_loss: 0.3092 - val_accuracy: 0.9107
# Epoch 115/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.1539 - accuracy: 0.9477 - val_loss: 0.2851 - val_accuracy: 0.9118
# Epoch 116/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.1432 - accuracy: 0.9519 - val_loss: 0.3264 - val_accuracy: 0.9160
# Epoch 117/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1438 - accuracy: 0.9511 - val_loss: 0.3004 - val_accuracy: 0.9160
# Epoch 118/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1459 - accuracy: 0.9487 - val_loss: 0.3258 - val_accuracy: 0.9044
# Epoch 119/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.1407 - accuracy: 0.9580 - val_loss: 0.3074 - val_accuracy: 0.9171
# Epoch 120/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.1461 - accuracy: 0.9511 - val_loss: 0.3294 - val_accuracy: 0.9160
# Epoch 121/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1395 - accuracy: 0.9509 - val_loss: 0.3278 - val_accuracy: 0.9129
# Epoch 122/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1443 - accuracy: 0.9506 - val_loss: 0.3115 - val_accuracy: 0.9182
# Epoch 123/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1279 - accuracy: 0.9588 - val_loss: 0.3069 - val_accuracy: 0.9097
# Epoch 124/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.1450 - accuracy: 0.9482 - val_loss: 0.3019 - val_accuracy: 0.9224
# Epoch 125/200
# 8/8 [==============================] - 2s 223ms/step - loss: 0.1336 - accuracy: 0.9596 - val_loss: 0.2835 - val_accuracy: 0.9065
# Epoch 126/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.1268 - accuracy: 0.9604 - val_loss: 0.3065 - val_accuracy: 0.9118
# Epoch 127/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.1314 - accuracy: 0.9556 - val_loss: 0.3016 - val_accuracy: 0.9171
# Epoch 128/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1326 - accuracy: 0.9548 - val_loss: 0.2913 - val_accuracy: 0.9086
# Epoch 129/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1214 - accuracy: 0.9617 - val_loss: 0.3009 - val_accuracy: 0.9118
# Epoch 130/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1283 - accuracy: 0.9554 - val_loss: 0.3352 - val_accuracy: 0.9107
# Epoch 131/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.1263 - accuracy: 0.9578 - val_loss: 0.3136 - val_accuracy: 0.9118
# Epoch 132/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.1365 - accuracy: 0.9548 - val_loss: 0.3149 - val_accuracy: 0.9256
# Epoch 133/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1254 - accuracy: 0.9572 - val_loss: 0.3623 - val_accuracy: 0.9022
# Epoch 134/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1575 - accuracy: 0.9437 - val_loss: 0.3508 - val_accuracy: 0.9107
# Epoch 135/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.1708 - accuracy: 0.9320 - val_loss: 0.4231 - val_accuracy: 0.8714
# Epoch 136/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.1691 - accuracy: 0.9416 - val_loss: 0.3018 - val_accuracy: 0.9139
# Epoch 137/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.1489 - accuracy: 0.9503 - val_loss: 0.3159 - val_accuracy: 0.9139
# Epoch 138/200
# 8/8 [==============================] - 2s 200ms/step - loss: 0.1303 - accuracy: 0.9548 - val_loss: 0.3173 - val_accuracy: 0.9160
# Epoch 139/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.1285 - accuracy: 0.9570 - val_loss: 0.3411 - val_accuracy: 0.9086
# Epoch 140/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1130 - accuracy: 0.9594 - val_loss: 0.3291 - val_accuracy: 0.9150
# Epoch 141/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.1065 - accuracy: 0.9636 - val_loss: 0.3285 - val_accuracy: 0.9139
# Epoch 142/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.1053 - accuracy: 0.9649 - val_loss: 0.3108 - val_accuracy: 0.9118
# Epoch 143/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.1136 - accuracy: 0.9628 - val_loss: 0.2984 - val_accuracy: 0.9107
# Epoch 144/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.1066 - accuracy: 0.9665 - val_loss: 0.3264 - val_accuracy: 0.9118
# Epoch 145/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.1117 - accuracy: 0.9625 - val_loss: 0.3091 - val_accuracy: 0.9139
# Epoch 146/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.1149 - accuracy: 0.9591 - val_loss: 0.3092 - val_accuracy: 0.9097
# Epoch 147/200
# 8/8 [==============================] - 2s 224ms/step - loss: 0.1181 - accuracy: 0.9612 - val_loss: 0.3109 - val_accuracy: 0.9097
# Epoch 148/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1111 - accuracy: 0.9612 - val_loss: 0.3174 - val_accuracy: 0.9160
# Epoch 149/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.1094 - accuracy: 0.9615 - val_loss: 0.3143 - val_accuracy: 0.9139
# Epoch 150/200
# 8/8 [==============================] - 2s 239ms/step - loss: 0.1108 - accuracy: 0.9644 - val_loss: 0.3022 - val_accuracy: 0.9150
# Epoch 151/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1053 - accuracy: 0.9689 - val_loss: 0.3130 - val_accuracy: 0.9150
# Epoch 152/200
# 8/8 [==============================] - 2s 195ms/step - loss: 0.1082 - accuracy: 0.9652 - val_loss: 0.3211 - val_accuracy: 0.9171
# Epoch 153/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.1021 - accuracy: 0.9660 - val_loss: 0.3466 - val_accuracy: 0.9150
# Epoch 154/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1006 - accuracy: 0.9649 - val_loss: 0.3120 - val_accuracy: 0.9245
# Epoch 155/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.0905 - accuracy: 0.9708 - val_loss: 0.3179 - val_accuracy: 0.9107
# Epoch 156/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.0898 - accuracy: 0.9705 - val_loss: 0.3319 - val_accuracy: 0.9118
# Epoch 157/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0924 - accuracy: 0.9692 - val_loss: 0.3124 - val_accuracy: 0.9139
# Epoch 158/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0881 - accuracy: 0.9724 - val_loss: 0.3456 - val_accuracy: 0.9065
# Epoch 159/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.1024 - accuracy: 0.9665 - val_loss: 0.3420 - val_accuracy: 0.9097
# Epoch 160/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.1133 - accuracy: 0.9620 - val_loss: 0.3505 - val_accuracy: 0.9192
# Epoch 161/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1122 - accuracy: 0.9594 - val_loss: 0.3218 - val_accuracy: 0.9075
# Epoch 162/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0996 - accuracy: 0.9668 - val_loss: 0.3549 - val_accuracy: 0.9097
# Epoch 163/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.1048 - accuracy: 0.9655 - val_loss: 0.3680 - val_accuracy: 0.9107
# Epoch 164/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0999 - accuracy: 0.9676 - val_loss: 0.3316 - val_accuracy: 0.9107
# Epoch 165/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.0936 - accuracy: 0.9718 - val_loss: 0.3224 - val_accuracy: 0.9118
# Epoch 166/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.0913 - accuracy: 0.9697 - val_loss: 0.3263 - val_accuracy: 0.9235
# Epoch 167/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.0906 - accuracy: 0.9684 - val_loss: 0.3165 - val_accuracy: 0.9224
# Epoch 168/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.1011 - accuracy: 0.9681 - val_loss: 0.3093 - val_accuracy: 0.9182
# Epoch 169/200
# 8/8 [==============================] - 2s 205ms/step - loss: 0.0878 - accuracy: 0.9708 - val_loss: 0.3482 - val_accuracy: 0.9139
# Epoch 170/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.3308 - val_accuracy: 0.9214
# Epoch 171/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0837 - accuracy: 0.9721 - val_loss: 0.3366 - val_accuracy: 0.9192
# Epoch 172/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.0910 - accuracy: 0.9692 - val_loss: 0.3305 - val_accuracy: 0.9107
# Epoch 173/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0827 - accuracy: 0.9737 - val_loss: 0.3723 - val_accuracy: 0.9150
# Epoch 174/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0844 - accuracy: 0.9708 - val_loss: 0.3328 - val_accuracy: 0.9160
# Epoch 175/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.0871 - accuracy: 0.9713 - val_loss: 0.3399 - val_accuracy: 0.9256
# Epoch 176/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0924 - accuracy: 0.9673 - val_loss: 0.3209 - val_accuracy: 0.9245
# Epoch 177/200
# 8/8 [==============================] - 2s 195ms/step - loss: 0.0955 - accuracy: 0.9644 - val_loss: 0.3323 - val_accuracy: 0.9203
# Epoch 178/200
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0967 - accuracy: 0.9679 - val_loss: 0.3656 - val_accuracy: 0.9139
# Epoch 179/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0835 - accuracy: 0.9726 - val_loss: 0.2760 - val_accuracy: 0.9192
# Epoch 180/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0863 - accuracy: 0.9721 - val_loss: 0.3558 - val_accuracy: 0.9182
# Epoch 181/200
# 8/8 [==============================] - 1s 178ms/step - loss: 0.0758 - accuracy: 0.9777 - val_loss: 0.3355 - val_accuracy: 0.9182
# Epoch 182/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0716 - accuracy: 0.9748 - val_loss: 0.3211 - val_accuracy: 0.9171
# Epoch 183/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.0660 - accuracy: 0.9777 - val_loss: 0.3513 - val_accuracy: 0.9129
# Epoch 184/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0655 - accuracy: 0.9761 - val_loss: 0.3329 - val_accuracy: 0.9203
# Epoch 185/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.0742 - accuracy: 0.9782 - val_loss: 0.3404 - val_accuracy: 0.9118
# Epoch 186/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.0846 - accuracy: 0.9708 - val_loss: 0.3436 - val_accuracy: 0.9245
# Epoch 187/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0731 - accuracy: 0.9769 - val_loss: 0.3344 - val_accuracy: 0.9171
# Epoch 188/200
# 8/8 [==============================] - 2s 212ms/step - loss: 0.0861 - accuracy: 0.9710 - val_loss: 0.3484 - val_accuracy: 0.9171
# Epoch 189/200
# 8/8 [==============================] - 1s 182ms/step - loss: 0.0770 - accuracy: 0.9758 - val_loss: 0.3369 - val_accuracy: 0.9192
# Epoch 190/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.0701 - accuracy: 0.9787 - val_loss: 0.3421 - val_accuracy: 0.9214
# Epoch 191/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0702 - accuracy: 0.9785 - val_loss: 0.3463 - val_accuracy: 0.9150
# Epoch 192/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.0729 - accuracy: 0.9750 - val_loss: 0.3270 - val_accuracy: 0.9182
# Epoch 193/200
# 8/8 [==============================] - 2s 189ms/step - loss: 0.0668 - accuracy: 0.9779 - val_loss: 0.3441 - val_accuracy: 0.9150
# Epoch 194/200
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0697 - accuracy: 0.9772 - val_loss: 0.3439 - val_accuracy: 0.9171
# Epoch 195/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0762 - accuracy: 0.9734 - val_loss: 0.3638 - val_accuracy: 0.9214
# Epoch 196/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.0795 - accuracy: 0.9726 - val_loss: 0.3084 - val_accuracy: 0.9192
# Epoch 197/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.0704 - accuracy: 0.9745 - val_loss: 0.3665 - val_accuracy: 0.9203
# Epoch 198/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0783 - accuracy: 0.9724 - val_loss: 0.3522 - val_accuracy: 0.9171
# Epoch 199/200
# 8/8 [==============================] - 2s 252ms/step - loss: 0.0695 - accuracy: 0.9790 - val_loss: 0.3630 - val_accuracy: 0.9118
# Epoch 200/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0728 - accuracy: 0.9764 - val_loss: 0.3302 - val_accuracy: 0.9214

# %%
plot_loss_history(CNNmodeln)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 8/8 [==============================] - 2s 245ms/step - loss: 0.0753 - accuracy: 0.9761 - val_loss: 0.3743 - val_accuracy: 0.9192
# Epoch 2/60
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0771 - accuracy: 0.9729 - val_loss: 0.3285 - val_accuracy: 0.9192
# Epoch 3/60
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0730 - accuracy: 0.9772 - val_loss: 0.3516 - val_accuracy: 0.9214
# Epoch 4/60
# 8/8 [==============================] - 2s 204ms/step - loss: 0.0706 - accuracy: 0.9777 - val_loss: 0.3456 - val_accuracy: 0.9182
# Epoch 5/60
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0733 - accuracy: 0.9766 - val_loss: 0.4115 - val_accuracy: 0.9150
# Epoch 6/60
# 8/8 [==============================] - 2s 189ms/step - loss: 0.0846 - accuracy: 0.9724 - val_loss: 0.3452 - val_accuracy: 0.9203
# Epoch 7/60
# 8/8 [==============================] - 2s 199ms/step - loss: 0.0760 - accuracy: 0.9756 - val_loss: 0.3628 - val_accuracy: 0.9214
# Epoch 8/60
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0730 - accuracy: 0.9734 - val_loss: 0.3437 - val_accuracy: 0.9235
# Epoch 9/60
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0613 - accuracy: 0.9793 - val_loss: 0.4030 - val_accuracy: 0.9139
# Epoch 10/60
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0667 - accuracy: 0.9798 - val_loss: 0.3377 - val_accuracy: 0.9256
# Epoch 11/60
# 8/8 [==============================] - 2s 211ms/step - loss: 0.0611 - accuracy: 0.9811 - val_loss: 0.3875 - val_accuracy: 0.9107
# Epoch 12/60
# 8/8 [==============================] - 2s 241ms/step - loss: 0.0576 - accuracy: 0.9817 - val_loss: 0.3617 - val_accuracy: 0.9171
# Epoch 13/60
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0544 - accuracy: 0.9822 - val_loss: 0.3510 - val_accuracy: 0.9182
# Epoch 14/60
# 8/8 [==============================] - 2s 212ms/step - loss: 0.0560 - accuracy: 0.9827 - val_loss: 0.3566 - val_accuracy: 0.9139
# Epoch 15/60
# 8/8 [==============================] - 2s 209ms/step - loss: 0.0568 - accuracy: 0.9825 - val_loss: 0.3564 - val_accuracy: 0.9171
# Epoch 16/60
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0527 - accuracy: 0.9835 - val_loss: 0.3657 - val_accuracy: 0.9129
# Epoch 17/60
# 8/8 [==============================] - 2s 209ms/step - loss: 0.0575 - accuracy: 0.9811 - val_loss: 0.3581 - val_accuracy: 0.9235
# Epoch 18/60
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0584 - accuracy: 0.9833 - val_loss: 0.3305 - val_accuracy: 0.9267
# Epoch 19/60
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0570 - accuracy: 0.9835 - val_loss: 0.3623 - val_accuracy: 0.9203
# Epoch 20/60
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0668 - accuracy: 0.9785 - val_loss: 0.3604 - val_accuracy: 0.9245
# Epoch 21/60
# 8/8 [==============================] - 2s 200ms/step - loss: 0.0596 - accuracy: 0.9819 - val_loss: 0.3501 - val_accuracy: 0.9150
# Epoch 22/60
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0646 - accuracy: 0.9779 - val_loss: 0.3699 - val_accuracy: 0.9256
# Epoch 23/60
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0660 - accuracy: 0.9785 - val_loss: 0.3596 - val_accuracy: 0.9214
# Epoch 24/60
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0638 - accuracy: 0.9798 - val_loss: 0.3461 - val_accuracy: 0.9182
# Epoch 25/60
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0578 - accuracy: 0.9814 - val_loss: 0.4042 - val_accuracy: 0.9171
# Epoch 26/60
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0566 - accuracy: 0.9851 - val_loss: 0.3357 - val_accuracy: 0.9129
# Epoch 27/60
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0625 - accuracy: 0.9811 - val_loss: 0.4133 - val_accuracy: 0.9256
# Epoch 28/60
# 8/8 [==============================] - 2s 210ms/step - loss: 0.0593 - accuracy: 0.9819 - val_loss: 0.3969 - val_accuracy: 0.9118
# Epoch 29/60
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0540 - accuracy: 0.9814 - val_loss: 0.3634 - val_accuracy: 0.9107
# Epoch 30/60
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0525 - accuracy: 0.9849 - val_loss: 0.3660 - val_accuracy: 0.9182
# Epoch 31/60
# 8/8 [==============================] - 2s 204ms/step - loss: 0.0486 - accuracy: 0.9851 - val_loss: 0.3725 - val_accuracy: 0.9277
# Epoch 32/60
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0477 - accuracy: 0.9849 - val_loss: 0.3772 - val_accuracy: 0.9203
# Epoch 33/60
# 8/8 [==============================] - 2s 239ms/step - loss: 0.0545 - accuracy: 0.9811 - val_loss: 0.3571 - val_accuracy: 0.9245
# Epoch 34/60
# 8/8 [==============================] - 2s 201ms/step - loss: 0.0538 - accuracy: 0.9833 - val_loss: 0.3578 - val_accuracy: 0.9256
# Epoch 35/60
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0479 - accuracy: 0.9859 - val_loss: 0.3831 - val_accuracy: 0.9245
# Epoch 36/60
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0517 - accuracy: 0.9825 - val_loss: 0.3336 - val_accuracy: 0.9288
# Epoch 37/60
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0578 - accuracy: 0.9825 - val_loss: 0.3322 - val_accuracy: 0.9277
# Epoch 38/60
# 8/8 [==============================] - 2s 237ms/step - loss: 0.0573 - accuracy: 0.9803 - val_loss: 0.3917 - val_accuracy: 0.9214
# Epoch 39/60
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0581 - accuracy: 0.9806 - val_loss: 0.4196 - val_accuracy: 0.9160
# Epoch 40/60
# 8/8 [==============================] - 2s 209ms/step - loss: 0.0557 - accuracy: 0.9814 - val_loss: 0.4282 - val_accuracy: 0.9203
# Epoch 41/60
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0560 - accuracy: 0.9825 - val_loss: 0.4284 - val_accuracy: 0.9107
# Epoch 42/60
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0510 - accuracy: 0.9841 - val_loss: 0.4005 - val_accuracy: 0.9214
# Epoch 43/60
# 8/8 [==============================] - 2s 220ms/step - loss: 0.0492 - accuracy: 0.9867 - val_loss: 0.3841 - val_accuracy: 0.9224
# Epoch 44/60
# 8/8 [==============================] - 2s 189ms/step - loss: 0.0565 - accuracy: 0.9827 - val_loss: 0.3761 - val_accuracy: 0.9203
# Epoch 45/60
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0579 - accuracy: 0.9801 - val_loss: 0.4194 - val_accuracy: 0.9224
# Epoch 46/60
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0529 - accuracy: 0.9841 - val_loss: 0.3867 - val_accuracy: 0.9245
# Epoch 47/60
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0551 - accuracy: 0.9814 - val_loss: 0.3925 - val_accuracy: 0.9139
# Epoch 48/60
# 8/8 [==============================] - 2s 206ms/step - loss: 0.0453 - accuracy: 0.9859 - val_loss: 0.4020 - val_accuracy: 0.9203
# Epoch 49/60
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0496 - accuracy: 0.9833 - val_loss: 0.3723 - val_accuracy: 0.9214
# Epoch 50/60
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0476 - accuracy: 0.9870 - val_loss: 0.3947 - val_accuracy: 0.9171
# Epoch 51/60
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0623 - accuracy: 0.9798 - val_loss: 0.3870 - val_accuracy: 0.9160
# Epoch 52/60
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0568 - accuracy: 0.9822 - val_loss: 0.4398 - val_accuracy: 0.9288
# Epoch 53/60
# 8/8 [==============================] - 2s 215ms/step - loss: 0.0465 - accuracy: 0.9857 - val_loss: 0.4132 - val_accuracy: 0.9182
# Epoch 54/60
# 8/8 [==============================] - 2s 205ms/step - loss: 0.0542 - accuracy: 0.9835 - val_loss: 0.4112 - val_accuracy: 0.9118
# Epoch 55/60
# 8/8 [==============================] - 2s 202ms/step - loss: 0.0590 - accuracy: 0.9809 - val_loss: 0.3972 - val_accuracy: 0.9139
# Epoch 56/60
# 8/8 [==============================] - 2s 199ms/step - loss: 0.0524 - accuracy: 0.9817 - val_loss: 0.4152 - val_accuracy: 0.9267
# Epoch 57/60
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0542 - accuracy: 0.9849 - val_loss: 0.4280 - val_accuracy: 0.9256
# Epoch 58/60
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0572 - accuracy: 0.9822 - val_loss: 0.4299 - val_accuracy: 0.9160
# Epoch 59/60
# 8/8 [==============================] - 2s 207ms/step - loss: 0.0501 - accuracy: 0.9854 - val_loss: 0.4082 - val_accuracy: 0.9171
# Epoch 60/60
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0466 - accuracy: 0.9841 - val_loss: 0.3987 - val_accuracy: 0.9245

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0191 - accuracy: 0.9971
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3987 - accuracy: 0.9245
# 0.9970775842666626 0.924548327922821

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 872, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:09:18

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_test_north_predict_map.png", bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen, open("./plots/CNN_Model2_spatial_train_north_test_north_predict_map.pickle", "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 140   0   0   0   0   0   0]
#  [  0   0   0 124   0   0   0   0   0]
#  [  0   0   0   0 313   5   0   2   0]
#  [  0   0   0   0   2 103  13   1   1]
#  [  0   0   1   0   5   9  31   1   3]
#  [  0   0   0   0   5   8   1  36   0]
#  [  0   0   0   0   4   6   2   2  23]]
#
# Accuracy Score
# 0.924548352816153
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      1.00      1.00       140
#       water       1.00      1.00      1.00       124
#       built       0.95      0.98      0.96       320
#     windows       0.79      0.86      0.82       120
#       roads       0.66      0.62      0.64        50
#        cars       0.86      0.72      0.78        50
#       metal       0.85      0.62      0.72        37
#
# avg / total       0.92      0.92      0.92       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_test_north_metrics.txt", "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_norm = (cube_reshaped - cube_reshaped.min()) / (cube_reshaped.max() - cube_reshaped.min())

import matplotlib.pyplot as plt
# %matplotlib inline

red_ind = (np.abs(cube.waves - 650.0)).argmin()
green_ind = (np.abs(cube.waves - 550.0)).argmin()
blue_ind = (np.abs(cube.waves - 450.0)).argmin()

cube_reshaped2 = cube_norm.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
cube_scene = cube_reshaped2[:, :, [red_ind, green_ind, blue_ind]]
fig, ax = plt.subplots(figsize=(10,10))
plt.title('veg_00108 RGB Image')
ax.imshow(cube_scene, aspect=0.5)
plt.show()

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 848)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 848) (60, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (480, 848) (120, 848)
# water  (40, 848) (10, 848)
# built  (816, 848) (204, 848)
# windows  (400, 848) (100, 848)
# roads  (24, 848) (6, 848)
# cars  (80, 848) (20, 848)
# metal  (80, 848) (20, 848)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 848) (2560,) (2560, 2)
# (640, 848) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 252ms/step - loss: 1.7538 - accuracy: 0.3863 - val_loss: 1.1972 - val_accuracy: 0.6375
# Epoch 2/200
# 5/5 [==============================] - 1s 173ms/step - loss: 1.0231 - accuracy: 0.6961 - val_loss: 0.7784 - val_accuracy: 0.7594
# Epoch 3/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.7838 - accuracy: 0.7488 - val_loss: 0.6526 - val_accuracy: 0.8188
# Epoch 4/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.6600 - accuracy: 0.8039 - val_loss: 0.5872 - val_accuracy: 0.8453
# Epoch 5/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.5849 - accuracy: 0.8266 - val_loss: 0.5037 - val_accuracy: 0.8625
# Epoch 6/200
# 5/5 [==============================] - 1s 237ms/step - loss: 0.4985 - accuracy: 0.8512 - val_loss: 0.4340 - val_accuracy: 0.8750
# Epoch 7/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.4479 - accuracy: 0.8613 - val_loss: 0.3962 - val_accuracy: 0.8813
# Epoch 8/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.4266 - accuracy: 0.8594 - val_loss: 0.4168 - val_accuracy: 0.8578
# Epoch 9/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.4088 - accuracy: 0.8715 - val_loss: 0.3438 - val_accuracy: 0.9000
# Epoch 10/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.3784 - accuracy: 0.8867 - val_loss: 0.3342 - val_accuracy: 0.9047
# Epoch 11/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.3719 - accuracy: 0.8863 - val_loss: 0.3478 - val_accuracy: 0.9062
# Epoch 12/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.3632 - accuracy: 0.8895 - val_loss: 0.3171 - val_accuracy: 0.9062
# Epoch 13/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.3363 - accuracy: 0.8914 - val_loss: 0.3112 - val_accuracy: 0.9000
# Epoch 14/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.3105 - accuracy: 0.9031 - val_loss: 0.2834 - val_accuracy: 0.9125
# Epoch 15/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.2926 - accuracy: 0.9090 - val_loss: 0.2762 - val_accuracy: 0.9141
# Epoch 16/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.2846 - accuracy: 0.9129 - val_loss: 0.2755 - val_accuracy: 0.9031
# Epoch 17/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.2807 - accuracy: 0.9105 - val_loss: 0.2836 - val_accuracy: 0.9094
# Epoch 18/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.3001 - accuracy: 0.9098 - val_loss: 0.2987 - val_accuracy: 0.9031
# Epoch 19/200
# 5/5 [==============================] - 1s 237ms/step - loss: 0.2848 - accuracy: 0.9148 - val_loss: 0.2589 - val_accuracy: 0.9125
# Epoch 20/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.2602 - accuracy: 0.9156 - val_loss: 0.2486 - val_accuracy: 0.9281
# Epoch 21/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.2561 - accuracy: 0.9254 - val_loss: 0.2466 - val_accuracy: 0.9234
# Epoch 22/200
# 5/5 [==============================] - 1s 272ms/step - loss: 0.2454 - accuracy: 0.9250 - val_loss: 0.2361 - val_accuracy: 0.9234
# Epoch 23/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.2483 - accuracy: 0.9199 - val_loss: 0.2277 - val_accuracy: 0.9281
# Epoch 24/200
# 5/5 [==============================] - 1s 222ms/step - loss: 0.2440 - accuracy: 0.9223 - val_loss: 0.2408 - val_accuracy: 0.9266
# Epoch 25/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.2419 - accuracy: 0.9199 - val_loss: 0.2377 - val_accuracy: 0.9359
# Epoch 26/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.2399 - accuracy: 0.9258 - val_loss: 0.2155 - val_accuracy: 0.9266
# Epoch 27/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.2225 - accuracy: 0.9238 - val_loss: 0.2181 - val_accuracy: 0.9297
# Epoch 28/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.2192 - accuracy: 0.9328 - val_loss: 0.2179 - val_accuracy: 0.9312
# Epoch 29/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2195 - accuracy: 0.9281 - val_loss: 0.2126 - val_accuracy: 0.9219
# Epoch 30/200
# 5/5 [==============================] - 1s 266ms/step - loss: 0.2092 - accuracy: 0.9293 - val_loss: 0.2111 - val_accuracy: 0.9328
# Epoch 31/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.1967 - accuracy: 0.9328 - val_loss: 0.2104 - val_accuracy: 0.9250
# Epoch 32/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.2142 - accuracy: 0.9316 - val_loss: 0.1983 - val_accuracy: 0.9344
# Epoch 33/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.1967 - accuracy: 0.9340 - val_loss: 0.1982 - val_accuracy: 0.9312
# Epoch 34/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1932 - accuracy: 0.9348 - val_loss: 0.2100 - val_accuracy: 0.9391
# Epoch 35/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2292 - accuracy: 0.9246 - val_loss: 0.2515 - val_accuracy: 0.9109
# Epoch 36/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.3300 - accuracy: 0.8855 - val_loss: 0.3613 - val_accuracy: 0.8750
# Epoch 37/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.2783 - accuracy: 0.9066 - val_loss: 0.2766 - val_accuracy: 0.9234
# Epoch 38/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.2567 - accuracy: 0.9148 - val_loss: 0.2116 - val_accuracy: 0.9312
# Epoch 39/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.2261 - accuracy: 0.9293 - val_loss: 0.2307 - val_accuracy: 0.9141
# Epoch 40/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.2223 - accuracy: 0.9301 - val_loss: 0.2213 - val_accuracy: 0.9187
# Epoch 41/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.2024 - accuracy: 0.9363 - val_loss: 0.1929 - val_accuracy: 0.9375
# Epoch 42/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1965 - accuracy: 0.9344 - val_loss: 0.1968 - val_accuracy: 0.9438
# Epoch 43/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.1818 - accuracy: 0.9422 - val_loss: 0.1678 - val_accuracy: 0.9391
# Epoch 44/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.1872 - accuracy: 0.9410 - val_loss: 0.1812 - val_accuracy: 0.9375
# Epoch 45/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.1724 - accuracy: 0.9410 - val_loss: 0.1970 - val_accuracy: 0.9266
# Epoch 46/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.1764 - accuracy: 0.9414 - val_loss: 0.1647 - val_accuracy: 0.9422
# Epoch 47/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.1673 - accuracy: 0.9426 - val_loss: 0.1563 - val_accuracy: 0.9391
# Epoch 48/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.1592 - accuracy: 0.9457 - val_loss: 0.1551 - val_accuracy: 0.9500
# Epoch 49/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.1530 - accuracy: 0.9500 - val_loss: 0.1473 - val_accuracy: 0.9500
# Epoch 50/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1540 - accuracy: 0.9465 - val_loss: 0.1520 - val_accuracy: 0.9500
# Epoch 51/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.1457 - accuracy: 0.9496 - val_loss: 0.1603 - val_accuracy: 0.9469
# Epoch 52/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.1470 - accuracy: 0.9504 - val_loss: 0.1460 - val_accuracy: 0.9438
# Epoch 53/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.1392 - accuracy: 0.9531 - val_loss: 0.1434 - val_accuracy: 0.9469
# Epoch 54/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.1297 - accuracy: 0.9566 - val_loss: 0.1290 - val_accuracy: 0.9625
# Epoch 55/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.1376 - accuracy: 0.9547 - val_loss: 0.1351 - val_accuracy: 0.9531
# Epoch 56/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.1384 - accuracy: 0.9555 - val_loss: 0.1359 - val_accuracy: 0.9516
# Epoch 57/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.1337 - accuracy: 0.9555 - val_loss: 0.1566 - val_accuracy: 0.9453
# Epoch 58/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.1392 - accuracy: 0.9539 - val_loss: 0.1704 - val_accuracy: 0.9375
# Epoch 59/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.1440 - accuracy: 0.9500 - val_loss: 0.1458 - val_accuracy: 0.9484
# Epoch 60/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1388 - accuracy: 0.9523 - val_loss: 0.1378 - val_accuracy: 0.9531
# Epoch 61/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1347 - accuracy: 0.9559 - val_loss: 0.1429 - val_accuracy: 0.9469
# Epoch 62/200
# 5/5 [==============================] - 1s 254ms/step - loss: 0.1334 - accuracy: 0.9508 - val_loss: 0.1430 - val_accuracy: 0.9484
# Epoch 63/200
# 5/5 [==============================] - 1s 234ms/step - loss: 0.1343 - accuracy: 0.9547 - val_loss: 0.1313 - val_accuracy: 0.9469
# Epoch 64/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.1268 - accuracy: 0.9598 - val_loss: 0.1669 - val_accuracy: 0.9438
# Epoch 65/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.1350 - accuracy: 0.9488 - val_loss: 0.1440 - val_accuracy: 0.9563
# Epoch 66/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.1377 - accuracy: 0.9492 - val_loss: 0.1364 - val_accuracy: 0.9563
# Epoch 67/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.1259 - accuracy: 0.9559 - val_loss: 0.1198 - val_accuracy: 0.9563
# Epoch 68/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1176 - accuracy: 0.9613 - val_loss: 0.1186 - val_accuracy: 0.9578
# Epoch 69/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.1128 - accuracy: 0.9625 - val_loss: 0.1276 - val_accuracy: 0.9578
# Epoch 70/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.1186 - accuracy: 0.9563 - val_loss: 0.1147 - val_accuracy: 0.9578
# Epoch 71/200
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1192 - accuracy: 0.9578 - val_loss: 0.1317 - val_accuracy: 0.9563
# Epoch 72/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1092 - accuracy: 0.9648 - val_loss: 0.1176 - val_accuracy: 0.9594
# Epoch 73/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.1091 - accuracy: 0.9598 - val_loss: 0.1111 - val_accuracy: 0.9641
# Epoch 74/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.1027 - accuracy: 0.9672 - val_loss: 0.1109 - val_accuracy: 0.9641
# Epoch 75/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.1056 - accuracy: 0.9621 - val_loss: 0.1192 - val_accuracy: 0.9609
# Epoch 76/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1126 - accuracy: 0.9613 - val_loss: 0.1257 - val_accuracy: 0.9641
# Epoch 77/200
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0962 - accuracy: 0.9703 - val_loss: 0.1066 - val_accuracy: 0.9656
# Epoch 78/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0991 - accuracy: 0.9664 - val_loss: 0.1298 - val_accuracy: 0.9531
# Epoch 79/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1059 - accuracy: 0.9605 - val_loss: 0.1252 - val_accuracy: 0.9500
# Epoch 80/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1011 - accuracy: 0.9652 - val_loss: 0.1356 - val_accuracy: 0.9484
# Epoch 81/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.1052 - accuracy: 0.9641 - val_loss: 0.1166 - val_accuracy: 0.9641
# Epoch 82/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0869 - accuracy: 0.9703 - val_loss: 0.1168 - val_accuracy: 0.9563
# Epoch 83/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0900 - accuracy: 0.9688 - val_loss: 0.1232 - val_accuracy: 0.9500
# Epoch 84/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.1020 - accuracy: 0.9684 - val_loss: 0.1334 - val_accuracy: 0.9469
# Epoch 85/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0969 - accuracy: 0.9676 - val_loss: 0.1141 - val_accuracy: 0.9578
# Epoch 86/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0965 - accuracy: 0.9684 - val_loss: 0.1279 - val_accuracy: 0.9563
# Epoch 87/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0967 - accuracy: 0.9676 - val_loss: 0.1110 - val_accuracy: 0.9625
# Epoch 88/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0975 - accuracy: 0.9688 - val_loss: 0.1366 - val_accuracy: 0.9594
# Epoch 89/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.1024 - accuracy: 0.9652 - val_loss: 0.1159 - val_accuracy: 0.9609
# Epoch 90/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.1092 - accuracy: 0.9637 - val_loss: 0.1201 - val_accuracy: 0.9609
# Epoch 91/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.1010 - accuracy: 0.9641 - val_loss: 0.1234 - val_accuracy: 0.9641
# Epoch 92/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0908 - accuracy: 0.9695 - val_loss: 0.0952 - val_accuracy: 0.9719
# Epoch 93/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0779 - accuracy: 0.9758 - val_loss: 0.1036 - val_accuracy: 0.9656
# Epoch 94/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0772 - accuracy: 0.9754 - val_loss: 0.0891 - val_accuracy: 0.9703
# Epoch 95/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0789 - accuracy: 0.9730 - val_loss: 0.0940 - val_accuracy: 0.9703
# Epoch 96/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0812 - accuracy: 0.9711 - val_loss: 0.0943 - val_accuracy: 0.9641
# Epoch 97/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0769 - accuracy: 0.9711 - val_loss: 0.1000 - val_accuracy: 0.9609
# Epoch 98/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0731 - accuracy: 0.9738 - val_loss: 0.0858 - val_accuracy: 0.9703
# Epoch 99/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0774 - accuracy: 0.9719 - val_loss: 0.1257 - val_accuracy: 0.9563
# Epoch 100/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0939 - accuracy: 0.9668 - val_loss: 0.1230 - val_accuracy: 0.9656
# Epoch 101/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0827 - accuracy: 0.9738 - val_loss: 0.1057 - val_accuracy: 0.9656
# Epoch 102/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0744 - accuracy: 0.9762 - val_loss: 0.0952 - val_accuracy: 0.9719
# Epoch 103/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0766 - accuracy: 0.9715 - val_loss: 0.0988 - val_accuracy: 0.9641
# Epoch 104/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0803 - accuracy: 0.9715 - val_loss: 0.1038 - val_accuracy: 0.9656
# Epoch 105/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0789 - accuracy: 0.9719 - val_loss: 0.0980 - val_accuracy: 0.9672
# Epoch 106/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0802 - accuracy: 0.9699 - val_loss: 0.0964 - val_accuracy: 0.9656
# Epoch 107/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0795 - accuracy: 0.9727 - val_loss: 0.0912 - val_accuracy: 0.9688
# Epoch 108/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0785 - accuracy: 0.9750 - val_loss: 0.0921 - val_accuracy: 0.9750
# Epoch 109/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0619 - accuracy: 0.9824 - val_loss: 0.0870 - val_accuracy: 0.9703
# Epoch 110/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 0.0889 - val_accuracy: 0.9734
# Epoch 111/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0711 - accuracy: 0.9742 - val_loss: 0.0967 - val_accuracy: 0.9719
# Epoch 112/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0721 - accuracy: 0.9715 - val_loss: 0.0993 - val_accuracy: 0.9719
# Epoch 113/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0787 - accuracy: 0.9723 - val_loss: 0.1012 - val_accuracy: 0.9703
# Epoch 114/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0715 - accuracy: 0.9777 - val_loss: 0.0928 - val_accuracy: 0.9719
# Epoch 115/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0675 - accuracy: 0.9797 - val_loss: 0.0921 - val_accuracy: 0.9656
# Epoch 116/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0575 - accuracy: 0.9789 - val_loss: 0.0973 - val_accuracy: 0.9703
# Epoch 117/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0670 - accuracy: 0.9750 - val_loss: 0.0938 - val_accuracy: 0.9703
# Epoch 118/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0561 - accuracy: 0.9816 - val_loss: 0.0902 - val_accuracy: 0.9734
# Epoch 119/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0629 - accuracy: 0.9809 - val_loss: 0.0949 - val_accuracy: 0.9672
# Epoch 120/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0633 - accuracy: 0.9777 - val_loss: 0.0888 - val_accuracy: 0.9719
# Epoch 121/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0618 - accuracy: 0.9746 - val_loss: 0.0878 - val_accuracy: 0.9672
# Epoch 122/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0586 - accuracy: 0.9773 - val_loss: 0.0946 - val_accuracy: 0.9688
# Epoch 123/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0530 - accuracy: 0.9809 - val_loss: 0.0772 - val_accuracy: 0.9781
# Epoch 124/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0571 - accuracy: 0.9832 - val_loss: 0.0882 - val_accuracy: 0.9703
# Epoch 125/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0543 - accuracy: 0.9805 - val_loss: 0.0902 - val_accuracy: 0.9703
# Epoch 126/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0539 - accuracy: 0.9812 - val_loss: 0.0849 - val_accuracy: 0.9766
# Epoch 127/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0556 - accuracy: 0.9812 - val_loss: 0.0855 - val_accuracy: 0.9750
# Epoch 128/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0548 - accuracy: 0.9824 - val_loss: 0.0827 - val_accuracy: 0.9734
# Epoch 129/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0625 - accuracy: 0.9785 - val_loss: 0.0925 - val_accuracy: 0.9672
# Epoch 130/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0587 - accuracy: 0.9805 - val_loss: 0.0868 - val_accuracy: 0.9719
# Epoch 131/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0596 - accuracy: 0.9793 - val_loss: 0.0863 - val_accuracy: 0.9719
# Epoch 132/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0495 - accuracy: 0.9848 - val_loss: 0.0827 - val_accuracy: 0.9734
# Epoch 133/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0553 - accuracy: 0.9789 - val_loss: 0.0877 - val_accuracy: 0.9766
# Epoch 134/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0626 - accuracy: 0.9781 - val_loss: 0.0816 - val_accuracy: 0.9750
# Epoch 135/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0562 - accuracy: 0.9789 - val_loss: 0.0860 - val_accuracy: 0.9719
# Epoch 136/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0707 - accuracy: 0.9734 - val_loss: 0.0991 - val_accuracy: 0.9703
# Epoch 137/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0749 - accuracy: 0.9727 - val_loss: 0.1034 - val_accuracy: 0.9656
# Epoch 138/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0693 - accuracy: 0.9762 - val_loss: 0.0977 - val_accuracy: 0.9641
# Epoch 139/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0658 - accuracy: 0.9797 - val_loss: 0.0849 - val_accuracy: 0.9703
# Epoch 140/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0595 - accuracy: 0.9820 - val_loss: 0.1064 - val_accuracy: 0.9688
# Epoch 141/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0578 - accuracy: 0.9793 - val_loss: 0.1014 - val_accuracy: 0.9672
# Epoch 142/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0522 - accuracy: 0.9805 - val_loss: 0.0908 - val_accuracy: 0.9656
# Epoch 143/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0520 - accuracy: 0.9840 - val_loss: 0.0849 - val_accuracy: 0.9750
# Epoch 144/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0498 - accuracy: 0.9844 - val_loss: 0.0825 - val_accuracy: 0.9734
# Epoch 145/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0410 - accuracy: 0.9883 - val_loss: 0.0906 - val_accuracy: 0.9688
# Epoch 146/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0536 - accuracy: 0.9824 - val_loss: 0.0903 - val_accuracy: 0.9719
# Epoch 147/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0442 - accuracy: 0.9883 - val_loss: 0.0782 - val_accuracy: 0.9781
# Epoch 148/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0463 - accuracy: 0.9840 - val_loss: 0.0964 - val_accuracy: 0.9719
# Epoch 149/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0406 - accuracy: 0.9867 - val_loss: 0.0754 - val_accuracy: 0.9734
# Epoch 150/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0411 - accuracy: 0.9891 - val_loss: 0.0851 - val_accuracy: 0.9719
# Epoch 151/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0409 - accuracy: 0.9875 - val_loss: 0.0819 - val_accuracy: 0.9719
# Epoch 152/200
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0420 - accuracy: 0.9875 - val_loss: 0.0891 - val_accuracy: 0.9719
# Epoch 153/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0579 - accuracy: 0.9797 - val_loss: 0.0852 - val_accuracy: 0.9734
# Epoch 154/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0434 - accuracy: 0.9867 - val_loss: 0.0905 - val_accuracy: 0.9672
# Epoch 155/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0577 - accuracy: 0.9816 - val_loss: 0.0953 - val_accuracy: 0.9656
# Epoch 156/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0493 - accuracy: 0.9855 - val_loss: 0.1074 - val_accuracy: 0.9641
# Epoch 157/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0418 - accuracy: 0.9863 - val_loss: 0.0953 - val_accuracy: 0.9688
# Epoch 158/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0455 - accuracy: 0.9852 - val_loss: 0.0810 - val_accuracy: 0.9719
# Epoch 159/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0369 - accuracy: 0.9887 - val_loss: 0.0739 - val_accuracy: 0.9734
# Epoch 160/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0409 - accuracy: 0.9863 - val_loss: 0.0783 - val_accuracy: 0.9719
# Epoch 161/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0469 - accuracy: 0.9863 - val_loss: 0.0898 - val_accuracy: 0.9750
# Epoch 162/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0453 - accuracy: 0.9848 - val_loss: 0.0831 - val_accuracy: 0.9766
# Epoch 163/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0409 - accuracy: 0.9852 - val_loss: 0.0750 - val_accuracy: 0.9750
# Epoch 164/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0390 - accuracy: 0.9879 - val_loss: 0.0894 - val_accuracy: 0.9781
# Epoch 165/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0455 - accuracy: 0.9859 - val_loss: 0.0823 - val_accuracy: 0.9750
# Epoch 166/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0407 - accuracy: 0.9887 - val_loss: 0.0754 - val_accuracy: 0.9750
# Epoch 167/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.0787 - val_accuracy: 0.9688
# Epoch 168/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0369 - accuracy: 0.9906 - val_loss: 0.0789 - val_accuracy: 0.9781
# Epoch 169/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0344 - accuracy: 0.9883 - val_loss: 0.0765 - val_accuracy: 0.9766
# Epoch 170/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0298 - accuracy: 0.9918 - val_loss: 0.0865 - val_accuracy: 0.9750
# Epoch 171/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0287 - accuracy: 0.9930 - val_loss: 0.0740 - val_accuracy: 0.9734
# Epoch 172/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0300 - accuracy: 0.9922 - val_loss: 0.0772 - val_accuracy: 0.9734
# Epoch 173/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.0920 - val_accuracy: 0.9703
# Epoch 174/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.0764 - val_accuracy: 0.9781
# Epoch 175/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0272 - accuracy: 0.9906 - val_loss: 0.0768 - val_accuracy: 0.9734
# Epoch 176/200
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0309 - accuracy: 0.9914 - val_loss: 0.0768 - val_accuracy: 0.9781
# Epoch 177/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0263 - accuracy: 0.9937 - val_loss: 0.0818 - val_accuracy: 0.9750
# Epoch 178/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0316 - accuracy: 0.9914 - val_loss: 0.0880 - val_accuracy: 0.9734
# Epoch 179/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0285 - accuracy: 0.9906 - val_loss: 0.0843 - val_accuracy: 0.9703
# Epoch 180/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0347 - accuracy: 0.9895 - val_loss: 0.0830 - val_accuracy: 0.9766
# Epoch 181/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0300 - accuracy: 0.9918 - val_loss: 0.0806 - val_accuracy: 0.9766
# Epoch 182/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0312 - accuracy: 0.9914 - val_loss: 0.0838 - val_accuracy: 0.9750
# Epoch 183/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0289 - accuracy: 0.9895 - val_loss: 0.0883 - val_accuracy: 0.9688
# Epoch 184/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0345 - accuracy: 0.9902 - val_loss: 0.0902 - val_accuracy: 0.9688
# Epoch 185/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0308 - accuracy: 0.9902 - val_loss: 0.0932 - val_accuracy: 0.9766
# Epoch 186/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0283 - accuracy: 0.9937 - val_loss: 0.0953 - val_accuracy: 0.9703
# Epoch 187/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0295 - accuracy: 0.9898 - val_loss: 0.0966 - val_accuracy: 0.9703
# Epoch 188/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0392 - accuracy: 0.9855 - val_loss: 0.0797 - val_accuracy: 0.9688
# Epoch 189/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0285 - accuracy: 0.9926 - val_loss: 0.0766 - val_accuracy: 0.9766
# Epoch 190/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.0773 - val_accuracy: 0.9719
# Epoch 191/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.0852 - val_accuracy: 0.9766
# Epoch 192/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0246 - accuracy: 0.9914 - val_loss: 0.0792 - val_accuracy: 0.9688
# Epoch 193/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0290 - accuracy: 0.9926 - val_loss: 0.0777 - val_accuracy: 0.9672
# Epoch 194/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0265 - accuracy: 0.9902 - val_loss: 0.0720 - val_accuracy: 0.9812
# Epoch 195/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0254 - accuracy: 0.9934 - val_loss: 0.0845 - val_accuracy: 0.9766
# Epoch 196/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0771 - val_accuracy: 0.9766
# Epoch 197/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0186 - accuracy: 0.9957 - val_loss: 0.0826 - val_accuracy: 0.9734
# Epoch 198/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.1197 - val_accuracy: 0.9641
# Epoch 199/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0295 - accuracy: 0.9902 - val_loss: 0.0783 - val_accuracy: 0.9703
# Epoch 200/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.0927 - val_accuracy: 0.9703

# %%
plot_loss_history(CNNmodel)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=70, batch_size=512)
# Out:
# Epoch 1/70
# 5/5 [==============================] - 2s 348ms/step - loss: 0.0221 - accuracy: 0.9949 - val_loss: 0.0730 - val_accuracy: 0.9781
# Epoch 2/70
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.0813 - val_accuracy: 0.9750
# Epoch 3/70
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0321 - accuracy: 0.9879 - val_loss: 0.0834 - val_accuracy: 0.9766
# Epoch 4/70
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0453 - accuracy: 0.9828 - val_loss: 0.0936 - val_accuracy: 0.9766
# Epoch 5/70
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0389 - accuracy: 0.9875 - val_loss: 0.1196 - val_accuracy: 0.9594
# Epoch 6/70
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0513 - accuracy: 0.9809 - val_loss: 0.0872 - val_accuracy: 0.9719
# Epoch 7/70
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0369 - accuracy: 0.9879 - val_loss: 0.0949 - val_accuracy: 0.9609
# Epoch 8/70
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.0866 - val_accuracy: 0.9734
# Epoch 9/70
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0310 - accuracy: 0.9922 - val_loss: 0.0872 - val_accuracy: 0.9750
# Epoch 10/70
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.0889 - val_accuracy: 0.9734
# Epoch 11/70
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0248 - accuracy: 0.9898 - val_loss: 0.0811 - val_accuracy: 0.9734
# Epoch 12/70
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0274 - accuracy: 0.9906 - val_loss: 0.0864 - val_accuracy: 0.9703
# Epoch 13/70
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0281 - accuracy: 0.9895 - val_loss: 0.1010 - val_accuracy: 0.9766
# Epoch 14/70
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0305 - accuracy: 0.9910 - val_loss: 0.0816 - val_accuracy: 0.9734
# Epoch 15/70
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0365 - accuracy: 0.9879 - val_loss: 0.0967 - val_accuracy: 0.9672
# Epoch 16/70
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0399 - accuracy: 0.9848 - val_loss: 0.0967 - val_accuracy: 0.9703
# Epoch 17/70
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0379 - accuracy: 0.9887 - val_loss: 0.0936 - val_accuracy: 0.9688
# Epoch 18/70
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0279 - accuracy: 0.9914 - val_loss: 0.0823 - val_accuracy: 0.9750
# Epoch 19/70
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.0929 - val_accuracy: 0.9719
# Epoch 20/70
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.1093 - val_accuracy: 0.9672
# Epoch 21/70
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0326 - accuracy: 0.9883 - val_loss: 0.1085 - val_accuracy: 0.9672
# Epoch 22/70
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0446 - accuracy: 0.9816 - val_loss: 0.0983 - val_accuracy: 0.9688
# Epoch 23/70
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0355 - accuracy: 0.9902 - val_loss: 0.0888 - val_accuracy: 0.9719
# Epoch 24/70
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0349 - accuracy: 0.9875 - val_loss: 0.0791 - val_accuracy: 0.9703
# Epoch 25/70
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0310 - accuracy: 0.9906 - val_loss: 0.0859 - val_accuracy: 0.9688
# Epoch 26/70
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0239 - accuracy: 0.9945 - val_loss: 0.0798 - val_accuracy: 0.9781
# Epoch 27/70
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.0816 - val_accuracy: 0.9719
# Epoch 28/70
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0236 - accuracy: 0.9906 - val_loss: 0.0778 - val_accuracy: 0.9719
# Epoch 29/70
# 5/5 [==============================] - 1s 223ms/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 0.0986 - val_accuracy: 0.9719
# Epoch 30/70
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0195 - accuracy: 0.9949 - val_loss: 0.0898 - val_accuracy: 0.9734
# Epoch 31/70
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0189 - accuracy: 0.9930 - val_loss: 0.0830 - val_accuracy: 0.9734
# Epoch 32/70
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.0819 - val_accuracy: 0.9766
# Epoch 33/70
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.0834 - val_accuracy: 0.9781
# Epoch 34/70
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0174 - accuracy: 0.9945 - val_loss: 0.0869 - val_accuracy: 0.9781
# Epoch 35/70
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0815 - val_accuracy: 0.9812
# Epoch 36/70
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0134 - accuracy: 0.9973 - val_loss: 0.0887 - val_accuracy: 0.9750
# Epoch 37/70
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 0.0978 - val_accuracy: 0.9734
# Epoch 38/70
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0983 - val_accuracy: 0.9766
# Epoch 39/70
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.0984 - val_accuracy: 0.9703
# Epoch 40/70
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0865 - val_accuracy: 0.9812
# Epoch 41/70
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0186 - accuracy: 0.9949 - val_loss: 0.0907 - val_accuracy: 0.9734
# Epoch 42/70
# 5/5 [==============================] - 1s 272ms/step - loss: 0.0174 - accuracy: 0.9934 - val_loss: 0.0794 - val_accuracy: 0.9766
# Epoch 43/70
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0192 - accuracy: 0.9930 - val_loss: 0.1123 - val_accuracy: 0.9656
# Epoch 44/70
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.0815 - val_accuracy: 0.9766
# Epoch 45/70
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0158 - accuracy: 0.9965 - val_loss: 0.0952 - val_accuracy: 0.9688
# Epoch 46/70
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.0922 - val_accuracy: 0.9719
# Epoch 47/70
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0906 - val_accuracy: 0.9734
# Epoch 48/70
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0847 - val_accuracy: 0.9750
# Epoch 49/70
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.0891 - val_accuracy: 0.9766
# Epoch 50/70
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0818 - val_accuracy: 0.9781
# Epoch 51/70
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0119 - accuracy: 0.9973 - val_loss: 0.0885 - val_accuracy: 0.9766
# Epoch 52/70
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0859 - val_accuracy: 0.9797
# Epoch 53/70
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0858 - val_accuracy: 0.9781
# Epoch 54/70
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.0829 - val_accuracy: 0.9812
# Epoch 55/70
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.0937 - val_accuracy: 0.9719
# Epoch 56/70
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.0865 - val_accuracy: 0.9781
# Epoch 57/70
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.0842 - val_accuracy: 0.9766
# Epoch 58/70
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0860 - val_accuracy: 0.9750
# Epoch 59/70
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 0.0875 - val_accuracy: 0.9797
# Epoch 60/70
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0100 - accuracy: 0.9977 - val_loss: 0.0884 - val_accuracy: 0.9781
# Epoch 61/70
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0981 - val_accuracy: 0.9719
# Epoch 62/70
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0153 - accuracy: 0.9945 - val_loss: 0.0864 - val_accuracy: 0.9703
# Epoch 63/70
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0817 - val_accuracy: 0.9797
# Epoch 64/70
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0880 - val_accuracy: 0.9812
# Epoch 65/70
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0101 - accuracy: 0.9977 - val_loss: 0.0850 - val_accuracy: 0.9750
# Epoch 66/70
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0102 - accuracy: 0.9984 - val_loss: 0.0946 - val_accuracy: 0.9734
# Epoch 67/70
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.0841 - val_accuracy: 0.9781
# Epoch 68/70
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.1140 - val_accuracy: 0.9719
# Epoch 69/70
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.0820 - val_accuracy: 0.9766
# Epoch 70/70
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.0846 - val_accuracy: 0.9812

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 1s 9ms/step - loss: 0.0030 - accuracy: 0.9996
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0846 - accuracy: 0.9812
# 0.9996093511581421 0.981249988079071

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 848, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:11:01

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.png", bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape, open("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.pickle", "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 120   0   0   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 202   0   0   1   1]
#  [  0   0   1   0   2  97   0   0   0]
#  [  0   0   0   0   0   0   6   0   0]
#  [  0   0   0   0   0   1   0  18   1]
#  [  0   0   0   0   4   0   0   0  16]]
#
# Accuracy Score
# 0.98125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       0.99      1.00      1.00       120
#       water       1.00      1.00      1.00        10
#       built       0.97      0.99      0.98       204
#     windows       0.99      0.97      0.98       100
#       roads       1.00      1.00      1.00         6
#        cars       0.95      0.90      0.92        20
#       metal       0.89      0.80      0.84        20
#
# avg / total       0.98      0.98      0.98       640

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_test_108_metrics.txt", "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %%
# plot mean spectra for testing set separately

import matplotlib.pyplot as plt
import matplotlib
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 15
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 15
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

f, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(14, 10))
ax1.plot(cube.waves, cube_standard[np.where(predictCube == 0)].T, color=[0,0,0,1], lw=0.001)
ax1.plot(cube.waves, cube_sky_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax1.plot(cube.waves, cube_sky_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax1.text(900, 2, 'sky')
ax1.set_ylabel('amplitude')
ax1.set_ylim(-2, 3)

ax2.plot(cube.waves, cube_standard[np.where(predictCube == 1)].T, color=[0,0,0,1], lw=0.001)
ax2.plot(cube.waves, cube_clouds_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax2.plot(cube.waves, cube_clouds_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax2.text(850, 2, 'clouds')
ax2.set_ylim(-2, 3)

ax3.plot(cube.waves, cube_standard[np.where(predictCube == 2)].T, color=[0,0,0,1], lw=0.001)
ax3.plot(cube.waves, cube_veg_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax3.plot(cube.waves, cube_veg_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax3.text(800, 2, 'vegetation')
ax3.set_ylim(-2, 3)

ax4.plot(cube.waves, cube_standard[np.where(predictCube == 3)].T, color=[0,0,0,1], lw=0.001)
ax4.plot(cube.waves, cube_wtr_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax4.plot(cube.waves, cube_wtr_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax4.text(850, 2, 'water')
ax4.set_ylabel('amplitude')
ax4.set_ylim(-2, 3)

ax5.plot(cube.waves, cube_standard[np.where(predictCube == 4)].T, color=[0,0,0,1], lw=0.001)
ax5.plot(cube.waves, cube_blt_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax5.plot(cube.waves, cube_blt_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax5.text(870, 2, 'built')
ax5.set_ylim(-2, 3)

ax6.plot(cube.waves, cube_standard[np.where(predictCube == 5)].T, color=[0,0,0,1], lw=0.001)
ax6.plot(cube.waves, cube_windows_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax6.plot(cube.waves, cube_windows_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax6.text(800, 2, 'windows')
ax6.set_ylim(-2, 3)

ax7.plot(cube.waves, cube_standard[np.where(predictCube == 6)].T, color=[0,0,0,1], lw=0.1)
ax7.plot(cube.waves, cube_rds_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax7.plot(cube.waves, cube_rds_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax7.text(850, 2, 'roads')
ax7.set_xlabel('wavelength (nm)')
ax7.set_ylabel('amplitude')
ax7.set_ylim(-2, 3)

ax8.plot(cube.waves, cube_standard[np.where(predictCube == 7)].T, color=[0,0,0,1], lw=0.001)
ax8.plot(cube.waves, cube_cars_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax8.plot(cube.waves, cube_cars_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax8.set_xlabel('wavelength (nm)')
ax8.text(900, 2, 'cars')
ax8.set_ylim(-2, 3)

ax9.plot(cube.waves, cube_standard[np.where(predictCube == 8)].T, color=[0,0,0,1], lw=0.001)
ax9.plot(cube.waves, cube_mtl_train.mean(0), color=[1,0.82353,0,1], lw=3, ls='dashed')
ax9.plot(cube.waves, cube_mtl_test.mean(0), color=[0.33725,0.70588,0.91373,1], lw=1)
ax9.set_xlabel('wavelength (nm)')
ax9.text(850, 2, 'metal')
ax9.set_ylim(-2, 3)

legend_elements = [Line2D([0], [0], color=[1,0.82353,0,1], lw=3, ls='dashed', label='mean training set'),
                  Line2D([0], [0], color=[0.33725,0.70588,0.91373,1], lw=2, label='mean testing set'),
                  Line2D([0], [0], color=[0,0,0,1], lw=1, label='labelled by model')]
ax6.legend(handles=legend_elements, loc='center right', borderaxespad=-13, facecolor='white'
           ,edgecolor='black', framealpha=1)
plt.show()
#f.savefig("./plots/CNN_change_params_spatial_train_108_7_108_spectra_train_test_predict_3x3.png", bbox_inches='tight',
#         dpi=300)

# %%
f.savefig("./plots/CNN_Model2_spatial_train_108_test_108_spectra_train_test_predict_3x3.png", 
          bbox_inches='tight', dpi=300)
