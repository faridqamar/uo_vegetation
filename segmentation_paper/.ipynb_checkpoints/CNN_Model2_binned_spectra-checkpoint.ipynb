# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 170
filtersize = 10
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 170
# [[0, 4], [4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40], [40, 44], [44, 48], [48, 52], [52, 56], [56, 60], [60, 64], [64, 68], [68, 72], [72, 76], [76, 80], [80, 84], [84, 88], [88, 92], [92, 96], [96, 100], [100, 104], [104, 108], [108, 112], [112, 116], [116, 120], [120, 124], [124, 128], [128, 132], [132, 136], [136, 140], [140, 144], [144, 148], [148, 152], [152, 156], [156, 160], [160, 164], [164, 168], [168, 172], [172, 176], [176, 180], [180, 184], [184, 188], [188, 192], [192, 196], [196, 200], [200, 204], [204, 208], [208, 212], [212, 216], [216, 220], [220, 224], [224, 228], [228, 232], [232, 236], [236, 240], [240, 244], [244, 248], [248, 252], [252, 256], [256, 260], [260, 264], [264, 268], [268, 272], [272, 276], [276, 280], [280, 284], [284, 288], [288, 292], [292, 296], [296, 300], [300, 304], [304, 308], [308, 312], [312, 316], [316, 320], [320, 324], [324, 328], [328, 332], [332, 336], [336, 340], [340, 344], [344, 348], [348, 352], [352, 356], [356, 360], [360, 364], [364, 368], [368, 372], [372, 376], [376, 380], [380, 384], [384, 388], [388, 392], [392, 396], [396, 400], [400, 404], [404, 408], [408, 412], [412, 416], [416, 420], [420, 424], [424, 428], [428, 432], [432, 436], [436, 440], [440, 444], [444, 448], [448, 452], [452, 456], [456, 460], [460, 464], [464, 468], [468, 472], [472, 476], [476, 480], [480, 484], [484, 488], [488, 492], [492, 496], [496, 500], [500, 504], [504, 508], [508, 512], [512, 516], [516, 520], [520, 524], [524, 528], [528, 532], [532, 536], [536, 540], [540, 544], [544, 548], [548, 552], [552, 556], [556, 560], [560, 564], [564, 568], [568, 572], [572, 576], [576, 580], [580, 584], [584, 588], [588, 592], [592, 596], [596, 600], [600, 604], [604, 608], [608, 612], [612, 616], [616, 620], [620, 624], [624, 628], [628, 632], [632, 636], [636, 640], [640, 644], [644, 648], [648, 652], [652, 656], [656, 660], [660, 664], [664, 668], [668, 672], [672, 676], [676, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 170)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 170)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 170)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 170) (60, 170)
# clouds  (400, 170) (100, 170)
# vegetation  (480, 170) (120, 170)
# water  (40, 170) (10, 170)
# built  (816, 170) (204, 170)
# windows  (400, 170) (100, 170)
# roads  (24, 170) (6, 170)
# cars  (80, 170) (20, 170)
# metal  (80, 170) (20, 170)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 170) (2560,) (2560, 2)
# (640, 170) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6774 - accuracy: 0.4090 - val_loss: 1.2295 - val_accuracy: 0.6562
# Epoch 2/200
# 5/5 [==============================] - 0s 44ms/step - loss: 1.1044 - accuracy: 0.6746 - val_loss: 0.8657 - val_accuracy: 0.7297
# Epoch 3/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.8539 - accuracy: 0.7262 - val_loss: 0.7180 - val_accuracy: 0.8297
# Epoch 4/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7439 - accuracy: 0.7820 - val_loss: 0.6357 - val_accuracy: 0.8094
# Epoch 5/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.6564 - accuracy: 0.8137 - val_loss: 0.5821 - val_accuracy: 0.8219
# Epoch 6/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6136 - accuracy: 0.8230 - val_loss: 0.5396 - val_accuracy: 0.8328
# Epoch 7/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5629 - accuracy: 0.8285 - val_loss: 0.5103 - val_accuracy: 0.8344
# Epoch 8/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5390 - accuracy: 0.8363 - val_loss: 0.4614 - val_accuracy: 0.8734
# Epoch 9/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4928 - accuracy: 0.8449 - val_loss: 0.4476 - val_accuracy: 0.8594
# Epoch 10/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4757 - accuracy: 0.8473 - val_loss: 0.4108 - val_accuracy: 0.8797
# Epoch 11/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4452 - accuracy: 0.8590 - val_loss: 0.3963 - val_accuracy: 0.8766
# Epoch 12/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4166 - accuracy: 0.8719 - val_loss: 0.3765 - val_accuracy: 0.8766
# Epoch 13/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.4081 - accuracy: 0.8691 - val_loss: 0.3583 - val_accuracy: 0.8969
# Epoch 14/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4018 - accuracy: 0.8750 - val_loss: 0.3471 - val_accuracy: 0.9000
# Epoch 15/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3888 - accuracy: 0.8781 - val_loss: 0.3398 - val_accuracy: 0.9016
# Epoch 16/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3847 - accuracy: 0.8848 - val_loss: 0.3237 - val_accuracy: 0.9031
# Epoch 17/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3773 - accuracy: 0.8824 - val_loss: 0.3213 - val_accuracy: 0.9062
# Epoch 18/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3596 - accuracy: 0.8902 - val_loss: 0.3156 - val_accuracy: 0.9109
# Epoch 19/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3533 - accuracy: 0.8898 - val_loss: 0.3051 - val_accuracy: 0.9062
# Epoch 20/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3518 - accuracy: 0.8871 - val_loss: 0.3130 - val_accuracy: 0.9016
# Epoch 21/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3447 - accuracy: 0.8863 - val_loss: 0.2928 - val_accuracy: 0.9094
# Epoch 22/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3242 - accuracy: 0.8938 - val_loss: 0.2868 - val_accuracy: 0.9125
# Epoch 23/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3277 - accuracy: 0.8926 - val_loss: 0.2772 - val_accuracy: 0.9109
# Epoch 24/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3214 - accuracy: 0.8965 - val_loss: 0.2783 - val_accuracy: 0.9109
# Epoch 25/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3162 - accuracy: 0.8988 - val_loss: 0.2706 - val_accuracy: 0.9156
# Epoch 26/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3093 - accuracy: 0.8988 - val_loss: 0.2646 - val_accuracy: 0.9125
# Epoch 27/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2968 - accuracy: 0.9098 - val_loss: 0.2596 - val_accuracy: 0.9125
# Epoch 28/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3028 - accuracy: 0.8984 - val_loss: 0.2632 - val_accuracy: 0.9141
# Epoch 29/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2999 - accuracy: 0.9047 - val_loss: 0.2585 - val_accuracy: 0.9141
# Epoch 30/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2889 - accuracy: 0.9062 - val_loss: 0.2532 - val_accuracy: 0.9187
# Epoch 31/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2741 - accuracy: 0.9164 - val_loss: 0.2455 - val_accuracy: 0.9172
# Epoch 32/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2722 - accuracy: 0.9164 - val_loss: 0.2507 - val_accuracy: 0.9203
# Epoch 33/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2831 - accuracy: 0.9055 - val_loss: 0.2574 - val_accuracy: 0.9219
# Epoch 34/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.2793 - accuracy: 0.9117 - val_loss: 0.2308 - val_accuracy: 0.9187
# Epoch 35/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2614 - accuracy: 0.9156 - val_loss: 0.2295 - val_accuracy: 0.9219
# Epoch 36/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2583 - accuracy: 0.9176 - val_loss: 0.2386 - val_accuracy: 0.9172
# Epoch 37/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2544 - accuracy: 0.9164 - val_loss: 0.2274 - val_accuracy: 0.9281
# Epoch 38/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2589 - accuracy: 0.9156 - val_loss: 0.2204 - val_accuracy: 0.9219
# Epoch 39/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2578 - accuracy: 0.9164 - val_loss: 0.2234 - val_accuracy: 0.9203
# Epoch 40/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2613 - accuracy: 0.9121 - val_loss: 0.2210 - val_accuracy: 0.9219
# Epoch 41/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2434 - accuracy: 0.9203 - val_loss: 0.2152 - val_accuracy: 0.9203
# Epoch 42/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2493 - accuracy: 0.9184 - val_loss: 0.2153 - val_accuracy: 0.9203
# Epoch 43/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2566 - accuracy: 0.9156 - val_loss: 0.2544 - val_accuracy: 0.9109
# Epoch 44/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2584 - accuracy: 0.9141 - val_loss: 0.2125 - val_accuracy: 0.9234
# Epoch 45/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2413 - accuracy: 0.9215 - val_loss: 0.2094 - val_accuracy: 0.9219
# Epoch 46/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2378 - accuracy: 0.9203 - val_loss: 0.2100 - val_accuracy: 0.9234
# Epoch 47/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2359 - accuracy: 0.9242 - val_loss: 0.2088 - val_accuracy: 0.9250
# Epoch 48/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2291 - accuracy: 0.9246 - val_loss: 0.2025 - val_accuracy: 0.9281
# Epoch 49/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2281 - accuracy: 0.9273 - val_loss: 0.1970 - val_accuracy: 0.9219
# Epoch 50/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2316 - accuracy: 0.9270 - val_loss: 0.1944 - val_accuracy: 0.9344
# Epoch 51/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2208 - accuracy: 0.9281 - val_loss: 0.1903 - val_accuracy: 0.9312
# Epoch 52/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2183 - accuracy: 0.9266 - val_loss: 0.1872 - val_accuracy: 0.9266
# Epoch 53/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2123 - accuracy: 0.9270 - val_loss: 0.1859 - val_accuracy: 0.9312
# Epoch 54/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2065 - accuracy: 0.9309 - val_loss: 0.1955 - val_accuracy: 0.9250
# Epoch 55/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2082 - accuracy: 0.9273 - val_loss: 0.1948 - val_accuracy: 0.9328
# Epoch 56/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2198 - accuracy: 0.9293 - val_loss: 0.1887 - val_accuracy: 0.9266
# Epoch 57/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2229 - accuracy: 0.9203 - val_loss: 0.1833 - val_accuracy: 0.9312
# Epoch 58/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2095 - accuracy: 0.9293 - val_loss: 0.1840 - val_accuracy: 0.9406
# Epoch 59/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2065 - accuracy: 0.9340 - val_loss: 0.1808 - val_accuracy: 0.9250
# Epoch 60/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1937 - accuracy: 0.9367 - val_loss: 0.1763 - val_accuracy: 0.9312
# Epoch 61/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2048 - accuracy: 0.9258 - val_loss: 0.1831 - val_accuracy: 0.9422
# Epoch 62/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2016 - accuracy: 0.9312 - val_loss: 0.1758 - val_accuracy: 0.9312
# Epoch 63/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1915 - accuracy: 0.9383 - val_loss: 0.1818 - val_accuracy: 0.9328
# Epoch 64/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1914 - accuracy: 0.9309 - val_loss: 0.1765 - val_accuracy: 0.9359
# Epoch 65/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1909 - accuracy: 0.9379 - val_loss: 0.1715 - val_accuracy: 0.9281
# Epoch 66/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1905 - accuracy: 0.9355 - val_loss: 0.1738 - val_accuracy: 0.9406
# Epoch 67/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1871 - accuracy: 0.9410 - val_loss: 0.1712 - val_accuracy: 0.9297
# Epoch 68/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1983 - accuracy: 0.9273 - val_loss: 0.1628 - val_accuracy: 0.9391
# Epoch 69/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1967 - accuracy: 0.9340 - val_loss: 0.1857 - val_accuracy: 0.9375
# Epoch 70/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1924 - accuracy: 0.9324 - val_loss: 0.1656 - val_accuracy: 0.9422
# Epoch 71/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1818 - accuracy: 0.9414 - val_loss: 0.1795 - val_accuracy: 0.9297
# Epoch 72/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1768 - accuracy: 0.9359 - val_loss: 0.1637 - val_accuracy: 0.9469
# Epoch 73/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1810 - accuracy: 0.9434 - val_loss: 0.1645 - val_accuracy: 0.9375
# Epoch 74/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1818 - accuracy: 0.9395 - val_loss: 0.1687 - val_accuracy: 0.9484
# Epoch 75/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1813 - accuracy: 0.9402 - val_loss: 0.1584 - val_accuracy: 0.9391
# Epoch 76/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1888 - accuracy: 0.9336 - val_loss: 0.1625 - val_accuracy: 0.9484
# Epoch 77/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1832 - accuracy: 0.9402 - val_loss: 0.1713 - val_accuracy: 0.9312
# Epoch 78/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1739 - accuracy: 0.9391 - val_loss: 0.1538 - val_accuracy: 0.9391
# Epoch 79/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1720 - accuracy: 0.9480 - val_loss: 0.1548 - val_accuracy: 0.9547
# Epoch 80/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1678 - accuracy: 0.9445 - val_loss: 0.1510 - val_accuracy: 0.9469
# Epoch 81/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1719 - accuracy: 0.9426 - val_loss: 0.1484 - val_accuracy: 0.9453
# Epoch 82/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1677 - accuracy: 0.9441 - val_loss: 0.1516 - val_accuracy: 0.9469
# Epoch 83/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1674 - accuracy: 0.9430 - val_loss: 0.1578 - val_accuracy: 0.9422
# Epoch 84/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1596 - accuracy: 0.9488 - val_loss: 0.1510 - val_accuracy: 0.9500
# Epoch 85/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1670 - accuracy: 0.9402 - val_loss: 0.1469 - val_accuracy: 0.9422
# Epoch 86/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1553 - accuracy: 0.9492 - val_loss: 0.1459 - val_accuracy: 0.9484
# Epoch 87/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1581 - accuracy: 0.9438 - val_loss: 0.1501 - val_accuracy: 0.9406
# Epoch 88/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1668 - accuracy: 0.9410 - val_loss: 0.1413 - val_accuracy: 0.9438
# Epoch 89/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1552 - accuracy: 0.9512 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 90/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1611 - accuracy: 0.9465 - val_loss: 0.1532 - val_accuracy: 0.9453
# Epoch 91/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1541 - accuracy: 0.9516 - val_loss: 0.1458 - val_accuracy: 0.9453
# Epoch 92/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1536 - accuracy: 0.9492 - val_loss: 0.1400 - val_accuracy: 0.9547
# Epoch 93/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1571 - accuracy: 0.9477 - val_loss: 0.1405 - val_accuracy: 0.9469
# Epoch 94/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1499 - accuracy: 0.9504 - val_loss: 0.1427 - val_accuracy: 0.9422
# Epoch 95/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1463 - accuracy: 0.9516 - val_loss: 0.1504 - val_accuracy: 0.9469
# Epoch 96/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1410 - accuracy: 0.9527 - val_loss: 0.1368 - val_accuracy: 0.9406
# Epoch 97/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1445 - accuracy: 0.9516 - val_loss: 0.1327 - val_accuracy: 0.9609
# Epoch 98/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1448 - accuracy: 0.9496 - val_loss: 0.1335 - val_accuracy: 0.9578
# Epoch 99/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1472 - accuracy: 0.9480 - val_loss: 0.1392 - val_accuracy: 0.9563
# Epoch 100/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1401 - accuracy: 0.9559 - val_loss: 0.1317 - val_accuracy: 0.9547
# Epoch 101/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1461 - accuracy: 0.9484 - val_loss: 0.1321 - val_accuracy: 0.9625
# Epoch 102/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1417 - accuracy: 0.9477 - val_loss: 0.1329 - val_accuracy: 0.9531
# Epoch 103/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1400 - accuracy: 0.9535 - val_loss: 0.1507 - val_accuracy: 0.9438
# Epoch 104/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1522 - accuracy: 0.9473 - val_loss: 0.1449 - val_accuracy: 0.9500
# Epoch 105/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1493 - accuracy: 0.9504 - val_loss: 0.1430 - val_accuracy: 0.9391
# Epoch 106/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1453 - accuracy: 0.9488 - val_loss: 0.1331 - val_accuracy: 0.9594
# Epoch 107/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1426 - accuracy: 0.9516 - val_loss: 0.1286 - val_accuracy: 0.9641
# Epoch 108/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1473 - accuracy: 0.9492 - val_loss: 0.1285 - val_accuracy: 0.9516
# Epoch 109/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1372 - accuracy: 0.9527 - val_loss: 0.1255 - val_accuracy: 0.9578
# Epoch 110/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1465 - accuracy: 0.9477 - val_loss: 0.1261 - val_accuracy: 0.9578
# Epoch 111/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1414 - accuracy: 0.9531 - val_loss: 0.1276 - val_accuracy: 0.9609
# Epoch 112/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1393 - accuracy: 0.9504 - val_loss: 0.1325 - val_accuracy: 0.9563
# Epoch 113/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1388 - accuracy: 0.9496 - val_loss: 0.1315 - val_accuracy: 0.9578
# Epoch 114/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1461 - accuracy: 0.9512 - val_loss: 0.1669 - val_accuracy: 0.9531
# Epoch 115/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1552 - accuracy: 0.9426 - val_loss: 0.1343 - val_accuracy: 0.9594
# Epoch 116/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1542 - accuracy: 0.9488 - val_loss: 0.1319 - val_accuracy: 0.9563
# Epoch 117/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1410 - accuracy: 0.9508 - val_loss: 0.1486 - val_accuracy: 0.9469
# Epoch 118/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1442 - accuracy: 0.9508 - val_loss: 0.1336 - val_accuracy: 0.9578
# Epoch 119/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1400 - accuracy: 0.9523 - val_loss: 0.1474 - val_accuracy: 0.9594
# Epoch 120/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1330 - accuracy: 0.9566 - val_loss: 0.1234 - val_accuracy: 0.9531
# Epoch 121/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1348 - accuracy: 0.9543 - val_loss: 0.1316 - val_accuracy: 0.9484
# Epoch 122/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1333 - accuracy: 0.9535 - val_loss: 0.1251 - val_accuracy: 0.9594
# Epoch 123/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1289 - accuracy: 0.9578 - val_loss: 0.1236 - val_accuracy: 0.9609
# Epoch 124/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1288 - accuracy: 0.9586 - val_loss: 0.1323 - val_accuracy: 0.9500
# Epoch 125/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1286 - accuracy: 0.9559 - val_loss: 0.1208 - val_accuracy: 0.9625
# Epoch 126/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1210 - accuracy: 0.9590 - val_loss: 0.1142 - val_accuracy: 0.9641
# Epoch 127/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1249 - accuracy: 0.9570 - val_loss: 0.1195 - val_accuracy: 0.9547
# Epoch 128/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1267 - accuracy: 0.9555 - val_loss: 0.1150 - val_accuracy: 0.9688
# Epoch 129/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1255 - accuracy: 0.9602 - val_loss: 0.1227 - val_accuracy: 0.9563
# Epoch 130/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1225 - accuracy: 0.9594 - val_loss: 0.1153 - val_accuracy: 0.9578
# Epoch 131/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1155 - accuracy: 0.9586 - val_loss: 0.1106 - val_accuracy: 0.9641
# Epoch 132/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1209 - accuracy: 0.9586 - val_loss: 0.1221 - val_accuracy: 0.9547
# Epoch 133/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1258 - accuracy: 0.9547 - val_loss: 0.1174 - val_accuracy: 0.9625
# Epoch 134/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1188 - accuracy: 0.9621 - val_loss: 0.1134 - val_accuracy: 0.9641
# Epoch 135/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1101 - accuracy: 0.9637 - val_loss: 0.1128 - val_accuracy: 0.9625
# Epoch 136/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1075 - accuracy: 0.9621 - val_loss: 0.1289 - val_accuracy: 0.9516
# Epoch 137/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1202 - accuracy: 0.9590 - val_loss: 0.1203 - val_accuracy: 0.9547
# Epoch 138/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1208 - accuracy: 0.9598 - val_loss: 0.1121 - val_accuracy: 0.9563
# Epoch 139/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1201 - accuracy: 0.9563 - val_loss: 0.1108 - val_accuracy: 0.9672
# Epoch 140/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1190 - accuracy: 0.9598 - val_loss: 0.1135 - val_accuracy: 0.9641
# Epoch 141/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1119 - accuracy: 0.9621 - val_loss: 0.1128 - val_accuracy: 0.9625
# Epoch 142/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1091 - accuracy: 0.9633 - val_loss: 0.1151 - val_accuracy: 0.9578
# Epoch 143/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1144 - accuracy: 0.9617 - val_loss: 0.1106 - val_accuracy: 0.9656
# Epoch 144/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1091 - accuracy: 0.9633 - val_loss: 0.1086 - val_accuracy: 0.9641
# Epoch 145/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1134 - accuracy: 0.9578 - val_loss: 0.1088 - val_accuracy: 0.9594
# Epoch 146/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1073 - accuracy: 0.9633 - val_loss: 0.1073 - val_accuracy: 0.9578
# Epoch 147/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1084 - accuracy: 0.9621 - val_loss: 0.1100 - val_accuracy: 0.9625
# Epoch 148/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1058 - accuracy: 0.9629 - val_loss: 0.1076 - val_accuracy: 0.9609
# Epoch 149/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1125 - accuracy: 0.9598 - val_loss: 0.1087 - val_accuracy: 0.9625
# Epoch 150/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1100 - accuracy: 0.9625 - val_loss: 0.1082 - val_accuracy: 0.9609
# Epoch 151/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1190 - accuracy: 0.9598 - val_loss: 0.1169 - val_accuracy: 0.9531
# Epoch 152/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1123 - accuracy: 0.9613 - val_loss: 0.1129 - val_accuracy: 0.9594
# Epoch 153/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1065 - accuracy: 0.9668 - val_loss: 0.1097 - val_accuracy: 0.9609
# Epoch 154/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1072 - accuracy: 0.9648 - val_loss: 0.1034 - val_accuracy: 0.9641
# Epoch 155/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1026 - accuracy: 0.9664 - val_loss: 0.1130 - val_accuracy: 0.9578
# Epoch 156/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1166 - accuracy: 0.9566 - val_loss: 0.1048 - val_accuracy: 0.9656
# Epoch 157/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0989 - accuracy: 0.9641 - val_loss: 0.1069 - val_accuracy: 0.9625
# Epoch 158/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1088 - accuracy: 0.9602 - val_loss: 0.0998 - val_accuracy: 0.9641
# Epoch 159/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1015 - accuracy: 0.9637 - val_loss: 0.1045 - val_accuracy: 0.9625
# Epoch 160/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1048 - accuracy: 0.9605 - val_loss: 0.1107 - val_accuracy: 0.9594
# Epoch 161/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0994 - accuracy: 0.9672 - val_loss: 0.1073 - val_accuracy: 0.9625
# Epoch 162/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0975 - accuracy: 0.9660 - val_loss: 0.1040 - val_accuracy: 0.9672
# Epoch 163/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1016 - accuracy: 0.9629 - val_loss: 0.1043 - val_accuracy: 0.9688
# Epoch 164/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0990 - accuracy: 0.9648 - val_loss: 0.1044 - val_accuracy: 0.9641
# Epoch 165/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1128 - accuracy: 0.9570 - val_loss: 0.1088 - val_accuracy: 0.9672
# Epoch 166/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1083 - accuracy: 0.9633 - val_loss: 0.1075 - val_accuracy: 0.9688
# Epoch 167/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1010 - accuracy: 0.9652 - val_loss: 0.1025 - val_accuracy: 0.9672
# Epoch 168/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0966 - accuracy: 0.9672 - val_loss: 0.1003 - val_accuracy: 0.9703
# Epoch 169/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1044 - accuracy: 0.9629 - val_loss: 0.0974 - val_accuracy: 0.9672
# Epoch 170/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0957 - accuracy: 0.9660 - val_loss: 0.0976 - val_accuracy: 0.9688
# Epoch 171/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0961 - accuracy: 0.9680 - val_loss: 0.1054 - val_accuracy: 0.9625
# Epoch 172/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1051 - accuracy: 0.9637 - val_loss: 0.1081 - val_accuracy: 0.9656
# Epoch 173/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1068 - accuracy: 0.9629 - val_loss: 0.1061 - val_accuracy: 0.9578
# Epoch 174/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1042 - accuracy: 0.9637 - val_loss: 0.1074 - val_accuracy: 0.9672
# Epoch 175/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1023 - accuracy: 0.9664 - val_loss: 0.1100 - val_accuracy: 0.9547
# Epoch 176/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0957 - accuracy: 0.9648 - val_loss: 0.0963 - val_accuracy: 0.9688
# Epoch 177/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0906 - accuracy: 0.9652 - val_loss: 0.1010 - val_accuracy: 0.9656
# Epoch 178/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0988 - accuracy: 0.9668 - val_loss: 0.1037 - val_accuracy: 0.9594
# Epoch 179/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0909 - accuracy: 0.9668 - val_loss: 0.1064 - val_accuracy: 0.9594
# Epoch 180/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0922 - accuracy: 0.9703 - val_loss: 0.1012 - val_accuracy: 0.9625
# Epoch 181/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0969 - accuracy: 0.9656 - val_loss: 0.0986 - val_accuracy: 0.9609
# Epoch 182/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1001 - accuracy: 0.9680 - val_loss: 0.0951 - val_accuracy: 0.9672
# Epoch 183/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0883 - accuracy: 0.9672 - val_loss: 0.0980 - val_accuracy: 0.9656
# Epoch 184/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0957 - accuracy: 0.9680 - val_loss: 0.0962 - val_accuracy: 0.9672
# Epoch 185/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0939 - accuracy: 0.9672 - val_loss: 0.0992 - val_accuracy: 0.9672
# Epoch 186/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0935 - accuracy: 0.9684 - val_loss: 0.0970 - val_accuracy: 0.9656
# Epoch 187/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0847 - accuracy: 0.9734 - val_loss: 0.0899 - val_accuracy: 0.9703
# Epoch 188/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0873 - accuracy: 0.9672 - val_loss: 0.0882 - val_accuracy: 0.9703
# Epoch 189/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0936 - accuracy: 0.9680 - val_loss: 0.0940 - val_accuracy: 0.9672
# Epoch 190/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0964 - accuracy: 0.9648 - val_loss: 0.1008 - val_accuracy: 0.9672
# Epoch 191/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0923 - accuracy: 0.9691 - val_loss: 0.0978 - val_accuracy: 0.9641
# Epoch 192/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0818 - accuracy: 0.9699 - val_loss: 0.0957 - val_accuracy: 0.9656
# Epoch 193/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0895 - accuracy: 0.9695 - val_loss: 0.0990 - val_accuracy: 0.9625
# Epoch 194/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0976 - accuracy: 0.9629 - val_loss: 0.0895 - val_accuracy: 0.9688
# Epoch 195/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0891 - accuracy: 0.9707 - val_loss: 0.0954 - val_accuracy: 0.9656
# Epoch 196/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0864 - accuracy: 0.9711 - val_loss: 0.1053 - val_accuracy: 0.9609
# Epoch 197/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0947 - accuracy: 0.9680 - val_loss: 0.1010 - val_accuracy: 0.9641
# Epoch 198/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0902 - accuracy: 0.9738 - val_loss: 0.0943 - val_accuracy: 0.9656
# Epoch 199/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0869 - accuracy: 0.9680 - val_loss: 0.1020 - val_accuracy: 0.9594
# Epoch 200/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0897 - accuracy: 0.9699 - val_loss: 0.0886 - val_accuracy: 0.9734

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=80, batch_size=512)
# Out:
# Epoch 1/80
# 5/5 [==============================] - 0s 72ms/step - loss: 1.7638 - accuracy: 0.3875 - val_loss: 1.3014 - val_accuracy: 0.6562
# Epoch 2/80
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1858 - accuracy: 0.6754 - val_loss: 0.9473 - val_accuracy: 0.6969
# Epoch 3/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8994 - accuracy: 0.7184 - val_loss: 0.7668 - val_accuracy: 0.7578
# Epoch 4/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.7539 - accuracy: 0.7805 - val_loss: 0.6873 - val_accuracy: 0.8109
# Epoch 5/80
# 5/5 [==============================] - 0s 54ms/step - loss: 0.7055 - accuracy: 0.7984 - val_loss: 0.6203 - val_accuracy: 0.8250
# Epoch 6/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.6631 - accuracy: 0.8117 - val_loss: 0.5624 - val_accuracy: 0.8391
# Epoch 7/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6038 - accuracy: 0.8172 - val_loss: 0.5441 - val_accuracy: 0.8406
# Epoch 8/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.5646 - accuracy: 0.8316 - val_loss: 0.4894 - val_accuracy: 0.8687
# Epoch 9/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.5213 - accuracy: 0.8426 - val_loss: 0.4651 - val_accuracy: 0.8359
# Epoch 10/80
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4904 - accuracy: 0.8445 - val_loss: 0.4293 - val_accuracy: 0.8797
# Epoch 11/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4681 - accuracy: 0.8547 - val_loss: 0.4079 - val_accuracy: 0.8891
# Epoch 12/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4411 - accuracy: 0.8586 - val_loss: 0.3909 - val_accuracy: 0.8719
# Epoch 13/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4253 - accuracy: 0.8656 - val_loss: 0.3753 - val_accuracy: 0.8734
# Epoch 14/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4196 - accuracy: 0.8762 - val_loss: 0.3589 - val_accuracy: 0.8922
# Epoch 15/80
# 5/5 [==============================] - 0s 56ms/step - loss: 0.4004 - accuracy: 0.8707 - val_loss: 0.3662 - val_accuracy: 0.8672
# Epoch 16/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3907 - accuracy: 0.8789 - val_loss: 0.3339 - val_accuracy: 0.9000
# Epoch 17/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3695 - accuracy: 0.8852 - val_loss: 0.3258 - val_accuracy: 0.9016
# Epoch 18/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3563 - accuracy: 0.8879 - val_loss: 0.3200 - val_accuracy: 0.9047
# Epoch 19/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3530 - accuracy: 0.8895 - val_loss: 0.3079 - val_accuracy: 0.9062
# Epoch 20/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3595 - accuracy: 0.8863 - val_loss: 0.3005 - val_accuracy: 0.9078
# Epoch 21/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3400 - accuracy: 0.8910 - val_loss: 0.3000 - val_accuracy: 0.9016
# Epoch 22/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3365 - accuracy: 0.8918 - val_loss: 0.3010 - val_accuracy: 0.9047
# Epoch 23/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3453 - accuracy: 0.8945 - val_loss: 0.2923 - val_accuracy: 0.9094
# Epoch 24/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3265 - accuracy: 0.8945 - val_loss: 0.2851 - val_accuracy: 0.9125
# Epoch 25/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3183 - accuracy: 0.9055 - val_loss: 0.2843 - val_accuracy: 0.9078
# Epoch 26/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3160 - accuracy: 0.9008 - val_loss: 0.2734 - val_accuracy: 0.9125
# Epoch 27/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2985 - accuracy: 0.9043 - val_loss: 0.2659 - val_accuracy: 0.9156
# Epoch 28/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2942 - accuracy: 0.9082 - val_loss: 0.2823 - val_accuracy: 0.9094
# Epoch 29/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3024 - accuracy: 0.9043 - val_loss: 0.2595 - val_accuracy: 0.9172
# Epoch 30/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2851 - accuracy: 0.9066 - val_loss: 0.2501 - val_accuracy: 0.9172
# Epoch 31/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2821 - accuracy: 0.9121 - val_loss: 0.2497 - val_accuracy: 0.9187
# Epoch 32/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2706 - accuracy: 0.9148 - val_loss: 0.2415 - val_accuracy: 0.9187
# Epoch 33/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2687 - accuracy: 0.9172 - val_loss: 0.2474 - val_accuracy: 0.9141
# Epoch 34/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2723 - accuracy: 0.9109 - val_loss: 0.2422 - val_accuracy: 0.9203
# Epoch 35/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2788 - accuracy: 0.9133 - val_loss: 0.2462 - val_accuracy: 0.9156
# Epoch 36/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2680 - accuracy: 0.9160 - val_loss: 0.2340 - val_accuracy: 0.9203
# Epoch 37/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2534 - accuracy: 0.9168 - val_loss: 0.2343 - val_accuracy: 0.9219
# Epoch 38/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2663 - accuracy: 0.9109 - val_loss: 0.2369 - val_accuracy: 0.9156
# Epoch 39/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2635 - accuracy: 0.9109 - val_loss: 0.2343 - val_accuracy: 0.9219
# Epoch 40/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2573 - accuracy: 0.9187 - val_loss: 0.2343 - val_accuracy: 0.9156
# Epoch 41/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2607 - accuracy: 0.9145 - val_loss: 0.2267 - val_accuracy: 0.9172
# Epoch 42/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2514 - accuracy: 0.9203 - val_loss: 0.2227 - val_accuracy: 0.9266
# Epoch 43/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2478 - accuracy: 0.9172 - val_loss: 0.2129 - val_accuracy: 0.9234
# Epoch 44/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2388 - accuracy: 0.9219 - val_loss: 0.2161 - val_accuracy: 0.9203
# Epoch 45/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2258 - accuracy: 0.9266 - val_loss: 0.2077 - val_accuracy: 0.9297
# Epoch 46/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2360 - accuracy: 0.9254 - val_loss: 0.2027 - val_accuracy: 0.9281
# Epoch 47/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2261 - accuracy: 0.9316 - val_loss: 0.2004 - val_accuracy: 0.9266
# Epoch 48/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2296 - accuracy: 0.9238 - val_loss: 0.2089 - val_accuracy: 0.9281
# Epoch 49/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2284 - accuracy: 0.9250 - val_loss: 0.2188 - val_accuracy: 0.9187
# Epoch 50/80
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2297 - accuracy: 0.9227 - val_loss: 0.2054 - val_accuracy: 0.9422
# Epoch 51/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2267 - accuracy: 0.9258 - val_loss: 0.2006 - val_accuracy: 0.9234
# Epoch 52/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2240 - accuracy: 0.9285 - val_loss: 0.1955 - val_accuracy: 0.9312
# Epoch 53/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2155 - accuracy: 0.9277 - val_loss: 0.1921 - val_accuracy: 0.9344
# Epoch 54/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2160 - accuracy: 0.9293 - val_loss: 0.1929 - val_accuracy: 0.9266
# Epoch 55/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2135 - accuracy: 0.9250 - val_loss: 0.1937 - val_accuracy: 0.9328
# Epoch 56/80
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2263 - accuracy: 0.9191 - val_loss: 0.1948 - val_accuracy: 0.9391
# Epoch 57/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2271 - accuracy: 0.9289 - val_loss: 0.2101 - val_accuracy: 0.9187
# Epoch 58/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2222 - accuracy: 0.9250 - val_loss: 0.1992 - val_accuracy: 0.9328
# Epoch 59/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2174 - accuracy: 0.9289 - val_loss: 0.2033 - val_accuracy: 0.9359
# Epoch 60/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2172 - accuracy: 0.9297 - val_loss: 0.2084 - val_accuracy: 0.9234
# Epoch 61/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2106 - accuracy: 0.9266 - val_loss: 0.2016 - val_accuracy: 0.9328
# Epoch 62/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2139 - accuracy: 0.9266 - val_loss: 0.1871 - val_accuracy: 0.9328
# Epoch 63/80
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2119 - accuracy: 0.9289 - val_loss: 0.1872 - val_accuracy: 0.9328
# Epoch 64/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2187 - accuracy: 0.9227 - val_loss: 0.2030 - val_accuracy: 0.9234
# Epoch 65/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2074 - accuracy: 0.9285 - val_loss: 0.1951 - val_accuracy: 0.9266
# Epoch 66/80
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1993 - accuracy: 0.9348 - val_loss: 0.1837 - val_accuracy: 0.9281
# Epoch 67/80
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2094 - accuracy: 0.9270 - val_loss: 0.1782 - val_accuracy: 0.9469
# Epoch 68/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1947 - accuracy: 0.9316 - val_loss: 0.1751 - val_accuracy: 0.9281
# Epoch 69/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1879 - accuracy: 0.9340 - val_loss: 0.1801 - val_accuracy: 0.9484
# Epoch 70/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1873 - accuracy: 0.9402 - val_loss: 0.1765 - val_accuracy: 0.9219
# Epoch 71/80
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1842 - accuracy: 0.9363 - val_loss: 0.1636 - val_accuracy: 0.9469
# Epoch 72/80
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1785 - accuracy: 0.9391 - val_loss: 0.1655 - val_accuracy: 0.9406
# Epoch 73/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1786 - accuracy: 0.9414 - val_loss: 0.1635 - val_accuracy: 0.9469
# Epoch 74/80
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1772 - accuracy: 0.9406 - val_loss: 0.1627 - val_accuracy: 0.9469
# Epoch 75/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1745 - accuracy: 0.9434 - val_loss: 0.1643 - val_accuracy: 0.9375
# Epoch 76/80
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1801 - accuracy: 0.9398 - val_loss: 0.1606 - val_accuracy: 0.9422
# Epoch 77/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1746 - accuracy: 0.9383 - val_loss: 0.1559 - val_accuracy: 0.9453
# Epoch 78/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1767 - accuracy: 0.9438 - val_loss: 0.1666 - val_accuracy: 0.9297
# Epoch 79/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1761 - accuracy: 0.9426 - val_loss: 0.1557 - val_accuracy: 0.9406
# Epoch 80/80
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1751 - accuracy: 0.9426 - val_loss: 0.1613 - val_accuracy: 0.9438

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1426 - accuracy: 0.9504
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1613 - accuracy: 0.9438
# 0.950390636920929 0.9437500238418579

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 170, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:13

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 196   6   0   1   1]
#  [  0   0   0   0   2  96   0   2   0]
#  [  0   0   0   0   2   0   4   0   0]
#  [  0   0   0   0   2   4   0  14   0]
#  [  0   0   0   0  12   1   0   0   7]]
#
# Accuracy Score
# 0.94375
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.91      0.96      0.93       204
#     windows       0.90      0.96      0.93       100
#       roads       1.00      0.67      0.80         6
#        cars       0.82      0.70      0.76        20
#       metal       0.88      0.35      0.50        20
#
# avg / total       0.94      0.94      0.94       640

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 170)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 170)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 170)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 170) (80, 170)
# clouds  (400, 170) (100, 170)
# vegetation  (488, 170) (122, 170)
# built  (960, 170) (240, 170)
# windows  (400, 170) (100, 170)
# roads  (48, 170) (12, 170)
# cars  (44, 170) (11, 170)
# metal  (184, 170) (46, 170)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 170) (2844,) (2844, 2)
# (711, 170) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 77ms/step - loss: 1.7003 - accuracy: 0.3499 - val_loss: 1.2623 - val_accuracy: 0.6512
# Epoch 2/200
# 6/6 [==============================] - 0s 46ms/step - loss: 1.1160 - accuracy: 0.6421 - val_loss: 0.9540 - val_accuracy: 0.6807
# Epoch 3/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.8560 - accuracy: 0.7022 - val_loss: 0.8057 - val_accuracy: 0.6793
# Epoch 4/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.7421 - accuracy: 0.7177 - val_loss: 0.7068 - val_accuracy: 0.6892
# Epoch 5/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.6770 - accuracy: 0.7275 - val_loss: 0.6286 - val_accuracy: 0.7525
# Epoch 6/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.6264 - accuracy: 0.7314 - val_loss: 0.6100 - val_accuracy: 0.7567
# Epoch 7/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5894 - accuracy: 0.7521 - val_loss: 0.5816 - val_accuracy: 0.7707
# Epoch 8/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.5710 - accuracy: 0.7605 - val_loss: 0.6173 - val_accuracy: 0.7595
# Epoch 9/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.5604 - accuracy: 0.7676 - val_loss: 0.5686 - val_accuracy: 0.7736
# Epoch 10/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.5377 - accuracy: 0.7813 - val_loss: 0.5443 - val_accuracy: 0.7792
# Epoch 11/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5281 - accuracy: 0.7859 - val_loss: 0.5301 - val_accuracy: 0.7806
# Epoch 12/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5059 - accuracy: 0.7918 - val_loss: 0.5408 - val_accuracy: 0.7679
# Epoch 13/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4857 - accuracy: 0.8140 - val_loss: 0.5187 - val_accuracy: 0.8087
# Epoch 14/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4755 - accuracy: 0.8091 - val_loss: 0.5067 - val_accuracy: 0.8031
# Epoch 15/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4557 - accuracy: 0.8235 - val_loss: 0.4956 - val_accuracy: 0.8200
# Epoch 16/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4489 - accuracy: 0.8270 - val_loss: 0.4822 - val_accuracy: 0.8031
# Epoch 17/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4418 - accuracy: 0.8326 - val_loss: 0.4749 - val_accuracy: 0.8411
# Epoch 18/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4537 - accuracy: 0.8267 - val_loss: 0.4774 - val_accuracy: 0.8214
# Epoch 19/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.4399 - accuracy: 0.8291 - val_loss: 0.4757 - val_accuracy: 0.8172
# Epoch 20/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4374 - accuracy: 0.8316 - val_loss: 0.4966 - val_accuracy: 0.8115
# Epoch 21/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4223 - accuracy: 0.8361 - val_loss: 0.4503 - val_accuracy: 0.8186
# Epoch 22/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4212 - accuracy: 0.8309 - val_loss: 0.4423 - val_accuracy: 0.8383
# Epoch 23/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4120 - accuracy: 0.8439 - val_loss: 0.4406 - val_accuracy: 0.8397
# Epoch 24/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3932 - accuracy: 0.8551 - val_loss: 0.4308 - val_accuracy: 0.8383
# Epoch 25/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3912 - accuracy: 0.8509 - val_loss: 0.4308 - val_accuracy: 0.8397
# Epoch 26/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3953 - accuracy: 0.8513 - val_loss: 0.4370 - val_accuracy: 0.8256
# Epoch 27/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3967 - accuracy: 0.8463 - val_loss: 0.4213 - val_accuracy: 0.8453
# Epoch 28/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3829 - accuracy: 0.8685 - val_loss: 0.4240 - val_accuracy: 0.8312
# Epoch 29/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3755 - accuracy: 0.8579 - val_loss: 0.4119 - val_accuracy: 0.8467
# Epoch 30/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3686 - accuracy: 0.8611 - val_loss: 0.4129 - val_accuracy: 0.8467
# Epoch 31/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3749 - accuracy: 0.8601 - val_loss: 0.4340 - val_accuracy: 0.8383
# Epoch 32/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3693 - accuracy: 0.8639 - val_loss: 0.4308 - val_accuracy: 0.8354
# Epoch 33/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3745 - accuracy: 0.8601 - val_loss: 0.4147 - val_accuracy: 0.8312
# Epoch 34/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3557 - accuracy: 0.8594 - val_loss: 0.3948 - val_accuracy: 0.8551
# Epoch 35/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3625 - accuracy: 0.8632 - val_loss: 0.3924 - val_accuracy: 0.8594
# Epoch 36/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3505 - accuracy: 0.8657 - val_loss: 0.4065 - val_accuracy: 0.8383
# Epoch 37/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3612 - accuracy: 0.8622 - val_loss: 0.4089 - val_accuracy: 0.8340
# Epoch 38/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3599 - accuracy: 0.8586 - val_loss: 0.3913 - val_accuracy: 0.8636
# Epoch 39/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3440 - accuracy: 0.8734 - val_loss: 0.3962 - val_accuracy: 0.8579
# Epoch 40/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3410 - accuracy: 0.8724 - val_loss: 0.3949 - val_accuracy: 0.8481
# Epoch 41/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3475 - accuracy: 0.8717 - val_loss: 0.3754 - val_accuracy: 0.8734
# Epoch 42/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3341 - accuracy: 0.8780 - val_loss: 0.3725 - val_accuracy: 0.8650
# Epoch 43/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.3290 - accuracy: 0.8745 - val_loss: 0.3765 - val_accuracy: 0.8734
# Epoch 44/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3322 - accuracy: 0.8748 - val_loss: 0.3796 - val_accuracy: 0.8636
# Epoch 45/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3302 - accuracy: 0.8850 - val_loss: 0.3773 - val_accuracy: 0.8608
# Epoch 46/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3384 - accuracy: 0.8741 - val_loss: 0.3668 - val_accuracy: 0.8678
# Epoch 47/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3198 - accuracy: 0.8819 - val_loss: 0.3873 - val_accuracy: 0.8551
# Epoch 48/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3151 - accuracy: 0.8819 - val_loss: 0.3727 - val_accuracy: 0.8608
# Epoch 49/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3186 - accuracy: 0.8854 - val_loss: 0.3675 - val_accuracy: 0.8664
# Epoch 50/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3161 - accuracy: 0.8822 - val_loss: 0.3599 - val_accuracy: 0.8664
# Epoch 51/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3232 - accuracy: 0.8833 - val_loss: 0.3565 - val_accuracy: 0.8678
# Epoch 52/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3140 - accuracy: 0.8903 - val_loss: 0.3592 - val_accuracy: 0.8706
# Epoch 53/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3043 - accuracy: 0.8836 - val_loss: 0.3566 - val_accuracy: 0.8706
# Epoch 54/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3043 - accuracy: 0.8878 - val_loss: 0.3524 - val_accuracy: 0.8776
# Epoch 55/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3174 - accuracy: 0.8801 - val_loss: 0.3536 - val_accuracy: 0.8720
# Epoch 56/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3013 - accuracy: 0.8868 - val_loss: 0.3445 - val_accuracy: 0.8734
# Epoch 57/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2944 - accuracy: 0.8970 - val_loss: 0.3541 - val_accuracy: 0.8706
# Epoch 58/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2921 - accuracy: 0.8973 - val_loss: 0.3384 - val_accuracy: 0.8790
# Epoch 59/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2902 - accuracy: 0.8952 - val_loss: 0.3400 - val_accuracy: 0.8776
# Epoch 60/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2995 - accuracy: 0.8917 - val_loss: 0.3432 - val_accuracy: 0.8748
# Epoch 61/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2904 - accuracy: 0.8970 - val_loss: 0.3458 - val_accuracy: 0.8819
# Epoch 62/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2938 - accuracy: 0.8892 - val_loss: 0.3434 - val_accuracy: 0.8776
# Epoch 63/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2960 - accuracy: 0.8935 - val_loss: 0.3330 - val_accuracy: 0.8833
# Epoch 64/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2976 - accuracy: 0.8878 - val_loss: 0.3390 - val_accuracy: 0.8833
# Epoch 65/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2910 - accuracy: 0.8931 - val_loss: 0.3294 - val_accuracy: 0.8805
# Epoch 66/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2792 - accuracy: 0.9005 - val_loss: 0.3257 - val_accuracy: 0.8847
# Epoch 67/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2783 - accuracy: 0.9015 - val_loss: 0.3254 - val_accuracy: 0.8833
# Epoch 68/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2704 - accuracy: 0.9072 - val_loss: 0.3589 - val_accuracy: 0.8650
# Epoch 69/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2806 - accuracy: 0.8928 - val_loss: 0.3295 - val_accuracy: 0.8819
# Epoch 70/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2762 - accuracy: 0.9015 - val_loss: 0.3383 - val_accuracy: 0.8833
# Epoch 71/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2747 - accuracy: 0.9012 - val_loss: 0.3257 - val_accuracy: 0.8917
# Epoch 72/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2696 - accuracy: 0.9072 - val_loss: 0.3603 - val_accuracy: 0.8650
# Epoch 73/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2849 - accuracy: 0.8959 - val_loss: 0.3316 - val_accuracy: 0.8819
# Epoch 74/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2831 - accuracy: 0.8966 - val_loss: 0.3363 - val_accuracy: 0.8734
# Epoch 75/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2858 - accuracy: 0.8945 - val_loss: 0.3271 - val_accuracy: 0.8889
# Epoch 76/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2784 - accuracy: 0.8994 - val_loss: 0.3463 - val_accuracy: 0.8762
# Epoch 77/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2668 - accuracy: 0.9005 - val_loss: 0.3181 - val_accuracy: 0.8847
# Epoch 78/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2581 - accuracy: 0.9096 - val_loss: 0.3157 - val_accuracy: 0.8903
# Epoch 79/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2645 - accuracy: 0.9058 - val_loss: 0.3197 - val_accuracy: 0.8931
# Epoch 80/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2556 - accuracy: 0.9079 - val_loss: 0.3188 - val_accuracy: 0.8959
# Epoch 81/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2609 - accuracy: 0.9058 - val_loss: 0.3206 - val_accuracy: 0.8917
# Epoch 82/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2515 - accuracy: 0.9177 - val_loss: 0.3225 - val_accuracy: 0.8861
# Epoch 83/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2521 - accuracy: 0.9086 - val_loss: 0.3435 - val_accuracy: 0.8748
# Epoch 84/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2562 - accuracy: 0.9072 - val_loss: 0.3056 - val_accuracy: 0.8945
# Epoch 85/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2594 - accuracy: 0.9030 - val_loss: 0.3077 - val_accuracy: 0.8959
# Epoch 86/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2657 - accuracy: 0.9086 - val_loss: 0.3251 - val_accuracy: 0.8875
# Epoch 87/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2602 - accuracy: 0.9068 - val_loss: 0.3097 - val_accuracy: 0.8833
# Epoch 88/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2540 - accuracy: 0.9110 - val_loss: 0.3155 - val_accuracy: 0.8847
# Epoch 89/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2474 - accuracy: 0.9124 - val_loss: 0.3548 - val_accuracy: 0.8650
# Epoch 90/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2547 - accuracy: 0.9082 - val_loss: 0.3105 - val_accuracy: 0.8959
# Epoch 91/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2417 - accuracy: 0.9068 - val_loss: 0.3110 - val_accuracy: 0.8931
# Epoch 92/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2447 - accuracy: 0.9075 - val_loss: 0.3163 - val_accuracy: 0.8875
# Epoch 93/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2430 - accuracy: 0.9135 - val_loss: 0.3059 - val_accuracy: 0.9001
# Epoch 94/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2431 - accuracy: 0.9142 - val_loss: 0.3108 - val_accuracy: 0.8819
# Epoch 95/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2397 - accuracy: 0.9167 - val_loss: 0.3029 - val_accuracy: 0.9044
# Epoch 96/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2427 - accuracy: 0.9139 - val_loss: 0.3018 - val_accuracy: 0.9044
# Epoch 97/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2324 - accuracy: 0.9184 - val_loss: 0.2934 - val_accuracy: 0.9001
# Epoch 98/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2333 - accuracy: 0.9188 - val_loss: 0.2924 - val_accuracy: 0.8959
# Epoch 99/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2302 - accuracy: 0.9132 - val_loss: 0.3007 - val_accuracy: 0.8917
# Epoch 100/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2264 - accuracy: 0.9146 - val_loss: 0.3107 - val_accuracy: 0.8973
# Epoch 101/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2407 - accuracy: 0.9086 - val_loss: 0.2974 - val_accuracy: 0.9030
# Epoch 102/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2297 - accuracy: 0.9139 - val_loss: 0.2903 - val_accuracy: 0.8945
# Epoch 103/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2216 - accuracy: 0.9216 - val_loss: 0.3095 - val_accuracy: 0.8889
# Epoch 104/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2429 - accuracy: 0.9117 - val_loss: 0.3162 - val_accuracy: 0.8875
# Epoch 105/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2397 - accuracy: 0.9163 - val_loss: 0.3168 - val_accuracy: 0.8889
# Epoch 106/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2266 - accuracy: 0.9205 - val_loss: 0.2989 - val_accuracy: 0.8945
# Epoch 107/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2213 - accuracy: 0.9184 - val_loss: 0.2952 - val_accuracy: 0.9058
# Epoch 108/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2207 - accuracy: 0.9237 - val_loss: 0.3057 - val_accuracy: 0.8973
# Epoch 109/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2249 - accuracy: 0.9170 - val_loss: 0.3044 - val_accuracy: 0.8889
# Epoch 110/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2309 - accuracy: 0.9128 - val_loss: 0.2851 - val_accuracy: 0.9001
# Epoch 111/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2293 - accuracy: 0.9212 - val_loss: 0.2909 - val_accuracy: 0.9030
# Epoch 112/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2249 - accuracy: 0.9177 - val_loss: 0.2952 - val_accuracy: 0.8987
# Epoch 113/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2217 - accuracy: 0.9202 - val_loss: 0.2983 - val_accuracy: 0.9030
# Epoch 114/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2228 - accuracy: 0.9251 - val_loss: 0.2859 - val_accuracy: 0.9001
# Epoch 115/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2095 - accuracy: 0.9279 - val_loss: 0.2861 - val_accuracy: 0.9030
# Epoch 116/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2191 - accuracy: 0.9184 - val_loss: 0.2846 - val_accuracy: 0.9030
# Epoch 117/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2112 - accuracy: 0.9265 - val_loss: 0.2811 - val_accuracy: 0.9044
# Epoch 118/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2057 - accuracy: 0.9248 - val_loss: 0.3148 - val_accuracy: 0.8875
# Epoch 119/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2134 - accuracy: 0.9219 - val_loss: 0.2795 - val_accuracy: 0.9100
# Epoch 120/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2093 - accuracy: 0.9290 - val_loss: 0.2868 - val_accuracy: 0.8987
# Epoch 121/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2143 - accuracy: 0.9226 - val_loss: 0.2775 - val_accuracy: 0.9086
# Epoch 122/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2047 - accuracy: 0.9276 - val_loss: 0.2780 - val_accuracy: 0.9114
# Epoch 123/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2072 - accuracy: 0.9251 - val_loss: 0.2839 - val_accuracy: 0.9086
# Epoch 124/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2062 - accuracy: 0.9283 - val_loss: 0.2875 - val_accuracy: 0.9030
# Epoch 125/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1971 - accuracy: 0.9307 - val_loss: 0.2732 - val_accuracy: 0.9142
# Epoch 126/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2078 - accuracy: 0.9209 - val_loss: 0.2788 - val_accuracy: 0.9044
# Epoch 127/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2081 - accuracy: 0.9205 - val_loss: 0.2856 - val_accuracy: 0.9086
# Epoch 128/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2113 - accuracy: 0.9233 - val_loss: 0.2764 - val_accuracy: 0.9058
# Epoch 129/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2008 - accuracy: 0.9283 - val_loss: 0.2771 - val_accuracy: 0.9044
# Epoch 130/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2066 - accuracy: 0.9276 - val_loss: 0.2753 - val_accuracy: 0.9030
# Epoch 131/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2032 - accuracy: 0.9262 - val_loss: 0.2684 - val_accuracy: 0.9058
# Epoch 132/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2019 - accuracy: 0.9279 - val_loss: 0.2672 - val_accuracy: 0.9100
# Epoch 133/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1886 - accuracy: 0.9321 - val_loss: 0.2714 - val_accuracy: 0.9058
# Epoch 134/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1998 - accuracy: 0.9198 - val_loss: 0.2773 - val_accuracy: 0.9030
# Epoch 135/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1940 - accuracy: 0.9342 - val_loss: 0.2852 - val_accuracy: 0.8987
# Epoch 136/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1943 - accuracy: 0.9297 - val_loss: 0.2987 - val_accuracy: 0.9001
# Epoch 137/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2026 - accuracy: 0.9290 - val_loss: 0.2703 - val_accuracy: 0.9100
# Epoch 138/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2025 - accuracy: 0.9293 - val_loss: 0.2660 - val_accuracy: 0.9072
# Epoch 139/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2066 - accuracy: 0.9241 - val_loss: 0.2645 - val_accuracy: 0.9184
# Epoch 140/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1989 - accuracy: 0.9297 - val_loss: 0.2686 - val_accuracy: 0.9086
# Epoch 141/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1946 - accuracy: 0.9325 - val_loss: 0.2733 - val_accuracy: 0.9086
# Epoch 142/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1821 - accuracy: 0.9346 - val_loss: 0.2638 - val_accuracy: 0.9086
# Epoch 143/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1884 - accuracy: 0.9314 - val_loss: 0.2647 - val_accuracy: 0.9114
# Epoch 144/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1857 - accuracy: 0.9332 - val_loss: 0.2815 - val_accuracy: 0.9072
# Epoch 145/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1931 - accuracy: 0.9276 - val_loss: 0.2953 - val_accuracy: 0.9001
# Epoch 146/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1925 - accuracy: 0.9335 - val_loss: 0.2678 - val_accuracy: 0.9072
# Epoch 147/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1847 - accuracy: 0.9367 - val_loss: 0.2613 - val_accuracy: 0.9142
# Epoch 148/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1793 - accuracy: 0.9353 - val_loss: 0.2623 - val_accuracy: 0.9170
# Epoch 149/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1919 - accuracy: 0.9311 - val_loss: 0.2560 - val_accuracy: 0.9198
# Epoch 150/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1849 - accuracy: 0.9406 - val_loss: 0.2551 - val_accuracy: 0.9128
# Epoch 151/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2001 - accuracy: 0.9314 - val_loss: 0.2611 - val_accuracy: 0.9100
# Epoch 152/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1829 - accuracy: 0.9297 - val_loss: 0.2565 - val_accuracy: 0.9241
# Epoch 153/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1840 - accuracy: 0.9346 - val_loss: 0.2629 - val_accuracy: 0.9044
# Epoch 154/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1915 - accuracy: 0.9300 - val_loss: 0.2723 - val_accuracy: 0.9030
# Epoch 155/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1932 - accuracy: 0.9297 - val_loss: 0.2633 - val_accuracy: 0.9170
# Epoch 156/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1787 - accuracy: 0.9346 - val_loss: 0.2719 - val_accuracy: 0.9100
# Epoch 157/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1891 - accuracy: 0.9328 - val_loss: 0.2610 - val_accuracy: 0.9156
# Epoch 158/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1857 - accuracy: 0.9307 - val_loss: 0.2797 - val_accuracy: 0.9100
# Epoch 159/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1980 - accuracy: 0.9276 - val_loss: 0.2739 - val_accuracy: 0.9100
# Epoch 160/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1971 - accuracy: 0.9255 - val_loss: 0.2619 - val_accuracy: 0.9072
# Epoch 161/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1932 - accuracy: 0.9286 - val_loss: 0.2917 - val_accuracy: 0.8903
# Epoch 162/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1956 - accuracy: 0.9293 - val_loss: 0.2735 - val_accuracy: 0.9044
# Epoch 163/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1862 - accuracy: 0.9371 - val_loss: 0.2681 - val_accuracy: 0.9072
# Epoch 164/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1847 - accuracy: 0.9307 - val_loss: 0.2559 - val_accuracy: 0.9072
# Epoch 165/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1833 - accuracy: 0.9339 - val_loss: 0.2730 - val_accuracy: 0.9044
# Epoch 166/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1750 - accuracy: 0.9392 - val_loss: 0.2708 - val_accuracy: 0.9044
# Epoch 167/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1724 - accuracy: 0.9360 - val_loss: 0.2624 - val_accuracy: 0.9100
# Epoch 168/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1870 - accuracy: 0.9304 - val_loss: 0.2425 - val_accuracy: 0.9241
# Epoch 169/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1707 - accuracy: 0.9353 - val_loss: 0.2608 - val_accuracy: 0.9142
# Epoch 170/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1794 - accuracy: 0.9353 - val_loss: 0.2453 - val_accuracy: 0.9212
# Epoch 171/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1754 - accuracy: 0.9385 - val_loss: 0.2481 - val_accuracy: 0.9241
# Epoch 172/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1636 - accuracy: 0.9413 - val_loss: 0.2441 - val_accuracy: 0.9212
# Epoch 173/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1674 - accuracy: 0.9381 - val_loss: 0.2513 - val_accuracy: 0.9114
# Epoch 174/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1653 - accuracy: 0.9434 - val_loss: 0.2501 - val_accuracy: 0.9198
# Epoch 175/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1575 - accuracy: 0.9459 - val_loss: 0.2531 - val_accuracy: 0.9156
# Epoch 176/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1627 - accuracy: 0.9399 - val_loss: 0.2455 - val_accuracy: 0.9241
# Epoch 177/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1644 - accuracy: 0.9423 - val_loss: 0.2460 - val_accuracy: 0.9198
# Epoch 178/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1646 - accuracy: 0.9381 - val_loss: 0.2569 - val_accuracy: 0.9114
# Epoch 179/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1706 - accuracy: 0.9402 - val_loss: 0.2382 - val_accuracy: 0.9297
# Epoch 180/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1635 - accuracy: 0.9441 - val_loss: 0.2554 - val_accuracy: 0.9170
# Epoch 181/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1573 - accuracy: 0.9434 - val_loss: 0.2398 - val_accuracy: 0.9297
# Epoch 182/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1633 - accuracy: 0.9427 - val_loss: 0.2416 - val_accuracy: 0.9255
# Epoch 183/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1589 - accuracy: 0.9459 - val_loss: 0.2370 - val_accuracy: 0.9198
# Epoch 184/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1615 - accuracy: 0.9402 - val_loss: 0.2406 - val_accuracy: 0.9269
# Epoch 185/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1610 - accuracy: 0.9437 - val_loss: 0.2703 - val_accuracy: 0.9030
# Epoch 186/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1685 - accuracy: 0.9406 - val_loss: 0.3030 - val_accuracy: 0.9030
# Epoch 187/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1726 - accuracy: 0.9342 - val_loss: 0.2671 - val_accuracy: 0.9044
# Epoch 188/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1758 - accuracy: 0.9360 - val_loss: 0.2355 - val_accuracy: 0.9325
# Epoch 189/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.1687 - accuracy: 0.9409 - val_loss: 0.2737 - val_accuracy: 0.9086
# Epoch 190/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1762 - accuracy: 0.9364 - val_loss: 0.2432 - val_accuracy: 0.9198
# Epoch 191/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1692 - accuracy: 0.9346 - val_loss: 0.2550 - val_accuracy: 0.9198
# Epoch 192/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1749 - accuracy: 0.9346 - val_loss: 0.2440 - val_accuracy: 0.9212
# Epoch 193/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1566 - accuracy: 0.9441 - val_loss: 0.2410 - val_accuracy: 0.9170
# Epoch 194/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1516 - accuracy: 0.9451 - val_loss: 0.2494 - val_accuracy: 0.9226
# Epoch 195/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1568 - accuracy: 0.9402 - val_loss: 0.2324 - val_accuracy: 0.9311
# Epoch 196/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1541 - accuracy: 0.9441 - val_loss: 0.2371 - val_accuracy: 0.9241
# Epoch 197/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1547 - accuracy: 0.9451 - val_loss: 0.2315 - val_accuracy: 0.9255
# Epoch 198/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1499 - accuracy: 0.9455 - val_loss: 0.2372 - val_accuracy: 0.9255
# Epoch 199/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1635 - accuracy: 0.9395 - val_loss: 0.2383 - val_accuracy: 0.9255
# Epoch 200/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1576 - accuracy: 0.9392 - val_loss: 0.2282 - val_accuracy: 0.9311

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 6/6 [==============================] - 1s 87ms/step - loss: 1.7498 - accuracy: 0.3400 - val_loss: 1.3655 - val_accuracy: 0.6273
# Epoch 2/60
# 6/6 [==============================] - 0s 44ms/step - loss: 1.2067 - accuracy: 0.6206 - val_loss: 1.0524 - val_accuracy: 0.6512
# Epoch 3/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.9368 - accuracy: 0.6790 - val_loss: 0.8476 - val_accuracy: 0.7131
# Epoch 4/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.7858 - accuracy: 0.7096 - val_loss: 0.7296 - val_accuracy: 0.7328
# Epoch 5/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.6844 - accuracy: 0.7222 - val_loss: 0.6348 - val_accuracy: 0.7581
# Epoch 6/60
# 6/6 [==============================] - 0s 47ms/step - loss: 0.6305 - accuracy: 0.7412 - val_loss: 0.5973 - val_accuracy: 0.7834
# Epoch 7/60
# 6/6 [==============================] - 0s 48ms/step - loss: 0.5964 - accuracy: 0.7539 - val_loss: 0.5892 - val_accuracy: 0.7553
# Epoch 8/60
# 6/6 [==============================] - 0s 45ms/step - loss: 0.5975 - accuracy: 0.7567 - val_loss: 0.5793 - val_accuracy: 0.7736
# Epoch 9/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.5952 - accuracy: 0.7563 - val_loss: 0.6179 - val_accuracy: 0.6990
# Epoch 10/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.5580 - accuracy: 0.7714 - val_loss: 0.5392 - val_accuracy: 0.7806
# Epoch 11/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.5240 - accuracy: 0.7940 - val_loss: 0.5389 - val_accuracy: 0.7932
# Epoch 12/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.5065 - accuracy: 0.7971 - val_loss: 0.5280 - val_accuracy: 0.8172
# Epoch 13/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.5080 - accuracy: 0.7971 - val_loss: 0.5159 - val_accuracy: 0.8158
# Epoch 14/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4973 - accuracy: 0.7996 - val_loss: 0.5020 - val_accuracy: 0.8228
# Epoch 15/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4861 - accuracy: 0.8140 - val_loss: 0.5157 - val_accuracy: 0.7975
# Epoch 16/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4752 - accuracy: 0.8129 - val_loss: 0.4990 - val_accuracy: 0.8073
# Epoch 17/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4596 - accuracy: 0.8179 - val_loss: 0.5531 - val_accuracy: 0.7961
# Epoch 18/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4934 - accuracy: 0.7915 - val_loss: 0.5647 - val_accuracy: 0.7932
# Epoch 19/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.4911 - accuracy: 0.7978 - val_loss: 0.5336 - val_accuracy: 0.7947
# Epoch 20/60
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4780 - accuracy: 0.8049 - val_loss: 0.4925 - val_accuracy: 0.8031
# Epoch 21/60
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4532 - accuracy: 0.8252 - val_loss: 0.4749 - val_accuracy: 0.8003
# Epoch 22/60
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4471 - accuracy: 0.8263 - val_loss: 0.4883 - val_accuracy: 0.8284
# Epoch 23/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.4491 - accuracy: 0.8337 - val_loss: 0.4582 - val_accuracy: 0.8368
# Epoch 24/60
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4407 - accuracy: 0.8288 - val_loss: 0.4554 - val_accuracy: 0.8186
# Epoch 25/60
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4255 - accuracy: 0.8418 - val_loss: 0.4485 - val_accuracy: 0.8312
# Epoch 26/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.4080 - accuracy: 0.8421 - val_loss: 0.4519 - val_accuracy: 0.8270
# Epoch 27/60
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4020 - accuracy: 0.8477 - val_loss: 0.4412 - val_accuracy: 0.8326
# Epoch 28/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4013 - accuracy: 0.8456 - val_loss: 0.4490 - val_accuracy: 0.8326
# Epoch 29/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4012 - accuracy: 0.8463 - val_loss: 0.4323 - val_accuracy: 0.8326
# Epoch 30/60
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3947 - accuracy: 0.8488 - val_loss: 0.4538 - val_accuracy: 0.8228
# Epoch 31/60
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3933 - accuracy: 0.8474 - val_loss: 0.4290 - val_accuracy: 0.8425
# Epoch 32/60
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3961 - accuracy: 0.8551 - val_loss: 0.4269 - val_accuracy: 0.8298
# Epoch 33/60
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3821 - accuracy: 0.8488 - val_loss: 0.4274 - val_accuracy: 0.8256
# Epoch 34/60
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3811 - accuracy: 0.8572 - val_loss: 0.4233 - val_accuracy: 0.8411
# Epoch 35/60
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3863 - accuracy: 0.8551 - val_loss: 0.4152 - val_accuracy: 0.8579
# Epoch 36/60
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3824 - accuracy: 0.8499 - val_loss: 0.4271 - val_accuracy: 0.8298
# Epoch 37/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3754 - accuracy: 0.8544 - val_loss: 0.4097 - val_accuracy: 0.8495
# Epoch 38/60
# 6/6 [==============================] - 1s 118ms/step - loss: 0.3765 - accuracy: 0.8576 - val_loss: 0.4086 - val_accuracy: 0.8481
# Epoch 39/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3760 - accuracy: 0.8660 - val_loss: 0.4149 - val_accuracy: 0.8523
# Epoch 40/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3704 - accuracy: 0.8590 - val_loss: 0.3995 - val_accuracy: 0.8425
# Epoch 41/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3600 - accuracy: 0.8611 - val_loss: 0.4260 - val_accuracy: 0.8298
# Epoch 42/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3710 - accuracy: 0.8534 - val_loss: 0.4561 - val_accuracy: 0.8340
# Epoch 43/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3637 - accuracy: 0.8650 - val_loss: 0.4462 - val_accuracy: 0.8354
# Epoch 44/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3704 - accuracy: 0.8590 - val_loss: 0.4199 - val_accuracy: 0.8411
# Epoch 45/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3582 - accuracy: 0.8643 - val_loss: 0.3868 - val_accuracy: 0.8523
# Epoch 46/60
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3638 - accuracy: 0.8657 - val_loss: 0.3980 - val_accuracy: 0.8551
# Epoch 47/60
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3621 - accuracy: 0.8625 - val_loss: 0.4034 - val_accuracy: 0.8523
# Epoch 48/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3671 - accuracy: 0.8636 - val_loss: 0.4172 - val_accuracy: 0.8383
# Epoch 49/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3550 - accuracy: 0.8667 - val_loss: 0.3962 - val_accuracy: 0.8453
# Epoch 50/60
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3446 - accuracy: 0.8664 - val_loss: 0.3797 - val_accuracy: 0.8636
# Epoch 51/60
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3413 - accuracy: 0.8780 - val_loss: 0.3867 - val_accuracy: 0.8439
# Epoch 52/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3429 - accuracy: 0.8752 - val_loss: 0.3929 - val_accuracy: 0.8551
# Epoch 53/60
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3426 - accuracy: 0.8724 - val_loss: 0.3726 - val_accuracy: 0.8579
# Epoch 54/60
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3306 - accuracy: 0.8833 - val_loss: 0.3906 - val_accuracy: 0.8439
# Epoch 55/60
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3316 - accuracy: 0.8755 - val_loss: 0.3709 - val_accuracy: 0.8636
# Epoch 56/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3257 - accuracy: 0.8787 - val_loss: 0.3666 - val_accuracy: 0.8636
# Epoch 57/60
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3307 - accuracy: 0.8776 - val_loss: 0.3698 - val_accuracy: 0.8594
# Epoch 58/60
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3147 - accuracy: 0.8878 - val_loss: 0.3668 - val_accuracy: 0.8594
# Epoch 59/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3246 - accuracy: 0.8787 - val_loss: 0.3612 - val_accuracy: 0.8608
# Epoch 60/60
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3278 - accuracy: 0.8734 - val_loss: 0.3753 - val_accuracy: 0.8537

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 5ms/step - loss: 0.2859 - accuracy: 0.8949
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3753 - accuracy: 0.8537
# 0.894866406917572 0.8537271618843079

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 170, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  99   0   1   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 233   6   0   0   1]
#  [  0   0   0  48  49   1   0   2]
#  [  0   0   0   0   1  11   0   0]
#  [  1   0   0   0   0   3   7   0]
#  [  0   0   0  33   4   0   0   9]]
#
# Accuracy Score
# 0.8537271448663853
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.99      1.00      0.99        80
#      clouds       1.00      0.99      0.99       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.73      0.97      0.84       240
#     windows       0.82      0.49      0.61       100
#       roads       0.73      0.92      0.81        12
#        cars       1.00      0.64      0.78        11
#       metal       0.75      0.20      0.31        46
#
# avg / total       0.86      0.85      0.84       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 170
# [[0, 5], [5, 10], [10, 15], [15, 20], [20, 25], [25, 30], [30, 35], [35, 40], [40, 45], [45, 50], [50, 55], [55, 60], [60, 65], [65, 70], [70, 75], [75, 80], [80, 85], [85, 90], [90, 95], [95, 100], [100, 105], [105, 110], [110, 115], [115, 120], [120, 125], [125, 130], [130, 135], [135, 140], [140, 145], [145, 150], [150, 155], [155, 160], [160, 165], [165, 170], [170, 175], [175, 180], [180, 185], [185, 190], [190, 195], [195, 200], [200, 205], [205, 210], [210, 215], [215, 220], [220, 225], [225, 230], [230, 235], [235, 240], [240, 245], [245, 250], [250, 255], [255, 260], [260, 265], [265, 270], [270, 275], [275, 280], [280, 285], [285, 290], [290, 295], [295, 300], [300, 305], [305, 310], [310, 315], [315, 320], [320, 325], [325, 330], [330, 335], [335, 340], [340, 345], [345, 350], [350, 355], [355, 360], [360, 365], [365, 370], [370, 375], [375, 380], [380, 385], [385, 390], [390, 395], [395, 400], [400, 405], [405, 410], [410, 415], [415, 420], [420, 425], [425, 430], [430, 435], [435, 440], [440, 445], [445, 450], [450, 455], [455, 460], [460, 465], [465, 470], [470, 475], [475, 480], [480, 485], [485, 490], [490, 495], [495, 500], [500, 505], [505, 510], [510, 515], [515, 520], [520, 525], [525, 530], [530, 535], [535, 540], [540, 545], [545, 550], [550, 555], [555, 560], [560, 565], [565, 570], [570, 575], [575, 580], [580, 585], [585, 590], [590, 595], [595, 600], [600, 605], [605, 610], [610, 615], [615, 620], [620, 625], [625, 630], [630, 635], [635, 640], [640, 645], [645, 650], [650, 655], [655, 660], [660, 665], [665, 670], [670, 675], [675, 680], [680, 685], [685, 690], [690, 695], [695, 700], [700, 705], [705, 710], [710, 715], [715, 720], [720, 725], [725, 730], [730, 735], [735, 740], [740, 745], [745, 750], [750, 755], [755, 760], [760, 765], [765, 770], [770, 775], [775, 780], [780, 785], [785, 790], [790, 795], [795, 800], [800, 805], [805, 810], [810, 815], [815, 820], [820, 825], [825, 830], [830, 835], [835, 840], [840, 845], [845, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 170)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 170)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 170)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 170) (60, 170)
# clouds  (160, 170) (40, 170)
# vegetation  (560, 170) (140, 170)
# water  (496, 170) (124, 170)
# built  (1280, 170) (320, 170)
# windows  (480, 170) (120, 170)
# roads  (200, 170) (50, 170)
# cars  (200, 170) (50, 170)
# metal  (148, 170) (37, 170)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 170) (3764,) (3764, 2)
# (941, 170) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 71ms/step - loss: 1.8138 - accuracy: 0.3656 - val_loss: 1.5126 - val_accuracy: 0.5016
# Epoch 2/200
# 8/8 [==============================] - 0s 51ms/step - loss: 1.4196 - accuracy: 0.5109 - val_loss: 1.3086 - val_accuracy: 0.5250
# Epoch 3/200
# 8/8 [==============================] - 0s 48ms/step - loss: 1.2754 - accuracy: 0.5430 - val_loss: 1.1741 - val_accuracy: 0.6259
# Epoch 4/200
# 8/8 [==============================] - 0s 44ms/step - loss: 1.1610 - accuracy: 0.5768 - val_loss: 1.0676 - val_accuracy: 0.6142
# Epoch 5/200
# 8/8 [==============================] - 0s 43ms/step - loss: 1.0413 - accuracy: 0.6360 - val_loss: 0.9595 - val_accuracy: 0.6908
# Epoch 6/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.9635 - accuracy: 0.6730 - val_loss: 0.8818 - val_accuracy: 0.7450
# Epoch 7/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.8799 - accuracy: 0.7157 - val_loss: 0.8184 - val_accuracy: 0.7651
# Epoch 8/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.8244 - accuracy: 0.7420 - val_loss: 0.7685 - val_accuracy: 0.7768
# Epoch 9/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7866 - accuracy: 0.7497 - val_loss: 0.7348 - val_accuracy: 0.7779
# Epoch 10/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7567 - accuracy: 0.7487 - val_loss: 0.6968 - val_accuracy: 0.7821
# Epoch 11/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.7203 - accuracy: 0.7633 - val_loss: 0.6711 - val_accuracy: 0.7938
# Epoch 12/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.7033 - accuracy: 0.7635 - val_loss: 0.6573 - val_accuracy: 0.7832
# Epoch 13/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6801 - accuracy: 0.7715 - val_loss: 0.6419 - val_accuracy: 0.8013
# Epoch 14/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.6644 - accuracy: 0.7779 - val_loss: 0.6430 - val_accuracy: 0.7864
# Epoch 15/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6539 - accuracy: 0.7792 - val_loss: 0.5935 - val_accuracy: 0.8321
# Epoch 16/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6330 - accuracy: 0.7856 - val_loss: 0.5947 - val_accuracy: 0.8130
# Epoch 17/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6097 - accuracy: 0.7941 - val_loss: 0.5853 - val_accuracy: 0.8130
# Epoch 18/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5952 - accuracy: 0.8026 - val_loss: 0.5609 - val_accuracy: 0.8321
# Epoch 19/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5738 - accuracy: 0.8087 - val_loss: 0.5535 - val_accuracy: 0.8395
# Epoch 20/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5770 - accuracy: 0.8140 - val_loss: 0.5557 - val_accuracy: 0.8353
# Epoch 21/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5684 - accuracy: 0.8122 - val_loss: 0.5740 - val_accuracy: 0.8023
# Epoch 22/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5742 - accuracy: 0.8029 - val_loss: 0.5641 - val_accuracy: 0.8013
# Epoch 23/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5595 - accuracy: 0.8095 - val_loss: 0.5227 - val_accuracy: 0.8470
# Epoch 24/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5482 - accuracy: 0.8209 - val_loss: 0.5127 - val_accuracy: 0.8555
# Epoch 25/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5321 - accuracy: 0.8244 - val_loss: 0.5235 - val_accuracy: 0.8193
# Epoch 26/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5399 - accuracy: 0.8201 - val_loss: 0.5168 - val_accuracy: 0.8448
# Epoch 27/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5193 - accuracy: 0.8302 - val_loss: 0.5084 - val_accuracy: 0.8438
# Epoch 28/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5190 - accuracy: 0.8321 - val_loss: 0.4793 - val_accuracy: 0.8629
# Epoch 29/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5005 - accuracy: 0.8371 - val_loss: 0.4988 - val_accuracy: 0.8459
# Epoch 30/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5030 - accuracy: 0.8387 - val_loss: 0.4793 - val_accuracy: 0.8544
# Epoch 31/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4939 - accuracy: 0.8390 - val_loss: 0.4748 - val_accuracy: 0.8533
# Epoch 32/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4913 - accuracy: 0.8448 - val_loss: 0.4613 - val_accuracy: 0.8725
# Epoch 33/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4809 - accuracy: 0.8433 - val_loss: 0.4579 - val_accuracy: 0.8650
# Epoch 34/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4740 - accuracy: 0.8491 - val_loss: 0.4715 - val_accuracy: 0.8629
# Epoch 35/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4538 - accuracy: 0.8584 - val_loss: 0.4429 - val_accuracy: 0.8789
# Epoch 36/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4516 - accuracy: 0.8547 - val_loss: 0.4422 - val_accuracy: 0.8778
# Epoch 37/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4538 - accuracy: 0.8536 - val_loss: 0.4434 - val_accuracy: 0.8810
# Epoch 38/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4487 - accuracy: 0.8571 - val_loss: 0.4417 - val_accuracy: 0.8789
# Epoch 39/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4522 - accuracy: 0.8587 - val_loss: 0.4459 - val_accuracy: 0.8629
# Epoch 40/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4386 - accuracy: 0.8581 - val_loss: 0.4296 - val_accuracy: 0.8863
# Epoch 41/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4377 - accuracy: 0.8587 - val_loss: 0.4235 - val_accuracy: 0.8884
# Epoch 42/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4312 - accuracy: 0.8621 - val_loss: 0.4224 - val_accuracy: 0.8789
# Epoch 43/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4306 - accuracy: 0.8650 - val_loss: 0.4112 - val_accuracy: 0.8852
# Epoch 44/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4087 - accuracy: 0.8725 - val_loss: 0.4089 - val_accuracy: 0.8810
# Epoch 45/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4076 - accuracy: 0.8714 - val_loss: 0.4220 - val_accuracy: 0.8831
# Epoch 46/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4015 - accuracy: 0.8765 - val_loss: 0.4041 - val_accuracy: 0.8895
# Epoch 47/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4051 - accuracy: 0.8738 - val_loss: 0.4014 - val_accuracy: 0.8874
# Epoch 48/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4149 - accuracy: 0.8725 - val_loss: 0.4199 - val_accuracy: 0.8810
# Epoch 49/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4014 - accuracy: 0.8738 - val_loss: 0.3906 - val_accuracy: 0.8799
# Epoch 50/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3875 - accuracy: 0.8767 - val_loss: 0.3926 - val_accuracy: 0.8927
# Epoch 51/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3861 - accuracy: 0.8786 - val_loss: 0.3921 - val_accuracy: 0.8863
# Epoch 52/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3813 - accuracy: 0.8765 - val_loss: 0.3928 - val_accuracy: 0.8948
# Epoch 53/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3815 - accuracy: 0.8796 - val_loss: 0.3700 - val_accuracy: 0.8895
# Epoch 54/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3731 - accuracy: 0.8810 - val_loss: 0.3818 - val_accuracy: 0.8959
# Epoch 55/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3639 - accuracy: 0.8844 - val_loss: 0.3772 - val_accuracy: 0.8916
# Epoch 56/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3638 - accuracy: 0.8855 - val_loss: 0.3837 - val_accuracy: 0.8863
# Epoch 57/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3672 - accuracy: 0.8812 - val_loss: 0.3756 - val_accuracy: 0.8969
# Epoch 58/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3633 - accuracy: 0.8871 - val_loss: 0.3817 - val_accuracy: 0.8937
# Epoch 59/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3556 - accuracy: 0.8858 - val_loss: 0.3700 - val_accuracy: 0.8927
# Epoch 60/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3512 - accuracy: 0.8919 - val_loss: 0.3575 - val_accuracy: 0.9001
# Epoch 61/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3550 - accuracy: 0.8868 - val_loss: 0.3623 - val_accuracy: 0.8927
# Epoch 62/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3533 - accuracy: 0.8868 - val_loss: 0.3680 - val_accuracy: 0.8842
# Epoch 63/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3709 - accuracy: 0.8791 - val_loss: 0.3972 - val_accuracy: 0.8757
# Epoch 64/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3670 - accuracy: 0.8799 - val_loss: 0.4006 - val_accuracy: 0.8863
# Epoch 65/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3539 - accuracy: 0.8876 - val_loss: 0.3681 - val_accuracy: 0.9001
# Epoch 66/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3457 - accuracy: 0.8929 - val_loss: 0.3744 - val_accuracy: 0.8884
# Epoch 67/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3525 - accuracy: 0.8810 - val_loss: 0.3470 - val_accuracy: 0.9118
# Epoch 68/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3274 - accuracy: 0.8998 - val_loss: 0.3556 - val_accuracy: 0.8927
# Epoch 69/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3279 - accuracy: 0.8982 - val_loss: 0.3426 - val_accuracy: 0.9001
# Epoch 70/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3162 - accuracy: 0.9033 - val_loss: 0.3514 - val_accuracy: 0.8810
# Epoch 71/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3249 - accuracy: 0.9004 - val_loss: 0.3433 - val_accuracy: 0.9001
# Epoch 72/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3168 - accuracy: 0.9012 - val_loss: 0.3460 - val_accuracy: 0.9001
# Epoch 73/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3108 - accuracy: 0.8996 - val_loss: 0.3553 - val_accuracy: 0.8990
# Epoch 74/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3060 - accuracy: 0.8959 - val_loss: 0.3552 - val_accuracy: 0.9001
# Epoch 75/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3254 - accuracy: 0.8974 - val_loss: 0.3489 - val_accuracy: 0.8948
# Epoch 76/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3059 - accuracy: 0.9022 - val_loss: 0.3422 - val_accuracy: 0.8842
# Epoch 77/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3083 - accuracy: 0.9036 - val_loss: 0.3408 - val_accuracy: 0.8959
# Epoch 78/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3153 - accuracy: 0.8996 - val_loss: 0.3443 - val_accuracy: 0.9075
# Epoch 79/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2976 - accuracy: 0.9049 - val_loss: 0.3458 - val_accuracy: 0.8980
# Epoch 80/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2973 - accuracy: 0.9067 - val_loss: 0.3240 - val_accuracy: 0.8980
# Epoch 81/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2932 - accuracy: 0.9057 - val_loss: 0.3258 - val_accuracy: 0.9012
# Epoch 82/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2891 - accuracy: 0.9070 - val_loss: 0.3349 - val_accuracy: 0.9022
# Epoch 83/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2953 - accuracy: 0.9067 - val_loss: 0.3324 - val_accuracy: 0.9054
# Epoch 84/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2889 - accuracy: 0.9110 - val_loss: 0.3220 - val_accuracy: 0.8980
# Epoch 85/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2837 - accuracy: 0.9089 - val_loss: 0.3218 - val_accuracy: 0.9107
# Epoch 86/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2770 - accuracy: 0.9102 - val_loss: 0.3261 - val_accuracy: 0.9065
# Epoch 87/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2849 - accuracy: 0.9054 - val_loss: 0.3253 - val_accuracy: 0.8969
# Epoch 88/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2810 - accuracy: 0.9126 - val_loss: 0.3260 - val_accuracy: 0.9065
# Epoch 89/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2822 - accuracy: 0.9121 - val_loss: 0.3123 - val_accuracy: 0.9044
# Epoch 90/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2905 - accuracy: 0.9060 - val_loss: 0.3248 - val_accuracy: 0.9001
# Epoch 91/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2763 - accuracy: 0.9081 - val_loss: 0.3086 - val_accuracy: 0.9097
# Epoch 92/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2667 - accuracy: 0.9142 - val_loss: 0.3122 - val_accuracy: 0.9086
# Epoch 93/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2715 - accuracy: 0.9163 - val_loss: 0.3229 - val_accuracy: 0.9012
# Epoch 94/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2585 - accuracy: 0.9126 - val_loss: 0.3157 - val_accuracy: 0.9097
# Epoch 95/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2601 - accuracy: 0.9179 - val_loss: 0.3419 - val_accuracy: 0.8895
# Epoch 96/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2936 - accuracy: 0.9062 - val_loss: 0.3251 - val_accuracy: 0.9012
# Epoch 97/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2685 - accuracy: 0.9123 - val_loss: 0.3177 - val_accuracy: 0.8980
# Epoch 98/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2702 - accuracy: 0.9113 - val_loss: 0.3119 - val_accuracy: 0.9012
# Epoch 99/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2625 - accuracy: 0.9137 - val_loss: 0.3037 - val_accuracy: 0.9075
# Epoch 100/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2654 - accuracy: 0.9121 - val_loss: 0.3249 - val_accuracy: 0.9022
# Epoch 101/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2604 - accuracy: 0.9203 - val_loss: 0.3086 - val_accuracy: 0.9107
# Epoch 102/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2638 - accuracy: 0.9195 - val_loss: 0.3105 - val_accuracy: 0.9086
# Epoch 103/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2495 - accuracy: 0.9232 - val_loss: 0.2998 - val_accuracy: 0.9075
# Epoch 104/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2487 - accuracy: 0.9187 - val_loss: 0.3086 - val_accuracy: 0.9012
# Epoch 105/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2495 - accuracy: 0.9206 - val_loss: 0.3053 - val_accuracy: 0.9129
# Epoch 106/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2440 - accuracy: 0.9200 - val_loss: 0.3101 - val_accuracy: 0.9075
# Epoch 107/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2426 - accuracy: 0.9224 - val_loss: 0.3002 - val_accuracy: 0.9086
# Epoch 108/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2338 - accuracy: 0.9238 - val_loss: 0.3294 - val_accuracy: 0.8959
# Epoch 109/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2510 - accuracy: 0.9230 - val_loss: 0.2971 - val_accuracy: 0.9075
# Epoch 110/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2376 - accuracy: 0.9269 - val_loss: 0.2940 - val_accuracy: 0.9097
# Epoch 111/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2308 - accuracy: 0.9230 - val_loss: 0.2975 - val_accuracy: 0.9097
# Epoch 112/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2342 - accuracy: 0.9245 - val_loss: 0.3090 - val_accuracy: 0.9075
# Epoch 113/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2413 - accuracy: 0.9195 - val_loss: 0.3173 - val_accuracy: 0.8948
# Epoch 114/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2425 - accuracy: 0.9224 - val_loss: 0.3022 - val_accuracy: 0.9118
# Epoch 115/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2615 - accuracy: 0.9139 - val_loss: 0.2974 - val_accuracy: 0.9065
# Epoch 116/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2446 - accuracy: 0.9195 - val_loss: 0.2912 - val_accuracy: 0.9086
# Epoch 117/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2348 - accuracy: 0.9275 - val_loss: 0.3048 - val_accuracy: 0.9097
# Epoch 118/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2470 - accuracy: 0.9176 - val_loss: 0.2949 - val_accuracy: 0.9022
# Epoch 119/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2286 - accuracy: 0.9235 - val_loss: 0.2972 - val_accuracy: 0.9075
# Epoch 120/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2375 - accuracy: 0.9206 - val_loss: 0.3061 - val_accuracy: 0.9075
# Epoch 121/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2380 - accuracy: 0.9235 - val_loss: 0.3112 - val_accuracy: 0.9118
# Epoch 122/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2504 - accuracy: 0.9171 - val_loss: 0.2952 - val_accuracy: 0.9107
# Epoch 123/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2321 - accuracy: 0.9200 - val_loss: 0.3284 - val_accuracy: 0.8969
# Epoch 124/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2470 - accuracy: 0.9195 - val_loss: 0.2891 - val_accuracy: 0.9107
# Epoch 125/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2289 - accuracy: 0.9235 - val_loss: 0.2994 - val_accuracy: 0.9097
# Epoch 126/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2252 - accuracy: 0.9317 - val_loss: 0.2875 - val_accuracy: 0.9107
# Epoch 127/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2137 - accuracy: 0.9315 - val_loss: 0.2894 - val_accuracy: 0.9118
# Epoch 128/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2128 - accuracy: 0.9328 - val_loss: 0.2876 - val_accuracy: 0.9075
# Epoch 129/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2160 - accuracy: 0.9288 - val_loss: 0.2950 - val_accuracy: 0.9097
# Epoch 130/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2260 - accuracy: 0.9277 - val_loss: 0.2905 - val_accuracy: 0.9107
# Epoch 131/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2238 - accuracy: 0.9269 - val_loss: 0.3051 - val_accuracy: 0.9065
# Epoch 132/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2094 - accuracy: 0.9338 - val_loss: 0.2882 - val_accuracy: 0.9160
# Epoch 133/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2097 - accuracy: 0.9341 - val_loss: 0.2876 - val_accuracy: 0.9097
# Epoch 134/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2099 - accuracy: 0.9346 - val_loss: 0.2819 - val_accuracy: 0.9150
# Epoch 135/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2097 - accuracy: 0.9336 - val_loss: 0.3081 - val_accuracy: 0.9097
# Epoch 136/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2177 - accuracy: 0.9261 - val_loss: 0.3088 - val_accuracy: 0.9097
# Epoch 137/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2121 - accuracy: 0.9293 - val_loss: 0.2864 - val_accuracy: 0.9129
# Epoch 138/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2146 - accuracy: 0.9344 - val_loss: 0.2971 - val_accuracy: 0.9160
# Epoch 139/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2289 - accuracy: 0.9245 - val_loss: 0.2914 - val_accuracy: 0.9192
# Epoch 140/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2249 - accuracy: 0.9296 - val_loss: 0.3199 - val_accuracy: 0.9107
# Epoch 141/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2125 - accuracy: 0.9336 - val_loss: 0.2796 - val_accuracy: 0.9129
# Epoch 142/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1993 - accuracy: 0.9323 - val_loss: 0.2887 - val_accuracy: 0.9097
# Epoch 143/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1965 - accuracy: 0.9397 - val_loss: 0.2921 - val_accuracy: 0.9107
# Epoch 144/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1975 - accuracy: 0.9346 - val_loss: 0.2844 - val_accuracy: 0.9182
# Epoch 145/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2053 - accuracy: 0.9362 - val_loss: 0.2869 - val_accuracy: 0.9160
# Epoch 146/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2048 - accuracy: 0.9349 - val_loss: 0.3051 - val_accuracy: 0.9086
# Epoch 147/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2098 - accuracy: 0.9291 - val_loss: 0.2991 - val_accuracy: 0.9129
# Epoch 148/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1883 - accuracy: 0.9400 - val_loss: 0.2906 - val_accuracy: 0.9150
# Epoch 149/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1943 - accuracy: 0.9360 - val_loss: 0.2771 - val_accuracy: 0.9150
# Epoch 150/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1823 - accuracy: 0.9408 - val_loss: 0.2835 - val_accuracy: 0.9171
# Epoch 151/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1870 - accuracy: 0.9423 - val_loss: 0.2849 - val_accuracy: 0.9150
# Epoch 152/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1930 - accuracy: 0.9416 - val_loss: 0.3016 - val_accuracy: 0.9160
# Epoch 153/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1947 - accuracy: 0.9376 - val_loss: 0.2940 - val_accuracy: 0.9118
# Epoch 154/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1911 - accuracy: 0.9370 - val_loss: 0.2752 - val_accuracy: 0.9160
# Epoch 155/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1863 - accuracy: 0.9418 - val_loss: 0.2782 - val_accuracy: 0.9192
# Epoch 156/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1820 - accuracy: 0.9418 - val_loss: 0.3572 - val_accuracy: 0.8895
# Epoch 157/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2444 - accuracy: 0.9222 - val_loss: 0.3133 - val_accuracy: 0.9086
# Epoch 158/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2116 - accuracy: 0.9325 - val_loss: 0.2975 - val_accuracy: 0.9150
# Epoch 159/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1931 - accuracy: 0.9392 - val_loss: 0.2701 - val_accuracy: 0.9171
# Epoch 160/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1877 - accuracy: 0.9389 - val_loss: 0.3053 - val_accuracy: 0.9150
# Epoch 161/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1936 - accuracy: 0.9365 - val_loss: 0.2842 - val_accuracy: 0.9139
# Epoch 162/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1832 - accuracy: 0.9416 - val_loss: 0.2636 - val_accuracy: 0.9203
# Epoch 163/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1880 - accuracy: 0.9392 - val_loss: 0.2980 - val_accuracy: 0.9192
# Epoch 164/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1868 - accuracy: 0.9392 - val_loss: 0.2745 - val_accuracy: 0.9224
# Epoch 165/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1745 - accuracy: 0.9453 - val_loss: 0.2744 - val_accuracy: 0.9171
# Epoch 166/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1780 - accuracy: 0.9397 - val_loss: 0.2826 - val_accuracy: 0.9160
# Epoch 167/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1754 - accuracy: 0.9431 - val_loss: 0.2952 - val_accuracy: 0.9139
# Epoch 168/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1746 - accuracy: 0.9439 - val_loss: 0.2755 - val_accuracy: 0.9182
# Epoch 169/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1664 - accuracy: 0.9453 - val_loss: 0.2747 - val_accuracy: 0.9224
# Epoch 170/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1743 - accuracy: 0.9442 - val_loss: 0.2792 - val_accuracy: 0.9214
# Epoch 171/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1761 - accuracy: 0.9458 - val_loss: 0.2900 - val_accuracy: 0.9171
# Epoch 172/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1798 - accuracy: 0.9397 - val_loss: 0.2745 - val_accuracy: 0.9203
# Epoch 173/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1696 - accuracy: 0.9442 - val_loss: 0.2700 - val_accuracy: 0.9267
# Epoch 174/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1671 - accuracy: 0.9450 - val_loss: 0.2727 - val_accuracy: 0.9182
# Epoch 175/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1652 - accuracy: 0.9455 - val_loss: 0.2767 - val_accuracy: 0.9192
# Epoch 176/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1609 - accuracy: 0.9479 - val_loss: 0.2678 - val_accuracy: 0.9192
# Epoch 177/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1584 - accuracy: 0.9495 - val_loss: 0.2643 - val_accuracy: 0.9150
# Epoch 178/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1719 - accuracy: 0.9429 - val_loss: 0.2889 - val_accuracy: 0.9097
# Epoch 179/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1753 - accuracy: 0.9423 - val_loss: 0.2701 - val_accuracy: 0.9203
# Epoch 180/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1707 - accuracy: 0.9453 - val_loss: 0.2699 - val_accuracy: 0.9171
# Epoch 181/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1616 - accuracy: 0.9447 - val_loss: 0.2873 - val_accuracy: 0.9214
# Epoch 182/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1824 - accuracy: 0.9413 - val_loss: 0.2785 - val_accuracy: 0.9171
# Epoch 183/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1695 - accuracy: 0.9416 - val_loss: 0.2723 - val_accuracy: 0.9267
# Epoch 184/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1678 - accuracy: 0.9442 - val_loss: 0.2920 - val_accuracy: 0.9139
# Epoch 185/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1653 - accuracy: 0.9471 - val_loss: 0.2717 - val_accuracy: 0.9224
# Epoch 186/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1625 - accuracy: 0.9498 - val_loss: 0.2697 - val_accuracy: 0.9203
# Epoch 187/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1571 - accuracy: 0.9516 - val_loss: 0.2764 - val_accuracy: 0.9192
# Epoch 188/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1489 - accuracy: 0.9495 - val_loss: 0.2680 - val_accuracy: 0.9299
# Epoch 189/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1546 - accuracy: 0.9453 - val_loss: 0.2796 - val_accuracy: 0.9182
# Epoch 190/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1482 - accuracy: 0.9498 - val_loss: 0.2697 - val_accuracy: 0.9224
# Epoch 191/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1523 - accuracy: 0.9482 - val_loss: 0.2688 - val_accuracy: 0.9288
# Epoch 192/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1550 - accuracy: 0.9485 - val_loss: 0.2703 - val_accuracy: 0.9203
# Epoch 193/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1482 - accuracy: 0.9527 - val_loss: 0.2739 - val_accuracy: 0.9192
# Epoch 194/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1510 - accuracy: 0.9524 - val_loss: 0.2778 - val_accuracy: 0.9245
# Epoch 195/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1607 - accuracy: 0.9495 - val_loss: 0.2669 - val_accuracy: 0.9203
# Epoch 196/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1500 - accuracy: 0.9501 - val_loss: 0.2850 - val_accuracy: 0.9150
# Epoch 197/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.1528 - accuracy: 0.9527 - val_loss: 0.2601 - val_accuracy: 0.9256
# Epoch 198/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1473 - accuracy: 0.9546 - val_loss: 0.2714 - val_accuracy: 0.9192
# Epoch 199/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1490 - accuracy: 0.9530 - val_loss: 0.2604 - val_accuracy: 0.9224
# Epoch 200/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1479 - accuracy: 0.9506 - val_loss: 0.2587 - val_accuracy: 0.9299

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 8/8 [==============================] - 0s 61ms/step - loss: 1.7513 - accuracy: 0.3924 - val_loss: 1.4224 - val_accuracy: 0.4665
# Epoch 2/60
# 8/8 [==============================] - 0s 43ms/step - loss: 1.3589 - accuracy: 0.5231 - val_loss: 1.2596 - val_accuracy: 0.5239
# Epoch 3/60
# 8/8 [==============================] - 0s 41ms/step - loss: 1.2205 - accuracy: 0.5614 - val_loss: 1.1298 - val_accuracy: 0.6971
# Epoch 4/60
# 8/8 [==============================] - 0s 43ms/step - loss: 1.1156 - accuracy: 0.6065 - val_loss: 1.0260 - val_accuracy: 0.6727
# Epoch 5/60
# 8/8 [==============================] - 0s 40ms/step - loss: 1.0237 - accuracy: 0.6281 - val_loss: 0.9598 - val_accuracy: 0.6886
# Epoch 6/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.9597 - accuracy: 0.6575 - val_loss: 0.8587 - val_accuracy: 0.7333
# Epoch 7/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.8723 - accuracy: 0.7163 - val_loss: 0.8225 - val_accuracy: 0.7343
# Epoch 8/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.8209 - accuracy: 0.7303 - val_loss: 0.7520 - val_accuracy: 0.7821
# Epoch 9/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.7816 - accuracy: 0.7402 - val_loss: 0.7250 - val_accuracy: 0.7673
# Epoch 10/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.7427 - accuracy: 0.7450 - val_loss: 0.6856 - val_accuracy: 0.7843
# Epoch 11/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.7193 - accuracy: 0.7651 - val_loss: 0.6632 - val_accuracy: 0.7864
# Epoch 12/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6952 - accuracy: 0.7675 - val_loss: 0.6598 - val_accuracy: 0.7641
# Epoch 13/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6701 - accuracy: 0.7736 - val_loss: 0.6344 - val_accuracy: 0.7991
# Epoch 14/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6525 - accuracy: 0.7784 - val_loss: 0.6030 - val_accuracy: 0.8013
# Epoch 15/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6268 - accuracy: 0.7914 - val_loss: 0.5933 - val_accuracy: 0.8193
# Epoch 16/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6154 - accuracy: 0.7912 - val_loss: 0.5781 - val_accuracy: 0.8140
# Epoch 17/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6157 - accuracy: 0.7885 - val_loss: 0.5680 - val_accuracy: 0.8183
# Epoch 18/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5911 - accuracy: 0.7991 - val_loss: 0.5844 - val_accuracy: 0.8002
# Epoch 19/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5871 - accuracy: 0.7981 - val_loss: 0.5458 - val_accuracy: 0.8257
# Epoch 20/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5774 - accuracy: 0.8061 - val_loss: 0.5741 - val_accuracy: 0.8045
# Epoch 21/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5689 - accuracy: 0.8106 - val_loss: 0.5322 - val_accuracy: 0.8385
# Epoch 22/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5543 - accuracy: 0.8193 - val_loss: 0.5364 - val_accuracy: 0.8342
# Epoch 23/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.5471 - accuracy: 0.8172 - val_loss: 0.5067 - val_accuracy: 0.8587
# Epoch 24/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5378 - accuracy: 0.8209 - val_loss: 0.5269 - val_accuracy: 0.8512
# Epoch 25/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5433 - accuracy: 0.8177 - val_loss: 0.5202 - val_accuracy: 0.8427
# Epoch 26/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5245 - accuracy: 0.8286 - val_loss: 0.5009 - val_accuracy: 0.8533
# Epoch 27/60
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5160 - accuracy: 0.8324 - val_loss: 0.5012 - val_accuracy: 0.8332
# Epoch 28/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4954 - accuracy: 0.8387 - val_loss: 0.4872 - val_accuracy: 0.8629
# Epoch 29/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4877 - accuracy: 0.8403 - val_loss: 0.4913 - val_accuracy: 0.8353
# Epoch 30/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4838 - accuracy: 0.8419 - val_loss: 0.4640 - val_accuracy: 0.8576
# Epoch 31/60
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4807 - accuracy: 0.8451 - val_loss: 0.4645 - val_accuracy: 0.8523
# Epoch 32/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4776 - accuracy: 0.8438 - val_loss: 0.4509 - val_accuracy: 0.8629
# Epoch 33/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4635 - accuracy: 0.8502 - val_loss: 0.4489 - val_accuracy: 0.8725
# Epoch 34/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4685 - accuracy: 0.8499 - val_loss: 0.4632 - val_accuracy: 0.8640
# Epoch 35/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4529 - accuracy: 0.8595 - val_loss: 0.4487 - val_accuracy: 0.8682
# Epoch 36/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4405 - accuracy: 0.8589 - val_loss: 0.4356 - val_accuracy: 0.8789
# Epoch 37/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4381 - accuracy: 0.8648 - val_loss: 0.4273 - val_accuracy: 0.8799
# Epoch 38/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4355 - accuracy: 0.8595 - val_loss: 0.4587 - val_accuracy: 0.8650
# Epoch 39/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4410 - accuracy: 0.8533 - val_loss: 0.4396 - val_accuracy: 0.8704
# Epoch 40/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4254 - accuracy: 0.8629 - val_loss: 0.4201 - val_accuracy: 0.8831
# Epoch 41/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4204 - accuracy: 0.8682 - val_loss: 0.4123 - val_accuracy: 0.8767
# Epoch 42/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4059 - accuracy: 0.8680 - val_loss: 0.4203 - val_accuracy: 0.8799
# Epoch 43/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4087 - accuracy: 0.8677 - val_loss: 0.4093 - val_accuracy: 0.8852
# Epoch 44/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4072 - accuracy: 0.8725 - val_loss: 0.4065 - val_accuracy: 0.8789
# Epoch 45/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3977 - accuracy: 0.8730 - val_loss: 0.4031 - val_accuracy: 0.8757
# Epoch 46/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4023 - accuracy: 0.8719 - val_loss: 0.4248 - val_accuracy: 0.8470
# Epoch 47/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3961 - accuracy: 0.8640 - val_loss: 0.4032 - val_accuracy: 0.8831
# Epoch 48/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3834 - accuracy: 0.8770 - val_loss: 0.3943 - val_accuracy: 0.8884
# Epoch 49/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3842 - accuracy: 0.8770 - val_loss: 0.3828 - val_accuracy: 0.8842
# Epoch 50/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3767 - accuracy: 0.8810 - val_loss: 0.3827 - val_accuracy: 0.8852
# Epoch 51/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3723 - accuracy: 0.8844 - val_loss: 0.3859 - val_accuracy: 0.8842
# Epoch 52/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3875 - accuracy: 0.8759 - val_loss: 0.4515 - val_accuracy: 0.8629
# Epoch 53/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4064 - accuracy: 0.8674 - val_loss: 0.3992 - val_accuracy: 0.8874
# Epoch 54/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3816 - accuracy: 0.8807 - val_loss: 0.3862 - val_accuracy: 0.8852
# Epoch 55/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3765 - accuracy: 0.8834 - val_loss: 0.3854 - val_accuracy: 0.8842
# Epoch 56/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3688 - accuracy: 0.8807 - val_loss: 0.4008 - val_accuracy: 0.8852
# Epoch 57/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3718 - accuracy: 0.8794 - val_loss: 0.3955 - val_accuracy: 0.8895
# Epoch 58/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3549 - accuracy: 0.8879 - val_loss: 0.3708 - val_accuracy: 0.8969
# Epoch 59/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3498 - accuracy: 0.8900 - val_loss: 0.3630 - val_accuracy: 0.8969
# Epoch 60/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3436 - accuracy: 0.8916 - val_loss: 0.3649 - val_accuracy: 0.8959

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 5ms/step - loss: 0.2962 - accuracy: 0.9070
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3649 - accuracy: 0.8959
# 0.9070138335227966 0.8958554863929749

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 170, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:49

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   1   0   0   0   0   0]
#  [  0   0   0 121   1   0   0   0   2]
#  [  0   0   0   1 309   7   1   2   0]
#  [  0   0   0   0   8 102   8   1   1]
#  [  0   0   1   0  10   7  30   0   2]
#  [  0   0   0   0  14   7   0  29   0]
#  [  0   0   0   2  13   7   0   2  13]]
#
# Accuracy Score
# 0.895855472901169
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.97      0.98      0.97       124
#       built       0.87      0.97      0.92       320
#     windows       0.78      0.85      0.82       120
#       roads       0.77      0.60      0.67        50
#        cars       0.85      0.58      0.69        50
#       metal       0.72      0.35      0.47        37
#
# avg / total       0.89      0.90      0.89       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
# Out:
# 170 10
