# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 122
filtersize = 7
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 122
# [[0, 6], [6, 12], [12, 18], [18, 24], [24, 30], [30, 36], [36, 42], [42, 48], [48, 54], [54, 60], [60, 66], [66, 72], [72, 78], [78, 84], [84, 90], [90, 96], [96, 102], [102, 108], [108, 114], [114, 120], [120, 126], [126, 132], [132, 138], [138, 144], [144, 150], [150, 156], [156, 162], [162, 168], [168, 174], [174, 180], [180, 186], [186, 192], [192, 198], [198, 204], [204, 210], [210, 216], [216, 222], [222, 228], [228, 234], [234, 240], [240, 246], [246, 252], [252, 258], [258, 264], [264, 270], [270, 276], [276, 282], [282, 288], [288, 294], [294, 300], [300, 306], [306, 312], [312, 318], [318, 324], [324, 330], [330, 336], [336, 342], [342, 348], [348, 354], [354, 360], [360, 366], [366, 372], [372, 378], [378, 384], [384, 390], [390, 396], [396, 402], [402, 408], [408, 414], [414, 420], [420, 426], [426, 432], [432, 438], [438, 444], [444, 450], [450, 456], [456, 462], [462, 468], [468, 474], [474, 480], [480, 486], [486, 492], [492, 498], [498, 504], [504, 510], [510, 516], [516, 522], [522, 528], [528, 534], [534, 540], [540, 546], [546, 552], [552, 558], [558, 564], [564, 570], [570, 576], [576, 582], [582, 588], [588, 594], [594, 600], [600, 606], [606, 612], [612, 618], [618, 624], [624, 630], [630, 636], [636, 642], [642, 648], [648, 654], [654, 660], [660, 666], [666, 672], [672, 678], [678, 684], [684, 690], [690, 696], [696, 702], [702, 708], [708, 714], [714, 720], [720, 726], [726, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 122)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 122)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 122) (60, 122)
# clouds  (400, 122) (100, 122)
# vegetation  (480, 122) (120, 122)
# water  (40, 122) (10, 122)
# built  (816, 122) (204, 122)
# windows  (400, 122) (100, 122)
# roads  (24, 122) (6, 122)
# cars  (80, 122) (20, 122)
# metal  (80, 122) (20, 122)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 122) (2560,) (2560, 2)
# (640, 122) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 111ms/step - loss: 1.7789 - accuracy: 0.3695 - val_loss: 1.3207 - val_accuracy: 0.6516
# Epoch 2/200
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2418 - accuracy: 0.6668 - val_loss: 0.9921 - val_accuracy: 0.6984
# Epoch 3/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.9800 - accuracy: 0.6848 - val_loss: 0.8342 - val_accuracy: 0.7344
# Epoch 4/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.8472 - accuracy: 0.7289 - val_loss: 0.7265 - val_accuracy: 0.8234
# Epoch 5/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7674 - accuracy: 0.7691 - val_loss: 0.6896 - val_accuracy: 0.7969
# Epoch 6/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7199 - accuracy: 0.7797 - val_loss: 0.6306 - val_accuracy: 0.8094
# Epoch 7/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6718 - accuracy: 0.7953 - val_loss: 0.5894 - val_accuracy: 0.8469
# Epoch 8/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.6442 - accuracy: 0.8035 - val_loss: 0.5493 - val_accuracy: 0.8203
# Epoch 9/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5858 - accuracy: 0.8199 - val_loss: 0.5360 - val_accuracy: 0.8250
# Epoch 10/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.5741 - accuracy: 0.8215 - val_loss: 0.4908 - val_accuracy: 0.8641
# Epoch 11/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5402 - accuracy: 0.8270 - val_loss: 0.4766 - val_accuracy: 0.8625
# Epoch 12/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5304 - accuracy: 0.8320 - val_loss: 0.4523 - val_accuracy: 0.8516
# Epoch 13/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5117 - accuracy: 0.8316 - val_loss: 0.4583 - val_accuracy: 0.8375
# Epoch 14/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4971 - accuracy: 0.8387 - val_loss: 0.4229 - val_accuracy: 0.8562
# Epoch 15/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4724 - accuracy: 0.8551 - val_loss: 0.4359 - val_accuracy: 0.8594
# Epoch 16/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.4856 - accuracy: 0.8477 - val_loss: 0.3981 - val_accuracy: 0.8734
# Epoch 17/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.4423 - accuracy: 0.8590 - val_loss: 0.3893 - val_accuracy: 0.8813
# Epoch 18/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4402 - accuracy: 0.8594 - val_loss: 0.3819 - val_accuracy: 0.8875
# Epoch 19/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4294 - accuracy: 0.8645 - val_loss: 0.3821 - val_accuracy: 0.8891
# Epoch 20/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4281 - accuracy: 0.8707 - val_loss: 0.3711 - val_accuracy: 0.8859
# Epoch 21/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.4127 - accuracy: 0.8754 - val_loss: 0.3517 - val_accuracy: 0.9094
# Epoch 22/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3933 - accuracy: 0.8785 - val_loss: 0.3475 - val_accuracy: 0.8969
# Epoch 23/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3929 - accuracy: 0.8770 - val_loss: 0.3396 - val_accuracy: 0.8969
# Epoch 24/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3791 - accuracy: 0.8770 - val_loss: 0.3322 - val_accuracy: 0.9016
# Epoch 25/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3698 - accuracy: 0.8840 - val_loss: 0.3212 - val_accuracy: 0.9047
# Epoch 26/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3712 - accuracy: 0.8809 - val_loss: 0.3269 - val_accuracy: 0.9062
# Epoch 27/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3733 - accuracy: 0.8855 - val_loss: 0.3137 - val_accuracy: 0.9078
# Epoch 28/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3527 - accuracy: 0.8930 - val_loss: 0.3124 - val_accuracy: 0.9141
# Epoch 29/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3559 - accuracy: 0.8871 - val_loss: 0.3031 - val_accuracy: 0.9078
# Epoch 30/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3438 - accuracy: 0.8930 - val_loss: 0.2989 - val_accuracy: 0.9109
# Epoch 31/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3346 - accuracy: 0.8906 - val_loss: 0.3030 - val_accuracy: 0.9094
# Epoch 32/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3360 - accuracy: 0.8906 - val_loss: 0.2969 - val_accuracy: 0.9156
# Epoch 33/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3393 - accuracy: 0.8973 - val_loss: 0.2920 - val_accuracy: 0.9047
# Epoch 34/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3324 - accuracy: 0.8887 - val_loss: 0.2787 - val_accuracy: 0.9172
# Epoch 35/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3250 - accuracy: 0.9000 - val_loss: 0.2837 - val_accuracy: 0.9094
# Epoch 36/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3204 - accuracy: 0.9023 - val_loss: 0.2720 - val_accuracy: 0.9172
# Epoch 37/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3158 - accuracy: 0.9055 - val_loss: 0.2683 - val_accuracy: 0.9187
# Epoch 38/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3058 - accuracy: 0.9004 - val_loss: 0.2647 - val_accuracy: 0.9172
# Epoch 39/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3055 - accuracy: 0.9070 - val_loss: 0.2600 - val_accuracy: 0.9187
# Epoch 40/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3035 - accuracy: 0.9070 - val_loss: 0.2596 - val_accuracy: 0.9156
# Epoch 41/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2978 - accuracy: 0.9043 - val_loss: 0.2581 - val_accuracy: 0.9187
# Epoch 42/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2917 - accuracy: 0.9012 - val_loss: 0.2522 - val_accuracy: 0.9156
# Epoch 43/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2869 - accuracy: 0.9082 - val_loss: 0.2488 - val_accuracy: 0.9156
# Epoch 44/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2879 - accuracy: 0.9070 - val_loss: 0.2534 - val_accuracy: 0.9141
# Epoch 45/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2849 - accuracy: 0.9062 - val_loss: 0.2438 - val_accuracy: 0.9187
# Epoch 46/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2810 - accuracy: 0.9117 - val_loss: 0.2422 - val_accuracy: 0.9187
# Epoch 47/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2784 - accuracy: 0.9090 - val_loss: 0.2488 - val_accuracy: 0.9156
# Epoch 48/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2746 - accuracy: 0.9113 - val_loss: 0.2367 - val_accuracy: 0.9250
# Epoch 49/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2783 - accuracy: 0.9098 - val_loss: 0.2294 - val_accuracy: 0.9187
# Epoch 50/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2676 - accuracy: 0.9172 - val_loss: 0.2327 - val_accuracy: 0.9187
# Epoch 51/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2612 - accuracy: 0.9156 - val_loss: 0.2238 - val_accuracy: 0.9203
# Epoch 52/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2604 - accuracy: 0.9180 - val_loss: 0.2429 - val_accuracy: 0.9141
# Epoch 53/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2665 - accuracy: 0.9113 - val_loss: 0.2263 - val_accuracy: 0.9187
# Epoch 54/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2588 - accuracy: 0.9141 - val_loss: 0.2172 - val_accuracy: 0.9203
# Epoch 55/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2597 - accuracy: 0.9195 - val_loss: 0.2148 - val_accuracy: 0.9203
# Epoch 56/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2572 - accuracy: 0.9172 - val_loss: 0.2211 - val_accuracy: 0.9250
# Epoch 57/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2566 - accuracy: 0.9180 - val_loss: 0.2138 - val_accuracy: 0.9219
# Epoch 58/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2508 - accuracy: 0.9172 - val_loss: 0.2120 - val_accuracy: 0.9250
# Epoch 59/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2475 - accuracy: 0.9172 - val_loss: 0.2082 - val_accuracy: 0.9266
# Epoch 60/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2448 - accuracy: 0.9203 - val_loss: 0.2125 - val_accuracy: 0.9219
# Epoch 61/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2420 - accuracy: 0.9187 - val_loss: 0.2069 - val_accuracy: 0.9312
# Epoch 62/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2361 - accuracy: 0.9219 - val_loss: 0.2061 - val_accuracy: 0.9234
# Epoch 63/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2374 - accuracy: 0.9211 - val_loss: 0.1993 - val_accuracy: 0.9250
# Epoch 64/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2303 - accuracy: 0.9238 - val_loss: 0.1993 - val_accuracy: 0.9297
# Epoch 65/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2279 - accuracy: 0.9285 - val_loss: 0.1933 - val_accuracy: 0.9281
# Epoch 66/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2313 - accuracy: 0.9238 - val_loss: 0.1938 - val_accuracy: 0.9312
# Epoch 67/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2235 - accuracy: 0.9320 - val_loss: 0.1937 - val_accuracy: 0.9234
# Epoch 68/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2245 - accuracy: 0.9293 - val_loss: 0.1908 - val_accuracy: 0.9234
# Epoch 69/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2219 - accuracy: 0.9258 - val_loss: 0.1946 - val_accuracy: 0.9438
# Epoch 70/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2299 - accuracy: 0.9309 - val_loss: 0.2059 - val_accuracy: 0.9219
# Epoch 71/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2255 - accuracy: 0.9230 - val_loss: 0.1883 - val_accuracy: 0.9391
# Epoch 72/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2207 - accuracy: 0.9270 - val_loss: 0.1910 - val_accuracy: 0.9297
# Epoch 73/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2230 - accuracy: 0.9270 - val_loss: 0.1859 - val_accuracy: 0.9266
# Epoch 74/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2133 - accuracy: 0.9297 - val_loss: 0.1977 - val_accuracy: 0.9297
# Epoch 75/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2173 - accuracy: 0.9262 - val_loss: 0.1858 - val_accuracy: 0.9203
# Epoch 76/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2094 - accuracy: 0.9305 - val_loss: 0.1815 - val_accuracy: 0.9328
# Epoch 77/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2070 - accuracy: 0.9324 - val_loss: 0.1803 - val_accuracy: 0.9375
# Epoch 78/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2047 - accuracy: 0.9320 - val_loss: 0.1829 - val_accuracy: 0.9266
# Epoch 79/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1974 - accuracy: 0.9340 - val_loss: 0.1731 - val_accuracy: 0.9438
# Epoch 80/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2016 - accuracy: 0.9301 - val_loss: 0.1760 - val_accuracy: 0.9297
# Epoch 81/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2019 - accuracy: 0.9355 - val_loss: 0.1713 - val_accuracy: 0.9344
# Epoch 82/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2048 - accuracy: 0.9324 - val_loss: 0.1686 - val_accuracy: 0.9531
# Epoch 83/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1959 - accuracy: 0.9344 - val_loss: 0.1808 - val_accuracy: 0.9281
# Epoch 84/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1949 - accuracy: 0.9363 - val_loss: 0.1718 - val_accuracy: 0.9453
# Epoch 85/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1910 - accuracy: 0.9324 - val_loss: 0.1648 - val_accuracy: 0.9359
# Epoch 86/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1927 - accuracy: 0.9355 - val_loss: 0.1713 - val_accuracy: 0.9531
# Epoch 87/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2011 - accuracy: 0.9344 - val_loss: 0.1638 - val_accuracy: 0.9453
# Epoch 88/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1895 - accuracy: 0.9367 - val_loss: 0.1687 - val_accuracy: 0.9266
# Epoch 89/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1938 - accuracy: 0.9352 - val_loss: 0.1626 - val_accuracy: 0.9516
# Epoch 90/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1865 - accuracy: 0.9383 - val_loss: 0.1624 - val_accuracy: 0.9453
# Epoch 91/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1880 - accuracy: 0.9367 - val_loss: 0.1681 - val_accuracy: 0.9312
# Epoch 92/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1877 - accuracy: 0.9363 - val_loss: 0.1636 - val_accuracy: 0.9578
# Epoch 93/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1870 - accuracy: 0.9379 - val_loss: 0.1714 - val_accuracy: 0.9422
# Epoch 94/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1910 - accuracy: 0.9371 - val_loss: 0.1730 - val_accuracy: 0.9500
# Epoch 95/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1878 - accuracy: 0.9395 - val_loss: 0.1660 - val_accuracy: 0.9312
# Epoch 96/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1894 - accuracy: 0.9344 - val_loss: 0.1514 - val_accuracy: 0.9531
# Epoch 97/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1742 - accuracy: 0.9398 - val_loss: 0.1501 - val_accuracy: 0.9453
# Epoch 98/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1715 - accuracy: 0.9445 - val_loss: 0.1552 - val_accuracy: 0.9531
# Epoch 99/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1786 - accuracy: 0.9379 - val_loss: 0.1562 - val_accuracy: 0.9500
# Epoch 100/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1819 - accuracy: 0.9430 - val_loss: 0.1554 - val_accuracy: 0.9406
# Epoch 101/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1879 - accuracy: 0.9391 - val_loss: 0.1548 - val_accuracy: 0.9578
# Epoch 102/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1821 - accuracy: 0.9363 - val_loss: 0.1462 - val_accuracy: 0.9500
# Epoch 103/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1828 - accuracy: 0.9410 - val_loss: 0.1649 - val_accuracy: 0.9344
# Epoch 104/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1832 - accuracy: 0.9359 - val_loss: 0.1541 - val_accuracy: 0.9516
# Epoch 105/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1823 - accuracy: 0.9359 - val_loss: 0.1518 - val_accuracy: 0.9516
# Epoch 106/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1725 - accuracy: 0.9426 - val_loss: 0.1444 - val_accuracy: 0.9578
# Epoch 107/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1745 - accuracy: 0.9449 - val_loss: 0.1618 - val_accuracy: 0.9484
# Epoch 108/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1773 - accuracy: 0.9414 - val_loss: 0.1496 - val_accuracy: 0.9438
# Epoch 109/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1701 - accuracy: 0.9441 - val_loss: 0.1461 - val_accuracy: 0.9516
# Epoch 110/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1661 - accuracy: 0.9422 - val_loss: 0.1373 - val_accuracy: 0.9484
# Epoch 111/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1668 - accuracy: 0.9449 - val_loss: 0.1381 - val_accuracy: 0.9547
# Epoch 112/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1562 - accuracy: 0.9469 - val_loss: 0.1359 - val_accuracy: 0.9500
# Epoch 113/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1669 - accuracy: 0.9438 - val_loss: 0.1554 - val_accuracy: 0.9484
# Epoch 114/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1656 - accuracy: 0.9461 - val_loss: 0.1329 - val_accuracy: 0.9547
# Epoch 115/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1608 - accuracy: 0.9434 - val_loss: 0.1330 - val_accuracy: 0.9578
# Epoch 116/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1663 - accuracy: 0.9422 - val_loss: 0.1378 - val_accuracy: 0.9547
# Epoch 117/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1649 - accuracy: 0.9461 - val_loss: 0.1365 - val_accuracy: 0.9531
# Epoch 118/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1647 - accuracy: 0.9453 - val_loss: 0.1340 - val_accuracy: 0.9531
# Epoch 119/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1540 - accuracy: 0.9465 - val_loss: 0.1467 - val_accuracy: 0.9563
# Epoch 120/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1576 - accuracy: 0.9480 - val_loss: 0.1319 - val_accuracy: 0.9516
# Epoch 121/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1524 - accuracy: 0.9469 - val_loss: 0.1309 - val_accuracy: 0.9594
# Epoch 122/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1593 - accuracy: 0.9445 - val_loss: 0.1317 - val_accuracy: 0.9516
# Epoch 123/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1497 - accuracy: 0.9523 - val_loss: 0.1319 - val_accuracy: 0.9547
# Epoch 124/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1488 - accuracy: 0.9492 - val_loss: 0.1306 - val_accuracy: 0.9547
# Epoch 125/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1564 - accuracy: 0.9484 - val_loss: 0.1301 - val_accuracy: 0.9609
# Epoch 126/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1480 - accuracy: 0.9559 - val_loss: 0.1289 - val_accuracy: 0.9547
# Epoch 127/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1598 - accuracy: 0.9426 - val_loss: 0.1253 - val_accuracy: 0.9578
# Epoch 128/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1543 - accuracy: 0.9434 - val_loss: 0.1324 - val_accuracy: 0.9578
# Epoch 129/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1623 - accuracy: 0.9422 - val_loss: 0.1344 - val_accuracy: 0.9453
# Epoch 130/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1499 - accuracy: 0.9512 - val_loss: 0.1364 - val_accuracy: 0.9531
# Epoch 131/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1457 - accuracy: 0.9516 - val_loss: 0.1196 - val_accuracy: 0.9594
# Epoch 132/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1483 - accuracy: 0.9520 - val_loss: 0.1214 - val_accuracy: 0.9609
# Epoch 133/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1579 - accuracy: 0.9410 - val_loss: 0.1295 - val_accuracy: 0.9594
# Epoch 134/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1552 - accuracy: 0.9438 - val_loss: 0.1452 - val_accuracy: 0.9516
# Epoch 135/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1600 - accuracy: 0.9461 - val_loss: 0.1411 - val_accuracy: 0.9500
# Epoch 136/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1672 - accuracy: 0.9391 - val_loss: 0.1549 - val_accuracy: 0.9406
# Epoch 137/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1629 - accuracy: 0.9480 - val_loss: 0.1593 - val_accuracy: 0.9359
# Epoch 138/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1579 - accuracy: 0.9457 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 139/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1587 - accuracy: 0.9473 - val_loss: 0.1350 - val_accuracy: 0.9516
# Epoch 140/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1452 - accuracy: 0.9512 - val_loss: 0.1237 - val_accuracy: 0.9656
# Epoch 141/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1480 - accuracy: 0.9492 - val_loss: 0.1225 - val_accuracy: 0.9531
# Epoch 142/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1459 - accuracy: 0.9508 - val_loss: 0.1307 - val_accuracy: 0.9531
# Epoch 143/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1459 - accuracy: 0.9480 - val_loss: 0.1144 - val_accuracy: 0.9641
# Epoch 144/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1406 - accuracy: 0.9574 - val_loss: 0.1197 - val_accuracy: 0.9563
# Epoch 145/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1386 - accuracy: 0.9504 - val_loss: 0.1225 - val_accuracy: 0.9609
# Epoch 146/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1457 - accuracy: 0.9512 - val_loss: 0.1307 - val_accuracy: 0.9547
# Epoch 147/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1478 - accuracy: 0.9512 - val_loss: 0.1407 - val_accuracy: 0.9547
# Epoch 148/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1428 - accuracy: 0.9500 - val_loss: 0.1217 - val_accuracy: 0.9531
# Epoch 149/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1469 - accuracy: 0.9516 - val_loss: 0.1223 - val_accuracy: 0.9625
# Epoch 150/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1298 - accuracy: 0.9570 - val_loss: 0.1187 - val_accuracy: 0.9547
# Epoch 151/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1382 - accuracy: 0.9527 - val_loss: 0.1183 - val_accuracy: 0.9594
# Epoch 152/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1375 - accuracy: 0.9543 - val_loss: 0.1147 - val_accuracy: 0.9609
# Epoch 153/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1318 - accuracy: 0.9508 - val_loss: 0.1153 - val_accuracy: 0.9609
# Epoch 154/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1216 - accuracy: 0.9617 - val_loss: 0.1297 - val_accuracy: 0.9500
# Epoch 155/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1555 - accuracy: 0.9445 - val_loss: 0.1129 - val_accuracy: 0.9609
# Epoch 156/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1368 - accuracy: 0.9535 - val_loss: 0.1240 - val_accuracy: 0.9563
# Epoch 157/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1454 - accuracy: 0.9512 - val_loss: 0.1209 - val_accuracy: 0.9578
# Epoch 158/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1427 - accuracy: 0.9543 - val_loss: 0.1226 - val_accuracy: 0.9547
# Epoch 159/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1254 - accuracy: 0.9563 - val_loss: 0.1112 - val_accuracy: 0.9625
# Epoch 160/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1365 - accuracy: 0.9547 - val_loss: 0.1076 - val_accuracy: 0.9609
# Epoch 161/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1344 - accuracy: 0.9535 - val_loss: 0.1149 - val_accuracy: 0.9563
# Epoch 162/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1340 - accuracy: 0.9555 - val_loss: 0.1165 - val_accuracy: 0.9547
# Epoch 163/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1295 - accuracy: 0.9512 - val_loss: 0.1166 - val_accuracy: 0.9609
# Epoch 164/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1296 - accuracy: 0.9520 - val_loss: 0.1100 - val_accuracy: 0.9609
# Epoch 165/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1207 - accuracy: 0.9609 - val_loss: 0.1110 - val_accuracy: 0.9563
# Epoch 166/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1216 - accuracy: 0.9586 - val_loss: 0.1114 - val_accuracy: 0.9563
# Epoch 167/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1312 - accuracy: 0.9535 - val_loss: 0.1026 - val_accuracy: 0.9656
# Epoch 168/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1294 - accuracy: 0.9543 - val_loss: 0.1104 - val_accuracy: 0.9656
# Epoch 169/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1296 - accuracy: 0.9598 - val_loss: 0.1072 - val_accuracy: 0.9625
# Epoch 170/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1264 - accuracy: 0.9590 - val_loss: 0.1027 - val_accuracy: 0.9641
# Epoch 171/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1295 - accuracy: 0.9574 - val_loss: 0.1070 - val_accuracy: 0.9672
# Epoch 172/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1193 - accuracy: 0.9602 - val_loss: 0.1012 - val_accuracy: 0.9641
# Epoch 173/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1166 - accuracy: 0.9578 - val_loss: 0.1006 - val_accuracy: 0.9625
# Epoch 174/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1210 - accuracy: 0.9621 - val_loss: 0.1043 - val_accuracy: 0.9641
# Epoch 175/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1133 - accuracy: 0.9582 - val_loss: 0.1076 - val_accuracy: 0.9609
# Epoch 176/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1307 - accuracy: 0.9563 - val_loss: 0.0978 - val_accuracy: 0.9656
# Epoch 177/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1214 - accuracy: 0.9551 - val_loss: 0.1149 - val_accuracy: 0.9531
# Epoch 178/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1268 - accuracy: 0.9566 - val_loss: 0.1071 - val_accuracy: 0.9625
# Epoch 179/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1278 - accuracy: 0.9566 - val_loss: 0.1067 - val_accuracy: 0.9578
# Epoch 180/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1215 - accuracy: 0.9621 - val_loss: 0.1086 - val_accuracy: 0.9625
# Epoch 181/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1141 - accuracy: 0.9598 - val_loss: 0.1110 - val_accuracy: 0.9578
# Epoch 182/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1281 - accuracy: 0.9578 - val_loss: 0.1023 - val_accuracy: 0.9625
# Epoch 183/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1165 - accuracy: 0.9578 - val_loss: 0.1173 - val_accuracy: 0.9563
# Epoch 184/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1325 - accuracy: 0.9555 - val_loss: 0.0999 - val_accuracy: 0.9719
# Epoch 185/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1282 - accuracy: 0.9598 - val_loss: 0.0998 - val_accuracy: 0.9625
# Epoch 186/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1136 - accuracy: 0.9629 - val_loss: 0.1029 - val_accuracy: 0.9641
# Epoch 187/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1166 - accuracy: 0.9633 - val_loss: 0.1076 - val_accuracy: 0.9672
# Epoch 188/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1158 - accuracy: 0.9598 - val_loss: 0.0957 - val_accuracy: 0.9609
# Epoch 189/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1209 - accuracy: 0.9574 - val_loss: 0.1016 - val_accuracy: 0.9641
# Epoch 190/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1191 - accuracy: 0.9625 - val_loss: 0.1025 - val_accuracy: 0.9641
# Epoch 191/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1194 - accuracy: 0.9590 - val_loss: 0.0984 - val_accuracy: 0.9594
# Epoch 192/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1132 - accuracy: 0.9594 - val_loss: 0.1015 - val_accuracy: 0.9641
# Epoch 193/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1163 - accuracy: 0.9559 - val_loss: 0.0982 - val_accuracy: 0.9641
# Epoch 194/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1097 - accuracy: 0.9563 - val_loss: 0.0959 - val_accuracy: 0.9641
# Epoch 195/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1176 - accuracy: 0.9582 - val_loss: 0.0998 - val_accuracy: 0.9594
# Epoch 196/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1121 - accuracy: 0.9602 - val_loss: 0.1050 - val_accuracy: 0.9734
# Epoch 197/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1100 - accuracy: 0.9664 - val_loss: 0.0976 - val_accuracy: 0.9641
# Epoch 198/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1092 - accuracy: 0.9609 - val_loss: 0.1006 - val_accuracy: 0.9703
# Epoch 199/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1062 - accuracy: 0.9660 - val_loss: 0.0940 - val_accuracy: 0.9594
# Epoch 200/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1028 - accuracy: 0.9648 - val_loss: 0.0910 - val_accuracy: 0.9656

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 5/5 [==============================] - 0s 81ms/step - loss: 1.6834 - accuracy: 0.4301 - val_loss: 1.2538 - val_accuracy: 0.7031
# Epoch 2/60
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1777 - accuracy: 0.6621 - val_loss: 0.9581 - val_accuracy: 0.7281
# Epoch 3/60
# 5/5 [==============================] - 0s 47ms/step - loss: 0.9382 - accuracy: 0.7066 - val_loss: 0.7981 - val_accuracy: 0.7578
# Epoch 4/60
# 5/5 [==============================] - 0s 42ms/step - loss: 0.8120 - accuracy: 0.7492 - val_loss: 0.7229 - val_accuracy: 0.7859
# Epoch 5/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7652 - accuracy: 0.7660 - val_loss: 0.6662 - val_accuracy: 0.8016
# Epoch 6/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7080 - accuracy: 0.7816 - val_loss: 0.6456 - val_accuracy: 0.8047
# Epoch 7/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.6954 - accuracy: 0.7824 - val_loss: 0.5909 - val_accuracy: 0.8078
# Epoch 8/60
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6541 - accuracy: 0.7934 - val_loss: 0.5713 - val_accuracy: 0.8172
# Epoch 9/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6239 - accuracy: 0.8031 - val_loss: 0.5653 - val_accuracy: 0.8359
# Epoch 10/60
# 5/5 [==============================] - 0s 39ms/step - loss: 0.5879 - accuracy: 0.8180 - val_loss: 0.5149 - val_accuracy: 0.8297
# Epoch 11/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5578 - accuracy: 0.8223 - val_loss: 0.4961 - val_accuracy: 0.8313
# Epoch 12/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5343 - accuracy: 0.8270 - val_loss: 0.4732 - val_accuracy: 0.8672
# Epoch 13/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.5256 - accuracy: 0.8305 - val_loss: 0.4461 - val_accuracy: 0.8625
# Epoch 14/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.5045 - accuracy: 0.8410 - val_loss: 0.4346 - val_accuracy: 0.8734
# Epoch 15/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4895 - accuracy: 0.8492 - val_loss: 0.4210 - val_accuracy: 0.8656
# Epoch 16/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4693 - accuracy: 0.8551 - val_loss: 0.4162 - val_accuracy: 0.8375
# Epoch 17/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.4570 - accuracy: 0.8555 - val_loss: 0.4018 - val_accuracy: 0.8531
# Epoch 18/60
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4466 - accuracy: 0.8633 - val_loss: 0.3859 - val_accuracy: 0.8656
# Epoch 19/60
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4184 - accuracy: 0.8730 - val_loss: 0.3759 - val_accuracy: 0.8875
# Epoch 20/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.4258 - accuracy: 0.8687 - val_loss: 0.3660 - val_accuracy: 0.9000
# Epoch 21/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.4091 - accuracy: 0.8758 - val_loss: 0.3511 - val_accuracy: 0.9031
# Epoch 22/60
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4016 - accuracy: 0.8746 - val_loss: 0.3483 - val_accuracy: 0.9000
# Epoch 23/60
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3975 - accuracy: 0.8813 - val_loss: 0.3510 - val_accuracy: 0.9062
# Epoch 24/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3948 - accuracy: 0.8770 - val_loss: 0.3350 - val_accuracy: 0.9016
# Epoch 25/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3918 - accuracy: 0.8832 - val_loss: 0.3429 - val_accuracy: 0.8969
# Epoch 26/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3802 - accuracy: 0.8824 - val_loss: 0.3255 - val_accuracy: 0.9109
# Epoch 27/60
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3690 - accuracy: 0.8844 - val_loss: 0.3324 - val_accuracy: 0.9000
# Epoch 28/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3680 - accuracy: 0.8863 - val_loss: 0.3225 - val_accuracy: 0.9094
# Epoch 29/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3601 - accuracy: 0.8926 - val_loss: 0.3204 - val_accuracy: 0.9062
# Epoch 30/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3508 - accuracy: 0.8965 - val_loss: 0.3181 - val_accuracy: 0.9031
# Epoch 31/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.3630 - accuracy: 0.8793 - val_loss: 0.3173 - val_accuracy: 0.9078
# Epoch 32/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3610 - accuracy: 0.8875 - val_loss: 0.3064 - val_accuracy: 0.9062
# Epoch 33/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3450 - accuracy: 0.8926 - val_loss: 0.2960 - val_accuracy: 0.9172
# Epoch 34/60
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3307 - accuracy: 0.8953 - val_loss: 0.2994 - val_accuracy: 0.9094
# Epoch 35/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3389 - accuracy: 0.8980 - val_loss: 0.2919 - val_accuracy: 0.9062
# Epoch 36/60
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3156 - accuracy: 0.9031 - val_loss: 0.2885 - val_accuracy: 0.9172
# Epoch 37/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3247 - accuracy: 0.8988 - val_loss: 0.2820 - val_accuracy: 0.9141
# Epoch 38/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3110 - accuracy: 0.8930 - val_loss: 0.2750 - val_accuracy: 0.9187
# Epoch 39/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3146 - accuracy: 0.9023 - val_loss: 0.2889 - val_accuracy: 0.9078
# Epoch 40/60
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3122 - accuracy: 0.9031 - val_loss: 0.2747 - val_accuracy: 0.9187
# Epoch 41/60
# 5/5 [==============================] - 0s 38ms/step - loss: 0.3017 - accuracy: 0.9074 - val_loss: 0.2634 - val_accuracy: 0.9141
# Epoch 42/60
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3049 - accuracy: 0.9055 - val_loss: 0.2838 - val_accuracy: 0.9078
# Epoch 43/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2959 - accuracy: 0.9008 - val_loss: 0.2664 - val_accuracy: 0.9156
# Epoch 44/60
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3011 - accuracy: 0.8988 - val_loss: 0.2578 - val_accuracy: 0.9172
# Epoch 45/60
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2969 - accuracy: 0.9039 - val_loss: 0.2667 - val_accuracy: 0.9156
# Epoch 46/60
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2848 - accuracy: 0.9117 - val_loss: 0.2519 - val_accuracy: 0.9187
# Epoch 47/60
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2870 - accuracy: 0.9059 - val_loss: 0.2504 - val_accuracy: 0.9187
# Epoch 48/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2875 - accuracy: 0.9102 - val_loss: 0.2485 - val_accuracy: 0.9141
# Epoch 49/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2734 - accuracy: 0.9086 - val_loss: 0.2419 - val_accuracy: 0.9234
# Epoch 50/60
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2704 - accuracy: 0.9137 - val_loss: 0.2350 - val_accuracy: 0.9219
# Epoch 51/60
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2749 - accuracy: 0.9121 - val_loss: 0.2357 - val_accuracy: 0.9203
# Epoch 52/60
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2661 - accuracy: 0.9117 - val_loss: 0.2404 - val_accuracy: 0.9281
# Epoch 53/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2787 - accuracy: 0.9129 - val_loss: 0.2375 - val_accuracy: 0.9156
# Epoch 54/60
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2632 - accuracy: 0.9125 - val_loss: 0.2296 - val_accuracy: 0.9250
# Epoch 55/60
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2648 - accuracy: 0.9160 - val_loss: 0.2259 - val_accuracy: 0.9281
# Epoch 56/60
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2577 - accuracy: 0.9191 - val_loss: 0.2298 - val_accuracy: 0.9203
# Epoch 57/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2614 - accuracy: 0.9211 - val_loss: 0.2221 - val_accuracy: 0.9266
# Epoch 58/60
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2539 - accuracy: 0.9141 - val_loss: 0.2149 - val_accuracy: 0.9219
# Epoch 59/60
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2506 - accuracy: 0.9215 - val_loss: 0.2158 - val_accuracy: 0.9234
# Epoch 60/60
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2445 - accuracy: 0.9187 - val_loss: 0.2151 - val_accuracy: 0.9297

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2098 - accuracy: 0.9320
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2151 - accuracy: 0.9297
# 0.9320312738418579 0.9296875

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 122, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:57

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 201   3   0   0   0]
#  [  0   0   0   0   5  93   0   2   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   4   5   0  11   0]
#  [  0   0   0   0  17   1   0   0   2]]
#
# Accuracy Score
# 0.9296875
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.86      0.99      0.92       204
#     windows       0.91      0.93      0.92       100
#       roads       0.00      0.00      0.00         6
#        cars       0.85      0.55      0.67        20
#       metal       1.00      0.10      0.18        20
#
# avg / total       0.93      0.93      0.91       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 122)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 122)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 122) (80, 122)
# clouds  (400, 122) (100, 122)
# vegetation  (488, 122) (122, 122)
# built  (960, 122) (240, 122)
# windows  (400, 122) (100, 122)
# roads  (48, 122) (12, 122)
# cars  (44, 122) (11, 122)
# metal  (184, 122) (46, 122)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 122) (2844,) (2844, 2)
# (711, 122) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 126ms/step - loss: 1.7155 - accuracy: 0.3664 - val_loss: 1.3502 - val_accuracy: 0.6498
# Epoch 2/200
# 6/6 [==============================] - 0s 47ms/step - loss: 1.2291 - accuracy: 0.6083 - val_loss: 1.0519 - val_accuracy: 0.6442
# Epoch 3/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.9765 - accuracy: 0.6639 - val_loss: 0.8757 - val_accuracy: 0.6920
# Epoch 4/200
# 6/6 [==============================] - 1s 139ms/step - loss: 0.8339 - accuracy: 0.6909 - val_loss: 0.7556 - val_accuracy: 0.7286
# Epoch 5/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.7348 - accuracy: 0.7194 - val_loss: 0.6886 - val_accuracy: 0.7286
# Epoch 6/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.6934 - accuracy: 0.7184 - val_loss: 0.6434 - val_accuracy: 0.7440
# Epoch 7/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.6580 - accuracy: 0.7278 - val_loss: 0.6318 - val_accuracy: 0.7159
# Epoch 8/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.6349 - accuracy: 0.7324 - val_loss: 0.6230 - val_accuracy: 0.7103
# Epoch 9/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.6236 - accuracy: 0.7402 - val_loss: 0.6290 - val_accuracy: 0.6934
# Epoch 10/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.6023 - accuracy: 0.7563 - val_loss: 0.5763 - val_accuracy: 0.7764
# Epoch 11/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.5679 - accuracy: 0.7707 - val_loss: 0.5866 - val_accuracy: 0.7806
# Epoch 12/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5649 - accuracy: 0.7714 - val_loss: 0.5472 - val_accuracy: 0.7932
# Epoch 13/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5344 - accuracy: 0.7883 - val_loss: 0.5353 - val_accuracy: 0.8143
# Epoch 14/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.5244 - accuracy: 0.7918 - val_loss: 0.5276 - val_accuracy: 0.8031
# Epoch 15/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.5076 - accuracy: 0.8070 - val_loss: 0.5120 - val_accuracy: 0.8087
# Epoch 16/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4985 - accuracy: 0.8098 - val_loss: 0.5172 - val_accuracy: 0.8059
# Epoch 17/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4875 - accuracy: 0.8024 - val_loss: 0.5063 - val_accuracy: 0.7932
# Epoch 18/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4840 - accuracy: 0.8112 - val_loss: 0.5001 - val_accuracy: 0.8003
# Epoch 19/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4835 - accuracy: 0.8143 - val_loss: 0.5454 - val_accuracy: 0.7553
# Epoch 20/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4701 - accuracy: 0.8129 - val_loss: 0.5044 - val_accuracy: 0.7961
# Epoch 21/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4843 - accuracy: 0.8073 - val_loss: 0.5105 - val_accuracy: 0.7722
# Epoch 22/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4752 - accuracy: 0.8084 - val_loss: 0.4946 - val_accuracy: 0.8073
# Epoch 23/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4509 - accuracy: 0.8196 - val_loss: 0.4679 - val_accuracy: 0.8270
# Epoch 24/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4531 - accuracy: 0.8270 - val_loss: 0.4831 - val_accuracy: 0.8284
# Epoch 25/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4570 - accuracy: 0.8291 - val_loss: 0.4709 - val_accuracy: 0.8129
# Epoch 26/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4397 - accuracy: 0.8333 - val_loss: 0.4638 - val_accuracy: 0.8284
# Epoch 27/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4299 - accuracy: 0.8316 - val_loss: 0.4765 - val_accuracy: 0.8340
# Epoch 28/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4361 - accuracy: 0.8323 - val_loss: 0.4562 - val_accuracy: 0.8256
# Epoch 29/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4205 - accuracy: 0.8474 - val_loss: 0.4764 - val_accuracy: 0.8326
# Epoch 30/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4178 - accuracy: 0.8393 - val_loss: 0.4567 - val_accuracy: 0.8256
# Epoch 31/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4092 - accuracy: 0.8432 - val_loss: 0.4453 - val_accuracy: 0.8411
# Epoch 32/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4089 - accuracy: 0.8481 - val_loss: 0.4414 - val_accuracy: 0.8383
# Epoch 33/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3998 - accuracy: 0.8513 - val_loss: 0.4823 - val_accuracy: 0.8256
# Epoch 34/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4168 - accuracy: 0.8372 - val_loss: 0.4438 - val_accuracy: 0.8368
# Epoch 35/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4020 - accuracy: 0.8397 - val_loss: 0.4373 - val_accuracy: 0.8397
# Epoch 36/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3992 - accuracy: 0.8516 - val_loss: 0.4382 - val_accuracy: 0.8200
# Epoch 37/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4043 - accuracy: 0.8414 - val_loss: 0.4297 - val_accuracy: 0.8509
# Epoch 38/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3900 - accuracy: 0.8530 - val_loss: 0.4417 - val_accuracy: 0.8354
# Epoch 39/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3934 - accuracy: 0.8569 - val_loss: 0.4342 - val_accuracy: 0.8439
# Epoch 40/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3968 - accuracy: 0.8516 - val_loss: 0.4300 - val_accuracy: 0.8397
# Epoch 41/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3818 - accuracy: 0.8586 - val_loss: 0.4193 - val_accuracy: 0.8368
# Epoch 42/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3704 - accuracy: 0.8611 - val_loss: 0.4364 - val_accuracy: 0.8411
# Epoch 43/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3759 - accuracy: 0.8594 - val_loss: 0.4250 - val_accuracy: 0.8326
# Epoch 44/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3776 - accuracy: 0.8618 - val_loss: 0.4079 - val_accuracy: 0.8509
# Epoch 45/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3738 - accuracy: 0.8604 - val_loss: 0.4010 - val_accuracy: 0.8495
# Epoch 46/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3766 - accuracy: 0.8544 - val_loss: 0.4070 - val_accuracy: 0.8523
# Epoch 47/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3772 - accuracy: 0.8555 - val_loss: 0.4044 - val_accuracy: 0.8551
# Epoch 48/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3650 - accuracy: 0.8674 - val_loss: 0.4018 - val_accuracy: 0.8523
# Epoch 49/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3654 - accuracy: 0.8643 - val_loss: 0.3996 - val_accuracy: 0.8608
# Epoch 50/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3602 - accuracy: 0.8731 - val_loss: 0.3994 - val_accuracy: 0.8495
# Epoch 51/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3520 - accuracy: 0.8674 - val_loss: 0.3874 - val_accuracy: 0.8636
# Epoch 52/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3561 - accuracy: 0.8695 - val_loss: 0.3934 - val_accuracy: 0.8551
# Epoch 53/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3587 - accuracy: 0.8681 - val_loss: 0.3902 - val_accuracy: 0.8565
# Epoch 54/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3517 - accuracy: 0.8650 - val_loss: 0.3873 - val_accuracy: 0.8608
# Epoch 55/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3424 - accuracy: 0.8731 - val_loss: 0.3914 - val_accuracy: 0.8523
# Epoch 56/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3402 - accuracy: 0.8773 - val_loss: 0.3785 - val_accuracy: 0.8720
# Epoch 57/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3502 - accuracy: 0.8720 - val_loss: 0.3889 - val_accuracy: 0.8594
# Epoch 58/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3398 - accuracy: 0.8762 - val_loss: 0.3804 - val_accuracy: 0.8720
# Epoch 59/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3467 - accuracy: 0.8710 - val_loss: 0.3769 - val_accuracy: 0.8706
# Epoch 60/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3414 - accuracy: 0.8773 - val_loss: 0.3751 - val_accuracy: 0.8664
# Epoch 61/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3228 - accuracy: 0.8843 - val_loss: 0.3703 - val_accuracy: 0.8678
# Epoch 62/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3318 - accuracy: 0.8797 - val_loss: 0.3720 - val_accuracy: 0.8664
# Epoch 63/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3313 - accuracy: 0.8783 - val_loss: 0.3663 - val_accuracy: 0.8748
# Epoch 64/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3417 - accuracy: 0.8741 - val_loss: 0.3779 - val_accuracy: 0.8565
# Epoch 65/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3359 - accuracy: 0.8773 - val_loss: 0.3639 - val_accuracy: 0.8762
# Epoch 66/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3341 - accuracy: 0.8822 - val_loss: 0.3699 - val_accuracy: 0.8636
# Epoch 67/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3321 - accuracy: 0.8801 - val_loss: 0.3633 - val_accuracy: 0.8664
# Epoch 68/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3300 - accuracy: 0.8819 - val_loss: 0.3690 - val_accuracy: 0.8805
# Epoch 69/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3316 - accuracy: 0.8759 - val_loss: 0.3563 - val_accuracy: 0.8706
# Epoch 70/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3277 - accuracy: 0.8773 - val_loss: 0.3618 - val_accuracy: 0.8594
# Epoch 71/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3157 - accuracy: 0.8871 - val_loss: 0.3583 - val_accuracy: 0.8734
# Epoch 72/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3181 - accuracy: 0.8843 - val_loss: 0.3685 - val_accuracy: 0.8636
# Epoch 73/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3287 - accuracy: 0.8794 - val_loss: 0.3559 - val_accuracy: 0.8734
# Epoch 74/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3134 - accuracy: 0.8889 - val_loss: 0.3547 - val_accuracy: 0.8706
# Epoch 75/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3121 - accuracy: 0.8882 - val_loss: 0.3635 - val_accuracy: 0.8650
# Epoch 76/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3100 - accuracy: 0.8896 - val_loss: 0.3520 - val_accuracy: 0.8734
# Epoch 77/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3206 - accuracy: 0.8819 - val_loss: 0.3623 - val_accuracy: 0.8734
# Epoch 78/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3232 - accuracy: 0.8819 - val_loss: 0.3477 - val_accuracy: 0.8805
# Epoch 79/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3085 - accuracy: 0.8921 - val_loss: 0.3495 - val_accuracy: 0.8748
# Epoch 80/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3130 - accuracy: 0.8822 - val_loss: 0.3423 - val_accuracy: 0.8748
# Epoch 81/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3102 - accuracy: 0.8875 - val_loss: 0.3542 - val_accuracy: 0.8720
# Epoch 82/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2958 - accuracy: 0.8882 - val_loss: 0.3416 - val_accuracy: 0.8819
# Epoch 83/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3094 - accuracy: 0.8910 - val_loss: 0.3435 - val_accuracy: 0.8720
# Epoch 84/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2963 - accuracy: 0.8921 - val_loss: 0.3374 - val_accuracy: 0.8776
# Epoch 85/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2977 - accuracy: 0.8928 - val_loss: 0.3371 - val_accuracy: 0.8819
# Epoch 86/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3071 - accuracy: 0.8910 - val_loss: 0.3374 - val_accuracy: 0.8706
# Epoch 87/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2923 - accuracy: 0.8910 - val_loss: 0.3403 - val_accuracy: 0.8776
# Epoch 88/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2997 - accuracy: 0.8935 - val_loss: 0.3429 - val_accuracy: 0.8805
# Epoch 89/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2956 - accuracy: 0.8921 - val_loss: 0.3286 - val_accuracy: 0.8847
# Epoch 90/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2972 - accuracy: 0.8896 - val_loss: 0.3333 - val_accuracy: 0.8861
# Epoch 91/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2922 - accuracy: 0.8928 - val_loss: 0.3332 - val_accuracy: 0.8833
# Epoch 92/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3038 - accuracy: 0.8819 - val_loss: 0.3422 - val_accuracy: 0.8805
# Epoch 93/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2957 - accuracy: 0.8956 - val_loss: 0.3312 - val_accuracy: 0.8748
# Epoch 94/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2844 - accuracy: 0.8977 - val_loss: 0.3467 - val_accuracy: 0.8720
# Epoch 95/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2912 - accuracy: 0.8906 - val_loss: 0.3509 - val_accuracy: 0.8650
# Epoch 96/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2924 - accuracy: 0.8843 - val_loss: 0.3299 - val_accuracy: 0.8805
# Epoch 97/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2823 - accuracy: 0.8998 - val_loss: 0.3406 - val_accuracy: 0.8790
# Epoch 98/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2816 - accuracy: 0.8977 - val_loss: 0.3188 - val_accuracy: 0.8875
# Epoch 99/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2831 - accuracy: 0.8973 - val_loss: 0.3297 - val_accuracy: 0.8833
# Epoch 100/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2905 - accuracy: 0.8903 - val_loss: 0.3240 - val_accuracy: 0.8875
# Epoch 101/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2917 - accuracy: 0.8917 - val_loss: 0.3218 - val_accuracy: 0.8917
# Epoch 102/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2764 - accuracy: 0.9008 - val_loss: 0.3195 - val_accuracy: 0.8875
# Epoch 103/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2960 - accuracy: 0.8906 - val_loss: 0.3382 - val_accuracy: 0.8734
# Epoch 104/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2779 - accuracy: 0.9001 - val_loss: 0.3129 - val_accuracy: 0.8861
# Epoch 105/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2784 - accuracy: 0.8980 - val_loss: 0.3414 - val_accuracy: 0.8720
# Epoch 106/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2845 - accuracy: 0.8956 - val_loss: 0.3274 - val_accuracy: 0.8790
# Epoch 107/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2743 - accuracy: 0.8984 - val_loss: 0.3133 - val_accuracy: 0.8917
# Epoch 108/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2719 - accuracy: 0.9096 - val_loss: 0.3155 - val_accuracy: 0.8861
# Epoch 109/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2655 - accuracy: 0.9030 - val_loss: 0.3169 - val_accuracy: 0.8819
# Epoch 110/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2702 - accuracy: 0.9005 - val_loss: 0.3239 - val_accuracy: 0.8875
# Epoch 111/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2750 - accuracy: 0.9008 - val_loss: 0.3077 - val_accuracy: 0.8903
# Epoch 112/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2605 - accuracy: 0.9093 - val_loss: 0.3142 - val_accuracy: 0.8931
# Epoch 113/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2819 - accuracy: 0.8963 - val_loss: 0.3099 - val_accuracy: 0.8917
# Epoch 114/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2846 - accuracy: 0.8945 - val_loss: 0.3130 - val_accuracy: 0.8903
# Epoch 115/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2780 - accuracy: 0.8970 - val_loss: 0.3141 - val_accuracy: 0.8805
# Epoch 116/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2669 - accuracy: 0.9086 - val_loss: 0.3095 - val_accuracy: 0.8861
# Epoch 117/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2644 - accuracy: 0.9030 - val_loss: 0.3137 - val_accuracy: 0.8861
# Epoch 118/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2759 - accuracy: 0.8977 - val_loss: 0.3176 - val_accuracy: 0.8875
# Epoch 119/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2662 - accuracy: 0.9072 - val_loss: 0.3251 - val_accuracy: 0.8734
# Epoch 120/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2690 - accuracy: 0.9019 - val_loss: 0.3124 - val_accuracy: 0.8903
# Epoch 121/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2662 - accuracy: 0.9075 - val_loss: 0.2988 - val_accuracy: 0.8987
# Epoch 122/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2509 - accuracy: 0.9128 - val_loss: 0.3027 - val_accuracy: 0.8973
# Epoch 123/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2584 - accuracy: 0.9061 - val_loss: 0.2974 - val_accuracy: 0.8945
# Epoch 124/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2509 - accuracy: 0.9068 - val_loss: 0.3214 - val_accuracy: 0.8762
# Epoch 125/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2604 - accuracy: 0.9051 - val_loss: 0.2929 - val_accuracy: 0.9015
# Epoch 126/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2549 - accuracy: 0.9026 - val_loss: 0.3292 - val_accuracy: 0.8805
# Epoch 127/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2564 - accuracy: 0.9033 - val_loss: 0.3089 - val_accuracy: 0.8889
# Epoch 128/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2549 - accuracy: 0.9110 - val_loss: 0.2928 - val_accuracy: 0.8987
# Epoch 129/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2496 - accuracy: 0.9132 - val_loss: 0.2965 - val_accuracy: 0.8917
# Epoch 130/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2401 - accuracy: 0.9167 - val_loss: 0.2990 - val_accuracy: 0.8861
# Epoch 131/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2488 - accuracy: 0.9128 - val_loss: 0.2875 - val_accuracy: 0.9001
# Epoch 132/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2458 - accuracy: 0.9100 - val_loss: 0.3003 - val_accuracy: 0.8945
# Epoch 133/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2463 - accuracy: 0.9121 - val_loss: 0.2983 - val_accuracy: 0.8931
# Epoch 134/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2434 - accuracy: 0.9153 - val_loss: 0.2900 - val_accuracy: 0.8973
# Epoch 135/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2452 - accuracy: 0.9068 - val_loss: 0.2938 - val_accuracy: 0.8987
# Epoch 136/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2360 - accuracy: 0.9153 - val_loss: 0.2991 - val_accuracy: 0.8917
# Epoch 137/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2455 - accuracy: 0.9100 - val_loss: 0.2849 - val_accuracy: 0.8973
# Epoch 138/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2413 - accuracy: 0.9135 - val_loss: 0.2966 - val_accuracy: 0.8917
# Epoch 139/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2443 - accuracy: 0.9146 - val_loss: 0.2919 - val_accuracy: 0.8945
# Epoch 140/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2425 - accuracy: 0.9142 - val_loss: 0.2835 - val_accuracy: 0.9001
# Epoch 141/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2320 - accuracy: 0.9184 - val_loss: 0.2946 - val_accuracy: 0.8903
# Epoch 142/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2451 - accuracy: 0.9075 - val_loss: 0.2808 - val_accuracy: 0.9015
# Epoch 143/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2398 - accuracy: 0.9124 - val_loss: 0.2742 - val_accuracy: 0.9086
# Epoch 144/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2365 - accuracy: 0.9184 - val_loss: 0.2807 - val_accuracy: 0.9058
# Epoch 145/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2304 - accuracy: 0.9170 - val_loss: 0.2723 - val_accuracy: 0.9072
# Epoch 146/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2208 - accuracy: 0.9198 - val_loss: 0.2762 - val_accuracy: 0.9015
# Epoch 147/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2241 - accuracy: 0.9181 - val_loss: 0.2751 - val_accuracy: 0.9072
# Epoch 148/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2305 - accuracy: 0.9139 - val_loss: 0.2818 - val_accuracy: 0.8987
# Epoch 149/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2313 - accuracy: 0.9153 - val_loss: 0.2730 - val_accuracy: 0.8959
# Epoch 150/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2243 - accuracy: 0.9191 - val_loss: 0.2789 - val_accuracy: 0.9044
# Epoch 151/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2164 - accuracy: 0.9195 - val_loss: 0.2669 - val_accuracy: 0.9044
# Epoch 152/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2209 - accuracy: 0.9177 - val_loss: 0.2712 - val_accuracy: 0.9030
# Epoch 153/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2230 - accuracy: 0.9195 - val_loss: 0.2801 - val_accuracy: 0.9030
# Epoch 154/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2244 - accuracy: 0.9153 - val_loss: 0.2706 - val_accuracy: 0.9044
# Epoch 155/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2156 - accuracy: 0.9223 - val_loss: 0.2782 - val_accuracy: 0.9015
# Epoch 156/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2319 - accuracy: 0.9110 - val_loss: 0.2661 - val_accuracy: 0.9058
# Epoch 157/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2290 - accuracy: 0.9170 - val_loss: 0.2682 - val_accuracy: 0.9044
# Epoch 158/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2292 - accuracy: 0.9216 - val_loss: 0.2673 - val_accuracy: 0.9058
# Epoch 159/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2106 - accuracy: 0.9233 - val_loss: 0.2693 - val_accuracy: 0.9030
# Epoch 160/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2185 - accuracy: 0.9258 - val_loss: 0.2653 - val_accuracy: 0.9114
# Epoch 161/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2166 - accuracy: 0.9223 - val_loss: 0.2608 - val_accuracy: 0.9170
# Epoch 162/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2226 - accuracy: 0.9184 - val_loss: 0.2654 - val_accuracy: 0.9058
# Epoch 163/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.2184 - accuracy: 0.9216 - val_loss: 0.2645 - val_accuracy: 0.9058
# Epoch 164/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2205 - accuracy: 0.9188 - val_loss: 0.2705 - val_accuracy: 0.9030
# Epoch 165/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2224 - accuracy: 0.9216 - val_loss: 0.2627 - val_accuracy: 0.9142
# Epoch 166/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2176 - accuracy: 0.9205 - val_loss: 0.2666 - val_accuracy: 0.9058
# Epoch 167/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2180 - accuracy: 0.9265 - val_loss: 0.2587 - val_accuracy: 0.9142
# Epoch 168/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2113 - accuracy: 0.9290 - val_loss: 0.2628 - val_accuracy: 0.9072
# Epoch 169/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2111 - accuracy: 0.9226 - val_loss: 0.2757 - val_accuracy: 0.8945
# Epoch 170/200
# 6/6 [==============================] - 0s 43ms/step - loss: 0.2163 - accuracy: 0.9212 - val_loss: 0.2619 - val_accuracy: 0.9044
# Epoch 171/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2218 - accuracy: 0.9167 - val_loss: 0.2744 - val_accuracy: 0.9086
# Epoch 172/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2114 - accuracy: 0.9216 - val_loss: 0.2659 - val_accuracy: 0.9015
# Epoch 173/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2198 - accuracy: 0.9244 - val_loss: 0.2569 - val_accuracy: 0.9044
# Epoch 174/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2159 - accuracy: 0.9262 - val_loss: 0.2728 - val_accuracy: 0.8987
# Epoch 175/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2092 - accuracy: 0.9276 - val_loss: 0.2599 - val_accuracy: 0.9015
# Epoch 176/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.2055 - accuracy: 0.9272 - val_loss: 0.2553 - val_accuracy: 0.9086
# Epoch 177/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2040 - accuracy: 0.9293 - val_loss: 0.2575 - val_accuracy: 0.9072
# Epoch 178/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2016 - accuracy: 0.9283 - val_loss: 0.2473 - val_accuracy: 0.9170
# Epoch 179/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1965 - accuracy: 0.9293 - val_loss: 0.2485 - val_accuracy: 0.9128
# Epoch 180/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1968 - accuracy: 0.9286 - val_loss: 0.2477 - val_accuracy: 0.9156
# Epoch 181/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2041 - accuracy: 0.9219 - val_loss: 0.2456 - val_accuracy: 0.9198
# Epoch 182/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2011 - accuracy: 0.9286 - val_loss: 0.2620 - val_accuracy: 0.8987
# Epoch 183/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2077 - accuracy: 0.9237 - val_loss: 0.2578 - val_accuracy: 0.9072
# Epoch 184/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2035 - accuracy: 0.9311 - val_loss: 0.2495 - val_accuracy: 0.9114
# Epoch 185/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2010 - accuracy: 0.9272 - val_loss: 0.2545 - val_accuracy: 0.9142
# Epoch 186/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2017 - accuracy: 0.9304 - val_loss: 0.2512 - val_accuracy: 0.9156
# Epoch 187/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1930 - accuracy: 0.9276 - val_loss: 0.2425 - val_accuracy: 0.9184
# Epoch 188/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1923 - accuracy: 0.9339 - val_loss: 0.2499 - val_accuracy: 0.9128
# Epoch 189/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1944 - accuracy: 0.9293 - val_loss: 0.2552 - val_accuracy: 0.9100
# Epoch 190/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1972 - accuracy: 0.9279 - val_loss: 0.2544 - val_accuracy: 0.9114
# Epoch 191/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2019 - accuracy: 0.9290 - val_loss: 0.2497 - val_accuracy: 0.9086
# Epoch 192/200
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1955 - accuracy: 0.9255 - val_loss: 0.2594 - val_accuracy: 0.9058
# Epoch 193/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2061 - accuracy: 0.9272 - val_loss: 0.2447 - val_accuracy: 0.9142
# Epoch 194/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1903 - accuracy: 0.9328 - val_loss: 0.2511 - val_accuracy: 0.9072
# Epoch 195/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1918 - accuracy: 0.9304 - val_loss: 0.2430 - val_accuracy: 0.9072
# Epoch 196/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1899 - accuracy: 0.9318 - val_loss: 0.2381 - val_accuracy: 0.9170
# Epoch 197/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1943 - accuracy: 0.9318 - val_loss: 0.2390 - val_accuracy: 0.9142
# Epoch 198/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1884 - accuracy: 0.9304 - val_loss: 0.2369 - val_accuracy: 0.9184
# Epoch 199/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1935 - accuracy: 0.9286 - val_loss: 0.2465 - val_accuracy: 0.9156
# Epoch 200/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.1946 - accuracy: 0.9255 - val_loss: 0.2506 - val_accuracy: 0.9100

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 6/6 [==============================] - 0s 75ms/step - loss: 1.8132 - accuracy: 0.3520 - val_loss: 1.4198 - val_accuracy: 0.5767
# Epoch 2/60
# 6/6 [==============================] - 0s 40ms/step - loss: 1.2951 - accuracy: 0.6139 - val_loss: 1.1150 - val_accuracy: 0.6512
# Epoch 3/60
# 6/6 [==============================] - 0s 38ms/step - loss: 1.0417 - accuracy: 0.6530 - val_loss: 0.9386 - val_accuracy: 0.6723
# Epoch 4/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.8812 - accuracy: 0.6895 - val_loss: 0.8271 - val_accuracy: 0.6681
# Epoch 5/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.7783 - accuracy: 0.7032 - val_loss: 0.7403 - val_accuracy: 0.7089
# Epoch 6/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.7059 - accuracy: 0.7191 - val_loss: 0.6726 - val_accuracy: 0.7468
# Epoch 7/60
# 6/6 [==============================] - 0s 34ms/step - loss: 0.6677 - accuracy: 0.7278 - val_loss: 0.6284 - val_accuracy: 0.7651
# Epoch 8/60
# 6/6 [==============================] - 0s 31ms/step - loss: 0.6226 - accuracy: 0.7440 - val_loss: 0.6245 - val_accuracy: 0.7637
# Epoch 9/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.6206 - accuracy: 0.7409 - val_loss: 0.5960 - val_accuracy: 0.7820
# Epoch 10/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.5964 - accuracy: 0.7542 - val_loss: 0.5849 - val_accuracy: 0.7623
# Epoch 11/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5632 - accuracy: 0.7718 - val_loss: 0.5672 - val_accuracy: 0.7932
# Epoch 12/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5492 - accuracy: 0.7792 - val_loss: 0.5740 - val_accuracy: 0.7862
# Epoch 13/60
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5435 - accuracy: 0.7816 - val_loss: 0.5441 - val_accuracy: 0.7918
# Epoch 14/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5319 - accuracy: 0.7880 - val_loss: 0.5423 - val_accuracy: 0.7932
# Epoch 15/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5145 - accuracy: 0.7985 - val_loss: 0.5477 - val_accuracy: 0.8017
# Epoch 16/60
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5285 - accuracy: 0.7880 - val_loss: 0.5369 - val_accuracy: 0.8087
# Epoch 17/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5082 - accuracy: 0.8017 - val_loss: 0.5264 - val_accuracy: 0.8031
# Epoch 18/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4805 - accuracy: 0.8147 - val_loss: 0.5098 - val_accuracy: 0.8045
# Epoch 19/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4920 - accuracy: 0.8073 - val_loss: 0.5224 - val_accuracy: 0.8158
# Epoch 20/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4893 - accuracy: 0.8119 - val_loss: 0.5014 - val_accuracy: 0.7848
# Epoch 21/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4709 - accuracy: 0.8122 - val_loss: 0.5036 - val_accuracy: 0.7961
# Epoch 22/60
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4690 - accuracy: 0.8112 - val_loss: 0.4828 - val_accuracy: 0.8101
# Epoch 23/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4628 - accuracy: 0.8115 - val_loss: 0.4757 - val_accuracy: 0.8326
# Epoch 24/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4439 - accuracy: 0.8302 - val_loss: 0.4707 - val_accuracy: 0.8200
# Epoch 25/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4446 - accuracy: 0.8354 - val_loss: 0.4582 - val_accuracy: 0.8298
# Epoch 26/60
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4311 - accuracy: 0.8368 - val_loss: 0.4645 - val_accuracy: 0.8214
# Epoch 27/60
# 6/6 [==============================] - 0s 43ms/step - loss: 0.4320 - accuracy: 0.8372 - val_loss: 0.4503 - val_accuracy: 0.8340
# Epoch 28/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4212 - accuracy: 0.8404 - val_loss: 0.4502 - val_accuracy: 0.8326
# Epoch 29/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4264 - accuracy: 0.8407 - val_loss: 0.4460 - val_accuracy: 0.8298
# Epoch 30/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4164 - accuracy: 0.8439 - val_loss: 0.4359 - val_accuracy: 0.8467
# Epoch 31/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.4082 - accuracy: 0.8456 - val_loss: 0.4360 - val_accuracy: 0.8368
# Epoch 32/60
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3965 - accuracy: 0.8565 - val_loss: 0.4356 - val_accuracy: 0.8368
# Epoch 33/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3931 - accuracy: 0.8534 - val_loss: 0.4315 - val_accuracy: 0.8397
# Epoch 34/60
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4030 - accuracy: 0.8544 - val_loss: 0.4361 - val_accuracy: 0.8467
# Epoch 35/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.4047 - accuracy: 0.8463 - val_loss: 0.4166 - val_accuracy: 0.8579
# Epoch 36/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3863 - accuracy: 0.8576 - val_loss: 0.4245 - val_accuracy: 0.8383
# Epoch 37/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4001 - accuracy: 0.8456 - val_loss: 0.4204 - val_accuracy: 0.8425
# Epoch 38/60
# 6/6 [==============================] - 0s 44ms/step - loss: 0.3858 - accuracy: 0.8523 - val_loss: 0.4131 - val_accuracy: 0.8537
# Epoch 39/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3747 - accuracy: 0.8601 - val_loss: 0.4199 - val_accuracy: 0.8312
# Epoch 40/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3865 - accuracy: 0.8495 - val_loss: 0.4258 - val_accuracy: 0.8509
# Epoch 41/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3875 - accuracy: 0.8499 - val_loss: 0.4184 - val_accuracy: 0.8326
# Epoch 42/60
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3816 - accuracy: 0.8513 - val_loss: 0.4019 - val_accuracy: 0.8481
# Epoch 43/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3704 - accuracy: 0.8597 - val_loss: 0.3991 - val_accuracy: 0.8579
# Epoch 44/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3631 - accuracy: 0.8685 - val_loss: 0.4049 - val_accuracy: 0.8509
# Epoch 45/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3629 - accuracy: 0.8650 - val_loss: 0.4006 - val_accuracy: 0.8565
# Epoch 46/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3606 - accuracy: 0.8594 - val_loss: 0.4064 - val_accuracy: 0.8509
# Epoch 47/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3598 - accuracy: 0.8586 - val_loss: 0.4088 - val_accuracy: 0.8495
# Epoch 48/60
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3607 - accuracy: 0.8699 - val_loss: 0.3934 - val_accuracy: 0.8523
# Epoch 49/60
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3459 - accuracy: 0.8710 - val_loss: 0.3882 - val_accuracy: 0.8636
# Epoch 50/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3523 - accuracy: 0.8688 - val_loss: 0.3801 - val_accuracy: 0.8650
# Epoch 51/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3501 - accuracy: 0.8703 - val_loss: 0.3841 - val_accuracy: 0.8706
# Epoch 52/60
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3507 - accuracy: 0.8717 - val_loss: 0.3910 - val_accuracy: 0.8579
# Epoch 53/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3403 - accuracy: 0.8706 - val_loss: 0.3754 - val_accuracy: 0.8706
# Epoch 54/60
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3370 - accuracy: 0.8854 - val_loss: 0.3828 - val_accuracy: 0.8608
# Epoch 55/60
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3397 - accuracy: 0.8762 - val_loss: 0.3737 - val_accuracy: 0.8650
# Epoch 56/60
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3398 - accuracy: 0.8812 - val_loss: 0.3803 - val_accuracy: 0.8565
# Epoch 57/60
# 6/6 [==============================] - 0s 35ms/step - loss: 0.3337 - accuracy: 0.8727 - val_loss: 0.3695 - val_accuracy: 0.8636
# Epoch 58/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3387 - accuracy: 0.8734 - val_loss: 0.3763 - val_accuracy: 0.8594
# Epoch 59/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3261 - accuracy: 0.8885 - val_loss: 0.3787 - val_accuracy: 0.8565
# Epoch 60/60
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3291 - accuracy: 0.8780 - val_loss: 0.3655 - val_accuracy: 0.8692

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.9030
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8692
# 0.902953565120697 0.8691983222961426

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 122, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:54

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 226   6   0   0   8]
#  [  0   0   0  36  56   0   1   7]
#  [  0   0   0   0   1  10   1   0]
#  [  3   0   0   0   0   1   7   0]
#  [  0   0   0  24   2   0   0  20]]
#
# Accuracy Score
# 0.869198312236287
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.96      1.00      0.98        80
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.78      0.94      0.85       240
#     windows       0.86      0.56      0.68       100
#       roads       0.91      0.83      0.87        12
#        cars       0.78      0.64      0.70        11
#       metal       0.57      0.43      0.49        46
#
# avg / total       0.87      0.87      0.86       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 122
# [[0, 7], [7, 14], [14, 21], [21, 28], [28, 35], [35, 42], [42, 49], [49, 56], [56, 63], [63, 70], [70, 77], [77, 84], [84, 91], [91, 98], [98, 105], [105, 112], [112, 119], [119, 126], [126, 133], [133, 140], [140, 147], [147, 154], [154, 161], [161, 168], [168, 175], [175, 182], [182, 189], [189, 196], [196, 203], [203, 210], [210, 217], [217, 224], [224, 231], [231, 238], [238, 245], [245, 252], [252, 259], [259, 266], [266, 273], [273, 280], [280, 287], [287, 294], [294, 301], [301, 308], [308, 315], [315, 322], [322, 329], [329, 336], [336, 343], [343, 350], [350, 357], [357, 364], [364, 371], [371, 378], [378, 385], [385, 392], [392, 399], [399, 406], [406, 413], [413, 420], [420, 427], [427, 434], [434, 441], [441, 448], [448, 455], [455, 462], [462, 469], [469, 476], [476, 483], [483, 490], [490, 497], [497, 504], [504, 511], [511, 518], [518, 525], [525, 532], [532, 539], [539, 546], [546, 553], [553, 560], [560, 567], [567, 574], [574, 581], [581, 588], [588, 595], [595, 602], [602, 609], [609, 616], [616, 623], [623, 630], [630, 637], [637, 644], [644, 651], [651, 658], [658, 665], [665, 672], [672, 679], [679, 686], [686, 693], [693, 700], [700, 707], [707, 714], [714, 721], [721, 728], [728, 735], [735, 742], [742, 749], [749, 756], [756, 763], [763, 770], [770, 777], [777, 784], [784, 791], [791, 798], [798, 805], [805, 812], [812, 819], [819, 826], [826, 833], [833, 840], [840, 847], [847, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 122)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 122)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 122)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 122) (60, 122)
# clouds  (160, 122) (40, 122)
# vegetation  (560, 122) (140, 122)
# water  (496, 122) (124, 122)
# built  (1280, 122) (320, 122)
# windows  (480, 122) (120, 122)
# roads  (200, 122) (50, 122)
# cars  (200, 122) (50, 122)
# metal  (148, 122) (37, 122)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 122) (3764,) (3764, 2)
# (941, 122) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 88ms/step - loss: 1.8436 - accuracy: 0.3547 - val_loss: 1.5289 - val_accuracy: 0.5133
# Epoch 2/200
# 8/8 [==============================] - 0s 48ms/step - loss: 1.4574 - accuracy: 0.4992 - val_loss: 1.3485 - val_accuracy: 0.5037
# Epoch 3/200
# 8/8 [==============================] - 0s 52ms/step - loss: 1.3292 - accuracy: 0.5234 - val_loss: 1.2643 - val_accuracy: 0.5622
# Epoch 4/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.2479 - accuracy: 0.5587 - val_loss: 1.1907 - val_accuracy: 0.5919
# Epoch 5/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.1788 - accuracy: 0.5802 - val_loss: 1.1534 - val_accuracy: 0.5494
# Epoch 6/200
# 8/8 [==============================] - 0s 40ms/step - loss: 1.1217 - accuracy: 0.6031 - val_loss: 1.0355 - val_accuracy: 0.6971
# Epoch 7/200
# 8/8 [==============================] - 0s 38ms/step - loss: 1.0507 - accuracy: 0.6344 - val_loss: 0.9769 - val_accuracy: 0.7343
# Epoch 8/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.9948 - accuracy: 0.6722 - val_loss: 0.9122 - val_accuracy: 0.7450
# Epoch 9/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.9468 - accuracy: 0.6868 - val_loss: 0.8910 - val_accuracy: 0.6918
# Epoch 10/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.9058 - accuracy: 0.6876 - val_loss: 0.8323 - val_accuracy: 0.7747
# Epoch 11/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.8585 - accuracy: 0.7272 - val_loss: 0.7803 - val_accuracy: 0.7768
# Epoch 12/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.8108 - accuracy: 0.7444 - val_loss: 0.7794 - val_accuracy: 0.7609
# Epoch 13/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.7962 - accuracy: 0.7471 - val_loss: 0.7439 - val_accuracy: 0.7620
# Epoch 14/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7752 - accuracy: 0.7365 - val_loss: 0.7111 - val_accuracy: 0.7630
# Epoch 15/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.7341 - accuracy: 0.7633 - val_loss: 0.6685 - val_accuracy: 0.8045
# Epoch 16/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7105 - accuracy: 0.7678 - val_loss: 0.6724 - val_accuracy: 0.7960
# Epoch 17/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.7082 - accuracy: 0.7683 - val_loss: 0.6383 - val_accuracy: 0.8215
# Epoch 18/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.6705 - accuracy: 0.7880 - val_loss: 0.6147 - val_accuracy: 0.8353
# Epoch 19/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.6682 - accuracy: 0.7821 - val_loss: 0.6378 - val_accuracy: 0.7832
# Epoch 20/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6468 - accuracy: 0.7906 - val_loss: 0.5995 - val_accuracy: 0.8342
# Epoch 21/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6404 - accuracy: 0.7941 - val_loss: 0.5933 - val_accuracy: 0.8215
# Epoch 22/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6357 - accuracy: 0.7952 - val_loss: 0.5944 - val_accuracy: 0.8448
# Epoch 23/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6204 - accuracy: 0.7912 - val_loss: 0.5831 - val_accuracy: 0.8215
# Epoch 24/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6154 - accuracy: 0.7999 - val_loss: 0.5623 - val_accuracy: 0.8353
# Epoch 25/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5989 - accuracy: 0.8029 - val_loss: 0.5626 - val_accuracy: 0.8427
# Epoch 26/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5840 - accuracy: 0.8127 - val_loss: 0.5280 - val_accuracy: 0.8544
# Epoch 27/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5631 - accuracy: 0.8262 - val_loss: 0.5315 - val_accuracy: 0.8544
# Epoch 28/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5559 - accuracy: 0.8276 - val_loss: 0.5256 - val_accuracy: 0.8523
# Epoch 29/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5542 - accuracy: 0.8278 - val_loss: 0.5146 - val_accuracy: 0.8491
# Epoch 30/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5435 - accuracy: 0.8212 - val_loss: 0.5058 - val_accuracy: 0.8587
# Epoch 31/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5380 - accuracy: 0.8326 - val_loss: 0.5025 - val_accuracy: 0.8640
# Epoch 32/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5269 - accuracy: 0.8305 - val_loss: 0.4981 - val_accuracy: 0.8565
# Epoch 33/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5227 - accuracy: 0.8355 - val_loss: 0.5059 - val_accuracy: 0.8491
# Epoch 34/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5217 - accuracy: 0.8332 - val_loss: 0.4852 - val_accuracy: 0.8650
# Epoch 35/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5079 - accuracy: 0.8478 - val_loss: 0.5134 - val_accuracy: 0.8417
# Epoch 36/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5209 - accuracy: 0.8353 - val_loss: 0.5008 - val_accuracy: 0.8629
# Epoch 37/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5125 - accuracy: 0.8382 - val_loss: 0.4765 - val_accuracy: 0.8661
# Epoch 38/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4961 - accuracy: 0.8446 - val_loss: 0.4753 - val_accuracy: 0.8618
# Epoch 39/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4919 - accuracy: 0.8425 - val_loss: 0.4649 - val_accuracy: 0.8746
# Epoch 40/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4884 - accuracy: 0.8488 - val_loss: 0.4734 - val_accuracy: 0.8725
# Epoch 41/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4819 - accuracy: 0.8454 - val_loss: 0.4543 - val_accuracy: 0.8767
# Epoch 42/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4829 - accuracy: 0.8448 - val_loss: 0.4570 - val_accuracy: 0.8682
# Epoch 43/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4802 - accuracy: 0.8464 - val_loss: 0.4530 - val_accuracy: 0.8767
# Epoch 44/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4597 - accuracy: 0.8552 - val_loss: 0.4424 - val_accuracy: 0.8757
# Epoch 45/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4608 - accuracy: 0.8504 - val_loss: 0.4457 - val_accuracy: 0.8757
# Epoch 46/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4653 - accuracy: 0.8531 - val_loss: 0.4369 - val_accuracy: 0.8789
# Epoch 47/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4573 - accuracy: 0.8565 - val_loss: 0.4351 - val_accuracy: 0.8693
# Epoch 48/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4477 - accuracy: 0.8533 - val_loss: 0.4269 - val_accuracy: 0.8820
# Epoch 49/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4443 - accuracy: 0.8587 - val_loss: 0.4362 - val_accuracy: 0.8746
# Epoch 50/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4441 - accuracy: 0.8605 - val_loss: 0.4189 - val_accuracy: 0.8799
# Epoch 51/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.4313 - accuracy: 0.8592 - val_loss: 0.4280 - val_accuracy: 0.8650
# Epoch 52/200
# 8/8 [==============================] - 3s 369ms/step - loss: 0.4409 - accuracy: 0.8600 - val_loss: 0.4307 - val_accuracy: 0.8682
# Epoch 53/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4406 - accuracy: 0.8608 - val_loss: 0.4259 - val_accuracy: 0.8693
# Epoch 54/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4247 - accuracy: 0.8680 - val_loss: 0.4312 - val_accuracy: 0.8735
# Epoch 55/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4330 - accuracy: 0.8666 - val_loss: 0.4093 - val_accuracy: 0.8916
# Epoch 56/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4296 - accuracy: 0.8672 - val_loss: 0.4065 - val_accuracy: 0.8810
# Epoch 57/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4198 - accuracy: 0.8696 - val_loss: 0.4054 - val_accuracy: 0.8820
# Epoch 58/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4106 - accuracy: 0.8727 - val_loss: 0.4024 - val_accuracy: 0.8916
# Epoch 59/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4044 - accuracy: 0.8727 - val_loss: 0.3923 - val_accuracy: 0.8874
# Epoch 60/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4034 - accuracy: 0.8759 - val_loss: 0.3982 - val_accuracy: 0.8799
# Epoch 61/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4076 - accuracy: 0.8701 - val_loss: 0.3989 - val_accuracy: 0.8905
# Epoch 62/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4142 - accuracy: 0.8685 - val_loss: 0.3880 - val_accuracy: 0.8895
# Epoch 63/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4012 - accuracy: 0.8690 - val_loss: 0.4080 - val_accuracy: 0.8735
# Epoch 64/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3934 - accuracy: 0.8789 - val_loss: 0.3858 - val_accuracy: 0.8874
# Epoch 65/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3926 - accuracy: 0.8746 - val_loss: 0.3913 - val_accuracy: 0.8927
# Epoch 66/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3994 - accuracy: 0.8722 - val_loss: 0.3911 - val_accuracy: 0.8831
# Epoch 67/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3956 - accuracy: 0.8719 - val_loss: 0.3753 - val_accuracy: 0.8905
# Epoch 68/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3834 - accuracy: 0.8778 - val_loss: 0.3702 - val_accuracy: 0.8990
# Epoch 69/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3803 - accuracy: 0.8765 - val_loss: 0.3782 - val_accuracy: 0.8905
# Epoch 70/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3836 - accuracy: 0.8802 - val_loss: 0.3792 - val_accuracy: 0.8884
# Epoch 71/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3901 - accuracy: 0.8714 - val_loss: 0.3794 - val_accuracy: 0.8937
# Epoch 72/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3759 - accuracy: 0.8796 - val_loss: 0.3792 - val_accuracy: 0.8895
# Epoch 73/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3748 - accuracy: 0.8783 - val_loss: 0.3924 - val_accuracy: 0.8820
# Epoch 74/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3732 - accuracy: 0.8807 - val_loss: 0.3765 - val_accuracy: 0.8874
# Epoch 75/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3694 - accuracy: 0.8842 - val_loss: 0.3666 - val_accuracy: 0.8969
# Epoch 76/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3697 - accuracy: 0.8826 - val_loss: 0.3693 - val_accuracy: 0.8895
# Epoch 77/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3674 - accuracy: 0.8799 - val_loss: 0.3702 - val_accuracy: 0.9001
# Epoch 78/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3666 - accuracy: 0.8884 - val_loss: 0.3709 - val_accuracy: 0.8905
# Epoch 79/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3562 - accuracy: 0.8866 - val_loss: 0.3529 - val_accuracy: 0.9001
# Epoch 80/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3526 - accuracy: 0.8866 - val_loss: 0.3458 - val_accuracy: 0.8969
# Epoch 81/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3597 - accuracy: 0.8847 - val_loss: 0.3586 - val_accuracy: 0.8916
# Epoch 82/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3559 - accuracy: 0.8884 - val_loss: 0.3599 - val_accuracy: 0.8969
# Epoch 83/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3554 - accuracy: 0.8895 - val_loss: 0.3601 - val_accuracy: 0.9022
# Epoch 84/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3497 - accuracy: 0.8863 - val_loss: 0.3469 - val_accuracy: 0.9022
# Epoch 85/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3326 - accuracy: 0.8990 - val_loss: 0.3431 - val_accuracy: 0.9044
# Epoch 86/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3386 - accuracy: 0.8956 - val_loss: 0.3409 - val_accuracy: 0.9033
# Epoch 87/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3292 - accuracy: 0.8985 - val_loss: 0.3446 - val_accuracy: 0.8969
# Epoch 88/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3346 - accuracy: 0.8982 - val_loss: 0.3439 - val_accuracy: 0.9044
# Epoch 89/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3342 - accuracy: 0.8972 - val_loss: 0.3502 - val_accuracy: 0.8927
# Epoch 90/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3304 - accuracy: 0.8932 - val_loss: 0.3512 - val_accuracy: 0.8990
# Epoch 91/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3368 - accuracy: 0.8940 - val_loss: 0.3454 - val_accuracy: 0.8916
# Epoch 92/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3278 - accuracy: 0.8913 - val_loss: 0.3496 - val_accuracy: 0.9022
# Epoch 93/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3362 - accuracy: 0.8929 - val_loss: 0.3487 - val_accuracy: 0.8927
# Epoch 94/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3238 - accuracy: 0.8916 - val_loss: 0.3344 - val_accuracy: 0.9033
# Epoch 95/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3249 - accuracy: 0.8967 - val_loss: 0.3326 - val_accuracy: 0.9022
# Epoch 96/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3206 - accuracy: 0.8948 - val_loss: 0.3270 - val_accuracy: 0.9012
# Epoch 97/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3170 - accuracy: 0.9012 - val_loss: 0.3309 - val_accuracy: 0.9054
# Epoch 98/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3194 - accuracy: 0.8969 - val_loss: 0.3336 - val_accuracy: 0.9022
# Epoch 99/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3132 - accuracy: 0.9036 - val_loss: 0.3246 - val_accuracy: 0.9097
# Epoch 100/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.3073 - accuracy: 0.9054 - val_loss: 0.3306 - val_accuracy: 0.9022
# Epoch 101/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3109 - accuracy: 0.9033 - val_loss: 0.3199 - val_accuracy: 0.9097
# Epoch 102/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3076 - accuracy: 0.9020 - val_loss: 0.3260 - val_accuracy: 0.9118
# Epoch 103/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.3025 - accuracy: 0.9025 - val_loss: 0.3337 - val_accuracy: 0.8990
# Epoch 104/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3141 - accuracy: 0.9001 - val_loss: 0.3223 - val_accuracy: 0.9044
# Epoch 105/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3020 - accuracy: 0.9028 - val_loss: 0.3253 - val_accuracy: 0.9054
# Epoch 106/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3026 - accuracy: 0.9012 - val_loss: 0.3373 - val_accuracy: 0.9012
# Epoch 107/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2982 - accuracy: 0.9062 - val_loss: 0.3106 - val_accuracy: 0.9097
# Epoch 108/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3030 - accuracy: 0.9033 - val_loss: 0.3177 - val_accuracy: 0.9054
# Epoch 109/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2975 - accuracy: 0.9078 - val_loss: 0.3145 - val_accuracy: 0.9075
# Epoch 110/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2909 - accuracy: 0.9091 - val_loss: 0.3134 - val_accuracy: 0.9054
# Epoch 111/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2896 - accuracy: 0.9089 - val_loss: 0.3099 - val_accuracy: 0.9097
# Epoch 112/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2948 - accuracy: 0.9049 - val_loss: 0.3242 - val_accuracy: 0.9044
# Epoch 113/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2939 - accuracy: 0.9041 - val_loss: 0.3157 - val_accuracy: 0.9065
# Epoch 114/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2945 - accuracy: 0.9083 - val_loss: 0.3052 - val_accuracy: 0.9075
# Epoch 115/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2832 - accuracy: 0.9078 - val_loss: 0.3104 - val_accuracy: 0.9033
# Epoch 116/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2812 - accuracy: 0.9105 - val_loss: 0.3001 - val_accuracy: 0.9097
# Epoch 117/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2770 - accuracy: 0.9105 - val_loss: 0.3076 - val_accuracy: 0.9118
# Epoch 118/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2808 - accuracy: 0.9115 - val_loss: 0.3039 - val_accuracy: 0.9075
# Epoch 119/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2888 - accuracy: 0.9081 - val_loss: 0.2971 - val_accuracy: 0.9171
# Epoch 120/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2754 - accuracy: 0.9145 - val_loss: 0.3050 - val_accuracy: 0.9097
# Epoch 121/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2776 - accuracy: 0.9142 - val_loss: 0.3210 - val_accuracy: 0.9086
# Epoch 122/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2867 - accuracy: 0.9105 - val_loss: 0.3012 - val_accuracy: 0.9097
# Epoch 123/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2767 - accuracy: 0.9160 - val_loss: 0.3098 - val_accuracy: 0.9075
# Epoch 124/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2750 - accuracy: 0.9131 - val_loss: 0.3054 - val_accuracy: 0.9097
# Epoch 125/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2716 - accuracy: 0.9142 - val_loss: 0.2917 - val_accuracy: 0.9129
# Epoch 126/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2640 - accuracy: 0.9174 - val_loss: 0.2953 - val_accuracy: 0.9182
# Epoch 127/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2626 - accuracy: 0.9147 - val_loss: 0.2998 - val_accuracy: 0.9086
# Epoch 128/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2751 - accuracy: 0.9126 - val_loss: 0.2948 - val_accuracy: 0.9182
# Epoch 129/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2760 - accuracy: 0.9097 - val_loss: 0.2989 - val_accuracy: 0.9129
# Epoch 130/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2690 - accuracy: 0.9166 - val_loss: 0.2973 - val_accuracy: 0.9160
# Epoch 131/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2656 - accuracy: 0.9139 - val_loss: 0.2876 - val_accuracy: 0.9160
# Epoch 132/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2624 - accuracy: 0.9168 - val_loss: 0.3196 - val_accuracy: 0.9097
# Epoch 133/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2598 - accuracy: 0.9163 - val_loss: 0.3003 - val_accuracy: 0.9160
# Epoch 134/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2564 - accuracy: 0.9203 - val_loss: 0.3019 - val_accuracy: 0.9075
# Epoch 135/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2696 - accuracy: 0.9121 - val_loss: 0.2995 - val_accuracy: 0.9075
# Epoch 136/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2563 - accuracy: 0.9200 - val_loss: 0.2924 - val_accuracy: 0.9171
# Epoch 137/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2591 - accuracy: 0.9203 - val_loss: 0.2871 - val_accuracy: 0.9129
# Epoch 138/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2598 - accuracy: 0.9179 - val_loss: 0.3036 - val_accuracy: 0.9118
# Epoch 139/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2566 - accuracy: 0.9129 - val_loss: 0.2901 - val_accuracy: 0.9160
# Epoch 140/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2517 - accuracy: 0.9198 - val_loss: 0.2860 - val_accuracy: 0.9150
# Epoch 141/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2503 - accuracy: 0.9192 - val_loss: 0.2795 - val_accuracy: 0.9192
# Epoch 142/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2565 - accuracy: 0.9182 - val_loss: 0.2824 - val_accuracy: 0.9150
# Epoch 143/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2497 - accuracy: 0.9150 - val_loss: 0.2895 - val_accuracy: 0.9160
# Epoch 144/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2488 - accuracy: 0.9240 - val_loss: 0.2909 - val_accuracy: 0.9139
# Epoch 145/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2408 - accuracy: 0.9222 - val_loss: 0.2792 - val_accuracy: 0.9192
# Epoch 146/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2563 - accuracy: 0.9190 - val_loss: 0.2938 - val_accuracy: 0.9139
# Epoch 147/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2443 - accuracy: 0.9216 - val_loss: 0.2812 - val_accuracy: 0.9192
# Epoch 148/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2427 - accuracy: 0.9208 - val_loss: 0.3008 - val_accuracy: 0.9118
# Epoch 149/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2461 - accuracy: 0.9248 - val_loss: 0.2870 - val_accuracy: 0.9182
# Epoch 150/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2427 - accuracy: 0.9208 - val_loss: 0.2805 - val_accuracy: 0.9235
# Epoch 151/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2410 - accuracy: 0.9240 - val_loss: 0.2745 - val_accuracy: 0.9203
# Epoch 152/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2343 - accuracy: 0.9256 - val_loss: 0.2908 - val_accuracy: 0.9150
# Epoch 153/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2313 - accuracy: 0.9256 - val_loss: 0.2822 - val_accuracy: 0.9224
# Epoch 154/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2507 - accuracy: 0.9184 - val_loss: 0.2701 - val_accuracy: 0.9214
# Epoch 155/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2374 - accuracy: 0.9224 - val_loss: 0.2851 - val_accuracy: 0.9171
# Epoch 156/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2330 - accuracy: 0.9283 - val_loss: 0.2915 - val_accuracy: 0.9129
# Epoch 157/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2314 - accuracy: 0.9251 - val_loss: 0.2871 - val_accuracy: 0.9192
# Epoch 158/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2364 - accuracy: 0.9230 - val_loss: 0.2923 - val_accuracy: 0.9118
# Epoch 159/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2372 - accuracy: 0.9232 - val_loss: 0.2965 - val_accuracy: 0.9118
# Epoch 160/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2403 - accuracy: 0.9243 - val_loss: 0.2749 - val_accuracy: 0.9160
# Epoch 161/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2301 - accuracy: 0.9272 - val_loss: 0.2746 - val_accuracy: 0.9256
# Epoch 162/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2261 - accuracy: 0.9283 - val_loss: 0.2732 - val_accuracy: 0.9203
# Epoch 163/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2294 - accuracy: 0.9245 - val_loss: 0.2650 - val_accuracy: 0.9224
# Epoch 164/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2328 - accuracy: 0.9245 - val_loss: 0.2833 - val_accuracy: 0.9150
# Epoch 165/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2168 - accuracy: 0.9328 - val_loss: 0.2747 - val_accuracy: 0.9224
# Epoch 166/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2250 - accuracy: 0.9264 - val_loss: 0.2808 - val_accuracy: 0.9192
# Epoch 167/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2228 - accuracy: 0.9232 - val_loss: 0.2694 - val_accuracy: 0.9235
# Epoch 168/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2137 - accuracy: 0.9336 - val_loss: 0.2663 - val_accuracy: 0.9224
# Epoch 169/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2221 - accuracy: 0.9296 - val_loss: 0.2808 - val_accuracy: 0.9182
# Epoch 170/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2182 - accuracy: 0.9307 - val_loss: 0.2648 - val_accuracy: 0.9182
# Epoch 171/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2172 - accuracy: 0.9309 - val_loss: 0.2684 - val_accuracy: 0.9288
# Epoch 172/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2190 - accuracy: 0.9280 - val_loss: 0.2754 - val_accuracy: 0.9235
# Epoch 173/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2235 - accuracy: 0.9296 - val_loss: 0.2779 - val_accuracy: 0.9214
# Epoch 174/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2141 - accuracy: 0.9312 - val_loss: 0.2679 - val_accuracy: 0.9214
# Epoch 175/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2085 - accuracy: 0.9349 - val_loss: 0.2574 - val_accuracy: 0.9267
# Epoch 176/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.2143 - accuracy: 0.9330 - val_loss: 0.2851 - val_accuracy: 0.9171
# Epoch 177/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2109 - accuracy: 0.9304 - val_loss: 0.2675 - val_accuracy: 0.9245
# Epoch 178/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2134 - accuracy: 0.9320 - val_loss: 0.2740 - val_accuracy: 0.9160
# Epoch 179/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2082 - accuracy: 0.9344 - val_loss: 0.2573 - val_accuracy: 0.9214
# Epoch 180/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2051 - accuracy: 0.9376 - val_loss: 0.2602 - val_accuracy: 0.9203
# Epoch 181/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1971 - accuracy: 0.9370 - val_loss: 0.2569 - val_accuracy: 0.9267
# Epoch 182/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2177 - accuracy: 0.9291 - val_loss: 0.2626 - val_accuracy: 0.9224
# Epoch 183/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.2089 - accuracy: 0.9325 - val_loss: 0.2754 - val_accuracy: 0.9182
# Epoch 184/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.2127 - accuracy: 0.9330 - val_loss: 0.2739 - val_accuracy: 0.9171
# Epoch 185/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2032 - accuracy: 0.9346 - val_loss: 0.2654 - val_accuracy: 0.9171
# Epoch 186/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2054 - accuracy: 0.9315 - val_loss: 0.2558 - val_accuracy: 0.9245
# Epoch 187/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2004 - accuracy: 0.9360 - val_loss: 0.2611 - val_accuracy: 0.9214
# Epoch 188/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.2015 - accuracy: 0.9365 - val_loss: 0.2734 - val_accuracy: 0.9214
# Epoch 189/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2027 - accuracy: 0.9370 - val_loss: 0.2876 - val_accuracy: 0.9139
# Epoch 190/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2059 - accuracy: 0.9330 - val_loss: 0.2604 - val_accuracy: 0.9299
# Epoch 191/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2091 - accuracy: 0.9323 - val_loss: 0.2662 - val_accuracy: 0.9214
# Epoch 192/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1975 - accuracy: 0.9346 - val_loss: 0.2574 - val_accuracy: 0.9245
# Epoch 193/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1995 - accuracy: 0.9354 - val_loss: 0.2596 - val_accuracy: 0.9267
# Epoch 194/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1970 - accuracy: 0.9357 - val_loss: 0.2636 - val_accuracy: 0.9299
# Epoch 195/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2012 - accuracy: 0.9352 - val_loss: 0.2636 - val_accuracy: 0.9203
# Epoch 196/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2014 - accuracy: 0.9360 - val_loss: 0.2552 - val_accuracy: 0.9245
# Epoch 197/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1944 - accuracy: 0.9378 - val_loss: 0.2659 - val_accuracy: 0.9203
# Epoch 198/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1987 - accuracy: 0.9365 - val_loss: 0.2623 - val_accuracy: 0.9267
# Epoch 199/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1985 - accuracy: 0.9405 - val_loss: 0.2631 - val_accuracy: 0.9267
# Epoch 200/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.2039 - accuracy: 0.9352 - val_loss: 0.2656 - val_accuracy: 0.9182

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 8/8 [==============================] - 1s 78ms/step - loss: 1.8658 - accuracy: 0.3618 - val_loss: 1.5595 - val_accuracy: 0.5133
# Epoch 2/60
# 8/8 [==============================] - 0s 44ms/step - loss: 1.4838 - accuracy: 0.5058 - val_loss: 1.3566 - val_accuracy: 0.5420
# Epoch 3/60
# 8/8 [==============================] - 0s 38ms/step - loss: 1.3248 - accuracy: 0.5316 - val_loss: 1.2384 - val_accuracy: 0.5558
# Epoch 4/60
# 8/8 [==============================] - 0s 41ms/step - loss: 1.2065 - accuracy: 0.5850 - val_loss: 1.1357 - val_accuracy: 0.5717
# Epoch 5/60
# 8/8 [==============================] - 0s 40ms/step - loss: 1.1131 - accuracy: 0.6068 - val_loss: 1.0400 - val_accuracy: 0.6493
# Epoch 6/60
# 8/8 [==============================] - 0s 37ms/step - loss: 1.0444 - accuracy: 0.6312 - val_loss: 0.9793 - val_accuracy: 0.7141
# Epoch 7/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.9665 - accuracy: 0.6809 - val_loss: 0.8931 - val_accuracy: 0.7396
# Epoch 8/60
# 8/8 [==============================] - 0s 33ms/step - loss: 0.9055 - accuracy: 0.7112 - val_loss: 0.8489 - val_accuracy: 0.7694
# Epoch 9/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.8619 - accuracy: 0.7181 - val_loss: 0.8211 - val_accuracy: 0.7715
# Epoch 10/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.8218 - accuracy: 0.7290 - val_loss: 0.7870 - val_accuracy: 0.7428
# Epoch 11/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.7812 - accuracy: 0.7473 - val_loss: 0.7224 - val_accuracy: 0.7864
# Epoch 12/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.7485 - accuracy: 0.7598 - val_loss: 0.6938 - val_accuracy: 0.8023
# Epoch 13/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.7233 - accuracy: 0.7643 - val_loss: 0.6624 - val_accuracy: 0.8140
# Epoch 14/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6936 - accuracy: 0.7763 - val_loss: 0.6458 - val_accuracy: 0.8002
# Epoch 15/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.6825 - accuracy: 0.7768 - val_loss: 0.6496 - val_accuracy: 0.7715
# Epoch 16/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.6680 - accuracy: 0.7723 - val_loss: 0.6127 - val_accuracy: 0.8236
# Epoch 17/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6448 - accuracy: 0.7864 - val_loss: 0.6088 - val_accuracy: 0.8236
# Epoch 18/60
# 8/8 [==============================] - 0s 33ms/step - loss: 0.6401 - accuracy: 0.7883 - val_loss: 0.5966 - val_accuracy: 0.8332
# Epoch 19/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6136 - accuracy: 0.7986 - val_loss: 0.5950 - val_accuracy: 0.8077
# Epoch 20/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.6066 - accuracy: 0.7997 - val_loss: 0.5780 - val_accuracy: 0.8087
# Epoch 21/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.5971 - accuracy: 0.8079 - val_loss: 0.5710 - val_accuracy: 0.8268
# Epoch 22/60
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5838 - accuracy: 0.8069 - val_loss: 0.5526 - val_accuracy: 0.8353
# Epoch 23/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5752 - accuracy: 0.8135 - val_loss: 0.5507 - val_accuracy: 0.8332
# Epoch 24/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5758 - accuracy: 0.8151 - val_loss: 0.5261 - val_accuracy: 0.8438
# Epoch 25/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.5530 - accuracy: 0.8185 - val_loss: 0.5178 - val_accuracy: 0.8555
# Epoch 26/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.5470 - accuracy: 0.8252 - val_loss: 0.5219 - val_accuracy: 0.8533
# Epoch 27/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.5285 - accuracy: 0.8302 - val_loss: 0.5125 - val_accuracy: 0.8480
# Epoch 28/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.5198 - accuracy: 0.8355 - val_loss: 0.4991 - val_accuracy: 0.8576
# Epoch 29/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5104 - accuracy: 0.8329 - val_loss: 0.4909 - val_accuracy: 0.8533
# Epoch 30/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5183 - accuracy: 0.8353 - val_loss: 0.5018 - val_accuracy: 0.8608
# Epoch 31/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.5094 - accuracy: 0.8385 - val_loss: 0.4838 - val_accuracy: 0.8565
# Epoch 32/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.5049 - accuracy: 0.8355 - val_loss: 0.4863 - val_accuracy: 0.8480
# Epoch 33/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4939 - accuracy: 0.8406 - val_loss: 0.4852 - val_accuracy: 0.8597
# Epoch 34/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4935 - accuracy: 0.8377 - val_loss: 0.4817 - val_accuracy: 0.8640
# Epoch 35/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.4950 - accuracy: 0.8414 - val_loss: 0.4763 - val_accuracy: 0.8650
# Epoch 36/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4820 - accuracy: 0.8464 - val_loss: 0.4725 - val_accuracy: 0.8555
# Epoch 37/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4751 - accuracy: 0.8446 - val_loss: 0.4550 - val_accuracy: 0.8693
# Epoch 38/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4728 - accuracy: 0.8555 - val_loss: 0.4543 - val_accuracy: 0.8714
# Epoch 39/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4519 - accuracy: 0.8565 - val_loss: 0.4473 - val_accuracy: 0.8789
# Epoch 40/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4610 - accuracy: 0.8478 - val_loss: 0.4472 - val_accuracy: 0.8767
# Epoch 41/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4470 - accuracy: 0.8579 - val_loss: 0.4389 - val_accuracy: 0.8842
# Epoch 42/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4418 - accuracy: 0.8608 - val_loss: 0.4402 - val_accuracy: 0.8704
# Epoch 43/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4525 - accuracy: 0.8555 - val_loss: 0.4309 - val_accuracy: 0.8852
# Epoch 44/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4471 - accuracy: 0.8605 - val_loss: 0.4381 - val_accuracy: 0.8810
# Epoch 45/60
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4393 - accuracy: 0.8595 - val_loss: 0.4359 - val_accuracy: 0.8693
# Epoch 46/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4316 - accuracy: 0.8557 - val_loss: 0.4207 - val_accuracy: 0.8874
# Epoch 47/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4218 - accuracy: 0.8613 - val_loss: 0.4110 - val_accuracy: 0.8874
# Epoch 48/60
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4221 - accuracy: 0.8640 - val_loss: 0.4069 - val_accuracy: 0.8916
# Epoch 49/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4229 - accuracy: 0.8632 - val_loss: 0.4216 - val_accuracy: 0.8895
# Epoch 50/60
# 8/8 [==============================] - 0s 36ms/step - loss: 0.4139 - accuracy: 0.8701 - val_loss: 0.4137 - val_accuracy: 0.8789
# Epoch 51/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.4183 - accuracy: 0.8645 - val_loss: 0.3983 - val_accuracy: 0.8874
# Epoch 52/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.4128 - accuracy: 0.8706 - val_loss: 0.4029 - val_accuracy: 0.8842
# Epoch 53/60
# 8/8 [==============================] - 0s 37ms/step - loss: 0.3975 - accuracy: 0.8754 - val_loss: 0.4173 - val_accuracy: 0.8842
# Epoch 54/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4137 - accuracy: 0.8690 - val_loss: 0.3977 - val_accuracy: 0.8884
# Epoch 55/60
# 8/8 [==============================] - 0s 38ms/step - loss: 0.4032 - accuracy: 0.8714 - val_loss: 0.3964 - val_accuracy: 0.8884
# Epoch 56/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4058 - accuracy: 0.8738 - val_loss: 0.3927 - val_accuracy: 0.8969
# Epoch 57/60
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3892 - accuracy: 0.8770 - val_loss: 0.3895 - val_accuracy: 0.8852
# Epoch 58/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3967 - accuracy: 0.8709 - val_loss: 0.3845 - val_accuracy: 0.8895
# Epoch 59/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3785 - accuracy: 0.8762 - val_loss: 0.3890 - val_accuracy: 0.8916
# Epoch 60/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3785 - accuracy: 0.8765 - val_loss: 0.3793 - val_accuracy: 0.8916

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 4ms/step - loss: 0.3269 - accuracy: 0.9006
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3793 - accuracy: 0.8916
# 0.9006376266479492 0.8916046619415283

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 122, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:03:48

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   0   0   0   1   0   0]
#  [  0   0   0 123   0   0   0   0   1]
#  [  0   0   0   0 309   8   3   0   0]
#  [  0   0   0   1   8 102   8   0   1]
#  [  0   0   1   0   6  14  26   0   3]
#  [  0   0   0   0  14   9   0  27   0]
#  [  0   0   0   3  10   8   3   0  13]]
#
# Accuracy Score
# 0.8916046758767269
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.97      0.99      0.98       124
#       built       0.89      0.97      0.93       320
#     windows       0.72      0.85      0.78       120
#       roads       0.63      0.52      0.57        50
#        cars       1.00      0.54      0.70        50
#       metal       0.72      0.35      0.47        37
#
# avg / total       0.89      0.89      0.88       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
# Out:
# 122 7
