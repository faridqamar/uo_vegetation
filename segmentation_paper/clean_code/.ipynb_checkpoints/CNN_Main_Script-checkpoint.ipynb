# %% [markdown]
# # Pixel-wise Classification of High-Resolution Ground-Based Urban Hyperspectral Images with Convolutional Neural Networks
#
# ## Main Script
#
# ---

# %%
# -- importing necessary libraries

import os
import math
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import layers
from sklearn import metrics
import time
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %% [markdown]
# ## Select Parameters:

# %% [markdown]
# ### Pick either Model 1 or Model 2, or make your own with Model 3

# %%
# -- Model 1 has 32 filters in the first convolutional layer and 64 filters in the second
#    each with a width of 5 spectral channels (3.6 nm) 
#modelnum = 1
#filtersize = 5
#conv1 = 32
#dens1 = 1024

# -- Model 2 has 16 filters in the first convolutional layer and 32 filters in the second
#    each with a width of 50 spectral channels (36 nm)
modelnum = 2
filtersize = 50
conv1 = 16
dens1 = 512

# -- Model 3: make your own - use this option when running reduced spectral resolution (binned)
#modelnum = 3
#filtersize = 200 # - size of filter (spectral bands)
#conv1 = 16       # - number of filters in the 1st conv. layer (twice this will be in the 2nd)
#dens1 = 512      # - number of units in the fully connected flattened dense layer before output

# %% [markdown]
# ### Pick either to include or exclude the spatial coordinates
# #### NOTE: for transferring the model, ALWAYS pick FALSE

# %%
include_spatial = True

#include_spatial = False # pick this to transfer the models

# %% [markdown]
# ### Pick whether to use full spectral resolution or reduced (binned)
# #### Full resolution is 848 channels (or bins)
# #### enter the number of channels if reduced_resolution = True, filtersize is proportional to the number of channels

# %%
reduced_resolution = False

#reduced_resolution = True
#num_of_bins = 848
#filtersize = math.ceil(50 * num_of_bins/848)

# %% [markdown]
# ### Pick the train/test split ratio
# #### if trrat = 0.8, then 80% (stratified) will be used for training and 20% for testing

# %%
trrat = 0.8

# %% [markdown]
# ---

# %% [markdown]
# ### Defining the needed functions

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
# -- splitting text into row index and column index 

def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
# -- transforming individual row and column numbers into an array

def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
# -- function to read the manually classified pixels coordinates
#    given the type of pixels (kind) and image identifier (scan)

def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
# -- function used to split the manually classified pixel coordinates into
#    into training and testing sets given a split ratio (trrat)

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
# -- Create the CNN model using tensorflow.keras and the parameters selected above

def CNN_Model(nwaves, spatial, filtersize, conv1, dens1):        
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(conv1, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(conv1*2, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)
    
    if spatial:
        Inputs_2 = keras.Input(shape=(2,), name="spatial")
        Concat = layers.concatenate([Flatten_1, Inputs_2])
        Dense_1 = layers.Dense(dens1, activation="relu")(Concat)
        Output = layers.Dense(9, activation="softmax")(Dense_1)

        model = keras.Model(inputs=[Inputs_1, Inputs_2],
                            outputs=[Output],)
    else:
        Dense_1 = layers.Dense(dens1, activation="relu")(Flatten_1)
        Output = layers.Dense(9, activation="softmax")(Dense_1)

        model = keras.Model(inputs=[Inputs_1],
                            outputs=[Output],)
    
    return model

# %%
# -- plot the loss history of a CNN model and its accuracy

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['acc'])
    ax2.plot(model.history['val_acc'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['acc'])
    ax4.plot(model.history['val_acc'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 0. Sky
# 1. Clouds
# 2. Water
# 3. Vegetation
# 4. Buildings (concrete structures)
# 5. Windows
# 6. Roads
# 7. Cars
# 8. Metal Structures
# ---

# %% [markdown]
# ---
# # CNN trained and tested on Scene 1-b

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
cube_sub0 = cube0.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
# -- if reduced_resolution = True, the spectra are averaged into bins to simulate reduced resolution

if reduced_resolution:
    bin_ind = []

    for i in range(0, num_of_bins):
        low_ind = int(i*int(cube_sub0.shape[0]/num_of_bins))
        upp_ind = int(low_ind + int(cube_sub0.shape[0]/num_of_bins))
        bin_ind.append([low_ind, upp_ind])
    bin_ind[-1][-1] = cube_sub0.shape[0]

    cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))
    for i in range(num_of_bins):
        cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

    cube_standard0 = cube_binned0
    
# -- reshape standardized cube to (row, col, wavelength)
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], cube_sub0.shape[0])

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# -- create position array from coordinates and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
# -- get the coordinates of training and testing sets for each class
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)

cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 848) (80, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (488, 848) (122, 848)
# built  (960, 848) (240, 848)
# windows  (400, 848) (100, 848)
# roads  (48, 848) (12, 848)
# cars  (44, 848) (11, 848)
# metal  (184, 848) (46, 848)

# %%
# -- concatenate the training arrays into training data and labels

cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
cube_train_labels0 = np.array(cube_train_labels0)
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
cube_test_labels0 = np.array(cube_test_labels0)
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnn0 = CNN_Model(cube_std0_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                         validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                         epochs=200, batch_size=512)
else:
    CNNmodel0 = cnn0.fit({"spectra":cube_train02}, cube_train_labels0, 
                         validation_data=({"spectra":cube_test02}, cube_test_labels0),
                         epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 195ms/step - loss: 2.0650 - accuracy: 0.2911 - val_loss: 1.6569 - val_accuracy: 0.4079
# Epoch 2/200
# 6/6 [==============================] - 1s 157ms/step - loss: 1.3199 - accuracy: 0.5661 - val_loss: 1.0537 - val_accuracy: 0.6653
# Epoch 3/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.9213 - accuracy: 0.6892 - val_loss: 0.7926 - val_accuracy: 0.6990
# Epoch 4/200
# 6/6 [==============================] - 2s 286ms/step - loss: 0.7095 - accuracy: 0.7356 - val_loss: 0.6538 - val_accuracy: 0.7553
# Epoch 5/200
# 6/6 [==============================] - 1s 193ms/step - loss: 0.6068 - accuracy: 0.7489 - val_loss: 0.5852 - val_accuracy: 0.7918
# Epoch 6/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.5355 - accuracy: 0.7862 - val_loss: 0.5459 - val_accuracy: 0.7961
# Epoch 7/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.5512 - accuracy: 0.7722 - val_loss: 0.5488 - val_accuracy: 0.7918
# Epoch 8/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.5160 - accuracy: 0.7894 - val_loss: 0.5399 - val_accuracy: 0.8101
# Epoch 9/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.4783 - accuracy: 0.8045 - val_loss: 0.5180 - val_accuracy: 0.8101
# Epoch 10/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.4601 - accuracy: 0.8189 - val_loss: 0.4974 - val_accuracy: 0.8003
# Epoch 11/200
# 6/6 [==============================] - 1s 160ms/step - loss: 0.4342 - accuracy: 0.8298 - val_loss: 0.4960 - val_accuracy: 0.8017
# Epoch 12/200
# 6/6 [==============================] - 1s 185ms/step - loss: 0.4209 - accuracy: 0.8432 - val_loss: 0.4599 - val_accuracy: 0.8312
# Epoch 13/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.4071 - accuracy: 0.8527 - val_loss: 0.4537 - val_accuracy: 0.8143
# Epoch 14/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.3954 - accuracy: 0.8527 - val_loss: 0.4605 - val_accuracy: 0.8411
# Epoch 15/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.3767 - accuracy: 0.8660 - val_loss: 0.4405 - val_accuracy: 0.8256
# Epoch 16/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.3731 - accuracy: 0.8625 - val_loss: 0.4252 - val_accuracy: 0.8340
# Epoch 17/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.3646 - accuracy: 0.8632 - val_loss: 0.4277 - val_accuracy: 0.8453
# Epoch 18/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.3559 - accuracy: 0.8678 - val_loss: 0.3990 - val_accuracy: 0.8565
# Epoch 19/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.3505 - accuracy: 0.8703 - val_loss: 0.4020 - val_accuracy: 0.8509
# Epoch 20/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.3382 - accuracy: 0.8692 - val_loss: 0.3927 - val_accuracy: 0.8608
# Epoch 21/200
# 6/6 [==============================] - 1s 181ms/step - loss: 0.3280 - accuracy: 0.8773 - val_loss: 0.4151 - val_accuracy: 0.8439
# Epoch 22/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.3429 - accuracy: 0.8660 - val_loss: 0.4312 - val_accuracy: 0.8298
# Epoch 23/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.3507 - accuracy: 0.8643 - val_loss: 0.3800 - val_accuracy: 0.8523
# Epoch 24/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.3223 - accuracy: 0.8805 - val_loss: 0.4021 - val_accuracy: 0.8411
# Epoch 25/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.3249 - accuracy: 0.8776 - val_loss: 0.4052 - val_accuracy: 0.8579
# Epoch 26/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.3227 - accuracy: 0.8805 - val_loss: 0.3896 - val_accuracy: 0.8565
# Epoch 27/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.3458 - accuracy: 0.8713 - val_loss: 0.3875 - val_accuracy: 0.8622
# Epoch 28/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.3266 - accuracy: 0.8769 - val_loss: 0.3563 - val_accuracy: 0.8664
# Epoch 29/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.3054 - accuracy: 0.8885 - val_loss: 0.3543 - val_accuracy: 0.8706
# Epoch 30/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.3068 - accuracy: 0.8864 - val_loss: 0.3555 - val_accuracy: 0.8720
# Epoch 31/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.2962 - accuracy: 0.8949 - val_loss: 0.3437 - val_accuracy: 0.8776
# Epoch 32/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.2880 - accuracy: 0.8878 - val_loss: 0.3415 - val_accuracy: 0.8692
# Epoch 33/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.2875 - accuracy: 0.8896 - val_loss: 0.3390 - val_accuracy: 0.8762
# Epoch 34/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.2784 - accuracy: 0.9015 - val_loss: 0.3333 - val_accuracy: 0.8819
# Epoch 35/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.2803 - accuracy: 0.8942 - val_loss: 0.3856 - val_accuracy: 0.8523
# Epoch 36/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2853 - accuracy: 0.8914 - val_loss: 0.3709 - val_accuracy: 0.8481
# Epoch 37/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2817 - accuracy: 0.8963 - val_loss: 0.3875 - val_accuracy: 0.8481
# Epoch 38/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.2906 - accuracy: 0.8931 - val_loss: 0.3171 - val_accuracy: 0.8790
# Epoch 39/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.2679 - accuracy: 0.8935 - val_loss: 0.3263 - val_accuracy: 0.8861
# Epoch 40/200
# 6/6 [==============================] - 1s 188ms/step - loss: 0.2643 - accuracy: 0.8980 - val_loss: 0.3256 - val_accuracy: 0.8875
# Epoch 41/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.2686 - accuracy: 0.8959 - val_loss: 0.3233 - val_accuracy: 0.8833
# Epoch 42/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.2668 - accuracy: 0.8998 - val_loss: 0.3319 - val_accuracy: 0.8931
# Epoch 43/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.2775 - accuracy: 0.8938 - val_loss: 0.3325 - val_accuracy: 0.8805
# Epoch 44/200
# 6/6 [==============================] - 1s 195ms/step - loss: 0.2695 - accuracy: 0.9008 - val_loss: 0.3486 - val_accuracy: 0.8776
# Epoch 45/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.2846 - accuracy: 0.8928 - val_loss: 0.3258 - val_accuracy: 0.8861
# Epoch 46/200
# 6/6 [==============================] - 1s 163ms/step - loss: 0.2526 - accuracy: 0.9072 - val_loss: 0.3405 - val_accuracy: 0.8664
# Epoch 47/200
# 6/6 [==============================] - 1s 159ms/step - loss: 0.2667 - accuracy: 0.9044 - val_loss: 0.3143 - val_accuracy: 0.8847
# Epoch 48/200
# 6/6 [==============================] - 1s 193ms/step - loss: 0.2469 - accuracy: 0.9153 - val_loss: 0.3019 - val_accuracy: 0.8931
# Epoch 49/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.2393 - accuracy: 0.9146 - val_loss: 0.2987 - val_accuracy: 0.8931
# Epoch 50/200
# 6/6 [==============================] - 1s 154ms/step - loss: 0.2303 - accuracy: 0.9149 - val_loss: 0.3135 - val_accuracy: 0.8875
# Epoch 51/200
# 6/6 [==============================] - 1s 159ms/step - loss: 0.2454 - accuracy: 0.9089 - val_loss: 0.3103 - val_accuracy: 0.8847
# Epoch 52/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.2435 - accuracy: 0.9068 - val_loss: 0.3293 - val_accuracy: 0.8790
# Epoch 53/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.2332 - accuracy: 0.9184 - val_loss: 0.2839 - val_accuracy: 0.9001
# Epoch 54/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.2217 - accuracy: 0.9198 - val_loss: 0.2778 - val_accuracy: 0.9044
# Epoch 55/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.2248 - accuracy: 0.9188 - val_loss: 0.2963 - val_accuracy: 0.8945
# Epoch 56/200
# 6/6 [==============================] - 1s 191ms/step - loss: 0.2420 - accuracy: 0.9121 - val_loss: 0.2918 - val_accuracy: 0.8959
# Epoch 57/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2571 - accuracy: 0.9033 - val_loss: 0.3047 - val_accuracy: 0.8875
# Epoch 58/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.2519 - accuracy: 0.9026 - val_loss: 0.2995 - val_accuracy: 0.9001
# Epoch 59/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.2372 - accuracy: 0.9124 - val_loss: 0.2902 - val_accuracy: 0.8973
# Epoch 60/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.2383 - accuracy: 0.9114 - val_loss: 0.2939 - val_accuracy: 0.9001
# Epoch 61/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.2362 - accuracy: 0.9139 - val_loss: 0.2832 - val_accuracy: 0.8973
# Epoch 62/200
# 6/6 [==============================] - 1s 155ms/step - loss: 0.2250 - accuracy: 0.9160 - val_loss: 0.2716 - val_accuracy: 0.9072
# Epoch 63/200
# 6/6 [==============================] - 1s 163ms/step - loss: 0.2210 - accuracy: 0.9191 - val_loss: 0.2698 - val_accuracy: 0.9058
# Epoch 64/200
# 6/6 [==============================] - 1s 190ms/step - loss: 0.2143 - accuracy: 0.9160 - val_loss: 0.2710 - val_accuracy: 0.9044
# Epoch 65/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.2052 - accuracy: 0.9241 - val_loss: 0.2614 - val_accuracy: 0.9100
# Epoch 66/200
# 6/6 [==============================] - 1s 163ms/step - loss: 0.1904 - accuracy: 0.9318 - val_loss: 0.2732 - val_accuracy: 0.8973
# Epoch 67/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.1963 - accuracy: 0.9255 - val_loss: 0.2712 - val_accuracy: 0.9001
# Epoch 68/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1944 - accuracy: 0.9272 - val_loss: 0.2847 - val_accuracy: 0.9001
# Epoch 69/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.2012 - accuracy: 0.9269 - val_loss: 0.2674 - val_accuracy: 0.9044
# Epoch 70/200
# 6/6 [==============================] - 1s 150ms/step - loss: 0.2084 - accuracy: 0.9233 - val_loss: 0.2572 - val_accuracy: 0.9086
# Epoch 71/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.1917 - accuracy: 0.9297 - val_loss: 0.2750 - val_accuracy: 0.9001
# Epoch 72/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.2048 - accuracy: 0.9233 - val_loss: 0.2762 - val_accuracy: 0.9058
# Epoch 73/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.1936 - accuracy: 0.9283 - val_loss: 0.2539 - val_accuracy: 0.9142
# Epoch 74/200
# 6/6 [==============================] - 1s 165ms/step - loss: 0.1930 - accuracy: 0.9279 - val_loss: 0.2610 - val_accuracy: 0.9156
# Epoch 75/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.1922 - accuracy: 0.9269 - val_loss: 0.3077 - val_accuracy: 0.8805
# Epoch 76/200
# 6/6 [==============================] - 1s 181ms/step - loss: 0.2256 - accuracy: 0.9110 - val_loss: 0.4176 - val_accuracy: 0.8594
# Epoch 77/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2758 - accuracy: 0.8987 - val_loss: 0.3238 - val_accuracy: 0.8748
# Epoch 78/200
# 6/6 [==============================] - 1s 154ms/step - loss: 0.2286 - accuracy: 0.9163 - val_loss: 0.3085 - val_accuracy: 0.8931
# Epoch 79/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.2305 - accuracy: 0.9188 - val_loss: 0.3231 - val_accuracy: 0.8973
# Epoch 80/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.2125 - accuracy: 0.9265 - val_loss: 0.2822 - val_accuracy: 0.9030
# Epoch 81/200
# 6/6 [==============================] - 2s 358ms/step - loss: 0.2027 - accuracy: 0.9219 - val_loss: 0.2824 - val_accuracy: 0.8959
# Epoch 82/200
# 6/6 [==============================] - 1s 159ms/step - loss: 0.2086 - accuracy: 0.9226 - val_loss: 0.2616 - val_accuracy: 0.9156
# Epoch 83/200
# 6/6 [==============================] - 1s 181ms/step - loss: 0.2073 - accuracy: 0.9233 - val_loss: 0.2771 - val_accuracy: 0.9001
# Epoch 84/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.2019 - accuracy: 0.9233 - val_loss: 0.2704 - val_accuracy: 0.9058
# Epoch 85/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.2041 - accuracy: 0.9251 - val_loss: 0.2611 - val_accuracy: 0.9114
# Epoch 86/200
# 6/6 [==============================] - 1s 157ms/step - loss: 0.1912 - accuracy: 0.9311 - val_loss: 0.3194 - val_accuracy: 0.8790
# Epoch 87/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.1926 - accuracy: 0.9272 - val_loss: 0.2393 - val_accuracy: 0.9226
# Epoch 88/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.1892 - accuracy: 0.9304 - val_loss: 0.2465 - val_accuracy: 0.9226
# Epoch 89/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.1853 - accuracy: 0.9342 - val_loss: 0.2447 - val_accuracy: 0.9030
# Epoch 90/200
# 6/6 [==============================] - 1s 152ms/step - loss: 0.1850 - accuracy: 0.9346 - val_loss: 0.2495 - val_accuracy: 0.9142
# Epoch 91/200
# 6/6 [==============================] - 1s 160ms/step - loss: 0.1756 - accuracy: 0.9381 - val_loss: 0.2311 - val_accuracy: 0.9170
# Epoch 92/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.1764 - accuracy: 0.9357 - val_loss: 0.2391 - val_accuracy: 0.9170
# Epoch 93/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.1855 - accuracy: 0.9297 - val_loss: 0.2322 - val_accuracy: 0.9226
# Epoch 94/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.1730 - accuracy: 0.9360 - val_loss: 0.2451 - val_accuracy: 0.9142
# Epoch 95/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.1743 - accuracy: 0.9346 - val_loss: 0.2737 - val_accuracy: 0.9030
# Epoch 96/200
# 6/6 [==============================] - 1s 165ms/step - loss: 0.1750 - accuracy: 0.9335 - val_loss: 0.2514 - val_accuracy: 0.9114
# Epoch 97/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1712 - accuracy: 0.9378 - val_loss: 0.2468 - val_accuracy: 0.9142
# Epoch 98/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.1574 - accuracy: 0.9434 - val_loss: 0.2396 - val_accuracy: 0.9170
# Epoch 99/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.1573 - accuracy: 0.9409 - val_loss: 0.2493 - val_accuracy: 0.9184
# Epoch 100/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.1535 - accuracy: 0.9427 - val_loss: 0.2439 - val_accuracy: 0.9170
# Epoch 101/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.1511 - accuracy: 0.9469 - val_loss: 0.2385 - val_accuracy: 0.9128
# Epoch 102/200
# 6/6 [==============================] - 1s 160ms/step - loss: 0.1486 - accuracy: 0.9469 - val_loss: 0.2210 - val_accuracy: 0.9241
# Epoch 103/200
# 6/6 [==============================] - 1s 165ms/step - loss: 0.1529 - accuracy: 0.9451 - val_loss: 0.2258 - val_accuracy: 0.9255
# Epoch 104/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.1466 - accuracy: 0.9466 - val_loss: 0.2436 - val_accuracy: 0.9198
# Epoch 105/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.1562 - accuracy: 0.9427 - val_loss: 0.2276 - val_accuracy: 0.9156
# Epoch 106/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1452 - accuracy: 0.9525 - val_loss: 0.2281 - val_accuracy: 0.9226
# Epoch 107/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.1445 - accuracy: 0.9480 - val_loss: 0.2245 - val_accuracy: 0.9297
# Epoch 108/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.1518 - accuracy: 0.9434 - val_loss: 0.2345 - val_accuracy: 0.9212
# Epoch 109/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.1440 - accuracy: 0.9494 - val_loss: 0.2200 - val_accuracy: 0.9241
# Epoch 110/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.1502 - accuracy: 0.9459 - val_loss: 0.2290 - val_accuracy: 0.9255
# Epoch 111/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.1379 - accuracy: 0.9532 - val_loss: 0.2375 - val_accuracy: 0.9212
# Epoch 112/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.1396 - accuracy: 0.9494 - val_loss: 0.2458 - val_accuracy: 0.9156
# Epoch 113/200
# 6/6 [==============================] - 1s 173ms/step - loss: 0.1443 - accuracy: 0.9490 - val_loss: 0.2336 - val_accuracy: 0.9184
# Epoch 114/200
# 6/6 [==============================] - 1s 147ms/step - loss: 0.1379 - accuracy: 0.9501 - val_loss: 0.2157 - val_accuracy: 0.9283
# Epoch 115/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.1379 - accuracy: 0.9539 - val_loss: 0.2100 - val_accuracy: 0.9311
# Epoch 116/200
# 6/6 [==============================] - 1s 163ms/step - loss: 0.1319 - accuracy: 0.9511 - val_loss: 0.2277 - val_accuracy: 0.9226
# Epoch 117/200
# 6/6 [==============================] - 1s 175ms/step - loss: 0.1290 - accuracy: 0.9504 - val_loss: 0.2210 - val_accuracy: 0.9269
# Epoch 118/200
# 6/6 [==============================] - 1s 154ms/step - loss: 0.1306 - accuracy: 0.9529 - val_loss: 0.2218 - val_accuracy: 0.9255
# Epoch 119/200
# 6/6 [==============================] - 1s 151ms/step - loss: 0.1237 - accuracy: 0.9529 - val_loss: 0.2233 - val_accuracy: 0.9283
# Epoch 120/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.1264 - accuracy: 0.9617 - val_loss: 0.2154 - val_accuracy: 0.9381
# Epoch 121/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.1326 - accuracy: 0.9508 - val_loss: 0.2096 - val_accuracy: 0.9283
# Epoch 122/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.1155 - accuracy: 0.9610 - val_loss: 0.2147 - val_accuracy: 0.9311
# Epoch 123/200
# 6/6 [==============================] - 1s 152ms/step - loss: 0.1282 - accuracy: 0.9522 - val_loss: 0.2339 - val_accuracy: 0.9184
# Epoch 124/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.1276 - accuracy: 0.9525 - val_loss: 0.2187 - val_accuracy: 0.9311
# Epoch 125/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1294 - accuracy: 0.9589 - val_loss: 0.2263 - val_accuracy: 0.9269
# Epoch 126/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1193 - accuracy: 0.9631 - val_loss: 0.2029 - val_accuracy: 0.9381
# Epoch 127/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.1157 - accuracy: 0.9575 - val_loss: 0.2067 - val_accuracy: 0.9339
# Epoch 128/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.1189 - accuracy: 0.9557 - val_loss: 0.2550 - val_accuracy: 0.9184
# Epoch 129/200
# 6/6 [==============================] - 1s 182ms/step - loss: 0.1363 - accuracy: 0.9536 - val_loss: 0.2357 - val_accuracy: 0.9184
# Epoch 130/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.1425 - accuracy: 0.9497 - val_loss: 0.2288 - val_accuracy: 0.9226
# Epoch 131/200
# 6/6 [==============================] - 1s 159ms/step - loss: 0.1301 - accuracy: 0.9518 - val_loss: 0.2150 - val_accuracy: 0.9339
# Epoch 132/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1360 - accuracy: 0.9518 - val_loss: 0.2421 - val_accuracy: 0.9269
# Epoch 133/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.1379 - accuracy: 0.9504 - val_loss: 0.2207 - val_accuracy: 0.9269
# Epoch 134/200
# 6/6 [==============================] - 1s 170ms/step - loss: 0.1190 - accuracy: 0.9592 - val_loss: 0.2175 - val_accuracy: 0.9325
# Epoch 135/200
# 6/6 [==============================] - 1s 157ms/step - loss: 0.1197 - accuracy: 0.9617 - val_loss: 0.2026 - val_accuracy: 0.9325
# Epoch 136/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1221 - accuracy: 0.9585 - val_loss: 0.2222 - val_accuracy: 0.9311
# Epoch 137/200
# 6/6 [==============================] - 1s 190ms/step - loss: 0.1223 - accuracy: 0.9589 - val_loss: 0.2189 - val_accuracy: 0.9255
# Epoch 138/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.1119 - accuracy: 0.9603 - val_loss: 0.2045 - val_accuracy: 0.9423
# Epoch 139/200
# 6/6 [==============================] - 1s 153ms/step - loss: 0.1078 - accuracy: 0.9634 - val_loss: 0.2034 - val_accuracy: 0.9395
# Epoch 140/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1079 - accuracy: 0.9631 - val_loss: 0.2320 - val_accuracy: 0.9297
# Epoch 141/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.1112 - accuracy: 0.9592 - val_loss: 0.2171 - val_accuracy: 0.9311
# Epoch 142/200
# 6/6 [==============================] - 1s 163ms/step - loss: 0.1189 - accuracy: 0.9571 - val_loss: 0.2150 - val_accuracy: 0.9311
# Epoch 143/200
# 6/6 [==============================] - 1s 160ms/step - loss: 0.1023 - accuracy: 0.9669 - val_loss: 0.1992 - val_accuracy: 0.9423
# Epoch 144/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.0948 - accuracy: 0.9669 - val_loss: 0.1934 - val_accuracy: 0.9423
# Epoch 145/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.1070 - accuracy: 0.9638 - val_loss: 0.2080 - val_accuracy: 0.9325
# Epoch 146/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.1101 - accuracy: 0.9617 - val_loss: 0.2110 - val_accuracy: 0.9297
# Epoch 147/200
# 6/6 [==============================] - 1s 167ms/step - loss: 0.1057 - accuracy: 0.9620 - val_loss: 0.2299 - val_accuracy: 0.9212
# Epoch 148/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.1139 - accuracy: 0.9589 - val_loss: 0.2209 - val_accuracy: 0.9297
# Epoch 149/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0997 - accuracy: 0.9648 - val_loss: 0.2165 - val_accuracy: 0.9325
# Epoch 150/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.0984 - accuracy: 0.9659 - val_loss: 0.2045 - val_accuracy: 0.9353
# Epoch 151/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0955 - accuracy: 0.9648 - val_loss: 0.2032 - val_accuracy: 0.9367
# Epoch 152/200
# 6/6 [==============================] - 1s 187ms/step - loss: 0.0978 - accuracy: 0.9634 - val_loss: 0.2208 - val_accuracy: 0.9297
# Epoch 153/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.1069 - accuracy: 0.9617 - val_loss: 0.2002 - val_accuracy: 0.9381
# Epoch 154/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.1022 - accuracy: 0.9641 - val_loss: 0.2002 - val_accuracy: 0.9325
# Epoch 155/200
# 6/6 [==============================] - 1s 164ms/step - loss: 0.0954 - accuracy: 0.9694 - val_loss: 0.1949 - val_accuracy: 0.9423
# Epoch 156/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.0984 - accuracy: 0.9627 - val_loss: 0.2013 - val_accuracy: 0.9409
# Epoch 157/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0852 - accuracy: 0.9719 - val_loss: 0.2061 - val_accuracy: 0.9325
# Epoch 158/200
# 6/6 [==============================] - 1s 149ms/step - loss: 0.0940 - accuracy: 0.9627 - val_loss: 0.2067 - val_accuracy: 0.9437
# Epoch 159/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0829 - accuracy: 0.9708 - val_loss: 0.2064 - val_accuracy: 0.9297
# Epoch 160/200
# 6/6 [==============================] - 1s 169ms/step - loss: 0.0879 - accuracy: 0.9701 - val_loss: 0.1976 - val_accuracy: 0.9423
# Epoch 161/200
# 6/6 [==============================] - 1s 172ms/step - loss: 0.0904 - accuracy: 0.9680 - val_loss: 0.2067 - val_accuracy: 0.9409
# Epoch 162/200
# 6/6 [==============================] - 1s 162ms/step - loss: 0.0967 - accuracy: 0.9684 - val_loss: 0.2342 - val_accuracy: 0.9297
# Epoch 163/200
# 6/6 [==============================] - 1s 150ms/step - loss: 0.0947 - accuracy: 0.9652 - val_loss: 0.2232 - val_accuracy: 0.9395
# Epoch 164/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.1043 - accuracy: 0.9624 - val_loss: 0.2318 - val_accuracy: 0.9198
# Epoch 165/200
# 6/6 [==============================] - 1s 175ms/step - loss: 0.1098 - accuracy: 0.9613 - val_loss: 0.2226 - val_accuracy: 0.9241
# Epoch 166/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.1022 - accuracy: 0.9645 - val_loss: 0.2110 - val_accuracy: 0.9381
# Epoch 167/200
# 6/6 [==============================] - 1s 155ms/step - loss: 0.0985 - accuracy: 0.9645 - val_loss: 0.2294 - val_accuracy: 0.9311
# Epoch 168/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1027 - accuracy: 0.9638 - val_loss: 0.2249 - val_accuracy: 0.9409
# Epoch 169/200
# 6/6 [==============================] - 1s 187ms/step - loss: 0.0895 - accuracy: 0.9673 - val_loss: 0.2076 - val_accuracy: 0.9367
# Epoch 170/200
# 6/6 [==============================] - 1s 180ms/step - loss: 0.0897 - accuracy: 0.9669 - val_loss: 0.2161 - val_accuracy: 0.9325
# Epoch 171/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.0883 - accuracy: 0.9705 - val_loss: 0.1950 - val_accuracy: 0.9508
# Epoch 172/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0762 - accuracy: 0.9733 - val_loss: 0.2222 - val_accuracy: 0.9311
# Epoch 173/200
# 6/6 [==============================] - 1s 178ms/step - loss: 0.0783 - accuracy: 0.9708 - val_loss: 0.1954 - val_accuracy: 0.9451
# Epoch 174/200
# 6/6 [==============================] - 1s 183ms/step - loss: 0.0804 - accuracy: 0.9719 - val_loss: 0.1960 - val_accuracy: 0.9409
# Epoch 175/200
# 6/6 [==============================] - 1s 157ms/step - loss: 0.0787 - accuracy: 0.9722 - val_loss: 0.2152 - val_accuracy: 0.9409
# Epoch 176/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.0841 - accuracy: 0.9684 - val_loss: 0.2080 - val_accuracy: 0.9395
# Epoch 177/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.0824 - accuracy: 0.9712 - val_loss: 0.2197 - val_accuracy: 0.9381
# Epoch 178/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0908 - accuracy: 0.9669 - val_loss: 0.2126 - val_accuracy: 0.9395
# Epoch 179/200
# 6/6 [==============================] - 1s 150ms/step - loss: 0.0878 - accuracy: 0.9705 - val_loss: 0.2186 - val_accuracy: 0.9353
# Epoch 180/200
# 6/6 [==============================] - 1s 158ms/step - loss: 0.0944 - accuracy: 0.9655 - val_loss: 0.1990 - val_accuracy: 0.9494
# Epoch 181/200
# 6/6 [==============================] - 1s 186ms/step - loss: 0.0841 - accuracy: 0.9726 - val_loss: 0.2023 - val_accuracy: 0.9381
# Epoch 182/200
# 6/6 [==============================] - 1s 177ms/step - loss: 0.0859 - accuracy: 0.9715 - val_loss: 0.1946 - val_accuracy: 0.9423
# Epoch 183/200
# 6/6 [==============================] - 1s 149ms/step - loss: 0.0991 - accuracy: 0.9641 - val_loss: 0.2399 - val_accuracy: 0.9297
# Epoch 184/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.1001 - accuracy: 0.9687 - val_loss: 0.2169 - val_accuracy: 0.9381
# Epoch 185/200
# 6/6 [==============================] - 1s 179ms/step - loss: 0.0848 - accuracy: 0.9705 - val_loss: 0.2220 - val_accuracy: 0.9381
# Epoch 186/200
# 6/6 [==============================] - 1s 173ms/step - loss: 0.0869 - accuracy: 0.9691 - val_loss: 0.1911 - val_accuracy: 0.9437
# Epoch 187/200
# 6/6 [==============================] - 1s 156ms/step - loss: 0.0739 - accuracy: 0.9778 - val_loss: 0.1942 - val_accuracy: 0.9451
# Epoch 188/200
# 6/6 [==============================] - 1s 157ms/step - loss: 0.0783 - accuracy: 0.9750 - val_loss: 0.1987 - val_accuracy: 0.9423
# Epoch 189/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.0612 - accuracy: 0.9793 - val_loss: 0.2004 - val_accuracy: 0.9451
# Epoch 190/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0734 - accuracy: 0.9691 - val_loss: 0.1883 - val_accuracy: 0.9508
# Epoch 191/200
# 6/6 [==============================] - 1s 157ms/step - loss: 0.0872 - accuracy: 0.9726 - val_loss: 0.2027 - val_accuracy: 0.9423
# Epoch 192/200
# 6/6 [==============================] - 1s 161ms/step - loss: 0.0848 - accuracy: 0.9684 - val_loss: 0.2433 - val_accuracy: 0.9283
# Epoch 193/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0974 - accuracy: 0.9655 - val_loss: 0.2389 - val_accuracy: 0.9283
# Epoch 194/200
# 6/6 [==============================] - 1s 168ms/step - loss: 0.1009 - accuracy: 0.9624 - val_loss: 0.2399 - val_accuracy: 0.9297
# Epoch 195/200
# 6/6 [==============================] - 1s 176ms/step - loss: 0.0976 - accuracy: 0.9645 - val_loss: 0.2060 - val_accuracy: 0.9367
# Epoch 196/200
# 6/6 [==============================] - 1s 159ms/step - loss: 0.0873 - accuracy: 0.9662 - val_loss: 0.2079 - val_accuracy: 0.9423
# Epoch 197/200
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1154 - accuracy: 0.9582 - val_loss: 0.2222 - val_accuracy: 0.9311
# Epoch 198/200
# 6/6 [==============================] - 1s 171ms/step - loss: 0.0920 - accuracy: 0.9645 - val_loss: 0.2075 - val_accuracy: 0.9381
# Epoch 199/200
# 6/6 [==============================] - 1s 174ms/step - loss: 0.0951 - accuracy: 0.9634 - val_loss: 0.1986 - val_accuracy: 0.9395
# Epoch 200/200
# 6/6 [==============================] - 1s 149ms/step - loss: 0.0734 - accuracy: 0.9757 - val_loss: 0.1976 - val_accuracy: 0.9508

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodel0)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnn0 = CNN_Model(cube_std0_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                         validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                         epochs=100, batch_size=512)
else:
    CNNmodel0 = cnn0.fit({"spectra":cube_train02}, cube_train_labels0, 
                         validation_data=({"spectra":cube_test02}, cube_test_labels0),
                         epochs=100, batch_size=512)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 207ms/step - loss: 1.8913 - accuracy: 0.3316 - val_loss: 1.4265 - val_accuracy: 0.4627
# Epoch 2/100
# 6/6 [==============================] - 1s 153ms/step - loss: 1.1569 - accuracy: 0.6157 - val_loss: 0.9342 - val_accuracy: 0.7004
# Epoch 3/100
# 6/6 [==============================] - 1s 161ms/step - loss: 0.8391 - accuracy: 0.6930 - val_loss: 0.7931 - val_accuracy: 0.6920
# Epoch 4/100
# 6/6 [==============================] - 1s 174ms/step - loss: 0.7060 - accuracy: 0.7124 - val_loss: 0.6905 - val_accuracy: 0.6737
# Epoch 5/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.6228 - accuracy: 0.7366 - val_loss: 0.6266 - val_accuracy: 0.7834
# Epoch 6/100
# 6/6 [==============================] - 1s 178ms/step - loss: 0.5609 - accuracy: 0.7700 - val_loss: 0.5596 - val_accuracy: 0.7722
# Epoch 7/100
# 6/6 [==============================] - 1s 159ms/step - loss: 0.5108 - accuracy: 0.7968 - val_loss: 0.5542 - val_accuracy: 0.7623
# Epoch 8/100
# 6/6 [==============================] - 1s 179ms/step - loss: 0.4794 - accuracy: 0.8136 - val_loss: 0.5398 - val_accuracy: 0.7707
# Epoch 9/100
# 6/6 [==============================] - 1s 174ms/step - loss: 0.4676 - accuracy: 0.8172 - val_loss: 0.5302 - val_accuracy: 0.8003
# Epoch 10/100
# 6/6 [==============================] - 1s 172ms/step - loss: 0.4715 - accuracy: 0.8133 - val_loss: 0.4816 - val_accuracy: 0.7989
# Epoch 11/100
# 6/6 [==============================] - 1s 152ms/step - loss: 0.4412 - accuracy: 0.8274 - val_loss: 0.4798 - val_accuracy: 0.8312
# Epoch 12/100
# 6/6 [==============================] - 1s 161ms/step - loss: 0.4340 - accuracy: 0.8252 - val_loss: 0.4933 - val_accuracy: 0.7989
# Epoch 13/100
# 6/6 [==============================] - 1s 175ms/step - loss: 0.4092 - accuracy: 0.8407 - val_loss: 0.4391 - val_accuracy: 0.8340
# Epoch 14/100
# 6/6 [==============================] - 1s 185ms/step - loss: 0.4003 - accuracy: 0.8449 - val_loss: 0.4327 - val_accuracy: 0.8340
# Epoch 15/100
# 6/6 [==============================] - 1s 152ms/step - loss: 0.3753 - accuracy: 0.8615 - val_loss: 0.4127 - val_accuracy: 0.8481
# Epoch 16/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.3635 - accuracy: 0.8611 - val_loss: 0.4059 - val_accuracy: 0.8411
# Epoch 17/100
# 6/6 [==============================] - 1s 189ms/step - loss: 0.3624 - accuracy: 0.8618 - val_loss: 0.4021 - val_accuracy: 0.8481
# Epoch 18/100
# 6/6 [==============================] - 1s 185ms/step - loss: 0.3470 - accuracy: 0.8695 - val_loss: 0.3905 - val_accuracy: 0.8650
# Epoch 19/100
# 6/6 [==============================] - 1s 153ms/step - loss: 0.3430 - accuracy: 0.8671 - val_loss: 0.4300 - val_accuracy: 0.8383
# Epoch 20/100
# 6/6 [==============================] - 1s 160ms/step - loss: 0.3684 - accuracy: 0.8523 - val_loss: 0.4203 - val_accuracy: 0.8326
# Epoch 21/100
# 6/6 [==============================] - 1s 187ms/step - loss: 0.3506 - accuracy: 0.8710 - val_loss: 0.4421 - val_accuracy: 0.8383
# Epoch 22/100
# 6/6 [==============================] - 1s 177ms/step - loss: 0.3625 - accuracy: 0.8590 - val_loss: 0.3884 - val_accuracy: 0.8565
# Epoch 23/100
# 6/6 [==============================] - 1s 158ms/step - loss: 0.3268 - accuracy: 0.8812 - val_loss: 0.3689 - val_accuracy: 0.8748
# Epoch 24/100
# 6/6 [==============================] - 1s 168ms/step - loss: 0.3251 - accuracy: 0.8780 - val_loss: 0.3727 - val_accuracy: 0.8579
# Epoch 25/100
# 6/6 [==============================] - 1s 177ms/step - loss: 0.3039 - accuracy: 0.8847 - val_loss: 0.3772 - val_accuracy: 0.8594
# Epoch 26/100
# 6/6 [==============================] - 1s 179ms/step - loss: 0.3096 - accuracy: 0.8787 - val_loss: 0.3507 - val_accuracy: 0.8776
# Epoch 27/100
# 6/6 [==============================] - 1s 162ms/step - loss: 0.3207 - accuracy: 0.8745 - val_loss: 0.3511 - val_accuracy: 0.8776
# Epoch 28/100
# 6/6 [==============================] - 1s 153ms/step - loss: 0.2967 - accuracy: 0.8864 - val_loss: 0.3576 - val_accuracy: 0.8790
# Epoch 29/100
# 6/6 [==============================] - 1s 162ms/step - loss: 0.2886 - accuracy: 0.8949 - val_loss: 0.3379 - val_accuracy: 0.8762
# Epoch 30/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.2804 - accuracy: 0.8875 - val_loss: 0.3446 - val_accuracy: 0.8805
# Epoch 31/100
# 6/6 [==============================] - 1s 177ms/step - loss: 0.3037 - accuracy: 0.8805 - val_loss: 0.3630 - val_accuracy: 0.8720
# Epoch 32/100
# 6/6 [==============================] - 1s 153ms/step - loss: 0.3061 - accuracy: 0.8857 - val_loss: 0.3542 - val_accuracy: 0.8636
# Epoch 33/100
# 6/6 [==============================] - 1s 169ms/step - loss: 0.2883 - accuracy: 0.8921 - val_loss: 0.3411 - val_accuracy: 0.8861
# Epoch 34/100
# 6/6 [==============================] - 1s 172ms/step - loss: 0.2745 - accuracy: 0.8973 - val_loss: 0.3120 - val_accuracy: 0.8875
# Epoch 35/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2586 - accuracy: 0.9005 - val_loss: 0.3111 - val_accuracy: 0.8931
# Epoch 36/100
# 6/6 [==============================] - 1s 154ms/step - loss: 0.2633 - accuracy: 0.9026 - val_loss: 0.3235 - val_accuracy: 0.8833
# Epoch 37/100
# 6/6 [==============================] - 1s 158ms/step - loss: 0.2644 - accuracy: 0.9061 - val_loss: 0.3268 - val_accuracy: 0.8805
# Epoch 38/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.3076 - accuracy: 0.8745 - val_loss: 0.4751 - val_accuracy: 0.7890
# Epoch 39/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.3496 - accuracy: 0.8572 - val_loss: 0.4041 - val_accuracy: 0.8425
# Epoch 40/100
# 6/6 [==============================] - 1s 150ms/step - loss: 0.3095 - accuracy: 0.8850 - val_loss: 0.3495 - val_accuracy: 0.8748
# Epoch 41/100
# 6/6 [==============================] - 1s 151ms/step - loss: 0.2813 - accuracy: 0.8977 - val_loss: 0.3386 - val_accuracy: 0.8861
# Epoch 42/100
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2680 - accuracy: 0.9082 - val_loss: 0.3178 - val_accuracy: 0.8917
# Epoch 43/100
# 6/6 [==============================] - 1s 168ms/step - loss: 0.2611 - accuracy: 0.9015 - val_loss: 0.3198 - val_accuracy: 0.8833
# Epoch 44/100
# 6/6 [==============================] - 1s 156ms/step - loss: 0.2637 - accuracy: 0.8945 - val_loss: 0.3243 - val_accuracy: 0.8987
# Epoch 45/100
# 6/6 [==============================] - 1s 149ms/step - loss: 0.2570 - accuracy: 0.9079 - val_loss: 0.3298 - val_accuracy: 0.8762
# Epoch 46/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2470 - accuracy: 0.9093 - val_loss: 0.3139 - val_accuracy: 0.8805
# Epoch 47/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.2410 - accuracy: 0.9132 - val_loss: 0.3002 - val_accuracy: 0.8917
# Epoch 48/100
# 6/6 [==============================] - 1s 164ms/step - loss: 0.2360 - accuracy: 0.9100 - val_loss: 0.2801 - val_accuracy: 0.9100
# Epoch 49/100
# 6/6 [==============================] - 1s 155ms/step - loss: 0.2256 - accuracy: 0.9124 - val_loss: 0.2831 - val_accuracy: 0.9030
# Epoch 50/100
# 6/6 [==============================] - 1s 168ms/step - loss: 0.2221 - accuracy: 0.9184 - val_loss: 0.2823 - val_accuracy: 0.8987
# Epoch 51/100
# 6/6 [==============================] - 1s 190ms/step - loss: 0.2189 - accuracy: 0.9177 - val_loss: 0.3004 - val_accuracy: 0.8973
# Epoch 52/100
# 6/6 [==============================] - 1s 170ms/step - loss: 0.2235 - accuracy: 0.9167 - val_loss: 0.2825 - val_accuracy: 0.8987
# Epoch 53/100
# 6/6 [==============================] - 1s 154ms/step - loss: 0.2246 - accuracy: 0.9153 - val_loss: 0.2722 - val_accuracy: 0.9044
# Epoch 54/100
# 6/6 [==============================] - 1s 208ms/step - loss: 0.2420 - accuracy: 0.9121 - val_loss: 0.3025 - val_accuracy: 0.8875
# Epoch 55/100
# 6/6 [==============================] - 1s 182ms/step - loss: 0.2680 - accuracy: 0.8949 - val_loss: 0.3672 - val_accuracy: 0.8692
# Epoch 56/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2653 - accuracy: 0.8994 - val_loss: 0.3078 - val_accuracy: 0.8903
# Epoch 57/100
# 6/6 [==============================] - 1s 151ms/step - loss: 0.2848 - accuracy: 0.8892 - val_loss: 0.3047 - val_accuracy: 0.8861
# Epoch 58/100
# 6/6 [==============================] - 1s 162ms/step - loss: 0.2559 - accuracy: 0.9030 - val_loss: 0.3162 - val_accuracy: 0.8762
# Epoch 59/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2505 - accuracy: 0.9128 - val_loss: 0.2934 - val_accuracy: 0.8917
# Epoch 60/100
# 6/6 [==============================] - 1s 176ms/step - loss: 0.2247 - accuracy: 0.9272 - val_loss: 0.2923 - val_accuracy: 0.8973
# Epoch 61/100
# 6/6 [==============================] - 1s 149ms/step - loss: 0.2203 - accuracy: 0.9184 - val_loss: 0.2947 - val_accuracy: 0.9001
# Epoch 62/100
# 6/6 [==============================] - 1s 155ms/step - loss: 0.2159 - accuracy: 0.9146 - val_loss: 0.2861 - val_accuracy: 0.8959
# Epoch 63/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2133 - accuracy: 0.9219 - val_loss: 0.2848 - val_accuracy: 0.9015
# Epoch 64/100
# 6/6 [==============================] - 1s 175ms/step - loss: 0.2073 - accuracy: 0.9248 - val_loss: 0.2874 - val_accuracy: 0.8973
# Epoch 65/100
# 6/6 [==============================] - 1s 169ms/step - loss: 0.2123 - accuracy: 0.9230 - val_loss: 0.2729 - val_accuracy: 0.9086
# Epoch 66/100
# 6/6 [==============================] - 1s 158ms/step - loss: 0.2123 - accuracy: 0.9209 - val_loss: 0.2903 - val_accuracy: 0.9072
# Epoch 67/100
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2169 - accuracy: 0.9198 - val_loss: 0.2693 - val_accuracy: 0.9015
# Epoch 68/100
# 6/6 [==============================] - 1s 161ms/step - loss: 0.2035 - accuracy: 0.9244 - val_loss: 0.2539 - val_accuracy: 0.9156
# Epoch 69/100
# 6/6 [==============================] - 1s 167ms/step - loss: 0.2175 - accuracy: 0.9195 - val_loss: 0.2822 - val_accuracy: 0.9030
# Epoch 70/100
# 6/6 [==============================] - 1s 152ms/step - loss: 0.2108 - accuracy: 0.9191 - val_loss: 0.2681 - val_accuracy: 0.9170
# Epoch 71/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1983 - accuracy: 0.9233 - val_loss: 0.2570 - val_accuracy: 0.9128
# Epoch 72/100
# 6/6 [==============================] - 1s 167ms/step - loss: 0.2047 - accuracy: 0.9255 - val_loss: 0.3061 - val_accuracy: 0.8987
# Epoch 73/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.2187 - accuracy: 0.9114 - val_loss: 0.2879 - val_accuracy: 0.9001
# Epoch 74/100
# 6/6 [==============================] - 1s 149ms/step - loss: 0.2053 - accuracy: 0.9258 - val_loss: 0.2498 - val_accuracy: 0.9128
# Epoch 75/100
# 6/6 [==============================] - 1s 178ms/step - loss: 0.1975 - accuracy: 0.9286 - val_loss: 0.2884 - val_accuracy: 0.8987
# Epoch 76/100
# 6/6 [==============================] - 1s 174ms/step - loss: 0.1876 - accuracy: 0.9325 - val_loss: 0.2646 - val_accuracy: 0.9072
# Epoch 77/100
# 6/6 [==============================] - 1s 180ms/step - loss: 0.1851 - accuracy: 0.9385 - val_loss: 0.2476 - val_accuracy: 0.9184
# Epoch 78/100
# 6/6 [==============================] - 1s 154ms/step - loss: 0.1917 - accuracy: 0.9293 - val_loss: 0.2435 - val_accuracy: 0.9226
# Epoch 79/100
# 6/6 [==============================] - 1s 156ms/step - loss: 0.1856 - accuracy: 0.9314 - val_loss: 0.2644 - val_accuracy: 0.9044
# Epoch 80/100
# 6/6 [==============================] - 1s 177ms/step - loss: 0.1873 - accuracy: 0.9269 - val_loss: 0.2626 - val_accuracy: 0.9086
# Epoch 81/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1826 - accuracy: 0.9346 - val_loss: 0.2353 - val_accuracy: 0.9212
# Epoch 82/100
# 6/6 [==============================] - 1s 153ms/step - loss: 0.1736 - accuracy: 0.9374 - val_loss: 0.2464 - val_accuracy: 0.9184
# Epoch 83/100
# 6/6 [==============================] - 1s 152ms/step - loss: 0.1666 - accuracy: 0.9430 - val_loss: 0.2447 - val_accuracy: 0.9128
# Epoch 84/100
# 6/6 [==============================] - 1s 177ms/step - loss: 0.1673 - accuracy: 0.9441 - val_loss: 0.2559 - val_accuracy: 0.9142
# Epoch 85/100
# 6/6 [==============================] - 1s 163ms/step - loss: 0.1649 - accuracy: 0.9430 - val_loss: 0.2272 - val_accuracy: 0.9283
# Epoch 86/100
# 6/6 [==============================] - 1s 152ms/step - loss: 0.1699 - accuracy: 0.9423 - val_loss: 0.2338 - val_accuracy: 0.9198
# Epoch 87/100
# 6/6 [==============================] - 1s 158ms/step - loss: 0.1695 - accuracy: 0.9385 - val_loss: 0.2289 - val_accuracy: 0.9241
# Epoch 88/100
# 6/6 [==============================] - 1s 171ms/step - loss: 0.1652 - accuracy: 0.9451 - val_loss: 0.2535 - val_accuracy: 0.9044
# Epoch 89/100
# 6/6 [==============================] - 1s 164ms/step - loss: 0.1740 - accuracy: 0.9332 - val_loss: 0.2546 - val_accuracy: 0.9058
# Epoch 90/100
# 6/6 [==============================] - 1s 161ms/step - loss: 0.1659 - accuracy: 0.9342 - val_loss: 0.2190 - val_accuracy: 0.9269
# Epoch 91/100
# 6/6 [==============================] - 1s 160ms/step - loss: 0.1570 - accuracy: 0.9434 - val_loss: 0.2234 - val_accuracy: 0.9283
# Epoch 92/100
# 6/6 [==============================] - 1s 178ms/step - loss: 0.1474 - accuracy: 0.9473 - val_loss: 0.2484 - val_accuracy: 0.9086
# Epoch 93/100
# 6/6 [==============================] - 1s 176ms/step - loss: 0.1417 - accuracy: 0.9473 - val_loss: 0.2319 - val_accuracy: 0.9241
# Epoch 94/100
# 6/6 [==============================] - 1s 175ms/step - loss: 0.1498 - accuracy: 0.9420 - val_loss: 0.2296 - val_accuracy: 0.9241
# Epoch 95/100
# 6/6 [==============================] - 1s 155ms/step - loss: 0.1585 - accuracy: 0.9420 - val_loss: 0.2348 - val_accuracy: 0.9212
# Epoch 96/100
# 6/6 [==============================] - 1s 173ms/step - loss: 0.1552 - accuracy: 0.9441 - val_loss: 0.2741 - val_accuracy: 0.9128
# Epoch 97/100
# 6/6 [==============================] - 1s 168ms/step - loss: 0.2717 - accuracy: 0.9054 - val_loss: 0.2974 - val_accuracy: 0.8987
# Epoch 98/100
# 6/6 [==============================] - 1s 184ms/step - loss: 0.2304 - accuracy: 0.9177 - val_loss: 0.3103 - val_accuracy: 0.8917
# Epoch 99/100
# 6/6 [==============================] - 1s 160ms/step - loss: 0.2111 - accuracy: 0.9226 - val_loss: 0.2425 - val_accuracy: 0.9212
# Epoch 100/100
# 6/6 [==============================] - 1s 160ms/step - loss: 0.1671 - accuracy: 0.9423 - val_loss: 0.2319 - val_accuracy: 0.9184

# %%
# model accuracy on training and testing sets
if include_spatial:
    train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
    test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)
else:
    train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02}, cube_train_labels0)
    test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 1s 7ms/step - loss: 0.1277 - accuracy: 0.9641
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2319 - accuracy: 0.9184
# 0.9641350507736206 0.9184247255325317

# %% [markdown]
# ### Predict pixel classification on all of Scene 1-b

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])

start_time = time.time()
if include_spatial:
    probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})
else:
    probCube0 = cnn0.predict({"spectra":cube_standard0_1})

predictCube0 = probCube0.argmax(axis=-1)
elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:09:47

# %%
# -- Plot the prediction map of Scene 1-b

predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 1-b

# %%
# -- create the prediction arrays from the predictions of the testing set

labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg,
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# -- create the true arrays from the labeled testing set 

labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg,
                               labels0_true_blt, labels0_true_windows, labels0_true_rds, 
                               labels0_true_cars, labels0_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-b

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 226   6   0   0   8]
#  [  0   0   0  11  76   1   0  12]
#  [  0   0   0   0   0  12   0   0]
#  [  0   0   0   0   0   4   7   0]
#  [  0   0   0  12   0   1   0  33]]
#
# Accuracy Score
# 0.9184247538677919
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        80
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.90      0.94      0.92       240
#     windows       0.93      0.76      0.84       100
#       roads       0.67      1.00      0.80        12
#        cars       1.00      0.64      0.78        11
#       metal       0.62      0.72      0.67        46
#
# avg / total       0.92      0.92      0.92       711

# %% [markdown]
# ---
# # CNN trained on Scene 2

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
cube_sub_north = cube_north.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]),
                                                                cube_sub_north.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)

# -- extrapolate to fit same nwaves as 1-a
interp_hsi = interp1d(cube_north.waves, cube_standard_north, axis=1, fill_value="extrapolate")
cube_standard_north = interp_hsi(cube0.waves)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
# -- if reduced_resolution = True, the spectra are averaged into bins to simulate reduced resolution

if reduced_resolution:
    bin_ind = []

    for i in range(0, num_of_bins):
        low_ind = int(i*int(cube_sub0.shape[0]/num_of_bins))
        upp_ind = int(low_ind + int(cube_sub0.shape[0]/num_of_bins))
        bin_ind.append([low_ind, upp_ind])
    bin_ind[-1][-1] = cube_sub0.shape[0]

    cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))
    for i in range(num_of_bins):
        cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

    cube_standard_north = cube_binnedn
    
# -- reshape standardized cube to (row, col, wavelength)
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], cube_sub_north.shape[0])

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
# -- create position array from coordinates and normalize

xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
# -- get the coordinates of training and testing sets for each class
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 872) (60, 872)
# clouds  (160, 872) (40, 872)
# vegetation  (560, 872) (140, 872)
# water  (496, 872) (124, 872)
# built  (1280, 872) (320, 872)
# windows  (480, 872) (120, 872)
# roads  (200, 872) (50, 872)
# cars  (200, 872) (50, 872)
# metal  (148, 872) (37, 872)

# %%
# -- concatenate the training arrays into training data and labels

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
cube_train_labelsn = np.array(cube_train_labelsn)
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
cube_test_labelsn = np.array(cube_test_labelsn)
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnnn = CNN_Model(cube_stdn_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                         validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                         epochs=200, batch_size=512)
else:
    CNNmodeln = cnnn.fit({"spectra":cube_trainn2}, cube_train_labelsn, 
                         validation_data=({"spectra":cube_testn2}, cube_test_labelsn),
                         epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 235ms/step - loss: 2.0742 - accuracy: 0.3252 - val_loss: 1.5885 - val_accuracy: 0.3369
# Epoch 2/200
# 8/8 [==============================] - 2s 212ms/step - loss: 1.3847 - accuracy: 0.5165 - val_loss: 1.1577 - val_accuracy: 0.6196
# Epoch 3/200
# 8/8 [==============================] - 1s 187ms/step - loss: 1.1019 - accuracy: 0.6081 - val_loss: 1.0471 - val_accuracy: 0.6270
# Epoch 4/200
# 8/8 [==============================] - 2s 195ms/step - loss: 0.9751 - accuracy: 0.6528 - val_loss: 0.9891 - val_accuracy: 0.6217
# Epoch 5/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.8999 - accuracy: 0.7019 - val_loss: 0.8603 - val_accuracy: 0.7078
# Epoch 6/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.8084 - accuracy: 0.7287 - val_loss: 0.7517 - val_accuracy: 0.7673
# Epoch 7/200
# 8/8 [==============================] - 1s 185ms/step - loss: 0.7446 - accuracy: 0.7529 - val_loss: 0.7239 - val_accuracy: 0.7566
# Epoch 8/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.6929 - accuracy: 0.7614 - val_loss: 0.6699 - val_accuracy: 0.7800
# Epoch 9/200
# 8/8 [==============================] - 2s 205ms/step - loss: 0.6731 - accuracy: 0.7633 - val_loss: 0.6378 - val_accuracy: 0.7864
# Epoch 10/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.6429 - accuracy: 0.7779 - val_loss: 0.5776 - val_accuracy: 0.8247
# Epoch 11/200
# 8/8 [==============================] - 2s 200ms/step - loss: 0.6054 - accuracy: 0.7912 - val_loss: 0.6258 - val_accuracy: 0.7875
# Epoch 12/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.6059 - accuracy: 0.7885 - val_loss: 0.5654 - val_accuracy: 0.8236
# Epoch 13/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.5722 - accuracy: 0.7952 - val_loss: 0.6071 - val_accuracy: 0.7758
# Epoch 14/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.5538 - accuracy: 0.7997 - val_loss: 0.5583 - val_accuracy: 0.8353
# Epoch 15/200
# 8/8 [==============================] - 2s 188ms/step - loss: 0.5356 - accuracy: 0.8162 - val_loss: 0.5033 - val_accuracy: 0.8512
# Epoch 16/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.5176 - accuracy: 0.8162 - val_loss: 0.5097 - val_accuracy: 0.8300
# Epoch 17/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.5216 - accuracy: 0.8098 - val_loss: 0.5542 - val_accuracy: 0.8108
# Epoch 18/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.5184 - accuracy: 0.8196 - val_loss: 0.5373 - val_accuracy: 0.8236
# Epoch 19/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.5451 - accuracy: 0.8071 - val_loss: 0.5503 - val_accuracy: 0.7949
# Epoch 20/200
# 8/8 [==============================] - 1s 184ms/step - loss: 0.5219 - accuracy: 0.8114 - val_loss: 0.5262 - val_accuracy: 0.8257
# Epoch 21/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.4791 - accuracy: 0.8316 - val_loss: 0.4718 - val_accuracy: 0.8502
# Epoch 22/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.4451 - accuracy: 0.8565 - val_loss: 0.4568 - val_accuracy: 0.8523
# Epoch 23/200
# 8/8 [==============================] - 1s 174ms/step - loss: 0.4233 - accuracy: 0.8608 - val_loss: 0.4391 - val_accuracy: 0.8640
# Epoch 24/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.4268 - accuracy: 0.8603 - val_loss: 0.4527 - val_accuracy: 0.8470
# Epoch 25/200
# 8/8 [==============================] - 2s 200ms/step - loss: 0.4421 - accuracy: 0.8451 - val_loss: 0.4285 - val_accuracy: 0.8714
# Epoch 26/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.4163 - accuracy: 0.8595 - val_loss: 0.4412 - val_accuracy: 0.8682
# Epoch 27/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.4312 - accuracy: 0.8491 - val_loss: 0.4326 - val_accuracy: 0.8597
# Epoch 28/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.4376 - accuracy: 0.8435 - val_loss: 0.4219 - val_accuracy: 0.8629
# Epoch 29/200
# 8/8 [==============================] - 1s 184ms/step - loss: 0.3999 - accuracy: 0.8640 - val_loss: 0.4280 - val_accuracy: 0.8778
# Epoch 30/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.3878 - accuracy: 0.8666 - val_loss: 0.4051 - val_accuracy: 0.8714
# Epoch 31/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.3859 - accuracy: 0.8658 - val_loss: 0.3819 - val_accuracy: 0.8884
# Epoch 32/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.3719 - accuracy: 0.8711 - val_loss: 0.3966 - val_accuracy: 0.8725
# Epoch 33/200
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3645 - accuracy: 0.8751 - val_loss: 0.3701 - val_accuracy: 0.8916
# Epoch 34/200
# 8/8 [==============================] - 2s 203ms/step - loss: 0.3581 - accuracy: 0.8757 - val_loss: 0.3793 - val_accuracy: 0.8895
# Epoch 35/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.3634 - accuracy: 0.8725 - val_loss: 0.4431 - val_accuracy: 0.8565
# Epoch 36/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.3909 - accuracy: 0.8589 - val_loss: 0.5532 - val_accuracy: 0.8183
# Epoch 37/200
# 8/8 [==============================] - 1s 184ms/step - loss: 0.6176 - accuracy: 0.7726 - val_loss: 0.4796 - val_accuracy: 0.8268
# Epoch 38/200
# 8/8 [==============================] - 2s 195ms/step - loss: 0.4487 - accuracy: 0.8355 - val_loss: 0.5143 - val_accuracy: 0.8119
# Epoch 39/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.4241 - accuracy: 0.8462 - val_loss: 0.4545 - val_accuracy: 0.8565
# Epoch 40/200
# 8/8 [==============================] - 2s 193ms/step - loss: 0.3981 - accuracy: 0.8581 - val_loss: 0.4111 - val_accuracy: 0.8714
# Epoch 41/200
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3460 - accuracy: 0.8789 - val_loss: 0.3843 - val_accuracy: 0.8863
# Epoch 42/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3501 - accuracy: 0.8789 - val_loss: 0.3783 - val_accuracy: 0.8778
# Epoch 43/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.3390 - accuracy: 0.8844 - val_loss: 0.3820 - val_accuracy: 0.8799
# Epoch 44/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.3217 - accuracy: 0.8940 - val_loss: 0.3611 - val_accuracy: 0.8916
# Epoch 45/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.3149 - accuracy: 0.8943 - val_loss: 0.3899 - val_accuracy: 0.8884
# Epoch 46/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.3203 - accuracy: 0.8905 - val_loss: 0.3549 - val_accuracy: 0.8789
# Epoch 47/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.3050 - accuracy: 0.8982 - val_loss: 0.3654 - val_accuracy: 0.8757
# Epoch 48/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.3153 - accuracy: 0.8903 - val_loss: 0.3755 - val_accuracy: 0.8990
# Epoch 49/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.3037 - accuracy: 0.8969 - val_loss: 0.3591 - val_accuracy: 0.9022
# Epoch 50/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.2915 - accuracy: 0.8998 - val_loss: 0.3752 - val_accuracy: 0.8937
# Epoch 51/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.2937 - accuracy: 0.8998 - val_loss: 0.3391 - val_accuracy: 0.8969
# Epoch 52/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.2911 - accuracy: 0.9014 - val_loss: 0.3870 - val_accuracy: 0.8735
# Epoch 53/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.2969 - accuracy: 0.8961 - val_loss: 0.3592 - val_accuracy: 0.8948
# Epoch 54/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.2871 - accuracy: 0.9036 - val_loss: 0.3463 - val_accuracy: 0.8980
# Epoch 55/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.2763 - accuracy: 0.9094 - val_loss: 0.3396 - val_accuracy: 0.8980
# Epoch 56/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.2636 - accuracy: 0.9126 - val_loss: 0.3438 - val_accuracy: 0.8820
# Epoch 57/200
# 8/8 [==============================] - 2s 193ms/step - loss: 0.2653 - accuracy: 0.9110 - val_loss: 0.3336 - val_accuracy: 0.9022
# Epoch 58/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.2795 - accuracy: 0.9052 - val_loss: 0.3901 - val_accuracy: 0.8852
# Epoch 59/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.2711 - accuracy: 0.9073 - val_loss: 0.3353 - val_accuracy: 0.8969
# Epoch 60/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.2670 - accuracy: 0.9089 - val_loss: 0.3573 - val_accuracy: 0.8959
# Epoch 61/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.2696 - accuracy: 0.9097 - val_loss: 0.3343 - val_accuracy: 0.8980
# Epoch 62/200
# 8/8 [==============================] - 1s 170ms/step - loss: 0.2527 - accuracy: 0.9134 - val_loss: 0.3465 - val_accuracy: 0.8969
# Epoch 63/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.2467 - accuracy: 0.9198 - val_loss: 0.3349 - val_accuracy: 0.8916
# Epoch 64/200
# 8/8 [==============================] - 1s 187ms/step - loss: 0.2536 - accuracy: 0.9168 - val_loss: 0.3736 - val_accuracy: 0.8852
# Epoch 65/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.2470 - accuracy: 0.9155 - val_loss: 0.3438 - val_accuracy: 0.8927
# Epoch 66/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.2496 - accuracy: 0.9184 - val_loss: 0.3351 - val_accuracy: 0.9044
# Epoch 67/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.2292 - accuracy: 0.9238 - val_loss: 0.3335 - val_accuracy: 0.8990
# Epoch 68/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.2349 - accuracy: 0.9219 - val_loss: 0.3120 - val_accuracy: 0.9086
# Epoch 69/200
# 8/8 [==============================] - 2s 204ms/step - loss: 0.2378 - accuracy: 0.9152 - val_loss: 0.3171 - val_accuracy: 0.9065
# Epoch 70/200
# 8/8 [==============================] - 1s 185ms/step - loss: 0.2251 - accuracy: 0.9253 - val_loss: 0.3269 - val_accuracy: 0.8948
# Epoch 71/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.2227 - accuracy: 0.9240 - val_loss: 0.3398 - val_accuracy: 0.9075
# Epoch 72/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.2153 - accuracy: 0.9275 - val_loss: 0.3234 - val_accuracy: 0.9044
# Epoch 73/200
# 8/8 [==============================] - 2s 202ms/step - loss: 0.2075 - accuracy: 0.9280 - val_loss: 0.3263 - val_accuracy: 0.9033
# Epoch 74/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.2189 - accuracy: 0.9238 - val_loss: 0.3132 - val_accuracy: 0.9107
# Epoch 75/200
# 8/8 [==============================] - 2s 189ms/step - loss: 0.2193 - accuracy: 0.9224 - val_loss: 0.3231 - val_accuracy: 0.8990
# Epoch 76/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.2057 - accuracy: 0.9323 - val_loss: 0.3102 - val_accuracy: 0.9150
# Epoch 77/200
# 8/8 [==============================] - 2s 193ms/step - loss: 0.2038 - accuracy: 0.9341 - val_loss: 0.3391 - val_accuracy: 0.9054
# Epoch 78/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1979 - accuracy: 0.9389 - val_loss: 0.3254 - val_accuracy: 0.9054
# Epoch 79/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.2080 - accuracy: 0.9296 - val_loss: 0.3064 - val_accuracy: 0.9139
# Epoch 80/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1990 - accuracy: 0.9320 - val_loss: 0.3494 - val_accuracy: 0.9001
# Epoch 81/200
# 8/8 [==============================] - 1s 182ms/step - loss: 0.2055 - accuracy: 0.9256 - val_loss: 0.2944 - val_accuracy: 0.9107
# Epoch 82/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.2050 - accuracy: 0.9368 - val_loss: 0.3320 - val_accuracy: 0.9001
# Epoch 83/200
# 8/8 [==============================] - 2s 207ms/step - loss: 0.2009 - accuracy: 0.9346 - val_loss: 0.3155 - val_accuracy: 0.9033
# Epoch 84/200
# 8/8 [==============================] - 2s 188ms/step - loss: 0.1997 - accuracy: 0.9315 - val_loss: 0.3409 - val_accuracy: 0.9097
# Epoch 85/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1909 - accuracy: 0.9346 - val_loss: 0.3167 - val_accuracy: 0.9065
# Epoch 86/200
# 8/8 [==============================] - 2s 192ms/step - loss: 0.1873 - accuracy: 0.9410 - val_loss: 0.2977 - val_accuracy: 0.9097
# Epoch 87/200
# 8/8 [==============================] - 2s 210ms/step - loss: 0.1888 - accuracy: 0.9346 - val_loss: 0.3576 - val_accuracy: 0.9107
# Epoch 88/200
# 8/8 [==============================] - 2s 190ms/step - loss: 0.2009 - accuracy: 0.9349 - val_loss: 0.3295 - val_accuracy: 0.9044
# Epoch 89/200
# 8/8 [==============================] - 1s 175ms/step - loss: 0.1801 - accuracy: 0.9413 - val_loss: 0.2906 - val_accuracy: 0.9160
# Epoch 90/200
# 8/8 [==============================] - 1s 184ms/step - loss: 0.1890 - accuracy: 0.9373 - val_loss: 0.3385 - val_accuracy: 0.9001
# Epoch 91/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1893 - accuracy: 0.9354 - val_loss: 0.3212 - val_accuracy: 0.9086
# Epoch 92/200
# 8/8 [==============================] - 2s 203ms/step - loss: 0.1986 - accuracy: 0.9309 - val_loss: 0.3704 - val_accuracy: 0.8799
# Epoch 93/200
# 8/8 [==============================] - 2s 188ms/step - loss: 0.2272 - accuracy: 0.9267 - val_loss: 0.3541 - val_accuracy: 0.8937
# Epoch 94/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1934 - accuracy: 0.9362 - val_loss: 0.3012 - val_accuracy: 0.9139
# Epoch 95/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1740 - accuracy: 0.9394 - val_loss: 0.3064 - val_accuracy: 0.9097
# Epoch 96/200
# 8/8 [==============================] - 2s 206ms/step - loss: 0.1691 - accuracy: 0.9431 - val_loss: 0.3028 - val_accuracy: 0.9150
# Epoch 97/200
# 8/8 [==============================] - 2s 193ms/step - loss: 0.1828 - accuracy: 0.9400 - val_loss: 0.3070 - val_accuracy: 0.9107
# Epoch 98/200
# 8/8 [==============================] - 1s 175ms/step - loss: 0.1840 - accuracy: 0.9376 - val_loss: 0.3372 - val_accuracy: 0.9129
# Epoch 99/200
# 8/8 [==============================] - 2s 189ms/step - loss: 0.1800 - accuracy: 0.9394 - val_loss: 0.3485 - val_accuracy: 0.8948
# Epoch 100/200
# 8/8 [==============================] - 1s 185ms/step - loss: 0.1809 - accuracy: 0.9370 - val_loss: 0.2992 - val_accuracy: 0.9139
# Epoch 101/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1691 - accuracy: 0.9410 - val_loss: 0.2930 - val_accuracy: 0.9192
# Epoch 102/200
# 8/8 [==============================] - 2s 198ms/step - loss: 0.1677 - accuracy: 0.9469 - val_loss: 0.2846 - val_accuracy: 0.9171
# Epoch 103/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1568 - accuracy: 0.9455 - val_loss: 0.2920 - val_accuracy: 0.9171
# Epoch 104/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1488 - accuracy: 0.9538 - val_loss: 0.2996 - val_accuracy: 0.9139
# Epoch 105/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.1439 - accuracy: 0.9519 - val_loss: 0.3264 - val_accuracy: 0.9054
# Epoch 106/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1552 - accuracy: 0.9461 - val_loss: 0.3001 - val_accuracy: 0.9139
# Epoch 107/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1533 - accuracy: 0.9485 - val_loss: 0.2916 - val_accuracy: 0.9065
# Epoch 108/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1681 - accuracy: 0.9408 - val_loss: 0.3334 - val_accuracy: 0.9182
# Epoch 109/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.1654 - accuracy: 0.9421 - val_loss: 0.2968 - val_accuracy: 0.9171
# Epoch 110/200
# 8/8 [==============================] - 2s 201ms/step - loss: 0.1445 - accuracy: 0.9514 - val_loss: 0.2847 - val_accuracy: 0.9203
# Epoch 111/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1395 - accuracy: 0.9501 - val_loss: 0.3480 - val_accuracy: 0.8937
# Epoch 112/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.1594 - accuracy: 0.9466 - val_loss: 0.3579 - val_accuracy: 0.9171
# Epoch 113/200
# 8/8 [==============================] - 2s 209ms/step - loss: 0.1701 - accuracy: 0.9429 - val_loss: 0.3622 - val_accuracy: 0.9107
# Epoch 114/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.1480 - accuracy: 0.9477 - val_loss: 0.2964 - val_accuracy: 0.9171
# Epoch 115/200
# 8/8 [==============================] - 2s 189ms/step - loss: 0.1453 - accuracy: 0.9538 - val_loss: 0.3151 - val_accuracy: 0.9214
# Epoch 116/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1403 - accuracy: 0.9532 - val_loss: 0.3018 - val_accuracy: 0.9150
# Epoch 117/200
# 8/8 [==============================] - 2s 188ms/step - loss: 0.1357 - accuracy: 0.9551 - val_loss: 0.2955 - val_accuracy: 0.9160
# Epoch 118/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1340 - accuracy: 0.9572 - val_loss: 0.3269 - val_accuracy: 0.9150
# Epoch 119/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.1348 - accuracy: 0.9551 - val_loss: 0.3180 - val_accuracy: 0.9192
# Epoch 120/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1350 - accuracy: 0.9522 - val_loss: 0.2980 - val_accuracy: 0.9224
# Epoch 121/200
# 8/8 [==============================] - 2s 194ms/step - loss: 0.1329 - accuracy: 0.9543 - val_loss: 0.3455 - val_accuracy: 0.9171
# Epoch 122/200
# 8/8 [==============================] - 3s 321ms/step - loss: 0.1467 - accuracy: 0.9479 - val_loss: 0.3069 - val_accuracy: 0.9171
# Epoch 123/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1475 - accuracy: 0.9514 - val_loss: 0.3208 - val_accuracy: 0.9139
# Epoch 124/200
# 8/8 [==============================] - 1s 169ms/step - loss: 0.1352 - accuracy: 0.9548 - val_loss: 0.3115 - val_accuracy: 0.9139
# Epoch 125/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1279 - accuracy: 0.9570 - val_loss: 0.2985 - val_accuracy: 0.9192
# Epoch 126/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1244 - accuracy: 0.9567 - val_loss: 0.2974 - val_accuracy: 0.9171
# Epoch 127/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.1268 - accuracy: 0.9572 - val_loss: 0.3033 - val_accuracy: 0.9182
# Epoch 128/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1293 - accuracy: 0.9564 - val_loss: 0.3197 - val_accuracy: 0.9182
# Epoch 129/200
# 8/8 [==============================] - 1s 167ms/step - loss: 0.1252 - accuracy: 0.9604 - val_loss: 0.3465 - val_accuracy: 0.9086
# Epoch 130/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.1224 - accuracy: 0.9551 - val_loss: 0.2802 - val_accuracy: 0.9267
# Epoch 131/200
# 8/8 [==============================] - 2s 196ms/step - loss: 0.1162 - accuracy: 0.9620 - val_loss: 0.3212 - val_accuracy: 0.9171
# Epoch 132/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.1237 - accuracy: 0.9588 - val_loss: 0.3331 - val_accuracy: 0.9150
# Epoch 133/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1217 - accuracy: 0.9625 - val_loss: 0.3146 - val_accuracy: 0.9224
# Epoch 134/200
# 8/8 [==============================] - 1s 178ms/step - loss: 0.1188 - accuracy: 0.9633 - val_loss: 0.3395 - val_accuracy: 0.9245
# Epoch 135/200
# 8/8 [==============================] - 1s 184ms/step - loss: 0.1445 - accuracy: 0.9522 - val_loss: 0.3251 - val_accuracy: 0.9129
# Epoch 136/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1287 - accuracy: 0.9562 - val_loss: 0.3145 - val_accuracy: 0.9171
# Epoch 137/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1196 - accuracy: 0.9586 - val_loss: 0.3010 - val_accuracy: 0.9171
# Epoch 138/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1110 - accuracy: 0.9612 - val_loss: 0.3124 - val_accuracy: 0.9203
# Epoch 139/200
# 8/8 [==============================] - 1s 175ms/step - loss: 0.1066 - accuracy: 0.9644 - val_loss: 0.3319 - val_accuracy: 0.9182
# Epoch 140/200
# 8/8 [==============================] - 2s 199ms/step - loss: 0.1047 - accuracy: 0.9652 - val_loss: 0.3139 - val_accuracy: 0.9160
# Epoch 141/200
# 8/8 [==============================] - 2s 189ms/step - loss: 0.1224 - accuracy: 0.9604 - val_loss: 0.3181 - val_accuracy: 0.9129
# Epoch 142/200
# 8/8 [==============================] - 1s 159ms/step - loss: 0.1253 - accuracy: 0.9564 - val_loss: 0.2939 - val_accuracy: 0.9171
# Epoch 143/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1167 - accuracy: 0.9596 - val_loss: 0.3340 - val_accuracy: 0.9129
# Epoch 144/200
# 8/8 [==============================] - 1s 172ms/step - loss: 0.1209 - accuracy: 0.9567 - val_loss: 0.3165 - val_accuracy: 0.9182
# Epoch 145/200
# 8/8 [==============================] - 1s 185ms/step - loss: 0.1098 - accuracy: 0.9641 - val_loss: 0.3152 - val_accuracy: 0.9224
# Epoch 146/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1113 - accuracy: 0.9647 - val_loss: 0.3448 - val_accuracy: 0.9235
# Epoch 147/200
# 8/8 [==============================] - 1s 163ms/step - loss: 0.1040 - accuracy: 0.9660 - val_loss: 0.3199 - val_accuracy: 0.9171
# Epoch 148/200
# 8/8 [==============================] - 1s 169ms/step - loss: 0.1029 - accuracy: 0.9649 - val_loss: 0.3193 - val_accuracy: 0.9214
# Epoch 149/200
# 8/8 [==============================] - 1s 181ms/step - loss: 0.1114 - accuracy: 0.9644 - val_loss: 0.3386 - val_accuracy: 0.9160
# Epoch 150/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1206 - accuracy: 0.9548 - val_loss: 0.2914 - val_accuracy: 0.9150
# Epoch 151/200
# 8/8 [==============================] - 1s 166ms/step - loss: 0.1216 - accuracy: 0.9567 - val_loss: 0.3977 - val_accuracy: 0.8980
# Epoch 152/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1439 - accuracy: 0.9501 - val_loss: 0.2802 - val_accuracy: 0.9299
# Epoch 153/200
# 8/8 [==============================] - 1s 178ms/step - loss: 0.1258 - accuracy: 0.9530 - val_loss: 0.3909 - val_accuracy: 0.9022
# Epoch 154/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.1347 - accuracy: 0.9511 - val_loss: 0.3253 - val_accuracy: 0.9139
# Epoch 155/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.1112 - accuracy: 0.9652 - val_loss: 0.3579 - val_accuracy: 0.9139
# Epoch 156/200
# 8/8 [==============================] - 1s 163ms/step - loss: 0.1118 - accuracy: 0.9623 - val_loss: 0.4265 - val_accuracy: 0.9044
# Epoch 157/200
# 8/8 [==============================] - 1s 174ms/step - loss: 0.1322 - accuracy: 0.9562 - val_loss: 0.3219 - val_accuracy: 0.9192
# Epoch 158/200
# 8/8 [==============================] - 1s 175ms/step - loss: 0.1112 - accuracy: 0.9615 - val_loss: 0.3652 - val_accuracy: 0.9160
# Epoch 159/200
# 8/8 [==============================] - 1s 186ms/step - loss: 0.1096 - accuracy: 0.9636 - val_loss: 0.3351 - val_accuracy: 0.9203
# Epoch 160/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.1059 - accuracy: 0.9644 - val_loss: 0.3121 - val_accuracy: 0.9214
# Epoch 161/200
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0946 - accuracy: 0.9697 - val_loss: 0.3528 - val_accuracy: 0.9160
# Epoch 162/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1009 - accuracy: 0.9641 - val_loss: 0.3743 - val_accuracy: 0.9097
# Epoch 163/200
# 8/8 [==============================] - 1s 180ms/step - loss: 0.1466 - accuracy: 0.9522 - val_loss: 0.3488 - val_accuracy: 0.9160
# Epoch 164/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1316 - accuracy: 0.9524 - val_loss: 0.3521 - val_accuracy: 0.9118
# Epoch 165/200
# 8/8 [==============================] - 1s 162ms/step - loss: 0.1198 - accuracy: 0.9578 - val_loss: 0.3854 - val_accuracy: 0.9107
# Epoch 166/200
# 8/8 [==============================] - 1s 166ms/step - loss: 0.1058 - accuracy: 0.9655 - val_loss: 0.3108 - val_accuracy: 0.9182
# Epoch 167/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1054 - accuracy: 0.9671 - val_loss: 0.3461 - val_accuracy: 0.9267
# Epoch 168/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0908 - accuracy: 0.9684 - val_loss: 0.3635 - val_accuracy: 0.9182
# Epoch 169/200
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0889 - accuracy: 0.9700 - val_loss: 0.3182 - val_accuracy: 0.9150
# Epoch 170/200
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0863 - accuracy: 0.9721 - val_loss: 0.3558 - val_accuracy: 0.9150
# Epoch 171/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0890 - accuracy: 0.9742 - val_loss: 0.3270 - val_accuracy: 0.9203
# Epoch 172/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.0881 - accuracy: 0.9713 - val_loss: 0.3800 - val_accuracy: 0.9150
# Epoch 173/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0996 - accuracy: 0.9647 - val_loss: 0.3280 - val_accuracy: 0.9203
# Epoch 174/200
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0826 - accuracy: 0.9758 - val_loss: 0.3349 - val_accuracy: 0.9182
# Epoch 175/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.0809 - accuracy: 0.9718 - val_loss: 0.3382 - val_accuracy: 0.9245
# Epoch 176/200
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0844 - accuracy: 0.9716 - val_loss: 0.3386 - val_accuracy: 0.9224
# Epoch 177/200
# 8/8 [==============================] - 2s 195ms/step - loss: 0.0853 - accuracy: 0.9687 - val_loss: 0.3593 - val_accuracy: 0.9224
# Epoch 178/200
# 8/8 [==============================] - 1s 174ms/step - loss: 0.0825 - accuracy: 0.9726 - val_loss: 0.3476 - val_accuracy: 0.9214
# Epoch 179/200
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0813 - accuracy: 0.9742 - val_loss: 0.3333 - val_accuracy: 0.9139
# Epoch 180/200
# 8/8 [==============================] - 1s 180ms/step - loss: 0.0788 - accuracy: 0.9742 - val_loss: 0.3272 - val_accuracy: 0.9256
# Epoch 181/200
# 8/8 [==============================] - 1s 179ms/step - loss: 0.0830 - accuracy: 0.9716 - val_loss: 0.3270 - val_accuracy: 0.9235
# Epoch 182/200
# 8/8 [==============================] - 2s 191ms/step - loss: 0.0774 - accuracy: 0.9777 - val_loss: 0.4159 - val_accuracy: 0.9150
# Epoch 183/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0827 - accuracy: 0.9750 - val_loss: 0.3613 - val_accuracy: 0.9277
# Epoch 184/200
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0756 - accuracy: 0.9764 - val_loss: 0.3403 - val_accuracy: 0.9214
# Epoch 185/200
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0749 - accuracy: 0.9766 - val_loss: 0.3870 - val_accuracy: 0.9203
# Epoch 186/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0767 - accuracy: 0.9748 - val_loss: 0.3649 - val_accuracy: 0.9118
# Epoch 187/200
# 8/8 [==============================] - 1s 170ms/step - loss: 0.0742 - accuracy: 0.9748 - val_loss: 0.3267 - val_accuracy: 0.9203
# Epoch 188/200
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0745 - accuracy: 0.9756 - val_loss: 0.3743 - val_accuracy: 0.9245
# Epoch 189/200
# 8/8 [==============================] - 1s 162ms/step - loss: 0.0726 - accuracy: 0.9774 - val_loss: 0.4013 - val_accuracy: 0.9192
# Epoch 190/200
# 8/8 [==============================] - 1s 170ms/step - loss: 0.0702 - accuracy: 0.9766 - val_loss: 0.3474 - val_accuracy: 0.9235
# Epoch 191/200
# 8/8 [==============================] - 2s 197ms/step - loss: 0.0769 - accuracy: 0.9748 - val_loss: 0.3422 - val_accuracy: 0.9277
# Epoch 192/200
# 8/8 [==============================] - 1s 177ms/step - loss: 0.0778 - accuracy: 0.9761 - val_loss: 0.3681 - val_accuracy: 0.9129
# Epoch 193/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0782 - accuracy: 0.9713 - val_loss: 0.3636 - val_accuracy: 0.9256
# Epoch 194/200
# 8/8 [==============================] - 1s 178ms/step - loss: 0.0821 - accuracy: 0.9705 - val_loss: 0.4660 - val_accuracy: 0.9044
# Epoch 195/200
# 8/8 [==============================] - 1s 185ms/step - loss: 0.0855 - accuracy: 0.9697 - val_loss: 0.3801 - val_accuracy: 0.9139
# Epoch 196/200
# 8/8 [==============================] - 1s 187ms/step - loss: 0.0777 - accuracy: 0.9772 - val_loss: 0.4215 - val_accuracy: 0.9118
# Epoch 197/200
# 8/8 [==============================] - 1s 163ms/step - loss: 0.0772 - accuracy: 0.9732 - val_loss: 0.4231 - val_accuracy: 0.9160
# Epoch 198/200
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0763 - accuracy: 0.9753 - val_loss: 0.3864 - val_accuracy: 0.9171
# Epoch 199/200
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0744 - accuracy: 0.9766 - val_loss: 0.3967 - val_accuracy: 0.9192
# Epoch 200/200
# 8/8 [==============================] - 1s 183ms/step - loss: 0.0666 - accuracy: 0.9772 - val_loss: 0.3614 - val_accuracy: 0.9235

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodeln)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnnn = CNN_Model(cube_stdn_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                         validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                         epochs=70, batch_size=512)
else:
    CNNmodeln = cnnn.fit({"spectra":cube_trainn2}, cube_train_labelsn, 
                         validation_data=({"spectra":cube_testn2}, cube_test_labelsn),
                         epochs=70, batch_size=512)
# Out:
# Epoch 1/70
# 8/8 [==============================] - 2s 198ms/step - loss: 2.0799 - accuracy: 0.3090 - val_loss: 1.7297 - val_accuracy: 0.3464
# Epoch 2/70
# 8/8 [==============================] - 1s 175ms/step - loss: 1.4841 - accuracy: 0.4676 - val_loss: 1.2654 - val_accuracy: 0.5909
# Epoch 3/70
# 8/8 [==============================] - 1s 170ms/step - loss: 1.1612 - accuracy: 0.6055 - val_loss: 1.1385 - val_accuracy: 0.5409
# Epoch 4/70
# 8/8 [==============================] - 1s 171ms/step - loss: 1.0250 - accuracy: 0.6209 - val_loss: 0.9158 - val_accuracy: 0.7078
# Epoch 5/70
# 8/8 [==============================] - 1s 174ms/step - loss: 0.8849 - accuracy: 0.6945 - val_loss: 0.8455 - val_accuracy: 0.7237
# Epoch 6/70
# 8/8 [==============================] - 1s 166ms/step - loss: 0.8092 - accuracy: 0.7346 - val_loss: 0.7742 - val_accuracy: 0.7333
# Epoch 7/70
# 8/8 [==============================] - 1s 164ms/step - loss: 0.7560 - accuracy: 0.7351 - val_loss: 0.7425 - val_accuracy: 0.7407
# Epoch 8/70
# 8/8 [==============================] - 1s 176ms/step - loss: 0.7172 - accuracy: 0.7423 - val_loss: 0.6873 - val_accuracy: 0.7736
# Epoch 9/70
# 8/8 [==============================] - 1s 174ms/step - loss: 0.6829 - accuracy: 0.7606 - val_loss: 0.6639 - val_accuracy: 0.7662
# Epoch 10/70
# 8/8 [==============================] - 1s 183ms/step - loss: 0.6518 - accuracy: 0.7678 - val_loss: 0.6242 - val_accuracy: 0.7970
# Epoch 11/70
# 8/8 [==============================] - 1s 169ms/step - loss: 0.6262 - accuracy: 0.7819 - val_loss: 0.6261 - val_accuracy: 0.7843
# Epoch 12/70
# 8/8 [==============================] - 1s 175ms/step - loss: 0.6181 - accuracy: 0.7806 - val_loss: 0.5723 - val_accuracy: 0.8172
# Epoch 13/70
# 8/8 [==============================] - 1s 178ms/step - loss: 0.6007 - accuracy: 0.7840 - val_loss: 0.5939 - val_accuracy: 0.7906
# Epoch 14/70
# 8/8 [==============================] - 1s 185ms/step - loss: 0.5808 - accuracy: 0.7952 - val_loss: 0.5787 - val_accuracy: 0.8172
# Epoch 15/70
# 8/8 [==============================] - 1s 182ms/step - loss: 0.5843 - accuracy: 0.7885 - val_loss: 0.5296 - val_accuracy: 0.8257
# Epoch 16/70
# 8/8 [==============================] - 1s 162ms/step - loss: 0.5489 - accuracy: 0.8034 - val_loss: 0.5815 - val_accuracy: 0.8130
# Epoch 17/70
# 8/8 [==============================] - 1s 172ms/step - loss: 0.5606 - accuracy: 0.7962 - val_loss: 0.6018 - val_accuracy: 0.7800
# Epoch 18/70
# 8/8 [==============================] - 1s 168ms/step - loss: 0.5731 - accuracy: 0.7944 - val_loss: 0.5393 - val_accuracy: 0.8257
# Epoch 19/70
# 8/8 [==============================] - 1s 180ms/step - loss: 0.5697 - accuracy: 0.7944 - val_loss: 0.6020 - val_accuracy: 0.8087
# Epoch 20/70
# 8/8 [==============================] - 1s 169ms/step - loss: 0.5343 - accuracy: 0.8069 - val_loss: 0.5017 - val_accuracy: 0.8427
# Epoch 21/70
# 8/8 [==============================] - 1s 163ms/step - loss: 0.5134 - accuracy: 0.8191 - val_loss: 0.5721 - val_accuracy: 0.7970
# Epoch 22/70
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5199 - accuracy: 0.8135 - val_loss: 0.5427 - val_accuracy: 0.8193
# Epoch 23/70
# 8/8 [==============================] - 2s 188ms/step - loss: 0.4941 - accuracy: 0.8252 - val_loss: 0.4673 - val_accuracy: 0.8470
# Epoch 24/70
# 8/8 [==============================] - 2s 190ms/step - loss: 0.4683 - accuracy: 0.8345 - val_loss: 0.4534 - val_accuracy: 0.8704
# Epoch 25/70
# 8/8 [==============================] - 1s 161ms/step - loss: 0.4611 - accuracy: 0.8361 - val_loss: 0.4533 - val_accuracy: 0.8565
# Epoch 26/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.4633 - accuracy: 0.8382 - val_loss: 0.4552 - val_accuracy: 0.8480
# Epoch 27/70
# 8/8 [==============================] - 1s 182ms/step - loss: 0.4420 - accuracy: 0.8435 - val_loss: 0.4579 - val_accuracy: 0.8650
# Epoch 28/70
# 8/8 [==============================] - 1s 185ms/step - loss: 0.4434 - accuracy: 0.8491 - val_loss: 0.4822 - val_accuracy: 0.8629
# Epoch 29/70
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4432 - accuracy: 0.8486 - val_loss: 0.4563 - val_accuracy: 0.8704
# Epoch 30/70
# 8/8 [==============================] - 1s 161ms/step - loss: 0.4412 - accuracy: 0.8440 - val_loss: 0.4619 - val_accuracy: 0.8704
# Epoch 31/70
# 8/8 [==============================] - 1s 164ms/step - loss: 0.4357 - accuracy: 0.8480 - val_loss: 0.4105 - val_accuracy: 0.8714
# Epoch 32/70
# 8/8 [==============================] - 1s 166ms/step - loss: 0.4051 - accuracy: 0.8589 - val_loss: 0.4187 - val_accuracy: 0.8757
# Epoch 33/70
# 8/8 [==============================] - 1s 171ms/step - loss: 0.3954 - accuracy: 0.8682 - val_loss: 0.4607 - val_accuracy: 0.8247
# Epoch 34/70
# 8/8 [==============================] - 1s 175ms/step - loss: 0.4262 - accuracy: 0.8499 - val_loss: 0.4431 - val_accuracy: 0.8597
# Epoch 35/70
# 8/8 [==============================] - 1s 163ms/step - loss: 0.4160 - accuracy: 0.8549 - val_loss: 0.4006 - val_accuracy: 0.8852
# Epoch 36/70
# 8/8 [==============================] - 1s 176ms/step - loss: 0.3746 - accuracy: 0.8757 - val_loss: 0.3941 - val_accuracy: 0.8852
# Epoch 37/70
# 8/8 [==============================] - 1s 183ms/step - loss: 0.3679 - accuracy: 0.8714 - val_loss: 0.4008 - val_accuracy: 0.8842
# Epoch 38/70
# 8/8 [==============================] - 1s 185ms/step - loss: 0.3674 - accuracy: 0.8709 - val_loss: 0.3917 - val_accuracy: 0.8874
# Epoch 39/70
# 8/8 [==============================] - 1s 164ms/step - loss: 0.3490 - accuracy: 0.8823 - val_loss: 0.3955 - val_accuracy: 0.8714
# Epoch 40/70
# 8/8 [==============================] - 1s 163ms/step - loss: 0.3619 - accuracy: 0.8783 - val_loss: 0.3970 - val_accuracy: 0.8863
# Epoch 41/70
# 8/8 [==============================] - 1s 186ms/step - loss: 0.3532 - accuracy: 0.8831 - val_loss: 0.3883 - val_accuracy: 0.8948
# Epoch 42/70
# 8/8 [==============================] - 2s 191ms/step - loss: 0.3507 - accuracy: 0.8871 - val_loss: 0.3615 - val_accuracy: 0.8767
# Epoch 43/70
# 8/8 [==============================] - 1s 180ms/step - loss: 0.3919 - accuracy: 0.8600 - val_loss: 0.3957 - val_accuracy: 0.8789
# Epoch 44/70
# 8/8 [==============================] - 1s 167ms/step - loss: 0.4330 - accuracy: 0.8438 - val_loss: 0.4619 - val_accuracy: 0.8555
# Epoch 45/70
# 8/8 [==============================] - 1s 169ms/step - loss: 0.4263 - accuracy: 0.8451 - val_loss: 0.4037 - val_accuracy: 0.8735
# Epoch 46/70
# 8/8 [==============================] - 1s 186ms/step - loss: 0.3772 - accuracy: 0.8743 - val_loss: 0.3923 - val_accuracy: 0.8820
# Epoch 47/70
# 8/8 [==============================] - 1s 180ms/step - loss: 0.3445 - accuracy: 0.8799 - val_loss: 0.3727 - val_accuracy: 0.8895
# Epoch 48/70
# 8/8 [==============================] - 1s 161ms/step - loss: 0.3313 - accuracy: 0.8863 - val_loss: 0.3807 - val_accuracy: 0.8895
# Epoch 49/70
# 8/8 [==============================] - 1s 168ms/step - loss: 0.3249 - accuracy: 0.8905 - val_loss: 0.3873 - val_accuracy: 0.8735
# Epoch 50/70
# 8/8 [==============================] - 1s 178ms/step - loss: 0.3219 - accuracy: 0.8924 - val_loss: 0.3744 - val_accuracy: 0.8831
# Epoch 51/70
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3007 - accuracy: 0.8974 - val_loss: 0.3499 - val_accuracy: 0.8969
# Epoch 52/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.3045 - accuracy: 0.8943 - val_loss: 0.3618 - val_accuracy: 0.8927
# Epoch 53/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.3048 - accuracy: 0.8977 - val_loss: 0.3378 - val_accuracy: 0.9054
# Epoch 54/70
# 8/8 [==============================] - 1s 170ms/step - loss: 0.2888 - accuracy: 0.9083 - val_loss: 0.3794 - val_accuracy: 0.8990
# Epoch 55/70
# 8/8 [==============================] - 2s 198ms/step - loss: 0.3021 - accuracy: 0.9006 - val_loss: 0.3337 - val_accuracy: 0.8969
# Epoch 56/70
# 8/8 [==============================] - 1s 171ms/step - loss: 0.2892 - accuracy: 0.9041 - val_loss: 0.3550 - val_accuracy: 0.8863
# Epoch 57/70
# 8/8 [==============================] - 1s 157ms/step - loss: 0.2830 - accuracy: 0.9012 - val_loss: 0.3535 - val_accuracy: 0.9001
# Epoch 58/70
# 8/8 [==============================] - 1s 169ms/step - loss: 0.2835 - accuracy: 0.9067 - val_loss: 0.3971 - val_accuracy: 0.8704
# Epoch 59/70
# 8/8 [==============================] - 1s 171ms/step - loss: 0.2925 - accuracy: 0.8990 - val_loss: 0.3907 - val_accuracy: 0.8884
# Epoch 60/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.2920 - accuracy: 0.8985 - val_loss: 0.3946 - val_accuracy: 0.8895
# Epoch 61/70
# 8/8 [==============================] - 1s 169ms/step - loss: 0.2994 - accuracy: 0.8935 - val_loss: 0.3494 - val_accuracy: 0.8948
# Epoch 62/70
# 8/8 [==============================] - 1s 163ms/step - loss: 0.2770 - accuracy: 0.9033 - val_loss: 0.3321 - val_accuracy: 0.8927
# Epoch 63/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.2723 - accuracy: 0.9081 - val_loss: 0.3389 - val_accuracy: 0.9033
# Epoch 64/70
# 8/8 [==============================] - 2s 195ms/step - loss: 0.2572 - accuracy: 0.9147 - val_loss: 0.3333 - val_accuracy: 0.8980
# Epoch 65/70
# 8/8 [==============================] - 1s 178ms/step - loss: 0.2437 - accuracy: 0.9179 - val_loss: 0.3242 - val_accuracy: 0.9118
# Epoch 66/70
# 8/8 [==============================] - 1s 159ms/step - loss: 0.2454 - accuracy: 0.9163 - val_loss: 0.3254 - val_accuracy: 0.9022
# Epoch 67/70
# 8/8 [==============================] - 1s 156ms/step - loss: 0.2387 - accuracy: 0.9198 - val_loss: 0.3415 - val_accuracy: 0.9022
# Epoch 68/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.2495 - accuracy: 0.9176 - val_loss: 0.3283 - val_accuracy: 0.9107
# Epoch 69/70
# 8/8 [==============================] - 1s 185ms/step - loss: 0.2439 - accuracy: 0.9158 - val_loss: 0.3228 - val_accuracy: 0.9054
# Epoch 70/70
# 8/8 [==============================] - 1s 173ms/step - loss: 0.2455 - accuracy: 0.9200 - val_loss: 0.3321 - val_accuracy: 0.9065

# %%
# model accuracy on training and testing sets
if include_spatial:
    train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
    test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)
else:
    train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2}, cube_train_labelsn)
    test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2}, cube_test_labelsn)
    
print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 7ms/step - loss: 0.1939 - accuracy: 0.9400
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3321 - accuracy: 0.9065
# 0.9399574995040894 0.906482458114624

# %% [markdown]
# ### Predict pixel classification on all of Scene 2

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])

start_time = time.time()

if include_spatial:
    probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})
else:
    probCuben = cnnn.predict({"spectra":cube_standardn_1})
    
predictCuben = probCuben.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:07:40

# %%
# -- Plot the prediction map of Scene 2

predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 2

# %%
# -- create the prediction arrays from the predictions of the testing set

labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# -- create the true arrays from the labeled testing set 

labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 2

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 140   0   0   0   0   0   0]
#  [  0   0   0 123   0   0   0   0   1]
#  [  0   0   0   1 315   3   0   1   0]
#  [  0   0   0   0   7 101   9   3   0]
#  [  0   0   1   0   6   8  32   1   2]
#  [  0   0   0   0   9   9   1  31   0]
#  [  0   0   0   2  11   9   2   2  11]]
#
# Accuracy Score
# 0.9064824654622742
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      1.00      1.00       140
#       water       0.98      0.99      0.98       124
#       built       0.91      0.98      0.94       320
#     windows       0.78      0.84      0.81       120
#       roads       0.73      0.64      0.68        50
#        cars       0.82      0.62      0.70        50
#       metal       0.79      0.30      0.43        37
#
# avg / total       0.90      0.91      0.90       941

# %% [markdown]
# ---
# # CNN on Scene 1-a

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
cube_sub = cube.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
# -- if reduced_resolution = True, the spectra are averaged into bins to simulate reduced resolution

if reduced_resolution:
    bin_ind = []

    for i in range(0, num_of_bins):
        low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
        upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
        bin_ind.append([low_ind, upp_ind])
    bin_ind[-1][-1] = cube_sub.shape[0]

    cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))
    for i in range(num_of_bins):
        cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

    cube_standard = cube_binned
    
# -- reshape standardized cube to (row, col, wavelength)
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# -- create position array from coordinates and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
trrat = 0.8  # set train/test ratio to have 80% training, 20% testing

# -- get the coordinates of training and testing sets for each class
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 848) (60, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (480, 848) (120, 848)
# water  (40, 848) (10, 848)
# built  (816, 848) (204, 848)
# windows  (400, 848) (100, 848)
# roads  (24, 848) (6, 848)
# cars  (80, 848) (20, 848)
# metal  (80, 848) (20, 848)

# %%
# -- concatenate the training arrays into training data and labels

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
cube_train_labels = np.array(cube_train_labels)
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
cube_test_labels = np.array(cube_test_labels)
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnn = CNN_Model(cube_std_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                         validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                         epochs=200, batch_size=512)
else:
    CNNmodel = cnn.fit({"spectra":cube_train2}, cube_train_labels, 
                         validation_data=({"spectra":cube_test2}, cube_test_labels),
                         epochs=200, batch_size=512)
# Out:
# Train on 2560 samples, validate on 640 samples
# Epoch 1/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 2.0201 - acc: 0.3348 - val_loss: 1.6582 - val_acc: 0.4938
# Epoch 2/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 1.3245 - acc: 0.5980 - val_loss: 1.0112 - val_acc: 0.6734
# Epoch 3/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.9770 - acc: 0.7172 - val_loss: 0.8108 - val_acc: 0.7688
# Epoch 4/200
# 2560/2560 [==============================] - 4s 1ms/step - loss: 0.7959 - acc: 0.7480 - val_loss: 0.6883 - val_acc: 0.8141
# Epoch 5/200
# 2560/2560 [==============================] - 4s 1ms/step - loss: 0.6913 - acc: 0.8016 - val_loss: 0.6186 - val_acc: 0.8078
# Epoch 6/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.6281 - acc: 0.8129 - val_loss: 0.5899 - val_acc: 0.8203
# Epoch 7/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.5665 - acc: 0.8277 - val_loss: 0.4861 - val_acc: 0.8344
# Epoch 8/200
# 2560/2560 [==============================] - 4s 1ms/step - loss: 0.4949 - acc: 0.8465 - val_loss: 0.4507 - val_acc: 0.8656
# Epoch 9/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.4663 - acc: 0.8555 - val_loss: 0.3939 - val_acc: 0.8859
# Epoch 10/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.4335 - acc: 0.8648 - val_loss: 0.3983 - val_acc: 0.8734
# Epoch 11/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.4048 - acc: 0.8781 - val_loss: 0.3711 - val_acc: 0.8828
# Epoch 12/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3912 - acc: 0.8840 - val_loss: 0.3339 - val_acc: 0.9062
# Epoch 13/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3766 - acc: 0.8820 - val_loss: 0.3295 - val_acc: 0.9062
# Epoch 14/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3582 - acc: 0.8906 - val_loss: 0.3341 - val_acc: 0.8969
# Epoch 15/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3365 - acc: 0.8965 - val_loss: 0.3359 - val_acc: 0.8984
# Epoch 16/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3484 - acc: 0.8953 - val_loss: 0.3072 - val_acc: 0.9125
# Epoch 17/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3249 - acc: 0.9016 - val_loss: 0.2950 - val_acc: 0.9141
# Epoch 18/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3032 - acc: 0.9062 - val_loss: 0.2814 - val_acc: 0.9047
# Epoch 19/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2971 - acc: 0.9074 - val_loss: 0.2689 - val_acc: 0.9109
# Epoch 20/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2785 - acc: 0.9133 - val_loss: 0.2634 - val_acc: 0.9156
# Epoch 21/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2660 - acc: 0.9164 - val_loss: 0.2489 - val_acc: 0.9219
# Epoch 22/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2652 - acc: 0.9172 - val_loss: 0.2573 - val_acc: 0.9234
# Epoch 23/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2647 - acc: 0.9152 - val_loss: 0.2516 - val_acc: 0.9172
# Epoch 24/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2448 - acc: 0.9215 - val_loss: 0.2529 - val_acc: 0.9250
# Epoch 25/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2703 - acc: 0.9160 - val_loss: 0.3427 - val_acc: 0.8844
# Epoch 26/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2877 - acc: 0.9027 - val_loss: 0.2786 - val_acc: 0.9078
# Epoch 27/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2867 - acc: 0.9090 - val_loss: 0.2601 - val_acc: 0.9125
# Epoch 28/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2586 - acc: 0.9168 - val_loss: 0.2462 - val_acc: 0.9156
# Epoch 29/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2444 - acc: 0.9180 - val_loss: 0.2305 - val_acc: 0.9172
# Epoch 30/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2381 - acc: 0.9238 - val_loss: 0.2285 - val_acc: 0.9219
# Epoch 31/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2263 - acc: 0.9234 - val_loss: 0.2213 - val_acc: 0.9250
# Epoch 32/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2222 - acc: 0.9277 - val_loss: 0.2241 - val_acc: 0.9344
# Epoch 33/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2195 - acc: 0.9320 - val_loss: 0.2100 - val_acc: 0.9203
# Epoch 34/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2114 - acc: 0.9293 - val_loss: 0.2018 - val_acc: 0.9359
# Epoch 35/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2313 - acc: 0.9234 - val_loss: 0.2228 - val_acc: 0.9109
# Epoch 36/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2240 - acc: 0.9242 - val_loss: 0.2112 - val_acc: 0.9219
# Epoch 37/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2159 - acc: 0.9289 - val_loss: 0.1993 - val_acc: 0.9250
# Epoch 38/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1952 - acc: 0.9320 - val_loss: 0.1903 - val_acc: 0.9297
# Epoch 39/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2014 - acc: 0.9297 - val_loss: 0.2094 - val_acc: 0.9359
# Epoch 40/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2014 - acc: 0.9305 - val_loss: 0.1877 - val_acc: 0.9359
# Epoch 41/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1940 - acc: 0.9375 - val_loss: 0.1899 - val_acc: 0.9313
# Epoch 42/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1878 - acc: 0.9340 - val_loss: 0.2054 - val_acc: 0.9453
# Epoch 43/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1935 - acc: 0.9355 - val_loss: 0.1846 - val_acc: 0.9328
# Epoch 44/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1913 - acc: 0.9340 - val_loss: 0.2132 - val_acc: 0.9187
# Epoch 45/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1895 - acc: 0.9352 - val_loss: 0.1927 - val_acc: 0.9234
# Epoch 46/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1820 - acc: 0.9359 - val_loss: 0.1833 - val_acc: 0.9328
# Epoch 47/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1772 - acc: 0.9402 - val_loss: 0.1866 - val_acc: 0.9328
# Epoch 48/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1851 - acc: 0.9328 - val_loss: 0.1934 - val_acc: 0.9484
# Epoch 49/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1831 - acc: 0.9410 - val_loss: 0.2399 - val_acc: 0.9391
# Epoch 50/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1911 - acc: 0.9352 - val_loss: 0.2001 - val_acc: 0.9359
# Epoch 51/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1867 - acc: 0.9391 - val_loss: 0.1707 - val_acc: 0.9359
# Epoch 52/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1707 - acc: 0.9402 - val_loss: 0.1654 - val_acc: 0.9406
# Epoch 53/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1621 - acc: 0.9449 - val_loss: 0.1879 - val_acc: 0.9344
# Epoch 54/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1689 - acc: 0.9418 - val_loss: 0.1747 - val_acc: 0.9406
# Epoch 55/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1552 - acc: 0.9473 - val_loss: 0.1556 - val_acc: 0.9375
# Epoch 56/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1614 - acc: 0.9422 - val_loss: 0.1559 - val_acc: 0.9578
# Epoch 57/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1634 - acc: 0.9430 - val_loss: 0.1565 - val_acc: 0.9453
# Epoch 58/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1558 - acc: 0.9457 - val_loss: 0.1502 - val_acc: 0.9406
# Epoch 59/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1575 - acc: 0.9422 - val_loss: 0.1857 - val_acc: 0.9297
# Epoch 60/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1529 - acc: 0.9457 - val_loss: 0.1513 - val_acc: 0.9453
# Epoch 61/200
# 2560/2560 [==============================] - 4s 1ms/step - loss: 0.1496 - acc: 0.9512 - val_loss: 0.1561 - val_acc: 0.9359
# Epoch 62/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1508 - acc: 0.9508 - val_loss: 0.1941 - val_acc: 0.9156
# Epoch 63/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1407 - acc: 0.9535 - val_loss: 0.1644 - val_acc: 0.9375
# Epoch 64/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1400 - acc: 0.9531 - val_loss: 0.1435 - val_acc: 0.9547
# Epoch 65/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1359 - acc: 0.9527 - val_loss: 0.1347 - val_acc: 0.9563
# Epoch 66/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1290 - acc: 0.9562 - val_loss: 0.1418 - val_acc: 0.9422
# Epoch 67/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1312 - acc: 0.9520 - val_loss: 0.1349 - val_acc: 0.9516
# Epoch 68/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1300 - acc: 0.9551 - val_loss: 0.1465 - val_acc: 0.9594
# Epoch 69/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1446 - acc: 0.9508 - val_loss: 0.1370 - val_acc: 0.9547
# Epoch 70/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1444 - acc: 0.9531 - val_loss: 0.1482 - val_acc: 0.9469
# Epoch 71/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1620 - acc: 0.9418 - val_loss: 0.1790 - val_acc: 0.9578
# Epoch 72/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1479 - acc: 0.9496 - val_loss: 0.1654 - val_acc: 0.9547
# Epoch 73/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1682 - acc: 0.9434 - val_loss: 0.1791 - val_acc: 0.9516
# Epoch 74/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1481 - acc: 0.9504 - val_loss: 0.1389 - val_acc: 0.9578
# Epoch 75/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1416 - acc: 0.9453 - val_loss: 0.1293 - val_acc: 0.9609
# Epoch 76/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1252 - acc: 0.9633 - val_loss: 0.1516 - val_acc: 0.9453
# Epoch 77/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1279 - acc: 0.9586 - val_loss: 0.1318 - val_acc: 0.9563
# Epoch 78/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1256 - acc: 0.9590 - val_loss: 0.1252 - val_acc: 0.9578
# Epoch 79/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1246 - acc: 0.9590 - val_loss: 0.1390 - val_acc: 0.9578
# Epoch 80/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1199 - acc: 0.9641 - val_loss: 0.1695 - val_acc: 0.9406
# Epoch 81/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1263 - acc: 0.9570 - val_loss: 0.1574 - val_acc: 0.9437
# Epoch 82/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1268 - acc: 0.9578 - val_loss: 0.1289 - val_acc: 0.9531
# Epoch 83/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1233 - acc: 0.9590 - val_loss: 0.1426 - val_acc: 0.9484
# Epoch 84/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1234 - acc: 0.9605 - val_loss: 0.1421 - val_acc: 0.9422
# Epoch 85/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1129 - acc: 0.9613 - val_loss: 0.1300 - val_acc: 0.9594
# Epoch 86/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1085 - acc: 0.9648 - val_loss: 0.1275 - val_acc: 0.9641
# Epoch 87/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1099 - acc: 0.9641 - val_loss: 0.1171 - val_acc: 0.9625
# Epoch 88/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1124 - acc: 0.9625 - val_loss: 0.1320 - val_acc: 0.9547
# Epoch 89/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1134 - acc: 0.9641 - val_loss: 0.1346 - val_acc: 0.9531
# Epoch 90/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1132 - acc: 0.9598 - val_loss: 0.1373 - val_acc: 0.9484
# Epoch 91/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1066 - acc: 0.9625 - val_loss: 0.1386 - val_acc: 0.9484
# Epoch 92/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1115 - acc: 0.9633 - val_loss: 0.1282 - val_acc: 0.9578
# Epoch 93/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1089 - acc: 0.9641 - val_loss: 0.1261 - val_acc: 0.9641
# Epoch 94/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1010 - acc: 0.9676 - val_loss: 0.1185 - val_acc: 0.9594
# Epoch 95/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0930 - acc: 0.9691 - val_loss: 0.1203 - val_acc: 0.9609
# Epoch 96/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1020 - acc: 0.9641 - val_loss: 0.1099 - val_acc: 0.9641
# Epoch 97/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0911 - acc: 0.9688 - val_loss: 0.1111 - val_acc: 0.9656
# Epoch 98/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0886 - acc: 0.9699 - val_loss: 0.1156 - val_acc: 0.9609
# Epoch 99/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0899 - acc: 0.9707 - val_loss: 0.1061 - val_acc: 0.9625
# Epoch 100/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1051 - acc: 0.9613 - val_loss: 0.1150 - val_acc: 0.9578
# Epoch 101/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1314 - acc: 0.9539 - val_loss: 0.1237 - val_acc: 0.9578
# Epoch 102/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1148 - acc: 0.9598 - val_loss: 0.1198 - val_acc: 0.9578
# Epoch 103/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1137 - acc: 0.9637 - val_loss: 0.1254 - val_acc: 0.9563
# Epoch 104/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1016 - acc: 0.9656 - val_loss: 0.1103 - val_acc: 0.9609
# Epoch 105/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0876 - acc: 0.9703 - val_loss: 0.1003 - val_acc: 0.9625
# Epoch 106/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0869 - acc: 0.9719 - val_loss: 0.1028 - val_acc: 0.9656
# Epoch 107/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0801 - acc: 0.9723 - val_loss: 0.1069 - val_acc: 0.9641
# Epoch 108/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0869 - acc: 0.9688 - val_loss: 0.1172 - val_acc: 0.9641
# Epoch 109/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0877 - acc: 0.9695 - val_loss: 0.1101 - val_acc: 0.9656
# Epoch 110/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0899 - acc: 0.9742 - val_loss: 0.0941 - val_acc: 0.9719
# Epoch 111/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0868 - acc: 0.9711 - val_loss: 0.1103 - val_acc: 0.9656
# Epoch 112/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0898 - acc: 0.9734 - val_loss: 0.1091 - val_acc: 0.9672
# Epoch 113/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0964 - acc: 0.9699 - val_loss: 0.1061 - val_acc: 0.9641
# Epoch 114/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0862 - acc: 0.9727 - val_loss: 0.1130 - val_acc: 0.9672
# Epoch 115/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0872 - acc: 0.9750 - val_loss: 0.1211 - val_acc: 0.9594
# Epoch 116/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0932 - acc: 0.9711 - val_loss: 0.1176 - val_acc: 0.9594
# Epoch 117/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0908 - acc: 0.9688 - val_loss: 0.1089 - val_acc: 0.9656
# Epoch 118/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0805 - acc: 0.9703 - val_loss: 0.0993 - val_acc: 0.9656
# Epoch 119/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0757 - acc: 0.9750 - val_loss: 0.0977 - val_acc: 0.9641
# Epoch 120/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0750 - acc: 0.9703 - val_loss: 0.1120 - val_acc: 0.9641
# Epoch 121/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0743 - acc: 0.9754 - val_loss: 0.0939 - val_acc: 0.9719
# Epoch 122/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0770 - acc: 0.9723 - val_loss: 0.1073 - val_acc: 0.9625
# Epoch 123/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0803 - acc: 0.9734 - val_loss: 0.1025 - val_acc: 0.9672
# Epoch 124/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0816 - acc: 0.9715 - val_loss: 0.0961 - val_acc: 0.9734
# Epoch 125/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0794 - acc: 0.9715 - val_loss: 0.0951 - val_acc: 0.9703
# Epoch 126/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0754 - acc: 0.9766 - val_loss: 0.0990 - val_acc: 0.9656
# Epoch 127/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0738 - acc: 0.9777 - val_loss: 0.1052 - val_acc: 0.9656
# Epoch 128/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0715 - acc: 0.9766 - val_loss: 0.1009 - val_acc: 0.9641
# Epoch 129/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0831 - acc: 0.9699 - val_loss: 0.0979 - val_acc: 0.9656
# Epoch 130/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0849 - acc: 0.9695 - val_loss: 0.1083 - val_acc: 0.9656
# Epoch 131/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0707 - acc: 0.9762 - val_loss: 0.1085 - val_acc: 0.9656
# Epoch 132/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0724 - acc: 0.9766 - val_loss: 0.0995 - val_acc: 0.9703
# Epoch 133/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0648 - acc: 0.9785 - val_loss: 0.1014 - val_acc: 0.9672
# Epoch 134/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0678 - acc: 0.9777 - val_loss: 0.0925 - val_acc: 0.9688
# Epoch 135/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0638 - acc: 0.9797 - val_loss: 0.1004 - val_acc: 0.9688
# Epoch 136/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0651 - acc: 0.9801 - val_loss: 0.1022 - val_acc: 0.9688
# Epoch 137/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0672 - acc: 0.9785 - val_loss: 0.0943 - val_acc: 0.9703
# Epoch 138/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0700 - acc: 0.9754 - val_loss: 0.1049 - val_acc: 0.9594
# Epoch 139/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0655 - acc: 0.9781 - val_loss: 0.0928 - val_acc: 0.9688
# Epoch 140/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0559 - acc: 0.9813 - val_loss: 0.1015 - val_acc: 0.9703
# Epoch 141/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0578 - acc: 0.9828 - val_loss: 0.1040 - val_acc: 0.9672
# Epoch 142/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0659 - acc: 0.9773 - val_loss: 0.0878 - val_acc: 0.9719
# Epoch 143/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0573 - acc: 0.9813 - val_loss: 0.0933 - val_acc: 0.9703
# Epoch 144/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0510 - acc: 0.9824 - val_loss: 0.1021 - val_acc: 0.9609
# Epoch 145/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0605 - acc: 0.9777 - val_loss: 0.1002 - val_acc: 0.9656
# Epoch 146/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0684 - acc: 0.9785 - val_loss: 0.1077 - val_acc: 0.9672
# Epoch 147/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0661 - acc: 0.9750 - val_loss: 0.0943 - val_acc: 0.9672
# Epoch 148/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0595 - acc: 0.9816 - val_loss: 0.0994 - val_acc: 0.9672
# Epoch 149/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0662 - acc: 0.9758 - val_loss: 0.0934 - val_acc: 0.9734
# Epoch 150/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0624 - acc: 0.9797 - val_loss: 0.0999 - val_acc: 0.9672
# Epoch 151/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0571 - acc: 0.9805 - val_loss: 0.1061 - val_acc: 0.9656
# Epoch 152/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0719 - acc: 0.9750 - val_loss: 0.1059 - val_acc: 0.9656
# Epoch 153/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0641 - acc: 0.9816 - val_loss: 0.0887 - val_acc: 0.9719
# Epoch 154/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0658 - acc: 0.9789 - val_loss: 0.1053 - val_acc: 0.9656
# Epoch 155/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0702 - acc: 0.9746 - val_loss: 0.1151 - val_acc: 0.9578
# Epoch 156/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0673 - acc: 0.9758 - val_loss: 0.0877 - val_acc: 0.9719
# Epoch 157/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0552 - acc: 0.9809 - val_loss: 0.0968 - val_acc: 0.9766
# Epoch 158/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0621 - acc: 0.9754 - val_loss: 0.1198 - val_acc: 0.9641
# Epoch 159/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0562 - acc: 0.9781 - val_loss: 0.1071 - val_acc: 0.9578
# Epoch 160/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0595 - acc: 0.9770 - val_loss: 0.0980 - val_acc: 0.9719
# Epoch 161/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0526 - acc: 0.9809 - val_loss: 0.0952 - val_acc: 0.9719
# Epoch 162/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0504 - acc: 0.9805 - val_loss: 0.0994 - val_acc: 0.9688
# Epoch 163/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0527 - acc: 0.9836 - val_loss: 0.0888 - val_acc: 0.9703
# Epoch 164/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0569 - acc: 0.9824 - val_loss: 0.0840 - val_acc: 0.9688
# Epoch 165/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0512 - acc: 0.9871 - val_loss: 0.0867 - val_acc: 0.9703
# Epoch 166/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0461 - acc: 0.9867 - val_loss: 0.0926 - val_acc: 0.9688
# Epoch 167/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0467 - acc: 0.9840 - val_loss: 0.0915 - val_acc: 0.9719
# Epoch 168/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0594 - acc: 0.9797 - val_loss: 0.1027 - val_acc: 0.9672
# Epoch 169/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0581 - acc: 0.9813 - val_loss: 0.1059 - val_acc: 0.9609
# Epoch 170/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0591 - acc: 0.9801 - val_loss: 0.1157 - val_acc: 0.9688
# Epoch 171/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0593 - acc: 0.9801 - val_loss: 0.1030 - val_acc: 0.9672
# Epoch 172/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0509 - acc: 0.9820 - val_loss: 0.0849 - val_acc: 0.9719
# Epoch 173/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0460 - acc: 0.9863 - val_loss: 0.1158 - val_acc: 0.9656
# Epoch 174/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0552 - acc: 0.9809 - val_loss: 0.0984 - val_acc: 0.9688
# Epoch 175/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0477 - acc: 0.9828 - val_loss: 0.0915 - val_acc: 0.9688
# Epoch 176/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0485 - acc: 0.9832 - val_loss: 0.0931 - val_acc: 0.9688
# Epoch 177/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0483 - acc: 0.9805 - val_loss: 0.0904 - val_acc: 0.9734
# Epoch 178/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0512 - acc: 0.9816 - val_loss: 0.0856 - val_acc: 0.9734
# Epoch 179/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0470 - acc: 0.9844 - val_loss: 0.0905 - val_acc: 0.9719
# Epoch 180/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0487 - acc: 0.9805 - val_loss: 0.0896 - val_acc: 0.9719
# Epoch 181/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0349 - acc: 0.9910 - val_loss: 0.0935 - val_acc: 0.9719
# Epoch 182/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0408 - acc: 0.9859 - val_loss: 0.0865 - val_acc: 0.9766
# Epoch 183/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0324 - acc: 0.9902 - val_loss: 0.0909 - val_acc: 0.9688
# Epoch 184/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0430 - acc: 0.9879 - val_loss: 0.0904 - val_acc: 0.9672
# Epoch 185/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0341 - acc: 0.9891 - val_loss: 0.0895 - val_acc: 0.9719
# Epoch 186/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0380 - acc: 0.9867 - val_loss: 0.0818 - val_acc: 0.9797
# Epoch 187/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0338 - acc: 0.9887 - val_loss: 0.0861 - val_acc: 0.9750
# Epoch 188/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0424 - acc: 0.9859 - val_loss: 0.0865 - val_acc: 0.9703
# Epoch 189/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0337 - acc: 0.9902 - val_loss: 0.0821 - val_acc: 0.9797
# Epoch 190/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0354 - acc: 0.9879 - val_loss: 0.0831 - val_acc: 0.9703
# Epoch 191/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0336 - acc: 0.9875 - val_loss: 0.0846 - val_acc: 0.9734
# Epoch 192/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0330 - acc: 0.9895 - val_loss: 0.0870 - val_acc: 0.9703
# Epoch 193/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0389 - acc: 0.9871 - val_loss: 0.0899 - val_acc: 0.9719
# Epoch 194/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0440 - acc: 0.9832 - val_loss: 0.0972 - val_acc: 0.9641
# Epoch 195/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0413 - acc: 0.9867 - val_loss: 0.0912 - val_acc: 0.9703
# Epoch 196/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0419 - acc: 0.9863 - val_loss: 0.1171 - val_acc: 0.9563
# Epoch 197/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0414 - acc: 0.9848 - val_loss: 0.0831 - val_acc: 0.9766
# Epoch 198/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0347 - acc: 0.9891 - val_loss: 0.0848 - val_acc: 0.9734
# Epoch 199/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0363 - acc: 0.9891 - val_loss: 0.0948 - val_acc: 0.9688
# Epoch 200/200
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0367 - acc: 0.9871 - val_loss: 0.0840 - val_acc: 0.9734

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodel)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnn = CNN_Model(cube_std_3d.shape[2], spatial=include_spatial, filtersize, conv1, dens1)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
if include_spatial:
    CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                         validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                         epochs=110, batch_size=512)
else:
    CNNmodel = cnn.fit({"spectra":cube_train2}, cube_train_labels, 
                         validation_data=({"spectra":cube_test2}, cube_test_labels),
                         epochs=110, batch_size=512)
# Out:
# Train on 2560 samples, validate on 640 samples
# Epoch 1/110
# 2560/2560 [==============================] - 4s 1ms/step - loss: 1.8735 - acc: 0.3578 - val_loss: 1.3647 - val_acc: 0.4953
# Epoch 2/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 1.1288 - acc: 0.6168 - val_loss: 0.9450 - val_acc: 0.7328
# Epoch 3/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.8377 - acc: 0.7375 - val_loss: 0.6991 - val_acc: 0.8031
# Epoch 4/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.6695 - acc: 0.8055 - val_loss: 0.5742 - val_acc: 0.8109
# Epoch 5/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.5985 - acc: 0.8148 - val_loss: 0.5794 - val_acc: 0.8141
# Epoch 6/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.5484 - acc: 0.8234 - val_loss: 0.4836 - val_acc: 0.8328
# Epoch 7/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.4782 - acc: 0.8469 - val_loss: 0.4415 - val_acc: 0.8750
# Epoch 8/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.4429 - acc: 0.8559 - val_loss: 0.3987 - val_acc: 0.8750
# Epoch 9/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3964 - acc: 0.8828 - val_loss: 0.3521 - val_acc: 0.9062
# Epoch 10/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3524 - acc: 0.8914 - val_loss: 0.3222 - val_acc: 0.9078
# Epoch 11/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3500 - acc: 0.8910 - val_loss: 0.3273 - val_acc: 0.8969
# Epoch 12/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3512 - acc: 0.8891 - val_loss: 0.2990 - val_acc: 0.9094
# Epoch 13/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3298 - acc: 0.8957 - val_loss: 0.3053 - val_acc: 0.9078
# Epoch 14/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3232 - acc: 0.9023 - val_loss: 0.3075 - val_acc: 0.9187
# Epoch 15/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3075 - acc: 0.9102 - val_loss: 0.2920 - val_acc: 0.9078
# Epoch 16/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2900 - acc: 0.9074 - val_loss: 0.2733 - val_acc: 0.9141
# Epoch 17/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2869 - acc: 0.9062 - val_loss: 0.2412 - val_acc: 0.9187
# Epoch 18/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2765 - acc: 0.9168 - val_loss: 0.2834 - val_acc: 0.9234
# Epoch 19/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.3275 - acc: 0.8910 - val_loss: 0.2528 - val_acc: 0.9172
# Epoch 20/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2921 - acc: 0.9059 - val_loss: 0.2744 - val_acc: 0.9203
# Epoch 21/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2636 - acc: 0.9145 - val_loss: 0.2428 - val_acc: 0.9172
# Epoch 22/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2588 - acc: 0.9191 - val_loss: 0.2288 - val_acc: 0.9344
# Epoch 23/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2533 - acc: 0.9230 - val_loss: 0.2336 - val_acc: 0.9250
# Epoch 24/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2428 - acc: 0.9254 - val_loss: 0.2234 - val_acc: 0.9250
# Epoch 25/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2403 - acc: 0.9227 - val_loss: 0.2488 - val_acc: 0.9187
# Epoch 26/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2512 - acc: 0.9176 - val_loss: 0.2476 - val_acc: 0.9094
# Epoch 27/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2283 - acc: 0.9234 - val_loss: 0.2292 - val_acc: 0.9172
# Epoch 28/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2377 - acc: 0.9199 - val_loss: 0.2172 - val_acc: 0.9234
# Epoch 29/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2122 - acc: 0.9289 - val_loss: 0.2064 - val_acc: 0.9250
# Epoch 30/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2132 - acc: 0.9258 - val_loss: 0.1942 - val_acc: 0.9344
# Epoch 31/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2048 - acc: 0.9340 - val_loss: 0.2090 - val_acc: 0.9281
# Epoch 32/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2000 - acc: 0.9398 - val_loss: 0.1945 - val_acc: 0.9328
# Epoch 33/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1981 - acc: 0.9359 - val_loss: 0.2179 - val_acc: 0.9172
# Epoch 34/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2024 - acc: 0.9348 - val_loss: 0.1996 - val_acc: 0.9313
# Epoch 35/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1905 - acc: 0.9352 - val_loss: 0.1872 - val_acc: 0.9344
# Epoch 36/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1942 - acc: 0.9340 - val_loss: 0.1783 - val_acc: 0.9391
# Epoch 37/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1813 - acc: 0.9414 - val_loss: 0.1783 - val_acc: 0.9391
# Epoch 38/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1734 - acc: 0.9422 - val_loss: 0.1762 - val_acc: 0.9437
# Epoch 39/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1859 - acc: 0.9391 - val_loss: 0.1965 - val_acc: 0.9406
# Epoch 40/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1808 - acc: 0.9395 - val_loss: 0.1688 - val_acc: 0.9422
# Epoch 41/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.2128 - acc: 0.9273 - val_loss: 0.2190 - val_acc: 0.9187
# Epoch 42/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1922 - acc: 0.9398 - val_loss: 0.1973 - val_acc: 0.9391
# Epoch 43/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1944 - acc: 0.9363 - val_loss: 0.1803 - val_acc: 0.9359
# Epoch 44/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1852 - acc: 0.9410 - val_loss: 0.1786 - val_acc: 0.9469
# Epoch 45/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1702 - acc: 0.9418 - val_loss: 0.2072 - val_acc: 0.9422
# Epoch 46/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1808 - acc: 0.9422 - val_loss: 0.1794 - val_acc: 0.9453
# Epoch 47/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1660 - acc: 0.9465 - val_loss: 0.1754 - val_acc: 0.9344
# Epoch 48/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1541 - acc: 0.9473 - val_loss: 0.1625 - val_acc: 0.9422
# Epoch 49/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1534 - acc: 0.9500 - val_loss: 0.1704 - val_acc: 0.9375
# Epoch 50/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1720 - acc: 0.9418 - val_loss: 0.2111 - val_acc: 0.9266
# Epoch 51/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1749 - acc: 0.9422 - val_loss: 0.1581 - val_acc: 0.9453
# Epoch 52/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1568 - acc: 0.9465 - val_loss: 0.1626 - val_acc: 0.9422
# Epoch 53/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1590 - acc: 0.9434 - val_loss: 0.1562 - val_acc: 0.9484
# Epoch 54/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1455 - acc: 0.9480 - val_loss: 0.1787 - val_acc: 0.9437
# Epoch 55/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1786 - acc: 0.9398 - val_loss: 0.1716 - val_acc: 0.9484
# Epoch 56/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1547 - acc: 0.9484 - val_loss: 0.1531 - val_acc: 0.9578
# Epoch 57/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1530 - acc: 0.9539 - val_loss: 0.1725 - val_acc: 0.9422
# Epoch 58/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1456 - acc: 0.9500 - val_loss: 0.1651 - val_acc: 0.9547
# Epoch 59/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1799 - acc: 0.9398 - val_loss: 0.1484 - val_acc: 0.9500
# Epoch 60/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1710 - acc: 0.9465 - val_loss: 0.1708 - val_acc: 0.9437
# Epoch 61/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1728 - acc: 0.9445 - val_loss: 0.1528 - val_acc: 0.9547
# Epoch 62/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1516 - acc: 0.9473 - val_loss: 0.1678 - val_acc: 0.9484
# Epoch 63/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1432 - acc: 0.9539 - val_loss: 0.1561 - val_acc: 0.9406
# Epoch 64/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1421 - acc: 0.9527 - val_loss: 0.1474 - val_acc: 0.9500
# Epoch 65/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1394 - acc: 0.9535 - val_loss: 0.1624 - val_acc: 0.9375
# Epoch 66/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1273 - acc: 0.9566 - val_loss: 0.1455 - val_acc: 0.9406
# Epoch 67/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1228 - acc: 0.9570 - val_loss: 0.1330 - val_acc: 0.9594
# Epoch 68/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1222 - acc: 0.9609 - val_loss: 0.1302 - val_acc: 0.9563
# Epoch 69/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1145 - acc: 0.9609 - val_loss: 0.1290 - val_acc: 0.9594
# Epoch 70/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1126 - acc: 0.9652 - val_loss: 0.1228 - val_acc: 0.9578
# Epoch 71/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1098 - acc: 0.9617 - val_loss: 0.1287 - val_acc: 0.9656
# Epoch 72/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1147 - acc: 0.9633 - val_loss: 0.1377 - val_acc: 0.9547
# Epoch 73/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1075 - acc: 0.9652 - val_loss: 0.1242 - val_acc: 0.9641
# Epoch 74/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1138 - acc: 0.9625 - val_loss: 0.1244 - val_acc: 0.9531
# Epoch 75/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1060 - acc: 0.9629 - val_loss: 0.1312 - val_acc: 0.9516
# Epoch 76/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1253 - acc: 0.9598 - val_loss: 0.1354 - val_acc: 0.9500
# Epoch 77/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1101 - acc: 0.9652 - val_loss: 0.1242 - val_acc: 0.9547
# Epoch 78/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1260 - acc: 0.9512 - val_loss: 0.1417 - val_acc: 0.9547
# Epoch 79/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1475 - acc: 0.9465 - val_loss: 0.1415 - val_acc: 0.9453
# Epoch 80/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1329 - acc: 0.9555 - val_loss: 0.1433 - val_acc: 0.9484
# Epoch 81/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1300 - acc: 0.9602 - val_loss: 0.1353 - val_acc: 0.9437
# Epoch 82/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1186 - acc: 0.9582 - val_loss: 0.1386 - val_acc: 0.9563
# Epoch 83/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1074 - acc: 0.9660 - val_loss: 0.1315 - val_acc: 0.9609
# Epoch 84/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1025 - acc: 0.9668 - val_loss: 0.1217 - val_acc: 0.9594
# Epoch 85/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1052 - acc: 0.9648 - val_loss: 0.1213 - val_acc: 0.9656
# Epoch 86/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0958 - acc: 0.9688 - val_loss: 0.1219 - val_acc: 0.9703
# Epoch 87/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1066 - acc: 0.9660 - val_loss: 0.1294 - val_acc: 0.9609
# Epoch 88/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.1068 - acc: 0.9652 - val_loss: 0.1123 - val_acc: 0.9609
# Epoch 89/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0976 - acc: 0.9664 - val_loss: 0.1226 - val_acc: 0.9578
# Epoch 90/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0922 - acc: 0.9699 - val_loss: 0.1193 - val_acc: 0.9547
# Epoch 91/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0917 - acc: 0.9711 - val_loss: 0.1068 - val_acc: 0.9578
# Epoch 92/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0854 - acc: 0.9719 - val_loss: 0.1076 - val_acc: 0.9641
# Epoch 93/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0917 - acc: 0.9660 - val_loss: 0.1113 - val_acc: 0.9625
# Epoch 94/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0933 - acc: 0.9699 - val_loss: 0.1131 - val_acc: 0.9641
# Epoch 95/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0869 - acc: 0.9680 - val_loss: 0.1202 - val_acc: 0.9609
# Epoch 96/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0849 - acc: 0.9742 - val_loss: 0.1136 - val_acc: 0.9688
# Epoch 97/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0969 - acc: 0.9684 - val_loss: 0.1204 - val_acc: 0.9563
# Epoch 98/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0832 - acc: 0.9766 - val_loss: 0.0980 - val_acc: 0.9672
# Epoch 99/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0813 - acc: 0.9691 - val_loss: 0.1040 - val_acc: 0.9641
# Epoch 100/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0832 - acc: 0.9711 - val_loss: 0.1013 - val_acc: 0.9672
# Epoch 101/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0801 - acc: 0.9719 - val_loss: 0.0990 - val_acc: 0.9641
# Epoch 102/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0742 - acc: 0.9766 - val_loss: 0.1026 - val_acc: 0.9641
# Epoch 103/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0773 - acc: 0.9742 - val_loss: 0.1025 - val_acc: 0.9672
# Epoch 104/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0752 - acc: 0.9742 - val_loss: 0.0973 - val_acc: 0.9656
# Epoch 105/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0746 - acc: 0.9762 - val_loss: 0.0978 - val_acc: 0.9688
# Epoch 106/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0719 - acc: 0.9770 - val_loss: 0.1013 - val_acc: 0.9656
# Epoch 107/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0807 - acc: 0.9699 - val_loss: 0.1044 - val_acc: 0.9656
# Epoch 108/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0773 - acc: 0.9746 - val_loss: 0.0994 - val_acc: 0.9688
# Epoch 109/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0691 - acc: 0.9805 - val_loss: 0.0996 - val_acc: 0.9656
# Epoch 110/110
# 2560/2560 [==============================] - 3s 1ms/step - loss: 0.0706 - acc: 0.9770 - val_loss: 0.0925 - val_acc: 0.9641

# %%
# model accuracy on training and testing sets

if include_spatial:
    train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
    test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)
else:
    train_loss, train_acc = cnn.evaluate({"spectra":cube_train2}, cube_train_labels)
    test_loss, test_acc = cnn.evaluate({"spectra":cube_test2}, cube_test_labels)
    
print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 1s 9ms/step - loss: 0.0455 - accuracy: 0.9887
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0967 - accuracy: 0.9656
# 0.9886718988418579 0.965624988079071

# %% [markdown]
# ### Predict pixel classification on all of Scene 1-a

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])

start_time = time.time()

if include_spatial:
    probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})
else:
    probCube = cnn.predict({"spectra":cube_standard_1})
    
predictCube = probCube.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:22:38

# %%
# -- Plot the prediction map of Scene 1-a

predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 1-a

# %%
# -- create the prediction arrays from the predictions of the testing set

labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# -- create the true arrays from the labeled testing set

labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-a

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 120   0   0   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 195   2   0   1   6]
#  [  0   0   0   0   1  97   0   0   2]
#  [  0   0   0   0   0   0   4   0   2]
#  [  0   0   0   0   0   3   0  16   1]
#  [  0   0   0   0   3   0   0   0  17]]
#
# Accuracy Score
# 0.965625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      1.00      1.00       120
#       water       1.00      1.00      1.00        10
#       built       0.98      0.96      0.97       204
#     windows       0.95      0.97      0.96       100
#       roads       1.00      0.67      0.80         6
#        cars       0.94      0.80      0.86        20
#       metal       0.61      0.85      0.71        20
#
# avg / total       0.97      0.97      0.97       640

# %% [markdown]
# ### CNN Features

# %%
cnn.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# spectra (InputLayer)            (None, 848, 1)       0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 848, 16)      816         spectra[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 424, 16)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 424, 32)      25632       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 212, 32)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 212, 32)      0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 6784)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# spatial (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6786)         0           flatten_2[0][0]
#                                                                  spatial[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          3474944     concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 9)            4617        dense_3[0][0]
# ==================================================================================================
# Total params: 3,506,009
# Trainable params: 3,506,009
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ---
# # The Following parts allow for a model trained on Scene 1-a to be transferred to Scene 1-b and Scene 2
#
# ## spatial features cannot be included in this model, rerun model on Scene 1-a with include_spatial = False if not done so

# %% [markdown]
# ---
# ## Transfer model trained on Scene 1-a to predict Scene 1-b

# %%
start_time = time.time()

if include_spatial:
    probCube0 = cnn.predict({"spectra":cube_standard0_1})
    predictCube0 = probCube0.argmax(axis=-1)
else:
    print("!!! ERROR: cannot transfer a model with spatial included")

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

# %%
# -- Plot the prediction map of Scene 1-b from transferred model

predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics (Model trained on Scene 1-a transferred to 1-b)

# %%
# -- create the prediction arrays from the predictions of the testing set

wtr_coords0=np.array([[0,0]])
labels0_pred_sky = predictCube_reshape0[sky_coords0[:, 0], sky_coords0[:, 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[:, 0], clouds_coords0[:,1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[:,0], veg_coords0[:,1]]
labels0_pred_wtr = predictCube_reshape0[wtr_coords0[:,0], wtr_coords0[:,1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[:,0], blt_coords0[:,1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[:,0], windows_coords0[:,1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[:,0], rds_coords0[:,1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[:,0], cars_coords0[:,1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[:,0], mtl_coords0[:,1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# -- create the true arrays from the labeled testing set

labels0_true_sky = np.full((sky_coords0.shape[0]), 0)
labels0_true_clouds = np.full((clouds_coords0.shape[0]), 1)
labels0_true_veg = np.full((veg_coords0.shape[0]), 2)
labels0_true_wtr = np.full((wtr_coords0.shape[0]), 3)
labels0_true_blt = np.full((blt_coords0.shape[0]), 4)
labels0_true_windows = np.full((windows_coords0.shape[0]), 5)
labels0_true_rds = np.full((rds_coords0.shape[0]), 6)
labels0_true_cars = np.full((cars_coords0.shape[0]), 7)
labels0_true_mtl = np.full((mtl_coords0.shape[0]), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-b

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))

# %% [markdown]
# ---
# ## Transfer Model trained on Scene 1-a to predict Scene 2

# %%
# classify entire binned cube
import time
start_time = time.time()

if include_spatial:
    probCuben = cnn.predict({"spectra":cube_standardn_1})
    predictCuben = probCuben.argmax(axis=-1)
else:
    print("!!! ERROR: cannot transfer a model with spatial included")

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

# %%
# -- Plot the prediction map of Scene 2 from transferred model

predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics (Model trained on Scene 1-a transferred to 2)

# %%
# -- create the prediction arrays from the predictions of the testing set

labelsn_pred_sky = predictCube_reshapen[sky_coordsn[:, 0], sky_coordsn[:, 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[:, 0], clouds_coordsn[:,1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[:,0], veg_coordsn[:,1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[:,0], wtr_coordsn[:,1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[:,0], blt_coordsn[:,1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[:,0], windows_coordsn[:,1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[:,0], rds_coordsn[:,1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[:,0], cars_coordsn[:,1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[:,0], mtl_coordsn[:,1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# -- create the true arrays from the labeled testing set

labelsn_true_sky = np.full((sky_coordsn.shape[0]), 0)
labelsn_true_clouds = np.full((clouds_coordsn.shape[0]), 1)
labelsn_true_veg = np.full((veg_coordsn.shape[0]), 2)
labelsn_true_wtr = np.full((wtr_coordsn.shape[0]), 3)
labelsn_true_blt = np.full((blt_coordsn.shape[0]), 4)
labelsn_true_windows = np.full((windows_coordsn.shape[0]), 5)
labelsn_true_rds = np.full((rds_coordsn.shape[0]), 6)
labelsn_true_cars = np.full((cars_coordsn.shape[0]), 7)
labelsn_true_mtl = np.full((mtl_coordsn.shape[0]), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 2

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
