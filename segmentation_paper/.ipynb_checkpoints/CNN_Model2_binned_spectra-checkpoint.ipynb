# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 15
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 15
# [[0, 56], [56, 112], [112, 168], [168, 224], [224, 280], [280, 336], [336, 392], [392, 448], [448, 504], [504, 560], [560, 616], [616, 672], [672, 728], [728, 784], [784, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 15)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 15)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 15) (60, 15)
# clouds  (400, 15) (100, 15)
# vegetation  (480, 15) (120, 15)
# water  (40, 15) (10, 15)
# built  (816, 15) (204, 15)
# windows  (400, 15) (100, 15)
# roads  (24, 15) (6, 15)
# cars  (80, 15) (20, 15)
# metal  (80, 15) (20, 15)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 15) (2560,) (2560, 2)
# (640, 15) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 73ms/step - loss: 2.1193 - accuracy: 0.2773 - val_loss: 1.9887 - val_accuracy: 0.3187
# Epoch 2/200
# 5/5 [==============================] - 0s 31ms/step - loss: 1.9021 - accuracy: 0.3301 - val_loss: 1.7671 - val_accuracy: 0.3187
# Epoch 3/200
# 5/5 [==============================] - 0s 37ms/step - loss: 1.7465 - accuracy: 0.3285 - val_loss: 1.6746 - val_accuracy: 0.3187
# Epoch 4/200
# 5/5 [==============================] - 0s 34ms/step - loss: 1.6551 - accuracy: 0.4430 - val_loss: 1.5611 - val_accuracy: 0.6281
# Epoch 5/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.5341 - accuracy: 0.5816 - val_loss: 1.4000 - val_accuracy: 0.6438
# Epoch 6/200
# 5/5 [==============================] - 0s 28ms/step - loss: 1.3800 - accuracy: 0.6109 - val_loss: 1.2284 - val_accuracy: 0.6562
# Epoch 7/200
# 5/5 [==============================] - 0s 28ms/step - loss: 1.2256 - accuracy: 0.6387 - val_loss: 1.0762 - val_accuracy: 0.6547
# Epoch 8/200
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0946 - accuracy: 0.6531 - val_loss: 0.9641 - val_accuracy: 0.6625
# Epoch 9/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.9891 - accuracy: 0.6730 - val_loss: 0.8844 - val_accuracy: 0.7016
# Epoch 10/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.9133 - accuracy: 0.6898 - val_loss: 0.8222 - val_accuracy: 0.7359
# Epoch 11/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.8584 - accuracy: 0.7086 - val_loss: 0.7753 - val_accuracy: 0.7141
# Epoch 12/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.8091 - accuracy: 0.7234 - val_loss: 0.7364 - val_accuracy: 0.7375
# Epoch 13/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.7699 - accuracy: 0.7609 - val_loss: 0.7042 - val_accuracy: 0.7531
# Epoch 14/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7376 - accuracy: 0.7652 - val_loss: 0.6720 - val_accuracy: 0.7891
# Epoch 15/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.7100 - accuracy: 0.7785 - val_loss: 0.6482 - val_accuracy: 0.7922
# Epoch 16/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6885 - accuracy: 0.8004 - val_loss: 0.6323 - val_accuracy: 0.7891
# Epoch 17/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.6621 - accuracy: 0.7988 - val_loss: 0.6132 - val_accuracy: 0.8156
# Epoch 18/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6451 - accuracy: 0.8047 - val_loss: 0.5884 - val_accuracy: 0.8062
# Epoch 19/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.6270 - accuracy: 0.8102 - val_loss: 0.5709 - val_accuracy: 0.8047
# Epoch 20/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6069 - accuracy: 0.8129 - val_loss: 0.5559 - val_accuracy: 0.8188
# Epoch 21/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5998 - accuracy: 0.8070 - val_loss: 0.5431 - val_accuracy: 0.8172
# Epoch 22/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5795 - accuracy: 0.8207 - val_loss: 0.5332 - val_accuracy: 0.8344
# Epoch 23/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5642 - accuracy: 0.8234 - val_loss: 0.5159 - val_accuracy: 0.8188
# Epoch 24/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5500 - accuracy: 0.8281 - val_loss: 0.5062 - val_accuracy: 0.8234
# Epoch 25/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5295 - accuracy: 0.8270 - val_loss: 0.4973 - val_accuracy: 0.8266
# Epoch 26/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5193 - accuracy: 0.8340 - val_loss: 0.4840 - val_accuracy: 0.8219
# Epoch 27/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5135 - accuracy: 0.8355 - val_loss: 0.4807 - val_accuracy: 0.8625
# Epoch 28/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.5043 - accuracy: 0.8406 - val_loss: 0.4663 - val_accuracy: 0.8578
# Epoch 29/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4954 - accuracy: 0.8547 - val_loss: 0.4593 - val_accuracy: 0.8359
# Epoch 30/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4878 - accuracy: 0.8492 - val_loss: 0.4516 - val_accuracy: 0.8703
# Epoch 31/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4783 - accuracy: 0.8574 - val_loss: 0.4386 - val_accuracy: 0.8641
# Epoch 32/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4732 - accuracy: 0.8547 - val_loss: 0.4333 - val_accuracy: 0.8766
# Epoch 33/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4552 - accuracy: 0.8629 - val_loss: 0.4228 - val_accuracy: 0.8594
# Epoch 34/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4548 - accuracy: 0.8668 - val_loss: 0.4144 - val_accuracy: 0.8813
# Epoch 35/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4471 - accuracy: 0.8641 - val_loss: 0.4124 - val_accuracy: 0.8828
# Epoch 36/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4477 - accuracy: 0.8641 - val_loss: 0.4066 - val_accuracy: 0.8813
# Epoch 37/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4388 - accuracy: 0.8715 - val_loss: 0.4015 - val_accuracy: 0.8797
# Epoch 38/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4333 - accuracy: 0.8703 - val_loss: 0.3917 - val_accuracy: 0.8844
# Epoch 39/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4333 - accuracy: 0.8695 - val_loss: 0.4011 - val_accuracy: 0.8734
# Epoch 40/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4286 - accuracy: 0.8691 - val_loss: 0.3886 - val_accuracy: 0.8844
# Epoch 41/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4131 - accuracy: 0.8773 - val_loss: 0.3835 - val_accuracy: 0.8797
# Epoch 42/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4165 - accuracy: 0.8742 - val_loss: 0.3702 - val_accuracy: 0.8844
# Epoch 43/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3996 - accuracy: 0.8816 - val_loss: 0.3642 - val_accuracy: 0.8859
# Epoch 44/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3960 - accuracy: 0.8824 - val_loss: 0.3584 - val_accuracy: 0.8844
# Epoch 45/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3917 - accuracy: 0.8883 - val_loss: 0.3524 - val_accuracy: 0.8844
# Epoch 46/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3875 - accuracy: 0.8852 - val_loss: 0.3449 - val_accuracy: 0.8844
# Epoch 47/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3864 - accuracy: 0.8832 - val_loss: 0.3470 - val_accuracy: 0.8906
# Epoch 48/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3766 - accuracy: 0.8863 - val_loss: 0.3393 - val_accuracy: 0.8859
# Epoch 49/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3670 - accuracy: 0.8914 - val_loss: 0.3351 - val_accuracy: 0.8953
# Epoch 50/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3735 - accuracy: 0.8902 - val_loss: 0.3348 - val_accuracy: 0.8859
# Epoch 51/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3630 - accuracy: 0.8914 - val_loss: 0.3308 - val_accuracy: 0.8953
# Epoch 52/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3614 - accuracy: 0.8891 - val_loss: 0.3247 - val_accuracy: 0.8906
# Epoch 53/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3603 - accuracy: 0.8918 - val_loss: 0.3146 - val_accuracy: 0.8969
# Epoch 54/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3457 - accuracy: 0.8914 - val_loss: 0.3102 - val_accuracy: 0.8922
# Epoch 55/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3502 - accuracy: 0.8926 - val_loss: 0.3148 - val_accuracy: 0.8984
# Epoch 56/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3448 - accuracy: 0.8980 - val_loss: 0.3088 - val_accuracy: 0.8953
# Epoch 57/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3429 - accuracy: 0.9000 - val_loss: 0.3141 - val_accuracy: 0.8953
# Epoch 58/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3437 - accuracy: 0.8945 - val_loss: 0.2994 - val_accuracy: 0.8938
# Epoch 59/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3345 - accuracy: 0.8918 - val_loss: 0.3096 - val_accuracy: 0.9047
# Epoch 60/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3432 - accuracy: 0.8980 - val_loss: 0.2987 - val_accuracy: 0.9000
# Epoch 61/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3295 - accuracy: 0.8977 - val_loss: 0.2903 - val_accuracy: 0.9078
# Epoch 62/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3253 - accuracy: 0.8945 - val_loss: 0.2926 - val_accuracy: 0.8969
# Epoch 63/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3210 - accuracy: 0.9039 - val_loss: 0.2788 - val_accuracy: 0.9062
# Epoch 64/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3164 - accuracy: 0.9012 - val_loss: 0.2746 - val_accuracy: 0.9094
# Epoch 65/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3091 - accuracy: 0.9047 - val_loss: 0.2749 - val_accuracy: 0.9031
# Epoch 66/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3014 - accuracy: 0.9113 - val_loss: 0.2696 - val_accuracy: 0.9047
# Epoch 67/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3037 - accuracy: 0.9086 - val_loss: 0.2682 - val_accuracy: 0.9062
# Epoch 68/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3051 - accuracy: 0.9082 - val_loss: 0.2657 - val_accuracy: 0.9078
# Epoch 69/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2996 - accuracy: 0.9109 - val_loss: 0.2641 - val_accuracy: 0.9125
# Epoch 70/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3015 - accuracy: 0.9066 - val_loss: 0.2601 - val_accuracy: 0.9078
# Epoch 71/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2954 - accuracy: 0.9094 - val_loss: 0.2593 - val_accuracy: 0.9094
# Epoch 72/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2987 - accuracy: 0.9133 - val_loss: 0.2548 - val_accuracy: 0.9109
# Epoch 73/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2956 - accuracy: 0.9098 - val_loss: 0.2598 - val_accuracy: 0.9109
# Epoch 74/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2970 - accuracy: 0.9086 - val_loss: 0.2530 - val_accuracy: 0.9094
# Epoch 75/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2840 - accuracy: 0.9090 - val_loss: 0.2522 - val_accuracy: 0.9109
# Epoch 76/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2874 - accuracy: 0.9105 - val_loss: 0.2508 - val_accuracy: 0.9187
# Epoch 77/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2749 - accuracy: 0.9145 - val_loss: 0.2421 - val_accuracy: 0.9156
# Epoch 78/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2773 - accuracy: 0.9129 - val_loss: 0.2445 - val_accuracy: 0.9125
# Epoch 79/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2699 - accuracy: 0.9176 - val_loss: 0.2415 - val_accuracy: 0.9187
# Epoch 80/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2789 - accuracy: 0.9117 - val_loss: 0.2369 - val_accuracy: 0.9125
# Epoch 81/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2736 - accuracy: 0.9176 - val_loss: 0.2412 - val_accuracy: 0.9172
# Epoch 82/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2657 - accuracy: 0.9168 - val_loss: 0.2290 - val_accuracy: 0.9172
# Epoch 83/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2679 - accuracy: 0.9125 - val_loss: 0.2313 - val_accuracy: 0.9187
# Epoch 84/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2630 - accuracy: 0.9180 - val_loss: 0.2264 - val_accuracy: 0.9156
# Epoch 85/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2678 - accuracy: 0.9160 - val_loss: 0.2237 - val_accuracy: 0.9156
# Epoch 86/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2638 - accuracy: 0.9191 - val_loss: 0.2242 - val_accuracy: 0.9219
# Epoch 87/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2559 - accuracy: 0.9203 - val_loss: 0.2179 - val_accuracy: 0.9187
# Epoch 88/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2502 - accuracy: 0.9152 - val_loss: 0.2176 - val_accuracy: 0.9234
# Epoch 89/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2552 - accuracy: 0.9187 - val_loss: 0.2172 - val_accuracy: 0.9187
# Epoch 90/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2552 - accuracy: 0.9180 - val_loss: 0.2186 - val_accuracy: 0.9187
# Epoch 91/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2463 - accuracy: 0.9187 - val_loss: 0.2127 - val_accuracy: 0.9219
# Epoch 92/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2501 - accuracy: 0.9176 - val_loss: 0.2160 - val_accuracy: 0.9219
# Epoch 93/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2414 - accuracy: 0.9184 - val_loss: 0.2153 - val_accuracy: 0.9187
# Epoch 94/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2398 - accuracy: 0.9160 - val_loss: 0.2095 - val_accuracy: 0.9312
# Epoch 95/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2406 - accuracy: 0.9199 - val_loss: 0.2126 - val_accuracy: 0.9172
# Epoch 96/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2406 - accuracy: 0.9242 - val_loss: 0.2085 - val_accuracy: 0.9297
# Epoch 97/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2441 - accuracy: 0.9187 - val_loss: 0.2048 - val_accuracy: 0.9203
# Epoch 98/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2375 - accuracy: 0.9258 - val_loss: 0.2087 - val_accuracy: 0.9312
# Epoch 99/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2390 - accuracy: 0.9227 - val_loss: 0.1995 - val_accuracy: 0.9250
# Epoch 100/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2308 - accuracy: 0.9230 - val_loss: 0.2007 - val_accuracy: 0.9297
# Epoch 101/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2401 - accuracy: 0.9164 - val_loss: 0.1964 - val_accuracy: 0.9281
# Epoch 102/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2371 - accuracy: 0.9227 - val_loss: 0.1996 - val_accuracy: 0.9297
# Epoch 103/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2337 - accuracy: 0.9230 - val_loss: 0.1954 - val_accuracy: 0.9297
# Epoch 104/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2309 - accuracy: 0.9215 - val_loss: 0.2014 - val_accuracy: 0.9281
# Epoch 105/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2358 - accuracy: 0.9168 - val_loss: 0.1954 - val_accuracy: 0.9297
# Epoch 106/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2318 - accuracy: 0.9191 - val_loss: 0.1920 - val_accuracy: 0.9312
# Epoch 107/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2295 - accuracy: 0.9211 - val_loss: 0.1926 - val_accuracy: 0.9344
# Epoch 108/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2227 - accuracy: 0.9254 - val_loss: 0.2019 - val_accuracy: 0.9219
# Epoch 109/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2325 - accuracy: 0.9234 - val_loss: 0.1904 - val_accuracy: 0.9312
# Epoch 110/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2201 - accuracy: 0.9289 - val_loss: 0.1907 - val_accuracy: 0.9375
# Epoch 111/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2273 - accuracy: 0.9223 - val_loss: 0.1883 - val_accuracy: 0.9297
# Epoch 112/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2217 - accuracy: 0.9246 - val_loss: 0.1946 - val_accuracy: 0.9375
# Epoch 113/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2219 - accuracy: 0.9238 - val_loss: 0.1878 - val_accuracy: 0.9328
# Epoch 114/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2216 - accuracy: 0.9223 - val_loss: 0.1876 - val_accuracy: 0.9312
# Epoch 115/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2133 - accuracy: 0.9254 - val_loss: 0.1793 - val_accuracy: 0.9328
# Epoch 116/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2128 - accuracy: 0.9273 - val_loss: 0.1798 - val_accuracy: 0.9359
# Epoch 117/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2179 - accuracy: 0.9281 - val_loss: 0.1802 - val_accuracy: 0.9359
# Epoch 118/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2210 - accuracy: 0.9281 - val_loss: 0.1796 - val_accuracy: 0.9406
# Epoch 119/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2095 - accuracy: 0.9281 - val_loss: 0.1758 - val_accuracy: 0.9312
# Epoch 120/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2115 - accuracy: 0.9273 - val_loss: 0.1794 - val_accuracy: 0.9375
# Epoch 121/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2006 - accuracy: 0.9312 - val_loss: 0.1710 - val_accuracy: 0.9344
# Epoch 122/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2064 - accuracy: 0.9270 - val_loss: 0.1794 - val_accuracy: 0.9375
# Epoch 123/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2104 - accuracy: 0.9242 - val_loss: 0.1726 - val_accuracy: 0.9375
# Epoch 124/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2052 - accuracy: 0.9309 - val_loss: 0.1757 - val_accuracy: 0.9422
# Epoch 125/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2043 - accuracy: 0.9316 - val_loss: 0.1757 - val_accuracy: 0.9312
# Epoch 126/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2035 - accuracy: 0.9277 - val_loss: 0.1734 - val_accuracy: 0.9484
# Epoch 127/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1927 - accuracy: 0.9352 - val_loss: 0.1690 - val_accuracy: 0.9484
# Epoch 128/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2000 - accuracy: 0.9305 - val_loss: 0.1709 - val_accuracy: 0.9406
# Epoch 129/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2017 - accuracy: 0.9309 - val_loss: 0.1686 - val_accuracy: 0.9406
# Epoch 130/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2025 - accuracy: 0.9359 - val_loss: 0.1744 - val_accuracy: 0.9438
# Epoch 131/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2024 - accuracy: 0.9312 - val_loss: 0.1673 - val_accuracy: 0.9344
# Epoch 132/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1984 - accuracy: 0.9270 - val_loss: 0.1648 - val_accuracy: 0.9422
# Epoch 133/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2051 - accuracy: 0.9312 - val_loss: 0.1826 - val_accuracy: 0.9375
# Epoch 134/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1988 - accuracy: 0.9312 - val_loss: 0.1715 - val_accuracy: 0.9375
# Epoch 135/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2015 - accuracy: 0.9320 - val_loss: 0.1719 - val_accuracy: 0.9453
# Epoch 136/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1918 - accuracy: 0.9363 - val_loss: 0.1675 - val_accuracy: 0.9375
# Epoch 137/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1986 - accuracy: 0.9371 - val_loss: 0.1686 - val_accuracy: 0.9406
# Epoch 138/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1956 - accuracy: 0.9371 - val_loss: 0.1769 - val_accuracy: 0.9453
# Epoch 139/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2001 - accuracy: 0.9293 - val_loss: 0.1619 - val_accuracy: 0.9391
# Epoch 140/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1951 - accuracy: 0.9309 - val_loss: 0.1614 - val_accuracy: 0.9500
# Epoch 141/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1948 - accuracy: 0.9324 - val_loss: 0.1572 - val_accuracy: 0.9484
# Epoch 142/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1872 - accuracy: 0.9371 - val_loss: 0.1573 - val_accuracy: 0.9516
# Epoch 143/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1912 - accuracy: 0.9359 - val_loss: 0.1622 - val_accuracy: 0.9469
# Epoch 144/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1880 - accuracy: 0.9375 - val_loss: 0.1567 - val_accuracy: 0.9516
# Epoch 145/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1824 - accuracy: 0.9391 - val_loss: 0.1597 - val_accuracy: 0.9516
# Epoch 146/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1850 - accuracy: 0.9348 - val_loss: 0.1539 - val_accuracy: 0.9578
# Epoch 147/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1878 - accuracy: 0.9383 - val_loss: 0.1647 - val_accuracy: 0.9484
# Epoch 148/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1821 - accuracy: 0.9375 - val_loss: 0.1510 - val_accuracy: 0.9484
# Epoch 149/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1748 - accuracy: 0.9406 - val_loss: 0.1497 - val_accuracy: 0.9531
# Epoch 150/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1783 - accuracy: 0.9383 - val_loss: 0.1477 - val_accuracy: 0.9563
# Epoch 151/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1759 - accuracy: 0.9438 - val_loss: 0.1486 - val_accuracy: 0.9484
# Epoch 152/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1745 - accuracy: 0.9402 - val_loss: 0.1448 - val_accuracy: 0.9531
# Epoch 153/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1752 - accuracy: 0.9391 - val_loss: 0.1537 - val_accuracy: 0.9500
# Epoch 154/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1802 - accuracy: 0.9383 - val_loss: 0.1444 - val_accuracy: 0.9563
# Epoch 155/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1762 - accuracy: 0.9410 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 156/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1763 - accuracy: 0.9391 - val_loss: 0.1544 - val_accuracy: 0.9563
# Epoch 157/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1776 - accuracy: 0.9406 - val_loss: 0.1470 - val_accuracy: 0.9563
# Epoch 158/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1777 - accuracy: 0.9395 - val_loss: 0.1457 - val_accuracy: 0.9547
# Epoch 159/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1725 - accuracy: 0.9473 - val_loss: 0.1534 - val_accuracy: 0.9484
# Epoch 160/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1786 - accuracy: 0.9406 - val_loss: 0.1423 - val_accuracy: 0.9563
# Epoch 161/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1689 - accuracy: 0.9383 - val_loss: 0.1389 - val_accuracy: 0.9578
# Epoch 162/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1742 - accuracy: 0.9422 - val_loss: 0.1405 - val_accuracy: 0.9578
# Epoch 163/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1726 - accuracy: 0.9402 - val_loss: 0.1483 - val_accuracy: 0.9531
# Epoch 164/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1683 - accuracy: 0.9414 - val_loss: 0.1450 - val_accuracy: 0.9563
# Epoch 165/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1672 - accuracy: 0.9422 - val_loss: 0.1432 - val_accuracy: 0.9484
# Epoch 166/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1735 - accuracy: 0.9430 - val_loss: 0.1450 - val_accuracy: 0.9563
# Epoch 167/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1733 - accuracy: 0.9406 - val_loss: 0.1502 - val_accuracy: 0.9531
# Epoch 168/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1877 - accuracy: 0.9383 - val_loss: 0.1708 - val_accuracy: 0.9484
# Epoch 169/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1812 - accuracy: 0.9410 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 170/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1600 - accuracy: 0.9453 - val_loss: 0.1445 - val_accuracy: 0.9547
# Epoch 171/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1683 - accuracy: 0.9438 - val_loss: 0.1363 - val_accuracy: 0.9563
# Epoch 172/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1611 - accuracy: 0.9426 - val_loss: 0.1398 - val_accuracy: 0.9563
# Epoch 173/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1599 - accuracy: 0.9453 - val_loss: 0.1406 - val_accuracy: 0.9578
# Epoch 174/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1628 - accuracy: 0.9422 - val_loss: 0.1341 - val_accuracy: 0.9578
# Epoch 175/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1530 - accuracy: 0.9496 - val_loss: 0.1420 - val_accuracy: 0.9516
# Epoch 176/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1604 - accuracy: 0.9488 - val_loss: 0.1334 - val_accuracy: 0.9531
# Epoch 177/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1579 - accuracy: 0.9461 - val_loss: 0.1326 - val_accuracy: 0.9594
# Epoch 178/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1612 - accuracy: 0.9430 - val_loss: 0.1325 - val_accuracy: 0.9594
# Epoch 179/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1581 - accuracy: 0.9453 - val_loss: 0.1346 - val_accuracy: 0.9563
# Epoch 180/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1590 - accuracy: 0.9496 - val_loss: 0.1456 - val_accuracy: 0.9594
# Epoch 181/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1622 - accuracy: 0.9453 - val_loss: 0.1288 - val_accuracy: 0.9578
# Epoch 182/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1610 - accuracy: 0.9430 - val_loss: 0.1357 - val_accuracy: 0.9578
# Epoch 183/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1583 - accuracy: 0.9461 - val_loss: 0.1283 - val_accuracy: 0.9594
# Epoch 184/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1518 - accuracy: 0.9438 - val_loss: 0.1403 - val_accuracy: 0.9578
# Epoch 185/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1549 - accuracy: 0.9469 - val_loss: 0.1295 - val_accuracy: 0.9547
# Epoch 186/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1541 - accuracy: 0.9469 - val_loss: 0.1278 - val_accuracy: 0.9578
# Epoch 187/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1542 - accuracy: 0.9484 - val_loss: 0.1314 - val_accuracy: 0.9594
# Epoch 188/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1572 - accuracy: 0.9480 - val_loss: 0.1279 - val_accuracy: 0.9531
# Epoch 189/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1542 - accuracy: 0.9465 - val_loss: 0.1268 - val_accuracy: 0.9594
# Epoch 190/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1536 - accuracy: 0.9438 - val_loss: 0.1312 - val_accuracy: 0.9594
# Epoch 191/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1532 - accuracy: 0.9480 - val_loss: 0.1252 - val_accuracy: 0.9625
# Epoch 192/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1476 - accuracy: 0.9504 - val_loss: 0.1226 - val_accuracy: 0.9531
# Epoch 193/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1493 - accuracy: 0.9461 - val_loss: 0.1368 - val_accuracy: 0.9500
# Epoch 194/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1502 - accuracy: 0.9477 - val_loss: 0.1244 - val_accuracy: 0.9609
# Epoch 195/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1465 - accuracy: 0.9520 - val_loss: 0.1249 - val_accuracy: 0.9578
# Epoch 196/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1494 - accuracy: 0.9484 - val_loss: 0.1238 - val_accuracy: 0.9547
# Epoch 197/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1496 - accuracy: 0.9508 - val_loss: 0.1254 - val_accuracy: 0.9594
# Epoch 198/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1504 - accuracy: 0.9531 - val_loss: 0.1239 - val_accuracy: 0.9625
# Epoch 199/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1425 - accuracy: 0.9496 - val_loss: 0.1217 - val_accuracy: 0.9594
# Epoch 200/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1441 - accuracy: 0.9508 - val_loss: 0.1193 - val_accuracy: 0.9688

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 0s 54ms/step - loss: 2.1671 - accuracy: 0.2266 - val_loss: 2.0622 - val_accuracy: 0.3703
# Epoch 2/40
# 5/5 [==============================] - 0s 32ms/step - loss: 1.9758 - accuracy: 0.3543 - val_loss: 1.8365 - val_accuracy: 0.3187
# Epoch 3/40
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7827 - accuracy: 0.3215 - val_loss: 1.7199 - val_accuracy: 0.3187
# Epoch 4/40
# 5/5 [==============================] - 0s 27ms/step - loss: 1.7082 - accuracy: 0.3688 - val_loss: 1.6173 - val_accuracy: 0.5844
# Epoch 5/40
# 5/5 [==============================] - 0s 27ms/step - loss: 1.6009 - accuracy: 0.5520 - val_loss: 1.4861 - val_accuracy: 0.6031
# Epoch 6/40
# 5/5 [==============================] - 0s 27ms/step - loss: 1.4627 - accuracy: 0.5629 - val_loss: 1.3262 - val_accuracy: 0.6062
# Epoch 7/40
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3188 - accuracy: 0.5992 - val_loss: 1.1741 - val_accuracy: 0.6562
# Epoch 8/40
# 5/5 [==============================] - 0s 30ms/step - loss: 1.1801 - accuracy: 0.6469 - val_loss: 1.0513 - val_accuracy: 0.6562
# Epoch 9/40
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0647 - accuracy: 0.6551 - val_loss: 0.9511 - val_accuracy: 0.6562
# Epoch 10/40
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9687 - accuracy: 0.6684 - val_loss: 0.8703 - val_accuracy: 0.6953
# Epoch 11/40
# 5/5 [==============================] - 0s 24ms/step - loss: 0.8910 - accuracy: 0.6965 - val_loss: 0.8058 - val_accuracy: 0.7437
# Epoch 12/40
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8363 - accuracy: 0.7148 - val_loss: 0.7512 - val_accuracy: 0.7453
# Epoch 13/40
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7886 - accuracy: 0.7375 - val_loss: 0.7095 - val_accuracy: 0.7656
# Epoch 14/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.7526 - accuracy: 0.7598 - val_loss: 0.6800 - val_accuracy: 0.7812
# Epoch 15/40
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7094 - accuracy: 0.7734 - val_loss: 0.6552 - val_accuracy: 0.7906
# Epoch 16/40
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6924 - accuracy: 0.7887 - val_loss: 0.6297 - val_accuracy: 0.7906
# Epoch 17/40
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6686 - accuracy: 0.7895 - val_loss: 0.6091 - val_accuracy: 0.7969
# Epoch 18/40
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6469 - accuracy: 0.8059 - val_loss: 0.5976 - val_accuracy: 0.8188
# Epoch 19/40
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6323 - accuracy: 0.8000 - val_loss: 0.5760 - val_accuracy: 0.8000
# Epoch 20/40
# 5/5 [==============================] - 0s 28ms/step - loss: 0.6137 - accuracy: 0.8031 - val_loss: 0.5618 - val_accuracy: 0.8219
# Epoch 21/40
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6140 - accuracy: 0.7977 - val_loss: 0.5471 - val_accuracy: 0.8172
# Epoch 22/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5783 - accuracy: 0.8191 - val_loss: 0.5325 - val_accuracy: 0.8141
# Epoch 23/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5673 - accuracy: 0.8207 - val_loss: 0.5231 - val_accuracy: 0.8250
# Epoch 24/40
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5633 - accuracy: 0.8191 - val_loss: 0.5213 - val_accuracy: 0.8469
# Epoch 25/40
# 5/5 [==============================] - 0s 35ms/step - loss: 0.5360 - accuracy: 0.8336 - val_loss: 0.4993 - val_accuracy: 0.8234
# Epoch 26/40
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5281 - accuracy: 0.8285 - val_loss: 0.4937 - val_accuracy: 0.8297
# Epoch 27/40
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5340 - accuracy: 0.8301 - val_loss: 0.4931 - val_accuracy: 0.8500
# Epoch 28/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5226 - accuracy: 0.8371 - val_loss: 0.4841 - val_accuracy: 0.8406
# Epoch 29/40
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5086 - accuracy: 0.8383 - val_loss: 0.4604 - val_accuracy: 0.8375
# Epoch 30/40
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4981 - accuracy: 0.8445 - val_loss: 0.4592 - val_accuracy: 0.8703
# Epoch 31/40
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4983 - accuracy: 0.8500 - val_loss: 0.4668 - val_accuracy: 0.8422
# Epoch 32/40
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4976 - accuracy: 0.8449 - val_loss: 0.4581 - val_accuracy: 0.8516
# Epoch 33/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4783 - accuracy: 0.8574 - val_loss: 0.4337 - val_accuracy: 0.8531
# Epoch 34/40
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4626 - accuracy: 0.8645 - val_loss: 0.4280 - val_accuracy: 0.8766
# Epoch 35/40
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4513 - accuracy: 0.8645 - val_loss: 0.4167 - val_accuracy: 0.8844
# Epoch 36/40
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4555 - accuracy: 0.8641 - val_loss: 0.4106 - val_accuracy: 0.8828
# Epoch 37/40
# 5/5 [==============================] - 0s 34ms/step - loss: 0.4359 - accuracy: 0.8758 - val_loss: 0.4029 - val_accuracy: 0.8828
# Epoch 38/40
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4453 - accuracy: 0.8605 - val_loss: 0.3935 - val_accuracy: 0.8906
# Epoch 39/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4283 - accuracy: 0.8754 - val_loss: 0.3897 - val_accuracy: 0.8906
# Epoch 40/40
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4203 - accuracy: 0.8707 - val_loss: 0.3801 - val_accuracy: 0.8891

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8945
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3801 - accuracy: 0.8891
# 0.89453125 0.8890625238418579

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 15, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:58

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 58   0   0   0   2   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 117   0   3   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  2   0   0   0 195   7   0   0   0]
#  [  0   0   0   0  11  89   0   0   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   9  11   0   0   0]
#  [  0   0   0   0  15   5   0   0   0]]
#
# Accuracy Score
# 0.8890625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.97      0.97      0.97        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.97      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.81      0.96      0.88       204
#     windows       0.79      0.89      0.84       100
#       roads       0.00      0.00      0.00         6
#        cars       0.00      0.00      0.00        20
#       metal       0.00      0.00      0.00        20
#
# avg / total       0.83      0.89      0.86       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 15)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 15)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 15) (80, 15)
# clouds  (400, 15) (100, 15)
# vegetation  (488, 15) (122, 15)
# built  (960, 15) (240, 15)
# windows  (400, 15) (100, 15)
# roads  (48, 15) (12, 15)
# cars  (44, 15) (11, 15)
# metal  (184, 15) (46, 15)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 15) (2844,) (2844, 2)
# (711, 15) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 52ms/step - loss: 2.0898 - accuracy: 0.3087 - val_loss: 1.9276 - val_accuracy: 0.3376
# Epoch 2/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.8307 - accuracy: 0.3376 - val_loss: 1.7201 - val_accuracy: 0.3376
# Epoch 3/200
# 6/6 [==============================] - 0s 35ms/step - loss: 1.6912 - accuracy: 0.3379 - val_loss: 1.6026 - val_accuracy: 0.3390
# Epoch 4/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.5696 - accuracy: 0.4754 - val_loss: 1.4755 - val_accuracy: 0.5331
# Epoch 5/200
# 6/6 [==============================] - 0s 25ms/step - loss: 1.4326 - accuracy: 0.5193 - val_loss: 1.3113 - val_accuracy: 0.5879
# Epoch 6/200
# 6/6 [==============================] - 0s 27ms/step - loss: 1.2673 - accuracy: 0.6220 - val_loss: 1.1345 - val_accuracy: 0.6737
# Epoch 7/200
# 6/6 [==============================] - 0s 29ms/step - loss: 1.1029 - accuracy: 0.6624 - val_loss: 0.9929 - val_accuracy: 0.6892
# Epoch 8/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9708 - accuracy: 0.6951 - val_loss: 0.8975 - val_accuracy: 0.6962
# Epoch 9/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.8888 - accuracy: 0.7046 - val_loss: 0.8271 - val_accuracy: 0.7089
# Epoch 10/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.8326 - accuracy: 0.7089 - val_loss: 0.7813 - val_accuracy: 0.7257
# Epoch 11/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.7669 - accuracy: 0.7229 - val_loss: 0.7414 - val_accuracy: 0.7440
# Epoch 12/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.7371 - accuracy: 0.7264 - val_loss: 0.7065 - val_accuracy: 0.7370
# Epoch 13/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.7008 - accuracy: 0.7356 - val_loss: 0.6870 - val_accuracy: 0.7440
# Epoch 14/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6790 - accuracy: 0.7359 - val_loss: 0.6546 - val_accuracy: 0.7412
# Epoch 15/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6521 - accuracy: 0.7363 - val_loss: 0.6382 - val_accuracy: 0.7440
# Epoch 16/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6319 - accuracy: 0.7475 - val_loss: 0.6214 - val_accuracy: 0.7553
# Epoch 17/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6101 - accuracy: 0.7493 - val_loss: 0.6051 - val_accuracy: 0.7440
# Epoch 18/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5943 - accuracy: 0.7560 - val_loss: 0.5970 - val_accuracy: 0.7511
# Epoch 19/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5866 - accuracy: 0.7535 - val_loss: 0.5784 - val_accuracy: 0.7581
# Epoch 20/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5724 - accuracy: 0.7616 - val_loss: 0.5676 - val_accuracy: 0.7539
# Epoch 21/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5754 - accuracy: 0.7602 - val_loss: 0.5594 - val_accuracy: 0.7595
# Epoch 22/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5507 - accuracy: 0.7725 - val_loss: 0.5521 - val_accuracy: 0.7651
# Epoch 23/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5459 - accuracy: 0.7644 - val_loss: 0.5434 - val_accuracy: 0.7637
# Epoch 24/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5343 - accuracy: 0.7746 - val_loss: 0.5338 - val_accuracy: 0.7679
# Epoch 25/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5149 - accuracy: 0.7809 - val_loss: 0.5249 - val_accuracy: 0.7820
# Epoch 26/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5171 - accuracy: 0.7799 - val_loss: 0.5198 - val_accuracy: 0.7848
# Epoch 27/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5139 - accuracy: 0.7901 - val_loss: 0.5095 - val_accuracy: 0.7904
# Epoch 28/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.4976 - accuracy: 0.7985 - val_loss: 0.5054 - val_accuracy: 0.7890
# Epoch 29/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4991 - accuracy: 0.7845 - val_loss: 0.4991 - val_accuracy: 0.8059
# Epoch 30/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4859 - accuracy: 0.8020 - val_loss: 0.4957 - val_accuracy: 0.8143
# Epoch 31/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4813 - accuracy: 0.8006 - val_loss: 0.4889 - val_accuracy: 0.8031
# Epoch 32/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4891 - accuracy: 0.8154 - val_loss: 0.4878 - val_accuracy: 0.7989
# Epoch 33/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4743 - accuracy: 0.8013 - val_loss: 0.4801 - val_accuracy: 0.8129
# Epoch 34/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4695 - accuracy: 0.8066 - val_loss: 0.4844 - val_accuracy: 0.8354
# Epoch 35/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4631 - accuracy: 0.8143 - val_loss: 0.4888 - val_accuracy: 0.8172
# Epoch 36/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4561 - accuracy: 0.8165 - val_loss: 0.4735 - val_accuracy: 0.8214
# Epoch 37/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4499 - accuracy: 0.8263 - val_loss: 0.4617 - val_accuracy: 0.8214
# Epoch 38/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4480 - accuracy: 0.8154 - val_loss: 0.4653 - val_accuracy: 0.8172
# Epoch 39/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4427 - accuracy: 0.8256 - val_loss: 0.4583 - val_accuracy: 0.8383
# Epoch 40/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4310 - accuracy: 0.8330 - val_loss: 0.4486 - val_accuracy: 0.8298
# Epoch 41/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4348 - accuracy: 0.8245 - val_loss: 0.4487 - val_accuracy: 0.8340
# Epoch 42/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4355 - accuracy: 0.8298 - val_loss: 0.4611 - val_accuracy: 0.8214
# Epoch 43/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4298 - accuracy: 0.8295 - val_loss: 0.4792 - val_accuracy: 0.8158
# Epoch 44/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4238 - accuracy: 0.8400 - val_loss: 0.4428 - val_accuracy: 0.8368
# Epoch 45/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4309 - accuracy: 0.8302 - val_loss: 0.4416 - val_accuracy: 0.8340
# Epoch 46/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4191 - accuracy: 0.8365 - val_loss: 0.4557 - val_accuracy: 0.8158
# Epoch 47/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4235 - accuracy: 0.8312 - val_loss: 0.4472 - val_accuracy: 0.8383
# Epoch 48/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4032 - accuracy: 0.8488 - val_loss: 0.4260 - val_accuracy: 0.8565
# Epoch 49/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4016 - accuracy: 0.8576 - val_loss: 0.4280 - val_accuracy: 0.8354
# Epoch 50/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3949 - accuracy: 0.8537 - val_loss: 0.4184 - val_accuracy: 0.8608
# Epoch 51/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3887 - accuracy: 0.8513 - val_loss: 0.4208 - val_accuracy: 0.8551
# Epoch 52/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3916 - accuracy: 0.8608 - val_loss: 0.4162 - val_accuracy: 0.8594
# Epoch 53/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3856 - accuracy: 0.8601 - val_loss: 0.4385 - val_accuracy: 0.8256
# Epoch 54/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3955 - accuracy: 0.8470 - val_loss: 0.4159 - val_accuracy: 0.8537
# Epoch 55/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3877 - accuracy: 0.8558 - val_loss: 0.4211 - val_accuracy: 0.8354
# Epoch 56/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3813 - accuracy: 0.8597 - val_loss: 0.4194 - val_accuracy: 0.8495
# Epoch 57/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3822 - accuracy: 0.8660 - val_loss: 0.4016 - val_accuracy: 0.8622
# Epoch 58/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3684 - accuracy: 0.8667 - val_loss: 0.4057 - val_accuracy: 0.8481
# Epoch 59/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3715 - accuracy: 0.8615 - val_loss: 0.3971 - val_accuracy: 0.8692
# Epoch 60/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3615 - accuracy: 0.8766 - val_loss: 0.3997 - val_accuracy: 0.8608
# Epoch 61/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3654 - accuracy: 0.8671 - val_loss: 0.3957 - val_accuracy: 0.8636
# Epoch 62/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3582 - accuracy: 0.8713 - val_loss: 0.3923 - val_accuracy: 0.8622
# Epoch 63/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3535 - accuracy: 0.8724 - val_loss: 0.3940 - val_accuracy: 0.8579
# Epoch 64/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3599 - accuracy: 0.8706 - val_loss: 0.3962 - val_accuracy: 0.8608
# Epoch 65/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3501 - accuracy: 0.8720 - val_loss: 0.3939 - val_accuracy: 0.8622
# Epoch 66/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3478 - accuracy: 0.8812 - val_loss: 0.3880 - val_accuracy: 0.8636
# Epoch 67/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3472 - accuracy: 0.8752 - val_loss: 0.3859 - val_accuracy: 0.8706
# Epoch 68/200
# 6/6 [==============================] - 1s 115ms/step - loss: 0.3443 - accuracy: 0.8755 - val_loss: 0.3864 - val_accuracy: 0.8608
# Epoch 69/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3360 - accuracy: 0.8801 - val_loss: 0.3805 - val_accuracy: 0.8720
# Epoch 70/200
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3403 - accuracy: 0.8801 - val_loss: 0.3829 - val_accuracy: 0.8579
# Epoch 71/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3398 - accuracy: 0.8783 - val_loss: 0.3850 - val_accuracy: 0.8636
# Epoch 72/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3440 - accuracy: 0.8699 - val_loss: 0.3799 - val_accuracy: 0.8636
# Epoch 73/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3326 - accuracy: 0.8801 - val_loss: 0.3755 - val_accuracy: 0.8720
# Epoch 74/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3386 - accuracy: 0.8783 - val_loss: 0.3782 - val_accuracy: 0.8622
# Epoch 75/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3299 - accuracy: 0.8755 - val_loss: 0.3739 - val_accuracy: 0.8636
# Epoch 76/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3348 - accuracy: 0.8766 - val_loss: 0.3791 - val_accuracy: 0.8579
# Epoch 77/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3332 - accuracy: 0.8773 - val_loss: 0.3716 - val_accuracy: 0.8664
# Epoch 78/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3347 - accuracy: 0.8755 - val_loss: 0.3730 - val_accuracy: 0.8636
# Epoch 79/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3239 - accuracy: 0.8822 - val_loss: 0.3782 - val_accuracy: 0.8678
# Epoch 80/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3309 - accuracy: 0.8819 - val_loss: 0.3673 - val_accuracy: 0.8636
# Epoch 81/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3185 - accuracy: 0.8829 - val_loss: 0.3652 - val_accuracy: 0.8608
# Epoch 82/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3248 - accuracy: 0.8850 - val_loss: 0.3613 - val_accuracy: 0.8650
# Epoch 83/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3153 - accuracy: 0.8805 - val_loss: 0.3609 - val_accuracy: 0.8650
# Epoch 84/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3220 - accuracy: 0.8759 - val_loss: 0.3594 - val_accuracy: 0.8664
# Epoch 85/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3113 - accuracy: 0.8906 - val_loss: 0.3598 - val_accuracy: 0.8636
# Epoch 86/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3095 - accuracy: 0.8850 - val_loss: 0.3638 - val_accuracy: 0.8579
# Epoch 87/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3160 - accuracy: 0.8840 - val_loss: 0.3560 - val_accuracy: 0.8706
# Epoch 88/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3176 - accuracy: 0.8797 - val_loss: 0.3573 - val_accuracy: 0.8748
# Epoch 89/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3105 - accuracy: 0.8892 - val_loss: 0.3523 - val_accuracy: 0.8706
# Epoch 90/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3101 - accuracy: 0.8878 - val_loss: 0.3501 - val_accuracy: 0.8692
# Epoch 91/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3031 - accuracy: 0.8892 - val_loss: 0.3549 - val_accuracy: 0.8622
# Epoch 92/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3119 - accuracy: 0.8787 - val_loss: 0.3541 - val_accuracy: 0.8650
# Epoch 93/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3023 - accuracy: 0.8871 - val_loss: 0.3459 - val_accuracy: 0.8762
# Epoch 94/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3057 - accuracy: 0.8864 - val_loss: 0.3534 - val_accuracy: 0.8692
# Epoch 95/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2958 - accuracy: 0.8903 - val_loss: 0.3443 - val_accuracy: 0.8762
# Epoch 96/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2994 - accuracy: 0.8921 - val_loss: 0.3464 - val_accuracy: 0.8664
# Epoch 97/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2994 - accuracy: 0.8942 - val_loss: 0.3386 - val_accuracy: 0.8734
# Epoch 98/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3026 - accuracy: 0.8896 - val_loss: 0.3465 - val_accuracy: 0.8678
# Epoch 99/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2945 - accuracy: 0.8980 - val_loss: 0.3417 - val_accuracy: 0.8762
# Epoch 100/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2967 - accuracy: 0.8917 - val_loss: 0.3386 - val_accuracy: 0.8776
# Epoch 101/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2928 - accuracy: 0.8938 - val_loss: 0.3364 - val_accuracy: 0.8805
# Epoch 102/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2896 - accuracy: 0.8952 - val_loss: 0.3449 - val_accuracy: 0.8664
# Epoch 103/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2964 - accuracy: 0.8882 - val_loss: 0.3442 - val_accuracy: 0.8734
# Epoch 104/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2856 - accuracy: 0.8994 - val_loss: 0.3356 - val_accuracy: 0.8678
# Epoch 105/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2899 - accuracy: 0.8931 - val_loss: 0.3490 - val_accuracy: 0.8748
# Epoch 106/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3056 - accuracy: 0.8861 - val_loss: 0.3441 - val_accuracy: 0.8790
# Epoch 107/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3053 - accuracy: 0.8812 - val_loss: 0.3306 - val_accuracy: 0.8720
# Epoch 108/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2979 - accuracy: 0.8935 - val_loss: 0.3806 - val_accuracy: 0.8622
# Epoch 109/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3088 - accuracy: 0.8899 - val_loss: 0.3294 - val_accuracy: 0.8776
# Epoch 110/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2800 - accuracy: 0.8952 - val_loss: 0.3445 - val_accuracy: 0.8706
# Epoch 111/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2872 - accuracy: 0.8921 - val_loss: 0.3269 - val_accuracy: 0.8805
# Epoch 112/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2828 - accuracy: 0.8980 - val_loss: 0.3266 - val_accuracy: 0.8720
# Epoch 113/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2718 - accuracy: 0.8973 - val_loss: 0.3238 - val_accuracy: 0.8805
# Epoch 114/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2763 - accuracy: 0.9012 - val_loss: 0.3248 - val_accuracy: 0.8833
# Epoch 115/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2777 - accuracy: 0.8945 - val_loss: 0.3237 - val_accuracy: 0.8819
# Epoch 116/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2718 - accuracy: 0.9033 - val_loss: 0.3225 - val_accuracy: 0.8847
# Epoch 117/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2750 - accuracy: 0.8959 - val_loss: 0.3282 - val_accuracy: 0.8819
# Epoch 118/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2693 - accuracy: 0.8980 - val_loss: 0.3349 - val_accuracy: 0.8805
# Epoch 119/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2784 - accuracy: 0.8956 - val_loss: 0.3209 - val_accuracy: 0.8805
# Epoch 120/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2696 - accuracy: 0.9015 - val_loss: 0.3176 - val_accuracy: 0.8833
# Epoch 121/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2732 - accuracy: 0.8998 - val_loss: 0.3154 - val_accuracy: 0.8847
# Epoch 122/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2664 - accuracy: 0.9005 - val_loss: 0.3194 - val_accuracy: 0.8833
# Epoch 123/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2693 - accuracy: 0.9040 - val_loss: 0.3164 - val_accuracy: 0.8875
# Epoch 124/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2693 - accuracy: 0.8991 - val_loss: 0.3196 - val_accuracy: 0.8833
# Epoch 125/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2678 - accuracy: 0.8998 - val_loss: 0.3166 - val_accuracy: 0.8833
# Epoch 126/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2652 - accuracy: 0.9037 - val_loss: 0.3102 - val_accuracy: 0.8917
# Epoch 127/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2618 - accuracy: 0.9037 - val_loss: 0.3263 - val_accuracy: 0.8833
# Epoch 128/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2604 - accuracy: 0.9093 - val_loss: 0.3076 - val_accuracy: 0.8917
# Epoch 129/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2621 - accuracy: 0.9001 - val_loss: 0.3072 - val_accuracy: 0.8889
# Epoch 130/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2597 - accuracy: 0.9068 - val_loss: 0.3109 - val_accuracy: 0.8889
# Epoch 131/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2593 - accuracy: 0.9061 - val_loss: 0.3117 - val_accuracy: 0.8819
# Epoch 132/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2573 - accuracy: 0.9047 - val_loss: 0.3066 - val_accuracy: 0.8861
# Epoch 133/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2526 - accuracy: 0.9089 - val_loss: 0.3050 - val_accuracy: 0.8917
# Epoch 134/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2480 - accuracy: 0.9132 - val_loss: 0.3024 - val_accuracy: 0.8917
# Epoch 135/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2530 - accuracy: 0.9033 - val_loss: 0.3011 - val_accuracy: 0.8861
# Epoch 136/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2493 - accuracy: 0.9047 - val_loss: 0.2982 - val_accuracy: 0.8987
# Epoch 137/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2456 - accuracy: 0.9121 - val_loss: 0.3087 - val_accuracy: 0.8903
# Epoch 138/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2552 - accuracy: 0.9051 - val_loss: 0.2968 - val_accuracy: 0.9001
# Epoch 139/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2540 - accuracy: 0.9047 - val_loss: 0.3180 - val_accuracy: 0.8875
# Epoch 140/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2565 - accuracy: 0.9044 - val_loss: 0.2973 - val_accuracy: 0.8917
# Epoch 141/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2548 - accuracy: 0.9065 - val_loss: 0.3118 - val_accuracy: 0.8875
# Epoch 142/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2534 - accuracy: 0.9075 - val_loss: 0.3002 - val_accuracy: 0.8987
# Epoch 143/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2478 - accuracy: 0.9030 - val_loss: 0.2897 - val_accuracy: 0.9072
# Epoch 144/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2366 - accuracy: 0.9153 - val_loss: 0.3078 - val_accuracy: 0.8875
# Epoch 145/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2487 - accuracy: 0.9044 - val_loss: 0.2880 - val_accuracy: 0.9015
# Epoch 146/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2413 - accuracy: 0.9103 - val_loss: 0.2891 - val_accuracy: 0.8987
# Epoch 147/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2401 - accuracy: 0.9107 - val_loss: 0.2889 - val_accuracy: 0.9015
# Epoch 148/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2413 - accuracy: 0.9121 - val_loss: 0.2933 - val_accuracy: 0.8917
# Epoch 149/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2407 - accuracy: 0.9146 - val_loss: 0.2862 - val_accuracy: 0.8987
# Epoch 150/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2359 - accuracy: 0.9121 - val_loss: 0.2870 - val_accuracy: 0.9044
# Epoch 151/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2328 - accuracy: 0.9156 - val_loss: 0.2899 - val_accuracy: 0.8959
# Epoch 152/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2409 - accuracy: 0.9079 - val_loss: 0.2831 - val_accuracy: 0.9001
# Epoch 153/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2355 - accuracy: 0.9117 - val_loss: 0.2876 - val_accuracy: 0.9015
# Epoch 154/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2335 - accuracy: 0.9184 - val_loss: 0.2834 - val_accuracy: 0.9044
# Epoch 155/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2294 - accuracy: 0.9132 - val_loss: 0.2817 - val_accuracy: 0.9072
# Epoch 156/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2319 - accuracy: 0.9121 - val_loss: 0.2823 - val_accuracy: 0.9015
# Epoch 157/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2340 - accuracy: 0.9110 - val_loss: 0.2820 - val_accuracy: 0.9072
# Epoch 158/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2342 - accuracy: 0.9093 - val_loss: 0.2794 - val_accuracy: 0.9044
# Epoch 159/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2293 - accuracy: 0.9188 - val_loss: 0.2816 - val_accuracy: 0.9015
# Epoch 160/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2276 - accuracy: 0.9174 - val_loss: 0.2796 - val_accuracy: 0.9030
# Epoch 161/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2323 - accuracy: 0.9100 - val_loss: 0.2829 - val_accuracy: 0.9030
# Epoch 162/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2271 - accuracy: 0.9135 - val_loss: 0.2760 - val_accuracy: 0.8973
# Epoch 163/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2224 - accuracy: 0.9209 - val_loss: 0.2804 - val_accuracy: 0.8987
# Epoch 164/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2225 - accuracy: 0.9244 - val_loss: 0.2747 - val_accuracy: 0.9086
# Epoch 165/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2247 - accuracy: 0.9167 - val_loss: 0.2856 - val_accuracy: 0.9015
# Epoch 166/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2212 - accuracy: 0.9163 - val_loss: 0.2745 - val_accuracy: 0.9114
# Epoch 167/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2173 - accuracy: 0.9205 - val_loss: 0.2724 - val_accuracy: 0.9100
# Epoch 168/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2209 - accuracy: 0.9195 - val_loss: 0.2703 - val_accuracy: 0.9058
# Epoch 169/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2144 - accuracy: 0.9195 - val_loss: 0.2708 - val_accuracy: 0.9114
# Epoch 170/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2189 - accuracy: 0.9174 - val_loss: 0.2685 - val_accuracy: 0.9114
# Epoch 171/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2141 - accuracy: 0.9202 - val_loss: 0.2698 - val_accuracy: 0.9114
# Epoch 172/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2124 - accuracy: 0.9219 - val_loss: 0.2700 - val_accuracy: 0.9072
# Epoch 173/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2113 - accuracy: 0.9212 - val_loss: 0.2673 - val_accuracy: 0.9072
# Epoch 174/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2109 - accuracy: 0.9233 - val_loss: 0.2668 - val_accuracy: 0.9100
# Epoch 175/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2110 - accuracy: 0.9233 - val_loss: 0.2641 - val_accuracy: 0.9100
# Epoch 176/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2095 - accuracy: 0.9219 - val_loss: 0.2621 - val_accuracy: 0.9142
# Epoch 177/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2172 - accuracy: 0.9219 - val_loss: 0.2638 - val_accuracy: 0.9114
# Epoch 178/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2126 - accuracy: 0.9233 - val_loss: 0.2662 - val_accuracy: 0.9100
# Epoch 179/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2102 - accuracy: 0.9241 - val_loss: 0.2616 - val_accuracy: 0.9100
# Epoch 180/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2148 - accuracy: 0.9241 - val_loss: 0.2660 - val_accuracy: 0.9142
# Epoch 181/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2121 - accuracy: 0.9304 - val_loss: 0.2613 - val_accuracy: 0.9128
# Epoch 182/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2071 - accuracy: 0.9202 - val_loss: 0.2615 - val_accuracy: 0.9072
# Epoch 183/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2170 - accuracy: 0.9223 - val_loss: 0.2639 - val_accuracy: 0.9114
# Epoch 184/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2080 - accuracy: 0.9244 - val_loss: 0.2555 - val_accuracy: 0.9100
# Epoch 185/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2064 - accuracy: 0.9251 - val_loss: 0.2615 - val_accuracy: 0.9156
# Epoch 186/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2054 - accuracy: 0.9297 - val_loss: 0.2591 - val_accuracy: 0.9156
# Epoch 187/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2059 - accuracy: 0.9307 - val_loss: 0.2673 - val_accuracy: 0.9072
# Epoch 188/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2103 - accuracy: 0.9191 - val_loss: 0.2551 - val_accuracy: 0.9128
# Epoch 189/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2060 - accuracy: 0.9248 - val_loss: 0.2586 - val_accuracy: 0.9128
# Epoch 190/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1993 - accuracy: 0.9262 - val_loss: 0.2584 - val_accuracy: 0.9156
# Epoch 191/200
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1998 - accuracy: 0.9293 - val_loss: 0.2498 - val_accuracy: 0.9142
# Epoch 192/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1991 - accuracy: 0.9290 - val_loss: 0.2536 - val_accuracy: 0.9128
# Epoch 193/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1935 - accuracy: 0.9311 - val_loss: 0.2536 - val_accuracy: 0.9156
# Epoch 194/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1957 - accuracy: 0.9300 - val_loss: 0.2534 - val_accuracy: 0.9170
# Epoch 195/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2001 - accuracy: 0.9279 - val_loss: 0.2470 - val_accuracy: 0.9184
# Epoch 196/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1966 - accuracy: 0.9283 - val_loss: 0.2499 - val_accuracy: 0.9184
# Epoch 197/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1974 - accuracy: 0.9300 - val_loss: 0.2508 - val_accuracy: 0.9142
# Epoch 198/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1975 - accuracy: 0.9286 - val_loss: 0.2627 - val_accuracy: 0.9086
# Epoch 199/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1934 - accuracy: 0.9297 - val_loss: 0.2614 - val_accuracy: 0.9170
# Epoch 200/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2018 - accuracy: 0.9248 - val_loss: 0.2524 - val_accuracy: 0.9114

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 0s 46ms/step - loss: 2.0446 - accuracy: 0.3070 - val_loss: 1.8561 - val_accuracy: 0.3376
# Epoch 2/40
# 6/6 [==============================] - 0s 24ms/step - loss: 1.7904 - accuracy: 0.3376 - val_loss: 1.7074 - val_accuracy: 0.3376
# Epoch 3/40
# 6/6 [==============================] - 0s 24ms/step - loss: 1.6684 - accuracy: 0.3527 - val_loss: 1.6002 - val_accuracy: 0.4402
# Epoch 4/40
# 6/6 [==============================] - 0s 27ms/step - loss: 1.5703 - accuracy: 0.4603 - val_loss: 1.4721 - val_accuracy: 0.4571
# Epoch 5/40
# 6/6 [==============================] - 0s 29ms/step - loss: 1.4415 - accuracy: 0.4951 - val_loss: 1.3042 - val_accuracy: 0.6596
# Epoch 6/40
# 6/6 [==============================] - 0s 26ms/step - loss: 1.2650 - accuracy: 0.6473 - val_loss: 1.1354 - val_accuracy: 0.6667
# Epoch 7/40
# 6/6 [==============================] - 0s 23ms/step - loss: 1.1113 - accuracy: 0.6705 - val_loss: 0.9927 - val_accuracy: 0.6892
# Epoch 8/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.9837 - accuracy: 0.6758 - val_loss: 0.8908 - val_accuracy: 0.7018
# Epoch 9/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.8891 - accuracy: 0.6994 - val_loss: 0.8154 - val_accuracy: 0.7229
# Epoch 10/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.8269 - accuracy: 0.7057 - val_loss: 0.7709 - val_accuracy: 0.7328
# Epoch 11/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.7696 - accuracy: 0.7191 - val_loss: 0.7377 - val_accuracy: 0.7286
# Epoch 12/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.7295 - accuracy: 0.7264 - val_loss: 0.7005 - val_accuracy: 0.7300
# Epoch 13/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7013 - accuracy: 0.7278 - val_loss: 0.6775 - val_accuracy: 0.7286
# Epoch 14/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.6699 - accuracy: 0.7257 - val_loss: 0.6522 - val_accuracy: 0.7384
# Epoch 15/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6455 - accuracy: 0.7468 - val_loss: 0.6359 - val_accuracy: 0.7342
# Epoch 16/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6315 - accuracy: 0.7387 - val_loss: 0.6188 - val_accuracy: 0.7412
# Epoch 17/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6077 - accuracy: 0.7493 - val_loss: 0.6077 - val_accuracy: 0.7300
# Epoch 18/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5957 - accuracy: 0.7507 - val_loss: 0.5929 - val_accuracy: 0.7567
# Epoch 19/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5760 - accuracy: 0.7567 - val_loss: 0.5833 - val_accuracy: 0.7539
# Epoch 20/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5742 - accuracy: 0.7504 - val_loss: 0.5685 - val_accuracy: 0.7553
# Epoch 21/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5663 - accuracy: 0.7605 - val_loss: 0.5701 - val_accuracy: 0.7384
# Epoch 22/40
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5512 - accuracy: 0.7651 - val_loss: 0.5515 - val_accuracy: 0.7693
# Epoch 23/40
# 6/6 [==============================] - 0s 23ms/step - loss: 0.5463 - accuracy: 0.7644 - val_loss: 0.5499 - val_accuracy: 0.7736
# Epoch 24/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5387 - accuracy: 0.7809 - val_loss: 0.5390 - val_accuracy: 0.7722
# Epoch 25/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5222 - accuracy: 0.7760 - val_loss: 0.5275 - val_accuracy: 0.7890
# Epoch 26/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5149 - accuracy: 0.7809 - val_loss: 0.5192 - val_accuracy: 0.7834
# Epoch 27/40
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5074 - accuracy: 0.7799 - val_loss: 0.5149 - val_accuracy: 0.7820
# Epoch 28/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4924 - accuracy: 0.7985 - val_loss: 0.5046 - val_accuracy: 0.7947
# Epoch 29/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4888 - accuracy: 0.7985 - val_loss: 0.4959 - val_accuracy: 0.7932
# Epoch 30/40
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4834 - accuracy: 0.7982 - val_loss: 0.4911 - val_accuracy: 0.8003
# Epoch 31/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4689 - accuracy: 0.8150 - val_loss: 0.4884 - val_accuracy: 0.8143
# Epoch 32/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4654 - accuracy: 0.8112 - val_loss: 0.4776 - val_accuracy: 0.8242
# Epoch 33/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4636 - accuracy: 0.8217 - val_loss: 0.4741 - val_accuracy: 0.8200
# Epoch 34/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4523 - accuracy: 0.8207 - val_loss: 0.4678 - val_accuracy: 0.8200
# Epoch 35/40
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4494 - accuracy: 0.8147 - val_loss: 0.4639 - val_accuracy: 0.8354
# Epoch 36/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4538 - accuracy: 0.8242 - val_loss: 0.4587 - val_accuracy: 0.8256
# Epoch 37/40
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4390 - accuracy: 0.8214 - val_loss: 0.4645 - val_accuracy: 0.8312
# Epoch 38/40
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4370 - accuracy: 0.8361 - val_loss: 0.4566 - val_accuracy: 0.8312
# Epoch 39/40
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4322 - accuracy: 0.8340 - val_loss: 0.4481 - val_accuracy: 0.8312
# Epoch 40/40
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4282 - accuracy: 0.8439 - val_loss: 0.4425 - val_accuracy: 0.8397

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 3ms/step - loss: 0.3823 - accuracy: 0.8681
# 23/23 [==============================] - 0s 3ms/step - loss: 0.4425 - accuracy: 0.8397
# 0.8681434392929077 0.8396624326705933

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 15, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:58

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   2 116   1   3   0   0   0]
#  [  0   4   0 228   6   0   0   2]
#  [  0   1   2  52  42   1   0   2]
#  [  0   0   0   0   1  11   0   0]
#  [  0   0   0   0   3   3   5   0]
#  [  0   0   0  27   4   0   0  15]]
#
# Accuracy Score
# 0.8396624472573839
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        80
#      clouds       0.93      1.00      0.97       100
#  vegetation       0.98      0.95      0.97       122
#       built       0.74      0.95      0.83       240
#     windows       0.71      0.42      0.53       100
#       roads       0.73      0.92      0.81        12
#        cars       1.00      0.45      0.62        11
#       metal       0.79      0.33      0.46        46
#
# avg / total       0.84      0.84      0.82       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 15
# [[0, 58], [58, 116], [116, 174], [174, 232], [232, 290], [290, 348], [348, 406], [406, 464], [464, 522], [522, 580], [580, 638], [638, 696], [696, 754], [754, 812], [812, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 15)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 15)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 15)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 15) (60, 15)
# clouds  (160, 15) (40, 15)
# vegetation  (560, 15) (140, 15)
# water  (496, 15) (124, 15)
# built  (1280, 15) (320, 15)
# windows  (480, 15) (120, 15)
# roads  (200, 15) (50, 15)
# cars  (200, 15) (50, 15)
# metal  (148, 15) (37, 15)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 15) (3764,) (3764, 2)
# (941, 15) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 42ms/step - loss: 2.0651 - accuracy: 0.3390 - val_loss: 1.8901 - val_accuracy: 0.3401
# Epoch 2/200
# 8/8 [==============================] - 0s 28ms/step - loss: 1.8680 - accuracy: 0.3425 - val_loss: 1.7557 - val_accuracy: 0.3656
# Epoch 3/200
# 8/8 [==============================] - 0s 24ms/step - loss: 1.7212 - accuracy: 0.4243 - val_loss: 1.5823 - val_accuracy: 0.4453
# Epoch 4/200
# 8/8 [==============================] - 0s 22ms/step - loss: 1.5433 - accuracy: 0.4633 - val_loss: 1.4079 - val_accuracy: 0.5133
# Epoch 5/200
# 8/8 [==============================] - 0s 22ms/step - loss: 1.4036 - accuracy: 0.5316 - val_loss: 1.3191 - val_accuracy: 0.5866
# Epoch 6/200
# 8/8 [==============================] - 0s 22ms/step - loss: 1.3242 - accuracy: 0.5491 - val_loss: 1.2576 - val_accuracy: 0.5675
# Epoch 7/200
# 8/8 [==============================] - 0s 22ms/step - loss: 1.2673 - accuracy: 0.5731 - val_loss: 1.2170 - val_accuracy: 0.5983
# Epoch 8/200
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2136 - accuracy: 0.5909 - val_loss: 1.1655 - val_accuracy: 0.6121
# Epoch 9/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1778 - accuracy: 0.6105 - val_loss: 1.1213 - val_accuracy: 0.6334
# Epoch 10/200
# 8/8 [==============================] - 0s 26ms/step - loss: 1.1356 - accuracy: 0.6270 - val_loss: 1.0865 - val_accuracy: 0.6387
# Epoch 11/200
# 8/8 [==============================] - 0s 28ms/step - loss: 1.0955 - accuracy: 0.6485 - val_loss: 1.0472 - val_accuracy: 0.6504
# Epoch 12/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.0643 - accuracy: 0.6477 - val_loss: 1.0148 - val_accuracy: 0.6716
# Epoch 13/200
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0242 - accuracy: 0.6671 - val_loss: 0.9871 - val_accuracy: 0.7024
# Epoch 14/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9969 - accuracy: 0.6833 - val_loss: 0.9596 - val_accuracy: 0.7226
# Epoch 15/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.9712 - accuracy: 0.6918 - val_loss: 0.9343 - val_accuracy: 0.7163
# Epoch 16/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9482 - accuracy: 0.6870 - val_loss: 0.9132 - val_accuracy: 0.7279
# Epoch 17/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9231 - accuracy: 0.6993 - val_loss: 0.8891 - val_accuracy: 0.7269
# Epoch 18/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9063 - accuracy: 0.7072 - val_loss: 0.8674 - val_accuracy: 0.7184
# Epoch 19/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8851 - accuracy: 0.7133 - val_loss: 0.8531 - val_accuracy: 0.7248
# Epoch 20/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.8702 - accuracy: 0.7067 - val_loss: 0.8410 - val_accuracy: 0.7311
# Epoch 21/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.8510 - accuracy: 0.7264 - val_loss: 0.8082 - val_accuracy: 0.7375
# Epoch 22/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8248 - accuracy: 0.7335 - val_loss: 0.7866 - val_accuracy: 0.7386
# Epoch 23/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.8001 - accuracy: 0.7378 - val_loss: 0.7679 - val_accuracy: 0.7588
# Epoch 24/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7820 - accuracy: 0.7439 - val_loss: 0.7458 - val_accuracy: 0.7715
# Epoch 25/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7726 - accuracy: 0.7481 - val_loss: 0.7362 - val_accuracy: 0.7566
# Epoch 26/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7555 - accuracy: 0.7535 - val_loss: 0.7059 - val_accuracy: 0.7885
# Epoch 27/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7319 - accuracy: 0.7659 - val_loss: 0.7087 - val_accuracy: 0.7641
# Epoch 28/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7260 - accuracy: 0.7710 - val_loss: 0.6860 - val_accuracy: 0.7853
# Epoch 29/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7075 - accuracy: 0.7848 - val_loss: 0.6696 - val_accuracy: 0.8013
# Epoch 30/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7033 - accuracy: 0.7792 - val_loss: 0.6606 - val_accuracy: 0.8172
# Epoch 31/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.6802 - accuracy: 0.7917 - val_loss: 0.6419 - val_accuracy: 0.8098
# Epoch 32/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6749 - accuracy: 0.7893 - val_loss: 0.6394 - val_accuracy: 0.8193
# Epoch 33/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6659 - accuracy: 0.7885 - val_loss: 0.6267 - val_accuracy: 0.8204
# Epoch 34/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6560 - accuracy: 0.7970 - val_loss: 0.6157 - val_accuracy: 0.8363
# Epoch 35/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6446 - accuracy: 0.7954 - val_loss: 0.6108 - val_accuracy: 0.8204
# Epoch 36/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6363 - accuracy: 0.8018 - val_loss: 0.6130 - val_accuracy: 0.8215
# Epoch 37/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6354 - accuracy: 0.8005 - val_loss: 0.5932 - val_accuracy: 0.8310
# Epoch 38/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6262 - accuracy: 0.8037 - val_loss: 0.5933 - val_accuracy: 0.8321
# Epoch 39/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6190 - accuracy: 0.8061 - val_loss: 0.5782 - val_accuracy: 0.8395
# Epoch 40/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6082 - accuracy: 0.8140 - val_loss: 0.5723 - val_accuracy: 0.8448
# Epoch 41/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6033 - accuracy: 0.8143 - val_loss: 0.5757 - val_accuracy: 0.8321
# Epoch 42/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5920 - accuracy: 0.8185 - val_loss: 0.5617 - val_accuracy: 0.8427
# Epoch 43/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5890 - accuracy: 0.8164 - val_loss: 0.5583 - val_accuracy: 0.8395
# Epoch 44/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5857 - accuracy: 0.8180 - val_loss: 0.5589 - val_accuracy: 0.8406
# Epoch 45/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5823 - accuracy: 0.8228 - val_loss: 0.5490 - val_accuracy: 0.8480
# Epoch 46/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5878 - accuracy: 0.8162 - val_loss: 0.5496 - val_accuracy: 0.8502
# Epoch 47/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5855 - accuracy: 0.8140 - val_loss: 0.5436 - val_accuracy: 0.8491
# Epoch 48/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5795 - accuracy: 0.8225 - val_loss: 0.5351 - val_accuracy: 0.8502
# Epoch 49/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5674 - accuracy: 0.8247 - val_loss: 0.5389 - val_accuracy: 0.8512
# Epoch 50/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5731 - accuracy: 0.8188 - val_loss: 0.5287 - val_accuracy: 0.8470
# Epoch 51/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5656 - accuracy: 0.8302 - val_loss: 0.5355 - val_accuracy: 0.8491
# Epoch 52/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5635 - accuracy: 0.8233 - val_loss: 0.5255 - val_accuracy: 0.8555
# Epoch 53/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5503 - accuracy: 0.8244 - val_loss: 0.5196 - val_accuracy: 0.8512
# Epoch 54/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5430 - accuracy: 0.8297 - val_loss: 0.5173 - val_accuracy: 0.8533
# Epoch 55/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5439 - accuracy: 0.8316 - val_loss: 0.5104 - val_accuracy: 0.8565
# Epoch 56/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5295 - accuracy: 0.8374 - val_loss: 0.5048 - val_accuracy: 0.8565
# Epoch 57/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5342 - accuracy: 0.8350 - val_loss: 0.5047 - val_accuracy: 0.8587
# Epoch 58/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5288 - accuracy: 0.8350 - val_loss: 0.4976 - val_accuracy: 0.8565
# Epoch 59/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5273 - accuracy: 0.8353 - val_loss: 0.5102 - val_accuracy: 0.8565
# Epoch 60/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5234 - accuracy: 0.8355 - val_loss: 0.4979 - val_accuracy: 0.8565
# Epoch 61/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5234 - accuracy: 0.8332 - val_loss: 0.4972 - val_accuracy: 0.8587
# Epoch 62/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5224 - accuracy: 0.8387 - val_loss: 0.4952 - val_accuracy: 0.8544
# Epoch 63/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5237 - accuracy: 0.8398 - val_loss: 0.5052 - val_accuracy: 0.8587
# Epoch 64/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5246 - accuracy: 0.8337 - val_loss: 0.4977 - val_accuracy: 0.8565
# Epoch 65/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5198 - accuracy: 0.8363 - val_loss: 0.4870 - val_accuracy: 0.8544
# Epoch 66/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.5124 - accuracy: 0.8371 - val_loss: 0.4919 - val_accuracy: 0.8544
# Epoch 67/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5065 - accuracy: 0.8395 - val_loss: 0.4830 - val_accuracy: 0.8650
# Epoch 68/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5016 - accuracy: 0.8382 - val_loss: 0.4743 - val_accuracy: 0.8629
# Epoch 69/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4876 - accuracy: 0.8456 - val_loss: 0.4827 - val_accuracy: 0.8587
# Epoch 70/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4963 - accuracy: 0.8403 - val_loss: 0.4709 - val_accuracy: 0.8693
# Epoch 71/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4858 - accuracy: 0.8446 - val_loss: 0.4660 - val_accuracy: 0.8640
# Epoch 72/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4794 - accuracy: 0.8494 - val_loss: 0.4681 - val_accuracy: 0.8629
# Epoch 73/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4880 - accuracy: 0.8510 - val_loss: 0.4651 - val_accuracy: 0.8693
# Epoch 74/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4838 - accuracy: 0.8557 - val_loss: 0.4636 - val_accuracy: 0.8629
# Epoch 75/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4886 - accuracy: 0.8427 - val_loss: 0.4694 - val_accuracy: 0.8629
# Epoch 76/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4808 - accuracy: 0.8480 - val_loss: 0.4624 - val_accuracy: 0.8693
# Epoch 77/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4746 - accuracy: 0.8491 - val_loss: 0.4646 - val_accuracy: 0.8757
# Epoch 78/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4775 - accuracy: 0.8507 - val_loss: 0.4609 - val_accuracy: 0.8714
# Epoch 79/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4733 - accuracy: 0.8486 - val_loss: 0.4479 - val_accuracy: 0.8735
# Epoch 80/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4741 - accuracy: 0.8451 - val_loss: 0.4510 - val_accuracy: 0.8650
# Epoch 81/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4683 - accuracy: 0.8502 - val_loss: 0.4455 - val_accuracy: 0.8714
# Epoch 82/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4662 - accuracy: 0.8475 - val_loss: 0.4474 - val_accuracy: 0.8661
# Epoch 83/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4587 - accuracy: 0.8579 - val_loss: 0.4415 - val_accuracy: 0.8757
# Epoch 84/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4563 - accuracy: 0.8587 - val_loss: 0.4400 - val_accuracy: 0.8725
# Epoch 85/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4643 - accuracy: 0.8512 - val_loss: 0.4378 - val_accuracy: 0.8735
# Epoch 86/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4514 - accuracy: 0.8547 - val_loss: 0.4334 - val_accuracy: 0.8778
# Epoch 87/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4510 - accuracy: 0.8541 - val_loss: 0.4305 - val_accuracy: 0.8831
# Epoch 88/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4524 - accuracy: 0.8576 - val_loss: 0.4376 - val_accuracy: 0.8767
# Epoch 89/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4479 - accuracy: 0.8528 - val_loss: 0.4319 - val_accuracy: 0.8799
# Epoch 90/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4385 - accuracy: 0.8629 - val_loss: 0.4277 - val_accuracy: 0.8767
# Epoch 91/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4474 - accuracy: 0.8579 - val_loss: 0.4319 - val_accuracy: 0.8757
# Epoch 92/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4434 - accuracy: 0.8576 - val_loss: 0.4247 - val_accuracy: 0.8757
# Epoch 93/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4376 - accuracy: 0.8584 - val_loss: 0.4237 - val_accuracy: 0.8874
# Epoch 94/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4397 - accuracy: 0.8616 - val_loss: 0.4172 - val_accuracy: 0.8789
# Epoch 95/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4419 - accuracy: 0.8576 - val_loss: 0.4256 - val_accuracy: 0.8789
# Epoch 96/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4391 - accuracy: 0.8616 - val_loss: 0.4141 - val_accuracy: 0.8778
# Epoch 97/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4281 - accuracy: 0.8626 - val_loss: 0.4168 - val_accuracy: 0.8810
# Epoch 98/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4315 - accuracy: 0.8634 - val_loss: 0.4127 - val_accuracy: 0.8799
# Epoch 99/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4357 - accuracy: 0.8608 - val_loss: 0.4148 - val_accuracy: 0.8874
# Epoch 100/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4283 - accuracy: 0.8709 - val_loss: 0.4068 - val_accuracy: 0.8895
# Epoch 101/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4277 - accuracy: 0.8645 - val_loss: 0.4078 - val_accuracy: 0.8874
# Epoch 102/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4189 - accuracy: 0.8688 - val_loss: 0.4053 - val_accuracy: 0.8852
# Epoch 103/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4249 - accuracy: 0.8680 - val_loss: 0.4024 - val_accuracy: 0.8874
# Epoch 104/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4113 - accuracy: 0.8690 - val_loss: 0.4020 - val_accuracy: 0.8831
# Epoch 105/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4102 - accuracy: 0.8706 - val_loss: 0.3987 - val_accuracy: 0.8937
# Epoch 106/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4110 - accuracy: 0.8701 - val_loss: 0.4004 - val_accuracy: 0.8905
# Epoch 107/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4139 - accuracy: 0.8717 - val_loss: 0.4000 - val_accuracy: 0.8874
# Epoch 108/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4136 - accuracy: 0.8666 - val_loss: 0.3949 - val_accuracy: 0.8884
# Epoch 109/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4135 - accuracy: 0.8682 - val_loss: 0.3991 - val_accuracy: 0.8863
# Epoch 110/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4093 - accuracy: 0.8704 - val_loss: 0.3892 - val_accuracy: 0.8895
# Epoch 111/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4059 - accuracy: 0.8704 - val_loss: 0.3860 - val_accuracy: 0.8927
# Epoch 112/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4060 - accuracy: 0.8690 - val_loss: 0.3833 - val_accuracy: 0.8959
# Epoch 113/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3998 - accuracy: 0.8754 - val_loss: 0.3816 - val_accuracy: 0.8916
# Epoch 114/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3905 - accuracy: 0.8807 - val_loss: 0.3825 - val_accuracy: 0.8948
# Epoch 115/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3986 - accuracy: 0.8719 - val_loss: 0.3848 - val_accuracy: 0.8895
# Epoch 116/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3904 - accuracy: 0.8781 - val_loss: 0.3837 - val_accuracy: 0.8980
# Epoch 117/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4003 - accuracy: 0.8704 - val_loss: 0.3809 - val_accuracy: 0.8969
# Epoch 118/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3944 - accuracy: 0.8727 - val_loss: 0.3897 - val_accuracy: 0.8905
# Epoch 119/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4039 - accuracy: 0.8725 - val_loss: 0.3783 - val_accuracy: 0.8980
# Epoch 120/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3914 - accuracy: 0.8812 - val_loss: 0.3792 - val_accuracy: 0.8937
# Epoch 121/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3867 - accuracy: 0.8778 - val_loss: 0.3772 - val_accuracy: 0.8937
# Epoch 122/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3851 - accuracy: 0.8804 - val_loss: 0.3750 - val_accuracy: 0.8969
# Epoch 123/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3918 - accuracy: 0.8815 - val_loss: 0.3732 - val_accuracy: 0.8959
# Epoch 124/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3839 - accuracy: 0.8796 - val_loss: 0.3732 - val_accuracy: 0.8916
# Epoch 125/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3759 - accuracy: 0.8783 - val_loss: 0.3674 - val_accuracy: 0.9022
# Epoch 126/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3824 - accuracy: 0.8741 - val_loss: 0.3667 - val_accuracy: 0.8980
# Epoch 127/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3811 - accuracy: 0.8804 - val_loss: 0.3688 - val_accuracy: 0.8927
# Epoch 128/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3716 - accuracy: 0.8858 - val_loss: 0.3740 - val_accuracy: 0.8990
# Epoch 129/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3800 - accuracy: 0.8823 - val_loss: 0.3669 - val_accuracy: 0.8990
# Epoch 130/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3735 - accuracy: 0.8842 - val_loss: 0.3636 - val_accuracy: 0.9001
# Epoch 131/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3723 - accuracy: 0.8799 - val_loss: 0.3667 - val_accuracy: 0.8959
# Epoch 132/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3786 - accuracy: 0.8815 - val_loss: 0.3588 - val_accuracy: 0.8969
# Epoch 133/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3707 - accuracy: 0.8842 - val_loss: 0.3561 - val_accuracy: 0.9075
# Epoch 134/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3779 - accuracy: 0.8804 - val_loss: 0.3603 - val_accuracy: 0.8980
# Epoch 135/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3627 - accuracy: 0.8887 - val_loss: 0.3566 - val_accuracy: 0.8948
# Epoch 136/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3646 - accuracy: 0.8882 - val_loss: 0.3540 - val_accuracy: 0.8990
# Epoch 137/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3582 - accuracy: 0.8866 - val_loss: 0.3641 - val_accuracy: 0.8916
# Epoch 138/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3651 - accuracy: 0.8855 - val_loss: 0.3674 - val_accuracy: 0.8937
# Epoch 139/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3654 - accuracy: 0.8847 - val_loss: 0.3664 - val_accuracy: 0.8948
# Epoch 140/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3689 - accuracy: 0.8828 - val_loss: 0.3544 - val_accuracy: 0.9012
# Epoch 141/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3581 - accuracy: 0.8831 - val_loss: 0.3510 - val_accuracy: 0.9065
# Epoch 142/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3557 - accuracy: 0.8905 - val_loss: 0.3461 - val_accuracy: 0.8990
# Epoch 143/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3558 - accuracy: 0.8874 - val_loss: 0.3457 - val_accuracy: 0.9054
# Epoch 144/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3492 - accuracy: 0.8919 - val_loss: 0.3460 - val_accuracy: 0.9022
# Epoch 145/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3507 - accuracy: 0.8937 - val_loss: 0.3500 - val_accuracy: 0.9044
# Epoch 146/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3544 - accuracy: 0.8874 - val_loss: 0.3422 - val_accuracy: 0.9086
# Epoch 147/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3526 - accuracy: 0.8911 - val_loss: 0.3503 - val_accuracy: 0.8969
# Epoch 148/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3505 - accuracy: 0.8905 - val_loss: 0.3552 - val_accuracy: 0.8969
# Epoch 149/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3528 - accuracy: 0.8887 - val_loss: 0.3529 - val_accuracy: 0.8927
# Epoch 150/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3421 - accuracy: 0.8951 - val_loss: 0.3382 - val_accuracy: 0.9097
# Epoch 151/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3452 - accuracy: 0.8900 - val_loss: 0.3366 - val_accuracy: 0.9044
# Epoch 152/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3382 - accuracy: 0.8964 - val_loss: 0.3338 - val_accuracy: 0.9107
# Epoch 153/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3353 - accuracy: 0.8956 - val_loss: 0.3369 - val_accuracy: 0.9097
# Epoch 154/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3476 - accuracy: 0.8916 - val_loss: 0.3393 - val_accuracy: 0.9118
# Epoch 155/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3423 - accuracy: 0.8921 - val_loss: 0.3357 - val_accuracy: 0.9044
# Epoch 156/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3335 - accuracy: 0.8982 - val_loss: 0.3340 - val_accuracy: 0.9118
# Epoch 157/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3368 - accuracy: 0.8919 - val_loss: 0.3312 - val_accuracy: 0.9097
# Epoch 158/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3343 - accuracy: 0.8953 - val_loss: 0.3412 - val_accuracy: 0.9033
# Epoch 159/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3348 - accuracy: 0.8967 - val_loss: 0.3340 - val_accuracy: 0.9097
# Epoch 160/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3356 - accuracy: 0.8982 - val_loss: 0.3251 - val_accuracy: 0.9097
# Epoch 161/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3302 - accuracy: 0.8953 - val_loss: 0.3261 - val_accuracy: 0.9118
# Epoch 162/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3325 - accuracy: 0.8974 - val_loss: 0.3264 - val_accuracy: 0.9097
# Epoch 163/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3225 - accuracy: 0.9009 - val_loss: 0.3238 - val_accuracy: 0.9129
# Epoch 164/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3252 - accuracy: 0.8993 - val_loss: 0.3246 - val_accuracy: 0.9118
# Epoch 165/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3280 - accuracy: 0.8972 - val_loss: 0.3208 - val_accuracy: 0.9118
# Epoch 166/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3269 - accuracy: 0.8988 - val_loss: 0.3309 - val_accuracy: 0.9065
# Epoch 167/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3241 - accuracy: 0.8988 - val_loss: 0.3367 - val_accuracy: 0.9075
# Epoch 168/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3297 - accuracy: 0.8985 - val_loss: 0.3324 - val_accuracy: 0.9118
# Epoch 169/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3251 - accuracy: 0.9012 - val_loss: 0.3302 - val_accuracy: 0.9065
# Epoch 170/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3260 - accuracy: 0.8967 - val_loss: 0.3332 - val_accuracy: 0.9054
# Epoch 171/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3239 - accuracy: 0.8964 - val_loss: 0.3147 - val_accuracy: 0.9150
# Epoch 172/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3250 - accuracy: 0.9009 - val_loss: 0.3135 - val_accuracy: 0.9086
# Epoch 173/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3103 - accuracy: 0.9057 - val_loss: 0.3148 - val_accuracy: 0.9150
# Epoch 174/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3151 - accuracy: 0.9054 - val_loss: 0.3170 - val_accuracy: 0.9118
# Epoch 175/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3153 - accuracy: 0.8974 - val_loss: 0.3079 - val_accuracy: 0.9150
# Epoch 176/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3051 - accuracy: 0.9046 - val_loss: 0.3083 - val_accuracy: 0.9171
# Epoch 177/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3076 - accuracy: 0.9062 - val_loss: 0.3239 - val_accuracy: 0.9129
# Epoch 178/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3134 - accuracy: 0.9006 - val_loss: 0.3080 - val_accuracy: 0.9171
# Epoch 179/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3089 - accuracy: 0.9033 - val_loss: 0.3054 - val_accuracy: 0.9192
# Epoch 180/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3208 - accuracy: 0.9028 - val_loss: 0.3105 - val_accuracy: 0.9203
# Epoch 181/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3051 - accuracy: 0.9060 - val_loss: 0.3033 - val_accuracy: 0.9150
# Epoch 182/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3063 - accuracy: 0.9052 - val_loss: 0.3056 - val_accuracy: 0.9203
# Epoch 183/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3083 - accuracy: 0.9046 - val_loss: 0.3168 - val_accuracy: 0.9160
# Epoch 184/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3085 - accuracy: 0.9054 - val_loss: 0.3042 - val_accuracy: 0.9160
# Epoch 185/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3065 - accuracy: 0.9030 - val_loss: 0.3103 - val_accuracy: 0.9139
# Epoch 186/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3113 - accuracy: 0.9030 - val_loss: 0.3196 - val_accuracy: 0.9107
# Epoch 187/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3069 - accuracy: 0.9036 - val_loss: 0.3143 - val_accuracy: 0.9150
# Epoch 188/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3023 - accuracy: 0.9065 - val_loss: 0.3055 - val_accuracy: 0.9139
# Epoch 189/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3011 - accuracy: 0.9086 - val_loss: 0.2957 - val_accuracy: 0.9203
# Epoch 190/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2987 - accuracy: 0.9057 - val_loss: 0.3000 - val_accuracy: 0.9214
# Epoch 191/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2991 - accuracy: 0.9094 - val_loss: 0.3014 - val_accuracy: 0.9139
# Epoch 192/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2953 - accuracy: 0.9081 - val_loss: 0.2975 - val_accuracy: 0.9192
# Epoch 193/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2951 - accuracy: 0.9089 - val_loss: 0.2994 - val_accuracy: 0.9150
# Epoch 194/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.2902 - accuracy: 0.9102 - val_loss: 0.3068 - val_accuracy: 0.9118
# Epoch 195/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2937 - accuracy: 0.9110 - val_loss: 0.2950 - val_accuracy: 0.9235
# Epoch 196/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2970 - accuracy: 0.9078 - val_loss: 0.2976 - val_accuracy: 0.9171
# Epoch 197/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2981 - accuracy: 0.9078 - val_loss: 0.2977 - val_accuracy: 0.9235
# Epoch 198/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3010 - accuracy: 0.9017 - val_loss: 0.2948 - val_accuracy: 0.9214
# Epoch 199/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2942 - accuracy: 0.9062 - val_loss: 0.2927 - val_accuracy: 0.9192
# Epoch 200/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2887 - accuracy: 0.9113 - val_loss: 0.2918 - val_accuracy: 0.9182

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 8/8 [==============================] - 0s 48ms/step - loss: 2.0981 - accuracy: 0.2803 - val_loss: 1.8917 - val_accuracy: 0.3401
# Epoch 2/40
# 8/8 [==============================] - 0s 26ms/step - loss: 1.8491 - accuracy: 0.3411 - val_loss: 1.7407 - val_accuracy: 0.4038
# Epoch 3/40
# 8/8 [==============================] - 0s 32ms/step - loss: 1.6983 - accuracy: 0.4527 - val_loss: 1.5565 - val_accuracy: 0.5228
# Epoch 4/40
# 8/8 [==============================] - 0s 31ms/step - loss: 1.5262 - accuracy: 0.4801 - val_loss: 1.4029 - val_accuracy: 0.5484
# Epoch 5/40
# 8/8 [==============================] - 0s 29ms/step - loss: 1.4010 - accuracy: 0.5287 - val_loss: 1.3193 - val_accuracy: 0.5664
# Epoch 6/40
# 8/8 [==============================] - 0s 23ms/step - loss: 1.3390 - accuracy: 0.5377 - val_loss: 1.2679 - val_accuracy: 0.5760
# Epoch 7/40
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2826 - accuracy: 0.5715 - val_loss: 1.2286 - val_accuracy: 0.5664
# Epoch 8/40
# 8/8 [==============================] - 0s 23ms/step - loss: 1.2327 - accuracy: 0.5685 - val_loss: 1.1793 - val_accuracy: 0.6281
# Epoch 9/40
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1903 - accuracy: 0.6068 - val_loss: 1.1447 - val_accuracy: 0.6238
# Epoch 10/40
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1531 - accuracy: 0.6052 - val_loss: 1.1075 - val_accuracy: 0.6312
# Epoch 11/40
# 8/8 [==============================] - 0s 29ms/step - loss: 1.1186 - accuracy: 0.6323 - val_loss: 1.0749 - val_accuracy: 0.6738
# Epoch 12/40
# 8/8 [==============================] - 0s 29ms/step - loss: 1.0886 - accuracy: 0.6366 - val_loss: 1.0451 - val_accuracy: 0.6908
# Epoch 13/40
# 8/8 [==============================] - 0s 28ms/step - loss: 1.0652 - accuracy: 0.6554 - val_loss: 1.0133 - val_accuracy: 0.6823
# Epoch 14/40
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0251 - accuracy: 0.6496 - val_loss: 0.9895 - val_accuracy: 0.6929
# Epoch 15/40
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0076 - accuracy: 0.6700 - val_loss: 0.9702 - val_accuracy: 0.6780
# Epoch 16/40
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9945 - accuracy: 0.6655 - val_loss: 0.9515 - val_accuracy: 0.7226
# Epoch 17/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.9707 - accuracy: 0.6769 - val_loss: 0.9260 - val_accuracy: 0.7194
# Epoch 18/40
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9458 - accuracy: 0.6947 - val_loss: 0.9106 - val_accuracy: 0.7078
# Epoch 19/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.9280 - accuracy: 0.7014 - val_loss: 0.8947 - val_accuracy: 0.7226
# Epoch 20/40
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9086 - accuracy: 0.6982 - val_loss: 0.8799 - val_accuracy: 0.7184
# Epoch 21/40
# 8/8 [==============================] - 0s 34ms/step - loss: 0.8927 - accuracy: 0.7080 - val_loss: 0.8642 - val_accuracy: 0.7216
# Epoch 22/40
# 8/8 [==============================] - 0s 31ms/step - loss: 0.8882 - accuracy: 0.7104 - val_loss: 0.8503 - val_accuracy: 0.7226
# Epoch 23/40
# 8/8 [==============================] - 0s 29ms/step - loss: 0.8651 - accuracy: 0.7192 - val_loss: 0.8357 - val_accuracy: 0.7237
# Epoch 24/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8545 - accuracy: 0.7187 - val_loss: 0.8302 - val_accuracy: 0.7354
# Epoch 25/40
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8374 - accuracy: 0.7197 - val_loss: 0.8133 - val_accuracy: 0.7407
# Epoch 26/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8247 - accuracy: 0.7298 - val_loss: 0.7969 - val_accuracy: 0.7333
# Epoch 27/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.8159 - accuracy: 0.7383 - val_loss: 0.7871 - val_accuracy: 0.7396
# Epoch 28/40
# 8/8 [==============================] - 0s 22ms/step - loss: 0.8070 - accuracy: 0.7394 - val_loss: 0.7728 - val_accuracy: 0.7450
# Epoch 29/40
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7949 - accuracy: 0.7428 - val_loss: 0.7680 - val_accuracy: 0.7333
# Epoch 30/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7862 - accuracy: 0.7420 - val_loss: 0.7558 - val_accuracy: 0.7535
# Epoch 31/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7728 - accuracy: 0.7473 - val_loss: 0.7452 - val_accuracy: 0.7535
# Epoch 32/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7628 - accuracy: 0.7577 - val_loss: 0.7276 - val_accuracy: 0.7694
# Epoch 33/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7520 - accuracy: 0.7635 - val_loss: 0.7188 - val_accuracy: 0.7726
# Epoch 34/40
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7329 - accuracy: 0.7718 - val_loss: 0.7067 - val_accuracy: 0.7779
# Epoch 35/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7219 - accuracy: 0.7707 - val_loss: 0.6935 - val_accuracy: 0.7832
# Epoch 36/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7125 - accuracy: 0.7766 - val_loss: 0.6827 - val_accuracy: 0.7896
# Epoch 37/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7093 - accuracy: 0.7750 - val_loss: 0.6646 - val_accuracy: 0.8002
# Epoch 38/40
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6872 - accuracy: 0.7816 - val_loss: 0.6637 - val_accuracy: 0.8034
# Epoch 39/40
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6863 - accuracy: 0.7885 - val_loss: 0.6467 - val_accuracy: 0.8045
# Epoch 40/40
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6690 - accuracy: 0.7922 - val_loss: 0.6317 - val_accuracy: 0.8225

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.8196
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.8225
# 0.8196067810058594 0.8225291967391968

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 15, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:17

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   0   0   1   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 138   0   0   2   0   0   0]
#  [  3   2   0 115   2   1   0   0   1]
#  [  0   2   0   0 315   3   0   0   0]
#  [  0   1   2   0  41  74   2   0   0]
#  [  0   0   1   0  21   5  21   0   2]
#  [  0   0   1   0  19  13  11   6   0]
#  [  0   0   0   3  17  11   0   0   6]]
#
# Accuracy Score
# 0.822529224229543
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.95      0.98      0.97        60
#      clouds       0.89      1.00      0.94        40
#  vegetation       0.97      0.99      0.98       140
#       water       0.97      0.93      0.95       124
#       built       0.76      0.98      0.86       320
#     windows       0.68      0.62      0.65       120
#       roads       0.62      0.42      0.50        50
#        cars       1.00      0.12      0.21        50
#       metal       0.67      0.16      0.26        37
#
# avg / total       0.83      0.82      0.79       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
