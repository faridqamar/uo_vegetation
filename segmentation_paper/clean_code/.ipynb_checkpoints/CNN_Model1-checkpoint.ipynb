# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### training on each image separately Model 1
#
# ---

# %%
# -- importing necessary libraries
import os
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import layers
from sklearn import metrics
import time
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %% [markdown]
# ### Defining the needed functions

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
# -- splitting text into row index and column index 

def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
# -- transforming individual row and column numbers into an array

def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
# -- function to read the manually classified pixels coordinates
#    given the type of pixels (kind) and image identifier (scan)

def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
# -- function used to split the manually classified pixel coordinates into
#    into training and testing sets given a split ratio (trrat)

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
# -- Create the CNN model using tensorflow.keras

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(32, kernel_size=(5), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(64, kernel_size=(5), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(1024, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
# -- plot the loss history of a CNN model and its accuracy

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 0. Sky
# 1. Clouds
# 2. Water
# 3. Vegetation
# 4. Buildings (concrete structures)
# 5. Windows
# 6. Roads
# 7. Cars
# 8. Metal Structures
# ---

# %% [markdown]
# ---
# # CNN trained and tested on Scene 1-b

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
cube_sub0 = cube0.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)

# -- reshape standardized cube to (row, col, wavelength)
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], cube_sub0.shape[0])
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# -- create position array from coordinates and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
trrat = 0.8  # set train/test ratio to have 80% training, 20% testing

# -- get the coordinates of training and testing sets for each class
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)

cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 848) (80, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (488, 848) (122, 848)
# built  (960, 848) (240, 848)
# windows  (400, 848) (100, 848)
# roads  (48, 848) (12, 848)
# cars  (44, 848) (11, 848)
# metal  (184, 848) (46, 848)

# %%
# -- concatenate the training arrays into training data and labels

cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
cube_train_labels0 = np.array(cube_train_labels0)
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
cube_test_labels0 = np.array(cube_test_labels0)
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0_i = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 2s 259ms/step - loss: 2.4870 - accuracy: 0.3017 - val_loss: 1.4189 - val_accuracy: 0.5134
# Epoch 2/200
# 6/6 [==============================] - 1s 208ms/step - loss: 1.2645 - accuracy: 0.5858 - val_loss: 1.0617 - val_accuracy: 0.6892
# Epoch 3/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.9538 - accuracy: 0.6881 - val_loss: 0.8629 - val_accuracy: 0.7314
# Epoch 4/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.7685 - accuracy: 0.7289 - val_loss: 0.7043 - val_accuracy: 0.7032
# Epoch 5/200
# 6/6 [==============================] - 1s 230ms/step - loss: 0.6230 - accuracy: 0.7602 - val_loss: 0.6018 - val_accuracy: 0.7904
# Epoch 6/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.5309 - accuracy: 0.8038 - val_loss: 0.5339 - val_accuracy: 0.7848
# Epoch 7/200
# 6/6 [==============================] - 2s 380ms/step - loss: 0.4840 - accuracy: 0.8119 - val_loss: 0.5076 - val_accuracy: 0.8031
# Epoch 8/200
# 6/6 [==============================] - 1s 243ms/step - loss: 0.4431 - accuracy: 0.8210 - val_loss: 0.4762 - val_accuracy: 0.8129
# Epoch 9/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.4284 - accuracy: 0.8323 - val_loss: 0.4724 - val_accuracy: 0.8186
# Epoch 10/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.4170 - accuracy: 0.8316 - val_loss: 0.4721 - val_accuracy: 0.8256
# Epoch 11/200
# 6/6 [==============================] - 1s 249ms/step - loss: 0.4250 - accuracy: 0.8383 - val_loss: 0.4814 - val_accuracy: 0.7904
# Epoch 12/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.4185 - accuracy: 0.8291 - val_loss: 0.4384 - val_accuracy: 0.8340
# Epoch 13/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.4000 - accuracy: 0.8565 - val_loss: 0.4194 - val_accuracy: 0.8425
# Epoch 14/200
# 6/6 [==============================] - 1s 224ms/step - loss: 0.3731 - accuracy: 0.8527 - val_loss: 0.4201 - val_accuracy: 0.8495
# Epoch 15/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.3607 - accuracy: 0.8594 - val_loss: 0.4307 - val_accuracy: 0.8326
# Epoch 16/200
# 6/6 [==============================] - 1s 223ms/step - loss: 0.3555 - accuracy: 0.8604 - val_loss: 0.4158 - val_accuracy: 0.8551
# Epoch 17/200
# 6/6 [==============================] - 1s 246ms/step - loss: 0.3577 - accuracy: 0.8699 - val_loss: 0.3788 - val_accuracy: 0.8411
# Epoch 18/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.3328 - accuracy: 0.8783 - val_loss: 0.3747 - val_accuracy: 0.8481
# Epoch 19/200
# 6/6 [==============================] - 2s 283ms/step - loss: 0.3224 - accuracy: 0.8797 - val_loss: 0.3728 - val_accuracy: 0.8467
# Epoch 20/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.3150 - accuracy: 0.8812 - val_loss: 0.3758 - val_accuracy: 0.8467
# Epoch 21/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.3078 - accuracy: 0.8808 - val_loss: 0.3649 - val_accuracy: 0.8594
# Epoch 22/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.3037 - accuracy: 0.8840 - val_loss: 0.3645 - val_accuracy: 0.8467
# Epoch 23/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.3067 - accuracy: 0.8776 - val_loss: 0.3537 - val_accuracy: 0.8537
# Epoch 24/200
# 6/6 [==============================] - 1s 246ms/step - loss: 0.2959 - accuracy: 0.8829 - val_loss: 0.3575 - val_accuracy: 0.8523
# Epoch 25/200
# 6/6 [==============================] - 1s 236ms/step - loss: 0.2900 - accuracy: 0.8850 - val_loss: 0.3448 - val_accuracy: 0.8692
# Epoch 26/200
# 6/6 [==============================] - 1s 211ms/step - loss: 0.2925 - accuracy: 0.8857 - val_loss: 0.3482 - val_accuracy: 0.8594
# Epoch 27/200
# 6/6 [==============================] - 1s 243ms/step - loss: 0.2803 - accuracy: 0.8931 - val_loss: 0.3442 - val_accuracy: 0.8706
# Epoch 28/200
# 6/6 [==============================] - 2s 253ms/step - loss: 0.2845 - accuracy: 0.8914 - val_loss: 0.3394 - val_accuracy: 0.8678
# Epoch 29/200
# 6/6 [==============================] - 1s 219ms/step - loss: 0.2817 - accuracy: 0.8903 - val_loss: 0.3244 - val_accuracy: 0.8692
# Epoch 30/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.2815 - accuracy: 0.8885 - val_loss: 0.3332 - val_accuracy: 0.8579
# Epoch 31/200
# 6/6 [==============================] - 1s 233ms/step - loss: 0.2696 - accuracy: 0.8998 - val_loss: 0.3311 - val_accuracy: 0.8579
# Epoch 32/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.2687 - accuracy: 0.8949 - val_loss: 0.3244 - val_accuracy: 0.8636
# Epoch 33/200
# 6/6 [==============================] - 2s 251ms/step - loss: 0.2584 - accuracy: 0.8966 - val_loss: 0.3243 - val_accuracy: 0.8790
# Epoch 34/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.2536 - accuracy: 0.9037 - val_loss: 0.3233 - val_accuracy: 0.8776
# Epoch 35/200
# 6/6 [==============================] - 1s 249ms/step - loss: 0.2597 - accuracy: 0.8966 - val_loss: 0.3354 - val_accuracy: 0.8608
# Epoch 36/200
# 6/6 [==============================] - 1s 232ms/step - loss: 0.2520 - accuracy: 0.9044 - val_loss: 0.3561 - val_accuracy: 0.8439
# Epoch 37/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.2660 - accuracy: 0.8966 - val_loss: 0.3906 - val_accuracy: 0.8608
# Epoch 38/200
# 6/6 [==============================] - 2s 277ms/step - loss: 0.2856 - accuracy: 0.8840 - val_loss: 0.3541 - val_accuracy: 0.8425
# Epoch 39/200
# 6/6 [==============================] - 1s 230ms/step - loss: 0.3056 - accuracy: 0.8797 - val_loss: 0.4112 - val_accuracy: 0.8256
# Epoch 40/200
# 6/6 [==============================] - 1s 223ms/step - loss: 0.2785 - accuracy: 0.8878 - val_loss: 0.3072 - val_accuracy: 0.8636
# Epoch 41/200
# 6/6 [==============================] - 1s 242ms/step - loss: 0.2480 - accuracy: 0.9061 - val_loss: 0.3186 - val_accuracy: 0.8790
# Epoch 42/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.2404 - accuracy: 0.9139 - val_loss: 0.3321 - val_accuracy: 0.8762
# Epoch 43/200
# 6/6 [==============================] - 2s 274ms/step - loss: 0.2346 - accuracy: 0.9121 - val_loss: 0.3207 - val_accuracy: 0.8903
# Epoch 44/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.2158 - accuracy: 0.9209 - val_loss: 0.2887 - val_accuracy: 0.8903
# Epoch 45/200
# 6/6 [==============================] - 1s 245ms/step - loss: 0.2044 - accuracy: 0.9244 - val_loss: 0.3081 - val_accuracy: 0.8790
# Epoch 46/200
# 6/6 [==============================] - 1s 245ms/step - loss: 0.2115 - accuracy: 0.9212 - val_loss: 0.3144 - val_accuracy: 0.8776
# Epoch 47/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.2008 - accuracy: 0.9237 - val_loss: 0.3139 - val_accuracy: 0.8776
# Epoch 48/200
# 6/6 [==============================] - 1s 234ms/step - loss: 0.2078 - accuracy: 0.9241 - val_loss: 0.2879 - val_accuracy: 0.8945
# Epoch 49/200
# 6/6 [==============================] - 1s 226ms/step - loss: 0.2017 - accuracy: 0.9244 - val_loss: 0.2940 - val_accuracy: 0.8790
# Epoch 50/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1979 - accuracy: 0.9258 - val_loss: 0.2884 - val_accuracy: 0.8931
# Epoch 51/200
# 6/6 [==============================] - 2s 251ms/step - loss: 0.2056 - accuracy: 0.9248 - val_loss: 0.3074 - val_accuracy: 0.8776
# Epoch 52/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.2057 - accuracy: 0.9255 - val_loss: 0.2934 - val_accuracy: 0.8917
# Epoch 53/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.1928 - accuracy: 0.9293 - val_loss: 0.2837 - val_accuracy: 0.8847
# Epoch 54/200
# 6/6 [==============================] - 2s 254ms/step - loss: 0.1954 - accuracy: 0.9286 - val_loss: 0.2924 - val_accuracy: 0.8973
# Epoch 55/200
# 6/6 [==============================] - 1s 226ms/step - loss: 0.1998 - accuracy: 0.9241 - val_loss: 0.3197 - val_accuracy: 0.8790
# Epoch 56/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.1947 - accuracy: 0.9244 - val_loss: 0.2845 - val_accuracy: 0.8776
# Epoch 57/200
# 6/6 [==============================] - 2s 276ms/step - loss: 0.1757 - accuracy: 0.9342 - val_loss: 0.2787 - val_accuracy: 0.8790
# Epoch 58/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.1803 - accuracy: 0.9321 - val_loss: 0.3008 - val_accuracy: 0.8748
# Epoch 59/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.1820 - accuracy: 0.9293 - val_loss: 0.2711 - val_accuracy: 0.9001
# Epoch 60/200
# 6/6 [==============================] - 2s 264ms/step - loss: 0.1782 - accuracy: 0.9392 - val_loss: 0.2980 - val_accuracy: 0.8861
# Epoch 61/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1867 - accuracy: 0.9297 - val_loss: 0.2823 - val_accuracy: 0.8861
# Epoch 62/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.1747 - accuracy: 0.9360 - val_loss: 0.2969 - val_accuracy: 0.8748
# Epoch 63/200
# 6/6 [==============================] - 2s 258ms/step - loss: 0.1774 - accuracy: 0.9311 - val_loss: 0.2733 - val_accuracy: 0.9030
# Epoch 64/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.1686 - accuracy: 0.9427 - val_loss: 0.2996 - val_accuracy: 0.8959
# Epoch 65/200
# 6/6 [==============================] - 1s 239ms/step - loss: 0.1672 - accuracy: 0.9378 - val_loss: 0.2770 - val_accuracy: 0.8959
# Epoch 66/200
# 6/6 [==============================] - 1s 236ms/step - loss: 0.1541 - accuracy: 0.9437 - val_loss: 0.3334 - val_accuracy: 0.8762
# Epoch 67/200
# 6/6 [==============================] - 1s 197ms/step - loss: 0.1686 - accuracy: 0.9346 - val_loss: 0.3076 - val_accuracy: 0.8973
# Epoch 68/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.1648 - accuracy: 0.9402 - val_loss: 0.2864 - val_accuracy: 0.8889
# Epoch 69/200
# 6/6 [==============================] - 2s 253ms/step - loss: 0.1559 - accuracy: 0.9451 - val_loss: 0.2610 - val_accuracy: 0.9015
# Epoch 70/200
# 6/6 [==============================] - 1s 201ms/step - loss: 0.1427 - accuracy: 0.9494 - val_loss: 0.2526 - val_accuracy: 0.8987
# Epoch 71/200
# 6/6 [==============================] - 1s 233ms/step - loss: 0.1346 - accuracy: 0.9543 - val_loss: 0.2536 - val_accuracy: 0.9058
# Epoch 72/200
# 6/6 [==============================] - 1s 231ms/step - loss: 0.1338 - accuracy: 0.9525 - val_loss: 0.2559 - val_accuracy: 0.8917
# Epoch 73/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.1322 - accuracy: 0.9543 - val_loss: 0.2629 - val_accuracy: 0.9100
# Epoch 74/200
# 6/6 [==============================] - 2s 254ms/step - loss: 0.1349 - accuracy: 0.9511 - val_loss: 0.2563 - val_accuracy: 0.9100
# Epoch 75/200
# 6/6 [==============================] - 1s 225ms/step - loss: 0.1257 - accuracy: 0.9578 - val_loss: 0.2492 - val_accuracy: 0.8973
# Epoch 76/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.1313 - accuracy: 0.9550 - val_loss: 0.2582 - val_accuracy: 0.9072
# Epoch 77/200
# 6/6 [==============================] - 1s 239ms/step - loss: 0.1358 - accuracy: 0.9501 - val_loss: 0.2559 - val_accuracy: 0.8987
# Epoch 78/200
# 6/6 [==============================] - 1s 225ms/step - loss: 0.1269 - accuracy: 0.9508 - val_loss: 0.2460 - val_accuracy: 0.9015
# Epoch 79/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.1182 - accuracy: 0.9631 - val_loss: 0.2524 - val_accuracy: 0.9072
# Epoch 80/200
# 6/6 [==============================] - 2s 263ms/step - loss: 0.1232 - accuracy: 0.9610 - val_loss: 0.2415 - val_accuracy: 0.9114
# Epoch 81/200
# 6/6 [==============================] - 2s 378ms/step - loss: 0.1276 - accuracy: 0.9560 - val_loss: 0.2496 - val_accuracy: 0.9086
# Epoch 82/200
# 6/6 [==============================] - 1s 243ms/step - loss: 0.1176 - accuracy: 0.9627 - val_loss: 0.2583 - val_accuracy: 0.9072
# Epoch 83/200
# 6/6 [==============================] - 2s 256ms/step - loss: 0.1162 - accuracy: 0.9613 - val_loss: 0.2522 - val_accuracy: 0.9058
# Epoch 84/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.1096 - accuracy: 0.9606 - val_loss: 0.2844 - val_accuracy: 0.9001
# Epoch 85/200
# 6/6 [==============================] - 2s 259ms/step - loss: 0.1168 - accuracy: 0.9624 - val_loss: 0.2564 - val_accuracy: 0.9086
# Epoch 86/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.1198 - accuracy: 0.9553 - val_loss: 0.2455 - val_accuracy: 0.9100
# Epoch 87/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.1106 - accuracy: 0.9648 - val_loss: 0.2646 - val_accuracy: 0.8973
# Epoch 88/200
# 6/6 [==============================] - 2s 265ms/step - loss: 0.1146 - accuracy: 0.9599 - val_loss: 0.2432 - val_accuracy: 0.9072
# Epoch 89/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.1040 - accuracy: 0.9659 - val_loss: 0.2517 - val_accuracy: 0.9015
# Epoch 90/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.1077 - accuracy: 0.9638 - val_loss: 0.2395 - val_accuracy: 0.9030
# Epoch 91/200
# 6/6 [==============================] - 2s 252ms/step - loss: 0.1023 - accuracy: 0.9634 - val_loss: 0.2467 - val_accuracy: 0.9015
# Epoch 92/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0983 - accuracy: 0.9712 - val_loss: 0.2490 - val_accuracy: 0.9100
# Epoch 93/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.1057 - accuracy: 0.9645 - val_loss: 0.2757 - val_accuracy: 0.9058
# Epoch 94/200
# 6/6 [==============================] - 1s 234ms/step - loss: 0.1037 - accuracy: 0.9624 - val_loss: 0.2507 - val_accuracy: 0.9015
# Epoch 95/200
# 6/6 [==============================] - 1s 215ms/step - loss: 0.0976 - accuracy: 0.9684 - val_loss: 0.2529 - val_accuracy: 0.9001
# Epoch 96/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0863 - accuracy: 0.9757 - val_loss: 0.2580 - val_accuracy: 0.9072
# Epoch 97/200
# 6/6 [==============================] - 2s 264ms/step - loss: 0.0918 - accuracy: 0.9691 - val_loss: 0.2502 - val_accuracy: 0.9114
# Epoch 98/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.0904 - accuracy: 0.9740 - val_loss: 0.2559 - val_accuracy: 0.9086
# Epoch 99/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.0832 - accuracy: 0.9750 - val_loss: 0.2413 - val_accuracy: 0.9114
# Epoch 100/200
# 6/6 [==============================] - 2s 256ms/step - loss: 0.0839 - accuracy: 0.9747 - val_loss: 0.2409 - val_accuracy: 0.9015
# Epoch 101/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.0902 - accuracy: 0.9680 - val_loss: 0.2529 - val_accuracy: 0.9001
# Epoch 102/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0931 - accuracy: 0.9705 - val_loss: 0.2801 - val_accuracy: 0.8987
# Epoch 103/200
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0840 - accuracy: 0.9740 - val_loss: 0.2842 - val_accuracy: 0.8973
# Epoch 104/200
# 6/6 [==============================] - 1s 220ms/step - loss: 0.0831 - accuracy: 0.9712 - val_loss: 0.2570 - val_accuracy: 0.9058
# Epoch 105/200
# 6/6 [==============================] - 1s 243ms/step - loss: 0.0830 - accuracy: 0.9722 - val_loss: 0.2476 - val_accuracy: 0.9086
# Epoch 106/200
# 6/6 [==============================] - 1s 242ms/step - loss: 0.0850 - accuracy: 0.9705 - val_loss: 0.2753 - val_accuracy: 0.9058
# Epoch 107/200
# 6/6 [==============================] - 1s 224ms/step - loss: 0.0794 - accuracy: 0.9757 - val_loss: 0.2423 - val_accuracy: 0.9128
# Epoch 108/200
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0735 - accuracy: 0.9750 - val_loss: 0.2467 - val_accuracy: 0.9086
# Epoch 109/200
# 6/6 [==============================] - 1s 245ms/step - loss: 0.0622 - accuracy: 0.9835 - val_loss: 0.2600 - val_accuracy: 0.9086
# Epoch 110/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0790 - accuracy: 0.9750 - val_loss: 0.2518 - val_accuracy: 0.9015
# Epoch 111/200
# 6/6 [==============================] - 1s 246ms/step - loss: 0.0767 - accuracy: 0.9747 - val_loss: 0.2666 - val_accuracy: 0.9128
# Epoch 112/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.0812 - accuracy: 0.9719 - val_loss: 0.2531 - val_accuracy: 0.9100
# Epoch 113/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0752 - accuracy: 0.9761 - val_loss: 0.2874 - val_accuracy: 0.8889
# Epoch 114/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.0786 - accuracy: 0.9754 - val_loss: 0.2398 - val_accuracy: 0.9100
# Epoch 115/200
# 6/6 [==============================] - 1s 231ms/step - loss: 0.0791 - accuracy: 0.9740 - val_loss: 0.2530 - val_accuracy: 0.9100
# Epoch 116/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.0656 - accuracy: 0.9800 - val_loss: 0.2526 - val_accuracy: 0.8973
# Epoch 117/200
# 6/6 [==============================] - 1s 224ms/step - loss: 0.0659 - accuracy: 0.9786 - val_loss: 0.2413 - val_accuracy: 0.9142
# Epoch 118/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.0611 - accuracy: 0.9814 - val_loss: 0.2519 - val_accuracy: 0.9058
# Epoch 119/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0565 - accuracy: 0.9845 - val_loss: 0.2798 - val_accuracy: 0.9030
# Epoch 120/200
# 6/6 [==============================] - 2s 260ms/step - loss: 0.0608 - accuracy: 0.9796 - val_loss: 0.2665 - val_accuracy: 0.9030
# Epoch 121/200
# 6/6 [==============================] - 1s 218ms/step - loss: 0.0556 - accuracy: 0.9849 - val_loss: 0.2537 - val_accuracy: 0.9156
# Epoch 122/200
# 6/6 [==============================] - 1s 217ms/step - loss: 0.0566 - accuracy: 0.9803 - val_loss: 0.2642 - val_accuracy: 0.9198
# Epoch 123/200
# 6/6 [==============================] - 2s 250ms/step - loss: 0.0547 - accuracy: 0.9852 - val_loss: 0.2883 - val_accuracy: 0.9058
# Epoch 124/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.0648 - accuracy: 0.9786 - val_loss: 0.2776 - val_accuracy: 0.9128
# Epoch 125/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.0578 - accuracy: 0.9838 - val_loss: 0.2755 - val_accuracy: 0.9156
# Epoch 126/200
# 6/6 [==============================] - 1s 241ms/step - loss: 0.0610 - accuracy: 0.9803 - val_loss: 0.2658 - val_accuracy: 0.9142
# Epoch 127/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0580 - accuracy: 0.9821 - val_loss: 0.2627 - val_accuracy: 0.9058
# Epoch 128/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0576 - accuracy: 0.9807 - val_loss: 0.2627 - val_accuracy: 0.8987
# Epoch 129/200
# 6/6 [==============================] - 2s 253ms/step - loss: 0.0566 - accuracy: 0.9831 - val_loss: 0.2470 - val_accuracy: 0.9142
# Epoch 130/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0444 - accuracy: 0.9887 - val_loss: 0.2549 - val_accuracy: 0.9184
# Epoch 131/200
# 6/6 [==============================] - 1s 194ms/step - loss: 0.0433 - accuracy: 0.9873 - val_loss: 0.2539 - val_accuracy: 0.9114
# Epoch 132/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.0507 - accuracy: 0.9842 - val_loss: 0.2631 - val_accuracy: 0.9072
# Epoch 133/200
# 6/6 [==============================] - 1s 205ms/step - loss: 0.0552 - accuracy: 0.9835 - val_loss: 0.2600 - val_accuracy: 0.9044
# Epoch 134/200
# 6/6 [==============================] - 1s 190ms/step - loss: 0.0539 - accuracy: 0.9838 - val_loss: 0.2723 - val_accuracy: 0.9156
# Epoch 135/200
# 6/6 [==============================] - 1s 230ms/step - loss: 0.0507 - accuracy: 0.9842 - val_loss: 0.2614 - val_accuracy: 0.9114
# Epoch 136/200
# 6/6 [==============================] - 1s 221ms/step - loss: 0.0444 - accuracy: 0.9880 - val_loss: 0.2620 - val_accuracy: 0.9086
# Epoch 137/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0429 - accuracy: 0.9895 - val_loss: 0.2629 - val_accuracy: 0.9184
# Epoch 138/200
# 6/6 [==============================] - 1s 244ms/step - loss: 0.0431 - accuracy: 0.9873 - val_loss: 0.2950 - val_accuracy: 0.9072
# Epoch 139/200
# 6/6 [==============================] - 2s 258ms/step - loss: 0.0463 - accuracy: 0.9849 - val_loss: 0.2722 - val_accuracy: 0.9128
# Epoch 140/200
# 6/6 [==============================] - 1s 223ms/step - loss: 0.0409 - accuracy: 0.9870 - val_loss: 0.2596 - val_accuracy: 0.9142
# Epoch 141/200
# 6/6 [==============================] - 2s 262ms/step - loss: 0.0464 - accuracy: 0.9849 - val_loss: 0.2646 - val_accuracy: 0.9198
# Epoch 142/200
# 6/6 [==============================] - 1s 227ms/step - loss: 0.0443 - accuracy: 0.9887 - val_loss: 0.2637 - val_accuracy: 0.9184
# Epoch 143/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0372 - accuracy: 0.9912 - val_loss: 0.2704 - val_accuracy: 0.9142
# Epoch 144/200
# 6/6 [==============================] - 2s 252ms/step - loss: 0.0392 - accuracy: 0.9884 - val_loss: 0.2600 - val_accuracy: 0.9086
# Epoch 145/200
# 6/6 [==============================] - 1s 229ms/step - loss: 0.0414 - accuracy: 0.9877 - val_loss: 0.2609 - val_accuracy: 0.9198
# Epoch 146/200
# 6/6 [==============================] - 1s 244ms/step - loss: 0.0413 - accuracy: 0.9891 - val_loss: 0.3176 - val_accuracy: 0.9001
# Epoch 147/200
# 6/6 [==============================] - 1s 247ms/step - loss: 0.0459 - accuracy: 0.9859 - val_loss: 0.2759 - val_accuracy: 0.9114
# Epoch 148/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0436 - accuracy: 0.9870 - val_loss: 0.2574 - val_accuracy: 0.9128
# Epoch 149/200
# 6/6 [==============================] - 2s 266ms/step - loss: 0.0410 - accuracy: 0.9880 - val_loss: 0.2726 - val_accuracy: 0.9072
# Epoch 150/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0382 - accuracy: 0.9912 - val_loss: 0.2824 - val_accuracy: 0.9100
# Epoch 151/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0378 - accuracy: 0.9905 - val_loss: 0.2579 - val_accuracy: 0.9198
# Epoch 152/200
# 6/6 [==============================] - 2s 269ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.2718 - val_accuracy: 0.9156
# Epoch 153/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0349 - accuracy: 0.9902 - val_loss: 0.2745 - val_accuracy: 0.9241
# Epoch 154/200
# 6/6 [==============================] - 1s 200ms/step - loss: 0.0279 - accuracy: 0.9940 - val_loss: 0.2730 - val_accuracy: 0.9198
# Epoch 155/200
# 6/6 [==============================] - 2s 259ms/step - loss: 0.0319 - accuracy: 0.9919 - val_loss: 0.2728 - val_accuracy: 0.9114
# Epoch 156/200
# 6/6 [==============================] - 1s 212ms/step - loss: 0.0304 - accuracy: 0.9926 - val_loss: 0.2902 - val_accuracy: 0.9156
# Epoch 157/200
# 6/6 [==============================] - 1s 202ms/step - loss: 0.0333 - accuracy: 0.9912 - val_loss: 0.3191 - val_accuracy: 0.9142
# Epoch 158/200
# 6/6 [==============================] - 1s 249ms/step - loss: 0.0279 - accuracy: 0.9933 - val_loss: 0.2889 - val_accuracy: 0.9072
# Epoch 159/200
# 6/6 [==============================] - 1s 199ms/step - loss: 0.0270 - accuracy: 0.9933 - val_loss: 0.2773 - val_accuracy: 0.9170
# Epoch 160/200
# 6/6 [==============================] - 1s 204ms/step - loss: 0.0281 - accuracy: 0.9937 - val_loss: 0.2641 - val_accuracy: 0.9184
# Epoch 161/200
# 6/6 [==============================] - 1s 211ms/step - loss: 0.0279 - accuracy: 0.9944 - val_loss: 0.2657 - val_accuracy: 0.9198
# Epoch 162/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0329 - accuracy: 0.9898 - val_loss: 0.2707 - val_accuracy: 0.9184
# Epoch 163/200
# 6/6 [==============================] - 1s 190ms/step - loss: 0.0272 - accuracy: 0.9933 - val_loss: 0.2814 - val_accuracy: 0.9156
# Epoch 164/200
# 6/6 [==============================] - 1s 242ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.2757 - val_accuracy: 0.9184
# Epoch 165/200
# 6/6 [==============================] - 1s 228ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.2998 - val_accuracy: 0.9142
# Epoch 166/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0287 - accuracy: 0.9923 - val_loss: 0.3227 - val_accuracy: 0.9072
# Epoch 167/200
# 6/6 [==============================] - 1s 236ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 0.3277 - val_accuracy: 0.9142
# Epoch 168/200
# 6/6 [==============================] - 1s 227ms/step - loss: 0.0306 - accuracy: 0.9916 - val_loss: 0.2950 - val_accuracy: 0.9184
# Epoch 169/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.2725 - val_accuracy: 0.9184
# Epoch 170/200
# 6/6 [==============================] - 1s 236ms/step - loss: 0.0246 - accuracy: 0.9940 - val_loss: 0.2752 - val_accuracy: 0.9156
# Epoch 171/200
# 6/6 [==============================] - 1s 228ms/step - loss: 0.0249 - accuracy: 0.9923 - val_loss: 0.2722 - val_accuracy: 0.9128
# Epoch 172/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0230 - accuracy: 0.9933 - val_loss: 0.2759 - val_accuracy: 0.9170
# Epoch 173/200
# 6/6 [==============================] - 1s 248ms/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 0.2786 - val_accuracy: 0.9184
# Epoch 174/200
# 6/6 [==============================] - 1s 226ms/step - loss: 0.0211 - accuracy: 0.9958 - val_loss: 0.2814 - val_accuracy: 0.9170
# Epoch 175/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.0217 - accuracy: 0.9944 - val_loss: 0.2812 - val_accuracy: 0.9170
# Epoch 176/200
# 6/6 [==============================] - 1s 232ms/step - loss: 0.0218 - accuracy: 0.9951 - val_loss: 0.2754 - val_accuracy: 0.9212
# Epoch 177/200
# 6/6 [==============================] - 1s 238ms/step - loss: 0.0178 - accuracy: 0.9965 - val_loss: 0.3153 - val_accuracy: 0.9184
# Epoch 178/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.0242 - accuracy: 0.9916 - val_loss: 0.2888 - val_accuracy: 0.9128
# Epoch 179/200
# 6/6 [==============================] - 2s 267ms/step - loss: 0.0182 - accuracy: 0.9972 - val_loss: 0.2810 - val_accuracy: 0.9170
# Epoch 180/200
# 6/6 [==============================] - 1s 210ms/step - loss: 0.0167 - accuracy: 0.9975 - val_loss: 0.2960 - val_accuracy: 0.9156
# Epoch 181/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 0.2992 - val_accuracy: 0.9170
# Epoch 182/200
# 6/6 [==============================] - 2s 258ms/step - loss: 0.0187 - accuracy: 0.9965 - val_loss: 0.2843 - val_accuracy: 0.9198
# Epoch 183/200
# 6/6 [==============================] - 1s 203ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.2877 - val_accuracy: 0.9212
# Epoch 184/200
# 6/6 [==============================] - 1s 242ms/step - loss: 0.0183 - accuracy: 0.9954 - val_loss: 0.2944 - val_accuracy: 0.9198
# Epoch 185/200
# 6/6 [==============================] - 2s 254ms/step - loss: 0.0204 - accuracy: 0.9951 - val_loss: 0.3056 - val_accuracy: 0.9072
# Epoch 186/200
# 6/6 [==============================] - 1s 208ms/step - loss: 0.0159 - accuracy: 0.9975 - val_loss: 0.2916 - val_accuracy: 0.9184
# Epoch 187/200
# 6/6 [==============================] - 1s 242ms/step - loss: 0.0207 - accuracy: 0.9958 - val_loss: 0.2963 - val_accuracy: 0.9198
# Epoch 188/200
# 6/6 [==============================] - 1s 240ms/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 0.2987 - val_accuracy: 0.9142
# Epoch 189/200
# 6/6 [==============================] - 1s 206ms/step - loss: 0.0144 - accuracy: 0.9975 - val_loss: 0.2943 - val_accuracy: 0.9226
# Epoch 190/200
# 6/6 [==============================] - 2s 264ms/step - loss: 0.0148 - accuracy: 0.9982 - val_loss: 0.2864 - val_accuracy: 0.9142
# Epoch 191/200
# 6/6 [==============================] - 1s 214ms/step - loss: 0.0158 - accuracy: 0.9965 - val_loss: 0.2996 - val_accuracy: 0.9170
# Epoch 192/200
# 6/6 [==============================] - 1s 196ms/step - loss: 0.0168 - accuracy: 0.9968 - val_loss: 0.3029 - val_accuracy: 0.9156
# Epoch 193/200
# 6/6 [==============================] - 2s 259ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.3060 - val_accuracy: 0.9184
# Epoch 194/200
# 6/6 [==============================] - 1s 207ms/step - loss: 0.0164 - accuracy: 0.9972 - val_loss: 0.3130 - val_accuracy: 0.9170
# Epoch 195/200
# 6/6 [==============================] - 1s 192ms/step - loss: 0.0138 - accuracy: 0.9979 - val_loss: 0.3175 - val_accuracy: 0.9184
# Epoch 196/200
# 6/6 [==============================] - 2s 251ms/step - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.2941 - val_accuracy: 0.9184
# Epoch 197/200
# 6/6 [==============================] - 1s 213ms/step - loss: 0.0151 - accuracy: 0.9965 - val_loss: 0.2995 - val_accuracy: 0.9184
# Epoch 198/200
# 6/6 [==============================] - 1s 189ms/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 0.3104 - val_accuracy: 0.9184
# Epoch 199/200
# 6/6 [==============================] - 1s 222ms/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 0.2989 - val_accuracy: 0.9212
# Epoch 200/200
# 6/6 [==============================] - 1s 209ms/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 0.2922 - val_accuracy: 0.9184

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodel0)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 6/6 [==============================] - 2s 263ms/step - loss: 2.4348 - accuracy: 0.2314 - val_loss: 1.4992 - val_accuracy: 0.5162
# Epoch 2/40
# 6/6 [==============================] - 1s 205ms/step - loss: 1.3616 - accuracy: 0.5594 - val_loss: 1.1583 - val_accuracy: 0.6807
# Epoch 3/40
# 6/6 [==============================] - 1s 228ms/step - loss: 1.0460 - accuracy: 0.6624 - val_loss: 0.9455 - val_accuracy: 0.7032
# Epoch 4/40
# 6/6 [==============================] - 1s 239ms/step - loss: 0.8601 - accuracy: 0.7057 - val_loss: 0.7712 - val_accuracy: 0.7229
# Epoch 5/40
# 6/6 [==============================] - 1s 205ms/step - loss: 0.7056 - accuracy: 0.7324 - val_loss: 0.6829 - val_accuracy: 0.7173
# Epoch 6/40
# 6/6 [==============================] - 1s 192ms/step - loss: 0.5948 - accuracy: 0.7679 - val_loss: 0.5665 - val_accuracy: 0.8017
# Epoch 7/40
# 6/6 [==============================] - 1s 219ms/step - loss: 0.5066 - accuracy: 0.8133 - val_loss: 0.5242 - val_accuracy: 0.8158
# Epoch 8/40
# 6/6 [==============================] - 1s 207ms/step - loss: 0.4642 - accuracy: 0.8115 - val_loss: 0.4971 - val_accuracy: 0.7792
# Epoch 9/40
# 6/6 [==============================] - 1s 184ms/step - loss: 0.4404 - accuracy: 0.8186 - val_loss: 0.4920 - val_accuracy: 0.8228
# Epoch 10/40
# 6/6 [==============================] - 1s 214ms/step - loss: 0.4202 - accuracy: 0.8372 - val_loss: 0.4451 - val_accuracy: 0.8228
# Epoch 11/40
# 6/6 [==============================] - 1s 236ms/step - loss: 0.4054 - accuracy: 0.8418 - val_loss: 0.4616 - val_accuracy: 0.8214
# Epoch 12/40
# 6/6 [==============================] - 1s 200ms/step - loss: 0.4070 - accuracy: 0.8383 - val_loss: 0.5311 - val_accuracy: 0.8214
# Epoch 13/40
# 6/6 [==============================] - 1s 211ms/step - loss: 0.4508 - accuracy: 0.8295 - val_loss: 0.4514 - val_accuracy: 0.8087
# Epoch 14/40
# 6/6 [==============================] - 1s 227ms/step - loss: 0.4070 - accuracy: 0.8333 - val_loss: 0.4203 - val_accuracy: 0.8186
# Epoch 15/40
# 6/6 [==============================] - 1s 191ms/step - loss: 0.3751 - accuracy: 0.8534 - val_loss: 0.3927 - val_accuracy: 0.8467
# Epoch 16/40
# 6/6 [==============================] - 1s 212ms/step - loss: 0.3879 - accuracy: 0.8509 - val_loss: 0.4001 - val_accuracy: 0.8481
# Epoch 17/40
# 6/6 [==============================] - 1s 222ms/step - loss: 0.3616 - accuracy: 0.8572 - val_loss: 0.3983 - val_accuracy: 0.8636
# Epoch 18/40
# 6/6 [==============================] - 1s 204ms/step - loss: 0.3380 - accuracy: 0.8720 - val_loss: 0.3788 - val_accuracy: 0.8495
# Epoch 19/40
# 6/6 [==============================] - 1s 198ms/step - loss: 0.3414 - accuracy: 0.8706 - val_loss: 0.4119 - val_accuracy: 0.8439
# Epoch 20/40
# 6/6 [==============================] - 1s 231ms/step - loss: 0.3314 - accuracy: 0.8710 - val_loss: 0.4073 - val_accuracy: 0.8481
# Epoch 21/40
# 6/6 [==============================] - 1s 204ms/step - loss: 0.3407 - accuracy: 0.8692 - val_loss: 0.3644 - val_accuracy: 0.8551
# Epoch 22/40
# 6/6 [==============================] - 1s 200ms/step - loss: 0.3154 - accuracy: 0.8812 - val_loss: 0.3685 - val_accuracy: 0.8551
# Epoch 23/40
# 6/6 [==============================] - 1s 236ms/step - loss: 0.3102 - accuracy: 0.8741 - val_loss: 0.3619 - val_accuracy: 0.8664
# Epoch 24/40
# 6/6 [==============================] - 1s 211ms/step - loss: 0.3071 - accuracy: 0.8822 - val_loss: 0.3628 - val_accuracy: 0.8551
# Epoch 25/40
# 6/6 [==============================] - 1s 200ms/step - loss: 0.3057 - accuracy: 0.8843 - val_loss: 0.3551 - val_accuracy: 0.8537
# Epoch 26/40
# 6/6 [==============================] - 2s 268ms/step - loss: 0.3108 - accuracy: 0.8850 - val_loss: 0.3456 - val_accuracy: 0.8537
# Epoch 27/40
# 6/6 [==============================] - 1s 216ms/step - loss: 0.2924 - accuracy: 0.8836 - val_loss: 0.3483 - val_accuracy: 0.8565
# Epoch 28/40
# 6/6 [==============================] - 1s 209ms/step - loss: 0.2929 - accuracy: 0.8871 - val_loss: 0.3694 - val_accuracy: 0.8565
# Epoch 29/40
# 6/6 [==============================] - 1s 247ms/step - loss: 0.3007 - accuracy: 0.8833 - val_loss: 0.3543 - val_accuracy: 0.8411
# Epoch 30/40
# 6/6 [==============================] - 1s 217ms/step - loss: 0.2981 - accuracy: 0.8797 - val_loss: 0.3480 - val_accuracy: 0.8509
# Epoch 31/40
# 6/6 [==============================] - 1s 192ms/step - loss: 0.2865 - accuracy: 0.8906 - val_loss: 0.3410 - val_accuracy: 0.8579
# Epoch 32/40
# 6/6 [==============================] - 1s 209ms/step - loss: 0.2829 - accuracy: 0.8910 - val_loss: 0.3314 - val_accuracy: 0.8706
# Epoch 33/40
# 6/6 [==============================] - 1s 222ms/step - loss: 0.2705 - accuracy: 0.8994 - val_loss: 0.3264 - val_accuracy: 0.8692
# Epoch 34/40
# 6/6 [==============================] - 1s 188ms/step - loss: 0.2594 - accuracy: 0.9015 - val_loss: 0.3210 - val_accuracy: 0.8734
# Epoch 35/40
# 6/6 [==============================] - 1s 240ms/step - loss: 0.2636 - accuracy: 0.8977 - val_loss: 0.3178 - val_accuracy: 0.8805
# Epoch 36/40
# 6/6 [==============================] - 1s 217ms/step - loss: 0.2577 - accuracy: 0.8980 - val_loss: 0.3281 - val_accuracy: 0.8720
# Epoch 37/40
# 6/6 [==============================] - 1s 201ms/step - loss: 0.2591 - accuracy: 0.8987 - val_loss: 0.3453 - val_accuracy: 0.8579
# Epoch 38/40
# 6/6 [==============================] - 1s 242ms/step - loss: 0.2639 - accuracy: 0.8998 - val_loss: 0.3290 - val_accuracy: 0.8636
# Epoch 39/40
# 6/6 [==============================] - 1s 229ms/step - loss: 0.2625 - accuracy: 0.8984 - val_loss: 0.3184 - val_accuracy: 0.8847
# Epoch 40/40
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2427 - accuracy: 0.9044 - val_loss: 0.3068 - val_accuracy: 0.8678

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 1s 12ms/step - loss: 0.2222 - accuracy: 0.9128
# 23/23 [==============================] - 0s 11ms/step - loss: 0.3068 - accuracy: 0.8678
# 0.9127988815307617 0.8677918314933777

# %% [markdown]
# ### Predict pixel classification on all of Scene 1-b

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])

start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})
predictCube0 = probCube0.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:13:26

# %%
# -- Plot the prediction map of Scene 1-b

predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
# -- create the prediction arrays from the predictions of the testing set

labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg,
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# -- create the true arrays from the labeled testing set 

labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, 
                               labels0_true_cars, labels0_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-b

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   1 119   2   0   0   0   0]
#  [  0   1   0 210  27   0   0   2]
#  [  0   0   0  16  76   0   1   7]
#  [  0   0   0   0   1  11   0   0]
#  [  0   0   0   0   2   4   5   0]
#  [  0   0   0  17  13   0   0  16]]
#
# Accuracy Score
# 0.8677918424753868
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        80
#      clouds       0.98      1.00      0.99       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.86      0.88      0.87       240
#     windows       0.64      0.76      0.69       100
#       roads       0.73      0.92      0.81        12
#        cars       0.83      0.45      0.59        11
#       metal       0.64      0.35      0.45        46
#
# avg / total       0.87      0.87      0.86       711

# %% [markdown]
# ---
# # CNN trained on Scene 2

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
cube_sub_north = cube_north.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]),
                                                                cube_sub_north.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)

# -- reshape standardized cube to (row, col, wavelength)
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], cube_sub_north.shape[0])
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
# -- create position array from coordinates and normalize

xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
trrat = 0.8  # set train/test ratio to have 80% training, 20% testing

# -- get the coordinates of training and testing sets for each class
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 872) (60, 872)
# clouds  (160, 872) (40, 872)
# vegetation  (560, 872) (140, 872)
# water  (496, 872) (124, 872)
# built  (1280, 872) (320, 872)
# windows  (480, 872) (120, 872)
# roads  (200, 872) (50, 872)
# cars  (200, 872) (50, 872)
# metal  (148, 872) (37, 872)

# %%
# -- concatenate the training arrays into training data and labels

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
cube_train_labelsn = np.array(cube_train_labelsn)
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
cube_test_labelsn = np.array(cube_test_labelsn)
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 3s 324ms/step - loss: 2.5325 - accuracy: 0.3026 - val_loss: 1.6465 - val_accuracy: 0.4867
# Epoch 2/200
# 8/8 [==============================] - 2s 244ms/step - loss: 1.4708 - accuracy: 0.5104 - val_loss: 1.3007 - val_accuracy: 0.5611
# Epoch 3/200
# 8/8 [==============================] - 2s 220ms/step - loss: 1.2053 - accuracy: 0.5972 - val_loss: 1.0901 - val_accuracy: 0.6164
# Epoch 4/200
# 8/8 [==============================] - 2s 211ms/step - loss: 1.0143 - accuracy: 0.6352 - val_loss: 0.9482 - val_accuracy: 0.6769
# Epoch 5/200
# 8/8 [==============================] - 2s 214ms/step - loss: 0.8779 - accuracy: 0.6921 - val_loss: 0.8428 - val_accuracy: 0.7396
# Epoch 6/200
# 8/8 [==============================] - 2s 306ms/step - loss: 0.8051 - accuracy: 0.7192 - val_loss: 0.8034 - val_accuracy: 0.7566
# Epoch 7/200
# 8/8 [==============================] - 2s 261ms/step - loss: 0.7592 - accuracy: 0.7327 - val_loss: 0.7666 - val_accuracy: 0.7216
# Epoch 8/200
# 8/8 [==============================] - 2s 249ms/step - loss: 0.7013 - accuracy: 0.7577 - val_loss: 0.7194 - val_accuracy: 0.7428
# Epoch 9/200
# 8/8 [==============================] - 2s 309ms/step - loss: 0.6654 - accuracy: 0.7713 - val_loss: 0.6517 - val_accuracy: 0.7981
# Epoch 10/200
# 8/8 [==============================] - 4s 515ms/step - loss: 0.6173 - accuracy: 0.7957 - val_loss: 0.6232 - val_accuracy: 0.7949
# Epoch 11/200
# 8/8 [==============================] - 2s 248ms/step - loss: 0.5839 - accuracy: 0.8045 - val_loss: 0.6178 - val_accuracy: 0.7853
# Epoch 12/200
# 8/8 [==============================] - 2s 293ms/step - loss: 0.5637 - accuracy: 0.8061 - val_loss: 0.5963 - val_accuracy: 0.8151
# Epoch 13/200
# 8/8 [==============================] - 2s 235ms/step - loss: 0.5376 - accuracy: 0.8212 - val_loss: 0.5785 - val_accuracy: 0.8087
# Epoch 14/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.5257 - accuracy: 0.8257 - val_loss: 0.5638 - val_accuracy: 0.8151
# Epoch 15/200
# 8/8 [==============================] - 2s 296ms/step - loss: 0.4960 - accuracy: 0.8377 - val_loss: 0.5384 - val_accuracy: 0.8385
# Epoch 16/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.4719 - accuracy: 0.8486 - val_loss: 0.5225 - val_accuracy: 0.8406
# Epoch 17/200
# 8/8 [==============================] - 2s 251ms/step - loss: 0.4575 - accuracy: 0.8523 - val_loss: 0.5171 - val_accuracy: 0.8491
# Epoch 18/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.4324 - accuracy: 0.8632 - val_loss: 0.5011 - val_accuracy: 0.8512
# Epoch 19/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.4292 - accuracy: 0.8632 - val_loss: 0.5009 - val_accuracy: 0.8395
# Epoch 20/200
# 8/8 [==============================] - 2s 267ms/step - loss: 0.4204 - accuracy: 0.8568 - val_loss: 0.5239 - val_accuracy: 0.8204
# Epoch 21/200
# 8/8 [==============================] - 2s 277ms/step - loss: 0.4377 - accuracy: 0.8510 - val_loss: 0.4946 - val_accuracy: 0.8406
# Epoch 22/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.3898 - accuracy: 0.8701 - val_loss: 0.4682 - val_accuracy: 0.8544
# Epoch 23/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.3729 - accuracy: 0.8775 - val_loss: 0.4370 - val_accuracy: 0.8682
# Epoch 24/200
# 8/8 [==============================] - 2s 287ms/step - loss: 0.3645 - accuracy: 0.8802 - val_loss: 0.4787 - val_accuracy: 0.8565
# Epoch 25/200
# 8/8 [==============================] - 2s 224ms/step - loss: 0.3606 - accuracy: 0.8799 - val_loss: 0.4695 - val_accuracy: 0.8544
# Epoch 26/200
# 8/8 [==============================] - 2s 255ms/step - loss: 0.3600 - accuracy: 0.8767 - val_loss: 0.4998 - val_accuracy: 0.8374
# Epoch 27/200
# 8/8 [==============================] - 2s 299ms/step - loss: 0.3755 - accuracy: 0.8672 - val_loss: 0.4738 - val_accuracy: 0.8565
# Epoch 28/200
# 8/8 [==============================] - 2s 234ms/step - loss: 0.3758 - accuracy: 0.8709 - val_loss: 0.5171 - val_accuracy: 0.8502
# Epoch 29/200
# 8/8 [==============================] - 2s 246ms/step - loss: 0.3632 - accuracy: 0.8738 - val_loss: 0.4975 - val_accuracy: 0.8512
# Epoch 30/200
# 8/8 [==============================] - 2s 297ms/step - loss: 0.3515 - accuracy: 0.8781 - val_loss: 0.4500 - val_accuracy: 0.8757
# Epoch 31/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.3254 - accuracy: 0.8908 - val_loss: 0.4338 - val_accuracy: 0.8693
# Epoch 32/200
# 8/8 [==============================] - 2s 270ms/step - loss: 0.3179 - accuracy: 0.8911 - val_loss: 0.4331 - val_accuracy: 0.8735
# Epoch 33/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.2904 - accuracy: 0.9070 - val_loss: 0.4710 - val_accuracy: 0.8672
# Epoch 34/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.3000 - accuracy: 0.8988 - val_loss: 0.4417 - val_accuracy: 0.8682
# Epoch 35/200
# 8/8 [==============================] - 2s 285ms/step - loss: 0.2843 - accuracy: 0.9052 - val_loss: 0.5509 - val_accuracy: 0.8555
# Epoch 36/200
# 8/8 [==============================] - 2s 277ms/step - loss: 0.2956 - accuracy: 0.8969 - val_loss: 0.5740 - val_accuracy: 0.8438
# Epoch 37/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.3217 - accuracy: 0.8866 - val_loss: 0.5516 - val_accuracy: 0.8576
# Epoch 38/200
# 8/8 [==============================] - 2s 249ms/step - loss: 0.2962 - accuracy: 0.9030 - val_loss: 0.4519 - val_accuracy: 0.8608
# Epoch 39/200
# 8/8 [==============================] - 2s 264ms/step - loss: 0.2727 - accuracy: 0.9105 - val_loss: 0.4971 - val_accuracy: 0.8682
# Epoch 40/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.2799 - accuracy: 0.9089 - val_loss: 0.4338 - val_accuracy: 0.8778
# Epoch 41/200
# 8/8 [==============================] - 2s 268ms/step - loss: 0.2591 - accuracy: 0.9142 - val_loss: 0.4409 - val_accuracy: 0.8799
# Epoch 42/200
# 8/8 [==============================] - 2s 280ms/step - loss: 0.2573 - accuracy: 0.9171 - val_loss: 0.4467 - val_accuracy: 0.8767
# Epoch 43/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.2440 - accuracy: 0.9245 - val_loss: 0.4508 - val_accuracy: 0.8757
# Epoch 44/200
# 8/8 [==============================] - 2s 285ms/step - loss: 0.2539 - accuracy: 0.9163 - val_loss: 0.4863 - val_accuracy: 0.8576
# Epoch 45/200
# 8/8 [==============================] - 2s 240ms/step - loss: 0.2664 - accuracy: 0.9075 - val_loss: 0.4815 - val_accuracy: 0.8704
# Epoch 46/200
# 8/8 [==============================] - 2s 227ms/step - loss: 0.2566 - accuracy: 0.9176 - val_loss: 0.4475 - val_accuracy: 0.8767
# Epoch 47/200
# 8/8 [==============================] - 2s 297ms/step - loss: 0.2430 - accuracy: 0.9145 - val_loss: 0.4882 - val_accuracy: 0.8735
# Epoch 48/200
# 8/8 [==============================] - 2s 252ms/step - loss: 0.2371 - accuracy: 0.9216 - val_loss: 0.4818 - val_accuracy: 0.8820
# Epoch 49/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.2233 - accuracy: 0.9269 - val_loss: 0.4890 - val_accuracy: 0.8714
# Epoch 50/200
# 8/8 [==============================] - 2s 255ms/step - loss: 0.2199 - accuracy: 0.9253 - val_loss: 0.4533 - val_accuracy: 0.8735
# Epoch 51/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.2339 - accuracy: 0.9200 - val_loss: 0.4836 - val_accuracy: 0.8618
# Epoch 52/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.2334 - accuracy: 0.9230 - val_loss: 0.4924 - val_accuracy: 0.8725
# Epoch 53/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.2142 - accuracy: 0.9280 - val_loss: 0.4745 - val_accuracy: 0.8778
# Epoch 54/200
# 8/8 [==============================] - 2s 266ms/step - loss: 0.2129 - accuracy: 0.9280 - val_loss: 0.4649 - val_accuracy: 0.8810
# Epoch 55/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.2012 - accuracy: 0.9323 - val_loss: 0.4836 - val_accuracy: 0.8852
# Epoch 56/200
# 8/8 [==============================] - 2s 291ms/step - loss: 0.2097 - accuracy: 0.9275 - val_loss: 0.4815 - val_accuracy: 0.8661
# Epoch 57/200
# 8/8 [==============================] - 2s 247ms/step - loss: 0.2035 - accuracy: 0.9304 - val_loss: 0.4995 - val_accuracy: 0.8757
# Epoch 58/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.2068 - accuracy: 0.9288 - val_loss: 0.4638 - val_accuracy: 0.8725
# Epoch 59/200
# 8/8 [==============================] - 2s 280ms/step - loss: 0.2045 - accuracy: 0.9349 - val_loss: 0.4513 - val_accuracy: 0.8725
# Epoch 60/200
# 8/8 [==============================] - 2s 245ms/step - loss: 0.1995 - accuracy: 0.9330 - val_loss: 0.4835 - val_accuracy: 0.8778
# Epoch 61/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.1903 - accuracy: 0.9357 - val_loss: 0.4754 - val_accuracy: 0.8799
# Epoch 62/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.1923 - accuracy: 0.9325 - val_loss: 0.5063 - val_accuracy: 0.8746
# Epoch 63/200
# 8/8 [==============================] - 2s 237ms/step - loss: 0.1879 - accuracy: 0.9402 - val_loss: 0.5328 - val_accuracy: 0.8810
# Epoch 64/200
# 8/8 [==============================] - 2s 211ms/step - loss: 0.1866 - accuracy: 0.9365 - val_loss: 0.5104 - val_accuracy: 0.8693
# Epoch 65/200
# 8/8 [==============================] - 2s 250ms/step - loss: 0.1835 - accuracy: 0.9368 - val_loss: 0.5217 - val_accuracy: 0.8799
# Epoch 66/200
# 8/8 [==============================] - 2s 267ms/step - loss: 0.1716 - accuracy: 0.9408 - val_loss: 0.5003 - val_accuracy: 0.8852
# Epoch 67/200
# 8/8 [==============================] - 2s 220ms/step - loss: 0.1654 - accuracy: 0.9455 - val_loss: 0.4924 - val_accuracy: 0.8842
# Epoch 68/200
# 8/8 [==============================] - 2s 279ms/step - loss: 0.1584 - accuracy: 0.9471 - val_loss: 0.5181 - val_accuracy: 0.8820
# Epoch 69/200
# 8/8 [==============================] - 2s 249ms/step - loss: 0.1644 - accuracy: 0.9466 - val_loss: 0.5245 - val_accuracy: 0.8704
# Epoch 70/200
# 8/8 [==============================] - 2s 227ms/step - loss: 0.1630 - accuracy: 0.9453 - val_loss: 0.5222 - val_accuracy: 0.8778
# Epoch 71/200
# 8/8 [==============================] - 2s 273ms/step - loss: 0.1587 - accuracy: 0.9455 - val_loss: 0.4943 - val_accuracy: 0.8831
# Epoch 72/200
# 8/8 [==============================] - 2s 248ms/step - loss: 0.1680 - accuracy: 0.9461 - val_loss: 0.5097 - val_accuracy: 0.8650
# Epoch 73/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.1492 - accuracy: 0.9511 - val_loss: 0.5184 - val_accuracy: 0.8842
# Epoch 74/200
# 8/8 [==============================] - 2s 283ms/step - loss: 0.1476 - accuracy: 0.9543 - val_loss: 0.5126 - val_accuracy: 0.8799
# Epoch 75/200
# 8/8 [==============================] - 2s 251ms/step - loss: 0.1443 - accuracy: 0.9524 - val_loss: 0.5562 - val_accuracy: 0.8820
# Epoch 76/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.1560 - accuracy: 0.9461 - val_loss: 0.5106 - val_accuracy: 0.8767
# Epoch 77/200
# 8/8 [==============================] - 2s 268ms/step - loss: 0.1519 - accuracy: 0.9511 - val_loss: 0.5528 - val_accuracy: 0.8714
# Epoch 78/200
# 8/8 [==============================] - 2s 273ms/step - loss: 0.1480 - accuracy: 0.9490 - val_loss: 0.5283 - val_accuracy: 0.8884
# Epoch 79/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.1392 - accuracy: 0.9532 - val_loss: 0.5335 - val_accuracy: 0.8735
# Epoch 80/200
# 8/8 [==============================] - 2s 264ms/step - loss: 0.1415 - accuracy: 0.9524 - val_loss: 0.5431 - val_accuracy: 0.8905
# Epoch 81/200
# 8/8 [==============================] - 2s 257ms/step - loss: 0.1700 - accuracy: 0.9455 - val_loss: 0.6097 - val_accuracy: 0.8714
# Epoch 82/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.2967 - accuracy: 0.8932 - val_loss: 0.5412 - val_accuracy: 0.8555
# Epoch 83/200
# 8/8 [==============================] - 2s 288ms/step - loss: 0.2132 - accuracy: 0.9238 - val_loss: 0.6456 - val_accuracy: 0.8448
# Epoch 84/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.1820 - accuracy: 0.9394 - val_loss: 0.5301 - val_accuracy: 0.8799
# Epoch 85/200
# 8/8 [==============================] - 2s 216ms/step - loss: 0.1632 - accuracy: 0.9495 - val_loss: 0.4819 - val_accuracy: 0.8799
# Epoch 86/200
# 8/8 [==============================] - 2s 294ms/step - loss: 0.1431 - accuracy: 0.9591 - val_loss: 0.5461 - val_accuracy: 0.8820
# Epoch 87/200
# 8/8 [==============================] - 2s 252ms/step - loss: 0.1278 - accuracy: 0.9607 - val_loss: 0.4657 - val_accuracy: 0.8852
# Epoch 88/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.1248 - accuracy: 0.9620 - val_loss: 0.4996 - val_accuracy: 0.8863
# Epoch 89/200
# 8/8 [==============================] - 2s 264ms/step - loss: 0.1185 - accuracy: 0.9623 - val_loss: 0.4971 - val_accuracy: 0.8852
# Epoch 90/200
# 8/8 [==============================] - 2s 248ms/step - loss: 0.1116 - accuracy: 0.9660 - val_loss: 0.5212 - val_accuracy: 0.8831
# Epoch 91/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.1144 - accuracy: 0.9631 - val_loss: 0.5542 - val_accuracy: 0.8725
# Epoch 92/200
# 8/8 [==============================] - 2s 263ms/step - loss: 0.1103 - accuracy: 0.9663 - val_loss: 0.5203 - val_accuracy: 0.8820
# Epoch 93/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.1089 - accuracy: 0.9652 - val_loss: 0.5207 - val_accuracy: 0.8831
# Epoch 94/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.1028 - accuracy: 0.9687 - val_loss: 0.5139 - val_accuracy: 0.8810
# Epoch 95/200
# 8/8 [==============================] - 2s 292ms/step - loss: 0.1009 - accuracy: 0.9700 - val_loss: 0.5735 - val_accuracy: 0.8820
# Epoch 96/200
# 8/8 [==============================] - 2s 254ms/step - loss: 0.1084 - accuracy: 0.9663 - val_loss: 0.5703 - val_accuracy: 0.8820
# Epoch 97/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.1039 - accuracy: 0.9681 - val_loss: 0.5520 - val_accuracy: 0.8895
# Epoch 98/200
# 8/8 [==============================] - 2s 298ms/step - loss: 0.1053 - accuracy: 0.9681 - val_loss: 0.5794 - val_accuracy: 0.8810
# Epoch 99/200
# 8/8 [==============================] - 2s 245ms/step - loss: 0.1059 - accuracy: 0.9665 - val_loss: 0.5872 - val_accuracy: 0.8767
# Epoch 100/200
# 8/8 [==============================] - 2s 249ms/step - loss: 0.0973 - accuracy: 0.9713 - val_loss: 0.6499 - val_accuracy: 0.8831
# Epoch 101/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0973 - accuracy: 0.9697 - val_loss: 0.5517 - val_accuracy: 0.8820
# Epoch 102/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0899 - accuracy: 0.9716 - val_loss: 0.5248 - val_accuracy: 0.8852
# Epoch 103/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0974 - accuracy: 0.9673 - val_loss: 0.5592 - val_accuracy: 0.8852
# Epoch 104/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.0828 - accuracy: 0.9753 - val_loss: 0.5844 - val_accuracy: 0.8863
# Epoch 105/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.0844 - accuracy: 0.9740 - val_loss: 0.5518 - val_accuracy: 0.8831
# Epoch 106/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0841 - accuracy: 0.9753 - val_loss: 0.5568 - val_accuracy: 0.8852
# Epoch 107/200
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0882 - accuracy: 0.9718 - val_loss: 0.5519 - val_accuracy: 0.8863
# Epoch 108/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0855 - accuracy: 0.9726 - val_loss: 0.6363 - val_accuracy: 0.8831
# Epoch 109/200
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0958 - accuracy: 0.9663 - val_loss: 0.7168 - val_accuracy: 0.8789
# Epoch 110/200
# 8/8 [==============================] - 2s 273ms/step - loss: 0.0884 - accuracy: 0.9710 - val_loss: 0.5891 - val_accuracy: 0.8810
# Epoch 111/200
# 8/8 [==============================] - 2s 229ms/step - loss: 0.0869 - accuracy: 0.9721 - val_loss: 0.5864 - val_accuracy: 0.8842
# Epoch 112/200
# 8/8 [==============================] - 2s 225ms/step - loss: 0.0722 - accuracy: 0.9801 - val_loss: 0.7205 - val_accuracy: 0.8757
# Epoch 113/200
# 8/8 [==============================] - 2s 283ms/step - loss: 0.0806 - accuracy: 0.9750 - val_loss: 0.6946 - val_accuracy: 0.8650
# Epoch 114/200
# 8/8 [==============================] - 2s 242ms/step - loss: 0.0794 - accuracy: 0.9732 - val_loss: 0.6785 - val_accuracy: 0.8714
# Epoch 115/200
# 8/8 [==============================] - 2s 234ms/step - loss: 0.0799 - accuracy: 0.9785 - val_loss: 0.6172 - val_accuracy: 0.8831
# Epoch 116/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.0692 - accuracy: 0.9777 - val_loss: 0.6080 - val_accuracy: 0.8916
# Epoch 117/200
# 8/8 [==============================] - 2s 247ms/step - loss: 0.0723 - accuracy: 0.9766 - val_loss: 0.5454 - val_accuracy: 0.8863
# Epoch 118/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0710 - accuracy: 0.9772 - val_loss: 0.6684 - val_accuracy: 0.8810
# Epoch 119/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.0645 - accuracy: 0.9825 - val_loss: 0.6783 - val_accuracy: 0.8778
# Epoch 120/200
# 8/8 [==============================] - 2s 254ms/step - loss: 0.0664 - accuracy: 0.9803 - val_loss: 0.6836 - val_accuracy: 0.8789
# Epoch 121/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.0663 - accuracy: 0.9819 - val_loss: 0.5399 - val_accuracy: 0.8842
# Epoch 122/200
# 8/8 [==============================] - 2s 299ms/step - loss: 0.0677 - accuracy: 0.9795 - val_loss: 0.6338 - val_accuracy: 0.8852
# Epoch 123/200
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0615 - accuracy: 0.9819 - val_loss: 0.6269 - val_accuracy: 0.8820
# Epoch 124/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.0631 - accuracy: 0.9817 - val_loss: 0.6211 - val_accuracy: 0.8884
# Epoch 125/200
# 8/8 [==============================] - 2s 290ms/step - loss: 0.0629 - accuracy: 0.9809 - val_loss: 0.6681 - val_accuracy: 0.8757
# Epoch 126/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0609 - accuracy: 0.9825 - val_loss: 0.6717 - val_accuracy: 0.8842
# Epoch 127/200
# 8/8 [==============================] - 2s 247ms/step - loss: 0.0560 - accuracy: 0.9846 - val_loss: 0.5713 - val_accuracy: 0.8842
# Epoch 128/200
# 8/8 [==============================] - 2s 309ms/step - loss: 0.0591 - accuracy: 0.9817 - val_loss: 0.6454 - val_accuracy: 0.8831
# Epoch 129/200
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0546 - accuracy: 0.9846 - val_loss: 0.6584 - val_accuracy: 0.8831
# Epoch 130/200
# 8/8 [==============================] - 2s 265ms/step - loss: 0.0551 - accuracy: 0.9841 - val_loss: 0.6455 - val_accuracy: 0.8884
# Epoch 131/200
# 8/8 [==============================] - 2s 280ms/step - loss: 0.0504 - accuracy: 0.9867 - val_loss: 0.6250 - val_accuracy: 0.8810
# Epoch 132/200
# 8/8 [==============================] - 2s 224ms/step - loss: 0.0497 - accuracy: 0.9859 - val_loss: 0.6548 - val_accuracy: 0.8863
# Epoch 133/200
# 8/8 [==============================] - 2s 273ms/step - loss: 0.0565 - accuracy: 0.9841 - val_loss: 0.6227 - val_accuracy: 0.8884
# Epoch 134/200
# 8/8 [==============================] - 2s 236ms/step - loss: 0.0668 - accuracy: 0.9779 - val_loss: 0.6635 - val_accuracy: 0.8810
# Epoch 135/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0536 - accuracy: 0.9851 - val_loss: 0.6305 - val_accuracy: 0.8820
# Epoch 136/200
# 8/8 [==============================] - 2s 268ms/step - loss: 0.0494 - accuracy: 0.9878 - val_loss: 0.6479 - val_accuracy: 0.8852
# Epoch 137/200
# 8/8 [==============================] - 2s 272ms/step - loss: 0.0511 - accuracy: 0.9838 - val_loss: 0.5850 - val_accuracy: 0.8820
# Epoch 138/200
# 8/8 [==============================] - 2s 237ms/step - loss: 0.0434 - accuracy: 0.9875 - val_loss: 0.6834 - val_accuracy: 0.8799
# Epoch 139/200
# 8/8 [==============================] - 2s 295ms/step - loss: 0.0484 - accuracy: 0.9849 - val_loss: 0.6862 - val_accuracy: 0.8852
# Epoch 140/200
# 8/8 [==============================] - 2s 255ms/step - loss: 0.0504 - accuracy: 0.9851 - val_loss: 0.7937 - val_accuracy: 0.8778
# Epoch 141/200
# 8/8 [==============================] - 2s 233ms/step - loss: 0.0553 - accuracy: 0.9827 - val_loss: 0.7584 - val_accuracy: 0.8852
# Epoch 142/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.0454 - accuracy: 0.9867 - val_loss: 0.6650 - val_accuracy: 0.8767
# Epoch 143/200
# 8/8 [==============================] - 2s 271ms/step - loss: 0.0518 - accuracy: 0.9854 - val_loss: 0.6529 - val_accuracy: 0.8863
# Epoch 144/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0484 - accuracy: 0.9854 - val_loss: 0.7237 - val_accuracy: 0.8778
# Epoch 145/200
# 8/8 [==============================] - 2s 267ms/step - loss: 0.0512 - accuracy: 0.9862 - val_loss: 0.7708 - val_accuracy: 0.8789
# Epoch 146/200
# 8/8 [==============================] - 2s 246ms/step - loss: 0.0502 - accuracy: 0.9865 - val_loss: 0.7787 - val_accuracy: 0.8799
# Epoch 147/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0407 - accuracy: 0.9896 - val_loss: 0.7939 - val_accuracy: 0.8820
# Epoch 148/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0432 - accuracy: 0.9880 - val_loss: 0.7562 - val_accuracy: 0.8789
# Epoch 149/200
# 8/8 [==============================] - 2s 228ms/step - loss: 0.0394 - accuracy: 0.9883 - val_loss: 0.6972 - val_accuracy: 0.8820
# Epoch 150/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0358 - accuracy: 0.9912 - val_loss: 0.6769 - val_accuracy: 0.8842
# Epoch 151/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0336 - accuracy: 0.9907 - val_loss: 0.6836 - val_accuracy: 0.8831
# Epoch 152/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0394 - accuracy: 0.9886 - val_loss: 0.6717 - val_accuracy: 0.8820
# Epoch 153/200
# 8/8 [==============================] - 2s 243ms/step - loss: 0.0361 - accuracy: 0.9912 - val_loss: 0.7245 - val_accuracy: 0.8820
# Epoch 154/200
# 8/8 [==============================] - 2s 293ms/step - loss: 0.0341 - accuracy: 0.9912 - val_loss: 0.7520 - val_accuracy: 0.8810
# Epoch 155/200
# 8/8 [==============================] - 2s 226ms/step - loss: 0.0383 - accuracy: 0.9880 - val_loss: 0.7168 - val_accuracy: 0.8831
# Epoch 156/200
# 8/8 [==============================] - 2s 245ms/step - loss: 0.0302 - accuracy: 0.9931 - val_loss: 0.7660 - val_accuracy: 0.8810
# Epoch 157/200
# 8/8 [==============================] - 2s 304ms/step - loss: 0.0315 - accuracy: 0.9926 - val_loss: 0.7347 - val_accuracy: 0.8842
# Epoch 158/200
# 8/8 [==============================] - 2s 232ms/step - loss: 0.0286 - accuracy: 0.9934 - val_loss: 0.7067 - val_accuracy: 0.8852
# Epoch 159/200
# 8/8 [==============================] - 2s 254ms/step - loss: 0.0302 - accuracy: 0.9931 - val_loss: 0.9813 - val_accuracy: 0.8735
# Epoch 160/200
# 8/8 [==============================] - 2s 286ms/step - loss: 0.0332 - accuracy: 0.9902 - val_loss: 0.7174 - val_accuracy: 0.8852
# Epoch 161/200
# 8/8 [==============================] - 2s 227ms/step - loss: 0.0331 - accuracy: 0.9902 - val_loss: 0.6391 - val_accuracy: 0.8810
# Epoch 162/200
# 8/8 [==============================] - 2s 264ms/step - loss: 0.0368 - accuracy: 0.9912 - val_loss: 0.8504 - val_accuracy: 0.8757
# Epoch 163/200
# 8/8 [==============================] - 2s 263ms/step - loss: 0.0374 - accuracy: 0.9910 - val_loss: 0.8229 - val_accuracy: 0.8799
# Epoch 164/200
# 8/8 [==============================] - 2s 219ms/step - loss: 0.0275 - accuracy: 0.9926 - val_loss: 0.8458 - val_accuracy: 0.8842
# Epoch 165/200
# 8/8 [==============================] - 2s 261ms/step - loss: 0.0324 - accuracy: 0.9918 - val_loss: 0.9040 - val_accuracy: 0.8735
# Epoch 166/200
# 8/8 [==============================] - 2s 272ms/step - loss: 0.0309 - accuracy: 0.9915 - val_loss: 0.9089 - val_accuracy: 0.8810
# Epoch 167/200
# 8/8 [==============================] - 2s 223ms/step - loss: 0.0272 - accuracy: 0.9923 - val_loss: 0.8706 - val_accuracy: 0.8852
# Epoch 168/200
# 8/8 [==============================] - 3s 315ms/step - loss: 0.0297 - accuracy: 0.9931 - val_loss: 0.8273 - val_accuracy: 0.8820
# Epoch 169/200
# 8/8 [==============================] - 2s 256ms/step - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.8165 - val_accuracy: 0.8767
# Epoch 170/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0287 - accuracy: 0.9918 - val_loss: 0.8476 - val_accuracy: 0.8820
# Epoch 171/200
# 8/8 [==============================] - 2s 280ms/step - loss: 0.0287 - accuracy: 0.9926 - val_loss: 0.7298 - val_accuracy: 0.8778
# Epoch 172/200
# 8/8 [==============================] - 2s 240ms/step - loss: 0.0247 - accuracy: 0.9939 - val_loss: 0.7350 - val_accuracy: 0.8852
# Epoch 173/200
# 8/8 [==============================] - 2s 217ms/step - loss: 0.0238 - accuracy: 0.9950 - val_loss: 0.7570 - val_accuracy: 0.8874
# Epoch 174/200
# 8/8 [==============================] - 2s 271ms/step - loss: 0.0250 - accuracy: 0.9931 - val_loss: 0.7656 - val_accuracy: 0.8874
# Epoch 175/200
# 8/8 [==============================] - 2s 247ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.7749 - val_accuracy: 0.8916
# Epoch 176/200
# 8/8 [==============================] - 2s 213ms/step - loss: 0.0254 - accuracy: 0.9931 - val_loss: 0.7637 - val_accuracy: 0.8895
# Epoch 177/200
# 8/8 [==============================] - 2s 271ms/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 0.7904 - val_accuracy: 0.8863
# Epoch 178/200
# 8/8 [==============================] - 2s 251ms/step - loss: 0.0243 - accuracy: 0.9936 - val_loss: 0.8287 - val_accuracy: 0.8799
# Epoch 179/200
# 8/8 [==============================] - 2s 215ms/step - loss: 0.0276 - accuracy: 0.9928 - val_loss: 0.8660 - val_accuracy: 0.8842
# Epoch 180/200
# 8/8 [==============================] - 2s 253ms/step - loss: 0.0199 - accuracy: 0.9955 - val_loss: 0.8571 - val_accuracy: 0.8820
# Epoch 181/200
# 8/8 [==============================] - 2s 267ms/step - loss: 0.0240 - accuracy: 0.9928 - val_loss: 0.8433 - val_accuracy: 0.8810
# Epoch 182/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0242 - accuracy: 0.9912 - val_loss: 0.8299 - val_accuracy: 0.8778
# Epoch 183/200
# 8/8 [==============================] - 2s 257ms/step - loss: 0.0222 - accuracy: 0.9942 - val_loss: 0.8481 - val_accuracy: 0.8820
# Epoch 184/200
# 8/8 [==============================] - 2s 268ms/step - loss: 0.0235 - accuracy: 0.9939 - val_loss: 0.8918 - val_accuracy: 0.8704
# Epoch 185/200
# 8/8 [==============================] - 2s 208ms/step - loss: 0.0251 - accuracy: 0.9920 - val_loss: 0.8783 - val_accuracy: 0.8799
# Epoch 186/200
# 8/8 [==============================] - 2s 246ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 0.9090 - val_accuracy: 0.8757
# Epoch 187/200
# 8/8 [==============================] - 2s 275ms/step - loss: 0.0255 - accuracy: 0.9926 - val_loss: 0.9065 - val_accuracy: 0.8725
# Epoch 188/200
# 8/8 [==============================] - 2s 222ms/step - loss: 0.0217 - accuracy: 0.9944 - val_loss: 0.8562 - val_accuracy: 0.8810
# Epoch 189/200
# 8/8 [==============================] - 2s 248ms/step - loss: 0.0211 - accuracy: 0.9971 - val_loss: 0.8586 - val_accuracy: 0.8778
# Epoch 190/200
# 8/8 [==============================] - 2s 295ms/step - loss: 0.0226 - accuracy: 0.9936 - val_loss: 0.8598 - val_accuracy: 0.8799
# Epoch 191/200
# 8/8 [==============================] - 2s 221ms/step - loss: 0.0207 - accuracy: 0.9950 - val_loss: 0.7962 - val_accuracy: 0.8852
# Epoch 192/200
# 8/8 [==============================] - 2s 244ms/step - loss: 0.0191 - accuracy: 0.9963 - val_loss: 0.8299 - val_accuracy: 0.8789
# Epoch 193/200
# 8/8 [==============================] - 2s 282ms/step - loss: 0.0186 - accuracy: 0.9960 - val_loss: 0.8073 - val_accuracy: 0.8820
# Epoch 194/200
# 8/8 [==============================] - 2s 231ms/step - loss: 0.0172 - accuracy: 0.9965 - val_loss: 0.8241 - val_accuracy: 0.8842
# Epoch 195/200
# 8/8 [==============================] - 2s 258ms/step - loss: 0.0182 - accuracy: 0.9971 - val_loss: 0.8522 - val_accuracy: 0.8842
# Epoch 196/200
# 8/8 [==============================] - 2s 285ms/step - loss: 0.0188 - accuracy: 0.9955 - val_loss: 0.8744 - val_accuracy: 0.8778
# Epoch 197/200
# 8/8 [==============================] - 2s 218ms/step - loss: 0.0233 - accuracy: 0.9939 - val_loss: 0.8269 - val_accuracy: 0.8842
# Epoch 198/200
# 8/8 [==============================] - 2s 230ms/step - loss: 0.0191 - accuracy: 0.9965 - val_loss: 0.8324 - val_accuracy: 0.8905
# Epoch 199/200
# 8/8 [==============================] - 2s 272ms/step - loss: 0.0184 - accuracy: 0.9952 - val_loss: 0.7983 - val_accuracy: 0.8831
# Epoch 200/200
# 8/8 [==============================] - 2s 235ms/step - loss: 0.0166 - accuracy: 0.9963 - val_loss: 0.8315 - val_accuracy: 0.8874

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodeln)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=20, batch_size=512)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 2s 302ms/step - loss: 2.6739 - accuracy: 0.3374 - val_loss: 1.7059 - val_accuracy: 0.3815
# Epoch 2/20
# 8/8 [==============================] - 2s 242ms/step - loss: 1.4770 - accuracy: 0.4995 - val_loss: 1.2726 - val_accuracy: 0.5930
# Epoch 3/20
# 8/8 [==============================] - 2s 210ms/step - loss: 1.2042 - accuracy: 0.6111 - val_loss: 1.1093 - val_accuracy: 0.6227
# Epoch 4/20
# 8/8 [==============================] - 2s 238ms/step - loss: 1.0326 - accuracy: 0.6403 - val_loss: 0.9671 - val_accuracy: 0.6599
# Epoch 5/20
# 8/8 [==============================] - 2s 263ms/step - loss: 0.9140 - accuracy: 0.6477 - val_loss: 0.8886 - val_accuracy: 0.6897
# Epoch 6/20
# 8/8 [==============================] - 2s 209ms/step - loss: 0.8367 - accuracy: 0.7062 - val_loss: 0.8314 - val_accuracy: 0.7290
# Epoch 7/20
# 8/8 [==============================] - 2s 242ms/step - loss: 0.7644 - accuracy: 0.7452 - val_loss: 0.7917 - val_accuracy: 0.7513
# Epoch 8/20
# 8/8 [==============================] - 2s 287ms/step - loss: 0.7253 - accuracy: 0.7662 - val_loss: 0.7483 - val_accuracy: 0.7460
# Epoch 9/20
# 8/8 [==============================] - 2s 218ms/step - loss: 0.6747 - accuracy: 0.7731 - val_loss: 0.7026 - val_accuracy: 0.7471
# Epoch 10/20
# 8/8 [==============================] - 2s 240ms/step - loss: 0.6443 - accuracy: 0.7774 - val_loss: 0.6310 - val_accuracy: 0.8055
# Epoch 11/20
# 8/8 [==============================] - 2s 285ms/step - loss: 0.5944 - accuracy: 0.8007 - val_loss: 0.6264 - val_accuracy: 0.7949
# Epoch 12/20
# 8/8 [==============================] - 2s 221ms/step - loss: 0.5826 - accuracy: 0.7954 - val_loss: 0.5841 - val_accuracy: 0.8087
# Epoch 13/20
# 8/8 [==============================] - 2s 228ms/step - loss: 0.5521 - accuracy: 0.8114 - val_loss: 0.5861 - val_accuracy: 0.8140
# Epoch 14/20
# 8/8 [==============================] - 2s 279ms/step - loss: 0.5208 - accuracy: 0.8204 - val_loss: 0.5829 - val_accuracy: 0.8257
# Epoch 15/20
# 8/8 [==============================] - 2s 227ms/step - loss: 0.5189 - accuracy: 0.8337 - val_loss: 0.5401 - val_accuracy: 0.8193
# Epoch 16/20
# 8/8 [==============================] - 2s 221ms/step - loss: 0.4872 - accuracy: 0.8419 - val_loss: 0.5101 - val_accuracy: 0.8480
# Epoch 17/20
# 8/8 [==============================] - 2s 272ms/step - loss: 0.4645 - accuracy: 0.8448 - val_loss: 0.5023 - val_accuracy: 0.8406
# Epoch 18/20
# 8/8 [==============================] - 2s 250ms/step - loss: 0.4457 - accuracy: 0.8533 - val_loss: 0.4888 - val_accuracy: 0.8406
# Epoch 19/20
# 8/8 [==============================] - 2s 219ms/step - loss: 0.4277 - accuracy: 0.8579 - val_loss: 0.5027 - val_accuracy: 0.8374
# Epoch 20/20
# 8/8 [==============================] - 2s 287ms/step - loss: 0.4317 - accuracy: 0.8496 - val_loss: 0.5199 - val_accuracy: 0.8321

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 12ms/step - loss: 0.4041 - accuracy: 0.8658
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5199 - accuracy: 0.8321
# 0.8658342361450195 0.8320935368537903

# %% [markdown]
# ### Predict pixel classification on all of Scene 2

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])

start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})
predictCuben = probCuben.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:10:18

# %%
# -- Plot the prediction map of Scene 2

predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 2

# %%
# -- create the prediction arrays from the predictions of the testing set

labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# -- create the true arrays from the labeled testing set 

labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 2

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 138   0   0   1   1   0   0]
#  [  4   0   0 114   0   6   0   0   0]
#  [  0   0   0   1 280  29   9   1   0]
#  [  0   0   0   2   5  98  15   0   0]
#  [  0   0   1   0   4  14  31   0   0]
#  [  0   1   0   0  16  10   1  22   0]
#  [  0   0   0   7  11  17   2   0   0]]
#
# Accuracy Score
# 0.8320935175345378
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.94      1.00      0.97        60
#      clouds       0.98      1.00      0.99        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.92      0.92      0.92       124
#       built       0.89      0.88      0.88       320
#     windows       0.56      0.82      0.66       120
#       roads       0.53      0.62      0.57        50
#        cars       0.96      0.44      0.60        50
#       metal       0.00      0.00      0.00        37
#
# avg / total       0.82      0.83      0.82       941
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# # CNN on Scene 1-a

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
cube_sub = cube.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)

# -- reshape standardized cube to (row, col, wavelength)
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# -- create position array from coordinates and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
trrat = 0.8  # set train/test ratio to have 80% training, 20% testing

# -- get the coordinates of training and testing sets for each class
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 848) (60, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (480, 848) (120, 848)
# water  (40, 848) (10, 848)
# built  (816, 848) (204, 848)
# windows  (400, 848) (100, 848)
# roads  (24, 848) (6, 848)
# cars  (80, 848) (20, 848)
# metal  (80, 848) (20, 848)

# %%
# -- concatenate the training arrays into training data and labels

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
cube_train_labels = np.array(cube_train_labels)
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
cube_test_labels = np.array(cube_test_labels)
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %% [markdown]
# ### Train CNN

# %%
# -- create an initial model to use for choosing 'best' epoch

cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 2s 324ms/step - loss: 3.1577 - accuracy: 0.3805 - val_loss: 1.6292 - val_accuracy: 0.4234
# Epoch 2/200
# 5/5 [==============================] - 1s 240ms/step - loss: 1.3257 - accuracy: 0.5184 - val_loss: 1.1690 - val_accuracy: 0.5641
# Epoch 3/200
# 5/5 [==============================] - 1s 243ms/step - loss: 1.0649 - accuracy: 0.6797 - val_loss: 0.8898 - val_accuracy: 0.7484
# Epoch 4/200
# 5/5 [==============================] - 2s 350ms/step - loss: 0.8358 - accuracy: 0.7598 - val_loss: 0.7226 - val_accuracy: 0.8484
# Epoch 5/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.6757 - accuracy: 0.8062 - val_loss: 0.5870 - val_accuracy: 0.8687
# Epoch 6/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.5593 - accuracy: 0.8676 - val_loss: 0.4996 - val_accuracy: 0.8766
# Epoch 7/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.4859 - accuracy: 0.8680 - val_loss: 0.4454 - val_accuracy: 0.8797
# Epoch 8/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.4350 - accuracy: 0.8730 - val_loss: 0.4160 - val_accuracy: 0.8781
# Epoch 9/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.4029 - accuracy: 0.8813 - val_loss: 0.3873 - val_accuracy: 0.8922
# Epoch 10/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.3956 - accuracy: 0.8816 - val_loss: 0.4177 - val_accuracy: 0.8750
# Epoch 11/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.3928 - accuracy: 0.8809 - val_loss: 0.3896 - val_accuracy: 0.8781
# Epoch 12/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.3711 - accuracy: 0.8848 - val_loss: 0.3534 - val_accuracy: 0.8906
# Epoch 13/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.3411 - accuracy: 0.8934 - val_loss: 0.3582 - val_accuracy: 0.8969
# Epoch 14/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.3407 - accuracy: 0.8906 - val_loss: 0.3557 - val_accuracy: 0.8969
# Epoch 15/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.3283 - accuracy: 0.8980 - val_loss: 0.3218 - val_accuracy: 0.9000
# Epoch 16/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.3221 - accuracy: 0.8961 - val_loss: 0.3202 - val_accuracy: 0.9031
# Epoch 17/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.3182 - accuracy: 0.9016 - val_loss: 0.3231 - val_accuracy: 0.9062
# Epoch 18/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.3027 - accuracy: 0.8992 - val_loss: 0.3299 - val_accuracy: 0.9016
# Epoch 19/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2906 - accuracy: 0.9031 - val_loss: 0.3101 - val_accuracy: 0.9047
# Epoch 20/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.2786 - accuracy: 0.9027 - val_loss: 0.2972 - val_accuracy: 0.9000
# Epoch 21/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.2774 - accuracy: 0.9133 - val_loss: 0.2934 - val_accuracy: 0.8969
# Epoch 22/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.2688 - accuracy: 0.9137 - val_loss: 0.3067 - val_accuracy: 0.9000
# Epoch 23/200
# 5/5 [==============================] - 2s 328ms/step - loss: 0.2669 - accuracy: 0.9117 - val_loss: 0.2780 - val_accuracy: 0.8969
# Epoch 24/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.2638 - accuracy: 0.9133 - val_loss: 0.2794 - val_accuracy: 0.9125
# Epoch 25/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.2567 - accuracy: 0.9078 - val_loss: 0.2773 - val_accuracy: 0.9203
# Epoch 26/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.2410 - accuracy: 0.9180 - val_loss: 0.2814 - val_accuracy: 0.9094
# Epoch 27/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.2422 - accuracy: 0.9184 - val_loss: 0.2592 - val_accuracy: 0.9031
# Epoch 28/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.2258 - accuracy: 0.9219 - val_loss: 0.2622 - val_accuracy: 0.9016
# Epoch 29/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.2228 - accuracy: 0.9227 - val_loss: 0.2679 - val_accuracy: 0.9094
# Epoch 30/200
# 5/5 [==============================] - 1s 296ms/step - loss: 0.2310 - accuracy: 0.9164 - val_loss: 0.2435 - val_accuracy: 0.9187
# Epoch 31/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.2145 - accuracy: 0.9262 - val_loss: 0.2405 - val_accuracy: 0.9109
# Epoch 32/200
# 5/5 [==============================] - 1s 214ms/step - loss: 0.1987 - accuracy: 0.9320 - val_loss: 0.2309 - val_accuracy: 0.9062
# Epoch 33/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.2042 - accuracy: 0.9293 - val_loss: 0.2321 - val_accuracy: 0.9047
# Epoch 34/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.1929 - accuracy: 0.9277 - val_loss: 0.2192 - val_accuracy: 0.9234
# Epoch 35/200
# 5/5 [==============================] - 1s 240ms/step - loss: 0.1848 - accuracy: 0.9359 - val_loss: 0.2133 - val_accuracy: 0.9266
# Epoch 36/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.1881 - accuracy: 0.9367 - val_loss: 0.2138 - val_accuracy: 0.9250
# Epoch 37/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.1818 - accuracy: 0.9391 - val_loss: 0.2428 - val_accuracy: 0.9125
# Epoch 38/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1797 - accuracy: 0.9430 - val_loss: 0.2051 - val_accuracy: 0.9297
# Epoch 39/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.1657 - accuracy: 0.9457 - val_loss: 0.2089 - val_accuracy: 0.9156
# Epoch 40/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.1714 - accuracy: 0.9410 - val_loss: 0.2307 - val_accuracy: 0.9203
# Epoch 41/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1790 - accuracy: 0.9391 - val_loss: 0.2012 - val_accuracy: 0.9250
# Epoch 42/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.1597 - accuracy: 0.9457 - val_loss: 0.2112 - val_accuracy: 0.9125
# Epoch 43/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.1615 - accuracy: 0.9484 - val_loss: 0.1984 - val_accuracy: 0.9250
# Epoch 44/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.1484 - accuracy: 0.9516 - val_loss: 0.1982 - val_accuracy: 0.9219
# Epoch 45/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.1484 - accuracy: 0.9477 - val_loss: 0.1935 - val_accuracy: 0.9391
# Epoch 46/200
# 5/5 [==============================] - 1s 222ms/step - loss: 0.1480 - accuracy: 0.9508 - val_loss: 0.2103 - val_accuracy: 0.9391
# Epoch 47/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1452 - accuracy: 0.9500 - val_loss: 0.1920 - val_accuracy: 0.9406
# Epoch 48/200
# 5/5 [==============================] - 1s 253ms/step - loss: 0.1450 - accuracy: 0.9488 - val_loss: 0.2085 - val_accuracy: 0.9344
# Epoch 49/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.1604 - accuracy: 0.9449 - val_loss: 0.1897 - val_accuracy: 0.9453
# Epoch 50/200
# 5/5 [==============================] - 1s 265ms/step - loss: 0.1574 - accuracy: 0.9441 - val_loss: 0.1934 - val_accuracy: 0.9250
# Epoch 51/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.1511 - accuracy: 0.9488 - val_loss: 0.1851 - val_accuracy: 0.9203
# Epoch 52/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.1585 - accuracy: 0.9434 - val_loss: 0.1843 - val_accuracy: 0.9234
# Epoch 53/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.1490 - accuracy: 0.9520 - val_loss: 0.2034 - val_accuracy: 0.9375
# Epoch 54/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.1345 - accuracy: 0.9527 - val_loss: 0.1812 - val_accuracy: 0.9469
# Epoch 55/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.1281 - accuracy: 0.9574 - val_loss: 0.1854 - val_accuracy: 0.9406
# Epoch 56/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.1275 - accuracy: 0.9559 - val_loss: 0.1747 - val_accuracy: 0.9469
# Epoch 57/200
# 5/5 [==============================] - 1s 231ms/step - loss: 0.1346 - accuracy: 0.9574 - val_loss: 0.2016 - val_accuracy: 0.9344
# Epoch 58/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.1382 - accuracy: 0.9551 - val_loss: 0.1916 - val_accuracy: 0.9312
# Epoch 59/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1351 - accuracy: 0.9570 - val_loss: 0.1788 - val_accuracy: 0.9266
# Epoch 60/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.1154 - accuracy: 0.9621 - val_loss: 0.1662 - val_accuracy: 0.9344
# Epoch 61/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.1121 - accuracy: 0.9676 - val_loss: 0.1834 - val_accuracy: 0.9281
# Epoch 62/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1127 - accuracy: 0.9648 - val_loss: 0.1701 - val_accuracy: 0.9375
# Epoch 63/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.1109 - accuracy: 0.9617 - val_loss: 0.1661 - val_accuracy: 0.9422
# Epoch 64/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0995 - accuracy: 0.9684 - val_loss: 0.1743 - val_accuracy: 0.9359
# Epoch 65/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0994 - accuracy: 0.9676 - val_loss: 0.1666 - val_accuracy: 0.9422
# Epoch 66/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0936 - accuracy: 0.9691 - val_loss: 0.1643 - val_accuracy: 0.9438
# Epoch 67/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.1023 - accuracy: 0.9660 - val_loss: 0.1725 - val_accuracy: 0.9312
# Epoch 68/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.1015 - accuracy: 0.9688 - val_loss: 0.1741 - val_accuracy: 0.9250
# Epoch 69/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.1003 - accuracy: 0.9664 - val_loss: 0.1572 - val_accuracy: 0.9438
# Epoch 70/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0914 - accuracy: 0.9719 - val_loss: 0.1555 - val_accuracy: 0.9391
# Epoch 71/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0911 - accuracy: 0.9719 - val_loss: 0.1679 - val_accuracy: 0.9375
# Epoch 72/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0879 - accuracy: 0.9711 - val_loss: 0.1672 - val_accuracy: 0.9344
# Epoch 73/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0910 - accuracy: 0.9707 - val_loss: 0.1611 - val_accuracy: 0.9406
# Epoch 74/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0872 - accuracy: 0.9711 - val_loss: 0.1716 - val_accuracy: 0.9250
# Epoch 75/200
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0857 - accuracy: 0.9754 - val_loss: 0.1566 - val_accuracy: 0.9438
# Epoch 76/200
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0902 - accuracy: 0.9738 - val_loss: 0.1570 - val_accuracy: 0.9453
# Epoch 77/200
# 5/5 [==============================] - 1s 241ms/step - loss: 0.0799 - accuracy: 0.9758 - val_loss: 0.1574 - val_accuracy: 0.9500
# Epoch 78/200
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0817 - accuracy: 0.9746 - val_loss: 0.1532 - val_accuracy: 0.9531
# Epoch 79/200
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0810 - accuracy: 0.9746 - val_loss: 0.1514 - val_accuracy: 0.9453
# Epoch 80/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0716 - accuracy: 0.9809 - val_loss: 0.1552 - val_accuracy: 0.9406
# Epoch 81/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0696 - accuracy: 0.9793 - val_loss: 0.1535 - val_accuracy: 0.9516
# Epoch 82/200
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0694 - accuracy: 0.9820 - val_loss: 0.1558 - val_accuracy: 0.9484
# Epoch 83/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0736 - accuracy: 0.9766 - val_loss: 0.1523 - val_accuracy: 0.9469
# Epoch 84/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0680 - accuracy: 0.9801 - val_loss: 0.1599 - val_accuracy: 0.9391
# Epoch 85/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0705 - accuracy: 0.9785 - val_loss: 0.1601 - val_accuracy: 0.9438
# Epoch 86/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0774 - accuracy: 0.9738 - val_loss: 0.1578 - val_accuracy: 0.9469
# Epoch 87/200
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0762 - accuracy: 0.9723 - val_loss: 0.1518 - val_accuracy: 0.9438
# Epoch 88/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0759 - accuracy: 0.9766 - val_loss: 0.1848 - val_accuracy: 0.9375
# Epoch 89/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0682 - accuracy: 0.9781 - val_loss: 0.1571 - val_accuracy: 0.9375
# Epoch 90/200
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0703 - accuracy: 0.9773 - val_loss: 0.1644 - val_accuracy: 0.9438
# Epoch 91/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0667 - accuracy: 0.9797 - val_loss: 0.1548 - val_accuracy: 0.9500
# Epoch 92/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0675 - accuracy: 0.9816 - val_loss: 0.1507 - val_accuracy: 0.9391
# Epoch 93/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0625 - accuracy: 0.9820 - val_loss: 0.1480 - val_accuracy: 0.9438
# Epoch 94/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0595 - accuracy: 0.9848 - val_loss: 0.1517 - val_accuracy: 0.9453
# Epoch 95/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0578 - accuracy: 0.9816 - val_loss: 0.1701 - val_accuracy: 0.9391
# Epoch 96/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0606 - accuracy: 0.9805 - val_loss: 0.1579 - val_accuracy: 0.9422
# Epoch 97/200
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0604 - accuracy: 0.9801 - val_loss: 0.1471 - val_accuracy: 0.9500
# Epoch 98/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0577 - accuracy: 0.9824 - val_loss: 0.1519 - val_accuracy: 0.9484
# Epoch 99/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0621 - accuracy: 0.9816 - val_loss: 0.1838 - val_accuracy: 0.9438
# Epoch 100/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0592 - accuracy: 0.9816 - val_loss: 0.1526 - val_accuracy: 0.9531
# Epoch 101/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0550 - accuracy: 0.9871 - val_loss: 0.1532 - val_accuracy: 0.9453
# Epoch 102/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0519 - accuracy: 0.9863 - val_loss: 0.1575 - val_accuracy: 0.9438
# Epoch 103/200
# 5/5 [==============================] - 1s 299ms/step - loss: 0.0489 - accuracy: 0.9875 - val_loss: 0.1455 - val_accuracy: 0.9438
# Epoch 104/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0476 - accuracy: 0.9871 - val_loss: 0.1563 - val_accuracy: 0.9500
# Epoch 105/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0568 - accuracy: 0.9832 - val_loss: 0.1616 - val_accuracy: 0.9500
# Epoch 106/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0546 - accuracy: 0.9840 - val_loss: 0.1671 - val_accuracy: 0.9484
# Epoch 107/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0510 - accuracy: 0.9844 - val_loss: 0.1478 - val_accuracy: 0.9500
# Epoch 108/200
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0494 - accuracy: 0.9887 - val_loss: 0.1651 - val_accuracy: 0.9391
# Epoch 109/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0482 - accuracy: 0.9875 - val_loss: 0.1617 - val_accuracy: 0.9422
# Epoch 110/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0532 - accuracy: 0.9848 - val_loss: 0.1506 - val_accuracy: 0.9406
# Epoch 111/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0498 - accuracy: 0.9852 - val_loss: 0.1586 - val_accuracy: 0.9406
# Epoch 112/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0482 - accuracy: 0.9863 - val_loss: 0.1511 - val_accuracy: 0.9484
# Epoch 113/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0412 - accuracy: 0.9887 - val_loss: 0.1558 - val_accuracy: 0.9484
# Epoch 114/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0418 - accuracy: 0.9867 - val_loss: 0.1446 - val_accuracy: 0.9516
# Epoch 115/200
# 5/5 [==============================] - 1s 227ms/step - loss: 0.0384 - accuracy: 0.9914 - val_loss: 0.1536 - val_accuracy: 0.9484
# Epoch 116/200
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0352 - accuracy: 0.9918 - val_loss: 0.1652 - val_accuracy: 0.9391
# Epoch 117/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0379 - accuracy: 0.9898 - val_loss: 0.1437 - val_accuracy: 0.9484
# Epoch 118/200
# 5/5 [==============================] - 1s 202ms/step - loss: 0.0299 - accuracy: 0.9930 - val_loss: 0.1545 - val_accuracy: 0.9516
# Epoch 119/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0339 - accuracy: 0.9922 - val_loss: 0.1548 - val_accuracy: 0.9438
# Epoch 120/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0356 - accuracy: 0.9906 - val_loss: 0.1654 - val_accuracy: 0.9453
# Epoch 121/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0390 - accuracy: 0.9879 - val_loss: 0.1538 - val_accuracy: 0.9531
# Epoch 122/200
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0333 - accuracy: 0.9906 - val_loss: 0.1678 - val_accuracy: 0.9484
# Epoch 123/200
# 5/5 [==============================] - 1s 243ms/step - loss: 0.0362 - accuracy: 0.9898 - val_loss: 0.1562 - val_accuracy: 0.9438
# Epoch 124/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0367 - accuracy: 0.9895 - val_loss: 0.1798 - val_accuracy: 0.9391
# Epoch 125/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0427 - accuracy: 0.9875 - val_loss: 0.1565 - val_accuracy: 0.9469
# Epoch 126/200
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0331 - accuracy: 0.9906 - val_loss: 0.1622 - val_accuracy: 0.9422
# Epoch 127/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0347 - accuracy: 0.9910 - val_loss: 0.1580 - val_accuracy: 0.9375
# Epoch 128/200
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0313 - accuracy: 0.9918 - val_loss: 0.1462 - val_accuracy: 0.9453
# Epoch 129/200
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0332 - accuracy: 0.9910 - val_loss: 0.1653 - val_accuracy: 0.9484
# Epoch 130/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0353 - accuracy: 0.9902 - val_loss: 0.1561 - val_accuracy: 0.9500
# Epoch 131/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0381 - accuracy: 0.9891 - val_loss: 0.1574 - val_accuracy: 0.9500
# Epoch 132/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0297 - accuracy: 0.9941 - val_loss: 0.1524 - val_accuracy: 0.9453
# Epoch 133/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0270 - accuracy: 0.9953 - val_loss: 0.1622 - val_accuracy: 0.9438
# Epoch 134/200
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0272 - accuracy: 0.9934 - val_loss: 0.1476 - val_accuracy: 0.9453
# Epoch 135/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0233 - accuracy: 0.9953 - val_loss: 0.1488 - val_accuracy: 0.9469
# Epoch 136/200
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0265 - accuracy: 0.9934 - val_loss: 0.1546 - val_accuracy: 0.9469
# Epoch 137/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0266 - accuracy: 0.9914 - val_loss: 0.1686 - val_accuracy: 0.9500
# Epoch 138/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0257 - accuracy: 0.9934 - val_loss: 0.1612 - val_accuracy: 0.9484
# Epoch 139/200
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0273 - accuracy: 0.9934 - val_loss: 0.1594 - val_accuracy: 0.9500
# Epoch 140/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0258 - accuracy: 0.9934 - val_loss: 0.1577 - val_accuracy: 0.9453
# Epoch 141/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0236 - accuracy: 0.9945 - val_loss: 0.1533 - val_accuracy: 0.9484
# Epoch 142/200
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0276 - accuracy: 0.9922 - val_loss: 0.1519 - val_accuracy: 0.9500
# Epoch 143/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0287 - accuracy: 0.9918 - val_loss: 0.1767 - val_accuracy: 0.9484
# Epoch 144/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0290 - accuracy: 0.9902 - val_loss: 0.1790 - val_accuracy: 0.9500
# Epoch 145/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0338 - accuracy: 0.9891 - val_loss: 0.1535 - val_accuracy: 0.9500
# Epoch 146/200
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.1813 - val_accuracy: 0.9391
# Epoch 147/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0302 - accuracy: 0.9910 - val_loss: 0.1560 - val_accuracy: 0.9422
# Epoch 148/200
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0244 - accuracy: 0.9941 - val_loss: 0.1685 - val_accuracy: 0.9453
# Epoch 149/200
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0205 - accuracy: 0.9973 - val_loss: 0.1558 - val_accuracy: 0.9469
# Epoch 150/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0216 - accuracy: 0.9961 - val_loss: 0.1687 - val_accuracy: 0.9406
# Epoch 151/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0250 - accuracy: 0.9945 - val_loss: 0.1588 - val_accuracy: 0.9453
# Epoch 152/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0251 - accuracy: 0.9945 - val_loss: 0.1502 - val_accuracy: 0.9469
# Epoch 153/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0183 - accuracy: 0.9965 - val_loss: 0.1671 - val_accuracy: 0.9438
# Epoch 154/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0219 - accuracy: 0.9969 - val_loss: 0.1666 - val_accuracy: 0.9391
# Epoch 155/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0212 - accuracy: 0.9965 - val_loss: 0.1584 - val_accuracy: 0.9484
# Epoch 156/200
# 5/5 [==============================] - 1s 296ms/step - loss: 0.0209 - accuracy: 0.9945 - val_loss: 0.1582 - val_accuracy: 0.9500
# Epoch 157/200
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0169 - accuracy: 0.9965 - val_loss: 0.1602 - val_accuracy: 0.9422
# Epoch 158/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0210 - accuracy: 0.9937 - val_loss: 0.1600 - val_accuracy: 0.9484
# Epoch 159/200
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0182 - accuracy: 0.9961 - val_loss: 0.1592 - val_accuracy: 0.9531
# Epoch 160/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0210 - accuracy: 0.9949 - val_loss: 0.1607 - val_accuracy: 0.9516
# Epoch 161/200
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.1685 - val_accuracy: 0.9438
# Epoch 162/200
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0183 - accuracy: 0.9953 - val_loss: 0.1688 - val_accuracy: 0.9422
# Epoch 163/200
# 5/5 [==============================] - 1s 272ms/step - loss: 0.0193 - accuracy: 0.9945 - val_loss: 0.1613 - val_accuracy: 0.9453
# Epoch 164/200
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0165 - accuracy: 0.9961 - val_loss: 0.1610 - val_accuracy: 0.9438
# Epoch 165/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0190 - accuracy: 0.9957 - val_loss: 0.1655 - val_accuracy: 0.9516
# Epoch 166/200
# 5/5 [==============================] - 1s 236ms/step - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.1670 - val_accuracy: 0.9453
# Epoch 167/200
# 5/5 [==============================] - 1s 239ms/step - loss: 0.0169 - accuracy: 0.9965 - val_loss: 0.1681 - val_accuracy: 0.9500
# Epoch 168/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0120 - accuracy: 0.9980 - val_loss: 0.1630 - val_accuracy: 0.9438
# Epoch 169/200
# 5/5 [==============================] - 1s 248ms/step - loss: 0.0142 - accuracy: 0.9969 - val_loss: 0.1719 - val_accuracy: 0.9469
# Epoch 170/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0154 - accuracy: 0.9984 - val_loss: 0.1607 - val_accuracy: 0.9422
# Epoch 171/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0166 - accuracy: 0.9973 - val_loss: 0.1712 - val_accuracy: 0.9469
# Epoch 172/200
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0154 - accuracy: 0.9961 - val_loss: 0.1810 - val_accuracy: 0.9391
# Epoch 173/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0166 - accuracy: 0.9957 - val_loss: 0.1791 - val_accuracy: 0.9453
# Epoch 174/200
# 5/5 [==============================] - 1s 278ms/step - loss: 0.0171 - accuracy: 0.9949 - val_loss: 0.1637 - val_accuracy: 0.9438
# Epoch 175/200
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0169 - accuracy: 0.9969 - val_loss: 0.1996 - val_accuracy: 0.9406
# Epoch 176/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0168 - accuracy: 0.9953 - val_loss: 0.1772 - val_accuracy: 0.9391
# Epoch 177/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0172 - accuracy: 0.9969 - val_loss: 0.1720 - val_accuracy: 0.9469
# Epoch 178/200
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0148 - accuracy: 0.9973 - val_loss: 0.1665 - val_accuracy: 0.9453
# Epoch 179/200
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0133 - accuracy: 0.9980 - val_loss: 0.1708 - val_accuracy: 0.9469
# Epoch 180/200
# 5/5 [==============================] - 1s 215ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 0.1680 - val_accuracy: 0.9438
# Epoch 181/200
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0114 - accuracy: 0.9988 - val_loss: 0.1692 - val_accuracy: 0.9469
# Epoch 182/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.1767 - val_accuracy: 0.9500
# Epoch 183/200
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.1846 - val_accuracy: 0.9453
# Epoch 184/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.1623 - val_accuracy: 0.9422
# Epoch 185/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.1692 - val_accuracy: 0.9469
# Epoch 186/200
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 0.1766 - val_accuracy: 0.9484
# Epoch 187/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0128 - accuracy: 0.9984 - val_loss: 0.1722 - val_accuracy: 0.9469
# Epoch 188/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.0119 - accuracy: 0.9973 - val_loss: 0.1697 - val_accuracy: 0.9438
# Epoch 189/200
# 5/5 [==============================] - 1s 284ms/step - loss: 0.0128 - accuracy: 0.9973 - val_loss: 0.1711 - val_accuracy: 0.9500
# Epoch 190/200
# 5/5 [==============================] - 1s 245ms/step - loss: 0.0141 - accuracy: 0.9969 - val_loss: 0.1686 - val_accuracy: 0.9422
# Epoch 191/200
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0122 - accuracy: 0.9980 - val_loss: 0.1708 - val_accuracy: 0.9438
# Epoch 192/200
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.1785 - val_accuracy: 0.9453
# Epoch 193/200
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.1766 - val_accuracy: 0.9453
# Epoch 194/200
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0098 - accuracy: 0.9992 - val_loss: 0.1679 - val_accuracy: 0.9469
# Epoch 195/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0122 - accuracy: 0.9969 - val_loss: 0.1659 - val_accuracy: 0.9469
# Epoch 196/200
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0120 - accuracy: 0.9977 - val_loss: 0.1600 - val_accuracy: 0.9500
# Epoch 197/200
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1809 - val_accuracy: 0.9438
# Epoch 198/200
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.1913 - val_accuracy: 0.9453
# Epoch 199/200
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.1765 - val_accuracy: 0.9469
# Epoch 200/200
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.1822 - val_accuracy: 0.9484

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodel)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=40, batch_size=512)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 2s 307ms/step - loss: 2.6617 - accuracy: 0.2922 - val_loss: 1.5156 - val_accuracy: 0.4187
# Epoch 2/40
# 5/5 [==============================] - 1s 276ms/step - loss: 1.3129 - accuracy: 0.5078 - val_loss: 1.1889 - val_accuracy: 0.4797
# Epoch 3/40
# 5/5 [==============================] - 1s 253ms/step - loss: 1.0915 - accuracy: 0.6336 - val_loss: 0.9224 - val_accuracy: 0.7328
# Epoch 4/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.8694 - accuracy: 0.7465 - val_loss: 0.7807 - val_accuracy: 0.7969
# Epoch 5/40
# 5/5 [==============================] - 1s 239ms/step - loss: 0.7504 - accuracy: 0.7711 - val_loss: 0.6639 - val_accuracy: 0.8422
# Epoch 6/40
# 5/5 [==============================] - 1s 234ms/step - loss: 0.6446 - accuracy: 0.8430 - val_loss: 0.5858 - val_accuracy: 0.8625
# Epoch 7/40
# 5/5 [==============================] - 1s 241ms/step - loss: 0.5794 - accuracy: 0.8480 - val_loss: 0.5378 - val_accuracy: 0.8656
# Epoch 8/40
# 5/5 [==============================] - 1s 288ms/step - loss: 0.5414 - accuracy: 0.8523 - val_loss: 0.4925 - val_accuracy: 0.8719
# Epoch 9/40
# 5/5 [==============================] - 1s 244ms/step - loss: 0.4869 - accuracy: 0.8582 - val_loss: 0.4788 - val_accuracy: 0.8687
# Epoch 10/40
# 5/5 [==============================] - 1s 214ms/step - loss: 0.4598 - accuracy: 0.8672 - val_loss: 0.4161 - val_accuracy: 0.8797
# Epoch 11/40
# 5/5 [==============================] - 1s 245ms/step - loss: 0.4158 - accuracy: 0.8809 - val_loss: 0.3891 - val_accuracy: 0.8906
# Epoch 12/40
# 5/5 [==============================] - 1s 221ms/step - loss: 0.3878 - accuracy: 0.8875 - val_loss: 0.3903 - val_accuracy: 0.8906
# Epoch 13/40
# 5/5 [==============================] - 1s 232ms/step - loss: 0.3847 - accuracy: 0.8840 - val_loss: 0.3590 - val_accuracy: 0.8984
# Epoch 14/40
# 5/5 [==============================] - 1s 245ms/step - loss: 0.3560 - accuracy: 0.8891 - val_loss: 0.3515 - val_accuracy: 0.8969
# Epoch 15/40
# 5/5 [==============================] - 1s 222ms/step - loss: 0.3434 - accuracy: 0.8934 - val_loss: 0.3416 - val_accuracy: 0.8953
# Epoch 16/40
# 5/5 [==============================] - 1s 227ms/step - loss: 0.3383 - accuracy: 0.8953 - val_loss: 0.3496 - val_accuracy: 0.8953
# Epoch 17/40
# 5/5 [==============================] - 1s 196ms/step - loss: 0.3309 - accuracy: 0.8965 - val_loss: 0.3349 - val_accuracy: 0.8953
# Epoch 18/40
# 5/5 [==============================] - 1s 252ms/step - loss: 0.3086 - accuracy: 0.9020 - val_loss: 0.3245 - val_accuracy: 0.8984
# Epoch 19/40
# 5/5 [==============================] - 1s 220ms/step - loss: 0.3067 - accuracy: 0.9035 - val_loss: 0.3199 - val_accuracy: 0.9047
# Epoch 20/40
# 5/5 [==============================] - 1s 248ms/step - loss: 0.3012 - accuracy: 0.9020 - val_loss: 0.2976 - val_accuracy: 0.9047
# Epoch 21/40
# 5/5 [==============================] - 1s 267ms/step - loss: 0.2844 - accuracy: 0.9055 - val_loss: 0.2950 - val_accuracy: 0.9000
# Epoch 22/40
# 5/5 [==============================] - 1s 274ms/step - loss: 0.2750 - accuracy: 0.9098 - val_loss: 0.2920 - val_accuracy: 0.9031
# Epoch 23/40
# 5/5 [==============================] - 1s 213ms/step - loss: 0.2684 - accuracy: 0.9090 - val_loss: 0.2868 - val_accuracy: 0.9109
# Epoch 24/40
# 5/5 [==============================] - 1s 227ms/step - loss: 0.2681 - accuracy: 0.9070 - val_loss: 0.2879 - val_accuracy: 0.9172
# Epoch 25/40
# 5/5 [==============================] - 1s 248ms/step - loss: 0.2570 - accuracy: 0.9160 - val_loss: 0.2717 - val_accuracy: 0.9000
# Epoch 26/40
# 5/5 [==============================] - 1s 209ms/step - loss: 0.2451 - accuracy: 0.9187 - val_loss: 0.2740 - val_accuracy: 0.8984
# Epoch 27/40
# 5/5 [==============================] - 1s 244ms/step - loss: 0.2510 - accuracy: 0.9164 - val_loss: 0.2692 - val_accuracy: 0.9047
# Epoch 28/40
# 5/5 [==============================] - 1s 289ms/step - loss: 0.2378 - accuracy: 0.9191 - val_loss: 0.2622 - val_accuracy: 0.9109
# Epoch 29/40
# 5/5 [==============================] - 1s 249ms/step - loss: 0.2396 - accuracy: 0.9184 - val_loss: 0.2796 - val_accuracy: 0.9281
# Epoch 30/40
# 5/5 [==============================] - 1s 234ms/step - loss: 0.2461 - accuracy: 0.9199 - val_loss: 0.2487 - val_accuracy: 0.9172
# Epoch 31/40
# 5/5 [==============================] - 1s 215ms/step - loss: 0.2197 - accuracy: 0.9234 - val_loss: 0.2654 - val_accuracy: 0.9047
# Epoch 32/40
# 5/5 [==============================] - 1s 246ms/step - loss: 0.2252 - accuracy: 0.9281 - val_loss: 0.2465 - val_accuracy: 0.9125
# Epoch 33/40
# 5/5 [==============================] - 1s 229ms/step - loss: 0.2124 - accuracy: 0.9266 - val_loss: 0.2408 - val_accuracy: 0.9187
# Epoch 34/40
# 5/5 [==============================] - 1s 231ms/step - loss: 0.2098 - accuracy: 0.9270 - val_loss: 0.2342 - val_accuracy: 0.9156
# Epoch 35/40
# 5/5 [==============================] - 1s 276ms/step - loss: 0.2042 - accuracy: 0.9305 - val_loss: 0.2311 - val_accuracy: 0.9250
# Epoch 36/40
# 5/5 [==============================] - 1s 231ms/step - loss: 0.1984 - accuracy: 0.9336 - val_loss: 0.2249 - val_accuracy: 0.9187
# Epoch 37/40
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2085 - accuracy: 0.9336 - val_loss: 0.2393 - val_accuracy: 0.9078
# Epoch 38/40
# 5/5 [==============================] - 1s 217ms/step - loss: 0.2059 - accuracy: 0.9285 - val_loss: 0.2446 - val_accuracy: 0.9047
# Epoch 39/40
# 5/5 [==============================] - 1s 227ms/step - loss: 0.1955 - accuracy: 0.9324 - val_loss: 0.2380 - val_accuracy: 0.9078
# Epoch 40/40
# 5/5 [==============================] - 1s 230ms/step - loss: 0.1998 - accuracy: 0.9324 - val_loss: 0.2379 - val_accuracy: 0.9109

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1726 - accuracy: 0.9297
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2379 - accuracy: 0.9109
# 0.9296875 0.910937488079071

# %% [markdown]
# ### Predict pixel classification on all of Scene 1-a

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])

start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})
predictCube = probCube.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:15:08

# %%
# -- Plot the prediction map of Scene 1-a

predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 1-a

# %%
# -- create the prediction arrays from the predictions of the testing set

labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# -- create the true arrays from the labeled testing set

labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-a

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0   9   1   0   0   0   0]
#  [  0   0   0   0 197   5   0   1   1]
#  [  0   0   0   0   9  91   0   0   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  1   0   0   0   7   5   0   7   0]
#  [  0   0   0   0  19   0   0   0   1]]
#
# Accuracy Score
# 0.9109375
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.98      1.00      0.99        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      0.90      0.95        10
#       built       0.82      0.97      0.89       204
#     windows       0.90      0.91      0.91       100
#       roads       0.00      0.00      0.00         6
#        cars       0.88      0.35      0.50        20
#       metal       0.50      0.05      0.09        20
#
# avg / total       0.90      0.91      0.89       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
