# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 848)
# (1600, 1600, 2)

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
train_acc = {}
test_acc = {}

# %%
lbl = '50_50'
trrat = 0.5

#lbl = '20_80'
#trrat = 0.2

#lbl = '10_90'
#trrat = 0.1

#lbl = '5_95'
#trrat = 0.05

#lbl = '3_97'
#trrat = 0.03

#lbl = '1_99'
#trrat = 0.01

#lbl = '05_995'
#trrat = 0.005

#lbl = '01_999'
#trrat = 0.001

# %%
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 150 150
# clouds: 250 250
# veg: 300 300
# wtr: 25 25
# blt: 510 510
# windows: 250 250
# rds: 15 15
# cars: 50 50
# mtl: 50 50

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (150, 848) (150, 848)
# clouds  (250, 848) (250, 848)
# vegetation  (300, 848) (300, 848)
# water  (25, 848) (25, 848)
# built  (510, 848) (510, 848)
# windows  (250, 848) (250, 848)
# roads  (15, 848) (15, 848)
# cars  (50, 848) (50, 848)
# metal  (50, 848) (50, 848)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (1600, 848) (1600,) (1600, 2)
# (1600, 848) (1600,) (1600, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 229ms/step - loss: 1.7329 - accuracy: 0.4038 - val_loss: 1.0521 - val_accuracy: 0.6550
# Epoch 2/200
# 4/4 [==============================] - 1s 144ms/step - loss: 1.0014 - accuracy: 0.6481 - val_loss: 0.7878 - val_accuracy: 0.7306
# Epoch 3/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.7956 - accuracy: 0.7225 - val_loss: 0.6822 - val_accuracy: 0.8156
# Epoch 4/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.6783 - accuracy: 0.7912 - val_loss: 0.6674 - val_accuracy: 0.7769
# Epoch 5/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.6394 - accuracy: 0.7981 - val_loss: 0.5743 - val_accuracy: 0.8219
# Epoch 6/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.5452 - accuracy: 0.8381 - val_loss: 0.5633 - val_accuracy: 0.8213
# Epoch 7/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.5141 - accuracy: 0.8394 - val_loss: 0.4582 - val_accuracy: 0.8413
# Epoch 8/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.4491 - accuracy: 0.8619 - val_loss: 0.4131 - val_accuracy: 0.8731
# Epoch 9/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.4205 - accuracy: 0.8706 - val_loss: 0.4091 - val_accuracy: 0.8694
# Epoch 10/200
# 4/4 [==============================] - 1s 160ms/step - loss: 0.3977 - accuracy: 0.8756 - val_loss: 0.3744 - val_accuracy: 0.8906
# Epoch 11/200
# 4/4 [==============================] - 1s 279ms/step - loss: 0.3546 - accuracy: 0.8975 - val_loss: 0.4273 - val_accuracy: 0.8431
# Epoch 12/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.3858 - accuracy: 0.8850 - val_loss: 0.8887 - val_accuracy: 0.7237
# Epoch 13/200
# 4/4 [==============================] - 1s 183ms/step - loss: 0.5681 - accuracy: 0.8231 - val_loss: 0.4164 - val_accuracy: 0.8906
# Epoch 14/200
# 4/4 [==============================] - 1s 188ms/step - loss: 0.4027 - accuracy: 0.8744 - val_loss: 0.4490 - val_accuracy: 0.8763
# Epoch 15/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.4335 - accuracy: 0.8725 - val_loss: 0.3550 - val_accuracy: 0.8888
# Epoch 16/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.3696 - accuracy: 0.8963 - val_loss: 0.3879 - val_accuracy: 0.9100
# Epoch 17/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.3637 - accuracy: 0.8863 - val_loss: 0.3539 - val_accuracy: 0.8931
# Epoch 18/200
# 4/4 [==============================] - 1s 178ms/step - loss: 0.3369 - accuracy: 0.8969 - val_loss: 0.3435 - val_accuracy: 0.8925
# Epoch 19/200
# 4/4 [==============================] - 1s 183ms/step - loss: 0.3322 - accuracy: 0.8963 - val_loss: 0.3145 - val_accuracy: 0.9019
# Epoch 20/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.3107 - accuracy: 0.9075 - val_loss: 0.3057 - val_accuracy: 0.9019
# Epoch 21/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.2927 - accuracy: 0.9069 - val_loss: 0.3101 - val_accuracy: 0.9050
# Epoch 22/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.2825 - accuracy: 0.9075 - val_loss: 0.3074 - val_accuracy: 0.9125
# Epoch 23/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.2860 - accuracy: 0.9156 - val_loss: 0.2806 - val_accuracy: 0.9131
# Epoch 24/200
# 4/4 [==============================] - 1s 175ms/step - loss: 0.2579 - accuracy: 0.9181 - val_loss: 0.2862 - val_accuracy: 0.9087
# Epoch 25/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.2505 - accuracy: 0.9200 - val_loss: 0.2659 - val_accuracy: 0.9175
# Epoch 26/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2533 - accuracy: 0.9181 - val_loss: 0.2777 - val_accuracy: 0.9144
# Epoch 27/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.2562 - accuracy: 0.9175 - val_loss: 0.2701 - val_accuracy: 0.9106
# Epoch 28/200
# 4/4 [==============================] - 1s 131ms/step - loss: 0.2739 - accuracy: 0.9169 - val_loss: 0.4703 - val_accuracy: 0.8006
# Epoch 29/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.3226 - accuracy: 0.8863 - val_loss: 0.2891 - val_accuracy: 0.9025
# Epoch 30/200
# 4/4 [==============================] - 1s 174ms/step - loss: 0.2798 - accuracy: 0.9131 - val_loss: 0.2931 - val_accuracy: 0.9044
# Epoch 31/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.2655 - accuracy: 0.9206 - val_loss: 0.2803 - val_accuracy: 0.9150
# Epoch 32/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.2460 - accuracy: 0.9237 - val_loss: 0.2611 - val_accuracy: 0.9125
# Epoch 33/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2326 - accuracy: 0.9225 - val_loss: 0.2532 - val_accuracy: 0.9187
# Epoch 34/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2244 - accuracy: 0.9294 - val_loss: 0.2482 - val_accuracy: 0.9244
# Epoch 35/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.2190 - accuracy: 0.9269 - val_loss: 0.2487 - val_accuracy: 0.9194
# Epoch 36/200
# 4/4 [==============================] - 1s 170ms/step - loss: 0.2172 - accuracy: 0.9281 - val_loss: 0.2448 - val_accuracy: 0.9237
# Epoch 37/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2142 - accuracy: 0.9331 - val_loss: 0.2419 - val_accuracy: 0.9244
# Epoch 38/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.2161 - accuracy: 0.9300 - val_loss: 0.2455 - val_accuracy: 0.9325
# Epoch 39/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.2186 - accuracy: 0.9325 - val_loss: 0.2378 - val_accuracy: 0.9262
# Epoch 40/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.2105 - accuracy: 0.9375 - val_loss: 0.2421 - val_accuracy: 0.9237
# Epoch 41/200
# 4/4 [==============================] - 1s 170ms/step - loss: 0.2041 - accuracy: 0.9312 - val_loss: 0.2262 - val_accuracy: 0.9319
# Epoch 42/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.1868 - accuracy: 0.9431 - val_loss: 0.2355 - val_accuracy: 0.9275
# Epoch 43/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.1968 - accuracy: 0.9406 - val_loss: 0.2199 - val_accuracy: 0.9306
# Epoch 44/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1885 - accuracy: 0.9431 - val_loss: 0.2659 - val_accuracy: 0.9200
# Epoch 45/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2164 - accuracy: 0.9269 - val_loss: 0.2227 - val_accuracy: 0.9350
# Epoch 46/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.1936 - accuracy: 0.9350 - val_loss: 0.2533 - val_accuracy: 0.9137
# Epoch 47/200
# 4/4 [==============================] - 1s 190ms/step - loss: 0.2028 - accuracy: 0.9306 - val_loss: 0.2243 - val_accuracy: 0.9294
# Epoch 48/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.1887 - accuracy: 0.9344 - val_loss: 0.2307 - val_accuracy: 0.9331
# Epoch 49/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1803 - accuracy: 0.9381 - val_loss: 0.2324 - val_accuracy: 0.9244
# Epoch 50/200
# 4/4 [==============================] - 1s 132ms/step - loss: 0.1893 - accuracy: 0.9431 - val_loss: 0.2203 - val_accuracy: 0.9356
# Epoch 51/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1889 - accuracy: 0.9375 - val_loss: 0.2162 - val_accuracy: 0.9312
# Epoch 52/200
# 4/4 [==============================] - 1s 166ms/step - loss: 0.1670 - accuracy: 0.9456 - val_loss: 0.2193 - val_accuracy: 0.9300
# Epoch 53/200
# 4/4 [==============================] - 1s 166ms/step - loss: 0.1759 - accuracy: 0.9400 - val_loss: 0.4262 - val_accuracy: 0.8487
# Epoch 54/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.2449 - accuracy: 0.9100 - val_loss: 0.2569 - val_accuracy: 0.9144
# Epoch 55/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.2300 - accuracy: 0.9169 - val_loss: 0.2517 - val_accuracy: 0.9181
# Epoch 56/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.2091 - accuracy: 0.9388 - val_loss: 0.2463 - val_accuracy: 0.9212
# Epoch 57/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.1961 - accuracy: 0.9337 - val_loss: 0.2404 - val_accuracy: 0.9325
# Epoch 58/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1865 - accuracy: 0.9400 - val_loss: 0.2120 - val_accuracy: 0.9413
# Epoch 59/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2106 - accuracy: 0.9319 - val_loss: 0.2458 - val_accuracy: 0.9194
# Epoch 60/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.2114 - accuracy: 0.9244 - val_loss: 0.2682 - val_accuracy: 0.9256
# Epoch 61/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.2101 - accuracy: 0.9331 - val_loss: 0.2455 - val_accuracy: 0.9212
# Epoch 62/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1973 - accuracy: 0.9362 - val_loss: 0.2131 - val_accuracy: 0.9331
# Epoch 63/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1849 - accuracy: 0.9444 - val_loss: 0.2060 - val_accuracy: 0.9269
# Epoch 64/200
# 4/4 [==============================] - 1s 175ms/step - loss: 0.1694 - accuracy: 0.9419 - val_loss: 0.2112 - val_accuracy: 0.9369
# Epoch 65/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.1665 - accuracy: 0.9475 - val_loss: 0.2012 - val_accuracy: 0.9381
# Epoch 66/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1606 - accuracy: 0.9488 - val_loss: 0.1995 - val_accuracy: 0.9413
# Epoch 67/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1558 - accuracy: 0.9506 - val_loss: 0.1995 - val_accuracy: 0.9337
# Epoch 68/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.1553 - accuracy: 0.9475 - val_loss: 0.2207 - val_accuracy: 0.9231
# Epoch 69/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1812 - accuracy: 0.9312 - val_loss: 0.2001 - val_accuracy: 0.9475
# Epoch 70/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.1737 - accuracy: 0.9481 - val_loss: 0.2245 - val_accuracy: 0.9250
# Epoch 71/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.1777 - accuracy: 0.9431 - val_loss: 0.2183 - val_accuracy: 0.9369
# Epoch 72/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.1609 - accuracy: 0.9456 - val_loss: 0.1888 - val_accuracy: 0.9362
# Epoch 73/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1474 - accuracy: 0.9481 - val_loss: 0.1892 - val_accuracy: 0.9413
# Epoch 74/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.1503 - accuracy: 0.9481 - val_loss: 0.1941 - val_accuracy: 0.9406
# Epoch 75/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1478 - accuracy: 0.9500 - val_loss: 0.2342 - val_accuracy: 0.9425
# Epoch 76/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.1536 - accuracy: 0.9469 - val_loss: 0.1921 - val_accuracy: 0.9362
# Epoch 77/200
# 4/4 [==============================] - 1s 154ms/step - loss: 0.1584 - accuracy: 0.9538 - val_loss: 0.1849 - val_accuracy: 0.9394
# Epoch 78/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.1362 - accuracy: 0.9550 - val_loss: 0.2278 - val_accuracy: 0.9269
# Epoch 79/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.1866 - accuracy: 0.9369 - val_loss: 0.2497 - val_accuracy: 0.9319
# Epoch 80/200
# 4/4 [==============================] - 2s 585ms/step - loss: 0.1737 - accuracy: 0.9438 - val_loss: 0.2257 - val_accuracy: 0.9200
# Epoch 81/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1781 - accuracy: 0.9406 - val_loss: 0.1907 - val_accuracy: 0.9456
# Epoch 82/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1387 - accuracy: 0.9513 - val_loss: 0.2018 - val_accuracy: 0.9344
# Epoch 83/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.1564 - accuracy: 0.9494 - val_loss: 0.1770 - val_accuracy: 0.9413
# Epoch 84/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1449 - accuracy: 0.9519 - val_loss: 0.1784 - val_accuracy: 0.9531
# Epoch 85/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1461 - accuracy: 0.9494 - val_loss: 0.1796 - val_accuracy: 0.9431
# Epoch 86/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1351 - accuracy: 0.9600 - val_loss: 0.1763 - val_accuracy: 0.9431
# Epoch 87/200
# 4/4 [==============================] - 1s 182ms/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.1832 - val_accuracy: 0.9444
# Epoch 88/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.1379 - accuracy: 0.9519 - val_loss: 0.1627 - val_accuracy: 0.9519
# Epoch 89/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.1191 - accuracy: 0.9644 - val_loss: 0.1680 - val_accuracy: 0.9475
# Epoch 90/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1383 - accuracy: 0.9494 - val_loss: 0.1725 - val_accuracy: 0.9450
# Epoch 91/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1206 - accuracy: 0.9588 - val_loss: 0.1826 - val_accuracy: 0.9419
# Epoch 92/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.1241 - accuracy: 0.9606 - val_loss: 0.1763 - val_accuracy: 0.9438
# Epoch 93/200
# 4/4 [==============================] - 1s 174ms/step - loss: 0.1263 - accuracy: 0.9550 - val_loss: 0.1693 - val_accuracy: 0.9481
# Epoch 94/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1286 - accuracy: 0.9594 - val_loss: 0.1608 - val_accuracy: 0.9538
# Epoch 95/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1361 - accuracy: 0.9519 - val_loss: 0.1915 - val_accuracy: 0.9381
# Epoch 96/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1288 - accuracy: 0.9556 - val_loss: 0.1674 - val_accuracy: 0.9481
# Epoch 97/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1193 - accuracy: 0.9594 - val_loss: 0.1592 - val_accuracy: 0.9544
# Epoch 98/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.1288 - accuracy: 0.9525 - val_loss: 0.1782 - val_accuracy: 0.9425
# Epoch 99/200
# 4/4 [==============================] - 1s 172ms/step - loss: 0.1384 - accuracy: 0.9475 - val_loss: 0.2104 - val_accuracy: 0.9450
# Epoch 100/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1309 - accuracy: 0.9506 - val_loss: 0.1783 - val_accuracy: 0.9413
# Epoch 101/200
# 4/4 [==============================] - 1s 153ms/step - loss: 0.1179 - accuracy: 0.9519 - val_loss: 0.1796 - val_accuracy: 0.9413
# Epoch 102/200
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1556 - accuracy: 0.9488 - val_loss: 0.1740 - val_accuracy: 0.9469
# Epoch 103/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1404 - accuracy: 0.9519 - val_loss: 0.1748 - val_accuracy: 0.9513
# Epoch 104/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1215 - accuracy: 0.9581 - val_loss: 0.1579 - val_accuracy: 0.9525
# Epoch 105/200
# 4/4 [==============================] - 1s 184ms/step - loss: 0.1306 - accuracy: 0.9531 - val_loss: 0.1880 - val_accuracy: 0.9356
# Epoch 106/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1366 - accuracy: 0.9519 - val_loss: 0.1960 - val_accuracy: 0.9406
# Epoch 107/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.1319 - accuracy: 0.9525 - val_loss: 0.1675 - val_accuracy: 0.9538
# Epoch 108/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.1229 - accuracy: 0.9650 - val_loss: 0.1970 - val_accuracy: 0.9319
# Epoch 109/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1454 - accuracy: 0.9450 - val_loss: 0.1688 - val_accuracy: 0.9475
# Epoch 110/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.1151 - accuracy: 0.9588 - val_loss: 0.1692 - val_accuracy: 0.9500
# Epoch 111/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.1277 - accuracy: 0.9525 - val_loss: 0.1863 - val_accuracy: 0.9400
# Epoch 112/200
# 4/4 [==============================] - 1s 158ms/step - loss: 0.1126 - accuracy: 0.9613 - val_loss: 0.1568 - val_accuracy: 0.9538
# Epoch 113/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1165 - accuracy: 0.9631 - val_loss: 0.1544 - val_accuracy: 0.9513
# Epoch 114/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1104 - accuracy: 0.9625 - val_loss: 0.1548 - val_accuracy: 0.9531
# Epoch 115/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0956 - accuracy: 0.9694 - val_loss: 0.1638 - val_accuracy: 0.9475
# Epoch 116/200
# 4/4 [==============================] - 1s 167ms/step - loss: 0.0980 - accuracy: 0.9675 - val_loss: 0.1574 - val_accuracy: 0.9594
# Epoch 117/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1083 - accuracy: 0.9650 - val_loss: 0.1642 - val_accuracy: 0.9463
# Epoch 118/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1034 - accuracy: 0.9669 - val_loss: 0.1675 - val_accuracy: 0.9531
# Epoch 119/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1232 - accuracy: 0.9638 - val_loss: 0.1583 - val_accuracy: 0.9438
# Epoch 120/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1088 - accuracy: 0.9575 - val_loss: 0.1571 - val_accuracy: 0.9525
# Epoch 121/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.1067 - accuracy: 0.9625 - val_loss: 0.1506 - val_accuracy: 0.9581
# Epoch 122/200
# 4/4 [==============================] - 1s 186ms/step - loss: 0.1086 - accuracy: 0.9644 - val_loss: 0.1639 - val_accuracy: 0.9506
# Epoch 123/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.1008 - accuracy: 0.9675 - val_loss: 0.1534 - val_accuracy: 0.9513
# Epoch 124/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.1009 - accuracy: 0.9644 - val_loss: 0.1826 - val_accuracy: 0.9388
# Epoch 125/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.1004 - accuracy: 0.9650 - val_loss: 0.1404 - val_accuracy: 0.9525
# Epoch 126/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0943 - accuracy: 0.9638 - val_loss: 0.1607 - val_accuracy: 0.9538
# Epoch 127/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.1058 - accuracy: 0.9663 - val_loss: 0.1377 - val_accuracy: 0.9581
# Epoch 128/200
# 4/4 [==============================] - 1s 182ms/step - loss: 0.0872 - accuracy: 0.9700 - val_loss: 0.1484 - val_accuracy: 0.9544
# Epoch 129/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0876 - accuracy: 0.9731 - val_loss: 0.1374 - val_accuracy: 0.9563
# Epoch 130/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.0829 - accuracy: 0.9750 - val_loss: 0.1451 - val_accuracy: 0.9613
# Epoch 131/200
# 4/4 [==============================] - 1s 135ms/step - loss: 0.0889 - accuracy: 0.9706 - val_loss: 0.1387 - val_accuracy: 0.9588
# Epoch 132/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.1078 - accuracy: 0.9631 - val_loss: 0.1845 - val_accuracy: 0.9438
# Epoch 133/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.1069 - accuracy: 0.9600 - val_loss: 0.1409 - val_accuracy: 0.9563
# Epoch 134/200
# 4/4 [==============================] - 1s 192ms/step - loss: 0.1021 - accuracy: 0.9631 - val_loss: 0.1860 - val_accuracy: 0.9488
# Epoch 135/200
# 4/4 [==============================] - 1s 154ms/step - loss: 0.1144 - accuracy: 0.9581 - val_loss: 0.1461 - val_accuracy: 0.9531
# Epoch 136/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.1098 - accuracy: 0.9669 - val_loss: 0.1633 - val_accuracy: 0.9450
# Epoch 137/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.1102 - accuracy: 0.9575 - val_loss: 0.1676 - val_accuracy: 0.9538
# Epoch 138/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.1031 - accuracy: 0.9656 - val_loss: 0.1747 - val_accuracy: 0.9469
# Epoch 139/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.1143 - accuracy: 0.9581 - val_loss: 0.1689 - val_accuracy: 0.9431
# Epoch 140/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.1118 - accuracy: 0.9563 - val_loss: 0.1620 - val_accuracy: 0.9550
# Epoch 141/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1037 - accuracy: 0.9681 - val_loss: 0.1557 - val_accuracy: 0.9513
# Epoch 142/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.1072 - accuracy: 0.9606 - val_loss: 0.1463 - val_accuracy: 0.9563
# Epoch 143/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0876 - accuracy: 0.9688 - val_loss: 0.1536 - val_accuracy: 0.9494
# Epoch 144/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0978 - accuracy: 0.9650 - val_loss: 0.1498 - val_accuracy: 0.9538
# Epoch 145/200
# 4/4 [==============================] - 1s 161ms/step - loss: 0.0979 - accuracy: 0.9638 - val_loss: 0.1417 - val_accuracy: 0.9556
# Epoch 146/200
# 4/4 [==============================] - 1s 157ms/step - loss: 0.0816 - accuracy: 0.9731 - val_loss: 0.1533 - val_accuracy: 0.9563
# Epoch 147/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0998 - accuracy: 0.9638 - val_loss: 0.1457 - val_accuracy: 0.9569
# Epoch 148/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.0918 - accuracy: 0.9681 - val_loss: 0.1506 - val_accuracy: 0.9538
# Epoch 149/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0869 - accuracy: 0.9737 - val_loss: 0.1398 - val_accuracy: 0.9550
# Epoch 150/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0795 - accuracy: 0.9725 - val_loss: 0.1577 - val_accuracy: 0.9500
# Epoch 151/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1050 - accuracy: 0.9650 - val_loss: 0.1435 - val_accuracy: 0.9575
# Epoch 152/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0882 - accuracy: 0.9731 - val_loss: 0.1424 - val_accuracy: 0.9581
# Epoch 153/200
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0951 - accuracy: 0.9644 - val_loss: 0.1604 - val_accuracy: 0.9450
# Epoch 154/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0736 - accuracy: 0.9769 - val_loss: 0.1456 - val_accuracy: 0.9563
# Epoch 155/200
# 4/4 [==============================] - 1s 137ms/step - loss: 0.0795 - accuracy: 0.9794 - val_loss: 0.1504 - val_accuracy: 0.9513
# Epoch 156/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0789 - accuracy: 0.9750 - val_loss: 0.1361 - val_accuracy: 0.9613
# Epoch 157/200
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0701 - accuracy: 0.9750 - val_loss: 0.1455 - val_accuracy: 0.9525
# Epoch 158/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0775 - accuracy: 0.9712 - val_loss: 0.1361 - val_accuracy: 0.9606
# Epoch 159/200
# 4/4 [==============================] - 1s 147ms/step - loss: 0.0658 - accuracy: 0.9750 - val_loss: 0.1283 - val_accuracy: 0.9594
# Epoch 160/200
# 4/4 [==============================] - 1s 142ms/step - loss: 0.0663 - accuracy: 0.9794 - val_loss: 0.1250 - val_accuracy: 0.9638
# Epoch 161/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0649 - accuracy: 0.9800 - val_loss: 0.1266 - val_accuracy: 0.9619
# Epoch 162/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0615 - accuracy: 0.9831 - val_loss: 0.1268 - val_accuracy: 0.9600
# Epoch 163/200
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0609 - accuracy: 0.9819 - val_loss: 0.1391 - val_accuracy: 0.9619
# Epoch 164/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0653 - accuracy: 0.9787 - val_loss: 0.1448 - val_accuracy: 0.9538
# Epoch 165/200
# 4/4 [==============================] - 1s 163ms/step - loss: 0.0728 - accuracy: 0.9750 - val_loss: 0.1298 - val_accuracy: 0.9631
# Epoch 166/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0589 - accuracy: 0.9781 - val_loss: 0.1502 - val_accuracy: 0.9575
# Epoch 167/200
# 4/4 [==============================] - 1s 144ms/step - loss: 0.0786 - accuracy: 0.9719 - val_loss: 0.1417 - val_accuracy: 0.9594
# Epoch 168/200
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0815 - accuracy: 0.9737 - val_loss: 0.1305 - val_accuracy: 0.9619
# Epoch 169/200
# 4/4 [==============================] - 1s 170ms/step - loss: 0.0689 - accuracy: 0.9769 - val_loss: 0.1375 - val_accuracy: 0.9594
# Epoch 170/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0731 - accuracy: 0.9756 - val_loss: 0.1298 - val_accuracy: 0.9606
# Epoch 171/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.0905 - accuracy: 0.9706 - val_loss: 0.1372 - val_accuracy: 0.9631
# Epoch 172/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.0850 - accuracy: 0.9700 - val_loss: 0.1299 - val_accuracy: 0.9594
# Epoch 173/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.0931 - accuracy: 0.9725 - val_loss: 0.1308 - val_accuracy: 0.9594
# Epoch 174/200
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0748 - accuracy: 0.9681 - val_loss: 0.1331 - val_accuracy: 0.9619
# Epoch 175/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0761 - accuracy: 0.9731 - val_loss: 0.1526 - val_accuracy: 0.9594
# Epoch 176/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.0842 - accuracy: 0.9700 - val_loss: 0.1436 - val_accuracy: 0.9506
# Epoch 177/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0776 - accuracy: 0.9694 - val_loss: 0.1578 - val_accuracy: 0.9519
# Epoch 178/200
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0846 - accuracy: 0.9656 - val_loss: 0.1456 - val_accuracy: 0.9556
# Epoch 179/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.0991 - accuracy: 0.9681 - val_loss: 0.1479 - val_accuracy: 0.9600
# Epoch 180/200
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0829 - accuracy: 0.9719 - val_loss: 0.1368 - val_accuracy: 0.9581
# Epoch 181/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0797 - accuracy: 0.9712 - val_loss: 0.1340 - val_accuracy: 0.9613
# Epoch 182/200
# 4/4 [==============================] - 1s 154ms/step - loss: 0.0653 - accuracy: 0.9769 - val_loss: 0.1317 - val_accuracy: 0.9606
# Epoch 183/200
# 4/4 [==============================] - 1s 139ms/step - loss: 0.0629 - accuracy: 0.9806 - val_loss: 0.1297 - val_accuracy: 0.9625
# Epoch 184/200
# 4/4 [==============================] - 1s 138ms/step - loss: 0.0586 - accuracy: 0.9794 - val_loss: 0.1445 - val_accuracy: 0.9544
# Epoch 185/200
# 4/4 [==============================] - 1s 151ms/step - loss: 0.0725 - accuracy: 0.9700 - val_loss: 0.1465 - val_accuracy: 0.9594
# Epoch 186/200
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0611 - accuracy: 0.9787 - val_loss: 0.1265 - val_accuracy: 0.9631
# Epoch 187/200
# 4/4 [==============================] - 1s 148ms/step - loss: 0.0535 - accuracy: 0.9862 - val_loss: 0.1235 - val_accuracy: 0.9669
# Epoch 188/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0542 - accuracy: 0.9837 - val_loss: 0.1261 - val_accuracy: 0.9638
# Epoch 189/200
# 4/4 [==============================] - 1s 134ms/step - loss: 0.0612 - accuracy: 0.9787 - val_loss: 0.1657 - val_accuracy: 0.9538
# Epoch 190/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.0839 - accuracy: 0.9737 - val_loss: 0.1492 - val_accuracy: 0.9581
# Epoch 191/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.0655 - accuracy: 0.9762 - val_loss: 0.1230 - val_accuracy: 0.9656
# Epoch 192/200
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0597 - accuracy: 0.9812 - val_loss: 0.1391 - val_accuracy: 0.9550
# Epoch 193/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.0679 - accuracy: 0.9769 - val_loss: 0.1431 - val_accuracy: 0.9525
# Epoch 194/200
# 4/4 [==============================] - 1s 145ms/step - loss: 0.0803 - accuracy: 0.9688 - val_loss: 0.1559 - val_accuracy: 0.9588
# Epoch 195/200
# 4/4 [==============================] - 1s 140ms/step - loss: 0.0790 - accuracy: 0.9775 - val_loss: 0.1538 - val_accuracy: 0.9494
# Epoch 196/200
# 4/4 [==============================] - 1s 150ms/step - loss: 0.0817 - accuracy: 0.9681 - val_loss: 0.1259 - val_accuracy: 0.9644
# Epoch 197/200
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0680 - accuracy: 0.9781 - val_loss: 0.1384 - val_accuracy: 0.9594
# Epoch 198/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0591 - accuracy: 0.9775 - val_loss: 0.1597 - val_accuracy: 0.9544
# Epoch 199/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0747 - accuracy: 0.9750 - val_loss: 0.1356 - val_accuracy: 0.9625
# Epoch 200/200
# 4/4 [==============================] - 1s 136ms/step - loss: 0.0631 - accuracy: 0.9775 - val_loss: 0.1316 - val_accuracy: 0.9650

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=65, batch_size=512)
# Out:
# Epoch 1/65
# 4/4 [==============================] - 1s 232ms/step - loss: 1.8642 - accuracy: 0.3187 - val_loss: 1.3684 - val_accuracy: 0.4956
# Epoch 2/65
# 4/4 [==============================] - 1s 158ms/step - loss: 1.1948 - accuracy: 0.6169 - val_loss: 1.1169 - val_accuracy: 0.6519
# Epoch 3/65
# 4/4 [==============================] - 1s 156ms/step - loss: 0.9978 - accuracy: 0.7025 - val_loss: 0.8221 - val_accuracy: 0.6619
# Epoch 4/65
# 4/4 [==============================] - 1s 137ms/step - loss: 0.8092 - accuracy: 0.6913 - val_loss: 0.7174 - val_accuracy: 0.7719
# Epoch 5/65
# 4/4 [==============================] - 1s 138ms/step - loss: 0.7177 - accuracy: 0.8006 - val_loss: 0.6597 - val_accuracy: 0.7869
# Epoch 6/65
# 4/4 [==============================] - 1s 138ms/step - loss: 0.6458 - accuracy: 0.7937 - val_loss: 0.5832 - val_accuracy: 0.8356
# Epoch 7/65
# 4/4 [==============================] - 1s 168ms/step - loss: 0.5527 - accuracy: 0.8419 - val_loss: 0.5221 - val_accuracy: 0.8462
# Epoch 8/65
# 4/4 [==============================] - 1s 154ms/step - loss: 0.5104 - accuracy: 0.8531 - val_loss: 0.4526 - val_accuracy: 0.8462
# Epoch 9/65
# 4/4 [==============================] - 1s 155ms/step - loss: 0.4437 - accuracy: 0.8631 - val_loss: 0.4243 - val_accuracy: 0.8569
# Epoch 10/65
# 4/4 [==============================] - 1s 137ms/step - loss: 0.4148 - accuracy: 0.8656 - val_loss: 0.4036 - val_accuracy: 0.8850
# Epoch 11/65
# 4/4 [==============================] - 1s 144ms/step - loss: 0.3889 - accuracy: 0.8800 - val_loss: 0.4058 - val_accuracy: 0.8550
# Epoch 12/65
# 4/4 [==============================] - 1s 143ms/step - loss: 0.4030 - accuracy: 0.8631 - val_loss: 0.3871 - val_accuracy: 0.8781
# Epoch 13/65
# 4/4 [==============================] - 1s 166ms/step - loss: 0.3794 - accuracy: 0.8800 - val_loss: 0.3713 - val_accuracy: 0.8781
# Epoch 14/65
# 4/4 [==============================] - 1s 158ms/step - loss: 0.3642 - accuracy: 0.8850 - val_loss: 0.3477 - val_accuracy: 0.8988
# Epoch 15/65
# 4/4 [==============================] - 1s 163ms/step - loss: 0.3403 - accuracy: 0.8981 - val_loss: 0.4511 - val_accuracy: 0.8562
# Epoch 16/65
# 4/4 [==============================] - 1s 141ms/step - loss: 0.4184 - accuracy: 0.8706 - val_loss: 0.3352 - val_accuracy: 0.9075
# Epoch 17/65
# 4/4 [==============================] - 1s 151ms/step - loss: 0.3379 - accuracy: 0.8988 - val_loss: 0.4116 - val_accuracy: 0.8806
# Epoch 18/65
# 4/4 [==============================] - 1s 160ms/step - loss: 0.3719 - accuracy: 0.8913 - val_loss: 0.3366 - val_accuracy: 0.9025
# Epoch 19/65
# 4/4 [==============================] - 1s 205ms/step - loss: 0.3122 - accuracy: 0.8994 - val_loss: 0.2956 - val_accuracy: 0.9087
# Epoch 20/65
# 4/4 [==============================] - 1s 153ms/step - loss: 0.3089 - accuracy: 0.9056 - val_loss: 0.2977 - val_accuracy: 0.9044
# Epoch 21/65
# 4/4 [==============================] - 1s 156ms/step - loss: 0.2924 - accuracy: 0.9025 - val_loss: 0.2983 - val_accuracy: 0.9131
# Epoch 22/65
# 4/4 [==============================] - 1s 152ms/step - loss: 0.2811 - accuracy: 0.9162 - val_loss: 0.3032 - val_accuracy: 0.9025
# Epoch 23/65
# 4/4 [==============================] - 1s 153ms/step - loss: 0.2659 - accuracy: 0.9137 - val_loss: 0.3038 - val_accuracy: 0.9125
# Epoch 24/65
# 4/4 [==============================] - 1s 169ms/step - loss: 0.2844 - accuracy: 0.9156 - val_loss: 0.2785 - val_accuracy: 0.9144
# Epoch 25/65
# 4/4 [==============================] - 1s 169ms/step - loss: 0.2358 - accuracy: 0.9244 - val_loss: 0.2854 - val_accuracy: 0.9069
# Epoch 26/65
# 4/4 [==============================] - 1s 164ms/step - loss: 0.2584 - accuracy: 0.9200 - val_loss: 0.2846 - val_accuracy: 0.9094
# Epoch 27/65
# 4/4 [==============================] - 1s 151ms/step - loss: 0.2522 - accuracy: 0.9162 - val_loss: 0.2633 - val_accuracy: 0.9162
# Epoch 28/65
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2456 - accuracy: 0.9231 - val_loss: 0.2517 - val_accuracy: 0.9206
# Epoch 29/65
# 4/4 [==============================] - 1s 163ms/step - loss: 0.2238 - accuracy: 0.9231 - val_loss: 0.3576 - val_accuracy: 0.8969
# Epoch 30/65
# 4/4 [==============================] - 1s 201ms/step - loss: 0.2668 - accuracy: 0.9194 - val_loss: 0.2750 - val_accuracy: 0.9112
# Epoch 31/65
# 4/4 [==============================] - 1s 145ms/step - loss: 0.2755 - accuracy: 0.9137 - val_loss: 0.2506 - val_accuracy: 0.9169
# Epoch 32/65
# 4/4 [==============================] - 1s 168ms/step - loss: 0.2776 - accuracy: 0.9106 - val_loss: 0.2731 - val_accuracy: 0.9119
# Epoch 33/65
# 4/4 [==============================] - 1s 143ms/step - loss: 0.2485 - accuracy: 0.9175 - val_loss: 0.2741 - val_accuracy: 0.9150
# Epoch 34/65
# 4/4 [==============================] - 1s 152ms/step - loss: 0.2533 - accuracy: 0.9187 - val_loss: 0.2694 - val_accuracy: 0.9219
# Epoch 35/65
# 4/4 [==============================] - 1s 185ms/step - loss: 0.2509 - accuracy: 0.9219 - val_loss: 0.2516 - val_accuracy: 0.9162
# Epoch 36/65
# 4/4 [==============================] - 1s 150ms/step - loss: 0.2268 - accuracy: 0.9262 - val_loss: 0.2405 - val_accuracy: 0.9306
# Epoch 37/65
# 4/4 [==============================] - 1s 156ms/step - loss: 0.2228 - accuracy: 0.9294 - val_loss: 0.2546 - val_accuracy: 0.9131
# Epoch 38/65
# 4/4 [==============================] - 1s 138ms/step - loss: 0.2343 - accuracy: 0.9219 - val_loss: 0.3079 - val_accuracy: 0.9119
# Epoch 39/65
# 4/4 [==============================] - 1s 139ms/step - loss: 0.2863 - accuracy: 0.9075 - val_loss: 0.2668 - val_accuracy: 0.9269
# Epoch 40/65
# 4/4 [==============================] - 1s 161ms/step - loss: 0.2552 - accuracy: 0.9187 - val_loss: 0.3317 - val_accuracy: 0.9013
# Epoch 41/65
# 4/4 [==============================] - 1s 189ms/step - loss: 0.2545 - accuracy: 0.9212 - val_loss: 0.2956 - val_accuracy: 0.8975
# Epoch 42/65
# 4/4 [==============================] - 1s 154ms/step - loss: 0.2668 - accuracy: 0.9100 - val_loss: 0.2518 - val_accuracy: 0.9125
# Epoch 43/65
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2281 - accuracy: 0.9244 - val_loss: 0.2355 - val_accuracy: 0.9219
# Epoch 44/65
# 4/4 [==============================] - 1s 149ms/step - loss: 0.2219 - accuracy: 0.9350 - val_loss: 0.2231 - val_accuracy: 0.9306
# Epoch 45/65
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2043 - accuracy: 0.9294 - val_loss: 0.2267 - val_accuracy: 0.9206
# Epoch 46/65
# 4/4 [==============================] - 1s 185ms/step - loss: 0.2024 - accuracy: 0.9312 - val_loss: 0.2220 - val_accuracy: 0.9250
# Epoch 47/65
# 4/4 [==============================] - 1s 151ms/step - loss: 0.1937 - accuracy: 0.9294 - val_loss: 0.2250 - val_accuracy: 0.9262
# Epoch 48/65
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1887 - accuracy: 0.9369 - val_loss: 0.2411 - val_accuracy: 0.9169
# Epoch 49/65
# 4/4 [==============================] - 1s 145ms/step - loss: 0.2066 - accuracy: 0.9281 - val_loss: 0.2612 - val_accuracy: 0.9250
# Epoch 50/65
# 4/4 [==============================] - 1s 153ms/step - loss: 0.1965 - accuracy: 0.9381 - val_loss: 0.2139 - val_accuracy: 0.9275
# Epoch 51/65
# 4/4 [==============================] - 1s 181ms/step - loss: 0.2055 - accuracy: 0.9337 - val_loss: 0.2314 - val_accuracy: 0.9269
# Epoch 52/65
# 4/4 [==============================] - 1s 157ms/step - loss: 0.2170 - accuracy: 0.9294 - val_loss: 0.2189 - val_accuracy: 0.9225
# Epoch 53/65
# 4/4 [==============================] - 1s 173ms/step - loss: 0.1802 - accuracy: 0.9319 - val_loss: 0.2154 - val_accuracy: 0.9262
# Epoch 54/65
# 4/4 [==============================] - 1s 146ms/step - loss: 0.1882 - accuracy: 0.9431 - val_loss: 0.2189 - val_accuracy: 0.9219
# Epoch 55/65
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1835 - accuracy: 0.9331 - val_loss: 0.2178 - val_accuracy: 0.9256
# Epoch 56/65
# 4/4 [==============================] - 1s 154ms/step - loss: 0.1761 - accuracy: 0.9406 - val_loss: 0.2029 - val_accuracy: 0.9331
# Epoch 57/65
# 4/4 [==============================] - 1s 171ms/step - loss: 0.1855 - accuracy: 0.9431 - val_loss: 0.2079 - val_accuracy: 0.9319
# Epoch 58/65
# 4/4 [==============================] - 1s 157ms/step - loss: 0.1767 - accuracy: 0.9350 - val_loss: 0.2185 - val_accuracy: 0.9312
# Epoch 59/65
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1738 - accuracy: 0.9356 - val_loss: 0.1943 - val_accuracy: 0.9369
# Epoch 60/65
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1704 - accuracy: 0.9463 - val_loss: 0.2024 - val_accuracy: 0.9388
# Epoch 61/65
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1710 - accuracy: 0.9438 - val_loss: 0.1953 - val_accuracy: 0.9325
# Epoch 62/65
# 4/4 [==============================] - 1s 242ms/step - loss: 0.1638 - accuracy: 0.9356 - val_loss: 0.1915 - val_accuracy: 0.9375
# Epoch 63/65
# 4/4 [==============================] - 1s 154ms/step - loss: 0.1555 - accuracy: 0.9450 - val_loss: 0.2291 - val_accuracy: 0.9212
# Epoch 64/65
# 4/4 [==============================] - 1s 156ms/step - loss: 0.1758 - accuracy: 0.9425 - val_loss: 0.2388 - val_accuracy: 0.9256
# Epoch 65/65
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1961 - accuracy: 0.9369 - val_loss: 0.2729 - val_accuracy: 0.9212

# %%
# model accuracy on training and testing sets

train_loss, train_acc[trrat] = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc[trrat] = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2002 - accuracy: 0.9419
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2729 - accuracy: 0.9212
# {0.5: 0.9418749809265137} {0.5: 0.9212499856948853}

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 848, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:09:22

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
#fig.savefig("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.png", bbox_inches='tight')

# %%
#import pickle
#pickle.dump(predictCube_reshape, open("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.pickle", "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (1600,)
# (1600,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[149   1   0   0   0   0   0   0   0]
#  [  1 249   0   0   0   0   0   0   0]
#  [  0   0 296   0   4   0   0   0   0]
#  [  0   0   0  24   1   0   0   0   0]
#  [  0   0   0   0 474  34   0   2   0]
#  [  0   0   0   0   4 245   0   1   0]
#  [  0   0   0   0   0  12   3   0   0]
#  [  0   0   0   0   8  18   0  24   0]
#  [  0   0   0   0  11  29   0   0  10]]
#
# Accuracy Score
# 0.92125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.99      0.99      0.99       150
#      clouds       1.00      1.00      1.00       250
#  vegetation       1.00      0.99      0.99       300
#       water       1.00      0.96      0.98        25
#       built       0.94      0.93      0.94       510
#     windows       0.72      0.98      0.83       250
#       roads       1.00      0.20      0.33        15
#        cars       0.89      0.48      0.62        50
#       metal       1.00      0.20      0.33        50
#
# avg / total       0.93      0.92      0.91      1600

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(lbl), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %% [markdown]
# ___
# ## Plot Results

# %%
import numpy as np

#train_acc = [train_acc_200, train_acc_100, train_acc_50, train_acc_20, train_acc_10, train_acc_5]
#test_acc =[test_acc_100, test_acc_100, test_acc_50, test_acc_20, test_acc_10, test_acc_5]

plt_train_acc = [0.9574, train_acc[0.5], train_acc[0.2], train_acc[0.1], train_acc[0.05], train_acc[0.03], 
                 train_acc[0.01], train_acc[0.005], train_acc[0.001]]
plt_test_acc =[0.9422, test_acc[0.5], test_acc[0.2], test_acc[0.1], test_acc[0.05], test_acc[0.03],
               test_acc[0.01], test_acc[0.005], test_acc[0.001]]

print(plt_train_acc)
print(plt_test_acc)

# %%
n_groups = 9

avg_prec = np.zeros(n_groups)
avg_recall = np.zeros(n_groups)
avg_f1 = np.zeros(n_groups)
train_size = np.zeros(n_groups)
sky_prec = np.zeros(n_groups)
sky_recall = np.zeros(n_groups)
sky_f1 = np.zeros(n_groups)
sky_train_size = np.zeros(n_groups)
clouds_prec = np.zeros(n_groups)
clouds_recall = np.zeros(n_groups)
clouds_f1 = np.zeros(n_groups)
clouds_train_size = np.zeros(n_groups)
veg_prec = np.zeros(n_groups)
veg_recall = np.zeros(n_groups)
veg_f1 = np.zeros(n_groups)
veg_train_size = np.zeros(n_groups)
wtr_prec = np.zeros(n_groups)
wtr_recall = np.zeros(n_groups)
wtr_f1 = np.zeros(n_groups)
wtr_train_size = np.zeros(n_groups)
blt_prec = np.zeros(n_groups)
blt_recall = np.zeros(n_groups)
blt_f1 = np.zeros(n_groups)
blt_train_size = np.zeros(n_groups)
windows_prec = np.zeros(n_groups)
windows_recall = np.zeros(n_groups)
windows_f1 = np.zeros(n_groups)
windows_train_size = np.zeros(n_groups)
rds_prec = np.zeros(n_groups)
rds_recall = np.zeros(n_groups)
rds_f1 = np.zeros(n_groups)
rds_train_size = np.zeros(n_groups)
cars_prec = np.zeros(n_groups)
cars_recall = np.zeros(n_groups)
cars_f1 = np.zeros(n_groups)
cars_train_size = np.zeros(n_groups)
mtl_prec = np.zeros(n_groups)
mtl_recall = np.zeros(n_groups)
mtl_f1 = np.zeros(n_groups)
mtl_train_size = np.zeros(n_groups)

# %%
def read_prec_recall(file, line):
    Nums = []
    for num in file[line].split():
        try:
            Nums.append(float(num))
        except ValueError:
            pass
    prec = Nums[0]
    recall = Nums[1]
    f1 = Nums[2]
    #size = int(Nums[3]*(tt_ratio/100)/((100-tt_ratio)/100))
    size = Nums[3]
    
    return prec, recall, f1, size

# %%
filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics.txt"
f = open(filename, "r")
f1 = f.readlines()
i=0
avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
f.close()

# %%
train_split = ['80_20', '50_50', '20_80', '10_90', '5_95', '3_97', '1_99', '05_995', '01_999']
#tr_splits = [80, 50, 20, 10, 5, 3, 1, 0.5, 0.1]

#i=0
#for split in train_split:
for i in range(1,n_groups):
    filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(train_split[i])
    f = open(filename, "r")
    f1 = f.readlines()

    avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
    sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
    clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
    veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
    wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
    blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
    windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
    rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
    cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
    mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
    f.close()
    #i += 1

# %%
train_size = 3200 - train_size
sky_train_size = sky_coords.shape[0] - sky_train_size
clouds_train_size = clouds_coords.shape[0] - clouds_train_size
veg_train_size = veg_coords.shape[0] - veg_train_size
wtr_train_size = wtr_coords.shape[0] - wtr_train_size
blt_train_size = blt_coords.shape[0] - blt_train_size
windows_train_size = windows_coords.shape[0] - windows_train_size
rds_train_size = rds_coords.shape[0] - rds_train_size
cars_train_size = cars_coords.shape[0] - cars_train_size
mtl_train_size = mtl_coords.shape[0] - mtl_train_size

# %%
print(train_size)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 22
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

#train_size = [2560, 1600, 640, 320, 159]

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(20,5))

ax1.plot(train_size, plt_train_acc, '-o', color='b', lw=3, label='train')
ax1.plot(train_size, plt_test_acc, '-o', color='g', lw=3, label='test')
ax1.set_title("Accuracy", fontsize=20)
ax1.set_xlabel("training instances")
ax1.set_ylabel("accuracy")
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white')
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(train_size)
ax1.set_xlim(2800,8)
ax1.set_ylim(0.55,0.99)

ax2.plot(train_size, avg_prec, '-o', color='b', lw=3, label='mP')
ax2.plot(train_size, avg_recall, '-o', color='y', lw=3, label='mR')
ax2.plot(train_size, avg_f1, '-o', color='r', lw=3, label='mF1')
ax2.set_title("Mean Precision, Recall, and F1-Score", fontsize=20)
ax2.set_xlabel("training instances")
ax2.set_ylabel("metric")
handles, labels = ax2.get_legend_handles_labels()
ax2.legend(handles, labels, facecolor='white')
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(train_size)
ax2.set_xlim(2800,8)
ax2.set_ylim(0.55,0.99)

plt.show
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_overall_metrics_extend.png", bbox_inches='tight', dpi=300

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

fig, ((ax1, ax2, ax3),(ax4, ax5, ax6),(ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(25,18))
ax1.plot(sky_train_size[:-1], sky_prec[:-1], '-o', color='b', lw=3, label='Precision')
ax1.plot(sky_train_size[:-1], sky_recall[:-1], '-o', color='y', lw=3, label='Recall')
ax1.plot(sky_train_size[:-1], sky_f1[:-1], '-o', color='r', lw=3, label='F1 Score')
ax1.set(title="Sky")
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(sky_train_size[:-1])
ax1.set_xticks([1,2,8,32,128,512])
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(0.8,1000)
ax1.set_ylabel("metric")
ax1.invert_xaxis()
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white', loc='lower left')

ax2.plot(clouds_train_size, clouds_prec, '-o', color='b', lw=3)
ax2.plot(clouds_train_size, clouds_recall, '-o', color='y', lw=3)
ax2.plot(clouds_train_size, clouds_f1, '-o', color='r', lw=3)
ax2.set(title="Clouds")
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(clouds_train_size)
ax2.set_xticks([1,2,8,32,128,512])
ax2.set_ylim(-0.1,1.1)
ax2.set_xlim(0.8,1000)
ax2.invert_xaxis()
ax2.legend(handles, labels, facecolor='white', loc='lower left')

ax3.plot(veg_train_size, veg_prec, '-o', color='b', lw=3)
ax3.plot(veg_train_size, veg_recall, '-o', color='y', lw=3)
ax3.plot(veg_train_size, veg_f1, '-o', color='r', lw=3)
ax3.set(title="Vegetation")
ax3.set_xscale('log', basex=2)
ax3.xaxis.set_major_formatter(ScalarFormatter())
#ax3.set_xticks(veg_train_size)
ax3.set_xticks([1,2,8,32,128,512])
ax3.set_ylim(-0.1,1.1)
ax3.set_xlim(0.8,1000)
ax3.invert_xaxis()
ax3.legend(handles, labels, facecolor='white', loc='lower left')

ax4.plot(wtr_train_size[:-3], wtr_prec[:-3], '-o', color='b', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_recall[:-3], '-o', color='y', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_f1[:-3], '-o', color='r', lw=3)
ax4.set(title="Water")
ax4.set_xscale('log', basex=2)
ax4.xaxis.set_major_formatter(ScalarFormatter())
#ax4.set_xticks(wtr_train_size[:-3])
ax4.set_xticks([1,2,8,32,128,512])
ax4.set_ylim(-0.1,1.1)
ax4.set_xlim(0.8,1000)
ax4.set_ylabel("metric")
ax4.invert_xaxis()
ax4.legend(handles, labels, facecolor='white', loc='lower left')

ax5.plot(blt_train_size, blt_prec, '-o', color='b', lw=3)
ax5.plot(blt_train_size, blt_recall, '-o', color='y', lw=3)
ax5.plot(blt_train_size, blt_f1, '-o', color='r', lw=3)
ax5.set(title="Built")
ax5.set_xscale('log', basex=2)
ax5.xaxis.set_major_formatter(ScalarFormatter())
#ax5.set_xticks(blt_train_size)
ax5.set_xticks([1,2,8,32,128,512])
ax5.set_xlim(0.8,1000)
ax5.set_ylim(-0.1,1.1)
ax5.invert_xaxis()
ax5.legend(handles, labels, facecolor='white', loc='lower left')

ax6.plot(windows_train_size, windows_prec, '-o', color='b', lw=3, label='Precision')
ax6.plot(windows_train_size, windows_recall, '-o', color='y', lw=3, label='Recall')
ax6.plot(windows_train_size, windows_f1, '-o', color='r', lw=3, label='F1 Score')
ax6.set(title="Windows")
ax6.set_xscale('log', basex=2)
ax6.xaxis.set_major_formatter(ScalarFormatter())
#ax6.set_xticks(windows_train_size)
ax6.set_xticks([1,2,8,32,128,512])
ax6.set_ylim(-0.1,1.1)
ax6.set_xlim(0.8,1000)
ax6.invert_xaxis()
ax6.legend(handles, labels, facecolor='white', loc='lower left')

ax7.plot(rds_train_size[:-4], rds_prec[:-4], '-o', color='b', lw=3)
ax7.plot(rds_train_size[:-4], rds_recall[:-4], '-o', color='y', lw=3)
ax7.plot(rds_train_size[:-4], rds_f1[:-4], '-o', color='r', lw=3)
ax7.set(title="Roads")
ax7.set_xscale('log', basex=2)
ax7.xaxis.set_major_formatter(ScalarFormatter())
#ax7.set_xticks(rds_train_size[:-4])
ax7.set_xticks([1,2,8,32,128,512])
ax7.set_ylim(-0.1,1.1)
ax7.set_xlim(0.8,1000)
ax7.set_xlabel("training instances")
ax7.set_ylabel("metric")
ax7.invert_xaxis()
ax7.legend(handles, labels, facecolor='white', loc='lower left')

ax8.plot(cars_train_size[:-2], cars_prec[:-2], '-o', color='b', lw=3)
ax8.plot(cars_train_size[:-2], cars_recall[:-2], '-o', color='y', lw=3)
ax8.plot(cars_train_size[:-2], cars_f1[:-2], '-o', color='r', lw=3)
ax8.set(title="Cars")
ax8.set_xscale('log', basex=2)
ax8.xaxis.set_major_formatter(ScalarFormatter())
#ax8.set_xticks(cars_train_size[:-2])
ax8.set_xticks([1,2,8,32,128,512])
ax8.set_ylim(-0.1,1.1)
ax8.set_xlim(0.8,1000)
ax8.set_xlabel("training instances")
ax8.invert_xaxis()
ax8.legend(handles, labels, facecolor='white', loc='lower left')

ax9.plot(mtl_train_size[:-2], mtl_prec[:-2], '-o', color='b', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_recall[:-2], '-o', color='y', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_f1[:-2], '-o', color='r', lw=3)
ax9.set(title="Metal")
ax9.set_xscale('log', basex=2)
ax9.xaxis.set_major_formatter(ScalarFormatter())
#ax9.set_xticks(mtl_train_size[:-2])
ax9.set_xticks([1,2,8,32,128,512])
ax9.set_ylim(-0.1,1.1)
ax9.set_xlim(0.8,1000)
ax9.set_xlabel("training instances")
ax9.invert_xaxis()
ax9.legend(handles, labels, facecolor='white', loc='lower left')

#handles, labels = ax6.get_legend_handles_labels()
#ax6.legend(handles, labels, loc='center right', borderaxespad=-10.0)

plt.show()
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_3_By_Class_Prec_Recall_extend.png",
#           bbox_inches='tight', dpi=300)
