# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### using CNN Models with various filter (kernel) sizes
#
# ---

# %%
# -- importing necessary libraries

import os
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras import layers
from sklearn import metrics
import time
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %% [markdown]
# ### Defining the needed functions

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
# -- splitting text into row index and column index 

def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
# -- transforming individual row and column numbers into an array

def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
# -- function to read the manually classified pixels coordinates
#    given the type of pixels (kind) and image identifier (scan)

def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
# -- function used to split the manually classified pixel coordinates into
#    into training and testing sets given a split ratio (trrat)

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
# -- Create the CNN model using tensorflow.keras given a variable filtersize 

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
# -- plot the loss history of a CNN model and its accuracy

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 0. Sky
# 1. Clouds
# 2. Water
# 3. Vegetation
# 4. Buildings (concrete structures)
# 5. Windows
# 6. Roads
# 7. Cars
# 8. Metal Structures
# ---

# %% [markdown]
# ---
# # CNN trained and tested on Scene 1-b

# %% [markdown]
# ### Read and prepare the data

# %%
# -- read the cube from .raw file into float array

fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
cube_sub = cube.data[:, :, :].astype(float)

# -- reshape cube from (wavelength, row, col) to shape (row*col, wavelength)
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])

# -- standardize the cube to have mean=0 and standard deviation=1
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)

# -- reshape standardized cube to (row, col, wavelength)
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
# -- Read hand labeled data of each class to use for training and testing the model

sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# -- create position array from coordinates and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
trrat = 0.8  # set train/test ratio to have 80% training, 20% testing

# -- get the coordinates of training and testing sets for each class
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
# -- create the training and testing arrays for each class from the coordinates

cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 848) (60, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (480, 848) (120, 848)
# water  (40, 848) (10, 848)
# built  (816, 848) (204, 848)
# windows  (400, 848) (100, 848)
# roads  (24, 848) (6, 848)
# cars  (80, 848) (20, 848)
# metal  (80, 848) (20, 848)

# %%
# -- concatenate the training arrays into training data and labels

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
cube_train_labels = np.array(cube_train_labels)
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

# -- concatenate the testing arrays into testing data and labels

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
cube_test_labels = np.array(cube_test_labels)
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
# -- create a dictionary to house the training and testing accuracies of the models
#    with the various filtersizes as keys later on

model_metrics = {}

# %% [markdown]
# ### Train CNN

# %%
# -- rerun from this point with different filtersizes to produce
#    the needed models (run with values=5,10,20,50,100,200)

filtersize = 200

# %%
# -- create an initial model to use for choosing 'best' epoch

cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 4s 778ms/step - loss: 2.0310 - accuracy: 0.3277 - val_loss: 1.2727 - val_accuracy: 0.6359
# Epoch 2/200
# 5/5 [==============================] - 4s 713ms/step - loss: 1.1024 - accuracy: 0.6453 - val_loss: 0.8876 - val_accuracy: 0.6844
# Epoch 3/200
# 5/5 [==============================] - 4s 773ms/step - loss: 0.8584 - accuracy: 0.7082 - val_loss: 0.7815 - val_accuracy: 0.7328
# Epoch 4/200
# 5/5 [==============================] - 4s 811ms/step - loss: 0.7747 - accuracy: 0.7473 - val_loss: 0.6776 - val_accuracy: 0.7812
# Epoch 5/200
# 5/5 [==============================] - 4s 730ms/step - loss: 0.6988 - accuracy: 0.7707 - val_loss: 0.6206 - val_accuracy: 0.7922
# Epoch 6/200
# 5/5 [==============================] - 3s 697ms/step - loss: 0.6197 - accuracy: 0.7969 - val_loss: 0.5472 - val_accuracy: 0.8078
# Epoch 7/200
# 5/5 [==============================] - 4s 744ms/step - loss: 0.5605 - accuracy: 0.8188 - val_loss: 0.4973 - val_accuracy: 0.8141
# Epoch 8/200
# 5/5 [==============================] - 3s 695ms/step - loss: 0.5194 - accuracy: 0.8367 - val_loss: 0.4499 - val_accuracy: 0.8625
# Epoch 9/200
# 5/5 [==============================] - 4s 764ms/step - loss: 0.5274 - accuracy: 0.8344 - val_loss: 0.4705 - val_accuracy: 0.8516
# Epoch 10/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.4945 - accuracy: 0.8461 - val_loss: 0.4280 - val_accuracy: 0.8531
# Epoch 11/200
# 5/5 [==============================] - 3s 664ms/step - loss: 0.4700 - accuracy: 0.8520 - val_loss: 0.4265 - val_accuracy: 0.8719
# Epoch 12/200
# 5/5 [==============================] - 4s 739ms/step - loss: 0.4478 - accuracy: 0.8641 - val_loss: 0.3726 - val_accuracy: 0.8938
# Epoch 13/200
# 5/5 [==============================] - 4s 707ms/step - loss: 0.4273 - accuracy: 0.8598 - val_loss: 0.3723 - val_accuracy: 0.8781
# Epoch 14/200
# 5/5 [==============================] - 3s 662ms/step - loss: 0.4233 - accuracy: 0.8625 - val_loss: 0.3540 - val_accuracy: 0.9062
# Epoch 15/200
# 5/5 [==============================] - 4s 708ms/step - loss: 0.4047 - accuracy: 0.8758 - val_loss: 0.3561 - val_accuracy: 0.8719
# Epoch 16/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.3848 - accuracy: 0.8746 - val_loss: 0.3872 - val_accuracy: 0.8797
# Epoch 17/200
# 5/5 [==============================] - 3s 686ms/step - loss: 0.3771 - accuracy: 0.8898 - val_loss: 0.3605 - val_accuracy: 0.8875
# Epoch 18/200
# 5/5 [==============================] - 4s 712ms/step - loss: 0.3707 - accuracy: 0.8813 - val_loss: 0.3445 - val_accuracy: 0.8844
# Epoch 19/200
# 5/5 [==============================] - 4s 707ms/step - loss: 0.3692 - accuracy: 0.8852 - val_loss: 0.3554 - val_accuracy: 0.8750
# Epoch 20/200
# 5/5 [==============================] - 4s 716ms/step - loss: 0.3518 - accuracy: 0.8918 - val_loss: 0.3142 - val_accuracy: 0.9031
# Epoch 21/200
# 5/5 [==============================] - 4s 788ms/step - loss: 0.3501 - accuracy: 0.8934 - val_loss: 0.3009 - val_accuracy: 0.9000
# Epoch 22/200
# 5/5 [==============================] - 3s 677ms/step - loss: 0.3256 - accuracy: 0.8977 - val_loss: 0.2945 - val_accuracy: 0.9062
# Epoch 23/200
# 5/5 [==============================] - 4s 729ms/step - loss: 0.3131 - accuracy: 0.9012 - val_loss: 0.2891 - val_accuracy: 0.9031
# Epoch 24/200
# 5/5 [==============================] - 4s 711ms/step - loss: 0.3032 - accuracy: 0.9070 - val_loss: 0.2761 - val_accuracy: 0.8984
# Epoch 25/200
# 5/5 [==============================] - 4s 709ms/step - loss: 0.3061 - accuracy: 0.9031 - val_loss: 0.2662 - val_accuracy: 0.9094
# Epoch 26/200
# 5/5 [==============================] - 4s 715ms/step - loss: 0.2991 - accuracy: 0.9059 - val_loss: 0.2733 - val_accuracy: 0.9219
# Epoch 27/200
# 5/5 [==============================] - 4s 712ms/step - loss: 0.2950 - accuracy: 0.9062 - val_loss: 0.2681 - val_accuracy: 0.9234
# Epoch 28/200
# 5/5 [==============================] - 3s 693ms/step - loss: 0.2805 - accuracy: 0.9117 - val_loss: 0.2547 - val_accuracy: 0.9172
# Epoch 29/200
# 5/5 [==============================] - 4s 727ms/step - loss: 0.2743 - accuracy: 0.9094 - val_loss: 0.2511 - val_accuracy: 0.9172
# Epoch 30/200
# 5/5 [==============================] - 4s 785ms/step - loss: 0.2690 - accuracy: 0.9117 - val_loss: 0.2570 - val_accuracy: 0.9172
# Epoch 31/200
# 5/5 [==============================] - 4s 701ms/step - loss: 0.2779 - accuracy: 0.9090 - val_loss: 0.2504 - val_accuracy: 0.9250
# Epoch 32/200
# 5/5 [==============================] - 4s 732ms/step - loss: 0.2810 - accuracy: 0.9078 - val_loss: 0.2383 - val_accuracy: 0.9156
# Epoch 33/200
# 5/5 [==============================] - 4s 765ms/step - loss: 0.2739 - accuracy: 0.9113 - val_loss: 0.2342 - val_accuracy: 0.9187
# Epoch 34/200
# 5/5 [==============================] - 4s 727ms/step - loss: 0.2665 - accuracy: 0.9129 - val_loss: 0.2333 - val_accuracy: 0.9141
# Epoch 35/200
# 5/5 [==============================] - 4s 700ms/step - loss: 0.2529 - accuracy: 0.9195 - val_loss: 0.2292 - val_accuracy: 0.9219
# Epoch 36/200
# 5/5 [==============================] - 4s 759ms/step - loss: 0.2554 - accuracy: 0.9129 - val_loss: 0.2356 - val_accuracy: 0.9156
# Epoch 37/200
# 5/5 [==============================] - 3s 680ms/step - loss: 0.2351 - accuracy: 0.9195 - val_loss: 0.2213 - val_accuracy: 0.9219
# Epoch 38/200
# 5/5 [==============================] - 4s 701ms/step - loss: 0.2463 - accuracy: 0.9141 - val_loss: 0.2358 - val_accuracy: 0.9234
# Epoch 39/200
# 5/5 [==============================] - 4s 766ms/step - loss: 0.2436 - accuracy: 0.9129 - val_loss: 0.2250 - val_accuracy: 0.9328
# Epoch 40/200
# 5/5 [==============================] - 4s 761ms/step - loss: 0.2398 - accuracy: 0.9176 - val_loss: 0.2210 - val_accuracy: 0.9234
# Epoch 41/200
# 5/5 [==============================] - 4s 729ms/step - loss: 0.2208 - accuracy: 0.9246 - val_loss: 0.2219 - val_accuracy: 0.9281
# Epoch 42/200
# 5/5 [==============================] - 4s 747ms/step - loss: 0.2303 - accuracy: 0.9195 - val_loss: 0.2139 - val_accuracy: 0.9266
# Epoch 43/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.2099 - accuracy: 0.9281 - val_loss: 0.2020 - val_accuracy: 0.9281
# Epoch 44/200
# 5/5 [==============================] - 4s 756ms/step - loss: 0.2198 - accuracy: 0.9254 - val_loss: 0.2021 - val_accuracy: 0.9359
# Epoch 45/200
# 5/5 [==============================] - 4s 764ms/step - loss: 0.2151 - accuracy: 0.9250 - val_loss: 0.2158 - val_accuracy: 0.9312
# Epoch 46/200
# 5/5 [==============================] - 3s 657ms/step - loss: 0.2191 - accuracy: 0.9266 - val_loss: 0.2038 - val_accuracy: 0.9266
# Epoch 47/200
# 5/5 [==============================] - 4s 732ms/step - loss: 0.2020 - accuracy: 0.9332 - val_loss: 0.1976 - val_accuracy: 0.9219
# Epoch 48/200
# 5/5 [==============================] - 4s 761ms/step - loss: 0.1901 - accuracy: 0.9367 - val_loss: 0.1913 - val_accuracy: 0.9344
# Epoch 49/200
# 5/5 [==============================] - 4s 724ms/step - loss: 0.1840 - accuracy: 0.9363 - val_loss: 0.1806 - val_accuracy: 0.9359
# Epoch 50/200
# 5/5 [==============================] - 4s 741ms/step - loss: 0.1862 - accuracy: 0.9359 - val_loss: 0.1907 - val_accuracy: 0.9422
# Epoch 51/200
# 5/5 [==============================] - 4s 770ms/step - loss: 0.1833 - accuracy: 0.9391 - val_loss: 0.1977 - val_accuracy: 0.9359
# Epoch 52/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.1843 - accuracy: 0.9371 - val_loss: 0.1794 - val_accuracy: 0.9344
# Epoch 53/200
# 5/5 [==============================] - 4s 705ms/step - loss: 0.1934 - accuracy: 0.9324 - val_loss: 0.1892 - val_accuracy: 0.9359
# Epoch 54/200
# 5/5 [==============================] - 4s 771ms/step - loss: 0.1849 - accuracy: 0.9355 - val_loss: 0.1779 - val_accuracy: 0.9391
# Epoch 55/200
# 5/5 [==============================] - 3s 690ms/step - loss: 0.1844 - accuracy: 0.9379 - val_loss: 0.1776 - val_accuracy: 0.9422
# Epoch 56/200
# 5/5 [==============================] - 4s 737ms/step - loss: 0.1954 - accuracy: 0.9297 - val_loss: 0.1929 - val_accuracy: 0.9250
# Epoch 57/200
# 5/5 [==============================] - 4s 741ms/step - loss: 0.1816 - accuracy: 0.9402 - val_loss: 0.1713 - val_accuracy: 0.9391
# Epoch 58/200
# 5/5 [==============================] - 4s 762ms/step - loss: 0.1617 - accuracy: 0.9441 - val_loss: 0.1652 - val_accuracy: 0.9422
# Epoch 59/200
# 5/5 [==============================] - 4s 716ms/step - loss: 0.1513 - accuracy: 0.9488 - val_loss: 0.1785 - val_accuracy: 0.9422
# Epoch 60/200
# 5/5 [==============================] - 4s 743ms/step - loss: 0.1646 - accuracy: 0.9434 - val_loss: 0.1934 - val_accuracy: 0.9234
# Epoch 61/200
# 5/5 [==============================] - 3s 685ms/step - loss: 0.1807 - accuracy: 0.9379 - val_loss: 0.1731 - val_accuracy: 0.9375
# Epoch 62/200
# 5/5 [==============================] - 4s 751ms/step - loss: 0.1586 - accuracy: 0.9414 - val_loss: 0.1810 - val_accuracy: 0.9422
# Epoch 63/200
# 5/5 [==============================] - 4s 730ms/step - loss: 0.1642 - accuracy: 0.9422 - val_loss: 0.1805 - val_accuracy: 0.9391
# Epoch 64/200
# 5/5 [==============================] - 3s 693ms/step - loss: 0.1688 - accuracy: 0.9418 - val_loss: 0.1688 - val_accuracy: 0.9391
# Epoch 65/200
# 5/5 [==============================] - 4s 741ms/step - loss: 0.1678 - accuracy: 0.9453 - val_loss: 0.1925 - val_accuracy: 0.9344
# Epoch 66/200
# 5/5 [==============================] - 4s 766ms/step - loss: 0.1826 - accuracy: 0.9387 - val_loss: 0.1707 - val_accuracy: 0.9375
# Epoch 67/200
# 5/5 [==============================] - 4s 719ms/step - loss: 0.1862 - accuracy: 0.9367 - val_loss: 0.1963 - val_accuracy: 0.9438
# Epoch 68/200
# 5/5 [==============================] - 4s 712ms/step - loss: 0.1632 - accuracy: 0.9441 - val_loss: 0.1619 - val_accuracy: 0.9375
# Epoch 69/200
# 5/5 [==============================] - 4s 754ms/step - loss: 0.1618 - accuracy: 0.9441 - val_loss: 0.1785 - val_accuracy: 0.9422
# Epoch 70/200
# 5/5 [==============================] - 4s 711ms/step - loss: 0.1545 - accuracy: 0.9477 - val_loss: 0.1547 - val_accuracy: 0.9516
# Epoch 71/200
# 5/5 [==============================] - 4s 738ms/step - loss: 0.1592 - accuracy: 0.9434 - val_loss: 0.1765 - val_accuracy: 0.9344
# Epoch 72/200
# 5/5 [==============================] - 4s 729ms/step - loss: 0.1560 - accuracy: 0.9484 - val_loss: 0.1506 - val_accuracy: 0.9453
# Epoch 73/200
# 5/5 [==============================] - 4s 715ms/step - loss: 0.1481 - accuracy: 0.9492 - val_loss: 0.2067 - val_accuracy: 0.9328
# Epoch 74/200
# 5/5 [==============================] - 4s 790ms/step - loss: 0.1616 - accuracy: 0.9477 - val_loss: 0.1663 - val_accuracy: 0.9484
# Epoch 75/200
# 5/5 [==============================] - 4s 745ms/step - loss: 0.1502 - accuracy: 0.9484 - val_loss: 0.1691 - val_accuracy: 0.9406
# Epoch 76/200
# 5/5 [==============================] - 4s 701ms/step - loss: 0.1434 - accuracy: 0.9473 - val_loss: 0.1802 - val_accuracy: 0.9375
# Epoch 77/200
# 5/5 [==============================] - 4s 725ms/step - loss: 0.1574 - accuracy: 0.9465 - val_loss: 0.1750 - val_accuracy: 0.9453
# Epoch 78/200
# 5/5 [==============================] - 4s 772ms/step - loss: 0.1542 - accuracy: 0.9457 - val_loss: 0.1946 - val_accuracy: 0.9281
# Epoch 79/200
# 5/5 [==============================] - 3s 696ms/step - loss: 0.1475 - accuracy: 0.9508 - val_loss: 0.1647 - val_accuracy: 0.9422
# Epoch 80/200
# 5/5 [==============================] - 3s 699ms/step - loss: 0.1393 - accuracy: 0.9512 - val_loss: 0.1554 - val_accuracy: 0.9531
# Epoch 81/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.1322 - accuracy: 0.9531 - val_loss: 0.1498 - val_accuracy: 0.9531
# Epoch 82/200
# 5/5 [==============================] - 4s 718ms/step - loss: 0.1226 - accuracy: 0.9617 - val_loss: 0.1418 - val_accuracy: 0.9484
# Epoch 83/200
# 5/5 [==============================] - 4s 758ms/step - loss: 0.1186 - accuracy: 0.9617 - val_loss: 0.1307 - val_accuracy: 0.9469
# Epoch 84/200
# 5/5 [==============================] - 4s 738ms/step - loss: 0.1086 - accuracy: 0.9637 - val_loss: 0.1396 - val_accuracy: 0.9547
# Epoch 85/200
# 5/5 [==============================] - 4s 714ms/step - loss: 0.1203 - accuracy: 0.9582 - val_loss: 0.1385 - val_accuracy: 0.9547
# Epoch 86/200
# 5/5 [==============================] - 4s 736ms/step - loss: 0.1141 - accuracy: 0.9605 - val_loss: 0.1405 - val_accuracy: 0.9531
# Epoch 87/200
# 5/5 [==============================] - 4s 745ms/step - loss: 0.1210 - accuracy: 0.9586 - val_loss: 0.1456 - val_accuracy: 0.9469
# Epoch 88/200
# 5/5 [==============================] - 3s 695ms/step - loss: 0.1273 - accuracy: 0.9551 - val_loss: 0.1579 - val_accuracy: 0.9469
# Epoch 89/200
# 5/5 [==============================] - 3s 691ms/step - loss: 0.1285 - accuracy: 0.9578 - val_loss: 0.1381 - val_accuracy: 0.9563
# Epoch 90/200
# 5/5 [==============================] - 4s 741ms/step - loss: 0.1158 - accuracy: 0.9637 - val_loss: 0.1641 - val_accuracy: 0.9484
# Epoch 91/200
# 5/5 [==============================] - 3s 679ms/step - loss: 0.1159 - accuracy: 0.9605 - val_loss: 0.1491 - val_accuracy: 0.9469
# Epoch 92/200
# 5/5 [==============================] - 4s 739ms/step - loss: 0.1090 - accuracy: 0.9652 - val_loss: 0.1538 - val_accuracy: 0.9484
# Epoch 93/200
# 5/5 [==============================] - 3s 689ms/step - loss: 0.1106 - accuracy: 0.9590 - val_loss: 0.1678 - val_accuracy: 0.9391
# Epoch 94/200
# 5/5 [==============================] - 4s 709ms/step - loss: 0.1188 - accuracy: 0.9605 - val_loss: 0.1524 - val_accuracy: 0.9469
# Epoch 95/200
# 5/5 [==============================] - 4s 725ms/step - loss: 0.1076 - accuracy: 0.9660 - val_loss: 0.1522 - val_accuracy: 0.9500
# Epoch 96/200
# 5/5 [==============================] - 4s 758ms/step - loss: 0.1071 - accuracy: 0.9621 - val_loss: 0.1348 - val_accuracy: 0.9531
# Epoch 97/200
# 5/5 [==============================] - 3s 691ms/step - loss: 0.1110 - accuracy: 0.9633 - val_loss: 0.1483 - val_accuracy: 0.9500
# Epoch 98/200
# 5/5 [==============================] - 4s 739ms/step - loss: 0.1065 - accuracy: 0.9617 - val_loss: 0.1348 - val_accuracy: 0.9563
# Epoch 99/200
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0971 - accuracy: 0.9707 - val_loss: 0.1418 - val_accuracy: 0.9531
# Epoch 100/200
# 5/5 [==============================] - 3s 691ms/step - loss: 0.1010 - accuracy: 0.9668 - val_loss: 0.1403 - val_accuracy: 0.9594
# Epoch 101/200
# 5/5 [==============================] - 4s 737ms/step - loss: 0.0923 - accuracy: 0.9691 - val_loss: 0.1543 - val_accuracy: 0.9500
# Epoch 102/200
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0996 - accuracy: 0.9672 - val_loss: 0.1371 - val_accuracy: 0.9531
# Epoch 103/200
# 5/5 [==============================] - 3s 680ms/step - loss: 0.1003 - accuracy: 0.9672 - val_loss: 0.1355 - val_accuracy: 0.9578
# Epoch 104/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.1432 - val_accuracy: 0.9594
# Epoch 105/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.0927 - accuracy: 0.9695 - val_loss: 0.1392 - val_accuracy: 0.9453
# Epoch 106/200
# 5/5 [==============================] - 3s 648ms/step - loss: 0.1010 - accuracy: 0.9648 - val_loss: 0.1475 - val_accuracy: 0.9422
# Epoch 107/200
# 5/5 [==============================] - 4s 736ms/step - loss: 0.1093 - accuracy: 0.9629 - val_loss: 0.1498 - val_accuracy: 0.9469
# Epoch 108/200
# 5/5 [==============================] - 4s 711ms/step - loss: 0.1041 - accuracy: 0.9633 - val_loss: 0.1469 - val_accuracy: 0.9531
# Epoch 109/200
# 5/5 [==============================] - 3s 682ms/step - loss: 0.1069 - accuracy: 0.9691 - val_loss: 0.1413 - val_accuracy: 0.9594
# Epoch 110/200
# 5/5 [==============================] - 4s 720ms/step - loss: 0.1009 - accuracy: 0.9672 - val_loss: 0.1438 - val_accuracy: 0.9500
# Epoch 111/200
# 5/5 [==============================] - 4s 708ms/step - loss: 0.1006 - accuracy: 0.9652 - val_loss: 0.1408 - val_accuracy: 0.9500
# Epoch 112/200
# 5/5 [==============================] - 4s 701ms/step - loss: 0.0963 - accuracy: 0.9668 - val_loss: 0.1478 - val_accuracy: 0.9563
# Epoch 113/200
# 5/5 [==============================] - 4s 739ms/step - loss: 0.0970 - accuracy: 0.9688 - val_loss: 0.1312 - val_accuracy: 0.9641
# Epoch 114/200
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0788 - accuracy: 0.9738 - val_loss: 0.1380 - val_accuracy: 0.9625
# Epoch 115/200
# 5/5 [==============================] - 4s 729ms/step - loss: 0.0890 - accuracy: 0.9719 - val_loss: 0.1409 - val_accuracy: 0.9531
# Epoch 116/200
# 5/5 [==============================] - 4s 705ms/step - loss: 0.0939 - accuracy: 0.9668 - val_loss: 0.1280 - val_accuracy: 0.9578
# Epoch 117/200
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0887 - accuracy: 0.9695 - val_loss: 0.1373 - val_accuracy: 0.9609
# Epoch 118/200
# 5/5 [==============================] - 4s 736ms/step - loss: 0.0968 - accuracy: 0.9691 - val_loss: 0.1447 - val_accuracy: 0.9500
# Epoch 119/200
# 5/5 [==============================] - 4s 701ms/step - loss: 0.0985 - accuracy: 0.9637 - val_loss: 0.1427 - val_accuracy: 0.9531
# Epoch 120/200
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0932 - accuracy: 0.9684 - val_loss: 0.1459 - val_accuracy: 0.9500
# Epoch 121/200
# 5/5 [==============================] - 4s 751ms/step - loss: 0.0834 - accuracy: 0.9719 - val_loss: 0.1422 - val_accuracy: 0.9594
# Epoch 122/200
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0855 - accuracy: 0.9758 - val_loss: 0.1363 - val_accuracy: 0.9594
# Epoch 123/200
# 5/5 [==============================] - 4s 727ms/step - loss: 0.0836 - accuracy: 0.9715 - val_loss: 0.1429 - val_accuracy: 0.9500
# Epoch 124/200
# 5/5 [==============================] - 4s 741ms/step - loss: 0.0802 - accuracy: 0.9738 - val_loss: 0.1527 - val_accuracy: 0.9578
# Epoch 125/200
# 5/5 [==============================] - 4s 705ms/step - loss: 0.0812 - accuracy: 0.9707 - val_loss: 0.1269 - val_accuracy: 0.9547
# Epoch 126/200
# 5/5 [==============================] - 4s 735ms/step - loss: 0.0929 - accuracy: 0.9695 - val_loss: 0.1393 - val_accuracy: 0.9484
# Epoch 127/200
# 5/5 [==============================] - 4s 799ms/step - loss: 0.0903 - accuracy: 0.9656 - val_loss: 0.1544 - val_accuracy: 0.9594
# Epoch 128/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.0734 - accuracy: 0.9723 - val_loss: 0.1556 - val_accuracy: 0.9531
# Epoch 129/200
# 5/5 [==============================] - 4s 706ms/step - loss: 0.0831 - accuracy: 0.9691 - val_loss: 0.1369 - val_accuracy: 0.9547
# Epoch 130/200
# 5/5 [==============================] - 4s 781ms/step - loss: 0.0810 - accuracy: 0.9746 - val_loss: 0.1380 - val_accuracy: 0.9594
# Epoch 131/200
# 5/5 [==============================] - 4s 702ms/step - loss: 0.0747 - accuracy: 0.9730 - val_loss: 0.1349 - val_accuracy: 0.9547
# Epoch 132/200
# 5/5 [==============================] - 4s 711ms/step - loss: 0.0721 - accuracy: 0.9730 - val_loss: 0.1276 - val_accuracy: 0.9594
# Epoch 133/200
# 5/5 [==============================] - 4s 759ms/step - loss: 0.0783 - accuracy: 0.9742 - val_loss: 0.1475 - val_accuracy: 0.9563
# Epoch 134/200
# 5/5 [==============================] - 3s 699ms/step - loss: 0.0728 - accuracy: 0.9746 - val_loss: 0.1382 - val_accuracy: 0.9547
# Epoch 135/200
# 5/5 [==============================] - 3s 681ms/step - loss: 0.0788 - accuracy: 0.9719 - val_loss: 0.1483 - val_accuracy: 0.9500
# Epoch 136/200
# 5/5 [==============================] - 4s 709ms/step - loss: 0.0909 - accuracy: 0.9707 - val_loss: 0.1581 - val_accuracy: 0.9578
# Epoch 137/200
# 5/5 [==============================] - 3s 670ms/step - loss: 0.1050 - accuracy: 0.9637 - val_loss: 0.1903 - val_accuracy: 0.9297
# Epoch 138/200
# 5/5 [==============================] - 4s 749ms/step - loss: 0.1088 - accuracy: 0.9625 - val_loss: 0.1349 - val_accuracy: 0.9578
# Epoch 139/200
# 5/5 [==============================] - 4s 733ms/step - loss: 0.0954 - accuracy: 0.9676 - val_loss: 0.1386 - val_accuracy: 0.9547
# Epoch 140/200
# 5/5 [==============================] - 3s 670ms/step - loss: 0.0955 - accuracy: 0.9691 - val_loss: 0.1323 - val_accuracy: 0.9578
# Epoch 141/200
# 5/5 [==============================] - 4s 758ms/step - loss: 0.0852 - accuracy: 0.9730 - val_loss: 0.1299 - val_accuracy: 0.9594
# Epoch 142/200
# 5/5 [==============================] - 4s 725ms/step - loss: 0.0806 - accuracy: 0.9691 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 143/200
# 5/5 [==============================] - 3s 678ms/step - loss: 0.0722 - accuracy: 0.9742 - val_loss: 0.1343 - val_accuracy: 0.9531
# Epoch 144/200
# 5/5 [==============================] - 3s 696ms/step - loss: 0.0684 - accuracy: 0.9746 - val_loss: 0.1382 - val_accuracy: 0.9578
# Epoch 145/200
# 5/5 [==============================] - 3s 662ms/step - loss: 0.0678 - accuracy: 0.9754 - val_loss: 0.1513 - val_accuracy: 0.9516
# Epoch 146/200
# 5/5 [==============================] - 3s 688ms/step - loss: 0.0614 - accuracy: 0.9785 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 147/200
# 5/5 [==============================] - 4s 779ms/step - loss: 0.0648 - accuracy: 0.9781 - val_loss: 0.1485 - val_accuracy: 0.9516
# Epoch 148/200
# 5/5 [==============================] - 3s 700ms/step - loss: 0.0733 - accuracy: 0.9734 - val_loss: 0.1581 - val_accuracy: 0.9578
# Epoch 149/200
# 5/5 [==============================] - 3s 678ms/step - loss: 0.0742 - accuracy: 0.9738 - val_loss: 0.1564 - val_accuracy: 0.9500
# Epoch 150/200
# 5/5 [==============================] - 4s 858ms/step - loss: 0.0663 - accuracy: 0.9754 - val_loss: 0.1547 - val_accuracy: 0.9578
# Epoch 151/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.0577 - accuracy: 0.9793 - val_loss: 0.1359 - val_accuracy: 0.9594
# Epoch 152/200
# 5/5 [==============================] - 4s 717ms/step - loss: 0.0616 - accuracy: 0.9762 - val_loss: 0.1329 - val_accuracy: 0.9578
# Epoch 153/200
# 5/5 [==============================] - 4s 724ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 0.1467 - val_accuracy: 0.9625
# Epoch 154/200
# 5/5 [==============================] - 4s 748ms/step - loss: 0.0631 - accuracy: 0.9770 - val_loss: 0.1475 - val_accuracy: 0.9594
# Epoch 155/200
# 5/5 [==============================] - 3s 682ms/step - loss: 0.0676 - accuracy: 0.9758 - val_loss: 0.1356 - val_accuracy: 0.9578
# Epoch 156/200
# 5/5 [==============================] - 4s 744ms/step - loss: 0.0630 - accuracy: 0.9801 - val_loss: 0.1390 - val_accuracy: 0.9531
# Epoch 157/200
# 5/5 [==============================] - 4s 729ms/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.1423 - val_accuracy: 0.9625
# Epoch 158/200
# 5/5 [==============================] - 3s 678ms/step - loss: 0.0615 - accuracy: 0.9770 - val_loss: 0.1416 - val_accuracy: 0.9594
# Epoch 159/200
# 5/5 [==============================] - 4s 714ms/step - loss: 0.0642 - accuracy: 0.9781 - val_loss: 0.1369 - val_accuracy: 0.9609
# Epoch 160/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.0692 - accuracy: 0.9793 - val_loss: 0.1650 - val_accuracy: 0.9547
# Epoch 161/200
# 5/5 [==============================] - 3s 661ms/step - loss: 0.0722 - accuracy: 0.9766 - val_loss: 0.1519 - val_accuracy: 0.9609
# Epoch 162/200
# 5/5 [==============================] - 3s 695ms/step - loss: 0.0712 - accuracy: 0.9727 - val_loss: 0.1665 - val_accuracy: 0.9609
# Epoch 163/200
# 5/5 [==============================] - 4s 700ms/step - loss: 0.0676 - accuracy: 0.9754 - val_loss: 0.1518 - val_accuracy: 0.9516
# Epoch 164/200
# 5/5 [==============================] - 4s 721ms/step - loss: 0.0678 - accuracy: 0.9789 - val_loss: 0.1220 - val_accuracy: 0.9609
# Epoch 165/200
# 5/5 [==============================] - 3s 694ms/step - loss: 0.0669 - accuracy: 0.9793 - val_loss: 0.1671 - val_accuracy: 0.9531
# Epoch 166/200
# 5/5 [==============================] - 4s 765ms/step - loss: 0.0749 - accuracy: 0.9762 - val_loss: 0.1498 - val_accuracy: 0.9609
# Epoch 167/200
# 5/5 [==============================] - 4s 706ms/step - loss: 0.0685 - accuracy: 0.9754 - val_loss: 0.1533 - val_accuracy: 0.9609
# Epoch 168/200
# 5/5 [==============================] - 4s 712ms/step - loss: 0.0695 - accuracy: 0.9766 - val_loss: 0.1352 - val_accuracy: 0.9594
# Epoch 169/200
# 5/5 [==============================] - 4s 787ms/step - loss: 0.0742 - accuracy: 0.9746 - val_loss: 0.1734 - val_accuracy: 0.9438
# Epoch 170/200
# 5/5 [==============================] - 4s 769ms/step - loss: 0.0677 - accuracy: 0.9781 - val_loss: 0.1617 - val_accuracy: 0.9563
# Epoch 171/200
# 5/5 [==============================] - 4s 725ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.1367 - val_accuracy: 0.9609
# Epoch 172/200
# 5/5 [==============================] - 4s 713ms/step - loss: 0.0649 - accuracy: 0.9762 - val_loss: 0.1412 - val_accuracy: 0.9609
# Epoch 173/200
# 5/5 [==============================] - 4s 712ms/step - loss: 0.0653 - accuracy: 0.9742 - val_loss: 0.1390 - val_accuracy: 0.9578
# Epoch 174/200
# 5/5 [==============================] - 4s 720ms/step - loss: 0.0624 - accuracy: 0.9785 - val_loss: 0.1631 - val_accuracy: 0.9547
# Epoch 175/200
# 5/5 [==============================] - 3s 677ms/step - loss: 0.0573 - accuracy: 0.9789 - val_loss: 0.1375 - val_accuracy: 0.9594
# Epoch 176/200
# 5/5 [==============================] - 4s 703ms/step - loss: 0.0529 - accuracy: 0.9824 - val_loss: 0.1422 - val_accuracy: 0.9672
# Epoch 177/200
# 5/5 [==============================] - 3s 682ms/step - loss: 0.0526 - accuracy: 0.9824 - val_loss: 0.1621 - val_accuracy: 0.9609
# Epoch 178/200
# 5/5 [==============================] - 4s 734ms/step - loss: 0.0625 - accuracy: 0.9801 - val_loss: 0.1449 - val_accuracy: 0.9578
# Epoch 179/200
# 5/5 [==============================] - 4s 757ms/step - loss: 0.0576 - accuracy: 0.9789 - val_loss: 0.1755 - val_accuracy: 0.9516
# Epoch 180/200
# 5/5 [==============================] - 4s 717ms/step - loss: 0.0547 - accuracy: 0.9789 - val_loss: 0.1526 - val_accuracy: 0.9656
# Epoch 181/200
# 5/5 [==============================] - 4s 704ms/step - loss: 0.0615 - accuracy: 0.9797 - val_loss: 0.1340 - val_accuracy: 0.9609
# Epoch 182/200
# 5/5 [==============================] - 3s 692ms/step - loss: 0.0575 - accuracy: 0.9781 - val_loss: 0.1489 - val_accuracy: 0.9594
# Epoch 183/200
# 5/5 [==============================] - 4s 725ms/step - loss: 0.0672 - accuracy: 0.9770 - val_loss: 0.1842 - val_accuracy: 0.9547
# Epoch 184/200
# 5/5 [==============================] - 3s 690ms/step - loss: 0.0782 - accuracy: 0.9688 - val_loss: 0.1552 - val_accuracy: 0.9531
# Epoch 185/200
# 5/5 [==============================] - 4s 713ms/step - loss: 0.0754 - accuracy: 0.9734 - val_loss: 0.1611 - val_accuracy: 0.9516
# Epoch 186/200
# 5/5 [==============================] - 3s 689ms/step - loss: 0.0773 - accuracy: 0.9754 - val_loss: 0.1400 - val_accuracy: 0.9531
# Epoch 187/200
# 5/5 [==============================] - 4s 719ms/step - loss: 0.0697 - accuracy: 0.9754 - val_loss: 0.1672 - val_accuracy: 0.9500
# Epoch 188/200
# 5/5 [==============================] - 4s 825ms/step - loss: 0.0573 - accuracy: 0.9828 - val_loss: 0.1536 - val_accuracy: 0.9625
# Epoch 189/200
# 5/5 [==============================] - 4s 720ms/step - loss: 0.0533 - accuracy: 0.9820 - val_loss: 0.1346 - val_accuracy: 0.9578
# Epoch 190/200
# 5/5 [==============================] - 4s 722ms/step - loss: 0.0557 - accuracy: 0.9793 - val_loss: 0.1472 - val_accuracy: 0.9625
# Epoch 191/200
# 5/5 [==============================] - 4s 719ms/step - loss: 0.0599 - accuracy: 0.9809 - val_loss: 0.1626 - val_accuracy: 0.9547
# Epoch 192/200
# 5/5 [==============================] - 4s 728ms/step - loss: 0.0493 - accuracy: 0.9832 - val_loss: 0.1483 - val_accuracy: 0.9594
# Epoch 193/200
# 5/5 [==============================] - 3s 671ms/step - loss: 0.0600 - accuracy: 0.9789 - val_loss: 0.1318 - val_accuracy: 0.9641
# Epoch 194/200
# 5/5 [==============================] - 3s 686ms/step - loss: 0.0434 - accuracy: 0.9875 - val_loss: 0.1384 - val_accuracy: 0.9609
# Epoch 195/200
# 5/5 [==============================] - 3s 680ms/step - loss: 0.0441 - accuracy: 0.9848 - val_loss: 0.1332 - val_accuracy: 0.9688
# Epoch 196/200
# 5/5 [==============================] - 3s 652ms/step - loss: 0.0507 - accuracy: 0.9844 - val_loss: 0.1373 - val_accuracy: 0.9594
# Epoch 197/200
# 5/5 [==============================] - 4s 733ms/step - loss: 0.0475 - accuracy: 0.9824 - val_loss: 0.1615 - val_accuracy: 0.9609
# Epoch 198/200
# 5/5 [==============================] - 4s 702ms/step - loss: 0.0401 - accuracy: 0.9844 - val_loss: 0.1585 - val_accuracy: 0.9578
# Epoch 199/200
# 5/5 [==============================] - 3s 650ms/step - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.1333 - val_accuracy: 0.9594
# Epoch 200/200
# 5/5 [==============================] - 4s 730ms/step - loss: 0.0453 - accuracy: 0.9848 - val_loss: 0.1694 - val_accuracy: 0.9578

# %%
# -- plot loss history and accuracy history of model
plot_loss_history(CNNmodel)

# %%
# -- choose most appropriate number of epochs based on the above plot
#    reintialize the model and run again with given number of epochs

cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=25, batch_size=512)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 4s 730ms/step - loss: 2.4183 - accuracy: 0.3609 - val_loss: 1.5915 - val_accuracy: 0.5531
# Epoch 2/25
# 5/5 [==============================] - 4s 720ms/step - loss: 1.2640 - accuracy: 0.6281 - val_loss: 0.9572 - val_accuracy: 0.7078
# Epoch 3/25
# 5/5 [==============================] - 4s 727ms/step - loss: 0.9176 - accuracy: 0.6961 - val_loss: 0.8209 - val_accuracy: 0.7219
# Epoch 4/25
# 5/5 [==============================] - 4s 703ms/step - loss: 0.7988 - accuracy: 0.7285 - val_loss: 0.6811 - val_accuracy: 0.8047
# Epoch 5/25
# 5/5 [==============================] - 4s 824ms/step - loss: 0.6864 - accuracy: 0.7906 - val_loss: 0.6008 - val_accuracy: 0.8062
# Epoch 6/25
# 5/5 [==============================] - 4s 706ms/step - loss: 0.6120 - accuracy: 0.7973 - val_loss: 0.5092 - val_accuracy: 0.8281
# Epoch 7/25
# 5/5 [==============================] - 3s 675ms/step - loss: 0.5595 - accuracy: 0.8133 - val_loss: 0.4766 - val_accuracy: 0.8422
# Epoch 8/25
# 5/5 [==============================] - 4s 748ms/step - loss: 0.5111 - accuracy: 0.8375 - val_loss: 0.4237 - val_accuracy: 0.8797
# Epoch 9/25
# 5/5 [==============================] - 4s 731ms/step - loss: 0.4666 - accuracy: 0.8559 - val_loss: 0.4106 - val_accuracy: 0.8719
# Epoch 10/25
# 5/5 [==============================] - 4s 705ms/step - loss: 0.4435 - accuracy: 0.8574 - val_loss: 0.3708 - val_accuracy: 0.8969
# Epoch 11/25
# 5/5 [==============================] - 4s 702ms/step - loss: 0.4087 - accuracy: 0.8754 - val_loss: 0.3585 - val_accuracy: 0.8953
# Epoch 12/25
# 5/5 [==============================] - 4s 777ms/step - loss: 0.3985 - accuracy: 0.8789 - val_loss: 0.3413 - val_accuracy: 0.9000
# Epoch 13/25
# 5/5 [==============================] - 3s 688ms/step - loss: 0.3919 - accuracy: 0.8785 - val_loss: 0.3445 - val_accuracy: 0.9031
# Epoch 14/25
# 5/5 [==============================] - 4s 706ms/step - loss: 0.3649 - accuracy: 0.8895 - val_loss: 0.3236 - val_accuracy: 0.9094
# Epoch 15/25
# 5/5 [==============================] - 4s 719ms/step - loss: 0.3532 - accuracy: 0.8945 - val_loss: 0.3226 - val_accuracy: 0.8984
# Epoch 16/25
# 5/5 [==============================] - 3s 674ms/step - loss: 0.3484 - accuracy: 0.8957 - val_loss: 0.3109 - val_accuracy: 0.9156
# Epoch 17/25
# 5/5 [==============================] - 4s 708ms/step - loss: 0.3436 - accuracy: 0.8918 - val_loss: 0.2924 - val_accuracy: 0.9047
# Epoch 18/25
# 5/5 [==============================] - 3s 695ms/step - loss: 0.3323 - accuracy: 0.8992 - val_loss: 0.3388 - val_accuracy: 0.8922
# Epoch 19/25
# 5/5 [==============================] - 3s 670ms/step - loss: 0.3264 - accuracy: 0.8980 - val_loss: 0.2871 - val_accuracy: 0.9062
# Epoch 20/25
# 5/5 [==============================] - 4s 708ms/step - loss: 0.3226 - accuracy: 0.8969 - val_loss: 0.3005 - val_accuracy: 0.9141
# Epoch 21/25
# 5/5 [==============================] - 4s 730ms/step - loss: 0.3294 - accuracy: 0.8988 - val_loss: 0.2870 - val_accuracy: 0.9078
# Epoch 22/25
# 5/5 [==============================] - 4s 708ms/step - loss: 0.3035 - accuracy: 0.9031 - val_loss: 0.2833 - val_accuracy: 0.9156
# Epoch 23/25
# 5/5 [==============================] - 4s 700ms/step - loss: 0.2907 - accuracy: 0.9082 - val_loss: 0.2632 - val_accuracy: 0.9094
# Epoch 24/25
# 5/5 [==============================] - 4s 731ms/step - loss: 0.2771 - accuracy: 0.9117 - val_loss: 0.2515 - val_accuracy: 0.9219
# Epoch 25/25
# 5/5 [==============================] - 3s 679ms/step - loss: 0.2782 - accuracy: 0.9137 - val_loss: 0.2652 - val_accuracy: 0.9156

# %%
# -- function to get the training and testing accuracies and loss of the models

def get_acc(cnn, ctr, cte, xytr, xyte, lbtr, lbte):
    train_loss, train_acc = cnn.evaluate({"spectra":ctr, "spatial":xytr}, lbtr)
    test_loss, test_acc = cnn.evaluate({"spectra":cte, "spatial":xyte}, lbte)

    return [train_acc, test_acc]

# %%
# -- use model_metrics dictionary to save the accuracies
#    with the filtersizes as keys

model_metrics[filtersize] = get_acc(cnn, cube_train2, cube_test2,
                                    xy_train, xy_test, cube_train_labels, cube_test_labels)
# Out:
# 80/80 [==============================] - 1s 11ms/step - loss: 0.2555 - accuracy: 0.9195
# 20/20 [==============================] - 0s 10ms/step - loss: 0.2652 - accuracy: 0.9156

# %% [markdown]
# ### Predict pixel classification on all of Scene 1-a

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])

start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})
predictCube = probCube.argmax(axis=-1)

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:11:44

# %%
# -- Plot the prediction map of Scene 1-a

predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()

# %% [markdown]
# ### Evaluation Metrics of Scene 1-a

# %%
# -- create the prediction arrays from the predictions of the testing set

labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# -- create the true arrays from the labeled testing set

labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
# -- print the confusion matrix, accuracy, and classification report of Scene 1-a

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 193   6   0   2   3]
#  [  0   0   0   0   8  90   0   2   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  0   0   0   0   7   5   0   7   1]
#  [  0   0   0   0   7   4   0   0   9]]
#
# Accuracy Score
# 0.915625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.87      0.95      0.90       204
#     windows       0.86      0.90      0.88       100
#       roads       0.00      0.00      0.00         6
#        cars       0.64      0.35      0.45        20
#       metal       0.69      0.45      0.55        20
#
# avg / total       0.90      0.92      0.91       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# -- Save metrics to file in order to read for plotting later

f = open("./metrics/CNN_filter_size_{0}_metrics.txt".format(filtersize), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## ---STOP HERE--- ##
# ### rerun from "Train CNN" above with different filter size
# ### Continue if done

# %% [markdown]
# ---
#
# ## Plot Results

# %%
# -- split training and testing accuracies into separate numpy arrays
#    and put the filtersizes (keys) in its own array

train_acc = np.zeros(len(model_metrics.keys()))
test_acc = np.zeros(len(model_metrics.keys()))
filter_size = np.zeros(len(model_metrics.keys()))

j = 0
for i in model_metrics.keys():
    train_acc[j] = model_metrics[i][0]
    test_acc[j] = model_metrics[i][1]
    filter_size[j] = i
    j += 1

# %%
# -- function used to read the precision, recall, and F1 scores from the metrics files

def read_prec_recall(file, line):
    Nums = []
    for num in file[line].split():
        try:
            Nums.append(float(num))
        except ValueError:
            pass
    prec = Nums[0]
    recall = Nums[1]
    f1 = Nums[2]
    
    return prec, recall, f1

# %%
# -- read mean precision, recall, and F1 scores from each filtersize

n_groups = len(train_acc)

avg_prec = np.zeros(n_groups)
avg_recall = np.zeros(n_groups)
avg_f1 = np.zeros(n_groups)

for size in filter_size:
    filename = "./metrics/CNN_filter_size_{0}_metrics.txt".format(size)
    f = open(filename, "r")
    f1 = f.readlines()
    avg_prec[i], avg_recall[i], avg_f1[i] = read_prec_recall(f1, 27)
    f.close()
    i += 1

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 15
plt.rcParams['axes.labelsize'] = 15
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 15
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(filter_size, train_acc, '-o', color='b', lw=4, label='train')
ax1.plot(filter_size, test_acc, '-o', color='g', lw=4, label='test')
ax1.set_title("Accuracy", fontsize=18)
ax1.set_xlabel("filter size (number of spectral channels)")
ax1.set_ylabel("accuracy")
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white', loc='upper left')
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
ax1.set_xticks(filter_size)
ax1.set_ylim(0.88,0.98)

ax2.plot(filter_size, avg_prec, '-o', color='b', lw=4, label='mP')
ax2.plot(filter_size, avg_recall, '-o', color='y', lw=4, label='mR')
ax2.plot(filter_size, avg_f1, '-o', color='r', lw=4, label='mF1')
ax2.set_title("Mean Precision, Recall, and F1-Score", fontsize=18)
ax2.set_xlabel("filter size (number of spectral channels)")
ax2.set_ylabel("metric")
handles, labels = ax2.get_legend_handles_labels()
ax2.legend(handles, labels, facecolor='white', loc='upper left')
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
ax2.set_xticks(filter_size)
ax2.set_ylim(0.88,0.98)

plt.show()
