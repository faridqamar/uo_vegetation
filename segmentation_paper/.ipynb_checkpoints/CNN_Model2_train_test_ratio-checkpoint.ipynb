# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### standardized spectra at full resolution with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_norm = (cube_reshaped - cube_reshaped.min()) / (cube_reshaped.max() - cube_reshaped.min())

import matplotlib.pyplot as plt
# %matplotlib inline

red_ind = (np.abs(cube.waves - 650.0)).argmin()
green_ind = (np.abs(cube.waves - 550.0)).argmin()
blue_ind = (np.abs(cube.waves - 450.0)).argmin()

cube_reshaped2 = cube_norm.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
cube_scene = cube_reshaped2[:, :, [red_ind, green_ind, blue_ind]]
fig, ax = plt.subplots(figsize=(10,10))
plt.title('veg_00108 RGB Image')
ax.imshow(cube_scene, aspect=0.5)
plt.show()

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], cube_sub.shape[0])
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 848)
# (1600, 1600, 2)

# %% [markdown]
# #### split classified pixels into training and testing sets

# %%
train_acc = {}
test_acc = {}

# %%
lbl = '50_50'
trrat = 0.5

#lbl = '20_80'
#trrat = 0.2

#lbl = '10_90'
#trrat = 0.1

#lbl = '5_95'
#trrat = 0.05

#lbl = '3_97'
#trrat = 0.03

#lbl = '1_99'
#trrat = 0.01

#lbl = '05_995'
#trrat = 0.005

#lbl = '01_999'
#trrat = 0.001

# %%
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 848) (60, 848)
# clouds  (400, 848) (100, 848)
# vegetation  (480, 848) (120, 848)
# water  (40, 848) (10, 848)
# built  (816, 848) (204, 848)
# windows  (400, 848) (100, 848)
# roads  (24, 848) (6, 848)
# cars  (80, 848) (20, 848)
# metal  (80, 848) (20, 848)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 848) (2560,) (2560, 2)
# (640, 848) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 2s 367ms/step - loss: 1.9194 - accuracy: 0.3570 - val_loss: 1.5367 - val_accuracy: 0.4938
# Epoch 2/200
# 5/5 [==============================] - 1s 219ms/step - loss: 1.2696 - accuracy: 0.5746 - val_loss: 1.0246 - val_accuracy: 0.6344
# Epoch 3/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.9412 - accuracy: 0.6922 - val_loss: 0.8201 - val_accuracy: 0.7125
# Epoch 4/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.7754 - accuracy: 0.7437 - val_loss: 0.6756 - val_accuracy: 0.8047
# Epoch 5/200
# 5/5 [==============================] - 1s 156ms/step - loss: 0.6765 - accuracy: 0.8012 - val_loss: 0.5712 - val_accuracy: 0.8156
# Epoch 6/200
# 5/5 [==============================] - 1s 166ms/step - loss: 0.5966 - accuracy: 0.8191 - val_loss: 0.5428 - val_accuracy: 0.8516
# Epoch 7/200
# 5/5 [==============================] - 1s 155ms/step - loss: 0.5386 - accuracy: 0.8332 - val_loss: 0.4463 - val_accuracy: 0.8766
# Epoch 8/200
# 5/5 [==============================] - 1s 155ms/step - loss: 0.4680 - accuracy: 0.8578 - val_loss: 0.4123 - val_accuracy: 0.8813
# Epoch 9/200
# 5/5 [==============================] - 1s 152ms/step - loss: 0.4206 - accuracy: 0.8695 - val_loss: 0.3726 - val_accuracy: 0.8953
# Epoch 10/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.4079 - accuracy: 0.8711 - val_loss: 0.3611 - val_accuracy: 0.8891
# Epoch 11/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3780 - accuracy: 0.8824 - val_loss: 0.3359 - val_accuracy: 0.9094
# Epoch 12/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.3606 - accuracy: 0.8906 - val_loss: 0.3735 - val_accuracy: 0.8797
# Epoch 13/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.3567 - accuracy: 0.8859 - val_loss: 0.3254 - val_accuracy: 0.9031
# Epoch 14/200
# 5/5 [==============================] - 1s 244ms/step - loss: 0.3284 - accuracy: 0.9016 - val_loss: 0.3133 - val_accuracy: 0.9016
# Epoch 15/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.3082 - accuracy: 0.9027 - val_loss: 0.2940 - val_accuracy: 0.9219
# Epoch 16/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.3147 - accuracy: 0.9074 - val_loss: 0.2792 - val_accuracy: 0.9125
# Epoch 17/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3169 - accuracy: 0.9012 - val_loss: 0.3045 - val_accuracy: 0.9000
# Epoch 18/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.2966 - accuracy: 0.9070 - val_loss: 0.2636 - val_accuracy: 0.9062
# Epoch 19/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.2876 - accuracy: 0.9066 - val_loss: 0.2969 - val_accuracy: 0.9125
# Epoch 20/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.2854 - accuracy: 0.9129 - val_loss: 0.2714 - val_accuracy: 0.9141
# Epoch 21/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.2657 - accuracy: 0.9129 - val_loss: 0.2414 - val_accuracy: 0.9250
# Epoch 22/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.2579 - accuracy: 0.9195 - val_loss: 0.2671 - val_accuracy: 0.9172
# Epoch 23/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.2556 - accuracy: 0.9180 - val_loss: 0.2500 - val_accuracy: 0.9328
# Epoch 24/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.2474 - accuracy: 0.9203 - val_loss: 0.2239 - val_accuracy: 0.9219
# Epoch 25/200
# 5/5 [==============================] - 1s 166ms/step - loss: 0.2385 - accuracy: 0.9191 - val_loss: 0.2359 - val_accuracy: 0.9172
# Epoch 26/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.2327 - accuracy: 0.9258 - val_loss: 0.2239 - val_accuracy: 0.9250
# Epoch 27/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.2454 - accuracy: 0.9203 - val_loss: 0.2132 - val_accuracy: 0.9266
# Epoch 28/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.2358 - accuracy: 0.9227 - val_loss: 0.3029 - val_accuracy: 0.9250
# Epoch 29/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.2811 - accuracy: 0.9023 - val_loss: 0.2897 - val_accuracy: 0.9125
# Epoch 30/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.2762 - accuracy: 0.9078 - val_loss: 0.2547 - val_accuracy: 0.9109
# Epoch 31/200
# 5/5 [==============================] - 1s 220ms/step - loss: 0.2309 - accuracy: 0.9293 - val_loss: 0.2216 - val_accuracy: 0.9219
# Epoch 32/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.2233 - accuracy: 0.9242 - val_loss: 0.2240 - val_accuracy: 0.9328
# Epoch 33/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.2226 - accuracy: 0.9277 - val_loss: 0.2058 - val_accuracy: 0.9281
# Epoch 34/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.2104 - accuracy: 0.9285 - val_loss: 0.2099 - val_accuracy: 0.9344
# Epoch 35/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.2022 - accuracy: 0.9316 - val_loss: 0.1958 - val_accuracy: 0.9328
# Epoch 36/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1955 - accuracy: 0.9309 - val_loss: 0.1875 - val_accuracy: 0.9359
# Epoch 37/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1930 - accuracy: 0.9309 - val_loss: 0.1919 - val_accuracy: 0.9391
# Epoch 38/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1897 - accuracy: 0.9348 - val_loss: 0.1926 - val_accuracy: 0.9297
# Epoch 39/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.1877 - accuracy: 0.9348 - val_loss: 0.1782 - val_accuracy: 0.9344
# Epoch 40/200
# 5/5 [==============================] - 1s 223ms/step - loss: 0.1817 - accuracy: 0.9391 - val_loss: 0.2067 - val_accuracy: 0.9219
# Epoch 41/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.2148 - accuracy: 0.9320 - val_loss: 0.2078 - val_accuracy: 0.9281
# Epoch 42/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.2009 - accuracy: 0.9332 - val_loss: 0.1974 - val_accuracy: 0.9469
# Epoch 43/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1904 - accuracy: 0.9363 - val_loss: 0.2032 - val_accuracy: 0.9250
# Epoch 44/200
# 5/5 [==============================] - 1s 167ms/step - loss: 0.1915 - accuracy: 0.9344 - val_loss: 0.1761 - val_accuracy: 0.9375
# Epoch 45/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.1783 - accuracy: 0.9371 - val_loss: 0.1830 - val_accuracy: 0.9547
# Epoch 46/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.1791 - accuracy: 0.9359 - val_loss: 0.1665 - val_accuracy: 0.9438
# Epoch 47/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1795 - accuracy: 0.9418 - val_loss: 0.1764 - val_accuracy: 0.9344
# Epoch 48/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1788 - accuracy: 0.9375 - val_loss: 0.1590 - val_accuracy: 0.9422
# Epoch 49/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1621 - accuracy: 0.9430 - val_loss: 0.1580 - val_accuracy: 0.9469
# Epoch 50/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1737 - accuracy: 0.9453 - val_loss: 0.1669 - val_accuracy: 0.9406
# Epoch 51/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1925 - accuracy: 0.9352 - val_loss: 0.1706 - val_accuracy: 0.9359
# Epoch 52/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1688 - accuracy: 0.9445 - val_loss: 0.1780 - val_accuracy: 0.9359
# Epoch 53/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1619 - accuracy: 0.9461 - val_loss: 0.1619 - val_accuracy: 0.9391
# Epoch 54/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1535 - accuracy: 0.9492 - val_loss: 0.1516 - val_accuracy: 0.9438
# Epoch 55/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1391 - accuracy: 0.9508 - val_loss: 0.1459 - val_accuracy: 0.9484
# Epoch 56/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.1447 - accuracy: 0.9543 - val_loss: 0.1531 - val_accuracy: 0.9453
# Epoch 57/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1389 - accuracy: 0.9520 - val_loss: 0.1475 - val_accuracy: 0.9516
# Epoch 58/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1450 - accuracy: 0.9508 - val_loss: 0.1395 - val_accuracy: 0.9594
# Epoch 59/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1378 - accuracy: 0.9488 - val_loss: 0.1366 - val_accuracy: 0.9563
# Epoch 60/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1307 - accuracy: 0.9555 - val_loss: 0.1484 - val_accuracy: 0.9484
# Epoch 61/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1390 - accuracy: 0.9492 - val_loss: 0.1441 - val_accuracy: 0.9500
# Epoch 62/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1319 - accuracy: 0.9543 - val_loss: 0.1404 - val_accuracy: 0.9547
# Epoch 63/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1288 - accuracy: 0.9590 - val_loss: 0.1437 - val_accuracy: 0.9531
# Epoch 64/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1376 - accuracy: 0.9570 - val_loss: 0.1375 - val_accuracy: 0.9563
# Epoch 65/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1306 - accuracy: 0.9531 - val_loss: 0.1365 - val_accuracy: 0.9500
# Epoch 66/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.1311 - accuracy: 0.9531 - val_loss: 0.1338 - val_accuracy: 0.9594
# Epoch 67/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.1390 - accuracy: 0.9527 - val_loss: 0.1528 - val_accuracy: 0.9438
# Epoch 68/200
# 5/5 [==============================] - 1s 168ms/step - loss: 0.1261 - accuracy: 0.9520 - val_loss: 0.1353 - val_accuracy: 0.9531
# Epoch 69/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.1270 - accuracy: 0.9555 - val_loss: 0.1196 - val_accuracy: 0.9578
# Epoch 70/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.1325 - accuracy: 0.9551 - val_loss: 0.1614 - val_accuracy: 0.9375
# Epoch 71/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.1324 - accuracy: 0.9563 - val_loss: 0.1344 - val_accuracy: 0.9516
# Epoch 72/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1205 - accuracy: 0.9586 - val_loss: 0.1285 - val_accuracy: 0.9594
# Epoch 73/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.1185 - accuracy: 0.9586 - val_loss: 0.1281 - val_accuracy: 0.9563
# Epoch 74/200
# 5/5 [==============================] - 1s 218ms/step - loss: 0.1151 - accuracy: 0.9605 - val_loss: 0.1243 - val_accuracy: 0.9547
# Epoch 75/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1118 - accuracy: 0.9609 - val_loss: 0.1267 - val_accuracy: 0.9531
# Epoch 76/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1109 - accuracy: 0.9598 - val_loss: 0.1268 - val_accuracy: 0.9563
# Epoch 77/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.1066 - accuracy: 0.9617 - val_loss: 0.1232 - val_accuracy: 0.9484
# Epoch 78/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.1114 - accuracy: 0.9590 - val_loss: 0.1154 - val_accuracy: 0.9531
# Epoch 79/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.1097 - accuracy: 0.9613 - val_loss: 0.1261 - val_accuracy: 0.9453
# Epoch 80/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.1087 - accuracy: 0.9602 - val_loss: 0.1334 - val_accuracy: 0.9531
# Epoch 81/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.1079 - accuracy: 0.9648 - val_loss: 0.1131 - val_accuracy: 0.9531
# Epoch 82/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1066 - accuracy: 0.9625 - val_loss: 0.1109 - val_accuracy: 0.9594
# Epoch 83/200
# 5/5 [==============================] - 1s 210ms/step - loss: 0.1090 - accuracy: 0.9629 - val_loss: 0.1151 - val_accuracy: 0.9609
# Epoch 84/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1137 - accuracy: 0.9594 - val_loss: 0.1267 - val_accuracy: 0.9531
# Epoch 85/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.1120 - accuracy: 0.9602 - val_loss: 0.1856 - val_accuracy: 0.9563
# Epoch 86/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.2481 - accuracy: 0.9074 - val_loss: 0.2878 - val_accuracy: 0.9047
# Epoch 87/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.3233 - accuracy: 0.8996 - val_loss: 0.2087 - val_accuracy: 0.9297
# Epoch 88/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.2580 - accuracy: 0.9121 - val_loss: 0.2730 - val_accuracy: 0.9125
# Epoch 89/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.2178 - accuracy: 0.9227 - val_loss: 0.2035 - val_accuracy: 0.9375
# Epoch 90/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1976 - accuracy: 0.9387 - val_loss: 0.1811 - val_accuracy: 0.9344
# Epoch 91/200
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1710 - accuracy: 0.9465 - val_loss: 0.1676 - val_accuracy: 0.9484
# Epoch 92/200
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1639 - accuracy: 0.9438 - val_loss: 0.1558 - val_accuracy: 0.9516
# Epoch 93/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.1484 - accuracy: 0.9477 - val_loss: 0.1395 - val_accuracy: 0.9516
# Epoch 94/200
# 5/5 [==============================] - 1s 170ms/step - loss: 0.1391 - accuracy: 0.9512 - val_loss: 0.1565 - val_accuracy: 0.9578
# Epoch 95/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1463 - accuracy: 0.9516 - val_loss: 0.1471 - val_accuracy: 0.9531
# Epoch 96/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1287 - accuracy: 0.9578 - val_loss: 0.1276 - val_accuracy: 0.9547
# Epoch 97/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.1300 - accuracy: 0.9543 - val_loss: 0.1228 - val_accuracy: 0.9578
# Epoch 98/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 0.1214 - val_accuracy: 0.9516
# Epoch 99/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1149 - accuracy: 0.9590 - val_loss: 0.1257 - val_accuracy: 0.9578
# Epoch 100/200
# 5/5 [==============================] - 1s 217ms/step - loss: 0.1134 - accuracy: 0.9609 - val_loss: 0.1194 - val_accuracy: 0.9641
# Epoch 101/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1159 - accuracy: 0.9605 - val_loss: 0.1217 - val_accuracy: 0.9625
# Epoch 102/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1139 - accuracy: 0.9613 - val_loss: 0.1271 - val_accuracy: 0.9594
# Epoch 103/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1072 - accuracy: 0.9660 - val_loss: 0.1076 - val_accuracy: 0.9609
# Epoch 104/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1198 - accuracy: 0.9586 - val_loss: 0.1045 - val_accuracy: 0.9625
# Epoch 105/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.1004 - accuracy: 0.9672 - val_loss: 0.1074 - val_accuracy: 0.9625
# Epoch 106/200
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1099 - accuracy: 0.9668 - val_loss: 0.1201 - val_accuracy: 0.9609
# Epoch 107/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1017 - accuracy: 0.9684 - val_loss: 0.1196 - val_accuracy: 0.9547
# Epoch 108/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.1087 - accuracy: 0.9668 - val_loss: 0.1236 - val_accuracy: 0.9563
# Epoch 109/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.1077 - accuracy: 0.9633 - val_loss: 0.1170 - val_accuracy: 0.9563
# Epoch 110/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1019 - accuracy: 0.9641 - val_loss: 0.1055 - val_accuracy: 0.9609
# Epoch 111/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1041 - accuracy: 0.9641 - val_loss: 0.1112 - val_accuracy: 0.9625
# Epoch 112/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.1011 - accuracy: 0.9656 - val_loss: 0.1195 - val_accuracy: 0.9563
# Epoch 113/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0954 - accuracy: 0.9676 - val_loss: 0.1101 - val_accuracy: 0.9656
# Epoch 114/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1022 - accuracy: 0.9645 - val_loss: 0.1081 - val_accuracy: 0.9625
# Epoch 115/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1031 - accuracy: 0.9609 - val_loss: 0.1096 - val_accuracy: 0.9672
# Epoch 116/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0978 - accuracy: 0.9641 - val_loss: 0.1053 - val_accuracy: 0.9641
# Epoch 117/200
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0947 - accuracy: 0.9672 - val_loss: 0.1020 - val_accuracy: 0.9641
# Epoch 118/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0865 - accuracy: 0.9734 - val_loss: 0.1026 - val_accuracy: 0.9641
# Epoch 119/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0942 - accuracy: 0.9648 - val_loss: 0.1152 - val_accuracy: 0.9656
# Epoch 120/200
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0912 - accuracy: 0.9668 - val_loss: 0.1008 - val_accuracy: 0.9719
# Epoch 121/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0901 - accuracy: 0.9711 - val_loss: 0.1123 - val_accuracy: 0.9594
# Epoch 122/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0856 - accuracy: 0.9730 - val_loss: 0.1058 - val_accuracy: 0.9625
# Epoch 123/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0921 - accuracy: 0.9668 - val_loss: 0.1110 - val_accuracy: 0.9625
# Epoch 124/200
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0967 - accuracy: 0.9680 - val_loss: 0.1188 - val_accuracy: 0.9578
# Epoch 125/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0903 - accuracy: 0.9719 - val_loss: 0.0995 - val_accuracy: 0.9672
# Epoch 126/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0943 - accuracy: 0.9688 - val_loss: 0.0985 - val_accuracy: 0.9656
# Epoch 127/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0880 - accuracy: 0.9703 - val_loss: 0.1176 - val_accuracy: 0.9547
# Epoch 128/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0868 - accuracy: 0.9715 - val_loss: 0.0970 - val_accuracy: 0.9672
# Epoch 129/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0764 - accuracy: 0.9727 - val_loss: 0.0987 - val_accuracy: 0.9656
# Epoch 130/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0805 - accuracy: 0.9695 - val_loss: 0.0950 - val_accuracy: 0.9641
# Epoch 131/200
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0822 - accuracy: 0.9734 - val_loss: 0.1012 - val_accuracy: 0.9672
# Epoch 132/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0772 - accuracy: 0.9738 - val_loss: 0.0893 - val_accuracy: 0.9672
# Epoch 133/200
# 5/5 [==============================] - 1s 187ms/step - loss: 0.0814 - accuracy: 0.9711 - val_loss: 0.0932 - val_accuracy: 0.9688
# Epoch 134/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0813 - accuracy: 0.9746 - val_loss: 0.0935 - val_accuracy: 0.9672
# Epoch 135/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0782 - accuracy: 0.9730 - val_loss: 0.0980 - val_accuracy: 0.9688
# Epoch 136/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0764 - accuracy: 0.9734 - val_loss: 0.0991 - val_accuracy: 0.9641
# Epoch 137/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0708 - accuracy: 0.9734 - val_loss: 0.0880 - val_accuracy: 0.9703
# Epoch 138/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0714 - accuracy: 0.9715 - val_loss: 0.0885 - val_accuracy: 0.9703
# Epoch 139/200
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0698 - accuracy: 0.9781 - val_loss: 0.0941 - val_accuracy: 0.9688
# Epoch 140/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0707 - accuracy: 0.9750 - val_loss: 0.0903 - val_accuracy: 0.9688
# Epoch 141/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0665 - accuracy: 0.9785 - val_loss: 0.0864 - val_accuracy: 0.9688
# Epoch 142/200
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0647 - accuracy: 0.9754 - val_loss: 0.0923 - val_accuracy: 0.9688
# Epoch 143/200
# 5/5 [==============================] - 1s 194ms/step - loss: 0.0796 - accuracy: 0.9750 - val_loss: 0.1021 - val_accuracy: 0.9656
# Epoch 144/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0689 - accuracy: 0.9781 - val_loss: 0.0947 - val_accuracy: 0.9672
# Epoch 145/200
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0698 - accuracy: 0.9766 - val_loss: 0.0890 - val_accuracy: 0.9719
# Epoch 146/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0637 - accuracy: 0.9797 - val_loss: 0.0939 - val_accuracy: 0.9641
# Epoch 147/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0756 - accuracy: 0.9754 - val_loss: 0.0931 - val_accuracy: 0.9688
# Epoch 148/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0659 - accuracy: 0.9750 - val_loss: 0.0968 - val_accuracy: 0.9703
# Epoch 149/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0642 - accuracy: 0.9773 - val_loss: 0.0857 - val_accuracy: 0.9703
# Epoch 150/200
# 5/5 [==============================] - 1s 192ms/step - loss: 0.0666 - accuracy: 0.9781 - val_loss: 0.0900 - val_accuracy: 0.9750
# Epoch 151/200
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0588 - accuracy: 0.9820 - val_loss: 0.0845 - val_accuracy: 0.9719
# Epoch 152/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0582 - accuracy: 0.9812 - val_loss: 0.0936 - val_accuracy: 0.9734
# Epoch 153/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 0.0954 - val_accuracy: 0.9641
# Epoch 154/200
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0594 - accuracy: 0.9789 - val_loss: 0.0893 - val_accuracy: 0.9656
# Epoch 155/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0582 - accuracy: 0.9801 - val_loss: 0.0860 - val_accuracy: 0.9641
# Epoch 156/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0615 - accuracy: 0.9801 - val_loss: 0.0998 - val_accuracy: 0.9688
# Epoch 157/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0611 - accuracy: 0.9777 - val_loss: 0.0893 - val_accuracy: 0.9719
# Epoch 158/200
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0591 - accuracy: 0.9789 - val_loss: 0.0920 - val_accuracy: 0.9688
# Epoch 159/200
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0639 - accuracy: 0.9777 - val_loss: 0.0903 - val_accuracy: 0.9672
# Epoch 160/200
# 5/5 [==============================] - 1s 186ms/step - loss: 0.0627 - accuracy: 0.9777 - val_loss: 0.0876 - val_accuracy: 0.9719
# Epoch 161/200
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0559 - accuracy: 0.9805 - val_loss: 0.0812 - val_accuracy: 0.9734
# Epoch 162/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0576 - accuracy: 0.9797 - val_loss: 0.0875 - val_accuracy: 0.9688
# Epoch 163/200
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0702 - accuracy: 0.9754 - val_loss: 0.1267 - val_accuracy: 0.9609
# Epoch 164/200
# 5/5 [==============================] - 1s 184ms/step - loss: 0.0797 - accuracy: 0.9730 - val_loss: 0.0967 - val_accuracy: 0.9672
# Epoch 165/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0597 - accuracy: 0.9797 - val_loss: 0.0905 - val_accuracy: 0.9703
# Epoch 166/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0553 - accuracy: 0.9809 - val_loss: 0.0941 - val_accuracy: 0.9641
# Epoch 167/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0536 - accuracy: 0.9824 - val_loss: 0.0939 - val_accuracy: 0.9703
# Epoch 168/200
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0623 - accuracy: 0.9789 - val_loss: 0.0804 - val_accuracy: 0.9719
# Epoch 169/200
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0549 - accuracy: 0.9836 - val_loss: 0.0903 - val_accuracy: 0.9703
# Epoch 170/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0528 - accuracy: 0.9832 - val_loss: 0.0851 - val_accuracy: 0.9672
# Epoch 171/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0509 - accuracy: 0.9855 - val_loss: 0.0847 - val_accuracy: 0.9703
# Epoch 172/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.0820 - val_accuracy: 0.9688
# Epoch 173/200
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0508 - accuracy: 0.9820 - val_loss: 0.0873 - val_accuracy: 0.9672
# Epoch 174/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0439 - accuracy: 0.9859 - val_loss: 0.0831 - val_accuracy: 0.9719
# Epoch 175/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.0844 - val_accuracy: 0.9719
# Epoch 176/200
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0468 - accuracy: 0.9863 - val_loss: 0.0796 - val_accuracy: 0.9719
# Epoch 177/200
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0474 - accuracy: 0.9844 - val_loss: 0.0810 - val_accuracy: 0.9672
# Epoch 178/200
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0484 - accuracy: 0.9832 - val_loss: 0.0853 - val_accuracy: 0.9719
# Epoch 179/200
# 5/5 [==============================] - 1s 176ms/step - loss: 0.0496 - accuracy: 0.9840 - val_loss: 0.0858 - val_accuracy: 0.9734
# Epoch 180/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0467 - accuracy: 0.9840 - val_loss: 0.0791 - val_accuracy: 0.9750
# Epoch 181/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0460 - accuracy: 0.9836 - val_loss: 0.0807 - val_accuracy: 0.9750
# Epoch 182/200
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.0861 - val_accuracy: 0.9750
# Epoch 183/200
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0503 - accuracy: 0.9832 - val_loss: 0.0864 - val_accuracy: 0.9750
# Epoch 184/200
# 5/5 [==============================] - 1s 211ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.0871 - val_accuracy: 0.9703
# Epoch 185/200
# 5/5 [==============================] - 1s 179ms/step - loss: 0.0501 - accuracy: 0.9859 - val_loss: 0.0857 - val_accuracy: 0.9719
# Epoch 186/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0386 - accuracy: 0.9871 - val_loss: 0.0788 - val_accuracy: 0.9766
# Epoch 187/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0423 - accuracy: 0.9879 - val_loss: 0.0895 - val_accuracy: 0.9703
# Epoch 188/200
# 5/5 [==============================] - 1s 201ms/step - loss: 0.0465 - accuracy: 0.9848 - val_loss: 0.0798 - val_accuracy: 0.9703
# Epoch 189/200
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0372 - accuracy: 0.9891 - val_loss: 0.0906 - val_accuracy: 0.9688
# Epoch 190/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0456 - accuracy: 0.9844 - val_loss: 0.0831 - val_accuracy: 0.9703
# Epoch 191/200
# 5/5 [==============================] - 1s 181ms/step - loss: 0.0405 - accuracy: 0.9859 - val_loss: 0.0809 - val_accuracy: 0.9719
# Epoch 192/200
# 5/5 [==============================] - 1s 191ms/step - loss: 0.0406 - accuracy: 0.9852 - val_loss: 0.0854 - val_accuracy: 0.9766
# Epoch 193/200
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0419 - accuracy: 0.9848 - val_loss: 0.0829 - val_accuracy: 0.9734
# Epoch 194/200
# 5/5 [==============================] - 1s 206ms/step - loss: 0.0372 - accuracy: 0.9867 - val_loss: 0.0887 - val_accuracy: 0.9734
# Epoch 195/200
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.0817 - val_accuracy: 0.9719
# Epoch 196/200
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0415 - accuracy: 0.9883 - val_loss: 0.0765 - val_accuracy: 0.9750
# Epoch 197/200
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0351 - accuracy: 0.9898 - val_loss: 0.0757 - val_accuracy: 0.9734
# Epoch 198/200
# 5/5 [==============================] - 1s 196ms/step - loss: 0.0451 - accuracy: 0.9852 - val_loss: 0.0787 - val_accuracy: 0.9734
# Epoch 199/200
# 5/5 [==============================] - 1s 188ms/step - loss: 0.0436 - accuracy: 0.9836 - val_loss: 0.0921 - val_accuracy: 0.9719
# Epoch 200/200
# 5/5 [==============================] - 1s 197ms/step - loss: 0.0380 - accuracy: 0.9895 - val_loss: 0.0792 - val_accuracy: 0.9719

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=110, batch_size=512)
# Out:
# Epoch 1/110
# 5/5 [==============================] - 1s 241ms/step - loss: 1.7598 - accuracy: 0.3992 - val_loss: 1.2416 - val_accuracy: 0.5125
# Epoch 2/110
# 5/5 [==============================] - 1s 170ms/step - loss: 1.0367 - accuracy: 0.6809 - val_loss: 0.7731 - val_accuracy: 0.7328
# Epoch 3/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.7529 - accuracy: 0.7672 - val_loss: 0.6503 - val_accuracy: 0.8047
# Epoch 4/110
# 5/5 [==============================] - 1s 183ms/step - loss: 0.6246 - accuracy: 0.8156 - val_loss: 0.5363 - val_accuracy: 0.8531
# Epoch 5/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.5161 - accuracy: 0.8465 - val_loss: 0.4324 - val_accuracy: 0.8594
# Epoch 6/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.4627 - accuracy: 0.8551 - val_loss: 0.3931 - val_accuracy: 0.8828
# Epoch 7/110
# 5/5 [==============================] - 1s 195ms/step - loss: 0.4087 - accuracy: 0.8734 - val_loss: 0.3683 - val_accuracy: 0.8984
# Epoch 8/110
# 5/5 [==============================] - 1s 168ms/step - loss: 0.3761 - accuracy: 0.8844 - val_loss: 0.3424 - val_accuracy: 0.9062
# Epoch 9/110
# 5/5 [==============================] - 1s 193ms/step - loss: 0.3445 - accuracy: 0.8969 - val_loss: 0.3172 - val_accuracy: 0.9062
# Epoch 10/110
# 5/5 [==============================] - 1s 196ms/step - loss: 0.3178 - accuracy: 0.9051 - val_loss: 0.2978 - val_accuracy: 0.9125
# Epoch 11/110
# 5/5 [==============================] - 1s 170ms/step - loss: 0.3155 - accuracy: 0.9059 - val_loss: 0.2894 - val_accuracy: 0.9031
# Epoch 12/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3042 - accuracy: 0.9094 - val_loss: 0.2591 - val_accuracy: 0.9125
# Epoch 13/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.2762 - accuracy: 0.9105 - val_loss: 0.2554 - val_accuracy: 0.9234
# Epoch 14/110
# 5/5 [==============================] - 1s 176ms/step - loss: 0.2726 - accuracy: 0.9145 - val_loss: 0.2540 - val_accuracy: 0.9234
# Epoch 15/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.2613 - accuracy: 0.9172 - val_loss: 0.3019 - val_accuracy: 0.9031
# Epoch 16/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.3468 - accuracy: 0.8871 - val_loss: 0.6882 - val_accuracy: 0.7859
# Epoch 17/110
# 5/5 [==============================] - 1s 182ms/step - loss: 0.5589 - accuracy: 0.8219 - val_loss: 0.3066 - val_accuracy: 0.8984
# Epoch 18/110
# 5/5 [==============================] - 1s 213ms/step - loss: 0.3779 - accuracy: 0.8840 - val_loss: 0.3983 - val_accuracy: 0.8797
# Epoch 19/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.3520 - accuracy: 0.8852 - val_loss: 0.3569 - val_accuracy: 0.8687
# Epoch 20/110
# 5/5 [==============================] - 1s 174ms/step - loss: 0.3307 - accuracy: 0.8914 - val_loss: 0.3081 - val_accuracy: 0.9078
# Epoch 21/110
# 5/5 [==============================] - 1s 173ms/step - loss: 0.2939 - accuracy: 0.9102 - val_loss: 0.2667 - val_accuracy: 0.9062
# Epoch 22/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.2657 - accuracy: 0.9137 - val_loss: 0.2417 - val_accuracy: 0.9250
# Epoch 23/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.2511 - accuracy: 0.9207 - val_loss: 0.2243 - val_accuracy: 0.9297
# Epoch 24/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.2467 - accuracy: 0.9219 - val_loss: 0.2209 - val_accuracy: 0.9187
# Epoch 25/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.2457 - accuracy: 0.9246 - val_loss: 0.2122 - val_accuracy: 0.9250
# Epoch 26/110
# 5/5 [==============================] - 1s 200ms/step - loss: 0.2367 - accuracy: 0.9215 - val_loss: 0.2260 - val_accuracy: 0.9219
# Epoch 27/110
# 5/5 [==============================] - 1s 191ms/step - loss: 0.2350 - accuracy: 0.9266 - val_loss: 0.2082 - val_accuracy: 0.9281
# Epoch 28/110
# 5/5 [==============================] - 1s 199ms/step - loss: 0.2262 - accuracy: 0.9281 - val_loss: 0.2286 - val_accuracy: 0.9391
# Epoch 29/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.2170 - accuracy: 0.9328 - val_loss: 0.1937 - val_accuracy: 0.9328
# Epoch 30/110
# 5/5 [==============================] - 1s 193ms/step - loss: 0.2116 - accuracy: 0.9332 - val_loss: 0.2090 - val_accuracy: 0.9234
# Epoch 31/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.2128 - accuracy: 0.9309 - val_loss: 0.2010 - val_accuracy: 0.9328
# Epoch 32/110
# 5/5 [==============================] - 1s 180ms/step - loss: 0.2139 - accuracy: 0.9285 - val_loss: 0.1909 - val_accuracy: 0.9281
# Epoch 33/110
# 5/5 [==============================] - 1s 173ms/step - loss: 0.2076 - accuracy: 0.9305 - val_loss: 0.1898 - val_accuracy: 0.9312
# Epoch 34/110
# 5/5 [==============================] - 1s 181ms/step - loss: 0.1919 - accuracy: 0.9367 - val_loss: 0.1977 - val_accuracy: 0.9500
# Epoch 35/110
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2069 - accuracy: 0.9312 - val_loss: 0.1960 - val_accuracy: 0.9406
# Epoch 36/110
# 5/5 [==============================] - 1s 182ms/step - loss: 0.1834 - accuracy: 0.9398 - val_loss: 0.1813 - val_accuracy: 0.9281
# Epoch 37/110
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1809 - accuracy: 0.9395 - val_loss: 0.1832 - val_accuracy: 0.9375
# Epoch 38/110
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1782 - accuracy: 0.9422 - val_loss: 0.1768 - val_accuracy: 0.9266
# Epoch 39/110
# 5/5 [==============================] - 1s 190ms/step - loss: 0.1674 - accuracy: 0.9434 - val_loss: 0.1609 - val_accuracy: 0.9422
# Epoch 40/110
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1655 - accuracy: 0.9438 - val_loss: 0.1679 - val_accuracy: 0.9375
# Epoch 41/110
# 5/5 [==============================] - 1s 182ms/step - loss: 0.1728 - accuracy: 0.9406 - val_loss: 0.1587 - val_accuracy: 0.9422
# Epoch 42/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1761 - accuracy: 0.9441 - val_loss: 0.1655 - val_accuracy: 0.9391
# Epoch 43/110
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1675 - accuracy: 0.9422 - val_loss: 0.1679 - val_accuracy: 0.9359
# Epoch 44/110
# 5/5 [==============================] - 1s 186ms/step - loss: 0.1725 - accuracy: 0.9426 - val_loss: 0.2222 - val_accuracy: 0.9141
# Epoch 45/110
# 5/5 [==============================] - 1s 193ms/step - loss: 0.1868 - accuracy: 0.9340 - val_loss: 0.1781 - val_accuracy: 0.9297
# Epoch 46/110
# 5/5 [==============================] - 1s 166ms/step - loss: 0.1600 - accuracy: 0.9457 - val_loss: 0.1588 - val_accuracy: 0.9406
# Epoch 47/110
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1601 - accuracy: 0.9430 - val_loss: 0.1607 - val_accuracy: 0.9469
# Epoch 48/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.1560 - accuracy: 0.9469 - val_loss: 0.1603 - val_accuracy: 0.9469
# Epoch 49/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1597 - accuracy: 0.9480 - val_loss: 0.1657 - val_accuracy: 0.9516
# Epoch 50/110
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1601 - accuracy: 0.9461 - val_loss: 0.1641 - val_accuracy: 0.9578
# Epoch 51/110
# 5/5 [==============================] - 1s 199ms/step - loss: 0.1664 - accuracy: 0.9422 - val_loss: 0.1482 - val_accuracy: 0.9406
# Epoch 52/110
# 5/5 [==============================] - 1s 212ms/step - loss: 0.1544 - accuracy: 0.9477 - val_loss: 0.1667 - val_accuracy: 0.9406
# Epoch 53/110
# 5/5 [==============================] - 1s 206ms/step - loss: 0.1580 - accuracy: 0.9488 - val_loss: 0.1692 - val_accuracy: 0.9328
# Epoch 54/110
# 5/5 [==============================] - 1s 183ms/step - loss: 0.1572 - accuracy: 0.9516 - val_loss: 0.1741 - val_accuracy: 0.9312
# Epoch 55/110
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1490 - accuracy: 0.9516 - val_loss: 0.1448 - val_accuracy: 0.9438
# Epoch 56/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1447 - accuracy: 0.9520 - val_loss: 0.1449 - val_accuracy: 0.9469
# Epoch 57/110
# 5/5 [==============================] - 1s 202ms/step - loss: 0.1325 - accuracy: 0.9551 - val_loss: 0.1411 - val_accuracy: 0.9547
# Epoch 58/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1439 - accuracy: 0.9539 - val_loss: 0.1262 - val_accuracy: 0.9484
# Epoch 59/110
# 5/5 [==============================] - 1s 194ms/step - loss: 0.1373 - accuracy: 0.9520 - val_loss: 0.1461 - val_accuracy: 0.9531
# Epoch 60/110
# 5/5 [==============================] - 1s 208ms/step - loss: 0.1401 - accuracy: 0.9508 - val_loss: 0.1318 - val_accuracy: 0.9500
# Epoch 61/110
# 5/5 [==============================] - 1s 199ms/step - loss: 0.1295 - accuracy: 0.9531 - val_loss: 0.1220 - val_accuracy: 0.9500
# Epoch 62/110
# 5/5 [==============================] - 1s 175ms/step - loss: 0.1239 - accuracy: 0.9582 - val_loss: 0.1280 - val_accuracy: 0.9547
# Epoch 63/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.1231 - accuracy: 0.9566 - val_loss: 0.1338 - val_accuracy: 0.9563
# Epoch 64/110
# 5/5 [==============================] - 1s 171ms/step - loss: 0.1252 - accuracy: 0.9594 - val_loss: 0.1449 - val_accuracy: 0.9516
# Epoch 65/110
# 5/5 [==============================] - 1s 196ms/step - loss: 0.1431 - accuracy: 0.9512 - val_loss: 0.1353 - val_accuracy: 0.9500
# Epoch 66/110
# 5/5 [==============================] - 1s 175ms/step - loss: 0.1473 - accuracy: 0.9477 - val_loss: 0.1451 - val_accuracy: 0.9375
# Epoch 67/110
# 5/5 [==============================] - 1s 174ms/step - loss: 0.1336 - accuracy: 0.9551 - val_loss: 0.1486 - val_accuracy: 0.9547
# Epoch 68/110
# 5/5 [==============================] - 1s 206ms/step - loss: 0.1223 - accuracy: 0.9602 - val_loss: 0.1294 - val_accuracy: 0.9516
# Epoch 69/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.1308 - accuracy: 0.9539 - val_loss: 0.1373 - val_accuracy: 0.9375
# Epoch 70/110
# 5/5 [==============================] - 1s 207ms/step - loss: 0.1260 - accuracy: 0.9602 - val_loss: 0.1281 - val_accuracy: 0.9500
# Epoch 71/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.1244 - accuracy: 0.9535 - val_loss: 0.1327 - val_accuracy: 0.9594
# Epoch 72/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.1227 - accuracy: 0.9617 - val_loss: 0.1240 - val_accuracy: 0.9563
# Epoch 73/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1190 - accuracy: 0.9613 - val_loss: 0.1220 - val_accuracy: 0.9625
# Epoch 74/110
# 5/5 [==============================] - 1s 185ms/step - loss: 0.1119 - accuracy: 0.9664 - val_loss: 0.1202 - val_accuracy: 0.9563
# Epoch 75/110
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1113 - accuracy: 0.9602 - val_loss: 0.1382 - val_accuracy: 0.9438
# Epoch 76/110
# 5/5 [==============================] - 1s 192ms/step - loss: 0.1237 - accuracy: 0.9559 - val_loss: 0.1032 - val_accuracy: 0.9609
# Epoch 77/110
# 5/5 [==============================] - 1s 196ms/step - loss: 0.1051 - accuracy: 0.9629 - val_loss: 0.1127 - val_accuracy: 0.9547
# Epoch 78/110
# 5/5 [==============================] - 1s 188ms/step - loss: 0.1011 - accuracy: 0.9664 - val_loss: 0.1074 - val_accuracy: 0.9609
# Epoch 79/110
# 5/5 [==============================] - 1s 179ms/step - loss: 0.1039 - accuracy: 0.9648 - val_loss: 0.1082 - val_accuracy: 0.9625
# Epoch 80/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0992 - accuracy: 0.9660 - val_loss: 0.1192 - val_accuracy: 0.9531
# Epoch 81/110
# 5/5 [==============================] - 1s 190ms/step - loss: 0.0950 - accuracy: 0.9695 - val_loss: 0.1046 - val_accuracy: 0.9578
# Epoch 82/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0959 - accuracy: 0.9641 - val_loss: 0.1163 - val_accuracy: 0.9625
# Epoch 83/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0969 - accuracy: 0.9676 - val_loss: 0.1086 - val_accuracy: 0.9625
# Epoch 84/110
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0913 - accuracy: 0.9707 - val_loss: 0.0963 - val_accuracy: 0.9609
# Epoch 85/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0964 - accuracy: 0.9664 - val_loss: 0.1350 - val_accuracy: 0.9594
# Epoch 86/110
# 5/5 [==============================] - 1s 184ms/step - loss: 0.1052 - accuracy: 0.9656 - val_loss: 0.1084 - val_accuracy: 0.9578
# Epoch 87/110
# 5/5 [==============================] - 1s 193ms/step - loss: 0.0964 - accuracy: 0.9668 - val_loss: 0.1027 - val_accuracy: 0.9641
# Epoch 88/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0932 - accuracy: 0.9668 - val_loss: 0.1039 - val_accuracy: 0.9609
# Epoch 89/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0780 - accuracy: 0.9742 - val_loss: 0.1021 - val_accuracy: 0.9625
# Epoch 90/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0848 - accuracy: 0.9734 - val_loss: 0.1029 - val_accuracy: 0.9609
# Epoch 91/110
# 5/5 [==============================] - 1s 183ms/step - loss: 0.0812 - accuracy: 0.9750 - val_loss: 0.0963 - val_accuracy: 0.9672
# Epoch 92/110
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0816 - accuracy: 0.9695 - val_loss: 0.0990 - val_accuracy: 0.9609
# Epoch 93/110
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0878 - accuracy: 0.9668 - val_loss: 0.1075 - val_accuracy: 0.9656
# Epoch 94/110
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0893 - accuracy: 0.9695 - val_loss: 0.1209 - val_accuracy: 0.9531
# Epoch 95/110
# 5/5 [==============================] - 1s 198ms/step - loss: 0.0933 - accuracy: 0.9672 - val_loss: 0.1326 - val_accuracy: 0.9516
# Epoch 96/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.1050 - accuracy: 0.9641 - val_loss: 0.1127 - val_accuracy: 0.9641
# Epoch 97/110
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0883 - accuracy: 0.9719 - val_loss: 0.1005 - val_accuracy: 0.9719
# Epoch 98/110
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0843 - accuracy: 0.9707 - val_loss: 0.1018 - val_accuracy: 0.9766
# Epoch 99/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0754 - accuracy: 0.9730 - val_loss: 0.1077 - val_accuracy: 0.9672
# Epoch 100/110
# 5/5 [==============================] - 1s 182ms/step - loss: 0.0852 - accuracy: 0.9719 - val_loss: 0.1026 - val_accuracy: 0.9688
# Epoch 101/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0813 - accuracy: 0.9742 - val_loss: 0.0940 - val_accuracy: 0.9719
# Epoch 102/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0812 - accuracy: 0.9727 - val_loss: 0.1015 - val_accuracy: 0.9641
# Epoch 103/110
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0741 - accuracy: 0.9746 - val_loss: 0.1054 - val_accuracy: 0.9563
# Epoch 104/110
# 5/5 [==============================] - 1s 189ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.1128 - val_accuracy: 0.9672
# Epoch 105/110
# 5/5 [==============================] - 1s 200ms/step - loss: 0.0733 - accuracy: 0.9734 - val_loss: 0.1002 - val_accuracy: 0.9688
# Epoch 106/110
# 5/5 [==============================] - 1s 172ms/step - loss: 0.0795 - accuracy: 0.9734 - val_loss: 0.0942 - val_accuracy: 0.9703
# Epoch 107/110
# 5/5 [==============================] - 1s 180ms/step - loss: 0.0807 - accuracy: 0.9758 - val_loss: 0.1030 - val_accuracy: 0.9641
# Epoch 108/110
# 5/5 [==============================] - 1s 177ms/step - loss: 0.0701 - accuracy: 0.9805 - val_loss: 0.0992 - val_accuracy: 0.9609
# Epoch 109/110
# 5/5 [==============================] - 1s 178ms/step - loss: 0.0686 - accuracy: 0.9754 - val_loss: 0.0874 - val_accuracy: 0.9672
# Epoch 110/110
# 5/5 [==============================] - 1s 185ms/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 0.0967 - val_accuracy: 0.9656

# %%
# model accuracy on training and testing sets

train_loss, train_acc[trrat] = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc[trrat] = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 1s 9ms/step - loss: 0.0455 - accuracy: 0.9887
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0967 - accuracy: 0.9656
# 0.9886718988418579 0.965624988079071

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 848, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:09:29

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
#fig.savefig("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.png", bbox_inches='tight')

# %%
#import pickle
#pickle.dump(predictCube_reshape, open("./plots/CNN_Model2_spatial_train_108_test_108_predict_map.pickle", "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 120   0   0   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 195   2   0   1   6]
#  [  0   0   0   0   1  97   0   0   2]
#  [  0   0   0   0   0   0   4   0   2]
#  [  0   0   0   0   0   3   0  16   1]
#  [  0   0   0   0   3   0   0   0  17]]
#
# Accuracy Score
# 0.965625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      1.00      1.00       120
#       water       1.00      1.00      1.00        10
#       built       0.98      0.96      0.97       204
#     windows       0.95      0.97      0.96       100
#       roads       1.00      0.67      0.80         6
#        cars       0.94      0.80      0.86        20
#       metal       0.61      0.85      0.71        20
#
# avg / total       0.97      0.97      0.97       640

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(lbl), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %% [markdown]
# ___
# ## Plot Results

# %%
import numpy as np

#train_acc = [train_acc_200, train_acc_100, train_acc_50, train_acc_20, train_acc_10, train_acc_5]
#test_acc =[test_acc_100, test_acc_100, test_acc_50, test_acc_20, test_acc_10, test_acc_5]

plt_train_acc = [0.9574, train_acc[0.5], train_acc[0.2], train_acc[0.1], train_acc[0.05], train_acc[0.03], 
                 train_acc[0.01], train_acc[0.005], train_acc[0.001]]
plt_test_acc =[0.9422, test_acc[0.5], test_acc[0.2], test_acc[0.1], test_acc[0.05], test_acc[0.03],
               test_acc[0.01], test_acc[0.005], test_acc[0.001]]

print(plt_train_acc)
print(plt_test_acc)

# %%
n_groups = 9

avg_prec = np.zeros(n_groups)
avg_recall = np.zeros(n_groups)
avg_f1 = np.zeros(n_groups)
train_size = np.zeros(n_groups)
sky_prec = np.zeros(n_groups)
sky_recall = np.zeros(n_groups)
sky_f1 = np.zeros(n_groups)
sky_train_size = np.zeros(n_groups)
clouds_prec = np.zeros(n_groups)
clouds_recall = np.zeros(n_groups)
clouds_f1 = np.zeros(n_groups)
clouds_train_size = np.zeros(n_groups)
veg_prec = np.zeros(n_groups)
veg_recall = np.zeros(n_groups)
veg_f1 = np.zeros(n_groups)
veg_train_size = np.zeros(n_groups)
wtr_prec = np.zeros(n_groups)
wtr_recall = np.zeros(n_groups)
wtr_f1 = np.zeros(n_groups)
wtr_train_size = np.zeros(n_groups)
blt_prec = np.zeros(n_groups)
blt_recall = np.zeros(n_groups)
blt_f1 = np.zeros(n_groups)
blt_train_size = np.zeros(n_groups)
windows_prec = np.zeros(n_groups)
windows_recall = np.zeros(n_groups)
windows_f1 = np.zeros(n_groups)
windows_train_size = np.zeros(n_groups)
rds_prec = np.zeros(n_groups)
rds_recall = np.zeros(n_groups)
rds_f1 = np.zeros(n_groups)
rds_train_size = np.zeros(n_groups)
cars_prec = np.zeros(n_groups)
cars_recall = np.zeros(n_groups)
cars_f1 = np.zeros(n_groups)
cars_train_size = np.zeros(n_groups)
mtl_prec = np.zeros(n_groups)
mtl_recall = np.zeros(n_groups)
mtl_f1 = np.zeros(n_groups)
mtl_train_size = np.zeros(n_groups)

# %%
def read_prec_recall(file, line):
    Nums = []
    for num in file[line].split():
        try:
            Nums.append(float(num))
        except ValueError:
            pass
    prec = Nums[0]
    recall = Nums[1]
    f1 = Nums[2]
    #size = int(Nums[3]*(tt_ratio/100)/((100-tt_ratio)/100))
    size = Nums[3]
    
    return prec, recall, f1, size

# %%
filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics.txt"
f = open(filename, "r")
f1 = f.readlines()
i=0
avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
f.close()

# %%
train_split = ['80_20', '50_50', '20_80', '10_90', '5_95', '3_97', '1_99', '05_995', '01_999']
#tr_splits = [80, 50, 20, 10, 5, 3, 1, 0.5, 0.1]

#i=0
#for split in train_split:
for i in range(1,n_groups):
    filename = "./metrics/CNN_Model2_spatial_train_108_test_108_metrics_{0}_split.txt".format(train_split[i])
    f = open(filename, "r")
    f1 = f.readlines()

    avg_prec[i], avg_recall[i], avg_f1[i], train_size[i] = read_prec_recall(f1, 27)
    sky_prec[i], sky_recall[i], sky_f1[i], sky_train_size[i] = read_prec_recall(f1, 17)
    clouds_prec[i], clouds_recall[i], clouds_f1[i], clouds_train_size[i] = read_prec_recall(f1, 18)
    veg_prec[i], veg_recall[i], veg_f1[i], veg_train_size[i] = read_prec_recall(f1, 19)
    wtr_prec[i], wtr_recall[i], wtr_f1[i], wtr_train_size[i] = read_prec_recall(f1, 20) 
    blt_prec[i], blt_recall[i], blt_f1[i], blt_train_size[i] = read_prec_recall(f1, 21)
    windows_prec[i], windows_recall[i], windows_f1[i], windows_train_size[i] = read_prec_recall(f1, 22)
    rds_prec[i], rds_recall[i], rds_f1[i], rds_train_size[i] = read_prec_recall(f1, 23)
    cars_prec[i], cars_recall[i], cars_f1[i], cars_train_size[i] = read_prec_recall(f1, 24)
    mtl_prec[i], mtl_recall[i], mtl_f1[i], mtl_train_size[i] = read_prec_recall(f1, 25)
    
    f.close()
    #i += 1

# %%
train_size = 3200 - train_size
sky_train_size = sky_coords.shape[0] - sky_train_size
clouds_train_size = clouds_coords.shape[0] - clouds_train_size
veg_train_size = veg_coords.shape[0] - veg_train_size
wtr_train_size = wtr_coords.shape[0] - wtr_train_size
blt_train_size = blt_coords.shape[0] - blt_train_size
windows_train_size = windows_coords.shape[0] - windows_train_size
rds_train_size = rds_coords.shape[0] - rds_train_size
cars_train_size = cars_coords.shape[0] - cars_train_size
mtl_train_size = mtl_coords.shape[0] - mtl_train_size

# %%
print(train_size)

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 22
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

#train_size = [2560, 1600, 640, 320, 159]

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(20,5))

ax1.plot(train_size, plt_train_acc, '-o', color='b', lw=3, label='train')
ax1.plot(train_size, plt_test_acc, '-o', color='g', lw=3, label='test')
ax1.set_title("Accuracy", fontsize=20)
ax1.set_xlabel("training instances")
ax1.set_ylabel("accuracy")
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white')
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(train_size)
ax1.set_xlim(2800,8)
ax1.set_ylim(0.55,0.99)

ax2.plot(train_size, avg_prec, '-o', color='b', lw=3, label='mP')
ax2.plot(train_size, avg_recall, '-o', color='y', lw=3, label='mR')
ax2.plot(train_size, avg_f1, '-o', color='r', lw=3, label='mF1')
ax2.set_title("Mean Precision, Recall, and F1-Score", fontsize=20)
ax2.set_xlabel("training instances")
ax2.set_ylabel("metric")
handles, labels = ax2.get_legend_handles_labels()
ax2.legend(handles, labels, facecolor='white')
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(train_size)
ax2.set_xlim(2800,8)
ax2.set_ylim(0.55,0.99)

plt.show
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_overall_metrics_extend.png", bbox_inches='tight', dpi=300

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.labelweight'] = 'normal'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 15
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'

fig, ((ax1, ax2, ax3),(ax4, ax5, ax6),(ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(25,18))
ax1.plot(sky_train_size[:-1], sky_prec[:-1], '-o', color='b', lw=3, label='Precision')
ax1.plot(sky_train_size[:-1], sky_recall[:-1], '-o', color='y', lw=3, label='Recall')
ax1.plot(sky_train_size[:-1], sky_f1[:-1], '-o', color='r', lw=3, label='F1 Score')
ax1.set(title="Sky")
ax1.set_xscale('log', basex=2)
ax1.xaxis.set_major_formatter(ScalarFormatter())
#ax1.set_xticks(sky_train_size[:-1])
ax1.set_xticks([1,2,8,32,128,512])
ax1.set_ylim(-0.1,1.1)
ax1.set_xlim(0.8,1000)
ax1.set_ylabel("metric")
ax1.invert_xaxis()
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles, labels, facecolor='white', loc='lower left')

ax2.plot(clouds_train_size, clouds_prec, '-o', color='b', lw=3)
ax2.plot(clouds_train_size, clouds_recall, '-o', color='y', lw=3)
ax2.plot(clouds_train_size, clouds_f1, '-o', color='r', lw=3)
ax2.set(title="Clouds")
ax2.set_xscale('log', basex=2)
ax2.xaxis.set_major_formatter(ScalarFormatter())
#ax2.set_xticks(clouds_train_size)
ax2.set_xticks([1,2,8,32,128,512])
ax2.set_ylim(-0.1,1.1)
ax2.set_xlim(0.8,1000)
ax2.invert_xaxis()
ax2.legend(handles, labels, facecolor='white', loc='lower left')

ax3.plot(veg_train_size, veg_prec, '-o', color='b', lw=3)
ax3.plot(veg_train_size, veg_recall, '-o', color='y', lw=3)
ax3.plot(veg_train_size, veg_f1, '-o', color='r', lw=3)
ax3.set(title="Vegetation")
ax3.set_xscale('log', basex=2)
ax3.xaxis.set_major_formatter(ScalarFormatter())
#ax3.set_xticks(veg_train_size)
ax3.set_xticks([1,2,8,32,128,512])
ax3.set_ylim(-0.1,1.1)
ax3.set_xlim(0.8,1000)
ax3.invert_xaxis()
ax3.legend(handles, labels, facecolor='white', loc='lower left')

ax4.plot(wtr_train_size[:-3], wtr_prec[:-3], '-o', color='b', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_recall[:-3], '-o', color='y', lw=3)
ax4.plot(wtr_train_size[:-3], wtr_f1[:-3], '-o', color='r', lw=3)
ax4.set(title="Water")
ax4.set_xscale('log', basex=2)
ax4.xaxis.set_major_formatter(ScalarFormatter())
#ax4.set_xticks(wtr_train_size[:-3])
ax4.set_xticks([1,2,8,32,128,512])
ax4.set_ylim(-0.1,1.1)
ax4.set_xlim(0.8,1000)
ax4.set_ylabel("metric")
ax4.invert_xaxis()
ax4.legend(handles, labels, facecolor='white', loc='lower left')

ax5.plot(blt_train_size, blt_prec, '-o', color='b', lw=3)
ax5.plot(blt_train_size, blt_recall, '-o', color='y', lw=3)
ax5.plot(blt_train_size, blt_f1, '-o', color='r', lw=3)
ax5.set(title="Built")
ax5.set_xscale('log', basex=2)
ax5.xaxis.set_major_formatter(ScalarFormatter())
#ax5.set_xticks(blt_train_size)
ax5.set_xticks([1,2,8,32,128,512])
ax5.set_xlim(0.8,1000)
ax5.set_ylim(-0.1,1.1)
ax5.invert_xaxis()
ax5.legend(handles, labels, facecolor='white', loc='lower left')

ax6.plot(windows_train_size, windows_prec, '-o', color='b', lw=3, label='Precision')
ax6.plot(windows_train_size, windows_recall, '-o', color='y', lw=3, label='Recall')
ax6.plot(windows_train_size, windows_f1, '-o', color='r', lw=3, label='F1 Score')
ax6.set(title="Windows")
ax6.set_xscale('log', basex=2)
ax6.xaxis.set_major_formatter(ScalarFormatter())
#ax6.set_xticks(windows_train_size)
ax6.set_xticks([1,2,8,32,128,512])
ax6.set_ylim(-0.1,1.1)
ax6.set_xlim(0.8,1000)
ax6.invert_xaxis()
ax6.legend(handles, labels, facecolor='white', loc='lower left')

ax7.plot(rds_train_size[:-4], rds_prec[:-4], '-o', color='b', lw=3)
ax7.plot(rds_train_size[:-4], rds_recall[:-4], '-o', color='y', lw=3)
ax7.plot(rds_train_size[:-4], rds_f1[:-4], '-o', color='r', lw=3)
ax7.set(title="Roads")
ax7.set_xscale('log', basex=2)
ax7.xaxis.set_major_formatter(ScalarFormatter())
#ax7.set_xticks(rds_train_size[:-4])
ax7.set_xticks([1,2,8,32,128,512])
ax7.set_ylim(-0.1,1.1)
ax7.set_xlim(0.8,1000)
ax7.set_xlabel("training instances")
ax7.set_ylabel("metric")
ax7.invert_xaxis()
ax7.legend(handles, labels, facecolor='white', loc='lower left')

ax8.plot(cars_train_size[:-2], cars_prec[:-2], '-o', color='b', lw=3)
ax8.plot(cars_train_size[:-2], cars_recall[:-2], '-o', color='y', lw=3)
ax8.plot(cars_train_size[:-2], cars_f1[:-2], '-o', color='r', lw=3)
ax8.set(title="Cars")
ax8.set_xscale('log', basex=2)
ax8.xaxis.set_major_formatter(ScalarFormatter())
#ax8.set_xticks(cars_train_size[:-2])
ax8.set_xticks([1,2,8,32,128,512])
ax8.set_ylim(-0.1,1.1)
ax8.set_xlim(0.8,1000)
ax8.set_xlabel("training instances")
ax8.invert_xaxis()
ax8.legend(handles, labels, facecolor='white', loc='lower left')

ax9.plot(mtl_train_size[:-2], mtl_prec[:-2], '-o', color='b', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_recall[:-2], '-o', color='y', lw=3)
ax9.plot(mtl_train_size[:-2], mtl_f1[:-2], '-o', color='r', lw=3)
ax9.set(title="Metal")
ax9.set_xscale('log', basex=2)
ax9.xaxis.set_major_formatter(ScalarFormatter())
#ax9.set_xticks(mtl_train_size[:-2])
ax9.set_xticks([1,2,8,32,128,512])
ax9.set_ylim(-0.1,1.1)
ax9.set_xlim(0.8,1000)
ax9.set_xlabel("training instances")
ax9.invert_xaxis()
ax9.legend(handles, labels, facecolor='white', loc='lower left')

#handles, labels = ax6.get_legend_handles_labels()
#ax6.legend(handles, labels, loc='center right', borderaxespad=-10.0)

plt.show()
#fig.savefig("./plots/CNN_spatial_train_108_train_test_ratio_3_By_Class_Prec_Recall_extend.png",
#           bbox_inches='tight', dpi=300)
