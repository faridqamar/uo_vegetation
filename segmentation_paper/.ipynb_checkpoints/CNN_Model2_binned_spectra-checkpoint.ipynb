# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 424
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 424
# [[0, 2], [2, 4], [4, 6], [6, 8], [8, 10], [10, 12], [12, 14], [14, 16], [16, 18], [18, 20], [20, 22], [22, 24], [24, 26], [26, 28], [28, 30], [30, 32], [32, 34], [34, 36], [36, 38], [38, 40], [40, 42], [42, 44], [44, 46], [46, 48], [48, 50], [50, 52], [52, 54], [54, 56], [56, 58], [58, 60], [60, 62], [62, 64], [64, 66], [66, 68], [68, 70], [70, 72], [72, 74], [74, 76], [76, 78], [78, 80], [80, 82], [82, 84], [84, 86], [86, 88], [88, 90], [90, 92], [92, 94], [94, 96], [96, 98], [98, 100], [100, 102], [102, 104], [104, 106], [106, 108], [108, 110], [110, 112], [112, 114], [114, 116], [116, 118], [118, 120], [120, 122], [122, 124], [124, 126], [126, 128], [128, 130], [130, 132], [132, 134], [134, 136], [136, 138], [138, 140], [140, 142], [142, 144], [144, 146], [146, 148], [148, 150], [150, 152], [152, 154], [154, 156], [156, 158], [158, 160], [160, 162], [162, 164], [164, 166], [166, 168], [168, 170], [170, 172], [172, 174], [174, 176], [176, 178], [178, 180], [180, 182], [182, 184], [184, 186], [186, 188], [188, 190], [190, 192], [192, 194], [194, 196], [196, 198], [198, 200], [200, 202], [202, 204], [204, 206], [206, 208], [208, 210], [210, 212], [212, 214], [214, 216], [216, 218], [218, 220], [220, 222], [222, 224], [224, 226], [226, 228], [228, 230], [230, 232], [232, 234], [234, 236], [236, 238], [238, 240], [240, 242], [242, 244], [244, 246], [246, 248], [248, 250], [250, 252], [252, 254], [254, 256], [256, 258], [258, 260], [260, 262], [262, 264], [264, 266], [266, 268], [268, 270], [270, 272], [272, 274], [274, 276], [276, 278], [278, 280], [280, 282], [282, 284], [284, 286], [286, 288], [288, 290], [290, 292], [292, 294], [294, 296], [296, 298], [298, 300], [300, 302], [302, 304], [304, 306], [306, 308], [308, 310], [310, 312], [312, 314], [314, 316], [316, 318], [318, 320], [320, 322], [322, 324], [324, 326], [326, 328], [328, 330], [330, 332], [332, 334], [334, 336], [336, 338], [338, 340], [340, 342], [342, 344], [344, 346], [346, 348], [348, 350], [350, 352], [352, 354], [354, 356], [356, 358], [358, 360], [360, 362], [362, 364], [364, 366], [366, 368], [368, 370], [370, 372], [372, 374], [374, 376], [376, 378], [378, 380], [380, 382], [382, 384], [384, 386], [386, 388], [388, 390], [390, 392], [392, 394], [394, 396], [396, 398], [398, 400], [400, 402], [402, 404], [404, 406], [406, 408], [408, 410], [410, 412], [412, 414], [414, 416], [416, 418], [418, 420], [420, 422], [422, 424], [424, 426], [426, 428], [428, 430], [430, 432], [432, 434], [434, 436], [436, 438], [438, 440], [440, 442], [442, 444], [444, 446], [446, 448], [448, 450], [450, 452], [452, 454], [454, 456], [456, 458], [458, 460], [460, 462], [462, 464], [464, 466], [466, 468], [468, 470], [470, 472], [472, 474], [474, 476], [476, 478], [478, 480], [480, 482], [482, 484], [484, 486], [486, 488], [488, 490], [490, 492], [492, 494], [494, 496], [496, 498], [498, 500], [500, 502], [502, 504], [504, 506], [506, 508], [508, 510], [510, 512], [512, 514], [514, 516], [516, 518], [518, 520], [520, 522], [522, 524], [524, 526], [526, 528], [528, 530], [530, 532], [532, 534], [534, 536], [536, 538], [538, 540], [540, 542], [542, 544], [544, 546], [546, 548], [548, 550], [550, 552], [552, 554], [554, 556], [556, 558], [558, 560], [560, 562], [562, 564], [564, 566], [566, 568], [568, 570], [570, 572], [572, 574], [574, 576], [576, 578], [578, 580], [580, 582], [582, 584], [584, 586], [586, 588], [588, 590], [590, 592], [592, 594], [594, 596], [596, 598], [598, 600], [600, 602], [602, 604], [604, 606], [606, 608], [608, 610], [610, 612], [612, 614], [614, 616], [616, 618], [618, 620], [620, 622], [622, 624], [624, 626], [626, 628], [628, 630], [630, 632], [632, 634], [634, 636], [636, 638], [638, 640], [640, 642], [642, 644], [644, 646], [646, 648], [648, 650], [650, 652], [652, 654], [654, 656], [656, 658], [658, 660], [660, 662], [662, 664], [664, 666], [666, 668], [668, 670], [670, 672], [672, 674], [674, 676], [676, 678], [678, 680], [680, 682], [682, 684], [68 ...

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 424)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 424)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 424)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 424) (60, 424)
# clouds  (400, 424) (100, 424)
# vegetation  (480, 424) (120, 424)
# water  (40, 424) (10, 424)
# built  (816, 424) (204, 424)
# windows  (400, 424) (100, 424)
# roads  (24, 424) (6, 424)
# cars  (80, 424) (20, 424)
# metal  (80, 424) (20, 424)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 424) (2560,) (2560, 2)
# (640, 424) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 154ms/step - loss: 1.6394 - accuracy: 0.4523 - val_loss: 1.0375 - val_accuracy: 0.6516
# Epoch 2/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.9479 - accuracy: 0.7023 - val_loss: 0.7780 - val_accuracy: 0.7406
# Epoch 3/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.7706 - accuracy: 0.7422 - val_loss: 0.7065 - val_accuracy: 0.8016
# Epoch 4/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6887 - accuracy: 0.7789 - val_loss: 0.5845 - val_accuracy: 0.8156
# Epoch 5/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6212 - accuracy: 0.8035 - val_loss: 0.5228 - val_accuracy: 0.8500
# Epoch 6/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.5290 - accuracy: 0.8375 - val_loss: 0.4529 - val_accuracy: 0.8422
# Epoch 7/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4711 - accuracy: 0.8562 - val_loss: 0.4017 - val_accuracy: 0.8797
# Epoch 8/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4370 - accuracy: 0.8664 - val_loss: 0.3782 - val_accuracy: 0.9016
# Epoch 9/200
# 5/5 [==============================] - 0s 81ms/step - loss: 0.4024 - accuracy: 0.8754 - val_loss: 0.3419 - val_accuracy: 0.9078
# Epoch 10/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.4006 - accuracy: 0.8746 - val_loss: 0.3284 - val_accuracy: 0.9062
# Epoch 11/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.3882 - accuracy: 0.8773 - val_loss: 0.3653 - val_accuracy: 0.8750
# Epoch 12/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.3709 - accuracy: 0.8832 - val_loss: 0.3110 - val_accuracy: 0.9109
# Epoch 13/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.3497 - accuracy: 0.8938 - val_loss: 0.2978 - val_accuracy: 0.9156
# Epoch 14/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.3241 - accuracy: 0.9031 - val_loss: 0.2766 - val_accuracy: 0.9109
# Epoch 15/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.3246 - accuracy: 0.9023 - val_loss: 0.2928 - val_accuracy: 0.9094
# Epoch 16/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.3586 - accuracy: 0.8883 - val_loss: 0.3436 - val_accuracy: 0.9016
# Epoch 17/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.3391 - accuracy: 0.8922 - val_loss: 0.2862 - val_accuracy: 0.9062
# Epoch 18/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3065 - accuracy: 0.9086 - val_loss: 0.2764 - val_accuracy: 0.9094
# Epoch 19/200
# 5/5 [==============================] - 1s 108ms/step - loss: 0.3132 - accuracy: 0.9043 - val_loss: 0.2544 - val_accuracy: 0.9141
# Epoch 20/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2967 - accuracy: 0.9051 - val_loss: 0.2696 - val_accuracy: 0.9297
# Epoch 21/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.2946 - accuracy: 0.9062 - val_loss: 0.2795 - val_accuracy: 0.9219
# Epoch 22/200
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2945 - accuracy: 0.9051 - val_loss: 0.2399 - val_accuracy: 0.9234
# Epoch 23/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2739 - accuracy: 0.9129 - val_loss: 0.2412 - val_accuracy: 0.9203
# Epoch 24/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2672 - accuracy: 0.9207 - val_loss: 0.2248 - val_accuracy: 0.9266
# Epoch 25/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.2597 - accuracy: 0.9199 - val_loss: 0.2782 - val_accuracy: 0.8922
# Epoch 26/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.2755 - accuracy: 0.9113 - val_loss: 0.2201 - val_accuracy: 0.9156
# Epoch 27/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2778 - accuracy: 0.9090 - val_loss: 0.2234 - val_accuracy: 0.9281
# Epoch 28/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.2635 - accuracy: 0.9172 - val_loss: 0.2301 - val_accuracy: 0.9281
# Epoch 29/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2496 - accuracy: 0.9219 - val_loss: 0.2141 - val_accuracy: 0.9312
# Epoch 30/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2380 - accuracy: 0.9227 - val_loss: 0.2116 - val_accuracy: 0.9281
# Epoch 31/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.2373 - accuracy: 0.9262 - val_loss: 0.1961 - val_accuracy: 0.9266
# Epoch 32/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.2199 - accuracy: 0.9289 - val_loss: 0.1921 - val_accuracy: 0.9266
# Epoch 33/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2253 - accuracy: 0.9301 - val_loss: 0.1975 - val_accuracy: 0.9359
# Epoch 34/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2215 - accuracy: 0.9277 - val_loss: 0.2178 - val_accuracy: 0.9187
# Epoch 35/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2633 - accuracy: 0.9145 - val_loss: 0.3056 - val_accuracy: 0.9062
# Epoch 36/200
# 5/5 [==============================] - 1s 102ms/step - loss: 0.2534 - accuracy: 0.9152 - val_loss: 0.2184 - val_accuracy: 0.9281
# Epoch 37/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2405 - accuracy: 0.9266 - val_loss: 0.2247 - val_accuracy: 0.9234
# Epoch 38/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2294 - accuracy: 0.9270 - val_loss: 0.2058 - val_accuracy: 0.9281
# Epoch 39/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2213 - accuracy: 0.9293 - val_loss: 0.1840 - val_accuracy: 0.9359
# Epoch 40/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.2164 - accuracy: 0.9301 - val_loss: 0.2037 - val_accuracy: 0.9312
# Epoch 41/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.2126 - accuracy: 0.9301 - val_loss: 0.1805 - val_accuracy: 0.9391
# Epoch 42/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2019 - accuracy: 0.9340 - val_loss: 0.1824 - val_accuracy: 0.9281
# Epoch 43/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2089 - accuracy: 0.9309 - val_loss: 0.1759 - val_accuracy: 0.9359
# Epoch 44/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2001 - accuracy: 0.9328 - val_loss: 0.1988 - val_accuracy: 0.9297
# Epoch 45/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2052 - accuracy: 0.9316 - val_loss: 0.2047 - val_accuracy: 0.9250
# Epoch 46/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.2096 - accuracy: 0.9301 - val_loss: 0.1784 - val_accuracy: 0.9375
# Epoch 47/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1915 - accuracy: 0.9340 - val_loss: 0.1911 - val_accuracy: 0.9250
# Epoch 48/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1947 - accuracy: 0.9355 - val_loss: 0.1900 - val_accuracy: 0.9312
# Epoch 49/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1885 - accuracy: 0.9367 - val_loss: 0.1656 - val_accuracy: 0.9328
# Epoch 50/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.1809 - accuracy: 0.9379 - val_loss: 0.1637 - val_accuracy: 0.9500
# Epoch 51/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.1769 - accuracy: 0.9402 - val_loss: 0.1629 - val_accuracy: 0.9516
# Epoch 52/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1678 - accuracy: 0.9422 - val_loss: 0.1554 - val_accuracy: 0.9359
# Epoch 53/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1719 - accuracy: 0.9438 - val_loss: 0.1537 - val_accuracy: 0.9438
# Epoch 54/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1635 - accuracy: 0.9445 - val_loss: 0.1896 - val_accuracy: 0.9391
# Epoch 55/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1984 - accuracy: 0.9328 - val_loss: 0.1695 - val_accuracy: 0.9344
# Epoch 56/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1870 - accuracy: 0.9434 - val_loss: 0.1767 - val_accuracy: 0.9422
# Epoch 57/200
# 5/5 [==============================] - 1s 110ms/step - loss: 0.2337 - accuracy: 0.9211 - val_loss: 0.1683 - val_accuracy: 0.9375
# Epoch 58/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.2022 - accuracy: 0.9352 - val_loss: 0.1706 - val_accuracy: 0.9328
# Epoch 59/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1930 - accuracy: 0.9332 - val_loss: 0.1702 - val_accuracy: 0.9531
# Epoch 60/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1709 - accuracy: 0.9438 - val_loss: 0.1616 - val_accuracy: 0.9453
# Epoch 61/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1800 - accuracy: 0.9414 - val_loss: 0.1475 - val_accuracy: 0.9469
# Epoch 62/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.1728 - accuracy: 0.9391 - val_loss: 0.1638 - val_accuracy: 0.9328
# Epoch 63/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1840 - accuracy: 0.9379 - val_loss: 0.1513 - val_accuracy: 0.9516
# Epoch 64/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1626 - accuracy: 0.9438 - val_loss: 0.1566 - val_accuracy: 0.9406
# Epoch 65/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1586 - accuracy: 0.9480 - val_loss: 0.1344 - val_accuracy: 0.9422
# Epoch 66/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.1491 - accuracy: 0.9512 - val_loss: 0.1408 - val_accuracy: 0.9547
# Epoch 67/200
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1551 - accuracy: 0.9449 - val_loss: 0.1530 - val_accuracy: 0.9516
# Epoch 68/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1522 - accuracy: 0.9496 - val_loss: 0.1525 - val_accuracy: 0.9469
# Epoch 69/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1524 - accuracy: 0.9473 - val_loss: 0.1429 - val_accuracy: 0.9500
# Epoch 70/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1403 - accuracy: 0.9512 - val_loss: 0.1389 - val_accuracy: 0.9484
# Epoch 71/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1359 - accuracy: 0.9566 - val_loss: 0.1419 - val_accuracy: 0.9531
# Epoch 72/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1409 - accuracy: 0.9508 - val_loss: 0.1391 - val_accuracy: 0.9500
# Epoch 73/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1358 - accuracy: 0.9563 - val_loss: 0.1322 - val_accuracy: 0.9516
# Epoch 74/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1456 - accuracy: 0.9500 - val_loss: 0.1495 - val_accuracy: 0.9453
# Epoch 75/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1514 - accuracy: 0.9477 - val_loss: 0.1412 - val_accuracy: 0.9438
# Epoch 76/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1470 - accuracy: 0.9477 - val_loss: 0.1290 - val_accuracy: 0.9469
# Epoch 77/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1340 - accuracy: 0.9551 - val_loss: 0.1494 - val_accuracy: 0.9594
# Epoch 78/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1324 - accuracy: 0.9563 - val_loss: 0.1221 - val_accuracy: 0.9531
# Epoch 79/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.1398 - accuracy: 0.9496 - val_loss: 0.1648 - val_accuracy: 0.9438
# Epoch 80/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1489 - accuracy: 0.9516 - val_loss: 0.1394 - val_accuracy: 0.9578
# Epoch 81/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1391 - accuracy: 0.9508 - val_loss: 0.1295 - val_accuracy: 0.9625
# Epoch 82/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1379 - accuracy: 0.9547 - val_loss: 0.1256 - val_accuracy: 0.9578
# Epoch 83/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1325 - accuracy: 0.9523 - val_loss: 0.1336 - val_accuracy: 0.9609
# Epoch 84/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1282 - accuracy: 0.9566 - val_loss: 0.1229 - val_accuracy: 0.9469
# Epoch 85/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1273 - accuracy: 0.9570 - val_loss: 0.1402 - val_accuracy: 0.9531
# Epoch 86/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.1243 - accuracy: 0.9590 - val_loss: 0.1238 - val_accuracy: 0.9516
# Epoch 87/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1180 - accuracy: 0.9590 - val_loss: 0.1339 - val_accuracy: 0.9625
# Epoch 88/200
# 5/5 [==============================] - 1s 259ms/step - loss: 0.1272 - accuracy: 0.9574 - val_loss: 0.1295 - val_accuracy: 0.9547
# Epoch 89/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1186 - accuracy: 0.9621 - val_loss: 0.1206 - val_accuracy: 0.9531
# Epoch 90/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1232 - accuracy: 0.9566 - val_loss: 0.1145 - val_accuracy: 0.9563
# Epoch 91/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1144 - accuracy: 0.9594 - val_loss: 0.1213 - val_accuracy: 0.9594
# Epoch 92/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1097 - accuracy: 0.9602 - val_loss: 0.1101 - val_accuracy: 0.9625
# Epoch 93/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1078 - accuracy: 0.9672 - val_loss: 0.1085 - val_accuracy: 0.9578
# Epoch 94/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1124 - accuracy: 0.9555 - val_loss: 0.1169 - val_accuracy: 0.9594
# Epoch 95/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1093 - accuracy: 0.9641 - val_loss: 0.1133 - val_accuracy: 0.9625
# Epoch 96/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1026 - accuracy: 0.9664 - val_loss: 0.1086 - val_accuracy: 0.9563
# Epoch 97/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1115 - accuracy: 0.9602 - val_loss: 0.1257 - val_accuracy: 0.9578
# Epoch 98/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1071 - accuracy: 0.9641 - val_loss: 0.1031 - val_accuracy: 0.9641
# Epoch 99/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1069 - accuracy: 0.9637 - val_loss: 0.1043 - val_accuracy: 0.9609
# Epoch 100/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1035 - accuracy: 0.9641 - val_loss: 0.1076 - val_accuracy: 0.9578
# Epoch 101/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1050 - accuracy: 0.9629 - val_loss: 0.1168 - val_accuracy: 0.9547
# Epoch 102/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1071 - accuracy: 0.9633 - val_loss: 0.1193 - val_accuracy: 0.9609
# Epoch 103/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1407 - accuracy: 0.9504 - val_loss: 0.1059 - val_accuracy: 0.9594
# Epoch 104/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1304 - accuracy: 0.9563 - val_loss: 0.1076 - val_accuracy: 0.9578
# Epoch 105/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1174 - accuracy: 0.9605 - val_loss: 0.1148 - val_accuracy: 0.9547
# Epoch 106/200
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1223 - accuracy: 0.9559 - val_loss: 0.1320 - val_accuracy: 0.9609
# Epoch 107/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1240 - accuracy: 0.9590 - val_loss: 0.1298 - val_accuracy: 0.9609
# Epoch 108/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.1072 - accuracy: 0.9652 - val_loss: 0.1011 - val_accuracy: 0.9625
# Epoch 109/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1017 - accuracy: 0.9641 - val_loss: 0.1139 - val_accuracy: 0.9578
# Epoch 110/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0958 - accuracy: 0.9695 - val_loss: 0.0948 - val_accuracy: 0.9672
# Epoch 111/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0984 - accuracy: 0.9699 - val_loss: 0.1117 - val_accuracy: 0.9625
# Epoch 112/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0869 - accuracy: 0.9707 - val_loss: 0.0884 - val_accuracy: 0.9656
# Epoch 113/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0927 - accuracy: 0.9660 - val_loss: 0.0990 - val_accuracy: 0.9578
# Epoch 114/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0918 - accuracy: 0.9656 - val_loss: 0.0988 - val_accuracy: 0.9703
# Epoch 115/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0947 - accuracy: 0.9668 - val_loss: 0.0970 - val_accuracy: 0.9641
# Epoch 116/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0831 - accuracy: 0.9723 - val_loss: 0.0929 - val_accuracy: 0.9656
# Epoch 117/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0826 - accuracy: 0.9727 - val_loss: 0.0930 - val_accuracy: 0.9672
# Epoch 118/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0870 - accuracy: 0.9754 - val_loss: 0.0907 - val_accuracy: 0.9688
# Epoch 119/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1197 - accuracy: 0.9582 - val_loss: 0.3744 - val_accuracy: 0.8500
# Epoch 120/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4141 - accuracy: 0.8699 - val_loss: 0.1564 - val_accuracy: 0.9391
# Epoch 121/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.2231 - accuracy: 0.9223 - val_loss: 0.1957 - val_accuracy: 0.9344
# Epoch 122/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.2179 - accuracy: 0.9266 - val_loss: 0.1581 - val_accuracy: 0.9359
# Epoch 123/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1862 - accuracy: 0.9367 - val_loss: 0.1624 - val_accuracy: 0.9406
# Epoch 124/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1577 - accuracy: 0.9461 - val_loss: 0.1269 - val_accuracy: 0.9594
# Epoch 125/200
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1489 - accuracy: 0.9492 - val_loss: 0.1340 - val_accuracy: 0.9500
# Epoch 126/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1451 - accuracy: 0.9512 - val_loss: 0.1263 - val_accuracy: 0.9563
# Epoch 127/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1322 - accuracy: 0.9547 - val_loss: 0.1298 - val_accuracy: 0.9547
# Epoch 128/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.1206 - accuracy: 0.9570 - val_loss: 0.1111 - val_accuracy: 0.9641
# Epoch 129/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1110 - accuracy: 0.9629 - val_loss: 0.1093 - val_accuracy: 0.9625
# Epoch 130/200
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1111 - accuracy: 0.9637 - val_loss: 0.1004 - val_accuracy: 0.9625
# Epoch 131/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1149 - accuracy: 0.9590 - val_loss: 0.1151 - val_accuracy: 0.9594
# Epoch 132/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1291 - accuracy: 0.9566 - val_loss: 0.1192 - val_accuracy: 0.9563
# Epoch 133/200
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1203 - accuracy: 0.9590 - val_loss: 0.1206 - val_accuracy: 0.9594
# Epoch 134/200
# 5/5 [==============================] - 0s 100ms/step - loss: 0.1111 - accuracy: 0.9621 - val_loss: 0.1167 - val_accuracy: 0.9656
# Epoch 135/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1166 - accuracy: 0.9602 - val_loss: 0.1044 - val_accuracy: 0.9688
# Epoch 136/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0961 - accuracy: 0.9652 - val_loss: 0.1074 - val_accuracy: 0.9641
# Epoch 137/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1093 - accuracy: 0.9648 - val_loss: 0.1096 - val_accuracy: 0.9656
# Epoch 138/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0991 - accuracy: 0.9688 - val_loss: 0.0977 - val_accuracy: 0.9656
# Epoch 139/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1008 - accuracy: 0.9684 - val_loss: 0.1071 - val_accuracy: 0.9688
# Epoch 140/200
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0900 - accuracy: 0.9730 - val_loss: 0.1016 - val_accuracy: 0.9609
# Epoch 141/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0994 - accuracy: 0.9656 - val_loss: 0.0911 - val_accuracy: 0.9641
# Epoch 142/200
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0839 - accuracy: 0.9719 - val_loss: 0.0917 - val_accuracy: 0.9672
# Epoch 143/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0892 - accuracy: 0.9762 - val_loss: 0.0854 - val_accuracy: 0.9734
# Epoch 144/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0841 - accuracy: 0.9727 - val_loss: 0.0981 - val_accuracy: 0.9656
# Epoch 145/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0843 - accuracy: 0.9719 - val_loss: 0.1072 - val_accuracy: 0.9641
# Epoch 146/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0876 - accuracy: 0.9723 - val_loss: 0.0976 - val_accuracy: 0.9672
# Epoch 147/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0900 - accuracy: 0.9707 - val_loss: 0.0988 - val_accuracy: 0.9688
# Epoch 148/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0867 - accuracy: 0.9734 - val_loss: 0.0918 - val_accuracy: 0.9719
# Epoch 149/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0826 - accuracy: 0.9750 - val_loss: 0.0886 - val_accuracy: 0.9688
# Epoch 150/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0880 - accuracy: 0.9699 - val_loss: 0.0998 - val_accuracy: 0.9656
# Epoch 151/200
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0926 - accuracy: 0.9688 - val_loss: 0.0956 - val_accuracy: 0.9672
# Epoch 152/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0882 - accuracy: 0.9711 - val_loss: 0.0995 - val_accuracy: 0.9688
# Epoch 153/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0834 - accuracy: 0.9746 - val_loss: 0.1002 - val_accuracy: 0.9672
# Epoch 154/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0864 - accuracy: 0.9711 - val_loss: 0.0889 - val_accuracy: 0.9688
# Epoch 155/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0789 - accuracy: 0.9742 - val_loss: 0.0927 - val_accuracy: 0.9688
# Epoch 156/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0715 - accuracy: 0.9770 - val_loss: 0.0962 - val_accuracy: 0.9688
# Epoch 157/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0800 - accuracy: 0.9727 - val_loss: 0.0849 - val_accuracy: 0.9672
# Epoch 158/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0821 - accuracy: 0.9715 - val_loss: 0.0877 - val_accuracy: 0.9688
# Epoch 159/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0780 - accuracy: 0.9754 - val_loss: 0.0915 - val_accuracy: 0.9641
# Epoch 160/200
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0744 - accuracy: 0.9773 - val_loss: 0.0810 - val_accuracy: 0.9750
# Epoch 161/200
# 5/5 [==============================] - 1s 100ms/step - loss: 0.0782 - accuracy: 0.9754 - val_loss: 0.0839 - val_accuracy: 0.9719
# Epoch 162/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0746 - accuracy: 0.9750 - val_loss: 0.0854 - val_accuracy: 0.9703
# Epoch 163/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0768 - accuracy: 0.9754 - val_loss: 0.0838 - val_accuracy: 0.9719
# Epoch 164/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0696 - accuracy: 0.9785 - val_loss: 0.0813 - val_accuracy: 0.9719
# Epoch 165/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0685 - accuracy: 0.9801 - val_loss: 0.0882 - val_accuracy: 0.9688
# Epoch 166/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0675 - accuracy: 0.9766 - val_loss: 0.0834 - val_accuracy: 0.9719
# Epoch 167/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0732 - accuracy: 0.9730 - val_loss: 0.0954 - val_accuracy: 0.9672
# Epoch 168/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0880 - accuracy: 0.9719 - val_loss: 0.0858 - val_accuracy: 0.9688
# Epoch 169/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0731 - accuracy: 0.9758 - val_loss: 0.0768 - val_accuracy: 0.9750
# Epoch 170/200
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0740 - accuracy: 0.9746 - val_loss: 0.0784 - val_accuracy: 0.9781
# Epoch 171/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0704 - accuracy: 0.9785 - val_loss: 0.0844 - val_accuracy: 0.9734
# Epoch 172/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0654 - accuracy: 0.9797 - val_loss: 0.0778 - val_accuracy: 0.9688
# Epoch 173/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0728 - accuracy: 0.9766 - val_loss: 0.0812 - val_accuracy: 0.9719
# Epoch 174/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0714 - accuracy: 0.9750 - val_loss: 0.0776 - val_accuracy: 0.9719
# Epoch 175/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0628 - accuracy: 0.9820 - val_loss: 0.0868 - val_accuracy: 0.9703
# Epoch 176/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0749 - accuracy: 0.9730 - val_loss: 0.0796 - val_accuracy: 0.9688
# Epoch 177/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0794 - accuracy: 0.9758 - val_loss: 0.0864 - val_accuracy: 0.9703
# Epoch 178/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0780 - accuracy: 0.9730 - val_loss: 0.0798 - val_accuracy: 0.9703
# Epoch 179/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0715 - accuracy: 0.9742 - val_loss: 0.0839 - val_accuracy: 0.9734
# Epoch 180/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0693 - accuracy: 0.9762 - val_loss: 0.0777 - val_accuracy: 0.9656
# Epoch 181/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0607 - accuracy: 0.9793 - val_loss: 0.0827 - val_accuracy: 0.9781
# Epoch 182/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0642 - accuracy: 0.9820 - val_loss: 0.0798 - val_accuracy: 0.9703
# Epoch 183/200
# 5/5 [==============================] - 1s 107ms/step - loss: 0.0598 - accuracy: 0.9836 - val_loss: 0.0871 - val_accuracy: 0.9719
# Epoch 184/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0652 - accuracy: 0.9805 - val_loss: 0.0921 - val_accuracy: 0.9656
# Epoch 185/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0732 - accuracy: 0.9746 - val_loss: 0.0924 - val_accuracy: 0.9734
# Epoch 186/200
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0648 - accuracy: 0.9809 - val_loss: 0.0953 - val_accuracy: 0.9641
# Epoch 187/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0642 - accuracy: 0.9793 - val_loss: 0.0847 - val_accuracy: 0.9719
# Epoch 188/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0658 - accuracy: 0.9793 - val_loss: 0.0731 - val_accuracy: 0.9734
# Epoch 189/200
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0594 - accuracy: 0.9820 - val_loss: 0.0897 - val_accuracy: 0.9672
# Epoch 190/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.0619 - accuracy: 0.9789 - val_loss: 0.0991 - val_accuracy: 0.9656
# Epoch 191/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0616 - accuracy: 0.9801 - val_loss: 0.0806 - val_accuracy: 0.9719
# Epoch 192/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0572 - accuracy: 0.9820 - val_loss: 0.0857 - val_accuracy: 0.9719
# Epoch 193/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0597 - accuracy: 0.9816 - val_loss: 0.0687 - val_accuracy: 0.9734
# Epoch 194/200
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0601 - accuracy: 0.9789 - val_loss: 0.0756 - val_accuracy: 0.9750
# Epoch 195/200
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0540 - accuracy: 0.9844 - val_loss: 0.0817 - val_accuracy: 0.9766
# Epoch 196/200
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0485 - accuracy: 0.9855 - val_loss: 0.0783 - val_accuracy: 0.9750
# Epoch 197/200
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0510 - accuracy: 0.9840 - val_loss: 0.0739 - val_accuracy: 0.9766
# Epoch 198/200
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0481 - accuracy: 0.9855 - val_loss: 0.0863 - val_accuracy: 0.9688
# Epoch 199/200
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0560 - accuracy: 0.9828 - val_loss: 0.0797 - val_accuracy: 0.9672
# Epoch 200/200
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0575 - accuracy: 0.9805 - val_loss: 0.0775 - val_accuracy: 0.9766

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=140, batch_size=512)
# Out:
# Epoch 1/140
# 5/5 [==============================] - 1s 134ms/step - loss: 1.7352 - accuracy: 0.3590 - val_loss: 1.2521 - val_accuracy: 0.6250
# Epoch 2/140
# 5/5 [==============================] - 0s 87ms/step - loss: 1.0708 - accuracy: 0.6730 - val_loss: 0.8430 - val_accuracy: 0.7141
# Epoch 3/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.8281 - accuracy: 0.7324 - val_loss: 0.7202 - val_accuracy: 0.7547
# Epoch 4/140
# 5/5 [==============================] - 0s 95ms/step - loss: 0.7399 - accuracy: 0.7723 - val_loss: 0.6347 - val_accuracy: 0.8250
# Epoch 5/140
# 5/5 [==============================] - 1s 105ms/step - loss: 0.6519 - accuracy: 0.7852 - val_loss: 0.5832 - val_accuracy: 0.8281
# Epoch 6/140
# 5/5 [==============================] - 1s 102ms/step - loss: 0.5943 - accuracy: 0.8102 - val_loss: 0.5242 - val_accuracy: 0.8188
# Epoch 7/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.5536 - accuracy: 0.8223 - val_loss: 0.5017 - val_accuracy: 0.8234
# Epoch 8/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.5037 - accuracy: 0.8391 - val_loss: 0.4307 - val_accuracy: 0.8750
# Epoch 9/140
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4598 - accuracy: 0.8551 - val_loss: 0.4169 - val_accuracy: 0.8469
# Epoch 10/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.4331 - accuracy: 0.8633 - val_loss: 0.3714 - val_accuracy: 0.8750
# Epoch 11/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.4021 - accuracy: 0.8828 - val_loss: 0.3312 - val_accuracy: 0.9094
# Epoch 12/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.3709 - accuracy: 0.8914 - val_loss: 0.3120 - val_accuracy: 0.9125
# Epoch 13/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.3577 - accuracy: 0.8875 - val_loss: 0.3257 - val_accuracy: 0.8875
# Epoch 14/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3606 - accuracy: 0.8922 - val_loss: 0.2897 - val_accuracy: 0.9187
# Epoch 15/140
# 5/5 [==============================] - 1s 102ms/step - loss: 0.3440 - accuracy: 0.8969 - val_loss: 0.2994 - val_accuracy: 0.8969
# Epoch 16/140
# 5/5 [==============================] - 0s 84ms/step - loss: 0.3387 - accuracy: 0.8941 - val_loss: 0.2974 - val_accuracy: 0.8938
# Epoch 17/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.3204 - accuracy: 0.8973 - val_loss: 0.2684 - val_accuracy: 0.9141
# Epoch 18/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.2993 - accuracy: 0.9078 - val_loss: 0.3038 - val_accuracy: 0.9125
# Epoch 19/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.3113 - accuracy: 0.9008 - val_loss: 0.2545 - val_accuracy: 0.9078
# Epoch 20/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.3029 - accuracy: 0.9004 - val_loss: 0.2709 - val_accuracy: 0.9078
# Epoch 21/140
# 5/5 [==============================] - 0s 97ms/step - loss: 0.2895 - accuracy: 0.9078 - val_loss: 0.2589 - val_accuracy: 0.9125
# Epoch 22/140
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2864 - accuracy: 0.9109 - val_loss: 0.2454 - val_accuracy: 0.9156
# Epoch 23/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2844 - accuracy: 0.9121 - val_loss: 0.2351 - val_accuracy: 0.9125
# Epoch 24/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2633 - accuracy: 0.9199 - val_loss: 0.2309 - val_accuracy: 0.9219
# Epoch 25/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.2627 - accuracy: 0.9148 - val_loss: 0.2211 - val_accuracy: 0.9219
# Epoch 26/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2445 - accuracy: 0.9207 - val_loss: 0.2232 - val_accuracy: 0.9172
# Epoch 27/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.2503 - accuracy: 0.9230 - val_loss: 0.2191 - val_accuracy: 0.9344
# Epoch 28/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2534 - accuracy: 0.9203 - val_loss: 0.2372 - val_accuracy: 0.9250
# Epoch 29/140
# 5/5 [==============================] - 1s 108ms/step - loss: 0.2476 - accuracy: 0.9148 - val_loss: 0.2191 - val_accuracy: 0.9266
# Epoch 30/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2363 - accuracy: 0.9266 - val_loss: 0.2036 - val_accuracy: 0.9219
# Epoch 31/140
# 5/5 [==============================] - 0s 85ms/step - loss: 0.2321 - accuracy: 0.9254 - val_loss: 0.2065 - val_accuracy: 0.9219
# Epoch 32/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.2227 - accuracy: 0.9273 - val_loss: 0.1938 - val_accuracy: 0.9156
# Epoch 33/140
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2367 - accuracy: 0.9219 - val_loss: 0.2604 - val_accuracy: 0.9187
# Epoch 34/140
# 5/5 [==============================] - 1s 111ms/step - loss: 0.2383 - accuracy: 0.9191 - val_loss: 0.1985 - val_accuracy: 0.9297
# Epoch 35/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.2252 - accuracy: 0.9215 - val_loss: 0.2120 - val_accuracy: 0.9234
# Epoch 36/140
# 5/5 [==============================] - 1s 107ms/step - loss: 0.2217 - accuracy: 0.9277 - val_loss: 0.1988 - val_accuracy: 0.9203
# Epoch 37/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.2250 - accuracy: 0.9277 - val_loss: 0.1866 - val_accuracy: 0.9344
# Epoch 38/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2114 - accuracy: 0.9285 - val_loss: 0.1877 - val_accuracy: 0.9281
# Epoch 39/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.2042 - accuracy: 0.9320 - val_loss: 0.1791 - val_accuracy: 0.9297
# Epoch 40/140
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2022 - accuracy: 0.9355 - val_loss: 0.1797 - val_accuracy: 0.9344
# Epoch 41/140
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2072 - accuracy: 0.9348 - val_loss: 0.1747 - val_accuracy: 0.9328
# Epoch 42/140
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1978 - accuracy: 0.9309 - val_loss: 0.1811 - val_accuracy: 0.9359
# Epoch 43/140
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1955 - accuracy: 0.9348 - val_loss: 0.1687 - val_accuracy: 0.9422
# Epoch 44/140
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1845 - accuracy: 0.9387 - val_loss: 0.1661 - val_accuracy: 0.9359
# Epoch 45/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1780 - accuracy: 0.9418 - val_loss: 0.1758 - val_accuracy: 0.9375
# Epoch 46/140
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1908 - accuracy: 0.9352 - val_loss: 0.1747 - val_accuracy: 0.9312
# Epoch 47/140
# 5/5 [==============================] - 1s 102ms/step - loss: 0.1824 - accuracy: 0.9359 - val_loss: 0.1984 - val_accuracy: 0.9281
# Epoch 48/140
# 5/5 [==============================] - 1s 111ms/step - loss: 0.2208 - accuracy: 0.9219 - val_loss: 0.1760 - val_accuracy: 0.9375
# Epoch 49/140
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1983 - accuracy: 0.9328 - val_loss: 0.1701 - val_accuracy: 0.9312
# Epoch 50/140
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1890 - accuracy: 0.9348 - val_loss: 0.1608 - val_accuracy: 0.9500
# Epoch 51/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1821 - accuracy: 0.9387 - val_loss: 0.1740 - val_accuracy: 0.9375
# Epoch 52/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1964 - accuracy: 0.9297 - val_loss: 0.1963 - val_accuracy: 0.9359
# Epoch 53/140
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1983 - accuracy: 0.9359 - val_loss: 0.1929 - val_accuracy: 0.9391
# Epoch 54/140
# 5/5 [==============================] - 1s 119ms/step - loss: 0.1861 - accuracy: 0.9367 - val_loss: 0.1742 - val_accuracy: 0.9344
# Epoch 55/140
# 5/5 [==============================] - 1s 167ms/step - loss: 0.2034 - accuracy: 0.9316 - val_loss: 0.1550 - val_accuracy: 0.9484
# Epoch 56/140
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1927 - accuracy: 0.9367 - val_loss: 0.1599 - val_accuracy: 0.9406
# Epoch 57/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.1852 - accuracy: 0.9355 - val_loss: 0.1560 - val_accuracy: 0.9453
# Epoch 58/140
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1641 - accuracy: 0.9426 - val_loss: 0.1647 - val_accuracy: 0.9344
# Epoch 59/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1744 - accuracy: 0.9387 - val_loss: 0.1500 - val_accuracy: 0.9500
# Epoch 60/140
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1632 - accuracy: 0.9441 - val_loss: 0.1494 - val_accuracy: 0.9391
# Epoch 61/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1625 - accuracy: 0.9438 - val_loss: 0.1603 - val_accuracy: 0.9438
# Epoch 62/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.1735 - accuracy: 0.9410 - val_loss: 0.1657 - val_accuracy: 0.9531
# Epoch 63/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1695 - accuracy: 0.9398 - val_loss: 0.1479 - val_accuracy: 0.9484
# Epoch 64/140
# 5/5 [==============================] - 1s 111ms/step - loss: 0.1621 - accuracy: 0.9465 - val_loss: 0.1408 - val_accuracy: 0.9500
# Epoch 65/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1577 - accuracy: 0.9465 - val_loss: 0.1501 - val_accuracy: 0.9406
# Epoch 66/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1412 - accuracy: 0.9508 - val_loss: 0.1625 - val_accuracy: 0.9359
# Epoch 67/140
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1654 - accuracy: 0.9406 - val_loss: 0.1528 - val_accuracy: 0.9563
# Epoch 68/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1575 - accuracy: 0.9469 - val_loss: 0.1414 - val_accuracy: 0.9391
# Epoch 69/140
# 5/5 [==============================] - 1s 107ms/step - loss: 0.1480 - accuracy: 0.9469 - val_loss: 0.1600 - val_accuracy: 0.9344
# Epoch 70/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1470 - accuracy: 0.9492 - val_loss: 0.1446 - val_accuracy: 0.9484
# Epoch 71/140
# 5/5 [==============================] - 1s 105ms/step - loss: 0.1372 - accuracy: 0.9523 - val_loss: 0.1379 - val_accuracy: 0.9547
# Epoch 72/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1408 - accuracy: 0.9527 - val_loss: 0.1266 - val_accuracy: 0.9531
# Epoch 73/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1424 - accuracy: 0.9527 - val_loss: 0.1419 - val_accuracy: 0.9453
# Epoch 74/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1450 - accuracy: 0.9531 - val_loss: 0.1400 - val_accuracy: 0.9484
# Epoch 75/140
# 5/5 [==============================] - 0s 99ms/step - loss: 0.1231 - accuracy: 0.9551 - val_loss: 0.1322 - val_accuracy: 0.9547
# Epoch 76/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1329 - accuracy: 0.9531 - val_loss: 0.1245 - val_accuracy: 0.9484
# Epoch 77/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1312 - accuracy: 0.9543 - val_loss: 0.1283 - val_accuracy: 0.9500
# Epoch 78/140
# 5/5 [==============================] - 1s 112ms/step - loss: 0.1296 - accuracy: 0.9543 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 79/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1384 - accuracy: 0.9516 - val_loss: 0.1548 - val_accuracy: 0.9422
# Epoch 80/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.1389 - accuracy: 0.9547 - val_loss: 0.1392 - val_accuracy: 0.9469
# Epoch 81/140
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1301 - accuracy: 0.9527 - val_loss: 0.1262 - val_accuracy: 0.9594
# Epoch 82/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1325 - accuracy: 0.9543 - val_loss: 0.1225 - val_accuracy: 0.9547
# Epoch 83/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1187 - accuracy: 0.9559 - val_loss: 0.1214 - val_accuracy: 0.9594
# Epoch 84/140
# 5/5 [==============================] - 0s 97ms/step - loss: 0.1202 - accuracy: 0.9566 - val_loss: 0.1213 - val_accuracy: 0.9594
# Epoch 85/140
# 5/5 [==============================] - 1s 104ms/step - loss: 0.1278 - accuracy: 0.9520 - val_loss: 0.1855 - val_accuracy: 0.9484
# Epoch 86/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.1440 - accuracy: 0.9488 - val_loss: 0.1251 - val_accuracy: 0.9516
# Epoch 87/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.1391 - accuracy: 0.9492 - val_loss: 0.1280 - val_accuracy: 0.9625
# Epoch 88/140
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1389 - accuracy: 0.9500 - val_loss: 0.1385 - val_accuracy: 0.9547
# Epoch 89/140
# 5/5 [==============================] - 1s 100ms/step - loss: 0.1330 - accuracy: 0.9531 - val_loss: 0.1291 - val_accuracy: 0.9531
# Epoch 90/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1202 - accuracy: 0.9559 - val_loss: 0.1183 - val_accuracy: 0.9594
# Epoch 91/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1114 - accuracy: 0.9598 - val_loss: 0.1275 - val_accuracy: 0.9516
# Epoch 92/140
# 5/5 [==============================] - 1s 103ms/step - loss: 0.1210 - accuracy: 0.9574 - val_loss: 0.1466 - val_accuracy: 0.9500
# Epoch 93/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.1277 - accuracy: 0.9582 - val_loss: 0.1423 - val_accuracy: 0.9531
# Epoch 94/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1192 - accuracy: 0.9617 - val_loss: 0.1139 - val_accuracy: 0.9578
# Epoch 95/140
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1114 - accuracy: 0.9590 - val_loss: 0.1160 - val_accuracy: 0.9547
# Epoch 96/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0984 - accuracy: 0.9672 - val_loss: 0.1164 - val_accuracy: 0.9594
# Epoch 97/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.1054 - accuracy: 0.9652 - val_loss: 0.1012 - val_accuracy: 0.9625
# Epoch 98/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.1082 - accuracy: 0.9609 - val_loss: 0.1242 - val_accuracy: 0.9594
# Epoch 99/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1155 - accuracy: 0.9590 - val_loss: 0.1363 - val_accuracy: 0.9469
# Epoch 100/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.1289 - accuracy: 0.9582 - val_loss: 0.1267 - val_accuracy: 0.9594
# Epoch 101/140
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1109 - accuracy: 0.9625 - val_loss: 0.1108 - val_accuracy: 0.9578
# Epoch 102/140
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1159 - accuracy: 0.9617 - val_loss: 0.1106 - val_accuracy: 0.9594
# Epoch 103/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0972 - accuracy: 0.9660 - val_loss: 0.1147 - val_accuracy: 0.9625
# Epoch 104/140
# 5/5 [==============================] - 1s 109ms/step - loss: 0.1119 - accuracy: 0.9594 - val_loss: 0.1070 - val_accuracy: 0.9609
# Epoch 105/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.1074 - accuracy: 0.9582 - val_loss: 0.1257 - val_accuracy: 0.9609
# Epoch 106/140
# 5/5 [==============================] - 0s 96ms/step - loss: 0.1026 - accuracy: 0.9691 - val_loss: 0.1020 - val_accuracy: 0.9656
# Epoch 107/140
# 5/5 [==============================] - 1s 101ms/step - loss: 0.0936 - accuracy: 0.9676 - val_loss: 0.1204 - val_accuracy: 0.9578
# Epoch 108/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0928 - accuracy: 0.9711 - val_loss: 0.1047 - val_accuracy: 0.9625
# Epoch 109/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0905 - accuracy: 0.9691 - val_loss: 0.0996 - val_accuracy: 0.9641
# Epoch 110/140
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0964 - accuracy: 0.9676 - val_loss: 0.1042 - val_accuracy: 0.9625
# Epoch 111/140
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0890 - accuracy: 0.9703 - val_loss: 0.1000 - val_accuracy: 0.9641
# Epoch 112/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0839 - accuracy: 0.9738 - val_loss: 0.0985 - val_accuracy: 0.9656
# Epoch 113/140
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0890 - accuracy: 0.9695 - val_loss: 0.1047 - val_accuracy: 0.9641
# Epoch 114/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0914 - accuracy: 0.9680 - val_loss: 0.0999 - val_accuracy: 0.9656
# Epoch 115/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0957 - accuracy: 0.9664 - val_loss: 0.1109 - val_accuracy: 0.9641
# Epoch 116/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0945 - accuracy: 0.9707 - val_loss: 0.0906 - val_accuracy: 0.9641
# Epoch 117/140
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0927 - accuracy: 0.9684 - val_loss: 0.1052 - val_accuracy: 0.9594
# Epoch 118/140
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0821 - accuracy: 0.9742 - val_loss: 0.0959 - val_accuracy: 0.9672
# Epoch 119/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.1007 - val_accuracy: 0.9641
# Epoch 120/140
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0855 - accuracy: 0.9680 - val_loss: 0.0922 - val_accuracy: 0.9688
# Epoch 121/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0751 - accuracy: 0.9762 - val_loss: 0.0907 - val_accuracy: 0.9656
# Epoch 122/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0856 - accuracy: 0.9668 - val_loss: 0.0984 - val_accuracy: 0.9688
# Epoch 123/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0856 - accuracy: 0.9715 - val_loss: 0.0945 - val_accuracy: 0.9656
# Epoch 124/140
# 5/5 [==============================] - 1s 103ms/step - loss: 0.0789 - accuracy: 0.9777 - val_loss: 0.0934 - val_accuracy: 0.9625
# Epoch 125/140
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0789 - accuracy: 0.9758 - val_loss: 0.0926 - val_accuracy: 0.9656
# Epoch 126/140
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0775 - accuracy: 0.9738 - val_loss: 0.0949 - val_accuracy: 0.9641
# Epoch 127/140
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0781 - accuracy: 0.9734 - val_loss: 0.0885 - val_accuracy: 0.9719
# Epoch 128/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0732 - accuracy: 0.9738 - val_loss: 0.0881 - val_accuracy: 0.9672
# Epoch 129/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0635 - accuracy: 0.9801 - val_loss: 0.0955 - val_accuracy: 0.9641
# Epoch 130/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0864 - accuracy: 0.9715 - val_loss: 0.1024 - val_accuracy: 0.9641
# Epoch 131/140
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0977 - accuracy: 0.9633 - val_loss: 0.1058 - val_accuracy: 0.9672
# Epoch 132/140
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0929 - accuracy: 0.9707 - val_loss: 0.0875 - val_accuracy: 0.9625
# Epoch 133/140
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0790 - accuracy: 0.9750 - val_loss: 0.1073 - val_accuracy: 0.9641
# Epoch 134/140
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0837 - accuracy: 0.9730 - val_loss: 0.1009 - val_accuracy: 0.9625
# Epoch 135/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0927 - accuracy: 0.9664 - val_loss: 0.0971 - val_accuracy: 0.9656
# Epoch 136/140
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0802 - accuracy: 0.9734 - val_loss: 0.0948 - val_accuracy: 0.9641
# Epoch 137/140
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0859 - accuracy: 0.9691 - val_loss: 0.0867 - val_accuracy: 0.9688
# Epoch 138/140
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0782 - accuracy: 0.9754 - val_loss: 0.0878 - val_accuracy: 0.9625
# Epoch 139/140
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0724 - accuracy: 0.9742 - val_loss: 0.0962 - val_accuracy: 0.9656
# Epoch 140/140
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0730 - accuracy: 0.9738 - val_loss: 0.0991 - val_accuracy: 0.9641

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 1s 8ms/step - loss: 0.0670 - accuracy: 0.9758
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0991 - accuracy: 0.9641
# 0.975781261920929 0.964062511920929

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 424, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:07:53

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 120   0   0   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 196   5   0   1   2]
#  [  0   0   0   0   0 100   0   0   0]
#  [  0   0   0   0   0   0   6   0   0]
#  [  0   0   0   0   2   4   0  13   1]
#  [  0   0   0   0   4   4   0   0  12]]
#
# Accuracy Score
# 0.9640625
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      1.00      1.00       120
#       water       1.00      1.00      1.00        10
#       built       0.97      0.96      0.97       204
#     windows       0.88      1.00      0.94       100
#       roads       1.00      1.00      1.00         6
#        cars       0.93      0.65      0.76        20
#       metal       0.80      0.60      0.69        20
#
# avg / total       0.96      0.96      0.96       640

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 424)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 424)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 424)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 424) (80, 424)
# clouds  (400, 424) (100, 424)
# vegetation  (488, 424) (122, 424)
# built  (960, 424) (240, 424)
# windows  (400, 424) (100, 424)
# roads  (48, 424) (12, 424)
# cars  (44, 424) (11, 424)
# metal  (184, 424) (46, 424)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 424) (2844,) (2844, 2)
# (711, 424) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 1s 134ms/step - loss: 1.6022 - accuracy: 0.4402 - val_loss: 1.1304 - val_accuracy: 0.5893
# Epoch 2/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.9951 - accuracy: 0.6610 - val_loss: 0.8598 - val_accuracy: 0.6878
# Epoch 3/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.7598 - accuracy: 0.7075 - val_loss: 0.6807 - val_accuracy: 0.7103
# Epoch 4/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.6605 - accuracy: 0.7321 - val_loss: 0.7043 - val_accuracy: 0.7229
# Epoch 5/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.6006 - accuracy: 0.7479 - val_loss: 0.6425 - val_accuracy: 0.7454
# Epoch 6/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.5578 - accuracy: 0.7693 - val_loss: 0.5897 - val_accuracy: 0.7806
# Epoch 7/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5134 - accuracy: 0.7957 - val_loss: 0.5475 - val_accuracy: 0.7848
# Epoch 8/200
# 6/6 [==============================] - 1s 184ms/step - loss: 0.4755 - accuracy: 0.8115 - val_loss: 0.5188 - val_accuracy: 0.8017
# Epoch 9/200
# 6/6 [==============================] - 1s 88ms/step - loss: 0.4434 - accuracy: 0.8312 - val_loss: 0.5627 - val_accuracy: 0.8031
# Epoch 10/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.4472 - accuracy: 0.8238 - val_loss: 0.5216 - val_accuracy: 0.7609
# Epoch 11/200
# 6/6 [==============================] - 1s 115ms/step - loss: 0.4329 - accuracy: 0.8231 - val_loss: 0.4705 - val_accuracy: 0.8200
# Epoch 12/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.4050 - accuracy: 0.8492 - val_loss: 0.4595 - val_accuracy: 0.8228
# Epoch 13/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.3939 - accuracy: 0.8492 - val_loss: 0.4499 - val_accuracy: 0.8326
# Epoch 14/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.3794 - accuracy: 0.8579 - val_loss: 0.4255 - val_accuracy: 0.8368
# Epoch 15/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3653 - accuracy: 0.8611 - val_loss: 0.4282 - val_accuracy: 0.8481
# Epoch 16/200
# 6/6 [==============================] - 1s 88ms/step - loss: 0.3678 - accuracy: 0.8615 - val_loss: 0.4103 - val_accuracy: 0.8594
# Epoch 17/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.3448 - accuracy: 0.8724 - val_loss: 0.4008 - val_accuracy: 0.8537
# Epoch 18/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.3499 - accuracy: 0.8717 - val_loss: 0.4221 - val_accuracy: 0.8495
# Epoch 19/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3402 - accuracy: 0.8752 - val_loss: 0.3896 - val_accuracy: 0.8565
# Epoch 20/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.3296 - accuracy: 0.8769 - val_loss: 0.3802 - val_accuracy: 0.8692
# Epoch 21/200
# 6/6 [==============================] - 1s 114ms/step - loss: 0.3181 - accuracy: 0.8882 - val_loss: 0.3750 - val_accuracy: 0.8594
# Epoch 22/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.3230 - accuracy: 0.8797 - val_loss: 0.3883 - val_accuracy: 0.8636
# Epoch 23/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.3076 - accuracy: 0.8910 - val_loss: 0.3665 - val_accuracy: 0.8678
# Epoch 24/200
# 6/6 [==============================] - 1s 109ms/step - loss: 0.2918 - accuracy: 0.8931 - val_loss: 0.3540 - val_accuracy: 0.8748
# Epoch 25/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.3098 - accuracy: 0.8871 - val_loss: 0.4301 - val_accuracy: 0.8523
# Epoch 26/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3582 - accuracy: 0.8590 - val_loss: 0.4003 - val_accuracy: 0.8579
# Epoch 27/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.3464 - accuracy: 0.8622 - val_loss: 0.4360 - val_accuracy: 0.8101
# Epoch 28/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3350 - accuracy: 0.8703 - val_loss: 0.3749 - val_accuracy: 0.8622
# Epoch 29/200
# 6/6 [==============================] - 1s 113ms/step - loss: 0.3057 - accuracy: 0.8875 - val_loss: 0.3507 - val_accuracy: 0.8790
# Epoch 30/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.2881 - accuracy: 0.8938 - val_loss: 0.3561 - val_accuracy: 0.8748
# Epoch 31/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2835 - accuracy: 0.8977 - val_loss: 0.3805 - val_accuracy: 0.8664
# Epoch 32/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2817 - accuracy: 0.8963 - val_loss: 0.3462 - val_accuracy: 0.8776
# Epoch 33/200
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2866 - accuracy: 0.8952 - val_loss: 0.3651 - val_accuracy: 0.8636
# Epoch 34/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2851 - accuracy: 0.8970 - val_loss: 0.3520 - val_accuracy: 0.8748
# Epoch 35/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2936 - accuracy: 0.8892 - val_loss: 0.3386 - val_accuracy: 0.8776
# Epoch 36/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2827 - accuracy: 0.8931 - val_loss: 0.3589 - val_accuracy: 0.8692
# Epoch 37/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.2798 - accuracy: 0.8949 - val_loss: 0.3469 - val_accuracy: 0.8678
# Epoch 38/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2862 - accuracy: 0.8882 - val_loss: 0.3507 - val_accuracy: 0.8678
# Epoch 39/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2817 - accuracy: 0.8882 - val_loss: 0.3152 - val_accuracy: 0.8931
# Epoch 40/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2624 - accuracy: 0.9065 - val_loss: 0.3323 - val_accuracy: 0.8734
# Epoch 41/200
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2591 - accuracy: 0.9023 - val_loss: 0.3230 - val_accuracy: 0.8776
# Epoch 42/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2442 - accuracy: 0.9110 - val_loss: 0.3188 - val_accuracy: 0.8875
# Epoch 43/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.2432 - accuracy: 0.9121 - val_loss: 0.3194 - val_accuracy: 0.8861
# Epoch 44/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.2403 - accuracy: 0.9075 - val_loss: 0.3106 - val_accuracy: 0.8917
# Epoch 45/200
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2629 - accuracy: 0.8984 - val_loss: 0.3435 - val_accuracy: 0.8734
# Epoch 46/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2606 - accuracy: 0.9023 - val_loss: 0.3538 - val_accuracy: 0.8706
# Epoch 47/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.2556 - accuracy: 0.9047 - val_loss: 0.3223 - val_accuracy: 0.8875
# Epoch 48/200
# 6/6 [==============================] - 1s 106ms/step - loss: 0.2438 - accuracy: 0.9107 - val_loss: 0.3062 - val_accuracy: 0.8861
# Epoch 49/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2408 - accuracy: 0.9114 - val_loss: 0.2924 - val_accuracy: 0.9001
# Epoch 50/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2459 - accuracy: 0.9047 - val_loss: 0.3159 - val_accuracy: 0.8917
# Epoch 51/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2369 - accuracy: 0.9132 - val_loss: 0.2964 - val_accuracy: 0.8987
# Epoch 52/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.2180 - accuracy: 0.9209 - val_loss: 0.2908 - val_accuracy: 0.9030
# Epoch 53/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.2229 - accuracy: 0.9149 - val_loss: 0.3007 - val_accuracy: 0.8847
# Epoch 54/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.2203 - accuracy: 0.9202 - val_loss: 0.2807 - val_accuracy: 0.9058
# Epoch 55/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.2175 - accuracy: 0.9230 - val_loss: 0.2818 - val_accuracy: 0.9001
# Epoch 56/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.2150 - accuracy: 0.9226 - val_loss: 0.2831 - val_accuracy: 0.8945
# Epoch 57/200
# 6/6 [==============================] - 1s 110ms/step - loss: 0.2268 - accuracy: 0.9146 - val_loss: 0.2915 - val_accuracy: 0.8945
# Epoch 58/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.2102 - accuracy: 0.9223 - val_loss: 0.3042 - val_accuracy: 0.8931
# Epoch 59/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2128 - accuracy: 0.9174 - val_loss: 0.2885 - val_accuracy: 0.8973
# Epoch 60/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.2196 - accuracy: 0.9191 - val_loss: 0.3071 - val_accuracy: 0.8875
# Epoch 61/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.2131 - accuracy: 0.9226 - val_loss: 0.2949 - val_accuracy: 0.8875
# Epoch 62/200
# 6/6 [==============================] - 1s 86ms/step - loss: 0.2181 - accuracy: 0.9212 - val_loss: 0.2748 - val_accuracy: 0.9044
# Epoch 63/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1995 - accuracy: 0.9279 - val_loss: 0.2635 - val_accuracy: 0.9044
# Epoch 64/200
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2010 - accuracy: 0.9262 - val_loss: 0.3162 - val_accuracy: 0.8847
# Epoch 65/200
# 6/6 [==============================] - 1s 110ms/step - loss: 0.1990 - accuracy: 0.9279 - val_loss: 0.2664 - val_accuracy: 0.9142
# Epoch 66/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2031 - accuracy: 0.9258 - val_loss: 0.2853 - val_accuracy: 0.9044
# Epoch 67/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2086 - accuracy: 0.9237 - val_loss: 0.2816 - val_accuracy: 0.9015
# Epoch 68/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2084 - accuracy: 0.9251 - val_loss: 0.2930 - val_accuracy: 0.8931
# Epoch 69/200
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1970 - accuracy: 0.9251 - val_loss: 0.2701 - val_accuracy: 0.9114
# Epoch 70/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1911 - accuracy: 0.9297 - val_loss: 0.2625 - val_accuracy: 0.9058
# Epoch 71/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1857 - accuracy: 0.9335 - val_loss: 0.2569 - val_accuracy: 0.9072
# Epoch 72/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.1797 - accuracy: 0.9325 - val_loss: 0.2517 - val_accuracy: 0.9212
# Epoch 73/200
# 6/6 [==============================] - 1s 118ms/step - loss: 0.1894 - accuracy: 0.9328 - val_loss: 0.2626 - val_accuracy: 0.9030
# Epoch 74/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.1907 - accuracy: 0.9304 - val_loss: 0.2801 - val_accuracy: 0.8903
# Epoch 75/200
# 6/6 [==============================] - 1s 104ms/step - loss: 0.1900 - accuracy: 0.9272 - val_loss: 0.2585 - val_accuracy: 0.9128
# Epoch 76/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.1839 - accuracy: 0.9286 - val_loss: 0.2681 - val_accuracy: 0.9072
# Epoch 77/200
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1689 - accuracy: 0.9378 - val_loss: 0.2731 - val_accuracy: 0.9044
# Epoch 78/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1835 - accuracy: 0.9321 - val_loss: 0.2544 - val_accuracy: 0.9128
# Epoch 79/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1805 - accuracy: 0.9332 - val_loss: 0.2551 - val_accuracy: 0.9100
# Epoch 80/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1765 - accuracy: 0.9304 - val_loss: 0.2484 - val_accuracy: 0.9156
# Epoch 81/200
# 6/6 [==============================] - 1s 110ms/step - loss: 0.1767 - accuracy: 0.9342 - val_loss: 0.3119 - val_accuracy: 0.8889
# Epoch 82/200
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1922 - accuracy: 0.9262 - val_loss: 0.3258 - val_accuracy: 0.8790
# Epoch 83/200
# 6/6 [==============================] - 1s 113ms/step - loss: 0.2790 - accuracy: 0.8984 - val_loss: 0.3015 - val_accuracy: 0.8987
# Epoch 84/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2142 - accuracy: 0.9163 - val_loss: 0.3030 - val_accuracy: 0.8917
# Epoch 85/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2127 - accuracy: 0.9233 - val_loss: 0.2890 - val_accuracy: 0.8903
# Epoch 86/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1941 - accuracy: 0.9290 - val_loss: 0.2524 - val_accuracy: 0.9184
# Epoch 87/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1912 - accuracy: 0.9321 - val_loss: 0.2656 - val_accuracy: 0.8959
# Epoch 88/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1905 - accuracy: 0.9314 - val_loss: 0.2499 - val_accuracy: 0.9072
# Epoch 89/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.1736 - accuracy: 0.9325 - val_loss: 0.2681 - val_accuracy: 0.9086
# Epoch 90/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1735 - accuracy: 0.9381 - val_loss: 0.2691 - val_accuracy: 0.9058
# Epoch 91/200
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1829 - accuracy: 0.9286 - val_loss: 0.2586 - val_accuracy: 0.9156
# Epoch 92/200
# 6/6 [==============================] - 1s 109ms/step - loss: 0.1795 - accuracy: 0.9332 - val_loss: 0.2521 - val_accuracy: 0.9100
# Epoch 93/200
# 6/6 [==============================] - 1s 111ms/step - loss: 0.1702 - accuracy: 0.9357 - val_loss: 0.2483 - val_accuracy: 0.9128
# Epoch 94/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.1631 - accuracy: 0.9388 - val_loss: 0.2564 - val_accuracy: 0.9128
# Epoch 95/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1745 - accuracy: 0.9374 - val_loss: 0.2400 - val_accuracy: 0.9142
# Epoch 96/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.1633 - accuracy: 0.9399 - val_loss: 0.2295 - val_accuracy: 0.9311
# Epoch 97/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1483 - accuracy: 0.9490 - val_loss: 0.2375 - val_accuracy: 0.9212
# Epoch 98/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1505 - accuracy: 0.9462 - val_loss: 0.2724 - val_accuracy: 0.9072
# Epoch 99/200
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1593 - accuracy: 0.9409 - val_loss: 0.2425 - val_accuracy: 0.9184
# Epoch 100/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.1467 - accuracy: 0.9466 - val_loss: 0.2470 - val_accuracy: 0.9156
# Epoch 101/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.1437 - accuracy: 0.9459 - val_loss: 0.2431 - val_accuracy: 0.9156
# Epoch 102/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1472 - accuracy: 0.9455 - val_loss: 0.2314 - val_accuracy: 0.9255
# Epoch 103/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1369 - accuracy: 0.9476 - val_loss: 0.2196 - val_accuracy: 0.9311
# Epoch 104/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1384 - accuracy: 0.9511 - val_loss: 0.2188 - val_accuracy: 0.9339
# Epoch 105/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1386 - accuracy: 0.9497 - val_loss: 0.2186 - val_accuracy: 0.9241
# Epoch 106/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1402 - accuracy: 0.9459 - val_loss: 0.2361 - val_accuracy: 0.9156
# Epoch 107/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1398 - accuracy: 0.9525 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 108/200
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1313 - accuracy: 0.9494 - val_loss: 0.2343 - val_accuracy: 0.9226
# Epoch 109/200
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1429 - accuracy: 0.9451 - val_loss: 0.2451 - val_accuracy: 0.9142
# Epoch 110/200
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1377 - accuracy: 0.9487 - val_loss: 0.2121 - val_accuracy: 0.9339
# Epoch 111/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1382 - accuracy: 0.9494 - val_loss: 0.2225 - val_accuracy: 0.9255
# Epoch 112/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.1344 - accuracy: 0.9525 - val_loss: 0.2477 - val_accuracy: 0.9170
# Epoch 113/200
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1315 - accuracy: 0.9494 - val_loss: 0.2155 - val_accuracy: 0.9353
# Epoch 114/200
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1309 - accuracy: 0.9501 - val_loss: 0.2193 - val_accuracy: 0.9241
# Epoch 115/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1267 - accuracy: 0.9518 - val_loss: 0.2431 - val_accuracy: 0.9212
# Epoch 116/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1567 - accuracy: 0.9416 - val_loss: 0.2149 - val_accuracy: 0.9269
# Epoch 117/200
# 6/6 [==============================] - 1s 109ms/step - loss: 0.1284 - accuracy: 0.9490 - val_loss: 0.2423 - val_accuracy: 0.9198
# Epoch 118/200
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1360 - accuracy: 0.9522 - val_loss: 0.2279 - val_accuracy: 0.9283
# Epoch 119/200
# 6/6 [==============================] - 1s 109ms/step - loss: 0.1407 - accuracy: 0.9504 - val_loss: 0.2042 - val_accuracy: 0.9367
# Epoch 120/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1311 - accuracy: 0.9487 - val_loss: 0.2079 - val_accuracy: 0.9339
# Epoch 121/200
# 6/6 [==============================] - 1s 115ms/step - loss: 0.1241 - accuracy: 0.9571 - val_loss: 0.1975 - val_accuracy: 0.9409
# Epoch 122/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1273 - accuracy: 0.9518 - val_loss: 0.2120 - val_accuracy: 0.9311
# Epoch 123/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.1261 - accuracy: 0.9490 - val_loss: 0.2023 - val_accuracy: 0.9367
# Epoch 124/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1157 - accuracy: 0.9585 - val_loss: 0.1968 - val_accuracy: 0.9395
# Epoch 125/200
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1196 - accuracy: 0.9599 - val_loss: 0.2080 - val_accuracy: 0.9395
# Epoch 126/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1179 - accuracy: 0.9560 - val_loss: 0.2370 - val_accuracy: 0.9226
# Epoch 127/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1239 - accuracy: 0.9525 - val_loss: 0.2011 - val_accuracy: 0.9395
# Epoch 128/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.1171 - accuracy: 0.9522 - val_loss: 0.2268 - val_accuracy: 0.9226
# Epoch 129/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1378 - accuracy: 0.9490 - val_loss: 0.2450 - val_accuracy: 0.9198
# Epoch 130/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1356 - accuracy: 0.9476 - val_loss: 0.2167 - val_accuracy: 0.9269
# Epoch 131/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1288 - accuracy: 0.9550 - val_loss: 0.1977 - val_accuracy: 0.9367
# Epoch 132/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.1224 - accuracy: 0.9518 - val_loss: 0.2109 - val_accuracy: 0.9297
# Epoch 133/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1113 - accuracy: 0.9578 - val_loss: 0.1989 - val_accuracy: 0.9325
# Epoch 134/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1067 - accuracy: 0.9606 - val_loss: 0.1942 - val_accuracy: 0.9339
# Epoch 135/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1050 - accuracy: 0.9620 - val_loss: 0.2218 - val_accuracy: 0.9311
# Epoch 136/200
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1053 - accuracy: 0.9624 - val_loss: 0.2006 - val_accuracy: 0.9409
# Epoch 137/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0956 - accuracy: 0.9666 - val_loss: 0.2012 - val_accuracy: 0.9353
# Epoch 138/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0983 - accuracy: 0.9617 - val_loss: 0.1882 - val_accuracy: 0.9409
# Epoch 139/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0896 - accuracy: 0.9691 - val_loss: 0.1862 - val_accuracy: 0.9395
# Epoch 140/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0875 - accuracy: 0.9708 - val_loss: 0.1951 - val_accuracy: 0.9451
# Epoch 141/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.0975 - accuracy: 0.9655 - val_loss: 0.2068 - val_accuracy: 0.9381
# Epoch 142/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.1097 - accuracy: 0.9575 - val_loss: 0.2013 - val_accuracy: 0.9339
# Epoch 143/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.1160 - accuracy: 0.9553 - val_loss: 0.2283 - val_accuracy: 0.9212
# Epoch 144/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1219 - accuracy: 0.9515 - val_loss: 0.2123 - val_accuracy: 0.9395
# Epoch 145/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1108 - accuracy: 0.9575 - val_loss: 0.2088 - val_accuracy: 0.9311
# Epoch 146/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.1014 - accuracy: 0.9620 - val_loss: 0.2041 - val_accuracy: 0.9409
# Epoch 147/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1058 - accuracy: 0.9627 - val_loss: 0.1999 - val_accuracy: 0.9423
# Epoch 148/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1077 - accuracy: 0.9560 - val_loss: 0.2040 - val_accuracy: 0.9381
# Epoch 149/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0974 - accuracy: 0.9655 - val_loss: 0.2034 - val_accuracy: 0.9381
# Epoch 150/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.0971 - accuracy: 0.9666 - val_loss: 0.2012 - val_accuracy: 0.9437
# Epoch 151/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0964 - accuracy: 0.9641 - val_loss: 0.1868 - val_accuracy: 0.9466
# Epoch 152/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0832 - accuracy: 0.9715 - val_loss: 0.2153 - val_accuracy: 0.9395
# Epoch 153/200
# 6/6 [==============================] - 1s 109ms/step - loss: 0.1222 - accuracy: 0.9550 - val_loss: 0.2277 - val_accuracy: 0.9269
# Epoch 154/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0964 - accuracy: 0.9662 - val_loss: 0.2065 - val_accuracy: 0.9409
# Epoch 155/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0942 - accuracy: 0.9659 - val_loss: 0.1976 - val_accuracy: 0.9451
# Epoch 156/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0860 - accuracy: 0.9673 - val_loss: 0.1962 - val_accuracy: 0.9409
# Epoch 157/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0841 - accuracy: 0.9687 - val_loss: 0.1997 - val_accuracy: 0.9395
# Epoch 158/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0970 - accuracy: 0.9634 - val_loss: 0.2229 - val_accuracy: 0.9283
# Epoch 159/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0919 - accuracy: 0.9669 - val_loss: 0.2282 - val_accuracy: 0.9339
# Epoch 160/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0934 - accuracy: 0.9631 - val_loss: 0.1988 - val_accuracy: 0.9367
# Epoch 161/200
# 6/6 [==============================] - 1s 96ms/step - loss: 0.0958 - accuracy: 0.9652 - val_loss: 0.1785 - val_accuracy: 0.9494
# Epoch 162/200
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0818 - accuracy: 0.9691 - val_loss: 0.1965 - val_accuracy: 0.9409
# Epoch 163/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0787 - accuracy: 0.9729 - val_loss: 0.1861 - val_accuracy: 0.9451
# Epoch 164/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0881 - accuracy: 0.9669 - val_loss: 0.2104 - val_accuracy: 0.9367
# Epoch 165/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0855 - accuracy: 0.9627 - val_loss: 0.1916 - val_accuracy: 0.9480
# Epoch 166/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0816 - accuracy: 0.9708 - val_loss: 0.1942 - val_accuracy: 0.9381
# Epoch 167/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0845 - accuracy: 0.9673 - val_loss: 0.2563 - val_accuracy: 0.9212
# Epoch 168/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1077 - accuracy: 0.9617 - val_loss: 0.1886 - val_accuracy: 0.9451
# Epoch 169/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0890 - accuracy: 0.9666 - val_loss: 0.1991 - val_accuracy: 0.9367
# Epoch 170/200
# 6/6 [==============================] - 1s 101ms/step - loss: 0.0794 - accuracy: 0.9712 - val_loss: 0.1966 - val_accuracy: 0.9423
# Epoch 171/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0763 - accuracy: 0.9736 - val_loss: 0.1898 - val_accuracy: 0.9437
# Epoch 172/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0750 - accuracy: 0.9715 - val_loss: 0.2329 - val_accuracy: 0.9339
# Epoch 173/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0825 - accuracy: 0.9666 - val_loss: 0.2055 - val_accuracy: 0.9451
# Epoch 174/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0760 - accuracy: 0.9736 - val_loss: 0.1951 - val_accuracy: 0.9451
# Epoch 175/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0691 - accuracy: 0.9747 - val_loss: 0.2394 - val_accuracy: 0.9311
# Epoch 176/200
# 6/6 [==============================] - 1s 85ms/step - loss: 0.0922 - accuracy: 0.9652 - val_loss: 0.2081 - val_accuracy: 0.9395
# Epoch 177/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0928 - accuracy: 0.9645 - val_loss: 0.2172 - val_accuracy: 0.9381
# Epoch 178/200
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0973 - accuracy: 0.9648 - val_loss: 0.1846 - val_accuracy: 0.9423
# Epoch 179/200
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0729 - accuracy: 0.9761 - val_loss: 0.1792 - val_accuracy: 0.9480
# Epoch 180/200
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0719 - accuracy: 0.9750 - val_loss: 0.1911 - val_accuracy: 0.9451
# Epoch 181/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0735 - accuracy: 0.9722 - val_loss: 0.1809 - val_accuracy: 0.9466
# Epoch 182/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0647 - accuracy: 0.9775 - val_loss: 0.2109 - val_accuracy: 0.9437
# Epoch 183/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0799 - accuracy: 0.9722 - val_loss: 0.2107 - val_accuracy: 0.9395
# Epoch 184/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0759 - accuracy: 0.9726 - val_loss: 0.1916 - val_accuracy: 0.9480
# Epoch 185/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0661 - accuracy: 0.9768 - val_loss: 0.1792 - val_accuracy: 0.9480
# Epoch 186/200
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0697 - accuracy: 0.9782 - val_loss: 0.1897 - val_accuracy: 0.9550
# Epoch 187/200
# 6/6 [==============================] - 1s 92ms/step - loss: 0.0649 - accuracy: 0.9775 - val_loss: 0.2030 - val_accuracy: 0.9466
# Epoch 188/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0769 - accuracy: 0.9733 - val_loss: 0.1880 - val_accuracy: 0.9508
# Epoch 189/200
# 6/6 [==============================] - 1s 102ms/step - loss: 0.0765 - accuracy: 0.9722 - val_loss: 0.1800 - val_accuracy: 0.9466
# Epoch 190/200
# 6/6 [==============================] - 1s 107ms/step - loss: 0.0784 - accuracy: 0.9708 - val_loss: 0.1932 - val_accuracy: 0.9409
# Epoch 191/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0791 - accuracy: 0.9705 - val_loss: 0.1792 - val_accuracy: 0.9522
# Epoch 192/200
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0636 - accuracy: 0.9761 - val_loss: 0.1923 - val_accuracy: 0.9466
# Epoch 193/200
# 6/6 [==============================] - 1s 103ms/step - loss: 0.0674 - accuracy: 0.9743 - val_loss: 0.1898 - val_accuracy: 0.9409
# Epoch 194/200
# 6/6 [==============================] - 1s 86ms/step - loss: 0.0657 - accuracy: 0.9736 - val_loss: 0.1978 - val_accuracy: 0.9381
# Epoch 195/200
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0655 - accuracy: 0.9761 - val_loss: 0.1857 - val_accuracy: 0.9522
# Epoch 196/200
# 6/6 [==============================] - 1s 89ms/step - loss: 0.0700 - accuracy: 0.9761 - val_loss: 0.1775 - val_accuracy: 0.9522
# Epoch 197/200
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0614 - accuracy: 0.9778 - val_loss: 0.1742 - val_accuracy: 0.9578
# Epoch 198/200
# 6/6 [==============================] - 1s 93ms/step - loss: 0.0616 - accuracy: 0.9814 - val_loss: 0.1924 - val_accuracy: 0.9522
# Epoch 199/200
# 6/6 [==============================] - 1s 97ms/step - loss: 0.0600 - accuracy: 0.9810 - val_loss: 0.1903 - val_accuracy: 0.9494
# Epoch 200/200
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0658 - accuracy: 0.9747 - val_loss: 0.2150 - val_accuracy: 0.9522

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=100, batch_size=512)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 118ms/step - loss: 1.7546 - accuracy: 0.4177 - val_loss: 1.2051 - val_accuracy: 0.6146
# Epoch 2/100
# 6/6 [==============================] - 1s 84ms/step - loss: 1.0684 - accuracy: 0.6456 - val_loss: 0.8774 - val_accuracy: 0.6990
# Epoch 3/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7924 - accuracy: 0.7008 - val_loss: 0.7366 - val_accuracy: 0.6934
# Epoch 4/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.6735 - accuracy: 0.7331 - val_loss: 0.6611 - val_accuracy: 0.7032
# Epoch 5/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.5946 - accuracy: 0.7602 - val_loss: 0.5990 - val_accuracy: 0.7778
# Epoch 6/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.5552 - accuracy: 0.7686 - val_loss: 0.5594 - val_accuracy: 0.7750
# Epoch 7/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.5328 - accuracy: 0.7820 - val_loss: 0.5543 - val_accuracy: 0.7201
# Epoch 8/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.4890 - accuracy: 0.8052 - val_loss: 0.5345 - val_accuracy: 0.7736
# Epoch 9/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.4676 - accuracy: 0.8150 - val_loss: 0.5048 - val_accuracy: 0.7693
# Epoch 10/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.4469 - accuracy: 0.8214 - val_loss: 0.4888 - val_accuracy: 0.8270
# Epoch 11/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.4425 - accuracy: 0.8309 - val_loss: 0.4894 - val_accuracy: 0.8214
# Epoch 12/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.4245 - accuracy: 0.8435 - val_loss: 0.4766 - val_accuracy: 0.8214
# Epoch 13/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.3998 - accuracy: 0.8467 - val_loss: 0.4478 - val_accuracy: 0.8340
# Epoch 14/100
# 6/6 [==============================] - 1s 107ms/step - loss: 0.3916 - accuracy: 0.8544 - val_loss: 0.4270 - val_accuracy: 0.8368
# Epoch 15/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.3674 - accuracy: 0.8646 - val_loss: 0.4134 - val_accuracy: 0.8383
# Epoch 16/100
# 6/6 [==============================] - 1s 109ms/step - loss: 0.3637 - accuracy: 0.8618 - val_loss: 0.4376 - val_accuracy: 0.8453
# Epoch 17/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.3668 - accuracy: 0.8586 - val_loss: 0.4271 - val_accuracy: 0.8383
# Epoch 18/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.3614 - accuracy: 0.8604 - val_loss: 0.3919 - val_accuracy: 0.8537
# Epoch 19/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.3619 - accuracy: 0.8618 - val_loss: 0.4654 - val_accuracy: 0.7975
# Epoch 20/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.3837 - accuracy: 0.8506 - val_loss: 0.4217 - val_accuracy: 0.8298
# Epoch 21/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.3753 - accuracy: 0.8541 - val_loss: 0.3971 - val_accuracy: 0.8383
# Epoch 22/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.3471 - accuracy: 0.8688 - val_loss: 0.3775 - val_accuracy: 0.8636
# Epoch 23/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.3284 - accuracy: 0.8745 - val_loss: 0.3712 - val_accuracy: 0.8636
# Epoch 24/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.3243 - accuracy: 0.8815 - val_loss: 0.3655 - val_accuracy: 0.8622
# Epoch 25/100
# 6/6 [==============================] - 1s 112ms/step - loss: 0.3181 - accuracy: 0.8857 - val_loss: 0.3618 - val_accuracy: 0.8678
# Epoch 26/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3093 - accuracy: 0.8801 - val_loss: 0.3589 - val_accuracy: 0.8720
# Epoch 27/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3097 - accuracy: 0.8826 - val_loss: 0.3544 - val_accuracy: 0.8636
# Epoch 28/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2989 - accuracy: 0.8906 - val_loss: 0.3436 - val_accuracy: 0.8678
# Epoch 29/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.3056 - accuracy: 0.8889 - val_loss: 0.3730 - val_accuracy: 0.8650
# Epoch 30/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.3041 - accuracy: 0.8868 - val_loss: 0.3544 - val_accuracy: 0.8636
# Epoch 31/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.3028 - accuracy: 0.8899 - val_loss: 0.3562 - val_accuracy: 0.8537
# Epoch 32/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.2910 - accuracy: 0.8914 - val_loss: 0.3523 - val_accuracy: 0.8678
# Epoch 33/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.2907 - accuracy: 0.8875 - val_loss: 0.3461 - val_accuracy: 0.8734
# Epoch 34/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2844 - accuracy: 0.8938 - val_loss: 0.3583 - val_accuracy: 0.8664
# Epoch 35/100
# 6/6 [==============================] - 1s 115ms/step - loss: 0.2887 - accuracy: 0.8878 - val_loss: 0.3417 - val_accuracy: 0.8720
# Epoch 36/100
# 6/6 [==============================] - 1s 103ms/step - loss: 0.2813 - accuracy: 0.8987 - val_loss: 0.3398 - val_accuracy: 0.8805
# Epoch 37/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2810 - accuracy: 0.8991 - val_loss: 0.3453 - val_accuracy: 0.8678
# Epoch 38/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.2970 - accuracy: 0.8896 - val_loss: 0.3536 - val_accuracy: 0.8636
# Epoch 39/100
# 6/6 [==============================] - 1s 163ms/step - loss: 0.2870 - accuracy: 0.8910 - val_loss: 0.3491 - val_accuracy: 0.8776
# Epoch 40/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.2700 - accuracy: 0.8980 - val_loss: 0.3354 - val_accuracy: 0.8776
# Epoch 41/100
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2728 - accuracy: 0.8942 - val_loss: 0.3187 - val_accuracy: 0.8861
# Epoch 42/100
# 6/6 [==============================] - 1s 111ms/step - loss: 0.2666 - accuracy: 0.9012 - val_loss: 0.3185 - val_accuracy: 0.8833
# Epoch 43/100
# 6/6 [==============================] - 1s 107ms/step - loss: 0.2606 - accuracy: 0.9058 - val_loss: 0.3337 - val_accuracy: 0.8734
# Epoch 44/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2616 - accuracy: 0.8984 - val_loss: 0.3291 - val_accuracy: 0.8776
# Epoch 45/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.2584 - accuracy: 0.9065 - val_loss: 0.3039 - val_accuracy: 0.8903
# Epoch 46/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2497 - accuracy: 0.9117 - val_loss: 0.3103 - val_accuracy: 0.8861
# Epoch 47/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.2560 - accuracy: 0.9058 - val_loss: 0.3078 - val_accuracy: 0.8875
# Epoch 48/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.2572 - accuracy: 0.9093 - val_loss: 0.3208 - val_accuracy: 0.8861
# Epoch 49/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2561 - accuracy: 0.9044 - val_loss: 0.3028 - val_accuracy: 0.8903
# Epoch 50/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2432 - accuracy: 0.9093 - val_loss: 0.3098 - val_accuracy: 0.8861
# Epoch 51/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.2511 - accuracy: 0.9026 - val_loss: 0.3601 - val_accuracy: 0.8762
# Epoch 52/100
# 6/6 [==============================] - 1s 99ms/step - loss: 0.2555 - accuracy: 0.9044 - val_loss: 0.3202 - val_accuracy: 0.8805
# Epoch 53/100
# 6/6 [==============================] - 1s 106ms/step - loss: 0.2470 - accuracy: 0.9061 - val_loss: 0.2853 - val_accuracy: 0.9015
# Epoch 54/100
# 6/6 [==============================] - 1s 109ms/step - loss: 0.2373 - accuracy: 0.9089 - val_loss: 0.2863 - val_accuracy: 0.8931
# Epoch 55/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2296 - accuracy: 0.9160 - val_loss: 0.2818 - val_accuracy: 0.8987
# Epoch 56/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2400 - accuracy: 0.9114 - val_loss: 0.3152 - val_accuracy: 0.8917
# Epoch 57/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.2247 - accuracy: 0.9212 - val_loss: 0.3009 - val_accuracy: 0.8847
# Epoch 58/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2260 - accuracy: 0.9156 - val_loss: 0.2844 - val_accuracy: 0.8931
# Epoch 59/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2319 - accuracy: 0.9082 - val_loss: 0.2844 - val_accuracy: 0.8889
# Epoch 60/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2218 - accuracy: 0.9191 - val_loss: 0.2919 - val_accuracy: 0.8931
# Epoch 61/100
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2132 - accuracy: 0.9265 - val_loss: 0.2800 - val_accuracy: 0.8847
# Epoch 62/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2093 - accuracy: 0.9198 - val_loss: 0.2613 - val_accuracy: 0.9086
# Epoch 63/100
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2121 - accuracy: 0.9248 - val_loss: 0.2729 - val_accuracy: 0.8917
# Epoch 64/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2112 - accuracy: 0.9202 - val_loss: 0.2745 - val_accuracy: 0.9001
# Epoch 65/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2024 - accuracy: 0.9248 - val_loss: 0.2762 - val_accuracy: 0.9001
# Epoch 66/100
# 6/6 [==============================] - 1s 92ms/step - loss: 0.2036 - accuracy: 0.9230 - val_loss: 0.2470 - val_accuracy: 0.9184
# Epoch 67/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2004 - accuracy: 0.9262 - val_loss: 0.2762 - val_accuracy: 0.8973
# Epoch 68/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2033 - accuracy: 0.9237 - val_loss: 0.2708 - val_accuracy: 0.8945
# Epoch 69/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.2068 - accuracy: 0.9219 - val_loss: 0.2540 - val_accuracy: 0.9128
# Epoch 70/100
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2126 - accuracy: 0.9216 - val_loss: 0.2750 - val_accuracy: 0.8903
# Epoch 71/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2080 - accuracy: 0.9237 - val_loss: 0.2470 - val_accuracy: 0.9128
# Epoch 72/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.1952 - accuracy: 0.9279 - val_loss: 0.2465 - val_accuracy: 0.9142
# Epoch 73/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1979 - accuracy: 0.9276 - val_loss: 0.2726 - val_accuracy: 0.9001
# Epoch 74/100
# 6/6 [==============================] - 1s 108ms/step - loss: 0.2048 - accuracy: 0.9269 - val_loss: 0.2734 - val_accuracy: 0.9015
# Epoch 75/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.2013 - accuracy: 0.9276 - val_loss: 0.2316 - val_accuracy: 0.9212
# Epoch 76/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.1916 - accuracy: 0.9304 - val_loss: 0.2773 - val_accuracy: 0.8875
# Epoch 77/100
# 6/6 [==============================] - 1s 93ms/step - loss: 0.2020 - accuracy: 0.9244 - val_loss: 0.2422 - val_accuracy: 0.9142
# Epoch 78/100
# 6/6 [==============================] - 1s 104ms/step - loss: 0.1817 - accuracy: 0.9346 - val_loss: 0.2605 - val_accuracy: 0.8973
# Epoch 79/100
# 6/6 [==============================] - 1s 105ms/step - loss: 0.1879 - accuracy: 0.9339 - val_loss: 0.2557 - val_accuracy: 0.9114
# Epoch 80/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.2047 - accuracy: 0.9265 - val_loss: 0.2419 - val_accuracy: 0.9086
# Epoch 81/100
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1743 - accuracy: 0.9360 - val_loss: 0.2339 - val_accuracy: 0.9170
# Epoch 82/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.1935 - accuracy: 0.9300 - val_loss: 0.2375 - val_accuracy: 0.9142
# Epoch 83/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.1755 - accuracy: 0.9360 - val_loss: 0.2364 - val_accuracy: 0.9128
# Epoch 84/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1763 - accuracy: 0.9328 - val_loss: 0.2440 - val_accuracy: 0.9128
# Epoch 85/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1690 - accuracy: 0.9364 - val_loss: 0.2184 - val_accuracy: 0.9184
# Epoch 86/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1649 - accuracy: 0.9357 - val_loss: 0.2368 - val_accuracy: 0.9015
# Epoch 87/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1670 - accuracy: 0.9392 - val_loss: 0.2262 - val_accuracy: 0.9184
# Epoch 88/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1608 - accuracy: 0.9427 - val_loss: 0.2365 - val_accuracy: 0.9184
# Epoch 89/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1712 - accuracy: 0.9350 - val_loss: 0.2493 - val_accuracy: 0.9100
# Epoch 90/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.1791 - accuracy: 0.9371 - val_loss: 0.3570 - val_accuracy: 0.8551
# Epoch 91/100
# 6/6 [==============================] - 1s 104ms/step - loss: 0.2850 - accuracy: 0.8945 - val_loss: 0.4359 - val_accuracy: 0.8523
# Epoch 92/100
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2644 - accuracy: 0.8977 - val_loss: 0.3245 - val_accuracy: 0.8875
# Epoch 93/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2374 - accuracy: 0.9065 - val_loss: 0.2688 - val_accuracy: 0.8973
# Epoch 94/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2158 - accuracy: 0.9237 - val_loss: 0.2582 - val_accuracy: 0.9100
# Epoch 95/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1984 - accuracy: 0.9244 - val_loss: 0.2476 - val_accuracy: 0.9128
# Epoch 96/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1880 - accuracy: 0.9307 - val_loss: 0.2430 - val_accuracy: 0.9184
# Epoch 97/100
# 6/6 [==============================] - 1s 101ms/step - loss: 0.1778 - accuracy: 0.9367 - val_loss: 0.2309 - val_accuracy: 0.9212
# Epoch 98/100
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1731 - accuracy: 0.9339 - val_loss: 0.2178 - val_accuracy: 0.9269
# Epoch 99/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1692 - accuracy: 0.9381 - val_loss: 0.2230 - val_accuracy: 0.9241
# Epoch 100/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1592 - accuracy: 0.9388 - val_loss: 0.2191 - val_accuracy: 0.9255

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 1s 6ms/step - loss: 0.1213 - accuracy: 0.9536
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9255
# 0.9535865187644958 0.9254571199417114

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 424, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:07:45

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 230   6   0   0   4]
#  [  0   0   0  16  82   0   0   2]
#  [  0   0   0   0   1  11   0   0]
#  [  1   1   0   0   0   1   8   0]
#  [  0   0   0  16   2   0   0  28]]
#
# Accuracy Score
# 0.9254571026722925
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.99      1.00      0.99        80
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.87      0.96      0.91       240
#     windows       0.90      0.82      0.86       100
#       roads       0.92      0.92      0.92        12
#        cars       1.00      0.73      0.84        11
#       metal       0.82      0.61      0.70        46
#
# avg / total       0.93      0.93      0.92       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 424
# [[0, 2], [2, 4], [4, 6], [6, 8], [8, 10], [10, 12], [12, 14], [14, 16], [16, 18], [18, 20], [20, 22], [22, 24], [24, 26], [26, 28], [28, 30], [30, 32], [32, 34], [34, 36], [36, 38], [38, 40], [40, 42], [42, 44], [44, 46], [46, 48], [48, 50], [50, 52], [52, 54], [54, 56], [56, 58], [58, 60], [60, 62], [62, 64], [64, 66], [66, 68], [68, 70], [70, 72], [72, 74], [74, 76], [76, 78], [78, 80], [80, 82], [82, 84], [84, 86], [86, 88], [88, 90], [90, 92], [92, 94], [94, 96], [96, 98], [98, 100], [100, 102], [102, 104], [104, 106], [106, 108], [108, 110], [110, 112], [112, 114], [114, 116], [116, 118], [118, 120], [120, 122], [122, 124], [124, 126], [126, 128], [128, 130], [130, 132], [132, 134], [134, 136], [136, 138], [138, 140], [140, 142], [142, 144], [144, 146], [146, 148], [148, 150], [150, 152], [152, 154], [154, 156], [156, 158], [158, 160], [160, 162], [162, 164], [164, 166], [166, 168], [168, 170], [170, 172], [172, 174], [174, 176], [176, 178], [178, 180], [180, 182], [182, 184], [184, 186], [186, 188], [188, 190], [190, 192], [192, 194], [194, 196], [196, 198], [198, 200], [200, 202], [202, 204], [204, 206], [206, 208], [208, 210], [210, 212], [212, 214], [214, 216], [216, 218], [218, 220], [220, 222], [222, 224], [224, 226], [226, 228], [228, 230], [230, 232], [232, 234], [234, 236], [236, 238], [238, 240], [240, 242], [242, 244], [244, 246], [246, 248], [248, 250], [250, 252], [252, 254], [254, 256], [256, 258], [258, 260], [260, 262], [262, 264], [264, 266], [266, 268], [268, 270], [270, 272], [272, 274], [274, 276], [276, 278], [278, 280], [280, 282], [282, 284], [284, 286], [286, 288], [288, 290], [290, 292], [292, 294], [294, 296], [296, 298], [298, 300], [300, 302], [302, 304], [304, 306], [306, 308], [308, 310], [310, 312], [312, 314], [314, 316], [316, 318], [318, 320], [320, 322], [322, 324], [324, 326], [326, 328], [328, 330], [330, 332], [332, 334], [334, 336], [336, 338], [338, 340], [340, 342], [342, 344], [344, 346], [346, 348], [348, 350], [350, 352], [352, 354], [354, 356], [356, 358], [358, 360], [360, 362], [362, 364], [364, 366], [366, 368], [368, 370], [370, 372], [372, 374], [374, 376], [376, 378], [378, 380], [380, 382], [382, 384], [384, 386], [386, 388], [388, 390], [390, 392], [392, 394], [394, 396], [396, 398], [398, 400], [400, 402], [402, 404], [404, 406], [406, 408], [408, 410], [410, 412], [412, 414], [414, 416], [416, 418], [418, 420], [420, 422], [422, 424], [424, 426], [426, 428], [428, 430], [430, 432], [432, 434], [434, 436], [436, 438], [438, 440], [440, 442], [442, 444], [444, 446], [446, 448], [448, 450], [450, 452], [452, 454], [454, 456], [456, 458], [458, 460], [460, 462], [462, 464], [464, 466], [466, 468], [468, 470], [470, 472], [472, 474], [474, 476], [476, 478], [478, 480], [480, 482], [482, 484], [484, 486], [486, 488], [488, 490], [490, 492], [492, 494], [494, 496], [496, 498], [498, 500], [500, 502], [502, 504], [504, 506], [506, 508], [508, 510], [510, 512], [512, 514], [514, 516], [516, 518], [518, 520], [520, 522], [522, 524], [524, 526], [526, 528], [528, 530], [530, 532], [532, 534], [534, 536], [536, 538], [538, 540], [540, 542], [542, 544], [544, 546], [546, 548], [548, 550], [550, 552], [552, 554], [554, 556], [556, 558], [558, 560], [560, 562], [562, 564], [564, 566], [566, 568], [568, 570], [570, 572], [572, 574], [574, 576], [576, 578], [578, 580], [580, 582], [582, 584], [584, 586], [586, 588], [588, 590], [590, 592], [592, 594], [594, 596], [596, 598], [598, 600], [600, 602], [602, 604], [604, 606], [606, 608], [608, 610], [610, 612], [612, 614], [614, 616], [616, 618], [618, 620], [620, 622], [622, 624], [624, 626], [626, 628], [628, 630], [630, 632], [632, 634], [634, 636], [636, 638], [638, 640], [640, 642], [642, 644], [644, 646], [646, 648], [648, 650], [650, 652], [652, 654], [654, 656], [656, 658], [658, 660], [660, 662], [662, 664], [664, 666], [666, 668], [668, 670], [670, 672], [672, 674], [674, 676], [676, 678], [678, 680], [680, 682], [682, 684], [68 ...

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 424)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 424)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 424)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 424) (60, 424)
# clouds  (160, 424) (40, 424)
# vegetation  (560, 424) (140, 424)
# water  (496, 424) (124, 424)
# built  (1280, 424) (320, 424)
# windows  (480, 424) (120, 424)
# roads  (200, 424) (50, 424)
# cars  (200, 424) (50, 424)
# metal  (148, 424) (37, 424)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 424) (3764,) (3764, 2)
# (941, 424) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 125ms/step - loss: 1.7114 - accuracy: 0.4126 - val_loss: 1.3462 - val_accuracy: 0.5845
# Epoch 2/200
# 8/8 [==============================] - 1s 105ms/step - loss: 1.2404 - accuracy: 0.5677 - val_loss: 1.1525 - val_accuracy: 0.6015
# Epoch 3/200
# 8/8 [==============================] - 1s 94ms/step - loss: 1.0564 - accuracy: 0.6214 - val_loss: 0.9667 - val_accuracy: 0.6514
# Epoch 4/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.9156 - accuracy: 0.6857 - val_loss: 0.8493 - val_accuracy: 0.7322
# Epoch 5/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.8100 - accuracy: 0.7210 - val_loss: 0.7977 - val_accuracy: 0.7439
# Epoch 6/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.7604 - accuracy: 0.7402 - val_loss: 0.7037 - val_accuracy: 0.7492
# Epoch 7/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.7324 - accuracy: 0.7508 - val_loss: 0.7084 - val_accuracy: 0.7609
# Epoch 8/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.7140 - accuracy: 0.7577 - val_loss: 0.7449 - val_accuracy: 0.7173
# Epoch 9/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.6929 - accuracy: 0.7532 - val_loss: 0.6428 - val_accuracy: 0.7662
# Epoch 10/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6538 - accuracy: 0.7638 - val_loss: 0.6245 - val_accuracy: 0.8002
# Epoch 11/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.6067 - accuracy: 0.7896 - val_loss: 0.5911 - val_accuracy: 0.8130
# Epoch 12/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.5955 - accuracy: 0.7899 - val_loss: 0.5592 - val_accuracy: 0.8013
# Epoch 13/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.5679 - accuracy: 0.7994 - val_loss: 0.5864 - val_accuracy: 0.7768
# Epoch 14/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.5820 - accuracy: 0.7883 - val_loss: 0.6182 - val_accuracy: 0.7641
# Epoch 15/200
# 8/8 [==============================] - 1s 109ms/step - loss: 0.5620 - accuracy: 0.7899 - val_loss: 0.5492 - val_accuracy: 0.8119
# Epoch 16/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.5417 - accuracy: 0.8037 - val_loss: 0.5181 - val_accuracy: 0.8225
# Epoch 17/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.5242 - accuracy: 0.8130 - val_loss: 0.5197 - val_accuracy: 0.8204
# Epoch 18/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.5113 - accuracy: 0.8170 - val_loss: 0.4987 - val_accuracy: 0.8427
# Epoch 19/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4859 - accuracy: 0.8332 - val_loss: 0.4857 - val_accuracy: 0.8278
# Epoch 20/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.4769 - accuracy: 0.8318 - val_loss: 0.4780 - val_accuracy: 0.8363
# Epoch 21/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4779 - accuracy: 0.8257 - val_loss: 0.5429 - val_accuracy: 0.8236
# Epoch 22/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5103 - accuracy: 0.8241 - val_loss: 0.4938 - val_accuracy: 0.8417
# Epoch 23/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4817 - accuracy: 0.8337 - val_loss: 0.4938 - val_accuracy: 0.8385
# Epoch 24/200
# 8/8 [==============================] - 1s 115ms/step - loss: 0.4724 - accuracy: 0.8305 - val_loss: 0.5557 - val_accuracy: 0.7917
# Epoch 25/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.4837 - accuracy: 0.8220 - val_loss: 0.5183 - val_accuracy: 0.8087
# Epoch 26/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4813 - accuracy: 0.8342 - val_loss: 0.4526 - val_accuracy: 0.8608
# Epoch 27/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4507 - accuracy: 0.8462 - val_loss: 0.4876 - val_accuracy: 0.8289
# Epoch 28/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.4303 - accuracy: 0.8472 - val_loss: 0.4291 - val_accuracy: 0.8640
# Epoch 29/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4234 - accuracy: 0.8488 - val_loss: 0.4439 - val_accuracy: 0.8672
# Epoch 30/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4117 - accuracy: 0.8632 - val_loss: 0.4228 - val_accuracy: 0.8682
# Epoch 31/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.3987 - accuracy: 0.8674 - val_loss: 0.4087 - val_accuracy: 0.8927
# Epoch 32/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3900 - accuracy: 0.8709 - val_loss: 0.4112 - val_accuracy: 0.8799
# Epoch 33/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3832 - accuracy: 0.8698 - val_loss: 0.4060 - val_accuracy: 0.8789
# Epoch 34/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.3830 - accuracy: 0.8706 - val_loss: 0.4019 - val_accuracy: 0.8874
# Epoch 35/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3691 - accuracy: 0.8791 - val_loss: 0.3797 - val_accuracy: 0.8937
# Epoch 36/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3527 - accuracy: 0.8781 - val_loss: 0.3784 - val_accuracy: 0.8905
# Epoch 37/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.3488 - accuracy: 0.8892 - val_loss: 0.3888 - val_accuracy: 0.8948
# Epoch 38/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3427 - accuracy: 0.8828 - val_loss: 0.4245 - val_accuracy: 0.8491
# Epoch 39/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3534 - accuracy: 0.8775 - val_loss: 0.3737 - val_accuracy: 0.8980
# Epoch 40/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.3368 - accuracy: 0.8887 - val_loss: 0.3743 - val_accuracy: 0.8852
# Epoch 41/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.3282 - accuracy: 0.8953 - val_loss: 0.3591 - val_accuracy: 0.8959
# Epoch 42/200
# 8/8 [==============================] - 1s 121ms/step - loss: 0.3202 - accuracy: 0.8988 - val_loss: 0.3530 - val_accuracy: 0.9022
# Epoch 43/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.3173 - accuracy: 0.8961 - val_loss: 0.3993 - val_accuracy: 0.8650
# Epoch 44/200
# 8/8 [==============================] - 1s 114ms/step - loss: 0.3219 - accuracy: 0.8956 - val_loss: 0.3433 - val_accuracy: 0.8937
# Epoch 45/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.3016 - accuracy: 0.8964 - val_loss: 0.3631 - val_accuracy: 0.8927
# Epoch 46/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.2957 - accuracy: 0.8993 - val_loss: 0.3460 - val_accuracy: 0.8937
# Epoch 47/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2986 - accuracy: 0.9006 - val_loss: 0.3654 - val_accuracy: 0.8831
# Epoch 48/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3026 - accuracy: 0.9014 - val_loss: 0.3637 - val_accuracy: 0.8767
# Epoch 49/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2969 - accuracy: 0.8956 - val_loss: 0.3428 - val_accuracy: 0.8980
# Epoch 50/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.2875 - accuracy: 0.9062 - val_loss: 0.3717 - val_accuracy: 0.8852
# Epoch 51/200
# 8/8 [==============================] - 1s 112ms/step - loss: 0.2807 - accuracy: 0.9107 - val_loss: 0.3246 - val_accuracy: 0.9033
# Epoch 52/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2697 - accuracy: 0.9105 - val_loss: 0.3298 - val_accuracy: 0.8969
# Epoch 53/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2707 - accuracy: 0.9089 - val_loss: 0.3572 - val_accuracy: 0.8969
# Epoch 54/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2738 - accuracy: 0.9163 - val_loss: 0.3820 - val_accuracy: 0.8714
# Epoch 55/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2723 - accuracy: 0.9142 - val_loss: 0.3368 - val_accuracy: 0.8959
# Epoch 56/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.2521 - accuracy: 0.9187 - val_loss: 0.3471 - val_accuracy: 0.8852
# Epoch 57/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2526 - accuracy: 0.9129 - val_loss: 0.3295 - val_accuracy: 0.9012
# Epoch 58/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.2453 - accuracy: 0.9200 - val_loss: 0.3349 - val_accuracy: 0.9012
# Epoch 59/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2314 - accuracy: 0.9283 - val_loss: 0.3281 - val_accuracy: 0.9012
# Epoch 60/200
# 8/8 [==============================] - 1s 106ms/step - loss: 0.2404 - accuracy: 0.9184 - val_loss: 0.3141 - val_accuracy: 0.9065
# Epoch 61/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.2422 - accuracy: 0.9238 - val_loss: 0.3356 - val_accuracy: 0.9012
# Epoch 62/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2310 - accuracy: 0.9288 - val_loss: 0.3309 - val_accuracy: 0.9001
# Epoch 63/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.2348 - accuracy: 0.9251 - val_loss: 0.3367 - val_accuracy: 0.9086
# Epoch 64/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.2411 - accuracy: 0.9179 - val_loss: 0.3237 - val_accuracy: 0.9012
# Epoch 65/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.2429 - accuracy: 0.9190 - val_loss: 0.3480 - val_accuracy: 0.8810
# Epoch 66/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.2448 - accuracy: 0.9192 - val_loss: 0.3316 - val_accuracy: 0.9044
# Epoch 67/200
# 8/8 [==============================] - 1s 115ms/step - loss: 0.2331 - accuracy: 0.9251 - val_loss: 0.3284 - val_accuracy: 0.8990
# Epoch 68/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.2406 - accuracy: 0.9200 - val_loss: 0.3299 - val_accuracy: 0.8990
# Epoch 69/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.2285 - accuracy: 0.9267 - val_loss: 0.3369 - val_accuracy: 0.8937
# Epoch 70/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.2163 - accuracy: 0.9304 - val_loss: 0.3006 - val_accuracy: 0.9075
# Epoch 71/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2110 - accuracy: 0.9291 - val_loss: 0.2993 - val_accuracy: 0.9033
# Epoch 72/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1906 - accuracy: 0.9384 - val_loss: 0.3276 - val_accuracy: 0.9022
# Epoch 73/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1992 - accuracy: 0.9354 - val_loss: 0.2970 - val_accuracy: 0.9001
# Epoch 74/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1962 - accuracy: 0.9373 - val_loss: 0.2971 - val_accuracy: 0.9107
# Epoch 75/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1919 - accuracy: 0.9394 - val_loss: 0.3045 - val_accuracy: 0.9107
# Epoch 76/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1859 - accuracy: 0.9394 - val_loss: 0.3235 - val_accuracy: 0.9054
# Epoch 77/200
# 8/8 [==============================] - 1s 110ms/step - loss: 0.1968 - accuracy: 0.9338 - val_loss: 0.3680 - val_accuracy: 0.8799
# Epoch 78/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.2333 - accuracy: 0.9179 - val_loss: 0.3357 - val_accuracy: 0.9001
# Epoch 79/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2255 - accuracy: 0.9211 - val_loss: 0.4547 - val_accuracy: 0.8342
# Epoch 80/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.4132 - accuracy: 0.8581 - val_loss: 0.4891 - val_accuracy: 0.8385
# Epoch 81/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3593 - accuracy: 0.8690 - val_loss: 0.3989 - val_accuracy: 0.8704
# Epoch 82/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.2756 - accuracy: 0.9123 - val_loss: 0.3384 - val_accuracy: 0.8980
# Epoch 83/200
# 8/8 [==============================] - 1s 113ms/step - loss: 0.2377 - accuracy: 0.9232 - val_loss: 0.3018 - val_accuracy: 0.9065
# Epoch 84/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2256 - accuracy: 0.9222 - val_loss: 0.3060 - val_accuracy: 0.9086
# Epoch 85/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.2131 - accuracy: 0.9333 - val_loss: 0.3272 - val_accuracy: 0.8959
# Epoch 86/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2044 - accuracy: 0.9338 - val_loss: 0.3100 - val_accuracy: 0.9022
# Epoch 87/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.2008 - accuracy: 0.9352 - val_loss: 0.3230 - val_accuracy: 0.9075
# Epoch 88/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2083 - accuracy: 0.9304 - val_loss: 0.3382 - val_accuracy: 0.9107
# Epoch 89/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1950 - accuracy: 0.9389 - val_loss: 0.2926 - val_accuracy: 0.9086
# Epoch 90/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1778 - accuracy: 0.9413 - val_loss: 0.3048 - val_accuracy: 0.9171
# Epoch 91/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.1815 - accuracy: 0.9378 - val_loss: 0.3164 - val_accuracy: 0.9097
# Epoch 92/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1836 - accuracy: 0.9376 - val_loss: 0.2889 - val_accuracy: 0.9118
# Epoch 93/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1814 - accuracy: 0.9463 - val_loss: 0.3213 - val_accuracy: 0.8980
# Epoch 94/200
# 8/8 [==============================] - 1s 112ms/step - loss: 0.1814 - accuracy: 0.9400 - val_loss: 0.3081 - val_accuracy: 0.9022
# Epoch 95/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1739 - accuracy: 0.9421 - val_loss: 0.3029 - val_accuracy: 0.9054
# Epoch 96/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1730 - accuracy: 0.9405 - val_loss: 0.2963 - val_accuracy: 0.9044
# Epoch 97/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1635 - accuracy: 0.9466 - val_loss: 0.3023 - val_accuracy: 0.9139
# Epoch 98/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1806 - accuracy: 0.9389 - val_loss: 0.3150 - val_accuracy: 0.9001
# Epoch 99/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1737 - accuracy: 0.9463 - val_loss: 0.3090 - val_accuracy: 0.9086
# Epoch 100/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1613 - accuracy: 0.9437 - val_loss: 0.3088 - val_accuracy: 0.9097
# Epoch 101/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1588 - accuracy: 0.9445 - val_loss: 0.2869 - val_accuracy: 0.9129
# Epoch 102/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1505 - accuracy: 0.9509 - val_loss: 0.3014 - val_accuracy: 0.9129
# Epoch 103/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1709 - accuracy: 0.9421 - val_loss: 0.2996 - val_accuracy: 0.9139
# Epoch 104/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1602 - accuracy: 0.9479 - val_loss: 0.2968 - val_accuracy: 0.9129
# Epoch 105/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1513 - accuracy: 0.9554 - val_loss: 0.3311 - val_accuracy: 0.9118
# Epoch 106/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1884 - accuracy: 0.9360 - val_loss: 0.3495 - val_accuracy: 0.8959
# Epoch 107/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1748 - accuracy: 0.9421 - val_loss: 0.2945 - val_accuracy: 0.9118
# Epoch 108/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1664 - accuracy: 0.9405 - val_loss: 0.3140 - val_accuracy: 0.9107
# Epoch 109/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1500 - accuracy: 0.9516 - val_loss: 0.2912 - val_accuracy: 0.9075
# Epoch 110/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1512 - accuracy: 0.9495 - val_loss: 0.2908 - val_accuracy: 0.9150
# Epoch 111/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1507 - accuracy: 0.9455 - val_loss: 0.3054 - val_accuracy: 0.9097
# Epoch 112/200
# 8/8 [==============================] - 1s 111ms/step - loss: 0.1534 - accuracy: 0.9498 - val_loss: 0.2825 - val_accuracy: 0.9118
# Epoch 113/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1356 - accuracy: 0.9538 - val_loss: 0.2887 - val_accuracy: 0.9086
# Epoch 114/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1407 - accuracy: 0.9519 - val_loss: 0.3005 - val_accuracy: 0.9139
# Epoch 115/200
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1405 - accuracy: 0.9572 - val_loss: 0.2972 - val_accuracy: 0.9150
# Epoch 116/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1390 - accuracy: 0.9572 - val_loss: 0.3131 - val_accuracy: 0.9150
# Epoch 117/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1547 - accuracy: 0.9495 - val_loss: 0.3211 - val_accuracy: 0.9129
# Epoch 118/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1357 - accuracy: 0.9570 - val_loss: 0.3123 - val_accuracy: 0.9139
# Epoch 119/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.1442 - accuracy: 0.9524 - val_loss: 0.3147 - val_accuracy: 0.9139
# Epoch 120/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1350 - accuracy: 0.9562 - val_loss: 0.3211 - val_accuracy: 0.9129
# Epoch 121/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1437 - accuracy: 0.9532 - val_loss: 0.3050 - val_accuracy: 0.9107
# Epoch 122/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.1428 - accuracy: 0.9522 - val_loss: 0.3155 - val_accuracy: 0.9129
# Epoch 123/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.1383 - accuracy: 0.9522 - val_loss: 0.2954 - val_accuracy: 0.9182
# Epoch 124/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1353 - accuracy: 0.9546 - val_loss: 0.3141 - val_accuracy: 0.9097
# Epoch 125/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1410 - accuracy: 0.9562 - val_loss: 0.3081 - val_accuracy: 0.9139
# Epoch 126/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1299 - accuracy: 0.9572 - val_loss: 0.3027 - val_accuracy: 0.9150
# Epoch 127/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1176 - accuracy: 0.9612 - val_loss: 0.3132 - val_accuracy: 0.9118
# Epoch 128/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1195 - accuracy: 0.9615 - val_loss: 0.3373 - val_accuracy: 0.9065
# Epoch 129/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1228 - accuracy: 0.9562 - val_loss: 0.3022 - val_accuracy: 0.9129
# Epoch 130/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1189 - accuracy: 0.9623 - val_loss: 0.3134 - val_accuracy: 0.9129
# Epoch 131/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1097 - accuracy: 0.9663 - val_loss: 0.3257 - val_accuracy: 0.9118
# Epoch 132/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1315 - accuracy: 0.9564 - val_loss: 0.3316 - val_accuracy: 0.9118
# Epoch 133/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1200 - accuracy: 0.9607 - val_loss: 0.2869 - val_accuracy: 0.9139
# Epoch 134/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1132 - accuracy: 0.9641 - val_loss: 0.3177 - val_accuracy: 0.9139
# Epoch 135/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1108 - accuracy: 0.9665 - val_loss: 0.3396 - val_accuracy: 0.9118
# Epoch 136/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1231 - accuracy: 0.9599 - val_loss: 0.3350 - val_accuracy: 0.9171
# Epoch 137/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1216 - accuracy: 0.9591 - val_loss: 0.3235 - val_accuracy: 0.9097
# Epoch 138/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1146 - accuracy: 0.9631 - val_loss: 0.3192 - val_accuracy: 0.9150
# Epoch 139/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1078 - accuracy: 0.9649 - val_loss: 0.3143 - val_accuracy: 0.9160
# Epoch 140/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1031 - accuracy: 0.9644 - val_loss: 0.3291 - val_accuracy: 0.9171
# Epoch 141/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1120 - accuracy: 0.9623 - val_loss: 0.3646 - val_accuracy: 0.9118
# Epoch 142/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1036 - accuracy: 0.9671 - val_loss: 0.3306 - val_accuracy: 0.9129
# Epoch 143/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1062 - accuracy: 0.9633 - val_loss: 0.3171 - val_accuracy: 0.9107
# Epoch 144/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1091 - accuracy: 0.9612 - val_loss: 0.3091 - val_accuracy: 0.9150
# Epoch 145/200
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1062 - accuracy: 0.9676 - val_loss: 0.3337 - val_accuracy: 0.9086
# Epoch 146/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1110 - accuracy: 0.9636 - val_loss: 0.3226 - val_accuracy: 0.9214
# Epoch 147/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.1106 - accuracy: 0.9631 - val_loss: 0.3377 - val_accuracy: 0.9065
# Epoch 148/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.1365 - accuracy: 0.9522 - val_loss: 0.3765 - val_accuracy: 0.8959
# Epoch 149/200
# 8/8 [==============================] - 1s 108ms/step - loss: 0.1497 - accuracy: 0.9479 - val_loss: 0.3330 - val_accuracy: 0.9171
# Epoch 150/200
# 8/8 [==============================] - 1s 102ms/step - loss: 0.1291 - accuracy: 0.9532 - val_loss: 0.3493 - val_accuracy: 0.9107
# Epoch 151/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1132 - accuracy: 0.9625 - val_loss: 0.3192 - val_accuracy: 0.9182
# Epoch 152/200
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1015 - accuracy: 0.9657 - val_loss: 0.3550 - val_accuracy: 0.9075
# Epoch 153/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.1164 - accuracy: 0.9607 - val_loss: 0.3125 - val_accuracy: 0.9118
# Epoch 154/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.1116 - accuracy: 0.9660 - val_loss: 0.3433 - val_accuracy: 0.9107
# Epoch 155/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.1111 - accuracy: 0.9612 - val_loss: 0.3527 - val_accuracy: 0.9139
# Epoch 156/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.1200 - accuracy: 0.9559 - val_loss: 0.2849 - val_accuracy: 0.9160
# Epoch 157/200
# 8/8 [==============================] - 1s 107ms/step - loss: 0.1100 - accuracy: 0.9620 - val_loss: 0.3240 - val_accuracy: 0.9150
# Epoch 158/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0975 - accuracy: 0.9689 - val_loss: 0.3439 - val_accuracy: 0.9203
# Epoch 159/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0962 - accuracy: 0.9705 - val_loss: 0.3439 - val_accuracy: 0.9065
# Epoch 160/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0933 - accuracy: 0.9702 - val_loss: 0.3571 - val_accuracy: 0.9182
# Epoch 161/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1026 - accuracy: 0.9647 - val_loss: 0.3416 - val_accuracy: 0.9118
# Epoch 162/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0900 - accuracy: 0.9694 - val_loss: 0.3338 - val_accuracy: 0.9086
# Epoch 163/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0934 - accuracy: 0.9673 - val_loss: 0.3525 - val_accuracy: 0.9107
# Epoch 164/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0911 - accuracy: 0.9708 - val_loss: 0.3420 - val_accuracy: 0.9097
# Epoch 165/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0975 - accuracy: 0.9673 - val_loss: 0.3214 - val_accuracy: 0.9129
# Epoch 166/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0938 - accuracy: 0.9708 - val_loss: 0.3257 - val_accuracy: 0.9192
# Epoch 167/200
# 8/8 [==============================] - 1s 112ms/step - loss: 0.0875 - accuracy: 0.9716 - val_loss: 0.3153 - val_accuracy: 0.9224
# Epoch 168/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0872 - accuracy: 0.9705 - val_loss: 0.3380 - val_accuracy: 0.9086
# Epoch 169/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0901 - accuracy: 0.9713 - val_loss: 0.3369 - val_accuracy: 0.9160
# Epoch 170/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0903 - accuracy: 0.9710 - val_loss: 0.3362 - val_accuracy: 0.9171
# Epoch 171/200
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0914 - accuracy: 0.9681 - val_loss: 0.3286 - val_accuracy: 0.9129
# Epoch 172/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0844 - accuracy: 0.9748 - val_loss: 0.3649 - val_accuracy: 0.9160
# Epoch 173/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0858 - accuracy: 0.9745 - val_loss: 0.3407 - val_accuracy: 0.9107
# Epoch 174/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0766 - accuracy: 0.9769 - val_loss: 0.3362 - val_accuracy: 0.9192
# Epoch 175/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0847 - accuracy: 0.9753 - val_loss: 0.3256 - val_accuracy: 0.9150
# Epoch 176/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0751 - accuracy: 0.9777 - val_loss: 0.3544 - val_accuracy: 0.9097
# Epoch 177/200
# 8/8 [==============================] - 1s 101ms/step - loss: 0.0931 - accuracy: 0.9687 - val_loss: 0.3678 - val_accuracy: 0.9139
# Epoch 178/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0925 - accuracy: 0.9679 - val_loss: 0.3584 - val_accuracy: 0.9171
# Epoch 179/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0918 - accuracy: 0.9692 - val_loss: 0.3797 - val_accuracy: 0.9054
# Epoch 180/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0840 - accuracy: 0.9716 - val_loss: 0.3364 - val_accuracy: 0.9171
# Epoch 181/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0794 - accuracy: 0.9726 - val_loss: 0.3393 - val_accuracy: 0.9118
# Epoch 182/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0711 - accuracy: 0.9774 - val_loss: 0.3594 - val_accuracy: 0.9214
# Epoch 183/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0816 - accuracy: 0.9729 - val_loss: 0.3540 - val_accuracy: 0.9107
# Epoch 184/200
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0787 - accuracy: 0.9737 - val_loss: 0.3680 - val_accuracy: 0.9139
# Epoch 185/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0781 - accuracy: 0.9758 - val_loss: 0.3673 - val_accuracy: 0.9129
# Epoch 186/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0823 - accuracy: 0.9702 - val_loss: 0.3341 - val_accuracy: 0.9139
# Epoch 187/200
# 8/8 [==============================] - 1s 100ms/step - loss: 0.0850 - accuracy: 0.9750 - val_loss: 0.3824 - val_accuracy: 0.9033
# Epoch 188/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0845 - accuracy: 0.9702 - val_loss: 0.3597 - val_accuracy: 0.9235
# Epoch 189/200
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0817 - accuracy: 0.9740 - val_loss: 0.3377 - val_accuracy: 0.9139
# Epoch 190/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0893 - accuracy: 0.9692 - val_loss: 0.3389 - val_accuracy: 0.9097
# Epoch 191/200
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0824 - accuracy: 0.9769 - val_loss: 0.3478 - val_accuracy: 0.9086
# Epoch 192/200
# 8/8 [==============================] - 1s 95ms/step - loss: 0.0921 - accuracy: 0.9676 - val_loss: 0.3640 - val_accuracy: 0.9224
# Epoch 193/200
# 8/8 [==============================] - 1s 98ms/step - loss: 0.0874 - accuracy: 0.9721 - val_loss: 0.3894 - val_accuracy: 0.9097
# Epoch 194/200
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0800 - accuracy: 0.9753 - val_loss: 0.3647 - val_accuracy: 0.9022
# Epoch 195/200
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0787 - accuracy: 0.9756 - val_loss: 0.3738 - val_accuracy: 0.9129
# Epoch 196/200
# 8/8 [==============================] - 1s 96ms/step - loss: 0.0755 - accuracy: 0.9750 - val_loss: 0.3407 - val_accuracy: 0.9245
# Epoch 197/200
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0647 - accuracy: 0.9798 - val_loss: 0.3616 - val_accuracy: 0.9171
# Epoch 198/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0688 - accuracy: 0.9777 - val_loss: 0.3347 - val_accuracy: 0.9160
# Epoch 199/200
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0743 - accuracy: 0.9758 - val_loss: 0.3375 - val_accuracy: 0.9256
# Epoch 200/200
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0784 - accuracy: 0.9729 - val_loss: 0.3623 - val_accuracy: 0.9086

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=70, batch_size=512)
# Out:
# Epoch 1/70
# 8/8 [==============================] - 1s 127ms/step - loss: 2.0205 - accuracy: 0.3148 - val_loss: 1.6640 - val_accuracy: 0.3549
# Epoch 2/70
# 8/8 [==============================] - 1s 99ms/step - loss: 1.5138 - accuracy: 0.4469 - val_loss: 1.3751 - val_accuracy: 0.5143
# Epoch 3/70
# 8/8 [==============================] - 1s 96ms/step - loss: 1.3251 - accuracy: 0.5393 - val_loss: 1.2414 - val_accuracy: 0.5430
# Epoch 4/70
# 8/8 [==============================] - 1s 98ms/step - loss: 1.2013 - accuracy: 0.5842 - val_loss: 1.1815 - val_accuracy: 0.6089
# Epoch 5/70
# 8/8 [==============================] - 1s 87ms/step - loss: 1.0939 - accuracy: 0.5938 - val_loss: 1.0509 - val_accuracy: 0.5972
# Epoch 6/70
# 8/8 [==============================] - 1s 91ms/step - loss: 1.0034 - accuracy: 0.6243 - val_loss: 0.9468 - val_accuracy: 0.6801
# Epoch 7/70
# 8/8 [==============================] - 1s 99ms/step - loss: 0.9212 - accuracy: 0.6761 - val_loss: 0.8526 - val_accuracy: 0.7269
# Epoch 8/70
# 8/8 [==============================] - 1s 96ms/step - loss: 0.8739 - accuracy: 0.7014 - val_loss: 0.7980 - val_accuracy: 0.7386
# Epoch 9/70
# 8/8 [==============================] - 1s 95ms/step - loss: 0.8063 - accuracy: 0.7277 - val_loss: 0.7691 - val_accuracy: 0.7407
# Epoch 10/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7823 - accuracy: 0.7311 - val_loss: 0.7275 - val_accuracy: 0.7588
# Epoch 11/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7425 - accuracy: 0.7351 - val_loss: 0.6971 - val_accuracy: 0.7545
# Epoch 12/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7203 - accuracy: 0.7457 - val_loss: 0.6849 - val_accuracy: 0.7758
# Epoch 13/70
# 8/8 [==============================] - 1s 99ms/step - loss: 0.7188 - accuracy: 0.7532 - val_loss: 0.6594 - val_accuracy: 0.7535
# Epoch 14/70
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6633 - accuracy: 0.7689 - val_loss: 0.6921 - val_accuracy: 0.7524
# Epoch 15/70
# 8/8 [==============================] - 1s 94ms/step - loss: 0.6895 - accuracy: 0.7484 - val_loss: 0.6692 - val_accuracy: 0.7588
# Epoch 16/70
# 8/8 [==============================] - 1s 96ms/step - loss: 0.6360 - accuracy: 0.7731 - val_loss: 0.6046 - val_accuracy: 0.8045
# Epoch 17/70
# 8/8 [==============================] - 1s 100ms/step - loss: 0.6182 - accuracy: 0.7880 - val_loss: 0.5810 - val_accuracy: 0.8066
# Epoch 18/70
# 8/8 [==============================] - 1s 94ms/step - loss: 0.5993 - accuracy: 0.7819 - val_loss: 0.5974 - val_accuracy: 0.8023
# Epoch 19/70
# 8/8 [==============================] - 1s 111ms/step - loss: 0.6012 - accuracy: 0.7888 - val_loss: 0.5730 - val_accuracy: 0.8140
# Epoch 20/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5787 - accuracy: 0.7904 - val_loss: 0.5482 - val_accuracy: 0.8257
# Epoch 21/70
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5574 - accuracy: 0.8050 - val_loss: 0.5273 - val_accuracy: 0.8268
# Epoch 22/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.5571 - accuracy: 0.8021 - val_loss: 0.5495 - val_accuracy: 0.8023
# Epoch 23/70
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5512 - accuracy: 0.7968 - val_loss: 0.5072 - val_accuracy: 0.8321
# Epoch 24/70
# 8/8 [==============================] - 1s 95ms/step - loss: 0.5402 - accuracy: 0.8108 - val_loss: 0.5405 - val_accuracy: 0.8183
# Epoch 25/70
# 8/8 [==============================] - 1s 86ms/step - loss: 0.5349 - accuracy: 0.8069 - val_loss: 0.5064 - val_accuracy: 0.8342
# Epoch 26/70
# 8/8 [==============================] - 1s 93ms/step - loss: 0.5344 - accuracy: 0.8092 - val_loss: 0.5606 - val_accuracy: 0.8066
# Epoch 27/70
# 8/8 [==============================] - 1s 100ms/step - loss: 0.5325 - accuracy: 0.8159 - val_loss: 0.4996 - val_accuracy: 0.8353
# Epoch 28/70
# 8/8 [==============================] - 1s 93ms/step - loss: 0.4982 - accuracy: 0.8305 - val_loss: 0.4900 - val_accuracy: 0.8480
# Epoch 29/70
# 8/8 [==============================] - 1s 109ms/step - loss: 0.4846 - accuracy: 0.8278 - val_loss: 0.4733 - val_accuracy: 0.8544
# Epoch 30/70
# 8/8 [==============================] - 1s 96ms/step - loss: 0.4723 - accuracy: 0.8348 - val_loss: 0.4696 - val_accuracy: 0.8587
# Epoch 31/70
# 8/8 [==============================] - 1s 98ms/step - loss: 0.4608 - accuracy: 0.8443 - val_loss: 0.4523 - val_accuracy: 0.8597
# Epoch 32/70
# 8/8 [==============================] - 1s 87ms/step - loss: 0.4525 - accuracy: 0.8454 - val_loss: 0.4526 - val_accuracy: 0.8661
# Epoch 33/70
# 8/8 [==============================] - 1s 96ms/step - loss: 0.4414 - accuracy: 0.8462 - val_loss: 0.4314 - val_accuracy: 0.8810
# Epoch 34/70
# 8/8 [==============================] - 1s 86ms/step - loss: 0.4257 - accuracy: 0.8544 - val_loss: 0.4448 - val_accuracy: 0.8629
# Epoch 35/70
# 8/8 [==============================] - 1s 92ms/step - loss: 0.4376 - accuracy: 0.8523 - val_loss: 0.4288 - val_accuracy: 0.8767
# Epoch 36/70
# 8/8 [==============================] - 1s 99ms/step - loss: 0.4796 - accuracy: 0.8342 - val_loss: 0.9664 - val_accuracy: 0.6196
# Epoch 37/70
# 8/8 [==============================] - 1s 95ms/step - loss: 1.2547 - accuracy: 0.6690 - val_loss: 0.7321 - val_accuracy: 0.7821
# Epoch 38/70
# 8/8 [==============================] - 1s 105ms/step - loss: 0.7377 - accuracy: 0.7327 - val_loss: 0.6353 - val_accuracy: 0.8013
# Epoch 39/70
# 8/8 [==============================] - 1s 94ms/step - loss: 0.6482 - accuracy: 0.7790 - val_loss: 0.5678 - val_accuracy: 0.8438
# Epoch 40/70
# 8/8 [==============================] - 1s 98ms/step - loss: 0.5676 - accuracy: 0.8050 - val_loss: 0.5278 - val_accuracy: 0.8470
# Epoch 41/70
# 8/8 [==============================] - 1s 85ms/step - loss: 0.5251 - accuracy: 0.8289 - val_loss: 0.4948 - val_accuracy: 0.8597
# Epoch 42/70
# 8/8 [==============================] - 1s 91ms/step - loss: 0.4848 - accuracy: 0.8419 - val_loss: 0.4668 - val_accuracy: 0.8661
# Epoch 43/70
# 8/8 [==============================] - 1s 87ms/step - loss: 0.4618 - accuracy: 0.8438 - val_loss: 0.4414 - val_accuracy: 0.8746
# Epoch 44/70
# 8/8 [==============================] - 1s 90ms/step - loss: 0.4480 - accuracy: 0.8555 - val_loss: 0.4409 - val_accuracy: 0.8789
# Epoch 45/70
# 8/8 [==============================] - 1s 96ms/step - loss: 0.4505 - accuracy: 0.8472 - val_loss: 0.4396 - val_accuracy: 0.8789
# Epoch 46/70
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4394 - accuracy: 0.8573 - val_loss: 0.4331 - val_accuracy: 0.8810
# Epoch 47/70
# 8/8 [==============================] - 1s 103ms/step - loss: 0.4320 - accuracy: 0.8515 - val_loss: 0.4269 - val_accuracy: 0.8895
# Epoch 48/70
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4124 - accuracy: 0.8616 - val_loss: 0.4149 - val_accuracy: 0.8937
# Epoch 49/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.4124 - accuracy: 0.8632 - val_loss: 0.4210 - val_accuracy: 0.8842
# Epoch 50/70
# 8/8 [==============================] - 1s 93ms/step - loss: 0.3989 - accuracy: 0.8698 - val_loss: 0.3931 - val_accuracy: 0.9086
# Epoch 51/70
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3890 - accuracy: 0.8762 - val_loss: 0.4088 - val_accuracy: 0.8874
# Epoch 52/70
# 8/8 [==============================] - 1s 85ms/step - loss: 0.3849 - accuracy: 0.8749 - val_loss: 0.4108 - val_accuracy: 0.8704
# Epoch 53/70
# 8/8 [==============================] - 1s 92ms/step - loss: 0.3851 - accuracy: 0.8743 - val_loss: 0.3911 - val_accuracy: 0.8810
# Epoch 54/70
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3675 - accuracy: 0.8783 - val_loss: 0.3793 - val_accuracy: 0.9001
# Epoch 55/70
# 8/8 [==============================] - 1s 113ms/step - loss: 0.3651 - accuracy: 0.8831 - val_loss: 0.3701 - val_accuracy: 0.9054
# Epoch 56/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3592 - accuracy: 0.8858 - val_loss: 0.3736 - val_accuracy: 0.8980
# Epoch 57/70
# 8/8 [==============================] - 1s 97ms/step - loss: 0.3596 - accuracy: 0.8807 - val_loss: 0.3768 - val_accuracy: 0.9033
# Epoch 58/70
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3564 - accuracy: 0.8884 - val_loss: 0.3602 - val_accuracy: 0.9107
# Epoch 59/70
# 8/8 [==============================] - 1s 88ms/step - loss: 0.3505 - accuracy: 0.8852 - val_loss: 0.3579 - val_accuracy: 0.9054
# Epoch 60/70
# 8/8 [==============================] - 1s 98ms/step - loss: 0.3377 - accuracy: 0.8940 - val_loss: 0.3628 - val_accuracy: 0.9065
# Epoch 61/70
# 8/8 [==============================] - 1s 93ms/step - loss: 0.3530 - accuracy: 0.8804 - val_loss: 0.3574 - val_accuracy: 0.9075
# Epoch 62/70
# 8/8 [==============================] - 1s 101ms/step - loss: 0.3342 - accuracy: 0.8884 - val_loss: 0.3484 - val_accuracy: 0.9033
# Epoch 63/70
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3436 - accuracy: 0.8850 - val_loss: 0.3516 - val_accuracy: 0.9118
# Epoch 64/70
# 8/8 [==============================] - 1s 107ms/step - loss: 0.3434 - accuracy: 0.8879 - val_loss: 0.3395 - val_accuracy: 0.9022
# Epoch 65/70
# 8/8 [==============================] - 1s 103ms/step - loss: 0.3277 - accuracy: 0.8913 - val_loss: 0.3506 - val_accuracy: 0.9086
# Epoch 66/70
# 8/8 [==============================] - 1s 105ms/step - loss: 0.3209 - accuracy: 0.8921 - val_loss: 0.3473 - val_accuracy: 0.8937
# Epoch 67/70
# 8/8 [==============================] - 1s 89ms/step - loss: 0.3225 - accuracy: 0.8908 - val_loss: 0.3371 - val_accuracy: 0.9118
# Epoch 68/70
# 8/8 [==============================] - 1s 89ms/step - loss: 0.3196 - accuracy: 0.8919 - val_loss: 0.3586 - val_accuracy: 0.8937
# Epoch 69/70
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3136 - accuracy: 0.8953 - val_loss: 0.3512 - val_accuracy: 0.8969
# Epoch 70/70
# 8/8 [==============================] - 1s 93ms/step - loss: 0.3105 - accuracy: 0.8988 - val_loss: 0.3298 - val_accuracy: 0.9075

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 6ms/step - loss: 0.2523 - accuracy: 0.9248
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3298 - accuracy: 0.9075
# 0.9248140454292297 0.9075451493263245

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 424, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:01

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   1   0   0   0   0   0]
#  [  1   0   0 118   0   1   0   0   4]
#  [  0   0   0   0 310   6   1   1   2]
#  [  0   0   0   0   4 108   4   2   2]
#  [  0   0   1   0   7  10  28   0   4]
#  [  0   0   0   0   8   9   0  32   1]
#  [  0   0   0   2   7   9   0   0  19]]
#
# Accuracy Score
# 0.9075451647183846
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.98      1.00      0.99        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.98      0.95      0.96       124
#       built       0.92      0.97      0.95       320
#     windows       0.76      0.90      0.82       120
#       roads       0.85      0.56      0.67        50
#        cars       0.91      0.64      0.75        50
#       metal       0.59      0.51      0.55        37
#
# avg / total       0.91      0.91      0.90       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
