# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 106
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 106
# [[0, 8], [8, 16], [16, 24], [24, 32], [32, 40], [40, 48], [48, 56], [56, 64], [64, 72], [72, 80], [80, 88], [88, 96], [96, 104], [104, 112], [112, 120], [120, 128], [128, 136], [136, 144], [144, 152], [152, 160], [160, 168], [168, 176], [176, 184], [184, 192], [192, 200], [200, 208], [208, 216], [216, 224], [224, 232], [232, 240], [240, 248], [248, 256], [256, 264], [264, 272], [272, 280], [280, 288], [288, 296], [296, 304], [304, 312], [312, 320], [320, 328], [328, 336], [336, 344], [344, 352], [352, 360], [360, 368], [368, 376], [376, 384], [384, 392], [392, 400], [400, 408], [408, 416], [416, 424], [424, 432], [432, 440], [440, 448], [448, 456], [456, 464], [464, 472], [472, 480], [480, 488], [488, 496], [496, 504], [504, 512], [512, 520], [520, 528], [528, 536], [536, 544], [544, 552], [552, 560], [560, 568], [568, 576], [576, 584], [584, 592], [592, 600], [600, 608], [608, 616], [616, 624], [624, 632], [632, 640], [640, 648], [648, 656], [656, 664], [664, 672], [672, 680], [680, 688], [688, 696], [696, 704], [704, 712], [712, 720], [720, 728], [728, 736], [736, 744], [744, 752], [752, 760], [760, 768], [768, 776], [776, 784], [784, 792], [792, 800], [800, 808], [808, 816], [816, 824], [824, 832], [832, 840], [840, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 106)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 106)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 106)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 106) (60, 106)
# clouds  (400, 106) (100, 106)
# vegetation  (480, 106) (120, 106)
# water  (40, 106) (10, 106)
# built  (816, 106) (204, 106)
# windows  (400, 106) (100, 106)
# roads  (24, 106) (6, 106)
# cars  (80, 106) (20, 106)
# metal  (80, 106) (20, 106)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 106) (2560,) (2560, 2)
# (640, 106) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 96ms/step - loss: 1.7321 - accuracy: 0.4195 - val_loss: 1.2670 - val_accuracy: 0.6328
# Epoch 2/200
# 5/5 [==============================] - 0s 58ms/step - loss: 1.1464 - accuracy: 0.6461 - val_loss: 0.9182 - val_accuracy: 0.7172
# Epoch 3/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.8898 - accuracy: 0.7129 - val_loss: 0.7928 - val_accuracy: 0.7234
# Epoch 4/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.8051 - accuracy: 0.7332 - val_loss: 0.7348 - val_accuracy: 0.7688
# Epoch 5/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.7516 - accuracy: 0.7559 - val_loss: 0.6748 - val_accuracy: 0.7875
# Epoch 6/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.6939 - accuracy: 0.7766 - val_loss: 0.6102 - val_accuracy: 0.8297
# Epoch 7/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.6417 - accuracy: 0.7961 - val_loss: 0.5594 - val_accuracy: 0.8313
# Epoch 8/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.5909 - accuracy: 0.8094 - val_loss: 0.5323 - val_accuracy: 0.8313
# Epoch 9/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.5452 - accuracy: 0.8277 - val_loss: 0.4875 - val_accuracy: 0.8547
# Epoch 10/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.5163 - accuracy: 0.8332 - val_loss: 0.4505 - val_accuracy: 0.8625
# Epoch 11/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4910 - accuracy: 0.8422 - val_loss: 0.4195 - val_accuracy: 0.8719
# Epoch 12/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4705 - accuracy: 0.8586 - val_loss: 0.3996 - val_accuracy: 0.8750
# Epoch 13/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4470 - accuracy: 0.8672 - val_loss: 0.3859 - val_accuracy: 0.8969
# Epoch 14/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4230 - accuracy: 0.8746 - val_loss: 0.3697 - val_accuracy: 0.8891
# Epoch 15/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.4060 - accuracy: 0.8809 - val_loss: 0.3562 - val_accuracy: 0.9016
# Epoch 16/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3956 - accuracy: 0.8801 - val_loss: 0.3465 - val_accuracy: 0.9047
# Epoch 17/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3872 - accuracy: 0.8820 - val_loss: 0.3401 - val_accuracy: 0.9047
# Epoch 18/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3832 - accuracy: 0.8871 - val_loss: 0.3336 - val_accuracy: 0.9016
# Epoch 19/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3751 - accuracy: 0.8945 - val_loss: 0.3269 - val_accuracy: 0.9016
# Epoch 20/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3580 - accuracy: 0.8926 - val_loss: 0.3319 - val_accuracy: 0.8906
# Epoch 21/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3573 - accuracy: 0.8879 - val_loss: 0.3226 - val_accuracy: 0.8984
# Epoch 22/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3565 - accuracy: 0.8941 - val_loss: 0.3257 - val_accuracy: 0.8953
# Epoch 23/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3460 - accuracy: 0.8996 - val_loss: 0.3123 - val_accuracy: 0.8922
# Epoch 24/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.3274 - accuracy: 0.9023 - val_loss: 0.2921 - val_accuracy: 0.9187
# Epoch 25/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3272 - accuracy: 0.9059 - val_loss: 0.2930 - val_accuracy: 0.9125
# Epoch 26/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3153 - accuracy: 0.9070 - val_loss: 0.2846 - val_accuracy: 0.9062
# Epoch 27/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.3194 - accuracy: 0.9055 - val_loss: 0.2875 - val_accuracy: 0.9094
# Epoch 28/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3066 - accuracy: 0.9090 - val_loss: 0.2773 - val_accuracy: 0.9125
# Epoch 29/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3037 - accuracy: 0.9074 - val_loss: 0.2750 - val_accuracy: 0.9062
# Epoch 30/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2951 - accuracy: 0.9082 - val_loss: 0.2707 - val_accuracy: 0.9109
# Epoch 31/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2916 - accuracy: 0.9121 - val_loss: 0.2602 - val_accuracy: 0.9203
# Epoch 32/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.2809 - accuracy: 0.9129 - val_loss: 0.2556 - val_accuracy: 0.9156
# Epoch 33/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2767 - accuracy: 0.9191 - val_loss: 0.2497 - val_accuracy: 0.9172
# Epoch 34/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.2717 - accuracy: 0.9141 - val_loss: 0.2481 - val_accuracy: 0.9156
# Epoch 35/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.2619 - accuracy: 0.9187 - val_loss: 0.2448 - val_accuracy: 0.9094
# Epoch 36/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2667 - accuracy: 0.9195 - val_loss: 0.2458 - val_accuracy: 0.9094
# Epoch 37/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2607 - accuracy: 0.9199 - val_loss: 0.2495 - val_accuracy: 0.9234
# Epoch 38/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2614 - accuracy: 0.9238 - val_loss: 0.2384 - val_accuracy: 0.9250
# Epoch 39/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2702 - accuracy: 0.9156 - val_loss: 0.2418 - val_accuracy: 0.9266
# Epoch 40/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2552 - accuracy: 0.9223 - val_loss: 0.2256 - val_accuracy: 0.9234
# Epoch 41/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2428 - accuracy: 0.9230 - val_loss: 0.2207 - val_accuracy: 0.9281
# Epoch 42/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2384 - accuracy: 0.9234 - val_loss: 0.2236 - val_accuracy: 0.9281
# Epoch 43/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2348 - accuracy: 0.9293 - val_loss: 0.2162 - val_accuracy: 0.9266
# Epoch 44/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2345 - accuracy: 0.9273 - val_loss: 0.2267 - val_accuracy: 0.9156
# Epoch 45/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2327 - accuracy: 0.9227 - val_loss: 0.2179 - val_accuracy: 0.9125
# Epoch 46/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2317 - accuracy: 0.9277 - val_loss: 0.2235 - val_accuracy: 0.9359
# Epoch 47/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.2379 - accuracy: 0.9246 - val_loss: 0.2186 - val_accuracy: 0.9266
# Epoch 48/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2350 - accuracy: 0.9262 - val_loss: 0.2133 - val_accuracy: 0.9344
# Epoch 49/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2264 - accuracy: 0.9289 - val_loss: 0.2029 - val_accuracy: 0.9297
# Epoch 50/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2230 - accuracy: 0.9332 - val_loss: 0.2038 - val_accuracy: 0.9297
# Epoch 51/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2212 - accuracy: 0.9285 - val_loss: 0.2033 - val_accuracy: 0.9297
# Epoch 52/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.2147 - accuracy: 0.9320 - val_loss: 0.2006 - val_accuracy: 0.9328
# Epoch 53/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2179 - accuracy: 0.9266 - val_loss: 0.2006 - val_accuracy: 0.9359
# Epoch 54/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.2143 - accuracy: 0.9285 - val_loss: 0.1978 - val_accuracy: 0.9297
# Epoch 55/200
# 5/5 [==============================] - 0s 72ms/step - loss: 0.2116 - accuracy: 0.9297 - val_loss: 0.2034 - val_accuracy: 0.9406
# Epoch 56/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2127 - accuracy: 0.9312 - val_loss: 0.1997 - val_accuracy: 0.9359
# Epoch 57/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2123 - accuracy: 0.9281 - val_loss: 0.2002 - val_accuracy: 0.9391
# Epoch 58/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2065 - accuracy: 0.9320 - val_loss: 0.1838 - val_accuracy: 0.9344
# Epoch 59/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2026 - accuracy: 0.9293 - val_loss: 0.2050 - val_accuracy: 0.9172
# Epoch 60/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1929 - accuracy: 0.9359 - val_loss: 0.1961 - val_accuracy: 0.9250
# Epoch 61/200
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1967 - accuracy: 0.9336 - val_loss: 0.1855 - val_accuracy: 0.9297
# Epoch 62/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1866 - accuracy: 0.9367 - val_loss: 0.1834 - val_accuracy: 0.9359
# Epoch 63/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1807 - accuracy: 0.9402 - val_loss: 0.1718 - val_accuracy: 0.9391
# Epoch 64/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1760 - accuracy: 0.9410 - val_loss: 0.1741 - val_accuracy: 0.9406
# Epoch 65/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1788 - accuracy: 0.9387 - val_loss: 0.1694 - val_accuracy: 0.9406
# Epoch 66/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1788 - accuracy: 0.9363 - val_loss: 0.1740 - val_accuracy: 0.9469
# Epoch 67/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1706 - accuracy: 0.9426 - val_loss: 0.1662 - val_accuracy: 0.9422
# Epoch 68/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1670 - accuracy: 0.9457 - val_loss: 0.1615 - val_accuracy: 0.9406
# Epoch 69/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1677 - accuracy: 0.9410 - val_loss: 0.1664 - val_accuracy: 0.9500
# Epoch 70/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1683 - accuracy: 0.9477 - val_loss: 0.1608 - val_accuracy: 0.9422
# Epoch 71/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1632 - accuracy: 0.9414 - val_loss: 0.1595 - val_accuracy: 0.9484
# Epoch 72/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1594 - accuracy: 0.9461 - val_loss: 0.1585 - val_accuracy: 0.9422
# Epoch 73/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1666 - accuracy: 0.9461 - val_loss: 0.1683 - val_accuracy: 0.9391
# Epoch 74/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1559 - accuracy: 0.9477 - val_loss: 0.1628 - val_accuracy: 0.9391
# Epoch 75/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1616 - accuracy: 0.9453 - val_loss: 0.1689 - val_accuracy: 0.9406
# Epoch 76/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1614 - accuracy: 0.9445 - val_loss: 0.1643 - val_accuracy: 0.9484
# Epoch 77/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1577 - accuracy: 0.9434 - val_loss: 0.1693 - val_accuracy: 0.9344
# Epoch 78/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1618 - accuracy: 0.9465 - val_loss: 0.1511 - val_accuracy: 0.9438
# Epoch 79/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1592 - accuracy: 0.9445 - val_loss: 0.1651 - val_accuracy: 0.9484
# Epoch 80/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1603 - accuracy: 0.9457 - val_loss: 0.1585 - val_accuracy: 0.9422
# Epoch 81/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1579 - accuracy: 0.9492 - val_loss: 0.1540 - val_accuracy: 0.9469
# Epoch 82/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1579 - accuracy: 0.9473 - val_loss: 0.1614 - val_accuracy: 0.9422
# Epoch 83/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1495 - accuracy: 0.9480 - val_loss: 0.1672 - val_accuracy: 0.9359
# Epoch 84/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1533 - accuracy: 0.9512 - val_loss: 0.1496 - val_accuracy: 0.9391
# Epoch 85/200
# 5/5 [==============================] - 0s 72ms/step - loss: 0.1461 - accuracy: 0.9465 - val_loss: 0.1473 - val_accuracy: 0.9547
# Epoch 86/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1416 - accuracy: 0.9500 - val_loss: 0.1471 - val_accuracy: 0.9422
# Epoch 87/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1449 - accuracy: 0.9500 - val_loss: 0.1481 - val_accuracy: 0.9547
# Epoch 88/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1364 - accuracy: 0.9551 - val_loss: 0.1382 - val_accuracy: 0.9547
# Epoch 89/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1363 - accuracy: 0.9539 - val_loss: 0.1407 - val_accuracy: 0.9469
# Epoch 90/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1266 - accuracy: 0.9535 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 91/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1245 - accuracy: 0.9621 - val_loss: 0.1521 - val_accuracy: 0.9406
# Epoch 92/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1354 - accuracy: 0.9543 - val_loss: 0.1380 - val_accuracy: 0.9563
# Epoch 93/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1396 - accuracy: 0.9539 - val_loss: 0.1550 - val_accuracy: 0.9484
# Epoch 94/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1383 - accuracy: 0.9523 - val_loss: 0.1412 - val_accuracy: 0.9500
# Epoch 95/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1311 - accuracy: 0.9578 - val_loss: 0.1512 - val_accuracy: 0.9484
# Epoch 96/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1349 - accuracy: 0.9547 - val_loss: 0.1563 - val_accuracy: 0.9469
# Epoch 97/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1222 - accuracy: 0.9551 - val_loss: 0.1393 - val_accuracy: 0.9469
# Epoch 98/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.1244 - accuracy: 0.9609 - val_loss: 0.1383 - val_accuracy: 0.9531
# Epoch 99/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1253 - accuracy: 0.9574 - val_loss: 0.1386 - val_accuracy: 0.9563
# Epoch 100/200
# 5/5 [==============================] - 1s 148ms/step - loss: 0.1186 - accuracy: 0.9594 - val_loss: 0.1440 - val_accuracy: 0.9500
# Epoch 101/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1282 - accuracy: 0.9570 - val_loss: 0.1420 - val_accuracy: 0.9500
# Epoch 102/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1217 - accuracy: 0.9555 - val_loss: 0.1354 - val_accuracy: 0.9563
# Epoch 103/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1232 - accuracy: 0.9594 - val_loss: 0.1318 - val_accuracy: 0.9516
# Epoch 104/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1186 - accuracy: 0.9605 - val_loss: 0.1284 - val_accuracy: 0.9516
# Epoch 105/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1131 - accuracy: 0.9641 - val_loss: 0.1372 - val_accuracy: 0.9578
# Epoch 106/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1120 - accuracy: 0.9641 - val_loss: 0.1367 - val_accuracy: 0.9484
# Epoch 107/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1190 - accuracy: 0.9586 - val_loss: 0.1441 - val_accuracy: 0.9500
# Epoch 108/200
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1189 - accuracy: 0.9598 - val_loss: 0.1327 - val_accuracy: 0.9547
# Epoch 109/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1144 - accuracy: 0.9633 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 110/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1239 - accuracy: 0.9570 - val_loss: 0.1363 - val_accuracy: 0.9563
# Epoch 111/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1155 - accuracy: 0.9586 - val_loss: 0.1442 - val_accuracy: 0.9484
# Epoch 112/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1116 - accuracy: 0.9648 - val_loss: 0.1300 - val_accuracy: 0.9547
# Epoch 113/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1169 - accuracy: 0.9551 - val_loss: 0.1245 - val_accuracy: 0.9609
# Epoch 114/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1039 - accuracy: 0.9656 - val_loss: 0.1248 - val_accuracy: 0.9563
# Epoch 115/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1068 - accuracy: 0.9633 - val_loss: 0.1214 - val_accuracy: 0.9641
# Epoch 116/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1054 - accuracy: 0.9660 - val_loss: 0.1453 - val_accuracy: 0.9563
# Epoch 117/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1071 - accuracy: 0.9613 - val_loss: 0.1298 - val_accuracy: 0.9594
# Epoch 118/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1064 - accuracy: 0.9652 - val_loss: 0.1189 - val_accuracy: 0.9625
# Epoch 119/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1102 - accuracy: 0.9652 - val_loss: 0.1298 - val_accuracy: 0.9625
# Epoch 120/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.1013 - accuracy: 0.9641 - val_loss: 0.1435 - val_accuracy: 0.9516
# Epoch 121/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1144 - accuracy: 0.9578 - val_loss: 0.1215 - val_accuracy: 0.9578
# Epoch 122/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1035 - accuracy: 0.9641 - val_loss: 0.1231 - val_accuracy: 0.9641
# Epoch 123/200
# 5/5 [==============================] - 0s 68ms/step - loss: 0.1093 - accuracy: 0.9625 - val_loss: 0.1333 - val_accuracy: 0.9500
# Epoch 124/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0967 - accuracy: 0.9691 - val_loss: 0.1211 - val_accuracy: 0.9625
# Epoch 125/200
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0987 - accuracy: 0.9641 - val_loss: 0.1305 - val_accuracy: 0.9594
# Epoch 126/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1007 - accuracy: 0.9629 - val_loss: 0.1238 - val_accuracy: 0.9625
# Epoch 127/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0957 - accuracy: 0.9676 - val_loss: 0.1214 - val_accuracy: 0.9625
# Epoch 128/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0944 - accuracy: 0.9688 - val_loss: 0.1259 - val_accuracy: 0.9672
# Epoch 129/200
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0949 - accuracy: 0.9672 - val_loss: 0.1181 - val_accuracy: 0.9625
# Epoch 130/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0931 - accuracy: 0.9703 - val_loss: 0.1232 - val_accuracy: 0.9578
# Epoch 131/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0977 - accuracy: 0.9664 - val_loss: 0.1153 - val_accuracy: 0.9547
# Epoch 132/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0916 - accuracy: 0.9691 - val_loss: 0.1432 - val_accuracy: 0.9500
# Epoch 133/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0942 - accuracy: 0.9672 - val_loss: 0.1226 - val_accuracy: 0.9609
# Epoch 134/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0905 - accuracy: 0.9668 - val_loss: 0.1217 - val_accuracy: 0.9641
# Epoch 135/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0963 - accuracy: 0.9672 - val_loss: 0.1187 - val_accuracy: 0.9656
# Epoch 136/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0957 - accuracy: 0.9688 - val_loss: 0.1245 - val_accuracy: 0.9609
# Epoch 137/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0860 - accuracy: 0.9723 - val_loss: 0.1295 - val_accuracy: 0.9547
# Epoch 138/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0981 - accuracy: 0.9707 - val_loss: 0.1195 - val_accuracy: 0.9531
# Epoch 139/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0909 - accuracy: 0.9691 - val_loss: 0.1295 - val_accuracy: 0.9641
# Epoch 140/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0919 - accuracy: 0.9699 - val_loss: 0.1196 - val_accuracy: 0.9594
# Epoch 141/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0847 - accuracy: 0.9707 - val_loss: 0.1360 - val_accuracy: 0.9578
# Epoch 142/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0864 - accuracy: 0.9719 - val_loss: 0.1226 - val_accuracy: 0.9547
# Epoch 143/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0881 - accuracy: 0.9719 - val_loss: 0.1295 - val_accuracy: 0.9609
# Epoch 144/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0912 - accuracy: 0.9707 - val_loss: 0.1259 - val_accuracy: 0.9609
# Epoch 145/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0845 - accuracy: 0.9738 - val_loss: 0.1370 - val_accuracy: 0.9547
# Epoch 146/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0801 - accuracy: 0.9746 - val_loss: 0.1163 - val_accuracy: 0.9656
# Epoch 147/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0794 - accuracy: 0.9773 - val_loss: 0.1093 - val_accuracy: 0.9688
# Epoch 148/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0767 - accuracy: 0.9758 - val_loss: 0.1167 - val_accuracy: 0.9641
# Epoch 149/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0855 - accuracy: 0.9727 - val_loss: 0.1298 - val_accuracy: 0.9578
# Epoch 150/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0839 - accuracy: 0.9695 - val_loss: 0.1234 - val_accuracy: 0.9594
# Epoch 151/200
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0840 - accuracy: 0.9715 - val_loss: 0.1151 - val_accuracy: 0.9625
# Epoch 152/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0857 - accuracy: 0.9672 - val_loss: 0.1247 - val_accuracy: 0.9609
# Epoch 153/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0829 - accuracy: 0.9758 - val_loss: 0.1328 - val_accuracy: 0.9516
# Epoch 154/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0761 - accuracy: 0.9711 - val_loss: 0.1228 - val_accuracy: 0.9594
# Epoch 155/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0786 - accuracy: 0.9738 - val_loss: 0.1124 - val_accuracy: 0.9625
# Epoch 156/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0828 - accuracy: 0.9688 - val_loss: 0.1181 - val_accuracy: 0.9625
# Epoch 157/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0800 - accuracy: 0.9734 - val_loss: 0.1183 - val_accuracy: 0.9594
# Epoch 158/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0723 - accuracy: 0.9727 - val_loss: 0.1105 - val_accuracy: 0.9656
# Epoch 159/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0695 - accuracy: 0.9785 - val_loss: 0.1104 - val_accuracy: 0.9625
# Epoch 160/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0708 - accuracy: 0.9770 - val_loss: 0.1242 - val_accuracy: 0.9594
# Epoch 161/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0787 - accuracy: 0.9719 - val_loss: 0.1270 - val_accuracy: 0.9563
# Epoch 162/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0786 - accuracy: 0.9738 - val_loss: 0.1132 - val_accuracy: 0.9641
# Epoch 163/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0787 - accuracy: 0.9730 - val_loss: 0.1097 - val_accuracy: 0.9625
# Epoch 164/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0779 - accuracy: 0.9750 - val_loss: 0.1119 - val_accuracy: 0.9641
# Epoch 165/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0724 - accuracy: 0.9773 - val_loss: 0.1086 - val_accuracy: 0.9641
# Epoch 166/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0744 - accuracy: 0.9754 - val_loss: 0.1108 - val_accuracy: 0.9688
# Epoch 167/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0677 - accuracy: 0.9809 - val_loss: 0.1173 - val_accuracy: 0.9625
# Epoch 168/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0705 - accuracy: 0.9777 - val_loss: 0.1087 - val_accuracy: 0.9656
# Epoch 169/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0734 - accuracy: 0.9742 - val_loss: 0.1152 - val_accuracy: 0.9625
# Epoch 170/200
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0701 - accuracy: 0.9773 - val_loss: 0.1135 - val_accuracy: 0.9672
# Epoch 171/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0667 - accuracy: 0.9781 - val_loss: 0.1087 - val_accuracy: 0.9656
# Epoch 172/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0713 - accuracy: 0.9734 - val_loss: 0.1251 - val_accuracy: 0.9547
# Epoch 173/200
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0784 - accuracy: 0.9723 - val_loss: 0.1368 - val_accuracy: 0.9594
# Epoch 174/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0757 - accuracy: 0.9727 - val_loss: 0.1150 - val_accuracy: 0.9672
# Epoch 175/200
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0802 - accuracy: 0.9711 - val_loss: 0.1276 - val_accuracy: 0.9563
# Epoch 176/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0750 - accuracy: 0.9738 - val_loss: 0.1419 - val_accuracy: 0.9484
# Epoch 177/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0737 - accuracy: 0.9770 - val_loss: 0.1196 - val_accuracy: 0.9719
# Epoch 178/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0807 - accuracy: 0.9711 - val_loss: 0.1389 - val_accuracy: 0.9500
# Epoch 179/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0881 - accuracy: 0.9676 - val_loss: 0.1253 - val_accuracy: 0.9563
# Epoch 180/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0815 - accuracy: 0.9707 - val_loss: 0.1116 - val_accuracy: 0.9656
# Epoch 181/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0719 - accuracy: 0.9762 - val_loss: 0.1391 - val_accuracy: 0.9531
# Epoch 182/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0769 - accuracy: 0.9750 - val_loss: 0.1152 - val_accuracy: 0.9641
# Epoch 183/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0682 - accuracy: 0.9773 - val_loss: 0.1185 - val_accuracy: 0.9594
# Epoch 184/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0657 - accuracy: 0.9773 - val_loss: 0.1072 - val_accuracy: 0.9703
# Epoch 185/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0636 - accuracy: 0.9801 - val_loss: 0.1110 - val_accuracy: 0.9672
# Epoch 186/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0634 - accuracy: 0.9820 - val_loss: 0.1132 - val_accuracy: 0.9625
# Epoch 187/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.1205 - val_accuracy: 0.9563
# Epoch 188/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0610 - accuracy: 0.9785 - val_loss: 0.1138 - val_accuracy: 0.9609
# Epoch 189/200
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0603 - accuracy: 0.9801 - val_loss: 0.1214 - val_accuracy: 0.9641
# Epoch 190/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0592 - accuracy: 0.9828 - val_loss: 0.1139 - val_accuracy: 0.9656
# Epoch 191/200
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0551 - accuracy: 0.9820 - val_loss: 0.1203 - val_accuracy: 0.9641
# Epoch 192/200
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0643 - accuracy: 0.9793 - val_loss: 0.1034 - val_accuracy: 0.9703
# Epoch 193/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0570 - accuracy: 0.9820 - val_loss: 0.1136 - val_accuracy: 0.9656
# Epoch 194/200
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0567 - accuracy: 0.9801 - val_loss: 0.1207 - val_accuracy: 0.9656
# Epoch 195/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0542 - accuracy: 0.9828 - val_loss: 0.1090 - val_accuracy: 0.9672
# Epoch 196/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0581 - accuracy: 0.9809 - val_loss: 0.1266 - val_accuracy: 0.9609
# Epoch 197/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0597 - accuracy: 0.9785 - val_loss: 0.1138 - val_accuracy: 0.9703
# Epoch 198/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0698 - accuracy: 0.9773 - val_loss: 0.1122 - val_accuracy: 0.9719
# Epoch 199/200
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0579 - accuracy: 0.9801 - val_loss: 0.1167 - val_accuracy: 0.9641
# Epoch 200/200
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0555 - accuracy: 0.9801 - val_loss: 0.1080 - val_accuracy: 0.9688

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 5/5 [==============================] - 0s 84ms/step - loss: 1.7915 - accuracy: 0.3871 - val_loss: 1.3385 - val_accuracy: 0.6516
# Epoch 2/60
# 5/5 [==============================] - 0s 51ms/step - loss: 1.2213 - accuracy: 0.6574 - val_loss: 0.9893 - val_accuracy: 0.6547
# Epoch 3/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.9481 - accuracy: 0.6914 - val_loss: 0.8284 - val_accuracy: 0.7359
# Epoch 4/60
# 5/5 [==============================] - 0s 57ms/step - loss: 0.8250 - accuracy: 0.7242 - val_loss: 0.7603 - val_accuracy: 0.7828
# Epoch 5/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.7685 - accuracy: 0.7410 - val_loss: 0.6908 - val_accuracy: 0.8078
# Epoch 6/60
# 5/5 [==============================] - 0s 63ms/step - loss: 0.7141 - accuracy: 0.7812 - val_loss: 0.6428 - val_accuracy: 0.8094
# Epoch 7/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.6600 - accuracy: 0.7973 - val_loss: 0.5874 - val_accuracy: 0.8297
# Epoch 8/60
# 5/5 [==============================] - 0s 49ms/step - loss: 0.6158 - accuracy: 0.8090 - val_loss: 0.5333 - val_accuracy: 0.8406
# Epoch 9/60
# 5/5 [==============================] - 0s 61ms/step - loss: 0.5730 - accuracy: 0.8172 - val_loss: 0.4986 - val_accuracy: 0.8531
# Epoch 10/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.5389 - accuracy: 0.8273 - val_loss: 0.4719 - val_accuracy: 0.8672
# Epoch 11/60
# 5/5 [==============================] - 0s 60ms/step - loss: 0.5096 - accuracy: 0.8375 - val_loss: 0.4484 - val_accuracy: 0.8625
# Epoch 12/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.5019 - accuracy: 0.8363 - val_loss: 0.4417 - val_accuracy: 0.8594
# Epoch 13/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.4740 - accuracy: 0.8480 - val_loss: 0.4083 - val_accuracy: 0.8781
# Epoch 14/60
# 5/5 [==============================] - 0s 58ms/step - loss: 0.4382 - accuracy: 0.8629 - val_loss: 0.4048 - val_accuracy: 0.8953
# Epoch 15/60
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4269 - accuracy: 0.8691 - val_loss: 0.3891 - val_accuracy: 0.8734
# Epoch 16/60
# 5/5 [==============================] - 0s 65ms/step - loss: 0.4185 - accuracy: 0.8719 - val_loss: 0.3629 - val_accuracy: 0.8906
# Epoch 17/60
# 5/5 [==============================] - 0s 63ms/step - loss: 0.4046 - accuracy: 0.8781 - val_loss: 0.3582 - val_accuracy: 0.9062
# Epoch 18/60
# 5/5 [==============================] - 0s 69ms/step - loss: 0.3859 - accuracy: 0.8848 - val_loss: 0.3411 - val_accuracy: 0.8969
# Epoch 19/60
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3801 - accuracy: 0.8809 - val_loss: 0.3264 - val_accuracy: 0.9078
# Epoch 20/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3721 - accuracy: 0.8875 - val_loss: 0.3226 - val_accuracy: 0.9109
# Epoch 21/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.3588 - accuracy: 0.8918 - val_loss: 0.3114 - val_accuracy: 0.9078
# Epoch 22/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.3462 - accuracy: 0.9012 - val_loss: 0.3080 - val_accuracy: 0.9062
# Epoch 23/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3422 - accuracy: 0.8953 - val_loss: 0.3071 - val_accuracy: 0.9156
# Epoch 24/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3353 - accuracy: 0.9023 - val_loss: 0.2940 - val_accuracy: 0.9109
# Epoch 25/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3328 - accuracy: 0.8965 - val_loss: 0.2901 - val_accuracy: 0.9094
# Epoch 26/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.3305 - accuracy: 0.8965 - val_loss: 0.2832 - val_accuracy: 0.9109
# Epoch 27/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3165 - accuracy: 0.9004 - val_loss: 0.2808 - val_accuracy: 0.9094
# Epoch 28/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.3229 - accuracy: 0.9035 - val_loss: 0.2791 - val_accuracy: 0.9109
# Epoch 29/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3116 - accuracy: 0.9082 - val_loss: 0.2745 - val_accuracy: 0.9109
# Epoch 30/60
# 5/5 [==============================] - 0s 52ms/step - loss: 0.3035 - accuracy: 0.9090 - val_loss: 0.2704 - val_accuracy: 0.9078
# Epoch 31/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2902 - accuracy: 0.9141 - val_loss: 0.2644 - val_accuracy: 0.9172
# Epoch 32/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2889 - accuracy: 0.9102 - val_loss: 0.2635 - val_accuracy: 0.9109
# Epoch 33/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2903 - accuracy: 0.9152 - val_loss: 0.2612 - val_accuracy: 0.9109
# Epoch 34/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2831 - accuracy: 0.9141 - val_loss: 0.2756 - val_accuracy: 0.9047
# Epoch 35/60
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2755 - accuracy: 0.9117 - val_loss: 0.2704 - val_accuracy: 0.9047
# Epoch 36/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2792 - accuracy: 0.9148 - val_loss: 0.2491 - val_accuracy: 0.9094
# Epoch 37/60
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2657 - accuracy: 0.9168 - val_loss: 0.2403 - val_accuracy: 0.9234
# Epoch 38/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2711 - accuracy: 0.9176 - val_loss: 0.2456 - val_accuracy: 0.9250
# Epoch 39/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2715 - accuracy: 0.9203 - val_loss: 0.2505 - val_accuracy: 0.9219
# Epoch 40/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2697 - accuracy: 0.9145 - val_loss: 0.2462 - val_accuracy: 0.9219
# Epoch 41/60
# 5/5 [==============================] - 0s 69ms/step - loss: 0.2526 - accuracy: 0.9219 - val_loss: 0.2249 - val_accuracy: 0.9234
# Epoch 42/60
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2516 - accuracy: 0.9246 - val_loss: 0.2239 - val_accuracy: 0.9187
# Epoch 43/60
# 5/5 [==============================] - 0s 69ms/step - loss: 0.2375 - accuracy: 0.9246 - val_loss: 0.2292 - val_accuracy: 0.9219
# Epoch 44/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2465 - accuracy: 0.9223 - val_loss: 0.2263 - val_accuracy: 0.9172
# Epoch 45/60
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2394 - accuracy: 0.9238 - val_loss: 0.2198 - val_accuracy: 0.9203
# Epoch 46/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2321 - accuracy: 0.9246 - val_loss: 0.2132 - val_accuracy: 0.9172
# Epoch 47/60
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2333 - accuracy: 0.9277 - val_loss: 0.2168 - val_accuracy: 0.9281
# Epoch 48/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2336 - accuracy: 0.9266 - val_loss: 0.2238 - val_accuracy: 0.9281
# Epoch 49/60
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2283 - accuracy: 0.9270 - val_loss: 0.2248 - val_accuracy: 0.9297
# Epoch 50/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2358 - accuracy: 0.9230 - val_loss: 0.2083 - val_accuracy: 0.9375
# Epoch 51/60
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2368 - accuracy: 0.9223 - val_loss: 0.2042 - val_accuracy: 0.9266
# Epoch 52/60
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2293 - accuracy: 0.9250 - val_loss: 0.2046 - val_accuracy: 0.9187
# Epoch 53/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2136 - accuracy: 0.9309 - val_loss: 0.1987 - val_accuracy: 0.9375
# Epoch 54/60
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2040 - accuracy: 0.9324 - val_loss: 0.1930 - val_accuracy: 0.9219
# Epoch 55/60
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2076 - accuracy: 0.9324 - val_loss: 0.1853 - val_accuracy: 0.9359
# Epoch 56/60
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2066 - accuracy: 0.9285 - val_loss: 0.1925 - val_accuracy: 0.9375
# Epoch 57/60
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1990 - accuracy: 0.9344 - val_loss: 0.1979 - val_accuracy: 0.9359
# Epoch 58/60
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2023 - accuracy: 0.9312 - val_loss: 0.1835 - val_accuracy: 0.9281
# Epoch 59/60
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1966 - accuracy: 0.9348 - val_loss: 0.1821 - val_accuracy: 0.9375
# Epoch 60/60
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2051 - accuracy: 0.9355 - val_loss: 0.1824 - val_accuracy: 0.9469

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1683 - accuracy: 0.9461
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1824 - accuracy: 0.9469
# 0.946093738079071 0.9468749761581421

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 106, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:07

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 59   1   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 120   0   0   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 197   4   0   2   1]
#  [  0   0   0   0   4  93   0   3   0]
#  [  0   0   0   0   5   0   0   1   0]
#  [  0   0   0   0   1   3   0  16   0]
#  [  0   0   0   0   7   2   0   0  11]]
#
# Accuracy Score
# 0.946875
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      0.98      0.99        60
#      clouds       0.99      1.00      1.00       100
#  vegetation       1.00      1.00      1.00       120
#       water       1.00      1.00      1.00        10
#       built       0.92      0.97      0.94       204
#     windows       0.91      0.93      0.92       100
#       roads       0.00      0.00      0.00         6
#        cars       0.73      0.80      0.76        20
#       metal       0.92      0.55      0.69        20
#
# avg / total       0.94      0.95      0.94       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 106)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 106)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 106)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 106) (80, 106)
# clouds  (400, 106) (100, 106)
# vegetation  (488, 106) (122, 106)
# built  (960, 106) (240, 106)
# windows  (400, 106) (100, 106)
# roads  (48, 106) (12, 106)
# cars  (44, 106) (11, 106)
# metal  (184, 106) (46, 106)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 106) (2844,) (2844, 2)
# (711, 106) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 74ms/step - loss: 1.6588 - accuracy: 0.4318 - val_loss: 1.1800 - val_accuracy: 0.6596
# Epoch 2/200
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0962 - accuracy: 0.6297 - val_loss: 0.9195 - val_accuracy: 0.6624
# Epoch 3/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.8607 - accuracy: 0.6772 - val_loss: 0.7622 - val_accuracy: 0.7243
# Epoch 4/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.7315 - accuracy: 0.7141 - val_loss: 0.6663 - val_accuracy: 0.7525
# Epoch 5/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.6438 - accuracy: 0.7468 - val_loss: 0.6367 - val_accuracy: 0.7314
# Epoch 6/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.6198 - accuracy: 0.7500 - val_loss: 0.6345 - val_accuracy: 0.7511
# Epoch 7/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.5850 - accuracy: 0.7665 - val_loss: 0.5829 - val_accuracy: 0.7778
# Epoch 8/200
# 6/6 [==============================] - 0s 44ms/step - loss: 0.5597 - accuracy: 0.7757 - val_loss: 0.5725 - val_accuracy: 0.7848
# Epoch 9/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.5433 - accuracy: 0.7869 - val_loss: 0.5855 - val_accuracy: 0.7834
# Epoch 10/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.5304 - accuracy: 0.7943 - val_loss: 0.5407 - val_accuracy: 0.8017
# Epoch 11/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.5046 - accuracy: 0.8179 - val_loss: 0.5636 - val_accuracy: 0.7862
# Epoch 12/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.5053 - accuracy: 0.8059 - val_loss: 0.5596 - val_accuracy: 0.8003
# Epoch 13/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.5035 - accuracy: 0.8027 - val_loss: 0.5689 - val_accuracy: 0.7918
# Epoch 14/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4847 - accuracy: 0.8168 - val_loss: 0.5069 - val_accuracy: 0.8129
# Epoch 15/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4818 - accuracy: 0.8224 - val_loss: 0.5197 - val_accuracy: 0.8031
# Epoch 16/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4577 - accuracy: 0.8217 - val_loss: 0.5047 - val_accuracy: 0.8200
# Epoch 17/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4493 - accuracy: 0.8386 - val_loss: 0.4839 - val_accuracy: 0.8087
# Epoch 18/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4336 - accuracy: 0.8397 - val_loss: 0.4744 - val_accuracy: 0.8143
# Epoch 19/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4137 - accuracy: 0.8474 - val_loss: 0.4846 - val_accuracy: 0.8172
# Epoch 20/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4171 - accuracy: 0.8442 - val_loss: 0.4618 - val_accuracy: 0.8312
# Epoch 21/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.4026 - accuracy: 0.8548 - val_loss: 0.4570 - val_accuracy: 0.8326
# Epoch 22/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3985 - accuracy: 0.8636 - val_loss: 0.4507 - val_accuracy: 0.8326
# Epoch 23/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.3966 - accuracy: 0.8534 - val_loss: 0.4519 - val_accuracy: 0.8298
# Epoch 24/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3958 - accuracy: 0.8523 - val_loss: 0.4510 - val_accuracy: 0.8242
# Epoch 25/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3894 - accuracy: 0.8551 - val_loss: 0.4281 - val_accuracy: 0.8495
# Epoch 26/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3821 - accuracy: 0.8579 - val_loss: 0.4320 - val_accuracy: 0.8495
# Epoch 27/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3775 - accuracy: 0.8576 - val_loss: 0.4357 - val_accuracy: 0.8565
# Epoch 28/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3740 - accuracy: 0.8618 - val_loss: 0.4362 - val_accuracy: 0.8481
# Epoch 29/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3674 - accuracy: 0.8664 - val_loss: 0.4043 - val_accuracy: 0.8537
# Epoch 30/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3544 - accuracy: 0.8688 - val_loss: 0.4053 - val_accuracy: 0.8650
# Epoch 31/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3453 - accuracy: 0.8688 - val_loss: 0.4047 - val_accuracy: 0.8509
# Epoch 32/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3435 - accuracy: 0.8734 - val_loss: 0.3979 - val_accuracy: 0.8523
# Epoch 33/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3385 - accuracy: 0.8787 - val_loss: 0.4014 - val_accuracy: 0.8537
# Epoch 34/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3317 - accuracy: 0.8808 - val_loss: 0.3866 - val_accuracy: 0.8664
# Epoch 35/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3300 - accuracy: 0.8812 - val_loss: 0.3866 - val_accuracy: 0.8622
# Epoch 36/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3195 - accuracy: 0.8805 - val_loss: 0.3805 - val_accuracy: 0.8636
# Epoch 37/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.3202 - accuracy: 0.8875 - val_loss: 0.3744 - val_accuracy: 0.8762
# Epoch 38/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3236 - accuracy: 0.8822 - val_loss: 0.3960 - val_accuracy: 0.8692
# Epoch 39/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3248 - accuracy: 0.8805 - val_loss: 0.3773 - val_accuracy: 0.8650
# Epoch 40/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3140 - accuracy: 0.8833 - val_loss: 0.4149 - val_accuracy: 0.8579
# Epoch 41/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3220 - accuracy: 0.8829 - val_loss: 0.3812 - val_accuracy: 0.8636
# Epoch 42/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.3122 - accuracy: 0.8864 - val_loss: 0.3629 - val_accuracy: 0.8720
# Epoch 43/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3001 - accuracy: 0.8899 - val_loss: 0.3619 - val_accuracy: 0.8805
# Epoch 44/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.3074 - accuracy: 0.8797 - val_loss: 0.3452 - val_accuracy: 0.8805
# Epoch 45/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2883 - accuracy: 0.8899 - val_loss: 0.3481 - val_accuracy: 0.8790
# Epoch 46/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2819 - accuracy: 0.8984 - val_loss: 0.3541 - val_accuracy: 0.8819
# Epoch 47/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2808 - accuracy: 0.8980 - val_loss: 0.3520 - val_accuracy: 0.8819
# Epoch 48/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2793 - accuracy: 0.8994 - val_loss: 0.3271 - val_accuracy: 0.8790
# Epoch 49/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2717 - accuracy: 0.9023 - val_loss: 0.3270 - val_accuracy: 0.8861
# Epoch 50/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2698 - accuracy: 0.8994 - val_loss: 0.3370 - val_accuracy: 0.8875
# Epoch 51/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2772 - accuracy: 0.9015 - val_loss: 0.3325 - val_accuracy: 0.8917
# Epoch 52/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2720 - accuracy: 0.8994 - val_loss: 0.3303 - val_accuracy: 0.8776
# Epoch 53/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2607 - accuracy: 0.9015 - val_loss: 0.3305 - val_accuracy: 0.8833
# Epoch 54/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2689 - accuracy: 0.8991 - val_loss: 0.3099 - val_accuracy: 0.8959
# Epoch 55/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2691 - accuracy: 0.9008 - val_loss: 0.3172 - val_accuracy: 0.8903
# Epoch 56/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2616 - accuracy: 0.9110 - val_loss: 0.3045 - val_accuracy: 0.8931
# Epoch 57/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2438 - accuracy: 0.9153 - val_loss: 0.3033 - val_accuracy: 0.9044
# Epoch 58/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.2489 - accuracy: 0.9100 - val_loss: 0.3022 - val_accuracy: 0.8917
# Epoch 59/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2539 - accuracy: 0.9061 - val_loss: 0.3076 - val_accuracy: 0.8917
# Epoch 60/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2478 - accuracy: 0.9096 - val_loss: 0.3175 - val_accuracy: 0.8931
# Epoch 61/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2485 - accuracy: 0.9061 - val_loss: 0.3137 - val_accuracy: 0.8889
# Epoch 62/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2390 - accuracy: 0.9114 - val_loss: 0.3433 - val_accuracy: 0.8833
# Epoch 63/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2509 - accuracy: 0.9079 - val_loss: 0.3021 - val_accuracy: 0.8889
# Epoch 64/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2452 - accuracy: 0.9082 - val_loss: 0.2862 - val_accuracy: 0.8987
# Epoch 65/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2418 - accuracy: 0.9072 - val_loss: 0.2983 - val_accuracy: 0.8917
# Epoch 66/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2408 - accuracy: 0.9124 - val_loss: 0.2946 - val_accuracy: 0.9044
# Epoch 67/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2337 - accuracy: 0.9135 - val_loss: 0.2883 - val_accuracy: 0.8959
# Epoch 68/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2361 - accuracy: 0.9121 - val_loss: 0.2981 - val_accuracy: 0.8973
# Epoch 69/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2224 - accuracy: 0.9163 - val_loss: 0.2893 - val_accuracy: 0.9044
# Epoch 70/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.2255 - accuracy: 0.9209 - val_loss: 0.3062 - val_accuracy: 0.8833
# Epoch 71/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2307 - accuracy: 0.9089 - val_loss: 0.3075 - val_accuracy: 0.8889
# Epoch 72/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2286 - accuracy: 0.9121 - val_loss: 0.2996 - val_accuracy: 0.8931
# Epoch 73/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2228 - accuracy: 0.9212 - val_loss: 0.2776 - val_accuracy: 0.9072
# Epoch 74/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2238 - accuracy: 0.9121 - val_loss: 0.2787 - val_accuracy: 0.9044
# Epoch 75/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2196 - accuracy: 0.9184 - val_loss: 0.2789 - val_accuracy: 0.9072
# Epoch 76/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2215 - accuracy: 0.9110 - val_loss: 0.2696 - val_accuracy: 0.9044
# Epoch 77/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2088 - accuracy: 0.9255 - val_loss: 0.2562 - val_accuracy: 0.9170
# Epoch 78/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.2015 - accuracy: 0.9230 - val_loss: 0.2696 - val_accuracy: 0.9058
# Epoch 79/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2146 - accuracy: 0.9181 - val_loss: 0.2603 - val_accuracy: 0.9114
# Epoch 80/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2086 - accuracy: 0.9212 - val_loss: 0.2647 - val_accuracy: 0.9015
# Epoch 81/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1968 - accuracy: 0.9311 - val_loss: 0.2669 - val_accuracy: 0.9030
# Epoch 82/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2080 - accuracy: 0.9248 - val_loss: 0.2632 - val_accuracy: 0.9072
# Epoch 83/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1957 - accuracy: 0.9279 - val_loss: 0.2516 - val_accuracy: 0.9170
# Epoch 84/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1968 - accuracy: 0.9251 - val_loss: 0.2579 - val_accuracy: 0.9100
# Epoch 85/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1927 - accuracy: 0.9300 - val_loss: 0.2428 - val_accuracy: 0.9226
# Epoch 86/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1977 - accuracy: 0.9286 - val_loss: 0.2655 - val_accuracy: 0.9100
# Epoch 87/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1976 - accuracy: 0.9300 - val_loss: 0.2615 - val_accuracy: 0.9142
# Epoch 88/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1908 - accuracy: 0.9304 - val_loss: 0.2513 - val_accuracy: 0.9156
# Epoch 89/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1889 - accuracy: 0.9283 - val_loss: 0.2517 - val_accuracy: 0.9170
# Epoch 90/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1988 - accuracy: 0.9255 - val_loss: 0.2449 - val_accuracy: 0.9255
# Epoch 91/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1888 - accuracy: 0.9304 - val_loss: 0.2502 - val_accuracy: 0.9114
# Epoch 92/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1850 - accuracy: 0.9311 - val_loss: 0.2732 - val_accuracy: 0.9058
# Epoch 93/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1962 - accuracy: 0.9265 - val_loss: 0.2693 - val_accuracy: 0.9015
# Epoch 94/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1841 - accuracy: 0.9318 - val_loss: 0.2603 - val_accuracy: 0.9128
# Epoch 95/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1837 - accuracy: 0.9332 - val_loss: 0.2338 - val_accuracy: 0.9226
# Epoch 96/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1879 - accuracy: 0.9297 - val_loss: 0.2491 - val_accuracy: 0.9142
# Epoch 97/200
# 6/6 [==============================] - 0s 42ms/step - loss: 0.1859 - accuracy: 0.9304 - val_loss: 0.2417 - val_accuracy: 0.9156
# Epoch 98/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1787 - accuracy: 0.9311 - val_loss: 0.2440 - val_accuracy: 0.9198
# Epoch 99/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1783 - accuracy: 0.9381 - val_loss: 0.2518 - val_accuracy: 0.9072
# Epoch 100/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2055 - accuracy: 0.9212 - val_loss: 0.2650 - val_accuracy: 0.9114
# Epoch 101/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1868 - accuracy: 0.9318 - val_loss: 0.2736 - val_accuracy: 0.9058
# Epoch 102/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1928 - accuracy: 0.9272 - val_loss: 0.2439 - val_accuracy: 0.9212
# Epoch 103/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1793 - accuracy: 0.9335 - val_loss: 0.2336 - val_accuracy: 0.9297
# Epoch 104/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1743 - accuracy: 0.9378 - val_loss: 0.2409 - val_accuracy: 0.9226
# Epoch 105/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1699 - accuracy: 0.9335 - val_loss: 0.2609 - val_accuracy: 0.9128
# Epoch 106/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1777 - accuracy: 0.9314 - val_loss: 0.2403 - val_accuracy: 0.9212
# Epoch 107/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1650 - accuracy: 0.9427 - val_loss: 0.2261 - val_accuracy: 0.9255
# Epoch 108/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1677 - accuracy: 0.9381 - val_loss: 0.2408 - val_accuracy: 0.9269
# Epoch 109/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1640 - accuracy: 0.9406 - val_loss: 0.2273 - val_accuracy: 0.9255
# Epoch 110/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1605 - accuracy: 0.9434 - val_loss: 0.2272 - val_accuracy: 0.9297
# Epoch 111/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1616 - accuracy: 0.9385 - val_loss: 0.2195 - val_accuracy: 0.9226
# Epoch 112/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1510 - accuracy: 0.9423 - val_loss: 0.2325 - val_accuracy: 0.9269
# Epoch 113/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1608 - accuracy: 0.9402 - val_loss: 0.2167 - val_accuracy: 0.9353
# Epoch 114/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1607 - accuracy: 0.9448 - val_loss: 0.2245 - val_accuracy: 0.9269
# Epoch 115/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1538 - accuracy: 0.9455 - val_loss: 0.2136 - val_accuracy: 0.9353
# Epoch 116/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1569 - accuracy: 0.9437 - val_loss: 0.2134 - val_accuracy: 0.9367
# Epoch 117/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.1493 - accuracy: 0.9395 - val_loss: 0.2217 - val_accuracy: 0.9381
# Epoch 118/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1611 - accuracy: 0.9427 - val_loss: 0.2376 - val_accuracy: 0.9311
# Epoch 119/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1634 - accuracy: 0.9392 - val_loss: 0.2261 - val_accuracy: 0.9283
# Epoch 120/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1540 - accuracy: 0.9416 - val_loss: 0.2237 - val_accuracy: 0.9283
# Epoch 121/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1678 - accuracy: 0.9328 - val_loss: 0.2247 - val_accuracy: 0.9198
# Epoch 122/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1630 - accuracy: 0.9378 - val_loss: 0.2286 - val_accuracy: 0.9212
# Epoch 123/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1621 - accuracy: 0.9444 - val_loss: 0.2260 - val_accuracy: 0.9269
# Epoch 124/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1543 - accuracy: 0.9444 - val_loss: 0.2237 - val_accuracy: 0.9353
# Epoch 125/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1461 - accuracy: 0.9483 - val_loss: 0.2306 - val_accuracy: 0.9269
# Epoch 126/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1464 - accuracy: 0.9451 - val_loss: 0.2383 - val_accuracy: 0.9241
# Epoch 127/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1677 - accuracy: 0.9413 - val_loss: 0.2131 - val_accuracy: 0.9311
# Epoch 128/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1500 - accuracy: 0.9469 - val_loss: 0.2209 - val_accuracy: 0.9311
# Epoch 129/200
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1394 - accuracy: 0.9501 - val_loss: 0.2396 - val_accuracy: 0.9255
# Epoch 130/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1493 - accuracy: 0.9466 - val_loss: 0.2355 - val_accuracy: 0.9297
# Epoch 131/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1399 - accuracy: 0.9501 - val_loss: 0.2295 - val_accuracy: 0.9184
# Epoch 132/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1456 - accuracy: 0.9494 - val_loss: 0.2261 - val_accuracy: 0.9269
# Epoch 133/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1563 - accuracy: 0.9437 - val_loss: 0.2514 - val_accuracy: 0.9241
# Epoch 134/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1703 - accuracy: 0.9360 - val_loss: 0.2575 - val_accuracy: 0.9184
# Epoch 135/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1664 - accuracy: 0.9385 - val_loss: 0.2486 - val_accuracy: 0.9170
# Epoch 136/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1718 - accuracy: 0.9378 - val_loss: 0.2205 - val_accuracy: 0.9283
# Epoch 137/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1549 - accuracy: 0.9434 - val_loss: 0.2506 - val_accuracy: 0.9212
# Epoch 138/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1516 - accuracy: 0.9430 - val_loss: 0.2254 - val_accuracy: 0.9381
# Epoch 139/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1366 - accuracy: 0.9515 - val_loss: 0.2187 - val_accuracy: 0.9283
# Epoch 140/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1474 - accuracy: 0.9427 - val_loss: 0.2430 - val_accuracy: 0.9170
# Epoch 141/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1416 - accuracy: 0.9466 - val_loss: 0.2220 - val_accuracy: 0.9381
# Epoch 142/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1378 - accuracy: 0.9504 - val_loss: 0.2206 - val_accuracy: 0.9339
# Epoch 143/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1413 - accuracy: 0.9501 - val_loss: 0.2116 - val_accuracy: 0.9381
# Epoch 144/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1330 - accuracy: 0.9529 - val_loss: 0.2065 - val_accuracy: 0.9451
# Epoch 145/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1395 - accuracy: 0.9504 - val_loss: 0.2239 - val_accuracy: 0.9367
# Epoch 146/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1371 - accuracy: 0.9522 - val_loss: 0.2230 - val_accuracy: 0.9283
# Epoch 147/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1315 - accuracy: 0.9476 - val_loss: 0.2248 - val_accuracy: 0.9297
# Epoch 148/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1366 - accuracy: 0.9501 - val_loss: 0.2109 - val_accuracy: 0.9297
# Epoch 149/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1268 - accuracy: 0.9546 - val_loss: 0.2131 - val_accuracy: 0.9325
# Epoch 150/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1322 - accuracy: 0.9515 - val_loss: 0.2073 - val_accuracy: 0.9423
# Epoch 151/200
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1264 - accuracy: 0.9557 - val_loss: 0.2116 - val_accuracy: 0.9339
# Epoch 152/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1270 - accuracy: 0.9560 - val_loss: 0.2093 - val_accuracy: 0.9395
# Epoch 153/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1370 - accuracy: 0.9494 - val_loss: 0.2518 - val_accuracy: 0.9170
# Epoch 154/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1485 - accuracy: 0.9497 - val_loss: 0.2472 - val_accuracy: 0.9212
# Epoch 155/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1467 - accuracy: 0.9487 - val_loss: 0.2274 - val_accuracy: 0.9325
# Epoch 156/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1394 - accuracy: 0.9490 - val_loss: 0.2233 - val_accuracy: 0.9283
# Epoch 157/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1362 - accuracy: 0.9462 - val_loss: 0.2071 - val_accuracy: 0.9381
# Epoch 158/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.1242 - accuracy: 0.9546 - val_loss: 0.2122 - val_accuracy: 0.9353
# Epoch 159/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1260 - accuracy: 0.9557 - val_loss: 0.1948 - val_accuracy: 0.9466
# Epoch 160/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1223 - accuracy: 0.9515 - val_loss: 0.1956 - val_accuracy: 0.9466
# Epoch 161/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1140 - accuracy: 0.9631 - val_loss: 0.2074 - val_accuracy: 0.9409
# Epoch 162/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1220 - accuracy: 0.9582 - val_loss: 0.2074 - val_accuracy: 0.9395
# Epoch 163/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1121 - accuracy: 0.9589 - val_loss: 0.1954 - val_accuracy: 0.9494
# Epoch 164/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1144 - accuracy: 0.9589 - val_loss: 0.1953 - val_accuracy: 0.9437
# Epoch 165/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1177 - accuracy: 0.9564 - val_loss: 0.2085 - val_accuracy: 0.9409
# Epoch 166/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1085 - accuracy: 0.9617 - val_loss: 0.2001 - val_accuracy: 0.9423
# Epoch 167/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1135 - accuracy: 0.9606 - val_loss: 0.1968 - val_accuracy: 0.9466
# Epoch 168/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1137 - accuracy: 0.9585 - val_loss: 0.2125 - val_accuracy: 0.9395
# Epoch 169/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1236 - accuracy: 0.9525 - val_loss: 0.1938 - val_accuracy: 0.9395
# Epoch 170/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1155 - accuracy: 0.9546 - val_loss: 0.1932 - val_accuracy: 0.9353
# Epoch 171/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1120 - accuracy: 0.9571 - val_loss: 0.2328 - val_accuracy: 0.9283
# Epoch 172/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1307 - accuracy: 0.9497 - val_loss: 0.2185 - val_accuracy: 0.9255
# Epoch 173/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1217 - accuracy: 0.9589 - val_loss: 0.2012 - val_accuracy: 0.9339
# Epoch 174/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1182 - accuracy: 0.9592 - val_loss: 0.2065 - val_accuracy: 0.9466
# Epoch 175/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1198 - accuracy: 0.9536 - val_loss: 0.2122 - val_accuracy: 0.9283
# Epoch 176/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1111 - accuracy: 0.9603 - val_loss: 0.2017 - val_accuracy: 0.9466
# Epoch 177/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1158 - accuracy: 0.9585 - val_loss: 0.2028 - val_accuracy: 0.9480
# Epoch 178/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.1069 - accuracy: 0.9603 - val_loss: 0.2114 - val_accuracy: 0.9395
# Epoch 179/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1249 - accuracy: 0.9546 - val_loss: 0.2036 - val_accuracy: 0.9395
# Epoch 180/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1093 - accuracy: 0.9610 - val_loss: 0.2108 - val_accuracy: 0.9437
# Epoch 181/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1094 - accuracy: 0.9599 - val_loss: 0.2014 - val_accuracy: 0.9451
# Epoch 182/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1092 - accuracy: 0.9613 - val_loss: 0.2199 - val_accuracy: 0.9381
# Epoch 183/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1121 - accuracy: 0.9564 - val_loss: 0.2078 - val_accuracy: 0.9466
# Epoch 184/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.1023 - accuracy: 0.9659 - val_loss: 0.2014 - val_accuracy: 0.9480
# Epoch 185/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1009 - accuracy: 0.9606 - val_loss: 0.2165 - val_accuracy: 0.9423
# Epoch 186/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1042 - accuracy: 0.9603 - val_loss: 0.2023 - val_accuracy: 0.9480
# Epoch 187/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1040 - accuracy: 0.9596 - val_loss: 0.1999 - val_accuracy: 0.9409
# Epoch 188/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1047 - accuracy: 0.9613 - val_loss: 0.2081 - val_accuracy: 0.9409
# Epoch 189/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.1110 - accuracy: 0.9575 - val_loss: 0.2051 - val_accuracy: 0.9480
# Epoch 190/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1130 - accuracy: 0.9568 - val_loss: 0.2015 - val_accuracy: 0.9423
# Epoch 191/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1043 - accuracy: 0.9645 - val_loss: 0.2064 - val_accuracy: 0.9409
# Epoch 192/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1112 - accuracy: 0.9557 - val_loss: 0.1986 - val_accuracy: 0.9409
# Epoch 193/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1135 - accuracy: 0.9571 - val_loss: 0.1917 - val_accuracy: 0.9381
# Epoch 194/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1091 - accuracy: 0.9557 - val_loss: 0.2174 - val_accuracy: 0.9353
# Epoch 195/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1156 - accuracy: 0.9589 - val_loss: 0.2177 - val_accuracy: 0.9409
# Epoch 196/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1042 - accuracy: 0.9631 - val_loss: 0.2027 - val_accuracy: 0.9409
# Epoch 197/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0966 - accuracy: 0.9645 - val_loss: 0.1989 - val_accuracy: 0.9437
# Epoch 198/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0926 - accuracy: 0.9677 - val_loss: 0.2153 - val_accuracy: 0.9437
# Epoch 199/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1020 - accuracy: 0.9599 - val_loss: 0.2027 - val_accuracy: 0.9423
# Epoch 200/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0953 - accuracy: 0.9684 - val_loss: 0.2060 - val_accuracy: 0.9480

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 6/6 [==============================] - 0s 78ms/step - loss: 1.7765 - accuracy: 0.3477 - val_loss: 1.3258 - val_accuracy: 0.6259
# Epoch 2/45
# 6/6 [==============================] - 0s 47ms/step - loss: 1.2095 - accuracy: 0.6108 - val_loss: 1.0037 - val_accuracy: 0.6582
# Epoch 3/45
# 6/6 [==============================] - 0s 54ms/step - loss: 0.9537 - accuracy: 0.6617 - val_loss: 0.8491 - val_accuracy: 0.6639
# Epoch 4/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.8079 - accuracy: 0.7022 - val_loss: 0.7620 - val_accuracy: 0.6695
# Epoch 5/45
# 6/6 [==============================] - 0s 56ms/step - loss: 0.7100 - accuracy: 0.7177 - val_loss: 0.6600 - val_accuracy: 0.7482
# Epoch 6/45
# 6/6 [==============================] - 0s 54ms/step - loss: 0.6297 - accuracy: 0.7461 - val_loss: 0.6161 - val_accuracy: 0.7511
# Epoch 7/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5889 - accuracy: 0.7672 - val_loss: 0.5935 - val_accuracy: 0.7848
# Epoch 8/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5706 - accuracy: 0.7683 - val_loss: 0.5796 - val_accuracy: 0.7989
# Epoch 9/45
# 6/6 [==============================] - 0s 59ms/step - loss: 0.5400 - accuracy: 0.7831 - val_loss: 0.5567 - val_accuracy: 0.7947
# Epoch 10/45
# 6/6 [==============================] - 0s 62ms/step - loss: 0.5267 - accuracy: 0.7992 - val_loss: 0.5835 - val_accuracy: 0.7623
# Epoch 11/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.5242 - accuracy: 0.7947 - val_loss: 0.5479 - val_accuracy: 0.7904
# Epoch 12/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4866 - accuracy: 0.8221 - val_loss: 0.5517 - val_accuracy: 0.7904
# Epoch 13/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4982 - accuracy: 0.8098 - val_loss: 0.5231 - val_accuracy: 0.8158
# Epoch 14/45
# 6/6 [==============================] - 0s 47ms/step - loss: 0.4830 - accuracy: 0.8165 - val_loss: 0.5193 - val_accuracy: 0.8158
# Epoch 15/45
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4594 - accuracy: 0.8365 - val_loss: 0.5125 - val_accuracy: 0.8115
# Epoch 16/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4492 - accuracy: 0.8365 - val_loss: 0.5010 - val_accuracy: 0.8073
# Epoch 17/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.4464 - accuracy: 0.8333 - val_loss: 0.5068 - val_accuracy: 0.8200
# Epoch 18/45
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4557 - accuracy: 0.8326 - val_loss: 0.5194 - val_accuracy: 0.8129
# Epoch 19/45
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4391 - accuracy: 0.8372 - val_loss: 0.4725 - val_accuracy: 0.8256
# Epoch 20/45
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4203 - accuracy: 0.8428 - val_loss: 0.4762 - val_accuracy: 0.8214
# Epoch 21/45
# 6/6 [==============================] - 0s 46ms/step - loss: 0.4160 - accuracy: 0.8523 - val_loss: 0.4690 - val_accuracy: 0.8143
# Epoch 22/45
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4113 - accuracy: 0.8506 - val_loss: 0.4594 - val_accuracy: 0.8326
# Epoch 23/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4010 - accuracy: 0.8513 - val_loss: 0.4511 - val_accuracy: 0.8284
# Epoch 24/45
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3966 - accuracy: 0.8576 - val_loss: 0.4389 - val_accuracy: 0.8397
# Epoch 25/45
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3887 - accuracy: 0.8639 - val_loss: 0.4371 - val_accuracy: 0.8312
# Epoch 26/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3822 - accuracy: 0.8653 - val_loss: 0.4273 - val_accuracy: 0.8467
# Epoch 27/45
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3728 - accuracy: 0.8625 - val_loss: 0.4278 - val_accuracy: 0.8340
# Epoch 28/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3685 - accuracy: 0.8664 - val_loss: 0.4247 - val_accuracy: 0.8326
# Epoch 29/45
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3616 - accuracy: 0.8674 - val_loss: 0.4153 - val_accuracy: 0.8523
# Epoch 30/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3613 - accuracy: 0.8692 - val_loss: 0.4138 - val_accuracy: 0.8453
# Epoch 31/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3538 - accuracy: 0.8720 - val_loss: 0.4008 - val_accuracy: 0.8594
# Epoch 32/45
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3500 - accuracy: 0.8769 - val_loss: 0.4049 - val_accuracy: 0.8481
# Epoch 33/45
# 6/6 [==============================] - 0s 64ms/step - loss: 0.3509 - accuracy: 0.8752 - val_loss: 0.3936 - val_accuracy: 0.8594
# Epoch 34/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3440 - accuracy: 0.8766 - val_loss: 0.3854 - val_accuracy: 0.8565
# Epoch 35/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3339 - accuracy: 0.8805 - val_loss: 0.3839 - val_accuracy: 0.8608
# Epoch 36/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3294 - accuracy: 0.8829 - val_loss: 0.3694 - val_accuracy: 0.8692
# Epoch 37/45
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3262 - accuracy: 0.8801 - val_loss: 0.3721 - val_accuracy: 0.8664
# Epoch 38/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3246 - accuracy: 0.8857 - val_loss: 0.3699 - val_accuracy: 0.8748
# Epoch 39/45
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3160 - accuracy: 0.8871 - val_loss: 0.3754 - val_accuracy: 0.8622
# Epoch 40/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3012 - accuracy: 0.8914 - val_loss: 0.3697 - val_accuracy: 0.8762
# Epoch 41/45
# 6/6 [==============================] - 0s 48ms/step - loss: 0.3111 - accuracy: 0.8861 - val_loss: 0.3666 - val_accuracy: 0.8748
# Epoch 42/45
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2985 - accuracy: 0.8966 - val_loss: 0.3515 - val_accuracy: 0.8790
# Epoch 43/45
# 6/6 [==============================] - 0s 47ms/step - loss: 0.2959 - accuracy: 0.8910 - val_loss: 0.3518 - val_accuracy: 0.8776
# Epoch 44/45
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2914 - accuracy: 0.8903 - val_loss: 0.3714 - val_accuracy: 0.8650
# Epoch 45/45
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3074 - accuracy: 0.8875 - val_loss: 0.3749 - val_accuracy: 0.8692

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 5ms/step - loss: 0.2741 - accuracy: 0.9023
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3749 - accuracy: 0.8692
# 0.902250349521637 0.8691983222961426

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 106, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:07

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  99   0   1   0   0   0   0]
#  [  0   0 118   2   1   0   0   1]
#  [  0   0   0 232   3   0   0   5]
#  [  0   0   0  44  49   1   1   5]
#  [  0   0   0   0   0  12   0   0]
#  [  3   0   0   0   0   1   7   0]
#  [  0   0   0  23   1   1   0  21]]
#
# Accuracy Score
# 0.869198312236287
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.96      1.00      0.98        80
#      clouds       1.00      0.99      0.99       100
#  vegetation       1.00      0.97      0.98       122
#       built       0.77      0.97      0.86       240
#     windows       0.91      0.49      0.64       100
#       roads       0.80      1.00      0.89        12
#        cars       0.88      0.64      0.74        11
#       metal       0.66      0.46      0.54        46
#
# avg / total       0.88      0.87      0.86       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 106
# [[0, 8], [8, 16], [16, 24], [24, 32], [32, 40], [40, 48], [48, 56], [56, 64], [64, 72], [72, 80], [80, 88], [88, 96], [96, 104], [104, 112], [112, 120], [120, 128], [128, 136], [136, 144], [144, 152], [152, 160], [160, 168], [168, 176], [176, 184], [184, 192], [192, 200], [200, 208], [208, 216], [216, 224], [224, 232], [232, 240], [240, 248], [248, 256], [256, 264], [264, 272], [272, 280], [280, 288], [288, 296], [296, 304], [304, 312], [312, 320], [320, 328], [328, 336], [336, 344], [344, 352], [352, 360], [360, 368], [368, 376], [376, 384], [384, 392], [392, 400], [400, 408], [408, 416], [416, 424], [424, 432], [432, 440], [440, 448], [448, 456], [456, 464], [464, 472], [472, 480], [480, 488], [488, 496], [496, 504], [504, 512], [512, 520], [520, 528], [528, 536], [536, 544], [544, 552], [552, 560], [560, 568], [568, 576], [576, 584], [584, 592], [592, 600], [600, 608], [608, 616], [616, 624], [624, 632], [632, 640], [640, 648], [648, 656], [656, 664], [664, 672], [672, 680], [680, 688], [688, 696], [696, 704], [704, 712], [712, 720], [720, 728], [728, 736], [736, 744], [744, 752], [752, 760], [760, 768], [768, 776], [776, 784], [784, 792], [792, 800], [800, 808], [808, 816], [816, 824], [824, 832], [832, 840], [840, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 106)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 106)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 106)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 106) (60, 106)
# clouds  (160, 106) (40, 106)
# vegetation  (560, 106) (140, 106)
# water  (496, 106) (124, 106)
# built  (1280, 106) (320, 106)
# windows  (480, 106) (120, 106)
# roads  (200, 106) (50, 106)
# cars  (200, 106) (50, 106)
# metal  (148, 106) (37, 106)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 106) (3764,) (3764, 2)
# (941, 106) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 73ms/step - loss: 1.7655 - accuracy: 0.3767 - val_loss: 1.4493 - val_accuracy: 0.5090
# Epoch 2/200
# 8/8 [==============================] - 0s 59ms/step - loss: 1.4105 - accuracy: 0.5064 - val_loss: 1.3402 - val_accuracy: 0.4644
# Epoch 3/200
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3141 - accuracy: 0.5319 - val_loss: 1.2625 - val_accuracy: 0.6047
# Epoch 4/200
# 8/8 [==============================] - 0s 46ms/step - loss: 1.2372 - accuracy: 0.5577 - val_loss: 1.1780 - val_accuracy: 0.6174
# Epoch 5/200
# 8/8 [==============================] - 0s 49ms/step - loss: 1.1736 - accuracy: 0.5893 - val_loss: 1.1024 - val_accuracy: 0.6631
# Epoch 6/200
# 8/8 [==============================] - 0s 52ms/step - loss: 1.0963 - accuracy: 0.6100 - val_loss: 1.0084 - val_accuracy: 0.7014
# Epoch 7/200
# 8/8 [==============================] - 0s 56ms/step - loss: 1.0076 - accuracy: 0.6698 - val_loss: 0.9364 - val_accuracy: 0.7014
# Epoch 8/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.9254 - accuracy: 0.7009 - val_loss: 0.8489 - val_accuracy: 0.7396
# Epoch 9/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.8796 - accuracy: 0.7155 - val_loss: 0.8488 - val_accuracy: 0.7386
# Epoch 10/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.8496 - accuracy: 0.7208 - val_loss: 0.7817 - val_accuracy: 0.7418
# Epoch 11/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7840 - accuracy: 0.7407 - val_loss: 0.7210 - val_accuracy: 0.7609
# Epoch 12/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7408 - accuracy: 0.7492 - val_loss: 0.7064 - val_accuracy: 0.7673
# Epoch 13/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7262 - accuracy: 0.7577 - val_loss: 0.6983 - val_accuracy: 0.7811
# Epoch 14/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6983 - accuracy: 0.7683 - val_loss: 0.6508 - val_accuracy: 0.7875
# Epoch 15/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6659 - accuracy: 0.7774 - val_loss: 0.6114 - val_accuracy: 0.8055
# Epoch 16/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6403 - accuracy: 0.7848 - val_loss: 0.6074 - val_accuracy: 0.7917
# Epoch 17/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6307 - accuracy: 0.7840 - val_loss: 0.6360 - val_accuracy: 0.7981
# Epoch 18/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.6298 - accuracy: 0.7906 - val_loss: 0.5705 - val_accuracy: 0.8310
# Epoch 19/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5896 - accuracy: 0.8045 - val_loss: 0.5544 - val_accuracy: 0.8310
# Epoch 20/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5780 - accuracy: 0.8146 - val_loss: 0.5612 - val_accuracy: 0.8310
# Epoch 21/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5592 - accuracy: 0.8151 - val_loss: 0.5254 - val_accuracy: 0.8406
# Epoch 22/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5431 - accuracy: 0.8255 - val_loss: 0.5225 - val_accuracy: 0.8438
# Epoch 23/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5309 - accuracy: 0.8270 - val_loss: 0.5230 - val_accuracy: 0.8268
# Epoch 24/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5206 - accuracy: 0.8294 - val_loss: 0.4885 - val_accuracy: 0.8480
# Epoch 25/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5059 - accuracy: 0.8310 - val_loss: 0.5123 - val_accuracy: 0.8278
# Epoch 26/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5171 - accuracy: 0.8278 - val_loss: 0.5013 - val_accuracy: 0.8480
# Epoch 27/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5030 - accuracy: 0.8350 - val_loss: 0.4915 - val_accuracy: 0.8565
# Epoch 28/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5073 - accuracy: 0.8355 - val_loss: 0.4754 - val_accuracy: 0.8629
# Epoch 29/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4826 - accuracy: 0.8462 - val_loss: 0.4904 - val_accuracy: 0.8300
# Epoch 30/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4706 - accuracy: 0.8382 - val_loss: 0.4551 - val_accuracy: 0.8608
# Epoch 31/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4641 - accuracy: 0.8480 - val_loss: 0.4419 - val_accuracy: 0.8842
# Epoch 32/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4550 - accuracy: 0.8531 - val_loss: 0.4531 - val_accuracy: 0.8735
# Epoch 33/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4550 - accuracy: 0.8483 - val_loss: 0.4376 - val_accuracy: 0.8799
# Epoch 34/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4442 - accuracy: 0.8555 - val_loss: 0.4293 - val_accuracy: 0.8799
# Epoch 35/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4457 - accuracy: 0.8510 - val_loss: 0.4469 - val_accuracy: 0.8746
# Epoch 36/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4270 - accuracy: 0.8634 - val_loss: 0.4154 - val_accuracy: 0.8831
# Epoch 37/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4255 - accuracy: 0.8579 - val_loss: 0.4287 - val_accuracy: 0.8789
# Epoch 38/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.4262 - accuracy: 0.8597 - val_loss: 0.4141 - val_accuracy: 0.8852
# Epoch 39/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4113 - accuracy: 0.8677 - val_loss: 0.4136 - val_accuracy: 0.8725
# Epoch 40/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4075 - accuracy: 0.8661 - val_loss: 0.3997 - val_accuracy: 0.8884
# Epoch 41/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.4029 - accuracy: 0.8688 - val_loss: 0.4190 - val_accuracy: 0.8874
# Epoch 42/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3943 - accuracy: 0.8727 - val_loss: 0.3875 - val_accuracy: 0.8863
# Epoch 43/200
# 8/8 [==============================] - 1s 67ms/step - loss: 0.4019 - accuracy: 0.8714 - val_loss: 0.4163 - val_accuracy: 0.8725
# Epoch 44/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3922 - accuracy: 0.8770 - val_loss: 0.3864 - val_accuracy: 0.8937
# Epoch 45/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3891 - accuracy: 0.8711 - val_loss: 0.3993 - val_accuracy: 0.8863
# Epoch 46/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3797 - accuracy: 0.8775 - val_loss: 0.3795 - val_accuracy: 0.8990
# Epoch 47/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3716 - accuracy: 0.8812 - val_loss: 0.3660 - val_accuracy: 0.8980
# Epoch 48/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3656 - accuracy: 0.8789 - val_loss: 0.3717 - val_accuracy: 0.9001
# Epoch 49/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3579 - accuracy: 0.8831 - val_loss: 0.3760 - val_accuracy: 0.8884
# Epoch 50/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3640 - accuracy: 0.8810 - val_loss: 0.3879 - val_accuracy: 0.8884
# Epoch 51/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3751 - accuracy: 0.8767 - val_loss: 0.3872 - val_accuracy: 0.8863
# Epoch 52/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3675 - accuracy: 0.8794 - val_loss: 0.3595 - val_accuracy: 0.9012
# Epoch 53/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3540 - accuracy: 0.8876 - val_loss: 0.3598 - val_accuracy: 0.8959
# Epoch 54/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.3482 - accuracy: 0.8852 - val_loss: 0.3675 - val_accuracy: 0.8937
# Epoch 55/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3487 - accuracy: 0.8879 - val_loss: 0.3784 - val_accuracy: 0.8852
# Epoch 56/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3695 - accuracy: 0.8781 - val_loss: 0.3700 - val_accuracy: 0.8969
# Epoch 57/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.3589 - accuracy: 0.8820 - val_loss: 0.3565 - val_accuracy: 0.8948
# Epoch 58/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3489 - accuracy: 0.8847 - val_loss: 0.3857 - val_accuracy: 0.8799
# Epoch 59/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3429 - accuracy: 0.8908 - val_loss: 0.3490 - val_accuracy: 0.9044
# Epoch 60/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3477 - accuracy: 0.8892 - val_loss: 0.3815 - val_accuracy: 0.8980
# Epoch 61/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3429 - accuracy: 0.8900 - val_loss: 0.3486 - val_accuracy: 0.8927
# Epoch 62/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3248 - accuracy: 0.8932 - val_loss: 0.3392 - val_accuracy: 0.9012
# Epoch 63/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3152 - accuracy: 0.9014 - val_loss: 0.3429 - val_accuracy: 0.9012
# Epoch 64/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3192 - accuracy: 0.8948 - val_loss: 0.3517 - val_accuracy: 0.8980
# Epoch 65/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3161 - accuracy: 0.8990 - val_loss: 0.3408 - val_accuracy: 0.8990
# Epoch 66/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3313 - accuracy: 0.8897 - val_loss: 0.3543 - val_accuracy: 0.8948
# Epoch 67/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3296 - accuracy: 0.8943 - val_loss: 0.3664 - val_accuracy: 0.8778
# Epoch 68/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3287 - accuracy: 0.8935 - val_loss: 0.4004 - val_accuracy: 0.8905
# Epoch 69/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.3178 - accuracy: 0.8964 - val_loss: 0.3254 - val_accuracy: 0.9033
# Epoch 70/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3023 - accuracy: 0.8980 - val_loss: 0.3288 - val_accuracy: 0.9086
# Epoch 71/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3030 - accuracy: 0.8980 - val_loss: 0.3745 - val_accuracy: 0.8990
# Epoch 72/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3267 - accuracy: 0.8908 - val_loss: 0.3440 - val_accuracy: 0.8916
# Epoch 73/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3522 - accuracy: 0.8746 - val_loss: 0.3451 - val_accuracy: 0.8927
# Epoch 74/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3164 - accuracy: 0.8874 - val_loss: 0.3451 - val_accuracy: 0.9012
# Epoch 75/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3139 - accuracy: 0.8974 - val_loss: 0.3326 - val_accuracy: 0.9033
# Epoch 76/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3068 - accuracy: 0.8998 - val_loss: 0.3475 - val_accuracy: 0.9033
# Epoch 77/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3105 - accuracy: 0.8980 - val_loss: 0.3340 - val_accuracy: 0.9022
# Epoch 78/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3101 - accuracy: 0.8956 - val_loss: 0.3831 - val_accuracy: 0.8895
# Epoch 79/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.3136 - accuracy: 0.8977 - val_loss: 0.3275 - val_accuracy: 0.8937
# Epoch 80/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2973 - accuracy: 0.9075 - val_loss: 0.3176 - val_accuracy: 0.9022
# Epoch 81/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2907 - accuracy: 0.9060 - val_loss: 0.3121 - val_accuracy: 0.9129
# Epoch 82/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2882 - accuracy: 0.9041 - val_loss: 0.3170 - val_accuracy: 0.9139
# Epoch 83/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2824 - accuracy: 0.9044 - val_loss: 0.3127 - val_accuracy: 0.9129
# Epoch 84/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2867 - accuracy: 0.9001 - val_loss: 0.3250 - val_accuracy: 0.9054
# Epoch 85/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2748 - accuracy: 0.9099 - val_loss: 0.3122 - val_accuracy: 0.9097
# Epoch 86/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2817 - accuracy: 0.9081 - val_loss: 0.3120 - val_accuracy: 0.9001
# Epoch 87/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2898 - accuracy: 0.9089 - val_loss: 0.3160 - val_accuracy: 0.9022
# Epoch 88/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2869 - accuracy: 0.9078 - val_loss: 0.3012 - val_accuracy: 0.9160
# Epoch 89/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2725 - accuracy: 0.9118 - val_loss: 0.3143 - val_accuracy: 0.9022
# Epoch 90/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2664 - accuracy: 0.9091 - val_loss: 0.3042 - val_accuracy: 0.9107
# Epoch 91/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2609 - accuracy: 0.9155 - val_loss: 0.2979 - val_accuracy: 0.9044
# Epoch 92/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3006 - accuracy: 0.9004 - val_loss: 0.3502 - val_accuracy: 0.8990
# Epoch 93/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3106 - accuracy: 0.8980 - val_loss: 0.3654 - val_accuracy: 0.8863
# Epoch 94/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2960 - accuracy: 0.9054 - val_loss: 0.3516 - val_accuracy: 0.9012
# Epoch 95/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2746 - accuracy: 0.9094 - val_loss: 0.3519 - val_accuracy: 0.9054
# Epoch 96/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2710 - accuracy: 0.9139 - val_loss: 0.2899 - val_accuracy: 0.9171
# Epoch 97/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2654 - accuracy: 0.9097 - val_loss: 0.2978 - val_accuracy: 0.9097
# Epoch 98/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2588 - accuracy: 0.9145 - val_loss: 0.3089 - val_accuracy: 0.9150
# Epoch 99/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2535 - accuracy: 0.9195 - val_loss: 0.2983 - val_accuracy: 0.9107
# Epoch 100/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2487 - accuracy: 0.9216 - val_loss: 0.2901 - val_accuracy: 0.9129
# Epoch 101/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2366 - accuracy: 0.9230 - val_loss: 0.2813 - val_accuracy: 0.9182
# Epoch 102/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2430 - accuracy: 0.9184 - val_loss: 0.3243 - val_accuracy: 0.9044
# Epoch 103/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2548 - accuracy: 0.9176 - val_loss: 0.3208 - val_accuracy: 0.8969
# Epoch 104/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2476 - accuracy: 0.9211 - val_loss: 0.2957 - val_accuracy: 0.9075
# Epoch 105/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2416 - accuracy: 0.9243 - val_loss: 0.2864 - val_accuracy: 0.9129
# Epoch 106/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2405 - accuracy: 0.9222 - val_loss: 0.2781 - val_accuracy: 0.9192
# Epoch 107/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2398 - accuracy: 0.9222 - val_loss: 0.2944 - val_accuracy: 0.9129
# Epoch 108/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2299 - accuracy: 0.9248 - val_loss: 0.2838 - val_accuracy: 0.9192
# Epoch 109/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2345 - accuracy: 0.9203 - val_loss: 0.2935 - val_accuracy: 0.9129
# Epoch 110/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2264 - accuracy: 0.9235 - val_loss: 0.2931 - val_accuracy: 0.9160
# Epoch 111/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2296 - accuracy: 0.9240 - val_loss: 0.2800 - val_accuracy: 0.9182
# Epoch 112/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2359 - accuracy: 0.9232 - val_loss: 0.2810 - val_accuracy: 0.9192
# Epoch 113/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2236 - accuracy: 0.9264 - val_loss: 0.2732 - val_accuracy: 0.9192
# Epoch 114/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2206 - accuracy: 0.9328 - val_loss: 0.3007 - val_accuracy: 0.9086
# Epoch 115/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2286 - accuracy: 0.9269 - val_loss: 0.2773 - val_accuracy: 0.9203
# Epoch 116/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2326 - accuracy: 0.9256 - val_loss: 0.3005 - val_accuracy: 0.9086
# Epoch 117/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2339 - accuracy: 0.9259 - val_loss: 0.2708 - val_accuracy: 0.9224
# Epoch 118/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2170 - accuracy: 0.9320 - val_loss: 0.2868 - val_accuracy: 0.9150
# Epoch 119/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2198 - accuracy: 0.9304 - val_loss: 0.2751 - val_accuracy: 0.9203
# Epoch 120/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2163 - accuracy: 0.9293 - val_loss: 0.2706 - val_accuracy: 0.9235
# Epoch 121/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2092 - accuracy: 0.9344 - val_loss: 0.2785 - val_accuracy: 0.9171
# Epoch 122/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2038 - accuracy: 0.9365 - val_loss: 0.2647 - val_accuracy: 0.9245
# Epoch 123/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2154 - accuracy: 0.9299 - val_loss: 0.2690 - val_accuracy: 0.9245
# Epoch 124/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2091 - accuracy: 0.9346 - val_loss: 0.2849 - val_accuracy: 0.9182
# Epoch 125/200
# 8/8 [==============================] - 1s 65ms/step - loss: 0.2066 - accuracy: 0.9344 - val_loss: 0.2675 - val_accuracy: 0.9214
# Epoch 126/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2119 - accuracy: 0.9309 - val_loss: 0.3261 - val_accuracy: 0.9107
# Epoch 127/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2408 - accuracy: 0.9208 - val_loss: 0.2803 - val_accuracy: 0.9150
# Epoch 128/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2240 - accuracy: 0.9232 - val_loss: 0.2774 - val_accuracy: 0.9160
# Epoch 129/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2072 - accuracy: 0.9338 - val_loss: 0.2683 - val_accuracy: 0.9150
# Epoch 130/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2122 - accuracy: 0.9307 - val_loss: 0.2768 - val_accuracy: 0.9150
# Epoch 131/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2117 - accuracy: 0.9283 - val_loss: 0.2627 - val_accuracy: 0.9203
# Epoch 132/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2047 - accuracy: 0.9320 - val_loss: 0.2781 - val_accuracy: 0.9182
# Epoch 133/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2066 - accuracy: 0.9328 - val_loss: 0.2668 - val_accuracy: 0.9203
# Epoch 134/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2050 - accuracy: 0.9344 - val_loss: 0.2933 - val_accuracy: 0.9171
# Epoch 135/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2043 - accuracy: 0.9304 - val_loss: 0.2593 - val_accuracy: 0.9277
# Epoch 136/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2000 - accuracy: 0.9381 - val_loss: 0.2924 - val_accuracy: 0.9150
# Epoch 137/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1978 - accuracy: 0.9315 - val_loss: 0.2556 - val_accuracy: 0.9235
# Epoch 138/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1995 - accuracy: 0.9349 - val_loss: 0.2655 - val_accuracy: 0.9192
# Epoch 139/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1942 - accuracy: 0.9378 - val_loss: 0.2659 - val_accuracy: 0.9192
# Epoch 140/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1900 - accuracy: 0.9418 - val_loss: 0.2717 - val_accuracy: 0.9160
# Epoch 141/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1913 - accuracy: 0.9405 - val_loss: 0.2591 - val_accuracy: 0.9235
# Epoch 142/200
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1848 - accuracy: 0.9429 - val_loss: 0.2570 - val_accuracy: 0.9235
# Epoch 143/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1905 - accuracy: 0.9373 - val_loss: 0.2584 - val_accuracy: 0.9224
# Epoch 144/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1844 - accuracy: 0.9418 - val_loss: 0.2901 - val_accuracy: 0.9150
# Epoch 145/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1894 - accuracy: 0.9413 - val_loss: 0.2542 - val_accuracy: 0.9224
# Epoch 146/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1884 - accuracy: 0.9429 - val_loss: 0.2615 - val_accuracy: 0.9192
# Epoch 147/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1840 - accuracy: 0.9402 - val_loss: 0.2995 - val_accuracy: 0.9139
# Epoch 148/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1879 - accuracy: 0.9365 - val_loss: 0.2525 - val_accuracy: 0.9224
# Epoch 149/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1890 - accuracy: 0.9392 - val_loss: 0.2864 - val_accuracy: 0.9118
# Epoch 150/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1882 - accuracy: 0.9381 - val_loss: 0.2514 - val_accuracy: 0.9203
# Epoch 151/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1928 - accuracy: 0.9338 - val_loss: 0.2812 - val_accuracy: 0.9214
# Epoch 152/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1893 - accuracy: 0.9392 - val_loss: 0.2445 - val_accuracy: 0.9299
# Epoch 153/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1839 - accuracy: 0.9421 - val_loss: 0.2514 - val_accuracy: 0.9235
# Epoch 154/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1822 - accuracy: 0.9416 - val_loss: 0.2645 - val_accuracy: 0.9245
# Epoch 155/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1873 - accuracy: 0.9400 - val_loss: 0.2457 - val_accuracy: 0.9256
# Epoch 156/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1849 - accuracy: 0.9344 - val_loss: 0.2594 - val_accuracy: 0.9245
# Epoch 157/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1801 - accuracy: 0.9434 - val_loss: 0.2676 - val_accuracy: 0.9182
# Epoch 158/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1769 - accuracy: 0.9431 - val_loss: 0.2437 - val_accuracy: 0.9245
# Epoch 159/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1741 - accuracy: 0.9423 - val_loss: 0.2610 - val_accuracy: 0.9267
# Epoch 160/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1679 - accuracy: 0.9463 - val_loss: 0.2506 - val_accuracy: 0.9277
# Epoch 161/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1835 - accuracy: 0.9421 - val_loss: 0.2828 - val_accuracy: 0.9214
# Epoch 162/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1900 - accuracy: 0.9408 - val_loss: 0.2812 - val_accuracy: 0.9192
# Epoch 163/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2006 - accuracy: 0.9296 - val_loss: 0.2586 - val_accuracy: 0.9256
# Epoch 164/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1973 - accuracy: 0.9346 - val_loss: 0.2570 - val_accuracy: 0.9245
# Epoch 165/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1842 - accuracy: 0.9418 - val_loss: 0.2575 - val_accuracy: 0.9256
# Epoch 166/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1775 - accuracy: 0.9416 - val_loss: 0.2606 - val_accuracy: 0.9214
# Epoch 167/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1712 - accuracy: 0.9418 - val_loss: 0.3049 - val_accuracy: 0.9160
# Epoch 168/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1745 - accuracy: 0.9429 - val_loss: 0.2533 - val_accuracy: 0.9256
# Epoch 169/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1671 - accuracy: 0.9437 - val_loss: 0.2477 - val_accuracy: 0.9277
# Epoch 170/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1751 - accuracy: 0.9426 - val_loss: 0.2822 - val_accuracy: 0.9182
# Epoch 171/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1701 - accuracy: 0.9471 - val_loss: 0.2595 - val_accuracy: 0.9245
# Epoch 172/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1681 - accuracy: 0.9514 - val_loss: 0.2386 - val_accuracy: 0.9299
# Epoch 173/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1655 - accuracy: 0.9453 - val_loss: 0.2418 - val_accuracy: 0.9330
# Epoch 174/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1590 - accuracy: 0.9516 - val_loss: 0.2490 - val_accuracy: 0.9299
# Epoch 175/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1558 - accuracy: 0.9506 - val_loss: 0.2431 - val_accuracy: 0.9245
# Epoch 176/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1579 - accuracy: 0.9474 - val_loss: 0.3242 - val_accuracy: 0.9118
# Epoch 177/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1804 - accuracy: 0.9394 - val_loss: 0.2414 - val_accuracy: 0.9245
# Epoch 178/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1644 - accuracy: 0.9471 - val_loss: 0.2510 - val_accuracy: 0.9277
# Epoch 179/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1690 - accuracy: 0.9461 - val_loss: 0.2541 - val_accuracy: 0.9299
# Epoch 180/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1682 - accuracy: 0.9416 - val_loss: 0.2682 - val_accuracy: 0.9277
# Epoch 181/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1547 - accuracy: 0.9474 - val_loss: 0.2501 - val_accuracy: 0.9309
# Epoch 182/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1575 - accuracy: 0.9498 - val_loss: 0.2742 - val_accuracy: 0.9171
# Epoch 183/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1617 - accuracy: 0.9501 - val_loss: 0.2542 - val_accuracy: 0.9245
# Epoch 184/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1548 - accuracy: 0.9524 - val_loss: 0.2385 - val_accuracy: 0.9299
# Epoch 185/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1527 - accuracy: 0.9543 - val_loss: 0.2432 - val_accuracy: 0.9309
# Epoch 186/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1465 - accuracy: 0.9535 - val_loss: 0.2546 - val_accuracy: 0.9182
# Epoch 187/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1407 - accuracy: 0.9562 - val_loss: 0.2402 - val_accuracy: 0.9299
# Epoch 188/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1426 - accuracy: 0.9519 - val_loss: 0.2612 - val_accuracy: 0.9224
# Epoch 189/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1359 - accuracy: 0.9559 - val_loss: 0.2573 - val_accuracy: 0.9267
# Epoch 190/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1331 - accuracy: 0.9572 - val_loss: 0.2301 - val_accuracy: 0.9309
# Epoch 191/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1374 - accuracy: 0.9575 - val_loss: 0.2525 - val_accuracy: 0.9224
# Epoch 192/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1549 - accuracy: 0.9506 - val_loss: 0.3058 - val_accuracy: 0.9182
# Epoch 193/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1706 - accuracy: 0.9431 - val_loss: 0.2830 - val_accuracy: 0.9171
# Epoch 194/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1589 - accuracy: 0.9503 - val_loss: 0.2391 - val_accuracy: 0.9203
# Epoch 195/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1539 - accuracy: 0.9503 - val_loss: 0.2431 - val_accuracy: 0.9277
# Epoch 196/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1378 - accuracy: 0.9580 - val_loss: 0.2482 - val_accuracy: 0.9267
# Epoch 197/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1363 - accuracy: 0.9570 - val_loss: 0.2487 - val_accuracy: 0.9245
# Epoch 198/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1449 - accuracy: 0.9540 - val_loss: 0.2585 - val_accuracy: 0.9245
# Epoch 199/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1503 - accuracy: 0.9493 - val_loss: 0.2535 - val_accuracy: 0.9256
# Epoch 200/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1502 - accuracy: 0.9524 - val_loss: 0.2370 - val_accuracy: 0.9245

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 72ms/step - loss: 1.8364 - accuracy: 0.3696 - val_loss: 1.4895 - val_accuracy: 0.5399
# Epoch 2/50
# 8/8 [==============================] - 0s 49ms/step - loss: 1.4224 - accuracy: 0.5043 - val_loss: 1.3289 - val_accuracy: 0.4995
# Epoch 3/50
# 8/8 [==============================] - 0s 58ms/step - loss: 1.3028 - accuracy: 0.5239 - val_loss: 1.2756 - val_accuracy: 0.5930
# Epoch 4/50
# 8/8 [==============================] - 1s 64ms/step - loss: 1.2524 - accuracy: 0.5529 - val_loss: 1.1999 - val_accuracy: 0.6217
# Epoch 5/50
# 8/8 [==============================] - 0s 52ms/step - loss: 1.1776 - accuracy: 0.5964 - val_loss: 1.1081 - val_accuracy: 0.6026
# Epoch 6/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.1067 - accuracy: 0.6073 - val_loss: 1.0435 - val_accuracy: 0.6387
# Epoch 7/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0526 - accuracy: 0.6296 - val_loss: 1.0122 - val_accuracy: 0.6281
# Epoch 8/50
# 8/8 [==============================] - 0s 46ms/step - loss: 1.0051 - accuracy: 0.6509 - val_loss: 0.9743 - val_accuracy: 0.6567
# Epoch 9/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.9588 - accuracy: 0.6886 - val_loss: 0.8809 - val_accuracy: 0.7301
# Epoch 10/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8941 - accuracy: 0.7048 - val_loss: 0.8242 - val_accuracy: 0.7481
# Epoch 11/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8425 - accuracy: 0.7256 - val_loss: 0.7941 - val_accuracy: 0.7535
# Epoch 12/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.8124 - accuracy: 0.7346 - val_loss: 0.7675 - val_accuracy: 0.7471
# Epoch 13/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.7731 - accuracy: 0.7505 - val_loss: 0.7195 - val_accuracy: 0.7662
# Epoch 14/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.7529 - accuracy: 0.7497 - val_loss: 0.6955 - val_accuracy: 0.7768
# Epoch 15/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.7350 - accuracy: 0.7513 - val_loss: 0.7058 - val_accuracy: 0.7651
# Epoch 16/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.7060 - accuracy: 0.7654 - val_loss: 0.7023 - val_accuracy: 0.7481
# Epoch 17/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7081 - accuracy: 0.7654 - val_loss: 0.6541 - val_accuracy: 0.7853
# Epoch 18/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.6692 - accuracy: 0.7824 - val_loss: 0.6354 - val_accuracy: 0.7970
# Epoch 19/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6494 - accuracy: 0.7784 - val_loss: 0.6110 - val_accuracy: 0.7970
# Epoch 20/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6292 - accuracy: 0.7885 - val_loss: 0.6008 - val_accuracy: 0.8045
# Epoch 21/50
# 8/8 [==============================] - 0s 61ms/step - loss: 0.6186 - accuracy: 0.7986 - val_loss: 0.6809 - val_accuracy: 0.7450
# Epoch 22/50
# 8/8 [==============================] - 1s 67ms/step - loss: 0.6349 - accuracy: 0.7938 - val_loss: 0.6319 - val_accuracy: 0.8055
# Epoch 23/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.6058 - accuracy: 0.7946 - val_loss: 0.5883 - val_accuracy: 0.8055
# Epoch 24/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5961 - accuracy: 0.7893 - val_loss: 0.5784 - val_accuracy: 0.8108
# Epoch 25/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5665 - accuracy: 0.8124 - val_loss: 0.5530 - val_accuracy: 0.8236
# Epoch 26/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5598 - accuracy: 0.8135 - val_loss: 0.5298 - val_accuracy: 0.8438
# Epoch 27/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.5507 - accuracy: 0.8146 - val_loss: 0.5384 - val_accuracy: 0.8374
# Epoch 28/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5339 - accuracy: 0.8225 - val_loss: 0.5186 - val_accuracy: 0.8385
# Epoch 29/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5236 - accuracy: 0.8257 - val_loss: 0.5183 - val_accuracy: 0.8289
# Epoch 30/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5266 - accuracy: 0.8209 - val_loss: 0.5009 - val_accuracy: 0.8533
# Epoch 31/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5053 - accuracy: 0.8340 - val_loss: 0.4992 - val_accuracy: 0.8491
# Epoch 32/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4954 - accuracy: 0.8353 - val_loss: 0.4903 - val_accuracy: 0.8480
# Epoch 33/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4937 - accuracy: 0.8350 - val_loss: 0.4791 - val_accuracy: 0.8576
# Epoch 34/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4856 - accuracy: 0.8403 - val_loss: 0.4829 - val_accuracy: 0.8565
# Epoch 35/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4827 - accuracy: 0.8430 - val_loss: 0.4751 - val_accuracy: 0.8576
# Epoch 36/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4647 - accuracy: 0.8523 - val_loss: 0.4706 - val_accuracy: 0.8608
# Epoch 37/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4654 - accuracy: 0.8486 - val_loss: 0.4775 - val_accuracy: 0.8597
# Epoch 38/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4590 - accuracy: 0.8478 - val_loss: 0.4651 - val_accuracy: 0.8470
# Epoch 39/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4534 - accuracy: 0.8446 - val_loss: 0.4580 - val_accuracy: 0.8502
# Epoch 40/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4568 - accuracy: 0.8496 - val_loss: 0.4562 - val_accuracy: 0.8650
# Epoch 41/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4367 - accuracy: 0.8552 - val_loss: 0.4699 - val_accuracy: 0.8597
# Epoch 42/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4402 - accuracy: 0.8579 - val_loss: 0.4355 - val_accuracy: 0.8693
# Epoch 43/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4330 - accuracy: 0.8573 - val_loss: 0.4260 - val_accuracy: 0.8842
# Epoch 44/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4274 - accuracy: 0.8613 - val_loss: 0.4359 - val_accuracy: 0.8778
# Epoch 45/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4279 - accuracy: 0.8568 - val_loss: 0.4306 - val_accuracy: 0.8661
# Epoch 46/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4143 - accuracy: 0.8688 - val_loss: 0.4191 - val_accuracy: 0.8735
# Epoch 47/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4177 - accuracy: 0.8563 - val_loss: 0.4225 - val_accuracy: 0.8767
# Epoch 48/50
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4059 - accuracy: 0.8682 - val_loss: 0.4209 - val_accuracy: 0.8799
# Epoch 49/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4019 - accuracy: 0.8650 - val_loss: 0.4106 - val_accuracy: 0.8767
# Epoch 50/50
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4044 - accuracy: 0.8661 - val_loss: 0.3997 - val_accuracy: 0.8916

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 5ms/step - loss: 0.3503 - accuracy: 0.8905
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3997 - accuracy: 0.8916
# 0.8905419707298279 0.8916046619415283

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 106, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:04:46

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   1   0   0   0   0   0]
#  [  0   0   0 123   1   0   0   0   0]
#  [  0   0   0   0 309   5   4   0   2]
#  [  0   0   0   0  20  91   5   0   4]
#  [  0   0   1   0  10   6  30   0   3]
#  [  0   0   0   0  12   9   0  29   0]
#  [  0   0   0   2  10   7   0   0  18]]
#
# Accuracy Score
# 0.8916046758767269
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.98      0.99      0.98       124
#       built       0.85      0.97      0.91       320
#     windows       0.77      0.76      0.76       120
#       roads       0.77      0.60      0.67        50
#        cars       1.00      0.58      0.73        50
#       metal       0.67      0.49      0.56        37
#
# avg / total       0.89      0.89      0.89       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
