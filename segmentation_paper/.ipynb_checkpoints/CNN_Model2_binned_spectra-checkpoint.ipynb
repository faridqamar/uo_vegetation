# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(50), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(50), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 22
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 22
# [[0, 38], [38, 76], [76, 114], [114, 152], [152, 190], [190, 228], [228, 266], [266, 304], [304, 342], [342, 380], [380, 418], [418, 456], [456, 494], [494, 532], [532, 570], [570, 608], [608, 646], [646, 684], [684, 722], [722, 760], [760, 798], [798, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 22)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 22)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 22) (60, 22)
# clouds  (400, 22) (100, 22)
# vegetation  (480, 22) (120, 22)
# water  (40, 22) (10, 22)
# built  (816, 22) (204, 22)
# windows  (400, 22) (100, 22)
# roads  (24, 22) (6, 22)
# cars  (80, 22) (20, 22)
# metal  (80, 22) (20, 22)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 22) (2560,) (2560, 2)
# (640, 22) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 55ms/step - loss: 2.1049 - accuracy: 0.2500 - val_loss: 1.9161 - val_accuracy: 0.3187
# Epoch 2/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.8033 - accuracy: 0.3223 - val_loss: 1.6754 - val_accuracy: 0.3359
# Epoch 3/200
# 5/5 [==============================] - 0s 29ms/step - loss: 1.6420 - accuracy: 0.4301 - val_loss: 1.5151 - val_accuracy: 0.6281
# Epoch 4/200
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4830 - accuracy: 0.5957 - val_loss: 1.3108 - val_accuracy: 0.6484
# Epoch 5/200
# 5/5 [==============================] - 0s 31ms/step - loss: 1.2796 - accuracy: 0.6082 - val_loss: 1.1280 - val_accuracy: 0.6562
# Epoch 6/200
# 5/5 [==============================] - 0s 26ms/step - loss: 1.1155 - accuracy: 0.6535 - val_loss: 0.9852 - val_accuracy: 0.6891
# Epoch 7/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.9875 - accuracy: 0.6746 - val_loss: 0.8758 - val_accuracy: 0.6906
# Epoch 8/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.8924 - accuracy: 0.6965 - val_loss: 0.8056 - val_accuracy: 0.7266
# Epoch 9/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.8271 - accuracy: 0.7195 - val_loss: 0.7515 - val_accuracy: 0.7141
# Epoch 10/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7825 - accuracy: 0.7375 - val_loss: 0.7088 - val_accuracy: 0.7625
# Epoch 11/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7342 - accuracy: 0.7719 - val_loss: 0.6795 - val_accuracy: 0.7953
# Epoch 12/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6996 - accuracy: 0.7770 - val_loss: 0.6438 - val_accuracy: 0.8000
# Epoch 13/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.6635 - accuracy: 0.7961 - val_loss: 0.6158 - val_accuracy: 0.7859
# Epoch 14/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6371 - accuracy: 0.8016 - val_loss: 0.6035 - val_accuracy: 0.8219
# Epoch 15/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6282 - accuracy: 0.8109 - val_loss: 0.5713 - val_accuracy: 0.7984
# Epoch 16/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5973 - accuracy: 0.8113 - val_loss: 0.5597 - val_accuracy: 0.7969
# Epoch 17/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5834 - accuracy: 0.8078 - val_loss: 0.5348 - val_accuracy: 0.8250
# Epoch 18/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.5564 - accuracy: 0.8262 - val_loss: 0.5202 - val_accuracy: 0.8188
# Epoch 19/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5491 - accuracy: 0.8176 - val_loss: 0.5098 - val_accuracy: 0.8531
# Epoch 20/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.5215 - accuracy: 0.8340 - val_loss: 0.4997 - val_accuracy: 0.8141
# Epoch 21/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.5218 - accuracy: 0.8289 - val_loss: 0.4938 - val_accuracy: 0.8438
# Epoch 22/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4992 - accuracy: 0.8410 - val_loss: 0.4670 - val_accuracy: 0.8344
# Epoch 23/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4935 - accuracy: 0.8426 - val_loss: 0.4559 - val_accuracy: 0.8750
# Epoch 24/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4711 - accuracy: 0.8441 - val_loss: 0.4435 - val_accuracy: 0.8750
# Epoch 25/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4642 - accuracy: 0.8547 - val_loss: 0.4334 - val_accuracy: 0.8547
# Epoch 26/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4586 - accuracy: 0.8555 - val_loss: 0.4302 - val_accuracy: 0.8484
# Epoch 27/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4512 - accuracy: 0.8590 - val_loss: 0.4233 - val_accuracy: 0.8797
# Epoch 28/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4366 - accuracy: 0.8680 - val_loss: 0.4131 - val_accuracy: 0.8453
# Epoch 29/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4321 - accuracy: 0.8617 - val_loss: 0.4030 - val_accuracy: 0.8859
# Epoch 30/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4060 - accuracy: 0.8676 - val_loss: 0.3958 - val_accuracy: 0.8844
# Epoch 31/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4118 - accuracy: 0.8703 - val_loss: 0.3957 - val_accuracy: 0.8516
# Epoch 32/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4137 - accuracy: 0.8781 - val_loss: 0.4094 - val_accuracy: 0.8625
# Epoch 33/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.4164 - accuracy: 0.8672 - val_loss: 0.3790 - val_accuracy: 0.8844
# Epoch 34/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3947 - accuracy: 0.8781 - val_loss: 0.3674 - val_accuracy: 0.8922
# Epoch 35/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3787 - accuracy: 0.8855 - val_loss: 0.3603 - val_accuracy: 0.8938
# Epoch 36/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3838 - accuracy: 0.8840 - val_loss: 0.3525 - val_accuracy: 0.8922
# Epoch 37/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3749 - accuracy: 0.8824 - val_loss: 0.3642 - val_accuracy: 0.8891
# Epoch 38/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3728 - accuracy: 0.8887 - val_loss: 0.3443 - val_accuracy: 0.8938
# Epoch 39/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3726 - accuracy: 0.8879 - val_loss: 0.3420 - val_accuracy: 0.8922
# Epoch 40/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3568 - accuracy: 0.8949 - val_loss: 0.3307 - val_accuracy: 0.8906
# Epoch 41/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3507 - accuracy: 0.8910 - val_loss: 0.3254 - val_accuracy: 0.8938
# Epoch 42/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3508 - accuracy: 0.8918 - val_loss: 0.3289 - val_accuracy: 0.8922
# Epoch 43/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3447 - accuracy: 0.8984 - val_loss: 0.3167 - val_accuracy: 0.8938
# Epoch 44/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3338 - accuracy: 0.8984 - val_loss: 0.3103 - val_accuracy: 0.8984
# Epoch 45/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3399 - accuracy: 0.8918 - val_loss: 0.3162 - val_accuracy: 0.8953
# Epoch 46/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3286 - accuracy: 0.9020 - val_loss: 0.2998 - val_accuracy: 0.8984
# Epoch 47/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3241 - accuracy: 0.8977 - val_loss: 0.3014 - val_accuracy: 0.8984
# Epoch 48/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3202 - accuracy: 0.9012 - val_loss: 0.3032 - val_accuracy: 0.9078
# Epoch 49/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3319 - accuracy: 0.8895 - val_loss: 0.2908 - val_accuracy: 0.9047
# Epoch 50/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3229 - accuracy: 0.9043 - val_loss: 0.3016 - val_accuracy: 0.8938
# Epoch 51/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3070 - accuracy: 0.9086 - val_loss: 0.2765 - val_accuracy: 0.9047
# Epoch 52/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3048 - accuracy: 0.9082 - val_loss: 0.2787 - val_accuracy: 0.9156
# Epoch 53/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3128 - accuracy: 0.9031 - val_loss: 0.3059 - val_accuracy: 0.9000
# Epoch 54/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3114 - accuracy: 0.9043 - val_loss: 0.2724 - val_accuracy: 0.9109
# Epoch 55/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2979 - accuracy: 0.9098 - val_loss: 0.2731 - val_accuracy: 0.9078
# Epoch 56/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2972 - accuracy: 0.9059 - val_loss: 0.2760 - val_accuracy: 0.9125
# Epoch 57/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2945 - accuracy: 0.9105 - val_loss: 0.2619 - val_accuracy: 0.9141
# Epoch 58/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2852 - accuracy: 0.9137 - val_loss: 0.2609 - val_accuracy: 0.9078
# Epoch 59/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2855 - accuracy: 0.9105 - val_loss: 0.2540 - val_accuracy: 0.9047
# Epoch 60/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2788 - accuracy: 0.9168 - val_loss: 0.2541 - val_accuracy: 0.9172
# Epoch 61/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.2760 - accuracy: 0.9145 - val_loss: 0.2457 - val_accuracy: 0.9156
# Epoch 62/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2723 - accuracy: 0.9117 - val_loss: 0.2431 - val_accuracy: 0.9094
# Epoch 63/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2778 - accuracy: 0.9137 - val_loss: 0.2463 - val_accuracy: 0.9250
# Epoch 64/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2746 - accuracy: 0.9172 - val_loss: 0.2378 - val_accuracy: 0.9141
# Epoch 65/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2680 - accuracy: 0.9199 - val_loss: 0.2392 - val_accuracy: 0.9203
# Epoch 66/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2615 - accuracy: 0.9176 - val_loss: 0.2444 - val_accuracy: 0.9203
# Epoch 67/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2707 - accuracy: 0.9152 - val_loss: 0.2324 - val_accuracy: 0.9172
# Epoch 68/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2659 - accuracy: 0.9172 - val_loss: 0.2466 - val_accuracy: 0.9234
# Epoch 69/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2697 - accuracy: 0.9187 - val_loss: 0.2360 - val_accuracy: 0.9156
# Epoch 70/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2685 - accuracy: 0.9168 - val_loss: 0.2370 - val_accuracy: 0.9187
# Epoch 71/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2631 - accuracy: 0.9145 - val_loss: 0.2256 - val_accuracy: 0.9234
# Epoch 72/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2540 - accuracy: 0.9219 - val_loss: 0.2221 - val_accuracy: 0.9266
# Epoch 73/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2531 - accuracy: 0.9223 - val_loss: 0.2266 - val_accuracy: 0.9141
# Epoch 74/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2501 - accuracy: 0.9246 - val_loss: 0.2175 - val_accuracy: 0.9203
# Epoch 75/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2432 - accuracy: 0.9215 - val_loss: 0.2171 - val_accuracy: 0.9250
# Epoch 76/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2523 - accuracy: 0.9176 - val_loss: 0.2192 - val_accuracy: 0.9187
# Epoch 77/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2381 - accuracy: 0.9227 - val_loss: 0.2110 - val_accuracy: 0.9281
# Epoch 78/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2394 - accuracy: 0.9219 - val_loss: 0.2199 - val_accuracy: 0.9297
# Epoch 79/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2342 - accuracy: 0.9281 - val_loss: 0.2112 - val_accuracy: 0.9234
# Epoch 80/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2454 - accuracy: 0.9219 - val_loss: 0.2148 - val_accuracy: 0.9344
# Epoch 81/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2310 - accuracy: 0.9289 - val_loss: 0.2043 - val_accuracy: 0.9250
# Epoch 82/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2313 - accuracy: 0.9289 - val_loss: 0.2036 - val_accuracy: 0.9281
# Epoch 83/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2316 - accuracy: 0.9262 - val_loss: 0.2114 - val_accuracy: 0.9344
# Epoch 84/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2374 - accuracy: 0.9270 - val_loss: 0.2038 - val_accuracy: 0.9266
# Epoch 85/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2273 - accuracy: 0.9293 - val_loss: 0.2022 - val_accuracy: 0.9328
# Epoch 86/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2189 - accuracy: 0.9289 - val_loss: 0.1974 - val_accuracy: 0.9297
# Epoch 87/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2239 - accuracy: 0.9277 - val_loss: 0.1983 - val_accuracy: 0.9250
# Epoch 88/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2300 - accuracy: 0.9238 - val_loss: 0.1944 - val_accuracy: 0.9281
# Epoch 89/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2179 - accuracy: 0.9316 - val_loss: 0.1925 - val_accuracy: 0.9312
# Epoch 90/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2171 - accuracy: 0.9273 - val_loss: 0.1897 - val_accuracy: 0.9328
# Epoch 91/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2137 - accuracy: 0.9336 - val_loss: 0.1924 - val_accuracy: 0.9344
# Epoch 92/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2209 - accuracy: 0.9293 - val_loss: 0.1898 - val_accuracy: 0.9312
# Epoch 93/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2176 - accuracy: 0.9312 - val_loss: 0.1896 - val_accuracy: 0.9250
# Epoch 94/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2108 - accuracy: 0.9324 - val_loss: 0.2020 - val_accuracy: 0.9312
# Epoch 95/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2174 - accuracy: 0.9320 - val_loss: 0.1856 - val_accuracy: 0.9281
# Epoch 96/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2097 - accuracy: 0.9277 - val_loss: 0.1859 - val_accuracy: 0.9359
# Epoch 97/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2057 - accuracy: 0.9305 - val_loss: 0.1848 - val_accuracy: 0.9359
# Epoch 98/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.2132 - accuracy: 0.9332 - val_loss: 0.1834 - val_accuracy: 0.9375
# Epoch 99/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2103 - accuracy: 0.9355 - val_loss: 0.1855 - val_accuracy: 0.9375
# Epoch 100/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2158 - accuracy: 0.9270 - val_loss: 0.1766 - val_accuracy: 0.9266
# Epoch 101/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2077 - accuracy: 0.9336 - val_loss: 0.1843 - val_accuracy: 0.9328
# Epoch 102/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2039 - accuracy: 0.9316 - val_loss: 0.1755 - val_accuracy: 0.9312
# Epoch 103/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1996 - accuracy: 0.9352 - val_loss: 0.1754 - val_accuracy: 0.9406
# Epoch 104/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.2082 - accuracy: 0.9316 - val_loss: 0.1777 - val_accuracy: 0.9406
# Epoch 105/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2009 - accuracy: 0.9340 - val_loss: 0.1734 - val_accuracy: 0.9375
# Epoch 106/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2013 - accuracy: 0.9367 - val_loss: 0.1745 - val_accuracy: 0.9344
# Epoch 107/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2057 - accuracy: 0.9301 - val_loss: 0.1771 - val_accuracy: 0.9391
# Epoch 108/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1993 - accuracy: 0.9352 - val_loss: 0.1695 - val_accuracy: 0.9359
# Epoch 109/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1971 - accuracy: 0.9309 - val_loss: 0.1710 - val_accuracy: 0.9484
# Epoch 110/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1980 - accuracy: 0.9352 - val_loss: 0.1670 - val_accuracy: 0.9391
# Epoch 111/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1932 - accuracy: 0.9402 - val_loss: 0.1750 - val_accuracy: 0.9344
# Epoch 112/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1962 - accuracy: 0.9352 - val_loss: 0.1672 - val_accuracy: 0.9422
# Epoch 113/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1958 - accuracy: 0.9391 - val_loss: 0.1746 - val_accuracy: 0.9484
# Epoch 114/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1968 - accuracy: 0.9367 - val_loss: 0.1633 - val_accuracy: 0.9344
# Epoch 115/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1916 - accuracy: 0.9348 - val_loss: 0.1674 - val_accuracy: 0.9453
# Epoch 116/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1879 - accuracy: 0.9422 - val_loss: 0.1605 - val_accuracy: 0.9438
# Epoch 117/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1858 - accuracy: 0.9352 - val_loss: 0.1638 - val_accuracy: 0.9500
# Epoch 118/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1960 - accuracy: 0.9348 - val_loss: 0.1606 - val_accuracy: 0.9547
# Epoch 119/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1879 - accuracy: 0.9414 - val_loss: 0.1578 - val_accuracy: 0.9453
# Epoch 120/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1812 - accuracy: 0.9363 - val_loss: 0.1600 - val_accuracy: 0.9438
# Epoch 121/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1798 - accuracy: 0.9379 - val_loss: 0.1572 - val_accuracy: 0.9422
# Epoch 122/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1819 - accuracy: 0.9422 - val_loss: 0.1640 - val_accuracy: 0.9484
# Epoch 123/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1803 - accuracy: 0.9383 - val_loss: 0.1557 - val_accuracy: 0.9391
# Epoch 124/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1830 - accuracy: 0.9430 - val_loss: 0.1647 - val_accuracy: 0.9516
# Epoch 125/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1846 - accuracy: 0.9406 - val_loss: 0.1569 - val_accuracy: 0.9391
# Epoch 126/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1775 - accuracy: 0.9434 - val_loss: 0.1613 - val_accuracy: 0.9469
# Epoch 127/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1839 - accuracy: 0.9398 - val_loss: 0.1598 - val_accuracy: 0.9422
# Epoch 128/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1763 - accuracy: 0.9449 - val_loss: 0.1584 - val_accuracy: 0.9438
# Epoch 129/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1761 - accuracy: 0.9371 - val_loss: 0.1569 - val_accuracy: 0.9469
# Epoch 130/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1783 - accuracy: 0.9426 - val_loss: 0.1530 - val_accuracy: 0.9547
# Epoch 131/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1718 - accuracy: 0.9473 - val_loss: 0.1507 - val_accuracy: 0.9438
# Epoch 132/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1719 - accuracy: 0.9438 - val_loss: 0.1469 - val_accuracy: 0.9531
# Epoch 133/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1704 - accuracy: 0.9418 - val_loss: 0.1473 - val_accuracy: 0.9516
# Epoch 134/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1723 - accuracy: 0.9438 - val_loss: 0.1499 - val_accuracy: 0.9563
# Epoch 135/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1676 - accuracy: 0.9441 - val_loss: 0.1497 - val_accuracy: 0.9516
# Epoch 136/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1708 - accuracy: 0.9438 - val_loss: 0.1506 - val_accuracy: 0.9563
# Epoch 137/200
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1642 - accuracy: 0.9480 - val_loss: 0.1464 - val_accuracy: 0.9578
# Epoch 138/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1680 - accuracy: 0.9430 - val_loss: 0.1493 - val_accuracy: 0.9516
# Epoch 139/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1590 - accuracy: 0.9457 - val_loss: 0.1451 - val_accuracy: 0.9516
# Epoch 140/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1655 - accuracy: 0.9453 - val_loss: 0.1448 - val_accuracy: 0.9547
# Epoch 141/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1626 - accuracy: 0.9477 - val_loss: 0.1509 - val_accuracy: 0.9469
# Epoch 142/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1737 - accuracy: 0.9422 - val_loss: 0.1449 - val_accuracy: 0.9484
# Epoch 143/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1656 - accuracy: 0.9406 - val_loss: 0.1523 - val_accuracy: 0.9563
# Epoch 144/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1722 - accuracy: 0.9457 - val_loss: 0.1434 - val_accuracy: 0.9469
# Epoch 145/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1558 - accuracy: 0.9488 - val_loss: 0.1468 - val_accuracy: 0.9516
# Epoch 146/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1629 - accuracy: 0.9422 - val_loss: 0.1409 - val_accuracy: 0.9531
# Epoch 147/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1523 - accuracy: 0.9496 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 148/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1548 - accuracy: 0.9457 - val_loss: 0.1420 - val_accuracy: 0.9422
# Epoch 149/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1528 - accuracy: 0.9504 - val_loss: 0.1424 - val_accuracy: 0.9578
# Epoch 150/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1623 - accuracy: 0.9449 - val_loss: 0.1385 - val_accuracy: 0.9531
# Epoch 151/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1545 - accuracy: 0.9465 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 152/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1598 - accuracy: 0.9508 - val_loss: 0.1390 - val_accuracy: 0.9500
# Epoch 153/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1571 - accuracy: 0.9492 - val_loss: 0.1409 - val_accuracy: 0.9531
# Epoch 154/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1531 - accuracy: 0.9461 - val_loss: 0.1327 - val_accuracy: 0.9547
# Epoch 155/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1508 - accuracy: 0.9504 - val_loss: 0.1341 - val_accuracy: 0.9547
# Epoch 156/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1514 - accuracy: 0.9453 - val_loss: 0.1322 - val_accuracy: 0.9516
# Epoch 157/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1496 - accuracy: 0.9484 - val_loss: 0.1327 - val_accuracy: 0.9563
# Epoch 158/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1499 - accuracy: 0.9492 - val_loss: 0.1329 - val_accuracy: 0.9609
# Epoch 159/200
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1538 - accuracy: 0.9492 - val_loss: 0.1406 - val_accuracy: 0.9547
# Epoch 160/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1501 - accuracy: 0.9492 - val_loss: 0.1338 - val_accuracy: 0.9516
# Epoch 161/200
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1443 - accuracy: 0.9520 - val_loss: 0.1291 - val_accuracy: 0.9578
# Epoch 162/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1464 - accuracy: 0.9516 - val_loss: 0.1283 - val_accuracy: 0.9594
# Epoch 163/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1438 - accuracy: 0.9527 - val_loss: 0.1310 - val_accuracy: 0.9516
# Epoch 164/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1471 - accuracy: 0.9504 - val_loss: 0.1325 - val_accuracy: 0.9516
# Epoch 165/200
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1433 - accuracy: 0.9496 - val_loss: 0.1346 - val_accuracy: 0.9609
# Epoch 166/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1454 - accuracy: 0.9535 - val_loss: 0.1304 - val_accuracy: 0.9609
# Epoch 167/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1491 - accuracy: 0.9504 - val_loss: 0.1261 - val_accuracy: 0.9563
# Epoch 168/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1464 - accuracy: 0.9523 - val_loss: 0.1334 - val_accuracy: 0.9609
# Epoch 169/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1395 - accuracy: 0.9566 - val_loss: 0.1286 - val_accuracy: 0.9516
# Epoch 170/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1455 - accuracy: 0.9523 - val_loss: 0.1338 - val_accuracy: 0.9578
# Epoch 171/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1442 - accuracy: 0.9516 - val_loss: 0.1254 - val_accuracy: 0.9563
# Epoch 172/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1279 - accuracy: 0.9594 - val_loss: 0.1304 - val_accuracy: 0.9563
# Epoch 173/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1370 - accuracy: 0.9543 - val_loss: 0.1282 - val_accuracy: 0.9563
# Epoch 174/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1364 - accuracy: 0.9566 - val_loss: 0.1257 - val_accuracy: 0.9563
# Epoch 175/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1425 - accuracy: 0.9563 - val_loss: 0.1330 - val_accuracy: 0.9563
# Epoch 176/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1390 - accuracy: 0.9551 - val_loss: 0.1225 - val_accuracy: 0.9578
# Epoch 177/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1440 - accuracy: 0.9523 - val_loss: 0.1354 - val_accuracy: 0.9500
# Epoch 178/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1366 - accuracy: 0.9535 - val_loss: 0.1281 - val_accuracy: 0.9625
# Epoch 179/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1444 - accuracy: 0.9563 - val_loss: 0.1312 - val_accuracy: 0.9531
# Epoch 180/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1458 - accuracy: 0.9480 - val_loss: 0.1234 - val_accuracy: 0.9578
# Epoch 181/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1472 - accuracy: 0.9480 - val_loss: 0.1229 - val_accuracy: 0.9531
# Epoch 182/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1427 - accuracy: 0.9516 - val_loss: 0.1217 - val_accuracy: 0.9609
# Epoch 183/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1406 - accuracy: 0.9551 - val_loss: 0.1274 - val_accuracy: 0.9594
# Epoch 184/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1299 - accuracy: 0.9590 - val_loss: 0.1243 - val_accuracy: 0.9578
# Epoch 185/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1312 - accuracy: 0.9551 - val_loss: 0.1266 - val_accuracy: 0.9578
# Epoch 186/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1310 - accuracy: 0.9563 - val_loss: 0.1202 - val_accuracy: 0.9531
# Epoch 187/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1280 - accuracy: 0.9582 - val_loss: 0.1247 - val_accuracy: 0.9609
# Epoch 188/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1306 - accuracy: 0.9523 - val_loss: 0.1194 - val_accuracy: 0.9547
# Epoch 189/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1284 - accuracy: 0.9551 - val_loss: 0.1261 - val_accuracy: 0.9609
# Epoch 190/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1356 - accuracy: 0.9527 - val_loss: 0.1177 - val_accuracy: 0.9578
# Epoch 191/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1354 - accuracy: 0.9512 - val_loss: 0.1257 - val_accuracy: 0.9547
# Epoch 192/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1330 - accuracy: 0.9543 - val_loss: 0.1270 - val_accuracy: 0.9563
# Epoch 193/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1394 - accuracy: 0.9488 - val_loss: 0.1182 - val_accuracy: 0.9563
# Epoch 194/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1279 - accuracy: 0.9578 - val_loss: 0.1185 - val_accuracy: 0.9594
# Epoch 195/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1272 - accuracy: 0.9566 - val_loss: 0.1290 - val_accuracy: 0.9578
# Epoch 196/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1317 - accuracy: 0.9527 - val_loss: 0.1256 - val_accuracy: 0.9578
# Epoch 197/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1341 - accuracy: 0.9551 - val_loss: 0.1254 - val_accuracy: 0.9594
# Epoch 198/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1342 - accuracy: 0.9523 - val_loss: 0.1191 - val_accuracy: 0.9672
# Epoch 199/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1225 - accuracy: 0.9609 - val_loss: 0.1147 - val_accuracy: 0.9594
# Epoch 200/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1218 - accuracy: 0.9594 - val_loss: 0.1170 - val_accuracy: 0.9531

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2])
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=50, batch_size=512)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 59ms/step - loss: 2.0794 - accuracy: 0.2559 - val_loss: 1.8699 - val_accuracy: 0.3187
# Epoch 2/50
# 5/5 [==============================] - 0s 29ms/step - loss: 1.8080 - accuracy: 0.3187 - val_loss: 1.7104 - val_accuracy: 0.3187
# Epoch 3/50
# 5/5 [==============================] - 0s 28ms/step - loss: 1.6996 - accuracy: 0.4410 - val_loss: 1.6129 - val_accuracy: 0.6562
# Epoch 4/50
# 5/5 [==============================] - 0s 27ms/step - loss: 1.5657 - accuracy: 0.5379 - val_loss: 1.4232 - val_accuracy: 0.4953
# Epoch 5/50
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3767 - accuracy: 0.5480 - val_loss: 1.2026 - val_accuracy: 0.6562
# Epoch 6/50
# 5/5 [==============================] - 0s 29ms/step - loss: 1.1762 - accuracy: 0.6629 - val_loss: 1.0174 - val_accuracy: 0.6828
# Epoch 7/50
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0130 - accuracy: 0.6910 - val_loss: 0.8820 - val_accuracy: 0.7344
# Epoch 8/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.9035 - accuracy: 0.7102 - val_loss: 0.7930 - val_accuracy: 0.7500
# Epoch 9/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.8147 - accuracy: 0.7359 - val_loss: 0.7338 - val_accuracy: 0.7594
# Epoch 10/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.7583 - accuracy: 0.7641 - val_loss: 0.6885 - val_accuracy: 0.7688
# Epoch 11/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.7262 - accuracy: 0.7789 - val_loss: 0.6592 - val_accuracy: 0.7875
# Epoch 12/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6863 - accuracy: 0.7859 - val_loss: 0.6387 - val_accuracy: 0.7953
# Epoch 13/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.6587 - accuracy: 0.7891 - val_loss: 0.6007 - val_accuracy: 0.8062
# Epoch 14/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.6474 - accuracy: 0.7980 - val_loss: 0.5876 - val_accuracy: 0.8234
# Epoch 15/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.6132 - accuracy: 0.8109 - val_loss: 0.5541 - val_accuracy: 0.8109
# Epoch 16/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5946 - accuracy: 0.8102 - val_loss: 0.5421 - val_accuracy: 0.8109
# Epoch 17/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5782 - accuracy: 0.8129 - val_loss: 0.5307 - val_accuracy: 0.8359
# Epoch 18/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5619 - accuracy: 0.8125 - val_loss: 0.5010 - val_accuracy: 0.8344
# Epoch 19/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.5333 - accuracy: 0.8336 - val_loss: 0.4883 - val_accuracy: 0.8594
# Epoch 20/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5234 - accuracy: 0.8309 - val_loss: 0.4719 - val_accuracy: 0.8531
# Epoch 21/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.5046 - accuracy: 0.8441 - val_loss: 0.4610 - val_accuracy: 0.8375
# Epoch 22/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4903 - accuracy: 0.8453 - val_loss: 0.4476 - val_accuracy: 0.8656
# Epoch 23/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4797 - accuracy: 0.8410 - val_loss: 0.4347 - val_accuracy: 0.8719
# Epoch 24/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4698 - accuracy: 0.8582 - val_loss: 0.4318 - val_accuracy: 0.8500
# Epoch 25/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4654 - accuracy: 0.8562 - val_loss: 0.4108 - val_accuracy: 0.8875
# Epoch 26/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4446 - accuracy: 0.8672 - val_loss: 0.4174 - val_accuracy: 0.8687
# Epoch 27/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4388 - accuracy: 0.8684 - val_loss: 0.3896 - val_accuracy: 0.8875
# Epoch 28/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4264 - accuracy: 0.8676 - val_loss: 0.3855 - val_accuracy: 0.8734
# Epoch 29/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4172 - accuracy: 0.8754 - val_loss: 0.3812 - val_accuracy: 0.8844
# Epoch 30/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.4102 - accuracy: 0.8723 - val_loss: 0.3634 - val_accuracy: 0.8984
# Epoch 31/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3956 - accuracy: 0.8867 - val_loss: 0.3571 - val_accuracy: 0.8969
# Epoch 32/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3935 - accuracy: 0.8824 - val_loss: 0.3487 - val_accuracy: 0.8969
# Epoch 33/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3876 - accuracy: 0.8848 - val_loss: 0.3451 - val_accuracy: 0.8984
# Epoch 34/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3794 - accuracy: 0.8891 - val_loss: 0.3360 - val_accuracy: 0.8953
# Epoch 35/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3767 - accuracy: 0.8891 - val_loss: 0.3316 - val_accuracy: 0.8969
# Epoch 36/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3634 - accuracy: 0.8898 - val_loss: 0.3265 - val_accuracy: 0.8969
# Epoch 37/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3637 - accuracy: 0.8922 - val_loss: 0.3237 - val_accuracy: 0.9000
# Epoch 38/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3577 - accuracy: 0.8918 - val_loss: 0.3350 - val_accuracy: 0.8891
# Epoch 39/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3615 - accuracy: 0.8863 - val_loss: 0.3205 - val_accuracy: 0.9016
# Epoch 40/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3570 - accuracy: 0.8934 - val_loss: 0.3316 - val_accuracy: 0.8891
# Epoch 41/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3568 - accuracy: 0.8863 - val_loss: 0.3213 - val_accuracy: 0.8969
# Epoch 42/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3504 - accuracy: 0.8922 - val_loss: 0.3085 - val_accuracy: 0.9047
# Epoch 43/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3370 - accuracy: 0.9004 - val_loss: 0.2986 - val_accuracy: 0.9062
# Epoch 44/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3268 - accuracy: 0.8988 - val_loss: 0.2913 - val_accuracy: 0.9062
# Epoch 45/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3317 - accuracy: 0.9027 - val_loss: 0.2900 - val_accuracy: 0.9047
# Epoch 46/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3151 - accuracy: 0.9023 - val_loss: 0.2900 - val_accuracy: 0.9062
# Epoch 47/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3236 - accuracy: 0.9086 - val_loss: 0.2862 - val_accuracy: 0.9031
# Epoch 48/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3095 - accuracy: 0.9062 - val_loss: 0.2760 - val_accuracy: 0.9047
# Epoch 49/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3127 - accuracy: 0.9098 - val_loss: 0.2742 - val_accuracy: 0.9047
# Epoch 50/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3092 - accuracy: 0.9062 - val_loss: 0.2760 - val_accuracy: 0.9109

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2731 - accuracy: 0.9172
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2760 - accuracy: 0.9109
# 0.917187511920929 0.910937488079071

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 22, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:03:07

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 199   4   0   1   0]
#  [  1   0   0   0   8  89   0   2   0]
#  [  0   0   0   0   6   0   0   0   0]
#  [  2   0   0   0   4   8   0   5   1]
#  [  0   0   0   0  14   4   0   0   2]]
#
# Accuracy Score
# 0.9109375
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.95      1.00      0.98        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.85      0.98      0.91       204
#     windows       0.85      0.89      0.87       100
#       roads       0.00      0.00      0.00         6
#        cars       0.62      0.25      0.36        20
#       metal       0.67      0.10      0.17        20
#
# avg / total       0.89      0.91      0.89       640
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 22)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 22)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 22) (80, 22)
# clouds  (400, 22) (100, 22)
# vegetation  (488, 22) (122, 22)
# built  (960, 22) (240, 22)
# windows  (400, 22) (100, 22)
# roads  (48, 22) (12, 22)
# cars  (44, 22) (11, 22)
# metal  (184, 22) (46, 22)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 22) (2844,) (2844, 2)
# (711, 22) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 56ms/step - loss: 2.0719 - accuracy: 0.2806 - val_loss: 1.8212 - val_accuracy: 0.3376
# Epoch 2/200
# 6/6 [==============================] - 0s 28ms/step - loss: 1.7378 - accuracy: 0.3383 - val_loss: 1.5903 - val_accuracy: 0.3432
# Epoch 3/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5374 - accuracy: 0.5137 - val_loss: 1.3832 - val_accuracy: 0.6456
# Epoch 4/200
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3002 - accuracy: 0.6153 - val_loss: 1.1368 - val_accuracy: 0.6526
# Epoch 5/200
# 6/6 [==============================] - 0s 26ms/step - loss: 1.0842 - accuracy: 0.6733 - val_loss: 0.9690 - val_accuracy: 0.6892
# Epoch 6/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.9350 - accuracy: 0.6874 - val_loss: 0.8597 - val_accuracy: 0.7117
# Epoch 7/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.8442 - accuracy: 0.7089 - val_loss: 0.7845 - val_accuracy: 0.7314
# Epoch 8/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.7579 - accuracy: 0.7254 - val_loss: 0.7231 - val_accuracy: 0.7286
# Epoch 9/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.7114 - accuracy: 0.7352 - val_loss: 0.6818 - val_accuracy: 0.7398
# Epoch 10/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.6620 - accuracy: 0.7380 - val_loss: 0.6434 - val_accuracy: 0.7511
# Epoch 11/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.6259 - accuracy: 0.7504 - val_loss: 0.6263 - val_accuracy: 0.7454
# Epoch 12/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.6119 - accuracy: 0.7528 - val_loss: 0.6111 - val_accuracy: 0.7511
# Epoch 13/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5884 - accuracy: 0.7570 - val_loss: 0.5855 - val_accuracy: 0.7637
# Epoch 14/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5684 - accuracy: 0.7711 - val_loss: 0.5731 - val_accuracy: 0.7665
# Epoch 15/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5531 - accuracy: 0.7792 - val_loss: 0.5627 - val_accuracy: 0.7567
# Epoch 16/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5388 - accuracy: 0.7799 - val_loss: 0.5646 - val_accuracy: 0.7736
# Epoch 17/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5242 - accuracy: 0.7925 - val_loss: 0.5439 - val_accuracy: 0.7848
# Epoch 18/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.5132 - accuracy: 0.7855 - val_loss: 0.5457 - val_accuracy: 0.7764
# Epoch 19/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.5014 - accuracy: 0.8087 - val_loss: 0.5273 - val_accuracy: 0.7693
# Epoch 20/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4986 - accuracy: 0.7989 - val_loss: 0.5457 - val_accuracy: 0.7764
# Epoch 21/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.4944 - accuracy: 0.8112 - val_loss: 0.5118 - val_accuracy: 0.8045
# Epoch 22/200
# 6/6 [==============================] - 0s 37ms/step - loss: 0.4804 - accuracy: 0.8136 - val_loss: 0.5079 - val_accuracy: 0.7947
# Epoch 23/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.4790 - accuracy: 0.8126 - val_loss: 0.5147 - val_accuracy: 0.7961
# Epoch 24/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4732 - accuracy: 0.8161 - val_loss: 0.4947 - val_accuracy: 0.8017
# Epoch 25/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4633 - accuracy: 0.8126 - val_loss: 0.4833 - val_accuracy: 0.8073
# Epoch 26/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4517 - accuracy: 0.8270 - val_loss: 0.4852 - val_accuracy: 0.8143
# Epoch 27/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4494 - accuracy: 0.8361 - val_loss: 0.4803 - val_accuracy: 0.8129
# Epoch 28/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4504 - accuracy: 0.8249 - val_loss: 0.4730 - val_accuracy: 0.8172
# Epoch 29/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4339 - accuracy: 0.8333 - val_loss: 0.4610 - val_accuracy: 0.8298
# Epoch 30/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4273 - accuracy: 0.8347 - val_loss: 0.4598 - val_accuracy: 0.8284
# Epoch 31/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4309 - accuracy: 0.8316 - val_loss: 0.4511 - val_accuracy: 0.8354
# Epoch 32/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4207 - accuracy: 0.8393 - val_loss: 0.4471 - val_accuracy: 0.8397
# Epoch 33/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4182 - accuracy: 0.8509 - val_loss: 0.4475 - val_accuracy: 0.8383
# Epoch 34/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4028 - accuracy: 0.8516 - val_loss: 0.4374 - val_accuracy: 0.8397
# Epoch 35/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3997 - accuracy: 0.8555 - val_loss: 0.4349 - val_accuracy: 0.8383
# Epoch 36/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4004 - accuracy: 0.8520 - val_loss: 0.4387 - val_accuracy: 0.8354
# Epoch 37/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4001 - accuracy: 0.8565 - val_loss: 0.4284 - val_accuracy: 0.8397
# Epoch 38/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3939 - accuracy: 0.8611 - val_loss: 0.4483 - val_accuracy: 0.8312
# Epoch 39/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3955 - accuracy: 0.8534 - val_loss: 0.4513 - val_accuracy: 0.8326
# Epoch 40/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3973 - accuracy: 0.8558 - val_loss: 0.4335 - val_accuracy: 0.8270
# Epoch 41/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3944 - accuracy: 0.8555 - val_loss: 0.4129 - val_accuracy: 0.8579
# Epoch 42/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3836 - accuracy: 0.8653 - val_loss: 0.4205 - val_accuracy: 0.8537
# Epoch 43/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3742 - accuracy: 0.8611 - val_loss: 0.4146 - val_accuracy: 0.8523
# Epoch 44/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3743 - accuracy: 0.8629 - val_loss: 0.4044 - val_accuracy: 0.8565
# Epoch 45/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3701 - accuracy: 0.8664 - val_loss: 0.4090 - val_accuracy: 0.8622
# Epoch 46/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3633 - accuracy: 0.8710 - val_loss: 0.4030 - val_accuracy: 0.8594
# Epoch 47/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3675 - accuracy: 0.8685 - val_loss: 0.3985 - val_accuracy: 0.8622
# Epoch 48/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3590 - accuracy: 0.8639 - val_loss: 0.3957 - val_accuracy: 0.8537
# Epoch 49/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3498 - accuracy: 0.8773 - val_loss: 0.3947 - val_accuracy: 0.8594
# Epoch 50/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3499 - accuracy: 0.8681 - val_loss: 0.3915 - val_accuracy: 0.8565
# Epoch 51/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3490 - accuracy: 0.8738 - val_loss: 0.3944 - val_accuracy: 0.8565
# Epoch 52/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3521 - accuracy: 0.8741 - val_loss: 0.3910 - val_accuracy: 0.8565
# Epoch 53/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3432 - accuracy: 0.8734 - val_loss: 0.3836 - val_accuracy: 0.8608
# Epoch 54/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3386 - accuracy: 0.8759 - val_loss: 0.3837 - val_accuracy: 0.8636
# Epoch 55/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3416 - accuracy: 0.8734 - val_loss: 0.3808 - val_accuracy: 0.8650
# Epoch 56/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3338 - accuracy: 0.8812 - val_loss: 0.3797 - val_accuracy: 0.8579
# Epoch 57/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3345 - accuracy: 0.8752 - val_loss: 0.3861 - val_accuracy: 0.8608
# Epoch 58/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3414 - accuracy: 0.8783 - val_loss: 0.3765 - val_accuracy: 0.8650
# Epoch 59/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3315 - accuracy: 0.8790 - val_loss: 0.3866 - val_accuracy: 0.8608
# Epoch 60/200
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3285 - accuracy: 0.8826 - val_loss: 0.3915 - val_accuracy: 0.8551
# Epoch 61/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3306 - accuracy: 0.8801 - val_loss: 0.3829 - val_accuracy: 0.8622
# Epoch 62/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3217 - accuracy: 0.8819 - val_loss: 0.3706 - val_accuracy: 0.8594
# Epoch 63/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3218 - accuracy: 0.8808 - val_loss: 0.3687 - val_accuracy: 0.8720
# Epoch 64/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3214 - accuracy: 0.8854 - val_loss: 0.3621 - val_accuracy: 0.8720
# Epoch 65/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3134 - accuracy: 0.8836 - val_loss: 0.3648 - val_accuracy: 0.8664
# Epoch 66/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3129 - accuracy: 0.8878 - val_loss: 0.3659 - val_accuracy: 0.8678
# Epoch 67/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3241 - accuracy: 0.8847 - val_loss: 0.3639 - val_accuracy: 0.8748
# Epoch 68/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3149 - accuracy: 0.8878 - val_loss: 0.3580 - val_accuracy: 0.8734
# Epoch 69/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3176 - accuracy: 0.8815 - val_loss: 0.3603 - val_accuracy: 0.8720
# Epoch 70/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3073 - accuracy: 0.8861 - val_loss: 0.3657 - val_accuracy: 0.8678
# Epoch 71/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3135 - accuracy: 0.8914 - val_loss: 0.3772 - val_accuracy: 0.8664
# Epoch 72/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3165 - accuracy: 0.8808 - val_loss: 0.3614 - val_accuracy: 0.8790
# Epoch 73/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3207 - accuracy: 0.8854 - val_loss: 0.3534 - val_accuracy: 0.8720
# Epoch 74/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3096 - accuracy: 0.8878 - val_loss: 0.3550 - val_accuracy: 0.8692
# Epoch 75/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2992 - accuracy: 0.8942 - val_loss: 0.3701 - val_accuracy: 0.8692
# Epoch 76/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3055 - accuracy: 0.8878 - val_loss: 0.3504 - val_accuracy: 0.8776
# Epoch 77/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3134 - accuracy: 0.8857 - val_loss: 0.3801 - val_accuracy: 0.8608
# Epoch 78/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3096 - accuracy: 0.8896 - val_loss: 0.3585 - val_accuracy: 0.8664
# Epoch 79/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3072 - accuracy: 0.8861 - val_loss: 0.3631 - val_accuracy: 0.8692
# Epoch 80/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3072 - accuracy: 0.8871 - val_loss: 0.3545 - val_accuracy: 0.8720
# Epoch 81/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2974 - accuracy: 0.8966 - val_loss: 0.3511 - val_accuracy: 0.8748
# Epoch 82/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2912 - accuracy: 0.8991 - val_loss: 0.3384 - val_accuracy: 0.8805
# Epoch 83/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2914 - accuracy: 0.8924 - val_loss: 0.3405 - val_accuracy: 0.8833
# Epoch 84/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2870 - accuracy: 0.8991 - val_loss: 0.3405 - val_accuracy: 0.8762
# Epoch 85/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2862 - accuracy: 0.8966 - val_loss: 0.3586 - val_accuracy: 0.8706
# Epoch 86/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3028 - accuracy: 0.8928 - val_loss: 0.3548 - val_accuracy: 0.8692
# Epoch 87/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2957 - accuracy: 0.8914 - val_loss: 0.3366 - val_accuracy: 0.8931
# Epoch 88/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2822 - accuracy: 0.9005 - val_loss: 0.3464 - val_accuracy: 0.8819
# Epoch 89/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2825 - accuracy: 0.9023 - val_loss: 0.3356 - val_accuracy: 0.8917
# Epoch 90/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2830 - accuracy: 0.8903 - val_loss: 0.3322 - val_accuracy: 0.8861
# Epoch 91/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2793 - accuracy: 0.8991 - val_loss: 0.3371 - val_accuracy: 0.8734
# Epoch 92/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2842 - accuracy: 0.8949 - val_loss: 0.3280 - val_accuracy: 0.8931
# Epoch 93/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2757 - accuracy: 0.9026 - val_loss: 0.3353 - val_accuracy: 0.8833
# Epoch 94/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2711 - accuracy: 0.9037 - val_loss: 0.3224 - val_accuracy: 0.8903
# Epoch 95/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2683 - accuracy: 0.8984 - val_loss: 0.3340 - val_accuracy: 0.8776
# Epoch 96/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2747 - accuracy: 0.9005 - val_loss: 0.3295 - val_accuracy: 0.8776
# Epoch 97/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2777 - accuracy: 0.8977 - val_loss: 0.3329 - val_accuracy: 0.8819
# Epoch 98/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2696 - accuracy: 0.8970 - val_loss: 0.3190 - val_accuracy: 0.8959
# Epoch 99/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2684 - accuracy: 0.9110 - val_loss: 0.3314 - val_accuracy: 0.8776
# Epoch 100/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2607 - accuracy: 0.9030 - val_loss: 0.3133 - val_accuracy: 0.8917
# Epoch 101/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2679 - accuracy: 0.9015 - val_loss: 0.3209 - val_accuracy: 0.8903
# Epoch 102/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2621 - accuracy: 0.8991 - val_loss: 0.3202 - val_accuracy: 0.8833
# Epoch 103/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2642 - accuracy: 0.8973 - val_loss: 0.3156 - val_accuracy: 0.8945
# Epoch 104/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2609 - accuracy: 0.9019 - val_loss: 0.3098 - val_accuracy: 0.8917
# Epoch 105/200
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2610 - accuracy: 0.9096 - val_loss: 0.3118 - val_accuracy: 0.8917
# Epoch 106/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2600 - accuracy: 0.9040 - val_loss: 0.3120 - val_accuracy: 0.8959
# Epoch 107/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2502 - accuracy: 0.9110 - val_loss: 0.3119 - val_accuracy: 0.8959
# Epoch 108/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2578 - accuracy: 0.9082 - val_loss: 0.3146 - val_accuracy: 0.8945
# Epoch 109/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2516 - accuracy: 0.9065 - val_loss: 0.3069 - val_accuracy: 0.8973
# Epoch 110/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2572 - accuracy: 0.9047 - val_loss: 0.3068 - val_accuracy: 0.8931
# Epoch 111/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2533 - accuracy: 0.9114 - val_loss: 0.3028 - val_accuracy: 0.9001
# Epoch 112/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2487 - accuracy: 0.9082 - val_loss: 0.3181 - val_accuracy: 0.8847
# Epoch 113/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2515 - accuracy: 0.9068 - val_loss: 0.3054 - val_accuracy: 0.8931
# Epoch 114/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2510 - accuracy: 0.9082 - val_loss: 0.3095 - val_accuracy: 0.8931
# Epoch 115/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2397 - accuracy: 0.9202 - val_loss: 0.2995 - val_accuracy: 0.8959
# Epoch 116/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2377 - accuracy: 0.9139 - val_loss: 0.3032 - val_accuracy: 0.8861
# Epoch 117/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2497 - accuracy: 0.9079 - val_loss: 0.2969 - val_accuracy: 0.9001
# Epoch 118/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2492 - accuracy: 0.9114 - val_loss: 0.2999 - val_accuracy: 0.8987
# Epoch 119/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2398 - accuracy: 0.9121 - val_loss: 0.2975 - val_accuracy: 0.9015
# Epoch 120/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2406 - accuracy: 0.9135 - val_loss: 0.2934 - val_accuracy: 0.8973
# Epoch 121/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2341 - accuracy: 0.9142 - val_loss: 0.2899 - val_accuracy: 0.9114
# Epoch 122/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2350 - accuracy: 0.9191 - val_loss: 0.2987 - val_accuracy: 0.8973
# Epoch 123/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2339 - accuracy: 0.9132 - val_loss: 0.2863 - val_accuracy: 0.9086
# Epoch 124/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2293 - accuracy: 0.9149 - val_loss: 0.2910 - val_accuracy: 0.9001
# Epoch 125/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2243 - accuracy: 0.9212 - val_loss: 0.2936 - val_accuracy: 0.8973
# Epoch 126/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2296 - accuracy: 0.9139 - val_loss: 0.2860 - val_accuracy: 0.9142
# Epoch 127/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2293 - accuracy: 0.9160 - val_loss: 0.2882 - val_accuracy: 0.9142
# Epoch 128/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2274 - accuracy: 0.9184 - val_loss: 0.3057 - val_accuracy: 0.8833
# Epoch 129/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2356 - accuracy: 0.9142 - val_loss: 0.3008 - val_accuracy: 0.9015
# Epoch 130/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2322 - accuracy: 0.9160 - val_loss: 0.2942 - val_accuracy: 0.9030
# Epoch 131/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2281 - accuracy: 0.9156 - val_loss: 0.2903 - val_accuracy: 0.9015
# Epoch 132/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2220 - accuracy: 0.9184 - val_loss: 0.2778 - val_accuracy: 0.9072
# Epoch 133/200
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2220 - accuracy: 0.9223 - val_loss: 0.2938 - val_accuracy: 0.9030
# Epoch 134/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2281 - accuracy: 0.9174 - val_loss: 0.2776 - val_accuracy: 0.9114
# Epoch 135/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2272 - accuracy: 0.9170 - val_loss: 0.2878 - val_accuracy: 0.8931
# Epoch 136/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2165 - accuracy: 0.9276 - val_loss: 0.2735 - val_accuracy: 0.9142
# Epoch 137/200
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2173 - accuracy: 0.9216 - val_loss: 0.2745 - val_accuracy: 0.9058
# Epoch 138/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2150 - accuracy: 0.9226 - val_loss: 0.2772 - val_accuracy: 0.9044
# Epoch 139/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2163 - accuracy: 0.9212 - val_loss: 0.2754 - val_accuracy: 0.9184
# Epoch 140/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2140 - accuracy: 0.9216 - val_loss: 0.2808 - val_accuracy: 0.8987
# Epoch 141/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2127 - accuracy: 0.9209 - val_loss: 0.2884 - val_accuracy: 0.9058
# Epoch 142/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.2131 - accuracy: 0.9216 - val_loss: 0.2642 - val_accuracy: 0.9170
# Epoch 143/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2073 - accuracy: 0.9283 - val_loss: 0.2729 - val_accuracy: 0.9044
# Epoch 144/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.2033 - accuracy: 0.9297 - val_loss: 0.2613 - val_accuracy: 0.9170
# Epoch 145/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2084 - accuracy: 0.9248 - val_loss: 0.2703 - val_accuracy: 0.9100
# Epoch 146/200
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1979 - accuracy: 0.9328 - val_loss: 0.2649 - val_accuracy: 0.9198
# Epoch 147/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2025 - accuracy: 0.9241 - val_loss: 0.2659 - val_accuracy: 0.9142
# Epoch 148/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1966 - accuracy: 0.9276 - val_loss: 0.2613 - val_accuracy: 0.9241
# Epoch 149/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2000 - accuracy: 0.9265 - val_loss: 0.2570 - val_accuracy: 0.9170
# Epoch 150/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1908 - accuracy: 0.9346 - val_loss: 0.2684 - val_accuracy: 0.9100
# Epoch 151/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1962 - accuracy: 0.9265 - val_loss: 0.2568 - val_accuracy: 0.9184
# Epoch 152/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2035 - accuracy: 0.9297 - val_loss: 0.2602 - val_accuracy: 0.9170
# Epoch 153/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2023 - accuracy: 0.9279 - val_loss: 0.2573 - val_accuracy: 0.9170
# Epoch 154/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1930 - accuracy: 0.9311 - val_loss: 0.2627 - val_accuracy: 0.9086
# Epoch 155/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1910 - accuracy: 0.9314 - val_loss: 0.2549 - val_accuracy: 0.9184
# Epoch 156/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1906 - accuracy: 0.9342 - val_loss: 0.2588 - val_accuracy: 0.9269
# Epoch 157/200
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1894 - accuracy: 0.9325 - val_loss: 0.2519 - val_accuracy: 0.9128
# Epoch 158/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1916 - accuracy: 0.9307 - val_loss: 0.2520 - val_accuracy: 0.9241
# Epoch 159/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1879 - accuracy: 0.9339 - val_loss: 0.2532 - val_accuracy: 0.9114
# Epoch 160/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1886 - accuracy: 0.9307 - val_loss: 0.2478 - val_accuracy: 0.9241
# Epoch 161/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1889 - accuracy: 0.9332 - val_loss: 0.2495 - val_accuracy: 0.9128
# Epoch 162/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1859 - accuracy: 0.9367 - val_loss: 0.2420 - val_accuracy: 0.9241
# Epoch 163/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1867 - accuracy: 0.9325 - val_loss: 0.2446 - val_accuracy: 0.9184
# Epoch 164/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1823 - accuracy: 0.9300 - val_loss: 0.2495 - val_accuracy: 0.9170
# Epoch 165/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1817 - accuracy: 0.9413 - val_loss: 0.2464 - val_accuracy: 0.9156
# Epoch 166/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1816 - accuracy: 0.9371 - val_loss: 0.2411 - val_accuracy: 0.9269
# Epoch 167/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1857 - accuracy: 0.9304 - val_loss: 0.2442 - val_accuracy: 0.9212
# Epoch 168/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1849 - accuracy: 0.9318 - val_loss: 0.2388 - val_accuracy: 0.9226
# Epoch 169/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1763 - accuracy: 0.9416 - val_loss: 0.2424 - val_accuracy: 0.9198
# Epoch 170/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1747 - accuracy: 0.9367 - val_loss: 0.2462 - val_accuracy: 0.9184
# Epoch 171/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1831 - accuracy: 0.9300 - val_loss: 0.2328 - val_accuracy: 0.9269
# Epoch 172/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1776 - accuracy: 0.9364 - val_loss: 0.2401 - val_accuracy: 0.9170
# Epoch 173/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1809 - accuracy: 0.9342 - val_loss: 0.2403 - val_accuracy: 0.9283
# Epoch 174/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1802 - accuracy: 0.9357 - val_loss: 0.2494 - val_accuracy: 0.9142
# Epoch 175/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1778 - accuracy: 0.9357 - val_loss: 0.2392 - val_accuracy: 0.9198
# Epoch 176/200
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1786 - accuracy: 0.9318 - val_loss: 0.2295 - val_accuracy: 0.9226
# Epoch 177/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1723 - accuracy: 0.9342 - val_loss: 0.2371 - val_accuracy: 0.9226
# Epoch 178/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1716 - accuracy: 0.9420 - val_loss: 0.2344 - val_accuracy: 0.9269
# Epoch 179/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1706 - accuracy: 0.9423 - val_loss: 0.2314 - val_accuracy: 0.9269
# Epoch 180/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1724 - accuracy: 0.9402 - val_loss: 0.2289 - val_accuracy: 0.9226
# Epoch 181/200
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1689 - accuracy: 0.9378 - val_loss: 0.2368 - val_accuracy: 0.9241
# Epoch 182/200
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1700 - accuracy: 0.9388 - val_loss: 0.2286 - val_accuracy: 0.9255
# Epoch 183/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1663 - accuracy: 0.9399 - val_loss: 0.2371 - val_accuracy: 0.9212
# Epoch 184/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1693 - accuracy: 0.9388 - val_loss: 0.2303 - val_accuracy: 0.9255
# Epoch 185/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1650 - accuracy: 0.9444 - val_loss: 0.2280 - val_accuracy: 0.9255
# Epoch 186/200
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1608 - accuracy: 0.9423 - val_loss: 0.2299 - val_accuracy: 0.9283
# Epoch 187/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1636 - accuracy: 0.9437 - val_loss: 0.2319 - val_accuracy: 0.9241
# Epoch 188/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1683 - accuracy: 0.9395 - val_loss: 0.2232 - val_accuracy: 0.9241
# Epoch 189/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1645 - accuracy: 0.9406 - val_loss: 0.2333 - val_accuracy: 0.9212
# Epoch 190/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1647 - accuracy: 0.9399 - val_loss: 0.2277 - val_accuracy: 0.9269
# Epoch 191/200
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1577 - accuracy: 0.9448 - val_loss: 0.2297 - val_accuracy: 0.9283
# Epoch 192/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1638 - accuracy: 0.9409 - val_loss: 0.2258 - val_accuracy: 0.9269
# Epoch 193/200
# 6/6 [==============================] - 0s 30ms/step - loss: 0.1569 - accuracy: 0.9441 - val_loss: 0.2276 - val_accuracy: 0.9269
# Epoch 194/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1557 - accuracy: 0.9434 - val_loss: 0.2181 - val_accuracy: 0.9269
# Epoch 195/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1536 - accuracy: 0.9444 - val_loss: 0.2309 - val_accuracy: 0.9184
# Epoch 196/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1652 - accuracy: 0.9385 - val_loss: 0.2204 - val_accuracy: 0.9269
# Epoch 197/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1474 - accuracy: 0.9508 - val_loss: 0.2216 - val_accuracy: 0.9325
# Epoch 198/200
# 6/6 [==============================] - 0s 26ms/step - loss: 0.1574 - accuracy: 0.9451 - val_loss: 0.2260 - val_accuracy: 0.9212
# Epoch 199/200
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1521 - accuracy: 0.9469 - val_loss: 0.2154 - val_accuracy: 0.9311
# Epoch 200/200
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1540 - accuracy: 0.9444 - val_loss: 0.2212 - val_accuracy: 0.9325

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2])
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 6/6 [==============================] - 0s 68ms/step - loss: 2.0656 - accuracy: 0.2546 - val_loss: 1.7842 - val_accuracy: 0.3376
# Epoch 2/45
# 6/6 [==============================] - 0s 28ms/step - loss: 1.7298 - accuracy: 0.3400 - val_loss: 1.6116 - val_accuracy: 0.3797
# Epoch 3/45
# 6/6 [==============================] - 0s 29ms/step - loss: 1.5738 - accuracy: 0.4993 - val_loss: 1.4324 - val_accuracy: 0.5598
# Epoch 4/45
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3785 - accuracy: 0.5443 - val_loss: 1.2110 - val_accuracy: 0.6385
# Epoch 5/45
# 6/6 [==============================] - 0s 27ms/step - loss: 1.1677 - accuracy: 0.6568 - val_loss: 1.0217 - val_accuracy: 0.6878
# Epoch 6/45
# 6/6 [==============================] - 0s 38ms/step - loss: 0.9948 - accuracy: 0.6818 - val_loss: 0.8994 - val_accuracy: 0.6976
# Epoch 7/45
# 6/6 [==============================] - 0s 29ms/step - loss: 0.8829 - accuracy: 0.7018 - val_loss: 0.8131 - val_accuracy: 0.7173
# Epoch 8/45
# 6/6 [==============================] - 0s 32ms/step - loss: 0.8020 - accuracy: 0.7120 - val_loss: 0.7418 - val_accuracy: 0.7243
# Epoch 9/45
# 6/6 [==============================] - 0s 32ms/step - loss: 0.7390 - accuracy: 0.7264 - val_loss: 0.7168 - val_accuracy: 0.7215
# Epoch 10/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.7035 - accuracy: 0.7261 - val_loss: 0.6710 - val_accuracy: 0.7243
# Epoch 11/45
# 6/6 [==============================] - 0s 30ms/step - loss: 0.6636 - accuracy: 0.7289 - val_loss: 0.6465 - val_accuracy: 0.7482
# Epoch 12/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6369 - accuracy: 0.7419 - val_loss: 0.6232 - val_accuracy: 0.7300
# Epoch 13/45
# 6/6 [==============================] - 0s 33ms/step - loss: 0.6125 - accuracy: 0.7486 - val_loss: 0.6085 - val_accuracy: 0.7679
# Epoch 14/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5985 - accuracy: 0.7472 - val_loss: 0.5919 - val_accuracy: 0.7398
# Epoch 15/45
# 6/6 [==============================] - 0s 30ms/step - loss: 0.5858 - accuracy: 0.7539 - val_loss: 0.5826 - val_accuracy: 0.7637
# Epoch 16/45
# 6/6 [==============================] - 0s 32ms/step - loss: 0.5798 - accuracy: 0.7507 - val_loss: 0.5721 - val_accuracy: 0.7496
# Epoch 17/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5526 - accuracy: 0.7714 - val_loss: 0.5636 - val_accuracy: 0.7567
# Epoch 18/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5493 - accuracy: 0.7697 - val_loss: 0.5762 - val_accuracy: 0.7637
# Epoch 19/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5458 - accuracy: 0.7778 - val_loss: 0.5498 - val_accuracy: 0.7693
# Epoch 20/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5283 - accuracy: 0.7781 - val_loss: 0.5402 - val_accuracy: 0.7623
# Epoch 21/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5065 - accuracy: 0.7880 - val_loss: 0.5255 - val_accuracy: 0.7932
# Epoch 22/45
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5092 - accuracy: 0.7947 - val_loss: 0.5227 - val_accuracy: 0.7961
# Epoch 23/45
# 6/6 [==============================] - 0s 26ms/step - loss: 0.5013 - accuracy: 0.8027 - val_loss: 0.5171 - val_accuracy: 0.8017
# Epoch 24/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4935 - accuracy: 0.7911 - val_loss: 0.5063 - val_accuracy: 0.7918
# Epoch 25/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4796 - accuracy: 0.8094 - val_loss: 0.4995 - val_accuracy: 0.8101
# Epoch 26/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4681 - accuracy: 0.8200 - val_loss: 0.4909 - val_accuracy: 0.8087
# Epoch 27/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4546 - accuracy: 0.8295 - val_loss: 0.4994 - val_accuracy: 0.8101
# Epoch 28/45
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4666 - accuracy: 0.8210 - val_loss: 0.4993 - val_accuracy: 0.8256
# Epoch 29/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4679 - accuracy: 0.8235 - val_loss: 0.4863 - val_accuracy: 0.8354
# Epoch 30/45
# 6/6 [==============================] - 0s 29ms/step - loss: 0.4490 - accuracy: 0.8337 - val_loss: 0.4873 - val_accuracy: 0.8228
# Epoch 31/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4433 - accuracy: 0.8330 - val_loss: 0.4738 - val_accuracy: 0.8242
# Epoch 32/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4399 - accuracy: 0.8295 - val_loss: 0.4631 - val_accuracy: 0.8256
# Epoch 33/45
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4337 - accuracy: 0.8368 - val_loss: 0.4588 - val_accuracy: 0.8228
# Epoch 34/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4195 - accuracy: 0.8460 - val_loss: 0.4479 - val_accuracy: 0.8439
# Epoch 35/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4201 - accuracy: 0.8383 - val_loss: 0.4522 - val_accuracy: 0.8425
# Epoch 36/45
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4216 - accuracy: 0.8340 - val_loss: 0.4441 - val_accuracy: 0.8481
# Epoch 37/45
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4128 - accuracy: 0.8439 - val_loss: 0.4723 - val_accuracy: 0.8284
# Epoch 38/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.4213 - accuracy: 0.8414 - val_loss: 0.4402 - val_accuracy: 0.8495
# Epoch 39/45
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4090 - accuracy: 0.8551 - val_loss: 0.4348 - val_accuracy: 0.8383
# Epoch 40/45
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3953 - accuracy: 0.8537 - val_loss: 0.4330 - val_accuracy: 0.8425
# Epoch 41/45
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3961 - accuracy: 0.8534 - val_loss: 0.4563 - val_accuracy: 0.8270
# Epoch 42/45
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4161 - accuracy: 0.8456 - val_loss: 0.4299 - val_accuracy: 0.8312
# Epoch 43/45
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3991 - accuracy: 0.8492 - val_loss: 0.4185 - val_accuracy: 0.8551
# Epoch 44/45
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3929 - accuracy: 0.8572 - val_loss: 0.4496 - val_accuracy: 0.8467
# Epoch 45/45
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3848 - accuracy: 0.8548 - val_loss: 0.4159 - val_accuracy: 0.8579

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 3ms/step - loss: 0.3526 - accuracy: 0.8787
# 23/23 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8579
# 0.8786919713020325 0.8579465746879578

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 22, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:03:07

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0  96   0   4   0   0   0   0]
#  [  0   0 117   2   3   0   0   0]
#  [  0   4   0 211  13   0   0  12]
#  [  0   1   2  24  64   1   1   7]
#  [  0   0   0   0   1   9   2   0]
#  [  0   0   0   0   2   0   9   0]
#  [  0   0   0  15   7   0   0  24]]
#
# Accuracy Score
# 0.8579465541490858
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        80
#      clouds       0.95      0.96      0.96       100
#  vegetation       0.98      0.96      0.97       122
#       built       0.82      0.88      0.85       240
#     windows       0.71      0.64      0.67       100
#       roads       0.90      0.75      0.82        12
#        cars       0.75      0.82      0.78        11
#       metal       0.56      0.52      0.54        46
#
# avg / total       0.86      0.86      0.86       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 22
# [[0, 39], [39, 78], [78, 117], [117, 156], [156, 195], [195, 234], [234, 273], [273, 312], [312, 351], [351, 390], [390, 429], [429, 468], [468, 507], [507, 546], [546, 585], [585, 624], [624, 663], [663, 702], [702, 741], [741, 780], [780, 819], [819, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 22)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 22)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 22)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 22) (60, 22)
# clouds  (160, 22) (40, 22)
# vegetation  (560, 22) (140, 22)
# water  (496, 22) (124, 22)
# built  (1280, 22) (320, 22)
# windows  (480, 22) (120, 22)
# roads  (200, 22) (50, 22)
# cars  (200, 22) (50, 22)
# metal  (148, 22) (37, 22)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 22) (3764,) (3764, 2)
# (941, 22) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 45ms/step - loss: 2.0280 - accuracy: 0.2912 - val_loss: 1.8254 - val_accuracy: 0.3401
# Epoch 2/200
# 8/8 [==============================] - 0s 31ms/step - loss: 1.7657 - accuracy: 0.3969 - val_loss: 1.6209 - val_accuracy: 0.4187
# Epoch 3/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.5658 - accuracy: 0.4748 - val_loss: 1.4266 - val_accuracy: 0.4835
# Epoch 4/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.4126 - accuracy: 0.5106 - val_loss: 1.3453 - val_accuracy: 0.5399
# Epoch 5/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.3337 - accuracy: 0.5563 - val_loss: 1.2770 - val_accuracy: 0.5537
# Epoch 6/200
# 8/8 [==============================] - 0s 29ms/step - loss: 1.2737 - accuracy: 0.5616 - val_loss: 1.2270 - val_accuracy: 0.5845
# Epoch 7/200
# 8/8 [==============================] - 0s 28ms/step - loss: 1.2235 - accuracy: 0.5882 - val_loss: 1.1791 - val_accuracy: 0.6440
# Epoch 8/200
# 8/8 [==============================] - 0s 31ms/step - loss: 1.1816 - accuracy: 0.6092 - val_loss: 1.1323 - val_accuracy: 0.6334
# Epoch 9/200
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1361 - accuracy: 0.6312 - val_loss: 1.0946 - val_accuracy: 0.6525
# Epoch 10/200
# 8/8 [==============================] - 0s 38ms/step - loss: 1.1027 - accuracy: 0.6355 - val_loss: 1.0585 - val_accuracy: 0.6833
# Epoch 11/200
# 8/8 [==============================] - 0s 42ms/step - loss: 1.0704 - accuracy: 0.6629 - val_loss: 1.0269 - val_accuracy: 0.7078
# Epoch 12/200
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0283 - accuracy: 0.6761 - val_loss: 0.9876 - val_accuracy: 0.7078
# Epoch 13/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9991 - accuracy: 0.6809 - val_loss: 0.9506 - val_accuracy: 0.7248
# Epoch 14/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9646 - accuracy: 0.6854 - val_loss: 0.9218 - val_accuracy: 0.7248
# Epoch 15/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9224 - accuracy: 0.7056 - val_loss: 0.8898 - val_accuracy: 0.7439
# Epoch 16/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9005 - accuracy: 0.7101 - val_loss: 0.8526 - val_accuracy: 0.7333
# Epoch 17/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.8666 - accuracy: 0.7194 - val_loss: 0.8303 - val_accuracy: 0.7492
# Epoch 18/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8357 - accuracy: 0.7365 - val_loss: 0.8014 - val_accuracy: 0.7524
# Epoch 19/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.8160 - accuracy: 0.7495 - val_loss: 0.7735 - val_accuracy: 0.7673
# Epoch 20/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7893 - accuracy: 0.7521 - val_loss: 0.7581 - val_accuracy: 0.7524
# Epoch 21/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7691 - accuracy: 0.7606 - val_loss: 0.7303 - val_accuracy: 0.7779
# Epoch 22/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7465 - accuracy: 0.7635 - val_loss: 0.7057 - val_accuracy: 0.7758
# Epoch 23/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7236 - accuracy: 0.7792 - val_loss: 0.6886 - val_accuracy: 0.7938
# Epoch 24/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7148 - accuracy: 0.7723 - val_loss: 0.6780 - val_accuracy: 0.7949
# Epoch 25/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7001 - accuracy: 0.7851 - val_loss: 0.6594 - val_accuracy: 0.8119
# Epoch 26/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6872 - accuracy: 0.7875 - val_loss: 0.6580 - val_accuracy: 0.8034
# Epoch 27/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6783 - accuracy: 0.7872 - val_loss: 0.6365 - val_accuracy: 0.8204
# Epoch 28/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6688 - accuracy: 0.7896 - val_loss: 0.6332 - val_accuracy: 0.8151
# Epoch 29/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6575 - accuracy: 0.7949 - val_loss: 0.6332 - val_accuracy: 0.8172
# Epoch 30/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.6462 - accuracy: 0.8007 - val_loss: 0.6083 - val_accuracy: 0.8193
# Epoch 31/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6357 - accuracy: 0.7989 - val_loss: 0.6061 - val_accuracy: 0.8268
# Epoch 32/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6218 - accuracy: 0.8103 - val_loss: 0.5915 - val_accuracy: 0.8363
# Epoch 33/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6204 - accuracy: 0.8039 - val_loss: 0.5909 - val_accuracy: 0.8385
# Epoch 34/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6117 - accuracy: 0.8119 - val_loss: 0.5830 - val_accuracy: 0.8395
# Epoch 35/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.5980 - accuracy: 0.8170 - val_loss: 0.5702 - val_accuracy: 0.8417
# Epoch 36/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5906 - accuracy: 0.8191 - val_loss: 0.5668 - val_accuracy: 0.8491
# Epoch 37/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5736 - accuracy: 0.8247 - val_loss: 0.5540 - val_accuracy: 0.8459
# Epoch 38/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5758 - accuracy: 0.8239 - val_loss: 0.5475 - val_accuracy: 0.8480
# Epoch 39/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5722 - accuracy: 0.8228 - val_loss: 0.5513 - val_accuracy: 0.8438
# Epoch 40/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5657 - accuracy: 0.8249 - val_loss: 0.5436 - val_accuracy: 0.8417
# Epoch 41/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5618 - accuracy: 0.8244 - val_loss: 0.5345 - val_accuracy: 0.8480
# Epoch 42/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5628 - accuracy: 0.8207 - val_loss: 0.5495 - val_accuracy: 0.8459
# Epoch 43/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5610 - accuracy: 0.8255 - val_loss: 0.5354 - val_accuracy: 0.8395
# Epoch 44/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5516 - accuracy: 0.8286 - val_loss: 0.5329 - val_accuracy: 0.8480
# Epoch 45/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5445 - accuracy: 0.8334 - val_loss: 0.5222 - val_accuracy: 0.8502
# Epoch 46/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.5378 - accuracy: 0.8379 - val_loss: 0.5181 - val_accuracy: 0.8587
# Epoch 47/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5260 - accuracy: 0.8363 - val_loss: 0.5060 - val_accuracy: 0.8512
# Epoch 48/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5326 - accuracy: 0.8374 - val_loss: 0.5203 - val_accuracy: 0.8576
# Epoch 49/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5285 - accuracy: 0.8334 - val_loss: 0.5089 - val_accuracy: 0.8544
# Epoch 50/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5197 - accuracy: 0.8427 - val_loss: 0.5004 - val_accuracy: 0.8565
# Epoch 51/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5239 - accuracy: 0.8324 - val_loss: 0.4974 - val_accuracy: 0.8512
# Epoch 52/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5181 - accuracy: 0.8371 - val_loss: 0.4942 - val_accuracy: 0.8544
# Epoch 53/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5124 - accuracy: 0.8406 - val_loss: 0.4942 - val_accuracy: 0.8576
# Epoch 54/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5068 - accuracy: 0.8401 - val_loss: 0.4811 - val_accuracy: 0.8587
# Epoch 55/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4980 - accuracy: 0.8459 - val_loss: 0.4845 - val_accuracy: 0.8544
# Epoch 56/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5036 - accuracy: 0.8414 - val_loss: 0.4757 - val_accuracy: 0.8555
# Epoch 57/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4975 - accuracy: 0.8427 - val_loss: 0.4860 - val_accuracy: 0.8587
# Epoch 58/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4982 - accuracy: 0.8440 - val_loss: 0.4765 - val_accuracy: 0.8629
# Epoch 59/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4915 - accuracy: 0.8454 - val_loss: 0.4707 - val_accuracy: 0.8618
# Epoch 60/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4920 - accuracy: 0.8414 - val_loss: 0.4698 - val_accuracy: 0.8640
# Epoch 61/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4780 - accuracy: 0.8512 - val_loss: 0.4742 - val_accuracy: 0.8544
# Epoch 62/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4846 - accuracy: 0.8454 - val_loss: 0.4642 - val_accuracy: 0.8576
# Epoch 63/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4728 - accuracy: 0.8475 - val_loss: 0.4577 - val_accuracy: 0.8693
# Epoch 64/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4747 - accuracy: 0.8459 - val_loss: 0.4542 - val_accuracy: 0.8608
# Epoch 65/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4732 - accuracy: 0.8467 - val_loss: 0.4496 - val_accuracy: 0.8672
# Epoch 66/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4666 - accuracy: 0.8502 - val_loss: 0.4518 - val_accuracy: 0.8661
# Epoch 67/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4602 - accuracy: 0.8518 - val_loss: 0.4510 - val_accuracy: 0.8650
# Epoch 68/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.4554 - accuracy: 0.8560 - val_loss: 0.4434 - val_accuracy: 0.8757
# Epoch 69/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4601 - accuracy: 0.8512 - val_loss: 0.4528 - val_accuracy: 0.8682
# Epoch 70/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4564 - accuracy: 0.8573 - val_loss: 0.4385 - val_accuracy: 0.8789
# Epoch 71/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4485 - accuracy: 0.8616 - val_loss: 0.4349 - val_accuracy: 0.8714
# Epoch 72/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4472 - accuracy: 0.8595 - val_loss: 0.4371 - val_accuracy: 0.8735
# Epoch 73/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.4387 - accuracy: 0.8648 - val_loss: 0.4253 - val_accuracy: 0.8746
# Epoch 74/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.4490 - accuracy: 0.8560 - val_loss: 0.4327 - val_accuracy: 0.8725
# Epoch 75/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4494 - accuracy: 0.8571 - val_loss: 0.4390 - val_accuracy: 0.8778
# Epoch 76/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.4427 - accuracy: 0.8571 - val_loss: 0.4464 - val_accuracy: 0.8629
# Epoch 77/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4423 - accuracy: 0.8613 - val_loss: 0.4355 - val_accuracy: 0.8661
# Epoch 78/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4407 - accuracy: 0.8589 - val_loss: 0.4271 - val_accuracy: 0.8735
# Epoch 79/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4420 - accuracy: 0.8616 - val_loss: 0.4233 - val_accuracy: 0.8767
# Epoch 80/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4432 - accuracy: 0.8608 - val_loss: 0.4249 - val_accuracy: 0.8820
# Epoch 81/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4316 - accuracy: 0.8674 - val_loss: 0.4158 - val_accuracy: 0.8842
# Epoch 82/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.4264 - accuracy: 0.8656 - val_loss: 0.4173 - val_accuracy: 0.8799
# Epoch 83/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4247 - accuracy: 0.8656 - val_loss: 0.4137 - val_accuracy: 0.8735
# Epoch 84/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4239 - accuracy: 0.8656 - val_loss: 0.4054 - val_accuracy: 0.8842
# Epoch 85/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.4259 - accuracy: 0.8704 - val_loss: 0.4161 - val_accuracy: 0.8778
# Epoch 86/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4224 - accuracy: 0.8709 - val_loss: 0.4217 - val_accuracy: 0.8789
# Epoch 87/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4193 - accuracy: 0.8664 - val_loss: 0.4188 - val_accuracy: 0.8682
# Epoch 88/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.4351 - accuracy: 0.8595 - val_loss: 0.4160 - val_accuracy: 0.8693
# Epoch 89/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4350 - accuracy: 0.8613 - val_loss: 0.3960 - val_accuracy: 0.8863
# Epoch 90/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.4227 - accuracy: 0.8661 - val_loss: 0.4110 - val_accuracy: 0.8789
# Epoch 91/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4245 - accuracy: 0.8666 - val_loss: 0.4046 - val_accuracy: 0.8820
# Epoch 92/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4022 - accuracy: 0.8751 - val_loss: 0.3990 - val_accuracy: 0.8852
# Epoch 93/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3966 - accuracy: 0.8711 - val_loss: 0.3970 - val_accuracy: 0.8831
# Epoch 94/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3998 - accuracy: 0.8730 - val_loss: 0.3968 - val_accuracy: 0.8927
# Epoch 95/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4006 - accuracy: 0.8738 - val_loss: 0.3922 - val_accuracy: 0.8842
# Epoch 96/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3997 - accuracy: 0.8725 - val_loss: 0.4061 - val_accuracy: 0.8820
# Epoch 97/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4118 - accuracy: 0.8693 - val_loss: 0.4001 - val_accuracy: 0.8789
# Epoch 98/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.4088 - accuracy: 0.8682 - val_loss: 0.4089 - val_accuracy: 0.8778
# Epoch 99/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3954 - accuracy: 0.8751 - val_loss: 0.3994 - val_accuracy: 0.8863
# Epoch 100/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3865 - accuracy: 0.8754 - val_loss: 0.3973 - val_accuracy: 0.8916
# Epoch 101/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3989 - accuracy: 0.8775 - val_loss: 0.3821 - val_accuracy: 0.8916
# Epoch 102/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.3795 - accuracy: 0.8807 - val_loss: 0.3760 - val_accuracy: 0.8937
# Epoch 103/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3802 - accuracy: 0.8818 - val_loss: 0.3854 - val_accuracy: 0.8980
# Epoch 104/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3847 - accuracy: 0.8804 - val_loss: 0.3811 - val_accuracy: 0.8905
# Epoch 105/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3840 - accuracy: 0.8802 - val_loss: 0.3844 - val_accuracy: 0.8916
# Epoch 106/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3822 - accuracy: 0.8789 - val_loss: 0.3845 - val_accuracy: 0.8852
# Epoch 107/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3876 - accuracy: 0.8757 - val_loss: 0.3792 - val_accuracy: 0.8884
# Epoch 108/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3755 - accuracy: 0.8783 - val_loss: 0.3658 - val_accuracy: 0.9044
# Epoch 109/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3779 - accuracy: 0.8826 - val_loss: 0.3688 - val_accuracy: 0.8959
# Epoch 110/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3727 - accuracy: 0.8823 - val_loss: 0.3680 - val_accuracy: 0.9022
# Epoch 111/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3719 - accuracy: 0.8847 - val_loss: 0.3658 - val_accuracy: 0.9001
# Epoch 112/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3750 - accuracy: 0.8826 - val_loss: 0.3867 - val_accuracy: 0.8863
# Epoch 113/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3767 - accuracy: 0.8834 - val_loss: 0.3864 - val_accuracy: 0.8895
# Epoch 114/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3687 - accuracy: 0.8831 - val_loss: 0.3771 - val_accuracy: 0.8916
# Epoch 115/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3780 - accuracy: 0.8812 - val_loss: 0.3900 - val_accuracy: 0.8874
# Epoch 116/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3711 - accuracy: 0.8783 - val_loss: 0.3616 - val_accuracy: 0.8969
# Epoch 117/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3670 - accuracy: 0.8847 - val_loss: 0.3604 - val_accuracy: 0.8937
# Epoch 118/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3534 - accuracy: 0.8905 - val_loss: 0.3565 - val_accuracy: 0.9033
# Epoch 119/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3520 - accuracy: 0.8852 - val_loss: 0.3612 - val_accuracy: 0.8990
# Epoch 120/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3547 - accuracy: 0.8905 - val_loss: 0.3566 - val_accuracy: 0.8990
# Epoch 121/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3501 - accuracy: 0.8842 - val_loss: 0.3571 - val_accuracy: 0.8937
# Epoch 122/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3528 - accuracy: 0.8905 - val_loss: 0.3544 - val_accuracy: 0.8980
# Epoch 123/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3545 - accuracy: 0.8913 - val_loss: 0.3527 - val_accuracy: 0.9054
# Epoch 124/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3458 - accuracy: 0.8911 - val_loss: 0.3500 - val_accuracy: 0.9022
# Epoch 125/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3432 - accuracy: 0.8927 - val_loss: 0.3434 - val_accuracy: 0.9022
# Epoch 126/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3473 - accuracy: 0.8892 - val_loss: 0.3419 - val_accuracy: 0.8980
# Epoch 127/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3485 - accuracy: 0.8882 - val_loss: 0.3521 - val_accuracy: 0.8990
# Epoch 128/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3495 - accuracy: 0.8903 - val_loss: 0.3453 - val_accuracy: 0.9065
# Epoch 129/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3441 - accuracy: 0.8961 - val_loss: 0.3437 - val_accuracy: 0.9044
# Epoch 130/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3385 - accuracy: 0.8943 - val_loss: 0.3471 - val_accuracy: 0.8948
# Epoch 131/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3325 - accuracy: 0.8993 - val_loss: 0.3463 - val_accuracy: 0.9065
# Epoch 132/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3437 - accuracy: 0.8937 - val_loss: 0.3498 - val_accuracy: 0.9054
# Epoch 133/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3408 - accuracy: 0.8943 - val_loss: 0.3334 - val_accuracy: 0.9075
# Epoch 134/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3407 - accuracy: 0.8932 - val_loss: 0.3376 - val_accuracy: 0.8980
# Epoch 135/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3413 - accuracy: 0.8919 - val_loss: 0.3370 - val_accuracy: 0.9022
# Epoch 136/200
# 8/8 [==============================] - 0s 34ms/step - loss: 0.3462 - accuracy: 0.8908 - val_loss: 0.3487 - val_accuracy: 0.9054
# Epoch 137/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3463 - accuracy: 0.8876 - val_loss: 0.3898 - val_accuracy: 0.8927
# Epoch 138/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3687 - accuracy: 0.8796 - val_loss: 0.3899 - val_accuracy: 0.8927
# Epoch 139/200
# 8/8 [==============================] - 0s 36ms/step - loss: 0.3543 - accuracy: 0.8834 - val_loss: 0.3465 - val_accuracy: 0.8980
# Epoch 140/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3440 - accuracy: 0.8913 - val_loss: 0.3361 - val_accuracy: 0.9054
# Epoch 141/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3272 - accuracy: 0.8977 - val_loss: 0.3327 - val_accuracy: 0.9065
# Epoch 142/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3328 - accuracy: 0.8945 - val_loss: 0.3273 - val_accuracy: 0.9150
# Epoch 143/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3376 - accuracy: 0.8956 - val_loss: 0.3403 - val_accuracy: 0.9044
# Epoch 144/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3283 - accuracy: 0.9001 - val_loss: 0.3297 - val_accuracy: 0.9075
# Epoch 145/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3197 - accuracy: 0.8996 - val_loss: 0.3187 - val_accuracy: 0.9129
# Epoch 146/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3134 - accuracy: 0.9017 - val_loss: 0.3176 - val_accuracy: 0.9107
# Epoch 147/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3134 - accuracy: 0.9014 - val_loss: 0.3330 - val_accuracy: 0.9065
# Epoch 148/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3211 - accuracy: 0.9001 - val_loss: 0.3235 - val_accuracy: 0.9150
# Epoch 149/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3216 - accuracy: 0.9017 - val_loss: 0.3356 - val_accuracy: 0.8980
# Epoch 150/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3263 - accuracy: 0.8982 - val_loss: 0.3374 - val_accuracy: 0.9086
# Epoch 151/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3230 - accuracy: 0.9009 - val_loss: 0.3298 - val_accuracy: 0.9044
# Epoch 152/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3177 - accuracy: 0.9006 - val_loss: 0.3278 - val_accuracy: 0.9118
# Epoch 153/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3134 - accuracy: 0.9028 - val_loss: 0.3236 - val_accuracy: 0.9150
# Epoch 154/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3089 - accuracy: 0.9062 - val_loss: 0.3150 - val_accuracy: 0.9118
# Epoch 155/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.3152 - accuracy: 0.9046 - val_loss: 0.3183 - val_accuracy: 0.9107
# Epoch 156/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3127 - accuracy: 0.8993 - val_loss: 0.3131 - val_accuracy: 0.9139
# Epoch 157/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3058 - accuracy: 0.9014 - val_loss: 0.3125 - val_accuracy: 0.9182
# Epoch 158/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3032 - accuracy: 0.9038 - val_loss: 0.3264 - val_accuracy: 0.9118
# Epoch 159/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2998 - accuracy: 0.9070 - val_loss: 0.3186 - val_accuracy: 0.9182
# Epoch 160/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2952 - accuracy: 0.9126 - val_loss: 0.3081 - val_accuracy: 0.9129
# Epoch 161/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3087 - accuracy: 0.9067 - val_loss: 0.3070 - val_accuracy: 0.9150
# Epoch 162/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3178 - accuracy: 0.9020 - val_loss: 0.3071 - val_accuracy: 0.9160
# Epoch 163/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.3062 - accuracy: 0.9094 - val_loss: 0.3137 - val_accuracy: 0.9118
# Epoch 164/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3027 - accuracy: 0.9094 - val_loss: 0.3084 - val_accuracy: 0.9203
# Epoch 165/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.3020 - accuracy: 0.9097 - val_loss: 0.3091 - val_accuracy: 0.9097
# Epoch 166/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2938 - accuracy: 0.9105 - val_loss: 0.3002 - val_accuracy: 0.9214
# Epoch 167/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2986 - accuracy: 0.9025 - val_loss: 0.2994 - val_accuracy: 0.9192
# Epoch 168/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.3004 - accuracy: 0.9110 - val_loss: 0.3045 - val_accuracy: 0.9160
# Epoch 169/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2929 - accuracy: 0.9078 - val_loss: 0.2999 - val_accuracy: 0.9203
# Epoch 170/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2902 - accuracy: 0.9110 - val_loss: 0.3115 - val_accuracy: 0.9160
# Epoch 171/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2936 - accuracy: 0.9081 - val_loss: 0.3021 - val_accuracy: 0.9245
# Epoch 172/200
# 8/8 [==============================] - 0s 37ms/step - loss: 0.2808 - accuracy: 0.9145 - val_loss: 0.3084 - val_accuracy: 0.9203
# Epoch 173/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2895 - accuracy: 0.9102 - val_loss: 0.3290 - val_accuracy: 0.9139
# Epoch 174/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2969 - accuracy: 0.9049 - val_loss: 0.3144 - val_accuracy: 0.9150
# Epoch 175/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2988 - accuracy: 0.9107 - val_loss: 0.3006 - val_accuracy: 0.9192
# Epoch 176/200
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2851 - accuracy: 0.9126 - val_loss: 0.2939 - val_accuracy: 0.9214
# Epoch 177/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2771 - accuracy: 0.9155 - val_loss: 0.2927 - val_accuracy: 0.9182
# Epoch 178/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2829 - accuracy: 0.9113 - val_loss: 0.3019 - val_accuracy: 0.9192
# Epoch 179/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2803 - accuracy: 0.9158 - val_loss: 0.3009 - val_accuracy: 0.9214
# Epoch 180/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2813 - accuracy: 0.9115 - val_loss: 0.2946 - val_accuracy: 0.9139
# Epoch 181/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2895 - accuracy: 0.9137 - val_loss: 0.2892 - val_accuracy: 0.9224
# Epoch 182/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2807 - accuracy: 0.9160 - val_loss: 0.2890 - val_accuracy: 0.9245
# Epoch 183/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2801 - accuracy: 0.9137 - val_loss: 0.2996 - val_accuracy: 0.9150
# Epoch 184/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2807 - accuracy: 0.9123 - val_loss: 0.3044 - val_accuracy: 0.9214
# Epoch 185/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2731 - accuracy: 0.9118 - val_loss: 0.2909 - val_accuracy: 0.9203
# Epoch 186/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.2813 - accuracy: 0.9113 - val_loss: 0.2876 - val_accuracy: 0.9203
# Epoch 187/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2704 - accuracy: 0.9190 - val_loss: 0.2826 - val_accuracy: 0.9245
# Epoch 188/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2697 - accuracy: 0.9195 - val_loss: 0.2863 - val_accuracy: 0.9214
# Epoch 189/200
# 8/8 [==============================] - 0s 33ms/step - loss: 0.2775 - accuracy: 0.9155 - val_loss: 0.3022 - val_accuracy: 0.9160
# Epoch 190/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2757 - accuracy: 0.9147 - val_loss: 0.2901 - val_accuracy: 0.9224
# Epoch 191/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2788 - accuracy: 0.9115 - val_loss: 0.2845 - val_accuracy: 0.9267
# Epoch 192/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2882 - accuracy: 0.9115 - val_loss: 0.3120 - val_accuracy: 0.9118
# Epoch 193/200
# 8/8 [==============================] - 0s 38ms/step - loss: 0.2804 - accuracy: 0.9150 - val_loss: 0.2932 - val_accuracy: 0.9118
# Epoch 194/200
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2781 - accuracy: 0.9158 - val_loss: 0.2807 - val_accuracy: 0.9256
# Epoch 195/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2794 - accuracy: 0.9145 - val_loss: 0.2818 - val_accuracy: 0.9214
# Epoch 196/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2635 - accuracy: 0.9139 - val_loss: 0.2837 - val_accuracy: 0.9235
# Epoch 197/200
# 8/8 [==============================] - 0s 29ms/step - loss: 0.2617 - accuracy: 0.9192 - val_loss: 0.2802 - val_accuracy: 0.9277
# Epoch 198/200
# 8/8 [==============================] - 0s 27ms/step - loss: 0.2623 - accuracy: 0.9187 - val_loss: 0.2793 - val_accuracy: 0.9256
# Epoch 199/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2644 - accuracy: 0.9184 - val_loss: 0.2760 - val_accuracy: 0.9203
# Epoch 200/200
# 8/8 [==============================] - 0s 35ms/step - loss: 0.2670 - accuracy: 0.9139 - val_loss: 0.2762 - val_accuracy: 0.9267

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2])
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=45, batch_size=512)
# Out:
# Epoch 1/45
# 8/8 [==============================] - 0s 46ms/step - loss: 2.0261 - accuracy: 0.3047 - val_loss: 1.8368 - val_accuracy: 0.3401
# Epoch 2/45
# 8/8 [==============================] - 0s 25ms/step - loss: 1.7801 - accuracy: 0.3882 - val_loss: 1.6401 - val_accuracy: 0.5250
# Epoch 3/45
# 8/8 [==============================] - 0s 26ms/step - loss: 1.5725 - accuracy: 0.5061 - val_loss: 1.4212 - val_accuracy: 0.5515
# Epoch 4/45
# 8/8 [==============================] - 0s 27ms/step - loss: 1.4077 - accuracy: 0.5149 - val_loss: 1.3407 - val_accuracy: 0.5154
# Epoch 5/45
# 8/8 [==============================] - 0s 28ms/step - loss: 1.3224 - accuracy: 0.5444 - val_loss: 1.2649 - val_accuracy: 0.5643
# Epoch 6/45
# 8/8 [==============================] - 0s 26ms/step - loss: 1.2637 - accuracy: 0.5683 - val_loss: 1.2120 - val_accuracy: 0.5834
# Epoch 7/45
# 8/8 [==============================] - 0s 29ms/step - loss: 1.2134 - accuracy: 0.5901 - val_loss: 1.1656 - val_accuracy: 0.6121
# Epoch 8/45
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1720 - accuracy: 0.6002 - val_loss: 1.1292 - val_accuracy: 0.6557
# Epoch 9/45
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1291 - accuracy: 0.6254 - val_loss: 1.0812 - val_accuracy: 0.6525
# Epoch 10/45
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0916 - accuracy: 0.6435 - val_loss: 1.0399 - val_accuracy: 0.6833
# Epoch 11/45
# 8/8 [==============================] - 0s 24ms/step - loss: 1.0481 - accuracy: 0.6607 - val_loss: 1.0088 - val_accuracy: 0.7003
# Epoch 12/45
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0160 - accuracy: 0.6690 - val_loss: 0.9754 - val_accuracy: 0.6833
# Epoch 13/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.9906 - accuracy: 0.6825 - val_loss: 0.9306 - val_accuracy: 0.7163
# Epoch 14/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9472 - accuracy: 0.6910 - val_loss: 0.9099 - val_accuracy: 0.7258
# Epoch 15/45
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9193 - accuracy: 0.7046 - val_loss: 0.8735 - val_accuracy: 0.7343
# Epoch 16/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8859 - accuracy: 0.7149 - val_loss: 0.8391 - val_accuracy: 0.7588
# Epoch 17/45
# 8/8 [==============================] - 0s 29ms/step - loss: 0.8538 - accuracy: 0.7293 - val_loss: 0.8158 - val_accuracy: 0.7503
# Epoch 18/45
# 8/8 [==============================] - 0s 25ms/step - loss: 0.8218 - accuracy: 0.7394 - val_loss: 0.7852 - val_accuracy: 0.7662
# Epoch 19/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.8039 - accuracy: 0.7431 - val_loss: 0.7567 - val_accuracy: 0.7726
# Epoch 20/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7666 - accuracy: 0.7606 - val_loss: 0.7355 - val_accuracy: 0.7885
# Epoch 21/45
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7582 - accuracy: 0.7598 - val_loss: 0.7074 - val_accuracy: 0.7981
# Epoch 22/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7363 - accuracy: 0.7776 - val_loss: 0.7045 - val_accuracy: 0.7832
# Epoch 23/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7129 - accuracy: 0.7798 - val_loss: 0.6834 - val_accuracy: 0.7917
# Epoch 24/45
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7050 - accuracy: 0.7803 - val_loss: 0.6682 - val_accuracy: 0.8077
# Epoch 25/45
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6951 - accuracy: 0.7774 - val_loss: 0.6576 - val_accuracy: 0.8162
# Epoch 26/45
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6771 - accuracy: 0.7872 - val_loss: 0.6414 - val_accuracy: 0.8204
# Epoch 27/45
# 8/8 [==============================] - 0s 34ms/step - loss: 0.6676 - accuracy: 0.7941 - val_loss: 0.6265 - val_accuracy: 0.8268
# Epoch 28/45
# 8/8 [==============================] - 0s 29ms/step - loss: 0.6550 - accuracy: 0.7997 - val_loss: 0.6201 - val_accuracy: 0.8193
# Epoch 29/45
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6407 - accuracy: 0.8042 - val_loss: 0.6040 - val_accuracy: 0.8353
# Epoch 30/45
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6411 - accuracy: 0.7994 - val_loss: 0.5979 - val_accuracy: 0.8300
# Epoch 31/45
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6272 - accuracy: 0.8034 - val_loss: 0.6020 - val_accuracy: 0.8321
# Epoch 32/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6240 - accuracy: 0.8042 - val_loss: 0.5934 - val_accuracy: 0.8332
# Epoch 33/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6139 - accuracy: 0.8077 - val_loss: 0.5857 - val_accuracy: 0.8289
# Epoch 34/45
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6057 - accuracy: 0.8114 - val_loss: 0.5827 - val_accuracy: 0.8374
# Epoch 35/45
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6039 - accuracy: 0.8185 - val_loss: 0.5748 - val_accuracy: 0.8363
# Epoch 36/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5873 - accuracy: 0.8175 - val_loss: 0.5631 - val_accuracy: 0.8406
# Epoch 37/45
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5780 - accuracy: 0.8177 - val_loss: 0.5680 - val_accuracy: 0.8395
# Epoch 38/45
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5708 - accuracy: 0.8199 - val_loss: 0.5509 - val_accuracy: 0.8417
# Epoch 39/45
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5753 - accuracy: 0.8177 - val_loss: 0.5646 - val_accuracy: 0.8395
# Epoch 40/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5696 - accuracy: 0.8225 - val_loss: 0.5570 - val_accuracy: 0.8406
# Epoch 41/45
# 8/8 [==============================] - 0s 30ms/step - loss: 0.5669 - accuracy: 0.8244 - val_loss: 0.5495 - val_accuracy: 0.8332
# Epoch 42/45
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5554 - accuracy: 0.8201 - val_loss: 0.5475 - val_accuracy: 0.8459
# Epoch 43/45
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5612 - accuracy: 0.8236 - val_loss: 0.5463 - val_accuracy: 0.8470
# Epoch 44/45
# 8/8 [==============================] - 0s 29ms/step - loss: 0.5480 - accuracy: 0.8278 - val_loss: 0.5215 - val_accuracy: 0.8491
# Epoch 45/45
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5442 - accuracy: 0.8268 - val_loss: 0.5190 - val_accuracy: 0.8427

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 0s 3ms/step - loss: 0.4989 - accuracy: 0.8409
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.8427
# 0.8408607840538025 0.8427205085754395

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 22, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:02:24

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 138   0   0   2   0   0   0]
#  [  2   0   0 119   2   0   0   0   1]
#  [  0   0   0   0 302   5  11   0   2]
#  [  0   0   0   0  40  78   2   0   0]
#  [  0   0   1   0  16   2  27   0   4]
#  [  0   0   0   0  12   8  10  20   0]
#  [  0   0   0   5  12   8   3   0   9]]
#
# Accuracy Score
# 0.842720510095643
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.97      1.00      0.98        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.96      0.96      0.96       124
#       built       0.79      0.94      0.86       320
#     windows       0.76      0.65      0.70       120
#       roads       0.51      0.54      0.52        50
#        cars       1.00      0.40      0.57        50
#       metal       0.56      0.24      0.34        37
#
# avg / total       0.84      0.84      0.83       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()
