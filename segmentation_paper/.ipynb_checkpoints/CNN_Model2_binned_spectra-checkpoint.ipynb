# %% [markdown]
# ## Hyperspectral Image Segmentation by Convolutional Neural Network
#
# ### Binned spectra (424, 283, 212, 170, 142, 122, 106, 85, 53, 22, 15)
# ### with spatial dimension included
#
# ### training on each image separately
#
# ---

# %%
# -- here are functions that generate a class that memory maps the raw data 
#    cube.  After executing this cell, the syntax is:
#    fname = "[path to data]/foo.raw"
#    cube = read_hyper(fname)

import os
import numpy as np

def read_header(hdrfile, verbose=True):
    """
    Read a Middleton header file.

    Parameters
    ----------
    hdrfile : str
        Name of header file.
    verbose : bool, optional
        If True, alert the user.

    Returns
    -------
    dict : dict
        A dictionary continaing the number of rows, columns, and wavelengths
        as well as an array of band centers.
    """

    # -- alert
    if verbose:
        print("reading and parsing {0}...".format(hdrfile))

    # -- open the file and read in the records
    recs = [rec for rec in open(hdrfile)]

    # -- parse for samples, lines, bands, and the start of the wavelengths
    for irec, rec in enumerate(recs):
        if 'samples' in rec:
            samples = int(rec.split("=")[1])
        elif 'lines' in rec:
            lines = int(rec.split("=")[1])
        elif 'bands' in rec:
            bands = int(rec.split("=")[1])
        elif "Wavelength" in rec:
            w0ind = irec+1

    # -- parse for the wavelengths
    waves = np.array([float(rec.split(",")[0]) for rec in 
                      recs[w0ind:w0ind+bands]])

    # -- return a dictionary
    return {"nrow":samples, "ncol":lines, "nwav":bands, "waves":waves}


def read_raw(rawfile, shape, hyper=False, verbose=True):
    """
    Read a Middleton raw file.

    Parameters
    ----------
    rawfile : str
        The name of the raw file.
    shape : tuple
        The output shape of the data cube (nwav, nrow, ncol).
    hyper : bool, optional
        Set this flag to read a hyperspectral image.
    verbose : bool, optional
        Alert the user.

    Returns
    -------
    memmap : memmap
        A numpy memmap of the datacube.
    """

    # -- alert
    if verbose:
        print("reading {0}...".format(rawfile))

    # -- read either broadband or hyperspectral image
    if hyper:
        return np.memmap(rawfile, np.uint16, mode="r") \
            .reshape(shape[2], shape[0], shape[1])[:, :, ::-1] \
            .transpose(1, 2, 0)
    else:
        return np.memmap(rawfile, np.uint8, mode="r") \
            .reshape(shape[1], shape[2], shape[0])[:, :, ::-1]


def read_hyper(fpath, fname=None, full=True):
    """
    Read a full hyperspectral scan (raw and header file).

    Parameters
    ----------
    fpath : str
        Either the full name+path of the raw file or the path of the raw file.
        If the latter, fname must be supplied.
    fname : str, optional
        The name of the raw file (required if fpath is set to a path).
    full : bool, optional
        If True, output a class containing data and supplementary information.
        If False, output only the data.

    Returns
    -------
    output or memmap : class or memmap
        If full is True, a class containing data plus supplementary 
        information.  If full is False, a memmap array of the data.
    """

    # -- set up the file names
    if fname is not None:
        fpath = os.path.join(fpath, fname)

    # -- read the header
    hdr = read_header(fpath.replace("raw", "hdr"))
    sh  = (hdr["nwav"], hdr["nrow"], hdr["ncol"])

    # -- if desired, only output data cube
    if not full:
        return read_raw(fpath, sh, hyper=True)

    # -- output full structure
    class output():
        def __init__(self, fpath):
            self.filename = fpath
            self.data     = read_raw(fpath, sh, hyper=True)
            self.waves    = hdr["waves"]
            self.nwav     = sh[0]
            self.nrow     = sh[1]
            self.ncol     = sh[2]

    return output(fpath)

# %%
def kmeans_test_dictionary(labels, test, k):
    import collections, numpy
    
    unique_test, counts_test = numpy.unique(labels[test[:,0], test[:,1]], return_counts=True)
    counts_test_norm = (counts_test/test.shape[0])*100
    test_dict = dict(zip(unique_test, counts_test))
    test_dict_norm = dict(zip(unique_test, counts_test_norm))
    
    for i in range(0, k):
        if test_dict.get(i) is None: test_dict[i] = 0
        if test_dict_norm.get(i) is None: test_dict_norm[i] = 0
    
    return test_dict, test_dict_norm

# %%
def kmeans_test_dataframe(sky_dict,
                          clouds_dict,
                          veg_dict,
                          wtr_dict,
                          blt_dict,
                          windows_dict,
                          rds_dict,
                          cars_dict,
                          mtl_dict
                         ):
    import pandas as pd
    
    pixel_names = ['sky', 'clouds', 'vegetation', 'water', 'built',
                  'windows', 'roads', 'cars', 'metal']
    df_test = pd.DataFrame([sky_dict,
                            clouds_dict,
                            veg_dict,
                            wtr_dict,
                            blt_dict,
                            windows_dict,
                            rds_dict,
                            cars_dict,
                            mtl_dict], index=pixel_names)
    df_test = df_test.transpose()
    
    return df_test

# %%
def plot_confusion_matrix(df_test, norm=True):
    import numpy as np
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    cm = np.array([df_test['sky'].values,
                   df_test['clouds'].values,
                   df_test['vegetation'].values,
                   df_test['water'].values,
                   df_test['built'].values,
                   df_test['windows'].values,
                   df_test['roads'].values,
                   df_test['cars'].values,
                   df_test['metal'].values])
    classes = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 
              'cars', 'metal']
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    if norm:
        title='Normalized Confusion Matrix'
        fmt='.2f'
    else:
        title='Confusion Matrix'
        fmt='d'
    ax.set(xticks=np.arange(cm.shape[1]),
          yticks=np.arange(cm.shape[0]),
          xticklabels=np.arange(0,cm.shape[1]).astype(str), 
          yticklabels=classes,
          title=title,
          ylabel='True Label',
          xlabel='Predicted Label')
    #plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #        rotation_mode="anchor")
    thresh = cm.max()/2
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i,j], fmt),
                   ha="center", va="center",
                   color="white" if cm[i,j] > thresh else "black")
    fig.tight_layout()
    plt.show()

# %%
def plot_test_result(df_Test):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    df_test = df_Test.transpose()
    ax = df_test.plot.bar(rot=0, stacked=True, colormap='tab20b')
                          #color=['tab:blue', 'tab:green', 'tab:gray'])
    plt.xlabel('Actual Class')
    plt.ylabel('%of Test Pixels')
    plt.title('Error in Prediction')
    plt.legend(bbox_to_anchor=(1,1), loc=2, borderaxespad=1.0, prop={'size':11})
    plt.show()

# %%
def point_from_string(text):
    
    items = text.strip("\n").split(" ")
    rind = int(items[0])
    cind = int(items[1])
    
    return rind, cind

# %%
def coords(row, col):
    return np.array(list(np.ndindex((row, col)))).reshape(row, col, 2)

# %%
def read_labelled_coordinates(kind, scan):
    file = open("../manual_classified_pixels/{0}_coordinates_{1}.txt".format(kind, scan), "r")
    coords = file.readlines()
    file.close()
    coords = np.array([point_from_string(line) for line in coords])
    print("{0}: {1}".format(kind,coords.shape))
    
    return coords

# %%
import random

def split_train_test_indices(coords, seed, trrat, kind):
    ind = np.arange(coords.shape[0])
    random.Random(seed).shuffle(ind)
    lim_ind = int(len(ind)*trrat)
    train_ind = ind[:lim_ind]
    test_ind = ind[lim_ind:]
    
    print("{0}: {1} {2}".format(kind, len(train_ind), len(test_ind)))
    
    return train_ind, test_ind

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

def CNN_Model(nwaves, filtersize):
    Inputs_1 = keras.Input(shape=(nwaves, 1), name="spectra")
    Conv1D_1 = layers.Conv1D(16, kernel_size=(filtersize), padding="same", activation="relu")(Inputs_1)
    MaxPool_1 = layers.MaxPooling1D((2), strides=2)(Conv1D_1)
    Conv1D_2 = layers.Conv1D(32, kernel_size=(filtersize), padding="same", activation="relu")(MaxPool_1)
    MaxPool_2 = layers.MaxPooling1D((2), strides=2)(Conv1D_2)
    Dropout_1 = layers.Dropout(0.5)(MaxPool_2)
    Flatten_1 = layers.Flatten()(Dropout_1)

    Inputs_2 = keras.Input(shape=(2,), name="spatial")
    Concat = layers.concatenate([Flatten_1, Inputs_2])
    Dense_1 = layers.Dense(512, activation="relu")(Concat)
    Output = layers.Dense(9, activation="softmax")(Dense_1)

    model = keras.Model(inputs=[Inputs_1, Inputs_2],
                        outputs=[Output],)
    
    return model

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_loss_history(model):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(12, 10))
    ax1.plot(model.history['loss'])
    ax1.plot(model.history['val_loss'])
    ax1.set_title('CNN Model Loss')
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.locator_params(nbins=13, axis='x')
    ax1.legend(['train', 'test'], loc='center right')
    ax2.plot(model.history['accuracy'])
    ax2.plot(model.history['val_accuracy'])
    ax2.set_title('CNN Model Accuracy')
    ax2.set_ylabel('accuracy')
    ax2.set_xlabel('epoch')
    ax2.locator_params(nbins=12, axis='x')
    ax2.legend(['train', 'test'], loc='center right')
    ax3.plot(model.history['loss'])
    ax3.plot(model.history['val_loss'])
    ax3.set_ylabel('log(loss)')
    ax3.set_xlabel('epoch')
    ax3.locator_params(nbins=13, axis='x')
    ax3.legend(['train', 'test'], loc='center right')
    ax3.set_yscale('log')
    ax4.plot(model.history['accuracy'])
    ax4.plot(model.history['val_accuracy'])
    ax4.set_ylabel('log(accuracy)')
    ax4.set_xlabel('epoch')
    ax4.locator_params(nbins=12, axis='x')
    ax4.legend(['train', 'test'], loc='center right')
    ax4.set_yscale('log')
    plt.show()

# %% [markdown]
# ---
# ### Classes:
# 1. Sky
# 2. Clouds
# 3. Water
# 4. Vegetation
# 5. Buildings (concrete structures)
# 6. Windows
# 7. Roads
# 8. Cars
# 9. Metal Structures
# ---

# %% [markdown]
# ## CNN on veg_00108 (South Facing @ ~2pm)

# %%
fname = "../../image_files/veg_00108.raw"
cube = read_hyper(fname)
# Out:
# reading and parsing ../../image_files/veg_00108.hdr...
# reading ../../image_files/veg_00108.raw...

# %%
cube_sub = cube.data[:, :, :].astype(float)
print(cube_sub.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped = cube_sub.transpose(1, 2, 0).reshape((cube_sub.shape[1] * cube_sub.shape[2]), cube_sub.shape[0])
print(cube_reshaped.shape)
# Out:
# (2560000, 848)

# %%
cube_standard = (cube_reshaped - cube_reshaped.mean(1, keepdims=True)) / cube_reshaped.std(1, keepdims=True)
print(cube_standard.shape)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords = read_labelled_coordinates("1_sky", "108")
clouds_coords = read_labelled_coordinates("2_clouds", "108")
veg_coords = read_labelled_coordinates("3_vegetation", "108")
wtr_coords = read_labelled_coordinates("4_water", "108")
blt_coords = read_labelled_coordinates("5_buildings", "108")
windows_coords = read_labelled_coordinates("6_windows", "108")
rds_coords = read_labelled_coordinates("7_roads", "108")
cars_coords = read_labelled_coordinates("8_cars", "108")
mtl_coords = read_labelled_coordinates("9_metal", "108")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (600, 2)
# 4_water: (50, 2)
# 5_buildings: (1020, 2)
# 6_windows: (500, 2)
# 7_roads: (30, 2)
# 8_cars: (100, 2)
# 9_metal: (100, 2)

# %%
# create position array and normalize

xy = coords(cube_sub.shape[1], cube_sub.shape[2])
xy = xy/xy.max()

# %% [markdown]
# ### Bin Spectra

# %%
num_of_bins = 212
filtersize = 13
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 212
# [[0, 4], [4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40], [40, 44], [44, 48], [48, 52], [52, 56], [56, 60], [60, 64], [64, 68], [68, 72], [72, 76], [76, 80], [80, 84], [84, 88], [88, 92], [92, 96], [96, 100], [100, 104], [104, 108], [108, 112], [112, 116], [116, 120], [120, 124], [124, 128], [128, 132], [132, 136], [136, 140], [140, 144], [144, 148], [148, 152], [152, 156], [156, 160], [160, 164], [164, 168], [168, 172], [172, 176], [176, 180], [180, 184], [184, 188], [188, 192], [192, 196], [196, 200], [200, 204], [204, 208], [208, 212], [212, 216], [216, 220], [220, 224], [224, 228], [228, 232], [232, 236], [236, 240], [240, 244], [244, 248], [248, 252], [252, 256], [256, 260], [260, 264], [264, 268], [268, 272], [272, 276], [276, 280], [280, 284], [284, 288], [288, 292], [292, 296], [296, 300], [300, 304], [304, 308], [308, 312], [312, 316], [316, 320], [320, 324], [324, 328], [328, 332], [332, 336], [336, 340], [340, 344], [344, 348], [348, 352], [352, 356], [356, 360], [360, 364], [364, 368], [368, 372], [372, 376], [376, 380], [380, 384], [384, 388], [388, 392], [392, 396], [396, 400], [400, 404], [404, 408], [408, 412], [412, 416], [416, 420], [420, 424], [424, 428], [428, 432], [432, 436], [436, 440], [440, 444], [444, 448], [448, 452], [452, 456], [456, 460], [460, 464], [464, 468], [468, 472], [472, 476], [476, 480], [480, 484], [484, 488], [488, 492], [492, 496], [496, 500], [500, 504], [504, 508], [508, 512], [512, 516], [516, 520], [520, 524], [524, 528], [528, 532], [532, 536], [536, 540], [540, 544], [544, 548], [548, 552], [552, 556], [556, 560], [560, 564], [564, 568], [568, 572], [572, 576], [576, 580], [580, 584], [584, 588], [588, 592], [592, 596], [596, 600], [600, 604], [604, 608], [608, 612], [612, 616], [616, 620], [620, 624], [624, 628], [628, 632], [632, 636], [636, 640], [640, 644], [644, 648], [648, 652], [652, 656], [656, 660], [660, 664], [664, 668], [668, 672], [672, 676], [676, 680], [680, 684], [684, 688], [688, 692], [692, 696], [696, 700], [700, 704], [704, 708], [708, 712], [712, 716], [716, 720], [720, 724], [724, 728], [728, 732], [732, 736], [736, 740], [740, 744], [744, 748], [748, 752], [752, 756], [756, 760], [760, 764], [764, 768], [768, 772], [772, 776], [776, 780], [780, 784], [784, 788], [788, 792], [792, 796], [796, 800], [800, 804], [804, 808], [808, 812], [812, 816], [816, 820], [820, 824], [824, 828], [828, 832], [832, 836], [836, 840], [840, 844], [844, 848]]

# %%
cube_binned = np.zeros(shape=(cube_standard.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned[:, i] = cube_standard[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned.shape)
# Out:
# (2560000, 212)

# %%
cube_standard = cube_binned
print(cube_standard.shape)
# Out:
# (2560000, 212)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind, sky_test_ind = split_train_test_indices(sky_coords, 0, trrat, "sky")
clouds_train_ind, clouds_test_ind = split_train_test_indices(clouds_coords, 1, trrat, "clouds")
veg_train_ind, veg_test_ind = split_train_test_indices(veg_coords, 2, trrat, "veg")
wtr_train_ind, wtr_test_ind = split_train_test_indices(wtr_coords, 3, trrat, "wtr")
blt_train_ind, blt_test_ind = split_train_test_indices(blt_coords, 4, trrat, "blt")
windows_train_ind, windows_test_ind = split_train_test_indices(windows_coords, 5, trrat, "windows")
rds_train_ind, rds_test_ind = split_train_test_indices(rds_coords, 6, trrat, "rds")
cars_train_ind, cars_test_ind = split_train_test_indices(cars_coords, 7, trrat, "cars")
mtl_train_ind, mtl_test_ind = split_train_test_indices(mtl_coords, 8, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 400 100
# veg: 480 120
# wtr: 40 10
# blt: 816 204
# windows: 400 100
# rds: 24 6
# cars: 80 20
# mtl: 80 20

# %%
cube_std_3d = cube_standard.reshape(cube_sub.shape[1], cube_sub.shape[2], num_of_bins)
print(cube_std_3d.shape)
print(xy.shape)
# Out:
# (1600, 1600, 212)
# (1600, 1600, 2)

# %%
cube_sky_train = cube_std_3d[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
cube_sky_test = cube_std_3d[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
sky_xy_train = xy[sky_coords[sky_train_ind[:], 0], sky_coords[sky_train_ind[:], 1], :]
sky_xy_test = xy[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1], :]
print("sky ", cube_sky_train.shape, cube_sky_test.shape)

cube_clouds_train = cube_std_3d[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
cube_clouds_test = cube_std_3d[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
clouds_xy_train = xy[clouds_coords[clouds_train_ind[:], 0], clouds_coords[clouds_train_ind[:], 1], :]
clouds_xy_test = xy[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:], 1], :]
print("clouds ", cube_clouds_train.shape, cube_clouds_test.shape)

cube_veg_train = cube_std_3d[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
cube_veg_test = cube_std_3d[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
veg_xy_train = xy[veg_coords[veg_train_ind[:], 0], veg_coords[veg_train_ind[:], 1], :]
veg_xy_test = xy[veg_coords[veg_test_ind[:], 0], veg_coords[veg_test_ind[:], 1], :]
print("vegetation ", cube_veg_train.shape, cube_veg_test.shape)

cube_wtr_train = cube_std_3d[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
cube_wtr_test = cube_std_3d[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
wtr_xy_train = xy[wtr_coords[wtr_train_ind[:], 0], wtr_coords[wtr_train_ind[:], 1], :]
wtr_xy_test = xy[wtr_coords[wtr_test_ind[:], 0], wtr_coords[wtr_test_ind[:], 1], :]
print("water ", cube_wtr_train.shape, cube_wtr_test.shape)

cube_blt_train = cube_std_3d[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
cube_blt_test = cube_std_3d[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
blt_xy_train = xy[blt_coords[blt_train_ind[:], 0], blt_coords[blt_train_ind[:], 1], :]
blt_xy_test = xy[blt_coords[blt_test_ind[:], 0], blt_coords[blt_test_ind[:], 1], :]
print("built ", cube_blt_train.shape, cube_blt_test.shape)

cube_windows_train = cube_std_3d[windows_coords[windows_train_ind[:],0], windows_coords[windows_train_ind[:],1],:]
cube_windows_test = cube_std_3d[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
windows_xy_train = xy[windows_coords[windows_train_ind[:], 0], windows_coords[windows_train_ind[:], 1], :]
windows_xy_test = xy[windows_coords[windows_test_ind[:], 0], windows_coords[windows_test_ind[:], 1], :]
print("windows ", cube_windows_train.shape, cube_windows_test.shape)

cube_rds_train = cube_std_3d[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
cube_rds_test = cube_std_3d[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
rds_xy_train = xy[rds_coords[rds_train_ind[:], 0], rds_coords[rds_train_ind[:], 1], :]
rds_xy_test = xy[rds_coords[rds_test_ind[:], 0], rds_coords[rds_test_ind[:], 1], :]
print("roads ", cube_rds_train.shape, cube_rds_test.shape)

cube_cars_train = cube_std_3d[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cube_cars_test = cube_std_3d[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
cars_xy_train = xy[cars_coords[cars_train_ind[:], 0], cars_coords[cars_train_ind[:], 1], :]
cars_xy_test = xy[cars_coords[cars_test_ind[:], 0], cars_coords[cars_test_ind[:], 1], :]
print("cars ", cube_cars_train.shape, cube_cars_test.shape)

cube_mtl_train = cube_std_3d[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
cube_mtl_test = cube_std_3d[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
mtl_xy_train = xy[mtl_coords[mtl_train_ind[:], 0], mtl_coords[mtl_train_ind[:], 1], :]
mtl_xy_test = xy[mtl_coords[mtl_test_ind[:], 0], mtl_coords[mtl_test_ind[:], 1], :]
print("metal ", cube_mtl_train.shape, cube_mtl_test.shape)
# Out:
# sky  (240, 212) (60, 212)
# clouds  (400, 212) (100, 212)
# vegetation  (480, 212) (120, 212)
# water  (40, 212) (10, 212)
# built  (816, 212) (204, 212)
# windows  (400, 212) (100, 212)
# roads  (24, 212) (6, 212)
# cars  (80, 212) (20, 212)
# metal  (80, 212) (20, 212)

# %%
# concatenate training and testing sets and create index arrays

cube_train = np.concatenate((cube_sky_train, cube_clouds_train, cube_veg_train, cube_wtr_train, cube_blt_train,
                            cube_windows_train, cube_rds_train, cube_cars_train, cube_mtl_train), axis=0)
cube_train_labels = [0]*cube_sky_train.shape[0] + [1]*cube_clouds_train.shape[0] \
                    + [2]*cube_veg_train.shape[0] + [3]*cube_wtr_train.shape[0] \
                    + [4]*cube_blt_train.shape[0] + [5]*cube_windows_train.shape[0] \
                    + [6]*cube_rds_train.shape[0] + [7]*cube_cars_train.shape[0] + [8]*cube_mtl_train.shape[0]
xy_train = np.concatenate((sky_xy_train, clouds_xy_train, veg_xy_train, wtr_xy_train, blt_xy_train,
                             windows_xy_train, rds_xy_train, cars_xy_train, mtl_xy_train), axis=0)

cube_test = np.concatenate((cube_sky_test, cube_clouds_test, cube_veg_test, cube_wtr_test, cube_blt_test,
                            cube_windows_test, cube_rds_test, cube_cars_test, cube_mtl_test), axis=0)
cube_test_labels = [0]*cube_sky_test.shape[0] + [1]*cube_clouds_test.shape[0] \
                    + [2]*cube_veg_test.shape[0] + [3]*cube_wtr_test.shape[0] \
                    + [4]*cube_blt_test.shape[0] + [5]*cube_windows_test.shape[0] \
                    + [6]*cube_rds_test.shape[0] + [7]*cube_cars_test.shape[0] + [8]*cube_mtl_test.shape[0]
xy_test = np.concatenate((sky_xy_test, clouds_xy_test, veg_xy_test, wtr_xy_test, blt_xy_test,
                             windows_xy_test, rds_xy_test, cars_xy_test, mtl_xy_test), axis=0)

# %%
cube_train_labels = np.array(cube_train_labels)
cube_test_labels = np.array(cube_test_labels)

print(cube_train.shape, cube_train_labels.shape, xy_train.shape)
print(cube_test.shape, cube_test_labels.shape, xy_test.shape)
# Out:
# (2560, 212) (2560,) (2560, 2)
# (640, 212) (640,) (640, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn, show_shapes=True)
#cnn.summary()

cube_train2 = cube_train.reshape(cube_train.shape[0], cube_train.shape[1], 1)
cube_test2 = cube_test.reshape(cube_test.shape[0], cube_test.shape[1], 1)

# %%
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 91ms/step - loss: 1.7195 - accuracy: 0.3977 - val_loss: 1.2357 - val_accuracy: 0.7078
# Epoch 2/200
# 5/5 [==============================] - 0s 50ms/step - loss: 1.1127 - accuracy: 0.6785 - val_loss: 0.8892 - val_accuracy: 0.7391
# Epoch 3/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.8861 - accuracy: 0.7152 - val_loss: 0.7646 - val_accuracy: 0.7750
# Epoch 4/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.7880 - accuracy: 0.7500 - val_loss: 0.7162 - val_accuracy: 0.7922
# Epoch 5/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.7322 - accuracy: 0.7742 - val_loss: 0.6429 - val_accuracy: 0.8047
# Epoch 6/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.6727 - accuracy: 0.7930 - val_loss: 0.5962 - val_accuracy: 0.8062
# Epoch 7/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.6258 - accuracy: 0.8082 - val_loss: 0.5581 - val_accuracy: 0.8469
# Epoch 8/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5907 - accuracy: 0.8195 - val_loss: 0.5119 - val_accuracy: 0.8391
# Epoch 9/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5539 - accuracy: 0.8277 - val_loss: 0.4856 - val_accuracy: 0.8391
# Epoch 10/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.5343 - accuracy: 0.8266 - val_loss: 0.4591 - val_accuracy: 0.8359
# Epoch 11/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4954 - accuracy: 0.8477 - val_loss: 0.4718 - val_accuracy: 0.8344
# Epoch 12/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.5022 - accuracy: 0.8352 - val_loss: 0.4462 - val_accuracy: 0.8391
# Epoch 13/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4908 - accuracy: 0.8410 - val_loss: 0.4349 - val_accuracy: 0.8766
# Epoch 14/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4643 - accuracy: 0.8453 - val_loss: 0.4025 - val_accuracy: 0.8828
# Epoch 15/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4422 - accuracy: 0.8543 - val_loss: 0.4216 - val_accuracy: 0.8438
# Epoch 16/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4320 - accuracy: 0.8590 - val_loss: 0.3794 - val_accuracy: 0.9016
# Epoch 17/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4162 - accuracy: 0.8602 - val_loss: 0.3929 - val_accuracy: 0.8906
# Epoch 18/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4207 - accuracy: 0.8684 - val_loss: 0.3806 - val_accuracy: 0.8516
# Epoch 19/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4096 - accuracy: 0.8734 - val_loss: 0.3452 - val_accuracy: 0.9016
# Epoch 20/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3914 - accuracy: 0.8777 - val_loss: 0.3475 - val_accuracy: 0.9031
# Epoch 21/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3727 - accuracy: 0.8855 - val_loss: 0.3305 - val_accuracy: 0.9047
# Epoch 22/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3747 - accuracy: 0.8809 - val_loss: 0.3394 - val_accuracy: 0.8766
# Epoch 23/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3606 - accuracy: 0.8883 - val_loss: 0.3149 - val_accuracy: 0.9062
# Epoch 24/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3465 - accuracy: 0.8941 - val_loss: 0.3089 - val_accuracy: 0.9047
# Epoch 25/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3386 - accuracy: 0.8957 - val_loss: 0.2991 - val_accuracy: 0.9062
# Epoch 26/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3300 - accuracy: 0.8969 - val_loss: 0.2907 - val_accuracy: 0.9078
# Epoch 27/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3262 - accuracy: 0.9000 - val_loss: 0.2821 - val_accuracy: 0.9125
# Epoch 28/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3167 - accuracy: 0.9039 - val_loss: 0.2790 - val_accuracy: 0.9156
# Epoch 29/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3123 - accuracy: 0.9055 - val_loss: 0.2691 - val_accuracy: 0.9141
# Epoch 30/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3020 - accuracy: 0.9062 - val_loss: 0.2671 - val_accuracy: 0.9094
# Epoch 31/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2947 - accuracy: 0.9105 - val_loss: 0.2633 - val_accuracy: 0.9109
# Epoch 32/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2964 - accuracy: 0.9098 - val_loss: 0.2514 - val_accuracy: 0.9172
# Epoch 33/200
# 5/5 [==============================] - 0s 61ms/step - loss: 0.2927 - accuracy: 0.9047 - val_loss: 0.2530 - val_accuracy: 0.9234
# Epoch 34/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2809 - accuracy: 0.9168 - val_loss: 0.2628 - val_accuracy: 0.9125
# Epoch 35/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2896 - accuracy: 0.9102 - val_loss: 0.2477 - val_accuracy: 0.9187
# Epoch 36/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2815 - accuracy: 0.9109 - val_loss: 0.2579 - val_accuracy: 0.9359
# Epoch 37/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2778 - accuracy: 0.9137 - val_loss: 0.2696 - val_accuracy: 0.9172
# Epoch 38/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2744 - accuracy: 0.9184 - val_loss: 0.2398 - val_accuracy: 0.9172
# Epoch 39/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2667 - accuracy: 0.9117 - val_loss: 0.2780 - val_accuracy: 0.9172
# Epoch 40/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2814 - accuracy: 0.9105 - val_loss: 0.2446 - val_accuracy: 0.9187
# Epoch 41/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2738 - accuracy: 0.9152 - val_loss: 0.2607 - val_accuracy: 0.9187
# Epoch 42/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2749 - accuracy: 0.9105 - val_loss: 0.2328 - val_accuracy: 0.9125
# Epoch 43/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2665 - accuracy: 0.9117 - val_loss: 0.2433 - val_accuracy: 0.9219
# Epoch 44/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2620 - accuracy: 0.9164 - val_loss: 0.2348 - val_accuracy: 0.9203
# Epoch 45/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2553 - accuracy: 0.9137 - val_loss: 0.2178 - val_accuracy: 0.9219
# Epoch 46/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2441 - accuracy: 0.9207 - val_loss: 0.2075 - val_accuracy: 0.9187
# Epoch 47/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2444 - accuracy: 0.9219 - val_loss: 0.2094 - val_accuracy: 0.9328
# Epoch 48/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2417 - accuracy: 0.9246 - val_loss: 0.2056 - val_accuracy: 0.9219
# Epoch 49/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2312 - accuracy: 0.9289 - val_loss: 0.2022 - val_accuracy: 0.9266
# Epoch 50/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2224 - accuracy: 0.9258 - val_loss: 0.1987 - val_accuracy: 0.9250
# Epoch 51/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2315 - accuracy: 0.9242 - val_loss: 0.1968 - val_accuracy: 0.9297
# Epoch 52/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2314 - accuracy: 0.9234 - val_loss: 0.1944 - val_accuracy: 0.9391
# Epoch 53/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.2183 - accuracy: 0.9324 - val_loss: 0.2150 - val_accuracy: 0.9281
# Epoch 54/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2324 - accuracy: 0.9238 - val_loss: 0.2008 - val_accuracy: 0.9359
# Epoch 55/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2244 - accuracy: 0.9277 - val_loss: 0.1875 - val_accuracy: 0.9328
# Epoch 56/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2305 - accuracy: 0.9234 - val_loss: 0.1898 - val_accuracy: 0.9266
# Epoch 57/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2232 - accuracy: 0.9246 - val_loss: 0.1907 - val_accuracy: 0.9234
# Epoch 58/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2160 - accuracy: 0.9289 - val_loss: 0.1883 - val_accuracy: 0.9297
# Epoch 59/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2153 - accuracy: 0.9273 - val_loss: 0.1878 - val_accuracy: 0.9359
# Epoch 60/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2138 - accuracy: 0.9281 - val_loss: 0.1975 - val_accuracy: 0.9250
# Epoch 61/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2152 - accuracy: 0.9266 - val_loss: 0.1786 - val_accuracy: 0.9375
# Epoch 62/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1953 - accuracy: 0.9340 - val_loss: 0.1763 - val_accuracy: 0.9359
# Epoch 63/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2090 - accuracy: 0.9273 - val_loss: 0.1700 - val_accuracy: 0.9359
# Epoch 64/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2024 - accuracy: 0.9340 - val_loss: 0.1729 - val_accuracy: 0.9391
# Epoch 65/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1951 - accuracy: 0.9363 - val_loss: 0.1776 - val_accuracy: 0.9422
# Epoch 66/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2008 - accuracy: 0.9375 - val_loss: 0.1733 - val_accuracy: 0.9297
# Epoch 67/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1954 - accuracy: 0.9328 - val_loss: 0.1709 - val_accuracy: 0.9438
# Epoch 68/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1865 - accuracy: 0.9344 - val_loss: 0.1665 - val_accuracy: 0.9484
# Epoch 69/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1890 - accuracy: 0.9402 - val_loss: 0.1752 - val_accuracy: 0.9250
# Epoch 70/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2071 - accuracy: 0.9320 - val_loss: 0.1722 - val_accuracy: 0.9469
# Epoch 71/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2043 - accuracy: 0.9297 - val_loss: 0.1694 - val_accuracy: 0.9391
# Epoch 72/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1959 - accuracy: 0.9340 - val_loss: 0.1625 - val_accuracy: 0.9406
# Epoch 73/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1780 - accuracy: 0.9402 - val_loss: 0.1650 - val_accuracy: 0.9516
# Epoch 74/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1780 - accuracy: 0.9434 - val_loss: 0.1604 - val_accuracy: 0.9375
# Epoch 75/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1705 - accuracy: 0.9367 - val_loss: 0.1517 - val_accuracy: 0.9563
# Epoch 76/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1747 - accuracy: 0.9414 - val_loss: 0.1485 - val_accuracy: 0.9500
# Epoch 77/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1700 - accuracy: 0.9434 - val_loss: 0.1504 - val_accuracy: 0.9438
# Epoch 78/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1697 - accuracy: 0.9387 - val_loss: 0.1498 - val_accuracy: 0.9516
# Epoch 79/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1759 - accuracy: 0.9414 - val_loss: 0.1596 - val_accuracy: 0.9563
# Epoch 80/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1814 - accuracy: 0.9348 - val_loss: 0.1730 - val_accuracy: 0.9438
# Epoch 81/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1701 - accuracy: 0.9410 - val_loss: 0.1724 - val_accuracy: 0.9547
# Epoch 82/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1817 - accuracy: 0.9355 - val_loss: 0.1606 - val_accuracy: 0.9547
# Epoch 83/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1666 - accuracy: 0.9402 - val_loss: 0.1580 - val_accuracy: 0.9547
# Epoch 84/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1860 - accuracy: 0.9379 - val_loss: 0.1486 - val_accuracy: 0.9484
# Epoch 85/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1630 - accuracy: 0.9512 - val_loss: 0.1447 - val_accuracy: 0.9484
# Epoch 86/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1615 - accuracy: 0.9418 - val_loss: 0.1586 - val_accuracy: 0.9484
# Epoch 87/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1669 - accuracy: 0.9469 - val_loss: 0.1395 - val_accuracy: 0.9500
# Epoch 88/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1607 - accuracy: 0.9488 - val_loss: 0.1403 - val_accuracy: 0.9531
# Epoch 89/200
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1566 - accuracy: 0.9477 - val_loss: 0.1369 - val_accuracy: 0.9563
# Epoch 90/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1573 - accuracy: 0.9469 - val_loss: 0.1319 - val_accuracy: 0.9547
# Epoch 91/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1583 - accuracy: 0.9473 - val_loss: 0.1412 - val_accuracy: 0.9547
# Epoch 92/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1624 - accuracy: 0.9430 - val_loss: 0.1508 - val_accuracy: 0.9578
# Epoch 93/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1713 - accuracy: 0.9422 - val_loss: 0.1591 - val_accuracy: 0.9609
# Epoch 94/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1665 - accuracy: 0.9438 - val_loss: 0.1404 - val_accuracy: 0.9563
# Epoch 95/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1609 - accuracy: 0.9473 - val_loss: 0.1463 - val_accuracy: 0.9531
# Epoch 96/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1554 - accuracy: 0.9496 - val_loss: 0.1506 - val_accuracy: 0.9344
# Epoch 97/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1678 - accuracy: 0.9465 - val_loss: 0.1434 - val_accuracy: 0.9547
# Epoch 98/200
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1653 - accuracy: 0.9457 - val_loss: 0.1337 - val_accuracy: 0.9594
# Epoch 99/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1502 - accuracy: 0.9520 - val_loss: 0.1384 - val_accuracy: 0.9516
# Epoch 100/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1548 - accuracy: 0.9488 - val_loss: 0.1547 - val_accuracy: 0.9453
# Epoch 101/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1655 - accuracy: 0.9430 - val_loss: 0.1483 - val_accuracy: 0.9344
# Epoch 102/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1654 - accuracy: 0.9457 - val_loss: 0.1605 - val_accuracy: 0.9359
# Epoch 103/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1761 - accuracy: 0.9426 - val_loss: 0.1410 - val_accuracy: 0.9516
# Epoch 104/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1669 - accuracy: 0.9402 - val_loss: 0.1475 - val_accuracy: 0.9438
# Epoch 105/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1517 - accuracy: 0.9484 - val_loss: 0.1599 - val_accuracy: 0.9469
# Epoch 106/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1537 - accuracy: 0.9484 - val_loss: 0.1268 - val_accuracy: 0.9531
# Epoch 107/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1547 - accuracy: 0.9496 - val_loss: 0.1235 - val_accuracy: 0.9516
# Epoch 108/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1465 - accuracy: 0.9523 - val_loss: 0.1293 - val_accuracy: 0.9594
# Epoch 109/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1470 - accuracy: 0.9457 - val_loss: 0.1243 - val_accuracy: 0.9578
# Epoch 110/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1418 - accuracy: 0.9563 - val_loss: 0.1226 - val_accuracy: 0.9578
# Epoch 111/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1518 - accuracy: 0.9480 - val_loss: 0.1217 - val_accuracy: 0.9547
# Epoch 112/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1448 - accuracy: 0.9504 - val_loss: 0.1244 - val_accuracy: 0.9594
# Epoch 113/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1453 - accuracy: 0.9504 - val_loss: 0.1294 - val_accuracy: 0.9594
# Epoch 114/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1379 - accuracy: 0.9570 - val_loss: 0.1245 - val_accuracy: 0.9578
# Epoch 115/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1313 - accuracy: 0.9566 - val_loss: 0.1251 - val_accuracy: 0.9656
# Epoch 116/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1408 - accuracy: 0.9512 - val_loss: 0.1267 - val_accuracy: 0.9516
# Epoch 117/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1411 - accuracy: 0.9512 - val_loss: 0.1503 - val_accuracy: 0.9469
# Epoch 118/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1453 - accuracy: 0.9531 - val_loss: 0.1383 - val_accuracy: 0.9391
# Epoch 119/200
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1493 - accuracy: 0.9500 - val_loss: 0.1164 - val_accuracy: 0.9531
# Epoch 120/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1417 - accuracy: 0.9488 - val_loss: 0.1202 - val_accuracy: 0.9641
# Epoch 121/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1410 - accuracy: 0.9512 - val_loss: 0.1429 - val_accuracy: 0.9609
# Epoch 122/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1378 - accuracy: 0.9570 - val_loss: 0.1171 - val_accuracy: 0.9641
# Epoch 123/200
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1366 - accuracy: 0.9555 - val_loss: 0.1125 - val_accuracy: 0.9609
# Epoch 124/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1282 - accuracy: 0.9563 - val_loss: 0.1202 - val_accuracy: 0.9500
# Epoch 125/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1384 - accuracy: 0.9516 - val_loss: 0.1532 - val_accuracy: 0.9453
# Epoch 126/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1462 - accuracy: 0.9504 - val_loss: 0.1252 - val_accuracy: 0.9469
# Epoch 127/200
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1377 - accuracy: 0.9563 - val_loss: 0.1186 - val_accuracy: 0.9563
# Epoch 128/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1349 - accuracy: 0.9566 - val_loss: 0.1212 - val_accuracy: 0.9609
# Epoch 129/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1326 - accuracy: 0.9609 - val_loss: 0.1178 - val_accuracy: 0.9547
# Epoch 130/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1186 - accuracy: 0.9598 - val_loss: 0.1083 - val_accuracy: 0.9641
# Epoch 131/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1244 - accuracy: 0.9586 - val_loss: 0.1060 - val_accuracy: 0.9609
# Epoch 132/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1205 - accuracy: 0.9590 - val_loss: 0.1121 - val_accuracy: 0.9609
# Epoch 133/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1283 - accuracy: 0.9551 - val_loss: 0.1159 - val_accuracy: 0.9594
# Epoch 134/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1271 - accuracy: 0.9570 - val_loss: 0.1079 - val_accuracy: 0.9625
# Epoch 135/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1229 - accuracy: 0.9582 - val_loss: 0.1103 - val_accuracy: 0.9609
# Epoch 136/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1185 - accuracy: 0.9605 - val_loss: 0.1084 - val_accuracy: 0.9594
# Epoch 137/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1190 - accuracy: 0.9582 - val_loss: 0.1015 - val_accuracy: 0.9625
# Epoch 138/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1177 - accuracy: 0.9629 - val_loss: 0.1005 - val_accuracy: 0.9578
# Epoch 139/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1219 - accuracy: 0.9570 - val_loss: 0.0977 - val_accuracy: 0.9641
# Epoch 140/200
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1191 - accuracy: 0.9563 - val_loss: 0.1083 - val_accuracy: 0.9609
# Epoch 141/200
# 5/5 [==============================] - 0s 38ms/step - loss: 0.1097 - accuracy: 0.9629 - val_loss: 0.1245 - val_accuracy: 0.9500
# Epoch 142/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1242 - accuracy: 0.9590 - val_loss: 0.0996 - val_accuracy: 0.9609
# Epoch 143/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1161 - accuracy: 0.9605 - val_loss: 0.0980 - val_accuracy: 0.9656
# Epoch 144/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1096 - accuracy: 0.9609 - val_loss: 0.0934 - val_accuracy: 0.9672
# Epoch 145/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1132 - accuracy: 0.9617 - val_loss: 0.0909 - val_accuracy: 0.9656
# Epoch 146/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1069 - accuracy: 0.9641 - val_loss: 0.0973 - val_accuracy: 0.9641
# Epoch 147/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1150 - accuracy: 0.9621 - val_loss: 0.1043 - val_accuracy: 0.9734
# Epoch 148/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1128 - accuracy: 0.9637 - val_loss: 0.0968 - val_accuracy: 0.9656
# Epoch 149/200
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1071 - accuracy: 0.9629 - val_loss: 0.0984 - val_accuracy: 0.9688
# Epoch 150/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1172 - accuracy: 0.9602 - val_loss: 0.0982 - val_accuracy: 0.9594
# Epoch 151/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1171 - accuracy: 0.9605 - val_loss: 0.1460 - val_accuracy: 0.9453
# Epoch 152/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1413 - accuracy: 0.9520 - val_loss: 0.1218 - val_accuracy: 0.9578
# Epoch 153/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1270 - accuracy: 0.9512 - val_loss: 0.1217 - val_accuracy: 0.9516
# Epoch 154/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1236 - accuracy: 0.9566 - val_loss: 0.1017 - val_accuracy: 0.9609
# Epoch 155/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1112 - accuracy: 0.9633 - val_loss: 0.1042 - val_accuracy: 0.9703
# Epoch 156/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1104 - accuracy: 0.9629 - val_loss: 0.0978 - val_accuracy: 0.9609
# Epoch 157/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1105 - accuracy: 0.9629 - val_loss: 0.0906 - val_accuracy: 0.9641
# Epoch 158/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0981 - accuracy: 0.9691 - val_loss: 0.0915 - val_accuracy: 0.9688
# Epoch 159/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1013 - accuracy: 0.9695 - val_loss: 0.0960 - val_accuracy: 0.9609
# Epoch 160/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0990 - accuracy: 0.9703 - val_loss: 0.1002 - val_accuracy: 0.9656
# Epoch 161/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1161 - accuracy: 0.9605 - val_loss: 0.0928 - val_accuracy: 0.9672
# Epoch 162/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1007 - accuracy: 0.9668 - val_loss: 0.0850 - val_accuracy: 0.9719
# Epoch 163/200
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0992 - accuracy: 0.9652 - val_loss: 0.0872 - val_accuracy: 0.9719
# Epoch 164/200
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0987 - accuracy: 0.9688 - val_loss: 0.0909 - val_accuracy: 0.9734
# Epoch 165/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1045 - accuracy: 0.9652 - val_loss: 0.0855 - val_accuracy: 0.9672
# Epoch 166/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0948 - accuracy: 0.9668 - val_loss: 0.0868 - val_accuracy: 0.9719
# Epoch 167/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0939 - accuracy: 0.9715 - val_loss: 0.0907 - val_accuracy: 0.9641
# Epoch 168/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0961 - accuracy: 0.9703 - val_loss: 0.0910 - val_accuracy: 0.9594
# Epoch 169/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0972 - accuracy: 0.9645 - val_loss: 0.1052 - val_accuracy: 0.9578
# Epoch 170/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1121 - accuracy: 0.9625 - val_loss: 0.0941 - val_accuracy: 0.9578
# Epoch 171/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0983 - accuracy: 0.9680 - val_loss: 0.0916 - val_accuracy: 0.9641
# Epoch 172/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0994 - accuracy: 0.9629 - val_loss: 0.0900 - val_accuracy: 0.9703
# Epoch 173/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0942 - accuracy: 0.9695 - val_loss: 0.1075 - val_accuracy: 0.9625
# Epoch 174/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1109 - accuracy: 0.9598 - val_loss: 0.1032 - val_accuracy: 0.9578
# Epoch 175/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1138 - accuracy: 0.9609 - val_loss: 0.0948 - val_accuracy: 0.9625
# Epoch 176/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1124 - accuracy: 0.9605 - val_loss: 0.1111 - val_accuracy: 0.9688
# Epoch 177/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1079 - accuracy: 0.9613 - val_loss: 0.1038 - val_accuracy: 0.9656
# Epoch 178/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1012 - accuracy: 0.9691 - val_loss: 0.0916 - val_accuracy: 0.9625
# Epoch 179/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0952 - accuracy: 0.9684 - val_loss: 0.1052 - val_accuracy: 0.9641
# Epoch 180/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0969 - accuracy: 0.9664 - val_loss: 0.0850 - val_accuracy: 0.9609
# Epoch 181/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0884 - accuracy: 0.9738 - val_loss: 0.0858 - val_accuracy: 0.9641
# Epoch 182/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0912 - accuracy: 0.9699 - val_loss: 0.0809 - val_accuracy: 0.9672
# Epoch 183/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0924 - accuracy: 0.9672 - val_loss: 0.0811 - val_accuracy: 0.9641
# Epoch 184/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0846 - accuracy: 0.9742 - val_loss: 0.0952 - val_accuracy: 0.9703
# Epoch 185/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1029 - accuracy: 0.9664 - val_loss: 0.0900 - val_accuracy: 0.9703
# Epoch 186/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0867 - accuracy: 0.9719 - val_loss: 0.0845 - val_accuracy: 0.9688
# Epoch 187/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0990 - accuracy: 0.9668 - val_loss: 0.0808 - val_accuracy: 0.9734
# Epoch 188/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0953 - accuracy: 0.9676 - val_loss: 0.0899 - val_accuracy: 0.9656
# Epoch 189/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0926 - accuracy: 0.9695 - val_loss: 0.0910 - val_accuracy: 0.9609
# Epoch 190/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0849 - accuracy: 0.9730 - val_loss: 0.0832 - val_accuracy: 0.9688
# Epoch 191/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0763 - accuracy: 0.9750 - val_loss: 0.0770 - val_accuracy: 0.9734
# Epoch 192/200
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0823 - accuracy: 0.9742 - val_loss: 0.0748 - val_accuracy: 0.9734
# Epoch 193/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0909 - accuracy: 0.9695 - val_loss: 0.0769 - val_accuracy: 0.9703
# Epoch 194/200
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0922 - accuracy: 0.9711 - val_loss: 0.0963 - val_accuracy: 0.9625
# Epoch 195/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0797 - accuracy: 0.9699 - val_loss: 0.0862 - val_accuracy: 0.9672
# Epoch 196/200
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0801 - accuracy: 0.9719 - val_loss: 0.0873 - val_accuracy: 0.9609
# Epoch 197/200
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0806 - accuracy: 0.9738 - val_loss: 0.0753 - val_accuracy: 0.9703
# Epoch 198/200
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0833 - accuracy: 0.9727 - val_loss: 0.0759 - val_accuracy: 0.9703
# Epoch 199/200
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0862 - accuracy: 0.9691 - val_loss: 0.0763 - val_accuracy: 0.9719
# Epoch 200/200
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0842 - accuracy: 0.9719 - val_loss: 0.0738 - val_accuracy: 0.9719

# %%
plot_loss_history(CNNmodel)

# %%
cnn = CNN_Model(cube_std_3d.shape[2], filtersize)
cnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel = cnn.fit({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels, 
                     validation_data=({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels),
                     epochs=90, batch_size=512)
# Out:
# Epoch 1/90
# 5/5 [==============================] - 0s 74ms/step - loss: 1.6742 - accuracy: 0.3988 - val_loss: 1.2283 - val_accuracy: 0.6797
# Epoch 2/90
# 5/5 [==============================] - 0s 55ms/step - loss: 1.1212 - accuracy: 0.6621 - val_loss: 0.8828 - val_accuracy: 0.7469
# Epoch 3/90
# 5/5 [==============================] - 0s 58ms/step - loss: 0.8775 - accuracy: 0.7195 - val_loss: 0.7493 - val_accuracy: 0.8125
# Epoch 4/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.7467 - accuracy: 0.7809 - val_loss: 0.6713 - val_accuracy: 0.8188
# Epoch 5/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.6786 - accuracy: 0.8008 - val_loss: 0.6038 - val_accuracy: 0.8172
# Epoch 6/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.6331 - accuracy: 0.8129 - val_loss: 0.5558 - val_accuracy: 0.8266
# Epoch 7/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.5866 - accuracy: 0.8172 - val_loss: 0.5103 - val_accuracy: 0.8328
# Epoch 8/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.5472 - accuracy: 0.8316 - val_loss: 0.4783 - val_accuracy: 0.8469
# Epoch 9/90
# 5/5 [==============================] - 0s 46ms/step - loss: 0.5045 - accuracy: 0.8449 - val_loss: 0.4504 - val_accuracy: 0.8719
# Epoch 10/90
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4730 - accuracy: 0.8504 - val_loss: 0.4251 - val_accuracy: 0.8750
# Epoch 11/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4508 - accuracy: 0.8543 - val_loss: 0.4084 - val_accuracy: 0.8734
# Epoch 12/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4490 - accuracy: 0.8555 - val_loss: 0.4004 - val_accuracy: 0.8891
# Epoch 13/90
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4300 - accuracy: 0.8590 - val_loss: 0.3773 - val_accuracy: 0.8875
# Epoch 14/90
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4148 - accuracy: 0.8691 - val_loss: 0.3754 - val_accuracy: 0.8938
# Epoch 15/90
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4041 - accuracy: 0.8715 - val_loss: 0.3644 - val_accuracy: 0.8969
# Epoch 16/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3928 - accuracy: 0.8801 - val_loss: 0.3464 - val_accuracy: 0.8953
# Epoch 17/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3793 - accuracy: 0.8797 - val_loss: 0.3383 - val_accuracy: 0.9047
# Epoch 18/90
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3713 - accuracy: 0.8750 - val_loss: 0.3248 - val_accuracy: 0.9062
# Epoch 19/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3536 - accuracy: 0.8879 - val_loss: 0.3205 - val_accuracy: 0.9078
# Epoch 20/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3520 - accuracy: 0.8891 - val_loss: 0.3143 - val_accuracy: 0.9078
# Epoch 21/90
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3456 - accuracy: 0.8938 - val_loss: 0.3070 - val_accuracy: 0.9062
# Epoch 22/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3453 - accuracy: 0.8918 - val_loss: 0.3000 - val_accuracy: 0.9078
# Epoch 23/90
# 5/5 [==============================] - 0s 41ms/step - loss: 0.3393 - accuracy: 0.8953 - val_loss: 0.2941 - val_accuracy: 0.9078
# Epoch 24/90
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3274 - accuracy: 0.8977 - val_loss: 0.3052 - val_accuracy: 0.9125
# Epoch 25/90
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3260 - accuracy: 0.8969 - val_loss: 0.2875 - val_accuracy: 0.9109
# Epoch 26/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3124 - accuracy: 0.9023 - val_loss: 0.2915 - val_accuracy: 0.9047
# Epoch 27/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3188 - accuracy: 0.8988 - val_loss: 0.2727 - val_accuracy: 0.9109
# Epoch 28/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3094 - accuracy: 0.9012 - val_loss: 0.2729 - val_accuracy: 0.9141
# Epoch 29/90
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3023 - accuracy: 0.9055 - val_loss: 0.2770 - val_accuracy: 0.9156
# Epoch 30/90
# 5/5 [==============================] - 0s 50ms/step - loss: 0.3069 - accuracy: 0.9035 - val_loss: 0.2988 - val_accuracy: 0.9016
# Epoch 31/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3113 - accuracy: 0.9027 - val_loss: 0.2673 - val_accuracy: 0.9125
# Epoch 32/90
# 5/5 [==============================] - 0s 54ms/step - loss: 0.3009 - accuracy: 0.9035 - val_loss: 0.2566 - val_accuracy: 0.9125
# Epoch 33/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2957 - accuracy: 0.9035 - val_loss: 0.2738 - val_accuracy: 0.9187
# Epoch 34/90
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2927 - accuracy: 0.9059 - val_loss: 0.2577 - val_accuracy: 0.9141
# Epoch 35/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2810 - accuracy: 0.9160 - val_loss: 0.2491 - val_accuracy: 0.9172
# Epoch 36/90
# 5/5 [==============================] - 0s 54ms/step - loss: 0.2806 - accuracy: 0.9117 - val_loss: 0.2423 - val_accuracy: 0.9187
# Epoch 37/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2720 - accuracy: 0.9156 - val_loss: 0.2375 - val_accuracy: 0.9172
# Epoch 38/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2669 - accuracy: 0.9172 - val_loss: 0.2307 - val_accuracy: 0.9172
# Epoch 39/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2591 - accuracy: 0.9184 - val_loss: 0.2328 - val_accuracy: 0.9250
# Epoch 40/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2594 - accuracy: 0.9211 - val_loss: 0.2349 - val_accuracy: 0.9156
# Epoch 41/90
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2542 - accuracy: 0.9187 - val_loss: 0.2211 - val_accuracy: 0.9219
# Epoch 42/90
# 5/5 [==============================] - 0s 51ms/step - loss: 0.2568 - accuracy: 0.9160 - val_loss: 0.2155 - val_accuracy: 0.9250
# Epoch 43/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2476 - accuracy: 0.9227 - val_loss: 0.2170 - val_accuracy: 0.9234
# Epoch 44/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2411 - accuracy: 0.9211 - val_loss: 0.2119 - val_accuracy: 0.9266
# Epoch 45/90
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2355 - accuracy: 0.9285 - val_loss: 0.2132 - val_accuracy: 0.9250
# Epoch 46/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2386 - accuracy: 0.9250 - val_loss: 0.2113 - val_accuracy: 0.9281
# Epoch 47/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2507 - accuracy: 0.9195 - val_loss: 0.2042 - val_accuracy: 0.9250
# Epoch 48/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.2307 - accuracy: 0.9219 - val_loss: 0.2014 - val_accuracy: 0.9266
# Epoch 49/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2257 - accuracy: 0.9273 - val_loss: 0.2055 - val_accuracy: 0.9234
# Epoch 50/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2359 - accuracy: 0.9277 - val_loss: 0.2035 - val_accuracy: 0.9250
# Epoch 51/90
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2333 - accuracy: 0.9219 - val_loss: 0.2080 - val_accuracy: 0.9344
# Epoch 52/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2329 - accuracy: 0.9246 - val_loss: 0.2158 - val_accuracy: 0.9203
# Epoch 53/90
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2271 - accuracy: 0.9238 - val_loss: 0.2006 - val_accuracy: 0.9281
# Epoch 54/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2290 - accuracy: 0.9223 - val_loss: 0.1996 - val_accuracy: 0.9281
# Epoch 55/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2279 - accuracy: 0.9270 - val_loss: 0.1973 - val_accuracy: 0.9297
# Epoch 56/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2273 - accuracy: 0.9199 - val_loss: 0.2026 - val_accuracy: 0.9281
# Epoch 57/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2306 - accuracy: 0.9234 - val_loss: 0.1955 - val_accuracy: 0.9266
# Epoch 58/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2200 - accuracy: 0.9301 - val_loss: 0.1995 - val_accuracy: 0.9219
# Epoch 59/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.2135 - accuracy: 0.9312 - val_loss: 0.1867 - val_accuracy: 0.9297
# Epoch 60/90
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2056 - accuracy: 0.9328 - val_loss: 0.1807 - val_accuracy: 0.9312
# Epoch 61/90
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2121 - accuracy: 0.9297 - val_loss: 0.1776 - val_accuracy: 0.9344
# Epoch 62/90
# 5/5 [==============================] - 0s 55ms/step - loss: 0.2076 - accuracy: 0.9312 - val_loss: 0.1775 - val_accuracy: 0.9312
# Epoch 63/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2046 - accuracy: 0.9293 - val_loss: 0.1900 - val_accuracy: 0.9266
# Epoch 64/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1983 - accuracy: 0.9355 - val_loss: 0.1775 - val_accuracy: 0.9359
# Epoch 65/90
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1978 - accuracy: 0.9348 - val_loss: 0.1719 - val_accuracy: 0.9391
# Epoch 66/90
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1938 - accuracy: 0.9359 - val_loss: 0.1725 - val_accuracy: 0.9422
# Epoch 67/90
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1875 - accuracy: 0.9410 - val_loss: 0.1734 - val_accuracy: 0.9266
# Epoch 68/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.2009 - accuracy: 0.9312 - val_loss: 0.1755 - val_accuracy: 0.9359
# Epoch 69/90
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2013 - accuracy: 0.9312 - val_loss: 0.1677 - val_accuracy: 0.9438
# Epoch 70/90
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1904 - accuracy: 0.9395 - val_loss: 0.1693 - val_accuracy: 0.9344
# Epoch 71/90
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1910 - accuracy: 0.9320 - val_loss: 0.1645 - val_accuracy: 0.9484
# Epoch 72/90
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1922 - accuracy: 0.9395 - val_loss: 0.1628 - val_accuracy: 0.9422
# Epoch 73/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1831 - accuracy: 0.9371 - val_loss: 0.1575 - val_accuracy: 0.9422
# Epoch 74/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1914 - accuracy: 0.9312 - val_loss: 0.1572 - val_accuracy: 0.9406
# Epoch 75/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1823 - accuracy: 0.9402 - val_loss: 0.1623 - val_accuracy: 0.9531
# Epoch 76/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1752 - accuracy: 0.9441 - val_loss: 0.1574 - val_accuracy: 0.9391
# Epoch 77/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1732 - accuracy: 0.9418 - val_loss: 0.1562 - val_accuracy: 0.9547
# Epoch 78/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1714 - accuracy: 0.9426 - val_loss: 0.1553 - val_accuracy: 0.9438
# Epoch 79/90
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1733 - accuracy: 0.9383 - val_loss: 0.1544 - val_accuracy: 0.9531
# Epoch 80/90
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1794 - accuracy: 0.9414 - val_loss: 0.1482 - val_accuracy: 0.9531
# Epoch 81/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1729 - accuracy: 0.9434 - val_loss: 0.1506 - val_accuracy: 0.9625
# Epoch 82/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1658 - accuracy: 0.9434 - val_loss: 0.1502 - val_accuracy: 0.9516
# Epoch 83/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1661 - accuracy: 0.9477 - val_loss: 0.1542 - val_accuracy: 0.9531
# Epoch 84/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1772 - accuracy: 0.9391 - val_loss: 0.1475 - val_accuracy: 0.9625
# Epoch 85/90
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1733 - accuracy: 0.9461 - val_loss: 0.1583 - val_accuracy: 0.9531
# Epoch 86/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1733 - accuracy: 0.9395 - val_loss: 0.1447 - val_accuracy: 0.9594
# Epoch 87/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1676 - accuracy: 0.9453 - val_loss: 0.1423 - val_accuracy: 0.9500
# Epoch 88/90
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1634 - accuracy: 0.9508 - val_loss: 0.1435 - val_accuracy: 0.9438
# Epoch 89/90
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1592 - accuracy: 0.9469 - val_loss: 0.1385 - val_accuracy: 0.9484
# Epoch 90/90
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1601 - accuracy: 0.9465 - val_loss: 0.1416 - val_accuracy: 0.9531

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn.evaluate({"spectra":cube_train2, "spatial":xy_train}, cube_train_labels)
test_loss, test_acc = cnn.evaluate({"spectra":cube_test2, "spatial":xy_test}, cube_test_labels)

print(train_acc, test_acc)
# Out:
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1299 - accuracy: 0.9586
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1416 - accuracy: 0.9531
# 0.9585937261581421 0.953125

# %% [markdown]
# ### Predict pixel classification on veg_00108

# %%
cube_standard_1 = cube_standard.reshape(cube_standard.shape[0], cube_standard.shape[1], 1)
print(cube_standard_1.shape)
xy_2d = xy.reshape((xy.shape[0] * xy.shape[1]), xy.shape[2])
print(xy_2d.shape)
# Out:
# (2560000, 212, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube = cnn.predict({"spectra":cube_standard_1, "spatial":xy_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:56

# %%
predictCube = probCube.argmax(axis=-1)

# %%
predictCube_reshape = predictCube.reshape(cube_sub.shape[1], cube_sub.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_1_108_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.png".format(num_of_bins), 
            bbox_inches='tight')

# %%
import pickle
pickle.dump(predictCube_reshape,
            open("./plots/CNN_Model2_spatial_train_108_binned_{0}_test_108_predict_map.pickle".format(num_of_bins), 
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (veg_00108)

# %%
labels_pred_sky = predictCube_reshape[sky_coords[sky_test_ind[:], 0], sky_coords[sky_test_ind[:], 1]]
labels_pred_clouds = predictCube_reshape[clouds_coords[clouds_test_ind[:], 0], clouds_coords[clouds_test_ind[:],1]]
labels_pred_veg = predictCube_reshape[veg_coords[veg_test_ind[:],0], veg_coords[veg_test_ind[:],1]]
labels_pred_wtr = predictCube_reshape[wtr_coords[wtr_test_ind[:],0], wtr_coords[wtr_test_ind[:],1]]
labels_pred_blt = predictCube_reshape[blt_coords[blt_test_ind[:],0], blt_coords[blt_test_ind[:],1]]
labels_pred_windows = predictCube_reshape[windows_coords[windows_test_ind[:],0], windows_coords[windows_test_ind[:],1]]
labels_pred_rds = predictCube_reshape[rds_coords[rds_test_ind[:],0], rds_coords[rds_test_ind[:],1]]
labels_pred_cars = predictCube_reshape[cars_coords[cars_test_ind[:],0], cars_coords[cars_test_ind[:],1]]
labels_pred_mtl = predictCube_reshape[mtl_coords[mtl_test_ind[:],0], mtl_coords[mtl_test_ind[:],1]]

labels_pred = np.concatenate((labels_pred_sky, labels_pred_clouds, labels_pred_veg, labels_pred_wtr, 
                             labels_pred_blt, labels_pred_windows, labels_pred_rds, labels_pred_cars, labels_pred_mtl))

# %%
labels_true_sky = np.full(len(sky_test_ind), 0)
labels_true_clouds = np.full(len(clouds_test_ind), 1)
labels_true_veg = np.full(len(veg_test_ind), 2)
labels_true_wtr = np.full(len(wtr_test_ind), 3)
labels_true_blt = np.full(len(blt_test_ind), 4)
labels_true_windows = np.full(len(windows_test_ind), 5)
labels_true_rds = np.full(len(rds_test_ind), 6)
labels_true_cars = np.full(len(cars_test_ind), 7)
labels_true_mtl = np.full(len(mtl_test_ind), 8)

labels_true = np.concatenate((labels_true_sky, labels_true_clouds, labels_true_veg, labels_true_wtr, 
                             labels_true_blt, labels_true_windows, labels_true_rds, labels_true_cars, labels_true_mtl))

# %%
print(labels_pred.shape)
print(labels_true.shape)
# Out:
# (640,)
# (640,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels_true, labels_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels_true, labels_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0   0]
#  [  0   0 118   0   2   0   0   0   0]
#  [  0   0   0  10   0   0   0   0   0]
#  [  0   0   0   0 200   1   0   1   2]
#  [  0   0   0   0   5  91   0   2   2]
#  [  0   0   0   0   1   0   5   0   0]
#  [  0   0   0   0   2   3   1  13   1]
#  [  0   0   0   0   7   0   0   0  13]]
#
# Accuracy Score
# 0.953125
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       120
#       water       1.00      1.00      1.00        10
#       built       0.92      0.98      0.95       204
#     windows       0.96      0.91      0.93       100
#       roads       0.83      0.83      0.83         6
#        cars       0.81      0.65      0.72        20
#       metal       0.72      0.65      0.68        20
#
# avg / total       0.95      0.95      0.95       640

# %%
f = open("./metrics/CNN_Model2_spatial_train_108_binned_{0}_test_108_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels_true, labels_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels_true, labels_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels_true, labels_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on veg_00000 (Scene 1-b South Facing @ ~6pm)

# %%
fname0 = "../../image_files/veg_00000.raw"
cube0 = read_hyper(fname0)
# Out:
# reading and parsing ../../image_files/veg_00000.hdr...
# reading ../../image_files/veg_00000.raw...

# %%
cube_sub0 = cube0.data[:, :, :].astype(float)
print(cube_sub0.shape)
# Out:
# (848, 1600, 1600)

# %%
cube_reshaped0 = cube_sub0.transpose(1, 2, 0).reshape((cube_sub0.shape[1] * cube_sub0.shape[2]), cube_sub0.shape[0])
print(cube_reshaped0.shape)
# Out:
# (2560000, 848)

# %%
cube_standard0 = (cube_reshaped0 - cube_reshaped0.mean(1, keepdims=True)) / cube_reshaped0.std(1, keepdims=True)
print(cube_standard0.shape)
# Out:
# (2560000, 848)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coords0 = read_labelled_coordinates("1_sky", "000")
clouds_coords0 = read_labelled_coordinates("2_clouds", "000")
veg_coords0 = read_labelled_coordinates("3_vegetation", "000")
wtr_coords0 = read_labelled_coordinates("4_water", "000")
blt_coords0 = read_labelled_coordinates("5_buildings", "000")
windows_coords0 = read_labelled_coordinates("6_windows", "000")
rds_coords0 = read_labelled_coordinates("7_roads", "000")
cars_coords0 = read_labelled_coordinates("8_cars", "000")
mtl_coords0 = read_labelled_coordinates("9_metal", "000")
# Out:
# 1_sky: (400, 2)
# 2_clouds: (500, 2)
# 3_vegetation: (610, 2)
# 4_water: (0,)
# 5_buildings: (1200, 2)
# 6_windows: (500, 2)
# 7_roads: (60, 2)
# 8_cars: (55, 2)
# 9_metal: (230, 2)

# %%
# create position array and normalize

xy0 = coords(cube_sub0.shape[1], cube_sub0.shape[2])
xy0 = xy0/xy0.max()

# %% [markdown]
# ### Bin Spectra

# %%
cube_binned0 = np.zeros(shape=(cube_standard0.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binned0[:, i] = cube_standard0[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binned0.shape)
# Out:
# (2560000, 212)

# %%
cube_standard0 = cube_binned0
print(cube_standard0.shape)
# Out:
# (2560000, 212)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_ind0, sky_test_ind0 = split_train_test_indices(sky_coords0, 10, trrat, "sky")
clouds_train_ind0, clouds_test_ind0 = split_train_test_indices(clouds_coords0, 20, trrat, "clouds")
veg_train_ind0, veg_test_ind0 = split_train_test_indices(veg_coords0, 30, trrat, "veg")
#wtr_train_ind0, wtr_test_ind0 = split_train_test_indices(wtr_coords0, 40, trrat, "wtr")
blt_train_ind0, blt_test_ind0 = split_train_test_indices(blt_coords0, 50, trrat, "blt")
windows_train_ind0, windows_test_ind0 = split_train_test_indices(windows_coords0, 60, trrat, "windows")
rds_train_ind0, rds_test_ind0 = split_train_test_indices(rds_coords0, 70, trrat, "rds")
cars_train_ind0, cars_test_ind0 = split_train_test_indices(cars_coords0, 80, trrat, "cars")
mtl_train_ind0, mtl_test_ind0 = split_train_test_indices(mtl_coords0, 90, trrat, "mtl")
# Out:
# sky: 320 80
# clouds: 400 100
# veg: 488 122
# blt: 960 240
# windows: 400 100
# rds: 48 12
# cars: 44 11
# mtl: 184 46

# %%
cube_std0_3d = cube_standard0.reshape(cube_sub0.shape[1], cube_sub0.shape[2], num_of_bins)
print(cube_std0_3d.shape)
print(xy0.shape)
# Out:
# (1600, 1600, 212)
# (1600, 1600, 2)

# %%
cube_sky_train0 = cube_std0_3d[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
cube_sky_test0 = cube_std0_3d[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
sky_xy_train0 = xy0[sky_coords0[sky_train_ind0[:], 0], sky_coords0[sky_train_ind0[:], 1], :]
sky_xy_test0 = xy0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1], :]
print("sky ", cube_sky_train0.shape, cube_sky_test0.shape)


cube_clouds_train0 = cube_std0_3d[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
cube_clouds_test0 = cube_std0_3d[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
clouds_xy_train0 = xy0[clouds_coords0[clouds_train_ind0[:], 0], clouds_coords0[clouds_train_ind0[:], 1], :]
clouds_xy_test0 = xy0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:], 1], :]
print("clouds ", cube_clouds_train0.shape, cube_clouds_test0.shape)

cube_veg_train0 = cube_std0_3d[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
cube_veg_test0 = cube_std0_3d[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
veg_xy_train0 = xy0[veg_coords0[veg_train_ind0[:], 0], veg_coords0[veg_train_ind0[:], 1], :]
veg_xy_test0 = xy0[veg_coords0[veg_test_ind0[:], 0], veg_coords0[veg_test_ind0[:], 1], :]
print("vegetation ", cube_veg_train0.shape, cube_veg_test0.shape)

#cube_wtr_train0 = cube_std0_3d[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#cube_wtr_test0 = cube_std0_3d[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#wtr_xy_train0 = xy0[wtr_coords0[wtr_train_ind0[:], 0], wtr_coords0[wtr_train_ind0[:], 1], :]
#wtr_xy_test0 = xy0[wtr_coords0[wtr_test_ind0[:], 0], wtr_coords0[wtr_test_ind0[:], 1], :]
#print("water ", cube_wtr_train0.shape, cube_wtr_test0.shape)

cube_blt_train0 = cube_std0_3d[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
cube_blt_test0 = cube_std0_3d[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
blt_xy_train0 = xy0[blt_coords0[blt_train_ind0[:], 0], blt_coords0[blt_train_ind0[:], 1], :]
blt_xy_test0 = xy0[blt_coords0[blt_test_ind0[:], 0], blt_coords0[blt_test_ind0[:], 1], :]
print("built ", cube_blt_train0.shape, cube_blt_test0.shape)

cube_windows_train0 = cube_std0_3d[windows_coords0[windows_train_ind0[:],0], windows_coords0[windows_train_ind0[:],1],:]
cube_windows_test0 = cube_std0_3d[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
windows_xy_train0 = xy0[windows_coords0[windows_train_ind0[:], 0], windows_coords0[windows_train_ind0[:], 1], :]
windows_xy_test0 = xy0[windows_coords0[windows_test_ind0[:], 0], windows_coords0[windows_test_ind0[:], 1], :]
print("windows ", cube_windows_train0.shape, cube_windows_test0.shape)

cube_rds_train0 = cube_std0_3d[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
cube_rds_test0 = cube_std0_3d[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
rds_xy_train0 = xy0[rds_coords0[rds_train_ind0[:], 0], rds_coords0[rds_train_ind0[:], 1], :]
rds_xy_test0 = xy0[rds_coords0[rds_test_ind0[:], 0], rds_coords0[rds_test_ind0[:], 1], :]
print("roads ", cube_rds_train0.shape, cube_rds_test0.shape)

cube_cars_train0 = cube_std0_3d[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cube_cars_test0 = cube_std0_3d[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
cars_xy_train0 = xy0[cars_coords0[cars_train_ind0[:], 0], cars_coords0[cars_train_ind0[:], 1], :]
cars_xy_test0 = xy0[cars_coords0[cars_test_ind0[:], 0], cars_coords0[cars_test_ind0[:], 1], :]
print("cars ", cube_cars_train0.shape, cube_cars_test0.shape)

cube_mtl_train0 = cube_std0_3d[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
cube_mtl_test0 = cube_std0_3d[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
mtl_xy_train0 = xy0[mtl_coords0[mtl_train_ind0[:], 0], mtl_coords0[mtl_train_ind0[:], 1], :]
mtl_xy_test0 = xy0[mtl_coords0[mtl_test_ind0[:], 0], mtl_coords0[mtl_test_ind0[:], 1], :]
print("metal ", cube_mtl_train0.shape, cube_mtl_test0.shape)
# Out:
# sky  (320, 212) (80, 212)
# clouds  (400, 212) (100, 212)
# vegetation  (488, 212) (122, 212)
# built  (960, 212) (240, 212)
# windows  (400, 212) (100, 212)
# roads  (48, 212) (12, 212)
# cars  (44, 212) (11, 212)
# metal  (184, 212) (46, 212)

# %%
cube_train0 = np.concatenate((cube_sky_train0, cube_clouds_train0, cube_veg_train0, cube_blt_train0,
                             cube_windows_train0, cube_rds_train0, cube_cars_train0, cube_mtl_train0), axis=0)
cube_train_labels0 = [0]*cube_sky_train0.shape[0] + [1]*cube_clouds_train0.shape[0] \
                + [2]*cube_veg_train0.shape[0] + [4]*cube_blt_train0.shape[0] \
                + [5]*cube_windows_train0.shape[0] + [6]*cube_rds_train0.shape[0] \
                + [7]*cube_cars_train0.shape[0] + [8]*cube_mtl_train0.shape[0]
xy_train0 = np.concatenate((sky_xy_train0, clouds_xy_train0, veg_xy_train0, blt_xy_train0,
                             windows_xy_train0, rds_xy_train0, cars_xy_train0, mtl_xy_train0), axis=0)

cube_test0 = np.concatenate((cube_sky_test0, cube_clouds_test0, cube_veg_test0, cube_blt_test0,
                             cube_windows_test0, cube_rds_test0, cube_cars_test0, cube_mtl_test0), axis=0)
cube_test_labels0 = [0]*cube_sky_test0.shape[0] + [1]*cube_clouds_test0.shape[0] \
                + [2]*cube_veg_test0.shape[0] + [4]*cube_blt_test0.shape[0] \
                + [5]*cube_windows_test0.shape[0] + [6]*cube_rds_test0.shape[0] \
                + [7]*cube_cars_test0.shape[0] + [8]*cube_mtl_test0.shape[0]
xy_test0 = np.concatenate((sky_xy_test0, clouds_xy_test0, veg_xy_test0, blt_xy_test0,
                             windows_xy_test0, rds_xy_test0, cars_xy_test0, mtl_xy_test0), axis=0)

# %%
cube_train_labels0 = np.array(cube_train_labels0)
cube_test_labels0 = np.array(cube_test_labels0)

print(cube_train0.shape, cube_train_labels0.shape, xy_train0.shape)
print(cube_test0.shape, cube_test_labels0.shape, xy_test0.shape)
# Out:
# (2844, 212) (2844,) (2844, 2)
# (711, 212) (711,) (711, 2)

# %% [markdown]
# ### Train CNN

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnn0, show_shapes=True)
#cnn0.summary()

cube_train02 = cube_train0.reshape(cube_train0.shape[0], cube_train0.shape[1], 1)
cube_test02 = cube_test0.reshape(cube_test0.shape[0], cube_test0.shape[1], 1)

# %%
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 74ms/step - loss: 1.7487 - accuracy: 0.3499 - val_loss: 1.3632 - val_accuracy: 0.6695
# Epoch 2/200
# 6/6 [==============================] - 0s 48ms/step - loss: 1.1735 - accuracy: 0.6406 - val_loss: 0.9894 - val_accuracy: 0.6540
# Epoch 3/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.8949 - accuracy: 0.6867 - val_loss: 0.7892 - val_accuracy: 0.7004
# Epoch 4/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.7287 - accuracy: 0.7159 - val_loss: 0.6861 - val_accuracy: 0.7595
# Epoch 5/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.6627 - accuracy: 0.7342 - val_loss: 0.6337 - val_accuracy: 0.7539
# Epoch 6/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.5986 - accuracy: 0.7504 - val_loss: 0.6010 - val_accuracy: 0.7595
# Epoch 7/200
# 6/6 [==============================] - 0s 48ms/step - loss: 0.5659 - accuracy: 0.7718 - val_loss: 0.5716 - val_accuracy: 0.7932
# Epoch 8/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.5401 - accuracy: 0.7831 - val_loss: 0.5604 - val_accuracy: 0.7637
# Epoch 9/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5008 - accuracy: 0.8063 - val_loss: 0.5550 - val_accuracy: 0.7707
# Epoch 10/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.5054 - accuracy: 0.7932 - val_loss: 0.5867 - val_accuracy: 0.7623
# Epoch 11/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.5012 - accuracy: 0.8003 - val_loss: 0.5125 - val_accuracy: 0.8115
# Epoch 12/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4764 - accuracy: 0.8140 - val_loss: 0.4973 - val_accuracy: 0.7947
# Epoch 13/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4571 - accuracy: 0.8238 - val_loss: 0.4786 - val_accuracy: 0.8143
# Epoch 14/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.4416 - accuracy: 0.8256 - val_loss: 0.4636 - val_accuracy: 0.8256
# Epoch 15/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4363 - accuracy: 0.8277 - val_loss: 0.4883 - val_accuracy: 0.8397
# Epoch 16/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4424 - accuracy: 0.8295 - val_loss: 0.4876 - val_accuracy: 0.8059
# Epoch 17/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.4193 - accuracy: 0.8330 - val_loss: 0.4923 - val_accuracy: 0.8172
# Epoch 18/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4128 - accuracy: 0.8379 - val_loss: 0.4431 - val_accuracy: 0.8425
# Epoch 19/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3891 - accuracy: 0.8537 - val_loss: 0.4584 - val_accuracy: 0.8312
# Epoch 20/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4024 - accuracy: 0.8477 - val_loss: 0.4197 - val_accuracy: 0.8298
# Epoch 21/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3893 - accuracy: 0.8576 - val_loss: 0.4223 - val_accuracy: 0.8439
# Epoch 22/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3794 - accuracy: 0.8534 - val_loss: 0.4157 - val_accuracy: 0.8368
# Epoch 23/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3770 - accuracy: 0.8576 - val_loss: 0.4349 - val_accuracy: 0.8354
# Epoch 24/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3730 - accuracy: 0.8579 - val_loss: 0.4050 - val_accuracy: 0.8537
# Epoch 25/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3695 - accuracy: 0.8586 - val_loss: 0.3901 - val_accuracy: 0.8608
# Epoch 26/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3602 - accuracy: 0.8731 - val_loss: 0.4128 - val_accuracy: 0.8298
# Epoch 27/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3518 - accuracy: 0.8703 - val_loss: 0.3784 - val_accuracy: 0.8664
# Epoch 28/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3400 - accuracy: 0.8710 - val_loss: 0.4115 - val_accuracy: 0.8537
# Epoch 29/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3509 - accuracy: 0.8622 - val_loss: 0.3911 - val_accuracy: 0.8481
# Epoch 30/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3492 - accuracy: 0.8657 - val_loss: 0.4168 - val_accuracy: 0.8467
# Epoch 31/200
# 6/6 [==============================] - 0s 45ms/step - loss: 0.3529 - accuracy: 0.8632 - val_loss: 0.4274 - val_accuracy: 0.8453
# Epoch 32/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.3667 - accuracy: 0.8586 - val_loss: 0.3783 - val_accuracy: 0.8692
# Epoch 33/200
# 6/6 [==============================] - 0s 47ms/step - loss: 0.3258 - accuracy: 0.8759 - val_loss: 0.3737 - val_accuracy: 0.8579
# Epoch 34/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3208 - accuracy: 0.8840 - val_loss: 0.3697 - val_accuracy: 0.8650
# Epoch 35/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3368 - accuracy: 0.8688 - val_loss: 0.3887 - val_accuracy: 0.8453
# Epoch 36/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3441 - accuracy: 0.8590 - val_loss: 0.3763 - val_accuracy: 0.8509
# Epoch 37/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3231 - accuracy: 0.8776 - val_loss: 0.3939 - val_accuracy: 0.8439
# Epoch 38/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3243 - accuracy: 0.8790 - val_loss: 0.3767 - val_accuracy: 0.8678
# Epoch 39/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3106 - accuracy: 0.8854 - val_loss: 0.3499 - val_accuracy: 0.8734
# Epoch 40/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.3108 - accuracy: 0.8794 - val_loss: 0.3424 - val_accuracy: 0.8706
# Epoch 41/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3022 - accuracy: 0.8868 - val_loss: 0.3381 - val_accuracy: 0.8748
# Epoch 42/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.3027 - accuracy: 0.8797 - val_loss: 0.3442 - val_accuracy: 0.8734
# Epoch 43/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2927 - accuracy: 0.8921 - val_loss: 0.3348 - val_accuracy: 0.8720
# Epoch 44/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2980 - accuracy: 0.8861 - val_loss: 0.3429 - val_accuracy: 0.8762
# Epoch 45/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2973 - accuracy: 0.8875 - val_loss: 0.3356 - val_accuracy: 0.8833
# Epoch 46/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2990 - accuracy: 0.8850 - val_loss: 0.3402 - val_accuracy: 0.8776
# Epoch 47/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2909 - accuracy: 0.8871 - val_loss: 0.3315 - val_accuracy: 0.8819
# Epoch 48/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2861 - accuracy: 0.8973 - val_loss: 0.3293 - val_accuracy: 0.8819
# Epoch 49/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2811 - accuracy: 0.8973 - val_loss: 0.3297 - val_accuracy: 0.8776
# Epoch 50/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2833 - accuracy: 0.8896 - val_loss: 0.3205 - val_accuracy: 0.8833
# Epoch 51/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2737 - accuracy: 0.8984 - val_loss: 0.3267 - val_accuracy: 0.8805
# Epoch 52/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2816 - accuracy: 0.8949 - val_loss: 0.3155 - val_accuracy: 0.8833
# Epoch 53/200
# 6/6 [==============================] - 0s 49ms/step - loss: 0.2735 - accuracy: 0.9040 - val_loss: 0.3091 - val_accuracy: 0.8889
# Epoch 54/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2722 - accuracy: 0.8977 - val_loss: 0.3136 - val_accuracy: 0.8875
# Epoch 55/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2836 - accuracy: 0.8945 - val_loss: 0.3386 - val_accuracy: 0.8805
# Epoch 56/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2891 - accuracy: 0.8921 - val_loss: 0.3251 - val_accuracy: 0.8776
# Epoch 57/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2769 - accuracy: 0.9001 - val_loss: 0.3209 - val_accuracy: 0.8790
# Epoch 58/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2773 - accuracy: 0.9001 - val_loss: 0.3368 - val_accuracy: 0.8776
# Epoch 59/200
# 6/6 [==============================] - 0s 50ms/step - loss: 0.2968 - accuracy: 0.8914 - val_loss: 0.3447 - val_accuracy: 0.8805
# Epoch 60/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2801 - accuracy: 0.8924 - val_loss: 0.3305 - val_accuracy: 0.8762
# Epoch 61/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2780 - accuracy: 0.9008 - val_loss: 0.3198 - val_accuracy: 0.8875
# Epoch 62/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2574 - accuracy: 0.9023 - val_loss: 0.3044 - val_accuracy: 0.8833
# Epoch 63/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2599 - accuracy: 0.9061 - val_loss: 0.3288 - val_accuracy: 0.8819
# Epoch 64/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2599 - accuracy: 0.9026 - val_loss: 0.2963 - val_accuracy: 0.8987
# Epoch 65/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2582 - accuracy: 0.8994 - val_loss: 0.3170 - val_accuracy: 0.8790
# Epoch 66/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.2590 - accuracy: 0.9023 - val_loss: 0.2921 - val_accuracy: 0.8903
# Epoch 67/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2587 - accuracy: 0.9005 - val_loss: 0.3073 - val_accuracy: 0.8987
# Epoch 68/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2555 - accuracy: 0.9033 - val_loss: 0.3369 - val_accuracy: 0.8776
# Epoch 69/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2592 - accuracy: 0.9015 - val_loss: 0.3203 - val_accuracy: 0.8819
# Epoch 70/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2531 - accuracy: 0.9037 - val_loss: 0.2892 - val_accuracy: 0.9001
# Epoch 71/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2500 - accuracy: 0.9100 - val_loss: 0.2882 - val_accuracy: 0.9044
# Epoch 72/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2422 - accuracy: 0.9089 - val_loss: 0.3102 - val_accuracy: 0.8917
# Epoch 73/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2389 - accuracy: 0.9132 - val_loss: 0.2806 - val_accuracy: 0.8959
# Epoch 74/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2437 - accuracy: 0.9132 - val_loss: 0.3227 - val_accuracy: 0.8734
# Epoch 75/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2716 - accuracy: 0.8928 - val_loss: 0.3104 - val_accuracy: 0.8903
# Epoch 76/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2597 - accuracy: 0.9054 - val_loss: 0.3319 - val_accuracy: 0.8833
# Epoch 77/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.2554 - accuracy: 0.9072 - val_loss: 0.2832 - val_accuracy: 0.9030
# Epoch 78/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2428 - accuracy: 0.9177 - val_loss: 0.2930 - val_accuracy: 0.8959
# Epoch 79/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2443 - accuracy: 0.9107 - val_loss: 0.2957 - val_accuracy: 0.8945
# Epoch 80/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.2426 - accuracy: 0.9086 - val_loss: 0.2912 - val_accuracy: 0.9001
# Epoch 81/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2427 - accuracy: 0.9153 - val_loss: 0.2962 - val_accuracy: 0.8861
# Epoch 82/200
# 6/6 [==============================] - 0s 46ms/step - loss: 0.2352 - accuracy: 0.9153 - val_loss: 0.2818 - val_accuracy: 0.9001
# Epoch 83/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2328 - accuracy: 0.9132 - val_loss: 0.2719 - val_accuracy: 0.9086
# Epoch 84/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2199 - accuracy: 0.9223 - val_loss: 0.3178 - val_accuracy: 0.8917
# Epoch 85/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.2288 - accuracy: 0.9156 - val_loss: 0.2729 - val_accuracy: 0.9030
# Epoch 86/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2205 - accuracy: 0.9258 - val_loss: 0.2675 - val_accuracy: 0.9100
# Epoch 87/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2180 - accuracy: 0.9181 - val_loss: 0.2925 - val_accuracy: 0.8945
# Epoch 88/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2205 - accuracy: 0.9216 - val_loss: 0.2746 - val_accuracy: 0.9058
# Epoch 89/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2395 - accuracy: 0.9089 - val_loss: 0.3070 - val_accuracy: 0.8833
# Epoch 90/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2374 - accuracy: 0.9110 - val_loss: 0.2767 - val_accuracy: 0.9058
# Epoch 91/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2219 - accuracy: 0.9188 - val_loss: 0.2825 - val_accuracy: 0.8945
# Epoch 92/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2195 - accuracy: 0.9177 - val_loss: 0.2947 - val_accuracy: 0.8903
# Epoch 93/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2295 - accuracy: 0.9135 - val_loss: 0.2718 - val_accuracy: 0.9114
# Epoch 94/200
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2186 - accuracy: 0.9205 - val_loss: 0.2931 - val_accuracy: 0.9058
# Epoch 95/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2175 - accuracy: 0.9191 - val_loss: 0.2824 - val_accuracy: 0.8959
# Epoch 96/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2109 - accuracy: 0.9255 - val_loss: 0.2706 - val_accuracy: 0.9086
# Epoch 97/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.2186 - accuracy: 0.9202 - val_loss: 0.2776 - val_accuracy: 0.9001
# Epoch 98/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2087 - accuracy: 0.9230 - val_loss: 0.2629 - val_accuracy: 0.9184
# Epoch 99/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2159 - accuracy: 0.9255 - val_loss: 0.2702 - val_accuracy: 0.9170
# Epoch 100/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2146 - accuracy: 0.9216 - val_loss: 0.2621 - val_accuracy: 0.9015
# Epoch 101/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.2082 - accuracy: 0.9212 - val_loss: 0.2577 - val_accuracy: 0.9156
# Epoch 102/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2134 - accuracy: 0.9181 - val_loss: 0.2597 - val_accuracy: 0.9156
# Epoch 103/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1941 - accuracy: 0.9367 - val_loss: 0.2695 - val_accuracy: 0.9100
# Epoch 104/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2119 - accuracy: 0.9212 - val_loss: 0.2634 - val_accuracy: 0.9114
# Epoch 105/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2002 - accuracy: 0.9290 - val_loss: 0.2615 - val_accuracy: 0.9100
# Epoch 106/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.2109 - accuracy: 0.9191 - val_loss: 0.2774 - val_accuracy: 0.8917
# Epoch 107/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2081 - accuracy: 0.9226 - val_loss: 0.2566 - val_accuracy: 0.9142
# Epoch 108/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2007 - accuracy: 0.9290 - val_loss: 0.2813 - val_accuracy: 0.8931
# Epoch 109/200
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2035 - accuracy: 0.9255 - val_loss: 0.2540 - val_accuracy: 0.9156
# Epoch 110/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1955 - accuracy: 0.9283 - val_loss: 0.3139 - val_accuracy: 0.8833
# Epoch 111/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.2253 - accuracy: 0.9110 - val_loss: 0.2835 - val_accuracy: 0.8959
# Epoch 112/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2080 - accuracy: 0.9226 - val_loss: 0.2870 - val_accuracy: 0.9142
# Epoch 113/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2256 - accuracy: 0.9156 - val_loss: 0.2936 - val_accuracy: 0.8889
# Epoch 114/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2214 - accuracy: 0.9184 - val_loss: 0.2908 - val_accuracy: 0.8903
# Epoch 115/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2014 - accuracy: 0.9241 - val_loss: 0.2458 - val_accuracy: 0.9184
# Epoch 116/200
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1915 - accuracy: 0.9300 - val_loss: 0.2564 - val_accuracy: 0.9198
# Epoch 117/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1929 - accuracy: 0.9332 - val_loss: 0.2690 - val_accuracy: 0.9030
# Epoch 118/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2032 - accuracy: 0.9251 - val_loss: 0.2592 - val_accuracy: 0.9072
# Epoch 119/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2011 - accuracy: 0.9276 - val_loss: 0.2498 - val_accuracy: 0.9212
# Epoch 120/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1813 - accuracy: 0.9353 - val_loss: 0.2572 - val_accuracy: 0.9086
# Epoch 121/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1775 - accuracy: 0.9399 - val_loss: 0.2583 - val_accuracy: 0.9100
# Epoch 122/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1913 - accuracy: 0.9290 - val_loss: 0.2985 - val_accuracy: 0.8973
# Epoch 123/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2119 - accuracy: 0.9212 - val_loss: 0.2710 - val_accuracy: 0.9128
# Epoch 124/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1970 - accuracy: 0.9233 - val_loss: 0.2613 - val_accuracy: 0.9086
# Epoch 125/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1975 - accuracy: 0.9251 - val_loss: 0.2475 - val_accuracy: 0.9198
# Epoch 126/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1913 - accuracy: 0.9272 - val_loss: 0.2677 - val_accuracy: 0.8861
# Epoch 127/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1907 - accuracy: 0.9290 - val_loss: 0.2399 - val_accuracy: 0.9212
# Epoch 128/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1841 - accuracy: 0.9332 - val_loss: 0.2722 - val_accuracy: 0.9086
# Epoch 129/200
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1758 - accuracy: 0.9371 - val_loss: 0.2478 - val_accuracy: 0.9114
# Epoch 130/200
# 6/6 [==============================] - 0s 53ms/step - loss: 0.1801 - accuracy: 0.9335 - val_loss: 0.2380 - val_accuracy: 0.9198
# Epoch 131/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1822 - accuracy: 0.9350 - val_loss: 0.2338 - val_accuracy: 0.9198
# Epoch 132/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1815 - accuracy: 0.9360 - val_loss: 0.2520 - val_accuracy: 0.9072
# Epoch 133/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1874 - accuracy: 0.9346 - val_loss: 0.2745 - val_accuracy: 0.8973
# Epoch 134/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2054 - accuracy: 0.9230 - val_loss: 0.3048 - val_accuracy: 0.8776
# Epoch 135/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.2174 - accuracy: 0.9191 - val_loss: 0.2941 - val_accuracy: 0.8931
# Epoch 136/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1970 - accuracy: 0.9290 - val_loss: 0.2463 - val_accuracy: 0.9198
# Epoch 137/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1982 - accuracy: 0.9276 - val_loss: 0.2370 - val_accuracy: 0.9198
# Epoch 138/200
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1706 - accuracy: 0.9357 - val_loss: 0.2414 - val_accuracy: 0.9128
# Epoch 139/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1753 - accuracy: 0.9332 - val_loss: 0.2503 - val_accuracy: 0.9184
# Epoch 140/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1668 - accuracy: 0.9399 - val_loss: 0.2461 - val_accuracy: 0.9142
# Epoch 141/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1715 - accuracy: 0.9395 - val_loss: 0.2672 - val_accuracy: 0.9114
# Epoch 142/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1804 - accuracy: 0.9332 - val_loss: 0.2433 - val_accuracy: 0.9198
# Epoch 143/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1646 - accuracy: 0.9385 - val_loss: 0.2376 - val_accuracy: 0.9156
# Epoch 144/200
# 6/6 [==============================] - 0s 71ms/step - loss: 0.1709 - accuracy: 0.9364 - val_loss: 0.2547 - val_accuracy: 0.9030
# Epoch 145/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1656 - accuracy: 0.9430 - val_loss: 0.2466 - val_accuracy: 0.9100
# Epoch 146/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1695 - accuracy: 0.9395 - val_loss: 0.2385 - val_accuracy: 0.9156
# Epoch 147/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1638 - accuracy: 0.9409 - val_loss: 0.2211 - val_accuracy: 0.9283
# Epoch 148/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1643 - accuracy: 0.9395 - val_loss: 0.2320 - val_accuracy: 0.9198
# Epoch 149/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1645 - accuracy: 0.9381 - val_loss: 0.2361 - val_accuracy: 0.9212
# Epoch 150/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1715 - accuracy: 0.9353 - val_loss: 0.2663 - val_accuracy: 0.9001
# Epoch 151/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1799 - accuracy: 0.9286 - val_loss: 0.2473 - val_accuracy: 0.9072
# Epoch 152/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1731 - accuracy: 0.9395 - val_loss: 0.2315 - val_accuracy: 0.9156
# Epoch 153/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1595 - accuracy: 0.9413 - val_loss: 0.2280 - val_accuracy: 0.9156
# Epoch 154/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1614 - accuracy: 0.9342 - val_loss: 0.2330 - val_accuracy: 0.9184
# Epoch 155/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1696 - accuracy: 0.9353 - val_loss: 0.2276 - val_accuracy: 0.9255
# Epoch 156/200
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1511 - accuracy: 0.9476 - val_loss: 0.2142 - val_accuracy: 0.9283
# Epoch 157/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1496 - accuracy: 0.9459 - val_loss: 0.2165 - val_accuracy: 0.9198
# Epoch 158/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1545 - accuracy: 0.9413 - val_loss: 0.2328 - val_accuracy: 0.9198
# Epoch 159/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1562 - accuracy: 0.9427 - val_loss: 0.2301 - val_accuracy: 0.9241
# Epoch 160/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1544 - accuracy: 0.9451 - val_loss: 0.2249 - val_accuracy: 0.9283
# Epoch 161/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1538 - accuracy: 0.9448 - val_loss: 0.2178 - val_accuracy: 0.9212
# Epoch 162/200
# 6/6 [==============================] - 0s 74ms/step - loss: 0.1441 - accuracy: 0.9504 - val_loss: 0.2098 - val_accuracy: 0.9255
# Epoch 163/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1454 - accuracy: 0.9487 - val_loss: 0.2233 - val_accuracy: 0.9283
# Epoch 164/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1524 - accuracy: 0.9451 - val_loss: 0.2212 - val_accuracy: 0.9241
# Epoch 165/200
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1567 - accuracy: 0.9430 - val_loss: 0.2123 - val_accuracy: 0.9311
# Epoch 166/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1407 - accuracy: 0.9469 - val_loss: 0.2335 - val_accuracy: 0.9226
# Epoch 167/200
# 6/6 [==============================] - 0s 55ms/step - loss: 0.1592 - accuracy: 0.9409 - val_loss: 0.2859 - val_accuracy: 0.8945
# Epoch 168/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1739 - accuracy: 0.9371 - val_loss: 0.2476 - val_accuracy: 0.9212
# Epoch 169/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1597 - accuracy: 0.9437 - val_loss: 0.2182 - val_accuracy: 0.9269
# Epoch 170/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1485 - accuracy: 0.9487 - val_loss: 0.2266 - val_accuracy: 0.9170
# Epoch 171/200
# 6/6 [==============================] - 0s 79ms/step - loss: 0.1493 - accuracy: 0.9525 - val_loss: 0.2107 - val_accuracy: 0.9241
# Epoch 172/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1410 - accuracy: 0.9511 - val_loss: 0.2311 - val_accuracy: 0.9198
# Epoch 173/200
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1514 - accuracy: 0.9409 - val_loss: 0.2081 - val_accuracy: 0.9353
# Epoch 174/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1441 - accuracy: 0.9497 - val_loss: 0.2400 - val_accuracy: 0.9198
# Epoch 175/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1462 - accuracy: 0.9466 - val_loss: 0.2124 - val_accuracy: 0.9226
# Epoch 176/200
# 6/6 [==============================] - 0s 70ms/step - loss: 0.1397 - accuracy: 0.9494 - val_loss: 0.2111 - val_accuracy: 0.9241
# Epoch 177/200
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1283 - accuracy: 0.9543 - val_loss: 0.2083 - val_accuracy: 0.9353
# Epoch 178/200
# 6/6 [==============================] - 0s 68ms/step - loss: 0.1313 - accuracy: 0.9539 - val_loss: 0.2210 - val_accuracy: 0.9255
# Epoch 179/200
# 6/6 [==============================] - 0s 77ms/step - loss: 0.1503 - accuracy: 0.9476 - val_loss: 0.2324 - val_accuracy: 0.9128
# Epoch 180/200
# 6/6 [==============================] - 0s 64ms/step - loss: 0.1425 - accuracy: 0.9487 - val_loss: 0.2061 - val_accuracy: 0.9297
# Epoch 181/200
# 6/6 [==============================] - 0s 63ms/step - loss: 0.1396 - accuracy: 0.9518 - val_loss: 0.2164 - val_accuracy: 0.9212
# Epoch 182/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1461 - accuracy: 0.9437 - val_loss: 0.2211 - val_accuracy: 0.9198
# Epoch 183/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1310 - accuracy: 0.9508 - val_loss: 0.2002 - val_accuracy: 0.9353
# Epoch 184/200
# 6/6 [==============================] - 0s 56ms/step - loss: 0.1286 - accuracy: 0.9539 - val_loss: 0.2096 - val_accuracy: 0.9297
# Epoch 185/200
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1311 - accuracy: 0.9543 - val_loss: 0.2080 - val_accuracy: 0.9339
# Epoch 186/200
# 6/6 [==============================] - 0s 61ms/step - loss: 0.1352 - accuracy: 0.9466 - val_loss: 0.2226 - val_accuracy: 0.9170
# Epoch 187/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1332 - accuracy: 0.9522 - val_loss: 0.2131 - val_accuracy: 0.9297
# Epoch 188/200
# 6/6 [==============================] - 0s 69ms/step - loss: 0.1258 - accuracy: 0.9564 - val_loss: 0.2021 - val_accuracy: 0.9283
# Epoch 189/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1188 - accuracy: 0.9582 - val_loss: 0.1976 - val_accuracy: 0.9353
# Epoch 190/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1282 - accuracy: 0.9543 - val_loss: 0.2016 - val_accuracy: 0.9353
# Epoch 191/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1281 - accuracy: 0.9522 - val_loss: 0.2138 - val_accuracy: 0.9297
# Epoch 192/200
# 6/6 [==============================] - 0s 62ms/step - loss: 0.1277 - accuracy: 0.9532 - val_loss: 0.2222 - val_accuracy: 0.9297
# Epoch 193/200
# 6/6 [==============================] - 0s 73ms/step - loss: 0.1260 - accuracy: 0.9529 - val_loss: 0.2157 - val_accuracy: 0.9156
# Epoch 194/200
# 6/6 [==============================] - 0s 66ms/step - loss: 0.1414 - accuracy: 0.9448 - val_loss: 0.1977 - val_accuracy: 0.9381
# Epoch 195/200
# 6/6 [==============================] - 0s 67ms/step - loss: 0.1253 - accuracy: 0.9557 - val_loss: 0.2086 - val_accuracy: 0.9367
# Epoch 196/200
# 6/6 [==============================] - 0s 82ms/step - loss: 0.1314 - accuracy: 0.9515 - val_loss: 0.2006 - val_accuracy: 0.9367
# Epoch 197/200
# 6/6 [==============================] - 0s 65ms/step - loss: 0.1291 - accuracy: 0.9532 - val_loss: 0.2026 - val_accuracy: 0.9311
# Epoch 198/200
# 6/6 [==============================] - 0s 60ms/step - loss: 0.1239 - accuracy: 0.9543 - val_loss: 0.2312 - val_accuracy: 0.9198
# Epoch 199/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1183 - accuracy: 0.9592 - val_loss: 0.2416 - val_accuracy: 0.9156
# Epoch 200/200
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1347 - accuracy: 0.9476 - val_loss: 0.2058 - val_accuracy: 0.9353

# %%
plot_loss_history(CNNmodel0)

# %%
cnn0 = CNN_Model(cube_std0_3d.shape[2], filtersize)
cnn0.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodel0 = cnn0.fit({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0, 
                     validation_data=({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0),
                     epochs=70, batch_size=512)
# Out:
# Epoch 1/70
# 6/6 [==============================] - 0s 79ms/step - loss: 1.6029 - accuracy: 0.4350 - val_loss: 1.1538 - val_accuracy: 0.6231
# Epoch 2/70
# 6/6 [==============================] - 0s 65ms/step - loss: 1.0961 - accuracy: 0.6181 - val_loss: 0.9297 - val_accuracy: 0.6962
# Epoch 3/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.8864 - accuracy: 0.6695 - val_loss: 0.8231 - val_accuracy: 0.7060
# Epoch 4/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.7522 - accuracy: 0.7152 - val_loss: 0.7363 - val_accuracy: 0.6892
# Epoch 5/70
# 6/6 [==============================] - 0s 66ms/step - loss: 0.6953 - accuracy: 0.7159 - val_loss: 0.6924 - val_accuracy: 0.7384
# Epoch 6/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.6660 - accuracy: 0.7194 - val_loss: 0.6207 - val_accuracy: 0.7693
# Epoch 7/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.6231 - accuracy: 0.7373 - val_loss: 0.6238 - val_accuracy: 0.7511
# Epoch 8/70
# 6/6 [==============================] - 0s 53ms/step - loss: 0.6049 - accuracy: 0.7444 - val_loss: 0.6382 - val_accuracy: 0.7468
# Epoch 9/70
# 6/6 [==============================] - 0s 52ms/step - loss: 0.5571 - accuracy: 0.7795 - val_loss: 0.5759 - val_accuracy: 0.7848
# Epoch 10/70
# 6/6 [==============================] - 0s 71ms/step - loss: 0.5286 - accuracy: 0.7859 - val_loss: 0.5526 - val_accuracy: 0.7750
# Epoch 11/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.5253 - accuracy: 0.7911 - val_loss: 0.5376 - val_accuracy: 0.8003
# Epoch 12/70
# 6/6 [==============================] - 0s 59ms/step - loss: 0.5057 - accuracy: 0.8003 - val_loss: 0.5475 - val_accuracy: 0.7904
# Epoch 13/70
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4987 - accuracy: 0.8077 - val_loss: 0.5152 - val_accuracy: 0.8200
# Epoch 14/70
# 6/6 [==============================] - 0s 50ms/step - loss: 0.4838 - accuracy: 0.8112 - val_loss: 0.5147 - val_accuracy: 0.8158
# Epoch 15/70
# 6/6 [==============================] - 0s 53ms/step - loss: 0.4803 - accuracy: 0.8066 - val_loss: 0.5039 - val_accuracy: 0.8242
# Epoch 16/70
# 6/6 [==============================] - 0s 52ms/step - loss: 0.4627 - accuracy: 0.8270 - val_loss: 0.4842 - val_accuracy: 0.8186
# Epoch 17/70
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4453 - accuracy: 0.8340 - val_loss: 0.4931 - val_accuracy: 0.8115
# Epoch 18/70
# 6/6 [==============================] - 0s 51ms/step - loss: 0.4364 - accuracy: 0.8319 - val_loss: 0.5108 - val_accuracy: 0.8186
# Epoch 19/70
# 6/6 [==============================] - 0s 59ms/step - loss: 0.4395 - accuracy: 0.8358 - val_loss: 0.4859 - val_accuracy: 0.8284
# Epoch 20/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.4312 - accuracy: 0.8368 - val_loss: 0.4520 - val_accuracy: 0.8368
# Epoch 21/70
# 6/6 [==============================] - 0s 73ms/step - loss: 0.4132 - accuracy: 0.8421 - val_loss: 0.4630 - val_accuracy: 0.8172
# Epoch 22/70
# 6/6 [==============================] - 0s 55ms/step - loss: 0.4106 - accuracy: 0.8449 - val_loss: 0.4864 - val_accuracy: 0.8129
# Epoch 23/70
# 6/6 [==============================] - 0s 66ms/step - loss: 0.4442 - accuracy: 0.8161 - val_loss: 0.5041 - val_accuracy: 0.8256
# Epoch 24/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.4105 - accuracy: 0.8470 - val_loss: 0.4430 - val_accuracy: 0.8298
# Epoch 25/70
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3952 - accuracy: 0.8534 - val_loss: 0.4243 - val_accuracy: 0.8495
# Epoch 26/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3868 - accuracy: 0.8565 - val_loss: 0.4183 - val_accuracy: 0.8509
# Epoch 27/70
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3814 - accuracy: 0.8513 - val_loss: 0.4339 - val_accuracy: 0.8481
# Epoch 28/70
# 6/6 [==============================] - 0s 53ms/step - loss: 0.3833 - accuracy: 0.8551 - val_loss: 0.4628 - val_accuracy: 0.8326
# Epoch 29/70
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3785 - accuracy: 0.8576 - val_loss: 0.4174 - val_accuracy: 0.8537
# Epoch 30/70
# 6/6 [==============================] - 0s 62ms/step - loss: 0.3667 - accuracy: 0.8671 - val_loss: 0.4066 - val_accuracy: 0.8579
# Epoch 31/70
# 6/6 [==============================] - 0s 60ms/step - loss: 0.3574 - accuracy: 0.8692 - val_loss: 0.3989 - val_accuracy: 0.8650
# Epoch 32/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3588 - accuracy: 0.8629 - val_loss: 0.3972 - val_accuracy: 0.8636
# Epoch 33/70
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3656 - accuracy: 0.8579 - val_loss: 0.4117 - val_accuracy: 0.8481
# Epoch 34/70
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3648 - accuracy: 0.8601 - val_loss: 0.4124 - val_accuracy: 0.8565
# Epoch 35/70
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3537 - accuracy: 0.8674 - val_loss: 0.3951 - val_accuracy: 0.8523
# Epoch 36/70
# 6/6 [==============================] - 0s 49ms/step - loss: 0.3393 - accuracy: 0.8773 - val_loss: 0.3842 - val_accuracy: 0.8734
# Epoch 37/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3434 - accuracy: 0.8695 - val_loss: 0.3800 - val_accuracy: 0.8720
# Epoch 38/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3385 - accuracy: 0.8755 - val_loss: 0.3748 - val_accuracy: 0.8706
# Epoch 39/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3318 - accuracy: 0.8769 - val_loss: 0.3671 - val_accuracy: 0.8776
# Epoch 40/70
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3251 - accuracy: 0.8780 - val_loss: 0.3864 - val_accuracy: 0.8636
# Epoch 41/70
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3199 - accuracy: 0.8776 - val_loss: 0.3627 - val_accuracy: 0.8819
# Epoch 42/70
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3133 - accuracy: 0.8840 - val_loss: 0.3720 - val_accuracy: 0.8748
# Epoch 43/70
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3088 - accuracy: 0.8850 - val_loss: 0.3758 - val_accuracy: 0.8622
# Epoch 44/70
# 6/6 [==============================] - 0s 59ms/step - loss: 0.3176 - accuracy: 0.8812 - val_loss: 0.3551 - val_accuracy: 0.8776
# Epoch 45/70
# 6/6 [==============================] - 0s 51ms/step - loss: 0.3161 - accuracy: 0.8850 - val_loss: 0.3578 - val_accuracy: 0.8748
# Epoch 46/70
# 6/6 [==============================] - 0s 68ms/step - loss: 0.3073 - accuracy: 0.8910 - val_loss: 0.4065 - val_accuracy: 0.8523
# Epoch 47/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.3163 - accuracy: 0.8780 - val_loss: 0.3527 - val_accuracy: 0.8790
# Epoch 48/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.3028 - accuracy: 0.8864 - val_loss: 0.3613 - val_accuracy: 0.8706
# Epoch 49/70
# 6/6 [==============================] - 0s 70ms/step - loss: 0.3057 - accuracy: 0.8896 - val_loss: 0.3412 - val_accuracy: 0.8819
# Epoch 50/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2972 - accuracy: 0.8896 - val_loss: 0.3353 - val_accuracy: 0.8833
# Epoch 51/70
# 6/6 [==============================] - 0s 58ms/step - loss: 0.2960 - accuracy: 0.8910 - val_loss: 0.3600 - val_accuracy: 0.8706
# Epoch 52/70
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2944 - accuracy: 0.8889 - val_loss: 0.3310 - val_accuracy: 0.8903
# Epoch 53/70
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2862 - accuracy: 0.8984 - val_loss: 0.3299 - val_accuracy: 0.8917
# Epoch 54/70
# 6/6 [==============================] - 0s 54ms/step - loss: 0.2899 - accuracy: 0.8942 - val_loss: 0.3554 - val_accuracy: 0.8692
# Epoch 55/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2859 - accuracy: 0.8896 - val_loss: 0.3479 - val_accuracy: 0.8734
# Epoch 56/70
# 6/6 [==============================] - 0s 56ms/step - loss: 0.2933 - accuracy: 0.8942 - val_loss: 0.3375 - val_accuracy: 0.8762
# Epoch 57/70
# 6/6 [==============================] - 0s 57ms/step - loss: 0.2737 - accuracy: 0.8998 - val_loss: 0.3350 - val_accuracy: 0.8847
# Epoch 58/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2830 - accuracy: 0.8980 - val_loss: 0.3607 - val_accuracy: 0.8734
# Epoch 59/70
# 6/6 [==============================] - 0s 65ms/step - loss: 0.2860 - accuracy: 0.9015 - val_loss: 0.3415 - val_accuracy: 0.8776
# Epoch 60/70
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2820 - accuracy: 0.8921 - val_loss: 0.3284 - val_accuracy: 0.8790
# Epoch 61/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2780 - accuracy: 0.8998 - val_loss: 0.3335 - val_accuracy: 0.8776
# Epoch 62/70
# 6/6 [==============================] - 0s 67ms/step - loss: 0.2728 - accuracy: 0.9044 - val_loss: 0.3140 - val_accuracy: 0.9015
# Epoch 63/70
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2622 - accuracy: 0.9058 - val_loss: 0.3366 - val_accuracy: 0.8833
# Epoch 64/70
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2619 - accuracy: 0.9058 - val_loss: 0.3157 - val_accuracy: 0.8931
# Epoch 65/70
# 6/6 [==============================] - 0s 59ms/step - loss: 0.2755 - accuracy: 0.9015 - val_loss: 0.3323 - val_accuracy: 0.8889
# Epoch 66/70
# 6/6 [==============================] - 0s 66ms/step - loss: 0.2646 - accuracy: 0.9037 - val_loss: 0.3135 - val_accuracy: 0.8819
# Epoch 67/70
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2645 - accuracy: 0.8998 - val_loss: 0.3137 - val_accuracy: 0.8959
# Epoch 68/70
# 6/6 [==============================] - 0s 74ms/step - loss: 0.2601 - accuracy: 0.9072 - val_loss: 0.3107 - val_accuracy: 0.8987
# Epoch 69/70
# 6/6 [==============================] - 0s 62ms/step - loss: 0.2631 - accuracy: 0.9086 - val_loss: 0.2997 - val_accuracy: 0.8973
# Epoch 70/70
# 6/6 [==============================] - 0s 64ms/step - loss: 0.2655 - accuracy: 0.9023 - val_loss: 0.3352 - val_accuracy: 0.8762

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnn0.evaluate({"spectra":cube_train02, "spatial":xy_train0}, cube_train_labels0)
test_loss, test_acc = cnn0.evaluate({"spectra":cube_test02, "spatial":xy_test0}, cube_test_labels0)

print(train_acc, test_acc)
# Out:
# 89/89 [==============================] - 0s 6ms/step - loss: 0.2349 - accuracy: 0.9121
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3352 - accuracy: 0.8762
# 0.9120956659317017 0.8762306571006775

# %% [markdown]
# ### Predict pixel classification on veg_00000

# %%
cube_standard0_1 = cube_standard0.reshape(cube_standard0.shape[0], cube_standard0.shape[1], 1)
print(cube_standard0_1.shape)
xy0_2d = xy0.reshape((xy0.shape[0] * xy0.shape[1]), xy0.shape[2])
print(xy0_2d.shape)
# Out:
# (2560000, 212, 1)
# (2560000, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCube0 = cnn0.predict({"spectra":cube_standard0_1, "spatial":xy0_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:06:59

# %%
predictCube0 = probCube0.argmax(axis=-1)

# %%
predictCube_reshape0 = predictCube0.reshape(cube_sub0.shape[1], cube_sub0.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.5)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_3_000_predict_map.png", 
#bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshape0])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.5)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshape0, 
            open("./plots/CNN_Model2_spatial_train_000_binned_{0}_test_000_predict_map.pickle".format(num_of_bins), "wb"))

# %%
wtr_coords0=np.array([[0,0]])

# %% [markdown]
# ### Evaluation Metrics (veg_00000)

# %%
labels0_pred_sky = predictCube_reshape0[sky_coords0[sky_test_ind0[:], 0], sky_coords0[sky_test_ind0[:], 1]]
labels0_pred_clouds = predictCube_reshape0[clouds_coords0[clouds_test_ind0[:], 0], clouds_coords0[clouds_test_ind0[:],1]]
labels0_pred_veg = predictCube_reshape0[veg_coords0[veg_test_ind0[:],0], veg_coords0[veg_test_ind0[:],1]]
#labels0_pred_wtr = predictCube_reshape0[wtr_coords0[wtr_test_ind0[:],0], wtr_coords0[wtr_test_ind0[:],1]]
labels0_pred_blt = predictCube_reshape0[blt_coords0[blt_test_ind0[:],0], blt_coords0[blt_test_ind0[:],1]]
labels0_pred_windows = predictCube_reshape0[windows_coords0[windows_test_ind0[:],0], windows_coords0[windows_test_ind0[:],1]]
labels0_pred_rds = predictCube_reshape0[rds_coords0[rds_test_ind0[:],0], rds_coords0[rds_test_ind0[:],1]]
labels0_pred_cars = predictCube_reshape0[cars_coords0[cars_test_ind0[:],0], cars_coords0[cars_test_ind0[:],1]]
labels0_pred_mtl = predictCube_reshape0[mtl_coords0[mtl_test_ind0[:],0], mtl_coords0[mtl_test_ind0[:],1]]

labels0_pred = np.concatenate((labels0_pred_sky, labels0_pred_clouds, labels0_pred_veg, #labels0_pred_wtr, 
                             labels0_pred_blt, labels0_pred_windows, labels0_pred_rds, 
                               labels0_pred_cars, labels0_pred_mtl))

# %%
labels0_true_sky = np.full(len(sky_test_ind0), 0)
labels0_true_clouds = np.full(len(clouds_test_ind0), 1)
labels0_true_veg = np.full(len(veg_test_ind0), 2)
#labels0_true_wtr = np.full(len(wtr_test_ind0), 3)
labels0_true_blt = np.full(len(blt_test_ind0), 4)
labels0_true_windows = np.full(len(windows_test_ind0), 5)
labels0_true_rds = np.full(len(rds_test_ind0), 6)
labels0_true_cars = np.full(len(cars_test_ind0), 7)
labels0_true_mtl = np.full(len(mtl_test_ind0), 8)

labels0_true = np.concatenate((labels0_true_sky, labels0_true_clouds, labels0_true_veg, #labels0_true_wtr, 
                             labels0_true_blt, labels0_true_windows, labels0_true_rds, labels0_true_cars, labels0_true_mtl))

# %%
print(labels0_pred.shape)
print(labels0_true.shape)
# Out:
# (711,)
# (711,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labels0_true, labels0_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labels0_true, labels0_pred))

target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 80   0   0   0   0   0   0   0]
#  [  0 100   0   0   0   0   0   0]
#  [  0   0 119   3   0   0   0   0]
#  [  0   0   0 235   3   0   0   2]
#  [  0   0   0  39  55   0   0   6]
#  [  0   0   0   0   0  12   0   0]
#  [  3   0   0   0   0   2   6   0]
#  [  0   0   0  29   0   1   0  16]]
#
# Accuracy Score
# 0.8762306610407876
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       0.96      1.00      0.98        80
#      clouds       1.00      1.00      1.00       100
#  vegetation       1.00      0.98      0.99       122
#       built       0.77      0.98      0.86       240
#     windows       0.95      0.55      0.70       100
#       roads       0.80      1.00      0.89        12
#        cars       1.00      0.55      0.71        11
#       metal       0.67      0.35      0.46        46
#
# avg / total       0.89      0.88      0.86       711

# %%
f = open("./metrics/CNN_Model2_spatial_train_000_binned_{0}_test_000_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labels0_true, labels0_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labels0_true, labels0_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labels0_true, labels0_pred, target_names=target_names))
f.close()

# %% [markdown]
# ---
# ## CNN trained on North Facing Image

# %%
fname_north = "../../image_files/scan1_slow_roof_VNIR.raw"
cube_north = read_hyper(fname_north)
# Out:
# reading and parsing ../../image_files/scan1_slow_roof_VNIR.hdr...
# reading ../../image_files/scan1_slow_roof_VNIR.raw...

# %%
cube_sub_north = cube_north.data[:, :, :].astype(float)
print(cube_sub_north.shape)
# Out:
# (872, 1600, 1247)

# %%
cube_reshaped_north = cube_sub_north.transpose(1, 2, 0).reshape((cube_sub_north.shape[1] * cube_sub_north.shape[2]), cube_sub_north.shape[0])
print(cube_reshaped_north.shape)
# Out:
# (1995200, 872)

# %%
cube_standard_north = (cube_reshaped_north - cube_reshaped_north.mean(1, keepdims=True)) / cube_reshaped_north.std(1, keepdims=True)
print(cube_standard_north.shape)
# Out:
# (1995200, 872)

# %% [markdown]
# #### Reading manually classified set for training and testing

# %%
sky_coordsn = read_labelled_coordinates("1_sky", "north")
clouds_coordsn = read_labelled_coordinates("2_clouds", "north")
veg_coordsn = read_labelled_coordinates("3_vegetation", "north")
wtr_coordsn = read_labelled_coordinates("4_water", "north")
blt_coordsn = read_labelled_coordinates("5_buildings", "north")
windows_coordsn = read_labelled_coordinates("6_windows", "north")
rds_coordsn = read_labelled_coordinates("7_roads", "north")
cars_coordsn = read_labelled_coordinates("8_cars", "north")
mtl_coordsn = read_labelled_coordinates("9_metal", "north")
# Out:
# 1_sky: (300, 2)
# 2_clouds: (200, 2)
# 3_vegetation: (700, 2)
# 4_water: (620, 2)
# 5_buildings: (1600, 2)
# 6_windows: (600, 2)
# 7_roads: (250, 2)
# 8_cars: (250, 2)
# 9_metal: (185, 2)

# %%
xyn = coords(cube_sub_north.shape[1], cube_sub_north.shape[2])
xyn = xyn/xyn.max()

# %% [markdown]
# ### Bin Spectra

# %%
bin_ind = []

for i in range(0, num_of_bins):
    low_ind = int(i*int(cube_sub_north.shape[0]/num_of_bins))
    upp_ind = int(low_ind + int(cube_sub_north.shape[0]/num_of_bins))
    bin_ind.append([low_ind, upp_ind])
bin_ind[-1][-1] = cube_sub_north.shape[0]

print(len(bin_ind))
print(bin_ind)
# Out:
# 212
# [[0, 4], [4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40], [40, 44], [44, 48], [48, 52], [52, 56], [56, 60], [60, 64], [64, 68], [68, 72], [72, 76], [76, 80], [80, 84], [84, 88], [88, 92], [92, 96], [96, 100], [100, 104], [104, 108], [108, 112], [112, 116], [116, 120], [120, 124], [124, 128], [128, 132], [132, 136], [136, 140], [140, 144], [144, 148], [148, 152], [152, 156], [156, 160], [160, 164], [164, 168], [168, 172], [172, 176], [176, 180], [180, 184], [184, 188], [188, 192], [192, 196], [196, 200], [200, 204], [204, 208], [208, 212], [212, 216], [216, 220], [220, 224], [224, 228], [228, 232], [232, 236], [236, 240], [240, 244], [244, 248], [248, 252], [252, 256], [256, 260], [260, 264], [264, 268], [268, 272], [272, 276], [276, 280], [280, 284], [284, 288], [288, 292], [292, 296], [296, 300], [300, 304], [304, 308], [308, 312], [312, 316], [316, 320], [320, 324], [324, 328], [328, 332], [332, 336], [336, 340], [340, 344], [344, 348], [348, 352], [352, 356], [356, 360], [360, 364], [364, 368], [368, 372], [372, 376], [376, 380], [380, 384], [384, 388], [388, 392], [392, 396], [396, 400], [400, 404], [404, 408], [408, 412], [412, 416], [416, 420], [420, 424], [424, 428], [428, 432], [432, 436], [436, 440], [440, 444], [444, 448], [448, 452], [452, 456], [456, 460], [460, 464], [464, 468], [468, 472], [472, 476], [476, 480], [480, 484], [484, 488], [488, 492], [492, 496], [496, 500], [500, 504], [504, 508], [508, 512], [512, 516], [516, 520], [520, 524], [524, 528], [528, 532], [532, 536], [536, 540], [540, 544], [544, 548], [548, 552], [552, 556], [556, 560], [560, 564], [564, 568], [568, 572], [572, 576], [576, 580], [580, 584], [584, 588], [588, 592], [592, 596], [596, 600], [600, 604], [604, 608], [608, 612], [612, 616], [616, 620], [620, 624], [624, 628], [628, 632], [632, 636], [636, 640], [640, 644], [644, 648], [648, 652], [652, 656], [656, 660], [660, 664], [664, 668], [668, 672], [672, 676], [676, 680], [680, 684], [684, 688], [688, 692], [692, 696], [696, 700], [700, 704], [704, 708], [708, 712], [712, 716], [716, 720], [720, 724], [724, 728], [728, 732], [732, 736], [736, 740], [740, 744], [744, 748], [748, 752], [752, 756], [756, 760], [760, 764], [764, 768], [768, 772], [772, 776], [776, 780], [780, 784], [784, 788], [788, 792], [792, 796], [796, 800], [800, 804], [804, 808], [808, 812], [812, 816], [816, 820], [820, 824], [824, 828], [828, 832], [832, 836], [836, 840], [840, 844], [844, 872]]

# %%
cube_binnedn = np.zeros(shape=(cube_standard_north.shape[0], num_of_bins))

for i in range(num_of_bins):
    cube_binnedn[:, i] = cube_standard_north[:, bin_ind[i][0]:bin_ind[i][1]].mean(1)

print(cube_binnedn.shape)
# Out:
# (1995200, 212)

# %%
cube_standard_north = cube_binnedn
print(cube_standard_north.shape)
# Out:
# (1995200, 212)

# %% [markdown]
# #### split classified pixels into 80% training and 20% testing sets

# %%
trrat = 0.8
sky_train_indn, sky_test_indn = split_train_test_indices(sky_coordsn, 100, trrat, "sky")
clouds_train_indn, clouds_test_indn = split_train_test_indices(clouds_coordsn, 200, trrat, "clouds")
veg_train_indn, veg_test_indn = split_train_test_indices(veg_coordsn, 300, trrat, "veg")
wtr_train_indn, wtr_test_indn = split_train_test_indices(wtr_coordsn, 400, trrat, "wtr")
blt_train_indn, blt_test_indn = split_train_test_indices(blt_coordsn, 500, trrat, "blt")
windows_train_indn, windows_test_indn = split_train_test_indices(windows_coordsn, 600, trrat, "windows")
rds_train_indn, rds_test_indn = split_train_test_indices(rds_coordsn, 700, trrat, "rds")
cars_train_indn, cars_test_indn = split_train_test_indices(cars_coordsn, 800, trrat, "cars")
mtl_train_indn, mtl_test_indn = split_train_test_indices(mtl_coordsn, 900, trrat, "mtl")
# Out:
# sky: 240 60
# clouds: 160 40
# veg: 560 140
# wtr: 496 124
# blt: 1280 320
# windows: 480 120
# rds: 200 50
# cars: 200 50
# mtl: 148 37

# %%
cube_stdn_3d = cube_standard_north.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2], num_of_bins)
print(cube_stdn_3d.shape)
print(xyn.shape)
# Out:
# (1600, 1247, 212)
# (1600, 1247, 2)

# %%
cube_sky_trainn = cube_stdn_3d[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
cube_sky_testn = cube_stdn_3d[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
sky_xy_trainn = xyn[sky_coordsn[sky_train_indn[:], 0], sky_coordsn[sky_train_indn[:], 1], :]
sky_xy_testn = xyn[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1], :]
print("sky ", cube_sky_trainn.shape, cube_sky_testn.shape)

cube_clouds_trainn = cube_stdn_3d[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
cube_clouds_testn = cube_stdn_3d[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
clouds_xy_trainn = xyn[clouds_coordsn[clouds_train_indn[:], 0], clouds_coordsn[clouds_train_indn[:], 1], :]
clouds_xy_testn = xyn[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:], 1], :]
print("clouds ", cube_clouds_trainn.shape, cube_clouds_testn.shape)

cube_veg_trainn = cube_stdn_3d[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
cube_veg_testn = cube_stdn_3d[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
veg_xy_trainn = xyn[veg_coordsn[veg_train_indn[:], 0], veg_coordsn[veg_train_indn[:], 1], :]
veg_xy_testn = xyn[veg_coordsn[veg_test_indn[:], 0], veg_coordsn[veg_test_indn[:], 1], :]
print("vegetation ", cube_veg_trainn.shape, cube_veg_testn.shape)

cube_wtr_trainn = cube_stdn_3d[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
cube_wtr_testn = cube_stdn_3d[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
wtr_xy_trainn = xyn[wtr_coordsn[wtr_train_indn[:], 0], wtr_coordsn[wtr_train_indn[:], 1], :]
wtr_xy_testn = xyn[wtr_coordsn[wtr_test_indn[:], 0], wtr_coordsn[wtr_test_indn[:], 1], :]
print("water ", cube_wtr_trainn.shape, cube_wtr_testn.shape)

cube_blt_trainn = cube_stdn_3d[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
cube_blt_testn = cube_stdn_3d[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
blt_xy_trainn = xyn[blt_coordsn[blt_train_indn[:], 0], blt_coordsn[blt_train_indn[:], 1], :]
blt_xy_testn = xyn[blt_coordsn[blt_test_indn[:], 0], blt_coordsn[blt_test_indn[:], 1], :]
print("built ", cube_blt_trainn.shape, cube_blt_testn.shape)

cube_windows_trainn = cube_stdn_3d[windows_coordsn[windows_train_indn[:],0], windows_coordsn[windows_train_indn[:],1],:]
cube_windows_testn = cube_stdn_3d[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
windows_xy_trainn = xyn[windows_coordsn[windows_train_indn[:], 0], windows_coordsn[windows_train_indn[:], 1], :]
windows_xy_testn = xyn[windows_coordsn[windows_test_indn[:], 0], windows_coordsn[windows_test_indn[:], 1], :]
print("windows ", cube_windows_trainn.shape, cube_windows_testn.shape)

cube_rds_trainn = cube_stdn_3d[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
cube_rds_testn = cube_stdn_3d[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
rds_xy_trainn = xyn[rds_coordsn[rds_train_indn[:], 0], rds_coordsn[rds_train_indn[:], 1], :]
rds_xy_testn = xyn[rds_coordsn[rds_test_indn[:], 0], rds_coordsn[rds_test_indn[:], 1], :]
print("roads ", cube_rds_trainn.shape, cube_rds_testn.shape)

cube_cars_trainn = cube_stdn_3d[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cube_cars_testn = cube_stdn_3d[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
cars_xy_trainn = xyn[cars_coordsn[cars_train_indn[:], 0], cars_coordsn[cars_train_indn[:], 1], :]
cars_xy_testn = xyn[cars_coordsn[cars_test_indn[:], 0], cars_coordsn[cars_test_indn[:], 1], :]
print("cars ", cube_cars_trainn.shape, cube_cars_testn.shape)

cube_mtl_trainn = cube_stdn_3d[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
cube_mtl_testn = cube_stdn_3d[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
mtl_xy_trainn = xyn[mtl_coordsn[mtl_train_indn[:], 0], mtl_coordsn[mtl_train_indn[:], 1], :]
mtl_xy_testn = xyn[mtl_coordsn[mtl_test_indn[:], 0], mtl_coordsn[mtl_test_indn[:], 1], :]
print("metal ", cube_mtl_trainn.shape, cube_mtl_testn.shape)
# Out:
# sky  (240, 212) (60, 212)
# clouds  (160, 212) (40, 212)
# vegetation  (560, 212) (140, 212)
# water  (496, 212) (124, 212)
# built  (1280, 212) (320, 212)
# windows  (480, 212) (120, 212)
# roads  (200, 212) (50, 212)
# cars  (200, 212) (50, 212)
# metal  (148, 212) (37, 212)

# %%
# concatenate training and testing sets and create index arrays

cube_trainn = np.concatenate((cube_sky_trainn, cube_clouds_trainn, cube_veg_trainn, cube_wtr_trainn, cube_blt_trainn, 
                            cube_windows_trainn, cube_rds_trainn, cube_cars_trainn, cube_mtl_trainn), axis=0)
cube_train_labelsn = [0]*cube_sky_trainn.shape[0] + [1]*cube_clouds_trainn.shape[0] \
                    + [2]*cube_veg_trainn.shape[0] + [3]*cube_wtr_trainn.shape[0] + [4]*cube_blt_trainn.shape[0] \
                    + [5]*cube_windows_trainn.shape[0] + [6]*cube_rds_trainn.shape[0] \
                    + [7]*cube_cars_trainn.shape[0] + [8]*cube_mtl_trainn.shape[0]
xy_trainn = np.concatenate((sky_xy_trainn, clouds_xy_trainn, veg_xy_trainn, wtr_xy_trainn, blt_xy_trainn,
                             windows_xy_trainn, rds_xy_trainn, cars_xy_trainn, mtl_xy_trainn), axis=0)

cube_testn = np.concatenate((cube_sky_testn, cube_clouds_testn, cube_veg_testn, cube_wtr_testn, cube_blt_testn, 
                            cube_windows_testn, cube_rds_testn, cube_cars_testn, cube_mtl_testn), axis=0)
cube_test_labelsn = [0]*cube_sky_testn.shape[0] + [1]*cube_clouds_testn.shape[0] \
                    + [2]*cube_veg_testn.shape[0] + [3]*cube_wtr_testn.shape[0] + [4]*cube_blt_testn.shape[0] \
                    + [5]*cube_windows_testn.shape[0] + [6]*cube_rds_testn.shape[0] \
                    + [7]*cube_cars_testn.shape[0] + [8]*cube_mtl_testn.shape[0]
xy_testn = np.concatenate((sky_xy_testn, clouds_xy_testn, veg_xy_testn, wtr_xy_testn, blt_xy_testn, 
                             windows_xy_testn, rds_xy_testn, cars_xy_testn, mtl_xy_testn), axis=0)

# %%
cube_train_labelsn = np.array(cube_train_labelsn)
cube_test_labelsn = np.array(cube_test_labelsn)

print(cube_trainn.shape, cube_train_labelsn.shape, xy_trainn.shape)
print(cube_testn.shape, cube_test_labelsn.shape, xy_testn.shape)
# Out:
# (3764, 212) (3764,) (3764, 2)
# (941, 212) (941,) (941, 2)

# %% [markdown]
# #### Train CNN

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])

# %%
#keras.utils.plot_model(cnnn, show_shapes=True)
#cnnn.summary()

cube_trainn2 = cube_trainn.reshape(cube_trainn.shape[0], cube_trainn.shape[1], 1)
cube_testn2 = cube_testn.reshape(cube_testn.shape[0], cube_testn.shape[1], 1)

# %%
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=200, batch_size=512)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 69ms/step - loss: 1.7344 - accuracy: 0.3945 - val_loss: 1.4298 - val_accuracy: 0.5069
# Epoch 2/200
# 8/8 [==============================] - 0s 53ms/step - loss: 1.3729 - accuracy: 0.5138 - val_loss: 1.2630 - val_accuracy: 0.5590
# Epoch 3/200
# 8/8 [==============================] - 0s 50ms/step - loss: 1.2172 - accuracy: 0.5717 - val_loss: 1.1127 - val_accuracy: 0.6057
# Epoch 4/200
# 8/8 [==============================] - 0s 56ms/step - loss: 1.0943 - accuracy: 0.6063 - val_loss: 1.0342 - val_accuracy: 0.5813
# Epoch 5/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.9981 - accuracy: 0.6411 - val_loss: 0.9194 - val_accuracy: 0.7184
# Epoch 6/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.9266 - accuracy: 0.6958 - val_loss: 0.8637 - val_accuracy: 0.7173
# Epoch 7/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.8570 - accuracy: 0.7261 - val_loss: 0.8124 - val_accuracy: 0.7078
# Epoch 8/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.8151 - accuracy: 0.7181 - val_loss: 0.7464 - val_accuracy: 0.7343
# Epoch 9/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.7593 - accuracy: 0.7426 - val_loss: 0.7066 - val_accuracy: 0.7885
# Epoch 10/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.7353 - accuracy: 0.7543 - val_loss: 0.6868 - val_accuracy: 0.7875
# Epoch 11/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.7115 - accuracy: 0.7495 - val_loss: 0.6791 - val_accuracy: 0.7991
# Epoch 12/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.6877 - accuracy: 0.7614 - val_loss: 0.6341 - val_accuracy: 0.7970
# Epoch 13/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.6721 - accuracy: 0.7673 - val_loss: 0.6320 - val_accuracy: 0.8045
# Epoch 14/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.6558 - accuracy: 0.7755 - val_loss: 0.6158 - val_accuracy: 0.7960
# Epoch 15/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.6399 - accuracy: 0.7784 - val_loss: 0.5927 - val_accuracy: 0.8045
# Epoch 16/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.6281 - accuracy: 0.7856 - val_loss: 0.5731 - val_accuracy: 0.8225
# Epoch 17/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.6033 - accuracy: 0.7891 - val_loss: 0.5672 - val_accuracy: 0.8098
# Epoch 18/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5878 - accuracy: 0.7986 - val_loss: 0.5623 - val_accuracy: 0.8034
# Epoch 19/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.5754 - accuracy: 0.8010 - val_loss: 0.5668 - val_accuracy: 0.8289
# Epoch 20/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.5726 - accuracy: 0.8061 - val_loss: 0.5269 - val_accuracy: 0.8438
# Epoch 21/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5509 - accuracy: 0.8127 - val_loss: 0.5245 - val_accuracy: 0.8278
# Epoch 22/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5431 - accuracy: 0.8111 - val_loss: 0.5086 - val_accuracy: 0.8374
# Epoch 23/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5328 - accuracy: 0.8191 - val_loss: 0.5088 - val_accuracy: 0.8374
# Epoch 24/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.5299 - accuracy: 0.8201 - val_loss: 0.5372 - val_accuracy: 0.8363
# Epoch 25/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.5389 - accuracy: 0.8172 - val_loss: 0.5098 - val_accuracy: 0.8502
# Epoch 26/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.5272 - accuracy: 0.8183 - val_loss: 0.4841 - val_accuracy: 0.8491
# Epoch 27/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4957 - accuracy: 0.8361 - val_loss: 0.5763 - val_accuracy: 0.8045
# Epoch 28/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.5272 - accuracy: 0.8255 - val_loss: 0.4855 - val_accuracy: 0.8597
# Epoch 29/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4919 - accuracy: 0.8350 - val_loss: 0.4619 - val_accuracy: 0.8587
# Epoch 30/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4856 - accuracy: 0.8321 - val_loss: 0.4525 - val_accuracy: 0.8597
# Epoch 31/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4866 - accuracy: 0.8348 - val_loss: 0.4663 - val_accuracy: 0.8491
# Epoch 32/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4881 - accuracy: 0.8332 - val_loss: 0.4639 - val_accuracy: 0.8565
# Epoch 33/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4593 - accuracy: 0.8488 - val_loss: 0.4590 - val_accuracy: 0.8502
# Epoch 34/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4656 - accuracy: 0.8459 - val_loss: 0.4396 - val_accuracy: 0.8789
# Epoch 35/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.4497 - accuracy: 0.8512 - val_loss: 0.4449 - val_accuracy: 0.8650
# Epoch 36/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4388 - accuracy: 0.8565 - val_loss: 0.4368 - val_accuracy: 0.8693
# Epoch 37/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4287 - accuracy: 0.8595 - val_loss: 0.4330 - val_accuracy: 0.8810
# Epoch 38/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4427 - accuracy: 0.8589 - val_loss: 0.4195 - val_accuracy: 0.8852
# Epoch 39/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4302 - accuracy: 0.8656 - val_loss: 0.4143 - val_accuracy: 0.8650
# Epoch 40/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.4238 - accuracy: 0.8549 - val_loss: 0.4012 - val_accuracy: 0.8863
# Epoch 41/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.4000 - accuracy: 0.8685 - val_loss: 0.4090 - val_accuracy: 0.8735
# Epoch 42/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.4062 - accuracy: 0.8672 - val_loss: 0.3970 - val_accuracy: 0.8905
# Epoch 43/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3990 - accuracy: 0.8688 - val_loss: 0.3852 - val_accuracy: 0.8895
# Epoch 44/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3897 - accuracy: 0.8775 - val_loss: 0.3850 - val_accuracy: 0.8948
# Epoch 45/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3861 - accuracy: 0.8738 - val_loss: 0.3851 - val_accuracy: 0.8884
# Epoch 46/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3788 - accuracy: 0.8762 - val_loss: 0.3731 - val_accuracy: 0.8948
# Epoch 47/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3790 - accuracy: 0.8754 - val_loss: 0.3901 - val_accuracy: 0.8959
# Epoch 48/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3919 - accuracy: 0.8706 - val_loss: 0.3818 - val_accuracy: 0.8820
# Epoch 49/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3838 - accuracy: 0.8746 - val_loss: 0.3693 - val_accuracy: 0.9022
# Epoch 50/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3703 - accuracy: 0.8775 - val_loss: 0.3769 - val_accuracy: 0.8937
# Epoch 51/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3686 - accuracy: 0.8775 - val_loss: 0.4005 - val_accuracy: 0.8820
# Epoch 52/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3997 - accuracy: 0.8688 - val_loss: 0.3795 - val_accuracy: 0.8905
# Epoch 53/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3712 - accuracy: 0.8828 - val_loss: 0.3693 - val_accuracy: 0.8948
# Epoch 54/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3541 - accuracy: 0.8855 - val_loss: 0.3753 - val_accuracy: 0.8980
# Epoch 55/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3583 - accuracy: 0.8839 - val_loss: 0.3824 - val_accuracy: 0.8980
# Epoch 56/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3588 - accuracy: 0.8765 - val_loss: 0.3654 - val_accuracy: 0.8927
# Epoch 57/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.3519 - accuracy: 0.8916 - val_loss: 0.3544 - val_accuracy: 0.9044
# Epoch 58/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.3501 - accuracy: 0.8882 - val_loss: 0.3637 - val_accuracy: 0.8959
# Epoch 59/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3416 - accuracy: 0.8889 - val_loss: 0.3628 - val_accuracy: 0.8948
# Epoch 60/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.3344 - accuracy: 0.8897 - val_loss: 0.3783 - val_accuracy: 0.8916
# Epoch 61/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3422 - accuracy: 0.8956 - val_loss: 0.3626 - val_accuracy: 0.9012
# Epoch 62/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3290 - accuracy: 0.8919 - val_loss: 0.3557 - val_accuracy: 0.8927
# Epoch 63/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3169 - accuracy: 0.8959 - val_loss: 0.3355 - val_accuracy: 0.9044
# Epoch 64/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3155 - accuracy: 0.8959 - val_loss: 0.3379 - val_accuracy: 0.9033
# Epoch 65/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3191 - accuracy: 0.8953 - val_loss: 0.3413 - val_accuracy: 0.9033
# Epoch 66/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3090 - accuracy: 0.9017 - val_loss: 0.3349 - val_accuracy: 0.9044
# Epoch 67/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3100 - accuracy: 0.9004 - val_loss: 0.3355 - val_accuracy: 0.9054
# Epoch 68/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.3004 - accuracy: 0.9052 - val_loss: 0.3382 - val_accuracy: 0.9012
# Epoch 69/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3007 - accuracy: 0.9060 - val_loss: 0.3394 - val_accuracy: 0.9012
# Epoch 70/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2980 - accuracy: 0.9044 - val_loss: 0.3662 - val_accuracy: 0.8916
# Epoch 71/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.3109 - accuracy: 0.8953 - val_loss: 0.3424 - val_accuracy: 0.9001
# Epoch 72/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.3114 - accuracy: 0.8959 - val_loss: 0.3387 - val_accuracy: 0.9001
# Epoch 73/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.3014 - accuracy: 0.9025 - val_loss: 0.3419 - val_accuracy: 0.9012
# Epoch 74/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2921 - accuracy: 0.9097 - val_loss: 0.3209 - val_accuracy: 0.9086
# Epoch 75/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2867 - accuracy: 0.9065 - val_loss: 0.3216 - val_accuracy: 0.9097
# Epoch 76/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2825 - accuracy: 0.9049 - val_loss: 0.3300 - val_accuracy: 0.9065
# Epoch 77/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2865 - accuracy: 0.9073 - val_loss: 0.3284 - val_accuracy: 0.9044
# Epoch 78/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2893 - accuracy: 0.9075 - val_loss: 0.3300 - val_accuracy: 0.9044
# Epoch 79/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2857 - accuracy: 0.9078 - val_loss: 0.3244 - val_accuracy: 0.9033
# Epoch 80/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2794 - accuracy: 0.9147 - val_loss: 0.3273 - val_accuracy: 0.9107
# Epoch 81/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2826 - accuracy: 0.9083 - val_loss: 0.3198 - val_accuracy: 0.9075
# Epoch 82/200
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2749 - accuracy: 0.9107 - val_loss: 0.3142 - val_accuracy: 0.9065
# Epoch 83/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2709 - accuracy: 0.9113 - val_loss: 0.3319 - val_accuracy: 0.9097
# Epoch 84/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2704 - accuracy: 0.9129 - val_loss: 0.3209 - val_accuracy: 0.9075
# Epoch 85/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.2768 - accuracy: 0.9121 - val_loss: 0.3410 - val_accuracy: 0.9033
# Epoch 86/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2742 - accuracy: 0.9115 - val_loss: 0.3299 - val_accuracy: 0.9054
# Epoch 87/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2584 - accuracy: 0.9190 - val_loss: 0.3176 - val_accuracy: 0.9065
# Epoch 88/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2732 - accuracy: 0.9091 - val_loss: 0.3074 - val_accuracy: 0.9097
# Epoch 89/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2699 - accuracy: 0.9123 - val_loss: 0.3354 - val_accuracy: 0.9012
# Epoch 90/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2764 - accuracy: 0.9091 - val_loss: 0.3435 - val_accuracy: 0.9033
# Epoch 91/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2751 - accuracy: 0.9134 - val_loss: 0.3175 - val_accuracy: 0.9097
# Epoch 92/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2741 - accuracy: 0.9113 - val_loss: 0.3152 - val_accuracy: 0.9075
# Epoch 93/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2492 - accuracy: 0.9174 - val_loss: 0.3166 - val_accuracy: 0.9097
# Epoch 94/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2495 - accuracy: 0.9184 - val_loss: 0.3286 - val_accuracy: 0.9033
# Epoch 95/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2534 - accuracy: 0.9192 - val_loss: 0.3091 - val_accuracy: 0.9086
# Epoch 96/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2407 - accuracy: 0.9230 - val_loss: 0.3299 - val_accuracy: 0.8905
# Epoch 97/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2459 - accuracy: 0.9192 - val_loss: 0.3108 - val_accuracy: 0.9107
# Epoch 98/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2425 - accuracy: 0.9216 - val_loss: 0.2996 - val_accuracy: 0.9139
# Epoch 99/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.2395 - accuracy: 0.9182 - val_loss: 0.3024 - val_accuracy: 0.9075
# Epoch 100/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2415 - accuracy: 0.9187 - val_loss: 0.3157 - val_accuracy: 0.9001
# Epoch 101/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2436 - accuracy: 0.9232 - val_loss: 0.3048 - val_accuracy: 0.9129
# Epoch 102/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2358 - accuracy: 0.9264 - val_loss: 0.3060 - val_accuracy: 0.9086
# Epoch 103/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2338 - accuracy: 0.9243 - val_loss: 0.3383 - val_accuracy: 0.9001
# Epoch 104/200
# 8/8 [==============================] - 0s 58ms/step - loss: 0.2438 - accuracy: 0.9187 - val_loss: 0.3136 - val_accuracy: 0.9129
# Epoch 105/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.2277 - accuracy: 0.9264 - val_loss: 0.3087 - val_accuracy: 0.9129
# Epoch 106/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2343 - accuracy: 0.9219 - val_loss: 0.2943 - val_accuracy: 0.9182
# Epoch 107/200
# 8/8 [==============================] - 0s 61ms/step - loss: 0.2228 - accuracy: 0.9277 - val_loss: 0.3242 - val_accuracy: 0.9097
# Epoch 108/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2226 - accuracy: 0.9280 - val_loss: 0.3089 - val_accuracy: 0.9118
# Epoch 109/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2345 - accuracy: 0.9267 - val_loss: 0.3070 - val_accuracy: 0.9075
# Epoch 110/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2194 - accuracy: 0.9317 - val_loss: 0.2912 - val_accuracy: 0.9171
# Epoch 111/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.2207 - accuracy: 0.9296 - val_loss: 0.2925 - val_accuracy: 0.9182
# Epoch 112/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2117 - accuracy: 0.9317 - val_loss: 0.3001 - val_accuracy: 0.9118
# Epoch 113/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2109 - accuracy: 0.9309 - val_loss: 0.3118 - val_accuracy: 0.9075
# Epoch 114/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2218 - accuracy: 0.9264 - val_loss: 0.3797 - val_accuracy: 0.8820
# Epoch 115/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2822 - accuracy: 0.9038 - val_loss: 0.3175 - val_accuracy: 0.9086
# Epoch 116/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2252 - accuracy: 0.9251 - val_loss: 0.2914 - val_accuracy: 0.9118
# Epoch 117/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.2152 - accuracy: 0.9301 - val_loss: 0.2789 - val_accuracy: 0.9171
# Epoch 118/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.2216 - accuracy: 0.9256 - val_loss: 0.2958 - val_accuracy: 0.9182
# Epoch 119/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.2149 - accuracy: 0.9283 - val_loss: 0.2973 - val_accuracy: 0.9118
# Epoch 120/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2064 - accuracy: 0.9338 - val_loss: 0.3206 - val_accuracy: 0.9075
# Epoch 121/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2126 - accuracy: 0.9291 - val_loss: 0.2908 - val_accuracy: 0.9182
# Epoch 122/200
# 8/8 [==============================] - 0s 59ms/step - loss: 0.2217 - accuracy: 0.9216 - val_loss: 0.3059 - val_accuracy: 0.9033
# Epoch 123/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.2089 - accuracy: 0.9370 - val_loss: 0.2876 - val_accuracy: 0.9171
# Epoch 124/200
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2049 - accuracy: 0.9336 - val_loss: 0.3082 - val_accuracy: 0.9192
# Epoch 125/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2128 - accuracy: 0.9296 - val_loss: 0.3014 - val_accuracy: 0.9086
# Epoch 126/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2102 - accuracy: 0.9312 - val_loss: 0.2952 - val_accuracy: 0.9107
# Epoch 127/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.2001 - accuracy: 0.9373 - val_loss: 0.2959 - val_accuracy: 0.9214
# Epoch 128/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1957 - accuracy: 0.9362 - val_loss: 0.3131 - val_accuracy: 0.9086
# Epoch 129/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1989 - accuracy: 0.9328 - val_loss: 0.2848 - val_accuracy: 0.9192
# Epoch 130/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1801 - accuracy: 0.9394 - val_loss: 0.2830 - val_accuracy: 0.9118
# Epoch 131/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1906 - accuracy: 0.9384 - val_loss: 0.3086 - val_accuracy: 0.9171
# Epoch 132/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.2110 - accuracy: 0.9280 - val_loss: 0.3162 - val_accuracy: 0.9171
# Epoch 133/200
# 8/8 [==============================] - 0s 57ms/step - loss: 0.2057 - accuracy: 0.9370 - val_loss: 0.2890 - val_accuracy: 0.9118
# Epoch 134/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1903 - accuracy: 0.9376 - val_loss: 0.2959 - val_accuracy: 0.9139
# Epoch 135/200
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1847 - accuracy: 0.9381 - val_loss: 0.2895 - val_accuracy: 0.9129
# Epoch 136/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1832 - accuracy: 0.9400 - val_loss: 0.2979 - val_accuracy: 0.9192
# Epoch 137/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1937 - accuracy: 0.9368 - val_loss: 0.3168 - val_accuracy: 0.9097
# Epoch 138/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.2008 - accuracy: 0.9336 - val_loss: 0.3154 - val_accuracy: 0.9160
# Epoch 139/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2053 - accuracy: 0.9325 - val_loss: 0.3152 - val_accuracy: 0.9033
# Epoch 140/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1943 - accuracy: 0.9344 - val_loss: 0.2833 - val_accuracy: 0.9224
# Epoch 141/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1877 - accuracy: 0.9408 - val_loss: 0.2835 - val_accuracy: 0.9192
# Epoch 142/200
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1792 - accuracy: 0.9400 - val_loss: 0.2934 - val_accuracy: 0.9171
# Epoch 143/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1800 - accuracy: 0.9378 - val_loss: 0.2880 - val_accuracy: 0.9160
# Epoch 144/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1839 - accuracy: 0.9373 - val_loss: 0.3092 - val_accuracy: 0.9139
# Epoch 145/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1925 - accuracy: 0.9336 - val_loss: 0.2870 - val_accuracy: 0.9224
# Epoch 146/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1793 - accuracy: 0.9413 - val_loss: 0.2747 - val_accuracy: 0.9192
# Epoch 147/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1759 - accuracy: 0.9418 - val_loss: 0.2949 - val_accuracy: 0.9203
# Epoch 148/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1807 - accuracy: 0.9413 - val_loss: 0.3120 - val_accuracy: 0.9192
# Epoch 149/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1671 - accuracy: 0.9474 - val_loss: 0.2976 - val_accuracy: 0.9139
# Epoch 150/200
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1749 - accuracy: 0.9450 - val_loss: 0.2884 - val_accuracy: 0.9150
# Epoch 151/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1771 - accuracy: 0.9365 - val_loss: 0.2662 - val_accuracy: 0.9245
# Epoch 152/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1628 - accuracy: 0.9471 - val_loss: 0.2661 - val_accuracy: 0.9256
# Epoch 153/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1648 - accuracy: 0.9461 - val_loss: 0.3046 - val_accuracy: 0.9139
# Epoch 154/200
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1723 - accuracy: 0.9445 - val_loss: 0.2767 - val_accuracy: 0.9192
# Epoch 155/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1657 - accuracy: 0.9466 - val_loss: 0.2679 - val_accuracy: 0.9267
# Epoch 156/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1659 - accuracy: 0.9490 - val_loss: 0.3063 - val_accuracy: 0.9160
# Epoch 157/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1663 - accuracy: 0.9474 - val_loss: 0.2879 - val_accuracy: 0.9214
# Epoch 158/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1712 - accuracy: 0.9421 - val_loss: 0.2800 - val_accuracy: 0.9129
# Epoch 159/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1842 - accuracy: 0.9378 - val_loss: 0.2929 - val_accuracy: 0.9129
# Epoch 160/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.2024 - accuracy: 0.9330 - val_loss: 0.2945 - val_accuracy: 0.9214
# Epoch 161/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1729 - accuracy: 0.9469 - val_loss: 0.2815 - val_accuracy: 0.9182
# Epoch 162/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1627 - accuracy: 0.9501 - val_loss: 0.2734 - val_accuracy: 0.9224
# Epoch 163/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1627 - accuracy: 0.9455 - val_loss: 0.2834 - val_accuracy: 0.9203
# Epoch 164/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1651 - accuracy: 0.9485 - val_loss: 0.2982 - val_accuracy: 0.9182
# Epoch 165/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1522 - accuracy: 0.9532 - val_loss: 0.3051 - val_accuracy: 0.9160
# Epoch 166/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1667 - accuracy: 0.9498 - val_loss: 0.3302 - val_accuracy: 0.9171
# Epoch 167/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1616 - accuracy: 0.9490 - val_loss: 0.2770 - val_accuracy: 0.9245
# Epoch 168/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1485 - accuracy: 0.9498 - val_loss: 0.2850 - val_accuracy: 0.9160
# Epoch 169/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1470 - accuracy: 0.9487 - val_loss: 0.2826 - val_accuracy: 0.9267
# Epoch 170/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1556 - accuracy: 0.9493 - val_loss: 0.2930 - val_accuracy: 0.9214
# Epoch 171/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1628 - accuracy: 0.9503 - val_loss: 0.2863 - val_accuracy: 0.9118
# Epoch 172/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1488 - accuracy: 0.9509 - val_loss: 0.2732 - val_accuracy: 0.9299
# Epoch 173/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1496 - accuracy: 0.9511 - val_loss: 0.2768 - val_accuracy: 0.9203
# Epoch 174/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1410 - accuracy: 0.9543 - val_loss: 0.2765 - val_accuracy: 0.9214
# Epoch 175/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1527 - accuracy: 0.9540 - val_loss: 0.2775 - val_accuracy: 0.9139
# Epoch 176/200
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1432 - accuracy: 0.9511 - val_loss: 0.2854 - val_accuracy: 0.9277
# Epoch 177/200
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1517 - accuracy: 0.9474 - val_loss: 0.2935 - val_accuracy: 0.9203
# Epoch 178/200
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1637 - accuracy: 0.9471 - val_loss: 0.2819 - val_accuracy: 0.9245
# Epoch 179/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1521 - accuracy: 0.9514 - val_loss: 0.2805 - val_accuracy: 0.9160
# Epoch 180/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1359 - accuracy: 0.9588 - val_loss: 0.2740 - val_accuracy: 0.9107
# Epoch 181/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1480 - accuracy: 0.9524 - val_loss: 0.3000 - val_accuracy: 0.9214
# Epoch 182/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1411 - accuracy: 0.9551 - val_loss: 0.2751 - val_accuracy: 0.9245
# Epoch 183/200
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1430 - accuracy: 0.9538 - val_loss: 0.2650 - val_accuracy: 0.9256
# Epoch 184/200
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1383 - accuracy: 0.9559 - val_loss: 0.2702 - val_accuracy: 0.9224
# Epoch 185/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1476 - accuracy: 0.9503 - val_loss: 0.2998 - val_accuracy: 0.9171
# Epoch 186/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1700 - accuracy: 0.9421 - val_loss: 0.3227 - val_accuracy: 0.9192
# Epoch 187/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1780 - accuracy: 0.9421 - val_loss: 0.3029 - val_accuracy: 0.9065
# Epoch 188/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1750 - accuracy: 0.9400 - val_loss: 0.2942 - val_accuracy: 0.9139
# Epoch 189/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1485 - accuracy: 0.9548 - val_loss: 0.3006 - val_accuracy: 0.9203
# Epoch 190/200
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1431 - accuracy: 0.9538 - val_loss: 0.3086 - val_accuracy: 0.9214
# Epoch 191/200
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1483 - accuracy: 0.9509 - val_loss: 0.3103 - val_accuracy: 0.9150
# Epoch 192/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1661 - accuracy: 0.9450 - val_loss: 0.2897 - val_accuracy: 0.9235
# Epoch 193/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1640 - accuracy: 0.9469 - val_loss: 0.2858 - val_accuracy: 0.9182
# Epoch 194/200
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1463 - accuracy: 0.9516 - val_loss: 0.2710 - val_accuracy: 0.9256
# Epoch 195/200
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1485 - accuracy: 0.9532 - val_loss: 0.2775 - val_accuracy: 0.9224
# Epoch 196/200
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1329 - accuracy: 0.9559 - val_loss: 0.2823 - val_accuracy: 0.9203
# Epoch 197/200
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1421 - accuracy: 0.9524 - val_loss: 0.3464 - val_accuracy: 0.8884
# Epoch 198/200
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1788 - accuracy: 0.9360 - val_loss: 0.2794 - val_accuracy: 0.9203
# Epoch 199/200
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1481 - accuracy: 0.9516 - val_loss: 0.2953 - val_accuracy: 0.9203
# Epoch 200/200
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1546 - accuracy: 0.9493 - val_loss: 0.2834 - val_accuracy: 0.9235

# %%
plot_loss_history(CNNmodeln)

# %%
cnnn = CNN_Model(cube_stdn_3d.shape[2], filtersize)
cnnn.compile(optimizer="adam", loss="sparse_categorical_crossentropy",
             metrics=["accuracy"])
CNNmodeln = cnnn.fit({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn, 
                     validation_data=({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn),
                     epochs=60, batch_size=512)
# Out:
# Epoch 1/60
# 8/8 [==============================] - 1s 72ms/step - loss: 1.7386 - accuracy: 0.4022 - val_loss: 1.4133 - val_accuracy: 0.5303
# Epoch 2/60
# 8/8 [==============================] - 0s 52ms/step - loss: 1.3339 - accuracy: 0.5473 - val_loss: 1.2074 - val_accuracy: 0.5770
# Epoch 3/60
# 8/8 [==============================] - 0s 53ms/step - loss: 1.1490 - accuracy: 0.5991 - val_loss: 1.0622 - val_accuracy: 0.6451
# Epoch 4/60
# 8/8 [==============================] - 0s 51ms/step - loss: 1.0454 - accuracy: 0.6376 - val_loss: 0.9571 - val_accuracy: 0.7003
# Epoch 5/60
# 8/8 [==============================] - 0s 60ms/step - loss: 0.9468 - accuracy: 0.6740 - val_loss: 0.8709 - val_accuracy: 0.6939
# Epoch 6/60
# 8/8 [==============================] - 1s 115ms/step - loss: 0.8544 - accuracy: 0.7147 - val_loss: 0.7779 - val_accuracy: 0.7513
# Epoch 7/60
# 8/8 [==============================] - 0s 54ms/step - loss: 0.7977 - accuracy: 0.7341 - val_loss: 0.7291 - val_accuracy: 0.7620
# Epoch 8/60
# 8/8 [==============================] - 0s 55ms/step - loss: 0.7486 - accuracy: 0.7402 - val_loss: 0.7439 - val_accuracy: 0.7386
# Epoch 9/60
# 8/8 [==============================] - 0s 55ms/step - loss: 0.7384 - accuracy: 0.7394 - val_loss: 0.6749 - val_accuracy: 0.7821
# Epoch 10/60
# 8/8 [==============================] - 0s 50ms/step - loss: 0.7078 - accuracy: 0.7519 - val_loss: 0.6722 - val_accuracy: 0.7683
# Epoch 11/60
# 8/8 [==============================] - 0s 57ms/step - loss: 0.6842 - accuracy: 0.7601 - val_loss: 0.6380 - val_accuracy: 0.7641
# Epoch 12/60
# 8/8 [==============================] - 0s 50ms/step - loss: 0.6558 - accuracy: 0.7734 - val_loss: 0.6189 - val_accuracy: 0.8002
# Epoch 13/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.6321 - accuracy: 0.7808 - val_loss: 0.5914 - val_accuracy: 0.8119
# Epoch 14/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.6142 - accuracy: 0.7832 - val_loss: 0.6441 - val_accuracy: 0.7673
# Epoch 15/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.6147 - accuracy: 0.7880 - val_loss: 0.5718 - val_accuracy: 0.8098
# Epoch 16/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.6047 - accuracy: 0.7909 - val_loss: 0.5756 - val_accuracy: 0.8225
# Epoch 17/60
# 8/8 [==============================] - 0s 39ms/step - loss: 0.5930 - accuracy: 0.7930 - val_loss: 0.5872 - val_accuracy: 0.8023
# Epoch 18/60
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5790 - accuracy: 0.7981 - val_loss: 0.5587 - val_accuracy: 0.8098
# Epoch 19/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.5598 - accuracy: 0.8039 - val_loss: 0.5459 - val_accuracy: 0.8236
# Epoch 20/60
# 8/8 [==============================] - 0s 46ms/step - loss: 0.5704 - accuracy: 0.7994 - val_loss: 0.5527 - val_accuracy: 0.8151
# Epoch 21/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5461 - accuracy: 0.8127 - val_loss: 0.5352 - val_accuracy: 0.8236
# Epoch 22/60
# 8/8 [==============================] - 0s 49ms/step - loss: 0.5378 - accuracy: 0.8127 - val_loss: 0.5096 - val_accuracy: 0.8363
# Epoch 23/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5168 - accuracy: 0.8247 - val_loss: 0.5307 - val_accuracy: 0.8183
# Epoch 24/60
# 8/8 [==============================] - 0s 55ms/step - loss: 0.5285 - accuracy: 0.8180 - val_loss: 0.5092 - val_accuracy: 0.8459
# Epoch 25/60
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4956 - accuracy: 0.8334 - val_loss: 0.4967 - val_accuracy: 0.8512
# Epoch 26/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4971 - accuracy: 0.8340 - val_loss: 0.5061 - val_accuracy: 0.8342
# Epoch 27/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.5077 - accuracy: 0.8350 - val_loss: 0.4903 - val_accuracy: 0.8502
# Epoch 28/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4901 - accuracy: 0.8411 - val_loss: 0.4751 - val_accuracy: 0.8597
# Epoch 29/60
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4716 - accuracy: 0.8448 - val_loss: 0.4716 - val_accuracy: 0.8523
# Epoch 30/60
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4739 - accuracy: 0.8483 - val_loss: 0.4717 - val_accuracy: 0.8533
# Epoch 31/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4661 - accuracy: 0.8464 - val_loss: 0.4503 - val_accuracy: 0.8746
# Epoch 32/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.4642 - accuracy: 0.8502 - val_loss: 0.4666 - val_accuracy: 0.8704
# Epoch 33/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.4429 - accuracy: 0.8565 - val_loss: 0.4478 - val_accuracy: 0.8714
# Epoch 34/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4477 - accuracy: 0.8555 - val_loss: 0.4351 - val_accuracy: 0.8810
# Epoch 35/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.4363 - accuracy: 0.8613 - val_loss: 0.4358 - val_accuracy: 0.8831
# Epoch 36/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.4219 - accuracy: 0.8653 - val_loss: 0.4282 - val_accuracy: 0.8799
# Epoch 37/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.4337 - accuracy: 0.8573 - val_loss: 0.4457 - val_accuracy: 0.8672
# Epoch 38/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.4254 - accuracy: 0.8576 - val_loss: 0.4333 - val_accuracy: 0.8810
# Epoch 39/60
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4198 - accuracy: 0.8626 - val_loss: 0.4472 - val_accuracy: 0.8650
# Epoch 40/60
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4168 - accuracy: 0.8685 - val_loss: 0.4128 - val_accuracy: 0.8852
# Epoch 41/60
# 8/8 [==============================] - 0s 46ms/step - loss: 0.3994 - accuracy: 0.8730 - val_loss: 0.4219 - val_accuracy: 0.8778
# Epoch 42/60
# 8/8 [==============================] - 0s 51ms/step - loss: 0.4025 - accuracy: 0.8693 - val_loss: 0.4141 - val_accuracy: 0.8778
# Epoch 43/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3973 - accuracy: 0.8650 - val_loss: 0.4297 - val_accuracy: 0.8704
# Epoch 44/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3904 - accuracy: 0.8799 - val_loss: 0.4107 - val_accuracy: 0.8852
# Epoch 45/60
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3964 - accuracy: 0.8711 - val_loss: 0.4456 - val_accuracy: 0.8618
# Epoch 46/60
# 8/8 [==============================] - 0s 46ms/step - loss: 0.4054 - accuracy: 0.8629 - val_loss: 0.4557 - val_accuracy: 0.8470
# Epoch 47/60
# 8/8 [==============================] - 0s 49ms/step - loss: 0.4108 - accuracy: 0.8624 - val_loss: 0.4217 - val_accuracy: 0.8842
# Epoch 48/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3969 - accuracy: 0.8685 - val_loss: 0.4253 - val_accuracy: 0.8725
# Epoch 49/60
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3704 - accuracy: 0.8842 - val_loss: 0.3975 - val_accuracy: 0.8789
# Epoch 50/60
# 8/8 [==============================] - 0s 47ms/step - loss: 0.3746 - accuracy: 0.8746 - val_loss: 0.3941 - val_accuracy: 0.8874
# Epoch 51/60
# 8/8 [==============================] - 0s 41ms/step - loss: 0.3834 - accuracy: 0.8701 - val_loss: 0.3857 - val_accuracy: 0.8874
# Epoch 52/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3819 - accuracy: 0.8730 - val_loss: 0.3929 - val_accuracy: 0.8916
# Epoch 53/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3716 - accuracy: 0.8812 - val_loss: 0.4035 - val_accuracy: 0.8672
# Epoch 54/60
# 8/8 [==============================] - 0s 42ms/step - loss: 0.3661 - accuracy: 0.8810 - val_loss: 0.3789 - val_accuracy: 0.8842
# Epoch 55/60
# 8/8 [==============================] - 0s 40ms/step - loss: 0.3543 - accuracy: 0.8874 - val_loss: 0.3854 - val_accuracy: 0.8863
# Epoch 56/60
# 8/8 [==============================] - 0s 43ms/step - loss: 0.3570 - accuracy: 0.8855 - val_loss: 0.3892 - val_accuracy: 0.8820
# Epoch 57/60
# 8/8 [==============================] - 0s 44ms/step - loss: 0.3504 - accuracy: 0.8850 - val_loss: 0.4014 - val_accuracy: 0.8757
# Epoch 58/60
# 8/8 [==============================] - 0s 51ms/step - loss: 0.3332 - accuracy: 0.8911 - val_loss: 0.3952 - val_accuracy: 0.8895
# Epoch 59/60
# 8/8 [==============================] - 0s 45ms/step - loss: 0.3384 - accuracy: 0.8889 - val_loss: 0.3720 - val_accuracy: 0.8937
# Epoch 60/60
# 8/8 [==============================] - 0s 48ms/step - loss: 0.3420 - accuracy: 0.8850 - val_loss: 0.3739 - val_accuracy: 0.8927

# %%
# model accuracy on training and testing sets

train_loss, train_acc = cnnn.evaluate({"spectra":cube_trainn2, "spatial":xy_trainn}, cube_train_labelsn)
test_loss, test_acc = cnnn.evaluate({"spectra":cube_testn2, "spatial":xy_testn}, cube_test_labelsn)

print(train_acc, test_acc)
# Out:
# 118/118 [==============================] - 1s 6ms/step - loss: 0.2781 - accuracy: 0.9137
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3739 - accuracy: 0.8927
# 0.913655698299408 0.8926673531532288

# %% [markdown]
# ### Predict pixel classification on north facing image

# %%
cube_standardn_1 = cube_standard_north.reshape(cube_standard_north.shape[0], cube_standard_north.shape[1], 1)
print(cube_standardn_1.shape)
xyn_2d = xyn.reshape((xyn.shape[0] * xyn.shape[1]), xyn.shape[2])
print(xyn_2d.shape)
# Out:
# (1995200, 212, 1)
# (1995200, 2)

# %%
# classify entire binned cube
import time
start_time = time.time()

probCuben = cnnn.predict({"spectra":cube_standardn_1, "spatial":xyn_2d})

elapsed_time = time.time() - start_time
print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# 00:05:26

# %%
predictCuben = probCuben.argmax(axis=-1)

# %%
predictCube_reshapen = predictCuben.reshape(cube_sub_north.shape[1], cube_sub_north.shape[2])

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.tick_params(labelsize=10)
ax.imshow(arrayShow, aspect=0.4)
lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.show()
#fig.savefig("./plots/CNN_change_params_spatial_train_all_5_north_predict_map.png", bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as ListedColorMap
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter
# %matplotlib inline

cmap = {0:[0,0.32549,0.62353,1], 1:[0.93333,0.9098,0.77255,1], 2:[0,0.61961,0.45098,1],  3:[0.33725,0.70588,0.91373,1],
        4:[0,0,0,1], 5:[1,0.82353,0,1], 6:[0.90196,0.62353,0,1], 7:[0.83529,0.36863,0,1],
        8:[0.8,0.47451,0.65490,1]}
labels = {0:'sky', 1:'clouds', 2:'vegetation', 3:'water', 4:'built',
          5:'windows', 6:'roads', 7:'cars', 8:'metal'}
arrayShow = np.array([[cmap[i] for i in j] for j in predictCube_reshapen])
patches = [mpatches.Patch(color=cmap[i], label=labels[i]) for i in cmap]

fig = plt.figure(figsize=(15,15))
#ax = fig.add_axes([0.1,0.1,0.9,0.9])
#ax.tick_params(labelsize=10)
plt.imshow(arrayShow, aspect=0.4)
#lgd = ax.legend(handles=patches, bbox_to_anchor=(1,0.75), loc='upper left', borderaxespad=1.0, prop={'size':10}, ncol=1)
plt.axis('off')
plt.show()
fig.savefig("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.png".format(num_of_bins),
            bbox_inches='tight', dpi=300)

# %%
import pickle
pickle.dump(predictCube_reshapen,
            open("./plots/CNN_Model2_spatial_train_north_binned_{0}_test_north_predict_map.pickle".format(num_of_bins),
                 "wb"))

# %% [markdown]
# ### Evaluation Metrics (north facing)

# %%
labelsn_pred_sky = predictCube_reshapen[sky_coordsn[sky_test_indn[:], 0], sky_coordsn[sky_test_indn[:], 1]]
labelsn_pred_clouds = predictCube_reshapen[clouds_coordsn[clouds_test_indn[:], 0], clouds_coordsn[clouds_test_indn[:],1]]
labelsn_pred_veg = predictCube_reshapen[veg_coordsn[veg_test_indn[:],0], veg_coordsn[veg_test_indn[:],1]]
labelsn_pred_wtr = predictCube_reshapen[wtr_coordsn[wtr_test_indn[:],0], wtr_coordsn[wtr_test_indn[:],1]]
labelsn_pred_blt = predictCube_reshapen[blt_coordsn[blt_test_indn[:],0], blt_coordsn[blt_test_indn[:],1]]
labelsn_pred_windows = predictCube_reshapen[windows_coordsn[windows_test_indn[:],0], windows_coordsn[windows_test_indn[:],1]]
labelsn_pred_rds = predictCube_reshapen[rds_coordsn[rds_test_indn[:],0], rds_coordsn[rds_test_indn[:],1]]
labelsn_pred_cars = predictCube_reshapen[cars_coordsn[cars_test_indn[:],0], cars_coordsn[cars_test_indn[:],1]]
labelsn_pred_mtl = predictCube_reshapen[mtl_coordsn[mtl_test_indn[:],0], mtl_coordsn[mtl_test_indn[:],1]]

labelsn_pred = np.concatenate((labelsn_pred_sky, labelsn_pred_clouds, labelsn_pred_veg, labelsn_pred_wtr, 
                             labelsn_pred_blt, labelsn_pred_windows, labelsn_pred_rds, labelsn_pred_cars, labelsn_pred_mtl))

# %%
labelsn_true_sky = np.full(len(sky_test_indn), 0)
labelsn_true_clouds = np.full(len(clouds_test_indn), 1)
labelsn_true_veg = np.full(len(veg_test_indn), 2)
labelsn_true_wtr = np.full(len(wtr_test_indn), 3)
labelsn_true_blt = np.full(len(blt_test_indn), 4)
labelsn_true_windows = np.full(len(windows_test_indn), 5)
labelsn_true_rds = np.full(len(rds_test_indn), 6)
labelsn_true_cars = np.full(len(cars_test_indn), 7)
labelsn_true_mtl = np.full(len(mtl_test_indn), 8)

labelsn_true = np.concatenate((labelsn_true_sky, labelsn_true_clouds, labelsn_true_veg, labelsn_true_wtr, 
                             labelsn_true_blt, labelsn_true_windows, labelsn_true_rds, labelsn_true_cars, labelsn_true_mtl))

# %%
print(labelsn_pred.shape)
print(labelsn_true.shape)
# Out:
# (941,)
# (941,)

# %%
from sklearn import metrics

print("Confusion Matrix")
print(metrics.confusion_matrix(labelsn_true, labelsn_pred))

print("")
print("Accuracy Score")
print(metrics.accuracy_score(labelsn_true, labelsn_pred))

target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
print("")
print("Classification Report")
print(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
# Out:
# Confusion Matrix
# [[ 60   0   0   0   0   0   0   0   0]
#  [  0  40   0   0   0   0   0   0   0]
#  [  0   0 139   0   0   0   1   0   0]
#  [  0   0   0 122   0   0   0   0   2]
#  [  0   0   0   1 306   8   2   0   3]
#  [  0   0   0   1   4 106   7   0   2]
#  [  0   0   1   0   5  15  24   0   5]
#  [  0   0   0   0  15  10   1  23   1]
#  [  0   0   0   2   7   8   0   0  20]]
#
# Accuracy Score
# 0.8926673751328374
#
# Classification Report
#              precision    recall  f1-score   support
#
#         sky       1.00      1.00      1.00        60
#      clouds       1.00      1.00      1.00        40
#  vegetation       0.99      0.99      0.99       140
#       water       0.97      0.98      0.98       124
#       built       0.91      0.96      0.93       320
#     windows       0.72      0.88      0.79       120
#       roads       0.69      0.48      0.56        50
#        cars       1.00      0.46      0.63        50
#       metal       0.61      0.54      0.57        37
#
# avg / total       0.90      0.89      0.89       941

# %%
f = open("./metrics/CNN_Model2_spatial_train_north_binned_{0}_test_north_metrics.txt".format(num_of_bins), "w")
f.write("Confusion Matrix")
f.write('\n')
f.write(str(metrics.confusion_matrix(labelsn_true, labelsn_pred)))
f.write('\n')
f.write('\n')
f.write("Accuracy Score")
f.write('\n')
f.write(str(metrics.accuracy_score(labelsn_true, labelsn_pred)))
target_names = ['sky', 'clouds', 'vegetation', 'water', 'built', 'windows', 'roads', 'cars', 'metal']
f.write('\n')
f.write('\n')
f.write("Classification Report")
f.write('\n')
f.write(metrics.classification_report(labelsn_true, labelsn_pred, target_names=target_names))
f.close()

# %%
print(num_of_bins, filtersize)
# Out:
# 212 13
